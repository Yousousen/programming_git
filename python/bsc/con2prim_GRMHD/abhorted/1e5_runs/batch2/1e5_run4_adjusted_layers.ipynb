# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics

# %% [markdown]
# ## How to use this notebook
#
# ### Local installation
#
# 1. Install required packages with `pip install -r requirements.txt` to your desired environment.
# 2. If a script version of this notebook is desired, comment (not uncomment) the first line of `nbconvert` cell.
#
# ### Colab installation
#
# 1.  Comment (not uncomment) the first line of the drive mounting cell.
# 2.  Comment (not uncomment) the first line of the `pip install` cell.
#
# <!-- - For colab we also want to set the runtime to GPU by clicking _Change runtime_ in the _Runtime_ menu, and -->
# <!-- - We want to wait for the google drive connection popup to appear and follow the instructions. -->
#
# ### Loading / Generating data
# 3. Set `LOAD_DATA_FROM_CSV` to `True` / `False` to load data from csv files / generate data in this notebook.
#
# ### Training without optimization
#
# 4. Set `OPTIMIZE = False` in section _Constants and flags to set_.
# 5. Run the entire notebook.
#
# ### Training with optimization
#
# 4. Set `OPTIMIZE = True` in section _Constants and flags to set_.
# 5. Run the entire notebook.
#
# ### Loading an already trained model
#
# 4. Run cells in section _Initialization_.
# 5. Run cells with definitions in section _Input data and labels_.
# 6. Run cell with the definition of _Net_ in section _Defining the neural network_.
# 7. Make sure the `net.pth`, `optimizer.pth`, `scheduler.pth`, `var_dict.json` and `train_output.csv` files are in the directory containing this notebook.
# 8. Run the cells in section _Loading_ and continue from there.
#
# ### Generating the C++ model
#
# 9. Run section _Porting the model to C++_, this requires a model to be loaded.
# 10. Set the path to the `net.pt` file in the C++ source file.
# 11. `mkdir build && cd build`,
# 12. Configure a `CMakeLists.txt` file as is done [here](https://pytorch.org/cppdocs/installing.html).
# 13. `cmake -DCMAKE_PREFIX_PATH=/path/to/libtorch/ ..`,
# 14. Compile and run, e.g. `cmake --build . --config release && ./<executable name>`

# %% [markdown]
# ## Initialization

# %% [markdown]
# Use this first cell to **convert this notebook** to a python script.

# %%
# %%script echo skipping
#
# !jupyter nbconvert GRMHD_ML.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on **google colab**,

# %%
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")
# change this to your desired folder
drive_folder = "/content/drive/My Drive/bsc/con2prim_GRMHD/1e5_runs/adjusted_layers"

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
#%%script echo skipping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.6 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.2 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Installing collected packages: tensorboardX, Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0 tensorboardX-2.6

# %% [markdown]
# Importing the **libraries**,

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx
import pandas as pd

# %% [markdown]
# ### Constants and flags to set
# Defining some constants and parameters for convenience.
#
# **NOTE**: Some **subparameters** still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023) in the case the model is being trained without optimization.

# %%
# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

N_TRIALS = 300 # Number of trials for hyperparameter optimization # NOTE: Set this properly.
OPTIMIZE = True # Whether to optimize the hyperparameters or to use predetermined values. # NOTE: Set this properly.
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.
LOAD_DATA_FROM_CSV = False  # If not true we generate the data in this file and save to {x_train,y_train,x_test,y_test}.csv, otherwise we load the data from files of the same name. # NOTE: Set this before properly.

csv_filenames = { # File names to load input data and labels from if LOAD_DATA_FROM_CSV is True.
    "x_train": "x_train.csv",
    "x_val": "x_val.csv",
    "x_test": "x_test.csv",
    "y_train": "y_train.csv",
    "y_val": "y_val.csv",
    "y_test": "y_test.csv",
}

# Values to use for hyperparameters if OPTIMIZE is False; set these to the best parameters found by Optuna.
# NOTE: TODO: Currently (Sat May 27 05:16:57 PM CEST 2023) there are still subparameters to be set in create_model function.
N_LAYERS_NO_OPT = 3
N_UNITS_NO_OPT = [555, 458, 115]
HIDDEN_ACTIVATION_NAME_NO_OPT = "LeakyReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "RMSprop"
LR_NO_OPT = 0.000122770896701404
BATCH_SIZE_NO_OPT = 49
N_EPOCHS_NO_OPT = 500 # NOTE: Set this properly.
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"
DROPOUT_RATE_NO_OPT = 0.2

N_INPUTS = 14  # Number of input features.
N_OUTPUTS = 1  # Number of outputs.
Gamma = 5/3  # Adiabatic index

n_samples = 1e5 # NOTE: Set this properly.
train_frac = 0.7  # 70% of data for training
val_frac = 0.15  # 15% of data for validation, rest for testing

rho_interval = (0, 2) 
epsilon_interval = (1e-2, 2000)  # Will be sampled in log space
vx_interval = (0, 0.999)  
vy_interval = (0, 0.999)  
vz_interval = (0, 0.999)  
Bx_interval = (-10, 10)  
By_interval = (-10, 10)  
Bz_interval = (-10, 10)  
gxx_interval = (0.9, 1.1)
gxy_interval = (0, 0.1)
gxz_interval = (0, 0.1)
gyy_interval = (0.9, 1.1)
gyz_interval = (0, 0.1)
gzz_interval = (0.9, 1.1)

np.random.seed(72) # Comment for true random data.

# %% [markdown]
# ## Input data and labels
#
# We either generate the data or load the data. First the definitions for generating the data come below.

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    # Adding some assertions to check that the input tensors are valid and have 
    # the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    print('rho.shape: ', rho.shape)
    print('epsilon.shape: ', epsilon.shape)
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (Gamma - 1) * rho * epsilon

def sample_primitive_variables_and_metric():
    rho = np.random.uniform(*rho_interval)  
    epsilon = np.random.uniform(*np.log10(epsilon_interval))
    vx = np.random.uniform(*vx_interval)  
    vy = np.random.uniform(*vy_interval)  
    vz = np.random.uniform(*vz_interval)  
    Bx = np.random.uniform(*Bx_interval)  
    By = np.random.uniform(*By_interval)  
    Bz = np.random.uniform(*Bz_interval)  
    gxx = np.random.uniform(*gxx_interval)
    gxy = np.random.uniform(*gxy_interval)
    gxz = np.random.uniform(*gxz_interval)
    gyy = np.random.uniform(*gyy_interval)
    gyz = np.random.uniform(*gyz_interval)
    gzz = np.random.uniform(*gzz_interval)

    return rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz

def check_sample(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    wtemp_expr = 1 - (gxx * vx**2 + gyy * vy**2 + gzz * vz**2 + 2 * gxy * vx * vy + 2 * gxz * vx * vz + 2 * gyz * vy * vz)
    sdet_expr = gxx * gyy * gzz + 2 * gxy * gxz * gyz - gxx * gyz ** 2 - gyy * gxz ** 2 - gzz * gxy ** 2
    if vx**2 + vy**2 + vz**2 >= 1 or wtemp_expr < 0 or sdet_expr < 0:
        # print(f"Sample failed checks. vx^2+vy^2+vz^2: {vx**2 + vy**2 + vz**2}, wtemp_expr: {wtemp_expr}, sdet_expr: {sdet_expr}")
        return False
    else:
        # print(f"Sample passed checks. vx^2+vy^2+vz^2: {vx**2 + vy**2 + vz**2}, wtemp_expr: {wtemp_expr}, sdet_expr: {sdet_expr}")
        return True

def generate_samples(n_samples):
    samples = []
    while len(samples) < n_samples:
        sample = sample_primitive_variables_and_metric()
        if check_sample(*sample):
            samples.append(sample)
        # print(f"Number of valid samples: {len(samples)}")
    return zip(*samples)
def sdet(gxx, gxy, gxz, gyy, gyz, gzz):
    # Determinant of the three metric.
    return (gxx * gyy * gzz + 2 * gxy * gxz * gyz - gxx * gyz ** 2 - gyy * gxz ** 2 - gzz * gxy ** 2) ** 0.5

# Defining a function that computes conserved variables from primitive variables and the metric
# We follow the source code of GRaM-X: A new GPU-accelerated dynamical spacetime GRMHD code for Exascale
# computing with the Einstein Toolkit of Shankar et al.
def compute_conserved_variables(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    pres = eos_analytic(rho, epsilon)
    wtemp = 1 / (1 - (gxx * vx**2 + gyy * vy**2 + gzz * vz**2 +
        2 * gxy * vx * vy + 2 * gxz * vx * vz +
        2 * gyz * vy * vz))**0.5

    vlowx = gxx * vx + gxy * vy + gxz * vz
    vlowy = gxy * vx + gyy * vy + gyz * vz
    vlowz = gxz * vx + gyz * vy + gzz * vz

    Bxlow = gxx * Bx + gxy * By + gxz * Bz
    Bylow = gxy * Bx + gyy * By + gyz * Bz
    Bzlow = gxz * Bx + gyz * By + gzz * Bz

    B2 = Bxlow * Bx + Bylow * By + Bzlow * Bz

    Bdotv = Bxlow * vx + Bylow * vy + Bzlow * vz
    Bdotv2 = Bdotv * Bdotv
    wtemp2 = wtemp * wtemp
    b2 = B2 / wtemp2 + Bdotv2
    ab0 = wtemp * Bdotv

    blowx = (gxx * Bx + gxy * By + gxz * Bz) / wtemp + wtemp * Bdotv * vlowx
    blowy = (gxy * Bx + gyy * By + gyz * Bz) / wtemp + wtemp * Bdotv * vlowy
    blowz = (gxz * Bx + gyz * By + gzz * Bz) / wtemp + wtemp * Bdotv * vlowz

    hrhow2 = (rho * (1 + epsilon) + pres + b2) * (wtemp) * (wtemp)

    D = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * rho * (wtemp)
    Sx = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowx - ab0 * blowx)
    Sy = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowy - ab0 * blowy)
    Sz = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowz - ab0 * blowz)
    tau = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 - pres - b2 / 2 - ab0 * ab0) - D
    Bconsx = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * Bx
    Bconsy = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * By
    Bconsz = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * Bz

    return D, Sx, Sy, Sz, tau, Bconsx, Bconsy, Bconsz

def generate_input_data(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    rho = torch.tensor(np.array(rho), dtype=torch.float32).to(device)
    epsilon = torch.tensor(np.array(epsilon), dtype=torch.float32).to(device)
    vx = torch.tensor(np.array(vx), dtype=torch.float32).to(device)
    vy = torch.tensor(np.array(vy), dtype=torch.float32).to(device)
    vz = torch.tensor(np.array(vz), dtype=torch.float32).to(device)
    Bx = torch.tensor(np.array(Bx), dtype=torch.float32).to(device)
    By = torch.tensor(np.array(By), dtype=torch.float32).to(device)
    Bz = torch.tensor(np.array(Bz), dtype=torch.float32).to(device)
    gxx = torch.tensor(np.array(gxx), dtype=torch.float32).to(device)
    gxy = torch.tensor(np.array(gxy), dtype=torch.float32).to(device)
    gxz = torch.tensor(np.array(gxz), dtype=torch.float32).to(device)
    gyy = torch.tensor(np.array(gyy), dtype=torch.float32).to(device)
    gyz = torch.tensor(np.array(gyz), dtype=torch.float32).to(device)
    gzz = torch.tensor(np.array(gzz), dtype=torch.float32).to(device)

    D, Sx, Sy, Sz, tau, Bscriptx, Bscripty, Bscriptz = compute_conserved_variables(
        rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz
    ) 

    # Add gxx, gxy, gxz, gyy, gyz, gzz to the tensor
    x = torch.stack([D, Sx, Sy, Sz, tau, Bscriptx, Bscripty, Bscriptz, gxx, gxy, gxz, gyy, gyz, gzz], axis=1)
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
# We use the definitions as given in Recovery schemes for primitive variables in
# general-relativistic magnetohydrodynamics of Siegel et al.
def generate_labels(rho, epsilon, vx, vy, vz):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(np.array(rho), dtype=torch.float32).to(device)
    epsilon = torch.tensor(np.array(epsilon), dtype=torch.float32).to(device)
    vx = torch.tensor(np.array(vx), dtype=torch.float32).to(device)
    vy = torch.tensor(np.array(vy), dtype=torch.float32).to(device)
    vz = torch.tensor(np.array(vz), dtype=torch.float32).to(device)

    # Computing the required quantities
    pres = eos_analytic(rho, epsilon)
    h = 1 + epsilon + pres / rho
    W = 1 / torch.sqrt(1 - (vx * vx + vy * vy + vz * vz))

    # Returning the output data tensor
    return h * W

# %% [markdown]
# ### Generating or loading input data and labels

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
if LOAD_DATA_FROM_CSV:
    # Load the data from CSV files
    x_train = pd.read_csv(csv_filenames["x_train"]).values
    y_train = pd.read_csv(csv_filenames["y_train"]).values.squeeze()  # reshape to 1D
    x_val = pd.read_csv(csv_filenames["x_val"]).values
    y_val = pd.read_csv(csv_filenames["y_val"]).values.squeeze()  # reshape to 1D
    x_test = pd.read_csv(csv_filenames["x_test"]).values
    y_test = pd.read_csv(csv_filenames["y_test"]).values.squeeze()  # reshape to 1D

    # Convert numpy arrays to tensors
    x_train = torch.from_numpy(x_train).float().to(device)
    y_train = torch.from_numpy(y_train).float().to(device)
    x_val = torch.from_numpy(x_val).float().to(device)
    y_val = torch.from_numpy(y_val).float().to(device)
    x_test = torch.from_numpy(x_test).float().to(device)
    y_test = torch.from_numpy(y_test).float().to(device)

    # This is an alternative to having if clauses around the cells that visualize these variables.
    rho = epsilon = vx = vy = vz = Bx = By = Bz = gxx = gxy = gxz = gyy = gyz  = gzz = None

# %%
if not LOAD_DATA_FROM_CSV:
    # Sample primitive variables and metric
    rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz = generate_samples(n_samples)

# %%
if not LOAD_DATA_FROM_CSV:
    # Generate data and labels.
    x = generate_input_data(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz)
    y = generate_labels(rho, epsilon, vx, vy, vz)

    # Calculate the number of samples in each set
    n_train_samples = int(n_samples * train_frac)
    n_val_samples = int(n_samples * val_frac)

    # Create the data sets
    x_train = x[:n_train_samples]
    y_train = y[:n_train_samples]
    x_val = x[n_train_samples : n_train_samples + n_val_samples]
    y_val = y[n_train_samples : n_train_samples + n_val_samples]
    x_test = x[n_train_samples + n_val_samples :]
    y_test = y[n_train_samples + n_val_samples :]

    # Save the data to CSV files; tensors need to be converted numpy arrays for saving in CSV.
    pd.DataFrame(x_train.cpu().numpy()).to_csv(csv_filenames["x_train"], index=False)
    save_file(csv_filenames["x_train"])
    pd.DataFrame(y_train.cpu().numpy()).to_csv(csv_filenames["y_train"], index=False)
    save_file(csv_filenames["y_train"])

    pd.DataFrame(x_val.cpu().numpy()).to_csv(csv_filenames["x_val"], index=False)
    save_file(csv_filenames["x_val"])
    pd.DataFrame(y_val.cpu().numpy()).to_csv(csv_filenames["y_val"], index=False)
    save_file(csv_filenames["y_val"])

    pd.DataFrame(x_test.cpu().numpy()).to_csv(csv_filenames["x_test"], index=False)
    save_file(csv_filenames["x_test"])
    pd.DataFrame(y_test.cpu().numpy()).to_csv(csv_filenames["y_test"], index=False)
    save_file(csv_filenames["y_test"])
# Out:
# rho.shape:  torch.Size([100000])
# epsilon.shape:  torch.Size([100000])
# rho.shape:  torch.Size([100000])
# epsilon.shape:  torch.Size([100000])

# %%
x_train.shape
y_train.shape
x_val.shape
y_val.shape
x_test.shape
y_test.shape
x_train
y_train
x_val
y_val
x_test
y_test
# Out:
# torch.Size([70000, 14])
# torch.Size([70000])
# torch.Size([15000, 14])
# torch.Size([15000])
# torch.Size([15000, 14])
# torch.Size([15000])
# tensor([[ 3.3635e-01,  3.2057e+01,  2.7123e+01,  ...,  1.0893e+00,
#           4.1626e-02,  9.4949e-01],
#         [ 1.2159e+00,  8.3975e+00,  1.1721e+01,  ...,  9.2051e-01,
#           6.1788e-02,  1.0248e+00],
#         [ 1.6155e+00,  2.8689e+01,  4.7461e+00,  ...,  9.7287e-01,
#           1.7029e-02,  9.2619e-01],
#         ...,
#         [ 3.3402e+00,  1.2135e+02,  2.2167e+01,  ...,  9.4243e-01,
#           2.8055e-02,  1.0568e+00],
#         [ 2.4679e+00, -2.5273e+01,  2.1311e+01,  ...,  1.0864e+00,
#           7.2649e-02,  9.0914e-01],
#         [ 1.4380e+00,  2.9429e+01,  2.1760e+01,  ...,  9.9664e-01,
#           4.3986e-02,  1.0335e+00]], device='cuda:0')
# tensor([ 5.8095,  0.8273,  4.5749,  ...,  0.5855, -1.9226,  7.9780],
#        device='cuda:0')
# tensor([[ 4.3029e-01,  4.0047e+01,  9.1814e+01,  ...,  1.0559e+00,
#           5.4882e-02,  9.1970e-01],
#         [ 4.9670e-01,  1.6046e+01,  2.0885e+01,  ...,  9.6770e-01,
#           5.4741e-02,  9.2722e-01],
#         [ 2.1501e+00,  5.4981e+01,  2.1624e+01,  ...,  9.0101e-01,
#           7.4360e-02,  9.6084e-01],
#         ...,
#         [ 4.0244e-01,  8.1749e+00,  8.4463e+00,  ...,  9.4709e-01,
#           6.7633e-02,  1.0171e+00],
#         [ 2.2378e+00,  4.3011e+01, -2.9771e+01,  ...,  1.0964e+00,
#           2.9217e-02,  1.0023e+00],
#         [ 1.3582e+01,  7.0418e+01,  8.4664e+01,  ...,  9.1355e-01,
#           7.2177e-02,  1.0207e+00]], device='cuda:0')
# tensor([ 7.1012,  0.9422, 10.2281,  ...,  1.2135, -3.0563,  4.1973],
#        device='cuda:0')
# tensor([[ 3.0393e-01,  8.5735e+00, -4.3442e+01,  ...,  1.0437e+00,
#           1.4891e-02,  9.5644e-01],
#         [ 6.6606e+00,  1.7643e+02,  1.5964e+02,  ...,  1.0605e+00,
#           3.0852e-02,  1.0577e+00],
#         [ 1.3400e+00,  6.1293e+01,  5.8368e+01,  ...,  1.0735e+00,
#           2.2829e-02,  1.0897e+00],
#         ...,
#         [ 1.1818e+00,  1.1499e+01,  4.6317e+01,  ...,  1.0812e+00,
#           9.4329e-02,  9.4914e-01],
#         [ 9.9683e-01,  1.6335e+00,  1.9383e+01,  ...,  1.0236e+00,
#           2.0724e-02,  1.0601e+00],
#         [ 1.2923e+00,  3.4449e+01,  6.4798e+01,  ...,  9.7912e-01,
#           4.4840e-02,  9.4299e-01]], device='cuda:0')
# tensor([-2.1585, 21.0883,  3.5675,  ...,  2.8958,  0.6479,  5.3626],
#        device='cuda:0')

# %%
torch.isnan(x_train).any()
torch.isnan(x_val).any()
torch.isnan(x_test).any()
torch.isnan(y_train).any()
torch.isnan(y_val).any()
torch.isnan(y_test).any()
# Out:
# tensor(False, device='cuda:0')
# tensor(False, device='cuda:0')
# tensor(False, device='cuda:0')
# tensor(False, device='cuda:0')
# tensor(False, device='cuda:0')
# tensor(False, device='cuda:0')

# %%
nan_mask_train = torch.isnan(x_train)     # get a boolean mask indicating NaN values
nan_indices_train = torch.where(nan_mask_train)  # get the indices of the NaN values
nan_indices_train
# len(nan_indices_train)

nan_mask_val = torch.isnan(x_val)     # get a boolean mask indicating NaN values
nan_indices_val = torch.where(nan_mask_val)  # get the indices of the NaN values
nan_indices_val
# len(nan_indices_test)

nan_mask_test = torch.isnan(x_test)     # get a boolean mask indicating NaN values
nan_indices_test = torch.where(nan_mask_test)  # get the indices of the NaN values
nan_indices_test
# len(nan_indices_test)
# Out:
# (tensor([], device='cuda:0', dtype=torch.int64),
#  tensor([], device='cuda:0', dtype=torch.int64))
# (tensor([], device='cuda:0', dtype=torch.int64),
#  tensor([], device='cuda:0', dtype=torch.int64))
# (tensor([], device='cuda:0', dtype=torch.int64),
#  tensor([], device='cuda:0', dtype=torch.int64))

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# ### Visualizing sampled data

# %%
# %%script echo skipping
#
# if not LOAD_DATA_FROM_CSV:
#     rho
#     epsilon
#     vx
#     vy
#     vz
#     Bx
#     By
#     Bz
#     gxx
#     gxy
#     gxz
#     gyy
#     gyz
#     gzz
# Out:
# skipping

# %%
if not LOAD_DATA_FROM_CSV:
    print(len(rho))
    print(len(epsilon))
    print(len(vx))
    print(len(vy))
    print(len(vz))
    print(len(Bx))
    print(len(By))
    print(len(Bz))
    print()
    print(len(gxx))
    print(len(gxy))
    print(len(gxz))
    print(len(gyy))
    print(len(gyz))
    print(len(gzz))
# Out:
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
#
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# %%script echo skipping
#
# plt.hist([np.random.uniform(0, 0.999) for _ in range(n_train_samples)], bins=20)
# Out:
# skipping

# %%
# %%script echo skipping
#
# epsilon
# Out:
# skipping

# %% [markdown]
# The reason the sampling is not uniformly distributed in the following plots is due to the resampling and the fact that we certain values of e.g. velocity are more likely to violate the speed of light constraint than others.

# %%
#%%script echo skipping

if not LOAD_DATA_FROM_CSV:
    def plot_histogram(data, xlabel, ylabel, position, bins=20, xlog_scale=False, ylog_scale=False):
        plt.subplot(4, 5, position)
        plt.hist(data, bins=bins)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        if xlog_scale: # Setting does not work expected for epsilon.
            plt.xscale("log")
        if ylog_scale: # Setting does not work expected for epsilon.
            plt.yscale("log")

    # Plotting the histograms of rho, vx, epsilon, b0, b1, b2, and b3
    bins = 20
    plt.figure(figsize=(20, 16))

    plot_histogram(rho, "rho", "Frequency", 1, bins=bins)
    plot_histogram(epsilon, "epsilon", "Frequency", 2, bins=bins)
    plot_histogram(vx, "vx", "Frequency", 3, bins=bins)
    plot_histogram(vy, "vy", "Frequency", 4, bins=bins)
    plot_histogram(vz, "vz", "Frequency", 5, bins=bins)
    plot_histogram(Bx, "Bx", "Frequency", 6, bins=bins)
    plot_histogram(By, "By", "Frequency", 7, bins=bins)
    plot_histogram(Bz, "Bz", "Frequency", 8, bins=bins)

    # Plot these
    plot_histogram(gxx, "gxx", "Frequency", 9, bins=bins)
    plot_histogram(gxy, "gxy", "Frequency", 10, bins=bins)
    plot_histogram(gxz, "gxz", "Frequency", 11, bins=bins)
    plot_histogram(gyy, "gyy", "Frequency", 12, bins=bins)
    plot_histogram(gyz, "gyz", "Frequency", 13, bins=bins)
    plot_histogram(gzz, "gzz", "Frequency", 14, bins=bins)


    plt.suptitle("Primitive variables and metric")
    plt.tight_layout()
    plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
#%%script echo skipping

# Variable names
variable_names = ["D", "Sx", "Sy", "Sz", "tau", "Bconsx", "Bconsy", "Bconsz", "gxx", "gxy", "gxz", "gyy", "gyz", "gzz"]

# Plotting histograms of the input variables before z-score normalization
plt.figure(figsize=(16, 16))
plt.suptitle('Histograms of input variables before (or without at all) z-score normalization', y=1.03)

for i in range(N_INPUTS):
    plt.subplot(7, 2, i+1)
    data = x_train[:, i].cpu().numpy() # Convert tensor to numpy array for percentile calculation
    lower_bound, upper_bound = np.percentile(data, [1, 100]) # NOTE: Use this instead to visualize all the data.
    # lower_bound, upper_bound = np.percentile(data, [1, 90]) # Calculate 1st and 99th percentile

    plt.hist(data, bins=50, range=(lower_bound, upper_bound)) # Set range to the calculated percentile range
    plt.xlabel(variable_names[i])
    plt.xlim(lower_bound, upper_bound) # Set the x limit to match the range of the histogram

plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.show()

# Same plotting but for the test data. Adjust the percentile range as needed to zoom in.
# plt.figure(figsize=(16, 16))
# plt.suptitle('Histograms of input variables before (or without at all) z-score normalization (test data)', y=1.03)

# for i in range(14):
#     plt.subplot(7, 2, i+1)
#     data = x_test[:, i].cpu().numpy() # Convert tensor to numpy array for percentile calculation
#     #lower_bound, upper_bound = np.percentile(data, [1, 100]) # NOTE: Use this instead to visualize all the data.
#     lower_bound, upper_bound = np.percentile(data, [1, 99]) # Use this to zoom in.

#     plt.hist(data, bins=50, range=(lower_bound, upper_bound)) # Set range to the calculated percentile range
#     plt.xlabel(variable_names[i])
#     plt.xlim(lower_bound, upper_bound) # Set the x limit to match the range of the histogram

# plt.subplots_adjust(hspace=0.4, wspace=0.4)
# plt.show()

# %% [markdown]
# ### Data normalization

# %%
# Computing summary statistics of the input variables before and after z-score normalization
print('Summary statistics of input variables before z-score normalization')
print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.nanmean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))
# Out:
# Summary statistics of input variables before z-score normalization
# tensor([[ 1.8887e-05,  3.8238e+02,  2.2689e+00,  1.6626e+00,  4.1290e+00],
#         [-1.6198e+04,  3.4863e+05,  4.5844e+01,  2.2094e+01,  1.4641e+03],
#         [-1.3960e+04,  1.4962e+05,  4.3352e+01,  2.2047e+01,  8.1653e+02],
#         [-1.4486e+04,  2.9916e+05,  4.5262e+01,  2.2081e+01,  1.2683e+03],
#         [-2.1876e+04,  4.5921e+05,  1.0340e+02,  6.9807e+01,  2.0079e+03],
#         [-1.1375e+01,  1.1391e+01,  2.5317e-02,  3.5008e-02,  5.7318e+00],
#         [-1.1213e+01,  1.1157e+01,  1.6783e-02,  2.4105e-02,  5.7415e+00],
#         [-1.1175e+01,  1.1191e+01, -2.2684e-02, -2.9846e-02,  5.7241e+00],
#         [ 9.0001e-01,  1.1000e+00,  9.9848e-01,  9.9758e-01,  5.7728e-02],
#         [ 6.1297e-06,  9.9998e-02,  4.9549e-02,  4.9344e-02,  2.8956e-02],
#         [ 1.5352e-06,  9.9999e-02,  4.9662e-02,  4.9507e-02,  2.8908e-02],
#         [ 9.0001e-01,  1.1000e+00,  9.9872e-01,  9.9793e-01,  5.7559e-02],
#         [ 4.1736e-06,  9.9999e-02,  4.9710e-02,  4.9503e-02,  2.8857e-02],
#         [ 9.0000e-01,  1.1000e+00,  9.9874e-01,  9.9838e-01,  5.7758e-02]],
#        device='cuda:0')

# %% [markdown]
# Perform z-score normalization

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
if ZSCORE_NORMALIZATION:
    
    # TODO: Add magnetic field variables to the normalization if I decide to use the old code that is commented out here.
    # # Computing the median of each input variable from the training set using torch.nanmedian function
    # D_median = torch.nanmedian(x_train[:, 0])
    # Sx_median = torch.nanmedian(x_train[:, 1])
    # Sy_median = torch.nanmedian(x_train[:, 2])
    # Sz_median = torch.nanmedian(x_train[:, 3])
    # tau_median = torch.nanmedian(x_train[:, 4])

    # # Computing the standard deviation of each input variable from the training set using torch.std function with a boolean mask to ignore nan values
    # D_std = torch.std(x_train[~torch.isnan(x_train[:, 0]), 0])
    # Sx_std = torch.std(x_train[~torch.isnan(x_train[:, 1]), 1])
    # Sy_std = torch.std(x_train[~torch.isnan(x_train[:, 2]), 2])
    # Sz_std = torch.std(x_train[~torch.isnan(x_train[:, 3]), 3])
    # tau_std = torch.std(x_train[~torch.isnan(x_train[:, 4]), 4])


    # # Applying z-score normalization to both train and test sets using the statistics from the training set
    # x_train[:, 0] = torch.sub(x_train[:, 0], D_median).div(D_std)
    # x_train[:, 1] = torch.sub(x_train[:, 1], Sx_median).div(Sx_std)
    # x_train[:, 2] = torch.sub(x_train[:, 2], Sy_median).div(Sy_std)
    # x_train[:, 3] = torch.sub(x_train[:, 3], Sz_median).div(Sz_std)
    # x_train[:, 4] = torch.sub(x_train[:, 4], tau_median).div(tau_std)

    # x_test[:, 0] = torch.sub(x_test[:, 0], D_median).div(D_std)
    # x_test[:, 1] = torch.sub(x_test[:, 1], Sx_median).div(Sx_std)
    # x_test[:, 2] = torch.sub(x_test[:, 2], Sy_median).div(Sy_std)
    # x_test[:, 3] = torch.sub(x_test[:, 3], Sz_median).div(Sz_std)
    # x_test[:, 4] = torch.sub(x_test[:, 4], tau_median).div(tau_std)

    # Computing the mean and standard deviation of each column
    mean = x_train.mean(dim=0)
    std = x_train.std(dim=0)

    # Applying z-score normalization
    x_train = (x_train - mean) / std
    # Use the same mean and std from the training data as we don't want test data leakage.
    x_test = (x_test - mean) / std

# %% [markdown]
# Plotting the histograms of the input data after normalization if z-score normalization was performed.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
if not LOAD_DATA_FROM_CSV:
    if ZSCORE_NORMALIZATION:
        # Variable names
        variable_names = ["D", "Sx", "Sy", "Sz", "tau", "Bconsx", "Bconsy", "Bconsz", "gxx", "gxy", "gxz", "gyy", "gyz", "gzz"]

        # Plotting histograms of the input variables before z-score normalization
        plt.figure(figsize=(16, 16))
        plt.suptitle('Histograms of input variables before (or without at all) z-score normalization', y=1.03)

        for i in range(N_INPUTS):
            plt.subplot(7, 2, i+1)
            data = x_train[:, i].cpu().numpy() # Convert tensor to numpy array for percentile calculation
            lower_bound, upper_bound = np.percentile(data, [1, 100]) # NOTE: Use this instead to visualize all the data.
            # lower_bound, upper_bound = np.percentile(data, [1, 90]) # Calculate 1st and 99th percentile

            plt.hist(data, bins=50, range=(lower_bound, upper_bound)) # Set range to the calculated percentile range
            plt.xlabel(variable_names[i])
            plt.xlim(lower_bound, upper_bound) # Set the x limit to match the range of the histogram

        plt.subplots_adjust(hspace=0.4, wspace=0.4)
        plt.show()

# %%
if ZSCORE_NORMALIZATION:
    # Computing summary statistics of the input variables after z-score normalization
    print('Summary statistics of input variables after z-score normalization')
    print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.mean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))

# %% [markdown]
# ### Visualizing input data and labels

# %%
x_train
y_train
x_val
y_val
x_test
y_test
# Out:
# tensor([-2.1585, 21.0883,  3.5675,  ...,  2.8958,  0.6479,  5.3626],
#        device='cuda:0')

# %% [markdown]
# Checking if our output is always positive ~~by plotting a histogram of y_train and y_test tensors~~

# %%
import torch

# Create a sample tensor
tensor = torch.randn(80000, 14)  # Assuming a tensor of shape [80000, 14]
tensor


# Check if any element is negative
any_negative = torch.any(tensor < 0)

# Print the result
print(any_negative)
# Out:
# tensor(True)

# %%
y_train.shape
any_negative = torch.any(y_train < 0)
any_negative

y_test.shape
any_negative = torch.any(y_test < 0)
any_negative

x_train.shape
any_negative = torch.any(x_train < 0)
any_negative
# Out:
# tensor(True, device='cuda:0')

# %%
#%%script echo skipping

plt.figure(figsize=(8, 4))
plt.subplot(1, 3, 1)
plt.hist(y_train.cpu().numpy(), bins=100) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.xscale("log")
plt.subplot(1, 3, 2)
plt.hist(y_val.cpu().numpy(), bins=100) # must be cpu here
plt.xlabel("y_val")
plt.ylabel("Frequency")
plt.xscale("log")
plt.tight_layout()
plt.subplot(1, 3, 3)
plt.hist(y_test.cpu().numpy(), bins=100) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.xscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation, dropout_rate):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
            TODO: [ver. Copilot description] dropout_rate (float): The dropout rate to use for all layers.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation
        self.dropout_rate = dropout_rate

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList()
        self.dropouts = nn.ModuleList()

        self.layers.append(nn.Linear(N_INPUTS, n_units[0]))
        self.dropouts.append(nn.Dropout(p=dropout_rate))

        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
            self.dropouts.append(nn.Dropout(p=dropout_rate))

        self.layers.append(nn.Linear(n_units[-1], N_OUTPUTS))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, N_INPUTS).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, N_OUTPUTS).
        """
        # Adding an assertion to check that the input tensor has the expected shape and type
        assert isinstance(x, torch.Tensor), "x must be a torch.Tensor"
        assert x.shape[1] == N_INPUTS, f"x must have shape (batch_size, {N_INPUTS})"

        for layer, dropout in zip(self.layers[:-1], self.dropouts):
            x = dropout(self.hidden_activation(layer(x)))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x)) # No dropout at output layer

        return x # Returning the output tensor

# %%
# %%script echo skipping
#
# [1,2,3]
# [1,2,3][:-1]
# Out:
# skipping

# %%
for x in [1,2,3][:-1]:
    print(x)
# Out:
# 1
# 2

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
            dropout_rate is the dropout rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if OPTIMIZE:
        n_layers = trial.suggest_int("n_layers", 2, 6)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 4096) for i in range(n_layers)]

        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "PReLU", "Swish", "GELU", "SoftPlus"]
        )
        output_activation_name = trial.suggest_categorical( "output_activation", ["Linear"])

        loss_name = trial.suggest_categorical( "loss", ["MSE", "MAE", "Huber", "Quantile"]) 

        optimizer_name = trial.suggest_categorical( "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] )

        lr = trial.suggest_loguniform("lr", 1e-5, 1e-1)

        batch_size_list = [32, 64, 128, 256, 512, 1024, 2048]
        batch_size = trial.suggest_categorical("batch_size", batch_size_list)
        
        n_epochs = trial.suggest_int("n_epochs", 50, 150)

        # scheduler_name = trial.suggest_categorical("scheduler", ["CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "CyclicLR"])
        scheduler_name = trial.suggest_categorical("scheduler", ["CosineAnnealingLR", "ReduceLROnPlateau", "StepLR"])

        # Creating the activation functions from their names
        if hidden_activation_name == "ReLU":
            hidden_activation = nn.ReLU()
        elif hidden_activation_name == "LeakyReLU":
            negative_slope = trial.suggest_uniform("leakyrelu_slope", 0.01, 0.3)
            hidden_activation = nn.LeakyReLU(negative_slope=negative_slope)
        elif hidden_activation_name == "ELU":
            hidden_activation = nn.ELU() 
        elif hidden_activation_name == "PReLU":
            init = trial.suggest_uniform("prelu_init", 0.1, 0.3)
            hidden_activation = nn.PReLU(init=init)
        elif hidden_activation_name == "Swish":
            class Swish(nn.Module):
                def forward(self, x):
                    return x * torch.sigmoid(x)
            hidden_activation = Swish()
        elif hidden_activation_name == "GELU":
            hidden_activation = nn.GELU()
        elif hidden_activation_name == "SoftPlus":
            beta = trial.suggest_uniform("softplus_beta", 0.5, 1.5)
            hidden_activation = nn.Softplus(beta=beta) # We don't optimize thresshold subparameters, as it's mainly for numerical stability.

        dropout_rate = trial.suggest_uniform("dropout_rate", 0.0, 0.5)


    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT

        # Creating the activation functions from their names
        if hidden_activation_name == "ReLU":
            hidden_activation = nn.ReLU()
        elif hidden_activation_name == "LeakyReLU":
            negative_slope = 0.01
            hidden_activation = nn.LeakyReLU(negative_slope=negative_slope)
        elif hidden_activation_name == "ELU":
            hidden_activation = nn.ELU() 
        elif hidden_activation_name == "PReLU":
            init = 0.25
            hidden_activation = nn.PReLU(init=init)
        elif hidden_activation_name == "Swish":
            class Swish(nn.Module):
                def forward(self, x):
                    return x * torch.sigmoid(x)
            hidden_activation = Swish()
        elif hidden_activation_name == "GELU":
            hidden_activation = nn.GELU()
        elif hidden_activation_name == "SoftPlus":
            beta = 1
            hidden_activation = nn.Softplus(beta=beta) # We don't optimize threshold subparameter, as it's mainly for numerical stability.

        dropout_rate = DROPOUT_RATE_NO_OPT


    # We used to have options here, but since we have a regression problem with continuous output, we only use Linear.
    output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    elif loss_name == "Quantile":
        def quantile_loss(y_pred, y_true, q=0.5):
            e = y_pred - y_true
            return torch.mean(torch.max(q*e, (q-1)*e))
        loss_fn = quantile_loss
    else:
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(n_layers, n_units, hidden_activation, output_activation, dropout_rate).to(device)


    if OPTIMIZE:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.9, 0.999)
            beta2 = trial.suggest_uniform("beta2", 0.999, 0.9999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.1, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            if n_epochs < 150:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.1, 0.3)
            elif n_epochs > 250:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.05, 0.1)
            else:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.1, 0.2)

            T_max = int(n_epochs * t_max_fraction)
            eta_min = trial.suggest_loguniform("eta_min", 1e-7, 1e-2)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min=eta_min)
        elif scheduler_name == "ReduceLROnPlateau":
            factor = trial.suggest_uniform("factor", 0.1, 0.5)
            patience = trial.suggest_int("patience", 5, 10)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        elif scheduler_name == "CyclicLR":
            base_lr = trial.suggest_loguniform("base_lr", 1e-6, 1e-2)
            max_lr = trial.suggest_loguniform("max_lr", 1e-4, 1)
            step_size_up = trial.suggest_int("step_size_up", 200, 2000)
            scheduler = optim.lr_scheduler.CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr, step_size_up=step_size_up)
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer)
        elif scheduler_name == "ReduceLROnPlateau":
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        elif scheduler_name == "CyclicLR":
            # TODO: Change these appropriately.
            base_lr = 1e-6
            max_lr = 1e-4
            step_size_up = 200
            scheduler = optim.lr_scheduler.CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr, step_size_up=step_size_up)
        else:
            scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr, dropout_rate

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, train_loader, val_loader, test_loader, trial=None):
    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    val_losses = []
    test_losses = []
    train_metrics = []
    val_metrics = []
    test_metrics = []


    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(y_pred, y_batch, loss_fn)


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        if val_loader is not None:
            net.eval()
            val_loss = 0.0
            val_l1_norm = 0.0
            val_linf_norm = 0.0

            with torch.no_grad():
                for x_batch, y_batch in val_loader:
                    x_batch = x_batch.to(device)
                    y_batch = y_batch.to(device)
                    y_pred = net(x_batch)
                    loss, l1_norm, linf_norm = compute_loss_and_metrics(y_pred, y_batch, loss_fn)

                    val_loss += loss.item() * x_batch.size(0)
                    val_l1_norm += l1_norm.item() * x_batch.size(0)
                    val_linf_norm += linf_norm.item() * x_batch.size(0)

            val_loss /= len(val_loader.dataset)
            val_l1_norm /= len(val_loader.dataset)
            val_linf_norm /= len(val_loader.dataset)

            val_losses.append(val_loss)
            val_metrics.append(
                {
                    "l1_norm": val_l1_norm,
                    "linf_norm": val_linf_norm,
                }
            )

            writer.add_scalar("Loss/val", val_loss, epoch)
            writer.add_scalar("L1 norm/val", val_l1_norm, epoch)
            writer.add_scalar("Linf norm/val", val_linf_norm, epoch)
            print(f"Epoch {epoch+1}/{n_epochs}.. Train loss: {train_loss:.3f}.. Val loss: {val_loss:.3f}.. Train L1 norm: {train_l1_norm:.3f}.. Val L1 norm: {val_l1_norm:.3f}.. Train Linf norm: {train_linf_norm:.3f}.. Val Linf norm: {val_linf_norm:.3f}")


            update_scheduler(scheduler, val_loss)

        if test_loader is not None:
            net.eval()
            test_loss = 0.0
            test_l1_norm = 0.0
            test_linf_norm = 0.0

            with torch.no_grad():
                for x_batch, y_batch in test_loader:
                    x_batch = x_batch.to(device)
                    y_batch = y_batch.to(device)
                    y_pred = net(x_batch)
                    loss, l1_norm, linf_norm = compute_loss_and_metrics(y_pred, y_batch, loss_fn)

                    test_loss += loss.item() * x_batch.size(0)
                    test_l1_norm += l1_norm.item() * x_batch.size(0)
                    test_linf_norm += linf_norm.item() * x_batch.size(0)

            test_loss /= len(test_loader.dataset)
            test_l1_norm /= len(test_loader.dataset)
            test_linf_norm /= len(test_loader.dataset)

            test_losses.append(test_loss)
            test_metrics.append(
                {
                    "l1_norm": test_l1_norm,
                    "linf_norm": test_linf_norm,
                }
            )

            writer.add_scalar("Loss/test", test_loss, epoch)
            writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
            writer.add_scalar("Linf norm/test", test_linf_norm, epoch)
            print(f"Epoch {epoch+1}/{n_epochs}.. Train loss: {train_loss:.3f}.. Test loss: {test_loss:.3f}.. Train L1 norm: {train_l1_norm:.3f}.. Test L1 norm: {test_l1_norm:.3f}.. Train Linf norm: {train_linf_norm:.3f}.. Test Linf norm: {test_linf_norm:.3f}")


        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(val_l1_norm, epoch)

            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, val_losses, test_losses, train_metrics, val_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr, \
    dropout_rate = create_model(trial, optimize=True)

    # Create separate data loaders for training and validation
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    val_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_val, y_val), batch_size=batch_size
    )
    
    _, _, _, _, val_metrics, _ = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, train_loader, val_loader, None, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return val_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
# Out:
# [I 2023-05-31 09:19:59,112] A new study created in memory with name: no-name-a858e9f0-0181-48d6-a9c9-5532412ab453
# <ipython-input-37-46c28bc3cd67>:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform("lr", 1e-5, 1e-1)
# <ipython-input-37-46c28bc3cd67>:58: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   negative_slope = trial.suggest_uniform("leakyrelu_slope", 0.01, 0.3)
# <ipython-input-37-46c28bc3cd67>:76: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform("dropout_rate", 0.0, 0.5)
# <ipython-input-37-46c28bc3cd67>:161: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform("gamma", 0.1, 0.5)
# Epoch 1/129.. Train loss: 5.725.. Val loss: 4.242.. Train L1 norm: 5.693.. Val L1 norm: 1.942.. Train Linf norm: 119.962.. Val Linf norm: 28.955
# Epoch 2/129.. Train loss: 4.251.. Val loss: 3.845.. Train L1 norm: 5.440.. Val L1 norm: 5.546.. Train Linf norm: 124.000.. Val Linf norm: 122.273
# Epoch 3/129.. Train loss: 3.879.. Val loss: 3.141.. Train L1 norm: 5.505.. Val L1 norm: 4.434.. Train Linf norm: 127.480.. Val Linf norm: 101.135
# Epoch 4/129.. Train loss: 3.658.. Val loss: 2.802.. Train L1 norm: 5.426.. Val L1 norm: 4.818.. Train Linf norm: 128.386.. Val Linf norm: 113.914
# Epoch 5/129.. Train loss: 3.494.. Val loss: 3.089.. Train L1 norm: 4.599.. Val L1 norm: 4.485.. Train Linf norm: 102.741.. Val Linf norm: 103.800
# Epoch 6/129.. Train loss: 3.435.. Val loss: 2.820.. Train L1 norm: 6.309.. Val L1 norm: 5.084.. Train Linf norm: 157.144.. Val Linf norm: 117.992
# Epoch 7/129.. Train loss: 3.460.. Val loss: 2.772.. Train L1 norm: 4.384.. Val L1 norm: 6.344.. Train Linf norm: 97.151.. Val Linf norm: 152.550
# Epoch 8/129.. Train loss: 2.508.. Val loss: 2.057.. Train L1 norm: 4.294.. Val L1 norm: 4.303.. Train Linf norm: 100.667.. Val Linf norm: 106.396
# Epoch 9/129.. Train loss: 2.401.. Val loss: 1.993.. Train L1 norm: 4.726.. Val L1 norm: 3.472.. Train Linf norm: 115.780.. Val Linf norm: 83.949
# Epoch 10/129.. Train loss: 2.315.. Val loss: 2.050.. Train L1 norm: 4.871.. Val L1 norm: 4.407.. Train Linf norm: 121.816.. Val Linf norm: 108.349
# Epoch 11/129.. Train loss: 2.296.. Val loss: 1.879.. Train L1 norm: 4.899.. Val L1 norm: 4.162.. Train Linf norm: 122.911.. Val Linf norm: 105.137
# Epoch 12/129.. Train loss: 2.241.. Val loss: 1.811.. Train L1 norm: 4.955.. Val L1 norm: 3.846.. Train Linf norm: 125.827.. Val Linf norm: 96.410
# Epoch 13/129.. Train loss: 2.243.. Val loss: 1.783.. Train L1 norm: 4.800.. Val L1 norm: 3.975.. Train Linf norm: 121.161.. Val Linf norm: 99.808
# Epoch 14/129.. Train loss: 2.198.. Val loss: 1.811.. Train L1 norm: 4.657.. Val L1 norm: 3.618.. Train Linf norm: 117.256.. Val Linf norm: 89.343
# Epoch 15/129.. Train loss: 2.082.. Val loss: 1.736.. Train L1 norm: 4.331.. Val L1 norm: 3.712.. Train Linf norm: 107.778.. Val Linf norm: 92.996
# Epoch 16/129.. Train loss: 2.051.. Val loss: 1.713.. Train L1 norm: 4.106.. Val L1 norm: 3.827.. Train Linf norm: 100.466.. Val Linf norm: 96.854
# Epoch 17/129.. Train loss: 2.040.. Val loss: 1.716.. Train L1 norm: 4.427.. Val L1 norm: 3.896.. Train Linf norm: 111.421.. Val Linf norm: 98.092
# Epoch 18/129.. Train loss: 2.044.. Val loss: 1.705.. Train L1 norm: 4.709.. Val L1 norm: 3.799.. Train Linf norm: 120.081.. Val Linf norm: 95.168
# Epoch 19/129.. Train loss: 2.036.. Val loss: 1.692.. Train L1 norm: 4.565.. Val L1 norm: 3.602.. Train Linf norm: 114.940.. Val Linf norm: 90.559
# Epoch 20/129.. Train loss: 2.040.. Val loss: 1.710.. Train L1 norm: 4.992.. Val L1 norm: 3.839.. Train Linf norm: 129.285.. Val Linf norm: 96.611
# Epoch 21/129.. Train loss: 2.029.. Val loss: 1.705.. Train L1 norm: 4.875.. Val L1 norm: 3.742.. Train Linf norm: 126.245.. Val Linf norm: 94.486
# Epoch 22/129.. Train loss: 2.015.. Val loss: 1.675.. Train L1 norm: 5.194.. Val L1 norm: 3.837.. Train Linf norm: 136.158.. Val Linf norm: 96.973
# Epoch 23/129.. Train loss: 2.016.. Val loss: 1.674.. Train L1 norm: 5.247.. Val L1 norm: 3.812.. Train Linf norm: 137.730.. Val Linf norm: 96.148
# Epoch 24/129.. Train loss: 2.015.. Val loss: 1.665.. Train L1 norm: 5.448.. Val L1 norm: 3.848.. Train Linf norm: 142.873.. Val Linf norm: 97.014
# Epoch 25/129.. Train loss: 2.012.. Val loss: 1.665.. Train L1 norm: 4.706.. Val L1 norm: 3.792.. Train Linf norm: 120.117.. Val Linf norm: 95.798
# Epoch 26/129.. Train loss: 2.002.. Val loss: 1.658.. Train L1 norm: 4.013.. Val L1 norm: 3.934.. Train Linf norm: 98.001.. Val Linf norm: 99.524
# Epoch 27/129.. Train loss: 1.998.. Val loss: 1.658.. Train L1 norm: 4.413.. Val L1 norm: 3.974.. Train Linf norm: 110.878.. Val Linf norm: 100.569
# Epoch 28/129.. Train loss: 1.998.. Val loss: 1.658.. Train L1 norm: 4.376.. Val L1 norm: 3.886.. Train Linf norm: 109.228.. Val Linf norm: 98.242
# Epoch 29/129.. Train loss: 2.004.. Val loss: 1.657.. Train L1 norm: 4.849.. Val L1 norm: 3.909.. Train Linf norm: 124.871.. Val Linf norm: 98.840
# Epoch 30/129.. Train loss: 2.007.. Val loss: 1.656.. Train L1 norm: 5.369.. Val L1 norm: 3.912.. Train Linf norm: 141.423.. Val Linf norm: 98.904
# Epoch 31/129.. Train loss: 2.001.. Val loss: 1.656.. Train L1 norm: 4.637.. Val L1 norm: 3.900.. Train Linf norm: 117.778.. Val Linf norm: 98.619
# Epoch 32/129.. Train loss: 2.008.. Val loss: 1.657.. Train L1 norm: 4.564.. Val L1 norm: 3.890.. Train Linf norm: 115.521.. Val Linf norm: 98.427
# Epoch 33/129.. Train loss: 1.989.. Val loss: 1.657.. Train L1 norm: 5.098.. Val L1 norm: 3.916.. Train Linf norm: 133.105.. Val Linf norm: 99.128
# Epoch 34/129.. Train loss: 1.997.. Val loss: 1.658.. Train L1 norm: 4.489.. Val L1 norm: 3.872.. Train Linf norm: 113.602.. Val Linf norm: 97.901
# Epoch 35/129.. Train loss: 1.986.. Val loss: 1.658.. Train L1 norm: 4.913.. Val L1 norm: 3.899.. Train Linf norm: 126.842.. Val Linf norm: 98.628
# Epoch 36/129.. Train loss: 1.995.. Val loss: 1.658.. Train L1 norm: 5.053.. Val L1 norm: 3.889.. Train Linf norm: 131.519.. Val Linf norm: 98.365
# Epoch 37/129.. Train loss: 1.994.. Val loss: 1.658.. Train L1 norm: 5.245.. Val L1 norm: 3.895.. Train Linf norm: 137.618.. Val Linf norm: 98.522
# Epoch 38/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 5.591.. Val L1 norm: 3.890.. Train Linf norm: 149.272.. Val Linf norm: 98.369
# Epoch 39/129.. Train loss: 2.001.. Val loss: 1.658.. Train L1 norm: 4.787.. Val L1 norm: 3.886.. Train Linf norm: 123.713.. Val Linf norm: 98.261
# Epoch 40/129.. Train loss: 1.999.. Val loss: 1.658.. Train L1 norm: 4.487.. Val L1 norm: 3.890.. Train Linf norm: 113.084.. Val Linf norm: 98.382
# Epoch 41/129.. Train loss: 2.005.. Val loss: 1.658.. Train L1 norm: 5.245.. Val L1 norm: 3.883.. Train Linf norm: 137.789.. Val Linf norm: 98.199
# Epoch 42/129.. Train loss: 1.980.. Val loss: 1.658.. Train L1 norm: 4.033.. Val L1 norm: 3.881.. Train Linf norm: 99.341.. Val Linf norm: 98.135
# Epoch 43/129.. Train loss: 2.001.. Val loss: 1.658.. Train L1 norm: 5.100.. Val L1 norm: 3.881.. Train Linf norm: 133.058.. Val Linf norm: 98.135
# Epoch 44/129.. Train loss: 1.995.. Val loss: 1.658.. Train L1 norm: 4.260.. Val L1 norm: 3.880.. Train Linf norm: 106.200.. Val Linf norm: 98.115
# Epoch 45/129.. Train loss: 2.005.. Val loss: 1.658.. Train L1 norm: 4.413.. Val L1 norm: 3.880.. Train Linf norm: 111.243.. Val Linf norm: 98.108
# Epoch 46/129.. Train loss: 1.995.. Val loss: 1.658.. Train L1 norm: 4.498.. Val L1 norm: 3.881.. Train Linf norm: 113.501.. Val Linf norm: 98.135
# Epoch 47/129.. Train loss: 2.005.. Val loss: 1.658.. Train L1 norm: 5.169.. Val L1 norm: 3.882.. Train Linf norm: 135.105.. Val Linf norm: 98.155
# Epoch 48/129.. Train loss: 1.978.. Val loss: 1.658.. Train L1 norm: 4.872.. Val L1 norm: 3.882.. Train Linf norm: 125.875.. Val Linf norm: 98.175
# Epoch 49/129.. Train loss: 1.993.. Val loss: 1.658.. Train L1 norm: 4.945.. Val L1 norm: 3.883.. Train Linf norm: 128.098.. Val Linf norm: 98.189
# Epoch 50/129.. Train loss: 2.001.. Val loss: 1.658.. Train L1 norm: 3.914.. Val L1 norm: 3.883.. Train Linf norm: 95.121.. Val Linf norm: 98.190
# Epoch 51/129.. Train loss: 1.983.. Val loss: 1.658.. Train L1 norm: 4.444.. Val L1 norm: 3.883.. Train Linf norm: 112.290.. Val Linf norm: 98.188
# Epoch 52/129.. Train loss: 1.995.. Val loss: 1.658.. Train L1 norm: 4.475.. Val L1 norm: 3.883.. Train Linf norm: 113.299.. Val Linf norm: 98.187
# Epoch 53/129.. Train loss: 2.006.. Val loss: 1.658.. Train L1 norm: 3.797.. Val L1 norm: 3.883.. Train Linf norm: 91.171.. Val Linf norm: 98.187
# Epoch 54/129.. Train loss: 1.996.. Val loss: 1.658.. Train L1 norm: 4.703.. Val L1 norm: 3.883.. Train Linf norm: 120.162.. Val Linf norm: 98.181
# Epoch 55/129.. Train loss: 2.007.. Val loss: 1.658.. Train L1 norm: 4.233.. Val L1 norm: 3.883.. Train Linf norm: 104.775.. Val Linf norm: 98.178
# Epoch 56/129.. Train loss: 2.005.. Val loss: 1.658.. Train L1 norm: 4.163.. Val L1 norm: 3.882.. Train Linf norm: 102.615.. Val Linf norm: 98.173
# Epoch 57/129.. Train loss: 1.994.. Val loss: 1.658.. Train L1 norm: 3.687.. Val L1 norm: 3.882.. Train Linf norm: 87.682.. Val Linf norm: 98.173
# Epoch 58/129.. Train loss: 1.974.. Val loss: 1.658.. Train L1 norm: 5.228.. Val L1 norm: 3.882.. Train Linf norm: 137.221.. Val Linf norm: 98.172
# Epoch 59/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.521.. Val L1 norm: 3.882.. Train Linf norm: 114.384.. Val Linf norm: 98.172
# Epoch 60/129.. Train loss: 2.001.. Val loss: 1.658.. Train L1 norm: 5.148.. Val L1 norm: 3.882.. Train Linf norm: 134.398.. Val Linf norm: 98.172
# Epoch 61/129.. Train loss: 1.982.. Val loss: 1.658.. Train L1 norm: 4.567.. Val L1 norm: 3.882.. Train Linf norm: 115.976.. Val Linf norm: 98.171
# Epoch 62/129.. Train loss: 1.982.. Val loss: 1.658.. Train L1 norm: 4.678.. Val L1 norm: 3.882.. Train Linf norm: 119.254.. Val Linf norm: 98.172
# Epoch 63/129.. Train loss: 1.980.. Val loss: 1.658.. Train L1 norm: 5.065.. Val L1 norm: 3.882.. Train Linf norm: 131.980.. Val Linf norm: 98.171
# Epoch 64/129.. Train loss: 1.997.. Val loss: 1.658.. Train L1 norm: 5.067.. Val L1 norm: 3.882.. Train Linf norm: 130.903.. Val Linf norm: 98.171
# Epoch 65/129.. Train loss: 1.995.. Val loss: 1.658.. Train L1 norm: 4.506.. Val L1 norm: 3.882.. Train Linf norm: 114.184.. Val Linf norm: 98.171
# Epoch 66/129.. Train loss: 2.000.. Val loss: 1.658.. Train L1 norm: 4.607.. Val L1 norm: 3.882.. Train Linf norm: 117.356.. Val Linf norm: 98.171
# Epoch 67/129.. Train loss: 1.986.. Val loss: 1.658.. Train L1 norm: 4.556.. Val L1 norm: 3.882.. Train Linf norm: 115.745.. Val Linf norm: 98.171
# Epoch 68/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.597.. Val L1 norm: 3.882.. Train Linf norm: 117.297.. Val Linf norm: 98.171
# Epoch 69/129.. Train loss: 2.012.. Val loss: 1.658.. Train L1 norm: 4.511.. Val L1 norm: 3.882.. Train Linf norm: 113.969.. Val Linf norm: 98.171
# Epoch 70/129.. Train loss: 2.006.. Val loss: 1.658.. Train L1 norm: 4.503.. Val L1 norm: 3.882.. Train Linf norm: 114.062.. Val Linf norm: 98.171
# Epoch 71/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 4.046.. Val L1 norm: 3.882.. Train Linf norm: 99.785.. Val Linf norm: 98.171
# Epoch 72/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 5.152.. Val L1 norm: 3.882.. Train Linf norm: 134.567.. Val Linf norm: 98.171
# Epoch 73/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 5.335.. Val L1 norm: 3.882.. Train Linf norm: 140.611.. Val Linf norm: 98.171
# Epoch 74/129.. Train loss: 1.987.. Val loss: 1.658.. Train L1 norm: 5.048.. Val L1 norm: 3.882.. Train Linf norm: 131.259.. Val Linf norm: 98.171
# Epoch 75/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 4.222.. Val L1 norm: 3.882.. Train Linf norm: 105.117.. Val Linf norm: 98.171
# Epoch 76/129.. Train loss: 1.986.. Val loss: 1.658.. Train L1 norm: 4.797.. Val L1 norm: 3.882.. Train Linf norm: 123.974.. Val Linf norm: 98.171
# Epoch 77/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 4.298.. Val L1 norm: 3.882.. Train Linf norm: 107.741.. Val Linf norm: 98.171
# Epoch 78/129.. Train loss: 1.985.. Val loss: 1.658.. Train L1 norm: 4.526.. Val L1 norm: 3.882.. Train Linf norm: 114.503.. Val Linf norm: 98.171
# Epoch 79/129.. Train loss: 1.993.. Val loss: 1.658.. Train L1 norm: 5.131.. Val L1 norm: 3.882.. Train Linf norm: 134.553.. Val Linf norm: 98.171
# Epoch 80/129.. Train loss: 1.979.. Val loss: 1.658.. Train L1 norm: 4.153.. Val L1 norm: 3.882.. Train Linf norm: 103.209.. Val Linf norm: 98.171
# Epoch 81/129.. Train loss: 2.004.. Val loss: 1.658.. Train L1 norm: 4.575.. Val L1 norm: 3.882.. Train Linf norm: 115.144.. Val Linf norm: 98.171
# Epoch 82/129.. Train loss: 1.996.. Val loss: 1.658.. Train L1 norm: 4.983.. Val L1 norm: 3.882.. Train Linf norm: 129.569.. Val Linf norm: 98.171
# Epoch 83/129.. Train loss: 1.987.. Val loss: 1.658.. Train L1 norm: 5.086.. Val L1 norm: 3.882.. Train Linf norm: 132.170.. Val Linf norm: 98.171
# Epoch 84/129.. Train loss: 2.006.. Val loss: 1.658.. Train L1 norm: 3.944.. Val L1 norm: 3.882.. Train Linf norm: 95.987.. Val Linf norm: 98.171
# Epoch 85/129.. Train loss: 2.008.. Val loss: 1.658.. Train L1 norm: 4.753.. Val L1 norm: 3.882.. Train Linf norm: 121.905.. Val Linf norm: 98.171
# Epoch 86/129.. Train loss: 2.000.. Val loss: 1.658.. Train L1 norm: 4.224.. Val L1 norm: 3.882.. Train Linf norm: 105.195.. Val Linf norm: 98.171
# Epoch 87/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.589.. Val L1 norm: 3.882.. Train Linf norm: 116.981.. Val Linf norm: 98.171
# Epoch 88/129.. Train loss: 1.994.. Val loss: 1.658.. Train L1 norm: 4.626.. Val L1 norm: 3.882.. Train Linf norm: 117.922.. Val Linf norm: 98.171
# Epoch 89/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 4.337.. Val L1 norm: 3.882.. Train Linf norm: 108.604.. Val Linf norm: 98.171
# Epoch 90/129.. Train loss: 1.984.. Val loss: 1.658.. Train L1 norm: 4.761.. Val L1 norm: 3.882.. Train Linf norm: 122.513.. Val Linf norm: 98.171
# Epoch 91/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 4.802.. Val L1 norm: 3.882.. Train Linf norm: 123.736.. Val Linf norm: 98.171
# Epoch 92/129.. Train loss: 1.991.. Val loss: 1.658.. Train L1 norm: 3.974.. Val L1 norm: 3.882.. Train Linf norm: 96.800.. Val Linf norm: 98.171
# Epoch 93/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 4.639.. Val L1 norm: 3.882.. Train Linf norm: 117.691.. Val Linf norm: 98.171
# Epoch 94/129.. Train loss: 1.990.. Val loss: 1.658.. Train L1 norm: 4.345.. Val L1 norm: 3.882.. Train Linf norm: 109.092.. Val Linf norm: 98.171
# Epoch 95/129.. Train loss: 1.985.. Val loss: 1.658.. Train L1 norm: 4.922.. Val L1 norm: 3.882.. Train Linf norm: 127.553.. Val Linf norm: 98.171
# Epoch 96/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 5.605.. Val L1 norm: 3.882.. Train Linf norm: 147.257.. Val Linf norm: 98.171
# Epoch 97/129.. Train loss: 1.993.. Val loss: 1.658.. Train L1 norm: 4.805.. Val L1 norm: 3.882.. Train Linf norm: 123.423.. Val Linf norm: 98.171
# Epoch 98/129.. Train loss: 1.994.. Val loss: 1.658.. Train L1 norm: 4.377.. Val L1 norm: 3.882.. Train Linf norm: 110.014.. Val Linf norm: 98.171
# Epoch 99/129.. Train loss: 1.976.. Val loss: 1.658.. Train L1 norm: 4.427.. Val L1 norm: 3.882.. Train Linf norm: 111.300.. Val Linf norm: 98.171
# Epoch 100/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.918.. Val L1 norm: 3.882.. Train Linf norm: 127.283.. Val Linf norm: 98.171
# Epoch 101/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 4.026.. Val L1 norm: 3.882.. Train Linf norm: 99.057.. Val Linf norm: 98.171
# Epoch 102/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 4.414.. Val L1 norm: 3.882.. Train Linf norm: 111.365.. Val Linf norm: 98.171
# Epoch 103/129.. Train loss: 1.987.. Val loss: 1.658.. Train L1 norm: 4.458.. Val L1 norm: 3.882.. Train Linf norm: 112.817.. Val Linf norm: 98.171
# Epoch 104/129.. Train loss: 2.021.. Val loss: 1.658.. Train L1 norm: 4.704.. Val L1 norm: 3.882.. Train Linf norm: 120.374.. Val Linf norm: 98.171
# Epoch 105/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 5.245.. Val L1 norm: 3.882.. Train Linf norm: 137.500.. Val Linf norm: 98.171
# Epoch 106/129.. Train loss: 1.999.. Val loss: 1.658.. Train L1 norm: 4.771.. Val L1 norm: 3.882.. Train Linf norm: 122.855.. Val Linf norm: 98.171
# Epoch 107/129.. Train loss: 2.000.. Val loss: 1.658.. Train L1 norm: 5.201.. Val L1 norm: 3.882.. Train Linf norm: 136.745.. Val Linf norm: 98.171
# Epoch 108/129.. Train loss: 2.008.. Val loss: 1.658.. Train L1 norm: 5.255.. Val L1 norm: 3.882.. Train Linf norm: 137.750.. Val Linf norm: 98.171
# Epoch 109/129.. Train loss: 1.990.. Val loss: 1.658.. Train L1 norm: 4.885.. Val L1 norm: 3.882.. Train Linf norm: 126.667.. Val Linf norm: 98.171
# Epoch 110/129.. Train loss: 1.997.. Val loss: 1.658.. Train L1 norm: 3.898.. Val L1 norm: 3.882.. Train Linf norm: 94.990.. Val Linf norm: 98.171
# Epoch 111/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.844.. Val L1 norm: 3.882.. Train Linf norm: 125.292.. Val Linf norm: 98.171
# Epoch 112/129.. Train loss: 1.993.. Val loss: 1.658.. Train L1 norm: 5.402.. Val L1 norm: 3.882.. Train Linf norm: 142.682.. Val Linf norm: 98.171
# Epoch 113/129.. Train loss: 1.992.. Val loss: 1.658.. Train L1 norm: 4.407.. Val L1 norm: 3.882.. Train Linf norm: 110.479.. Val Linf norm: 98.171
# Epoch 114/129.. Train loss: 1.983.. Val loss: 1.658.. Train L1 norm: 4.461.. Val L1 norm: 3.882.. Train Linf norm: 113.162.. Val Linf norm: 98.171
# Epoch 115/129.. Train loss: 1.991.. Val loss: 1.658.. Train L1 norm: 5.508.. Val L1 norm: 3.882.. Train Linf norm: 146.368.. Val Linf norm: 98.171
# Epoch 116/129.. Train loss: 1.996.. Val loss: 1.658.. Train L1 norm: 5.030.. Val L1 norm: 3.882.. Train Linf norm: 131.030.. Val Linf norm: 98.171
# Epoch 117/129.. Train loss: 1.990.. Val loss: 1.658.. Train L1 norm: 4.584.. Val L1 norm: 3.882.. Train Linf norm: 116.383.. Val Linf norm: 98.171
# Epoch 118/129.. Train loss: 1.993.. Val loss: 1.658.. Train L1 norm: 5.399.. Val L1 norm: 3.882.. Train Linf norm: 142.875.. Val Linf norm: 98.171
# Epoch 119/129.. Train loss: 1.983.. Val loss: 1.658.. Train L1 norm: 4.990.. Val L1 norm: 3.882.. Train Linf norm: 129.618.. Val Linf norm: 98.171
# Epoch 120/129.. Train loss: 1.987.. Val loss: 1.658.. Train L1 norm: 4.857.. Val L1 norm: 3.882.. Train Linf norm: 125.160.. Val Linf norm: 98.171
# Epoch 121/129.. Train loss: 1.989.. Val loss: 1.658.. Train L1 norm: 4.635.. Val L1 norm: 3.882.. Train Linf norm: 118.173.. Val Linf norm: 98.171
# Epoch 122/129.. Train loss: 2.005.. Val loss: 1.658.. Train L1 norm: 4.854.. Val L1 norm: 3.882.. Train Linf norm: 124.887.. Val Linf norm: 98.171
# Epoch 123/129.. Train loss: 1.988.. Val loss: 1.658.. Train L1 norm: 4.305.. Val L1 norm: 3.882.. Train Linf norm: 107.145.. Val Linf norm: 98.171
# Epoch 124/129.. Train loss: 1.996.. Val loss: 1.658.. Train L1 norm: 4.997.. Val L1 norm: 3.882.. Train Linf norm: 129.846.. Val Linf norm: 98.171
# Epoch 125/129.. Train loss: 1.996.. Val loss: 1.658.. Train L1 norm: 4.615.. Val L1 norm: 3.882.. Train Linf norm: 117.545.. Val Linf norm: 98.171
# Epoch 126/129.. Train loss: 1.985.. Val loss: 1.658.. Train L1 norm: 4.184.. Val L1 norm: 3.882.. Train Linf norm: 103.704.. Val Linf norm: 98.171
# Epoch 127/129.. Train loss: 1.977.. Val loss: 1.658.. Train L1 norm: 4.443.. Val L1 norm: 3.882.. Train Linf norm: 112.617.. Val Linf norm: 98.171
# Epoch 128/129.. Train loss: 1.981.. Val loss: 1.658.. Train L1 norm: 4.024.. Val L1 norm: 3.882.. Train Linf norm: 98.871.. Val Linf norm: 98.171
# [I 2023-05-31 09:32:48,905] Trial 0 finished with value: 3.8822645977656047 and parameters: {'n_layers': 4, 'n_units_0': 1423, 'n_units_1': 575, 'n_units_2': 460, 'n_units_3': 638, 'hidden_activation': 'LeakyReLU', 'output_activation': 'Linear', 'loss': 'Huber', 'optimizer': 'RMSprop', 'lr': 0.0005389927102448582, 'batch_size': 32, 'n_epochs': 129, 'scheduler': 'StepLR', 'leakyrelu_slope': 0.2180867032354345, 'dropout_rate': 0.11840180766168223, 'step_size': 7, 'gamma': 0.15208804007585652}. Best is trial 0 with value: 3.8822645977656047.
# Epoch 129/129.. Train loss: 1.979.. Val loss: 1.658.. Train L1 norm: 4.383.. Val L1 norm: 3.882.. Train Linf norm: 109.893.. Val Linf norm: 98.171
# <ipython-input-37-46c28bc3cd67>:168: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.1, 0.3)
# <ipython-input-37-46c28bc3cd67>:175: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   eta_min = trial.suggest_loguniform("eta_min", 1e-7, 1e-2)
# Epoch 1/138.. Train loss: 12.568.. Val loss: 2.027.. Train L1 norm: 17.461.. Val L1 norm: 4.448.. Train Linf norm: 5098.208.. Val Linf norm: 3004.760
# Epoch 2/138.. Train loss: 2.132.. Val loss: 1.990.. Train L1 norm: 6.473.. Val L1 norm: 3.694.. Train Linf norm: 5896.204.. Val Linf norm: 1731.274
# Epoch 3/138.. Train loss: 2.080.. Val loss: 2.061.. Train L1 norm: 6.540.. Val L1 norm: 3.503.. Train Linf norm: 6474.945.. Val Linf norm: 2238.120
# Epoch 4/138.. Train loss: 2.013.. Val loss: 2.039.. Train L1 norm: 5.740.. Val L1 norm: 5.715.. Train Linf norm: 4836.416.. Val Linf norm: 4318.121
# Epoch 5/138.. Train loss: 1.994.. Val loss: 1.933.. Train L1 norm: 6.681.. Val L1 norm: 4.413.. Train Linf norm: 6573.879.. Val Linf norm: 3129.589
# Epoch 6/138.. Train loss: 1.978.. Val loss: 1.944.. Train L1 norm: 6.654.. Val L1 norm: 5.008.. Train Linf norm: 6608.517.. Val Linf norm: 3732.747
# Epoch 7/138.. Train loss: 1.953.. Val loss: 2.067.. Train L1 norm: 6.941.. Val L1 norm: 3.438.. Train Linf norm: 7155.527.. Val Linf norm: 1843.535
# Epoch 8/138.. Train loss: 1.936.. Val loss: 1.911.. Train L1 norm: 6.237.. Val L1 norm: 4.169.. Train Linf norm: 5720.602.. Val Linf norm: 2728.316
# Epoch 9/138.. Train loss: 1.927.. Val loss: 2.224.. Train L1 norm: 5.860.. Val L1 norm: 2.673.. Train Linf norm: 4847.982.. Val Linf norm: 950.279
# Epoch 10/138.. Train loss: 1.926.. Val loss: 1.933.. Train L1 norm: 6.218.. Val L1 norm: 3.915.. Train Linf norm: 5793.588.. Val Linf norm: 2174.282
# Epoch 11/138.. Train loss: 1.906.. Val loss: 1.884.. Train L1 norm: 6.022.. Val L1 norm: 4.543.. Train Linf norm: 5495.643.. Val Linf norm: 3191.810
# Epoch 12/138.. Train loss: 1.905.. Val loss: 1.951.. Train L1 norm: 6.021.. Val L1 norm: 3.787.. Train Linf norm: 5054.733.. Val Linf norm: 2459.406
# Epoch 13/138.. Train loss: 1.891.. Val loss: 1.914.. Train L1 norm: 6.428.. Val L1 norm: 4.060.. Train Linf norm: 5901.050.. Val Linf norm: 2576.336
# Epoch 14/138.. Train loss: 1.898.. Val loss: 1.970.. Train L1 norm: 5.743.. Val L1 norm: 3.451.. Train Linf norm: 4810.535.. Val Linf norm: 2022.590
# Epoch 15/138.. Train loss: 1.892.. Val loss: 1.933.. Train L1 norm: 6.157.. Val L1 norm: 3.752.. Train Linf norm: 5649.233.. Val Linf norm: 2365.926
# Epoch 16/138.. Train loss: 1.895.. Val loss: 1.935.. Train L1 norm: 6.807.. Val L1 norm: 3.730.. Train Linf norm: 7059.880.. Val Linf norm: 2310.635
# Epoch 17/138.. Train loss: 1.886.. Val loss: 1.926.. Train L1 norm: 6.694.. Val L1 norm: 3.815.. Train Linf norm: 6664.513.. Val Linf norm: 2422.443
# Epoch 18/138.. Train loss: 1.889.. Val loss: 1.929.. Train L1 norm: 6.901.. Val L1 norm: 3.787.. Train Linf norm: 5879.510.. Val Linf norm: 2385.446
# Epoch 19/138.. Train loss: 1.895.. Val loss: 1.929.. Train L1 norm: 6.538.. Val L1 norm: 3.789.. Train Linf norm: 5997.178.. Val Linf norm: 2382.124
# Epoch 20/138.. Train loss: 1.884.. Val loss: 1.923.. Train L1 norm: 5.677.. Val L1 norm: 3.831.. Train Linf norm: 4744.260.. Val Linf norm: 2435.267
# Epoch 21/138.. Train loss: 1.889.. Val loss: 1.922.. Train L1 norm: 5.864.. Val L1 norm: 3.809.. Train Linf norm: 4855.003.. Val Linf norm: 2421.205
# Epoch 22/138.. Train loss: 1.882.. Val loss: 1.924.. Train L1 norm: 6.643.. Val L1 norm: 3.795.. Train Linf norm: 6499.044.. Val Linf norm: 2395.383
# Epoch 23/138.. Train loss: 1.884.. Val loss: 1.938.. Train L1 norm: 5.498.. Val L1 norm: 3.649.. Train Linf norm: 4057.400.. Val Linf norm: 2201.323
# Epoch 24/138.. Train loss: 1.880.. Val loss: 1.932.. Train L1 norm: 6.067.. Val L1 norm: 3.602.. Train Linf norm: 5365.686.. Val Linf norm: 2193.022
# Epoch 25/138.. Train loss: 1.884.. Val loss: 1.925.. Train L1 norm: 5.699.. Val L1 norm: 3.640.. Train Linf norm: 4754.036.. Val Linf norm: 2300.317
# Epoch 26/138.. Train loss: 1.874.. Val loss: 1.892.. Train L1 norm: 6.625.. Val L1 norm: 3.897.. Train Linf norm: 6499.908.. Val Linf norm: 2495.601
# Epoch 27/138.. Train loss: 1.878.. Val loss: 1.896.. Train L1 norm: 6.788.. Val L1 norm: 3.930.. Train Linf norm: 5381.299.. Val Linf norm: 2557.708
# Epoch 28/138.. Train loss: 1.874.. Val loss: 1.822.. Train L1 norm: 5.895.. Val L1 norm: 4.896.. Train Linf norm: 5330.537.. Val Linf norm: 3522.172
# Epoch 29/138.. Train loss: 1.864.. Val loss: 1.941.. Train L1 norm: 6.113.. Val L1 norm: 3.346.. Train Linf norm: 5291.591.. Val Linf norm: 1990.868
# Epoch 30/138.. Train loss: 1.863.. Val loss: 1.874.. Train L1 norm: 5.073.. Val L1 norm: 3.837.. Train Linf norm: 3449.280.. Val Linf norm: 2604.387
# Epoch 31/138.. Train loss: 1.859.. Val loss: 1.827.. Train L1 norm: 5.520.. Val L1 norm: 5.270.. Train Linf norm: 3969.434.. Val Linf norm: 3386.232
# Epoch 32/138.. Train loss: 1.858.. Val loss: 1.787.. Train L1 norm: 5.974.. Val L1 norm: 4.649.. Train Linf norm: 5422.016.. Val Linf norm: 3090.655
# Epoch 33/138.. Train loss: 1.842.. Val loss: 1.858.. Train L1 norm: 5.697.. Val L1 norm: 3.384.. Train Linf norm: 4881.361.. Val Linf norm: 1894.013
# Epoch 34/138.. Train loss: 1.841.. Val loss: 1.767.. Train L1 norm: 6.767.. Val L1 norm: 4.082.. Train Linf norm: 6867.868.. Val Linf norm: 2534.599
# Epoch 35/138.. Train loss: 1.830.. Val loss: 1.772.. Train L1 norm: 6.653.. Val L1 norm: 4.452.. Train Linf norm: 7089.743.. Val Linf norm: 3162.246
# Epoch 36/138.. Train loss: 1.829.. Val loss: 1.848.. Train L1 norm: 5.251.. Val L1 norm: 3.197.. Train Linf norm: 4172.344.. Val Linf norm: 1940.129
# Epoch 37/138.. Train loss: 1.826.. Val loss: 1.753.. Train L1 norm: 5.632.. Val L1 norm: 4.429.. Train Linf norm: 4917.741.. Val Linf norm: 3328.905
# Epoch 38/138.. Train loss: 1.813.. Val loss: 1.751.. Train L1 norm: 7.002.. Val L1 norm: 5.463.. Train Linf norm: 6091.305.. Val Linf norm: 3934.021
# Epoch 39/138.. Train loss: 1.816.. Val loss: 1.710.. Train L1 norm: 5.988.. Val L1 norm: 5.975.. Train Linf norm: 4367.838.. Val Linf norm: 4569.707
# Epoch 40/138.. Train loss: 1.805.. Val loss: 1.780.. Train L1 norm: 6.249.. Val L1 norm: 6.694.. Train Linf norm: 6319.249.. Val Linf norm: 4846.804
# Epoch 41/138.. Train loss: 1.795.. Val loss: 1.724.. Train L1 norm: 6.469.. Val L1 norm: 5.577.. Train Linf norm: 6543.781.. Val Linf norm: 4330.536
# Epoch 42/138.. Train loss: 1.783.. Val loss: 1.672.. Train L1 norm: 5.833.. Val L1 norm: 3.774.. Train Linf norm: 5588.400.. Val Linf norm: 2597.781
# Epoch 43/138.. Train loss: 1.784.. Val loss: 1.654.. Train L1 norm: 4.979.. Val L1 norm: 4.705.. Train Linf norm: 3696.618.. Val Linf norm: 3614.729
# Epoch 44/138.. Train loss: 1.770.. Val loss: 1.655.. Train L1 norm: 6.585.. Val L1 norm: 4.643.. Train Linf norm: 6881.775.. Val Linf norm: 3371.953
# Epoch 45/138.. Train loss: 1.758.. Val loss: 1.615.. Train L1 norm: 5.118.. Val L1 norm: 5.201.. Train Linf norm: 4295.578.. Val Linf norm: 4009.785
# Epoch 46/138.. Train loss: 1.759.. Val loss: 1.606.. Train L1 norm: 5.922.. Val L1 norm: 4.791.. Train Linf norm: 5925.016.. Val Linf norm: 3396.832
# Epoch 47/138.. Train loss: 1.749.. Val loss: 1.608.. Train L1 norm: 6.523.. Val L1 norm: 5.325.. Train Linf norm: 7253.797.. Val Linf norm: 4087.410
# Epoch 48/138.. Train loss: 1.749.. Val loss: 1.596.. Train L1 norm: 6.544.. Val L1 norm: 4.917.. Train Linf norm: 6900.191.. Val Linf norm: 3657.625
# Epoch 49/138.. Train loss: 1.747.. Val loss: 1.595.. Train L1 norm: 6.486.. Val L1 norm: 4.867.. Train Linf norm: 6460.845.. Val Linf norm: 3566.150
# Epoch 50/138.. Train loss: 1.743.. Val loss: 1.591.. Train L1 norm: 4.956.. Val L1 norm: 4.197.. Train Linf norm: 3557.605.. Val Linf norm: 2884.599
# Epoch 51/138.. Train loss: 1.741.. Val loss: 1.590.. Train L1 norm: 5.943.. Val L1 norm: 4.109.. Train Linf norm: 6094.643.. Val Linf norm: 2924.895
# Epoch 52/138.. Train loss: 1.742.. Val loss: 1.581.. Train L1 norm: 6.788.. Val L1 norm: 4.577.. Train Linf norm: 7365.239.. Val Linf norm: 3350.935
# Epoch 53/138.. Train loss: 1.741.. Val loss: 1.580.. Train L1 norm: 6.805.. Val L1 norm: 4.511.. Train Linf norm: 7295.947.. Val Linf norm: 3287.019
# Epoch 54/138.. Train loss: 1.745.. Val loss: 1.580.. Train L1 norm: 7.621.. Val L1 norm: 4.504.. Train Linf norm: 9132.157.. Val Linf norm: 3280.523
# Epoch 55/138.. Train loss: 1.742.. Val loss: 1.580.. Train L1 norm: 4.541.. Val L1 norm: 4.509.. Train Linf norm: 3395.055.. Val Linf norm: 3284.681
# Epoch 56/138.. Train loss: 1.733.. Val loss: 1.580.. Train L1 norm: 5.246.. Val L1 norm: 4.550.. Train Linf norm: 4313.546.. Val Linf norm: 3319.848
# Epoch 57/138.. Train loss: 1.739.. Val loss: 1.579.. Train L1 norm: 4.897.. Val L1 norm: 4.527.. Train Linf norm: 3839.771.. Val Linf norm: 3312.975
# Epoch 58/138.. Train loss: 1.738.. Val loss: 1.580.. Train L1 norm: 4.838.. Val L1 norm: 4.493.. Train Linf norm: 3485.798.. Val Linf norm: 3277.009
# Epoch 59/138.. Train loss: 1.739.. Val loss: 1.585.. Train L1 norm: 7.617.. Val L1 norm: 4.627.. Train Linf norm: 9482.493.. Val Linf norm: 3415.167
# Epoch 60/138.. Train loss: 1.731.. Val loss: 1.584.. Train L1 norm: 5.029.. Val L1 norm: 4.849.. Train Linf norm: 3486.135.. Val Linf norm: 3686.329
# Epoch 61/138.. Train loss: 1.738.. Val loss: 1.585.. Train L1 norm: 5.515.. Val L1 norm: 4.958.. Train Linf norm: 5054.410.. Val Linf norm: 3658.670
# Epoch 62/138.. Train loss: 1.740.. Val loss: 1.578.. Train L1 norm: 4.981.. Val L1 norm: 4.843.. Train Linf norm: 3715.374.. Val Linf norm: 3472.108
# Epoch 63/138.. Train loss: 1.735.. Val loss: 1.582.. Train L1 norm: 5.488.. Val L1 norm: 5.082.. Train Linf norm: 4986.088.. Val Linf norm: 3652.094
# Epoch 64/138.. Train loss: 1.727.. Val loss: 1.577.. Train L1 norm: 6.021.. Val L1 norm: 5.020.. Train Linf norm: 5861.286.. Val Linf norm: 3661.270
# Epoch 65/138.. Train loss: 1.725.. Val loss: 1.548.. Train L1 norm: 6.047.. Val L1 norm: 4.232.. Train Linf norm: 5871.340.. Val Linf norm: 2975.997
# Epoch 66/138.. Train loss: 1.734.. Val loss: 1.586.. Train L1 norm: 5.832.. Val L1 norm: 4.976.. Train Linf norm: 5509.144.. Val Linf norm: 3198.777
# Epoch 67/138.. Train loss: 1.725.. Val loss: 1.580.. Train L1 norm: 6.720.. Val L1 norm: 4.827.. Train Linf norm: 7473.047.. Val Linf norm: 3187.075
# Epoch 68/138.. Train loss: 1.726.. Val loss: 1.553.. Train L1 norm: 6.225.. Val L1 norm: 4.061.. Train Linf norm: 5317.070.. Val Linf norm: 2518.006
# Epoch 69/138.. Train loss: 1.727.. Val loss: 1.545.. Train L1 norm: 4.883.. Val L1 norm: 4.887.. Train Linf norm: 3718.290.. Val Linf norm: 3710.093
# Epoch 70/138.. Train loss: 1.715.. Val loss: 1.557.. Train L1 norm: 5.716.. Val L1 norm: 3.303.. Train Linf norm: 5682.327.. Val Linf norm: 1750.305
# Epoch 71/138.. Train loss: 1.715.. Val loss: 1.647.. Train L1 norm: 5.623.. Val L1 norm: 5.873.. Train Linf norm: 5212.339.. Val Linf norm: 4192.460
# Epoch 72/138.. Train loss: 1.706.. Val loss: 1.517.. Train L1 norm: 5.474.. Val L1 norm: 4.108.. Train Linf norm: 5214.285.. Val Linf norm: 2730.790
# Epoch 73/138.. Train loss: 1.706.. Val loss: 1.608.. Train L1 norm: 5.052.. Val L1 norm: 5.745.. Train Linf norm: 4251.003.. Val Linf norm: 3943.853
# Epoch 74/138.. Train loss: 1.702.. Val loss: 1.534.. Train L1 norm: 5.515.. Val L1 norm: 3.166.. Train Linf norm: 5508.618.. Val Linf norm: 1761.192
# Epoch 75/138.. Train loss: 1.698.. Val loss: 1.491.. Train L1 norm: 5.155.. Val L1 norm: 4.215.. Train Linf norm: 4680.323.. Val Linf norm: 2918.594
# Epoch 76/138.. Train loss: 1.683.. Val loss: 1.506.. Train L1 norm: 5.458.. Val L1 norm: 4.980.. Train Linf norm: 4734.357.. Val Linf norm: 3584.140
# Epoch 77/138.. Train loss: 1.687.. Val loss: 1.493.. Train L1 norm: 4.542.. Val L1 norm: 4.551.. Train Linf norm: 3345.562.. Val Linf norm: 3044.875
# Epoch 78/138.. Train loss: 1.681.. Val loss: 1.488.. Train L1 norm: 5.500.. Val L1 norm: 3.641.. Train Linf norm: 5242.124.. Val Linf norm: 2325.801
# Epoch 79/138.. Train loss: 1.677.. Val loss: 1.499.. Train L1 norm: 6.370.. Val L1 norm: 5.369.. Train Linf norm: 6214.887.. Val Linf norm: 4198.841
# Epoch 80/138.. Train loss: 1.671.. Val loss: 1.506.. Train L1 norm: 5.941.. Val L1 norm: 5.027.. Train Linf norm: 6284.619.. Val Linf norm: 3551.532
# Epoch 81/138.. Train loss: 1.664.. Val loss: 1.468.. Train L1 norm: 4.859.. Val L1 norm: 4.621.. Train Linf norm: 3698.742.. Val Linf norm: 3458.144
# Epoch 82/138.. Train loss: 1.669.. Val loss: 1.493.. Train L1 norm: 5.161.. Val L1 norm: 4.931.. Train Linf norm: 4005.205.. Val Linf norm: 3465.637
# Epoch 83/138.. Train loss: 1.660.. Val loss: 1.499.. Train L1 norm: 5.398.. Val L1 norm: 4.882.. Train Linf norm: 5187.548.. Val Linf norm: 3297.954
# Epoch 84/138.. Train loss: 1.663.. Val loss: 1.491.. Train L1 norm: 6.652.. Val L1 norm: 4.755.. Train Linf norm: 7471.166.. Val Linf norm: 3159.139
# Epoch 85/138.. Train loss: 1.655.. Val loss: 1.475.. Train L1 norm: 5.120.. Val L1 norm: 4.367.. Train Linf norm: 3997.429.. Val Linf norm: 2723.463
# Epoch 86/138.. Train loss: 1.655.. Val loss: 1.468.. Train L1 norm: 6.171.. Val L1 norm: 4.269.. Train Linf norm: 6774.206.. Val Linf norm: 2637.216
# Epoch 87/138.. Train loss: 1.655.. Val loss: 1.478.. Train L1 norm: 6.764.. Val L1 norm: 4.511.. Train Linf norm: 7800.463.. Val Linf norm: 2896.711
# Epoch 88/138.. Train loss: 1.662.. Val loss: 1.476.. Train L1 norm: 5.259.. Val L1 norm: 4.417.. Train Linf norm: 4873.061.. Val Linf norm: 2795.799
# Epoch 89/138.. Train loss: 1.652.. Val loss: 1.479.. Train L1 norm: 5.693.. Val L1 norm: 4.494.. Train Linf norm: 5646.223.. Val Linf norm: 2876.441
# Epoch 90/138.. Train loss: 1.655.. Val loss: 1.480.. Train L1 norm: 4.851.. Val L1 norm: 4.511.. Train Linf norm: 4083.670.. Val Linf norm: 2890.964
# Epoch 91/138.. Train loss: 1.654.. Val loss: 1.480.. Train L1 norm: 6.421.. Val L1 norm: 4.511.. Train Linf norm: 7232.216.. Val Linf norm: 2892.192
# Epoch 92/138.. Train loss: 1.662.. Val loss: 1.480.. Train L1 norm: 6.203.. Val L1 norm: 4.503.. Train Linf norm: 5836.483.. Val Linf norm: 2886.223
# Epoch 93/138.. Train loss: 1.646.. Val loss: 1.478.. Train L1 norm: 5.186.. Val L1 norm: 4.486.. Train Linf norm: 4866.146.. Val Linf norm: 2879.136
# Epoch 94/138.. Train loss: 1.656.. Val loss: 1.481.. Train L1 norm: 4.665.. Val L1 norm: 4.582.. Train Linf norm: 3762.389.. Val Linf norm: 2986.248
# Epoch 95/138.. Train loss: 1.653.. Val loss: 1.489.. Train L1 norm: 5.258.. Val L1 norm: 4.709.. Train Linf norm: 4950.149.. Val Linf norm: 3117.991
# Epoch 96/138.. Train loss: 1.653.. Val loss: 1.486.. Train L1 norm: 4.361.. Val L1 norm: 4.627.. Train Linf norm: 2894.313.. Val Linf norm: 3037.367
# Epoch 97/138.. Train loss: 1.651.. Val loss: 1.485.. Train L1 norm: 5.681.. Val L1 norm: 4.578.. Train Linf norm: 5381.426.. Val Linf norm: 2946.457
# Epoch 98/138.. Train loss: 1.650.. Val loss: 1.484.. Train L1 norm: 6.487.. Val L1 norm: 4.458.. Train Linf norm: 7178.602.. Val Linf norm: 2934.212
# Epoch 99/138.. Train loss: 1.653.. Val loss: 1.509.. Train L1 norm: 6.302.. Val L1 norm: 4.950.. Train Linf norm: 6971.944.. Val Linf norm: 3246.791
# Epoch 100/138.. Train loss: 1.650.. Val loss: 1.475.. Train L1 norm: 5.431.. Val L1 norm: 4.538.. Train Linf norm: 5077.873.. Val Linf norm: 3014.904
# Epoch 101/138.. Train loss: 1.657.. Val loss: 1.471.. Train L1 norm: 4.713.. Val L1 norm: 4.655.. Train Linf norm: 3730.013.. Val Linf norm: 3174.566
# Epoch 102/138.. Train loss: 1.646.. Val loss: 1.431.. Train L1 norm: 6.184.. Val L1 norm: 3.731.. Train Linf norm: 6457.683.. Val Linf norm: 2243.854
# Epoch 103/138.. Train loss: 1.644.. Val loss: 1.467.. Train L1 norm: 4.853.. Val L1 norm: 4.259.. Train Linf norm: 4340.708.. Val Linf norm: 2553.178
# Epoch 104/138.. Train loss: 1.648.. Val loss: 1.494.. Train L1 norm: 4.898.. Val L1 norm: 4.890.. Train Linf norm: 4141.680.. Val Linf norm: 3108.080
# Epoch 105/138.. Train loss: 1.644.. Val loss: 1.458.. Train L1 norm: 5.052.. Val L1 norm: 4.452.. Train Linf norm: 4461.528.. Val Linf norm: 2766.443
# Epoch 106/138.. Train loss: 1.645.. Val loss: 1.540.. Train L1 norm: 5.425.. Val L1 norm: 5.505.. Train Linf norm: 5289.222.. Val Linf norm: 3688.186
# Epoch 107/138.. Train loss: 1.647.. Val loss: 1.465.. Train L1 norm: 4.702.. Val L1 norm: 4.719.. Train Linf norm: 3950.062.. Val Linf norm: 3046.376
# Epoch 108/138.. Train loss: 1.636.. Val loss: 1.549.. Train L1 norm: 5.223.. Val L1 norm: 5.728.. Train Linf norm: 4819.332.. Val Linf norm: 4195.402
# Epoch 109/138.. Train loss: 1.643.. Val loss: 1.421.. Train L1 norm: 5.176.. Val L1 norm: 3.926.. Train Linf norm: 4820.105.. Val Linf norm: 2713.583
# Epoch 110/138.. Train loss: 1.636.. Val loss: 1.434.. Train L1 norm: 5.723.. Val L1 norm: 3.355.. Train Linf norm: 5456.150.. Val Linf norm: 2042.815
# Epoch 111/138.. Train loss: 1.631.. Val loss: 1.431.. Train L1 norm: 7.168.. Val L1 norm: 4.165.. Train Linf norm: 8794.570.. Val Linf norm: 2887.863
# Epoch 112/138.. Train loss: 1.631.. Val loss: 1.615.. Train L1 norm: 5.714.. Val L1 norm: 6.403.. Train Linf norm: 5791.311.. Val Linf norm: 4776.038
# Epoch 113/138.. Train loss: 1.632.. Val loss: 1.443.. Train L1 norm: 5.822.. Val L1 norm: 4.158.. Train Linf norm: 6053.427.. Val Linf norm: 2942.193
# Epoch 114/138.. Train loss: 1.625.. Val loss: 1.432.. Train L1 norm: 5.034.. Val L1 norm: 4.581.. Train Linf norm: 4536.802.. Val Linf norm: 3539.035
# Epoch 115/138.. Train loss: 1.616.. Val loss: 1.457.. Train L1 norm: 5.469.. Val L1 norm: 4.510.. Train Linf norm: 5254.784.. Val Linf norm: 2892.240
# Epoch 116/138.. Train loss: 1.616.. Val loss: 1.421.. Train L1 norm: 4.765.. Val L1 norm: 4.659.. Train Linf norm: 4275.047.. Val Linf norm: 3280.535
# Epoch 117/138.. Train loss: 1.616.. Val loss: 1.453.. Train L1 norm: 4.675.. Val L1 norm: 4.874.. Train Linf norm: 4011.462.. Val Linf norm: 3373.765
# Epoch 118/138.. Train loss: 1.609.. Val loss: 1.447.. Train L1 norm: 4.744.. Val L1 norm: 5.108.. Train Linf norm: 3631.729.. Val Linf norm: 3833.181
# Epoch 119/138.. Train loss: 1.606.. Val loss: 1.439.. Train L1 norm: 4.654.. Val L1 norm: 4.847.. Train Linf norm: 3891.710.. Val Linf norm: 3530.203
# Epoch 120/138.. Train loss: 1.614.. Val loss: 1.449.. Train L1 norm: 4.411.. Val L1 norm: 4.883.. Train Linf norm: 3342.784.. Val Linf norm: 3522.457
# Epoch 121/138.. Train loss: 1.603.. Val loss: 1.430.. Train L1 norm: 4.978.. Val L1 norm: 4.515.. Train Linf norm: 4398.589.. Val Linf norm: 3134.644
# Epoch 122/138.. Train loss: 1.616.. Val loss: 1.433.. Train L1 norm: 5.832.. Val L1 norm: 4.613.. Train Linf norm: 6570.347.. Val Linf norm: 3244.120
# Epoch 123/138.. Train loss: 1.606.. Val loss: 1.450.. Train L1 norm: 5.900.. Val L1 norm: 4.765.. Train Linf norm: 5350.051.. Val Linf norm: 3341.290
# Epoch 124/138.. Train loss: 1.610.. Val loss: 1.445.. Train L1 norm: 6.108.. Val L1 norm: 4.686.. Train Linf norm: 6709.727.. Val Linf norm: 3216.015
# Epoch 125/138.. Train loss: 1.603.. Val loss: 1.445.. Train L1 norm: 5.929.. Val L1 norm: 4.688.. Train Linf norm: 6410.048.. Val Linf norm: 3216.212
# Epoch 126/138.. Train loss: 1.601.. Val loss: 1.445.. Train L1 norm: 6.462.. Val L1 norm: 4.691.. Train Linf norm: 7253.245.. Val Linf norm: 3222.487
# Epoch 127/138.. Train loss: 1.603.. Val loss: 1.445.. Train L1 norm: 5.115.. Val L1 norm: 4.704.. Train Linf norm: 4988.243.. Val Linf norm: 3234.613
# Epoch 128/138.. Train loss: 1.608.. Val loss: 1.445.. Train L1 norm: 5.232.. Val L1 norm: 4.691.. Train Linf norm: 4324.900.. Val Linf norm: 3216.247
# Epoch 129/138.. Train loss: 1.605.. Val loss: 1.445.. Train L1 norm: 6.342.. Val L1 norm: 4.701.. Train Linf norm: 6652.308.. Val Linf norm: 3224.908
# Epoch 130/138.. Train loss: 1.603.. Val loss: 1.443.. Train L1 norm: 5.401.. Val L1 norm: 4.661.. Train Linf norm: 5399.430.. Val Linf norm: 3184.771
# Epoch 131/138.. Train loss: 1.603.. Val loss: 1.433.. Train L1 norm: 5.904.. Val L1 norm: 4.486.. Train Linf norm: 6175.109.. Val Linf norm: 3025.977
# Epoch 132/138.. Train loss: 1.610.. Val loss: 1.442.. Train L1 norm: 5.117.. Val L1 norm: 4.736.. Train Linf norm: 4151.236.. Val Linf norm: 3303.630
# Epoch 133/138.. Train loss: 1.604.. Val loss: 1.438.. Train L1 norm: 5.046.. Val L1 norm: 4.646.. Train Linf norm: 4848.372.. Val Linf norm: 3175.280
# Epoch 134/138.. Train loss: 1.610.. Val loss: 1.434.. Train L1 norm: 5.470.. Val L1 norm: 4.624.. Train Linf norm: 5322.354.. Val Linf norm: 3245.254
# Epoch 135/138.. Train loss: 1.606.. Val loss: 1.432.. Train L1 norm: 5.570.. Val L1 norm: 4.564.. Train Linf norm: 5795.967.. Val Linf norm: 3220.071
# Epoch 136/138.. Train loss: 1.605.. Val loss: 1.426.. Train L1 norm: 6.808.. Val L1 norm: 4.482.. Train Linf norm: 8277.734.. Val Linf norm: 3106.764
# Epoch 137/138.. Train loss: 1.605.. Val loss: 1.478.. Train L1 norm: 5.772.. Val L1 norm: 5.503.. Train Linf norm: 6202.630.. Val Linf norm: 4128.343
# [I 2023-05-31 09:38:45,034] Trial 1 finished with value: 5.117266993204753 and parameters: {'n_layers': 6, 'n_units_0': 1300, 'n_units_1': 2183, 'n_units_2': 3245, 'n_units_3': 513, 'n_units_4': 666, 'n_units_5': 2076, 'hidden_activation': 'GELU', 'output_activation': 'Linear', 'loss': 'Quantile', 'optimizer': 'Adagrad', 'lr': 0.002558657031705037, 'batch_size': 2048, 'n_epochs': 138, 'scheduler': 'CosineAnnealingLR', 'dropout_rate': 0.34311584380997295, 't_max_fraction': 0.13112105732780963, 'eta_min': 2.2527275600509997e-05}. Best is trial 0 with value: 3.8822645977656047.
# Epoch 138/138.. Train loss: 1.601.. Val loss: 1.443.. Train L1 norm: 6.206.. Val L1 norm: 5.117.. Train Linf norm: 7147.348.. Val Linf norm: 3990.023
# <ipython-input-37-46c28bc3cd67>:73: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   beta = trial.suggest_uniform("softplus_beta", 0.5, 1.5)
# <ipython-input-37-46c28bc3cd67>:145: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
# <ipython-input-37-46c28bc3cd67>:146: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
# Epoch 1/148.. Train loss: 6.024.. Val loss: 4.089.. Train L1 norm: 7.531.. Val L1 norm: 4.775.. Train Linf norm: 5196.682.. Val Linf norm: 3144.052
# Epoch 2/148.. Train loss: 4.755.. Val loss: 4.284.. Train L1 norm: 8.335.. Val L1 norm: 6.822.. Train Linf norm: 8858.699.. Val Linf norm: 5130.550
# Epoch 3/148.. Train loss: 4.823.. Val loss: 4.129.. Train L1 norm: 6.456.. Val L1 norm: 5.279.. Train Linf norm: 5875.804.. Val Linf norm: 3530.027
# Epoch 4/148.. Train loss: 4.452.. Val loss: 4.704.. Train L1 norm: 6.718.. Val L1 norm: 10.388.. Train Linf norm: 6079.810.. Val Linf norm: 7786.177
# Epoch 5/148.. Train loss: 4.470.. Val loss: 4.057.. Train L1 norm: 6.755.. Val L1 norm: 5.623.. Train Linf norm: 6409.745.. Val Linf norm: 3857.692
# Epoch 6/148.. Train loss: 4.413.. Val loss: 4.024.. Train L1 norm: 6.571.. Val L1 norm: 4.541.. Train Linf norm: 5740.172.. Val Linf norm: 2774.189
# Epoch 7/148.. Train loss: 4.301.. Val loss: 4.037.. Train L1 norm: 5.601.. Val L1 norm: 5.781.. Train Linf norm: 4712.244.. Val Linf norm: 3874.351
# Epoch 8/148.. Train loss: 4.438.. Val loss: 4.120.. Train L1 norm: 7.022.. Val L1 norm: 4.088.. Train Linf norm: 7166.203.. Val Linf norm: 2551.386
# Epoch 9/148.. Train loss: 4.332.. Val loss: 4.054.. Train L1 norm: 5.980.. Val L1 norm: 4.537.. Train Linf norm: 4892.347.. Val Linf norm: 2864.109
# Epoch 10/148.. Train loss: 4.268.. Val loss: 14.784.. Train L1 norm: 6.457.. Val L1 norm: 12.824.. Train Linf norm: 5870.260.. Val Linf norm: 7128.411
# Epoch 11/148.. Train loss: 4.737.. Val loss: 4.062.. Train L1 norm: 6.665.. Val L1 norm: 4.929.. Train Linf norm: 6827.948.. Val Linf norm: 3153.100
# Epoch 12/148.. Train loss: 4.451.. Val loss: 4.017.. Train L1 norm: 5.468.. Val L1 norm: 5.325.. Train Linf norm: 4683.278.. Val Linf norm: 3462.448
# Epoch 13/148.. Train loss: 4.341.. Val loss: 3.997.. Train L1 norm: 6.667.. Val L1 norm: 5.561.. Train Linf norm: 6111.284.. Val Linf norm: 3648.993
# Epoch 14/148.. Train loss: 4.230.. Val loss: 3.990.. Train L1 norm: 6.688.. Val L1 norm: 5.049.. Train Linf norm: 4698.612.. Val Linf norm: 3213.984
# Epoch 15/148.. Train loss: 4.278.. Val loss: 4.036.. Train L1 norm: 6.792.. Val L1 norm: 5.069.. Train Linf norm: 6607.353.. Val Linf norm: 3299.022
# Epoch 16/148.. Train loss: 4.173.. Val loss: 3.974.. Train L1 norm: 6.600.. Val L1 norm: 5.078.. Train Linf norm: 6028.941.. Val Linf norm: 3249.876
# Epoch 17/148.. Train loss: 4.217.. Val loss: 4.020.. Train L1 norm: 6.246.. Val L1 norm: 5.122.. Train Linf norm: 4860.344.. Val Linf norm: 3298.866
# Epoch 18/148.. Train loss: 4.188.. Val loss: 4.015.. Train L1 norm: 6.365.. Val L1 norm: 5.336.. Train Linf norm: 5728.076.. Val Linf norm: 3463.213
# Epoch 19/148.. Train loss: 4.176.. Val loss: 4.013.. Train L1 norm: 6.562.. Val L1 norm: 5.050.. Train Linf norm: 6173.905.. Val Linf norm: 3225.264
# Epoch 20/148.. Train loss: 4.154.. Val loss: 4.012.. Train L1 norm: 6.668.. Val L1 norm: 5.206.. Train Linf norm: 6404.628.. Val Linf norm: 3333.794
# Epoch 21/148.. Train loss: 4.143.. Val loss: 4.005.. Train L1 norm: 6.615.. Val L1 norm: 5.292.. Train Linf norm: 6635.946.. Val Linf norm: 3386.527
# Epoch 22/148.. Train loss: 4.148.. Val loss: 4.009.. Train L1 norm: 6.525.. Val L1 norm: 5.223.. Train Linf norm: 6224.480.. Val Linf norm: 3327.089
# Epoch 23/148.. Train loss: 4.172.. Val loss: 4.009.. Train L1 norm: 6.669.. Val L1 norm: 5.117.. Train Linf norm: 6576.956.. Val Linf norm: 3241.509
# Epoch 24/148.. Train loss: 4.164.. Val loss: 4.009.. Train L1 norm: 6.549.. Val L1 norm: 5.110.. Train Linf norm: 6383.931.. Val Linf norm: 3229.703
# Epoch 25/148.. Train loss: 4.159.. Val loss: 4.005.. Train L1 norm: 6.576.. Val L1 norm: 5.206.. Train Linf norm: 6430.579.. Val Linf norm: 3299.873
# Epoch 26/148.. Train loss: 4.147.. Val loss: 3.989.. Train L1 norm: 6.325.. Val L1 norm: 5.277.. Train Linf norm: 6019.665.. Val Linf norm: 3326.931
# Epoch 27/148.. Train loss: 4.117.. Val loss: 3.974.. Train L1 norm: 6.229.. Val L1 norm: 5.187.. Train Linf norm: 5423.823.. Val Linf norm: 3203.909
# Epoch 28/148.. Train loss: 4.137.. Val loss: 4.410.. Train L1 norm: 5.796.. Val L1 norm: 2.942.. Train Linf norm: 4979.828.. Val Linf norm: 1518.344
# Epoch 29/148.. Train loss: 4.247.. Val loss: 3.946.. Train L1 norm: 5.455.. Val L1 norm: 5.424.. Train Linf norm: 4355.306.. Val Linf norm: 3464.571
# Epoch 30/148.. Train loss: 4.198.. Val loss: 4.000.. Train L1 norm: 6.361.. Val L1 norm: 4.854.. Train Linf norm: 6158.232.. Val Linf norm: 2985.099
# Epoch 31/148.. Train loss: 4.222.. Val loss: 3.995.. Train L1 norm: 6.347.. Val L1 norm: 4.784.. Train Linf norm: 5876.326.. Val Linf norm: 2965.764
# ...
# Epoch 13/61.. Train loss: 2.334.. Val loss: 2.217.. Train L1 norm: 2.399.. Val L1 norm: 2.227.. Train Linf norm: 1702.238.. Val Linf norm: 1021.294
# Epoch 14/61.. Train loss: 2.333.. Val loss: 2.203.. Train L1 norm: 2.424.. Val L1 norm: 2.312.. Train Linf norm: 1739.059.. Val Linf norm: 1083.491
# Epoch 15/61.. Train loss: 2.316.. Val loss: 2.189.. Train L1 norm: 2.380.. Val L1 norm: 2.396.. Train Linf norm: 1448.731.. Val Linf norm: 1144.842
# Epoch 16/61.. Train loss: 2.308.. Val loss: 2.177.. Train L1 norm: 2.842.. Val L1 norm: 2.479.. Train Linf norm: 1815.561.. Val Linf norm: 1204.855
# Epoch 17/61.. Train loss: 2.292.. Val loss: 2.165.. Train L1 norm: 2.951.. Val L1 norm: 2.560.. Train Linf norm: 2502.952.. Val Linf norm: 1263.692
# Epoch 18/61.. Train loss: 2.294.. Val loss: 2.153.. Train L1 norm: 2.953.. Val L1 norm: 2.640.. Train Linf norm: 2373.755.. Val Linf norm: 1320.747
# Epoch 19/61.. Train loss: 2.278.. Val loss: 2.143.. Train L1 norm: 2.874.. Val L1 norm: 2.718.. Train Linf norm: 2113.480.. Val Linf norm: 1376.929
# Epoch 20/61.. Train loss: 2.277.. Val loss: 2.132.. Train L1 norm: 3.020.. Val L1 norm: 2.796.. Train Linf norm: 2199.207.. Val Linf norm: 1432.662
# Epoch 21/61.. Train loss: 2.258.. Val loss: 2.122.. Train L1 norm: 3.171.. Val L1 norm: 2.873.. Train Linf norm: 2555.332.. Val Linf norm: 1487.636
# Epoch 22/61.. Train loss: 2.264.. Val loss: 2.113.. Train L1 norm: 3.249.. Val L1 norm: 2.945.. Train Linf norm: 2625.530.. Val Linf norm: 1539.142
# Epoch 23/61.. Train loss: 2.248.. Val loss: 2.105.. Train L1 norm: 3.300.. Val L1 norm: 3.017.. Train Linf norm: 2829.407.. Val Linf norm: 1590.235
# Epoch 24/61.. Train loss: 2.232.. Val loss: 2.096.. Train L1 norm: 3.443.. Val L1 norm: 3.090.. Train Linf norm: 2969.286.. Val Linf norm: 1641.711
# Epoch 25/61.. Train loss: 2.236.. Val loss: 2.089.. Train L1 norm: 3.473.. Val L1 norm: 3.159.. Train Linf norm: 2918.084.. Val Linf norm: 1690.068
# Epoch 26/61.. Train loss: 2.236.. Val loss: 2.082.. Train L1 norm: 3.484.. Val L1 norm: 3.223.. Train Linf norm: 2821.227.. Val Linf norm: 1735.499
# Epoch 27/61.. Train loss: 2.231.. Val loss: 2.075.. Train L1 norm: 3.530.. Val L1 norm: 3.287.. Train Linf norm: 2450.339.. Val Linf norm: 1780.670
# Epoch 28/61.. Train loss: 2.219.. Val loss: 2.070.. Train L1 norm: 3.733.. Val L1 norm: 3.346.. Train Linf norm: 2954.343.. Val Linf norm: 1822.183
# Epoch 29/61.. Train loss: 2.215.. Val loss: 2.064.. Train L1 norm: 3.669.. Val L1 norm: 3.407.. Train Linf norm: 3028.487.. Val Linf norm: 1865.367
# Epoch 30/61.. Train loss: 2.208.. Val loss: 2.058.. Train L1 norm: 3.949.. Val L1 norm: 3.468.. Train Linf norm: 3574.364.. Val Linf norm: 1907.815
# Epoch 31/61.. Train loss: 2.198.. Val loss: 2.053.. Train L1 norm: 3.954.. Val L1 norm: 3.528.. Train Linf norm: 3418.916.. Val Linf norm: 1949.737
# Epoch 32/61.. Train loss: 2.206.. Val loss: 2.048.. Train L1 norm: 4.012.. Val L1 norm: 3.584.. Train Linf norm: 3201.916.. Val Linf norm: 1989.499
# Epoch 33/61.. Train loss: 2.193.. Val loss: 2.043.. Train L1 norm: 3.977.. Val L1 norm: 3.640.. Train Linf norm: 3405.369.. Val Linf norm: 2028.110
# Epoch 34/61.. Train loss: 2.186.. Val loss: 2.039.. Train L1 norm: 4.134.. Val L1 norm: 3.695.. Train Linf norm: 3545.106.. Val Linf norm: 2066.487
# Epoch 35/61.. Train loss: 2.186.. Val loss: 2.035.. Train L1 norm: 4.114.. Val L1 norm: 3.747.. Train Linf norm: 3706.232.. Val Linf norm: 2103.028
# Epoch 36/61.. Train loss: 2.182.. Val loss: 2.031.. Train L1 norm: 4.159.. Val L1 norm: 3.798.. Train Linf norm: 3494.880.. Val Linf norm: 2138.773
# Epoch 37/61.. Train loss: 2.192.. Val loss: 2.027.. Train L1 norm: 4.155.. Val L1 norm: 3.847.. Train Linf norm: 3416.162.. Val Linf norm: 2173.310
# Epoch 38/61.. Train loss: 2.178.. Val loss: 2.024.. Train L1 norm: 4.420.. Val L1 norm: 3.893.. Train Linf norm: 4078.732.. Val Linf norm: 2205.652
# Epoch 39/61.. Train loss: 2.178.. Val loss: 2.021.. Train L1 norm: 4.493.. Val L1 norm: 3.940.. Train Linf norm: 4064.155.. Val Linf norm: 2238.218
# Epoch 40/61.. Train loss: 2.175.. Val loss: 2.018.. Train L1 norm: 4.398.. Val L1 norm: 3.981.. Train Linf norm: 3891.671.. Val Linf norm: 2267.540
# Epoch 41/61.. Train loss: 2.183.. Val loss: 2.015.. Train L1 norm: 4.580.. Val L1 norm: 4.023.. Train Linf norm: 4233.203.. Val Linf norm: 2296.884
# Epoch 42/61.. Train loss: 2.175.. Val loss: 2.013.. Train L1 norm: 4.535.. Val L1 norm: 4.064.. Train Linf norm: 3927.189.. Val Linf norm: 2325.326
# Epoch 43/61.. Train loss: 2.163.. Val loss: 2.010.. Train L1 norm: 4.560.. Val L1 norm: 4.103.. Train Linf norm: 4191.490.. Val Linf norm: 2352.649
# Epoch 44/61.. Train loss: 2.163.. Val loss: 2.008.. Train L1 norm: 4.570.. Val L1 norm: 4.141.. Train Linf norm: 4051.819.. Val Linf norm: 2379.913
# Epoch 45/61.. Train loss: 2.156.. Val loss: 2.005.. Train L1 norm: 4.586.. Val L1 norm: 4.180.. Train Linf norm: 4000.345.. Val Linf norm: 2406.767
# Epoch 46/61.. Train loss: 2.151.. Val loss: 2.003.. Train L1 norm: 4.679.. Val L1 norm: 4.218.. Train Linf norm: 4138.832.. Val Linf norm: 2434.040
# Epoch 47/61.. Train loss: 2.152.. Val loss: 2.001.. Train L1 norm: 4.783.. Val L1 norm: 4.257.. Train Linf norm: 4292.079.. Val Linf norm: 2460.960
# Epoch 48/61.. Train loss: 2.152.. Val loss: 1.999.. Train L1 norm: 4.744.. Val L1 norm: 4.293.. Train Linf norm: 3685.159.. Val Linf norm: 2486.699
# Epoch 49/61.. Train loss: 2.152.. Val loss: 1.997.. Train L1 norm: 4.784.. Val L1 norm: 4.327.. Train Linf norm: 4179.696.. Val Linf norm: 2510.605
# Epoch 50/61.. Train loss: 2.146.. Val loss: 1.996.. Train L1 norm: 4.950.. Val L1 norm: 4.362.. Train Linf norm: 4418.925.. Val Linf norm: 2535.078
# Epoch 51/61.. Train loss: 2.140.. Val loss: 1.994.. Train L1 norm: 4.875.. Val L1 norm: 4.395.. Train Linf norm: 4483.165.. Val Linf norm: 2558.194
# Epoch 52/61.. Train loss: 2.143.. Val loss: 1.992.. Train L1 norm: 4.906.. Val L1 norm: 4.427.. Train Linf norm: 4346.120.. Val Linf norm: 2580.406
# Epoch 53/61.. Train loss: 2.138.. Val loss: 1.991.. Train L1 norm: 4.954.. Val L1 norm: 4.455.. Train Linf norm: 4456.988.. Val Linf norm: 2600.639
# Epoch 54/61.. Train loss: 2.144.. Val loss: 1.990.. Train L1 norm: 5.046.. Val L1 norm: 4.484.. Train Linf norm: 4400.959.. Val Linf norm: 2620.867
# Epoch 55/61.. Train loss: 2.139.. Val loss: 1.988.. Train L1 norm: 4.979.. Val L1 norm: 4.510.. Train Linf norm: 4585.188.. Val Linf norm: 2639.921
# Epoch 56/61.. Train loss: 2.136.. Val loss: 1.987.. Train L1 norm: 5.220.. Val L1 norm: 4.537.. Train Linf norm: 4632.854.. Val Linf norm: 2659.308
# Epoch 57/61.. Train loss: 2.128.. Val loss: 1.986.. Train L1 norm: 5.187.. Val L1 norm: 4.565.. Train Linf norm: 5022.677.. Val Linf norm: 2679.103
# Epoch 58/61.. Train loss: 2.135.. Val loss: 1.985.. Train L1 norm: 5.066.. Val L1 norm: 4.591.. Train Linf norm: 4550.957.. Val Linf norm: 2697.338
# Epoch 59/61.. Train loss: 2.122.. Val loss: 1.984.. Train L1 norm: 5.176.. Val L1 norm: 4.604.. Train Linf norm: 4572.676.. Val Linf norm: 2708.022
# Epoch 60/61.. Train loss: 2.135.. Val loss: 1.984.. Train L1 norm: 5.261.. Val L1 norm: 4.604.. Train Linf norm: 4746.779.. Val Linf norm: 2709.946
# [I 2023-05-31 14:28:46,466] Trial 77 finished with value: 4.6282931224823 and parameters: {'n_layers': 6, 'n_units_0': 4068, 'n_units_1': 3362, 'n_units_2': 837, 'n_units_3': 2862, 'n_units_4': 2143, 'n_units_5': 1686, 'hidden_activation': 'ELU', 'output_activation': 'Linear', 'loss': 'Quantile', 'optimizer': 'SGD', 'lr': 1.0419952723506374e-05, 'batch_size': 2048, 'n_epochs': 61, 'scheduler': 'ReduceLROnPlateau', 'dropout_rate': 0.15377597539468296, 'weight_decay': 0.00023397215991429542, 'momentum': 0.5225271805587763, 'factor': 0.1421235835137385, 'patience': 9, 'threshold': 0.0029370893411907787}. Best is trial 76 with value: 1.8586644779841106.
# Epoch 61/61.. Train loss: 2.128.. Val loss: 1.983.. Train L1 norm: 5.137.. Val L1 norm: 4.628.. Train Linf norm: 4431.569.. Val Linf norm: 2727.518
# Epoch 1/56.. Train loss: 2.478.. Val loss: 2.303.. Train L1 norm: 1.740.. Val L1 norm: 1.774.. Train Linf norm: 873.222.. Val Linf norm: 646.403
# Epoch 2/56.. Train loss: 2.433.. Val loss: 2.242.. Train L1 norm: 2.448.. Val L1 norm: 2.133.. Train Linf norm: 1816.741.. Val Linf norm: 885.188
# Epoch 3/56.. Train loss: 2.410.. Val loss: 2.216.. Train L1 norm: 2.764.. Val L1 norm: 2.308.. Train Linf norm: 2081.566.. Val Linf norm: 1002.458
# Epoch 4/56.. Train loss: 2.420.. Val loss: 2.198.. Train L1 norm: 2.739.. Val L1 norm: 2.443.. Train Linf norm: 1876.520.. Val Linf norm: 1097.873
# Epoch 5/56.. Train loss: 2.388.. Val loss: 2.191.. Train L1 norm: 2.926.. Val L1 norm: 2.491.. Train Linf norm: 2148.871.. Val Linf norm: 1134.533
# Epoch 6/56.. Train loss: 2.390.. Val loss: 2.189.. Train L1 norm: 3.157.. Val L1 norm: 2.492.. Train Linf norm: 2366.476.. Val Linf norm: 1142.304
# Epoch 7/56.. Train loss: 2.414.. Val loss: 2.181.. Train L1 norm: 2.849.. Val L1 norm: 2.556.. Train Linf norm: 2016.193.. Val Linf norm: 1187.173
# Epoch 8/56.. Train loss: 2.396.. Val loss: 2.172.. Train L1 norm: 3.044.. Val L1 norm: 2.625.. Train Linf norm: 2395.421.. Val Linf norm: 1235.084
# Epoch 9/56.. Train loss: 2.388.. Val loss: 2.178.. Train L1 norm: 3.280.. Val L1 norm: 2.557.. Train Linf norm: 2630.741.. Val Linf norm: 1198.046
# Epoch 10/56.. Train loss: 2.377.. Val loss: 2.175.. Train L1 norm: 3.217.. Val L1 norm: 2.566.. Train Linf norm: 2237.398.. Val Linf norm: 1207.958
# Epoch 11/56.. Train loss: 2.375.. Val loss: 2.194.. Train L1 norm: 2.764.. Val L1 norm: 2.400.. Train Linf norm: 2028.884.. Val Linf norm: 1102.184
# Epoch 12/56.. Train loss: 2.387.. Val loss: 2.165.. Train L1 norm: 2.930.. Val L1 norm: 2.644.. Train Linf norm: 2175.621.. Val Linf norm: 1262.188
# Epoch 13/56.. Train loss: 2.391.. Val loss: 2.164.. Train L1 norm: 2.961.. Val L1 norm: 2.655.. Train Linf norm: 2143.774.. Val Linf norm: 1273.690
# Epoch 14/56.. Train loss: 2.386.. Val loss: 2.163.. Train L1 norm: 3.060.. Val L1 norm: 2.674.. Train Linf norm: 2196.984.. Val Linf norm: 1293.199
# Epoch 15/56.. Train loss: 2.390.. Val loss: 2.173.. Train L1 norm: 3.314.. Val L1 norm: 2.604.. Train Linf norm: 2197.157.. Val Linf norm: 1253.956
# Epoch 16/56.. Train loss: 2.357.. Val loss: 2.167.. Train L1 norm: 3.267.. Val L1 norm: 2.660.. Train Linf norm: 2235.644.. Val Linf norm: 1297.791
# Epoch 17/56.. Train loss: 2.374.. Val loss: 2.158.. Train L1 norm: 3.235.. Val L1 norm: 2.747.. Train Linf norm: 2401.951.. Val Linf norm: 1364.242
# Epoch 18/56.. Train loss: 2.365.. Val loss: 2.147.. Train L1 norm: 2.955.. Val L1 norm: 2.855.. Train Linf norm: 1614.599.. Val Linf norm: 1437.107
# Epoch 19/56.. Train loss: 2.348.. Val loss: 2.142.. Train L1 norm: 3.249.. Val L1 norm: 2.923.. Train Linf norm: 2499.743.. Val Linf norm: 1489.277
# Epoch 20/56.. Train loss: 2.342.. Val loss: 2.140.. Train L1 norm: 3.382.. Val L1 norm: 2.952.. Train Linf norm: 2710.507.. Val Linf norm: 1515.746
# Epoch 21/56.. Train loss: 2.340.. Val loss: 2.136.. Train L1 norm: 3.068.. Val L1 norm: 3.006.. Train Linf norm: 2230.125.. Val Linf norm: 1557.993
# Epoch 22/56.. Train loss: 2.353.. Val loss: 2.145.. Train L1 norm: 3.549.. Val L1 norm: 2.931.. Train Linf norm: 2802.665.. Val Linf norm: 1516.859
# Epoch 23/56.. Train loss: 2.354.. Val loss: 2.144.. Train L1 norm: 3.147.. Val L1 norm: 2.955.. Train Linf norm: 2395.174.. Val Linf norm: 1540.559
# Epoch 24/56.. Train loss: 2.363.. Val loss: 2.140.. Train L1 norm: 3.221.. Val L1 norm: 3.008.. Train Linf norm: 2529.475.. Val Linf norm: 1580.911
# Epoch 25/56.. Train loss: 2.348.. Val loss: 2.148.. Train L1 norm: 3.602.. Val L1 norm: 2.943.. Train Linf norm: 2425.829.. Val Linf norm: 1548.085
# Epoch 26/56.. Train loss: 2.333.. Val loss: 2.153.. Train L1 norm: 3.282.. Val L1 norm: 2.914.. Train Linf norm: 2606.185.. Val Linf norm: 1537.004
# Epoch 27/56.. Train loss: 2.350.. Val loss: 2.141.. Train L1 norm: 3.270.. Val L1 norm: 3.044.. Train Linf norm: 2549.634.. Val Linf norm: 1625.807
# Epoch 28/56.. Train loss: 2.348.. Val loss: 2.163.. Train L1 norm: 3.596.. Val L1 norm: 2.868.. Train Linf norm: 2949.173.. Val Linf norm: 1521.272
# Epoch 29/56.. Train loss: 2.358.. Val loss: 2.173.. Train L1 norm: 3.619.. Val L1 norm: 2.808.. Train Linf norm: 2874.884.. Val Linf norm: 1491.761
# Epoch 30/56.. Train loss: 2.338.. Val loss: 2.166.. Train L1 norm: 3.113.. Val L1 norm: 2.891.. Train Linf norm: 2268.037.. Val Linf norm: 1556.535
# Epoch 31/56.. Train loss: 2.324.. Val loss: 2.165.. Train L1 norm: 3.169.. Val L1 norm: 2.904.. Train Linf norm: 2264.617.. Val Linf norm: 1566.643
# Epoch 32/56.. Train loss: 2.333.. Val loss: 2.161.. Train L1 norm: 3.256.. Val L1 norm: 2.939.. Train Linf norm: 2205.975.. Val Linf norm: 1590.827
# Epoch 33/56.. Train loss: 2.337.. Val loss: 2.159.. Train L1 norm: 3.335.. Val L1 norm: 2.957.. Train Linf norm: 2472.442.. Val Linf norm: 1603.804
# Epoch 34/56.. Train loss: 2.318.. Val loss: 2.156.. Train L1 norm: 3.290.. Val L1 norm: 2.989.. Train Linf norm: 2382.062.. Val Linf norm: 1624.884
# Epoch 35/56.. Train loss: 2.328.. Val loss: 2.154.. Train L1 norm: 3.335.. Val L1 norm: 3.003.. Train Linf norm: 2313.120.. Val Linf norm: 1635.640
# Epoch 36/56.. Train loss: 2.315.. Val loss: 2.155.. Train L1 norm: 3.324.. Val L1 norm: 3.004.. Train Linf norm: 2540.742.. Val Linf norm: 1637.441
# Epoch 37/56.. Train loss: 2.323.. Val loss: 2.154.. Train L1 norm: 3.372.. Val L1 norm: 3.013.. Train Linf norm: 2600.815.. Val Linf norm: 1643.633
# Epoch 38/56.. Train loss: 2.293.. Val loss: 2.153.. Train L1 norm: 3.183.. Val L1 norm: 3.025.. Train Linf norm: 2327.784.. Val Linf norm: 1654.308
# Epoch 39/56.. Train loss: 2.317.. Val loss: 2.152.. Train L1 norm: 3.408.. Val L1 norm: 3.037.. Train Linf norm: 2432.195.. Val Linf norm: 1663.194
# Epoch 40/56.. Train loss: 2.326.. Val loss: 2.152.. Train L1 norm: 3.318.. Val L1 norm: 3.040.. Train Linf norm: 2489.984.. Val Linf norm: 1666.877
# Epoch 41/56.. Train loss: 2.322.. Val loss: 2.152.. Train L1 norm: 3.349.. Val L1 norm: 3.041.. Train Linf norm: 2121.881.. Val Linf norm: 1667.658
# Epoch 42/56.. Train loss: 2.335.. Val loss: 2.153.. Train L1 norm: 3.378.. Val L1 norm: 3.041.. Train Linf norm: 2205.996.. Val Linf norm: 1667.832
# Epoch 43/56.. Train loss: 2.318.. Val loss: 2.152.. Train L1 norm: 3.368.. Val L1 norm: 3.044.. Train Linf norm: 2377.290.. Val Linf norm: 1670.264
# Epoch 44/56.. Train loss: 2.312.. Val loss: 2.152.. Train L1 norm: 3.362.. Val L1 norm: 3.047.. Train Linf norm: 2272.099.. Val Linf norm: 1672.111
# Epoch 45/56.. Train loss: 2.309.. Val loss: 2.152.. Train L1 norm: 3.336.. Val L1 norm: 3.047.. Train Linf norm: 2496.247.. Val Linf norm: 1672.526
# Epoch 46/56.. Train loss: 2.318.. Val loss: 2.152.. Train L1 norm: 3.436.. Val L1 norm: 3.049.. Train Linf norm: 2669.904.. Val Linf norm: 1674.332
# Epoch 47/56.. Train loss: 2.319.. Val loss: 2.152.. Train L1 norm: 3.343.. Val L1 norm: 3.048.. Train Linf norm: 2545.556.. Val Linf norm: 1673.967
# Epoch 48/56.. Train loss: 2.319.. Val loss: 2.152.. Train L1 norm: 3.363.. Val L1 norm: 3.050.. Train Linf norm: 2560.120.. Val Linf norm: 1675.625
# Epoch 49/56.. Train loss: 2.327.. Val loss: 2.152.. Train L1 norm: 3.371.. Val L1 norm: 3.053.. Train Linf norm: 2683.926.. Val Linf norm: 1677.966
# Epoch 50/56.. Train loss: 2.331.. Val loss: 2.152.. Train L1 norm: 3.415.. Val L1 norm: 3.056.. Train Linf norm: 2639.622.. Val Linf norm: 1679.896
# Epoch 51/56.. Train loss: 2.299.. Val loss: 2.152.. Train L1 norm: 3.375.. Val L1 norm: 3.056.. Train Linf norm: 2564.848.. Val Linf norm: 1680.341
# Epoch 52/56.. Train loss: 2.322.. Val loss: 2.152.. Train L1 norm: 3.311.. Val L1 norm: 3.057.. Train Linf norm: 2494.880.. Val Linf norm: 1680.652
# Epoch 53/56.. Train loss: 2.305.. Val loss: 2.152.. Train L1 norm: 3.439.. Val L1 norm: 3.057.. Train Linf norm: 1820.774.. Val Linf norm: 1680.905
# Epoch 54/56.. Train loss: 2.333.. Val loss: 2.152.. Train L1 norm: 3.414.. Val L1 norm: 3.057.. Train Linf norm: 2535.646.. Val Linf norm: 1680.924

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr, \
    dropout_rate = create_model(trial, optimize=True)

# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr, \
    dropout_rate = create_model(trial=None, optimize=True)

# %%
print("loss_fn:", net)
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
print("lr", lr)
print("dropout_rate", dropout_rate)

# %% [markdown]
# After optimizing with Optuna and deciding on the best hyperparameters, we combine the training and validatin set, using that as the new training set for training the model, and then evaluate the model on the test set

# %%
x_train_val = torch.cat((x_train, x_val), 0)
y_train_val = torch.cat((y_train, y_val), 0)

train_val_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_train_val, y_train_val), batch_size=batch_size, shuffle=True
)
test_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
)

train_losses, _, test_losses, train_metrics, _, test_metrics, = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler, train_val_loader, None, test_loader, None
)

# %% [markdown]
# ## Saving

# %%
# create a dictionary to store the rest of the variables
import json

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
if isinstance(hidden_activation.__class__.__name__, list):
    hidden_activation_name = hidden_activation.__class__.__name__[0]
else:
    hidden_activation_name = hidden_activation.__class__.__name__

if isinstance(output_activation.__class__.__name__, list):
    output_activation_name = output_activation.__class__.__name__[0]
else:
    output_activation_name = output_activation.__class__.__name__

var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation_name,
  "output_activation_name": output_activation_name,
  "lr": lr,
  "dropout_rate": dropout_rate
}

# Adding the subparameters to the var_dict for saving
if hidden_activation_name == "LeakyReLU":
  var_dict["leakyrelu_slope"] = hidden_activation.negative_slope
elif hidden_activation_name == "PReLU":
  var_dict["prelu_init"] = hidden_activation.weight.item()  # .item() is needed because weight is a tensor
elif hidden_activation_name == "SoftPlus":
  var_dict["softplus_beta"] = hidden_activation.beta

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %%
[key for key in var_dict.keys()]

# %%
#%%script echo skipping

hidden_activation_name
output_activation_name

# %% [markdown]
# ## Visualizing the results

# %%
# First figure: Train and Test L1 Norm
plt.figure(figsize=(6, 4))
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm", color='blue')
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
plt.title("NNGRX Train and Test L1 Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
# plt.savefig("NNGRX_L1_norm_plot.png", dpi=300)
plt.savefig("NNGRX_L1_norm_plot.png")

# Second figure: Train and Test Linf Norm
plt.figure(figsize=(6, 4))
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm", color='blue')
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
plt.title("NNGRX Train and Test Linf Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
# plt.savefig("NNGRX_Linf_norm_plot.png", dpi=300)
plt.savefig("NNGRX_Linf_norm_plot.png")

# Third figure: MSE of training data and test data
plt.figure(figsize=(6, 4))
plt.plot(train_losses_loaded, label="Training Data", color='blue')
plt.plot(test_losses_loaded, label="Test Data", color='red')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("NNGRX MSE of Training and Test Data per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-7, 1e0)
plt.legend()
plt.tight_layout()
# plt.savefig("NNGRX_MSE_plot.png", dpi=300)
plt.savefig("NNGRX_MSE_plot.png")

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]
dropout_rate_loaded = var_dict_loaded["dropout_rate"]

# Loading the activation functions with subparameters
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  negative_slope_loaded = var_dict_loaded.get("leakyrelu_slope", 0.01)  # For backwards compatibiltiy with earlier models; default to 0.01 if not present
  hidden_activation_loaded = nn.LeakyReLU(negative_slope=negative_slope_loaded)
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU()
elif hidden_activation_name_loaded == "PReLU":
  init_loaded = var_dict_loaded.get("prelu_init", 0.25)  # Default to 0.25 if not present
  hidden_activation_loaded = nn.PReLU(init=init_loaded)
elif hidden_activation_name_loaded == "Swish":
    class Swish(nn.Module):
        def forward(self, x):
            return x * torch.sigmoid(x)
    hidden_activation_loaded = Swish()
elif hidden_activation_name_loaded == "GELU":
    hidden_activation_loaded = nn.GELU()
elif hidden_activation_name_loaded == "SoftPlus":
  beta_loaded = var_dict_loaded.get("softplus_beta", 1)  # Default to 1 if not present
  hidden_activation_loaded = nn.Softplus(beta=beta_loaded)



# We used to have options here, but since we have a regression problem with continuous output, we only use Linear.
output_activation_loaded = nn.Identity()

# load the network from the .pth file
net_loaded = Net(
    n_layers_loaded, 
    n_units_loaded, 
    hidden_activation_loaded, 
    output_activation_loaded, 
    dropout_rate_loaded
).to(device)

if torch.cuda.is_available():
 net_loaded.load_state_dict(torch.load("net.pth"))
else: 
  net_loaded.load_state_dict(torch.load("net.pth", map_location=torch.device('cpu')))


# Creating the loss function from its name
if loss_name_loaded == "MSE":
    loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
    loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
    loss_fn_loaded = nn.SmoothL1Loss() 
elif loss_name_loaded == "Quantile":
    def quantile_loss(y_pred, y_true, q=0.5):
        e = y_pred - y_true
        return torch.mean(torch.max(q*e, (q-1)*e))
    loss_fn_loaded = quantile_loss

# load the optimizer from the .pth file
if torch.cuda.is_available():
  optimizer_loaded_state_dict = torch.load("optimizer.pth")
else:
  optimizer_loaded_state_dict = torch.load("optimizer.pth", map_location=torch.device('cpu'))

if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "Adagrad":
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
if torch.cuda.is_available():
  scheduler_loaded_state_dict = torch.load("scheduler.pth")
else: 
  scheduler_loaded_state_dict = torch.load("scheduler.pth", map_location=torch.device('cpu'))

if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
elif scheduler_name_loaded == "CyclicLR":  # Added CyclicLR
    base_lr_loaded = scheduler_loaded_state_dict["base_lr"]
    max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
    step_size_up_loaded = scheduler_loaded_state_dict["step_size_up"]
    scheduler_loaded = optim.lr_scheduler.CyclicLR(
                    optimizer, base_lr=base_lr_loaded, max_lr=max_lr_loaded, step_size_up=step_size_up_loaded
                )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]

# %%
# %%script echo skipping

var_dict_loaded["batch_size"]
var_dict_loaded["n_epochs"]
var_dict_loaded["loss_name"]
var_dict_loaded["optimizer_name"]
var_dict_loaded["scheduler_name"]
var_dict_loaded["n_units"]
var_dict_loaded["n_layers"]
var_dict_loaded["hidden_activation_name"]
var_dict_loaded["output_activation_name"]
var_dict_loaded["lr"]
var_dict_loaded["dropout_rate"]

# %%
# %%script echo skipping
#
# scheduler_loaded_state_dict["mode"]
# scheduler_loaded_state_dict["factor"]
# scheduler_loaded_state_dict["patience"]
# scheduler_loaded_state_dict["threshold"]
# scheduler_loaded_state_dict["min_lrs"]
#
#
# scheduler_loaded_state_dict["base_lr"]
# scheduler_loaded_state_dict["max_lr"]
# scheduler_loaded_state_dict["step_size_up"]

# %%
# %%script echo skipping

var_dict
hidden_activation_name_loaded

# %%
# %%script echo skipping

if hidden_activation_name_loaded == "LeakyReLU":
  var_dict_loaded["leakyrelu_slope"]
if hidden_activation_name_loaded == "PReLU":
  var_dict_loaded["prelu_init"]
elif hidden_activation_name_loaded == "SoftPlus":
  var_dict_loaded["softplus_beta"]

batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
dropout_rate_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
if scheduler_loaded is not None:
  scheduler_loaded
  scheduler_loaded.__dict__ # print the subparameters of the scheduler
train_losses_loaded
test_losses_loaded
train_metrics_loaded
test_metrics_loaded

# %%
train_losses_loaded[-1]
test_losses_loaded[-1]
test_metrics_loaded[-1]['l1_norm']
test_metrics_loaded[-1]['linf_norm']
# print(f'Error is {test_metrics_loaded[-1]["l1_norm"] / (3.84e-4)} times bigger than in Dieselhorst et al.')
# print(f'Error is {test_metrics_loaded[-1]["linf_norm"] / (8.14e-3)} times bigger than in Dieselhorst et al.')

# %% [markdown]
# ### Visualize loaded results

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel(f"{loss_name_loaded} Loss")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Counting the number of parameters in the network.

# %%
net_loaded.eval()
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'The model has {count_parameters(net_loaded)} parameters.')

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network. Note that `net` is only available if we have trained the model in this session.

# %%
#%%script echo skipping

# Set the network to evaluation mode
net.eval()

# %%
# Set the network to evaluation mode
net_loaded.eval

# %%
for p1, p2 in zip(net.parameters(), net_loaded.parameters()):
    if p1.data.ne(p2.data).sum() > 0:
        print("Parameters are NOT the same.")
        break
else:
    print("Parameters are the same.")

print("Net device:", next(net.parameters()).device)
print("Net_loaded device:", next(net_loaded.parameters()).device)

# %%
#%%script echo skipping

print(list(net.parameters()))

# %%
print(list(net_loaded.parameters()))

# %%
rho_example, epsilon_example, vx_example, vy_example, vz_example, Bx_example, By_example, Bz_example, gxx_example, gxy_example, gxz_example, gyy_example, gyz_example, gzz_example = generate_samples(20)

inputs =  generate_input_data(rho_example, epsilon_example, vx_example, vy_example, vz_example, Bx_example, By_example, Bz_example, gxx_example, gxy_example, gxz_example, gyy_example, gyz_example, gzz_example)
inputs

# %%
#%%script echo skipping

# Pass the inputs to the network and get the outputs
outputs = [net(input.unsqueeze(0)) for input in inputs]
# Print the outputs
outputs

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input.unsqueeze(0)) for input in inputs]
# Print the outputs
outputs

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 5) to trace the model
dummy_input = torch.randn(1, N_INPUTS).to(device)

# Ensure that net_loaded is in evaluation mode.
net_loaded.eval()

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*generate_samples(1))
print("input shape: ", example_input_to_validate_correct_export_and_import.shape)
print("input: ", example_input_to_validate_correct_export_and_import)
print("Output:", net_loaded(example_input_to_validate_correct_export_and_import))
