# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics

# %% [markdown]
# ## How to use this notebook
#
# ### Local installation
#
# 1. Install required packages with `pip install -r requirements.txt` to your desired environment.
# 2. If a script version of this notebook is desired, comment (not uncomment) the first line of `nbconvert` cell.
#
# ### Colab installation
#
# 1.  Comment (not uncomment) the first line of the drive mounting cell.
# 2.  Comment (not uncomment) the first line of the `pip install` cell.
#
# <!-- - For colab we also want to set the runtime to GPU by clicking _Change runtime_ in the _Runtime_ menu, and -->
# <!-- - We want to wait for the google drive connection popup to appear and follow the instructions. -->
#
# ### Loading / Generating data
# 3. Set `LOAD_DATA_FROM_CSV` to `True` / `False` to load data from csv files / generate data in this notebook.
#
# ### Training without optimization
#
# 4. Set `OPTIMIZE = False` in section _Constants and flags to set_.
# 5. Run the entire notebook.
#
# ### Training with optimization
#
# 4. Set `OPTIMIZE = True` in section _Constants and flags to set_.
# 5. Run the entire notebook.
#
# ### Loading an already trained model
#
# 4. Run cells in section _Initialization_.
# 5. Run cells with definitions in section _Input data and labels_.
# 6. Run cell with the definition of _Net_ in section _Defining the neural network_.
# 7. Make sure the `net.pth`, `optimizer.pth`, `scheduler.pth`, `var_dict.json` and `train_output.csv` files are in the directory containing this notebook.
# 8. Run the cells in section _Loading_ and continue from there.
#
# ### Generating the C++ model
#
# 9. Run section _Porting the model to C++_, this requires a model to be loaded.
# 10. Set the path to the `net.pt` file in the C++ source file.
# 11. `mkdir build && cd build`,
# 12. Configure a `CMakeLists.txt` file as is done [here](https://pytorch.org/cppdocs/installing.html).
# 13. `cmake -DCMAKE_PREFIX_PATH=/path/to/libtorch/ ..`,
# 14. Compile and run, e.g. `cmake --build . --config release && ./<executable name>`

# %% [markdown]
# ## Initialization

# %% [markdown]
# Use this first cell to **convert this notebook** to a python script.

# %%
# %%script echo skipping
#
# !jupyter nbconvert pt1_before_restructuring.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on **google colab**,

# %%
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")
# change this to your desired folder
drive_folder = "/content/drive/My Drive/bsc/con2prim_GRMHD/old_hyperparameters_test3"

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
#%%script echo skipping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 17.3 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.0 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Installing collected packages: tensorboardX, Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1 tensorboardX-2.6

# %% [markdown]
# Importing the **libraries**,

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx
import pandas as pd

# %% [markdown]
# ### Constants and flags to set
# Defining some constants and parameters for convenience.
#
# **NOTE**: Some **subparameters** still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023) in the case the model is being trained without optimization.

# %%
# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.
LOAD_DATA_FROM_CSV = False  # If not true we generate the data in this file and save to {x_train,y_train,x_test,y_test}.csv, otherwise we load the data from files of the same name.

csv_filenames = { # File names to load input data and labels from if LOAD_DATA_FROM_CSV is True.
    "x_train": "x_train.csv",
    "y_train": "y_train.csv",
    "x_test": "x_test.csv",
    "y_test": "y_test.csv",
}

# Values to use for hyperparameters if OPTIMIZE is False.
N_LAYERS_NO_OPT = 3
N_UNITS_NO_OPT = [555, 458, 115]
HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "RMSprop"
LR_NO_OPT = 0.000122770896701404
BATCH_SIZE_NO_OPT = 49
N_EPOCHS_NO_OPT = 100
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

Gamma = 5 / 3  # Adiabatic index
n_train_samples = 80000 # Number of training samples
n_test_samples = 20000 # Number of test samples
rho_interval = (0, 2) # sample in linear space
epsilon_interval = (1e-2, 2000)  # Will be sampled in log space
vx_interval = (0, 0.999)  # sample in linear space
vy_interval = (0, 0.999)  # sample in linear space
vz_interval = (0, 0.999)  # sample in linear space
Bx_interval = (-10, 10)  # sample in linear space
By_interval = (-10, 10)  # sample in linear space
Bz_interval = (-10, 10)  # sample in linear space
gxx_interval = (0.9, 1.1)
gxy_interval = (0, 0.1)
gxz_interval = (0, 0.1)
gyy_interval = (0.9, 1.1)
gyz_interval = (0, 0.1)
gzz_interval = (0.9, 1.1)


N_INPUTS = 14  # Number of input features.

np.random.seed(49) # Comment for true random data.

# %% [markdown]
# ## Input data and labels
#
# We either generate the data or load the data. First the definitions for generating the data come below.

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    # Adding some assertions to check that the input tensors are valid and have 
    # the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    print('rho.shape: ', rho.shape)
    print('epsilon.shape: ', epsilon.shape)
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (Gamma - 1) * rho * epsilon



def sample_primitive_variables():
    rho = np.random.uniform(*rho_interval)  
    epsilon = 10 ** np.random.uniform(*np.log10(epsilon_interval))
    vx = np.random.uniform(*vx_interval)  
    vy = np.random.uniform(*vy_interval)  
    vz = np.random.uniform(*vz_interval)  
    Bx = np.random.uniform(*Bx_interval)  
    By = np.random.uniform(*By_interval)  
    Bz = np.random.uniform(*Bz_interval)  
    gxx = np.random.uniform(*gxx_interval)
    gxy = np.random.uniform(*gxy_interval)
    gxz = np.random.uniform(*gxz_interval)
    gyy = np.random.uniform(*gyy_interval)
    gyz = np.random.uniform(*gyz_interval)
    gzz = np.random.uniform(*gzz_interval)

    return rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz

def check_sample(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    wtemp_expr = 1 - (gxx * vx**2 + gyy * vy**2 + gzz * vz**2 + 2 * gxy * vx * vy + 2 * gxz * vx * vz + 2 * gyz * vy * vz)
    sdet_expr = gxx * gyy * gzz + 2 * gxy * gxz * gyz - gxx * gyz ** 2 - gyy * gxz ** 2 - gzz * gxy ** 2
    if vx**2 + vy**2 + vz**2 >= 1 or wtemp_expr < 0 or sdet_expr < 0:
        print(f"Sample failed checks. vx^2+vy^2+vz^2: {vx**2 + vy**2 + vz**2}, wtemp_expr: {wtemp_expr}, sdet_expr: {sdet_expr}")
        return False
    else:
        print(f"Sample passed checks. vx^2+vy^2+vz^2: {vx**2 + vy**2 + vz**2}, wtemp_expr: {wtemp_expr}, sdet_expr: {sdet_expr}")
        return True

def generate_samples(n_samples):
    samples = []
    while len(samples) < n_samples:
        sample = sample_primitive_variables()
        if check_sample(*sample):
            samples.append(sample)
        print(f"Number of valid samples: {len(samples)}")
    return zip(*samples)


def sdet(gxx, gxy, gxz, gyy, gyz, gzz):
    # Determinant of the three metric.
    return (gxx * gyy * gzz + 2 * gxy * gxz * gyz - gxx * gyz ** 2 - gyy * gxz ** 2 - gzz * gxy ** 2) ** 0.5

# Defining a function that computes conserved variables from primitive variables
# We follow the source code of GRaM-X: A new GPU-accelerated dynamical spacetime GRMHD code for Exascale
# computing with the Einstein Toolkit of Shankar et al.
def compute_conserved_variables(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    pres = eos_analytic(rho, epsilon)
    wtemp = 1 / (1 - (gxx * vx**2 + gyy * vy**2 + gzz * vz**2 +
        2 * gxy * vx * vy + 2 * gxz * vx * vz +
        2 * gyz * vy * vz))**0.5

    vlowx = gxx * vx + gxy * vy + gxz * vz
    vlowy = gxy * vx + gyy * vy + gyz * vz
    vlowz = gxz * vx + gyz * vy + gzz * vz

    Bxlow = gxx * Bx + gxy * By + gxz * Bz
    Bylow = gxy * Bx + gyy * By + gyz * Bz
    Bzlow = gxz * Bx + gyz * By + gzz * Bz

    B2 = Bxlow * Bx + Bylow * By + Bzlow * Bz

    Bdotv = Bxlow * vx + Bylow * vy + Bzlow * vz
    Bdotv2 = Bdotv * Bdotv
    wtemp2 = wtemp * wtemp
    b2 = B2 / wtemp2 + Bdotv2
    ab0 = wtemp * Bdotv

    blowx = (gxx * Bx + gxy * By + gxz * Bz) / wtemp + wtemp * Bdotv * vlowx
    blowy = (gxy * Bx + gyy * By + gyz * Bz) / wtemp + wtemp * Bdotv * vlowy
    blowz = (gxz * Bx + gyz * By + gzz * Bz) / wtemp + wtemp * Bdotv * vlowz

    hrhow2 = (rho * (1 + epsilon) + pres + b2) * (wtemp) * (wtemp)

    D = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * rho * (wtemp)
    Sx = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowx - ab0 * blowx)
    Sy = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowy - ab0 * blowy)
    Sz = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 * vlowz - ab0 * blowz)
    tau = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * (hrhow2 - pres - b2 / 2 - ab0 * ab0) - D
    Bconsx = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * Bx
    Bconsy = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * By
    Bconsz = sdet(gxx, gxy, gxz, gyy, gyz, gzz) * Bz

    return D, Sx, Sy, Sz, tau, Bconsx, Bconsy, Bconsz


def generate_input_data(rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz):
    rho = torch.tensor(np.array(rho), dtype=torch.float32).to(device)
    epsilon = torch.tensor(np.array(epsilon), dtype=torch.float32).to(device)
    vx = torch.tensor(np.array(vx), dtype=torch.float32).to(device)
    vy = torch.tensor(np.array(vy), dtype=torch.float32).to(device)
    vz = torch.tensor(np.array(vz), dtype=torch.float32).to(device)
    Bx = torch.tensor(np.array(Bx), dtype=torch.float32).to(device)
    By = torch.tensor(np.array(By), dtype=torch.float32).to(device)
    Bz = torch.tensor(np.array(Bz), dtype=torch.float32).to(device)
    gxx = torch.tensor(np.array(gxx), dtype=torch.float32).to(device)
    gxy = torch.tensor(np.array(gxy), dtype=torch.float32).to(device)
    gxz = torch.tensor(np.array(gxz), dtype=torch.float32).to(device)
    gyy = torch.tensor(np.array(gyy), dtype=torch.float32).to(device)
    gyz = torch.tensor(np.array(gyz), dtype=torch.float32).to(device)
    gzz = torch.tensor(np.array(gzz), dtype=torch.float32).to(device)


    
    D, Sx, Sy, Sz, tau, Bscriptx, Bscripty, Bscriptz = compute_conserved_variables(
        rho, epsilon, vx, vy, vz, Bx, By, Bz, gxx, gxy, gxz, gyy, gyz, gzz
    ) 

    # Add gxx, gxy, gxz, gyy, gyz, gzz to the tensor
    x = torch.stack([D, Sx, Sy, Sz, tau, Bscriptx, Bscripty, Bscriptz, gxx, gxy, gxz, gyy, gyz, gzz], axis=1)
    return x


# Defining a function that generates output data (labels) from given samples of primitive variables
# We use the definitions as given in Recovery schemes for primitive variables in
# general-relativistic magnetohydrodynamics of Siegel et al.
def generate_labels(rho, epsilon, vx, vy, vz):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(np.array(rho), dtype=torch.float32).to(device)
    epsilon = torch.tensor(np.array(epsilon), dtype=torch.float32).to(device)
    vx = torch.tensor(np.array(vx), dtype=torch.float32).to(device)
    vy = torch.tensor(np.array(vy), dtype=torch.float32).to(device)
    vz = torch.tensor(np.array(vz), dtype=torch.float32).to(device)

    # Computing the required quantities
    pres = eos_analytic(rho, epsilon)
    h = 1 + epsilon + pres / rho
    W = 1 / torch.sqrt(1 - (vx * vx + vy * vy + vz * vz))

    # Returning the output data tensor
    return h * W

# %% [markdown]
# ### Generating or loading input data and labels

# %%
if LOAD_DATA_FROM_CSV:
    # Load the data from CSV files
    x_train = pd.read_csv(csv_filenames["x_train"]).values
    y_train = pd.read_csv(csv_filenames["y_train"]).values.squeeze()  # reshape to 1D
    x_test = pd.read_csv(csv_filenames["x_test"]).values
    y_test = pd.read_csv(csv_filenames["y_test"]).values.squeeze()  # reshape to 1D

    # Convert numpy arrays to tensors
    x_train = torch.from_numpy(x_train).float().to(device)
    y_train = torch.from_numpy(y_train).float().to(device)
    x_test = torch.from_numpy(x_test).float().to(device)
    y_test = torch.from_numpy(y_test).float().to(device)

    # This is an alternative to having if clauses  around the cells that visualize these variables.
    rho_train = epsilon_train = vx_train = vy_train = vz_train = Bx_train = By_train = Bz_train = gxx_train = gxy_train = gxz_train = gyy_train = gyz_train = gzz_train = None
    rho_test = epsilon_test = vx_test = vy_test = vz_test = Bx_test = By_test = Bz_test = gxx_test = gxy_test = gxz_test = gyy_test = gyz_test = gzz_test = None

# %%
if not LOAD_DATA_FROM_CSV:
    # Sample primitive variables
    rho_train, epsilon_train, vx_train, vy_train, vz_train, Bx_train, By_train, Bz_train, gxx_train, gxy_train, gxz_train, gyy_train, gyz_train, gzz_train = generate_samples(n_train_samples)
    rho_test, epsilon_test, vx_test, vy_test, vz_test, Bx_test, By_test, Bz_test, gxx_test, gxy_test, gxz_test, gyy_test, gyz_test, gzz_test = generate_samples(n_test_samples)
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample passed checks. vx^2+vy^2+vz^2: 0.10820761251515287, wtemp_expr: 0.8830961522732392, sdet_expr: 1.122589519425744
# Number of valid samples: 18787
# Sample passed checks. vx^2+vy^2+vz^2: 0.7159355863874244, wtemp_expr: 0.2641883434175156, sdet_expr: 0.9525185270127909
# Number of valid samples: 18788
# Sample failed checks. vx^2+vy^2+vz^2: 1.3115553273398444, wtemp_expr: -0.39064518918547275, sdet_expr: 1.0445000112628786
# Number of valid samples: 18788
# Sample failed checks. vx^2+vy^2+vz^2: 1.014696929562598, wtemp_expr: -0.04404135659172703, sdet_expr: 0.8975337760015722
# Number of valid samples: 18788
# Sample passed checks. vx^2+vy^2+vz^2: 0.799256834502253, wtemp_expr: 0.10371327352262638, sdet_expr: 1.090003557258045
# Number of valid samples: 18789
# Sample failed checks. vx^2+vy^2+vz^2: 1.1035825538173598, wtemp_expr: -0.20887861937792285, sdet_expr: 1.0225013586842076
# Number of valid samples: 18789
# Sample passed checks. vx^2+vy^2+vz^2: 0.4382734932672926, wtemp_expr: 0.503561964941425, sdet_expr: 1.105914150826745
# Number of valid samples: 18790
# Sample passed checks. vx^2+vy^2+vz^2: 0.18715555439618636, wtemp_expr: 0.8015194310492897, sdet_expr: 1.050429013970826
# Number of valid samples: 18791
# Sample failed checks. vx^2+vy^2+vz^2: 1.0184219764316789, wtemp_expr: -0.059070894475672375, sdet_expr: 1.028602665781071
# Number of valid samples: 18791
# Sample failed checks. vx^2+vy^2+vz^2: 1.4583348917917034, wtemp_expr: -0.6484776056599875, sdet_expr: 1.0540879623429733
# Number of valid samples: 18791
# Sample failed checks. vx^2+vy^2+vz^2: 0.9956170018875056, wtemp_expr: -0.057185700166338505, sdet_expr: 0.9813203771250075
# Number of valid samples: 18791
# Sample passed checks. vx^2+vy^2+vz^2: 0.031714156806446826, wtemp_expr: 0.9644700989234833, sdet_expr: 1.0080931628657244
# Number of valid samples: 18792
# Sample failed checks. vx^2+vy^2+vz^2: 1.9322470405955228, wtemp_expr: -1.027617013953281, sdet_expr: 0.9559375716534934
# Number of valid samples: 18792
# Sample failed checks. vx^2+vy^2+vz^2: 1.8466065396561488, wtemp_expr: -0.984999109730027, sdet_expr: 0.9479062376305937
# Number of valid samples: 18792
# Sample passed checks. vx^2+vy^2+vz^2: 0.40247151894069066, wtemp_expr: 0.5847283869215354, sdet_expr: 0.9454607004716579
# Number of valid samples: 18793
# Sample passed checks. vx^2+vy^2+vz^2: 0.1683064367584228, wtemp_expr: 0.8135550699180152, sdet_expr: 1.0738523713839379
# Number of valid samples: 18794
# Sample failed checks. vx^2+vy^2+vz^2: 1.4688369258836689, wtemp_expr: -0.65900399211212, sdet_expr: 1.0429203863230117
# Number of valid samples: 18794
# Sample failed checks. vx^2+vy^2+vz^2: 2.400332753350746, wtemp_expr: -1.6022312322165742, sdet_expr: 1.023923603791946
# Number of valid samples: 18794
# Sample passed checks. vx^2+vy^2+vz^2: 0.6538711160004944, wtemp_expr: 0.326284915793675, sdet_expr: 1.0786142244184862
# Number of valid samples: 18795
# Sample passed checks. vx^2+vy^2+vz^2: 0.7812376154575246, wtemp_expr: 0.13690999399185633, sdet_expr: 1.009647330226727
# Number of valid samples: 18796
# Sample failed checks. vx^2+vy^2+vz^2: 1.5675680210322045, wtemp_expr: -0.6770421135931322, sdet_expr: 0.8544413761112378
# Number of valid samples: 18796
# Sample failed checks. vx^2+vy^2+vz^2: 2.5055453529991434, wtemp_expr: -1.7916182664129048, sdet_expr: 1.0323252175355573
# Number of valid samples: 18796
# Sample passed checks. vx^2+vy^2+vz^2: 0.6062267269370891, wtemp_expr: 0.35790999210262286, sdet_expr: 0.9079144580633811
# Number of valid samples: 18797
# Sample passed checks. vx^2+vy^2+vz^2: 0.09270264181508966, wtemp_expr: 0.8979949937775061, sdet_expr: 0.953886337116754
# Number of valid samples: 18798
# Sample passed checks. vx^2+vy^2+vz^2: 0.7665493878095792, wtemp_expr: 0.23336406816434363, sdet_expr: 0.8903506223116469
# Number of valid samples: 18799
# Sample failed checks. vx^2+vy^2+vz^2: 2.006377280766606, wtemp_expr: -1.236838683653327, sdet_expr: 1.1395914416163135
# Number of valid samples: 18799
# Sample failed checks. vx^2+vy^2+vz^2: 1.2166460313165992, wtemp_expr: -0.27143505171854265, sdet_expr: 1.084008876670699
# Number of valid samples: 18799
# Sample failed checks. vx^2+vy^2+vz^2: 1.500163568571897, wtemp_expr: -0.6113935352914173, sdet_expr: 1.0520234216913842
# Number of valid samples: 18799
# Sample failed checks. vx^2+vy^2+vz^2: 1.0916857933981188, wtemp_expr: -0.2471557955233903, sdet_expr: 1.1603509915900867
# Number of valid samples: 18799
# Sample passed checks. vx^2+vy^2+vz^2: 0.46399606377096275, wtemp_expr: 0.5594057502915916, sdet_expr: 0.9982403364602485
# Number of valid samples: 18800
# Sample failed checks. vx^2+vy^2+vz^2: 1.4502180465741814, wtemp_expr: -0.48151381598058096, sdet_expr: 0.884118758910188
# Number of valid samples: 18800
# Sample passed checks. vx^2+vy^2+vz^2: 0.2707251453410169, wtemp_expr: 0.698021651798588, sdet_expr: 1.1293094443917229
# Number of valid samples: 18801
# Sample passed checks. vx^2+vy^2+vz^2: 0.24813636920162468, wtemp_expr: 0.7338744171667622, sdet_expr: 1.0250396274968745
# Number of valid samples: 18802
# Sample failed checks. vx^2+vy^2+vz^2: 1.4581617075219344, wtemp_expr: -0.5847914482408394, sdet_expr: 1.122957264327702
# Number of valid samples: 18802
# Sample failed checks. vx^2+vy^2+vz^2: 1.0452170278697364, wtemp_expr: -0.034435110818292314, sdet_expr: 1.0241213385011487
# Number of valid samples: 18802
# Sample failed checks. vx^2+vy^2+vz^2: 0.9627987488558193, wtemp_expr: -0.038097817069063344, sdet_expr: 0.9871677956584927
# Number of valid samples: 18802
# Sample failed checks. vx^2+vy^2+vz^2: 1.286843117964916, wtemp_expr: -0.3609854220697568, sdet_expr: 0.9455748055254365
# Number of valid samples: 18802
# Sample failed checks. vx^2+vy^2+vz^2: 1.3366495255698085, wtemp_expr: -0.3487932543336063, sdet_expr: 0.9481282054326102
# Number of valid samples: 18802
# Sample passed checks. vx^2+vy^2+vz^2: 0.9405303528508018, wtemp_expr: 0.03148671372296674, sdet_expr: 0.8758686185225253
# Number of valid samples: 18803
# Sample passed checks. vx^2+vy^2+vz^2: 0.5605370730698396, wtemp_expr: 0.44194678211222704, sdet_expr: 0.9050786670114968
# Number of valid samples: 18804
# Sample passed checks. vx^2+vy^2+vz^2: 0.31863713787314885, wtemp_expr: 0.665252581775565, sdet_expr: 0.768144970301595
# Number of valid samples: 18805
# Sample passed checks. vx^2+vy^2+vz^2: 0.7448896739028298, wtemp_expr: 0.2173480372279608, sdet_expr: 0.9722638763554603
# Number of valid samples: 18806
# Sample failed checks. vx^2+vy^2+vz^2: 1.1702448047668719, wtemp_expr: -0.2829696484435773, sdet_expr: 1.032897638449694
# Number of valid samples: 18806
# Sample passed checks. vx^2+vy^2+vz^2: 0.24858539018963288, wtemp_expr: 0.7450433701405479, sdet_expr: 0.9233265398355625
# Number of valid samples: 18807
# Sample passed checks. vx^2+vy^2+vz^2: 0.9286210731751536, wtemp_expr: 0.04173475564823714, sdet_expr: 0.8720941553893463
# Number of valid samples: 18808
# Sample failed checks. vx^2+vy^2+vz^2: 1.3730968329691435, wtemp_expr: -0.39669443218401024, sdet_expr: 0.9564847374709596
# Number of valid samples: 18808
# Sample failed checks. vx^2+vy^2+vz^2: 1.043588672675234, wtemp_expr: -0.13025319835253968, sdet_expr: 0.8605945384694422
# Number of valid samples: 18808
# Sample failed checks. vx^2+vy^2+vz^2: 1.3576614529106463, wtemp_expr: -0.5052242646403895, sdet_expr: 0.9255695643471603
# Number of valid samples: 18808
# Sample failed checks. vx^2+vy^2+vz^2: 1.2361487579205435, wtemp_expr: -0.40358555475796454, sdet_expr: 1.100333313574127
# Number of valid samples: 18808
# Sample failed checks. vx^2+vy^2+vz^2: 2.1027882638817355, wtemp_expr: -1.2684648743561757, sdet_expr: 0.9242763291849707
# Number of valid samples: 18808
# Sample passed checks. vx^2+vy^2+vz^2: 0.9145739766725962, wtemp_expr: 0.0006337957871647149, sdet_expr: 0.9069084294764926
# Number of valid samples: 18809
# Sample passed checks. vx^2+vy^2+vz^2: 0.4979896821185654, wtemp_expr: 0.4425240492237493, sdet_expr: 1.0035909732430799
# Number of valid samples: 18810
# Sample passed checks. vx^2+vy^2+vz^2: 0.4902829437696844, wtemp_expr: 0.5183995499783103, sdet_expr: 0.8177449408835411
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.0671802044060188, wtemp_expr: -0.18430935823707384, sdet_expr: 0.9990450428912045
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.5180290923951558, wtemp_expr: -0.5809195335693407, sdet_expr: 0.9727252792796643
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 0.9264151490743833, wtemp_expr: -0.015032095853158012, sdet_expr: 1.0876444661308502
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.248596214577058, wtemp_expr: -0.33602464339084026, sdet_expr: 1.0376070721421102
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.4515448234480623, wtemp_expr: -0.5534830540967621, sdet_expr: 1.001256187113473
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.8954620089154186, wtemp_expr: -1.1981829753500572, sdet_expr: 1.122463619909321
# Number of valid samples: 18811
# Sample failed checks. vx^2+vy^2+vz^2: 1.4745249205005295, wtemp_expr: -0.5845441442653974, sdet_expr: 0.9522531944280058
# Number of valid samples: 18811
# Sample passed checks. vx^2+vy^2+vz^2: 0.9087948329268907, wtemp_expr: 0.035530984057782766, sdet_expr: 0.8969765909106945
# Number of valid samples: 18812
# Sample passed checks. vx^2+vy^2+vz^2: 0.8344831321401665, wtemp_expr: 0.11667652291073072, sdet_expr: 1.1304641226521168
# Number of valid samples: 18813
# Sample passed checks. vx^2+vy^2+vz^2: 0.777420202403237, wtemp_expr: 0.1668607389527058, sdet_expr: 0.9798350464511264
# Number of valid samples: 18814
# Sample passed checks. vx^2+vy^2+vz^2: 0.136927432665882, wtemp_expr: 0.8373480523807977, sdet_expr: 1.1505351996236657
# Number of valid samples: 18815
# Sample passed checks. vx^2+vy^2+vz^2: 0.5840603336917171, wtemp_expr: 0.40866493765155354, sdet_expr: 0.9452207276049504
# Number of valid samples: 18816
# Sample passed checks. vx^2+vy^2+vz^2: 0.2698279968001728, wtemp_expr: 0.7260212425703793, sdet_expr: 0.9286599735325569
# Number of valid samples: 18817
# Sample passed checks. vx^2+vy^2+vz^2: 0.17564903349396177, wtemp_expr: 0.8154316983684562, sdet_expr: 0.9258235546792347
# Number of valid samples: 18818
# Sample passed checks. vx^2+vy^2+vz^2: 0.1261158105566322, wtemp_expr: 0.8720978816758291, sdet_expr: 1.051760651877467
# Number of valid samples: 18819
# Sample failed checks. vx^2+vy^2+vz^2: 2.2639639885282334, wtemp_expr: -1.3840224018593745, sdet_expr: 0.8552067557048465
# Number of valid samples: 18819
# Sample failed checks. vx^2+vy^2+vz^2: 1.5009236460772861, wtemp_expr: -0.6828980351113987, sdet_expr: 1.033350440144357
# Number of valid samples: 18819
# Sample passed checks. vx^2+vy^2+vz^2: 0.7138179488058574, wtemp_expr: 0.2350580069199295, sdet_expr: 0.9985126962134699
# Number of valid samples: 18820
# Sample failed checks. vx^2+vy^2+vz^2: 1.9038874497830294, wtemp_expr: -1.067802703619631, sdet_expr: 0.8624784969916479
# Number of valid samples: 18820
# Sample failed checks. vx^2+vy^2+vz^2: 1.465863552557487, wtemp_expr: -0.5685876094985882, sdet_expr: 1.0264503470361706
# Number of valid samples: 18820
# Sample failed checks. vx^2+vy^2+vz^2: 2.0858034571365023, wtemp_expr: -1.442638730221304, sdet_expr: 1.228305906634889
# Number of valid samples: 18820
# Sample passed checks. vx^2+vy^2+vz^2: 0.6689035965927393, wtemp_expr: 0.259978110379427, sdet_expr: 1.0030122638890029
# Number of valid samples: 18821
# Sample failed checks. vx^2+vy^2+vz^2: 1.183059693617825, wtemp_expr: -0.3551602074521225, sdet_expr: 1.1138415635359435
# Number of valid samples: 18821
# Sample failed checks. vx^2+vy^2+vz^2: 1.529488141249637, wtemp_expr: -0.6690791954985986, sdet_expr: 0.9854695664785017
# Number of valid samples: 18821
# Sample passed checks. vx^2+vy^2+vz^2: 0.7868550236830786, wtemp_expr: 0.19696004279739332, sdet_expr: 0.8809101940857992
# Number of valid samples: 18822
# Sample failed checks. vx^2+vy^2+vz^2: 1.1007163421704824, wtemp_expr: -0.19414573002313928, sdet_expr: 0.8806871011764845
# Number of valid samples: 18822
# Sample failed checks. vx^2+vy^2+vz^2: 1.7475322741186385, wtemp_expr: -0.9621945042909688, sdet_expr: 0.9246030533348226
# Number of valid samples: 18822
# Sample failed checks. vx^2+vy^2+vz^2: 2.1217668418366404, wtemp_expr: -1.3776997435786829, sdet_expr: 0.9227300975518605
# Number of valid samples: 18822
# Sample passed checks. vx^2+vy^2+vz^2: 0.8369654624202778, wtemp_expr: 0.07662223752626873, sdet_expr: 1.0112091771792568
# Number of valid samples: 18823
# Sample passed checks. vx^2+vy^2+vz^2: 0.5849320567268781, wtemp_expr: 0.34109011039578074, sdet_expr: 0.9916672177031466
# Number of valid samples: 18824
# Sample failed checks. vx^2+vy^2+vz^2: 1.2017875218949297, wtemp_expr: -0.25489840237803985, sdet_expr: 0.9669184301020383
# Number of valid samples: 18824
# Sample failed checks. vx^2+vy^2+vz^2: 1.2363758436981913, wtemp_expr: -0.3505826669752934, sdet_expr: 1.2011266959938065
# Number of valid samples: 18824
# Sample failed checks. vx^2+vy^2+vz^2: 1.6204868749683103, wtemp_expr: -0.7811585391046729, sdet_expr: 1.0631390196609016
# Number of valid samples: 18824
# Sample passed checks. vx^2+vy^2+vz^2: 0.36685946829696353, wtemp_expr: 0.5743708607934473, sdet_expr: 1.2080154625942614
# Number of valid samples: 18825
# Sample passed checks. vx^2+vy^2+vz^2: 0.7354042927977645, wtemp_expr: 0.21228923420386914, sdet_expr: 0.9837010997726615
# Number of valid samples: 18826
# Sample passed checks. vx^2+vy^2+vz^2: 0.8420406408705605, wtemp_expr: 0.11031867441270116, sdet_expr: 1.0026793874657591
# Number of valid samples: 18827
# Sample passed checks. vx^2+vy^2+vz^2: 0.5084049705895684, wtemp_expr: 0.4268266332867614, sdet_expr: 0.9816059836379291
# Number of valid samples: 18828
# Sample passed checks. vx^2+vy^2+vz^2: 0.5292115764227496, wtemp_expr: 0.5005049012358158, sdet_expr: 0.9028913035035965
# Number of valid samples: 18829
# Sample passed checks. vx^2+vy^2+vz^2: 0.6889167781422353, wtemp_expr: 0.2993232756323475, sdet_expr: 0.8700504810868117
# Number of valid samples: 18830
# Sample passed checks. vx^2+vy^2+vz^2: 0.7938606823937554, wtemp_expr: 0.18452544146009098, sdet_expr: 0.9955145031398182
# Number of valid samples: 18831
# Sample failed checks. vx^2+vy^2+vz^2: 2.045567758144423, wtemp_expr: -1.1972693286124092, sdet_expr: 0.8321510166039029
# Number of valid samples: 18831
# Sample failed checks. vx^2+vy^2+vz^2: 0.9244121083800214, wtemp_expr: -0.04136618702019135, sdet_expr: 1.111950618864999
# Number of valid samples: 18831
# Sample failed checks. vx^2+vy^2+vz^2: 1.0088659479673634, wtemp_expr: -0.09971414602254947, sdet_expr: 0.9881890973712704
# Number of valid samples: 18831
# Sample passed checks. vx^2+vy^2+vz^2: 0.09851795080658547, wtemp_expr: 0.8984876375441988, sdet_expr: 0.9522277416263665
# Number of valid samples: 18832
# Sample passed checks. vx^2+vy^2+vz^2: 0.9970404356374982, wtemp_expr: 0.007440145867678827, sdet_expr: 1.0897757082502046
# Number of valid samples: 18833
# Sample passed checks. vx^2+vy^2+vz^2: 0.8179387776262799, wtemp_expr: 0.10442418537672471, sdet_expr: 0.9830446399325282
# Number of valid samples: 18834
# Sample failed checks. vx^2+vy^2+vz^2: 1.2177867140020968, wtemp_expr: -0.2693947769670806, sdet_expr: 0.9687097591722492
# Number of valid samples: 18834
# Sample passed checks. vx^2+vy^2+vz^2: 0.4786730418549914, wtemp_expr: 0.4569675969382221, sdet_expr: 1.1337782094656355
# Number of valid samples: 18835
# Sample passed checks. vx^2+vy^2+vz^2: 0.2896878542806666, wtemp_expr: 0.6687484520220754, sdet_expr: 0.9932890502437716
# Number of valid samples: 18836
# Sample failed checks. vx^2+vy^2+vz^2: 1.624054447839829, wtemp_expr: -0.7573357343941851, sdet_expr: 0.8865404555028286
# Number of valid samples: 18836
# Sample passed checks. vx^2+vy^2+vz^2: 0.5039128025961813, wtemp_expr: 0.45472447144981043, sdet_expr: 0.9765571016128896
# Number of valid samples: 18837
# Sample passed checks. vx^2+vy^2+vz^2: 0.5281455426420081, wtemp_expr: 0.44796617817159823, sdet_expr: 1.062799749064831
# Number of valid samples: 18838
# Sample failed checks. vx^2+vy^2+vz^2: 1.7868207350597851, wtemp_expr: -0.8991493302534317, sdet_expr: 0.9385922803320496
# Number of valid samples: 18838
# Sample passed checks. vx^2+vy^2+vz^2: 0.5207980829614728, wtemp_expr: 0.43211448974061895, sdet_expr: 0.9540424203278429
# Number of valid samples: 18839
# Sample failed checks. vx^2+vy^2+vz^2: 0.9145097573334362, wtemp_expr: -0.022197924307607808, sdet_expr: 1.097054126906126
# Number of valid samples: 18839
# Sample passed checks. vx^2+vy^2+vz^2: 0.7637275596796473, wtemp_expr: 0.15716442399302066, sdet_expr: 1.1079984067291844
# Number of valid samples: 18840
# Sample passed checks. vx^2+vy^2+vz^2: 0.3430374926132156, wtemp_expr: 0.6472687343916663, sdet_expr: 0.99560328750463
# Number of valid samples: 18841
# Sample failed checks. vx^2+vy^2+vz^2: 1.3998721686185855, wtemp_expr: -0.44360942183885377, sdet_expr: 0.8523539560332138
# Number of valid samples: 18841
# Sample passed checks. vx^2+vy^2+vz^2: 0.23282879725498706, wtemp_expr: 0.732595030888685, sdet_expr: 1.2296392507736826
# Number of valid samples: 18842
# Sample passed checks. vx^2+vy^2+vz^2: 0.9451150641177828, wtemp_expr: 0.050721896643499687, sdet_expr: 1.0350181836945653
# Number of valid samples: 18843
# Sample passed checks. vx^2+vy^2+vz^2: 0.9290684915344916, wtemp_expr: 0.004101893579263272, sdet_expr: 0.9541321788033283
# Number of valid samples: 18844
# Sample failed checks. vx^2+vy^2+vz^2: 1.7571484693373343, wtemp_expr: -0.8802815102356347, sdet_expr: 1.0046917716228705
# Number of valid samples: 18844
# Sample passed checks. vx^2+vy^2+vz^2: 0.9402721090956287, wtemp_expr: 0.025649814595696374, sdet_expr: 0.8354565152637247
# Number of valid samples: 18845
# Sample passed checks. vx^2+vy^2+vz^2: 0.18730888819369879, wtemp_expr: 0.7920887762683229, sdet_expr: 0.9975798417151087
# Number of valid samples: 18846
# Sample failed checks. vx^2+vy^2+vz^2: 2.2594762140382016, wtemp_expr: -1.3917894257021426, sdet_expr: 0.9219284204337564
# Number of valid samples: 18846
# Sample failed checks. vx^2+vy^2+vz^2: 1.4694887382969353, wtemp_expr: -0.6480179877363219, sdet_expr: 1.086469290979506
# Number of valid samples: 18846
# Sample passed checks. vx^2+vy^2+vz^2: 0.8821529280779894, wtemp_expr: 0.09780291382723183, sdet_expr: 0.955719685599602
# Number of valid samples: 18847
# Sample passed checks. vx^2+vy^2+vz^2: 0.5462954834479274, wtemp_expr: 0.4063590532896798, sdet_expr: 1.0340675972067859
# Number of valid samples: 18848
# Sample passed checks. vx^2+vy^2+vz^2: 0.8121497588344393, wtemp_expr: 0.16053059926751767, sdet_expr: 0.8860022010283336
# Number of valid samples: 18849
# Sample passed checks. vx^2+vy^2+vz^2: 0.9235204459054227, wtemp_expr: 0.02547942988712182, sdet_expr: 1.164322752415793
# Number of valid samples: 18850
# Sample failed checks. vx^2+vy^2+vz^2: 1.1381519486955916, wtemp_expr: -0.28015930853525894, sdet_expr: 0.9654715432887393
# Number of valid samples: 18850
# Sample passed checks. vx^2+vy^2+vz^2: 0.01989083702827754, wtemp_expr: 0.9793203395478386, sdet_expr: 1.020045877952941
# Number of valid samples: 18851
# Sample failed checks. vx^2+vy^2+vz^2: 2.3985048783695815, wtemp_expr: -1.6175337123248905, sdet_expr: 1.0437293696024248
# Number of valid samples: 18851
# Sample failed checks. vx^2+vy^2+vz^2: 1.0573907470228983, wtemp_expr: -0.18988812770329133, sdet_expr: 0.8684516340958085
# Number of valid samples: 18851
# Sample failed checks. vx^2+vy^2+vz^2: 1.1571384735311139, wtemp_expr: -0.23393248223441931, sdet_expr: 0.9077345449156192
# Number of valid samples: 18851
# Sample failed checks. vx^2+vy^2+vz^2: 1.274344143364493, wtemp_expr: -0.2996564951986005, sdet_expr: 0.8934847833468241
# Number of valid samples: 18851
# Sample passed checks. vx^2+vy^2+vz^2: 0.4207866234100238, wtemp_expr: 0.5571961182292453, sdet_expr: 0.9183654146641681
# Number of valid samples: 18852
# Sample failed checks. vx^2+vy^2+vz^2: 0.9417005196557804, wtemp_expr: -0.04216943943616136, sdet_expr: 1.0359911830090456
# Number of valid samples: 18852
# Sample failed checks. vx^2+vy^2+vz^2: 1.647454296221428, wtemp_expr: -0.7388705968932328, sdet_expr: 0.9090308418282841
# Number of valid samples: 18852
# Sample passed checks. vx^2+vy^2+vz^2: 0.2582340187811265, wtemp_expr: 0.7298053003041458, sdet_expr: 0.9193080624099643
# Number of valid samples: 18853
# Sample failed checks. vx^2+vy^2+vz^2: 1.507749718150205, wtemp_expr: -0.5750207885778793, sdet_expr: 0.8947794137775195
# Number of valid samples: 18853
# Sample passed checks. vx^2+vy^2+vz^2: 0.767606043775303, wtemp_expr: 0.20355862510823897, sdet_expr: 0.9893559676613475
# Number of valid samples: 18854
# Sample failed checks. vx^2+vy^2+vz^2: 1.3463934921163456, wtemp_expr: -0.3537027394281862, sdet_expr: 0.9603275304670437
# Number of valid samples: 18854
# Sample failed checks. vx^2+vy^2+vz^2: 1.0195496930705399, wtemp_expr: -0.06387188254388954, sdet_expr: 1.0397105221881688
# Number of valid samples: 18854
# Sample failed checks. vx^2+vy^2+vz^2: 1.4418049896634528, wtemp_expr: -0.6086353629159436, sdet_expr: 0.9744419357953485
# Number of valid samples: 18854
# Sample passed checks. vx^2+vy^2+vz^2: 0.5643442199055888, wtemp_expr: 0.4287116859544283, sdet_expr: 1.0002065624142336
# Number of valid samples: 18855
# Sample failed checks. vx^2+vy^2+vz^2: 1.1990499663381837, wtemp_expr: -0.27888826046474047, sdet_expr: 0.9377875497061405
# Number of valid samples: 18855
# Sample failed checks. vx^2+vy^2+vz^2: 1.9208614531980812, wtemp_expr: -1.0119280409616738, sdet_expr: 0.7622803785166106
# Number of valid samples: 18855
# Sample passed checks. vx^2+vy^2+vz^2: 0.7179216768061646, wtemp_expr: 0.20735365734178846, sdet_expr: 0.9483881728055678
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.5039397121586826, wtemp_expr: -0.6031598563272356, sdet_expr: 1.0464103081580158
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.5554030403578085, wtemp_expr: -0.6004490108344991, sdet_expr: 0.9510968287679175
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.645974991444376, wtemp_expr: -0.7829403676828186, sdet_expr: 1.1933702703128368
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.34148592612806, wtemp_expr: -0.29145433607333016, sdet_expr: 0.886606592136
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.5555643310534342, wtemp_expr: -0.6738918935128118, sdet_expr: 1.110649457775046
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.1062185589138511, wtemp_expr: -0.17944642472015992, sdet_expr: 0.9766031833065494
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.2841881622636742, wtemp_expr: -0.3316162042843984, sdet_expr: 0.8069486073943013
# Number of valid samples: 18856
# Sample failed checks. vx^2+vy^2+vz^2: 1.306791093346706, wtemp_expr: -0.34945197367797376, sdet_expr: 0.9352155307305569
# Number of valid samples: 18856
# Sample passed checks. vx^2+vy^2+vz^2: 0.8501993194509738, wtemp_expr: 0.08581515067153944, sdet_expr: 1.0759439719741175
# Number of valid samples: 18857
# Sample passed checks. vx^2+vy^2+vz^2: 0.39264389436588837, wtemp_expr: 0.5575062516501439, sdet_expr: 0.9442103122549953
# Number of valid samples: 18858
# Sample passed checks. vx^2+vy^2+vz^2: 0.4466853943702952, wtemp_expr: 0.4863193384719716, sdet_expr: 1.1279210177158077
# Number of valid samples: 18859
# Sample passed checks. vx^2+vy^2+vz^2: 0.7876881307118726, wtemp_expr: 0.10531289397476562, sdet_expr: 1.0818367832112583
# Number of valid samples: 18860
# Sample failed checks. vx^2+vy^2+vz^2: 1.1078361725700596, wtemp_expr: -0.2578438362218092, sdet_expr: 1.1451043082409933
# Number of valid samples: 18860
# Sample passed checks. vx^2+vy^2+vz^2: 0.7533747739515428, wtemp_expr: 0.18603654757977084, sdet_expr: 1.1175809529420042
# Number of valid samples: 18861
# Sample passed checks. vx^2+vy^2+vz^2: 0.5885105144581347, wtemp_expr: 0.38856865188383005, sdet_expr: 1.0686617147699757
# Number of valid samples: 18862
# Sample passed checks. vx^2+vy^2+vz^2: 0.6021747385847939, wtemp_expr: 0.3272537118027815, sdet_expr: 1.1542207518509329
# Number of valid samples: 18863
# Sample failed checks. vx^2+vy^2+vz^2: 1.3788897186805076, wtemp_expr: -0.4822820016600726, sdet_expr: 0.8946475784059036
# Number of valid samples: 18863
# Sample failed checks. vx^2+vy^2+vz^2: 0.9381219646928827, wtemp_expr: -0.0107681983784782, sdet_expr: 0.9213425729478429
# Number of valid samples: 18863
# Sample passed checks. vx^2+vy^2+vz^2: 0.8359469559995535, wtemp_expr: 0.21290451991397652, sdet_expr: 0.9245734235834041
# Number of valid samples: 18864
# Sample passed checks. vx^2+vy^2+vz^2: 0.9420618943476019, wtemp_expr: 0.028932275933358564, sdet_expr: 1.0240494089051326
# Number of valid samples: 18865
# Sample passed checks. vx^2+vy^2+vz^2: 0.8467575868145034, wtemp_expr: 0.05596969437093813, sdet_expr: 1.1390305810865988
# Number of valid samples: 18866
# Sample passed checks. vx^2+vy^2+vz^2: 0.8281002553117784, wtemp_expr: 0.23375870006432498, sdet_expr: 0.8511740273167034
# Number of valid samples: 18867
# Sample failed checks. vx^2+vy^2+vz^2: 1.1381033245309617, wtemp_expr: -0.13963658631958742, sdet_expr: 0.8438158016343544
# Number of valid samples: 18867
# Sample failed checks. vx^2+vy^2+vz^2: 1.7440381839555759, wtemp_expr: -0.9498136461484348, sdet_expr: 1.0837350523934466
# Number of valid samples: 18867
# Sample failed checks. vx^2+vy^2+vz^2: 1.262868586516513, wtemp_expr: -0.40803422196212846, sdet_expr: 0.9394885639692181
# Number of valid samples: 18867
# Sample passed checks. vx^2+vy^2+vz^2: 0.45719928067883525, wtemp_expr: 0.5206834760165683, sdet_expr: 1.1008328913411265
# Number of valid samples: 18868
# Sample failed checks. vx^2+vy^2+vz^2: 1.1691508847590737, wtemp_expr: -0.224656199683142, sdet_expr: 0.8486196698809297
# Number of valid samples: 18868
# Sample passed checks. vx^2+vy^2+vz^2: 0.8450346964182134, wtemp_expr: 0.14796240958944862, sdet_expr: 0.9660455799689934
# Number of valid samples: 18869
# Sample passed checks. vx^2+vy^2+vz^2: 0.45265807135587594, wtemp_expr: 0.556058655252911, sdet_expr: 0.8356649712702945
# Number of valid samples: 18870
# Sample passed checks. vx^2+vy^2+vz^2: 0.3780566190900455, wtemp_expr: 0.63912464359593, sdet_expr: 0.9910978153234197
# Number of valid samples: 18871
# Sample failed checks. vx^2+vy^2+vz^2: 1.1378545794065966, wtemp_expr: -0.27208232549435873, sdet_expr: 1.0876394207223417
# Number of valid samples: 18871
# Sample failed checks. vx^2+vy^2+vz^2: 1.0614232994881314, wtemp_expr: -0.1849057673940473, sdet_expr: 0.9246551957457531
# Number of valid samples: 18871
# Sample passed checks. vx^2+vy^2+vz^2: 0.3795201401671424, wtemp_expr: 0.6024234737674763, sdet_expr: 0.9724413152824866
# Number of valid samples: 18872
# Sample failed checks. vx^2+vy^2+vz^2: 1.1847947010736726, wtemp_expr: -0.2662346189086431, sdet_expr: 1.0433555086741566
# Number of valid samples: 18872
# Sample passed checks. vx^2+vy^2+vz^2: 0.5845304624121839, wtemp_expr: 0.3614035851246197, sdet_expr: 0.995523123991273
# Number of valid samples: 18873
# Sample passed checks. vx^2+vy^2+vz^2: 0.3569505510402283, wtemp_expr: 0.6165660221023397, sdet_expr: 0.8336949445864724
# Number of valid samples: 18874
# Sample failed checks. vx^2+vy^2+vz^2: 1.7972574323532924, wtemp_expr: -0.9525090056896661, sdet_expr: 1.0169496238418505
# Number of valid samples: 18874
# Sample passed checks. vx^2+vy^2+vz^2: 0.33383595729921345, wtemp_expr: 0.617327494248989, sdet_expr: 1.1594493493152664
# Number of valid samples: 18875
# Sample failed checks. vx^2+vy^2+vz^2: 1.782493343238707, wtemp_expr: -1.0234347094326748, sdet_expr: 0.9201593098456793
# Number of valid samples: 18875
# Sample failed checks. vx^2+vy^2+vz^2: 1.060646476981522, wtemp_expr: -0.23711343749412572, sdet_expr: 1.0284960213974588
# Number of valid samples: 18875
# Sample passed checks. vx^2+vy^2+vz^2: 0.50368285234638, wtemp_expr: 0.446281481111388, sdet_expr: 1.1809289925401965
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 1.0165390932031892, wtemp_expr: -0.06617705516730288, sdet_expr: 0.9741139796551052
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 0.9980433450660735, wtemp_expr: -0.05882598276286455, sdet_expr: 1.011501979077359
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 1.565152455591855, wtemp_expr: -0.6067703452214912, sdet_expr: 0.9290681209680075
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 1.0677207541532021, wtemp_expr: -0.022180308339619703, sdet_expr: 0.8490991482837028
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 1.39258700422457, wtemp_expr: -0.41779428436619637, sdet_expr: 0.9049833157343647
# Number of valid samples: 18876
# Sample failed checks. vx^2+vy^2+vz^2: 1.0799334452476246, wtemp_expr: -0.14467868355321367, sdet_expr: 0.9238270225071463
# Number of valid samples: 18876
# Sample passed checks. vx^2+vy^2+vz^2: 0.32537617047191103, wtemp_expr: 0.6514169550414302, sdet_expr: 1.0244517680339253
# Number of valid samples: 18877
# Sample failed checks. vx^2+vy^2+vz^2: 1.4406558977392367, wtemp_expr: -0.5567480228060082, sdet_expr: 1.0367701484869476
# Number of valid samples: 18877
# Sample passed checks. vx^2+vy^2+vz^2: 0.3820559302281961, wtemp_expr: 0.6049501630463556, sdet_expr: 1.044016550755624
# Number of valid samples: 18878
# Sample passed checks. vx^2+vy^2+vz^2: 0.6918464225930989, wtemp_expr: 0.292158325603705, sdet_expr: 0.8847047357485025
# Number of valid samples: 18879
# Sample passed checks. vx^2+vy^2+vz^2: 0.47716134605512883, wtemp_expr: 0.5026237424556212, sdet_expr: 1.0110803909798465
# Number of valid samples: 18880
# Sample passed checks. vx^2+vy^2+vz^2: 0.764473015135281, wtemp_expr: 0.24370979452206665, sdet_expr: 0.8119750670015711
# Number of valid samples: 18881
# Sample passed checks. vx^2+vy^2+vz^2: 0.5790961718039087, wtemp_expr: 0.45969967081312824, sdet_expr: 0.8819652880031811
# Number of valid samples: 18882
# Sample failed checks. vx^2+vy^2+vz^2: 1.6495365605593766, wtemp_expr: -0.7746933924767709, sdet_expr: 1.148336550789182
# Number of valid samples: 18882
# Sample failed checks. vx^2+vy^2+vz^2: 1.0085200765470879, wtemp_expr: -0.08546154225324543, sdet_expr: 1.0538000289745548
# Number of valid samples: 18882
# Sample passed checks. vx^2+vy^2+vz^2: 0.7019969254370361, wtemp_expr: 0.22594295152742427, sdet_expr: 1.0191043952048917
# Number of valid samples: 18883
# Sample failed checks. vx^2+vy^2+vz^2: 1.5512973539841615, wtemp_expr: -0.6478535352023269, sdet_expr: 0.8452762427091801
# Number of valid samples: 18883
# Sample passed checks. vx^2+vy^2+vz^2: 0.3847783975338367, wtemp_expr: 0.5784365098526476, sdet_expr: 0.9466606720588231
# Number of valid samples: 18884
# Sample passed checks. vx^2+vy^2+vz^2: 0.21976293326618299, wtemp_expr: 0.7704591564297285, sdet_expr: 1.0446553344054779
# Number of valid samples: 18885
# Sample passed checks. vx^2+vy^2+vz^2: 0.6174594290771155, wtemp_expr: 0.38747672730100535, sdet_expr: 1.0003297176685932
# Number of valid samples: 18886
# Sample passed checks. vx^2+vy^2+vz^2: 0.21460908250633376, wtemp_expr: 0.7559587557871024, sdet_expr: 1.142711989023874
# Number of valid samples: 18887
# Sample failed checks. vx^2+vy^2+vz^2: 1.2264313578149957, wtemp_expr: -0.3296140945792636, sdet_expr: 0.9304232831256991
# Number of valid samples: 18887
# Sample failed checks. vx^2+vy^2+vz^2: 1.75345237785917, wtemp_expr: -0.8600558151926805, sdet_expr: 1.100211566360212
# Number of valid samples: 18887
# Sample failed checks. vx^2+vy^2+vz^2: 1.0207481425931217, wtemp_expr: -0.14806038048157344, sdet_expr: 0.8801003190492455
# Number of valid samples: 18887
# Sample failed checks. vx^2+vy^2+vz^2: 1.1194100174760866, wtemp_expr: -0.11405528282918431, sdet_expr: 0.9175331936336256
# Number of valid samples: 18887
# Sample failed checks. vx^2+vy^2+vz^2: 1.183949274047503, wtemp_expr: -0.3065346448527708, sdet_expr: 0.9409666810093547
# Number of valid samples: 18887
# Sample passed checks. vx^2+vy^2+vz^2: 0.34601635505586587, wtemp_expr: 0.6442959734583316, sdet_expr: 1.1598456574512235
# Number of valid samples: 18888
# Sample passed checks. vx^2+vy^2+vz^2: 0.6469352266735017, wtemp_expr: 0.32382506846652903, sdet_expr: 0.989232142876783
# Number of valid samples: 18889
# Sample passed checks. vx^2+vy^2+vz^2: 0.38975991076101524, wtemp_expr: 0.6222413169397669, sdet_expr: 0.8167408624143581
# Number of valid samples: 18890
# Sample failed checks. vx^2+vy^2+vz^2: 1.7362433490736549, wtemp_expr: -0.880463789292492, sdet_expr: 0.9488523985590182
# Number of valid samples: 18890
# Sample passed checks. vx^2+vy^2+vz^2: 0.3807511162405865, wtemp_expr: 0.5998062777009894, sdet_expr: 0.9069634669722155
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.1835427127173632, wtemp_expr: -0.20788557435884347, sdet_expr: 0.9896381484274097
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.0511690943469265, wtemp_expr: -0.02465583869466248, sdet_expr: 0.8633589199026691
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.8466158424728736, wtemp_expr: -0.9320235405868464, sdet_expr: 0.9701215042686526
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.154520052607585, wtemp_expr: -0.2150623460390213, sdet_expr: 0.9697655970321621
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.168455026565746, wtemp_expr: -0.2629955974978959, sdet_expr: 0.9599466158342036
# Number of valid samples: 18891
# Sample failed checks. vx^2+vy^2+vz^2: 1.4050036785019753, wtemp_expr: -0.6412359857323136, sdet_expr: 1.234338134406217
# Number of valid samples: 18891
# Sample passed checks. vx^2+vy^2+vz^2: 0.14702978884232704, wtemp_expr: 0.8364256719042442, sdet_expr: 0.9085910315283136
# Number of valid samples: 18892
# Sample failed checks. vx^2+vy^2+vz^2: 1.5109676103104213, wtemp_expr: -0.636076930841817, sdet_expr: 1.1536880761520838
# Number of valid samples: 18892
# Sample failed checks. vx^2+vy^2+vz^2: 1.3337104411333387, wtemp_expr: -0.3520928414491189, sdet_expr: 0.9817448851983471
# Number of valid samples: 18892
# Sample failed checks. vx^2+vy^2+vz^2: 1.2828490739240344, wtemp_expr: -0.2309942070375719, sdet_expr: 0.8535263128657821
# Number of valid samples: 18892
# Sample failed checks. vx^2+vy^2+vz^2: 1.2473532560594496, wtemp_expr: -0.37478080644813083, sdet_expr: 1.0749790695600407
# Number of valid samples: 18892
# Sample passed checks. vx^2+vy^2+vz^2: 0.3168664715735037, wtemp_expr: 0.6635776770929966, sdet_expr: 1.006143421855062
# Number of valid samples: 18893
# Sample passed checks. vx^2+vy^2+vz^2: 0.25688779429968256, wtemp_expr: 0.7512101470503819, sdet_expr: 0.768279253288629
# Number of valid samples: 18894
# Sample failed checks. vx^2+vy^2+vz^2: 1.1801282629978886, wtemp_expr: -0.2327956178256969, sdet_expr: 0.9040751991568127
# Number of valid samples: 18894
# Sample passed checks. vx^2+vy^2+vz^2: 0.823018040935188, wtemp_expr: 0.05940262580431477, sdet_expr: 1.1321161910102946
# Number of valid samples: 18895
# Sample passed checks. vx^2+vy^2+vz^2: 0.39909671352393117, wtemp_expr: 0.5382800834206066, sdet_expr: 1.0199446159922678
# Number of valid samples: 18896
# Sample failed checks. vx^2+vy^2+vz^2: 1.444085376763702, wtemp_expr: -0.5451930331470312, sdet_expr: 0.9521892177234677
# Number of valid samples: 18896
# Sample failed checks. vx^2+vy^2+vz^2: 1.0638942791469754, wtemp_expr: -0.15900110514444976, sdet_expr: 1.0242534471767584
# Number of valid samples: 18896
# Sample passed checks. vx^2+vy^2+vz^2: 0.14579836045734038, wtemp_expr: 0.8539896752323511, sdet_expr: 0.9258029378312697
# Number of valid samples: 18897
# Sample failed checks. vx^2+vy^2+vz^2: 1.2082136089882196, wtemp_expr: -0.41473483506280995, sdet_expr: 1.0543590478375613
# Number of valid samples: 18897
# Sample passed checks. vx^2+vy^2+vz^2: 0.8683486129267163, wtemp_expr: 0.15415982257300975, sdet_expr: 1.136737103672707
# Number of valid samples: 18898
# Sample failed checks. vx^2+vy^2+vz^2: 1.6959498956822354, wtemp_expr: -0.7693134242504582, sdet_expr: 0.995575337468436
# Number of valid samples: 18898
# Sample passed checks. vx^2+vy^2+vz^2: 0.664351540665346, wtemp_expr: 0.2774415835618744, sdet_expr: 0.9915378238767435
# Number of valid samples: 18899
# Sample failed checks. vx^2+vy^2+vz^2: 1.5472186480986547, wtemp_expr: -0.5797213200515672, sdet_expr: 0.817947264265632
# Number of valid samples: 18899
# Sample passed checks. vx^2+vy^2+vz^2: 0.6183112942844975, wtemp_expr: 0.353118117401912, sdet_expr: 0.9917036813739338
# Number of valid samples: 18900
# Sample failed checks. vx^2+vy^2+vz^2: 1.7889716835178775, wtemp_expr: -1.0561228858505376, sdet_expr: 1.1192742494335417
# Number of valid samples: 18900
# Sample passed checks. vx^2+vy^2+vz^2: 0.46815502671071063, wtemp_expr: 0.49281871637631547, sdet_expr: 1.04403178652325
# Number of valid samples: 18901
# Sample passed checks. vx^2+vy^2+vz^2: 0.2856751627573524, wtemp_expr: 0.7256706933722813, sdet_expr: 0.8835268085971647
# Number of valid samples: 18902
# Sample passed checks. vx^2+vy^2+vz^2: 0.41311092481946554, wtemp_expr: 0.5940987696110989, sdet_expr: 0.8156546836701866
# Number of valid samples: 18903
# Sample passed checks. vx^2+vy^2+vz^2: 0.0679409995672084, wtemp_expr: 0.9324717330603586, sdet_expr: 0.8654630300354194
# Number of valid samples: 18904
# Sample failed checks. vx^2+vy^2+vz^2: 0.9264258445267135, wtemp_expr: -0.04991880519579994, sdet_expr: 0.9864427218738063
# Number of valid samples: 18904
# Sample failed checks. vx^2+vy^2+vz^2: 1.6122937104968726, wtemp_expr: -0.6489650596257486, sdet_expr: 0.9421942083413568
# Number of valid samples: 18904
# Sample failed checks. vx^2+vy^2+vz^2: 2.04258787432541, wtemp_expr: -1.335955682686902, sdet_expr: 0.9821390492342499
# Number of valid samples: 18904
# Sample failed checks. vx^2+vy^2+vz^2: 1.1205102951786596, wtemp_expr: -0.26109882998847644, sdet_expr: 1.0671884623152617
# Number of valid samples: 18904
# Sample failed checks. vx^2+vy^2+vz^2: 1.3134020244807327, wtemp_expr: -0.37724736352475063, sdet_expr: 0.8112660511095465
# Number of valid samples: 18904
# Sample passed checks. vx^2+vy^2+vz^2: 0.7014566204327648, wtemp_expr: 0.25384643775285654, sdet_expr: 0.9712716617024394
# Number of valid samples: 18905
# Sample failed checks. vx^2+vy^2+vz^2: 1.0879959513425002, wtemp_expr: -0.2563502191149545, sdet_expr: 1.0692924486404793
# Number of valid samples: 18905
# Sample passed checks. vx^2+vy^2+vz^2: 0.09701100419794474, wtemp_expr: 0.9038642946362255, sdet_expr: 0.8350752831508392
# Number of valid samples: 18906
# Sample failed checks. vx^2+vy^2+vz^2: 1.3781282738727758, wtemp_expr: -0.453874212559376, sdet_expr: 0.9182413292894589
# Number of valid samples: 18906
# Sample failed checks. vx^2+vy^2+vz^2: 1.9342113348191068, wtemp_expr: -0.9956639095483089, sdet_expr: 0.9914773558947204
# Number of valid samples: 18906
# Sample failed checks. vx^2+vy^2+vz^2: 1.1980719784488663, wtemp_expr: -0.33219281784705323, sdet_expr: 0.9224347626324572
# Number of valid samples: 18906
# Sample passed checks. vx^2+vy^2+vz^2: 0.23497477068472267, wtemp_expr: 0.7453512512066678, sdet_expr: 1.0330594155907022
# Number of valid samples: 18907
# Sample passed checks. vx^2+vy^2+vz^2: 0.8972031948519087, wtemp_expr: 0.053601333487369174, sdet_expr: 0.9338339628720076
# Number of valid samples: 18908
# Sample passed checks. vx^2+vy^2+vz^2: 0.2145289133367962, wtemp_expr: 0.7636129580561006, sdet_expr: 1.168455308215068
# Number of valid samples: 18909
# Sample failed checks. vx^2+vy^2+vz^2: 0.9845613749842197, wtemp_expr: -0.08466520929677035, sdet_expr: 1.0228060126710072
# Number of valid samples: 18909
# Sample passed checks. vx^2+vy^2+vz^2: 0.6649884436572563, wtemp_expr: 0.28286781671363403, sdet_expr: 0.9672298325040726
# Number of valid samples: 18910
# Sample passed checks. vx^2+vy^2+vz^2: 0.46349732874549854, wtemp_expr: 0.5106664548435167, sdet_expr: 0.9111447858500592
# Number of valid samples: 18911
# Sample passed checks. vx^2+vy^2+vz^2: 0.5591480002252612, wtemp_expr: 0.39189836686936264, sdet_expr: 1.0042590585038746
# Number of valid samples: 18912
# Sample failed checks. vx^2+vy^2+vz^2: 1.01237261135058, wtemp_expr: -0.019577882972156013, sdet_expr: 0.9924931594654907
# Number of valid samples: 18912
# Sample failed checks. vx^2+vy^2+vz^2: 1.5219189785119178, wtemp_expr: -0.6108150368226524, sdet_expr: 0.9723300636082675
# Number of valid samples: 18912
# Sample failed checks. vx^2+vy^2+vz^2: 1.7399935863532776, wtemp_expr: -0.7840560879827012, sdet_expr: 0.8995007602311146
# Number of valid samples: 18912
# Sample failed checks. vx^2+vy^2+vz^2: 1.8692700049121531, wtemp_expr: -1.1047636100198437, sdet_expr: 0.9921841684933181
# Number of valid samples: 18912
# Sample failed checks. vx^2+vy^2+vz^2: 0.9490975670731862, wtemp_expr: -0.018181093067229037, sdet_expr: 0.9386039517480165
# Number of valid samples: 18912
# Sample passed checks. vx^2+vy^2+vz^2: 0.5323555682175192, wtemp_expr: 0.4271479635214217, sdet_expr: 0.8991531474183044
# Number of valid samples: 18913
# Sample passed checks. vx^2+vy^2+vz^2: 0.6107966267073346, wtemp_expr: 0.34602454665417104, sdet_expr: 1.0754890504708416
# Number of valid samples: 18914
# Sample passed checks. vx^2+vy^2+vz^2: 0.649980572766085, wtemp_expr: 0.3817871068229042, sdet_expr: 0.9069008157587582
# Number of valid samples: 18915
# Sample passed checks. vx^2+vy^2+vz^2: 0.8658774267196865, wtemp_expr: 0.07661309353623968, sdet_expr: 1.1400599104311164
# Number of valid samples: 18916
# Sample failed checks. vx^2+vy^2+vz^2: 1.2912042060700606, wtemp_expr: -0.4347902715160985, sdet_expr: 0.8931318126378069
# Number of valid samples: 18916
# Sample failed checks. vx^2+vy^2+vz^2: 1.2176613070021407, wtemp_expr: -0.2590274973608737, sdet_expr: 0.9201171264924197
# Number of valid samples: 18916
# Sample failed checks. vx^2+vy^2+vz^2: 1.0936936938578472, wtemp_expr: -0.15778063292368216, sdet_expr: 0.8689838828618301
# Number of valid samples: 18916
# Sample passed checks. vx^2+vy^2+vz^2: 0.8668770589730956, wtemp_expr: 0.09943248347711886, sdet_expr: 0.9041196935966994
# Number of valid samples: 18917
# Sample failed checks. vx^2+vy^2+vz^2: 1.5570359392258188, wtemp_expr: -0.5148357934969823, sdet_expr: 0.8887846288149672
# Number of valid samples: 18917
# Sample failed checks. vx^2+vy^2+vz^2: 1.4250446284229537, wtemp_expr: -0.5321355156133072, sdet_expr: 0.8656253045403034
# Number of valid samples: 18917
# Sample failed checks. vx^2+vy^2+vz^2: 1.0240924512985594, wtemp_expr: 0.012392341922955907, sdet_expr: 0.8896722571201651
# Number of valid samples: 18917
# Sample failed checks. vx^2+vy^2+vz^2: 1.5074478466039216, wtemp_expr: -0.5264559082585707, sdet_expr: 0.850562127782615
# Number of valid samples: 18917
# Sample failed checks. vx^2+vy^2+vz^2: 1.3445375562418078, wtemp_expr: -0.47446845249724734, sdet_expr: 1.0400375113378115
# Number of valid samples: 18917
# Sample passed checks. vx^2+vy^2+vz^2: 0.4406849916464626, wtemp_expr: 0.5062626603105382, sdet_expr: 1.0037837636668943
# Number of valid samples: 18918
# Sample failed checks. vx^2+vy^2+vz^2: 1.2969162538284322, wtemp_expr: -0.4980508824591152, sdet_expr: 1.0995874729835977
# Number of valid samples: 18918
# Sample failed checks. vx^2+vy^2+vz^2: 1.0742048283326446, wtemp_expr: -0.1354139902802729, sdet_expr: 1.000413054926355
# Number of valid samples: 18918
# Sample passed checks. vx^2+vy^2+vz^2: 0.23261188379530146, wtemp_expr: 0.7505481380380878, sdet_expr: 1.006923429152784
# Number of valid samples: 18919
# Sample failed checks. vx^2+vy^2+vz^2: 2.754583283967834, wtemp_expr: -2.0820860086126203, sdet_expr: 0.9846013054204621
# Number of valid samples: 18919
# Sample passed checks. vx^2+vy^2+vz^2: 0.39745411585430984, wtemp_expr: 0.607617642930423, sdet_expr: 1.0901907548743732
# Number of valid samples: 18920
# Sample passed checks. vx^2+vy^2+vz^2: 0.8937030312149612, wtemp_expr: 0.02409751927904291, sdet_expr: 1.0514011553688514
# Number of valid samples: 18921
# Sample passed checks. vx^2+vy^2+vz^2: 0.36272151893755417, wtemp_expr: 0.5900223272810067, sdet_expr: 1.02116509661146
# Number of valid samples: 18922
# Sample passed checks. vx^2+vy^2+vz^2: 0.1648800093822329, wtemp_expr: 0.8382515888189486, sdet_expr: 0.8229279307611571
# Number of valid samples: 18923
# Sample failed checks. vx^2+vy^2+vz^2: 1.0017179340222397, wtemp_expr: 0.0591493184045645, sdet_expr: 0.8315712607938958
# Number of valid samples: 18923
# Sample passed checks. vx^2+vy^2+vz^2: 0.8869113804735638, wtemp_expr: 0.08967889335898283, sdet_expr: 0.8284680363424727
# Number of valid samples: 18924
# Sample failed checks. vx^2+vy^2+vz^2: 1.5554983580029866, wtemp_expr: -0.594334744253884, sdet_expr: 1.1039530187754518
# Number of valid samples: 18924
# Sample failed checks. vx^2+vy^2+vz^2: 0.961849099394779, wtemp_expr: -0.06621760545572308, sdet_expr: 0.8799593388157778
# Number of valid samples: 18924
# Sample failed checks. vx^2+vy^2+vz^2: 1.7882800605627336, wtemp_expr: -1.0447578292874864, sdet_expr: 1.0331941764435622
# Number of valid samples: 18924
# Sample passed checks. vx^2+vy^2+vz^2: 0.23934275276736772, wtemp_expr: 0.7163416618551695, sdet_expr: 1.1501018263270477
# Number of valid samples: 18925
# Sample failed checks. vx^2+vy^2+vz^2: 2.4545916773681, wtemp_expr: -1.5891448231481338, sdet_expr: 0.9572868124872418
# Number of valid samples: 18925
# Sample passed checks. vx^2+vy^2+vz^2: 0.4330767587077048, wtemp_expr: 0.5440517574411026, sdet_expr: 0.977183602406745
# Number of valid samples: 18926
# Sample failed checks. vx^2+vy^2+vz^2: 1.9588090708548185, wtemp_expr: -1.0567693038065107, sdet_expr: 1.0163840587690394
# Number of valid samples: 18926
# Sample passed checks. vx^2+vy^2+vz^2: 0.540463986176904, wtemp_expr: 0.40515101919199725, sdet_expr: 1.0554049535374044
# Number of valid samples: 18927
# Sample passed checks. vx^2+vy^2+vz^2: 0.7422266568646353, wtemp_expr: 0.28018133193902184, sdet_expr: 0.9310550478659307
# Number of valid samples: 18928
# Sample failed checks. vx^2+vy^2+vz^2: 1.0768256674557024, wtemp_expr: -0.10813616199393983, sdet_expr: 0.8083328112294447
# Number of valid samples: 18928
# Sample passed checks. vx^2+vy^2+vz^2: 0.9801739672323143, wtemp_expr: 0.03735191550744821, sdet_expr: 0.8728778376651124
# Number of valid samples: 18929
# Sample failed checks. vx^2+vy^2+vz^2: 1.1005201828965354, wtemp_expr: -0.14648730760305195, sdet_expr: 1.014092148335952
# Number of valid samples: 18929
# Sample failed checks. vx^2+vy^2+vz^2: 1.2480357851753898, wtemp_expr: -0.30137062319349894, sdet_expr: 0.9927438243001254
# Number of valid samples: 18929
# Sample passed checks. vx^2+vy^2+vz^2: 0.04582244421710025, wtemp_expr: 0.9453256179199624, sdet_expr: 1.228105233953074
# Number of valid samples: 18930
# Sample failed checks. vx^2+vy^2+vz^2: 1.0945315067422647, wtemp_expr: -0.13867973774009057, sdet_expr: 0.998176111202527
# Number of valid samples: 18930
# Sample passed checks. vx^2+vy^2+vz^2: 0.666987167377872, wtemp_expr: 0.2805805864676506, sdet_expr: 0.952347061246898
# Number of valid samples: 18931
# Sample failed checks. vx^2+vy^2+vz^2: 1.0404990720397802, wtemp_expr: -0.17014610335430747, sdet_expr: 1.1085227558867006
# Number of valid samples: 18931
# Sample failed checks. vx^2+vy^2+vz^2: 0.9580352811707893, wtemp_expr: -0.16019975908766138, sdet_expr: 1.203340192295496
# Number of valid samples: 18931
# Sample failed checks. vx^2+vy^2+vz^2: 1.037533291358544, wtemp_expr: -0.17090034251646857, sdet_expr: 1.1504616957822278
# Number of valid samples: 18931
# Sample failed checks. vx^2+vy^2+vz^2: 1.4516574976982075, wtemp_expr: -0.5121240971618104, sdet_expr: 0.9783591932159004
# Number of valid samples: 18931
# Sample passed checks. vx^2+vy^2+vz^2: 0.7985560616297736, wtemp_expr: 0.1976705807964979, sdet_expr: 0.8390538600382705
# Number of valid samples: 18932
# Sample failed checks. vx^2+vy^2+vz^2: 1.712383315896057, wtemp_expr: -0.8862482121708577, sdet_expr: 1.1135834346126197
# Number of valid samples: 18932
# Sample failed checks. vx^2+vy^2+vz^2: 1.0025369772935395, wtemp_expr: -0.09838918387933249, sdet_expr: 0.9070129951355169
# Number of valid samples: 18932
# Sample passed checks. vx^2+vy^2+vz^2: 0.7151959911924135, wtemp_expr: 0.2081983370811329, sdet_expr: 1.1087139402400497
# Number of valid samples: 18933
# Sample failed checks. vx^2+vy^2+vz^2: 0.9732665063402366, wtemp_expr: -0.023578989343601364, sdet_expr: 1.07017311303088
# Number of valid samples: 18933
# ...
# Number of valid samples: 19940
# Sample failed checks. vx^2+vy^2+vz^2: 1.929020560007645, wtemp_expr: -1.180885080499538, sdet_expr: 1.0700912843970884
# Number of valid samples: 19940
# Sample failed checks. vx^2+vy^2+vz^2: 0.9765265222696508, wtemp_expr: -0.026438009243069605, sdet_expr: 0.8576984533551769
# Number of valid samples: 19940
# Sample failed checks. vx^2+vy^2+vz^2: 1.5039659437280097, wtemp_expr: -0.6393102521700684, sdet_expr: 0.9266361128345695
# Number of valid samples: 19940
# Sample failed checks. vx^2+vy^2+vz^2: 1.7806651299009106, wtemp_expr: -0.9561183334656964, sdet_expr: 1.1915663188155767
# Number of valid samples: 19940
# Sample passed checks. vx^2+vy^2+vz^2: 0.6812090634096802, wtemp_expr: 0.25591345129107035, sdet_expr: 1.008648073501368
# Number of valid samples: 19941
# Sample passed checks. vx^2+vy^2+vz^2: 0.21891069388879747, wtemp_expr: 0.7659707837771893, sdet_expr: 0.9399674498262797
# Number of valid samples: 19942
# Sample failed checks. vx^2+vy^2+vz^2: 1.1393428048176184, wtemp_expr: -0.23715325902651818, sdet_expr: 1.0738331362451121
# Number of valid samples: 19942
# Sample failed checks. vx^2+vy^2+vz^2: 1.094422846801515, wtemp_expr: -0.12785580209869307, sdet_expr: 0.9103110038780021
# Number of valid samples: 19942
# Sample passed checks. vx^2+vy^2+vz^2: 0.2285900116934388, wtemp_expr: 0.7495529409562888, sdet_expr: 0.994570658043574
# Number of valid samples: 19943
# Sample failed checks. vx^2+vy^2+vz^2: 1.7659969032337401, wtemp_expr: -0.7878971730925624, sdet_expr: 0.8795583713547896
# Number of valid samples: 19943
# Sample passed checks. vx^2+vy^2+vz^2: 0.6378151258422318, wtemp_expr: 0.30505191501815554, sdet_expr: 1.0820684864212975
# Number of valid samples: 19944
# Sample passed checks. vx^2+vy^2+vz^2: 0.6680173003308212, wtemp_expr: 0.2638115919831677, sdet_expr: 0.9774578158819155
# Number of valid samples: 19945
# Sample failed checks. vx^2+vy^2+vz^2: 1.496319532098779, wtemp_expr: -0.6147065523921402, sdet_expr: 0.9414651121626372
# Number of valid samples: 19945
# Sample passed checks. vx^2+vy^2+vz^2: 0.31366526514158743, wtemp_expr: 0.6643201649354413, sdet_expr: 1.0036418914155667
# Number of valid samples: 19946
# Sample failed checks. vx^2+vy^2+vz^2: 1.0494437323784316, wtemp_expr: -0.054201537456582516, sdet_expr: 0.9278971308294665
# Number of valid samples: 19946
# Sample failed checks. vx^2+vy^2+vz^2: 1.047548405708398, wtemp_expr: -0.1773132256242389, sdet_expr: 0.9114538724046759
# Number of valid samples: 19946
# Sample passed checks. vx^2+vy^2+vz^2: 0.131530788819132, wtemp_expr: 0.8757295812140886, sdet_expr: 0.8081682344071354
# Number of valid samples: 19947
# Sample failed checks. vx^2+vy^2+vz^2: 1.6582084410594828, wtemp_expr: -0.8117610886126625, sdet_expr: 1.0684205055035974
# Number of valid samples: 19947
# Sample failed checks. vx^2+vy^2+vz^2: 1.4278287044586664, wtemp_expr: -0.4665959553430641, sdet_expr: 0.8496487131918776
# Number of valid samples: 19947
# Sample failed checks. vx^2+vy^2+vz^2: 1.3926793148814667, wtemp_expr: -0.47920131263709465, sdet_expr: 0.9186897477115015
# Number of valid samples: 19947
# Sample failed checks. vx^2+vy^2+vz^2: 1.340839017198132, wtemp_expr: -0.3938721663705076, sdet_expr: 0.9421912778008151
# Number of valid samples: 19947
# Sample passed checks. vx^2+vy^2+vz^2: 0.22660926820671906, wtemp_expr: 0.756690059666067, sdet_expr: 1.0105805516533903
# Number of valid samples: 19948
# Sample passed checks. vx^2+vy^2+vz^2: 0.07207352198612005, wtemp_expr: 0.9222105418009602, sdet_expr: 0.9621582084004364
# Number of valid samples: 19949
# Sample passed checks. vx^2+vy^2+vz^2: 0.4338189458205147, wtemp_expr: 0.5285392198058432, sdet_expr: 0.9785090369638656
# Number of valid samples: 19950
# Sample passed checks. vx^2+vy^2+vz^2: 0.7751307092565984, wtemp_expr: 0.1598065035517653, sdet_expr: 1.0834826224146246
# Number of valid samples: 19951
# Sample failed checks. vx^2+vy^2+vz^2: 1.012381962967097, wtemp_expr: -0.18724441207366382, sdet_expr: 1.272701096230115
# Number of valid samples: 19951
# Sample failed checks. vx^2+vy^2+vz^2: 1.6646246247398595, wtemp_expr: -0.8674712250946726, sdet_expr: 1.1698987748261587
# Number of valid samples: 19951
# Sample failed checks. vx^2+vy^2+vz^2: 2.6382175601984668, wtemp_expr: -2.0088992123247538, sdet_expr: 1.1710678219279178
# Number of valid samples: 19951
# Sample failed checks. vx^2+vy^2+vz^2: 1.5813408105491384, wtemp_expr: -0.5905258760151568, sdet_expr: 0.9412933592422568
# Number of valid samples: 19951
# Sample passed checks. vx^2+vy^2+vz^2: 0.03452955619006891, wtemp_expr: 0.9656987228486857, sdet_expr: 0.9616337396550578
# Number of valid samples: 19952
# Sample failed checks. vx^2+vy^2+vz^2: 1.0186558762355211, wtemp_expr: -0.16273023278567256, sdet_expr: 1.2003878698074715
# Number of valid samples: 19952
# Sample failed checks. vx^2+vy^2+vz^2: 1.2437746611118996, wtemp_expr: -0.291485113397264, sdet_expr: 0.9589632454651889
# Number of valid samples: 19952
# Sample passed checks. vx^2+vy^2+vz^2: 0.638647842625755, wtemp_expr: 0.2857417513594689, sdet_expr: 1.0504180798787637
# Number of valid samples: 19953
# Sample passed checks. vx^2+vy^2+vz^2: 0.5012850657425941, wtemp_expr: 0.522046390890436, sdet_expr: 0.852765049571225
# Number of valid samples: 19954
# Sample passed checks. vx^2+vy^2+vz^2: 0.9242812213484259, wtemp_expr: 0.06290160663969813, sdet_expr: 0.8838887812188831
# Number of valid samples: 19955
# Sample failed checks. vx^2+vy^2+vz^2: 1.7963080922849404, wtemp_expr: -0.9226036072832593, sdet_expr: 0.9672311513758249
# Number of valid samples: 19955
# Sample failed checks. vx^2+vy^2+vz^2: 1.2733262695400238, wtemp_expr: -0.4062713754206788, sdet_expr: 1.0951468076591777
# Number of valid samples: 19955
# Sample failed checks. vx^2+vy^2+vz^2: 1.551709399633371, wtemp_expr: -0.7017414774756134, sdet_expr: 1.07138723739877
# Number of valid samples: 19955
# Sample passed checks. vx^2+vy^2+vz^2: 0.9547896346499298, wtemp_expr: 0.01829152440813553, sdet_expr: 0.9009069321123965
# Number of valid samples: 19956
# Sample passed checks. vx^2+vy^2+vz^2: 0.9084038546584781, wtemp_expr: 0.12989429617115456, sdet_expr: 0.9227675843521452
# Number of valid samples: 19957
# Sample failed checks. vx^2+vy^2+vz^2: 1.215322470001011, wtemp_expr: -0.2940760261170521, sdet_expr: 0.9756806705910221
# Number of valid samples: 19957
# Sample failed checks. vx^2+vy^2+vz^2: 0.8943924863847337, wtemp_expr: -0.0305069055064775, sdet_expr: 0.9872739221559726
# Number of valid samples: 19957
# Sample passed checks. vx^2+vy^2+vz^2: 0.8929529899105854, wtemp_expr: 0.043803674237713364, sdet_expr: 0.977254024578085
# Number of valid samples: 19958
# Sample passed checks. vx^2+vy^2+vz^2: 0.23465489249049817, wtemp_expr: 0.7453117342294959, sdet_expr: 1.0343035808635186
# Number of valid samples: 19959
# Sample passed checks. vx^2+vy^2+vz^2: 0.32936267088367427, wtemp_expr: 0.6468909744520908, sdet_expr: 1.042841400686775
# Number of valid samples: 19960
# Sample passed checks. vx^2+vy^2+vz^2: 0.724299812083395, wtemp_expr: 0.22509723744854582, sdet_expr: 0.9134517161575457
# Number of valid samples: 19961
# Sample passed checks. vx^2+vy^2+vz^2: 0.6015048695451755, wtemp_expr: 0.34304095724094963, sdet_expr: 1.247362436754128
# Number of valid samples: 19962
# Sample passed checks. vx^2+vy^2+vz^2: 0.8156175332278766, wtemp_expr: 0.22225810614631825, sdet_expr: 0.9732704222208829
# Number of valid samples: 19963
# Sample failed checks. vx^2+vy^2+vz^2: 1.090601336496592, wtemp_expr: -0.22154266574025638, sdet_expr: 1.0584249948434636
# Number of valid samples: 19963
# Sample passed checks. vx^2+vy^2+vz^2: 0.33182363628807643, wtemp_expr: 0.675866232233642, sdet_expr: 0.9430030297867433
# Number of valid samples: 19964
# Sample failed checks. vx^2+vy^2+vz^2: 1.5290327400585797, wtemp_expr: -0.5246732976645474, sdet_expr: 0.8240496411019961
# Number of valid samples: 19964
# Sample failed checks. vx^2+vy^2+vz^2: 1.2679067393075107, wtemp_expr: -0.32860380532955347, sdet_expr: 0.8441147969201636
# Number of valid samples: 19964
# Sample passed checks. vx^2+vy^2+vz^2: 0.2249793502096499, wtemp_expr: 0.7331681934413523, sdet_expr: 1.1005830387627937
# Number of valid samples: 19965
# Sample passed checks. vx^2+vy^2+vz^2: 0.8287037178063537, wtemp_expr: 0.08324979593114123, sdet_expr: 0.9856537667725584
# Number of valid samples: 19966
# Sample failed checks. vx^2+vy^2+vz^2: 1.2381683204397063, wtemp_expr: -0.4216601685829453, sdet_expr: 1.1802067940895111
# Number of valid samples: 19966
# Sample failed checks. vx^2+vy^2+vz^2: 1.0764699342811954, wtemp_expr: -0.23955255510504925, sdet_expr: 1.0169421767426847
# Number of valid samples: 19966
# Sample failed checks. vx^2+vy^2+vz^2: 1.4600793323366221, wtemp_expr: -0.5217464206741038, sdet_expr: 0.9169302794931093
# Number of valid samples: 19966
# Sample passed checks. vx^2+vy^2+vz^2: 0.2355545389146873, wtemp_expr: 0.7553455233793278, sdet_expr: 0.872762203050653
# Number of valid samples: 19967
# Sample failed checks. vx^2+vy^2+vz^2: 2.3840326177244817, wtemp_expr: -1.6221158103127697, sdet_expr: 0.9763363315908321
# Number of valid samples: 19967
# Sample failed checks. vx^2+vy^2+vz^2: 1.7855891472920802, wtemp_expr: -1.0887056431528839, sdet_expr: 1.016208464348049
# Number of valid samples: 19967
# Sample failed checks. vx^2+vy^2+vz^2: 1.2275720460178592, wtemp_expr: -0.19674805469129986, sdet_expr: 0.9270489403628641
# Number of valid samples: 19967
# Sample passed checks. vx^2+vy^2+vz^2: 0.857933009780609, wtemp_expr: 0.054096233364908874, sdet_expr: 0.9739785573910167
# Number of valid samples: 19968
# Sample passed checks. vx^2+vy^2+vz^2: 0.8743827444988954, wtemp_expr: 0.13824294138733173, sdet_expr: 0.9969288168906649
# Number of valid samples: 19969
# Sample passed checks. vx^2+vy^2+vz^2: 0.5289396198394303, wtemp_expr: 0.4927362279098648, sdet_expr: 0.8820139151211703
# Number of valid samples: 19970
# Sample failed checks. vx^2+vy^2+vz^2: 1.8630325772384717, wtemp_expr: -0.9584067588695104, sdet_expr: 0.9043051151750983
# Number of valid samples: 19970
# Sample passed checks. vx^2+vy^2+vz^2: 0.9912467600101914, wtemp_expr: 0.04510236737721063, sdet_expr: 1.0307747757561367
# Number of valid samples: 19971
# Sample failed checks. vx^2+vy^2+vz^2: 1.1340228339180145, wtemp_expr: -0.22675880760457479, sdet_expr: 1.0792461618178584
# Number of valid samples: 19971
# Sample passed checks. vx^2+vy^2+vz^2: 0.755965374670521, wtemp_expr: 0.19172416095213551, sdet_expr: 0.9304867849846262
# Number of valid samples: 19972
# Sample failed checks. vx^2+vy^2+vz^2: 2.342606297553041, wtemp_expr: -1.643263048938476, sdet_expr: 0.9925054947840876
# Number of valid samples: 19972
# Sample passed checks. vx^2+vy^2+vz^2: 0.42326963675038176, wtemp_expr: 0.5540292991796361, sdet_expr: 1.004519800019896
# Number of valid samples: 19973
# Sample passed checks. vx^2+vy^2+vz^2: 0.49109686554630355, wtemp_expr: 0.4901619610085465, sdet_expr: 1.1105538652557794
# Number of valid samples: 19974
# Sample failed checks. vx^2+vy^2+vz^2: 1.0634149064229241, wtemp_expr: -0.17455402360905703, sdet_expr: 1.0739305966411796
# Number of valid samples: 19974
# Sample failed checks. vx^2+vy^2+vz^2: 1.1604765287163727, wtemp_expr: -0.16106967365462022, sdet_expr: 0.8587426745868579
# Number of valid samples: 19974
# Sample failed checks. vx^2+vy^2+vz^2: 1.1250119455317886, wtemp_expr: -0.2598402952300298, sdet_expr: 1.0991263665770543
# Number of valid samples: 19974
# Sample passed checks. vx^2+vy^2+vz^2: 0.8639653854432096, wtemp_expr: 0.09966039463986764, sdet_expr: 0.915490477975861
# Number of valid samples: 19975
# Sample passed checks. vx^2+vy^2+vz^2: 0.7807842342082888, wtemp_expr: 0.21012853520568087, sdet_expr: 1.130891206679403
# Number of valid samples: 19976
# Sample failed checks. vx^2+vy^2+vz^2: 1.520885607467917, wtemp_expr: -0.6654476330983385, sdet_expr: 1.1729403376090555
# Number of valid samples: 19976
# Sample passed checks. vx^2+vy^2+vz^2: 0.4856802742193994, wtemp_expr: 0.4969802398853207, sdet_expr: 0.9851715367365608
# Number of valid samples: 19977
# Sample passed checks. vx^2+vy^2+vz^2: 0.8238978634606707, wtemp_expr: 0.06189677053604603, sdet_expr: 0.985347337933394
# Number of valid samples: 19978
# Sample passed checks. vx^2+vy^2+vz^2: 0.6282602987952172, wtemp_expr: 0.3213612476460411, sdet_expr: 1.024982750648246
# Number of valid samples: 19979
# Sample failed checks. vx^2+vy^2+vz^2: 1.490268720888869, wtemp_expr: -0.7053483760108281, sdet_expr: 1.065393038383969
# Number of valid samples: 19979
# Sample passed checks. vx^2+vy^2+vz^2: 0.541325673449013, wtemp_expr: 0.4231500311495816, sdet_expr: 0.9460408452900193
# Number of valid samples: 19980
# Sample passed checks. vx^2+vy^2+vz^2: 0.634111161030799, wtemp_expr: 0.28807456847673185, sdet_expr: 1.1661087672712946
# Number of valid samples: 19981
# Sample passed checks. vx^2+vy^2+vz^2: 0.6425807757580642, wtemp_expr: 0.3414821283465187, sdet_expr: 1.0223850814206459
# Number of valid samples: 19982
# Sample passed checks. vx^2+vy^2+vz^2: 0.6239651110186031, wtemp_expr: 0.32106147240044525, sdet_expr: 0.9514842561500971
# Number of valid samples: 19983
# Sample passed checks. vx^2+vy^2+vz^2: 0.33743801898099995, wtemp_expr: 0.6633899928361582, sdet_expr: 0.8333083798850621
# Number of valid samples: 19984
# Sample failed checks. vx^2+vy^2+vz^2: 1.2586178470929659, wtemp_expr: -0.3188643343083766, sdet_expr: 0.9922084335482543
# Number of valid samples: 19984
# Sample passed checks. vx^2+vy^2+vz^2: 0.6324625737793613, wtemp_expr: 0.36007470095204697, sdet_expr: 1.0042882143861989
# Number of valid samples: 19985
# Sample passed checks. vx^2+vy^2+vz^2: 0.8893228287187335, wtemp_expr: 0.0758630737365944, sdet_expr: 1.0482128308942367
# Number of valid samples: 19986
# Sample passed checks. vx^2+vy^2+vz^2: 0.388015156305698, wtemp_expr: 0.6132811642927931, sdet_expr: 0.8245110047248055
# Number of valid samples: 19987
# Sample passed checks. vx^2+vy^2+vz^2: 0.8123305817119921, wtemp_expr: 0.14049293747654368, sdet_expr: 0.9729492567794118
# Number of valid samples: 19988
# Sample passed checks. vx^2+vy^2+vz^2: 0.32731225011259335, wtemp_expr: 0.6341456209909502, sdet_expr: 1.1093740204674243
# Number of valid samples: 19989
# Sample passed checks. vx^2+vy^2+vz^2: 0.03437785585868872, wtemp_expr: 0.963894766786362, sdet_expr: 1.0797463503702942
# Number of valid samples: 19990
# Sample passed checks. vx^2+vy^2+vz^2: 0.14622351707151873, wtemp_expr: 0.8616019897235975, sdet_expr: 0.8521828122645863
# Number of valid samples: 19991
# Sample passed checks. vx^2+vy^2+vz^2: 0.8322924872005609, wtemp_expr: 0.17857823821679997, sdet_expr: 1.1082219062764007
# Number of valid samples: 19992
# Sample passed checks. vx^2+vy^2+vz^2: 0.7183048476411094, wtemp_expr: 0.2404742308108554, sdet_expr: 1.0428103366001695
# Number of valid samples: 19993
# Sample passed checks. vx^2+vy^2+vz^2: 0.8671593370967898, wtemp_expr: 0.02403703296589854, sdet_expr: 1.1278582242926727
# Number of valid samples: 19994
# Sample passed checks. vx^2+vy^2+vz^2: 0.47668771780785546, wtemp_expr: 0.5229523818220694, sdet_expr: 0.9048142112596421
# Number of valid samples: 19995
# Sample passed checks. vx^2+vy^2+vz^2: 0.6271716588710696, wtemp_expr: 0.3754278320895591, sdet_expr: 1.057593113283887
# Number of valid samples: 19996
# Sample passed checks. vx^2+vy^2+vz^2: 0.8217756503269628, wtemp_expr: 0.09670544163711503, sdet_expr: 0.9049122058168995
# Number of valid samples: 19997
# Sample passed checks. vx^2+vy^2+vz^2: 0.7568041019819624, wtemp_expr: 0.1444987715395878, sdet_expr: 0.9687458243975688
# Number of valid samples: 19998
# Sample failed checks. vx^2+vy^2+vz^2: 1.5570435291948255, wtemp_expr: -0.6465313016623835, sdet_expr: 1.013533647062144
# Number of valid samples: 19998
# Sample failed checks. vx^2+vy^2+vz^2: 1.3026865126027622, wtemp_expr: -0.35915644504460187, sdet_expr: 0.8816678218381405
# Number of valid samples: 19998
# Sample passed checks. vx^2+vy^2+vz^2: 0.18178061583570654, wtemp_expr: 0.8135850156431114, sdet_expr: 0.9418919684648065
# Number of valid samples: 19999
# Sample passed checks. vx^2+vy^2+vz^2: 0.845365517576313, wtemp_expr: 0.04241842817849262, sdet_expr: 1.0419443444201004
# Number of valid samples: 20000

# %%
if not LOAD_DATA_FROM_CSV:
    # Generate data and labels.
    x_train = generate_input_data(rho_train, epsilon_train, vx_train, vy_train,
                                vz_train, Bx_train, By_train, Bz_train,
                                gxx_train,gxy_train,gxz_train,
                                gyy_train,gyz_train,gzz_train)
    y_train = generate_labels(rho_train, epsilon_train, vx_train, vy_train, vz_train)
    x_test = generate_input_data(rho_test, epsilon_test,vx_test,
                                vy_test,vz_test,Bx_test,
                                By_test,Bz_test,gxx_test,
                                gxy_test,gxz_test,
                                gyy_test,
                                gyz_test,gzz_test)
    y_test = generate_labels(rho_test, epsilon_test, vx_test, vy_test, vz_test)


    # Save the data to CSV files, tensors need to be converted numpy arrays for saving in CSV.
    pd.DataFrame(x_train.cpu().numpy()).to_csv(csv_filenames["x_train"], index=False)
    save_file(csv_filenames["x_train"])
    pd.DataFrame(y_train.cpu().numpy()).to_csv(csv_filenames["y_train"], index=False)
    save_file(csv_filenames["y_train"])
    pd.DataFrame(x_test.cpu().numpy()).to_csv(csv_filenames["x_test"], index=False)
    save_file(csv_filenames["x_test"])
    pd.DataFrame(y_test.cpu().numpy()).to_csv(csv_filenames["y_test"], index=False)
    save_file(csv_filenames["y_test"])
# Out:
# rho.shape:  torch.Size([80000])
# epsilon.shape:  torch.Size([80000])
# rho.shape:  torch.Size([80000])
# epsilon.shape:  torch.Size([80000])
# rho.shape:  torch.Size([20000])
# epsilon.shape:  torch.Size([20000])
# rho.shape:  torch.Size([20000])
# epsilon.shape:  torch.Size([20000])

# %%
x_train.shape
y_train.shape
x_test.shape
y_test.shape
x_train
y_train
x_test
y_test
# Out:
# tensor([  1.1569,   1.7467,   1.3334,  ...,   2.9477,  27.6700, 169.2676],
#        device='cuda:0')

# %%
torch.isnan(x_train).any()
torch.isnan(x_test).any()
torch.isnan(y_train).any()
torch.isnan(y_test).any()
# Out:
# tensor(False, device='cuda:0')

# %%
nan_mask_train = torch.isnan(x_train)     # get a boolean mask indicating NaN values
nan_indices_train = torch.where(nan_mask_train)  # get the indices of the NaN values
nan_indices_train
# len(nan_indices_train)

nan_mask_test = torch.isnan(x_test)     # get a boolean mask indicating NaN values
nan_indices_test = torch.where(nan_mask_train)  # get the indices of the NaN values
nan_indices_test
# len(nan_indices_test)
# Out:
# (tensor([], device='cuda:0', dtype=torch.int64),
#  tensor([], device='cuda:0', dtype=torch.int64))

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# ### Visualizing sampled data

# %%
if not LOAD_DATA_FROM_CSV:
    rho_train
    epsilon_train
    vx_train
    vy_train
    vz_train 
    Bx_train
    By_train
    Bz_train
    rho_test
    epsilon_test
    vx_test 
    vy_test 
    vz_test 
    Bx_test
    By_test
    Bz_test

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
if not LOAD_DATA_FROM_CSV:
    def plot_histogram(data, xlabel, ylabel, position, bins=20, log_scale=False):
        plt.subplot(4, 5, position)
        plt.hist(data, bins=bins)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        if log_scale:
            plt.yscale("log")

    # Plotting the histograms of rho, vx, epsilon, b0, b1, b2, and b3
    plt.figure(figsize=(20, 16))

    plot_histogram(rho_train, "rho", "Frequency", 1)
    plot_histogram(epsilon_train, "epsilon", "Frequency", 2)
    plot_histogram(vx_train, "vx", "Frequency", 3)
    plot_histogram(vy_train, "vy", "Frequency", 4)
    plot_histogram(vz_train, "vz", "Frequency", 5)
    plot_histogram(Bx_train, "Bx", "Frequency", 6)
    plot_histogram(By_train, "By", "Frequency", 7)
    plot_histogram(Bz_train, "Bz", "Frequency", 8)
    
    # Plot these
    plot_histogram(gxx_train, "gxx", "Frequency", 9)
    plot_histogram(gxy_train, "gxy", "Frequency", 10)
    plot_histogram(gxz_train, "gxz", "Frequency", 11)
    plot_histogram(gyy_train, "gyy", "Frequency", 12)
    plot_histogram(gyz_train, "gyz", "Frequency", 13)
    plot_histogram(gzz_train, "gzz", "Frequency", 14)
    # Adjust the layout as needed for the additional plots

    plt.suptitle("Primitive variables")
    plt.tight_layout()
    plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
if not LOAD_DATA_FROM_CSV:
    # List of variable names
    variable_names = ["D", "Sx", "Sy", "Sz", "tau", "Bconsx", "Bconsy", "Bconsz"]

    # Note how we are only plotting train and not test here. 
    # Plotting histograms of the input variables before z-score normalization
    plt.figure(figsize=(16, 16))
    plt.suptitle('Histograms of input variables before (or without at all) z-score normalization', y=1.03)
    for i in range(8):
        plt.subplot(4, 2, i+1)
        plt.hist(x_train[:, i].cpu(), bins=50) # Must be converted to cpu() for plotting.
        plt.xlabel(variable_names[i])
    plt.subplots_adjust(hspace=0.4, wspace=0.4)
    plt.show()

# %% [markdown]
# ### Data normalization

# %%
# Computing summary statistics of the input variables before and after z-score normalization
print('Summary statistics of input variables before z-score normalization')
print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.nanmean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))
# Out:
# Summary statistics of input variables before z-score normalization
# tensor([[ 1.5388e-07,  2.6438e+02,  2.2765e+00,  1.6756e+00,  3.5594e+00],
#         [-1.0548e+02,  1.0716e+07,  1.7637e+03,  4.8614e+01,  5.5278e+04],
#         [-1.0664e+02,  1.7318e+07,  1.9530e+03,  4.8294e+01,  7.9576e+04],
#         [-1.2383e+02,  6.2779e+06,  1.7316e+03,  4.8341e+01,  4.6098e+04],
#         [ 4.8285e-01,  1.7988e+07,  3.4638e+03,  1.1307e+02,  1.0296e+05],
#         [-1.1390e+01,  1.1213e+01, -7.3321e-03, -1.0816e-02,  5.7216e+00],
#         [-1.1276e+01,  1.1289e+01,  4.2612e-02,  8.8453e-02,  5.7317e+00],
#         [-1.1086e+01,  1.1305e+01,  9.2822e-03, -7.7466e-03,  5.7277e+00],
#         [ 9.0000e-01,  1.1000e+00,  9.9848e-01,  9.9761e-01,  5.7864e-02],
#         [ 6.6254e-07,  9.9999e-02,  4.9610e-02,  4.9404e-02,  2.8806e-02],
#         [ 9.1343e-07,  1.0000e-01,  4.9525e-02,  4.9293e-02,  2.8820e-02],
#         [ 9.0001e-01,  1.1000e+00,  9.9841e-01,  9.9768e-01,  5.7675e-02],
#         [ 2.5777e-06,  9.9998e-02,  4.9711e-02,  4.9631e-02,  2.8859e-02],
#         [ 9.0000e-01,  1.1000e+00,  9.9865e-01,  9.9761e-01,  5.7618e-02]],
#        device='cuda:0')

# %% [markdown]
# Perform z-score normalization

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
if ZSCORE_NORMALIZATION:
    
    # TODO: Add magnetic field variables to the normalization if I decide to use the old code that is commented out here.
    # # Computing the median of each input variable from the training set using torch.nanmedian function
    # D_median = torch.nanmedian(x_train[:, 0])
    # Sx_median = torch.nanmedian(x_train[:, 1])
    # Sy_median = torch.nanmedian(x_train[:, 2])
    # Sz_median = torch.nanmedian(x_train[:, 3])
    # tau_median = torch.nanmedian(x_train[:, 4])

    # # Computing the standard deviation of each input variable from the training set using torch.std function with a boolean mask to ignore nan values
    # D_std = torch.std(x_train[~torch.isnan(x_train[:, 0]), 0])
    # Sx_std = torch.std(x_train[~torch.isnan(x_train[:, 1]), 1])
    # Sy_std = torch.std(x_train[~torch.isnan(x_train[:, 2]), 2])
    # Sz_std = torch.std(x_train[~torch.isnan(x_train[:, 3]), 3])
    # tau_std = torch.std(x_train[~torch.isnan(x_train[:, 4]), 4])


    # # Applying z-score normalization to both train and test sets using the statistics from the training set
    # x_train[:, 0] = torch.sub(x_train[:, 0], D_median).div(D_std)
    # x_train[:, 1] = torch.sub(x_train[:, 1], Sx_median).div(Sx_std)
    # x_train[:, 2] = torch.sub(x_train[:, 2], Sy_median).div(Sy_std)
    # x_train[:, 3] = torch.sub(x_train[:, 3], Sz_median).div(Sz_std)
    # x_train[:, 4] = torch.sub(x_train[:, 4], tau_median).div(tau_std)

    # x_test[:, 0] = torch.sub(x_test[:, 0], D_median).div(D_std)
    # x_test[:, 1] = torch.sub(x_test[:, 1], Sx_median).div(Sx_std)
    # x_test[:, 2] = torch.sub(x_test[:, 2], Sy_median).div(Sy_std)
    # x_test[:, 3] = torch.sub(x_test[:, 3], Sz_median).div(Sz_std)
    # x_test[:, 4] = torch.sub(x_test[:, 4], tau_median).div(tau_std)

    # Computing the mean and standard deviation of each column
    mean = x_train.mean(dim=0)
    std = x_train.std(dim=0)

    # Applying z-score normalization
    x_train = (x_train - mean) / std
    # Use the same mean and std from the training data as we don't want test data leakage.
    x_test = (x_test - mean) / std

# %% [markdown]
# Plotting the histograms of the input data after normalization if z-score normalization was performed.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
if not LOAD_DATA_FROM_CSV:
    if ZSCORE_NORMALIZATION:
        # List of variable names
        variable_names = ["D", "Sx", "Sy", "Sz", "tau", "Bconsx", "Bconsy", "Bconsz"]

        # Note how we are only plotting train and not test here. 
        # Plotting histograms of the input variables before z-score normalization
        plt.figure(figsize=(16, 16))
        plt.suptitle('Histograms of input variables after z-score normalization', y=1.03)
        for i in range(8):
            plt.subplot(4, 2, i+1)
            plt.hist(x_train[:, i].cpu(), bins=50) # Must be converted to cpu() for plotting.
            plt.xlabel(variable_names[i])
        plt.subplots_adjust(hspace=0.4, wspace=0.4)
        plt.show()

# %%
if ZSCORE_NORMALIZATION:
    # Computing summary statistics of the input variables after z-score normalization
    print('Summary statistics of input variables after z-score normalization')
    print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.mean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))

# %% [markdown]
# ### Visualizing input data and labels

# %%
x_train
y_train
x_test
y_test
# Out:
# tensor([  1.1569,   1.7467,   1.3334,  ...,   2.9477,  27.6700, 169.2676],
#        device='cuda:0')

# %% [markdown]
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors

# %%
# Note how we are only plotting train.
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(N_INPUTS, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, N_INPUTS).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Adding an assertion to check that the input tensor has the expected shape and type
        assert isinstance(x, torch.Tensor), "x must be a torch.Tensor"
        assert x.shape[1] == N_INPUTS, f"x must have shape (batch_size, {N_INPUTS})"

        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if OPTIMIZE:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 2, 6)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 2048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            #"hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
            #"hidden_activation", ["ReLU", "LeakyReLU"]
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            #"output_activation", ["ReLU", "Softplus", "Linear"]
            "output_activation", ["ReLU", "Linear"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 

        batch_size_list = [32, 48, 64, 96, 128, 256, 512, 1048]
        batch_size = trial.suggest_categorical("batch_size", batch_size_list)
        #batch_size = trial.suggest_int("batch_size", 64, 1048)
        n_epochs = trial.suggest_int("n_epochs", 100, 300) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            # ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
            ["CosineAnnealingLR", "ReduceLROnPlateau", "StepLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if OPTIMIZE:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.9, 0.999)
            beta2 = trial.suggest_uniform("beta2", 0.999, 0.9999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.1, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            if n_epochs < 150:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.1, 0.3)
            elif n_epochs > 250:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.05, 0.1)
            else:
                t_max_fraction = trial.suggest_uniform('t_max_fraction', 0.1, 0.2)

            T_max = int(n_epochs * t_max_fraction)
            eta_min = trial.suggest_loguniform("eta_min", 1e-7, 1e-2)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min=eta_min)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.5)
            patience = trial.suggest_int("patience", 5, 10)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer)
        elif scheduler_name == "ReduceLROnPlateau":
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        else:
            scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: SmoothL1Loss()
# batch_size: 49
# n_epochs: 100
# scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7fcf636cece0>
# loss_name: Huber
# optimizer_name: RMSprop
# scheduler_name: ReduceLROnPlateau
# n_units: [555, 458, 115]
# n_layers: 3
# hidden_activation: ReLU()
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 548.2065, Test Loss: 584.6292, Train L1 Norm: 1.4774, Test L1 Norm: 2.3872, Train Linf Norm: 12.5862, Test Linf Norm: 21.5394
# Epoch 2: Train Loss: 517.2170, Test Loss: 572.9773, Train L1 Norm: 1.7434, Test L1 Norm: 2.3662, Train Linf Norm: 15.1362, Test Linf Norm: 27.4336
# Epoch 3: Train Loss: 518.2830, Test Loss: 475.2647, Train L1 Norm: 1.8472, Test L1 Norm: 1.1398, Train Linf Norm: 19.0604, Test Linf Norm: 8.3718
# Epoch 4: Train Loss: 526.3735, Test Loss: 448.7778, Train L1 Norm: 1.9021, Test L1 Norm: 1.1948, Train Linf Norm: 23.1257, Test Linf Norm: 11.4032
# Epoch 5: Train Loss: 467.8267, Test Loss: 405.7226, Train L1 Norm: 1.6149, Test L1 Norm: 1.8397, Train Linf Norm: 19.7468, Test Linf Norm: 26.0295
# Epoch 6: Train Loss: 470.5045, Test Loss: 483.3185, Train L1 Norm: 1.4895, Test L1 Norm: 2.1759, Train Linf Norm: 17.1208, Test Linf Norm: 31.8483
# Epoch 7: Train Loss: 459.3054, Test Loss: 436.9314, Train L1 Norm: 1.4935, Test L1 Norm: 0.9639, Train Linf Norm: 16.7600, Test Linf Norm: 3.9352
# Epoch 8: Train Loss: 444.8097, Test Loss: 434.3234, Train L1 Norm: 1.4381, Test L1 Norm: 1.1066, Train Linf Norm: 14.7043, Test Linf Norm: 12.2419
# Epoch 9: Train Loss: 486.8644, Test Loss: 381.5099, Train L1 Norm: 1.2894, Test L1 Norm: 1.8188, Train Linf Norm: 12.2643, Test Linf Norm: 21.4703
# Epoch 10: Train Loss: 388.8459, Test Loss: 376.1841, Train L1 Norm: 1.3553, Test L1 Norm: 1.2830, Train Linf Norm: 13.7696, Test Linf Norm: 16.2899
# Epoch 11: Train Loss: 405.1426, Test Loss: 417.1062, Train L1 Norm: 1.1968, Test L1 Norm: 0.8917, Train Linf Norm: 10.9573, Test Linf Norm: 1.1907
# Epoch 12: Train Loss: 392.3563, Test Loss: 484.2707, Train L1 Norm: 1.1773, Test L1 Norm: 1.8460, Train Linf Norm: 10.5028, Test Linf Norm: 26.3089
# Epoch 13: Train Loss: 425.3334, Test Loss: 452.2117, Train L1 Norm: 1.1280, Test L1 Norm: 1.3407, Train Linf Norm: 8.6727, Test Linf Norm: 13.4026
# Epoch 14: Train Loss: 444.2305, Test Loss: 364.8106, Train L1 Norm: 1.2826, Test L1 Norm: 0.8989, Train Linf Norm: 11.5723, Test Linf Norm: 4.7873
# Epoch 15: Train Loss: 398.1173, Test Loss: 379.8794, Train L1 Norm: 1.1481, Test L1 Norm: 0.8907, Train Linf Norm: 10.4507, Test Linf Norm: 4.2666
# Epoch 16: Train Loss: 394.3970, Test Loss: 378.7280, Train L1 Norm: 1.1019, Test L1 Norm: 1.2233, Train Linf Norm: 9.0769, Test Linf Norm: 13.6383
# Epoch 17: Train Loss: 371.5215, Test Loss: 418.8170, Train L1 Norm: 1.1082, Test L1 Norm: 0.8864, Train Linf Norm: 9.8162, Test Linf Norm: 1.3574
# Epoch 18: Train Loss: 367.4785, Test Loss: 417.8101, Train L1 Norm: 1.1246, Test L1 Norm: 1.3733, Train Linf Norm: 10.6177, Test Linf Norm: 18.8736
# Epoch 19: Train Loss: 392.5194, Test Loss: 859.3922, Train L1 Norm: 1.1156, Test L1 Norm: 1.5709, Train Linf Norm: 9.9900, Test Linf Norm: 27.4863
# Epoch 20: Train Loss: 360.8481, Test Loss: 324.2120, Train L1 Norm: 1.0962, Test L1 Norm: 1.4995, Train Linf Norm: 10.0164, Test Linf Norm: 18.8837
# Epoch 21: Train Loss: 345.4823, Test Loss: 369.9682, Train L1 Norm: 1.1038, Test L1 Norm: 0.9333, Train Linf Norm: 10.6164, Test Linf Norm: 6.6415
# Epoch 22: Train Loss: 421.9413, Test Loss: 364.5192, Train L1 Norm: 1.1556, Test L1 Norm: 1.0801, Train Linf Norm: 11.2997, Test Linf Norm: 11.1072
# Epoch 23: Train Loss: 407.2198, Test Loss: 425.3272, Train L1 Norm: 1.0880, Test L1 Norm: 1.2697, Train Linf Norm: 9.7712, Test Linf Norm: 13.3750
# Epoch 24: Train Loss: 370.1762, Test Loss: 352.6359, Train L1 Norm: 1.1381, Test L1 Norm: 1.1179, Train Linf Norm: 11.1141, Test Linf Norm: 10.8516
# Epoch 25: Train Loss: 410.8047, Test Loss: 369.8802, Train L1 Norm: 1.0744, Test L1 Norm: 0.9802, Train Linf Norm: 9.2678, Test Linf Norm: 7.0550
# Epoch 26: Train Loss: 374.4314, Test Loss: 337.7533, Train L1 Norm: 1.1118, Test L1 Norm: 0.9366, Train Linf Norm: 10.2307, Test Linf Norm: 6.8626
# Epoch 27: Train Loss: 371.7574, Test Loss: 352.5113, Train L1 Norm: 1.0592, Test L1 Norm: 1.2854, Train Linf Norm: 9.2030, Test Linf Norm: 14.5713
# Epoch 28: Train Loss: 386.2164, Test Loss: 346.0456, Train L1 Norm: 1.1172, Test L1 Norm: 1.1001, Train Linf Norm: 10.6830, Test Linf Norm: 10.5390
# Epoch 29: Train Loss: 357.0225, Test Loss: 364.8954, Train L1 Norm: 1.0739, Test L1 Norm: 1.1432, Train Linf Norm: 9.5785, Test Linf Norm: 12.1744
# Epoch 30: Train Loss: 375.4026, Test Loss: 370.9078, Train L1 Norm: 1.0685, Test L1 Norm: 1.1213, Train Linf Norm: 9.8005, Test Linf Norm: 12.4826
# Epoch 31: Train Loss: 392.5049, Test Loss: 341.2478, Train L1 Norm: 1.0751, Test L1 Norm: 0.9284, Train Linf Norm: 9.9613, Test Linf Norm: 7.4643
# Epoch 32: Train Loss: 350.5432, Test Loss: 370.2199, Train L1 Norm: 1.0209, Test L1 Norm: 1.0242, Train Linf Norm: 8.7885, Test Linf Norm: 8.8765
# Epoch 33: Train Loss: 298.7454, Test Loss: 284.6346, Train L1 Norm: 0.9950, Test L1 Norm: 0.9767, Train Linf Norm: 8.9664, Test Linf Norm: 8.5880
# Epoch 34: Train Loss: 294.6470, Test Loss: 283.6433, Train L1 Norm: 1.0282, Test L1 Norm: 1.0213, Train Linf Norm: 10.3416, Test Linf Norm: 9.9456
# Epoch 35: Train Loss: 294.8249, Test Loss: 281.9961, Train L1 Norm: 1.0054, Test L1 Norm: 1.0620, Train Linf Norm: 9.6484, Test Linf Norm: 11.0929
# Epoch 36: Train Loss: 295.1745, Test Loss: 283.2852, Train L1 Norm: 1.0016, Test L1 Norm: 0.9742, Train Linf Norm: 9.6181, Test Linf Norm: 8.9478
# Epoch 37: Train Loss: 285.3295, Test Loss: 292.8986, Train L1 Norm: 1.0227, Test L1 Norm: 1.0450, Train Linf Norm: 10.0770, Test Linf Norm: 11.0203
# Epoch 38: Train Loss: 287.1804, Test Loss: 300.3805, Train L1 Norm: 1.0157, Test L1 Norm: 0.9424, Train Linf Norm: 10.0402, Test Linf Norm: 7.3449
# Epoch 39: Train Loss: 293.8996, Test Loss: 291.5211, Train L1 Norm: 1.0164, Test L1 Norm: 0.9059, Train Linf Norm: 9.9948, Test Linf Norm: 6.2167
# Epoch 40: Train Loss: 289.9817, Test Loss: 272.3390, Train L1 Norm: 1.0061, Test L1 Norm: 1.0152, Train Linf Norm: 9.7823, Test Linf Norm: 10.0619
# Epoch 41: Train Loss: 279.8006, Test Loss: 275.6268, Train L1 Norm: 1.0103, Test L1 Norm: 1.0463, Train Linf Norm: 10.0814, Test Linf Norm: 11.1841
# Epoch 42: Train Loss: 282.6257, Test Loss: 302.2242, Train L1 Norm: 1.0073, Test L1 Norm: 1.0258, Train Linf Norm: 10.0429, Test Linf Norm: 10.8662
# Epoch 43: Train Loss: 279.1001, Test Loss: 305.7069, Train L1 Norm: 1.0005, Test L1 Norm: 1.1693, Train Linf Norm: 9.7451, Test Linf Norm: 14.7008
# Epoch 44: Train Loss: 272.1065, Test Loss: 269.4590, Train L1 Norm: 0.9890, Test L1 Norm: 0.9900, Train Linf Norm: 9.4971, Test Linf Norm: 9.3363
# Epoch 45: Train Loss: 280.3748, Test Loss: 322.5994, Train L1 Norm: 0.9889, Test L1 Norm: 1.1162, Train Linf Norm: 9.4398, Test Linf Norm: 13.6417
# Epoch 46: Train Loss: 282.1429, Test Loss: 272.9080, Train L1 Norm: 0.9857, Test L1 Norm: 1.0636, Train Linf Norm: 9.3793, Test Linf Norm: 11.8136
# Epoch 47: Train Loss: 274.4785, Test Loss: 285.9191, Train L1 Norm: 0.9958, Test L1 Norm: 1.0424, Train Linf Norm: 9.5732, Test Linf Norm: 10.9541
# Epoch 48: Train Loss: 271.2193, Test Loss: 273.9450, Train L1 Norm: 0.9824, Test L1 Norm: 1.0057, Train Linf Norm: 9.2467, Test Linf Norm: 10.0917
# Epoch 49: Train Loss: 277.6332, Test Loss: 282.4808, Train L1 Norm: 0.9773, Test L1 Norm: 0.9563, Train Linf Norm: 9.2183, Test Linf Norm: 8.3897
# Epoch 50: Train Loss: 273.9227, Test Loss: 270.8359, Train L1 Norm: 0.9813, Test L1 Norm: 1.0667, Train Linf Norm: 9.4038, Test Linf Norm: 11.7071
# Epoch 51: Train Loss: 275.7185, Test Loss: 268.0623, Train L1 Norm: 0.9677, Test L1 Norm: 0.9522, Train Linf Norm: 8.9396, Test Linf Norm: 8.2594
# Epoch 52: Train Loss: 272.6718, Test Loss: 263.9037, Train L1 Norm: 0.9675, Test L1 Norm: 0.9464, Train Linf Norm: 8.8046, Test Linf Norm: 8.0648
# Epoch 53: Train Loss: 276.0657, Test Loss: 284.2523, Train L1 Norm: 0.9605, Test L1 Norm: 1.0196, Train Linf Norm: 8.5866, Test Linf Norm: 10.2328
# Epoch 54: Train Loss: 276.7625, Test Loss: 264.5578, Train L1 Norm: 0.9649, Test L1 Norm: 0.9848, Train Linf Norm: 8.7800, Test Linf Norm: 9.4741
# Epoch 55: Train Loss: 282.4391, Test Loss: 280.1663, Train L1 Norm: 0.9596, Test L1 Norm: 1.0915, Train Linf Norm: 8.5944, Test Linf Norm: 13.0063
# Epoch 56: Train Loss: 285.6597, Test Loss: 268.7607, Train L1 Norm: 0.9625, Test L1 Norm: 1.0156, Train Linf Norm: 8.8040, Test Linf Norm: 10.3284
# Epoch 57: Train Loss: 277.4828, Test Loss: 260.8090, Train L1 Norm: 0.9599, Test L1 Norm: 0.9870, Train Linf Norm: 8.6662, Test Linf Norm: 9.3571
# Epoch 58: Train Loss: 274.2184, Test Loss: 261.1265, Train L1 Norm: 0.9630, Test L1 Norm: 0.9265, Train Linf Norm: 8.7662, Test Linf Norm: 7.4584
# Epoch 59: Train Loss: 280.6215, Test Loss: 308.2798, Train L1 Norm: 0.9614, Test L1 Norm: 0.9850, Train Linf Norm: 8.4999, Test Linf Norm: 10.0200
# Epoch 60: Train Loss: 264.2685, Test Loss: 272.1128, Train L1 Norm: 0.9686, Test L1 Norm: 1.0942, Train Linf Norm: 8.9817, Test Linf Norm: 12.9238
# Epoch 61: Train Loss: 290.4151, Test Loss: 291.2328, Train L1 Norm: 0.9512, Test L1 Norm: 0.9370, Train Linf Norm: 8.2597, Test Linf Norm: 7.2692
# Epoch 62: Train Loss: 263.0983, Test Loss: 253.1483, Train L1 Norm: 0.9687, Test L1 Norm: 0.9300, Train Linf Norm: 8.9635, Test Linf Norm: 7.6195
# Epoch 63: Train Loss: 276.4682, Test Loss: 296.5076, Train L1 Norm: 0.9497, Test L1 Norm: 0.9126, Train Linf Norm: 8.2360, Test Linf Norm: 6.1666
# Epoch 64: Train Loss: 266.5496, Test Loss: 293.9245, Train L1 Norm: 0.9553, Test L1 Norm: 0.9092, Train Linf Norm: 8.3869, Test Linf Norm: 6.1883
# Epoch 65: Train Loss: 263.3354, Test Loss: 264.8021, Train L1 Norm: 0.9527, Test L1 Norm: 0.9914, Train Linf Norm: 8.2841, Test Linf Norm: 9.5405
# Epoch 66: Train Loss: 272.7410, Test Loss: 256.4135, Train L1 Norm: 0.9495, Test L1 Norm: 0.9840, Train Linf Norm: 8.3474, Test Linf Norm: 9.6712
# Epoch 67: Train Loss: 266.7171, Test Loss: 253.6316, Train L1 Norm: 0.9505, Test L1 Norm: 0.9427, Train Linf Norm: 8.1880, Test Linf Norm: 7.9160
# Epoch 68: Train Loss: 264.1151, Test Loss: 257.2414, Train L1 Norm: 0.9544, Test L1 Norm: 0.9447, Train Linf Norm: 8.4195, Test Linf Norm: 8.3828
# Epoch 69: Train Loss: 275.7158, Test Loss: 246.1378, Train L1 Norm: 0.9559, Test L1 Norm: 0.9140, Train Linf Norm: 8.4502, Test Linf Norm: 6.9764
# Epoch 70: Train Loss: 265.3509, Test Loss: 261.3970, Train L1 Norm: 0.9490, Test L1 Norm: 1.0361, Train Linf Norm: 8.1388, Test Linf Norm: 11.1222
# Epoch 71: Train Loss: 260.4527, Test Loss: 247.3517, Train L1 Norm: 0.9476, Test L1 Norm: 0.9679, Train Linf Norm: 8.3223, Test Linf Norm: 9.0242
# Epoch 72: Train Loss: 259.3199, Test Loss: 318.3820, Train L1 Norm: 0.9411, Test L1 Norm: 1.0824, Train Linf Norm: 7.9072, Test Linf Norm: 13.0623
# Epoch 73: Train Loss: 281.2847, Test Loss: 282.5430, Train L1 Norm: 0.9557, Test L1 Norm: 1.0337, Train Linf Norm: 8.4084, Test Linf Norm: 11.4817
# Epoch 74: Train Loss: 257.9491, Test Loss: 277.2083, Train L1 Norm: 0.9421, Test L1 Norm: 0.8745, Train Linf Norm: 7.9977, Test Linf Norm: 4.4131
# Epoch 75: Train Loss: 280.1984, Test Loss: 299.2326, Train L1 Norm: 0.9548, Test L1 Norm: 0.9611, Train Linf Norm: 8.4255, Test Linf Norm: 8.1184
# Epoch 76: Train Loss: 262.0708, Test Loss: 258.9505, Train L1 Norm: 0.9541, Test L1 Norm: 1.0160, Train Linf Norm: 8.4710, Test Linf Norm: 10.9834
# Epoch 77: Train Loss: 250.5937, Test Loss: 312.7531, Train L1 Norm: 0.9505, Test L1 Norm: 1.0244, Train Linf Norm: 8.4184, Test Linf Norm: 11.2803
# Epoch 78: Train Loss: 256.5486, Test Loss: 247.4018, Train L1 Norm: 0.9532, Test L1 Norm: 0.9367, Train Linf Norm: 8.5270, Test Linf Norm: 7.6825
# Epoch 79: Train Loss: 261.0601, Test Loss: 282.5240, Train L1 Norm: 0.9605, Test L1 Norm: 0.9783, Train Linf Norm: 8.8127, Test Linf Norm: 9.6952
# Epoch 80: Train Loss: 258.5851, Test Loss: 271.2165, Train L1 Norm: 0.9509, Test L1 Norm: 0.9277, Train Linf Norm: 8.4429, Test Linf Norm: 7.1205
# Epoch 81: Train Loss: 271.1278, Test Loss: 247.0413, Train L1 Norm: 0.9472, Test L1 Norm: 0.9382, Train Linf Norm: 8.1542, Test Linf Norm: 7.9289
# Epoch 82: Train Loss: 233.1697, Test Loss: 243.3617, Train L1 Norm: 0.9465, Test L1 Norm: 0.9566, Train Linf Norm: 8.5709, Test Linf Norm: 8.7859
# Epoch 83: Train Loss: 233.8198, Test Loss: 256.7179, Train L1 Norm: 0.9498, Test L1 Norm: 0.9780, Train Linf Norm: 8.5766, Test Linf Norm: 9.6788
# Epoch 84: Train Loss: 232.6244, Test Loss: 257.3593, Train L1 Norm: 0.9471, Test L1 Norm: 0.9610, Train Linf Norm: 8.5844, Test Linf Norm: 9.1113
# Epoch 85: Train Loss: 230.3444, Test Loss: 243.6040, Train L1 Norm: 0.9483, Test L1 Norm: 0.9654, Train Linf Norm: 8.5672, Test Linf Norm: 9.1661
# Epoch 86: Train Loss: 234.8914, Test Loss: 254.2922, Train L1 Norm: 0.9440, Test L1 Norm: 0.9583, Train Linf Norm: 8.3815, Test Linf Norm: 8.9584
# Epoch 87: Train Loss: 233.0988, Test Loss: 254.0821, Train L1 Norm: 0.9444, Test L1 Norm: 0.9799, Train Linf Norm: 8.4157, Test Linf Norm: 9.7769
# Epoch 88: Train Loss: 229.4623, Test Loss: 257.1393, Train L1 Norm: 0.9454, Test L1 Norm: 0.9836, Train Linf Norm: 8.4869, Test Linf Norm: 9.8956
# Epoch 89: Train Loss: 228.6737, Test Loss: 247.0014, Train L1 Norm: 0.9472, Test L1 Norm: 0.9637, Train Linf Norm: 8.4486, Test Linf Norm: 9.1242
# Epoch 90: Train Loss: 231.2359, Test Loss: 258.6974, Train L1 Norm: 0.9462, Test L1 Norm: 0.9939, Train Linf Norm: 8.5257, Test Linf Norm: 10.2948
# Epoch 91: Train Loss: 226.8110, Test Loss: 257.6338, Train L1 Norm: 0.9438, Test L1 Norm: 0.9898, Train Linf Norm: 8.4129, Test Linf Norm: 10.1481
# Epoch 92: Train Loss: 228.8770, Test Loss: 248.3692, Train L1 Norm: 0.9446, Test L1 Norm: 0.9586, Train Linf Norm: 8.4142, Test Linf Norm: 8.9668
# Epoch 93: Train Loss: 227.8855, Test Loss: 240.4940, Train L1 Norm: 0.9416, Test L1 Norm: 0.9493, Train Linf Norm: 8.3644, Test Linf Norm: 8.4131
# Epoch 94: Train Loss: 231.9188, Test Loss: 253.8535, Train L1 Norm: 0.9398, Test L1 Norm: 0.9939, Train Linf Norm: 8.3415, Test Linf Norm: 10.2582
# Epoch 95: Train Loss: 225.1555, Test Loss: 256.6856, Train L1 Norm: 0.9395, Test L1 Norm: 0.9848, Train Linf Norm: 8.1261, Test Linf Norm: 9.8799
# Epoch 96: Train Loss: 225.3496, Test Loss: 244.0473, Train L1 Norm: 0.9413, Test L1 Norm: 0.9728, Train Linf Norm: 8.2994, Test Linf Norm: 9.4845
# Epoch 97: Train Loss: 229.6377, Test Loss: 244.5334, Train L1 Norm: 0.9365, Test L1 Norm: 0.9594, Train Linf Norm: 8.0194, Test Linf Norm: 8.9878
# Epoch 98: Train Loss: 226.3394, Test Loss: 248.5020, Train L1 Norm: 0.9376, Test L1 Norm: 0.9501, Train Linf Norm: 8.3044, Test Linf Norm: 8.6452
# Epoch 99: Train Loss: 225.9216, Test Loss: 240.8636, Train L1 Norm: 0.9361, Test L1 Norm: 0.9539, Train Linf Norm: 8.1095, Test Linf Norm: 8.6890
# Epoch 100: Train Loss: 226.5919, Test Loss: 246.9141, Train L1 Norm: 0.9348, Test L1 Norm: 0.9802, Train Linf Norm: 8.1097, Test Linf Norm: 9.6997

# %% [markdown]
# ## Saving

# %%
import json

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel(f"{loss_name} Loss")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Huber Loss')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
if torch.cuda.is_available():
 net_loaded.load_state_dict(torch.load("net.pth"))
else: 
  net_loaded.load_state_dict(torch.load("net.pth", map_location=torch.device('cpu')))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if torch.cuda.is_available():
  optimizer_loaded_state_dict = torch.load("optimizer.pth")
else:
  optimizer_loaded_state_dict = torch.load("optimizer.pth", map_location=torch.device('cpu'))

if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
if torch.cuda.is_available():
  scheduler_loaded_state_dict = torch.load("scheduler.pth")
else: 
  scheduler_loaded_state_dict = torch.load("scheduler.pth", map_location=torch.device('cpu'))

if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
# %%script echo skipping
#
# batch_size_loaded
# n_epochs_loaded
# loss_name_loaded
# optimizer_name_loaded
# scheduler_name_loaded
# n_units_loaded
# n_layers_loaded
# hidden_activation_name_loaded
# output_activation_name_loaded
# lr_loaded
# hidden_activation_loaded
# output_activation_loaded
# net_loaded
# net_loaded.__dict__ # print the subparameters of the network
# loss_fn_loaded
# optimizer_loaded
# optimizer_loaded.__dict__ # print the subparameters of the optimizer
# scheduler_loaded
# scheduler_loaded.__dict__ # print the subparameters of the scheduler
# train_losses_loaded
# test_losses_loaded
# train_metrics_loaded
# test_metrics_loaded
# Out:
# skipping

# %%
train_losses_loaded[-1]
test_losses_loaded[-1]
test_metrics_loaded[-1]['l1_norm']
test_metrics_loaded[-1]['linf_norm']
# print(f'Error is {test_metrics_loaded[-1]["l1_norm"] / (3.84e-4)} times bigger than in Dieselhorst et al.')
# print(f'Error is {test_metrics_loaded[-1]["linf_norm"] / (8.14e-3)} times bigger than in Dieselhorst et al.')
# Out:
# 226.5919436307192
# 246.91413935012815
# 0.9801763912051916
# 9.699666531646251

# %% [markdown]
# ### Visualize loaded results

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel(f"{loss_name_loaded} Loss")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Counting the number of parameters in the network.

# %%
net_loaded.eval()
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'The model has {count_parameters(net_loaded)} parameters.')
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=14, out_features=555, bias=True)
#     (1): Linear(in_features=555, out_features=458, bias=True)
#     (2): Linear(in_features=458, out_features=115, bias=True)
#     (3): Linear(in_features=115, out_features=1, bias=True)
#   )
# )
# The model has 315874 parameters.

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network. Note that `net` is only available if we have trained the model in this session.

# %%
#%%script echo skipping

# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=14, out_features=555, bias=True)
#     (1): Linear(in_features=555, out_features=458, bias=True)
#     (2): Linear(in_features=458, out_features=115, bias=True)
#     (3): Linear(in_features=115, out_features=1, bias=True)
#   )
# )

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=14, out_features=555, bias=True)
#     (1): Linear(in_features=555, out_features=458, bias=True)
#     (2): Linear(in_features=458, out_features=115, bias=True)
#     (3): Linear(in_features=115, out_features=1, bias=True)
#   )
# )

# %%
for p1, p2 in zip(net.parameters(), net_loaded.parameters()):
    if p1.data.ne(p2.data).sum() > 0:
        print("Parameters are NOT the same.")
        break
else:
    print("Parameters are the same.")

print("Net device:", next(net.parameters()).device)
print("Net_loaded device:", next(net_loaded.parameters()).device)
# Out:
# Parameters are the same.
# Net device: cuda:0
# Net_loaded device: cuda:0

# %%
#%%script echo skipping

print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 4.1050e-02,  1.9603e-01,  9.6777e-02,  ...,  2.8215e-01,
#           4.0703e-02,  3.9409e-01],
#         [-6.8367e-01,  3.4413e-02,  1.4170e-01,  ..., -3.1643e+00,
#          -2.6953e+00, -2.8631e+00],
#         [ 5.4239e-01, -8.3570e-03,  1.6431e-01,  ...,  4.4285e+00,
#           4.3170e+00,  4.6899e+00],
#         ...,
#         [ 4.2832e-01,  1.1930e-01, -3.9769e-02,  ...,  3.5001e-01,
#           4.3247e-01,  5.6765e-01],
#         [-1.1551e+00,  1.1328e-01,  2.2663e-03,  ..., -2.9274e-01,
#          -3.0652e-01, -5.4950e-01],
#         [-1.4130e-01,  2.5240e-01, -1.3460e-01,  ...,  3.8761e+00,
#           3.4128e+00,  3.8459e+00]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 3.5904e-01, -3.1182e+00,  4.2534e+00,  1.0226e+00,  1.9655e-01,
#          3.2399e+00,  2.0238e-01,  3.2741e+00,  1.2169e+00, -1.6384e+00,
#          1.6121e-01, -3.5748e-01, -4.1241e+00,  2.5124e-01, -6.2314e-01,
#         -1.8455e-01, -1.5176e+00,  2.9082e+00,  3.6041e+00,  3.6817e+00,
#         -4.0140e+00, -2.0206e-01, -4.8076e+00,  1.4358e+00, -3.9434e+00,
#         -5.2306e-01, -3.7840e+00,  1.9816e-01,  2.9991e+00,  1.4844e+00,
#          3.8511e+00, -3.7418e+00,  2.3624e+00, -4.1954e+00, -4.9292e-02,
#          7.9872e-02, -3.3705e+00, -2.7997e+00, -1.1824e-01,  1.4538e-01,
#          4.0606e+00, -3.3838e-02, -4.7968e-01, -4.4537e+00,  1.9527e-01,
#          1.0451e+00, -3.2601e+00,  5.6103e-01,  5.2412e-01, -1.4295e+00,
#          4.9348e-03,  1.7306e+00,  3.1557e+00, -4.0070e+00,  2.3338e-01,
#         -4.2138e+00,  9.3188e-01, -1.9328e+00,  2.1359e-01, -3.9715e+00,
#          2.5154e+00, -4.1586e+00, -5.6031e-02,  1.9320e+00,  4.3945e+00,
#          3.2137e+00, -2.9377e+00,  3.5087e+00,  1.6485e+00,  1.7184e+00,
#          6.0026e-01, -3.8645e-01, -3.7178e+00,  4.7015e+00,  2.2203e+00,
#          3.7523e+00,  2.8049e+00, -2.7032e+00,  3.4756e-01,  1.7191e+00,
#         -4.6518e-01, -8.7621e-01,  2.6446e+00, -2.3808e-01,  3.6073e-01,
#         -2.2505e-01, -8.9447e-02,  2.9381e-01,  3.5160e+00,  2.4377e+00,
#         -3.1520e+00, -1.5578e-01,  9.0277e-02,  3.6823e-01, -6.5209e-01,
#         -4.2133e+00, -4.5227e+00, -9.2220e-02,  4.6812e+00,  4.7587e+00,
#          3.5290e-01, -1.7796e+00, -2.6732e+00,  3.0943e+00, -2.7967e+00,
#          3.1306e+00,  1.5982e+00,  6.2987e-01, -4.0545e+00, -3.9583e+00,
#          1.6689e+00, -3.9757e+00,  3.0259e+00, -2.1015e+00, -3.8799e+00,
#          1.0761e-01, -4.6352e+00,  3.9906e+00,  2.8415e-01,  2.4670e+00,
#         -5.4514e+00,  1.2740e+00,  1.8332e-01, -1.1458e-01,  2.5705e-02,
#         -4.0214e+00,  2.2087e+00,  1.5852e+00, -3.7391e+00,  4.5423e+00,
#         -2.3331e+00, -2.7441e-01,  2.5690e-01,  3.9894e+00, -1.2500e-01,
#          2.1824e+00, -1.0638e+00, -7.8495e-01,  3.7743e+00,  3.4127e+00,
#          4.5952e+00,  3.2561e-01, -2.4576e-01, -2.1957e+00, -4.2798e+00,
#         -3.6032e+00,  2.2933e+00,  3.4543e-01, -4.8769e+00,  2.0098e-01,
#          4.4630e-01,  3.2614e+00, -2.4447e+00,  3.6276e-01,  2.0158e+00,
#         -3.4410e+00,  1.8041e-01,  6.0058e-01,  1.2632e+00,  3.2623e+00,
#         -2.9928e+00, -4.2084e-01, -4.8934e+00,  1.8150e-01,  2.5793e-01,
#          2.9828e+00, -2.1330e-01, -8.7591e-02, -3.4671e+00, -4.2121e+00,
#          9.7877e-03, -1.4454e-01, -4.8316e+00, -2.8399e+00, -4.3703e+00,
#          1.1209e-01,  2.7916e+00, -4.0504e+00, -4.7479e+00,  3.4911e-01,
#         -3.3806e+00, -2.1502e+00, -4.0742e+00,  3.8256e+00,  2.2791e-02,
#         -2.4685e+00,  2.5600e-01, -2.1356e+00, -1.3173e-01,  2.8744e+00,
#         -7.2543e-02, -1.0853e+00, -4.4742e+00,  2.9960e+00, -8.4822e-01,
#         -2.3578e+00, -1.1881e-01, -4.9315e+00,  3.6515e+00, -8.8655e-02,
#         -2.3604e-01,  2.0891e+00,  4.3556e+00,  2.1794e+00, -3.7844e+00,
#         -6.0660e-01, -2.1996e-01,  4.4411e+00,  5.5517e-01, -5.0042e+00,
#          4.1112e-01,  8.8380e-01,  6.1396e-01, -4.0118e+00,  2.2190e+00,
#         -4.4873e+00,  7.8183e-01,  1.3362e-01, -6.1861e-02, -6.9819e-01,
#          2.0023e+00, -3.8020e-01,  1.1422e+00, -4.6409e-01,  8.9748e-01,
#          2.6448e-01,  7.3917e-01,  5.5416e-03,  3.1311e+00, -2.2163e+00,
#          6.0413e-02, -4.7584e+00, -3.6345e+00, -1.1249e-01, -1.8348e-01,
#          5.5701e-03, -4.7712e-01, -4.0431e+00,  1.1997e-01,  3.7272e+00,
#          4.9830e-01, -2.7773e+00,  7.6707e-03,  2.9879e-02,  3.5543e+00,
#         -3.7229e-01,  2.9408e+00,  4.3052e+00, -1.4418e-02, -1.5338e-01,
#         -4.5965e+00, -2.7094e-01, -1.3032e-01,  1.4798e+00,  2.6750e+00,
#         -2.1066e+00, -4.9572e+00,  1.3283e-01, -1.0642e+00, -8.7468e-01,
#          2.9113e+00,  2.1978e+00, -1.1299e+00,  1.3292e-01,  1.0465e+00,
#          2.3422e-01, -4.2253e+00,  2.6674e+00,  2.2364e-02, -2.3083e+00,
#         -7.1504e-01,  3.6689e-01, -4.3449e+00, -5.8290e-01,  2.7832e+00,
#          1.0568e+00, -3.3260e+00, -9.3932e-01,  1.8138e-01,  4.0577e+00,
#         -3.4477e+00,  3.8712e+00, -1.6797e-01, -5.4427e+00,  1.4030e-01,
#          3.8245e+00, -1.5466e+00,  3.8024e+00, -2.9990e+00,  2.1420e-01,
#          3.0800e+00, -3.4472e+00, -7.5360e-01, -4.1336e+00,  1.1949e+00,
#          6.2474e-02, -2.4820e+00,  2.2541e-01,  5.9291e-01,  2.5417e-01,
#          1.2886e+00,  2.4634e+00,  3.7048e+00, -2.3129e+00,  7.8000e-03,
#          1.1929e+00,  2.1736e+00,  3.0638e+00, -3.1728e+00,  3.3641e+00,
#          2.0664e+00,  3.3605e+00, -4.3452e+00,  3.5059e-01,  4.8263e+00,
#         -1.3977e+00, -1.8880e+00,  1.2733e-01,  4.2620e+00,  1.9020e-01,
#          1.3775e+00,  3.2514e+00,  9.1559e-01,  2.4396e+00, -1.8940e-01,
#         -2.7640e-02,  3.8117e+00, -2.3995e+00, -7.4128e-02, -2.1364e+00,
#         -1.3018e+00,  3.2829e+00, -3.8760e-01, -1.8792e+00, -4.7569e-02,
#         -5.6614e-02, -4.6725e-02,  2.6904e+00, -3.4989e+00, -3.9751e+00,
#         -2.1076e+00,  2.1116e-02,  8.1668e-01,  1.4718e+00, -4.6792e+00,
#          3.5747e+00,  1.6785e-01, -4.7830e+00, -3.1350e-01, -1.0019e+00,
#         -1.4011e+00, -3.5195e+00,  1.5703e+00,  2.7999e-01,  3.2181e+00,
#          4.3998e+00,  4.0852e-01,  3.3797e+00,  4.0693e+00,  3.5014e+00,
#          3.9766e+00,  1.8819e-01,  4.5462e+00,  3.0477e-01, -1.4014e+00,
#          4.0986e-01, -4.0164e+00, -6.6018e-01,  1.1360e-01,  3.7098e+00,
#         -1.5306e-01, -1.4947e+00, -5.3485e+00, -6.5598e-01,  3.3239e-01,
#         -1.5530e-01, -4.9973e+00, -1.9236e+00, -1.7221e+00, -4.8439e+00,
#          2.6071e-01,  3.1199e-01, -2.2448e+00, -1.6762e-01,  3.2415e+00,
#          3.1777e+00,  3.6952e+00,  1.5507e+00,  3.1799e+00,  1.3230e-02,
#         -4.6191e+00,  3.8918e+00, -2.8636e+00,  2.1656e-01,  1.0995e-01,
#          2.5468e-01,  2.3974e+00,  3.9842e-01,  3.3734e-01,  3.3151e+00,
#          1.9130e-01, -4.0995e+00, -1.2117e+00, -3.8296e+00,  3.7688e+00,
#         -3.0252e+00, -2.6577e+00,  3.7557e-01,  4.3605e+00,  2.3132e+00,
#         -6.9354e-01,  6.0595e-01,  2.6945e+00, -4.0794e+00, -6.8594e-01,
#         -4.4631e-02,  8.2388e-02,  6.4801e-01, -3.2842e-01, -4.7560e+00,
#          3.5260e-02,  7.6327e-01,  2.8147e-01, -1.5909e+00, -2.0173e+00,
#         -9.9931e-01, -5.2621e+00, -4.2997e+00, -1.5992e+00,  2.9173e+00,
#          2.8483e-01,  6.0041e-02,  4.6777e+00,  3.7960e+00,  5.2145e-01,
#         -2.2921e-01,  1.6237e+00, -1.5963e+00,  3.5495e-01, -4.6097e-01,
#          1.9253e+00, -2.2598e+00, -4.1150e+00,  3.2823e+00, -2.1500e+00,
#          1.0709e-01,  3.3673e+00,  4.2433e+00,  3.6282e+00, -3.1796e+00,
#          2.4059e+00,  1.1869e+00, -3.0182e+00,  7.1731e-02, -1.9698e+00,
#          1.1436e+00,  1.2953e+00, -1.5266e+00,  3.5737e+00,  4.6375e-01,
#         -1.8653e+00, -7.3341e-01,  8.6807e-01,  2.4045e+00,  2.8965e+00,
#          4.4667e+00,  6.8368e-01,  2.2410e+00,  4.6591e+00, -1.0423e-01,
#          3.4475e+00,  2.0004e-01,  3.5017e-01,  1.5238e-01,  1.7060e-01,
#          2.9784e+00,  1.7625e+00, -2.9404e-01, -2.4351e+00, -4.7217e-01,
#         -2.1215e-01,  3.3674e+00, -3.2186e+00, -3.0797e-01,  3.8227e+00,
#          8.9838e-01, -5.5523e-01, -1.4852e+00, -2.5596e+00,  1.5893e-01,
#          7.7457e-01,  1.2676e+00,  1.2071e+00,  1.7905e+00, -4.1330e+00,
#          8.0587e-01,  3.6985e+00,  2.4779e+00,  7.4354e-01, -3.9516e+00,
#          2.6774e+00,  2.9244e+00,  2.7713e+00,  3.6397e+00,  3.7137e+00,
#          1.6148e-01, -3.2658e+00, -4.5685e+00,  5.4384e-01, -1.4670e-01,
#         -4.7373e-02, -4.4591e+00,  3.1928e+00,  3.3017e+00,  4.3955e-01,
#         -3.2585e+00,  1.8372e-02, -3.7546e-02,  2.6924e-01, -4.9536e+00,
#          7.5177e-01, -9.0671e-02,  5.5882e-01,  2.2507e+00, -1.5184e+00,
#          1.1084e+00,  1.3132e-02,  3.0311e+00,  3.8570e+00, -8.0732e-01,
#         -4.7675e+00,  8.0799e-01, -6.8256e-01, -4.2643e+00, -4.4294e+00,
#          5.3629e-01, -3.2009e-02,  3.2583e+00, -1.4624e+00,  3.8092e-02,
#          4.0121e-01, -3.0891e+00, -8.1822e-01,  2.3778e+00,  8.9958e-02,
#         -4.2750e+00, -3.6791e+00, -2.9894e+00,  2.7303e+00,  2.8377e+00,
#          2.8715e+00, -4.7538e+00,  2.7044e-01, -3.7090e-01,  3.9011e+00],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0703,  0.0322,  0.0479,  ..., -0.0606,  0.0463, -0.0132],
#         [ 0.0412,  0.0046,  0.0359,  ...,  0.0119,  0.0274,  0.0115],
#         [-0.0284,  0.0095, -0.0753,  ..., -0.0289, -0.0141,  0.0021],
#         ...,
#         [-0.0558,  0.0463,  0.0298,  ..., -0.0026,  0.0130, -0.0489],
#         [-0.0069,  0.0115,  0.0232,  ..., -0.0014, -0.0048, -0.0220],
#         [-0.0222,  0.0193, -0.0241,  ..., -0.0411, -0.0387, -0.0295]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-1.4696e+00,  1.0518e+00,  4.0804e-01, -4.6497e-01,  4.5202e+00,
#         -1.5891e+00,  4.5508e+00, -1.1598e+00,  3.8798e+00,  1.6589e+00,
#         -3.0121e-02, -2.4171e-01,  2.2716e+00, -8.4091e-03, -2.3332e+00,
#          3.2252e-02,  2.0377e-01,  3.8513e+00,  2.8544e+00,  2.5033e+00,
#          2.6810e+00, -2.8135e+00, -1.1286e+00,  3.5573e+00,  2.5053e-02,
#          2.8622e-02, -1.0748e-01,  1.1656e-03,  3.8343e+00, -2.6431e+00,
#         -1.5213e+00,  2.7340e+00,  2.9861e-04,  2.6048e+00,  2.9332e+00,
#          1.3722e+00,  1.7441e-02,  4.1538e+00, -3.4754e+00,  3.0928e+00,
#         -4.9385e-01,  9.0878e-01,  4.8720e-01,  2.4245e+00, -9.7596e-01,
#          1.8658e+00,  2.7258e+00, -7.7269e-02,  3.3566e+00, -3.5399e-02,
#          3.7629e+00,  3.0013e+00, -3.6083e-02, -1.3816e+00, -2.4651e-01,
#          3.6058e+00, -2.3159e-02,  1.2132e+00,  2.6861e+00,  4.7573e-01,
#          1.9702e+00, -5.9951e-03,  1.7711e-02,  1.5579e-02, -1.7286e-01,
#         -2.4450e-03,  4.0928e+00, -1.2644e+00,  1.6737e+00,  3.4064e+00,
#          2.2963e+00,  8.1633e-01, -4.8767e-02,  2.4764e-02,  2.9320e-02,
#          1.2484e+00,  2.6695e+00,  3.2228e-02,  1.2378e-01, -5.8944e-04,
#         -5.2671e-01,  1.9498e-02, -3.0552e+00,  3.1018e-02, -5.1164e-02,
#         -1.7700e+00,  2.7234e+00, -1.0290e+00,  3.2634e-02,  4.1450e+00,
#          3.8839e+00,  4.2094e+00,  1.3093e+00,  2.6402e+00, -6.0499e-03,
#         -1.3895e+00, -1.9968e-02, -1.0641e+00,  2.1781e+00,  1.0932e-02,
#          3.3584e+00, -1.3974e-01,  3.9247e+00, -9.4456e-03,  2.5039e+00,
#         -2.7864e-02, -3.5980e+00,  3.7682e-02,  1.7826e+00, -2.0541e-02,
#          9.1540e-01,  1.7984e+00,  3.4148e-02,  2.0575e+00, -6.0625e-01,
#         -5.2230e-02,  3.6279e+00, -2.1087e-03,  2.1051e-01, -2.6760e-02,
#         -2.4284e+00,  2.3680e+00,  3.2718e+00,  6.7213e-01, -1.3682e-02,
#          3.5575e+00,  2.4540e-01,  4.0847e-02, -4.6712e-02, -2.7397e+00,
#          2.8344e+00,  3.0783e+00,  1.7366e+00,  1.0980e+00,  3.6980e+00,
#         -5.5949e-01,  1.0493e+00,  4.0827e-02,  5.8722e-01,  4.1214e+00,
#          4.4254e+00,  1.5707e-02,  8.4708e-03, -6.2636e-01,  3.3074e+00,
#          1.3278e-02,  2.5561e+00,  2.8028e+00,  3.7891e+00, -7.9040e-02,
#         -2.6392e+00,  3.1596e+00, -2.9967e+00, -8.3225e-02, -2.4761e-02,
#          3.2372e+00,  3.5391e+00,  8.2038e-01,  3.7228e-01,  4.4096e+00,
#          2.9454e+00,  5.9244e-01,  1.8632e+00,  3.5731e+00, -1.4704e+00,
#         -5.4063e-01, -3.6194e-01,  4.1290e+00, -3.1693e+00, -2.6258e+00,
#          3.7881e+00, -3.2880e+00,  1.6755e+00,  1.7117e+00,  3.6439e-02,
#          2.6192e+00,  1.6382e-02,  7.2660e-02,  2.4610e+00, -3.0323e+00,
#          1.9316e+00,  2.7689e-02, -7.7682e-01,  3.9402e+00,  4.2271e+00,
#          3.2134e+00, -1.6893e-01, -3.5827e-02, -1.2783e-02, -1.7969e-01,
#          3.2119e+00, -1.8283e-02,  4.0905e+00, -1.0215e+00, -1.1065e+00,
#          3.2702e+00,  3.6647e+00,  4.0009e-01,  1.3859e-02,  1.1392e+00,
#          1.5239e-02,  3.6429e-02, -4.5742e+00,  4.8254e-03,  7.8225e-01,
#          2.7571e+00, -1.3764e-02,  3.5198e+00,  3.5846e-02,  3.6254e+00,
#         -5.1392e-01, -6.8203e-01, -4.4106e-02,  2.4437e+00,  1.5426e+00,
#          3.1860e+00,  2.3718e+00,  1.6963e+00, -2.8701e+00,  3.5264e+00,
#          2.0998e+00, -2.0692e-02,  3.2485e+00,  2.9452e+00,  2.8135e+00,
#         -1.3503e+00, -4.5909e+00, -3.7242e-02,  3.6324e-02,  1.4945e-03,
#         -1.8779e-01,  4.0516e+00,  3.7812e+00,  2.9559e+00,  2.0991e+00,
#          1.9842e-01, -3.2406e-02,  2.8378e+00,  1.9369e+00,  2.6101e-01,
#         -4.1067e-02, -2.4764e-02,  3.4832e-01,  1.7050e-02,  2.2636e-02,
#         -3.4727e-03,  1.8906e-02, -1.6966e+00, -3.5258e-02, -1.1555e-01,
#          2.7690e+00,  4.4111e+00, -2.7655e-01,  1.3048e+00, -3.0974e-02,
#         -2.4978e+00, -1.7054e-02,  3.6228e+00,  3.5627e+00,  3.9096e+00,
#          6.1616e-03, -4.4970e+00,  2.8962e+00, -3.1642e+00,  3.3764e+00,
#         -4.0421e-03,  2.7845e+00,  3.3847e+00,  2.1282e+00,  1.1530e+00,
#          1.7176e-02, -1.9739e-02,  3.3251e+00,  3.2740e+00,  1.8523e+00,
#         -4.8579e-02,  4.6265e+00,  3.5298e-01,  1.9716e+00,  3.0271e+00,
#          2.0544e-02, -3.3298e+00, -3.4718e-01,  1.6338e+00,  3.7744e-01,
#          3.0003e-02, -2.6624e+00,  3.9536e+00, -4.8078e-01, -3.9747e+00,
#          3.1783e+00, -5.0802e-01, -3.5482e-02, -7.3591e-02,  3.2144e+00,
#         -1.4312e-01, -3.1271e-01,  2.5865e-02, -1.8166e+00,  2.0224e+00,
#         -2.1385e-02, -1.8597e-01,  3.7386e+00,  3.5223e+00,  1.9236e-01,
#         -1.3413e-02,  3.2667e+00,  2.8767e+00,  2.1843e+00, -3.1483e+00,
#          3.9120e+00,  4.2346e+00,  2.4725e-02, -3.5243e-02,  3.5472e+00,
#         -4.9625e-02,  2.6395e+00, -6.0243e-01,  3.9947e+00,  3.5596e+00,
#          2.8636e+00,  4.0577e-03,  1.7246e+00,  3.1733e+00, -2.2705e+00,
#          3.6707e+00,  2.4816e+00, -3.2238e-02,  3.6317e+00, -2.2176e-02,
#          6.7134e-01,  2.5081e+00,  2.6451e+00,  1.3608e+00,  3.1370e+00,
#          3.8482e+00, -8.5744e-01,  2.7404e-02, -1.7116e-01,  1.0384e+00,
#          3.1734e+00,  2.1528e+00, -6.6163e-01,  3.7256e+00,  1.3452e-02,
#         -1.2650e-01,  3.3537e+00, -3.6572e+00, -2.9604e+00,  3.5587e+00,
#          3.0557e+00,  2.7342e+00, -5.0762e-01,  4.2284e+00, -3.1475e-02,
#         -1.8235e-02,  1.7537e+00, -1.6282e-01,  3.5556e+00, -8.3477e-03,
#          3.6290e+00,  7.7072e-01,  1.8876e+00,  3.6381e+00,  4.2431e+00,
#          2.6234e+00,  2.9877e+00,  1.9604e-02, -3.4460e-02,  4.0026e+00,
#          3.1262e-02, -3.4263e-02, -9.0490e-02, -3.4576e-01,  2.4339e-02,
#         -1.3194e+00,  2.2950e+00,  3.0489e+00, -4.8289e-01,  2.7339e+00,
#         -3.5916e+00,  2.8491e+00, -7.2557e-01,  1.2750e-01, -4.4376e-01,
#         -3.5581e-02,  9.9891e-03, -3.7231e-01, -5.8921e-02,  3.1598e+00,
#         -5.8137e-01,  3.2045e-01, -3.0750e+00,  2.9461e+00,  3.3774e+00,
#          3.5521e+00, -5.0910e-01, -2.4636e-02,  2.3371e+00,  4.0250e+00,
#         -4.4034e-02,  1.5031e+00,  2.9668e+00, -3.5425e-02,  1.0949e+00,
#          2.4745e-02,  2.5024e+00, -3.3097e+00,  2.7011e+00, -1.5168e+00,
#          1.2565e-03,  3.4478e+00, -1.2765e+00,  2.1170e-02,  8.6263e-01,
#          1.5156e+00, -6.9772e-01,  2.7912e-03, -6.5404e-01,  3.3062e+00,
#         -3.8264e-02, -4.1182e+00, -3.3006e-02, -3.1862e+00,  9.0010e-01,
#          2.3601e+00,  3.2322e+00,  1.0549e+00,  3.3538e+00,  3.0203e+00,
#         -1.8498e-01,  3.9914e+00, -1.5167e-01,  2.6743e+00, -4.1419e-02,
#         -3.2160e+00,  3.1871e+00,  3.4432e+00,  2.9613e+00, -3.5509e-02,
#          2.2857e+00,  3.2329e+00, -4.5278e+00,  4.2691e+00, -2.2435e-02,
#          7.7323e-01, -3.5164e+00,  1.6062e-02,  4.1841e+00,  2.7788e+00,
#          1.1572e+00, -1.7999e-02,  3.5117e+00, -2.2706e+00, -9.8294e-01,
#         -8.4515e-01, -2.1702e+00, -3.2057e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0200,  0.0398, -0.0008,  ...,  0.0019,  0.0166,  0.0016],
#         [-0.0741, -0.0099,  0.0104,  ..., -0.0087,  0.0152, -0.0431],
#         [-0.0393, -0.0127,  0.0016,  ..., -0.0168, -0.0072, -0.0064],
#         ...,
#         [-0.0402,  0.0121, -0.0460,  ..., -0.0357,  0.0461,  0.0284],
#         [-0.0091, -0.0206, -0.0402,  ..., -0.0029, -0.0942, -0.0307],
#         [-0.1311, -0.0058, -0.0444,  ..., -0.0346, -0.0285,  0.0234]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 5.8339e-01,  3.4293e+00,  1.0623e-02,  2.9064e-02,  7.2754e-03,
#          2.6910e+00, -4.2043e-02,  3.2112e+00,  4.7285e-02, -4.1023e-02,
#         -3.8782e+00, -8.8753e-03,  1.0869e+00, -2.7027e-02,  3.4798e+00,
#          6.1904e-03,  5.7306e-02,  4.4049e-03,  1.7255e+00, -3.0609e-03,
#          3.4878e+00,  3.4225e+00,  3.3767e+00, -3.6757e-02, -1.4456e-01,
#          1.1749e-01,  3.3712e+00,  1.0202e-01, -4.3495e-02, -2.9462e-02,
#         -1.8617e-02, -1.3211e+00,  8.8531e-03, -2.0840e-02,  3.3490e+00,
#          3.4451e+00,  3.3793e+00,  3.0246e+00,  3.4366e+00,  3.3549e+00,
#          3.3381e+00, -4.7907e-02, -6.0141e-02,  3.1432e+00,  3.4117e+00,
#         -2.9881e+00,  3.6510e+00,  3.2987e+00, -7.5809e-03,  3.1750e+00,
#         -8.0121e-02,  3.1558e+00,  3.1977e-01, -2.9196e-02, -2.0788e+00,
#         -3.0240e+00,  6.5312e-01,  3.1806e+00,  3.3350e+00,  3.0571e+00,
#          4.9428e-01,  2.8379e-02, -3.2776e+00,  3.3914e+00,  3.4677e+00,
#         -5.4579e-02, -2.9326e+00, -7.1081e-01,  1.1354e-01,  3.2841e+00,
#         -1.7102e+00,  1.2588e+00,  7.9904e-01,  1.6997e-02,  3.2178e+00,
#          2.6759e-02, -2.3332e-02, -2.5531e-01, -1.0059e-01, -1.4286e+00,
#          2.1098e-02, -3.2453e-02,  3.3544e+00,  3.2249e+00, -7.7939e-03,
#         -3.4629e+00,  3.3891e+00,  3.1645e-02,  3.4949e+00,  7.7679e-03,
#          2.7037e-02, -4.5508e-01,  3.5413e+00, -3.1437e+00,  4.5001e-02,
#          3.4559e+00,  3.4848e+00,  3.2422e+00,  3.4870e+00,  3.2653e+00,
#          3.4867e+00, -1.1389e-01, -1.5911e+00,  3.8810e-02,  3.2984e+00,
#          3.3049e+00, -3.1717e-02, -1.5063e-02, -1.1436e+00,  3.4097e+00,
#         -2.3889e+00, -1.5878e-01,  4.3773e-02, -3.2764e-01,  3.4564e+00],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-8.7402e-03,  4.1525e-02, -7.6503e-02, -2.0423e-02, -4.5212e-02,
#           1.0008e-02, -4.7283e-02,  1.4007e-01,  8.8280e-04, -3.3531e-02,
#          -1.1546e-01, -3.3779e-02,  3.8257e-04, -3.5796e-02,  5.4977e-02,
#          -5.4893e-02,  7.2622e-02, -2.2466e-02, -6.5436e-04, -8.4600e-02,
#           5.1633e-02,  3.1673e-02,  7.3581e-02, -2.3431e-03, -7.2186e-02,
#          -7.6163e-02,  5.4906e-02,  1.0201e-03, -3.0280e-02, -2.3738e-02,
#          -1.2457e-02, -1.3565e-01, -1.2946e-02, -8.2990e-02,  4.4030e-02,
#           1.6550e-02,  3.3148e-02,  2.7043e-02,  5.8469e-02,  3.5349e-02,
#           3.3105e-02, -6.0723e-02, -5.9255e-02,  1.7234e-02,  2.3296e-02,
#          -1.1807e-01,  2.0749e-02,  3.2223e-02, -5.9848e-02,  1.2805e-01,
#           1.0077e-03,  1.5802e-02, -1.1201e-03, -6.4095e-02, -4.3632e-02,
#          -9.5866e-02,  1.0260e-02,  1.0329e-01,  9.4222e-02,  1.3003e-01,
#          -1.2879e-04, -4.0706e-03, -1.1693e-01,  5.4265e-02,  7.5906e-02,
#          -6.0867e-03, -1.2596e-01, -1.3375e-01, -7.0532e-02,  4.0986e-02,
#          -2.0704e-01,  5.5911e-04,  1.0380e-04, -6.9477e-02,  8.2248e-02,
#          -2.7649e-02,  5.3276e-02, -7.7430e-02, -3.7253e-02, -1.1228e-01,
#          -8.6941e-02, -5.9662e-02,  4.8526e-02,  6.7846e-03, -2.7939e-04,
#          -1.3379e-01,  8.2585e-02, -7.9239e-04,  5.1958e-02, -7.2689e-02,
#          -7.7905e-02, -8.0090e-03,  7.5959e-02, -1.0029e-01, -3.3355e-02,
#           3.2463e-02,  5.5391e-02,  1.8841e-02,  2.5783e-02,  3.0841e-02,
#           5.8926e-02, -2.0222e-01, -5.5882e-02, -6.6526e-02,  1.0630e-01,
#           8.3629e-02, -3.8907e-02, -3.5013e-02, -1.0187e-01,  2.4677e-02,
#          -4.4612e-02, -8.1076e-03,  7.5519e-04, -1.8060e-02,  3.0076e-02]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([3.7609], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 4.1050e-02,  1.9603e-01,  9.6777e-02,  ...,  2.8215e-01,
#           4.0703e-02,  3.9409e-01],
#         [-6.8367e-01,  3.4413e-02,  1.4170e-01,  ..., -3.1643e+00,
#          -2.6953e+00, -2.8631e+00],
#         [ 5.4239e-01, -8.3570e-03,  1.6431e-01,  ...,  4.4285e+00,
#           4.3170e+00,  4.6899e+00],
#         ...,
#         [ 4.2832e-01,  1.1930e-01, -3.9769e-02,  ...,  3.5001e-01,
#           4.3247e-01,  5.6765e-01],
#         [-1.1551e+00,  1.1328e-01,  2.2663e-03,  ..., -2.9274e-01,
#          -3.0652e-01, -5.4950e-01],
#         [-1.4130e-01,  2.5240e-01, -1.3460e-01,  ...,  3.8761e+00,
#           3.4128e+00,  3.8459e+00]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 3.5904e-01, -3.1182e+00,  4.2534e+00,  1.0226e+00,  1.9655e-01,
#          3.2399e+00,  2.0238e-01,  3.2741e+00,  1.2169e+00, -1.6384e+00,
#          1.6121e-01, -3.5748e-01, -4.1241e+00,  2.5124e-01, -6.2314e-01,
#         -1.8455e-01, -1.5176e+00,  2.9082e+00,  3.6041e+00,  3.6817e+00,
#         -4.0140e+00, -2.0206e-01, -4.8076e+00,  1.4358e+00, -3.9434e+00,
#         -5.2306e-01, -3.7840e+00,  1.9816e-01,  2.9991e+00,  1.4844e+00,
#          3.8511e+00, -3.7418e+00,  2.3624e+00, -4.1954e+00, -4.9292e-02,
#          7.9872e-02, -3.3705e+00, -2.7997e+00, -1.1824e-01,  1.4538e-01,
#          4.0606e+00, -3.3838e-02, -4.7968e-01, -4.4537e+00,  1.9527e-01,
#          1.0451e+00, -3.2601e+00,  5.6103e-01,  5.2412e-01, -1.4295e+00,
#          4.9348e-03,  1.7306e+00,  3.1557e+00, -4.0070e+00,  2.3338e-01,
#         -4.2138e+00,  9.3188e-01, -1.9328e+00,  2.1359e-01, -3.9715e+00,
#          2.5154e+00, -4.1586e+00, -5.6031e-02,  1.9320e+00,  4.3945e+00,
#          3.2137e+00, -2.9377e+00,  3.5087e+00,  1.6485e+00,  1.7184e+00,
#          6.0026e-01, -3.8645e-01, -3.7178e+00,  4.7015e+00,  2.2203e+00,
#          3.7523e+00,  2.8049e+00, -2.7032e+00,  3.4756e-01,  1.7191e+00,
#         -4.6518e-01, -8.7621e-01,  2.6446e+00, -2.3808e-01,  3.6073e-01,
#         -2.2505e-01, -8.9447e-02,  2.9381e-01,  3.5160e+00,  2.4377e+00,
#         -3.1520e+00, -1.5578e-01,  9.0277e-02,  3.6823e-01, -6.5209e-01,
#         -4.2133e+00, -4.5227e+00, -9.2220e-02,  4.6812e+00,  4.7587e+00,
#          3.5290e-01, -1.7796e+00, -2.6732e+00,  3.0943e+00, -2.7967e+00,
#          3.1306e+00,  1.5982e+00,  6.2987e-01, -4.0545e+00, -3.9583e+00,
#          1.6689e+00, -3.9757e+00,  3.0259e+00, -2.1015e+00, -3.8799e+00,
#          1.0761e-01, -4.6352e+00,  3.9906e+00,  2.8415e-01,  2.4670e+00,
#         -5.4514e+00,  1.2740e+00,  1.8332e-01, -1.1458e-01,  2.5705e-02,
#         -4.0214e+00,  2.2087e+00,  1.5852e+00, -3.7391e+00,  4.5423e+00,
#         -2.3331e+00, -2.7441e-01,  2.5690e-01,  3.9894e+00, -1.2500e-01,
#          2.1824e+00, -1.0638e+00, -7.8495e-01,  3.7743e+00,  3.4127e+00,
#          4.5952e+00,  3.2561e-01, -2.4576e-01, -2.1957e+00, -4.2798e+00,
#         -3.6032e+00,  2.2933e+00,  3.4543e-01, -4.8769e+00,  2.0098e-01,
#          4.4630e-01,  3.2614e+00, -2.4447e+00,  3.6276e-01,  2.0158e+00,
#         -3.4410e+00,  1.8041e-01,  6.0058e-01,  1.2632e+00,  3.2623e+00,
#         -2.9928e+00, -4.2084e-01, -4.8934e+00,  1.8150e-01,  2.5793e-01,
#          2.9828e+00, -2.1330e-01, -8.7591e-02, -3.4671e+00, -4.2121e+00,
#          9.7877e-03, -1.4454e-01, -4.8316e+00, -2.8399e+00, -4.3703e+00,
#          1.1209e-01,  2.7916e+00, -4.0504e+00, -4.7479e+00,  3.4911e-01,
#         -3.3806e+00, -2.1502e+00, -4.0742e+00,  3.8256e+00,  2.2791e-02,
#         -2.4685e+00,  2.5600e-01, -2.1356e+00, -1.3173e-01,  2.8744e+00,
#         -7.2543e-02, -1.0853e+00, -4.4742e+00,  2.9960e+00, -8.4822e-01,
#         -2.3578e+00, -1.1881e-01, -4.9315e+00,  3.6515e+00, -8.8655e-02,
#         -2.3604e-01,  2.0891e+00,  4.3556e+00,  2.1794e+00, -3.7844e+00,
#         -6.0660e-01, -2.1996e-01,  4.4411e+00,  5.5517e-01, -5.0042e+00,
#          4.1112e-01,  8.8380e-01,  6.1396e-01, -4.0118e+00,  2.2190e+00,
#         -4.4873e+00,  7.8183e-01,  1.3362e-01, -6.1861e-02, -6.9819e-01,
#          2.0023e+00, -3.8020e-01,  1.1422e+00, -4.6409e-01,  8.9748e-01,
#          2.6448e-01,  7.3917e-01,  5.5416e-03,  3.1311e+00, -2.2163e+00,
#          6.0413e-02, -4.7584e+00, -3.6345e+00, -1.1249e-01, -1.8348e-01,
#          5.5701e-03, -4.7712e-01, -4.0431e+00,  1.1997e-01,  3.7272e+00,
#          4.9830e-01, -2.7773e+00,  7.6707e-03,  2.9879e-02,  3.5543e+00,
#         -3.7229e-01,  2.9408e+00,  4.3052e+00, -1.4418e-02, -1.5338e-01,
#         -4.5965e+00, -2.7094e-01, -1.3032e-01,  1.4798e+00,  2.6750e+00,
#         -2.1066e+00, -4.9572e+00,  1.3283e-01, -1.0642e+00, -8.7468e-01,
#          2.9113e+00,  2.1978e+00, -1.1299e+00,  1.3292e-01,  1.0465e+00,
#          2.3422e-01, -4.2253e+00,  2.6674e+00,  2.2364e-02, -2.3083e+00,
#         -7.1504e-01,  3.6689e-01, -4.3449e+00, -5.8290e-01,  2.7832e+00,
#          1.0568e+00, -3.3260e+00, -9.3932e-01,  1.8138e-01,  4.0577e+00,
#         -3.4477e+00,  3.8712e+00, -1.6797e-01, -5.4427e+00,  1.4030e-01,
#          3.8245e+00, -1.5466e+00,  3.8024e+00, -2.9990e+00,  2.1420e-01,
#          3.0800e+00, -3.4472e+00, -7.5360e-01, -4.1336e+00,  1.1949e+00,
#          6.2474e-02, -2.4820e+00,  2.2541e-01,  5.9291e-01,  2.5417e-01,
#          1.2886e+00,  2.4634e+00,  3.7048e+00, -2.3129e+00,  7.8000e-03,
#          1.1929e+00,  2.1736e+00,  3.0638e+00, -3.1728e+00,  3.3641e+00,
#          2.0664e+00,  3.3605e+00, -4.3452e+00,  3.5059e-01,  4.8263e+00,
#         -1.3977e+00, -1.8880e+00,  1.2733e-01,  4.2620e+00,  1.9020e-01,
#          1.3775e+00,  3.2514e+00,  9.1559e-01,  2.4396e+00, -1.8940e-01,
#         -2.7640e-02,  3.8117e+00, -2.3995e+00, -7.4128e-02, -2.1364e+00,
#         -1.3018e+00,  3.2829e+00, -3.8760e-01, -1.8792e+00, -4.7569e-02,
#         -5.6614e-02, -4.6725e-02,  2.6904e+00, -3.4989e+00, -3.9751e+00,
#         -2.1076e+00,  2.1116e-02,  8.1668e-01,  1.4718e+00, -4.6792e+00,
#          3.5747e+00,  1.6785e-01, -4.7830e+00, -3.1350e-01, -1.0019e+00,
#         -1.4011e+00, -3.5195e+00,  1.5703e+00,  2.7999e-01,  3.2181e+00,
#          4.3998e+00,  4.0852e-01,  3.3797e+00,  4.0693e+00,  3.5014e+00,
#          3.9766e+00,  1.8819e-01,  4.5462e+00,  3.0477e-01, -1.4014e+00,
#          4.0986e-01, -4.0164e+00, -6.6018e-01,  1.1360e-01,  3.7098e+00,
#         -1.5306e-01, -1.4947e+00, -5.3485e+00, -6.5598e-01,  3.3239e-01,
#         -1.5530e-01, -4.9973e+00, -1.9236e+00, -1.7221e+00, -4.8439e+00,
#          2.6071e-01,  3.1199e-01, -2.2448e+00, -1.6762e-01,  3.2415e+00,
#          3.1777e+00,  3.6952e+00,  1.5507e+00,  3.1799e+00,  1.3230e-02,
#         -4.6191e+00,  3.8918e+00, -2.8636e+00,  2.1656e-01,  1.0995e-01,
#          2.5468e-01,  2.3974e+00,  3.9842e-01,  3.3734e-01,  3.3151e+00,
#          1.9130e-01, -4.0995e+00, -1.2117e+00, -3.8296e+00,  3.7688e+00,
#         -3.0252e+00, -2.6577e+00,  3.7557e-01,  4.3605e+00,  2.3132e+00,
#         -6.9354e-01,  6.0595e-01,  2.6945e+00, -4.0794e+00, -6.8594e-01,
#         -4.4631e-02,  8.2388e-02,  6.4801e-01, -3.2842e-01, -4.7560e+00,
#          3.5260e-02,  7.6327e-01,  2.8147e-01, -1.5909e+00, -2.0173e+00,
#         -9.9931e-01, -5.2621e+00, -4.2997e+00, -1.5992e+00,  2.9173e+00,
#          2.8483e-01,  6.0041e-02,  4.6777e+00,  3.7960e+00,  5.2145e-01,
#         -2.2921e-01,  1.6237e+00, -1.5963e+00,  3.5495e-01, -4.6097e-01,
#          1.9253e+00, -2.2598e+00, -4.1150e+00,  3.2823e+00, -2.1500e+00,
#          1.0709e-01,  3.3673e+00,  4.2433e+00,  3.6282e+00, -3.1796e+00,
#          2.4059e+00,  1.1869e+00, -3.0182e+00,  7.1731e-02, -1.9698e+00,
#          1.1436e+00,  1.2953e+00, -1.5266e+00,  3.5737e+00,  4.6375e-01,
#         -1.8653e+00, -7.3341e-01,  8.6807e-01,  2.4045e+00,  2.8965e+00,
#          4.4667e+00,  6.8368e-01,  2.2410e+00,  4.6591e+00, -1.0423e-01,
#          3.4475e+00,  2.0004e-01,  3.5017e-01,  1.5238e-01,  1.7060e-01,
#          2.9784e+00,  1.7625e+00, -2.9404e-01, -2.4351e+00, -4.7217e-01,
#         -2.1215e-01,  3.3674e+00, -3.2186e+00, -3.0797e-01,  3.8227e+00,
#          8.9838e-01, -5.5523e-01, -1.4852e+00, -2.5596e+00,  1.5893e-01,
#          7.7457e-01,  1.2676e+00,  1.2071e+00,  1.7905e+00, -4.1330e+00,
#          8.0587e-01,  3.6985e+00,  2.4779e+00,  7.4354e-01, -3.9516e+00,
#          2.6774e+00,  2.9244e+00,  2.7713e+00,  3.6397e+00,  3.7137e+00,
#          1.6148e-01, -3.2658e+00, -4.5685e+00,  5.4384e-01, -1.4670e-01,
#         -4.7373e-02, -4.4591e+00,  3.1928e+00,  3.3017e+00,  4.3955e-01,
#         -3.2585e+00,  1.8372e-02, -3.7546e-02,  2.6924e-01, -4.9536e+00,
#          7.5177e-01, -9.0671e-02,  5.5882e-01,  2.2507e+00, -1.5184e+00,
#          1.1084e+00,  1.3132e-02,  3.0311e+00,  3.8570e+00, -8.0732e-01,
#         -4.7675e+00,  8.0799e-01, -6.8256e-01, -4.2643e+00, -4.4294e+00,
#          5.3629e-01, -3.2009e-02,  3.2583e+00, -1.4624e+00,  3.8092e-02,
#          4.0121e-01, -3.0891e+00, -8.1822e-01,  2.3778e+00,  8.9958e-02,
#         -4.2750e+00, -3.6791e+00, -2.9894e+00,  2.7303e+00,  2.8377e+00,
#          2.8715e+00, -4.7538e+00,  2.7044e-01, -3.7090e-01,  3.9011e+00],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0703,  0.0322,  0.0479,  ..., -0.0606,  0.0463, -0.0132],
#         [ 0.0412,  0.0046,  0.0359,  ...,  0.0119,  0.0274,  0.0115],
#         [-0.0284,  0.0095, -0.0753,  ..., -0.0289, -0.0141,  0.0021],
#         ...,
#         [-0.0558,  0.0463,  0.0298,  ..., -0.0026,  0.0130, -0.0489],
#         [-0.0069,  0.0115,  0.0232,  ..., -0.0014, -0.0048, -0.0220],
#         [-0.0222,  0.0193, -0.0241,  ..., -0.0411, -0.0387, -0.0295]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-1.4696e+00,  1.0518e+00,  4.0804e-01, -4.6497e-01,  4.5202e+00,
#         -1.5891e+00,  4.5508e+00, -1.1598e+00,  3.8798e+00,  1.6589e+00,
#         -3.0121e-02, -2.4171e-01,  2.2716e+00, -8.4091e-03, -2.3332e+00,
#          3.2252e-02,  2.0377e-01,  3.8513e+00,  2.8544e+00,  2.5033e+00,
#          2.6810e+00, -2.8135e+00, -1.1286e+00,  3.5573e+00,  2.5053e-02,
#          2.8622e-02, -1.0748e-01,  1.1656e-03,  3.8343e+00, -2.6431e+00,
#         -1.5213e+00,  2.7340e+00,  2.9861e-04,  2.6048e+00,  2.9332e+00,
#          1.3722e+00,  1.7441e-02,  4.1538e+00, -3.4754e+00,  3.0928e+00,
#         -4.9385e-01,  9.0878e-01,  4.8720e-01,  2.4245e+00, -9.7596e-01,
#          1.8658e+00,  2.7258e+00, -7.7269e-02,  3.3566e+00, -3.5399e-02,
#          3.7629e+00,  3.0013e+00, -3.6083e-02, -1.3816e+00, -2.4651e-01,
#          3.6058e+00, -2.3159e-02,  1.2132e+00,  2.6861e+00,  4.7573e-01,
#          1.9702e+00, -5.9951e-03,  1.7711e-02,  1.5579e-02, -1.7286e-01,
#         -2.4450e-03,  4.0928e+00, -1.2644e+00,  1.6737e+00,  3.4064e+00,
#          2.2963e+00,  8.1633e-01, -4.8767e-02,  2.4764e-02,  2.9320e-02,
#          1.2484e+00,  2.6695e+00,  3.2228e-02,  1.2378e-01, -5.8944e-04,
#         -5.2671e-01,  1.9498e-02, -3.0552e+00,  3.1018e-02, -5.1164e-02,
#         -1.7700e+00,  2.7234e+00, -1.0290e+00,  3.2634e-02,  4.1450e+00,
#          3.8839e+00,  4.2094e+00,  1.3093e+00,  2.6402e+00, -6.0499e-03,
#         -1.3895e+00, -1.9968e-02, -1.0641e+00,  2.1781e+00,  1.0932e-02,
#          3.3584e+00, -1.3974e-01,  3.9247e+00, -9.4456e-03,  2.5039e+00,
#         -2.7864e-02, -3.5980e+00,  3.7682e-02,  1.7826e+00, -2.0541e-02,
#          9.1540e-01,  1.7984e+00,  3.4148e-02,  2.0575e+00, -6.0625e-01,
#         -5.2230e-02,  3.6279e+00, -2.1087e-03,  2.1051e-01, -2.6760e-02,
#         -2.4284e+00,  2.3680e+00,  3.2718e+00,  6.7213e-01, -1.3682e-02,
#          3.5575e+00,  2.4540e-01,  4.0847e-02, -4.6712e-02, -2.7397e+00,
#          2.8344e+00,  3.0783e+00,  1.7366e+00,  1.0980e+00,  3.6980e+00,
#         -5.5949e-01,  1.0493e+00,  4.0827e-02,  5.8722e-01,  4.1214e+00,
#          4.4254e+00,  1.5707e-02,  8.4708e-03, -6.2636e-01,  3.3074e+00,
#          1.3278e-02,  2.5561e+00,  2.8028e+00,  3.7891e+00, -7.9040e-02,
#         -2.6392e+00,  3.1596e+00, -2.9967e+00, -8.3225e-02, -2.4761e-02,
#          3.2372e+00,  3.5391e+00,  8.2038e-01,  3.7228e-01,  4.4096e+00,
#          2.9454e+00,  5.9244e-01,  1.8632e+00,  3.5731e+00, -1.4704e+00,
#         -5.4063e-01, -3.6194e-01,  4.1290e+00, -3.1693e+00, -2.6258e+00,
#          3.7881e+00, -3.2880e+00,  1.6755e+00,  1.7117e+00,  3.6439e-02,
#          2.6192e+00,  1.6382e-02,  7.2660e-02,  2.4610e+00, -3.0323e+00,
#          1.9316e+00,  2.7689e-02, -7.7682e-01,  3.9402e+00,  4.2271e+00,
#          3.2134e+00, -1.6893e-01, -3.5827e-02, -1.2783e-02, -1.7969e-01,
#          3.2119e+00, -1.8283e-02,  4.0905e+00, -1.0215e+00, -1.1065e+00,
#          3.2702e+00,  3.6647e+00,  4.0009e-01,  1.3859e-02,  1.1392e+00,
#          1.5239e-02,  3.6429e-02, -4.5742e+00,  4.8254e-03,  7.8225e-01,
#          2.7571e+00, -1.3764e-02,  3.5198e+00,  3.5846e-02,  3.6254e+00,
#         -5.1392e-01, -6.8203e-01, -4.4106e-02,  2.4437e+00,  1.5426e+00,
#          3.1860e+00,  2.3718e+00,  1.6963e+00, -2.8701e+00,  3.5264e+00,
#          2.0998e+00, -2.0692e-02,  3.2485e+00,  2.9452e+00,  2.8135e+00,
#         -1.3503e+00, -4.5909e+00, -3.7242e-02,  3.6324e-02,  1.4945e-03,
#         -1.8779e-01,  4.0516e+00,  3.7812e+00,  2.9559e+00,  2.0991e+00,
#          1.9842e-01, -3.2406e-02,  2.8378e+00,  1.9369e+00,  2.6101e-01,
#         -4.1067e-02, -2.4764e-02,  3.4832e-01,  1.7050e-02,  2.2636e-02,
#         -3.4727e-03,  1.8906e-02, -1.6966e+00, -3.5258e-02, -1.1555e-01,
#          2.7690e+00,  4.4111e+00, -2.7655e-01,  1.3048e+00, -3.0974e-02,
#         -2.4978e+00, -1.7054e-02,  3.6228e+00,  3.5627e+00,  3.9096e+00,
#          6.1616e-03, -4.4970e+00,  2.8962e+00, -3.1642e+00,  3.3764e+00,
#         -4.0421e-03,  2.7845e+00,  3.3847e+00,  2.1282e+00,  1.1530e+00,
#          1.7176e-02, -1.9739e-02,  3.3251e+00,  3.2740e+00,  1.8523e+00,
#         -4.8579e-02,  4.6265e+00,  3.5298e-01,  1.9716e+00,  3.0271e+00,
#          2.0544e-02, -3.3298e+00, -3.4718e-01,  1.6338e+00,  3.7744e-01,
#          3.0003e-02, -2.6624e+00,  3.9536e+00, -4.8078e-01, -3.9747e+00,
#          3.1783e+00, -5.0802e-01, -3.5482e-02, -7.3591e-02,  3.2144e+00,
#         -1.4312e-01, -3.1271e-01,  2.5865e-02, -1.8166e+00,  2.0224e+00,
#         -2.1385e-02, -1.8597e-01,  3.7386e+00,  3.5223e+00,  1.9236e-01,
#         -1.3413e-02,  3.2667e+00,  2.8767e+00,  2.1843e+00, -3.1483e+00,
#          3.9120e+00,  4.2346e+00,  2.4725e-02, -3.5243e-02,  3.5472e+00,
#         -4.9625e-02,  2.6395e+00, -6.0243e-01,  3.9947e+00,  3.5596e+00,
#          2.8636e+00,  4.0577e-03,  1.7246e+00,  3.1733e+00, -2.2705e+00,
#          3.6707e+00,  2.4816e+00, -3.2238e-02,  3.6317e+00, -2.2176e-02,
#          6.7134e-01,  2.5081e+00,  2.6451e+00,  1.3608e+00,  3.1370e+00,
#          3.8482e+00, -8.5744e-01,  2.7404e-02, -1.7116e-01,  1.0384e+00,
#          3.1734e+00,  2.1528e+00, -6.6163e-01,  3.7256e+00,  1.3452e-02,
#         -1.2650e-01,  3.3537e+00, -3.6572e+00, -2.9604e+00,  3.5587e+00,
#          3.0557e+00,  2.7342e+00, -5.0762e-01,  4.2284e+00, -3.1475e-02,
#         -1.8235e-02,  1.7537e+00, -1.6282e-01,  3.5556e+00, -8.3477e-03,
#          3.6290e+00,  7.7072e-01,  1.8876e+00,  3.6381e+00,  4.2431e+00,
#          2.6234e+00,  2.9877e+00,  1.9604e-02, -3.4460e-02,  4.0026e+00,
#          3.1262e-02, -3.4263e-02, -9.0490e-02, -3.4576e-01,  2.4339e-02,
#         -1.3194e+00,  2.2950e+00,  3.0489e+00, -4.8289e-01,  2.7339e+00,
#         -3.5916e+00,  2.8491e+00, -7.2557e-01,  1.2750e-01, -4.4376e-01,
#         -3.5581e-02,  9.9891e-03, -3.7231e-01, -5.8921e-02,  3.1598e+00,
#         -5.8137e-01,  3.2045e-01, -3.0750e+00,  2.9461e+00,  3.3774e+00,
#          3.5521e+00, -5.0910e-01, -2.4636e-02,  2.3371e+00,  4.0250e+00,
#         -4.4034e-02,  1.5031e+00,  2.9668e+00, -3.5425e-02,  1.0949e+00,
#          2.4745e-02,  2.5024e+00, -3.3097e+00,  2.7011e+00, -1.5168e+00,
#          1.2565e-03,  3.4478e+00, -1.2765e+00,  2.1170e-02,  8.6263e-01,
#          1.5156e+00, -6.9772e-01,  2.7912e-03, -6.5404e-01,  3.3062e+00,
#         -3.8264e-02, -4.1182e+00, -3.3006e-02, -3.1862e+00,  9.0010e-01,
#          2.3601e+00,  3.2322e+00,  1.0549e+00,  3.3538e+00,  3.0203e+00,
#         -1.8498e-01,  3.9914e+00, -1.5167e-01,  2.6743e+00, -4.1419e-02,
#         -3.2160e+00,  3.1871e+00,  3.4432e+00,  2.9613e+00, -3.5509e-02,
#          2.2857e+00,  3.2329e+00, -4.5278e+00,  4.2691e+00, -2.2435e-02,
#          7.7323e-01, -3.5164e+00,  1.6062e-02,  4.1841e+00,  2.7788e+00,
#          1.1572e+00, -1.7999e-02,  3.5117e+00, -2.2706e+00, -9.8294e-01,
#         -8.4515e-01, -2.1702e+00, -3.2057e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0200,  0.0398, -0.0008,  ...,  0.0019,  0.0166,  0.0016],
#         [-0.0741, -0.0099,  0.0104,  ..., -0.0087,  0.0152, -0.0431],
#         [-0.0393, -0.0127,  0.0016,  ..., -0.0168, -0.0072, -0.0064],
#         ...,
#         [-0.0402,  0.0121, -0.0460,  ..., -0.0357,  0.0461,  0.0284],
#         [-0.0091, -0.0206, -0.0402,  ..., -0.0029, -0.0942, -0.0307],
#         [-0.1311, -0.0058, -0.0444,  ..., -0.0346, -0.0285,  0.0234]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 5.8339e-01,  3.4293e+00,  1.0623e-02,  2.9064e-02,  7.2754e-03,
#          2.6910e+00, -4.2043e-02,  3.2112e+00,  4.7285e-02, -4.1023e-02,
#         -3.8782e+00, -8.8753e-03,  1.0869e+00, -2.7027e-02,  3.4798e+00,
#          6.1904e-03,  5.7306e-02,  4.4049e-03,  1.7255e+00, -3.0609e-03,
#          3.4878e+00,  3.4225e+00,  3.3767e+00, -3.6757e-02, -1.4456e-01,
#          1.1749e-01,  3.3712e+00,  1.0202e-01, -4.3495e-02, -2.9462e-02,
#         -1.8617e-02, -1.3211e+00,  8.8531e-03, -2.0840e-02,  3.3490e+00,
#          3.4451e+00,  3.3793e+00,  3.0246e+00,  3.4366e+00,  3.3549e+00,
#          3.3381e+00, -4.7907e-02, -6.0141e-02,  3.1432e+00,  3.4117e+00,
#         -2.9881e+00,  3.6510e+00,  3.2987e+00, -7.5809e-03,  3.1750e+00,
#         -8.0121e-02,  3.1558e+00,  3.1977e-01, -2.9196e-02, -2.0788e+00,
#         -3.0240e+00,  6.5312e-01,  3.1806e+00,  3.3350e+00,  3.0571e+00,
#          4.9428e-01,  2.8379e-02, -3.2776e+00,  3.3914e+00,  3.4677e+00,
#         -5.4579e-02, -2.9326e+00, -7.1081e-01,  1.1354e-01,  3.2841e+00,
#         -1.7102e+00,  1.2588e+00,  7.9904e-01,  1.6997e-02,  3.2178e+00,
#          2.6759e-02, -2.3332e-02, -2.5531e-01, -1.0059e-01, -1.4286e+00,
#          2.1098e-02, -3.2453e-02,  3.3544e+00,  3.2249e+00, -7.7939e-03,
#         -3.4629e+00,  3.3891e+00,  3.1645e-02,  3.4949e+00,  7.7679e-03,
#          2.7037e-02, -4.5508e-01,  3.5413e+00, -3.1437e+00,  4.5001e-02,
#          3.4559e+00,  3.4848e+00,  3.2422e+00,  3.4870e+00,  3.2653e+00,
#          3.4867e+00, -1.1389e-01, -1.5911e+00,  3.8810e-02,  3.2984e+00,
#          3.3049e+00, -3.1717e-02, -1.5063e-02, -1.1436e+00,  3.4097e+00,
#         -2.3889e+00, -1.5878e-01,  4.3773e-02, -3.2764e-01,  3.4564e+00],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-8.7402e-03,  4.1525e-02, -7.6503e-02, -2.0423e-02, -4.5212e-02,
#           1.0008e-02, -4.7283e-02,  1.4007e-01,  8.8280e-04, -3.3531e-02,
#          -1.1546e-01, -3.3779e-02,  3.8257e-04, -3.5796e-02,  5.4977e-02,
#          -5.4893e-02,  7.2622e-02, -2.2466e-02, -6.5436e-04, -8.4600e-02,
#           5.1633e-02,  3.1673e-02,  7.3581e-02, -2.3431e-03, -7.2186e-02,
#          -7.6163e-02,  5.4906e-02,  1.0201e-03, -3.0280e-02, -2.3738e-02,
#          -1.2457e-02, -1.3565e-01, -1.2946e-02, -8.2990e-02,  4.4030e-02,
#           1.6550e-02,  3.3148e-02,  2.7043e-02,  5.8469e-02,  3.5349e-02,
#           3.3105e-02, -6.0723e-02, -5.9255e-02,  1.7234e-02,  2.3296e-02,
#          -1.1807e-01,  2.0749e-02,  3.2223e-02, -5.9848e-02,  1.2805e-01,
#           1.0077e-03,  1.5802e-02, -1.1201e-03, -6.4095e-02, -4.3632e-02,
#          -9.5866e-02,  1.0260e-02,  1.0329e-01,  9.4222e-02,  1.3003e-01,
#          -1.2879e-04, -4.0706e-03, -1.1693e-01,  5.4265e-02,  7.5906e-02,
#          -6.0867e-03, -1.2596e-01, -1.3375e-01, -7.0532e-02,  4.0986e-02,
#          -2.0704e-01,  5.5911e-04,  1.0380e-04, -6.9477e-02,  8.2248e-02,
#          -2.7649e-02,  5.3276e-02, -7.7430e-02, -3.7253e-02, -1.1228e-01,
#          -8.6941e-02, -5.9662e-02,  4.8526e-02,  6.7846e-03, -2.7939e-04,
#          -1.3379e-01,  8.2585e-02, -7.9239e-04,  5.1958e-02, -7.2689e-02,
#          -7.7905e-02, -8.0090e-03,  7.5959e-02, -1.0029e-01, -3.3355e-02,
#           3.2463e-02,  5.5391e-02,  1.8841e-02,  2.5783e-02,  3.0841e-02,
#           5.8926e-02, -2.0222e-01, -5.5882e-02, -6.6526e-02,  1.0630e-01,
#           8.3629e-02, -3.8907e-02, -3.5013e-02, -1.0187e-01,  2.4677e-02,
#          -4.4612e-02, -8.1076e-03,  7.5519e-04, -1.8060e-02,  3.0076e-02]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([3.7609], device='cuda:0', requires_grad=True)]

# %%
rho_example, epsilon_example, vx_example, vy_example, vz_example, Bx_example, By_example, Bz_example, gxx_example, gxy_example, gxz_example, gyy_example, gyz_example, gzz_example = generate_samples(20)

inputs =  generate_input_data(rho_example, epsilon_example, vx_example, vy_example, vz_example, Bx_example, By_example, Bz_example, gxx_example, gxy_example, gxz_example, gyy_example, gyz_example, gzz_example)
inputs
# Out:
# Sample passed checks. vx^2+vy^2+vz^2: 0.8192191756300613, wtemp_expr: 0.09321067330907329, sdet_expr: 1.0413387933989224
# Number of valid samples: 1
# Sample passed checks. vx^2+vy^2+vz^2: 0.7245341501633232, wtemp_expr: 0.1976045124840754, sdet_expr: 1.1553294052774976
# Number of valid samples: 2
# Sample failed checks. vx^2+vy^2+vz^2: 1.1629809313242014, wtemp_expr: -0.182835989329317, sdet_expr: 0.9846074510572069
# Number of valid samples: 2
# Sample passed checks. vx^2+vy^2+vz^2: 0.8916328787502463, wtemp_expr: 0.012748384138744462, sdet_expr: 1.1159983375596711
# Number of valid samples: 3
# Sample failed checks. vx^2+vy^2+vz^2: 1.4925857815623287, wtemp_expr: -0.7445700946815188, sdet_expr: 1.2074475957952948
# Number of valid samples: 3
# Sample failed checks. vx^2+vy^2+vz^2: 1.1088843407043383, wtemp_expr: -0.21919020759563246, sdet_expr: 1.0615761990679853
# Number of valid samples: 3
# Sample failed checks. vx^2+vy^2+vz^2: 1.7793268780080091, wtemp_expr: -0.856612415874757, sdet_expr: 0.8335814466750376
# Number of valid samples: 3
# Sample passed checks. vx^2+vy^2+vz^2: 0.9056538132176094, wtemp_expr: 0.08533856685089025, sdet_expr: 0.9647287373610082
# Number of valid samples: 4
# Sample failed checks. vx^2+vy^2+vz^2: 1.3740189617598135, wtemp_expr: -0.6757034496816234, sdet_expr: 1.1838387750095545
# Number of valid samples: 4
# Sample failed checks. vx^2+vy^2+vz^2: 1.0286353821072116, wtemp_expr: 0.017517407876788238, sdet_expr: 0.9567339734591682
# Number of valid samples: 4
# Sample failed checks. vx^2+vy^2+vz^2: 1.7105975450667505, wtemp_expr: -0.758074171743051, sdet_expr: 0.9800856922491389
# Number of valid samples: 4
# Sample passed checks. vx^2+vy^2+vz^2: 0.8112256494501271, wtemp_expr: 0.18271401871108117, sdet_expr: 1.0696286344777324
# Number of valid samples: 5
# Sample failed checks. vx^2+vy^2+vz^2: 1.0832497172090996, wtemp_expr: -0.2582619003317326, sdet_expr: 1.0778382863153697
# Number of valid samples: 5
# Sample failed checks. vx^2+vy^2+vz^2: 1.124341082927802, wtemp_expr: -0.17066160269599595, sdet_expr: 0.989453793826644
# Number of valid samples: 5
# Sample failed checks. vx^2+vy^2+vz^2: 1.0704567479866585, wtemp_expr: -0.16819580468686568, sdet_expr: 1.1033628772769115
# Number of valid samples: 5
# Sample passed checks. vx^2+vy^2+vz^2: 0.16692938552683267, wtemp_expr: 0.8276797507697273, sdet_expr: 1.0208850552036541
# Number of valid samples: 6
# Sample failed checks. vx^2+vy^2+vz^2: 1.2445890661681167, wtemp_expr: -0.4728871439004896, sdet_expr: 1.0583988885708946
# Number of valid samples: 6
# Sample failed checks. vx^2+vy^2+vz^2: 0.990152458525509, wtemp_expr: -0.12076680286752928, sdet_expr: 1.0568593747711748
# Number of valid samples: 6
# Sample passed checks. vx^2+vy^2+vz^2: 0.7208097491724088, wtemp_expr: 0.17378071418394847, sdet_expr: 1.164356085582937
# Number of valid samples: 7
# Sample failed checks. vx^2+vy^2+vz^2: 1.3479935586824863, wtemp_expr: -0.35405800843449553, sdet_expr: 0.9776661957057887
# Number of valid samples: 7
# Sample failed checks. vx^2+vy^2+vz^2: 1.1673258846976644, wtemp_expr: -0.2199659068272617, sdet_expr: 0.9004490587081131
# Number of valid samples: 7
# Sample passed checks. vx^2+vy^2+vz^2: 0.023677506835387954, wtemp_expr: 0.9729565911074953, sdet_expr: 1.109995441338064
# Number of valid samples: 8
# Sample failed checks. vx^2+vy^2+vz^2: 1.5397022149149362, wtemp_expr: -0.6474984814120952, sdet_expr: 1.0284729528578511
# Number of valid samples: 8
# Sample passed checks. vx^2+vy^2+vz^2: 0.7929959338771395, wtemp_expr: 0.15738499535554507, sdet_expr: 0.9692481316083711
# Number of valid samples: 9
# Sample failed checks. vx^2+vy^2+vz^2: 2.0538503131065737, wtemp_expr: -1.2905654358963936, sdet_expr: 0.9775089667312938
# Number of valid samples: 9
# Sample failed checks. vx^2+vy^2+vz^2: 1.399063580643531, wtemp_expr: -0.49270489104584314, sdet_expr: 1.012501747426679
# Number of valid samples: 9
# Sample passed checks. vx^2+vy^2+vz^2: 0.08186237271996102, wtemp_expr: 0.9159977555963771, sdet_expr: 1.0239087056031986
# Number of valid samples: 10
# Sample passed checks. vx^2+vy^2+vz^2: 0.7217931975055647, wtemp_expr: 0.3246547561504889, sdet_expr: 0.9969201389411756
# Number of valid samples: 11
# Sample passed checks. vx^2+vy^2+vz^2: 0.6218114784681918, wtemp_expr: 0.35395330283623083, sdet_expr: 0.9532253157776969
# Number of valid samples: 12
# Sample failed checks. vx^2+vy^2+vz^2: 1.34742290150557, wtemp_expr: -0.44949961756461, sdet_expr: 1.0196399680920296
# Number of valid samples: 12
# Sample passed checks. vx^2+vy^2+vz^2: 0.910271216363738, wtemp_expr: 0.010379061095247888, sdet_expr: 1.0563631592160838
# Number of valid samples: 13
# Sample failed checks. vx^2+vy^2+vz^2: 1.4402816828279525, wtemp_expr: -0.5404321872018154, sdet_expr: 0.8733521786871737
# Number of valid samples: 13
# Sample passed checks. vx^2+vy^2+vz^2: 0.9012127342533883, wtemp_expr: 0.0031685484005889997, sdet_expr: 1.0618395807364913
# Number of valid samples: 14
# Sample passed checks. vx^2+vy^2+vz^2: 0.8390196397266642, wtemp_expr: 0.13757987551360018, sdet_expr: 0.8709336102920179
# Number of valid samples: 15
# Sample failed checks. vx^2+vy^2+vz^2: 1.5595257747837374, wtemp_expr: -0.7468577295157128, sdet_expr: 1.0185190137343565
# Number of valid samples: 15
# Sample failed checks. vx^2+vy^2+vz^2: 1.957890868030242, wtemp_expr: -1.1080534995956368, sdet_expr: 0.8588740549792957
# Number of valid samples: 15
# Sample failed checks. vx^2+vy^2+vz^2: 1.5963565851074086, wtemp_expr: -0.7596997983565703, sdet_expr: 1.0587536118366103
# Number of valid samples: 15
# Sample failed checks. vx^2+vy^2+vz^2: 0.950005108404843, wtemp_expr: -0.01835572067054536, sdet_expr: 0.8026800431627162
# Number of valid samples: 15
# Sample passed checks. vx^2+vy^2+vz^2: 0.5341028219451027, wtemp_expr: 0.40711788937627746, sdet_expr: 1.0149370514222151
# Number of valid samples: 16
# Sample failed checks. vx^2+vy^2+vz^2: 2.184964350722287, wtemp_expr: -1.2959879706137851, sdet_expr: 0.928903374912873
# Number of valid samples: 16
# Sample failed checks. vx^2+vy^2+vz^2: 1.086853279876558, wtemp_expr: -0.14040051458985037, sdet_expr: 0.970867312066183
# Number of valid samples: 16
# Sample passed checks. vx^2+vy^2+vz^2: 0.3589562318008986, wtemp_expr: 0.6545879515686965, sdet_expr: 0.8431796839270177
# Number of valid samples: 17
# Sample passed checks. vx^2+vy^2+vz^2: 0.6148101528161002, wtemp_expr: 0.3137755655754655, sdet_expr: 1.1427831911155635
# Number of valid samples: 18
# Sample failed checks. vx^2+vy^2+vz^2: 1.1351762487581207, wtemp_expr: -0.1718575590964495, sdet_expr: 0.9112255079762428
# Number of valid samples: 18
# Sample failed checks. vx^2+vy^2+vz^2: 1.1293104527525855, wtemp_expr: -0.23999856849670542, sdet_expr: 1.1234409673716486
# Number of valid samples: 18
# Sample failed checks. vx^2+vy^2+vz^2: 1.674816586613416, wtemp_expr: -0.750859881042315, sdet_expr: 0.9482745219209121
# Number of valid samples: 18
# Sample passed checks. vx^2+vy^2+vz^2: 0.3109428884431886, wtemp_expr: 0.6527581887672926, sdet_expr: 0.9599899533044794
# Number of valid samples: 19
# Sample failed checks. vx^2+vy^2+vz^2: 1.7799920852992543, wtemp_expr: -0.8973297549539416, sdet_expr: 0.8999719430787813
# Number of valid samples: 19
# Sample passed checks. vx^2+vy^2+vz^2: 0.8551052065844336, wtemp_expr: 0.17029781477035855, sdet_expr: 0.8511481787992083
# Number of valid samples: 20
# rho.shape:  torch.Size([20])
# epsilon.shape:  torch.Size([20])
# tensor([[ 4.6952e+00,  4.8420e+01,  2.8658e-01,  2.9462e+01,  5.8579e+01,
#           1.3510e+00,  7.8844e+00,  9.1559e-01,  1.0727e+00,  3.7730e-02,
#           5.5847e-02,  1.0302e+00,  1.8680e-02,  9.4670e-01],
#         [ 4.1885e+00, -1.3541e+01,  6.8835e+01,  1.8634e+01,  8.4080e+01,
#          -5.0711e+00, -2.3143e+00, -6.8554e+00,  1.0272e+00,  8.4674e-02,
#           9.0856e-02,  1.0525e+00,  1.9505e-02,  1.0839e+00],
#         [ 4.9933e+00,  1.0876e+04,  2.8281e+04,  3.7609e+04,  4.5905e+04,
#           8.0610e+00, -2.3579e+00, -4.7785e+00,  9.8064e-01,  5.0048e-02,
#           5.5838e-02,  1.0552e+00,  1.1035e-02,  1.0844e+00],
#         [ 2.4083e+00,  1.5020e+02,  2.2729e+01,  3.1233e+01,  1.5316e+02,
#          -3.2805e+00,  6.2067e+00,  6.4267e+00,  1.0094e+00,  5.2517e-02,
#           2.5186e-04,  9.6105e-01,  4.5430e-02,  9.9945e-01],
#         [ 1.7461e+00,  1.1311e+02,  2.5265e+01,  3.5940e+01,  1.3560e+02,
#           1.9560e+00,  9.3081e+00, -8.6995e-01,  9.1543e-01,  3.0302e-02,
#           8.4017e-02,  1.0968e+00,  5.9069e-02,  1.0769e+00],
#         [ 1.8865e+00,  1.6348e+02,  3.6872e+02,  1.3278e+02,  6.7258e+02,
#           3.2985e+00, -1.9201e-01,  9.6313e+00,  1.0257e+00,  4.6769e-02,
#           8.7641e-02,  9.3735e-01,  7.1303e-02,  1.0766e+00],
#         [ 5.3525e-01,  2.8341e+01,  3.4393e+01,  5.9142e+01,  7.1408e+01,
#           1.5994e+00, -7.5072e+00,  4.3355e+00,  1.0580e+00,  3.2667e-02,
#           8.3005e-02,  1.0189e+00,  2.1679e-02,  1.0880e+00],
#         [ 1.0825e+00,  4.8733e+00,  8.7121e-01,  2.6381e+00,  1.7558e+01,
#          -1.3572e+00,  5.7174e+00,  7.9295e-01,  1.0020e+00,  4.2526e-02,
#           9.3256e-02,  1.0353e+00,  6.1588e-02,  1.0837e+00],
#         [ 2.2948e+00,  5.6602e+01,  7.3311e+01,  2.1743e+01,  1.1550e+02,
#          -8.9420e+00,  4.8224e+00, -5.7375e+00,  9.7627e-01,  4.5336e-02,
#           7.3217e-02,  9.9207e-01,  5.5561e-02,  1.0111e+00],
#         [ 2.3483e-01,  6.4953e+00,  4.7256e+01,  3.0789e+01,  1.5355e+02,
#           3.1155e+00,  9.0558e-01,  1.0091e+01,  1.0575e+00,  6.7249e-02,
#           6.8505e-02,  9.5412e-01,  1.1430e-02,  1.0239e+00],
#         [ 1.0777e+00,  1.0337e+01,  1.2477e+01,  3.7125e+01,  4.1247e+01,
#           2.8202e-01, -6.3164e+00,  2.2703e+00,  1.0808e+00,  2.5534e-02,
#           8.7314e-02,  1.0369e+00,  6.8243e-02,  9.0132e-01],
#         [ 2.4129e+00,  9.6319e+01,  7.3667e+01,  8.5289e+00,  1.2296e+02,
#          -4.1702e+00,  6.3054e+00, -2.3788e+00,  9.1878e-01,  7.8675e-02,
#           6.3658e-02,  1.0733e+00,  7.8049e-03,  9.7717e-01],
#         [ 1.2288e+01,  6.6091e+01,  6.9050e+01,  5.5160e+02,  5.5521e+02,
#           8.1658e+00, -3.7860e+00,  6.3893e+00,  1.0118e+00,  4.3854e-02,
#           7.3958e-02,  9.8918e-01,  2.2108e-02,  1.0632e+00],
#         [ 1.5563e+01,  6.8155e+02,  5.8443e+02,  1.2687e+03,  1.4698e+03,
#           6.7808e+00,  6.7327e+00, -1.2346e+00,  9.4998e-01,  2.3086e-02,
#           1.1462e-02,  1.0433e+00,  8.8214e-02,  1.0795e+00],
#         [ 1.9479e+00, -1.0308e+01, -2.4896e+01,  8.5924e+01,  1.2583e+02,
#          -3.7759e+00, -4.9139e+00, -7.8126e+00,  9.0856e-01,  6.2407e-02,
#           5.7824e-02,  9.7410e-01,  9.6160e-02,  1.0009e+00],
#         [ 1.2728e+00,  3.2710e+02,  1.4714e+02, -1.9580e+01,  3.7940e+02,
#           3.8431e+00,  2.5472e+00,  9.8349e+00,  1.0856e+00,  6.1322e-02,
#           5.2792e-02,  9.5402e-01,  9.0970e-03,  9.8613e-01],
#         [ 1.9849e+00,  4.5833e+01,  3.2123e+01,  1.0089e+01,  6.9892e+01,
#          -2.2970e+00,  5.6986e+00, -8.6718e+00,  9.0984e-01,  9.6696e-02,
#           2.4406e-02,  1.0010e+00,  3.8485e-02,  9.3732e-01],
#         [ 3.7391e+00,  9.5068e+02,  7.0006e+02,  5.9919e+02,  1.3186e+03,
#          -8.8586e+00,  6.1944e-01,  5.9208e+00,  1.0169e+00,  3.4027e-02,
#           5.2357e-02,  1.0404e+00,  6.4334e-02,  1.0878e+00],
#         [ 1.9400e+00,  2.5827e+01,  4.5390e+01,  4.0931e+01,  7.2055e+01,
#          -9.7685e+00,  4.3917e+00,  8.3943e-01,  9.0796e-01,  9.0147e-02,
#           6.6327e-02,  1.0952e+00,  7.6413e-02,  9.8267e-01],
#         [ 2.6880e+00,  1.7587e+01,  4.9170e+01,  2.3727e+01,  5.7662e+01,
#          -1.4486e+00,  3.1533e+00, -7.0567e+00,  9.4582e-01,  8.8930e-03,
#           4.0215e-04,  9.9262e-01,  3.2341e-02,  9.0773e-01]], device='cuda:0')

# %%
#%%script echo skipping

# Pass the inputs to the network and get the outputs
outputs = [net(input.unsqueeze(0)) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[1398.3224]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[598.4860]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[388.0679]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[295.2842]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[231.5736]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>)]

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input.unsqueeze(0)) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[1398.3224]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[598.4860]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[388.0679]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[295.2842]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[231.5736]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([[0.]], device='cuda:0', grad_fn=<ReluBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 5) to trace the model
dummy_input = torch.randn(1, N_INPUTS).to(device)

# Ensure that net_loaded is in evaluation mode.
net_loaded.eval()

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*generate_samples(1))
print("input shape: ", example_input_to_validate_correct_export_and_import.shape)
print("input: ", example_input_to_validate_correct_export_and_import)
print("Output:", net_loaded(example_input_to_validate_correct_export_and_import))
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=14, out_features=555, bias=True)
#     (1): Linear(in_features=555, out_features=458, bias=True)
#     (2): Linear(in_features=458, out_features=115, bias=True)
#     (3): Linear(in_features=115, out_features=1, bias=True)
#   )
# )
# Sample passed checks. vx^2+vy^2+vz^2: 0.33716445211690427, wtemp_expr: 0.6316655457739717, sdet_expr: 1.0188571407659155
# Number of valid samples: 1
# rho.shape:  torch.Size([1])
# epsilon.shape:  torch.Size([1])
# input shape:  torch.Size([1, 14])
# input:  tensor([[ 7.8062e-01,  4.2502e+02,  4.4369e+02,  2.6294e+02,  8.1160e+02,
#           8.5098e+00, -3.8393e-01,  4.3605e+00,  1.0464e+00,  5.2136e-02,
#           6.7759e-03,  9.8602e-01,  6.2288e-02,  9.9406e-01]], device='cuda:0')
# Output: tensor([[1102.6239]], device='cuda:0', grad_fn=<ReluBackward0>)
# <ipython-input-28-96b416f81db5>:53: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert x.shape[1] == N_INPUTS, f"x must have shape (batch_size, {N_INPUTS})"
