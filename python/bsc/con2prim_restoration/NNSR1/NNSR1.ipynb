# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.

# %%
# %%script echo skipping
#
# !jupyter nbconvert NNSR1.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# [NbConvertApp] Converting notebook NNSR1.ipynb to script
# [NbConvertApp] Writing 45226 bytes to NNSR1.py

# %%
# If running this command, make sure to have activated the desired python or conda environment first.
# %%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Couldn't find program: 'echo'

# %%
# %%script echo skipping
#
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Couldn't find program: 'echo'

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.

# %%
N_TRIALS = 150 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

# Dieselhorst hyperparameters
N_LAYERS_NO_OPT = 2
N_UNITS_NO_OPT = [600, 200]
HIDDEN_ACTIVATION_NAME_NO_OPT = "Sigmoid"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "MSE"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 6e-3
BATCH_SIZE_NO_OPT = 32
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"


c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(1) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
# Computing the mean and standard deviation of each input variable from the training set
D_mean = torch.mean(x_train[:, 0])
D_std = torch.std(x_train[:, 0])
Sx_mean = torch.mean(x_train[:, 1])
Sx_std = torch.std(x_train[:, 1])
tau_mean = torch.mean(x_train[:, 2])
tau_std = torch.std(x_train[:, 2])

# Applying z-score normalization to both train and test sets using the statistics from the training set
x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
torch.mean(x_train[:, 0])
torch.std(x_train[:, 0])
torch.mean(x_train[:, 1])
torch.std(x_train[:, 1])
torch.mean(x_train[:, 2])
torch.std(x_train[:, 2])

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
# must be cpu here.
plt.hist(y_train.cpu().numpy(), bins=20)
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
# must be cpu here
plt.hist(y_test.cpu().numpy(), bins=20)
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 3)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 256) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            "output_activation", ["Linear", "ReLU"]
        ) 
        loss_name = trial.suggest_categorical(
            "loss", ["MSE", "MAE", "Huber", "LogCosh"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 32, 256)
        n_epochs = trial.suggest_int("n_epochs", 50, 100) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )
    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    # Creating the optimizer from its name
    if optimizer_name == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=lr)
    elif optimizer_name == "Adam":
        optimizer = optim.Adam(net.parameters(), lr=lr)
    elif optimizer_name == "RMSprop":
        optimizer = optim.RMSprop(net.parameters(), lr=lr)
    else:
        # Added creating the Adagrad optimizer
        optimizer = optim.Adagrad(net.parameters(), lr=lr)

    # Creating the learning rate scheduler from its name
    if scheduler_name == "StepLR":
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif scheduler_name == "ExponentialLR":
        scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    elif scheduler_name == "CosineAnnealingLR":
        # Added creating the CosineAnnealingLR scheduler
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
    elif scheduler_name == "ReduceLROnPlateau":
        # Added creating the ReduceLROnPlateau scheduler
        # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
        #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
        #)
        # Use Dieseldorst et al. settings and add to that a minimum lr.
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                )
    else:
        scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: MSELoss()
# batch_size: 32
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f687ee17670>
# loss_name: MSE
# optimizer_name: Adam
# scheduler_name: ReduceLROnPlateau
# n_units: [600, 200]
# n_layers: 2
# hidden_activation: Sigmoid()
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.6690, Test Loss: 0.0290, Train L1 Norm: 3.8946, Test L1 Norm: 0.8899, Train Linf Norm: 102.8239, Test Linf Norm: 24.0285
# Epoch 2: Train Loss: 0.0225, Test Loss: 0.0528, Train L1 Norm: 0.9075, Test L1 Norm: 0.7651, Train Linf Norm: 24.5390, Test Linf Norm: 20.5254
# Epoch 3: Train Loss: 0.0148, Test Loss: 0.0048, Train L1 Norm: 0.6256, Test L1 Norm: 0.2270, Train Linf Norm: 16.5889, Test Linf Norm: 5.7394
# Epoch 4: Train Loss: 0.0139, Test Loss: 0.0069, Train L1 Norm: 0.6584, Test L1 Norm: 0.3949, Train Linf Norm: 17.7344, Test Linf Norm: 10.5790
# Epoch 5: Train Loss: 0.0110, Test Loss: 0.0078, Train L1 Norm: 0.5149, Test L1 Norm: 0.7458, Train Linf Norm: 13.5384, Test Linf Norm: 19.6415
# Epoch 6: Train Loss: 0.0108, Test Loss: 0.0031, Train L1 Norm: 0.4483, Test L1 Norm: 0.2383, Train Linf Norm: 11.5717, Test Linf Norm: 6.2912
# Epoch 7: Train Loss: 0.0076, Test Loss: 0.0034, Train L1 Norm: 0.4160, Test L1 Norm: 0.0887, Train Linf Norm: 10.6196, Test Linf Norm: 1.2472
# Epoch 8: Train Loss: 0.0067, Test Loss: 0.0038, Train L1 Norm: 0.3629, Test L1 Norm: 0.2256, Train Linf Norm: 9.2447, Test Linf Norm: 5.8990
# Epoch 9: Train Loss: 0.0072, Test Loss: 0.0095, Train L1 Norm: 0.4034, Test L1 Norm: 0.4199, Train Linf Norm: 10.5973, Test Linf Norm: 10.8300
# Epoch 10: Train Loss: 0.0056, Test Loss: 0.0389, Train L1 Norm: 0.3553, Test L1 Norm: 1.0279, Train Linf Norm: 9.2168, Test Linf Norm: 27.7133
# Epoch 11: Train Loss: 0.0053, Test Loss: 0.0026, Train L1 Norm: 0.3181, Test L1 Norm: 0.1831, Train Linf Norm: 8.1305, Test Linf Norm: 4.7596
# Epoch 12: Train Loss: 0.0051, Test Loss: 0.0034, Train L1 Norm: 0.3601, Test L1 Norm: 0.3749, Train Linf Norm: 9.5352, Test Linf Norm: 10.0223
# Epoch 13: Train Loss: 0.0054, Test Loss: 0.0042, Train L1 Norm: 0.3436, Test L1 Norm: 0.0999, Train Linf Norm: 8.9119, Test Linf Norm: 0.9059
# Epoch 14: Train Loss: 0.0040, Test Loss: 0.0011, Train L1 Norm: 0.2473, Test L1 Norm: 0.0638, Train Linf Norm: 5.9979, Test Linf Norm: 1.0887
# Epoch 15: Train Loss: 0.0045, Test Loss: 0.0034, Train L1 Norm: 0.2582, Test L1 Norm: 0.3800, Train Linf Norm: 6.3526, Test Linf Norm: 10.3941
# Epoch 16: Train Loss: 0.0033, Test Loss: 0.0143, Train L1 Norm: 0.2266, Test L1 Norm: 0.0889, Train Linf Norm: 5.6091, Test Linf Norm: 0.6848
# Epoch 17: Train Loss: 0.0038, Test Loss: 0.0012, Train L1 Norm: 0.2996, Test L1 Norm: 0.0584, Train Linf Norm: 7.7884, Test Linf Norm: 0.7685
# Epoch 18: Train Loss: 0.0037, Test Loss: 0.0035, Train L1 Norm: 0.2409, Test L1 Norm: 0.2098, Train Linf Norm: 5.9396, Test Linf Norm: 5.4925
# Epoch 19: Train Loss: 0.0046, Test Loss: 0.0544, Train L1 Norm: 0.2807, Test L1 Norm: 0.2439, Train Linf Norm: 7.3550, Test Linf Norm: 0.9949
# Epoch 20: Train Loss: 0.0038, Test Loss: 0.0006, Train L1 Norm: 0.2318, Test L1 Norm: 0.0647, Train Linf Norm: 5.8093, Test Linf Norm: 1.4730
# Epoch 21: Train Loss: 0.0028, Test Loss: 0.0007, Train L1 Norm: 0.2148, Test L1 Norm: 0.0457, Train Linf Norm: 5.4058, Test Linf Norm: 0.5529
# Epoch 22: Train Loss: 0.0030, Test Loss: 0.0029, Train L1 Norm: 0.2030, Test L1 Norm: 0.0641, Train Linf Norm: 5.0079, Test Linf Norm: 1.1532
# Epoch 23: Train Loss: 0.0026, Test Loss: 0.0014, Train L1 Norm: 0.2237, Test L1 Norm: 0.0880, Train Linf Norm: 5.6959, Test Linf Norm: 2.0400
# Epoch 24: Train Loss: 0.0029, Test Loss: 0.0004, Train L1 Norm: 0.1862, Test L1 Norm: 0.0550, Train Linf Norm: 4.4795, Test Linf Norm: 1.2363
# Epoch 25: Train Loss: 0.0026, Test Loss: 0.0006, Train L1 Norm: 0.2138, Test L1 Norm: 0.0503, Train Linf Norm: 5.4273, Test Linf Norm: 0.6767
# Epoch 26: Train Loss: 0.0027, Test Loss: 0.0010, Train L1 Norm: 0.2004, Test L1 Norm: 0.0444, Train Linf Norm: 4.9728, Test Linf Norm: 0.5602
# Epoch 27: Train Loss: 0.0029, Test Loss: 0.0016, Train L1 Norm: 0.1803, Test L1 Norm: 0.0758, Train Linf Norm: 4.3404, Test Linf Norm: 1.5083
# Epoch 28: Train Loss: 0.0022, Test Loss: 0.0027, Train L1 Norm: 0.1480, Test L1 Norm: 0.0755, Train Linf Norm: 3.4667, Test Linf Norm: 0.7220
# Epoch 29: Train Loss: 0.0022, Test Loss: 0.0007, Train L1 Norm: 0.1205, Test L1 Norm: 0.1065, Train Linf Norm: 2.7145, Test Linf Norm: 2.4584
# Epoch 30: Train Loss: 0.0023, Test Loss: 0.0008, Train L1 Norm: 0.1242, Test L1 Norm: 0.0464, Train Linf Norm: 2.7360, Test Linf Norm: 0.6217
# Epoch 31: Train Loss: 0.0006, Test Loss: 0.0026, Train L1 Norm: 0.0659, Test L1 Norm: 0.2214, Train Linf Norm: 1.4006, Test Linf Norm: 5.3891
# Epoch 32: Train Loss: 0.0007, Test Loss: 0.0003, Train L1 Norm: 0.0615, Test L1 Norm: 0.0472, Train Linf Norm: 1.1988, Test Linf Norm: 0.6789
# Epoch 33: Train Loss: 0.0006, Test Loss: 0.0006, Train L1 Norm: 0.0581, Test L1 Norm: 0.0448, Train Linf Norm: 1.1330, Test Linf Norm: 0.8906
# Epoch 34: Train Loss: 0.0006, Test Loss: 0.0004, Train L1 Norm: 0.0562, Test L1 Norm: 0.0431, Train Linf Norm: 1.0929, Test Linf Norm: 0.5729
# Epoch 35: Train Loss: 0.0007, Test Loss: 0.0003, Train L1 Norm: 0.0660, Test L1 Norm: 0.0265, Train Linf Norm: 1.3656, Test Linf Norm: 0.4300
# Epoch 36: Train Loss: 0.0006, Test Loss: 0.0003, Train L1 Norm: 0.0653, Test L1 Norm: 0.0357, Train Linf Norm: 1.3914, Test Linf Norm: 0.5100
# Epoch 37: Train Loss: 0.0007, Test Loss: 0.0004, Train L1 Norm: 0.0704, Test L1 Norm: 0.0275, Train Linf Norm: 1.5369, Test Linf Norm: 0.4386
# Epoch 38: Train Loss: 0.0006, Test Loss: 0.0005, Train L1 Norm: 0.0650, Test L1 Norm: 0.0297, Train Linf Norm: 1.3982, Test Linf Norm: 0.4675
# Epoch 39: Train Loss: 0.0002, Test Loss: 0.0004, Train L1 Norm: 0.0411, Test L1 Norm: 0.0293, Train Linf Norm: 0.8985, Test Linf Norm: 0.5644
# Epoch 40: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0413, Test L1 Norm: 0.0205, Train Linf Norm: 0.8527, Test Linf Norm: 0.3761
# Epoch 41: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0401, Test L1 Norm: 0.0323, Train Linf Norm: 0.8182, Test Linf Norm: 0.4821
# Epoch 42: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0391, Test L1 Norm: 0.0557, Train Linf Norm: 0.8223, Test Linf Norm: 1.2386
# Epoch 43: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0432, Test L1 Norm: 0.0580, Train Linf Norm: 0.9477, Test Linf Norm: 1.2337
# Epoch 44: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0361, Test L1 Norm: 0.0198, Train Linf Norm: 0.7280, Test Linf Norm: 0.3890
# Epoch 45: Train Loss: 0.0002, Test Loss: 0.0008, Train L1 Norm: 0.0395, Test L1 Norm: 0.0409, Train Linf Norm: 0.8464, Test Linf Norm: 0.5753
# Epoch 46: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0380, Test L1 Norm: 0.0244, Train Linf Norm: 0.7886, Test Linf Norm: 0.4567
# Epoch 47: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0420, Test L1 Norm: 0.0180, Train Linf Norm: 0.9295, Test Linf Norm: 0.3386
# Epoch 48: Train Loss: 0.0002, Test Loss: 0.0004, Train L1 Norm: 0.0367, Test L1 Norm: 0.0345, Train Linf Norm: 0.7785, Test Linf Norm: 0.5572
# Epoch 49: Train Loss: 0.0002, Test Loss: 0.0009, Train L1 Norm: 0.0376, Test L1 Norm: 0.1562, Train Linf Norm: 0.7923, Test Linf Norm: 3.7947
# Epoch 50: Train Loss: 0.0002, Test Loss: 0.0004, Train L1 Norm: 0.0350, Test L1 Norm: 0.0311, Train Linf Norm: 0.7323, Test Linf Norm: 0.4566
# Epoch 51: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0369, Test L1 Norm: 0.0210, Train Linf Norm: 0.7848, Test Linf Norm: 0.3716
# Epoch 52: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0378, Test L1 Norm: 0.0226, Train Linf Norm: 0.8183, Test Linf Norm: 0.4188
# Epoch 53: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0416, Test L1 Norm: 0.0164, Train Linf Norm: 0.9378, Test Linf Norm: 0.3259
# Epoch 54: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0375, Test L1 Norm: 0.0207, Train Linf Norm: 0.8116, Test Linf Norm: 0.3786
# Epoch 55: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0399, Test L1 Norm: 0.0359, Train Linf Norm: 0.8979, Test Linf Norm: 0.5574
# Epoch 56: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0368, Test L1 Norm: 0.0321, Train Linf Norm: 0.7863, Test Linf Norm: 0.7271
# Epoch 57: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0394, Test L1 Norm: 0.0154, Train Linf Norm: 0.8863, Test Linf Norm: 0.3138
# Epoch 58: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0343, Test L1 Norm: 0.0190, Train Linf Norm: 0.7242, Test Linf Norm: 0.3448
# Epoch 59: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0373, Test L1 Norm: 0.0190, Train Linf Norm: 0.8120, Test Linf Norm: 0.3727
# Epoch 60: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0315, Test L1 Norm: 0.0183, Train Linf Norm: 0.6423, Test Linf Norm: 0.3888
# Epoch 61: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0315, Test L1 Norm: 0.0167, Train Linf Norm: 0.6584, Test Linf Norm: 0.3245
# Epoch 62: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0379, Test L1 Norm: 0.0177, Train Linf Norm: 0.8155, Test Linf Norm: 0.3594
# Epoch 63: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0471, Test L1 Norm: 0.0234, Train Linf Norm: 1.1334, Test Linf Norm: 0.3701
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0242, Test L1 Norm: 0.0153, Train Linf Norm: 0.5244, Test Linf Norm: 0.2847
# Epoch 65: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0226, Test L1 Norm: 0.0140, Train Linf Norm: 0.4551, Test Linf Norm: 0.2807
# Epoch 66: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0273, Test L1 Norm: 0.0148, Train Linf Norm: 0.6019, Test Linf Norm: 0.2823
# Epoch 67: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0235, Test L1 Norm: 0.0162, Train Linf Norm: 0.4915, Test Linf Norm: 0.3025
# Epoch 68: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0231, Test L1 Norm: 0.0165, Train Linf Norm: 0.4689, Test Linf Norm: 0.3234
# Epoch 69: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0218, Test L1 Norm: 0.0168, Train Linf Norm: 0.4404, Test Linf Norm: 0.3261
# Epoch 70: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0215, Test L1 Norm: 0.0203, Train Linf Norm: 0.4355, Test Linf Norm: 0.3622
# Epoch 71: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0211, Test L1 Norm: 0.0132, Train Linf Norm: 0.4214, Test Linf Norm: 0.2663
# Epoch 72: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0242, Test L1 Norm: 0.0253, Train Linf Norm: 0.5187, Test Linf Norm: 0.5380
# Epoch 73: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0225, Test L1 Norm: 0.0127, Train Linf Norm: 0.4613, Test Linf Norm: 0.2598
# Epoch 74: Train Loss: 0.0001, Test Loss: 0.0002, Train L1 Norm: 0.0261, Test L1 Norm: 0.0526, Train Linf Norm: 0.5837, Test Linf Norm: 1.2399
# Epoch 75: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0203, Test L1 Norm: 0.0166, Train Linf Norm: 0.3952, Test Linf Norm: 0.3262
# Epoch 76: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0238, Test L1 Norm: 0.0142, Train Linf Norm: 0.5059, Test Linf Norm: 0.2837
# Epoch 77: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0228, Test L1 Norm: 0.0147, Train Linf Norm: 0.4828, Test Linf Norm: 0.2989
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0194, Test L1 Norm: 0.0185, Train Linf Norm: 0.4206, Test Linf Norm: 0.3297
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0178, Test L1 Norm: 0.0138, Train Linf Norm: 0.3682, Test Linf Norm: 0.2799
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0144, Train Linf Norm: 0.3534, Test Linf Norm: 0.2934
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0191, Test L1 Norm: 0.0137, Train Linf Norm: 0.4072, Test Linf Norm: 0.2794
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0165, Test L1 Norm: 0.0123, Train Linf Norm: 0.3221, Test Linf Norm: 0.2469
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0171, Test L1 Norm: 0.0131, Train Linf Norm: 0.3512, Test Linf Norm: 0.2641
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0211, Test L1 Norm: 0.0135, Train Linf Norm: 0.4735, Test Linf Norm: 0.2729
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0173, Test L1 Norm: 0.0125, Train Linf Norm: 0.3566, Test Linf Norm: 0.2522
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0174, Test L1 Norm: 0.0141, Train Linf Norm: 0.3617, Test Linf Norm: 0.2876
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0168, Test L1 Norm: 0.0153, Train Linf Norm: 0.3409, Test Linf Norm: 0.3036
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0160, Test L1 Norm: 0.0183, Train Linf Norm: 0.3372, Test Linf Norm: 0.3997
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0151, Test L1 Norm: 0.0140, Train Linf Norm: 0.3055, Test Linf Norm: 0.2844
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0162, Test L1 Norm: 0.0122, Train Linf Norm: 0.3418, Test Linf Norm: 0.2486
# Epoch 91: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0172, Test L1 Norm: 0.0118, Train Linf Norm: 0.3745, Test Linf Norm: 0.2420
# Epoch 92: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0158, Test L1 Norm: 0.0142, Train Linf Norm: 0.3271, Test Linf Norm: 0.3069
# Epoch 93: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0159, Test L1 Norm: 0.0127, Train Linf Norm: 0.3366, Test Linf Norm: 0.2646
# Epoch 94: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0158, Test L1 Norm: 0.0130, Train Linf Norm: 0.3332, Test Linf Norm: 0.2700
# Epoch 95: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0173, Test L1 Norm: 0.0127, Train Linf Norm: 0.3815, Test Linf Norm: 0.2617
# Epoch 96: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0156, Test L1 Norm: 0.0120, Train Linf Norm: 0.3301, Test Linf Norm: 0.2500
# Epoch 97: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0131, Train Linf Norm: 0.3863, Test Linf Norm: 0.2665
# Epoch 98: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0151, Test L1 Norm: 0.0126, Train Linf Norm: 0.3141, Test Linf Norm: 0.2521
# Epoch 99: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0161, Test L1 Norm: 0.0139, Train Linf Norm: 0.3440, Test Linf Norm: 0.2885
# Epoch 100: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0150, Test L1 Norm: 0.0124, Train Linf Norm: 0.3181, Test Linf Norm: 0.2655
# Epoch 101: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0147, Test L1 Norm: 0.0149, Train Linf Norm: 0.3073, Test Linf Norm: 0.3025
# Epoch 102: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0150, Test L1 Norm: 0.0121, Train Linf Norm: 0.3227, Test Linf Norm: 0.2510
# Epoch 103: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0147, Test L1 Norm: 0.0114, Train Linf Norm: 0.3065, Test Linf Norm: 0.2392
# Epoch 104: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0145, Test L1 Norm: 0.0117, Train Linf Norm: 0.3074, Test Linf Norm: 0.2439
# Epoch 105: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0150, Test L1 Norm: 0.0131, Train Linf Norm: 0.3201, Test Linf Norm: 0.2786
# Epoch 106: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0149, Test L1 Norm: 0.0115, Train Linf Norm: 0.3181, Test Linf Norm: 0.2358
# Epoch 107: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0145, Test L1 Norm: 0.0115, Train Linf Norm: 0.3048, Test Linf Norm: 0.2388
# Epoch 108: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0153, Test L1 Norm: 0.0115, Train Linf Norm: 0.3250, Test Linf Norm: 0.2393
# Epoch 109: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0143, Test L1 Norm: 0.0137, Train Linf Norm: 0.2969, Test Linf Norm: 0.2851
# Epoch 110: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0138, Test L1 Norm: 0.0116, Train Linf Norm: 0.2828, Test Linf Norm: 0.2478
# Epoch 111: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0148, Test L1 Norm: 0.0125, Train Linf Norm: 0.3186, Test Linf Norm: 0.2591
# Epoch 112: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0143, Test L1 Norm: 0.0116, Train Linf Norm: 0.3012, Test Linf Norm: 0.2421
# Epoch 113: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0142, Test L1 Norm: 0.0123, Train Linf Norm: 0.2940, Test Linf Norm: 0.2637
# Epoch 114: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0140, Test L1 Norm: 0.0115, Train Linf Norm: 0.2891, Test Linf Norm: 0.2419
# Epoch 115: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0145, Test L1 Norm: 0.0129, Train Linf Norm: 0.3084, Test Linf Norm: 0.2663
# Epoch 116: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0147, Test L1 Norm: 0.0123, Train Linf Norm: 0.3139, Test Linf Norm: 0.2569
# Epoch 117: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0140, Test L1 Norm: 0.0114, Train Linf Norm: 0.2917, Test Linf Norm: 0.2396
# Epoch 118: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0143, Test L1 Norm: 0.0111, Train Linf Norm: 0.3037, Test Linf Norm: 0.2326
# Epoch 119: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0149, Test L1 Norm: 0.0126, Train Linf Norm: 0.3268, Test Linf Norm: 0.2605
# Epoch 120: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0145, Test L1 Norm: 0.0119, Train Linf Norm: 0.3098, Test Linf Norm: 0.2498
# Epoch 121: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0136, Test L1 Norm: 0.0115, Train Linf Norm: 0.2866, Test Linf Norm: 0.2425
# Epoch 122: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0137, Test L1 Norm: 0.0113, Train Linf Norm: 0.2905, Test Linf Norm: 0.2383
# Epoch 123: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0139, Test L1 Norm: 0.0126, Train Linf Norm: 0.2974, Test Linf Norm: 0.2677
# Epoch 124: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0136, Test L1 Norm: 0.0118, Train Linf Norm: 0.2855, Test Linf Norm: 0.2501
# Epoch 125: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0139, Test L1 Norm: 0.0120, Train Linf Norm: 0.2972, Test Linf Norm: 0.2539
# Epoch 126: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0137, Test L1 Norm: 0.0121, Train Linf Norm: 0.2901, Test Linf Norm: 0.2567
# Epoch 127: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0135, Test L1 Norm: 0.0113, Train Linf Norm: 0.2810, Test Linf Norm: 0.2383
# Epoch 128: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0139, Test L1 Norm: 0.0115, Train Linf Norm: 0.2946, Test Linf Norm: 0.2401
# Epoch 129: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0116, Train Linf Norm: 0.2813, Test Linf Norm: 0.2443
# Epoch 130: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0138, Test L1 Norm: 0.0112, Train Linf Norm: 0.2901, Test Linf Norm: 0.2364
# Epoch 131: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0140, Test L1 Norm: 0.0117, Train Linf Norm: 0.2997, Test Linf Norm: 0.2485
# Epoch 132: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0141, Test L1 Norm: 0.0131, Train Linf Norm: 0.2986, Test Linf Norm: 0.2659
# Epoch 133: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0138, Test L1 Norm: 0.0114, Train Linf Norm: 0.2928, Test Linf Norm: 0.2399
# Epoch 134: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0136, Test L1 Norm: 0.0113, Train Linf Norm: 0.2877, Test Linf Norm: 0.2394
# Epoch 135: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0113, Train Linf Norm: 0.2834, Test Linf Norm: 0.2401
# Epoch 136: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0138, Test L1 Norm: 0.0120, Train Linf Norm: 0.2942, Test Linf Norm: 0.2552
# Epoch 137: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0137, Test L1 Norm: 0.0114, Train Linf Norm: 0.2903, Test Linf Norm: 0.2429
# Epoch 138: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0135, Test L1 Norm: 0.0118, Train Linf Norm: 0.2862, Test Linf Norm: 0.2517
# Epoch 139: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0135, Test L1 Norm: 0.0117, Train Linf Norm: 0.2869, Test Linf Norm: 0.2478
# Epoch 140: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0136, Test L1 Norm: 0.0115, Train Linf Norm: 0.2873, Test Linf Norm: 0.2454
# Epoch 141: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2773, Test Linf Norm: 0.2395
# Epoch 142: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0135, Test L1 Norm: 0.0114, Train Linf Norm: 0.2877, Test Linf Norm: 0.2392
# Epoch 143: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0114, Train Linf Norm: 0.2856, Test Linf Norm: 0.2432
# Epoch 144: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0113, Train Linf Norm: 0.2854, Test Linf Norm: 0.2386
# Epoch 145: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2784, Test Linf Norm: 0.2371
# Epoch 146: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0111, Train Linf Norm: 0.2835, Test Linf Norm: 0.2358
# Epoch 147: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0115, Train Linf Norm: 0.2830, Test Linf Norm: 0.2426
# Epoch 148: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0135, Test L1 Norm: 0.0114, Train Linf Norm: 0.2870, Test Linf Norm: 0.2421
# Epoch 149: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0112, Train Linf Norm: 0.2846, Test Linf Norm: 0.2366
# Epoch 150: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0116, Train Linf Norm: 0.2827, Test Linf Norm: 0.2463
# Epoch 151: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2797, Test Linf Norm: 0.2344
# Epoch 152: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0115, Train Linf Norm: 0.2886, Test Linf Norm: 0.2436
# Epoch 153: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2787, Test Linf Norm: 0.2374
# Epoch 154: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0121, Train Linf Norm: 0.2852, Test Linf Norm: 0.2550
# Epoch 155: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0116, Train Linf Norm: 0.2820, Test Linf Norm: 0.2460
# Epoch 156: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0113, Train Linf Norm: 0.2840, Test Linf Norm: 0.2399
# Epoch 157: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0117, Train Linf Norm: 0.2813, Test Linf Norm: 0.2481
# Epoch 158: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0117, Train Linf Norm: 0.2849, Test Linf Norm: 0.2489
# Epoch 159: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2843, Test Linf Norm: 0.2413
# Epoch 160: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2814, Test Linf Norm: 0.2381
# Epoch 161: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0117, Train Linf Norm: 0.2797, Test Linf Norm: 0.2500
# Epoch 162: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0116, Train Linf Norm: 0.2814, Test Linf Norm: 0.2480
# Epoch 163: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2828, Test Linf Norm: 0.2377
# Epoch 164: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2778, Test Linf Norm: 0.2382
# Epoch 165: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2830, Test Linf Norm: 0.2360
# Epoch 166: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2841, Test Linf Norm: 0.2354
# Epoch 167: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2807, Test Linf Norm: 0.2376
# Epoch 168: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2835, Test Linf Norm: 0.2377
# Epoch 169: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0116, Train Linf Norm: 0.2897, Test Linf Norm: 0.2482
# Epoch 170: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0115, Train Linf Norm: 0.2837, Test Linf Norm: 0.2450
# Epoch 171: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2768, Test Linf Norm: 0.2365
# Epoch 172: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2825, Test Linf Norm: 0.2363
# Epoch 173: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0115, Train Linf Norm: 0.2786, Test Linf Norm: 0.2436
# Epoch 174: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2808, Test Linf Norm: 0.2425
# Epoch 175: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2371
# Epoch 176: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2804, Test Linf Norm: 0.2371
# Epoch 177: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2821, Test Linf Norm: 0.2389
# Epoch 178: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2825, Test Linf Norm: 0.2361
# Epoch 179: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2842, Test Linf Norm: 0.2410
# Epoch 180: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2834, Test Linf Norm: 0.2390
# Epoch 181: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2832, Test Linf Norm: 0.2364
# Epoch 182: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2817, Test Linf Norm: 0.2362
# Epoch 183: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2822, Test Linf Norm: 0.2364
# Epoch 184: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2791, Test Linf Norm: 0.2393
# Epoch 185: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2822, Test Linf Norm: 0.2374
# Epoch 186: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2800, Test Linf Norm: 0.2418
# Epoch 187: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2770, Test Linf Norm: 0.2373
# Epoch 188: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2804, Test Linf Norm: 0.2454
# Epoch 189: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2794, Test Linf Norm: 0.2371
# Epoch 190: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2813, Test Linf Norm: 0.2442
# Epoch 191: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2815, Test Linf Norm: 0.2375
# Epoch 192: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2827, Test Linf Norm: 0.2368
# Epoch 193: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2829, Test Linf Norm: 0.2373
# Epoch 194: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0116, Train Linf Norm: 0.2818, Test Linf Norm: 0.2470
# Epoch 195: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2844, Test Linf Norm: 0.2428
# Epoch 196: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2833, Test Linf Norm: 0.2432
# Epoch 197: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2810, Test Linf Norm: 0.2419
# Epoch 198: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2814, Test Linf Norm: 0.2398
# Epoch 199: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2816, Test Linf Norm: 0.2396
# Epoch 200: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2812, Test Linf Norm: 0.2362
# Epoch 201: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2840, Test Linf Norm: 0.2364
# Epoch 202: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2837, Test Linf Norm: 0.2391
# Epoch 203: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2838, Test Linf Norm: 0.2366
# Epoch 204: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2818, Test Linf Norm: 0.2399
# Epoch 205: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2797, Test Linf Norm: 0.2379
# Epoch 206: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2799, Test Linf Norm: 0.2378
# Epoch 207: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2848, Test Linf Norm: 0.2366
# Epoch 208: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2831, Test Linf Norm: 0.2365
# Epoch 209: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2789, Test Linf Norm: 0.2363
# Epoch 210: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2832, Test Linf Norm: 0.2376
# Epoch 211: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2825, Test Linf Norm: 0.2409
# Epoch 212: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2873, Test Linf Norm: 0.2366
# Epoch 213: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2818, Test Linf Norm: 0.2381
# Epoch 214: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2820, Test Linf Norm: 0.2419
# Epoch 215: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2809, Test Linf Norm: 0.2413
# Epoch 216: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2835, Test Linf Norm: 0.2426
# Epoch 217: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2793, Test Linf Norm: 0.2400
# Epoch 218: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2375
# Epoch 219: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2795, Test Linf Norm: 0.2405
# Epoch 220: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2821, Test Linf Norm: 0.2369
# Epoch 221: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2791, Test Linf Norm: 0.2374
# Epoch 222: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2783, Test Linf Norm: 0.2407
# Epoch 223: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2787, Test Linf Norm: 0.2378
# Epoch 224: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2841, Test Linf Norm: 0.2366
# Epoch 225: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2869, Test Linf Norm: 0.2364
# Epoch 226: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2814, Test Linf Norm: 0.2372
# Epoch 227: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2830, Test Linf Norm: 0.2428
# Epoch 228: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2827, Test Linf Norm: 0.2455
# Epoch 229: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2853, Test Linf Norm: 0.2418
# Epoch 230: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2839, Test Linf Norm: 0.2364
# Epoch 231: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2775, Test Linf Norm: 0.2418
# Epoch 232: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2798, Test Linf Norm: 0.2432
# Epoch 233: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0116, Train Linf Norm: 0.2801, Test Linf Norm: 0.2462
# Epoch 234: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2853, Test Linf Norm: 0.2375
# Epoch 235: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2862, Test Linf Norm: 0.2428
# Epoch 236: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2844, Test Linf Norm: 0.2374
# Epoch 237: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2843, Test Linf Norm: 0.2381
# Epoch 238: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2815, Test Linf Norm: 0.2370
# Epoch 239: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0117, Train Linf Norm: 0.2836, Test Linf Norm: 0.2488
# Epoch 240: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2801, Test Linf Norm: 0.2415
# Epoch 241: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2810, Test Linf Norm: 0.2372
# Epoch 242: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0116, Train Linf Norm: 0.2789, Test Linf Norm: 0.2465
# Epoch 243: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2809, Test Linf Norm: 0.2423
# Epoch 244: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2828, Test Linf Norm: 0.2432
# Epoch 245: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2804, Test Linf Norm: 0.2391
# Epoch 246: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2860, Test Linf Norm: 0.2427
# Epoch 247: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0116, Train Linf Norm: 0.2778, Test Linf Norm: 0.2463
# Epoch 248: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2864, Test Linf Norm: 0.2386
# Epoch 249: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2855, Test Linf Norm: 0.2427
# Epoch 250: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2776, Test Linf Norm: 0.2415
# Epoch 251: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2841, Test Linf Norm: 0.2384
# Epoch 252: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2831, Test Linf Norm: 0.2376
# Epoch 253: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2824, Test Linf Norm: 0.2366
# Epoch 254: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2834, Test Linf Norm: 0.2371
# Epoch 255: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2842, Test Linf Norm: 0.2427
# Epoch 256: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2795, Test Linf Norm: 0.2377
# Epoch 257: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2825, Test Linf Norm: 0.2370
# Epoch 258: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2826, Test Linf Norm: 0.2388
# Epoch 259: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2838, Test Linf Norm: 0.2411
# Epoch 260: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2826, Test Linf Norm: 0.2427
# Epoch 261: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2780, Test Linf Norm: 0.2399
# Epoch 262: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2791, Test Linf Norm: 0.2367
# Epoch 263: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2827, Test Linf Norm: 0.2389
# Epoch 264: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2831, Test Linf Norm: 0.2368
# Epoch 265: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2818, Test Linf Norm: 0.2420
# Epoch 266: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2372
# Epoch 267: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2852, Test Linf Norm: 0.2418
# Epoch 268: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0116, Train Linf Norm: 0.2821, Test Linf Norm: 0.2473
# Epoch 269: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2803, Test Linf Norm: 0.2390
# Epoch 270: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2807, Test Linf Norm: 0.2376
# Epoch 271: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2797, Test Linf Norm: 0.2457
# Epoch 272: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2772, Test Linf Norm: 0.2373
# Epoch 273: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0116, Train Linf Norm: 0.2801, Test Linf Norm: 0.2469
# Epoch 274: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2842, Test Linf Norm: 0.2372
# Epoch 275: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2817, Test Linf Norm: 0.2370
# Epoch 276: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2798, Test Linf Norm: 0.2381
# Epoch 277: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2803, Test Linf Norm: 0.2410
# Epoch 278: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2821, Test Linf Norm: 0.2364
# Epoch 279: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2819, Test Linf Norm: 0.2448
# Epoch 280: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2812, Test Linf Norm: 0.2387
# Epoch 281: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2861, Test Linf Norm: 0.2369
# Epoch 282: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2839, Test Linf Norm: 0.2370
# Epoch 283: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2772, Test Linf Norm: 0.2362
# Epoch 284: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2830, Test Linf Norm: 0.2367
# Epoch 285: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2787, Test Linf Norm: 0.2371
# Epoch 286: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2786, Test Linf Norm: 0.2385
# Epoch 287: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2811, Test Linf Norm: 0.2381
# Epoch 288: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2867, Test Linf Norm: 0.2367
# Epoch 289: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0115, Train Linf Norm: 0.2821, Test Linf Norm: 0.2454
# Epoch 290: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2367
# Epoch 291: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0115, Train Linf Norm: 0.2772, Test Linf Norm: 0.2451
# Epoch 292: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2819, Test Linf Norm: 0.2382
# Epoch 293: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2798, Test Linf Norm: 0.2383
# Epoch 294: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2857, Test Linf Norm: 0.2379
# Epoch 295: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2811, Test Linf Norm: 0.2412
# Epoch 296: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0117, Train Linf Norm: 0.2806, Test Linf Norm: 0.2494
# Epoch 297: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2824, Test Linf Norm: 0.2369
# Epoch 298: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2790, Test Linf Norm: 0.2364
# Epoch 299: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2785, Test Linf Norm: 0.2418
# Epoch 300: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2840, Test Linf Norm: 0.2416
# Epoch 301: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2373
# Epoch 302: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2786, Test Linf Norm: 0.2375
# Epoch 303: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2857, Test Linf Norm: 0.2408
# Epoch 304: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2834, Test Linf Norm: 0.2369
# Epoch 305: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2811, Test Linf Norm: 0.2368
# Epoch 306: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2783, Test Linf Norm: 0.2367
# Epoch 307: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2840, Test Linf Norm: 0.2375
# Epoch 308: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2794, Test Linf Norm: 0.2365
# Epoch 309: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2809, Test Linf Norm: 0.2393
# Epoch 310: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2826, Test Linf Norm: 0.2400
# Epoch 311: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2841, Test Linf Norm: 0.2370
# Epoch 312: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2837, Test Linf Norm: 0.2368
# Epoch 313: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0115, Train Linf Norm: 0.2860, Test Linf Norm: 0.2443
# Epoch 314: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2786, Test Linf Norm: 0.2365
# Epoch 315: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2759, Test Linf Norm: 0.2448
# Epoch 316: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2825, Test Linf Norm: 0.2375
# Epoch 317: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0115, Train Linf Norm: 0.2818, Test Linf Norm: 0.2453
# Epoch 318: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2870, Test Linf Norm: 0.2377
# Epoch 319: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2816, Test Linf Norm: 0.2416
# Epoch 320: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2782, Test Linf Norm: 0.2393
# Epoch 321: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2804, Test Linf Norm: 0.2373
# Epoch 322: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2802, Test Linf Norm: 0.2371
# Epoch 323: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2823, Test Linf Norm: 0.2420
# Epoch 324: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2829, Test Linf Norm: 0.2367
# Epoch 325: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0114, Train Linf Norm: 0.2845, Test Linf Norm: 0.2413
# Epoch 326: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2792, Test Linf Norm: 0.2433
# Epoch 327: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2828, Test Linf Norm: 0.2384
# Epoch 328: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2809, Test Linf Norm: 0.2366
# Epoch 329: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2814, Test Linf Norm: 0.2399
# Epoch 330: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0111, Train Linf Norm: 0.2878, Test Linf Norm: 0.2361
# Epoch 331: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2822, Test Linf Norm: 0.2414
# Epoch 332: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2810, Test Linf Norm: 0.2376
# Epoch 333: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2828, Test Linf Norm: 0.2360
# Epoch 334: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2854, Test Linf Norm: 0.2362
# Epoch 335: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2831, Test Linf Norm: 0.2365
# Epoch 336: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2810, Test Linf Norm: 0.2359
# Epoch 337: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2836, Test Linf Norm: 0.2367
# Epoch 338: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2821, Test Linf Norm: 0.2371
# Epoch 339: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2804, Test Linf Norm: 0.2366
# Epoch 340: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2788, Test Linf Norm: 0.2396
# Epoch 341: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2824, Test Linf Norm: 0.2389
# Epoch 342: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2867, Test Linf Norm: 0.2376
# Epoch 343: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2789, Test Linf Norm: 0.2366
# Epoch 344: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2824, Test Linf Norm: 0.2431
# Epoch 345: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2790, Test Linf Norm: 0.2400
# Epoch 346: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2836, Test Linf Norm: 0.2386
# Epoch 347: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2810, Test Linf Norm: 0.2378
# Epoch 348: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2769, Test Linf Norm: 0.2386
# Epoch 349: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2845, Test Linf Norm: 0.2373
# Epoch 350: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2779, Test Linf Norm: 0.2370
# Epoch 351: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2831, Test Linf Norm: 0.2420
# Epoch 352: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2819, Test Linf Norm: 0.2417
# Epoch 353: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2795, Test Linf Norm: 0.2434
# Epoch 354: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2831, Test Linf Norm: 0.2416
# Epoch 355: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2833, Test Linf Norm: 0.2371
# Epoch 356: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2806, Test Linf Norm: 0.2384
# Epoch 357: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2769, Test Linf Norm: 0.2371
# Epoch 358: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2832, Test Linf Norm: 0.2360
# Epoch 359: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2826, Test Linf Norm: 0.2367
# Epoch 360: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2814, Test Linf Norm: 0.2363
# Epoch 361: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2811, Test Linf Norm: 0.2383
# Epoch 362: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2844, Test Linf Norm: 0.2365
# Epoch 363: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2844, Test Linf Norm: 0.2384
# Epoch 364: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0115, Train Linf Norm: 0.2876, Test Linf Norm: 0.2437
# Epoch 365: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2854, Test Linf Norm: 0.2387
# Epoch 366: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2802, Test Linf Norm: 0.2381
# Epoch 367: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2787, Test Linf Norm: 0.2414
# Epoch 368: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2790, Test Linf Norm: 0.2396
# Epoch 369: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2368
# Epoch 370: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0113, Train Linf Norm: 0.2856, Test Linf Norm: 0.2405
# Epoch 371: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2800, Test Linf Norm: 0.2367
# Epoch 372: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0116, Train Linf Norm: 0.2833, Test Linf Norm: 0.2468
# Epoch 373: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2800, Test Linf Norm: 0.2369
# Epoch 374: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0115, Train Linf Norm: 0.2837, Test Linf Norm: 0.2442
# Epoch 375: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0113, Train Linf Norm: 0.2762, Test Linf Norm: 0.2412
# Epoch 376: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2783, Test Linf Norm: 0.2370
# Epoch 377: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0134, Test L1 Norm: 0.0112, Train Linf Norm: 0.2901, Test Linf Norm: 0.2368
# Epoch 378: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2841, Test Linf Norm: 0.2359
# Epoch 379: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2783, Test Linf Norm: 0.2426
# Epoch 380: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2835, Test Linf Norm: 0.2378
# Epoch 381: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2829, Test Linf Norm: 0.2373
# Epoch 382: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2772, Test Linf Norm: 0.2372
# Epoch 383: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0114, Train Linf Norm: 0.2788, Test Linf Norm: 0.2434
# Epoch 384: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2789, Test Linf Norm: 0.2381
# Epoch 385: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0111, Train Linf Norm: 0.2790, Test Linf Norm: 0.2365
# Epoch 386: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2818, Test Linf Norm: 0.2372
# Epoch 387: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2860, Test Linf Norm: 0.2373
# Epoch 388: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2820, Test Linf Norm: 0.2375
# Epoch 389: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0111, Train Linf Norm: 0.2831, Test Linf Norm: 0.2360
# Epoch 390: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2822, Test Linf Norm: 0.2425
# Epoch 391: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2866, Test Linf Norm: 0.2413
# Epoch 392: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2824, Test Linf Norm: 0.2384
# Epoch 393: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0115, Train Linf Norm: 0.2797, Test Linf Norm: 0.2444
# Epoch 394: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2805, Test Linf Norm: 0.2370
# Epoch 395: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0112, Train Linf Norm: 0.2840, Test Linf Norm: 0.2371
# Epoch 396: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2792, Test Linf Norm: 0.2370
# Epoch 397: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.2813, Test Linf Norm: 0.2434
# Epoch 398: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0112, Train Linf Norm: 0.2819, Test Linf Norm: 0.2378
# Epoch 399: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0113, Train Linf Norm: 0.2830, Test Linf Norm: 0.2412
# Epoch 400: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0131, Test L1 Norm: 0.0112, Train Linf Norm: 0.2796, Test Linf Norm: 0.2374

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
  output_activation_loaded = nn.ReLU()
else:
  output_activation_loaded = nn.Identity()

# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
if torch.cuda.is_available():
 net_loaded.load_state_dict(torch.load("net.pth"))
else: 
  net_loaded.load_state_dict(torch.load("net.pth", map_location=torch.device('cpu')))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if optimizer_name_loaded == "SGD":
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "Adam":
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
if torch.cuda.is_available():
  optimizer_loaded_state_dict = torch.load("optimizer.pth")
else:
  optimizer_loaded_state_dict = torch.load("optimizer.pth", map_location=torch.device('cpu'))

# load the scheduler from the .pth file
if torch.cuda.is_available():
  scheduler_loaded_state_dict = torch.load("scheduler.pth")
else: 
  scheduler_loaded_state_dict = torch.load("scheduler.pth", map_location=torch.device('cpu'))
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size = scheduler_loaded_state_dict["step_size"]
  gamma = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode = scheduler_loaded_state_dict["mode"]
  factor = scheduler_loaded_state_dict["factor"]
  patience = scheduler_loaded_state_dict["patience"]
  threshold = scheduler_loaded_state_dict["threshold"]
  min_lr = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode, factor=factor, patience=patience, threshold=threshold, min_lr=min_lr
                )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
train_losses_loaded
test_losses_loaded
train_metrics_loaded
test_metrics_loaded
# Out:
# 32
# 400
# 'MSE'
# 'Adam'
# 'ReduceLROnPlateau'
# [600, 200]
# 2
# 'Sigmoid'
# 'ReLU'
# 0.006
# Sigmoid()
# ReLU()
# Net(
#   (hidden_activation): Sigmoid()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=600, bias=True)
#     (1): Linear(in_features=600, out_features=200, bias=True)
#     (2): Linear(in_features=200, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation', Sigmoid()),
#               ('output_activation', ReLU()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=3, out_features=600, bias=True)
#                  (1): Linear(in_features=600, out_features=200, bias=True)
#                  (2): Linear(in_features=200, out_features=1, bias=True)
#                ))]),
#  'n_layers': 2,
#  'n_units': [600, 200]}
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.006
#     maximize: False
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.006,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0,
#   'amsgrad': False,
#   'maximize': False,
#   'foreach': None,
#   'capturable': False,
#   'differentiable': False,
#   'fused': None},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#Adam.zero_grad',
#  'state': defaultdict(dict, {}),
#  'param_groups': [{'params': [Parameter containing:
#     tensor([[ 1.9683e-02,  6.6910e-01, -1.0763e+00],
#             [ 4.7322e-03,  4.1026e-01, -8.4866e-01],
#             [ 7.8186e-03,  6.7946e-01, -1.0336e+00],
#             ...,
#             [-4.5930e-03,  6.0222e-01, -9.1392e-01],
#             [-1.1787e+00, -2.3373e+00,  4.2116e-01],
#             [ 1.1814e-03,  6.2800e-01, -9.4704e-01]], requires_grad=True),
#     Parameter containing:
#     tensor([-10.9742, -11.0311, -11.6212,  -2.9740, -11.2726,  -2.1250,  -5.9841,
#              -1.4977,  -4.0242,  -1.1046,  -2.4409, -11.3583,  -1.6901,   0.1997,
#              -6.5848,  -1.6376,  -1.3428, -12.3658,  -9.2188,   1.0427,  -2.2368,
#              -0.6974,  -1.5252,  -4.6259,  -9.9853,  -5.8443,  -2.3777,  -2.2247,
#             -11.9492, -10.7338,  -4.3188,  -1.5658,  -5.3648, -11.4656,  -1.4165,
#             -12.0911, -12.3597,  -1.6724,  -3.4340,   1.5967,  -9.7749,  -2.1293,
#              -0.2582,  -3.2644, -12.2626, -11.6188, -11.9440, -10.7337,  -1.2041,
#             -12.5881, -12.0196,  -3.7845, -11.2184,  -7.7486,  -9.9219, -12.4863,
#              -6.8359,  -9.0209,  -3.7594, -12.1183,  -1.9529,  -2.7827,  -2.0623,
#              -4.1348, -11.7939,  -8.5721,  -4.0051,  -1.6643, -11.0176, -10.6538,
#              -2.7094, -12.0158, -11.9769, -10.9664,  -4.6459,  -9.9030,   1.9683,
#             -12.5454, -10.5908, -10.1271,  -3.9880, -10.0548,  -5.8133, -12.4453,
#              -1.0231,  -9.5692,  -8.1147,  -1.9958, -10.5011,  -9.6281,  -8.2883,
#              -5.5556,   2.0124,  -8.3309,  -4.5579, -11.8351,  -1.3813, -11.5445,
#              -2.8024,  -1.6159, -11.6331,  -5.3705,  -4.6210,  -9.1789, -12.2943,
#             -10.2017, -10.4124,  -8.2899, -10.5113, -12.4799,  -3.0149,  -2.0745,
#             -12.5896,  -1.6071,  -1.3489, -12.1448, -10.9363,  -9.4093, -12.0267,
#              -1.6447, -11.3452, -12.0030, -12.4679,  -4.0730, -10.8142,  -1.9000,
#              -1.1457,  -2.4455,  -5.0283,  -3.1196,  -7.0094, -10.8228, -11.0301,
#             -11.3203, -10.4507, -12.2004, -11.6495, -11.7596, -12.5704, -12.2161,
#             -11.1327,  -6.5593, -12.2936, -12.4314,  -6.6305,  -1.2678,  -1.3749,
#              -1.9393,  -1.9583,   1.0118,  -2.6455, -11.3237, -11.8226,  -5.2808,
#              -2.8814,  -9.9802,   0.1956,  -8.7894,  -3.5070,  -5.1650,  -2.7487,
#             -10.8183,  -2.3021,  -2.2103, -11.6408, -12.1970, -10.4793,  -1.2703,
#              -4.5846,  -2.2285,  -3.7368,  -1.2553,  -2.7551,  -4.1441, -11.3636,
#             -12.5585, -12.2652,  -1.4739, -11.8739,  -9.5413, -11.3857, -12.2545,
#              -2.9457,  -4.2276, -11.2270,  -0.6914,  -3.6959,  -8.7902,  -1.6832,
#              -0.9618, -12.4988,  -2.5408,  -3.5402, -12.2772,  -1.1598,  -1.5019,
#             -11.1400, -11.5910,  -1.7805,  -4.6176,  -2.1945,  -9.1956,  -1.6628,
#             -11.7692, -12.3535,  -1.4908, -10.2081,  -1.8274,  -9.3898,  -4.5394,
#              -2.2901,  -5.2796,  -3.2292, -10.2429,  -4.3475,  -6.0388,  -3.2424,
#             -11.9959,  -2.3585, -10.4342,  -5.2905,  -9.0763, -12.0480,  -2.9697,
#             -11.7517, -10.7949,  -1.0998,  -8.5814,  -6.8508, -10.6907,  -4.0348,
#             -10.8031,  -3.1437,  -4.2699,  -1.8046, -10.8001, -11.7349,  -1.9325,
#              -9.0619, -11.6565,  -7.9333,  -0.4603, -12.1702,  -2.3767,  -9.3873,
#             -10.8100, -11.2745,  -2.0358, -11.6203,  -7.6409,   0.9496,  -4.4299,
#             -11.9566,   1.6114, -12.5174,  -2.6354, -11.7854, -11.6520, -12.4208,
#              -2.0145, -11.9630, -12.2579,  -9.4917, -12.1717,  -4.9807, -12.0031,
#             -10.3188, -10.1584, -12.2926,  -3.0376, -12.4629,  -3.9551, -12.1198,
#             -12.0591,  -8.7546, -12.0216,  -7.4618,  -6.6089,  -8.6952,  -8.2425,
#             -12.2828,  -2.7948,   0.5608,  -2.7715,  -1.4938, -11.8777,  -7.2646,
#              -3.2702,  -2.1316, -11.0598,  -2.7281,  -4.5794,  -2.3350,  -1.2404,
#              -4.3087,  -5.0274,  -1.5458, -10.8599,  -3.8515,  -8.4831,  -3.4503,
#              -4.3158,  -2.4633,  -4.5680,  -4.1273,  -1.5215,   0.4911, -12.0469,
#              -7.2327,  -1.3556,  -2.6729,  -5.8175, -11.9554, -12.4311,   0.5659,
#             -11.8275, -11.1037, -11.7449, -10.2584,  -3.4688,  -0.2367,  -3.3707,
#              -4.0902, -11.8920,  -3.0545, -12.1096, -12.2009, -12.5846,  -1.9819,
#             -11.9423,  -9.9155,  -2.7075, -12.0620, -11.4157,  -1.4118,   0.3742,
#              -2.3803,  -3.1746,  -3.4491,  -0.3094,  -2.8814,  -3.1851, -10.2645,
#              -4.4976,  -6.9314, -10.0886,  -3.2275, -12.2914,  -6.4859,  -3.0061,
#              -1.6555,  -9.1195,  -1.5825,  -2.4067,  -0.3489,  -2.7417,  -0.2621,
#              -7.4999, -12.3122, -10.9567,  -2.3027,  -2.4350, -10.1663, -10.7953,
#              -3.0884,  -1.2954,  -7.5321,  -6.0889,  -1.2646,  -0.9644,  -1.2132,
#              -9.0625,  -5.1569,  -7.6879,  -7.3314,  -4.5520,  -3.1429,  -4.2805,
#             -11.7460, -12.0354,  -3.2813, -10.6135,  -3.5437, -12.4787,  -7.9719,
#              -2.5808, -12.1606, -11.7200,  -7.3197, -10.1819,  -6.1877, -12.4379,
#             -10.8430,  -1.2594,  -1.1495,  -1.1504, -12.2910, -11.6186,  -4.5397,
#             -12.1674, -11.7925, -10.5225, -11.2087,  -8.9983, -11.8924, -12.0330,
#              -1.6719,  -5.1752, -11.8882,  -1.6977, -12.3507,  -2.6073, -11.9016,
#             -12.4702, -12.0117,  -6.5908,  -1.7826, -11.9128,  -5.3717,  -1.7529,
#              -0.5544,  -5.7499, -12.1263,  -3.0676,  -8.8874,  -5.4960,  -9.9148,
#              -5.9673,  -9.5774,  -1.3174, -10.5756,  -8.2572,  -2.8038, -10.3785,
#             -10.3567, -11.5704,  -8.9947,  -2.9655,  -1.8352,  -1.2418, -10.7593,
#              -2.4387, -11.7773, -11.2213,  -3.5165,  -2.6055,  -2.5142, -11.8907,
#              -1.8554, -10.2430,  -8.8575,  -7.8699, -11.1664,  -1.4596, -12.1185,
#              -3.9296,  -6.0681,  -3.3416,  -5.8295,  -4.0853,  -2.4867,  -4.9199,
#             -11.7680, -11.2016,  -7.6629, -11.1982, -12.5241,  -1.2940,  -3.7157,
#              -0.1531,  -0.6862,  -7.5271, -11.6080, -10.9572, -10.2286, -11.9771,
#              -2.6908,  -7.9012,  -5.2164,   0.2542, -12.0465, -12.5299, -11.8889,
#              -2.0367, -11.7509, -11.8646,  -1.7160,  -1.8159, -12.5471, -11.9513,
#             -12.2262,  -1.8483, -12.3987,  -7.4550, -11.2195,  -0.9141,  -3.0295,
#              -8.4360, -10.4549,  -1.7639,  -4.5717,  -6.4094,  -2.7567,  -6.8359,
#              -2.4241,  -5.4252,  -9.9271,  -1.1355, -11.0877,  -4.7588,  -8.0734,
#              -2.1125, -11.2125,  -5.7958,   1.4078,  -0.1483,  -0.9378, -12.3998,
#              -2.3485, -11.0730,  -7.7488, -11.3663,  -2.9883,  -0.3790,  -6.3478,
#             -10.1026,  -1.3916,  -5.6613, -11.7623,  -1.4889, -10.3853,  -1.5857,
#              -6.4497,  -1.0473, -11.5557,  -4.1005,  -9.4283,  -2.4196,  -3.2962,
#               0.3094,  -1.3436,  -1.5879,  -6.2583,  -2.0871, -10.6641,  -7.4628,
#              -1.3937,  -4.9885,  -4.1553,  -4.3187,  -4.0483, -12.4014,  -5.4300,
#             -11.4148,  -3.1734, -10.4662, -10.8367, -12.2516, -12.2270,  -5.5193,
#              -3.2610,  -1.6946,  -3.5406,  -3.7467,  -6.1957,  -5.3227,   1.0694,
#              -2.4538, -12.1303,  -6.1761,  -2.6990,  -2.5247, -11.9415,  -8.5222,
#              -3.4886,   0.9334, -12.4095,  -2.8314,  -3.0684,  -4.8144,  -0.6026,
#             -12.2365,  -2.7316, -11.3046,  -1.7373,  -2.4080,  -8.2558,  -2.1799,
#              -2.1007,  -1.3083, -11.2753,  -5.5313,  -2.6019,  -2.8167, -11.1191,
#              -0.9126, -11.6133, -12.2474,  -4.4714, -12.0916], requires_grad=True),
#     Parameter containing:
#     tensor([[ 7.3345e-02,  2.6370e-01,  7.5688e-03,  ...,  2.8587e-02,
#               3.6812e+00,  2.7528e-02],
#             [-5.8483e-02, -3.6190e-02, -6.7512e-02,  ..., -6.2708e-02,
#              -1.2147e-01, -6.4166e-02],
#             [-8.5455e-02, -1.7845e-01, -7.5367e-02,  ..., -1.7858e-02,
#              -1.4399e-01, -7.2447e-02],
#             ...,
#             [ 6.3902e-02,  1.5026e-01,  1.3048e-01,  ...,  9.4750e-02,
#               8.9123e-02,  6.9591e-02],
#             [ 1.0850e-01,  3.7262e-01,  1.7443e-02,  ...,  3.4963e-02,
#               3.1186e-01,  5.0164e-02],
#             [ 2.6539e-02, -5.8126e-02,  5.1346e-02,  ..., -2.5071e-03,
#              -1.2206e-01,  5.8104e-02]], requires_grad=True),
#     Parameter containing:
#     tensor([-0.3785,  0.2642, -0.6715, -0.6740, -0.4738, -0.7037, -0.7143,  0.0326,
#             -0.1861, -1.1240, -0.7158, -0.5420, -0.7350,  0.4309, -0.7336, -0.6496,
#             -0.5814,  0.2610, -0.6437,  0.0190,  0.4091,  0.3563,  0.3283, -0.7041,
#              0.3983, -0.6868, -0.6624, -0.1969, -0.5062, -0.7666, -0.6867, -0.7044,
#             -0.6969, -0.6692, -0.6245, -0.6722, -0.7189, -0.7880, -0.6754, -0.6736,
#              0.2633,  0.3678, -0.7000, -0.7024, -0.7104, -0.6929, -0.7258,  0.2170,
#              0.1977, -0.6766, -0.6678, -0.6347, -0.6735, -0.6293, -0.7569, -0.7004,
#             -0.6958,  0.0688, -0.7317, -0.6617,  0.3272, -0.7034,  0.3393,  0.0186,
#              0.1863, -0.5082, -0.1925, -0.7230,  0.3365, -0.6702, -0.0687, -0.7188,
#             -0.6803, -0.6646,  0.4145, -1.0867,  0.3022,  0.3828, -0.6708, -0.7890,
#              0.2208, -0.0877, -0.7056, -0.7519,  0.1443, -0.6383, -0.6357, -0.7207,
#             -0.7019, -0.6918, -0.5537, -0.1976, -0.0520, -0.7186,  0.3459, -0.7054,
#             -0.6512, -0.6485,  0.0528,  0.3281,  0.2704, -0.2084, -0.7268,  0.3250,
#             -0.6984, -0.4916, -0.7244, -0.6740, -0.6789, -0.5577,  0.0768, -0.7033,
#             -0.3733, -0.7673, -0.7434,  0.0537, -0.2108, -0.4015, -0.6556, -0.6418,
#             -0.7278, -0.6942, -0.6974,  0.3781, -0.5092, -0.3229, -0.6858, -0.7071,
#             -0.7185, -0.4566,  0.2242,  0.4099, -0.6835, -0.7743, -0.7160, -0.8185,
#             -0.6401, -0.6709, -0.6537, -0.3793, -0.7557, -0.0077,  0.3134, -0.2319,
#              0.0929, -0.7135,  0.1582,  0.6197, -0.7214,  0.2973,  0.3449,  0.2720,
#             -0.6822, -0.6634, -0.6989, -0.8104,  0.3592, -0.6323, -0.7581,  0.2514,
#             -0.0504,  0.2391,  0.2032,  0.1314,  0.5679, -0.7441, -0.6857, -0.6831,
#              0.2855, -0.6741,  0.3523, -0.7213,  0.2615, -0.6414, -0.6689, -0.6533,
#             -0.7377, -0.1434,  0.3431, -0.7239, -0.6948,  0.3417,  0.4151, -0.2291,
#             -0.5070, -0.7844, -0.6901,  0.3929, -0.3019,  0.0374, -0.7132, -0.7133,
#             -0.6668, -0.5334,  0.5848,  0.3482,  0.3952,  0.3612, -0.0097, -0.6657],
#            requires_grad=True),
#     Parameter containing:
#     tensor([[ 0.0147,  1.9193,  0.3932,  0.3656,  1.4325,  0.3812,  0.3318,  0.0227,
#               0.0259,  0.1367,  0.3806, -0.5711,  0.3445, -0.0344,  0.3716,  0.4243,
#               0.4875, -0.0251,  0.3851,  0.0264, -0.0351, -0.0352, -0.0215,  0.3870,
#              -0.0342,  0.3461,  0.3845,  0.8671,  0.0612,  0.3517,  0.3858,  0.3875,
#               0.3773,  0.3585,  0.4085,  0.3806,  0.3683,  0.2863,  0.3508,  0.3623,
#               0.0610, -0.0369,  0.3897,  0.3537,  0.3572,  0.3392,  0.6746, -0.0208,
#              -0.0232,  0.4201,  0.4087,  0.4714,  0.3835,  0.4676,  0.3455,  0.4004,
#               0.3387,  0.2150,  0.3605,  0.3778, -0.0280,  0.3909, -0.0268,  0.0238,
#               0.0210,  0.1010,  0.0165,  0.2844, -0.0234,  0.3631,  0.0236,  0.3622,
#               0.3658,  0.3987, -0.0276, -0.0204,  0.0209, -0.0373,  0.3658,  0.2793,
#              -1.3099, -0.3512,  0.3846,  0.3524,  0.0294,  0.3923,  0.4132,  0.3715,
#               0.3832,  0.3641,  0.5045, -0.8954,  0.0272,  0.3517, -0.0319,  0.3969,
#               0.3900,  0.3783,  0.0231, -0.0253, -0.0215,  0.0309,  0.3270, -0.0231,
#               0.3798,  0.5169,  0.3357,  0.3831,  0.3549,  0.5037,  1.8187,  0.3786,
#               0.7285,  0.2611,  0.3116,  3.1544,  0.0242,  0.6523,  0.3794,  0.3885,
#               0.3565,  0.3557,  0.3829, -0.0339,  0.5859,  2.8106,  0.3590,  0.3958,
#               0.3802,  0.6916,  0.0316, -0.0346,  0.3732,  0.2725,  0.3608,  0.2708,
#               0.4460,  0.3875,  0.3925,  0.7050,  0.3404,  0.0221, -0.0239,  0.8139,
#               0.0733,  0.3537, -0.0161,  0.1899,  0.2776, -0.0252, -0.0299,  0.0110,
#               0.3620,  0.3795,  0.4025,  0.1338, -0.0249,  0.4009,  0.3432, -0.0195,
#               0.0087, -0.0160, -0.0166, -0.0173,  0.1268,  0.3577,  0.3845,  0.3673,
#              -0.0261,  0.3738, -0.0335,  0.2845, -0.0278,  0.3889,  0.3657,  0.4053,
#               0.3779,  2.8964, -0.0253,  0.3822,  0.3715, -0.0298, -0.0320,  0.0349,
#               0.5290,  0.2986,  0.4012, -0.0245,  0.0895,  0.0144,  0.3996,  0.3504,
#               0.3726,  0.5133,  0.4044, -0.0274, -0.0233, -0.0307,  0.0249,  0.4702]],
#            requires_grad=True),
#     Parameter containing:
#     tensor([-0.0045], requires_grad=True)],
#    'lr': 0.006,
#    'betas': (0.9, 0.999),
#    'eps': 1e-08,
#    'weight_decay': 0,
#    'amsgrad': False,
#    'maximize': False,
#    'foreach': None,
#    'capturable': False,
#    'differentiable': False,
#    'fused': None}],
#  '_warned_capturable_if_run_uncaptured': True}
# {'factor': 0.5,
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 0.006
#      maximize: False
#      weight_decay: 0
#  ),
#  'min_lrs': [1e-06],
#  'patience': 5,
#  'verbose': False,
#  'cooldown': 0,
#  'cooldown_counter': 0,
#  'mode': 'min',
#  'threshold': 0.0005,
#  'threshold_mode': 'rel',
#  'best': 9.850276625002153e-06,
#  'num_bad_epochs': 5,
#  'mode_worse': inf,
#  'eps': 1e-08,
#  'last_epoch': 400,
#  '_last_lr': [1e-06]}
# [0.6689629582898692,
#  0.0224862234469503,
#  0.0148005197587888,
#  0.0139427725197747,
#  0.0109685834532137,
#  0.010757406572299,
#  0.0076104256467428,
#  0.0066611046953126,
#  0.0071921351455035,
#  0.005622419585823,
#  0.0053003691853955,
#  0.0051014909618184,
#  0.0053965922835399,
#  0.0039572031654999,
#  0.0045410810803063,
#  0.0032948843301041,
#  0.0037701407254789,
#  0.0036693603076622,
#  0.0046327533262956,
#  0.0037579919109935,
#  0.0028089085431362,
#  0.0029550376165076,
#  0.00264820266522,
#  0.00285871338477,
#  0.0026165663725929,
#  0.0026960970032436,
#  0.0029375684479513,
#  0.0022134955222718,
#  0.0022331738587934,
#  0.0023150425947271,
#  0.0005683155331731,
#  0.0007289340340183,
#  0.000647092779589,
#  0.000645136505051,
#  0.0006634348802239,
#  0.0006022287115716,
#  0.0006654317543609,
#  0.000574474690124,
#  0.0001649452832476,
#  0.0002290868443626,
#  0.0002216506895369,
#  0.0001928621416409,
#  0.000206481351528,
#  0.0001949381123755,
#  0.0001744360627344,
#  0.0001926920841178,
#  0.0001813979182945,
#  0.0001869190900222,
#  0.0001929362484472,
#  0.0001606957370539,
#  0.0001718258349355,
#  0.0001751271351218,
#  0.0001751959717737,
#  0.0001696129753174,
#  0.0001630900879492,
#  0.0001647631542327,
#  0.0001570935114705,
#  0.0001753399079159,
#  0.0001530367295345,
#  0.0001658112577893,
#  0.0001409101227283,
#  0.0001733814862094,
#  0.0001607068472181,
#  4.934612016986648e-05,
#  6.947724500896583e-05,
#  6.608965326850011e-05,
#  6.348246869820286e-05,
#  6.480449994523952e-05,
#  6.28954203104513e-05,
#  5.982766466822796e-05,
#  5.976558029760781e-05,
#  5.972059361265565e-05,
#  6.092724969985284e-05,
#  5.83936802813696e-05,
#  5.9744527306611416e-05,
#  6.544470118351455e-05,
#  5.6744589234403976e-05,
#  2.8626618576527108e-05,
#  3.1649217793528805e-05,
#  3.0496163394673203e-05,
#  3.092470536666952e-05,
#  3.077254705312953e-05,
#  2.977708466078184e-05,
#  3.0030021389575267e-05,
#  2.9428289386123653e-05,
#  2.911761551731615e-05,
#  2.99171862186995e-05,
#  1.9716094492105183e-05,
#  1.9991293110797416e-05,
#  1.963639551631786e-05,
#  2.047731361253682e-05,
#  1.9641740574661525e-05,
#  2.019693803340488e-05,
#  1.953132943408491e-05,
#  1.9272606183494644e-05,
#  1.9049499163338623e-05,
#  1.958628088414116e-05,
#  1.8693968250045143e-05,
#  1.930634380933043e-05,
#  1.483599299672278e-05,
#  1.5500817352858576e-05,
#  1.5160821326026052e-05,
#  1.5084122760526952e-05,
#  1.4882631697946636e-05,
#  1.4923349405216868e-05,
#  1.5001904065684358e-05,
#  1.4678487265246077e-05,
#  1.4673152204886718e-05,
#  1.487717937980051e-05,
#  1.4619252412921924e-05,
#  1.4556437503779306e-05,
#  1.4707555976110595e-05,
#  1.4538742351851396e-05,
#  1.4195460985320096e-05,
#  1.4543512234922674e-05,
#  1.4135259627801132e-05,
#  1.4103245378191789e-05,
#  1.402820241974041e-05,
#  1.3896440262669785e-05,
#  1.4098931361240829e-05,
#  1.2205081643605809e-05,
#  1.2514853933134872e-05,
#  1.2285397203686444e-05,
#  1.2315931766897849e-05,
#  1.2306024807094218e-05,
#  1.2204763607132918e-05,
#  1.2276092209776834e-05,
#  1.2237946036839277e-05,
#  1.2164697698790403e-05,
#  1.210761483062015e-05,
#  1.2148325141879467e-05,
#  1.2054503368744915e-05,
#  1.2102904352104816e-05,
#  1.1260545072855164e-05,
#  1.1194444147076866e-05,
#  1.1231496606797009e-05,
#  1.1210671492517577e-05,
#  1.124827586536412e-05,
#  1.1184446377592394e-05,
#  1.1190488093325258e-05,
#  1.0730811706707754e-05,
#  1.0727009339188954e-05,
#  1.072696618257396e-05,
#  1.0804267588537186e-05,
#  1.0712728410089766e-05,
#  1.0694692945071438e-05,
#  1.0706260423103232e-05,
#  1.0703682164876228e-05,
#  1.0708655293365157e-05,
#  1.0674812967226898e-05,
#  1.065971260131846e-05,
#  1.045993077368621e-05,
#  1.0433821653077756e-05,
#  1.044810708053774e-05,
#  1.0444254284811905e-05,
#  1.0423158951107324e-05,
#  1.0428607721769368e-05,
#  1.04055056571724e-05,
#  1.03027479019147e-05,
#  1.030714972084752e-05,
#  1.0299135341483632e-05,
#  1.0311841979000749e-05,
#  1.0318117936003543e-05,
#  1.030046939949898e-05,
#  1.0301934530798462e-05,
#  1.029341128660235e-05,
#  1.0292976199070836e-05,
#  1.0288464543646116e-05,
#  1.028526735012747e-05,
#  1.0285834494334268e-05,
#  1.0273505030363596e-05,
#  1.0291886780214554e-05,
#  1.0218693827573589e-05,
#  1.0209916006897402e-05,
#  1.0216623426094884e-05,
#  1.0204909731237422e-05,
#  1.0209495824892655e-05,
#  1.0207992890627793e-05,
#  1.0203063634617138e-05,
#  1.0204089724174992e-05,
#  1.021153840470106e-05,
#  1.0205561152542942e-05,
#  1.0185177598395967e-05,
#  1.0187582130583905e-05,
#  1.018449535004038e-05,
#  1.0184173331708737e-05,
#  1.0178885754248767e-05,
#  1.0178795544834427e-05,
#  1.0182685385507284e-05,
#  1.0182864254147716e-05,
#  1.0177483924235276e-05,
#  1.0182210204402507e-05,
#  1.0177302859165138e-05,
#  1.017455624878494e-05,
#  1.017520143609545e-05,
#  1.0180741988870067e-05,
#  1.0174484306935484e-05,
#  1.0172703846365038e-05,
#  1.01704332562349e-05,
#  1.017577354768946e-05,
#  1.0175664881990088e-05,
#  1.016816357641801e-05,
#  1.0170083929551766e-05,
#  1.0170329183620196e-05,
#  1.0174911946887732e-05,
#  1.0168713173334254e-05,
#  1.0160122239176415e-05,
#  1.0163665302752631e-05,
#  1.015842479046114e-05,
#  1.0164124897983128e-05,
#  1.016334487212589e-05,
#  1.0159178710273409e-05,
#  1.0162338874397392e-05,
#  1.0160648376313474e-05,
#  1.0164629480368604e-05,
#  1.0158061615220504e-05,
#  1.0161145262827632e-05,
#  1.0158050453537724e-05,
#  1.0153794313828258e-05,
#  1.0155551911884686e-05,
#  1.0154563350442914e-05,
#  1.016033291534768e-05,
#  1.0152236528574576e-05,
#  1.0152522267162569e-05,
#  1.0153998316309298e-05,
#  1.0152514000401424e-05,
#  1.015027406592708e-05,
#  1.0143981882720254e-05,
#  1.0152734032089938e-05,
#  1.0148998102704354e-05,
#  1.0151995138312486e-05,
#  1.0143373280607194e-05,
#  1.0151886225685302e-05,
#  1.0145267461030017e-05,
#  1.0143297818285644e-05,
#  1.0142453983371524e-05,
#  1.014653040738267e-05,
#  1.0142842785535322e-05,
#  1.0144393595237487e-05,
#  1.0139829065064988e-05,
#  1.0140953491645632e-05,
#  1.013848332231646e-05,
#  1.0136190935645572e-05,
#  1.0139442363015404e-05,
#  1.0136692911237332e-05,
#  1.013924965491242e-05,
#  1.0133397915160458e-05,
#  1.0126712277997286e-05,
#  1.012776140250935e-05,
#  1.0136496495397297e-05,
#  1.0129268715900252e-05,
#  1.0135530627394472e-05,
#  1.0129254423372914e-05,
#  1.013417522635791e-05,
#  1.0130819210735351e-05,
#  1.013168058852898e-05,
#  1.0123724804725498e-05,
#  1.0123350753747218e-05,
#  1.0129697147112891e-05,
#  1.0125752450039727e-05,
#  1.0125657854860038e-05,
#  1.012185419413072e-05,
#  1.012139518143158e-05,
#  1.01253349128001e-05,
#  1.0119573079737166e-05,
#  1.0128616860220065e-05,
#  1.0124135011483305e-05,
#  1.0116208112776802e-05,
#  1.0121831077412936e-05,
#  1.011754934252167e-05,
#  1.0116296062551556e-05,
#  1.0115867962213088e-05,
#  1.0115780196611014e-05,
#  1.0114095985409222e-05,
#  1.0119121826755871e-05,
#  1.0112395574151378e-05,
#  1.0108632411356666e-05,
#  1.0116359424500844e-05,
#  1.0104459697413404e-05,
#  1.0106301977430122e-05,
#  1.010932153367321e-05,
#  1.0105832822409864e-05,
#  1.0103434716347692e-05,
#  1.01088968568547e-05,
#  1.0111059345763352e-05,
#  1.0105740276458164e-05,
#  1.0107388839969644e-05,
#  1.0107986071216144e-05,
#  1.0104458678142692e-05,
#  1.0104143069202109e-05,
#  1.0099328653632256e-05,
#  1.0100028910255788e-05,
#  1.0097865638908842e-05,
#  1.0099084161356586e-05,
#  1.010005120506321e-05,
#  1.009403926145751e-05,
#  1.0095426294356002e-05,
#  1.0100576070362877e-05,
#  1.0092778624584752e-05,
#  1.009816624191444e-05,
#  1.0089376713676756e-05,
#  1.0089725526268012e-05,
#  1.0090980504810433e-05,
#  1.008891001883967e-05,
#  1.0095375800665352e-05,
#  1.0092070140126452e-05,
#  1.008690496937561e-05,
#  1.0091264951552148e-05,
#  1.0092830371468154e-05,
#  1.008069120462096e-05,
#  1.0082008708104697e-05,
#  1.0083946787153763e-05,
#  1.0082619238437472e-05,
#  1.008365320149096e-05,
#  1.0083926743300254e-05,
#  1.0079572184349671e-05,
#  1.0080977609914044e-05,
#  1.008223793533034e-05,
#  1.0079842547656882e-05,
#  1.0083989934173588e-05,
#  1.007378433650956e-05,
#  1.0078037787570792e-05,
#  1.007391458733764e-05,
#  1.0081085436468127e-05,
#  1.0073337155154147e-05,
#  1.0073732453111006e-05,
#  1.0068803858439424e-05,
#  1.0073058840862358e-05,
#  1.006770947979021e-05,
#  1.0071774612242734e-05,
#  1.0067398333558231e-05,
#  1.0071454612307206e-05,
#  1.0069897305311317e-05,
#  1.0068303385060064e-05,
#  1.0072013221360977e-05,
#  1.0061234691966093e-05,
#  1.007005846749962e-05,
#  1.0062890917834011e-05,
#  1.0062879955512473e-05,
#  1.0066066057697754e-05,
#  1.0067073537720716e-05,
#  1.0063779660140426e-05,
#  1.0064501383749304e-05,
#  1.0058520652364678e-05,
#  1.005873414587768e-05,
#  1.0052858047947664e-05,
#  1.0056313828863495e-05,
#  1.0057767785019678e-05,
#  1.0057978136046586e-05,
#  1.0056923689808172e-05,
#  1.0055394017126671e-05,
#  1.0056892869397416e-05,
#  1.0053767989802509e-05,
#  1.0048860397819226e-05,
#  1.0049053496459236e-05,
#  1.005080804930003e-05,
#  1.004894631141724e-05,
#  1.0043494732235558e-05,
#  1.0052697871333294e-05,
#  1.0050026093404085e-05,
#  1.0047248772661988e-05,
#  1.004954980162438e-05,
#  1.0038985513529044e-05,
#  1.0039365056672976e-05,
#  1.0045011513557256e-05,
#  1.0039674328527326e-05,
#  1.0046239393795984e-05,
#  1.004263345939762e-05,
#  1.0039191311716425e-05,
#  1.0040321042924916e-05,
#  1.0036927180681233e-05,
#  1.0033317778015772e-05,
#  1.0040986646072267e-05,
#  1.0034177735906268e-05,
#  1.0034677834210016e-05,
#  1.0030237333467084e-05,
#  1.003535059189744e-05,
#  1.0032855308872968e-05,
#  1.0035119618532918e-05,
#  1.0033447700971007e-05,
#  1.0036094745373702e-05,
#  1.0028342693567538e-05,
#  1.0022419296456064e-05,
#  1.0023362254287348e-05,
#  1.0029996992670931e-05,
#  1.002693304881177e-05,
#  1.0025969385242206e-05,
#  1.0025263342322432e-05,
#  1.0022354899956552e-05,
#  1.0026228542938043e-05,
#  1.0022723791735188e-05,
#  1.0017756514844222e-05,
#  1.0022537976783496e-05,
#  1.00215661646871e-05,
#  1.00210732341111e-05,
#  1.0016530792472625e-05,
#  1.002403982956821e-05,
#  1.001196198121761e-05,
#  1.0012796788305425e-05,
#  1.001897136302432e-05]
# [0.0290278961211442,
#  0.0527622010976076,
#  0.0047565987829118,
#  0.0069000084735453,
#  0.0078056866556406,
#  0.0030893274517729,
#  0.0033519097492098,
#  0.0037680422525852,
#  0.0095470181152224,
#  0.0388521449387073,
#  0.0025775576476007,
#  0.0034012123607099,
#  0.0042404472015798,
#  0.001094933110848,
#  0.0034235361225903,
#  0.0143225837886333,
#  0.0012026363432407,
#  0.0034611094608902,
#  0.054409446465969,
#  0.0006036737196147,
#  0.0006566500082612,
#  0.0028860601536929,
#  0.001364498966746,
#  0.0004386020803358,
#  0.0006437460723333,
#  0.0009638621593825,
#  0.0015887649508193,
#  0.0026859200410544,
#  0.0006977565478533,
#  0.000802828796301,
#  0.0025986382272094,
#  0.0003084308135323,
#  0.0006248805255629,
#  0.0003940151444636,
#  0.0003202369046397,
#  0.0003389024761039,
#  0.0003512405593413,
#  0.0004929765021428,
#  0.0003723496218677,
#  0.0001400155362673,
#  0.0001943389736581,
#  0.0002081536253681,
#  0.000281862082309,
#  8.446457936079241e-05,
#  0.0008040820381604,
#  0.000118882404908,
#  7.729451518971472e-05,
#  0.000358244902594,
#  0.0009043755676597,
#  0.000386827642098,
#  0.0002539432769874,
#  8.924133046530187e-05,
#  5.2594973280793055e-05,
#  9.851064841495829e-05,
#  0.0002060551342787,
#  9.075178343337029e-05,
#  3.752799153153319e-05,
#  9.37261073035188e-05,
#  5.981110399588943e-05,
#  6.728178184712306e-05,
#  3.936195562127978e-05,
#  6.858385839732364e-05,
#  0.0001208152829553,
#  6.123771024285816e-05,
#  2.6657300164515618e-05,
#  7.189130395418033e-05,
#  5.498556944658048e-05,
#  6.337374214781448e-05,
#  3.995359314139933e-05,
#  5.099120519298594e-05,
#  2.369024403014919e-05,
#  5.844594699447043e-05,
#  2.4269277963321652e-05,
#  0.0001500727635808,
#  3.159887538058683e-05,
#  3.436096815858036e-05,
#  2.555083451152313e-05,
#  6.53721829818096e-05,
#  1.845560335787013e-05,
#  2.631878054817207e-05,
#  1.7703360121231527e-05,
#  2.0863692517741584e-05,
#  2.077464147878345e-05,
#  3.234600769064855e-05,
#  1.922700419963803e-05,
#  1.846917815855704e-05,
#  4.0515694045461714e-05,
#  2.645277843985241e-05,
#  1.774301750847371e-05,
#  2.964231112564448e-05,
#  1.811695781070739e-05,
#  1.7575494881020857e-05,
#  1.3254385511390864e-05,
#  1.460173776067677e-05,
#  1.5557621129846667e-05,
#  1.4045839649043048e-05,
#  3.0712845412199387e-05,
#  2.1899505669716747e-05,
#  1.4699411984474863e-05,
#  1.5555055939330485e-05,
#  1.7144654980802444e-05,
#  1.842776629055152e-05,
#  1.2934257766755764e-05,
#  1.292422266487847e-05,
#  1.6075991351681295e-05,
#  1.739040218453738e-05,
#  1.4040676735021409e-05,
#  1.3870707135356495e-05,
#  1.286354522962938e-05,
#  1.2055312187294476e-05,
#  1.419183135149069e-05,
#  1.3692412042291836e-05,
#  1.4585327050008344e-05,
#  1.1977596301585436e-05,
#  1.4118440536549317e-05,
#  1.680318818980595e-05,
#  1.2083825439185603e-05,
#  1.2187101476592944e-05,
#  1.919151919428259e-05,
#  1.2160740423860262e-05,
#  1.0934747618739491e-05,
#  1.13014628754172e-05,
#  1.1454546460299753e-05,
#  1.181469186922186e-05,
#  1.1304926603042986e-05,
#  1.1039246417567484e-05,
#  1.0895368688943563e-05,
#  1.1639434577955398e-05,
#  1.1273127614185797e-05,
#  1.1487090575974437e-05,
#  1.4859038749273168e-05,
#  1.5442668850300834e-05,
#  1.2600540877610911e-05,
#  1.053763055606396e-05,
#  1.056907302227046e-05,
#  1.06904465763364e-05,
#  1.139502154837828e-05,
#  1.2739068464725278e-05,
#  1.0544029548327672e-05,
#  1.0671637892664876e-05,
#  1.0825667792960304e-05,
#  1.098891738911334e-05,
#  1.0751441200409316e-05,
#  1.0291066111676628e-05,
#  1.0237733510439283e-05,
#  1.0758837745743222e-05,
#  1.0497162800675142e-05,
#  1.0503596379930968e-05,
#  1.031959699903382e-05,
#  1.032849858456757e-05,
#  1.0938784547761317e-05,
#  1.01692651216581e-05,
#  1.0252636633595104e-05,
#  1.0640174156287685e-05,
#  1.0169401698658476e-05,
#  1.0388253814016934e-05,
#  1.0427863769291434e-05,
#  1.0260371749609476e-05,
#  1.0142552133038409e-05,
#  1.0197034799784887e-05,
#  1.0250708020612364e-05,
#  1.0169249190948904e-05,
#  1.0068678764946526e-05,
#  1.0157245717709884e-05,
#  1.0084033673047088e-05,
#  1.006008259500959e-05,
#  1.0085677881579614e-05,
#  1.006147188018076e-05,
#  1.010235911962809e-05,
#  1.0224900622051792e-05,
#  1.0129068728565473e-05,
#  1.0127701900637475e-05,
#  1.0069421873777174e-05,
#  1.0075106921431143e-05,
#  1.0056974123654072e-05,
#  1.0032272181706505e-05,
#  1.016800049219455e-05,
#  1.007245684195368e-05,
#  1.0058304537596996e-05,
#  1.0258055332815275e-05,
#  1.0048108067712749e-05,
#  1.0034439131050022e-05,
#  1.001259693002794e-05,
#  1.0043286459404044e-05,
#  1.0035200768470531e-05,
#  1.0030001421910128e-05,
#  1.002972238275106e-05,
#  1.0087602947896813e-05,
#  1.00326643398148e-05,
#  1.0037094241852172e-05,
#  1.0151923341618386e-05,
#  1.0002779586648103e-05,
#  1.01152553652355e-05,
#  1.0108679599943572e-05,
#  1.0079554759431633e-05,
#  1.0031727904060972e-05,
#  1.0026438087879795e-05,
#  1.0037375005776991e-05,
#  1.0003424649039516e-05,
#  1.0027666862879412e-05,
#  1.004204097771435e-05,
#  9.99960731205647e-06,
#  1.0037322939388104e-05,
#  1.0066549222392497e-05,
#  1.00153535764548e-05,
#  1.001334387146926e-05,
#  9.998229666962289e-06,
#  9.982544495505863e-06,
#  1.000382303209335e-05,
#  1.0014431316085393e-05,
#  1.0008070202820816e-05,
#  1.0056949287536556e-05,
#  9.994005082262447e-06,
#  1.001362477290968e-05,
#  9.995277729831286e-06,
#  1.001634735002881e-05,
#  9.989116119686514e-06,
#  1.006188601422764e-05,
#  1.0036381053214427e-05,
#  9.9874583138444e-06,
#  1.0033203852799487e-05,
#  9.982138192572166e-06,
#  9.998352562251967e-06,
#  1.0043975546432192e-05,
#  9.991134804295144e-06,
#  1.0001980245942832e-05,
#  1.0194028291880384e-05,
#  1.0034783136507031e-05,
#  1.000998126110062e-05,
#  1.000171851410414e-05,
#  1.010389064103947e-05,
#  1.0024685429016245e-05,
#  1.0035221812722738e-05,
#  1.0000479351583637e-05,
#  9.989191062777536e-06,
#  9.985339066042795e-06,
#  9.97221832512878e-06,
#  9.966034411991132e-06,
#  1.0069531873159576e-05,
#  9.991876937419876e-06,
#  9.96942806232255e-06,
#  1.0065349930664524e-05,
#  1.00240508607385e-05,
#  1.0001403743081027e-05,
#  9.976326262403744e-06,
#  1.0016412028198829e-05,
#  1.0096695182073744e-05,
#  9.958289326459634e-06,
#  9.976132227893686e-06,
#  9.989430436689872e-06,
#  9.95939282438485e-06,
#  9.99271843902534e-06,
#  9.971042403412866e-06,
#  9.983432226727016e-06,
#  9.980413669836708e-06,
#  9.979580148865351e-06,
#  9.9735948817397e-06,
#  1.0052055612686671e-05,
#  9.9819548879168e-06,
#  9.976111021023826e-06,
#  9.948951622209278e-06,
#  9.969727203861112e-06,
#  9.95580650633201e-06,
#  9.976337887201226e-06,
#  1.0013052639260422e-05,
#  9.96064539467625e-06,
#  9.974176827745397e-06,
#  1.0215296559181297e-05,
#  9.947302982618566e-06,
#  9.9447073371266e-06,
#  1.0020599701965691e-05,
#  9.96140645147534e-06,
#  1.003648318510386e-05,
#  9.962225287381444e-06,
#  9.937485090267729e-06,
#  1.002501713883248e-05,
#  9.982160061917966e-06,
#  9.967125277762534e-06,
#  9.973179362714293e-06,
#  9.966520017042055e-06,
#  9.943425117307924e-06,
#  9.95990829251241e-06,
#  9.957768891035811e-06,
#  9.936594195460202e-06,
#  9.945159812195924e-06,
#  9.945953231363091e-06,
#  9.930531447025716e-06,
#  9.932921143627028e-06,
#  9.979383245081407e-06,
#  9.9288527329918e-06,
#  9.964839789608958e-06,
#  9.94105785539432e-06,
#  9.958206043665996e-06,
#  9.936315452068812e-06,
#  9.95347595489875e-06,
#  1.0093598993989873e-05,
#  9.940111941978102e-06,
#  9.951448770880234e-06,
#  9.944746108158144e-06,
#  9.945284607965732e-06,
#  9.962343727966072e-06,
#  9.930318740953226e-06,
#  9.9267627014342e-06,
#  9.920290557784028e-06,
#  9.92324952967465e-06,
#  9.950256750380504e-06,
#  9.95468290784629e-06,
#  9.91092180556734e-06,
#  9.938695139135234e-06,
#  9.94416175672086e-06,
#  9.92847402303596e-06,
#  9.912524609535467e-06,
#  1.0109713856945746e-05,
#  9.942417463025776e-06,
#  9.953136327749234e-06,
#  9.923634811275406e-06,
#  9.938880034314934e-06,
#  9.919914875354152e-06,
#  9.936519876646345e-06,
#  9.907825241680255e-06,
#  9.932779039809248e-06,
#  9.901148247081436e-06,
#  9.9438235789421e-06,
#  9.94459457724588e-06,
#  9.929858257964953e-06,
#  9.948532014823286e-06,
#  9.919951045230844e-06,
#  9.894012997028769e-06,
#  9.910414452315308e-06,
#  9.890947836174746e-06,
#  9.941991283267272e-06,
#  9.914345588185824e-06,
#  9.926212103164287e-06,
#  9.910914552165197e-06,
#  9.903044491511535e-06,
#  9.905534683639416e-06,
#  9.899281288016937e-06,
#  9.901796807389474e-06,
#  9.904614184051752e-06,
#  9.897917730995688e-06,
#  9.896568309341091e-06,
#  9.914460475192756e-06,
#  9.912727294431534e-06,
#  9.960291370225605e-06,
#  9.921840073002388e-06,
#  9.903881049831395e-06,
#  9.93006798744318e-06,
#  9.99632370803738e-06,
#  9.908404696034268e-06,
#  9.899939159367933e-06,
#  9.930119211639976e-06,
#  9.926806997100358e-06,
#  9.921847248187988e-06,
#  9.896649444999638e-06,
#  9.87770203864784e-06,
#  9.890684068523117e-06,
#  9.962011194147636e-06,
#  9.881285948358708e-06,
#  9.901336096663728e-06,
#  9.881574492465006e-06,
#  1.0016244516009466e-05,
#  9.863556248456008e-06,
#  9.873148370024864e-06,
#  9.924405946367187e-06,
#  9.890025593995233e-06,
#  9.943348480737767e-06,
#  9.87952140494599e-06,
#  9.883738331700442e-06,
#  9.892879506878672e-06,
#  9.894940806407248e-06,
#  9.90227198926732e-06,
#  9.973160194567754e-06,
#  9.866020062327152e-06,
#  9.96528462274e-06,
#  9.85969487010152e-06,
#  9.921728364861338e-06,
#  9.868214898597216e-06,
#  9.861960999842269e-06,
#  9.95705419773003e-06,
#  9.89181117984117e-06,
#  9.856280250824056e-06,
#  9.875042707426474e-06,
#  9.903105191915528e-06,
#  9.90210264317284e-06,
#  9.8673874650558e-06,
#  9.884552885341692e-06,
#  9.901330491629778e-06,
#  9.8716426808096e-06,
#  9.877492775194695e-06,
#  9.88349100225605e-06,
#  9.871325922722465e-06,
#  9.880919413626543e-06,
#  9.931849496206267e-06,
#  9.863447673706104e-06,
#  9.850276625002151e-06,
#  9.934630548013956e-06,
#  9.918154855404282e-06,
#  9.8574609910429e-06,
#  9.912868338142289e-06,
#  9.845937904901802e-06]
# [{'l1_norm': 3.894557126420736, 'linf_norm': 102.823879874444},
#  {'l1_norm': 0.9074894188433884, 'linf_norm': 24.53896044356823},
#  {'l1_norm': 0.6255996458441019, 'linf_norm': 16.588862043696643},
#  {'l1_norm': 0.6584345097441227, 'linf_norm': 17.73442048459947},
#  {'l1_norm': 0.5148536199931055, 'linf_norm': 13.53840166312009},
#  {'l1_norm': 0.4482792683135718, 'linf_norm': 11.57171520280987},
#  {'l1_norm': 0.4160169950898736, 'linf_norm': 10.619566849979758},
#  {'l1_norm': 0.3628954169299453, 'linf_norm': 9.244695050762594},
#  {'l1_norm': 0.4034054915931075, 'linf_norm': 10.59727642544955},
#  {'l1_norm': 0.35527117976062, 'linf_norm': 9.216766773293912},
#  {'l1_norm': 0.3180924961145967, 'linf_norm': 8.130492629876732},
#  {'l1_norm': 0.3600661977283657, 'linf_norm': 9.535163193938136},
#  {'l1_norm': 0.3435904118806124, 'linf_norm': 8.91187058428228},
#  {'l1_norm': 0.2472565819907933, 'linf_norm': 5.997946149566769},
#  {'l1_norm': 0.2581812349829823, 'linf_norm': 6.352595279283822},
#  {'l1_norm': 0.2266189989499747, 'linf_norm': 5.609134308526665},
#  {'l1_norm': 0.2995702399877831, 'linf_norm': 7.788383644931764},
#  {'l1_norm': 0.2409259089954197, 'linf_norm': 5.939558057825267},
#  {'l1_norm': 0.2807169298008084, 'linf_norm': 7.3550414056442674},
#  {'l1_norm': 0.2317859484190121, 'linf_norm': 5.809294942887127},
#  {'l1_norm': 0.2147916190449148, 'linf_norm': 5.405777849664539},
#  {'l1_norm': 0.2029854733383283, 'linf_norm': 5.007902593053878},
#  {'l1_norm': 0.223715245710127, 'linf_norm': 5.69592960254401},
#  {'l1_norm': 0.1862248649612069, 'linf_norm': 4.479452311009914},
#  {'l1_norm': 0.213795191385597, 'linf_norm': 5.427270236948132},
#  {'l1_norm': 0.2004083466950804, 'linf_norm': 4.972846578869223},
#  {'l1_norm': 0.1802714241677895, 'linf_norm': 4.340395949174464},
#  {'l1_norm': 0.1479777614550665, 'linf_norm': 3.466659049435705},
#  {'l1_norm': 0.1205462537223473, 'linf_norm': 2.714507666119188},
#  {'l1_norm': 0.1241970320321619, 'linf_norm': 2.736041616016999},
#  {'l1_norm': 0.0658970442365855, 'linf_norm': 1.400571590460837},
#  {'l1_norm': 0.0614739831642247, 'linf_norm': 1.1987698523186148},
#  {'l1_norm': 0.0580864066130481, 'linf_norm': 1.1329654151894153},
#  {'l1_norm': 0.0561936159273609, 'linf_norm': 1.092939498154819},
#  {'l1_norm': 0.0659763879502192, 'linf_norm': 1.3656089244559406},
#  {'l1_norm': 0.0653083818987943, 'linf_norm': 1.391400366567075},
#  {'l1_norm': 0.0703783964172937, 'linf_norm': 1.5369242352977397},
#  {'l1_norm': 0.0649517147426493, 'linf_norm': 1.398184443110973},
#  {'l1_norm': 0.0411005908462684, 'linf_norm': 0.898471255709976},
#  {'l1_norm': 0.0412709895705804, 'linf_norm': 0.8527049704439938},
#  {'l1_norm': 0.0400789469768293, 'linf_norm': 0.8181984603855759},
#  {'l1_norm': 0.0390775243004784, 'linf_norm': 0.8222515179924667},
#  {'l1_norm': 0.0431561721709556, 'linf_norm': 0.9477423358766364},
#  {'l1_norm': 0.0361393770632334, 'linf_norm': 0.7280003879370168},
#  {'l1_norm': 0.0394923685594461, 'linf_norm': 0.8464495425693691},
#  {'l1_norm': 0.0380242651151027, 'linf_norm': 0.7886200780527666},
#  {'l1_norm': 0.0420003893163986, 'linf_norm': 0.9295229030318558},
#  {'l1_norm': 0.0366838348699267, 'linf_norm': 0.778465992612578},
#  {'l1_norm': 0.0375979186174459, 'linf_norm': 0.7923158773733303},
#  {'l1_norm': 0.035028276685765, 'linf_norm': 0.7323118435813114},
#  {'l1_norm': 0.0368844095529988, 'linf_norm': 0.7847949044765905},
#  {'l1_norm': 0.0378222567076329, 'linf_norm': 0.8183208687715232},
#  {'l1_norm': 0.0415690416726283, 'linf_norm': 0.9377699930548667},
#  {'l1_norm': 0.037465714204451, 'linf_norm': 0.8116426386425272},
#  {'l1_norm': 0.0399175231475383, 'linf_norm': 0.8978572292372584},
#  {'l1_norm': 0.0367667492568958, 'linf_norm': 0.7862864093752578},
#  {'l1_norm': 0.0393958064005244, 'linf_norm': 0.8862786050369963},
#  {'l1_norm': 0.034270795054268, 'linf_norm': 0.724230242465809},
#  {'l1_norm': 0.0372711063816212, 'linf_norm': 0.8120287712087855},
#  {'l1_norm': 0.031496840951126, 'linf_norm': 0.6422567458834499},
#  {'l1_norm': 0.0314586136563681, 'linf_norm': 0.6584215489687398},
#  {'l1_norm': 0.0378730129770934, 'linf_norm': 0.815514834655635},
#  {'l1_norm': 0.0470581227239221, 'linf_norm': 1.133388274880126},
#  {'l1_norm': 0.0242082937917206, 'linf_norm': 0.5244045654414221},
#  {'l1_norm': 0.0225984697516541, 'linf_norm': 0.4550696219129488},
#  {'l1_norm': 0.0272761842568172, 'linf_norm': 0.6019373968802393},
#  {'l1_norm': 0.0235064264309126, 'linf_norm': 0.4915153361223638},
#  {'l1_norm': 0.0231359970324672, 'linf_norm': 0.4689026060797274},
#  {'l1_norm': 0.0217958473085891, 'linf_norm': 0.4404178443571552},
#  {'l1_norm': 0.02146207277067, 'linf_norm': 0.4355322932954877},
#  {'l1_norm': 0.0211025305588264, 'linf_norm': 0.4214389788208529},
#  {'l1_norm': 0.0241909857834689, 'linf_norm': 0.5187303133005277},
#  {'l1_norm': 0.0225265232826583, 'linf_norm': 0.4612548723600805},
#  {'l1_norm': 0.0261430816282052, 'linf_norm': 0.5836609114540741},
#  {'l1_norm': 0.0202849236229434, 'linf_norm': 0.395241905260086},
#  {'l1_norm': 0.0238033932264894, 'linf_norm': 0.505897708321549},
#  {'l1_norm': 0.0227746977600734, 'linf_norm': 0.4828184265084564},
#  {'l1_norm': 0.0193610972234513, 'linf_norm': 0.4205716015392914},
#  {'l1_norm': 0.0178057395605836, 'linf_norm': 0.3681687322726473},
#  {'l1_norm': 0.0174828145631123, 'linf_norm': 0.353396974517405},
#  {'l1_norm': 0.019060247286316, 'linf_norm': 0.4072133660049177},
#  {'l1_norm': 0.016548872833047, 'linf_norm': 0.3220695608122274},
#  {'l1_norm': 0.0171315446858759, 'linf_norm': 0.3512439357798546},
#  {'l1_norm': 0.0211063905987422, 'linf_norm': 0.4734549422824755},
#  {'l1_norm': 0.0172870899495203, 'linf_norm': 0.3565913187625818},
#  {'l1_norm': 0.0174342120115179, 'linf_norm': 0.36169672293365},
#  {'l1_norm': 0.0168480131635675, 'linf_norm': 0.3408518627741374},
#  {'l1_norm': 0.015999881895259, 'linf_norm': 0.3371956453181803},
#  {'l1_norm': 0.0151400867018848, 'linf_norm': 0.3054921445190906},
#  {'l1_norm': 0.0162162541953613, 'linf_norm': 0.341839047701098},
#  {'l1_norm': 0.017184349230118, 'linf_norm': 0.3745167010105215},
#  {'l1_norm': 0.0158038096519885, 'linf_norm': 0.3271191187024116},
#  {'l1_norm': 0.0159174351395806, 'linf_norm': 0.3366093825287186},
#  {'l1_norm': 0.0158256144519196, 'linf_norm': 0.3331563771439716},
#  {'l1_norm': 0.0172524604266742, 'linf_norm': 0.3815396292533725},
#  {'l1_norm': 0.0156305644868407, 'linf_norm': 0.3300587945157662},
#  {'l1_norm': 0.0174836885915603, 'linf_norm': 0.3862539645082317},
#  {'l1_norm': 0.0151090001133736, 'linf_norm': 0.3141371404811739},
#  {'l1_norm': 0.0161412067466881, 'linf_norm': 0.3439752408874221},
#  {'l1_norm': 0.0149784973444184, 'linf_norm': 0.3180640049630776},
#  {'l1_norm': 0.0147033466611756, 'linf_norm': 0.3072624998137355},
#  {'l1_norm': 0.0150234929969301, 'linf_norm': 0.3227412992350757},
#  {'l1_norm': 0.0146658617225708, 'linf_norm': 0.3064690354973077},
#  {'l1_norm': 0.0144646110058063, 'linf_norm': 0.3073526874559},
#  {'l1_norm': 0.0149957773121306, 'linf_norm': 0.3201052136891521},
#  {'l1_norm': 0.0148700200007529, 'linf_norm': 0.3180898041177541},
#  {'l1_norm': 0.0144823260127333, 'linf_norm': 0.3048480605407618},
#  {'l1_norm': 0.0153308494187193, 'linf_norm': 0.3250221354279667},
#  {'l1_norm': 0.0142772265144158, 'linf_norm': 0.2969419094756245},
#  {'l1_norm': 0.0138453642772044, 'linf_norm': 0.2828239623897709},
#  {'l1_norm': 0.0147541547633009, 'linf_norm': 0.3186442833677865},
#  {'l1_norm': 0.0143491346896626, 'linf_norm': 0.3011601575275883},
#  {'l1_norm': 0.0141917915950994, 'linf_norm': 0.2940094827998429},
#  {'l1_norm': 0.0140032094642519, 'linf_norm': 0.2890835977867245},
#  {'l1_norm': 0.0144862535712774, 'linf_norm': 0.3083680748995393},
#  {'l1_norm': 0.0146987315859878, 'linf_norm': 0.3138713609175756},
#  {'l1_norm': 0.0139739764136262, 'linf_norm': 0.2916693089788779},
#  {'l1_norm': 0.014288163320627, 'linf_norm': 0.3036842176091857},
#  {'l1_norm': 0.0149433077417081, 'linf_norm': 0.3267649608617649},
#  {'l1_norm': 0.0144892160774674, 'linf_norm': 0.3098004314322025},
#  {'l1_norm': 0.0136050910478457, 'linf_norm': 0.2865558825162239},
#  {'l1_norm': 0.0137349646549904, 'linf_norm': 0.2905429467933252},
#  {'l1_norm': 0.0139284002952277, 'linf_norm': 0.2974010895957239},
#  {'l1_norm': 0.0135796383764129, 'linf_norm': 0.2855125454142689},
#  {'l1_norm': 0.0139341461671283, 'linf_norm': 0.2972326451060362},
#  {'l1_norm': 0.0137250235889572, 'linf_norm': 0.2900531120174564},
#  {'l1_norm': 0.0134755016797687, 'linf_norm': 0.2809727069117129},
#  {'l1_norm': 0.0139068614656338, 'linf_norm': 0.2946346459896303},
#  {'l1_norm': 0.0134012504033045, 'linf_norm': 0.2812693654689938},
#  {'l1_norm': 0.013756879850314, 'linf_norm': 0.2901147298734635},
#  {'l1_norm': 0.0140148358212551, 'linf_norm': 0.2996885426420718},
#  {'l1_norm': 0.0140572148743085, 'linf_norm': 0.2985743867417797},
#  {'l1_norm': 0.0137651417336426, 'linf_norm': 0.2927659944225103},
#  {'l1_norm': 0.0136313219857169, 'linf_norm': 0.2876946837505326},
#  {'l1_norm': 0.0134149381289025, 'linf_norm': 0.2834490987581201},
#  {'l1_norm': 0.0137519107459578, 'linf_norm': 0.2942334597639739},
#  {'l1_norm': 0.0136996173223946, 'linf_norm': 0.2903391335063613},
#  {'l1_norm': 0.0135405928531661, 'linf_norm': 0.2861680180553347},
#  {'l1_norm': 0.0135184228590922, 'linf_norm': 0.2869314285798929},
#  {'l1_norm': 0.0136426430427934, 'linf_norm': 0.2872674926005303},
#  {'l1_norm': 0.013245547549962, 'linf_norm': 0.2773229536061175},
#  {'l1_norm': 0.0134556642338866, 'linf_norm': 0.2876792719173245},
#  {'l1_norm': 0.0133705719039542, 'linf_norm': 0.2856251577185467},
#  {'l1_norm': 0.0134324060002807, 'linf_norm': 0.2854131843533367},
#  {'l1_norm': 0.013213320480124, 'linf_norm': 0.27840949491309},
#  {'l1_norm': 0.0133764715046156, 'linf_norm': 0.2834945103751495},
#  {'l1_norm': 0.0133796284223441, 'linf_norm': 0.283035068253614},
#  {'l1_norm': 0.013474132232787, 'linf_norm': 0.2870332357728853},
#  {'l1_norm': 0.0133539883153047, 'linf_norm': 0.2846408945227973},
#  {'l1_norm': 0.0132992676295572, 'linf_norm': 0.2826552339142188},
#  {'l1_norm': 0.0132254848510259, 'linf_norm': 0.2797032093573361},
#  {'l1_norm': 0.0133725502400891, 'linf_norm': 0.2885550677068531},
#  {'l1_norm': 0.0132374100834364, 'linf_norm': 0.2787318451212719},
#  {'l1_norm': 0.0133332460094708, 'linf_norm': 0.2852104022812098},
#  {'l1_norm': 0.0131682727891253, 'linf_norm': 0.2819540614199824},
#  {'l1_norm': 0.0133430076151154, 'linf_norm': 0.2839935566525906},
#  {'l1_norm': 0.0132672459093388, 'linf_norm': 0.2812519276807084},
#  {'l1_norm': 0.0132551544035784, 'linf_norm': 0.2848938538229092},
#  {'l1_norm': 0.0132742507287999, 'linf_norm': 0.2843323919305578},
#  {'l1_norm': 0.0132030950037762, 'linf_norm': 0.2814010798443109},
#  {'l1_norm': 0.0132577854801435, 'linf_norm': 0.2796739026289433},
#  {'l1_norm': 0.0133837539329659, 'linf_norm': 0.2813714019516483},
#  {'l1_norm': 0.0133227994224987, 'linf_norm': 0.2827941191940568},
#  {'l1_norm': 0.0132923384446883, 'linf_norm': 0.2777784062864259},
#  {'l1_norm': 0.0132709191135596, 'linf_norm': 0.2829978309209458},
#  {'l1_norm': 0.0132784166730241, 'linf_norm': 0.2841360619026236},
#  {'l1_norm': 0.0132557937760255, 'linf_norm': 0.280655256614089},
#  {'l1_norm': 0.013300512815942, 'linf_norm': 0.2835439093307592},
#  {'l1_norm': 0.0133776257960824, 'linf_norm': 0.2897243948901072},
#  {'l1_norm': 0.0133622000320348, 'linf_norm': 0.2836756694085896},
#  {'l1_norm': 0.0130816220746375, 'linf_norm': 0.2767798688378185},
#  {'l1_norm': 0.013238918576017, 'linf_norm': 0.2825260827282443},
#  {'l1_norm': 0.0131494938513613, 'linf_norm': 0.2785509835803881},
#  {'l1_norm': 0.0132287411493249, 'linf_norm': 0.2807832817701622},
#  {'l1_norm': 0.0132265343789709, 'linf_norm': 0.2795999639214016},
#  {'l1_norm': 0.0131329434720799, 'linf_norm': 0.2803992628575302},
#  {'l1_norm': 0.0132448751481249, 'linf_norm': 0.2821322118731215},
#  {'l1_norm': 0.0132217303533572, 'linf_norm': 0.2824575483483262},
#  {'l1_norm': 0.0132944951450917, 'linf_norm': 0.2842227670767344},
#  {'l1_norm': 0.0132501981117064, 'linf_norm': 0.2834443281272426},
#  {'l1_norm': 0.0132555203208932, 'linf_norm': 0.2832097862370312},
#  {'l1_norm': 0.0132329186272108, 'linf_norm': 0.2816564301639795},
#  {'l1_norm': 0.0132235348019516, 'linf_norm': 0.2822038559914566},
#  {'l1_norm': 0.0131851591429207, 'linf_norm': 0.2790761124824173},
#  {'l1_norm': 0.0132812851796392, 'linf_norm': 0.2821503588410094},
#  {'l1_norm': 0.0132017832112265, 'linf_norm': 0.2800200625789352},
#  {'l1_norm': 0.0132196897424058, 'linf_norm': 0.2770286166448146},
#  {'l1_norm': 0.0131984008890576, 'linf_norm': 0.2804110315546393},
#  {'l1_norm': 0.0132438835194334, 'linf_norm': 0.2794332487171516},
#  {'l1_norm': 0.0132259879412362, 'linf_norm': 0.2812676155763678},
#  {'l1_norm': 0.0132635559757472, 'linf_norm': 0.2815269599662162},
#  {'l1_norm': 0.0131997956739272, 'linf_norm': 0.2826595967488363},
#  {'l1_norm': 0.0131584556365152, 'linf_norm': 0.282924240230117},
#  {'l1_norm': 0.0131874787313397, 'linf_norm': 0.2817858508081175},
#  {'l1_norm': 0.0132180657798075, 'linf_norm': 0.284439983379282},
#  {'l1_norm': 0.0132343414112459, 'linf_norm': 0.2832964390545152},
#  {'l1_norm': 0.0131850468769203, 'linf_norm': 0.2809999645756557},
#  {'l1_norm': 0.0131942330031772, 'linf_norm': 0.2813956336031668},
#  {'l1_norm': 0.0132278173990547, 'linf_norm': 0.2816046694531105},
#  {'l1_norm': 0.013187941913167, 'linf_norm': 0.2811876182585954},
#  {'l1_norm': 0.0131712180279428, 'linf_norm': 0.2840372966806404},
# ...
#  {'l1_norm': 0.011649592568539, 'linf_norm': 0.248017658302933},
#  {'l1_norm': 0.0112384217318147, 'linf_norm': 0.2377201922103762},
#  {'l1_norm': 0.0112264358935877, 'linf_norm': 0.2382015766337513},
#  {'l1_norm': 0.0111761911118403, 'linf_norm': 0.2359548543974757},
#  {'l1_norm': 0.0111568328516557, 'linf_norm': 0.235398754170537},
#  {'l1_norm': 0.0111966078339144, 'linf_norm': 0.237576666752994},
#  {'l1_norm': 0.0112299764882773, 'linf_norm': 0.237653625421226},
#  {'l1_norm': 0.0116450985601171, 'linf_norm': 0.2482157182127237},
#  {'l1_norm': 0.0115214800629764, 'linf_norm': 0.2449819801181554},
#  {'l1_norm': 0.011181795198284, 'linf_norm': 0.2364578124806285},
#  {'l1_norm': 0.0111539963221177, 'linf_norm': 0.2362883316516876},
#  {'l1_norm': 0.0114640109132975, 'linf_norm': 0.2435890506803989},
#  {'l1_norm': 0.0114318378392606, 'linf_norm': 0.2425065149188041},
#  {'l1_norm': 0.0112098871178925, 'linf_norm': 0.2371251850396394},
#  {'l1_norm': 0.0112047432631254, 'linf_norm': 0.237054964287579},
#  {'l1_norm': 0.0112272164097055, 'linf_norm': 0.2388968644127249},
#  {'l1_norm': 0.011169793116115, 'linf_norm': 0.2361019226506352},
#  {'l1_norm': 0.0113722821258008, 'linf_norm': 0.2409893998786807},
#  {'l1_norm': 0.0112483332466334, 'linf_norm': 0.2390020453974604},
#  {'l1_norm': 0.0111575008116662, 'linf_norm': 0.2364090941518545},
#  {'l1_norm': 0.0111580195723101, 'linf_norm': 0.2361556293413043},
#  {'l1_norm': 0.0111758587412536, 'linf_norm': 0.2363570624902844},
#  {'l1_norm': 0.0112953830819576, 'linf_norm': 0.2392908874616026},
#  {'l1_norm': 0.0111741571802645, 'linf_norm': 0.2374246136114001},
#  {'l1_norm': 0.0113917481614276, 'linf_norm': 0.2418269683554768},
#  {'l1_norm': 0.0112155977888032, 'linf_norm': 0.2373412475720047},
#  {'l1_norm': 0.0115283141965046, 'linf_norm': 0.2453548914797604},
#  {'l1_norm': 0.0112027328116819, 'linf_norm': 0.2371190356940031},
#  {'l1_norm': 0.0114860852321609, 'linf_norm': 0.2442179846309125},
#  {'l1_norm': 0.0112386678241193, 'linf_norm': 0.2375015492081642},
#  {'l1_norm': 0.0111991403710097, 'linf_norm': 0.2368452920913696},
#  {'l1_norm': 0.0112139467608183, 'linf_norm': 0.2373118313252926},
#  {'l1_norm': 0.0116047942062839, 'linf_norm': 0.2469931840568781},
#  {'l1_norm': 0.0114283225249499, 'linf_norm': 0.2427930863201618},
#  {'l1_norm': 0.0114485940204933, 'linf_norm': 0.2431857621207833},
#  {'l1_norm': 0.0113917069543153, 'linf_norm': 0.2419141373991966},
#  {'l1_norm': 0.0113110761867836, 'linf_norm': 0.2397683540970087},
#  {'l1_norm': 0.0113090723076835, 'linf_norm': 0.2396333457812667},
#  {'l1_norm': 0.0111421141711995, 'linf_norm': 0.2362400924712419},
#  {'l1_norm': 0.0111768255753442, 'linf_norm': 0.2363502737015485},
#  {'l1_norm': 0.0112845918314531, 'linf_norm': 0.2391225583210587},
#  {'l1_norm': 0.011186864699237, 'linf_norm': 0.2365950405150652},
#  {'l1_norm': 0.011311959169805, 'linf_norm': 0.2398655474819243},
#  {'l1_norm': 0.0112404142735525, 'linf_norm': 0.237865642671287},
#  {'l1_norm': 0.0112282261183485, 'linf_norm': 0.2378006766483187},
#  {'l1_norm': 0.011164216841571, 'linf_norm': 0.2365924603104591},
#  {'l1_norm': 0.0111713737037032, 'linf_norm': 0.236494615496695},
#  {'l1_norm': 0.0111696134032681, 'linf_norm': 0.2362806270241737},
#  {'l1_norm': 0.0112250898130238, 'linf_norm': 0.2376164514556527},
#  {'l1_norm': 0.0113566974975168, 'linf_norm': 0.2408704252958297},
#  {'l1_norm': 0.0111851527523249, 'linf_norm': 0.2365590552344918},
#  {'l1_norm': 0.0112460363674908, 'linf_norm': 0.2380929894089699},
#  {'l1_norm': 0.0113985385797917, 'linf_norm': 0.241905308060348},
#  {'l1_norm': 0.0113719496052712, 'linf_norm': 0.2413310085266828},
#  {'l1_norm': 0.0114239427415654, 'linf_norm': 0.2425786337479949},
#  {'l1_norm': 0.0113144466519355, 'linf_norm': 0.2399688947200775},
#  {'l1_norm': 0.0111850971255451, 'linf_norm': 0.2375173808947205},
#  {'l1_norm': 0.0113435120085254, 'linf_norm': 0.2404918247155845},
#  {'l1_norm': 0.0111970658373087, 'linf_norm': 0.236901155346632},
#  {'l1_norm': 0.011219448242709, 'linf_norm': 0.2374145338654518},
#  {'l1_norm': 0.0113440024184063, 'linf_norm': 0.2406904983088374},
#  {'l1_norm': 0.0111705505564808, 'linf_norm': 0.2378371482491493},
#  {'l1_norm': 0.01117069664523, 'linf_norm': 0.23659291125983},
#  {'l1_norm': 0.0111664340861141, 'linf_norm': 0.2364475056007504},
#  {'l1_norm': 0.0111528477685526, 'linf_norm': 0.2372152552142739},
#  {'l1_norm': 0.0114299488009884, 'linf_norm': 0.2427720722831785},
#  {'l1_norm': 0.0115376733478158, 'linf_norm': 0.2455492264449596},
#  {'l1_norm': 0.011385994580388, 'linf_norm': 0.2418066400319337},
#  {'l1_norm': 0.0111659847890958, 'linf_norm': 0.2364131604254245},
#  {'l1_norm': 0.0113936969069764, 'linf_norm': 0.2417633119538426},
#  {'l1_norm': 0.0114528492361307, 'linf_norm': 0.243184092310071},
#  {'l1_norm': 0.0115587304228916, 'linf_norm': 0.2461507508389651},
#  {'l1_norm': 0.0111674905115738, 'linf_norm': 0.2375375643700361},
#  {'l1_norm': 0.0114272434417158, 'linf_norm': 0.2428265056535601},
#  {'l1_norm': 0.0112115274937823, 'linf_norm': 0.2374083042681217},
#  {'l1_norm': 0.0112474640771746, 'linf_norm': 0.2380625210791826},
#  {'l1_norm': 0.011189439580217, 'linf_norm': 0.2369692136585712},
#  {'l1_norm': 0.0116817776473239, 'linf_norm': 0.2488291731387376},
#  {'l1_norm': 0.0113771986780688, 'linf_norm': 0.2414985277101397},
#  {'l1_norm': 0.0111883753355592, 'linf_norm': 0.2371912264317274},
#  {'l1_norm': 0.0115744172682985, 'linf_norm': 0.2465158279053866},
#  {'l1_norm': 0.0114067893590778, 'linf_norm': 0.2423418722428381},
#  {'l1_norm': 0.0114497014325112, 'linf_norm': 0.2432246990785002},
#  {'l1_norm': 0.011287424567528, 'linf_norm': 0.2391078370094299},
#  {'l1_norm': 0.0114287135198712, 'linf_norm': 0.242683329578489},
#  {'l1_norm': 0.01156282874085, 'linf_norm': 0.246338822761923},
#  {'l1_norm': 0.0112640315458178, 'linf_norm': 0.2386254588112235},
#  {'l1_norm': 0.0114302069697529, 'linf_norm': 0.2427205062285065},
#  {'l1_norm': 0.0113709707999601, 'linf_norm': 0.2414578660815954},
#  {'l1_norm': 0.0112536952575668, 'linf_norm': 0.2383780486650765},
#  {'l1_norm': 0.0111962797753512, 'linf_norm': 0.2375592344149947},
#  {'l1_norm': 0.0111673914229497, 'linf_norm': 0.2365761966243386},
#  {'l1_norm': 0.0111973058639094, 'linf_norm': 0.2370827954232692},
#  {'l1_norm': 0.011424997216463, 'linf_norm': 0.2426996969521045},
#  {'l1_norm': 0.0112198848433792, 'linf_norm': 0.2376737659439444},
#  {'l1_norm': 0.0111972231836989, 'linf_norm': 0.2369834742516279},
#  {'l1_norm': 0.0112264846656471, 'linf_norm': 0.2388024798780679},
#  {'l1_norm': 0.0113596200222149, 'linf_norm': 0.2410634902596473},
#  {'l1_norm': 0.0114264639334753, 'linf_norm': 0.2426940202966332},
#  {'l1_norm': 0.0113103089930489, 'linf_norm': 0.2399208355113864},
#  {'l1_norm': 0.0111701901083812, 'linf_norm': 0.2367038249239325},
#  {'l1_norm': 0.0112730717273429, 'linf_norm': 0.2389325885906815},
#  {'l1_norm': 0.0111926436979323, 'linf_norm': 0.2368108493804931},
#  {'l1_norm': 0.0113974850516766, 'linf_norm': 0.2419725169628858},
#  {'l1_norm': 0.011192178937979, 'linf_norm': 0.2372326681122183},
#  {'l1_norm': 0.0113867152083665, 'linf_norm': 0.2417723506137728},
#  {'l1_norm': 0.0116216603834182, 'linf_norm': 0.2472604754917323},
#  {'l1_norm': 0.0112741920832544, 'linf_norm': 0.2389650897487998},
#  {'l1_norm': 0.0112151864061132, 'linf_norm': 0.237642874982953},
#  {'l1_norm': 0.0115379311522468, 'linf_norm': 0.2456583502426743},
#  {'l1_norm': 0.0111850449539721, 'linf_norm': 0.2373460538432002},
#  {'l1_norm': 0.0115954273058101, 'linf_norm': 0.2469473167188465},
#  {'l1_norm': 0.0111885593760758, 'linf_norm': 0.237215486907959},
#  {'l1_norm': 0.0111952083142474, 'linf_norm': 0.236984534703195},
#  {'l1_norm': 0.0111869426673278, 'linf_norm': 0.2380863356411457},
#  {'l1_norm': 0.0113568033531308, 'linf_norm': 0.2409901917561888},
#  {'l1_norm': 0.0111673049367964, 'linf_norm': 0.2364087941348552},
#  {'l1_norm': 0.0115074058884754, 'linf_norm': 0.2447577474236488},
#  {'l1_norm': 0.0112658399825915, 'linf_norm': 0.2387207660377025},
#  {'l1_norm': 0.0111867864392697, 'linf_norm': 0.2369144014790654},
#  {'l1_norm': 0.0111565216083079, 'linf_norm': 0.2369740850687027},
#  {'l1_norm': 0.0111653387468308, 'linf_norm': 0.2362487551242113},
#  {'l1_norm': 0.0111775763534009, 'linf_norm': 0.2366552372440696},
#  {'l1_norm': 0.011203071860969, 'linf_norm': 0.2371185264572501},
#  {'l1_norm': 0.0112576756486669, 'linf_norm': 0.2385353691935539},
#  {'l1_norm': 0.0112373329985886, 'linf_norm': 0.2380720255687833},
#  {'l1_norm': 0.0111614809568971, 'linf_norm': 0.2367104675710201},
#  {'l1_norm': 0.0115387854931876, 'linf_norm': 0.2454277581125497},
#  {'l1_norm': 0.0111772016044706, 'linf_norm': 0.236749244877696},
#  {'l1_norm': 0.0115134846035391, 'linf_norm': 0.245140486164391},
#  {'l1_norm': 0.011242021434009, 'linf_norm': 0.2381521482557058},
#  {'l1_norm': 0.0112446328992024, 'linf_norm': 0.2383086269333958},
#  {'l1_norm': 0.0112334608236327, 'linf_norm': 0.2379431265719234},
#  {'l1_norm': 0.0113645508358255, 'linf_norm': 0.2412420800715685},
#  {'l1_norm': 0.0116987582471221, 'linf_norm': 0.2493720385931432},
#  {'l1_norm': 0.0111881400076672, 'linf_norm': 0.2368642968565225},
#  {'l1_norm': 0.0111526404002681, 'linf_norm': 0.2363542070239782},
#  {'l1_norm': 0.0113818033024668, 'linf_norm': 0.2417915898106992},
#  {'l1_norm': 0.011376128879562, 'linf_norm': 0.2416073160894215},
#  {'l1_norm': 0.0111877746744081, 'linf_norm': 0.2373202349334955},
#  {'l1_norm': 0.0111805112538859, 'linf_norm': 0.2374753662228584},
#  {'l1_norm': 0.0113473785674199, 'linf_norm': 0.2408484152860939},
#  {'l1_norm': 0.0111920100074261, 'linf_norm': 0.2369486638963222},
#  {'l1_norm': 0.0111651728201657, 'linf_norm': 0.2368132806032896},
#  {'l1_norm': 0.0111777795603498, 'linf_norm': 0.2366924072906374},
#  {'l1_norm': 0.0112152699107304, 'linf_norm': 0.237457741433382},
#  {'l1_norm': 0.0111717943966388, 'linf_norm': 0.2365169158264994},
#  {'l1_norm': 0.0112819086600095, 'linf_norm': 0.2392764568835497},
#  {'l1_norm': 0.0113162549158558, 'linf_norm': 0.2400421822637319},
#  {'l1_norm': 0.0111989320700988, 'linf_norm': 0.2370244721695781},
#  {'l1_norm': 0.0111781894233077, 'linf_norm': 0.2368381187796592},
#  {'l1_norm': 0.0114824693227186, 'linf_norm': 0.2442977712161839},
#  {'l1_norm': 0.011163904967904, 'linf_norm': 0.2365092302948236},
#  {'l1_norm': 0.0115026325307786, 'linf_norm': 0.2447660413667559},
#  {'l1_norm': 0.0111592499390244, 'linf_norm': 0.2374937167182564},
#  {'l1_norm': 0.0115236914500594, 'linf_norm': 0.2453092733092606},
#  {'l1_norm': 0.011224194686301, 'linf_norm': 0.2377157802835106},
#  {'l1_norm': 0.0113709542334079, 'linf_norm': 0.2416428668998181},
#  {'l1_norm': 0.0112812538439407, 'linf_norm': 0.2392607186853885},
#  {'l1_norm': 0.0111861528296023, 'linf_norm': 0.2372763734266162},
#  {'l1_norm': 0.0111862409427762, 'linf_norm': 0.2370729324460029},
#  {'l1_norm': 0.0113903236772865, 'linf_norm': 0.2420279265068471},
#  {'l1_norm': 0.0111852405348792, 'linf_norm': 0.2367196532607078},
#  {'l1_norm': 0.011363080471754, 'linf_norm': 0.2413214028343558},
#  {'l1_norm': 0.0114419556198641, 'linf_norm': 0.2433398287393152},
#  {'l1_norm': 0.0112480422973632, 'linf_norm': 0.2383768627934157},
#  {'l1_norm': 0.0111723907751962, 'linf_norm': 0.2366070582777261},
#  {'l1_norm': 0.0113024569418281, 'linf_norm': 0.2398539075069129},
#  {'l1_norm': 0.0111228978693485, 'linf_norm': 0.236088042062521},
#  {'l1_norm': 0.0113662088716402, 'linf_norm': 0.2414065676234662},
#  {'l1_norm': 0.0111883578857406, 'linf_norm': 0.2375614831089973},
#  {'l1_norm': 0.0111491184351965, 'linf_norm': 0.2360420700311661},
#  {'l1_norm': 0.0111317995287477, 'linf_norm': 0.2361976858139038},
#  {'l1_norm': 0.0111572091838344, 'linf_norm': 0.2365273249045014},
#  {'l1_norm': 0.0111386525968089, 'linf_norm': 0.2359257933944463},
#  {'l1_norm': 0.0111652737472206, 'linf_norm': 0.2367210371479392},
#  {'l1_norm': 0.0111912098160013, 'linf_norm': 0.2370520276993513},
#  {'l1_norm': 0.0111755128862336, 'linf_norm': 0.2365634140074253},
#  {'l1_norm': 0.0112938028562814, 'linf_norm': 0.2395517967015505},
#  {'l1_norm': 0.0112592635395005, 'linf_norm': 0.238860024049133},
#  {'l1_norm': 0.0112126518191769, 'linf_norm': 0.2376205674305558},
#  {'l1_norm': 0.011173134836927, 'linf_norm': 0.2366363484971225},
#  {'l1_norm': 0.0114216780912131, 'linf_norm': 0.2430645035892725},
#  {'l1_norm': 0.0113078307906165, 'linf_norm': 0.2399908962585032},
#  {'l1_norm': 0.011253436075896, 'linf_norm': 0.2386173898413777},
#  {'l1_norm': 0.0112156898096203, 'linf_norm': 0.2377822014138102},
#  {'l1_norm': 0.0112646990189328, 'linf_norm': 0.2385693796604871},
#  {'l1_norm': 0.011214230871573, 'linf_norm': 0.2373489929899573},
#  {'l1_norm': 0.0111677095575258, 'linf_norm': 0.2370353948950767},
#  {'l1_norm': 0.0113877098662778, 'linf_norm': 0.241976869443804},
#  {'l1_norm': 0.0113792932255193, 'linf_norm': 0.2417010974675417},
#  {'l1_norm': 0.0114451790789142, 'linf_norm': 0.2434159283317625},
#  {'l1_norm': 0.0113735424259677, 'linf_norm': 0.2416480865046382},
#  {'l1_norm': 0.0111863493774086, 'linf_norm': 0.2370812038138508},
#  {'l1_norm': 0.0112543962182477, 'linf_norm': 0.2384267437711358},
#  {'l1_norm': 0.0111662488752976, 'linf_norm': 0.2371495648041367},
#  {'l1_norm': 0.0111553261730819, 'linf_norm': 0.236024001789838},
#  {'l1_norm': 0.0111682520182803, 'linf_norm': 0.2366846986398101},
#  {'l1_norm': 0.0111547751642763, 'linf_norm': 0.236291752333194},
#  {'l1_norm': 0.0112005824230611, 'linf_norm': 0.2383468151420354},
#  {'l1_norm': 0.01116773519665, 'linf_norm': 0.2364799495771527},
#  {'l1_norm': 0.0112471740687266, 'linf_norm': 0.2384493031620979},
#  {'l1_norm': 0.0114614762017503, 'linf_norm': 0.2437359131842851},
#  {'l1_norm': 0.0112594813449308, 'linf_norm': 0.2387199466206133},
#  {'l1_norm': 0.0112033847130835, 'linf_norm': 0.2380875907450914},
#  {'l1_norm': 0.0113606192067265, 'linf_norm': 0.2414241441465914},
#  {'l1_norm': 0.0112937129052355, 'linf_norm': 0.2396454473406076},
#  {'l1_norm': 0.0111618098888546, 'linf_norm': 0.2368181879654526},
#  {'l1_norm': 0.0113256186246871, 'linf_norm': 0.2404860508657992},
#  {'l1_norm': 0.0111755511056631, 'linf_norm': 0.2367067204609513},
#  {'l1_norm': 0.0115829801334068, 'linf_norm': 0.2468324446573853},
#  {'l1_norm': 0.0111639398796483, 'linf_norm': 0.2369115341588854},
#  {'l1_norm': 0.0114705367160961, 'linf_norm': 0.2442305843286216},
#  {'l1_norm': 0.0113495531527325, 'linf_norm': 0.241158056615293},
#  {'l1_norm': 0.0111786970164626, 'linf_norm': 0.2370084635868668},
#  {'l1_norm': 0.0111833920581266, 'linf_norm': 0.2368057297676801},
#  {'l1_norm': 0.0111393524670973, 'linf_norm': 0.2358941527217626},
#  {'l1_norm': 0.0114119556710124, 'linf_norm': 0.2426466340325772},
#  {'l1_norm': 0.0111811310945078, 'linf_norm': 0.2377515421211719},
#  {'l1_norm': 0.0111666339630261, 'linf_norm': 0.2372620801240205},
#  {'l1_norm': 0.0111947058172896, 'linf_norm': 0.2371641662359237},
#  {'l1_norm': 0.0114445829581469, 'linf_norm': 0.2434277768567204},
#  {'l1_norm': 0.0111704805143177, 'linf_norm': 0.2380649021923542},
#  {'l1_norm': 0.0111431844266131, 'linf_norm': 0.2364566126838326},
#  {'l1_norm': 0.01119774744194, 'linf_norm': 0.237150377176702},
#  {'l1_norm': 0.0111660155082121, 'linf_norm': 0.2372636557906866},
#  {'l1_norm': 0.0111617946805432, 'linf_norm': 0.2374662705495953},
#  {'l1_norm': 0.0111417742880061, 'linf_norm': 0.2359531225353479},
#  {'l1_norm': 0.0114035740910097, 'linf_norm': 0.2424757015824317},
#  {'l1_norm': 0.0113518395138904, 'linf_norm': 0.2413073365285992},
#  {'l1_norm': 0.0111775241179391, 'linf_norm': 0.2384363602906465},
#  {'l1_norm': 0.0114728628873825, 'linf_norm': 0.2444497371539473},
#  {'l1_norm': 0.0111881000669673, 'linf_norm': 0.2370301344081759},
#  {'l1_norm': 0.0111752865271642, 'linf_norm': 0.2371494805201888},
#  {'l1_norm': 0.0111770095268264, 'linf_norm': 0.2369989014878869},
#  {'l1_norm': 0.0114356447452679, 'linf_norm': 0.2433846455745399},
#  {'l1_norm': 0.0112247958954423, 'linf_norm': 0.2378044748395681},
#  {'l1_norm': 0.0113493442989885, 'linf_norm': 0.2412046888887882},
#  {'l1_norm': 0.0111979976555332, 'linf_norm': 0.2373781639963388}]

# %%
len(test_metrics_loaded)
len(test_metrics_loaded[0])
# Out:
# 400
# 2

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %% [markdown]
# ## Counting the number of parameters on the network

# %%
net_loaded.eval()
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'The model has {count_parameters(net_loaded)} parameters.')
# Out:
# Net(
#   (hidden_activation): Sigmoid()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=600, bias=True)
#     (1): Linear(in_features=600, out_features=200, bias=True)
#     (2): Linear(in_features=200, out_features=1, bias=True)
#   )
# )
# The model has 122801 parameters.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ---
# ## Thesis

# %%
train_metrics_loaded[-10:]
test_metrics_loaded[-10:]
# Out:
# [{'l1_norm': 0.0132299261457985, 'linf_norm': 0.2865780784262344},
#  {'l1_norm': 0.0131230243486235, 'linf_norm': 0.2823748367040418},
#  {'l1_norm': 0.0131410097461892, 'linf_norm': 0.2796761171350255},
#  {'l1_norm': 0.013188516959967, 'linf_norm': 0.2804793174374849},
#  {'l1_norm': 0.0132668088375125, 'linf_norm': 0.2840360088680871},
#  {'l1_norm': 0.0131407254995079, 'linf_norm': 0.2791677417515777},
#  {'l1_norm': 0.0131690492888912, 'linf_norm': 0.2812666602040641},
#  {'l1_norm': 0.0131569827361498, 'linf_norm': 0.2818997822099365},
#  {'l1_norm': 0.013181861507357, 'linf_norm': 0.2830498933833092},
#  {'l1_norm': 0.013142774579511, 'linf_norm': 0.2796069753631949}]
# [{'l1_norm': 0.0113518395138904, 'linf_norm': 0.2413073365285992},
#  {'l1_norm': 0.0111775241179391, 'linf_norm': 0.2384363602906465},
#  {'l1_norm': 0.0114728628873825, 'linf_norm': 0.2444497371539473},
#  {'l1_norm': 0.0111881000669673, 'linf_norm': 0.2370301344081759},
#  {'l1_norm': 0.0111752865271642, 'linf_norm': 0.2371494805201888},
#  {'l1_norm': 0.0111770095268264, 'linf_norm': 0.2369989014878869},
#  {'l1_norm': 0.0114356447452679, 'linf_norm': 0.2433846455745399},
#  {'l1_norm': 0.0112247958954423, 'linf_norm': 0.2378044748395681},
#  {'l1_norm': 0.0113493442989885, 'linf_norm': 0.2412046888887882},
#  {'l1_norm': 0.0111979976555332, 'linf_norm': 0.2373781639963388}]

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# First figure: Train and Test L1 Norm
plt.figure(figsize=(6, 4))
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm", color='blue')
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
plt.title("NNSR1 Train and Test L1 Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR1_L1_norm_plot.png", dpi=300)

# Second figure: Train and Test Linf Norm
plt.figure(figsize=(6, 4))
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm", color='blue')
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
plt.title("NNSR1 Train and Test Linf Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR1_Linf_norm_plot.png", dpi=300)

# Third figure: MSE of training data and test data
plt.figure(figsize=(6, 4))
plt.plot(train_losses_loaded, label="Training Data", color='blue')
plt.plot(test_losses_loaded, label="Test Data", color='red')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("NNSR1 MSE of Training and Test Data per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-7, 1e0)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR1_MSE_plot.png", dpi=300)

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

def save_metrics_to_csv(metrics_data, filename):
    df = pd.DataFrame(metrics_data)
    df.columns = ['L1 Norm', 'Linf Norm']
    df.to_csv(filename, index=False)

save_metrics_to_csv(train_metrics_loaded, 'train_metrics_NNSR1.csv')
save_metrics_to_csv(test_metrics_loaded, 'test_metrics_NNSR1.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 1.9683e-02,  6.6910e-01, -1.0763e+00],
#         [ 4.7322e-03,  4.1026e-01, -8.4866e-01],
#         [ 7.8186e-03,  6.7946e-01, -1.0336e+00],
#         ...,
#         [-4.5930e-03,  6.0222e-01, -9.1392e-01],
#         [-1.1787e+00, -2.3373e+00,  4.2116e-01],
#         [ 1.1814e-03,  6.2800e-01, -9.4704e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([-10.9742, -11.0311, -11.6212,  -2.9740, -11.2726,  -2.1250,  -5.9841,
#          -1.4977,  -4.0242,  -1.1046,  -2.4409, -11.3583,  -1.6901,   0.1997,
#          -6.5848,  -1.6376,  -1.3428, -12.3658,  -9.2188,   1.0427,  -2.2368,
#          -0.6974,  -1.5252,  -4.6259,  -9.9853,  -5.8443,  -2.3777,  -2.2247,
#         -11.9492, -10.7338,  -4.3188,  -1.5658,  -5.3648, -11.4656,  -1.4165,
#         -12.0911, -12.3597,  -1.6724,  -3.4340,   1.5967,  -9.7749,  -2.1293,
#          -0.2582,  -3.2644, -12.2626, -11.6188, -11.9440, -10.7337,  -1.2041,
#         -12.5881, -12.0196,  -3.7845, -11.2184,  -7.7486,  -9.9219, -12.4863,
#          -6.8359,  -9.0209,  -3.7594, -12.1183,  -1.9529,  -2.7827,  -2.0623,
#          -4.1348, -11.7939,  -8.5721,  -4.0051,  -1.6643, -11.0176, -10.6538,
#          -2.7094, -12.0158, -11.9769, -10.9664,  -4.6459,  -9.9030,   1.9683,
#         -12.5454, -10.5908, -10.1271,  -3.9880, -10.0548,  -5.8133, -12.4453,
#          -1.0231,  -9.5692,  -8.1147,  -1.9958, -10.5011,  -9.6281,  -8.2883,
#          -5.5556,   2.0124,  -8.3309,  -4.5579, -11.8351,  -1.3813, -11.5445,
#          -2.8024,  -1.6159, -11.6331,  -5.3705,  -4.6210,  -9.1789, -12.2943,
#         -10.2017, -10.4124,  -8.2899, -10.5113, -12.4799,  -3.0149,  -2.0745,
#         -12.5896,  -1.6071,  -1.3489, -12.1448, -10.9363,  -9.4093, -12.0267,
#          -1.6447, -11.3452, -12.0030, -12.4679,  -4.0730, -10.8142,  -1.9000,
#          -1.1457,  -2.4455,  -5.0283,  -3.1196,  -7.0094, -10.8228, -11.0301,
#         -11.3203, -10.4507, -12.2004, -11.6495, -11.7596, -12.5704, -12.2161,
#         -11.1327,  -6.5593, -12.2936, -12.4314,  -6.6305,  -1.2678,  -1.3749,
#          -1.9393,  -1.9583,   1.0118,  -2.6455, -11.3237, -11.8226,  -5.2808,
#          -2.8814,  -9.9802,   0.1956,  -8.7894,  -3.5070,  -5.1650,  -2.7487,
#         -10.8183,  -2.3021,  -2.2103, -11.6408, -12.1970, -10.4793,  -1.2703,
#          -4.5846,  -2.2285,  -3.7368,  -1.2553,  -2.7551,  -4.1441, -11.3636,
#         -12.5585, -12.2652,  -1.4739, -11.8739,  -9.5413, -11.3857, -12.2545,
#          -2.9457,  -4.2276, -11.2270,  -0.6914,  -3.6959,  -8.7902,  -1.6832,
#          -0.9618, -12.4988,  -2.5408,  -3.5402, -12.2772,  -1.1598,  -1.5019,
#         -11.1400, -11.5910,  -1.7805,  -4.6176,  -2.1945,  -9.1956,  -1.6628,
#         -11.7692, -12.3535,  -1.4908, -10.2081,  -1.8274,  -9.3898,  -4.5394,
#          -2.2901,  -5.2796,  -3.2292, -10.2429,  -4.3475,  -6.0388,  -3.2424,
#         -11.9959,  -2.3585, -10.4342,  -5.2905,  -9.0763, -12.0480,  -2.9697,
#         -11.7517, -10.7949,  -1.0998,  -8.5814,  -6.8508, -10.6907,  -4.0348,
#         -10.8031,  -3.1437,  -4.2699,  -1.8046, -10.8001, -11.7349,  -1.9325,
#          -9.0619, -11.6565,  -7.9333,  -0.4603, -12.1702,  -2.3767,  -9.3873,
#         -10.8100, -11.2745,  -2.0358, -11.6203,  -7.6409,   0.9496,  -4.4299,
#         -11.9566,   1.6114, -12.5174,  -2.6354, -11.7854, -11.6520, -12.4208,
#          -2.0145, -11.9630, -12.2579,  -9.4917, -12.1717,  -4.9807, -12.0031,
#         -10.3188, -10.1584, -12.2926,  -3.0376, -12.4629,  -3.9551, -12.1198,
#         -12.0591,  -8.7546, -12.0216,  -7.4618,  -6.6089,  -8.6952,  -8.2425,
#         -12.2828,  -2.7948,   0.5608,  -2.7715,  -1.4938, -11.8777,  -7.2646,
#          -3.2702,  -2.1316, -11.0598,  -2.7281,  -4.5794,  -2.3350,  -1.2404,
#          -4.3087,  -5.0274,  -1.5458, -10.8599,  -3.8515,  -8.4831,  -3.4503,
#          -4.3158,  -2.4633,  -4.5680,  -4.1273,  -1.5215,   0.4911, -12.0469,
#          -7.2327,  -1.3556,  -2.6729,  -5.8175, -11.9554, -12.4311,   0.5659,
#         -11.8275, -11.1037, -11.7449, -10.2584,  -3.4688,  -0.2367,  -3.3707,
#          -4.0902, -11.8920,  -3.0545, -12.1096, -12.2009, -12.5846,  -1.9819,
#         -11.9423,  -9.9155,  -2.7075, -12.0620, -11.4157,  -1.4118,   0.3742,
#          -2.3803,  -3.1746,  -3.4491,  -0.3094,  -2.8814,  -3.1851, -10.2645,
#          -4.4976,  -6.9314, -10.0886,  -3.2275, -12.2914,  -6.4859,  -3.0061,
#          -1.6555,  -9.1195,  -1.5825,  -2.4067,  -0.3489,  -2.7417,  -0.2621,
#          -7.4999, -12.3122, -10.9567,  -2.3027,  -2.4350, -10.1663, -10.7953,
#          -3.0884,  -1.2954,  -7.5321,  -6.0889,  -1.2646,  -0.9644,  -1.2132,
#          -9.0625,  -5.1569,  -7.6879,  -7.3314,  -4.5520,  -3.1429,  -4.2805,
#         -11.7460, -12.0354,  -3.2813, -10.6135,  -3.5437, -12.4787,  -7.9719,
#          -2.5808, -12.1606, -11.7200,  -7.3197, -10.1819,  -6.1877, -12.4379,
#         -10.8430,  -1.2594,  -1.1495,  -1.1504, -12.2910, -11.6186,  -4.5397,
#         -12.1674, -11.7925, -10.5225, -11.2087,  -8.9983, -11.8924, -12.0330,
#          -1.6719,  -5.1752, -11.8882,  -1.6977, -12.3507,  -2.6073, -11.9016,
#         -12.4702, -12.0117,  -6.5908,  -1.7826, -11.9128,  -5.3717,  -1.7529,
#          -0.5544,  -5.7499, -12.1263,  -3.0676,  -8.8874,  -5.4960,  -9.9148,
#          -5.9673,  -9.5774,  -1.3174, -10.5756,  -8.2572,  -2.8038, -10.3785,
#         -10.3567, -11.5704,  -8.9947,  -2.9655,  -1.8352,  -1.2418, -10.7593,
#          -2.4387, -11.7773, -11.2213,  -3.5165,  -2.6055,  -2.5142, -11.8907,
#          -1.8554, -10.2430,  -8.8575,  -7.8699, -11.1664,  -1.4596, -12.1185,
#          -3.9296,  -6.0681,  -3.3416,  -5.8295,  -4.0853,  -2.4867,  -4.9199,
#         -11.7680, -11.2016,  -7.6629, -11.1982, -12.5241,  -1.2940,  -3.7157,
#          -0.1531,  -0.6862,  -7.5271, -11.6080, -10.9572, -10.2286, -11.9771,
#          -2.6908,  -7.9012,  -5.2164,   0.2542, -12.0465, -12.5299, -11.8889,
#          -2.0367, -11.7509, -11.8646,  -1.7160,  -1.8159, -12.5471, -11.9513,
#         -12.2262,  -1.8483, -12.3987,  -7.4550, -11.2195,  -0.9141,  -3.0295,
#          -8.4360, -10.4549,  -1.7639,  -4.5717,  -6.4094,  -2.7567,  -6.8359,
#          -2.4241,  -5.4252,  -9.9271,  -1.1355, -11.0877,  -4.7588,  -8.0734,
#          -2.1125, -11.2125,  -5.7958,   1.4078,  -0.1483,  -0.9378, -12.3998,
#          -2.3485, -11.0730,  -7.7488, -11.3663,  -2.9883,  -0.3790,  -6.3478,
#         -10.1026,  -1.3916,  -5.6613, -11.7623,  -1.4889, -10.3853,  -1.5857,
#          -6.4497,  -1.0473, -11.5557,  -4.1005,  -9.4283,  -2.4196,  -3.2962,
#           0.3094,  -1.3436,  -1.5879,  -6.2583,  -2.0871, -10.6641,  -7.4628,
#          -1.3937,  -4.9885,  -4.1553,  -4.3187,  -4.0483, -12.4014,  -5.4300,
#         -11.4148,  -3.1734, -10.4662, -10.8367, -12.2516, -12.2270,  -5.5193,
#          -3.2610,  -1.6946,  -3.5406,  -3.7467,  -6.1957,  -5.3227,   1.0694,
#          -2.4538, -12.1303,  -6.1761,  -2.6990,  -2.5247, -11.9415,  -8.5222,
#          -3.4886,   0.9334, -12.4095,  -2.8314,  -3.0684,  -4.8144,  -0.6026,
#         -12.2365,  -2.7316, -11.3046,  -1.7373,  -2.4080,  -8.2558,  -2.1799,
#          -2.1007,  -1.3083, -11.2753,  -5.5313,  -2.6019,  -2.8167, -11.1191,
#          -0.9126, -11.6133, -12.2474,  -4.4714, -12.0916], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[ 7.3345e-02,  2.6370e-01,  7.5688e-03,  ...,  2.8587e-02,
#           3.6812e+00,  2.7528e-02],
#         [-5.8483e-02, -3.6190e-02, -6.7512e-02,  ..., -6.2708e-02,
#          -1.2147e-01, -6.4166e-02],
#         [-8.5455e-02, -1.7845e-01, -7.5367e-02,  ..., -1.7858e-02,
#          -1.4399e-01, -7.2447e-02],
#         ...,
#         [ 6.3902e-02,  1.5026e-01,  1.3048e-01,  ...,  9.4750e-02,
#           8.9123e-02,  6.9591e-02],
#         [ 1.0850e-01,  3.7262e-01,  1.7443e-02,  ...,  3.4963e-02,
#           3.1186e-01,  5.0164e-02],
#         [ 2.6539e-02, -5.8126e-02,  5.1346e-02,  ..., -2.5071e-03,
#          -1.2206e-01,  5.8104e-02]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.3785,  0.2642, -0.6715, -0.6740, -0.4738, -0.7037, -0.7143,  0.0326,
#         -0.1861, -1.1240, -0.7158, -0.5420, -0.7350,  0.4309, -0.7336, -0.6496,
#         -0.5814,  0.2610, -0.6437,  0.0190,  0.4091,  0.3563,  0.3283, -0.7041,
#          0.3983, -0.6868, -0.6624, -0.1969, -0.5062, -0.7666, -0.6867, -0.7044,
#         -0.6969, -0.6692, -0.6245, -0.6722, -0.7189, -0.7880, -0.6754, -0.6736,
#          0.2633,  0.3678, -0.7000, -0.7024, -0.7104, -0.6929, -0.7258,  0.2170,
#          0.1977, -0.6766, -0.6678, -0.6347, -0.6735, -0.6293, -0.7569, -0.7004,
#         -0.6958,  0.0688, -0.7317, -0.6617,  0.3272, -0.7034,  0.3393,  0.0186,
#          0.1863, -0.5082, -0.1925, -0.7230,  0.3365, -0.6702, -0.0687, -0.7188,
#         -0.6803, -0.6646,  0.4145, -1.0867,  0.3022,  0.3828, -0.6708, -0.7890,
#          0.2208, -0.0877, -0.7056, -0.7519,  0.1443, -0.6383, -0.6357, -0.7207,
#         -0.7019, -0.6918, -0.5537, -0.1976, -0.0520, -0.7186,  0.3459, -0.7054,
#         -0.6512, -0.6485,  0.0528,  0.3281,  0.2704, -0.2084, -0.7268,  0.3250,
#         -0.6984, -0.4916, -0.7244, -0.6740, -0.6789, -0.5577,  0.0768, -0.7033,
#         -0.3733, -0.7673, -0.7434,  0.0537, -0.2108, -0.4015, -0.6556, -0.6418,
#         -0.7278, -0.6942, -0.6974,  0.3781, -0.5092, -0.3229, -0.6858, -0.7071,
#         -0.7185, -0.4566,  0.2242,  0.4099, -0.6835, -0.7743, -0.7160, -0.8185,
#         -0.6401, -0.6709, -0.6537, -0.3793, -0.7557, -0.0077,  0.3134, -0.2319,
#          0.0929, -0.7135,  0.1582,  0.6197, -0.7214,  0.2973,  0.3449,  0.2720,
#         -0.6822, -0.6634, -0.6989, -0.8104,  0.3592, -0.6323, -0.7581,  0.2514,
#         -0.0504,  0.2391,  0.2032,  0.1314,  0.5679, -0.7441, -0.6857, -0.6831,
#          0.2855, -0.6741,  0.3523, -0.7213,  0.2615, -0.6414, -0.6689, -0.6533,
#         -0.7377, -0.1434,  0.3431, -0.7239, -0.6948,  0.3417,  0.4151, -0.2291,
#         -0.5070, -0.7844, -0.6901,  0.3929, -0.3019,  0.0374, -0.7132, -0.7133,
#         -0.6668, -0.5334,  0.5848,  0.3482,  0.3952,  0.3612, -0.0097, -0.6657],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0147,  1.9193,  0.3932,  0.3656,  1.4325,  0.3812,  0.3318,  0.0227,
#           0.0259,  0.1367,  0.3806, -0.5711,  0.3445, -0.0344,  0.3716,  0.4243,
#           0.4875, -0.0251,  0.3851,  0.0264, -0.0351, -0.0352, -0.0215,  0.3870,
#          -0.0342,  0.3461,  0.3845,  0.8671,  0.0612,  0.3517,  0.3858,  0.3875,
#           0.3773,  0.3585,  0.4085,  0.3806,  0.3683,  0.2863,  0.3508,  0.3623,
#           0.0610, -0.0369,  0.3897,  0.3537,  0.3572,  0.3392,  0.6746, -0.0208,
#          -0.0232,  0.4201,  0.4087,  0.4714,  0.3835,  0.4676,  0.3455,  0.4004,
#           0.3387,  0.2150,  0.3605,  0.3778, -0.0280,  0.3909, -0.0268,  0.0238,
#           0.0210,  0.1010,  0.0165,  0.2844, -0.0234,  0.3631,  0.0236,  0.3622,
#           0.3658,  0.3987, -0.0276, -0.0204,  0.0209, -0.0373,  0.3658,  0.2793,
#          -1.3099, -0.3512,  0.3846,  0.3524,  0.0294,  0.3923,  0.4132,  0.3715,
#           0.3832,  0.3641,  0.5045, -0.8954,  0.0272,  0.3517, -0.0319,  0.3969,
#           0.3900,  0.3783,  0.0231, -0.0253, -0.0215,  0.0309,  0.3270, -0.0231,
#           0.3798,  0.5169,  0.3357,  0.3831,  0.3549,  0.5037,  1.8187,  0.3786,
#           0.7285,  0.2611,  0.3116,  3.1544,  0.0242,  0.6523,  0.3794,  0.3885,
#           0.3565,  0.3557,  0.3829, -0.0339,  0.5859,  2.8106,  0.3590,  0.3958,
#           0.3802,  0.6916,  0.0316, -0.0346,  0.3732,  0.2725,  0.3608,  0.2708,
#           0.4460,  0.3875,  0.3925,  0.7050,  0.3404,  0.0221, -0.0239,  0.8139,
#           0.0733,  0.3537, -0.0161,  0.1899,  0.2776, -0.0252, -0.0299,  0.0110,
#           0.3620,  0.3795,  0.4025,  0.1338, -0.0249,  0.4009,  0.3432, -0.0195,
#           0.0087, -0.0160, -0.0166, -0.0173,  0.1268,  0.3577,  0.3845,  0.3673,
#          -0.0261,  0.3738, -0.0335,  0.2845, -0.0278,  0.3889,  0.3657,  0.4053,
#           0.3779,  2.8964, -0.0253,  0.3822,  0.3715, -0.0298, -0.0320,  0.0349,
#           0.5290,  0.2986,  0.4012, -0.0245,  0.0895,  0.0144,  0.3996,  0.3504,
#           0.3726,  0.5133,  0.4044, -0.0274, -0.0233, -0.0307,  0.0249,  0.4702]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0045], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 1.9683e-02,  6.6910e-01, -1.0763e+00],
#         [ 4.7322e-03,  4.1026e-01, -8.4866e-01],
#         [ 7.8186e-03,  6.7946e-01, -1.0336e+00],
#         ...,
#         [-4.5930e-03,  6.0222e-01, -9.1392e-01],
#         [-1.1787e+00, -2.3373e+00,  4.2116e-01],
#         [ 1.1814e-03,  6.2800e-01, -9.4704e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([-10.9742, -11.0311, -11.6212,  -2.9740, -11.2726,  -2.1250,  -5.9841,
#          -1.4977,  -4.0242,  -1.1046,  -2.4409, -11.3583,  -1.6901,   0.1997,
#          -6.5848,  -1.6376,  -1.3428, -12.3658,  -9.2188,   1.0427,  -2.2368,
#          -0.6974,  -1.5252,  -4.6259,  -9.9853,  -5.8443,  -2.3777,  -2.2247,
#         -11.9492, -10.7338,  -4.3188,  -1.5658,  -5.3648, -11.4656,  -1.4165,
#         -12.0911, -12.3597,  -1.6724,  -3.4340,   1.5967,  -9.7749,  -2.1293,
#          -0.2582,  -3.2644, -12.2626, -11.6188, -11.9440, -10.7337,  -1.2041,
#         -12.5881, -12.0196,  -3.7845, -11.2184,  -7.7486,  -9.9219, -12.4863,
#          -6.8359,  -9.0209,  -3.7594, -12.1183,  -1.9529,  -2.7827,  -2.0623,
#          -4.1348, -11.7939,  -8.5721,  -4.0051,  -1.6643, -11.0176, -10.6538,
#          -2.7094, -12.0158, -11.9769, -10.9664,  -4.6459,  -9.9030,   1.9683,
#         -12.5454, -10.5908, -10.1271,  -3.9880, -10.0548,  -5.8133, -12.4453,
#          -1.0231,  -9.5692,  -8.1147,  -1.9958, -10.5011,  -9.6281,  -8.2883,
#          -5.5556,   2.0124,  -8.3309,  -4.5579, -11.8351,  -1.3813, -11.5445,
#          -2.8024,  -1.6159, -11.6331,  -5.3705,  -4.6210,  -9.1789, -12.2943,
#         -10.2017, -10.4124,  -8.2899, -10.5113, -12.4799,  -3.0149,  -2.0745,
#         -12.5896,  -1.6071,  -1.3489, -12.1448, -10.9363,  -9.4093, -12.0267,
#          -1.6447, -11.3452, -12.0030, -12.4679,  -4.0730, -10.8142,  -1.9000,
#          -1.1457,  -2.4455,  -5.0283,  -3.1196,  -7.0094, -10.8228, -11.0301,
#         -11.3203, -10.4507, -12.2004, -11.6495, -11.7596, -12.5704, -12.2161,
#         -11.1327,  -6.5593, -12.2936, -12.4314,  -6.6305,  -1.2678,  -1.3749,
#          -1.9393,  -1.9583,   1.0118,  -2.6455, -11.3237, -11.8226,  -5.2808,
#          -2.8814,  -9.9802,   0.1956,  -8.7894,  -3.5070,  -5.1650,  -2.7487,
#         -10.8183,  -2.3021,  -2.2103, -11.6408, -12.1970, -10.4793,  -1.2703,
#          -4.5846,  -2.2285,  -3.7368,  -1.2553,  -2.7551,  -4.1441, -11.3636,
#         -12.5585, -12.2652,  -1.4739, -11.8739,  -9.5413, -11.3857, -12.2545,
#          -2.9457,  -4.2276, -11.2270,  -0.6914,  -3.6959,  -8.7902,  -1.6832,
#          -0.9618, -12.4988,  -2.5408,  -3.5402, -12.2772,  -1.1598,  -1.5019,
#         -11.1400, -11.5910,  -1.7805,  -4.6176,  -2.1945,  -9.1956,  -1.6628,
#         -11.7692, -12.3535,  -1.4908, -10.2081,  -1.8274,  -9.3898,  -4.5394,
#          -2.2901,  -5.2796,  -3.2292, -10.2429,  -4.3475,  -6.0388,  -3.2424,
#         -11.9959,  -2.3585, -10.4342,  -5.2905,  -9.0763, -12.0480,  -2.9697,
#         -11.7517, -10.7949,  -1.0998,  -8.5814,  -6.8508, -10.6907,  -4.0348,
#         -10.8031,  -3.1437,  -4.2699,  -1.8046, -10.8001, -11.7349,  -1.9325,
#          -9.0619, -11.6565,  -7.9333,  -0.4603, -12.1702,  -2.3767,  -9.3873,
#         -10.8100, -11.2745,  -2.0358, -11.6203,  -7.6409,   0.9496,  -4.4299,
#         -11.9566,   1.6114, -12.5174,  -2.6354, -11.7854, -11.6520, -12.4208,
#          -2.0145, -11.9630, -12.2579,  -9.4917, -12.1717,  -4.9807, -12.0031,
#         -10.3188, -10.1584, -12.2926,  -3.0376, -12.4629,  -3.9551, -12.1198,
#         -12.0591,  -8.7546, -12.0216,  -7.4618,  -6.6089,  -8.6952,  -8.2425,
#         -12.2828,  -2.7948,   0.5608,  -2.7715,  -1.4938, -11.8777,  -7.2646,
#          -3.2702,  -2.1316, -11.0598,  -2.7281,  -4.5794,  -2.3350,  -1.2404,
#          -4.3087,  -5.0274,  -1.5458, -10.8599,  -3.8515,  -8.4831,  -3.4503,
#          -4.3158,  -2.4633,  -4.5680,  -4.1273,  -1.5215,   0.4911, -12.0469,
#          -7.2327,  -1.3556,  -2.6729,  -5.8175, -11.9554, -12.4311,   0.5659,
#         -11.8275, -11.1037, -11.7449, -10.2584,  -3.4688,  -0.2367,  -3.3707,
#          -4.0902, -11.8920,  -3.0545, -12.1096, -12.2009, -12.5846,  -1.9819,
#         -11.9423,  -9.9155,  -2.7075, -12.0620, -11.4157,  -1.4118,   0.3742,
#          -2.3803,  -3.1746,  -3.4491,  -0.3094,  -2.8814,  -3.1851, -10.2645,
#          -4.4976,  -6.9314, -10.0886,  -3.2275, -12.2914,  -6.4859,  -3.0061,
#          -1.6555,  -9.1195,  -1.5825,  -2.4067,  -0.3489,  -2.7417,  -0.2621,
#          -7.4999, -12.3122, -10.9567,  -2.3027,  -2.4350, -10.1663, -10.7953,
#          -3.0884,  -1.2954,  -7.5321,  -6.0889,  -1.2646,  -0.9644,  -1.2132,
#          -9.0625,  -5.1569,  -7.6879,  -7.3314,  -4.5520,  -3.1429,  -4.2805,
#         -11.7460, -12.0354,  -3.2813, -10.6135,  -3.5437, -12.4787,  -7.9719,
#          -2.5808, -12.1606, -11.7200,  -7.3197, -10.1819,  -6.1877, -12.4379,
#         -10.8430,  -1.2594,  -1.1495,  -1.1504, -12.2910, -11.6186,  -4.5397,
#         -12.1674, -11.7925, -10.5225, -11.2087,  -8.9983, -11.8924, -12.0330,
#          -1.6719,  -5.1752, -11.8882,  -1.6977, -12.3507,  -2.6073, -11.9016,
#         -12.4702, -12.0117,  -6.5908,  -1.7826, -11.9128,  -5.3717,  -1.7529,
#          -0.5544,  -5.7499, -12.1263,  -3.0676,  -8.8874,  -5.4960,  -9.9148,
#          -5.9673,  -9.5774,  -1.3174, -10.5756,  -8.2572,  -2.8038, -10.3785,
#         -10.3567, -11.5704,  -8.9947,  -2.9655,  -1.8352,  -1.2418, -10.7593,
#          -2.4387, -11.7773, -11.2213,  -3.5165,  -2.6055,  -2.5142, -11.8907,
#          -1.8554, -10.2430,  -8.8575,  -7.8699, -11.1664,  -1.4596, -12.1185,
#          -3.9296,  -6.0681,  -3.3416,  -5.8295,  -4.0853,  -2.4867,  -4.9199,
#         -11.7680, -11.2016,  -7.6629, -11.1982, -12.5241,  -1.2940,  -3.7157,
#          -0.1531,  -0.6862,  -7.5271, -11.6080, -10.9572, -10.2286, -11.9771,
#          -2.6908,  -7.9012,  -5.2164,   0.2542, -12.0465, -12.5299, -11.8889,
#          -2.0367, -11.7509, -11.8646,  -1.7160,  -1.8159, -12.5471, -11.9513,
#         -12.2262,  -1.8483, -12.3987,  -7.4550, -11.2195,  -0.9141,  -3.0295,
#          -8.4360, -10.4549,  -1.7639,  -4.5717,  -6.4094,  -2.7567,  -6.8359,
#          -2.4241,  -5.4252,  -9.9271,  -1.1355, -11.0877,  -4.7588,  -8.0734,
#          -2.1125, -11.2125,  -5.7958,   1.4078,  -0.1483,  -0.9378, -12.3998,
#          -2.3485, -11.0730,  -7.7488, -11.3663,  -2.9883,  -0.3790,  -6.3478,
#         -10.1026,  -1.3916,  -5.6613, -11.7623,  -1.4889, -10.3853,  -1.5857,
#          -6.4497,  -1.0473, -11.5557,  -4.1005,  -9.4283,  -2.4196,  -3.2962,
#           0.3094,  -1.3436,  -1.5879,  -6.2583,  -2.0871, -10.6641,  -7.4628,
#          -1.3937,  -4.9885,  -4.1553,  -4.3187,  -4.0483, -12.4014,  -5.4300,
#         -11.4148,  -3.1734, -10.4662, -10.8367, -12.2516, -12.2270,  -5.5193,
#          -3.2610,  -1.6946,  -3.5406,  -3.7467,  -6.1957,  -5.3227,   1.0694,
#          -2.4538, -12.1303,  -6.1761,  -2.6990,  -2.5247, -11.9415,  -8.5222,
#          -3.4886,   0.9334, -12.4095,  -2.8314,  -3.0684,  -4.8144,  -0.6026,
#         -12.2365,  -2.7316, -11.3046,  -1.7373,  -2.4080,  -8.2558,  -2.1799,
#          -2.1007,  -1.3083, -11.2753,  -5.5313,  -2.6019,  -2.8167, -11.1191,
#          -0.9126, -11.6133, -12.2474,  -4.4714, -12.0916], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[ 7.3345e-02,  2.6370e-01,  7.5688e-03,  ...,  2.8587e-02,
#           3.6812e+00,  2.7528e-02],
#         [-5.8483e-02, -3.6190e-02, -6.7512e-02,  ..., -6.2708e-02,
#          -1.2147e-01, -6.4166e-02],
#         [-8.5455e-02, -1.7845e-01, -7.5367e-02,  ..., -1.7858e-02,
#          -1.4399e-01, -7.2447e-02],
#         ...,
#         [ 6.3902e-02,  1.5026e-01,  1.3048e-01,  ...,  9.4750e-02,
#           8.9123e-02,  6.9591e-02],
#         [ 1.0850e-01,  3.7262e-01,  1.7443e-02,  ...,  3.4963e-02,
#           3.1186e-01,  5.0164e-02],
#         [ 2.6539e-02, -5.8126e-02,  5.1346e-02,  ..., -2.5071e-03,
#          -1.2206e-01,  5.8104e-02]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.3785,  0.2642, -0.6715, -0.6740, -0.4738, -0.7037, -0.7143,  0.0326,
#         -0.1861, -1.1240, -0.7158, -0.5420, -0.7350,  0.4309, -0.7336, -0.6496,
#         -0.5814,  0.2610, -0.6437,  0.0190,  0.4091,  0.3563,  0.3283, -0.7041,
#          0.3983, -0.6868, -0.6624, -0.1969, -0.5062, -0.7666, -0.6867, -0.7044,
#         -0.6969, -0.6692, -0.6245, -0.6722, -0.7189, -0.7880, -0.6754, -0.6736,
#          0.2633,  0.3678, -0.7000, -0.7024, -0.7104, -0.6929, -0.7258,  0.2170,
#          0.1977, -0.6766, -0.6678, -0.6347, -0.6735, -0.6293, -0.7569, -0.7004,
#         -0.6958,  0.0688, -0.7317, -0.6617,  0.3272, -0.7034,  0.3393,  0.0186,
#          0.1863, -0.5082, -0.1925, -0.7230,  0.3365, -0.6702, -0.0687, -0.7188,
#         -0.6803, -0.6646,  0.4145, -1.0867,  0.3022,  0.3828, -0.6708, -0.7890,
#          0.2208, -0.0877, -0.7056, -0.7519,  0.1443, -0.6383, -0.6357, -0.7207,
#         -0.7019, -0.6918, -0.5537, -0.1976, -0.0520, -0.7186,  0.3459, -0.7054,
#         -0.6512, -0.6485,  0.0528,  0.3281,  0.2704, -0.2084, -0.7268,  0.3250,
#         -0.6984, -0.4916, -0.7244, -0.6740, -0.6789, -0.5577,  0.0768, -0.7033,
#         -0.3733, -0.7673, -0.7434,  0.0537, -0.2108, -0.4015, -0.6556, -0.6418,
#         -0.7278, -0.6942, -0.6974,  0.3781, -0.5092, -0.3229, -0.6858, -0.7071,
#         -0.7185, -0.4566,  0.2242,  0.4099, -0.6835, -0.7743, -0.7160, -0.8185,
#         -0.6401, -0.6709, -0.6537, -0.3793, -0.7557, -0.0077,  0.3134, -0.2319,
#          0.0929, -0.7135,  0.1582,  0.6197, -0.7214,  0.2973,  0.3449,  0.2720,
#         -0.6822, -0.6634, -0.6989, -0.8104,  0.3592, -0.6323, -0.7581,  0.2514,
#         -0.0504,  0.2391,  0.2032,  0.1314,  0.5679, -0.7441, -0.6857, -0.6831,
#          0.2855, -0.6741,  0.3523, -0.7213,  0.2615, -0.6414, -0.6689, -0.6533,
#         -0.7377, -0.1434,  0.3431, -0.7239, -0.6948,  0.3417,  0.4151, -0.2291,
#         -0.5070, -0.7844, -0.6901,  0.3929, -0.3019,  0.0374, -0.7132, -0.7133,
#         -0.6668, -0.5334,  0.5848,  0.3482,  0.3952,  0.3612, -0.0097, -0.6657],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0147,  1.9193,  0.3932,  0.3656,  1.4325,  0.3812,  0.3318,  0.0227,
#           0.0259,  0.1367,  0.3806, -0.5711,  0.3445, -0.0344,  0.3716,  0.4243,
#           0.4875, -0.0251,  0.3851,  0.0264, -0.0351, -0.0352, -0.0215,  0.3870,
#          -0.0342,  0.3461,  0.3845,  0.8671,  0.0612,  0.3517,  0.3858,  0.3875,
#           0.3773,  0.3585,  0.4085,  0.3806,  0.3683,  0.2863,  0.3508,  0.3623,
#           0.0610, -0.0369,  0.3897,  0.3537,  0.3572,  0.3392,  0.6746, -0.0208,
#          -0.0232,  0.4201,  0.4087,  0.4714,  0.3835,  0.4676,  0.3455,  0.4004,
#           0.3387,  0.2150,  0.3605,  0.3778, -0.0280,  0.3909, -0.0268,  0.0238,
#           0.0210,  0.1010,  0.0165,  0.2844, -0.0234,  0.3631,  0.0236,  0.3622,
#           0.3658,  0.3987, -0.0276, -0.0204,  0.0209, -0.0373,  0.3658,  0.2793,
#          -1.3099, -0.3512,  0.3846,  0.3524,  0.0294,  0.3923,  0.4132,  0.3715,
#           0.3832,  0.3641,  0.5045, -0.8954,  0.0272,  0.3517, -0.0319,  0.3969,
#           0.3900,  0.3783,  0.0231, -0.0253, -0.0215,  0.0309,  0.3270, -0.0231,
#           0.3798,  0.5169,  0.3357,  0.3831,  0.3549,  0.5037,  1.8187,  0.3786,
#           0.7285,  0.2611,  0.3116,  3.1544,  0.0242,  0.6523,  0.3794,  0.3885,
#           0.3565,  0.3557,  0.3829, -0.0339,  0.5859,  2.8106,  0.3590,  0.3958,
#           0.3802,  0.6916,  0.0316, -0.0346,  0.3732,  0.2725,  0.3608,  0.2708,
#           0.4460,  0.3875,  0.3925,  0.7050,  0.3404,  0.0221, -0.0239,  0.8139,
#           0.0733,  0.3537, -0.0161,  0.1899,  0.2776, -0.0252, -0.0299,  0.0110,
#           0.3620,  0.3795,  0.4025,  0.1338, -0.0249,  0.4009,  0.3432, -0.0195,
#           0.0087, -0.0160, -0.0166, -0.0173,  0.1268,  0.3577,  0.3845,  0.3673,
#          -0.0261,  0.3738, -0.0335,  0.2845, -0.0278,  0.3889,  0.3657,  0.4053,
#           0.3779,  2.8964, -0.0253,  0.3822,  0.3715, -0.0298, -0.0320,  0.0349,
#           0.5290,  0.2986,  0.4012, -0.0245,  0.0895,  0.0144,  0.3996,  0.3504,
#           0.3726,  0.5133,  0.4044, -0.0274, -0.0233, -0.0307,  0.0249,  0.4702]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0045], device='cuda:0', requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): Sigmoid()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=600, bias=True)
#     (1): Linear(in_features=600, out_features=200, bias=True)
#     (2): Linear(in_features=200, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[10.1588,  9.8831, 14.4961],
#         [11.5457, 15.7093, 10.8330],
#         [ 7.0412,  3.4319,  3.3166],
#         [ 7.3073,  1.0524,  3.4916],
#         [ 7.3664,  6.4149,  3.4382],
#         [ 5.8061,  1.8218,  2.9277],
#         [ 1.8201,  1.0985,  1.8799],
#         [ 8.8289,  1.5228,  2.4887],
#         [ 4.1171,  6.2922,  4.7041],
#         [10.0273,  5.6213, 18.5256],
#         [ 1.5369,  0.8019,  0.6702],
#         [ 0.7968,  0.4608,  0.3384],
#         [ 8.0472, 15.8943, 12.1140],
#         [ 8.3138,  1.1167,  1.3626],
#         [12.4783, 34.9983, 34.1324],
#         [ 2.9598,  1.0919,  0.4657],
#         [10.5434,  9.5605,  5.4033],
#         [ 1.7182,  1.1161,  1.5269],
#         [ 1.2905,  2.7248,  2.5802],
#         [ 3.3545,  4.1875,  5.7451]], device='cuda:0')

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([15.3914], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([13.7305], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.0843], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([14.4821], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([12.0959], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([13.6399], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.6405], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.3516], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.6126], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([4.5232], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([9.8950], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.1153], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8983], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([9.8467], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.2427], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.2972], device='cuda:0', grad_fn=<ReluBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([15.3914], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([13.7305], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.0843], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([14.4821], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([12.0959], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([13.6399], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.6405], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.3516], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.6126], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([4.5232], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([9.8950], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.1153], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8983], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([9.8467], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.2427], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([15.2972], device='cuda:0', grad_fn=<ReluBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[15.3508]], device='cuda:0', grad_fn=<ReluBackward0>)
