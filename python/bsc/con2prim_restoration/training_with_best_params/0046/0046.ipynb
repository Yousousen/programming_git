# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# **training with found best parameters:**
# ```
# [I 2023-05-13 09:15:39,563] Trial 13 finished with value: 0.004641101454215823 and parameters: {'n_layers': 3, 'n_units_0': 66, 'n_units_1': 193, 'n_units_2': 248, 'hidden_activation': 'LeakyReLU', 'output_activation': 'ReLU', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 0.0009376919782324494, 'batch_size': 47, 'n_epochs': 65, 'scheduler': 'ExponentialLR'}. Best is trial 13 with value: 0.004641101454215823.
# ```

# %%
# %%script echo skipping
#
# !jupyter nbconvert 0046.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on google colab,

# %%
#%%script echo skipping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (2.6)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.
#
# NOTE: Some subparameters still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 3
N_UNITS_NO_OPT = [66, 193, 248]
HIDDEN_ACTIVATION_NAME_NO_OPT = "LeakyReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 0.0009376919782324494
BATCH_SIZE_NO_OPT = 47
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ExponentialLR"
#Best trial:
#hidden_activation': 'LeakyReLU', 'output_activation': 'ReLU', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 0.0009376919782324494, 'batch_size': 47, 'n_epochs': 65, 'scheduler': 'ExponentialLR'}. Best is trial 13 with value: 0.004641101454215823.


c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)
# Out:
# tensor([1.9220, 2.2925, 1.3112,  ..., 1.3882, 1.4931, 5.2596], device='cuda:0')

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
if ZSCORE_NORMALIZATION:
    # Computing the mean and standard deviation of each input variable from the training set
    D_mean = torch.mean(x_train[:, 0])
    D_std = torch.std(x_train[:, 0])
    Sx_mean = torch.mean(x_train[:, 1])
    Sx_std = torch.std(x_train[:, 1])
    tau_mean = torch.mean(x_train[:, 2])
    tau_std = torch.std(x_train[:, 2])

    # Applying z-score normalization to both train and test sets using the statistics from the training set
    x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
    x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
    x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
    x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
    x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
    x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
print(torch.mean(x_train[:, 0]))
print(torch.std(x_train[:, 0]))
print(torch.mean(x_train[:, 1]))
print(torch.std(x_train[:, 1]))
print(torch.mean(x_train[:, 2]))
print(torch.std(x_train[:, 2]))

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()
# Out:
# tensor(5.6259, device='cuda:0')
# tensor(3.3305, device='cuda:0')
# tensor(6.8267, device='cuda:0')
# tensor(8.0801, device='cuda:0')
# tensor(8.0068, device='cuda:0')
# tensor(7.8406, device='cuda:0')

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            #gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer) #, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        else:
            scheduler = None
#Best trial:
#  Value:  0.00270861783316941
#  Params: 
#    n_layers: 3
#    n_units_0: 555
#    n_units_1: 458
#    n_units_2: 115
#    hidden_activation: ReLU
#    output_activation: ReLU
#    loss: Huber
#    optimizer: RMSprop
#    lr: 0.000122770896701404
#    batch_size: 49
#    n_epochs: 152
#    scheduler: ReduceLROnPlateau
#    factor: 0.18979341786654758
#    patience: 11
#    threshold: 0.0017197466122611932


    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: SmoothL1Loss()
# batch_size: 47
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.ExponentialLR object at 0x7f24cc97de40>
# loss_name: Huber
# optimizer_name: Adam
# scheduler_name: ExponentialLR
# n_units: [66, 193, 248]
# n_layers: 3
# hidden_activation: LeakyReLU(negative_slope=0.01)
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.0217, Test Loss: 0.0110, Train L1 Norm: 0.1233, Test L1 Norm: 0.0887, Train Linf Norm: 3.7990, Test Linf Norm: 1.2133
# Epoch 2: Train Loss: 0.0016, Test Loss: 0.0018, Train L1 Norm: 0.0413, Test L1 Norm: 0.1144, Train Linf Norm: 1.1347, Test Linf Norm: 3.4627
# Epoch 3: Train Loss: 0.0012, Test Loss: 0.0028, Train L1 Norm: 0.0367, Test L1 Norm: 0.0845, Train Linf Norm: 0.9885, Test Linf Norm: 2.1521
# Epoch 4: Train Loss: 0.0010, Test Loss: 0.0001, Train L1 Norm: 0.0478, Test L1 Norm: 0.0304, Train Linf Norm: 1.5013, Test Linf Norm: 0.8893
# Epoch 5: Train Loss: 0.0008, Test Loss: 0.0209, Train L1 Norm: 0.0356, Test L1 Norm: 0.0660, Train Linf Norm: 1.0495, Test Linf Norm: 0.4736
# Epoch 6: Train Loss: 0.0004, Test Loss: 0.0009, Train L1 Norm: 0.0279, Test L1 Norm: 0.0256, Train Linf Norm: 0.8139, Test Linf Norm: 0.5139
# Epoch 7: Train Loss: 0.0006, Test Loss: 0.0006, Train L1 Norm: 0.0307, Test L1 Norm: 0.0299, Train Linf Norm: 0.9441, Test Linf Norm: 0.8271
# Epoch 8: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0242, Test L1 Norm: 0.0368, Train Linf Norm: 0.7217, Test Linf Norm: 1.1892
# Epoch 9: Train Loss: 0.0005, Test Loss: 0.0001, Train L1 Norm: 0.0264, Test L1 Norm: 0.0265, Train Linf Norm: 0.7904, Test Linf Norm: 0.7995
# Epoch 10: Train Loss: 0.0001, Test Loss: 0.0002, Train L1 Norm: 0.0169, Test L1 Norm: 0.0248, Train Linf Norm: 0.4773, Test Linf Norm: 0.7123
# Epoch 11: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0179, Test L1 Norm: 0.0389, Train Linf Norm: 0.4944, Test Linf Norm: 1.3392
# Epoch 12: Train Loss: 0.0001, Test Loss: 0.0002, Train L1 Norm: 0.0182, Test L1 Norm: 0.0291, Train Linf Norm: 0.5447, Test Linf Norm: 0.8418
# Epoch 13: Train Loss: 0.0002, Test Loss: 0.0006, Train L1 Norm: 0.0158, Test L1 Norm: 0.0407, Train Linf Norm: 0.4642, Test Linf Norm: 1.1130
# Epoch 14: Train Loss: 0.0001, Test Loss: 0.0003, Train L1 Norm: 0.0210, Test L1 Norm: 0.0287, Train Linf Norm: 0.7071, Test Linf Norm: 0.8051
# Epoch 15: Train Loss: 0.0001, Test Loss: 0.0002, Train L1 Norm: 0.0125, Test L1 Norm: 0.0125, Train Linf Norm: 0.3630, Test Linf Norm: 0.3165
# Epoch 16: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0150, Test L1 Norm: 0.0218, Train Linf Norm: 0.4723, Test Linf Norm: 0.6782
# Epoch 17: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0119, Test L1 Norm: 0.0128, Train Linf Norm: 0.3655, Test Linf Norm: 0.3902
# Epoch 18: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0133, Test L1 Norm: 0.0096, Train Linf Norm: 0.4268, Test Linf Norm: 0.2799
# Epoch 19: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0096, Test L1 Norm: 0.0079, Train Linf Norm: 0.2724, Test Linf Norm: 0.2119
# Epoch 20: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0101, Test L1 Norm: 0.0106, Train Linf Norm: 0.3014, Test Linf Norm: 0.2354
# Epoch 21: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0103, Test L1 Norm: 0.0149, Train Linf Norm: 0.3191, Test Linf Norm: 0.4410
# Epoch 22: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0095, Test L1 Norm: 0.0074, Train Linf Norm: 0.2971, Test Linf Norm: 0.1963
# Epoch 23: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0090, Test L1 Norm: 0.0099, Train Linf Norm: 0.2872, Test Linf Norm: 0.2918
# Epoch 24: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0086, Test L1 Norm: 0.0092, Train Linf Norm: 0.2683, Test Linf Norm: 0.2810
# Epoch 25: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0080, Train Linf Norm: 0.2480, Test Linf Norm: 0.2321
# Epoch 26: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0082, Test L1 Norm: 0.0084, Train Linf Norm: 0.2553, Test Linf Norm: 0.2178
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0109, Train Linf Norm: 0.2273, Test Linf Norm: 0.3253
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0062, Test L1 Norm: 0.0050, Train Linf Norm: 0.1788, Test Linf Norm: 0.1335
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0079, Train Linf Norm: 0.2024, Test Linf Norm: 0.2354
# Epoch 30: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0059, Train Linf Norm: 0.1897, Test Linf Norm: 0.1692
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0056, Train Linf Norm: 0.1896, Test Linf Norm: 0.1329
# Epoch 32: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0070, Train Linf Norm: 0.1971, Test Linf Norm: 0.2039
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0055, Train Linf Norm: 0.1727, Test Linf Norm: 0.1542
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0057, Train Linf Norm: 0.1744, Test Linf Norm: 0.1559
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0081, Train Linf Norm: 0.1641, Test Linf Norm: 0.2170
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0044, Train Linf Norm: 0.1748, Test Linf Norm: 0.1166
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0043, Train Linf Norm: 0.1824, Test Linf Norm: 0.1191
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0051, Train Linf Norm: 0.1621, Test Linf Norm: 0.1447
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0042, Train Linf Norm: 0.1551, Test Linf Norm: 0.1121
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0043, Train Linf Norm: 0.1599, Test Linf Norm: 0.1173
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0044, Train Linf Norm: 0.1428, Test Linf Norm: 0.1235
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0041, Train Linf Norm: 0.1632, Test Linf Norm: 0.1108
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0039, Train Linf Norm: 0.1618, Test Linf Norm: 0.1041
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0049, Train Linf Norm: 0.1515, Test Linf Norm: 0.1408
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0045, Train Linf Norm: 0.1437, Test Linf Norm: 0.1235
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0048, Train Linf Norm: 0.1586, Test Linf Norm: 0.1369
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0043, Train Linf Norm: 0.1525, Test Linf Norm: 0.1107
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0040, Train Linf Norm: 0.1498, Test Linf Norm: 0.1027
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0040, Train Linf Norm: 0.1542, Test Linf Norm: 0.1100
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0042, Train Linf Norm: 0.1498, Test Linf Norm: 0.1166
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0041, Train Linf Norm: 0.1487, Test Linf Norm: 0.1133
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0038, Train Linf Norm: 0.1555, Test Linf Norm: 0.1041
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0041, Train Linf Norm: 0.1435, Test Linf Norm: 0.1141
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0040, Train Linf Norm: 0.1495, Test Linf Norm: 0.1096
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0038, Train Linf Norm: 0.1529, Test Linf Norm: 0.1041
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0038, Train Linf Norm: 0.1487, Test Linf Norm: 0.1031
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0040, Train Linf Norm: 0.1450, Test Linf Norm: 0.1122
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0040, Train Linf Norm: 0.1444, Test Linf Norm: 0.1090
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0041, Train Linf Norm: 0.1448, Test Linf Norm: 0.1123
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0038, Train Linf Norm: 0.1469, Test Linf Norm: 0.1036
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0040, Train Linf Norm: 0.1486, Test Linf Norm: 0.1103
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1478, Test Linf Norm: 0.1070
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0040, Train Linf Norm: 0.1472, Test Linf Norm: 0.1114
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0038, Train Linf Norm: 0.1468, Test Linf Norm: 0.1058
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1396, Test Linf Norm: 0.1073
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0038, Train Linf Norm: 0.1449, Test Linf Norm: 0.1052
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1453, Test Linf Norm: 0.1092
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0040, Train Linf Norm: 0.1461, Test Linf Norm: 0.1121
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1077
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0040, Train Linf Norm: 0.1446, Test Linf Norm: 0.1105
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0038, Train Linf Norm: 0.1437, Test Linf Norm: 0.1061
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1092
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1083
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1420, Test Linf Norm: 0.1095
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1084
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0040, Train Linf Norm: 0.1444, Test Linf Norm: 0.1101
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1070
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1469, Test Linf Norm: 0.1082
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1454, Test Linf Norm: 0.1085
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1081
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1089
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1457, Test Linf Norm: 0.1096
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1088
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1093
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1087
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1077
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1451, Test Linf Norm: 0.1086
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1093
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1078
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1079
# Epoch 91: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 92: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1082
# Epoch 93: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1084
# Epoch 94: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1086
# Epoch 95: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 96: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1086
# Epoch 97: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1455, Test Linf Norm: 0.1084
# Epoch 98: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 99: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1086
# Epoch 100: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1451, Test Linf Norm: 0.1084
# Epoch 101: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1423, Test Linf Norm: 0.1086
# Epoch 102: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 103: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 104: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1412, Test Linf Norm: 0.1086
# Epoch 105: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1417, Test Linf Norm: 0.1084
# Epoch 106: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 107: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 108: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 109: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1453, Test Linf Norm: 0.1085
# Epoch 110: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 111: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 112: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 113: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 114: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 115: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 116: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 117: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 118: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 119: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 120: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 121: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 122: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1453, Test Linf Norm: 0.1085
# Epoch 123: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 124: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 125: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 126: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 127: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1419, Test Linf Norm: 0.1085
# Epoch 128: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 129: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 130: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 131: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 132: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 133: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 134: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 135: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1451, Test Linf Norm: 0.1085
# Epoch 136: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 137: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 138: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 139: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 140: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 141: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 142: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 143: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1423, Test Linf Norm: 0.1085
# Epoch 144: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1455, Test Linf Norm: 0.1085
# Epoch 145: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 146: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 147: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 148: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 149: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 150: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 151: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 152: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1421, Test Linf Norm: 0.1085
# Epoch 153: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1455, Test Linf Norm: 0.1085
# Epoch 154: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1423, Test Linf Norm: 0.1085
# Epoch 155: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 156: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1455, Test Linf Norm: 0.1085
# Epoch 157: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 158: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 159: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 160: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 161: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 162: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 163: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1085
# Epoch 164: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 165: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 166: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 167: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 168: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 169: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 170: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 171: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 172: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 173: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 174: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1455, Test Linf Norm: 0.1085
# Epoch 175: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 176: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 177: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 178: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 179: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 180: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1452, Test Linf Norm: 0.1085
# Epoch 181: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 182: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 183: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 184: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 185: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1415, Test Linf Norm: 0.1085
# Epoch 186: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 187: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 188: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 189: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 190: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 191: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1454, Test Linf Norm: 0.1085
# Epoch 192: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 193: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 194: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 195: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 196: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1457, Test Linf Norm: 0.1085
# Epoch 197: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 198: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 199: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1427, Test Linf Norm: 0.1085
# Epoch 200: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 201: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 202: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 203: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 204: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 205: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 206: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1433, Test Linf Norm: 0.1085
# Epoch 207: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 208: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 209: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 210: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1425, Test Linf Norm: 0.1085
# Epoch 211: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 212: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 213: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1423, Test Linf Norm: 0.1085
# Epoch 214: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1425, Test Linf Norm: 0.1085
# Epoch 215: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 216: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 217: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 218: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 219: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 220: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 221: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 222: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 223: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1085
# Epoch 224: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 225: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1433, Test Linf Norm: 0.1085
# Epoch 226: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 227: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 228: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 229: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 230: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1457, Test Linf Norm: 0.1085
# Epoch 231: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1453, Test Linf Norm: 0.1085
# Epoch 232: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 233: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 234: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 235: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 236: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1085
# Epoch 237: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 238: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 239: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 240: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 241: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 242: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 243: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 244: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 245: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1458, Test Linf Norm: 0.1085
# Epoch 246: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 247: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 248: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1457, Test Linf Norm: 0.1085
# Epoch 249: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1420, Test Linf Norm: 0.1085
# Epoch 250: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1450, Test Linf Norm: 0.1085
# Epoch 251: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 252: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 253: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 254: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1458, Test Linf Norm: 0.1085
# Epoch 255: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 256: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 257: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 258: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 259: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 260: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 261: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 262: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 263: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 264: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 265: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 266: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 267: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 268: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 269: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1085
# Epoch 270: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 271: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1451, Test Linf Norm: 0.1085
# Epoch 272: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 273: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 274: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 275: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 276: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 277: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1420, Test Linf Norm: 0.1085
# Epoch 278: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 279: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1452, Test Linf Norm: 0.1085
# Epoch 280: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 281: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1429, Test Linf Norm: 0.1085
# Epoch 282: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1425, Test Linf Norm: 0.1085
# Epoch 283: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 284: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 285: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 286: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 287: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 288: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 289: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 290: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1452, Test Linf Norm: 0.1085
# Epoch 291: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 292: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 293: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 294: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 295: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 296: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1428, Test Linf Norm: 0.1085
# Epoch 297: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 298: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 299: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 300: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1415, Test Linf Norm: 0.1085
# Epoch 301: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 302: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 303: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 304: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 305: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 306: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 307: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1427, Test Linf Norm: 0.1085
# Epoch 308: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 309: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1433, Test Linf Norm: 0.1085
# Epoch 310: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 311: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1454, Test Linf Norm: 0.1085
# Epoch 312: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 313: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 314: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 315: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 316: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 317: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 318: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 319: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 320: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 321: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 322: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 323: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1417, Test Linf Norm: 0.1085
# Epoch 324: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 325: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1453, Test Linf Norm: 0.1085
# Epoch 326: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 327: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1425, Test Linf Norm: 0.1085
# Epoch 328: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 329: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 330: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 331: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1418, Test Linf Norm: 0.1085
# Epoch 332: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 333: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 334: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 335: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 336: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1441, Test Linf Norm: 0.1085
# Epoch 337: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 338: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 339: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 340: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 341: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 342: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 343: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 344: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 345: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1430, Test Linf Norm: 0.1085
# Epoch 346: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 347: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 348: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1444, Test Linf Norm: 0.1085
# Epoch 349: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 350: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 351: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 352: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1452, Test Linf Norm: 0.1085
# Epoch 353: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 354: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 355: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1446, Test Linf Norm: 0.1085
# Epoch 356: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 357: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 358: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 359: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1445, Test Linf Norm: 0.1085
# Epoch 360: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1447, Test Linf Norm: 0.1085
# Epoch 361: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 362: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1437, Test Linf Norm: 0.1085
# Epoch 363: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 364: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 365: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1426, Test Linf Norm: 0.1085
# Epoch 366: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1381, Test Linf Norm: 0.1085
# Epoch 367: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1432, Test Linf Norm: 0.1085
# Epoch 368: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 369: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1431, Test Linf Norm: 0.1085
# Epoch 370: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1454, Test Linf Norm: 0.1085
# Epoch 371: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 372: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 373: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 374: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1424, Test Linf Norm: 0.1085
# Epoch 375: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 376: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1438, Test Linf Norm: 0.1085
# Epoch 377: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 378: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1435, Test Linf Norm: 0.1085
# Epoch 379: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 380: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 381: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 382: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1434, Test Linf Norm: 0.1085
# Epoch 383: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1436, Test Linf Norm: 0.1085
# Epoch 384: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 385: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 386: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1424, Test Linf Norm: 0.1085
# Epoch 387: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1439, Test Linf Norm: 0.1085
# Epoch 388: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 389: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1433, Test Linf Norm: 0.1085
# Epoch 390: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 391: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1452, Test Linf Norm: 0.1085
# Epoch 392: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 393: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1451, Test Linf Norm: 0.1085
# Epoch 394: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1433, Test Linf Norm: 0.1085
# Epoch 395: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1448, Test Linf Norm: 0.1085
# Epoch 396: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1442, Test Linf Norm: 0.1085
# Epoch 397: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1449, Test Linf Norm: 0.1085
# Epoch 398: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085
# Epoch 399: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1443, Test Linf Norm: 0.1085
# Epoch 400: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0039, Train Linf Norm: 0.1440, Test Linf Norm: 0.1085

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration/0046" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
optimizer_loaded_state_dict = torch.load("optimizer.pth")
if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
scheduler_loaded_state_dict = torch.load("scheduler.pth")
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded
# Out:
# 47
# 400
# 'Huber'
# 'Adam'
# 'ExponentialLR'
# [66, 193, 248]
# 3
# 'LeakyReLU'
# 'ReLU'
# 0.0009376919782324494
# LeakyReLU(negative_slope=0.01)
# ReLU()
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=66, bias=True)
#     (1): Linear(in_features=66, out_features=193, bias=True)
#     (2): Linear(in_features=193, out_features=248, bias=True)
#     (3): Linear(in_features=248, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation',
#                LeakyReLU(negative_slope=0.01)),
#               ('output_activation', ReLU()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=3, out_features=66, bias=True)
#                  (1): Linear(in_features=66, out_features=193, bias=True)
#                  (2): Linear(in_features=193, out_features=248, bias=True)
#                  (3): Linear(in_features=248, out_features=1, bias=True)
#                ))]),
#  'n_layers': 3,
#  'n_units': [66, 193, 248]}
# SmoothL1Loss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.0009376919782324494
#     lr: 4.667281295420373e-22
#     maximize: False
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.0009376919782324494,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0,
#   'amsgrad': False,
#   'maximize': False,
#   'foreach': None,
#   'capturable': False,
#   'differentiable': False,
#   'fused': None},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#Adam.zero_grad',
#  'state': defaultdict(dict,
#              {Parameter containing:
#               tensor([[ 4.0703e-01, -3.3209e-01,  2.4541e-01],
#                       [ 3.9574e-01,  4.4300e-01, -4.7536e-01],
#                       [ 5.3288e-01,  3.8867e-01, -4.8479e-01],
#                       [ 8.6288e-02,  2.2755e-01, -5.6166e-01],
#                       [ 4.5703e-01,  4.7261e-01,  3.9110e-01],
#                       [-1.0874e-01,  4.3502e-01, -2.9330e-01],
#                       [-4.7408e-01,  2.2947e-01, -1.5686e-01],
#                       [ 3.7815e-01, -3.5651e-01, -4.3197e-01],
#                       [-1.8735e-02, -3.5852e-01, -4.3461e-01],
#                       [ 1.5751e-02,  1.7131e-01,  3.0135e-02],
#                       [-5.5786e-01, -1.5186e-01, -5.5708e-02],
#                       [-3.2261e-01, -1.0598e-01,  7.4610e-02],
#                       [-3.3268e-01,  1.2492e-01,  3.4374e-02],
#                       [ 4.7166e-01,  1.1620e-01, -1.9587e-01],
#                       [-3.8253e-01,  2.6799e-01,  3.7434e-01],
#                       [-2.7552e-01, -2.0934e-01,  3.6939e-04],
#                       [ 2.5972e-01, -5.0087e-01, -1.0369e-01],
#                       [-3.9376e-01,  5.0110e-01,  9.8127e-02],
#                       [ 1.8719e-01, -8.1313e-02, -2.8015e-01],
#                       [-1.1466e-01, -4.5091e-01, -3.6362e-01],
#                       [-3.8132e-01,  8.7239e-02,  8.6272e-02],
#                       [-4.3027e-01,  1.3524e-02,  2.1827e-01],
#                       [-2.0852e-01,  1.6656e-01,  3.2412e-01],
#                       [ 3.8629e-01,  3.0472e-01,  4.1659e-01],
#                       [ 2.0792e-01,  9.1386e-02, -5.2300e-01],
#                       [-3.8574e-01,  3.0005e-01,  2.2964e-01],
#                       [ 3.2233e-01,  3.9980e-01, -4.8669e-01],
#                       [-8.3361e-02, -1.8442e-02,  3.5311e-02],
#                       [-3.4851e-01,  3.7308e-01, -1.7108e-01],
#                       [-9.7168e-02, -3.8977e-01,  9.4209e-02],
#                       [ 1.7467e-01, -1.8738e-01,  1.4916e-01],
#                       [-3.3370e-01,  1.6417e-01,  1.6782e-02],
#                       [-2.3076e-02, -5.5705e-01,  1.9449e-01],
#                       [-5.4737e-01, -5.6938e-02,  4.8260e-01],
#                       [-2.0278e-01,  4.4483e-01, -6.6182e-02],
#                       [ 4.3948e-01,  1.9841e-01,  3.4938e-01],
#                       [ 4.5413e-01, -1.9597e-01,  5.7271e-01],
#                       [ 4.6930e-01,  2.7708e-01, -2.8002e-01],
#                       [-5.2297e-01,  2.1001e-01,  1.3550e-01],
#                       [ 2.1478e-01,  4.9793e-01,  1.3830e-01],
#                       [ 5.0789e-02,  4.9282e-01, -4.8851e-01],
#                       [-7.8824e-02,  3.9813e-01,  4.9718e-01],
#                       [ 4.3622e-01,  3.6230e-01,  1.8949e-01],
#                       [-8.5955e-02, -9.7836e-02,  2.5725e-01],
#                       [-2.6691e-01,  4.0066e-01,  2.3975e-01],
#                       [-3.2434e-01, -3.2835e-02,  2.6271e-02],
#                       [ 4.4681e-01, -3.8512e-01, -4.4964e-01],
#                       [-4.9077e-01, -1.7938e-01,  4.1816e-01],
#                       [ 1.4816e-01, -2.7735e-01, -4.1722e-01],
#                       [ 1.0778e-01,  2.9132e-01,  3.3804e-01],
#                       [-3.7778e-01, -4.6641e-01,  5.6872e-01],
#                       [-4.0338e-01,  3.4110e-01, -2.4774e-02],
#                       [ 1.1895e-01,  2.7858e-01, -4.0135e-02],
#                       [ 3.4615e-01,  3.3874e-02, -1.3440e-01],
#                       [ 2.7207e-01,  1.1176e-01, -1.5754e-01],
#                       [-1.0054e-01, -4.0024e-01,  1.3083e-01],
#                       [ 4.7844e-01, -5.0384e-01,  2.1797e-01],
#                       [-3.0219e-01,  8.3160e-02,  1.1197e-01],
#                       [ 4.7103e-01,  4.6320e-01, -1.0860e-01],
#                       [ 3.9115e-01, -5.6066e-01, -5.4771e-01],
#                       [-4.0218e-01,  2.4949e-01, -9.9419e-02],
#                       [ 5.5686e-01, -4.1523e-01, -2.1529e-01],
#                       [-8.5780e-02, -3.6724e-01, -4.6862e-01],
#                       [ 8.6542e-02, -4.3628e-02, -3.7930e-01],
#                       [-3.5181e-02,  4.1098e-01, -1.5650e-01],
#                       [-2.8010e-01, -1.2258e-01, -2.9233e-01]], device='cuda:0',
#                      requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([[ 1.8406e-04,  1.3317e-04,  1.6730e-04],
#                        [-4.3821e-05, -2.0462e-05, -6.9223e-06],
#                        [-7.3376e-05, -5.5878e-05, -6.8426e-05],
#                        [ 3.0322e-05,  1.0274e-05,  4.2825e-06],
#                        [ 1.1268e-04,  8.2979e-05,  1.0759e-04],
#                        [-5.0283e-05, -2.2140e-05,  9.9862e-06],
#                        [-8.2683e-07, -4.5757e-07, -6.4589e-07],
#                        [ 1.0610e-05,  1.5474e-06, -4.8431e-08],
#                        [-9.6651e-08, -7.8793e-09, -5.7039e-08],
#                        [ 5.9072e-06, -1.1878e-06,  7.7562e-07],
#                        [-2.1279e-07, -3.1224e-07, -3.3108e-07],
#                        [-2.5459e-07, -2.4350e-07, -2.4627e-07],
#                        [ 1.1474e-05,  1.6810e-05,  2.5289e-05],
#                        [-1.1518e-06,  1.3894e-05,  8.1434e-06],
#                        [ 3.4523e-05,  2.0395e-05,  1.9558e-05],
#                        [ 1.7148e-07,  3.6045e-08,  3.7780e-08],
#                        [ 2.2398e-06,  1.0389e-06, -1.1416e-06],
#                        [-5.3824e-05, -3.0452e-05, -3.1171e-05],
#                        [ 1.5820e-05,  4.9479e-06,  2.6394e-06],
#                        [ 3.9284e-09, -4.0060e-08, -4.1951e-08],
#                        [ 5.1946e-06,  1.4017e-05,  1.3934e-05],
#                        [-6.0766e-06, -1.8462e-05, -1.7519e-05],
#                        [ 2.0906e-05,  5.0167e-06,  1.7172e-05],
#                        [ 8.3799e-05,  5.7186e-05,  7.7323e-05],
#                        [ 1.1311e-05,  2.5425e-06,  1.4807e-06],
#                        [ 3.9443e-06, -6.6630e-06,  1.0664e-06],
#                        [-1.5491e-04, -1.5872e-04, -1.3614e-04],
#                        [ 2.3956e-05,  2.5789e-05,  4.3399e-05],
#                        [ 2.5813e-05,  2.6223e-05,  3.5611e-05],
#                        [ 2.9503e-08, -7.1322e-08,  3.6014e-08],
#                        [ 1.3661e-04,  1.0240e-04,  1.2428e-04],
#                        [ 7.7626e-06,  8.1041e-06,  2.0622e-05],
#                        [ 3.1022e-07,  6.4670e-07,  3.2909e-06],
#                        [ 1.2511e-05, -6.6662e-06,  1.0626e-05],
#                        [-9.0125e-05, -6.6215e-05, -5.9863e-05],
#                        [ 4.8368e-05,  2.8351e-05,  4.1939e-05],
#                        [ 1.5113e-04,  9.0806e-05,  1.2970e-04],
#                        [-7.3906e-05, -4.7248e-05, -6.5796e-05],
#                        [ 1.0500e-05,  6.9992e-06,  1.6298e-05],
#                        [ 3.1122e-05,  8.5169e-06,  2.1281e-05],
#                        [-9.3726e-05, -9.8707e-05, -7.2897e-05],
#                        [ 8.8028e-05,  4.4972e-05,  7.0799e-05],
#                        [ 1.0521e-05,  1.3276e-05,  1.3445e-05],
#                        [ 6.6328e-05,  3.2522e-05,  3.9454e-05],
#                        [-1.5996e-05, -1.7402e-05, -1.7630e-05],
#                        [-4.1473e-08, -9.9056e-08, -1.2824e-07],
#                        [ 1.0590e-05,  3.2455e-06,  1.3638e-06],
#                        [ 5.4861e-06, -3.4735e-07,  5.0781e-06],
#                        [ 1.6653e-05,  2.8171e-06,  1.2332e-06],
#                        [ 3.1119e-05,  3.3264e-05,  3.1674e-05],
#                        [ 6.6729e-05,  1.0502e-05,  7.1581e-05],
#                        [ 1.9303e-05,  3.1383e-05,  5.0457e-05],
#                        [-3.9380e-06,  4.8539e-06,  1.6719e-06],
#                        [-4.6939e-05, -2.9754e-06, -1.5705e-05],
#                        [-3.6780e-05, -2.4263e-05, -2.7684e-05],
#                        [-4.6873e-07,  4.6988e-07,  7.7533e-07],
#                        [ 7.0119e-05,  6.9574e-05,  7.4961e-05],
#                        [-2.3935e-07, -1.0287e-06, -3.3485e-07],
#                        [-4.7011e-05, -2.7995e-05, -4.0117e-05],
#                        [ 1.2960e-05,  2.4658e-06, -2.4702e-07],
#                        [-3.4740e-05, -1.0022e-04, -9.1338e-05],
#                        [-4.5889e-05, -3.6627e-05, -3.9894e-05],
#                        [-3.6404e-07, -1.7422e-07, -2.0175e-07],
#                        [ 8.3082e-06,  1.3364e-06,  4.3534e-07],
#                        [-1.9014e-05, -9.1931e-07, -1.0350e-05],
#                        [-3.8279e-07, -1.8470e-07, -2.9859e-07]], device='cuda:0'),
#                'exp_avg_sq': tensor([[4.5566e-07, 1.9889e-06, 1.9846e-06],
#                        [9.9131e-08, 4.9896e-07, 4.7937e-07],
#                        [7.6077e-08, 3.5204e-07, 3.4620e-07],
#                        [3.8082e-09, 1.8411e-09, 4.7812e-10],
#                        [1.0084e-07, 3.7981e-07, 3.8978e-07],
#                        [1.9318e-07, 1.0724e-06, 1.0014e-06],
#                        [1.0178e-11, 4.3167e-11, 4.5216e-11],
#                        [5.6343e-10, 9.3816e-11, 6.3187e-11],
#                        [7.1422e-13, 3.0619e-12, 3.1454e-12],
#                        [1.6397e-09, 5.3982e-09, 7.1021e-09],
#                        [8.5923e-13, 3.5260e-12, 3.5206e-12],
#                        [1.4005e-13, 2.9331e-13, 2.9813e-13],
#                        [4.0367e-08, 3.2507e-07, 3.0844e-07],
#                        [1.5678e-09, 4.0163e-09, 4.2770e-09],
#                        [3.8876e-09, 9.4587e-09, 1.2144e-08],
#                        [5.0407e-13, 7.7282e-13, 8.5323e-13],
#                        [1.8326e-09, 5.9740e-11, 2.1859e-09],
#                        [4.7709e-08, 2.2172e-07, 2.2113e-07],
#                        [8.4816e-10, 3.3860e-10, 8.9919e-11],
#                        [1.1749e-13, 7.0213e-13, 6.5307e-13],
#                        [1.0828e-10, 9.1918e-10, 8.9960e-10],
#                        [2.0650e-09, 7.2033e-09, 1.0581e-08],
#                        [6.3782e-09, 2.1947e-08, 2.8277e-08],
#                        [7.0751e-08, 2.7166e-07, 2.8808e-07],
#                        [1.8434e-09, 8.6793e-10, 3.4279e-10],
#                        [1.4963e-09, 5.9157e-09, 6.7114e-09],
#                        [3.8868e-07, 1.8294e-06, 1.6819e-06],
#                        [1.1656e-09, 2.2503e-09, 4.8308e-09],
#                        [1.6289e-07, 1.0294e-06, 9.3686e-07],
#                        [5.3282e-12, 1.0256e-12, 2.0022e-11],
#                        [2.9829e-07, 1.3446e-06, 1.3289e-06],
#                        [3.0761e-08, 2.1614e-07, 2.0068e-07],
#                        [6.1076e-10, 4.4069e-11, 1.3998e-09],
#                        [2.4506e-08, 1.0965e-07, 1.2788e-07],
#                        [1.6223e-07, 8.4156e-07, 8.0285e-07],
#                        [4.4012e-08, 1.9681e-07, 2.0100e-07],
#                        [2.8484e-07, 1.1754e-06, 1.2197e-06],
#                        [5.1795e-08, 1.8771e-07, 2.0799e-07],
#                        [2.3156e-08, 1.5862e-07, 1.4665e-07],
#                        [1.0657e-08, 2.6033e-08, 3.3676e-08],
#                        [2.1937e-07, 1.2252e-06, 1.0632e-06],
#                        [7.2569e-08, 2.7544e-07, 2.9818e-07],
#                        [6.0677e-09, 2.7395e-08, 2.5706e-08],
#                        [4.6107e-08, 2.0307e-07, 2.0820e-07],
#                        [1.1111e-09, 4.6161e-09, 3.8961e-09],
#                        [1.5698e-13, 6.8573e-13, 6.0474e-13],
#                        [6.9915e-10, 8.0138e-11, 1.5876e-10],
#                        [6.8438e-09, 3.3897e-08, 4.2547e-08],
#                        [3.7304e-10, 1.6801e-11, 1.0973e-11],
#                        [6.9876e-09, 2.3609e-08, 2.0749e-08],
#                        [7.1516e-08, 1.0823e-07, 2.6072e-07],
#                        [9.7121e-08, 5.9753e-07, 5.6503e-07],
#                        [2.8427e-09, 1.2057e-08, 1.2598e-08],
#                        [2.4270e-08, 7.7463e-08, 8.8808e-08],
#                        [1.6426e-08, 7.9125e-08, 7.9770e-08],
#                        [5.1315e-10, 2.1860e-11, 1.1256e-09],
#                        [1.6672e-08, 2.2558e-08, 2.5348e-08],
#                        [5.4340e-10, 3.1298e-09, 3.1726e-09],
#                        [2.6787e-08, 1.0773e-07, 1.1821e-07],
#                        [5.5074e-10, 3.6797e-11, 3.5880e-11],
#                        [3.0586e-08, 2.9392e-07, 2.7641e-07],
#                        [3.2130e-09, 8.6417e-10, 3.8485e-09],
#                        [3.1442e-12, 7.5637e-12, 7.7357e-12],
#                        [1.3497e-10, 1.3953e-11, 8.7164e-12],
#                        [8.7687e-09, 3.2718e-08, 3.7892e-08],
#                        [4.7699e-13, 5.4072e-13, 8.7712e-13]], device='cuda:0')},
#               Parameter containing:
#               tensor([ 0.3392, -0.0676,  0.3211, -0.1155, -0.1619,  0.5251, -0.1288,  0.2064,
#                        0.0868, -0.6112, -0.3304, -0.0647, -0.1194,  0.1181,  0.2438,  0.3304,
#                        0.2704,  0.2447,  0.0634, -0.3550, -0.4921,  0.3307,  0.2780, -0.5304,
#                        0.3452, -0.5146,  0.1472,  0.2347,  0.0982, -0.5379,  0.3258, -0.0582,
#                       -0.2312, -0.0098, -0.1853,  0.1103, -0.5430,  0.2692, -0.1088,  0.3683,
#                       -0.1022, -0.1591, -0.4521,  0.4869, -0.3064,  0.0855,  0.4093, -0.3121,
#                        0.1299,  0.4032, -0.1672, -0.1366, -0.5081, -0.2706, -0.4001,  0.4441,
#                       -0.0102,  0.1336, -0.0675,  0.2166, -0.0840,  0.4400,  0.5121,  0.0026,
#                        0.4079, -0.2059], device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([ 2.0261e-05, -2.8553e-06, -8.2621e-06,  3.7254e-06,  1.3154e-05,
#                        -1.7799e-06, -9.5775e-08,  1.3943e-06,  4.0814e-08,  7.9177e-07,
#                        -2.5327e-08, -3.2029e-08,  1.3060e-06, -4.7076e-07,  3.4567e-06,
#                         2.8566e-07,  8.0820e-07, -6.9412e-06,  1.7982e-06,  6.6885e-10,
#                         4.3388e-07, -1.3169e-07,  3.1427e-06,  9.5066e-06,  1.5905e-06,
#                         1.0207e-06, -1.3596e-05,  4.4328e-06,  4.7323e-06,  5.5130e-09,
#                         1.4590e-05,  2.1980e-06, -1.1940e-08,  2.6832e-06, -9.7374e-06,
#                         5.4581e-06,  1.8584e-05, -8.8902e-06,  2.0056e-06,  4.1219e-06,
#                        -1.0301e-05,  1.0846e-05,  1.0434e-06,  7.7424e-06, -1.1613e-06,
#                        -5.3965e-08,  1.0242e-06,  1.2158e-06,  2.6048e-06,  3.2989e-06,
#                         1.1496e-05,  2.7947e-06, -1.1660e-06, -6.7832e-06, -4.1564e-06,
#                        -1.7347e-07,  8.4759e-06,  2.1770e-07, -5.4686e-06,  1.5250e-06,
#                        -3.2402e-06, -5.7338e-06,  3.1750e-07,  1.0871e-06, -2.7083e-06,
#                        -5.0040e-08], device='cuda:0'),
#                'exp_avg_sq': tensor([6.8056e-09, 1.3491e-09, 1.1220e-09, 5.1259e-11, 1.5497e-09, 2.5725e-09,
#                        1.5288e-13, 1.3565e-11, 2.2578e-13, 2.5821e-11, 1.2720e-14, 2.2142e-15,
#                        4.5911e-10, 2.6460e-11, 6.0922e-11, 1.9274e-12, 4.2608e-11, 6.5728e-10,
#                        1.7225e-11, 1.5661e-15, 1.1108e-12, 4.6638e-11, 1.1340e-10, 1.0681e-09,
#                        4.3458e-11, 2.3294e-11, 5.3695e-09, 5.6432e-11, 2.0038e-09, 7.0480e-14,
#                        4.3708e-09, 3.6432e-10, 1.1029e-11, 3.9344e-10, 2.1456e-09, 6.8125e-10,
#                        4.2619e-09, 8.3550e-10, 2.7474e-10, 1.8517e-10, 2.5739e-09, 1.1386e-09,
#                        8.1893e-11, 7.0617e-10, 1.4733e-11, 3.7592e-13, 1.7278e-11, 9.9571e-11,
#                        1.5835e-11, 1.0476e-10, 1.3353e-09, 1.2021e-09, 4.7005e-11, 3.6725e-10,
#                        2.1343e-10, 1.5289e-11, 2.8604e-10, 9.1452e-12, 4.5015e-10, 1.6236e-11,
#                        3.2010e-10, 7.3011e-11, 5.8999e-12, 3.3674e-12, 1.4670e-10, 8.8519e-15],
#                       device='cuda:0')},
#               Parameter containing:
#               tensor([[-0.0873, -0.0195, -0.0606,  ..., -0.0262,  0.1149, -0.1003],
#                       [ 0.0947,  0.0575, -0.0667,  ...,  0.0040,  0.0228,  0.0592],
#                       [ 0.1583, -0.0099, -0.0207,  ..., -0.0428, -0.0093,  0.0552],
#                       ...,
#                       [-0.0414,  0.0492,  0.1124,  ..., -0.1509,  0.0773,  0.0805],
#                       [ 0.0674, -0.0686, -0.1204,  ..., -0.0756,  0.0318, -0.0314],
#                       [ 0.0820, -0.0867, -0.0201,  ...,  0.0635,  0.0909,  0.1181]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([[ 9.6619e-07,  9.2615e-07,  1.3062e-06,  ...,  9.0478e-08,
#                          1.6617e-07, -8.5757e-09],
#                        [-5.7375e-08,  9.3598e-07,  1.0637e-06,  ...,  1.3962e-08,
#                          3.5082e-07, -1.2445e-09],
#                        [ 3.0742e-05,  1.8896e-05,  2.7757e-05,  ..., -6.0113e-07,
#                          1.0254e-05, -4.3921e-07],
#                        ...,
#                        [-1.6095e-06, -1.5442e-06, -2.1909e-06,  ...,  1.2961e-08,
#                         -1.3759e-06,  3.2055e-08],
#                        [ 2.1690e-07, -1.1574e-08, -1.6405e-08,  ..., -2.4147e-09,
#                          4.5153e-08, -3.9583e-09],
#                        [ 2.4814e-06,  2.8976e-06,  3.8159e-06,  ..., -1.2479e-08,
#                          1.4821e-06, -3.9538e-08]], device='cuda:0'),
#                'exp_avg_sq': tensor([[1.7779e-12, 1.0521e-12, 2.1707e-12,  ..., 5.3176e-15, 4.8602e-14,
#                         1.4103e-16],
#                        [3.9910e-11, 3.6340e-11, 5.7907e-11,  ..., 7.7291e-15, 2.6927e-11,
#                         1.5786e-14],
#                        [5.3877e-09, 4.2071e-09, 5.8444e-09,  ..., 2.2486e-12, 9.0588e-09,
#                         4.3704e-12],
#                        ...,
#                        [6.9952e-11, 1.3158e-10, 2.0315e-10,  ..., 1.6428e-14, 1.3057e-10,
#                         5.5871e-14],
#                        [4.3620e-13, 9.4264e-15, 1.4049e-14,  ..., 9.5939e-17, 7.7479e-14,
#                         1.7727e-16],
#                        [4.4926e-11, 3.9415e-11, 5.1720e-11,  ..., 3.1315e-14, 1.3072e-10,
#                         5.9823e-14]], device='cuda:0')},
#               Parameter containing:
#               tensor([-6.7190e-02,  5.0857e-02, -6.0886e-02, -6.8841e-02,  5.4440e-02,
#                       -2.7378e-02,  1.9591e-02, -3.9092e-03,  2.7291e-02, -8.2242e-02,
#                       -3.6240e-02,  3.0468e-03, -1.0347e-01, -9.6846e-02, -8.0039e-02,
#                       -5.6724e-02, -5.1376e-02, -1.1534e-01,  1.0357e-02, -1.3662e-01,
#                        1.5152e-01, -5.6677e-02,  2.9142e-02,  2.3898e-02,  9.6004e-02,
#                        9.3752e-02,  1.8263e-04, -3.1107e-02,  3.1472e-02,  1.8765e-02,
#                       -4.7950e-02,  3.1196e-02,  4.3236e-02, -1.1498e-01, -6.2510e-02,
#                       -6.5710e-02,  1.5251e-02, -1.2221e-01, -3.5116e-03, -1.6307e-01,
#                       -5.4335e-02,  1.0923e-01,  8.8543e-02, -4.6167e-05,  9.1507e-02,
#                       -7.2172e-02, -7.4399e-02, -6.0050e-02,  1.1322e-01, -5.9231e-02,
#                       -3.8494e-02,  5.8541e-02,  1.4531e-02, -3.0604e-02,  4.2338e-03,
#                        2.2296e-02, -7.0445e-02, -3.7109e-02, -5.5375e-02, -6.9400e-02,
#                        2.4298e-02,  3.3955e-02, -6.5531e-03, -1.3046e-01, -3.1256e-02,
#                        3.1977e-02, -4.1889e-02, -1.2122e-01,  4.5195e-03, -9.9163e-02,
#                        6.2637e-02, -8.8915e-02,  8.6932e-02, -6.0316e-03, -1.2568e-01,
#                       -1.1934e-02,  5.2724e-02,  7.8431e-02, -1.0713e-01,  1.6137e-02,
#                       -1.1494e-01,  1.0203e-01, -3.3963e-03, -3.9456e-02, -1.1026e-01,
#                        9.8439e-02,  6.2919e-02, -7.1842e-02,  5.5712e-02, -1.1066e-01,
#                       -1.1016e-01,  5.0132e-02, -6.3693e-02,  1.2336e-01,  3.9105e-02,
#                       -9.8456e-03, -1.7194e-03,  7.5350e-02, -1.0851e-01,  4.4660e-02,
#                       -9.7707e-02,  8.1962e-02, -4.4100e-02, -7.5631e-02,  3.8937e-03,
#                       -7.8049e-02,  1.3895e-01,  6.7897e-03, -9.0964e-02, -6.0723e-02,
#                       -3.8648e-02, -7.8081e-02,  1.0854e-01, -4.2285e-02, -7.0650e-02,
#                        7.3057e-02,  1.4174e-02,  1.3661e-02,  3.3792e-02, -2.7828e-02,
#                       -5.6915e-02, -9.1549e-02,  1.0506e-02, -4.6265e-02, -3.0409e-02,
#                       -1.0162e-01,  1.2938e-02,  4.7439e-02, -7.5812e-03,  2.2817e-02,
#                        1.1625e-01, -1.4128e-01,  1.0284e-01,  6.3534e-03,  1.0080e-01,
#                        1.3292e-02, -8.3533e-02, -3.2160e-02,  7.3365e-02, -1.5122e-01,
#                        1.5269e-01, -2.3433e-02, -1.1118e-02, -1.2607e-01,  9.1366e-02,
#                       -9.6396e-02,  1.0193e-01,  2.1217e-02,  5.3439e-03, -5.5557e-02,
#                        7.4500e-03, -8.2530e-03,  5.8513e-02, -1.2266e-01,  5.8895e-02,
#                       -8.0074e-03,  5.1904e-02,  1.3722e-01,  3.6998e-03,  5.1571e-03,
#                        1.4235e-02,  1.2329e-01,  1.2539e-02,  8.4832e-03, -2.3336e-02,
#                       -8.3123e-02, -4.2803e-02, -6.8731e-02, -1.3958e-03,  1.4646e-02,
#                       -7.7777e-02, -1.3160e-01,  8.2007e-02, -8.2963e-02,  2.8125e-03,
#                        5.3237e-02, -1.3795e-01,  7.3768e-02,  6.1554e-02,  1.0941e-01,
#                       -2.5339e-02,  7.4934e-02, -2.3276e-02, -7.0945e-02,  1.5682e-02,
#                       -1.7887e-01, -1.1670e-01, -1.4050e-02,  1.3051e-01, -9.0232e-02,
#                        6.7767e-02, -1.6114e-01,  7.2662e-02], device='cuda:0',
#                      requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([ 2.6336e-07, -1.3683e-07,  8.3093e-06,  2.0259e-06, -1.3334e-07,
#                         2.4411e-08, -4.5276e-08, -1.7393e-07,  1.2686e-07,  3.0015e-08,
#                        -1.9903e-08,  5.2073e-06,  3.6074e-07,  5.6044e-07,  1.1731e-05,
#                        -1.2824e-07,  8.4487e-09, -2.5974e-06,  5.5376e-08,  4.4098e-06,
#                        -5.8490e-07,  5.1098e-06,  1.5045e-07,  2.1370e-07, -1.4774e-07,
#                         1.2567e-08,  7.2784e-07,  2.6150e-09, -6.1321e-09, -1.4437e-08,
#                        -1.6465e-07,  1.6107e-09, -3.5724e-07,  1.7929e-07,  5.6335e-06,
#                        -6.1887e-08,  5.4130e-06,  9.8536e-06, -1.8839e-06, -2.4639e-07,
#                         2.0359e-07,  1.5580e-05, -2.0088e-07,  2.1064e-06,  7.5498e-07,
#                         5.6663e-06, -2.6734e-08, -8.8924e-07,  8.7008e-06, -2.6771e-08,
#                        -7.7486e-07, -5.2407e-09,  5.7938e-07, -3.8340e-07, -8.1244e-08,
#                        -5.5176e-09,  4.4843e-08, -9.8648e-09, -2.2285e-08,  1.0949e-07,
#                         8.2140e-07,  7.4935e-06,  3.5055e-07, -2.8846e-08,  1.9189e-07,
#                         4.9158e-09,  4.8286e-06, -2.0204e-06,  6.0233e-08,  6.1875e-06,
#                         3.1149e-08, -1.1953e-07, -8.2064e-08,  9.2887e-08,  7.0481e-07,
#                         1.3585e-06, -1.7454e-07,  8.5980e-08,  4.7484e-08,  7.2432e-06,
#                         5.3907e-06,  1.9119e-07, -6.8663e-06,  7.1589e-09, -8.4977e-09,
#                        -5.7964e-08,  1.0003e-07,  5.5737e-08,  2.1756e-08,  1.1235e-06,
#                        -2.1997e-07,  8.6578e-10,  1.6947e-08,  5.1741e-07, -6.1934e-06,
#                        -4.1308e-09, -1.0616e-06, -1.1511e-09, -6.1266e-08,  5.7372e-06,
#                         2.7258e-07,  1.1751e-07, -5.4560e-08, -1.1251e-08, -6.1467e-07,
#                         9.3363e-08,  9.1568e-07,  3.0843e-07, -8.2048e-07,  4.9051e-08,
#                        -1.9836e-08,  4.2406e-07,  6.0887e-08,  2.3312e-09, -4.5197e-06,
#                        -3.5683e-08, -2.2699e-07, -9.9850e-07, -1.8903e-07, -3.0802e-08,
#                        -1.8349e-08, -5.9156e-06,  1.0771e-06,  1.7497e-07, -5.7269e-08,
#                         1.1346e-06, -1.9226e-06,  1.0315e-07,  5.3663e-08,  6.6034e-10,
#                         8.1023e-06, -2.0895e-08, -1.4116e-08, -1.0540e-08,  6.0988e-07,
#                         2.9781e-07, -1.1569e-06,  8.0935e-06,  1.6612e-07,  8.2031e-06,
#                         1.1480e-06,  6.9007e-08,  2.2373e-07,  8.0197e-09,  7.4653e-06,
#                        -1.4829e-08, -3.9428e-07,  2.8593e-06,  2.2415e-07, -2.4961e-08,
#                        -2.7639e-08,  1.6058e-05, -9.2624e-09, -3.6470e-06, -7.2711e-11,
#                         7.4694e-06, -1.5483e-06, -5.0996e-06,  7.6410e-08,  1.2462e-08,
#                         5.6068e-07, -5.4328e-09,  7.1484e-08, -1.8520e-06, -2.0958e-07,
#                        -3.9087e-08,  4.7482e-06, -4.2750e-07,  6.4888e-06,  2.7769e-08,
#                         9.9455e-10,  5.8573e-09, -6.0682e-08, -1.1027e-09, -5.8513e-09,
#                         2.8208e-07,  1.0008e-06, -2.5368e-07, -1.8847e-07, -1.7174e-07,
#                         2.6962e-09,  1.1013e-05,  2.7105e-09, -6.7948e-08,  4.1456e-08,
#                         2.0791e-07, -2.4269e-08, -4.4917e-06, -6.3214e-07,  1.2048e-06,
#                        -8.7511e-07,  3.5600e-08,  7.8275e-07], device='cuda:0'),
#                'exp_avg_sq': tensor([1.1641e-13, 5.6273e-12, 5.8699e-10, 2.2053e-10, 1.9043e-12, 4.5117e-13,
#                        1.8797e-13, 2.4793e-13, 1.5885e-12, 1.4765e-13, 1.1207e-15, 1.9889e-10,
#                        2.8190e-12, 1.2350e-11, 1.0862e-09, 5.6326e-13, 7.2166e-16, 1.8234e-10,
#                        2.6098e-13, 1.9861e-10, 9.7972e-12, 2.6669e-10, 2.8031e-12, 7.2425e-13,
#                        1.1015e-12, 3.1517e-12, 9.3813e-12, 3.2147e-16, 1.5655e-13, 2.5694e-15,
#                        7.0664e-12, 4.0210e-13, 2.4549e-12, 5.8818e-13, 3.1967e-10, 4.1816e-14,
#                        2.0676e-10, 7.7397e-10, 6.2025e-11, 9.4381e-12, 1.2319e-12, 1.7429e-09,
#                        1.6068e-11, 1.1493e-10, 5.2803e-10, 4.6033e-10, 1.0410e-14, 2.7851e-11,
#                        8.7929e-10, 4.5631e-14, 2.4380e-11, 4.0578e-16, 3.1367e-10, 2.8333e-11,
#                        9.2509e-14, 7.4607e-16, 1.4310e-12, 1.4799e-14, 5.0043e-15, 1.2499e-13,
#                        5.9152e-11, 6.1756e-10, 1.3431e-12, 1.3541e-12, 1.1160e-12, 4.9260e-16,
#                        2.0436e-10, 3.9665e-11, 5.0212e-12, 3.1089e-10, 9.3063e-15, 4.7779e-14,
#                        1.7385e-12, 4.6178e-13, 5.2592e-12, 1.0867e-11, 6.5693e-13, 1.0764e-13,
#                        2.4067e-13, 5.9146e-10, 1.3198e-10, 4.0547e-13, 1.4558e-10, 1.1100e-14,
#                        3.2124e-16, 5.4795e-14, 7.8735e-13, 2.6005e-12, 1.8194e-12, 1.8932e-12,
#                        1.1035e-11, 2.2443e-11, 7.7702e-14, 3.3922e-11, 1.7753e-10, 7.0020e-14,
#                        1.4705e-11, 1.2528e-15, 3.3378e-14, 2.4688e-10, 1.9810e-12, 3.6367e-13,
#                        2.6376e-12, 4.4301e-15, 3.1712e-12, 1.7249e-12, 8.1474e-12, 1.9691e-11,
#                        3.8466e-11, 7.9227e-13, 2.7474e-15, 6.8123e-12, 1.5347e-12, 3.6521e-16,
#                        3.5032e-11, 3.9727e-14, 5.5095e-12, 4.7685e-11, 9.6181e-13, 1.0900e-14,
#                        7.3456e-15, 1.3314e-10, 8.4740e-11, 1.3850e-13, 1.4434e-11, 1.9225e-11,
#                        7.0510e-11, 1.8826e-12, 1.3686e-12, 6.1811e-16, 3.6184e-10, 7.8842e-15,
#                        2.0332e-12, 2.5083e-15, 3.4486e-12, 1.6771e-11, 2.8055e-11, 9.5183e-10,
#                        2.7660e-12, 4.6090e-10, 1.9436e-11, 2.8917e-12, 1.0096e-12, 4.1123e-13,
#                        6.7910e-10, 1.8141e-15, 2.3216e-11, 1.4841e-09, 6.8149e-12, 8.3058e-15,
#                        1.9107e-14, 3.1651e-09, 1.7300e-15, 5.5469e-11, 6.8285e-16, 5.6063e-10,
#                        1.7049e-11, 1.1874e-10, 5.0013e-13, 6.4204e-16, 8.3833e-13, 4.9707e-16,
#                        1.0057e-10, 2.8716e-11, 1.2231e-11, 6.8715e-15, 3.0357e-10, 2.1243e-12,
#                        3.6226e-10, 1.0607e-12, 8.8240e-16, 1.0482e-14, 3.3878e-12, 1.5966e-16,
#                        1.0281e-13, 3.4677e-12, 4.1996e-12, 5.5965e-12, 7.8554e-12, 5.3109e-13,
#                        2.6280e-16, 1.3405e-09, 2.2803e-16, 1.0657e-11, 6.0198e-14, 5.1932e-12,
#                        3.5246e-14, 1.5041e-10, 4.1518e-11, 1.2505e-11, 1.9307e-11, 1.6932e-14,
#                        7.2243e-12], device='cuda:0')},
#               Parameter containing:
#               tensor([[-0.0028,  0.0422, -0.0524,  ...,  0.0286,  0.0162, -0.0446],
#                       [-0.0195, -0.0292,  0.0102,  ...,  0.0308, -0.0195, -0.0486],
#                       [-0.0217, -0.0434,  0.0426,  ..., -0.0491,  0.0659, -0.0044],
#                       ...,
#                       [ 0.0163, -0.0542,  0.0471,  ..., -0.0106, -0.0019, -0.0550],
#                       [ 0.0558, -0.0143, -0.0409,  ..., -0.0150,  0.0234,  0.0233],
#                       [-0.0663, -0.0431,  0.0350,  ..., -0.0612,  0.0283, -0.0155]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([[-6.6427e-11,  3.3073e-08, -5.2078e-08,  ...,  4.7106e-08,
#                         -1.6332e-11, -1.0230e-08],
#                        [ 5.5228e-09,  1.0936e-08,  3.2240e-07,  ...,  9.0002e-09,
#                         -1.4242e-09,  7.5511e-08],
#                        [ 3.2658e-08,  1.9255e-06,  1.3451e-05,  ...,  1.8887e-06,
#                         -4.4003e-08,  3.0763e-06],
#                        ...,
#                        [-1.0845e-09,  3.7349e-07, -1.4426e-06,  ...,  5.0447e-07,
#                          1.3503e-09, -1.2971e-07],
#                        [ 2.4354e-10,  6.8737e-09, -4.8170e-07,  ...,  6.4736e-09,
#                         -9.3593e-10, -1.2296e-07],
#                        [-2.9143e-09, -1.0247e-08,  3.3513e-06,  ..., -8.4067e-09,
#                         -2.9727e-09,  4.0800e-07]], device='cuda:0'),
#                'exp_avg_sq': tensor([[1.4240e-17, 1.7358e-14, 1.1204e-11,  ..., 8.8785e-14, 2.1986e-17,
#                         5.7721e-15],
#                        [5.7354e-15, 4.6251e-16, 2.1125e-12,  ..., 7.0750e-16, 6.8225e-17,
#                         9.1857e-14],
#                        [3.1004e-13, 1.4033e-11, 7.1265e-09,  ..., 1.6247e-11, 1.1863e-14,
#                         1.9945e-10],
#                        ...,
#                        [1.5533e-15, 3.9691e-12, 1.1317e-09,  ..., 9.1847e-12, 4.3153e-15,
#                         3.6261e-13],
#                        [8.5967e-18, 2.1728e-16, 1.0832e-11,  ..., 1.8465e-16, 1.6349e-17,
#                         8.0336e-13],
#                        [1.3296e-16, 1.5163e-15, 1.6345e-10,  ..., 1.4105e-15, 1.0543e-16,
#                         2.3210e-12]], device='cuda:0')},
#               Parameter containing:
#               tensor([-0.0513, -0.0680,  0.0608, -0.0439,  0.0321,  0.0399,  0.0239,  0.0294,
#                        0.0328, -0.0746,  0.0094, -0.0688,  0.0567, -0.0016, -0.0845,  0.0270,
#                        0.0153, -0.0675,  0.0068, -0.0661,  0.0596,  0.0092, -0.0036,  0.0032,
#                        0.0159,  0.0190, -0.0258,  0.0505, -0.0561, -0.0333, -0.0343,  0.0895,
#                       -0.0615,  0.0209, -0.0564, -0.0156,  0.0888, -0.0418, -0.0338, -0.0685,
#                       -0.0728, -0.0678,  0.0322, -0.0778, -0.0034, -0.0196,  0.0351, -0.0980,
#                       -0.0631, -0.0047,  0.0241,  0.0236,  0.0055, -0.0541,  0.0019, -0.0244,
#                        0.0302, -0.0198,  0.0120, -0.0711,  0.0347, -0.0753, -0.0091, -0.0387,
#                        0.0047,  0.0134, -0.1244,  0.0499,  0.0180, -0.0419, -0.0619, -0.0702,
#                       -0.0313, -0.1349,  0.0178, -0.0733, -0.0703, -0.0312, -0.0004, -0.0533,
#                        0.0768, -0.0146,  0.0538,  0.0148, -0.0588, -0.0164,  0.0212, -0.0202,
#                        0.0485, -0.0038, -0.0265, -0.0488, -0.0229,  0.0165, -0.0247,  0.0126,
#                        0.0107,  0.0453,  0.0018, -0.0051, -0.0293, -0.0701, -0.0664,  0.0195,
#                        0.0507, -0.0465, -0.0041, -0.0211,  0.1363,  0.0763, -0.0856, -0.0788,
#                       -0.0488, -0.0436, -0.0473, -0.0154, -0.0146, -0.0461,  0.0268,  0.0214,
#                       -0.0097,  0.0339, -0.0642,  0.0014, -0.0200,  0.1042,  0.0252, -0.0182,
#                       -0.0189,  0.0003, -0.0557, -0.0855,  0.1325,  0.0281, -0.0156, -0.0024,
#                       -0.0538, -0.0548, -0.0766,  0.0029, -0.0816, -0.0779, -0.0235,  0.0182,
#                        0.0476, -0.0653, -0.0522,  0.0020, -0.0149, -0.0721,  0.0698, -0.0189,
#                        0.0387,  0.0228,  0.0291,  0.1051,  0.0469, -0.0186, -0.0237,  0.0282,
#                        0.0793, -0.0465, -0.0807, -0.0580, -0.0489, -0.0445, -0.0212, -0.0964,
#                       -0.0702, -0.0274, -0.0345,  0.1591, -0.0244,  0.0139, -0.0510,  0.0545,
#                       -0.0212,  0.0046,  0.0457, -0.1043, -0.0293,  0.0580,  0.0166,  0.0094,
#                       -0.0191,  0.0015, -0.0621,  0.0824,  0.0786,  0.0280, -0.0258, -0.0198,
#                       -0.0566, -0.0772, -0.0258, -0.1017, -0.0438, -0.0503, -0.0778, -0.0292,
#                        0.0090, -0.0034,  0.0020,  0.1365, -0.0732, -0.0048, -0.0587, -0.0118,
#                       -0.0834, -0.0136,  0.0248, -0.0977, -0.0403, -0.0629, -0.1594, -0.0888,
#                       -0.0973,  0.0210,  0.0362, -0.0766,  0.0415, -0.1538,  0.0166,  0.0273,
#                        0.0226,  0.0572,  0.0437, -0.0484, -0.0307, -0.0591, -0.0355,  0.0778,
#                        0.0024,  0.0132,  0.0111, -0.0194,  0.0826, -0.0759, -0.0270, -0.0656,
#                        0.0409, -0.0611,  0.0380,  0.0280, -0.0566, -0.0027, -0.0267, -0.0262],
#                      device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([ 9.1630e-08,  1.3837e-07,  5.7336e-06, -1.8525e-07,  3.8655e-08,
#                        -1.4609e-06,  9.7662e-07,  6.9435e-06,  5.6087e-06, -1.5923e-10,
#                        -1.6587e-08, -5.2179e-10,  3.8315e-06, -9.1386e-09, -7.3573e-07,
#                         1.7734e-06,  5.5415e-06,  3.1386e-08,  2.3703e-06, -1.6536e-09,
#                        -2.1939e-07,  1.7925e-09,  5.3709e-06,  5.7481e-06,  4.0272e-06,
#                        -2.9787e-07, -7.2791e-08,  5.1390e-06,  1.5949e-06,  5.1022e-06,
#                        -8.4331e-07,  1.1556e-07, -3.8615e-09, -5.0359e-08,  2.6173e-10,
#                        -6.5190e-08,  1.3153e-07,  1.6567e-08, -1.6712e-08,  1.3031e-08,
#                        -3.0929e-08, -5.6385e-08,  5.2524e-06, -2.1029e-08,  2.4708e-08,
#                        -3.3905e-08,  3.5432e-06, -1.8640e-08,  2.3338e-07,  2.1340e-06,
#                        -9.8370e-09,  7.5795e-08, -3.3993e-09, -2.1983e-09, -3.8491e-08,
#                         2.7210e-09, -3.3066e-07,  5.8447e-08,  1.9486e-06,  1.2275e-08,
#                         1.9477e-06,  5.5346e-08, -4.1677e-07,  3.0780e-07, -3.1001e-08,
#                        -2.0414e-08, -1.2469e-08,  3.2989e-07,  1.8915e-06, -1.3153e-07,
#                        -7.9338e-09, -2.4560e-08, -1.5600e-07,  3.6974e-08,  4.1958e-06,
#                        -2.4283e-08, -6.3560e-10, -2.7445e-08,  2.6996e-06, -1.5388e-08,
#                         4.3010e-06, -6.3066e-07,  6.2042e-06, -4.6754e-08, -2.6905e-08,
#                         1.0482e-08, -2.3899e-07,  4.8713e-08,  9.9352e-07,  3.9172e-07,
#                        -2.6244e-08, -1.0655e-09,  1.0843e-06,  4.2463e-08, -3.1960e-09,
#                         1.0876e-09, -2.2207e-08,  2.6093e-07, -1.8174e-06,  3.1599e-06,
#                         5.0253e-06, -5.8309e-08, -1.3329e-08,  5.3996e-06, -6.7148e-08,
#                        -6.4724e-07, -4.5311e-09,  2.7360e-08, -6.6516e-07,  1.1319e-07,
#                        -1.7628e-06, -2.2495e-08,  4.9160e-08,  1.6399e-10, -2.5092e-07,
#                        -1.6214e-07,  1.3366e-06, -1.2468e-07,  5.4975e-06, -3.1152e-06,
#                         5.5590e-06,  1.0203e-08,  9.2008e-09, -1.1631e-07,  5.6494e-06,
#                         6.9215e-08, -4.1657e-08,  6.2646e-07, -4.4189e-09, -1.8547e-07,
#                         2.7512e-06, -2.9233e-08, -2.4386e-06, -6.5138e-07,  1.1706e-07,
#                         2.0441e-06, -1.4937e-07, -3.3019e-08, -4.2462e-08, -8.7684e-08,
#                         1.0719e-07, -1.6034e-08, -4.1418e-09,  1.6906e-09, -1.2334e-08,
#                         1.0962e-09, -5.9885e-08,  5.8494e-06, -3.3399e-06, -3.7982e-06,
#                         4.8184e-06,  6.9756e-06,  6.2020e-06, -8.6723e-10,  3.3001e-07,
#                        -9.6375e-08, -3.1325e-08,  1.1539e-07,  4.1138e-08,  7.7425e-06,
#                         4.5830e-06,  1.8406e-07, -2.6190e-08, -4.2619e-09, -1.2720e-08,
#                         1.7181e-06,  3.4323e-06, -1.2072e-09, -1.0253e-08,  2.6371e-06,
#                         2.0116e-06, -2.0602e-07,  2.8396e-06,  1.9495e-07, -1.9202e-07,
#                        -7.5928e-08, -1.8114e-07, -3.0182e-08,  3.0011e-06, -3.1356e-09,
#                         2.3115e-08,  2.2323e-07, -6.3387e-07,  6.1251e-09,  2.4857e-08,
#                         2.6132e-07, -2.9002e-08,  3.9217e-07,  3.8355e-06, -4.6925e-07,
#                         5.5166e-07,  4.2677e-08,  6.3164e-06, -3.5259e-08,  2.9390e-07,
#                         2.0345e-08,  3.9623e-06,  1.7261e-07, -2.7071e-08, -2.9588e-08,
#                        -6.7447e-09, -2.7645e-06,  3.7324e-06, -2.3980e-07,  1.9233e-07,
#                         4.3317e-06,  4.2502e-07, -5.2842e-08, -4.5836e-08,  6.6670e-07,
#                         2.0337e-06,  4.1388e-08, -2.6348e-07, -2.0128e-09, -8.6088e-08,
#                        -8.5584e-10, -1.7541e-07,  2.4737e-08,  4.8851e-06, -1.0327e-08,
#                         4.4811e-06,  4.9231e-07, -8.8838e-08,  2.9074e-06,  3.1931e-06,
#                        -2.0695e-08,  4.2625e-06,  3.8429e-07,  1.6978e-06,  4.8199e-10,
#                         5.7256e-06,  6.3541e-06,  5.8943e-08,  2.2822e-07,  4.1902e-09,
#                         1.5277e-08,  3.0667e-06,  3.1451e-07, -5.4069e-08,  2.7255e-10,
#                         6.6393e-06, -6.1012e-08,  4.7845e-06, -9.1626e-07,  5.3111e-06,
#                         1.7351e-07, -1.4273e-08,  4.2021e-07], device='cuda:0'),
#                'exp_avg_sq': tensor([2.6626e-13, 8.2741e-13, 2.5515e-10, 6.0967e-13, 9.1796e-14, 4.3977e-11,
#                        3.5303e-11, 3.2624e-10, 2.2397e-10, 3.5507e-19, 3.8527e-15, 3.9191e-18,
#                        2.0558e-10, 1.1695e-15, 9.2388e-12, 4.1229e-11, 3.5043e-10, 1.3795e-14,
#                        1.2242e-10, 1.0902e-16, 8.9916e-13, 8.3183e-15, 2.1751e-10, 2.3156e-10,
#                        1.1914e-10, 2.4774e-11, 6.3123e-14, 3.7519e-10, 3.7878e-12, 1.8646e-10,
#                        2.1951e-11, 1.1100e-12, 2.0881e-16, 3.5514e-14, 2.1751e-16, 2.3606e-13,
#                        1.1866e-12, 2.1225e-14, 3.9113e-15, 2.7662e-14, 1.3396e-14, 4.4522e-14,
#                        3.8609e-10, 6.1925e-15, 7.5967e-14, 1.6098e-14, 5.1774e-11, 4.8658e-15,
#                        1.5662e-12, 5.4625e-11, 1.7336e-13, 2.3336e-13, 1.6174e-16, 6.7675e-17,
#                        8.6163e-14, 3.2675e-14, 4.9209e-12, 1.9466e-13, 5.5272e-11, 2.1099e-15,
#                        1.1598e-10, 9.3117e-13, 7.4185e-11, 8.3031e-13, 1.3459e-14, 7.2180e-15,
#                        2.1773e-15, 2.8378e-12, 3.6144e-11, 6.0506e-13, 8.8147e-16, 8.4467e-15,
#                        3.3895e-12, 1.6559e-13, 2.3917e-10, 8.2577e-15, 5.6573e-18, 1.0548e-14,
#                        7.8438e-11, 3.7489e-15, 1.5816e-10, 5.8809e-12, 5.3902e-10, 3.0646e-14,
#                        1.1583e-14, 1.0656e-14, 1.3375e-11, 4.7581e-13, 2.3812e-10, 8.5083e-13,
#                        3.7997e-12, 1.5899e-17, 2.5177e-10, 5.3261e-12, 1.4304e-16, 1.5833e-16,
#                        6.9058e-15, 2.5962e-11, 3.1843e-12, 7.0335e-11, 1.6811e-10, 4.7612e-14,
#                        2.4880e-15, 3.4581e-10, 2.1652e-13, 2.4077e-11, 2.3701e-14, 1.6012e-12,
#                        3.2677e-11, 1.0138e-11, 1.8789e-11, 1.6180e-14, 3.3648e-13, 6.1810e-17,
#                        9.8938e-13, 2.8769e-13, 2.2412e-11, 6.1181e-13, 4.2323e-10, 6.2419e-11,
#                        4.0013e-10, 6.2824e-14, 1.8848e-11, 7.4353e-13, 2.5450e-10, 9.6587e-12,
#                        2.4301e-14, 3.9484e-12, 2.7310e-16, 4.5436e-12, 9.4505e-11, 1.9401e-14,
#                        2.9536e-10, 1.9673e-11, 3.5318e-13, 4.1337e-11, 1.0533e-12, 1.5268e-14,
#                        5.0398e-14, 1.2971e-13, 1.4452e-12, 3.6000e-15, 2.4023e-16, 4.0023e-17,
#                        2.1302e-15, 1.7113e-17, 7.4027e-14, 4.9768e-10, 1.3805e-10, 2.2925e-11,
#                        3.2600e-10, 3.3933e-10, 5.3630e-10, 2.2538e-15, 1.3463e-12, 6.6101e-13,
#                        1.3741e-14, 1.2366e-12, 2.7188e-14, 4.0627e-10, 2.9427e-10, 9.3727e-13,
#                        9.6053e-15, 2.1761e-15, 2.2659e-15, 2.0801e-11, 6.3080e-12, 8.3418e-17,
#                        1.4722e-15, 4.6308e-11, 2.7243e-11, 9.8961e-12, 1.1048e-10, 8.3779e-13,
#                        3.3295e-13, 1.5096e-12, 2.2831e-13, 1.0904e-13, 5.7215e-11, 1.3768e-16,
#                        1.9581e-13, 3.3356e-12, 1.1010e-11, 5.2537e-16, 5.8102e-14, 2.6616e-12,
#                        1.1778e-14, 3.5393e-12, 8.9730e-11, 1.7361e-12, 3.3623e-12, 1.5351e-13,
#                        2.7655e-10, 1.7410e-14, 1.6498e-12, 1.2806e-13, 2.1116e-10, 2.8641e-11,
#                        6.8999e-14, 1.2260e-14, 8.5764e-15, 6.0661e-11, 9.5439e-11, 6.2234e-12,
#                        2.9574e-13, 2.6142e-10, 2.2215e-12, 3.9102e-14, 2.9421e-14, 4.7393e-12,
#                        3.0206e-11, 1.0574e-14, 5.2865e-12, 1.5221e-14, 2.9691e-13, 4.2119e-17,
#                        3.9097e-13, 9.9318e-14, 3.3419e-10, 1.4934e-15, 2.5361e-10, 3.6129e-13,
#                        1.2188e-13, 6.8166e-11, 1.3473e-10, 4.6060e-12, 2.5521e-10, 2.5093e-12,
#                        2.6292e-11, 3.2533e-18, 4.5069e-10, 5.6541e-10, 1.4882e-12, 6.6840e-13,
#                        3.5196e-15, 5.4890e-15, 1.3397e-10, 1.7569e-11, 1.5578e-13, 2.9687e-14,
#                        3.3667e-10, 1.0814e-12, 3.2056e-10, 5.7957e-11, 2.0014e-10, 4.3857e-11,
#                        2.1407e-13, 2.5238e-12], device='cuda:0')},
#               Parameter containing:
#               tensor([[-0.0173,  0.0248,  0.0477, -0.0128, -0.0174, -0.0694, -0.0663,  0.0539,
#                         0.0474, -0.0002, -0.0184, -0.0006,  0.0426, -0.0102, -0.0292,  0.0191,
#                         0.0557,  0.0349,  0.0511, -0.0018,  0.0149, -0.0027,  0.0442,  0.0455,
#                         0.0341, -0.0630,  0.0137,  0.0576, -0.0412,  0.0418, -0.0170, -0.0270,
#                        -0.0043, -0.0559, -0.0009,  0.0054, -0.0231, -0.0101, -0.0186, -0.0186,
#                        -0.0344, -0.0626,  0.0584, -0.0234, -0.0251, -0.0377,  0.0517, -0.0207,
#                        -0.0427,  0.0220, -0.0112, -0.0154, -0.0038, -0.0024, -0.0161,  0.0072,
#                        -0.0303,  0.0110,  0.0221,  0.0136, -0.0808, -0.0179,  0.0397, -0.0342,
#                        -0.0344, -0.0226, -0.0139, -0.0394,  0.0179,  0.0148, -0.0088, -0.0273,
#                        -0.0471, -0.0165,  0.0459, -0.0270, -0.0007, -0.0305,  0.0264, -0.0023,
#                         0.0374, -0.0285,  0.0689, -0.0519, -0.0300, -0.0080, -0.0328, -0.0333,
#                        -0.0822, -0.0376,  0.0243, -0.0012,  0.1173,  0.0418, -0.0036, -0.0009,
#                        -0.0247,  0.0646, -0.0276,  0.0253,  0.0399, -0.0648, -0.0148,  0.0553,
#                         0.0088, -0.0791,  0.0062, -0.0227,  0.0478, -0.0469, -0.0482, -0.0135,
#                         0.0163,  0.0009,  0.0224, -0.0542,  0.0279,  0.0108,  0.0611, -0.0737,
#                         0.0596, -0.0167, -0.0260,  0.0184,  0.0486, -0.0321, -0.0463, -0.0390,
#                        -0.0049,  0.0119,  0.0290, -0.0330,  0.1070, -0.0389, -0.0117,  0.0193,
#                        -0.0204, -0.0367,  0.0098,  0.0070, -0.0292, -0.0178, -0.0046,  0.0019,
#                        -0.0137,  0.0012, -0.0407,  0.0664, -0.1055, -0.0372,  0.0536,  0.0552,
#                         0.0688, -0.0033, -0.0533,  0.0114, -0.0348, -0.0444, -0.0041,  0.0601,
#                         0.0509, -0.0354, -0.0291, -0.0066, -0.0141, -0.0413,  0.0431, -0.0012,
#                        -0.0114,  0.0206,  0.0159,  0.0270,  0.0314, -0.0607, -0.0107,  0.0389,
#                         0.0155, -0.0117,  0.0225, -0.0035, -0.0171, -0.0322, -0.0264,  0.0068,
#                        -0.0186,  0.0198, -0.0322, -0.0347,  0.0283,  0.0287,  0.0056, -0.0301,
#                         0.0498, -0.0392, -0.0425,  0.0117,  0.0433, -0.0491,  0.0034, -0.0329,
#                         0.0044, -0.0545,  0.0294,  0.0418, -0.0266,  0.0482,  0.0045, -0.0587,
#                        -0.0509, -0.0644,  0.0170, -0.0058, -0.0204,  0.0033, -0.0117, -0.0010,
#                         0.0155, -0.0374,  0.0543, -0.0115,  0.0474, -0.0185,  0.0139,  0.0263,
#                         0.0345,  0.0268,  0.0475, -0.0315,  0.0162,  0.0005,  0.0631,  0.0706,
#                        -0.0196, -0.0318, -0.0061, -0.0019,  0.0344,  0.0146,  0.0048, -0.0079,
#                         0.0560, -0.0195,  0.0531, -0.0658,  0.0424, -0.0667,  0.0141, -0.0115]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([[-1.1399e-06, -2.1544e-07,  1.2889e-04,  7.1133e-08, -4.0465e-07,
#                          2.9419e-07, -4.4837e-06,  1.3287e-04,  2.6271e-05, -8.4768e-09,
#                         -7.9899e-07, -1.2389e-07,  2.0891e-04, -7.6237e-07,  6.9518e-07,
#                          1.1130e-04,  1.8031e-04, -4.8189e-07,  1.2258e-05, -1.4145e-07,
#                         -5.1297e-07, -2.3369e-07,  1.7055e-04,  1.7915e-04,  6.4178e-05,
#                          9.3963e-07, -1.9719e-07,  1.3453e-04, -7.5848e-06,  1.1448e-04,
#                         -6.7081e-06, -3.6231e-06, -5.8045e-07, -1.8866e-06, -2.6395e-07,
# ...
#                         2.9403e-11, 1.3810e-06, 2.4972e-08, 7.6925e-11, 6.0774e-11, 1.6087e-10,
#                         1.6950e-07, 7.1323e-12, 2.0667e-11, 2.2997e-12, 9.9568e-11, 2.4829e-13,
#                         1.7929e-11, 2.8888e-11, 6.4511e-07, 1.2785e-11, 1.0648e-06, 1.1149e-10,
#                         1.2737e-12, 2.9568e-07, 5.6552e-07, 3.3053e-11, 9.6769e-07, 8.2608e-12,
#                         1.2645e-07, 2.3896e-13, 7.5977e-07, 9.8514e-07, 1.6541e-10, 8.4893e-11,
#                         4.5361e-12, 1.7151e-12, 1.0149e-06, 4.7970e-08, 7.7106e-12, 4.8331e-12,
#                         4.3586e-07, 3.0269e-12, 6.0030e-07, 3.4535e-12, 4.0640e-07, 1.0207e-09,
#                         7.8679e-13, 3.0036e-11]], device='cuda:0')},
#               Parameter containing:
#               tensor([0.0520], device='cuda:0', requires_grad=True): {'step': tensor(681200.),
#                'exp_avg': tensor([9.0024e-05], device='cuda:0'),
#                'exp_avg_sq': tensor([1.1349e-07], device='cuda:0')}}),
#  'param_groups': [{'lr': 4.667281295420373e-22,
#    'betas': (0.9, 0.999),
#    'eps': 1e-08,
#    'weight_decay': 0,
#    'amsgrad': False,
#    'maximize': False,
#    'foreach': None,
#    'capturable': False,
#    'differentiable': False,
#    'fused': None,
#    'initial_lr': 0.0009376919782324494,
#    'params': [Parameter containing:
#     tensor([[ 4.0703e-01, -3.3209e-01,  2.4541e-01],
#             [ 3.9574e-01,  4.4300e-01, -4.7536e-01],
#             [ 5.3288e-01,  3.8867e-01, -4.8479e-01],
#             [ 8.6288e-02,  2.2755e-01, -5.6166e-01],
#             [ 4.5703e-01,  4.7261e-01,  3.9110e-01],
#             [-1.0874e-01,  4.3502e-01, -2.9330e-01],
#             [-4.7408e-01,  2.2947e-01, -1.5686e-01],
#             [ 3.7815e-01, -3.5651e-01, -4.3197e-01],
#             [-1.8735e-02, -3.5852e-01, -4.3461e-01],
#             [ 1.5751e-02,  1.7131e-01,  3.0135e-02],
#             [-5.5786e-01, -1.5186e-01, -5.5708e-02],
#             [-3.2261e-01, -1.0598e-01,  7.4610e-02],
#             [-3.3268e-01,  1.2492e-01,  3.4374e-02],
#             [ 4.7166e-01,  1.1620e-01, -1.9587e-01],
#             [-3.8253e-01,  2.6799e-01,  3.7434e-01],
#             [-2.7552e-01, -2.0934e-01,  3.6939e-04],
#             [ 2.5972e-01, -5.0087e-01, -1.0369e-01],
#             [-3.9376e-01,  5.0110e-01,  9.8127e-02],
#             [ 1.8719e-01, -8.1313e-02, -2.8015e-01],
#             [-1.1466e-01, -4.5091e-01, -3.6362e-01],
#             [-3.8132e-01,  8.7239e-02,  8.6272e-02],
#             [-4.3027e-01,  1.3524e-02,  2.1827e-01],
#             [-2.0852e-01,  1.6656e-01,  3.2412e-01],
#             [ 3.8629e-01,  3.0472e-01,  4.1659e-01],
#             [ 2.0792e-01,  9.1386e-02, -5.2300e-01],
#             [-3.8574e-01,  3.0005e-01,  2.2964e-01],
#             [ 3.2233e-01,  3.9980e-01, -4.8669e-01],
#             [-8.3361e-02, -1.8442e-02,  3.5311e-02],
#             [-3.4851e-01,  3.7308e-01, -1.7108e-01],
#             [-9.7168e-02, -3.8977e-01,  9.4209e-02],
#             [ 1.7467e-01, -1.8738e-01,  1.4916e-01],
#             [-3.3370e-01,  1.6417e-01,  1.6782e-02],
#             [-2.3076e-02, -5.5705e-01,  1.9449e-01],
#             [-5.4737e-01, -5.6938e-02,  4.8260e-01],
#             [-2.0278e-01,  4.4483e-01, -6.6182e-02],
#             [ 4.3948e-01,  1.9841e-01,  3.4938e-01],
#             [ 4.5413e-01, -1.9597e-01,  5.7271e-01],
#             [ 4.6930e-01,  2.7708e-01, -2.8002e-01],
#             [-5.2297e-01,  2.1001e-01,  1.3550e-01],
#             [ 2.1478e-01,  4.9793e-01,  1.3830e-01],
#             [ 5.0789e-02,  4.9282e-01, -4.8851e-01],
#             [-7.8824e-02,  3.9813e-01,  4.9718e-01],
#             [ 4.3622e-01,  3.6230e-01,  1.8949e-01],
#             [-8.5955e-02, -9.7836e-02,  2.5725e-01],
#             [-2.6691e-01,  4.0066e-01,  2.3975e-01],
#             [-3.2434e-01, -3.2835e-02,  2.6271e-02],
#             [ 4.4681e-01, -3.8512e-01, -4.4964e-01],
#             [-4.9077e-01, -1.7938e-01,  4.1816e-01],
#             [ 1.4816e-01, -2.7735e-01, -4.1722e-01],
#             [ 1.0778e-01,  2.9132e-01,  3.3804e-01],
#             [-3.7778e-01, -4.6641e-01,  5.6872e-01],
#             [-4.0338e-01,  3.4110e-01, -2.4774e-02],
#             [ 1.1895e-01,  2.7858e-01, -4.0135e-02],
#             [ 3.4615e-01,  3.3874e-02, -1.3440e-01],
#             [ 2.7207e-01,  1.1176e-01, -1.5754e-01],
#             [-1.0054e-01, -4.0024e-01,  1.3083e-01],
#             [ 4.7844e-01, -5.0384e-01,  2.1797e-01],
#             [-3.0219e-01,  8.3160e-02,  1.1197e-01],
#             [ 4.7103e-01,  4.6320e-01, -1.0860e-01],
#             [ 3.9115e-01, -5.6066e-01, -5.4771e-01],
#             [-4.0218e-01,  2.4949e-01, -9.9419e-02],
#             [ 5.5686e-01, -4.1523e-01, -2.1529e-01],
#             [-8.5780e-02, -3.6724e-01, -4.6862e-01],
#             [ 8.6542e-02, -4.3628e-02, -3.7930e-01],
#             [-3.5181e-02,  4.1098e-01, -1.5650e-01],
#             [-2.8010e-01, -1.2258e-01, -2.9233e-01]], device='cuda:0',
#            requires_grad=True),
#     Parameter containing:
#     tensor([ 0.3392, -0.0676,  0.3211, -0.1155, -0.1619,  0.5251, -0.1288,  0.2064,
#              0.0868, -0.6112, -0.3304, -0.0647, -0.1194,  0.1181,  0.2438,  0.3304,
#              0.2704,  0.2447,  0.0634, -0.3550, -0.4921,  0.3307,  0.2780, -0.5304,
#              0.3452, -0.5146,  0.1472,  0.2347,  0.0982, -0.5379,  0.3258, -0.0582,
#             -0.2312, -0.0098, -0.1853,  0.1103, -0.5430,  0.2692, -0.1088,  0.3683,
#             -0.1022, -0.1591, -0.4521,  0.4869, -0.3064,  0.0855,  0.4093, -0.3121,
#              0.1299,  0.4032, -0.1672, -0.1366, -0.5081, -0.2706, -0.4001,  0.4441,
#             -0.0102,  0.1336, -0.0675,  0.2166, -0.0840,  0.4400,  0.5121,  0.0026,
#              0.4079, -0.2059], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0873, -0.0195, -0.0606,  ..., -0.0262,  0.1149, -0.1003],
#             [ 0.0947,  0.0575, -0.0667,  ...,  0.0040,  0.0228,  0.0592],
#             [ 0.1583, -0.0099, -0.0207,  ..., -0.0428, -0.0093,  0.0552],
#             ...,
#             [-0.0414,  0.0492,  0.1124,  ..., -0.1509,  0.0773,  0.0805],
#             [ 0.0674, -0.0686, -0.1204,  ..., -0.0756,  0.0318, -0.0314],
#             [ 0.0820, -0.0867, -0.0201,  ...,  0.0635,  0.0909,  0.1181]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-6.7190e-02,  5.0857e-02, -6.0886e-02, -6.8841e-02,  5.4440e-02,
#             -2.7378e-02,  1.9591e-02, -3.9092e-03,  2.7291e-02, -8.2242e-02,
#             -3.6240e-02,  3.0468e-03, -1.0347e-01, -9.6846e-02, -8.0039e-02,
#             -5.6724e-02, -5.1376e-02, -1.1534e-01,  1.0357e-02, -1.3662e-01,
#              1.5152e-01, -5.6677e-02,  2.9142e-02,  2.3898e-02,  9.6004e-02,
#              9.3752e-02,  1.8263e-04, -3.1107e-02,  3.1472e-02,  1.8765e-02,
#             -4.7950e-02,  3.1196e-02,  4.3236e-02, -1.1498e-01, -6.2510e-02,
#             -6.5710e-02,  1.5251e-02, -1.2221e-01, -3.5116e-03, -1.6307e-01,
#             -5.4335e-02,  1.0923e-01,  8.8543e-02, -4.6167e-05,  9.1507e-02,
#             -7.2172e-02, -7.4399e-02, -6.0050e-02,  1.1322e-01, -5.9231e-02,
#             -3.8494e-02,  5.8541e-02,  1.4531e-02, -3.0604e-02,  4.2338e-03,
#              2.2296e-02, -7.0445e-02, -3.7109e-02, -5.5375e-02, -6.9400e-02,
#              2.4298e-02,  3.3955e-02, -6.5531e-03, -1.3046e-01, -3.1256e-02,
#              3.1977e-02, -4.1889e-02, -1.2122e-01,  4.5195e-03, -9.9163e-02,
#              6.2637e-02, -8.8915e-02,  8.6932e-02, -6.0316e-03, -1.2568e-01,
#             -1.1934e-02,  5.2724e-02,  7.8431e-02, -1.0713e-01,  1.6137e-02,
#             -1.1494e-01,  1.0203e-01, -3.3963e-03, -3.9456e-02, -1.1026e-01,
#              9.8439e-02,  6.2919e-02, -7.1842e-02,  5.5712e-02, -1.1066e-01,
#             -1.1016e-01,  5.0132e-02, -6.3693e-02,  1.2336e-01,  3.9105e-02,
#             -9.8456e-03, -1.7194e-03,  7.5350e-02, -1.0851e-01,  4.4660e-02,
#             -9.7707e-02,  8.1962e-02, -4.4100e-02, -7.5631e-02,  3.8937e-03,
#             -7.8049e-02,  1.3895e-01,  6.7897e-03, -9.0964e-02, -6.0723e-02,
#             -3.8648e-02, -7.8081e-02,  1.0854e-01, -4.2285e-02, -7.0650e-02,
#              7.3057e-02,  1.4174e-02,  1.3661e-02,  3.3792e-02, -2.7828e-02,
#             -5.6915e-02, -9.1549e-02,  1.0506e-02, -4.6265e-02, -3.0409e-02,
#             -1.0162e-01,  1.2938e-02,  4.7439e-02, -7.5812e-03,  2.2817e-02,
#              1.1625e-01, -1.4128e-01,  1.0284e-01,  6.3534e-03,  1.0080e-01,
#              1.3292e-02, -8.3533e-02, -3.2160e-02,  7.3365e-02, -1.5122e-01,
#              1.5269e-01, -2.3433e-02, -1.1118e-02, -1.2607e-01,  9.1366e-02,
#             -9.6396e-02,  1.0193e-01,  2.1217e-02,  5.3439e-03, -5.5557e-02,
#              7.4500e-03, -8.2530e-03,  5.8513e-02, -1.2266e-01,  5.8895e-02,
#             -8.0074e-03,  5.1904e-02,  1.3722e-01,  3.6998e-03,  5.1571e-03,
#              1.4235e-02,  1.2329e-01,  1.2539e-02,  8.4832e-03, -2.3336e-02,
#             -8.3123e-02, -4.2803e-02, -6.8731e-02, -1.3958e-03,  1.4646e-02,
#             -7.7777e-02, -1.3160e-01,  8.2007e-02, -8.2963e-02,  2.8125e-03,
#              5.3237e-02, -1.3795e-01,  7.3768e-02,  6.1554e-02,  1.0941e-01,
#             -2.5339e-02,  7.4934e-02, -2.3276e-02, -7.0945e-02,  1.5682e-02,
#             -1.7887e-01, -1.1670e-01, -1.4050e-02,  1.3051e-01, -9.0232e-02,
#              6.7767e-02, -1.6114e-01,  7.2662e-02], device='cuda:0',
#            requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0028,  0.0422, -0.0524,  ...,  0.0286,  0.0162, -0.0446],
#             [-0.0195, -0.0292,  0.0102,  ...,  0.0308, -0.0195, -0.0486],
#             [-0.0217, -0.0434,  0.0426,  ..., -0.0491,  0.0659, -0.0044],
#             ...,
#             [ 0.0163, -0.0542,  0.0471,  ..., -0.0106, -0.0019, -0.0550],
#             [ 0.0558, -0.0143, -0.0409,  ..., -0.0150,  0.0234,  0.0233],
#             [-0.0663, -0.0431,  0.0350,  ..., -0.0612,  0.0283, -0.0155]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-0.0513, -0.0680,  0.0608, -0.0439,  0.0321,  0.0399,  0.0239,  0.0294,
#              0.0328, -0.0746,  0.0094, -0.0688,  0.0567, -0.0016, -0.0845,  0.0270,
#              0.0153, -0.0675,  0.0068, -0.0661,  0.0596,  0.0092, -0.0036,  0.0032,
#              0.0159,  0.0190, -0.0258,  0.0505, -0.0561, -0.0333, -0.0343,  0.0895,
#             -0.0615,  0.0209, -0.0564, -0.0156,  0.0888, -0.0418, -0.0338, -0.0685,
#             -0.0728, -0.0678,  0.0322, -0.0778, -0.0034, -0.0196,  0.0351, -0.0980,
#             -0.0631, -0.0047,  0.0241,  0.0236,  0.0055, -0.0541,  0.0019, -0.0244,
#              0.0302, -0.0198,  0.0120, -0.0711,  0.0347, -0.0753, -0.0091, -0.0387,
#              0.0047,  0.0134, -0.1244,  0.0499,  0.0180, -0.0419, -0.0619, -0.0702,
#             -0.0313, -0.1349,  0.0178, -0.0733, -0.0703, -0.0312, -0.0004, -0.0533,
#              0.0768, -0.0146,  0.0538,  0.0148, -0.0588, -0.0164,  0.0212, -0.0202,
#              0.0485, -0.0038, -0.0265, -0.0488, -0.0229,  0.0165, -0.0247,  0.0126,
#              0.0107,  0.0453,  0.0018, -0.0051, -0.0293, -0.0701, -0.0664,  0.0195,
#              0.0507, -0.0465, -0.0041, -0.0211,  0.1363,  0.0763, -0.0856, -0.0788,
#             -0.0488, -0.0436, -0.0473, -0.0154, -0.0146, -0.0461,  0.0268,  0.0214,
#             -0.0097,  0.0339, -0.0642,  0.0014, -0.0200,  0.1042,  0.0252, -0.0182,
#             -0.0189,  0.0003, -0.0557, -0.0855,  0.1325,  0.0281, -0.0156, -0.0024,
#             -0.0538, -0.0548, -0.0766,  0.0029, -0.0816, -0.0779, -0.0235,  0.0182,
#              0.0476, -0.0653, -0.0522,  0.0020, -0.0149, -0.0721,  0.0698, -0.0189,
#              0.0387,  0.0228,  0.0291,  0.1051,  0.0469, -0.0186, -0.0237,  0.0282,
#              0.0793, -0.0465, -0.0807, -0.0580, -0.0489, -0.0445, -0.0212, -0.0964,
#             -0.0702, -0.0274, -0.0345,  0.1591, -0.0244,  0.0139, -0.0510,  0.0545,
#             -0.0212,  0.0046,  0.0457, -0.1043, -0.0293,  0.0580,  0.0166,  0.0094,
#             -0.0191,  0.0015, -0.0621,  0.0824,  0.0786,  0.0280, -0.0258, -0.0198,
#             -0.0566, -0.0772, -0.0258, -0.1017, -0.0438, -0.0503, -0.0778, -0.0292,
#              0.0090, -0.0034,  0.0020,  0.1365, -0.0732, -0.0048, -0.0587, -0.0118,
#             -0.0834, -0.0136,  0.0248, -0.0977, -0.0403, -0.0629, -0.1594, -0.0888,
#             -0.0973,  0.0210,  0.0362, -0.0766,  0.0415, -0.1538,  0.0166,  0.0273,
#              0.0226,  0.0572,  0.0437, -0.0484, -0.0307, -0.0591, -0.0355,  0.0778,
#              0.0024,  0.0132,  0.0111, -0.0194,  0.0826, -0.0759, -0.0270, -0.0656,
#              0.0409, -0.0611,  0.0380,  0.0280, -0.0566, -0.0027, -0.0267, -0.0262],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0173,  0.0248,  0.0477, -0.0128, -0.0174, -0.0694, -0.0663,  0.0539,
#               0.0474, -0.0002, -0.0184, -0.0006,  0.0426, -0.0102, -0.0292,  0.0191,
#               0.0557,  0.0349,  0.0511, -0.0018,  0.0149, -0.0027,  0.0442,  0.0455,
#               0.0341, -0.0630,  0.0137,  0.0576, -0.0412,  0.0418, -0.0170, -0.0270,
#              -0.0043, -0.0559, -0.0009,  0.0054, -0.0231, -0.0101, -0.0186, -0.0186,
#              -0.0344, -0.0626,  0.0584, -0.0234, -0.0251, -0.0377,  0.0517, -0.0207,
#              -0.0427,  0.0220, -0.0112, -0.0154, -0.0038, -0.0024, -0.0161,  0.0072,
#              -0.0303,  0.0110,  0.0221,  0.0136, -0.0808, -0.0179,  0.0397, -0.0342,
#              -0.0344, -0.0226, -0.0139, -0.0394,  0.0179,  0.0148, -0.0088, -0.0273,
#              -0.0471, -0.0165,  0.0459, -0.0270, -0.0007, -0.0305,  0.0264, -0.0023,
#               0.0374, -0.0285,  0.0689, -0.0519, -0.0300, -0.0080, -0.0328, -0.0333,
#              -0.0822, -0.0376,  0.0243, -0.0012,  0.1173,  0.0418, -0.0036, -0.0009,
#              -0.0247,  0.0646, -0.0276,  0.0253,  0.0399, -0.0648, -0.0148,  0.0553,
#               0.0088, -0.0791,  0.0062, -0.0227,  0.0478, -0.0469, -0.0482, -0.0135,
#               0.0163,  0.0009,  0.0224, -0.0542,  0.0279,  0.0108,  0.0611, -0.0737,
#               0.0596, -0.0167, -0.0260,  0.0184,  0.0486, -0.0321, -0.0463, -0.0390,
#              -0.0049,  0.0119,  0.0290, -0.0330,  0.1070, -0.0389, -0.0117,  0.0193,
#              -0.0204, -0.0367,  0.0098,  0.0070, -0.0292, -0.0178, -0.0046,  0.0019,
#              -0.0137,  0.0012, -0.0407,  0.0664, -0.1055, -0.0372,  0.0536,  0.0552,
#               0.0688, -0.0033, -0.0533,  0.0114, -0.0348, -0.0444, -0.0041,  0.0601,
#               0.0509, -0.0354, -0.0291, -0.0066, -0.0141, -0.0413,  0.0431, -0.0012,
#              -0.0114,  0.0206,  0.0159,  0.0270,  0.0314, -0.0607, -0.0107,  0.0389,
#               0.0155, -0.0117,  0.0225, -0.0035, -0.0171, -0.0322, -0.0264,  0.0068,
#              -0.0186,  0.0198, -0.0322, -0.0347,  0.0283,  0.0287,  0.0056, -0.0301,
#               0.0498, -0.0392, -0.0425,  0.0117,  0.0433, -0.0491,  0.0034, -0.0329,
#               0.0044, -0.0545,  0.0294,  0.0418, -0.0266,  0.0482,  0.0045, -0.0587,
#              -0.0509, -0.0644,  0.0170, -0.0058, -0.0204,  0.0033, -0.0117, -0.0010,
#               0.0155, -0.0374,  0.0543, -0.0115,  0.0474, -0.0185,  0.0139,  0.0263,
#               0.0345,  0.0268,  0.0475, -0.0315,  0.0162,  0.0005,  0.0631,  0.0706,
#              -0.0196, -0.0318, -0.0061, -0.0019,  0.0344,  0.0146,  0.0048, -0.0079,
#               0.0560, -0.0195,  0.0531, -0.0658,  0.0424, -0.0667,  0.0141, -0.0115]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([0.0520], device='cuda:0', requires_grad=True)]}],
#  '_warned_capturable_if_run_uncaptured': True,
#  'step': <function torch.optim.optimizer._use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)>,
#  '_step_count': 0}
# {'gamma': 0.9,
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      initial_lr: 0.0009376919782324494
#      lr: 4.667281295420373e-22
#      maximize: False
#      weight_decay: 0
#  ),
#  'base_lrs': [0.0009376919782324494],
#  'last_epoch': 400,
#  'verbose': False,
#  '_step_count': 401,
#  '_get_lr_called_within_step': False,
#  '_last_lr': [4.667281295420373e-22]}

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 4.0703e-01, -3.3209e-01,  2.4541e-01],
#         [ 3.9574e-01,  4.4300e-01, -4.7536e-01],
#         [ 5.3288e-01,  3.8867e-01, -4.8479e-01],
#         [ 8.6288e-02,  2.2755e-01, -5.6166e-01],
#         [ 4.5703e-01,  4.7261e-01,  3.9110e-01],
#         [-1.0874e-01,  4.3502e-01, -2.9330e-01],
#         [-4.7408e-01,  2.2947e-01, -1.5686e-01],
#         [ 3.7815e-01, -3.5651e-01, -4.3197e-01],
#         [-1.8735e-02, -3.5852e-01, -4.3461e-01],
#         [ 1.5751e-02,  1.7131e-01,  3.0135e-02],
#         [-5.5786e-01, -1.5186e-01, -5.5708e-02],
#         [-3.2261e-01, -1.0598e-01,  7.4610e-02],
#         [-3.3268e-01,  1.2492e-01,  3.4374e-02],
#         [ 4.7166e-01,  1.1620e-01, -1.9587e-01],
#         [-3.8253e-01,  2.6799e-01,  3.7434e-01],
#         [-2.7552e-01, -2.0934e-01,  3.6939e-04],
#         [ 2.5972e-01, -5.0087e-01, -1.0369e-01],
#         [-3.9376e-01,  5.0110e-01,  9.8127e-02],
#         [ 1.8719e-01, -8.1313e-02, -2.8015e-01],
#         [-1.1466e-01, -4.5091e-01, -3.6362e-01],
#         [-3.8132e-01,  8.7239e-02,  8.6272e-02],
#         [-4.3027e-01,  1.3524e-02,  2.1827e-01],
#         [-2.0852e-01,  1.6656e-01,  3.2412e-01],
#         [ 3.8629e-01,  3.0472e-01,  4.1659e-01],
#         [ 2.0792e-01,  9.1386e-02, -5.2300e-01],
#         [-3.8574e-01,  3.0005e-01,  2.2964e-01],
#         [ 3.2233e-01,  3.9980e-01, -4.8669e-01],
#         [-8.3361e-02, -1.8442e-02,  3.5311e-02],
#         [-3.4851e-01,  3.7308e-01, -1.7108e-01],
#         [-9.7168e-02, -3.8977e-01,  9.4209e-02],
#         [ 1.7467e-01, -1.8738e-01,  1.4916e-01],
#         [-3.3370e-01,  1.6417e-01,  1.6782e-02],
#         [-2.3076e-02, -5.5705e-01,  1.9449e-01],
#         [-5.4737e-01, -5.6938e-02,  4.8260e-01],
#         [-2.0278e-01,  4.4483e-01, -6.6182e-02],
#         [ 4.3948e-01,  1.9841e-01,  3.4938e-01],
#         [ 4.5413e-01, -1.9597e-01,  5.7271e-01],
#         [ 4.6930e-01,  2.7708e-01, -2.8002e-01],
#         [-5.2297e-01,  2.1001e-01,  1.3550e-01],
#         [ 2.1478e-01,  4.9793e-01,  1.3830e-01],
#         [ 5.0789e-02,  4.9282e-01, -4.8851e-01],
#         [-7.8824e-02,  3.9813e-01,  4.9718e-01],
#         [ 4.3622e-01,  3.6230e-01,  1.8949e-01],
#         [-8.5955e-02, -9.7836e-02,  2.5725e-01],
#         [-2.6691e-01,  4.0066e-01,  2.3975e-01],
#         [-3.2434e-01, -3.2835e-02,  2.6271e-02],
#         [ 4.4681e-01, -3.8512e-01, -4.4964e-01],
#         [-4.9077e-01, -1.7938e-01,  4.1816e-01],
#         [ 1.4816e-01, -2.7735e-01, -4.1722e-01],
#         [ 1.0778e-01,  2.9132e-01,  3.3804e-01],
#         [-3.7778e-01, -4.6641e-01,  5.6872e-01],
#         [-4.0338e-01,  3.4110e-01, -2.4774e-02],
#         [ 1.1895e-01,  2.7858e-01, -4.0135e-02],
#         [ 3.4615e-01,  3.3874e-02, -1.3440e-01],
#         [ 2.7207e-01,  1.1176e-01, -1.5754e-01],
#         [-1.0054e-01, -4.0024e-01,  1.3083e-01],
#         [ 4.7844e-01, -5.0384e-01,  2.1797e-01],
#         [-3.0219e-01,  8.3160e-02,  1.1197e-01],
#         [ 4.7103e-01,  4.6320e-01, -1.0860e-01],
#         [ 3.9115e-01, -5.6066e-01, -5.4771e-01],
#         [-4.0218e-01,  2.4949e-01, -9.9419e-02],
#         [ 5.5686e-01, -4.1523e-01, -2.1529e-01],
#         [-8.5780e-02, -3.6724e-01, -4.6862e-01],
#         [ 8.6542e-02, -4.3628e-02, -3.7930e-01],
#         [-3.5181e-02,  4.1098e-01, -1.5650e-01],
#         [-2.8010e-01, -1.2258e-01, -2.9233e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([ 0.3392, -0.0676,  0.3211, -0.1155, -0.1619,  0.5251, -0.1288,  0.2064,
#          0.0868, -0.6112, -0.3304, -0.0647, -0.1194,  0.1181,  0.2438,  0.3304,
#          0.2704,  0.2447,  0.0634, -0.3550, -0.4921,  0.3307,  0.2780, -0.5304,
#          0.3452, -0.5146,  0.1472,  0.2347,  0.0982, -0.5379,  0.3258, -0.0582,
#         -0.2312, -0.0098, -0.1853,  0.1103, -0.5430,  0.2692, -0.1088,  0.3683,
#         -0.1022, -0.1591, -0.4521,  0.4869, -0.3064,  0.0855,  0.4093, -0.3121,
#          0.1299,  0.4032, -0.1672, -0.1366, -0.5081, -0.2706, -0.4001,  0.4441,
#         -0.0102,  0.1336, -0.0675,  0.2166, -0.0840,  0.4400,  0.5121,  0.0026,
#          0.4079, -0.2059], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0873, -0.0195, -0.0606,  ..., -0.0262,  0.1149, -0.1003],
#         [ 0.0947,  0.0575, -0.0667,  ...,  0.0040,  0.0228,  0.0592],
#         [ 0.1583, -0.0099, -0.0207,  ..., -0.0428, -0.0093,  0.0552],
#         ...,
#         [-0.0414,  0.0492,  0.1124,  ..., -0.1509,  0.0773,  0.0805],
#         [ 0.0674, -0.0686, -0.1204,  ..., -0.0756,  0.0318, -0.0314],
#         [ 0.0820, -0.0867, -0.0201,  ...,  0.0635,  0.0909,  0.1181]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-6.7190e-02,  5.0857e-02, -6.0886e-02, -6.8841e-02,  5.4440e-02,
#         -2.7378e-02,  1.9591e-02, -3.9092e-03,  2.7291e-02, -8.2242e-02,
#         -3.6240e-02,  3.0468e-03, -1.0347e-01, -9.6846e-02, -8.0039e-02,
#         -5.6724e-02, -5.1376e-02, -1.1534e-01,  1.0357e-02, -1.3662e-01,
#          1.5152e-01, -5.6677e-02,  2.9142e-02,  2.3898e-02,  9.6004e-02,
#          9.3752e-02,  1.8263e-04, -3.1107e-02,  3.1472e-02,  1.8765e-02,
#         -4.7950e-02,  3.1196e-02,  4.3236e-02, -1.1498e-01, -6.2510e-02,
#         -6.5710e-02,  1.5251e-02, -1.2221e-01, -3.5116e-03, -1.6307e-01,
#         -5.4335e-02,  1.0923e-01,  8.8543e-02, -4.6167e-05,  9.1507e-02,
#         -7.2172e-02, -7.4399e-02, -6.0050e-02,  1.1322e-01, -5.9231e-02,
#         -3.8494e-02,  5.8541e-02,  1.4531e-02, -3.0604e-02,  4.2338e-03,
#          2.2296e-02, -7.0445e-02, -3.7109e-02, -5.5375e-02, -6.9400e-02,
#          2.4298e-02,  3.3955e-02, -6.5531e-03, -1.3046e-01, -3.1256e-02,
#          3.1977e-02, -4.1889e-02, -1.2122e-01,  4.5195e-03, -9.9163e-02,
#          6.2637e-02, -8.8915e-02,  8.6932e-02, -6.0316e-03, -1.2568e-01,
#         -1.1934e-02,  5.2724e-02,  7.8431e-02, -1.0713e-01,  1.6137e-02,
#         -1.1494e-01,  1.0203e-01, -3.3963e-03, -3.9456e-02, -1.1026e-01,
#          9.8439e-02,  6.2919e-02, -7.1842e-02,  5.5712e-02, -1.1066e-01,
#         -1.1016e-01,  5.0132e-02, -6.3693e-02,  1.2336e-01,  3.9105e-02,
#         -9.8456e-03, -1.7194e-03,  7.5350e-02, -1.0851e-01,  4.4660e-02,
#         -9.7707e-02,  8.1962e-02, -4.4100e-02, -7.5631e-02,  3.8937e-03,
#         -7.8049e-02,  1.3895e-01,  6.7897e-03, -9.0964e-02, -6.0723e-02,
#         -3.8648e-02, -7.8081e-02,  1.0854e-01, -4.2285e-02, -7.0650e-02,
#          7.3057e-02,  1.4174e-02,  1.3661e-02,  3.3792e-02, -2.7828e-02,
#         -5.6915e-02, -9.1549e-02,  1.0506e-02, -4.6265e-02, -3.0409e-02,
#         -1.0162e-01,  1.2938e-02,  4.7439e-02, -7.5812e-03,  2.2817e-02,
#          1.1625e-01, -1.4128e-01,  1.0284e-01,  6.3534e-03,  1.0080e-01,
#          1.3292e-02, -8.3533e-02, -3.2160e-02,  7.3365e-02, -1.5122e-01,
#          1.5269e-01, -2.3433e-02, -1.1118e-02, -1.2607e-01,  9.1366e-02,
#         -9.6396e-02,  1.0193e-01,  2.1217e-02,  5.3439e-03, -5.5557e-02,
#          7.4500e-03, -8.2530e-03,  5.8513e-02, -1.2266e-01,  5.8895e-02,
#         -8.0074e-03,  5.1904e-02,  1.3722e-01,  3.6998e-03,  5.1571e-03,
#          1.4235e-02,  1.2329e-01,  1.2539e-02,  8.4832e-03, -2.3336e-02,
#         -8.3123e-02, -4.2803e-02, -6.8731e-02, -1.3958e-03,  1.4646e-02,
#         -7.7777e-02, -1.3160e-01,  8.2007e-02, -8.2963e-02,  2.8125e-03,
#          5.3237e-02, -1.3795e-01,  7.3768e-02,  6.1554e-02,  1.0941e-01,
#         -2.5339e-02,  7.4934e-02, -2.3276e-02, -7.0945e-02,  1.5682e-02,
#         -1.7887e-01, -1.1670e-01, -1.4050e-02,  1.3051e-01, -9.0232e-02,
#          6.7767e-02, -1.6114e-01,  7.2662e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0028,  0.0422, -0.0524,  ...,  0.0286,  0.0162, -0.0446],
#         [-0.0195, -0.0292,  0.0102,  ...,  0.0308, -0.0195, -0.0486],
#         [-0.0217, -0.0434,  0.0426,  ..., -0.0491,  0.0659, -0.0044],
#         ...,
#         [ 0.0163, -0.0542,  0.0471,  ..., -0.0106, -0.0019, -0.0550],
#         [ 0.0558, -0.0143, -0.0409,  ..., -0.0150,  0.0234,  0.0233],
#         [-0.0663, -0.0431,  0.0350,  ..., -0.0612,  0.0283, -0.0155]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0513, -0.0680,  0.0608, -0.0439,  0.0321,  0.0399,  0.0239,  0.0294,
#          0.0328, -0.0746,  0.0094, -0.0688,  0.0567, -0.0016, -0.0845,  0.0270,
#          0.0153, -0.0675,  0.0068, -0.0661,  0.0596,  0.0092, -0.0036,  0.0032,
#          0.0159,  0.0190, -0.0258,  0.0505, -0.0561, -0.0333, -0.0343,  0.0895,
#         -0.0615,  0.0209, -0.0564, -0.0156,  0.0888, -0.0418, -0.0338, -0.0685,
#         -0.0728, -0.0678,  0.0322, -0.0778, -0.0034, -0.0196,  0.0351, -0.0980,
#         -0.0631, -0.0047,  0.0241,  0.0236,  0.0055, -0.0541,  0.0019, -0.0244,
#          0.0302, -0.0198,  0.0120, -0.0711,  0.0347, -0.0753, -0.0091, -0.0387,
#          0.0047,  0.0134, -0.1244,  0.0499,  0.0180, -0.0419, -0.0619, -0.0702,
#         -0.0313, -0.1349,  0.0178, -0.0733, -0.0703, -0.0312, -0.0004, -0.0533,
#          0.0768, -0.0146,  0.0538,  0.0148, -0.0588, -0.0164,  0.0212, -0.0202,
#          0.0485, -0.0038, -0.0265, -0.0488, -0.0229,  0.0165, -0.0247,  0.0126,
#          0.0107,  0.0453,  0.0018, -0.0051, -0.0293, -0.0701, -0.0664,  0.0195,
#          0.0507, -0.0465, -0.0041, -0.0211,  0.1363,  0.0763, -0.0856, -0.0788,
#         -0.0488, -0.0436, -0.0473, -0.0154, -0.0146, -0.0461,  0.0268,  0.0214,
#         -0.0097,  0.0339, -0.0642,  0.0014, -0.0200,  0.1042,  0.0252, -0.0182,
#         -0.0189,  0.0003, -0.0557, -0.0855,  0.1325,  0.0281, -0.0156, -0.0024,
#         -0.0538, -0.0548, -0.0766,  0.0029, -0.0816, -0.0779, -0.0235,  0.0182,
#          0.0476, -0.0653, -0.0522,  0.0020, -0.0149, -0.0721,  0.0698, -0.0189,
#          0.0387,  0.0228,  0.0291,  0.1051,  0.0469, -0.0186, -0.0237,  0.0282,
#          0.0793, -0.0465, -0.0807, -0.0580, -0.0489, -0.0445, -0.0212, -0.0964,
#         -0.0702, -0.0274, -0.0345,  0.1591, -0.0244,  0.0139, -0.0510,  0.0545,
#         -0.0212,  0.0046,  0.0457, -0.1043, -0.0293,  0.0580,  0.0166,  0.0094,
#         -0.0191,  0.0015, -0.0621,  0.0824,  0.0786,  0.0280, -0.0258, -0.0198,
#         -0.0566, -0.0772, -0.0258, -0.1017, -0.0438, -0.0503, -0.0778, -0.0292,
#          0.0090, -0.0034,  0.0020,  0.1365, -0.0732, -0.0048, -0.0587, -0.0118,
#         -0.0834, -0.0136,  0.0248, -0.0977, -0.0403, -0.0629, -0.1594, -0.0888,
#         -0.0973,  0.0210,  0.0362, -0.0766,  0.0415, -0.1538,  0.0166,  0.0273,
#          0.0226,  0.0572,  0.0437, -0.0484, -0.0307, -0.0591, -0.0355,  0.0778,
#          0.0024,  0.0132,  0.0111, -0.0194,  0.0826, -0.0759, -0.0270, -0.0656,
#          0.0409, -0.0611,  0.0380,  0.0280, -0.0566, -0.0027, -0.0267, -0.0262],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0173,  0.0248,  0.0477, -0.0128, -0.0174, -0.0694, -0.0663,  0.0539,
#           0.0474, -0.0002, -0.0184, -0.0006,  0.0426, -0.0102, -0.0292,  0.0191,
#           0.0557,  0.0349,  0.0511, -0.0018,  0.0149, -0.0027,  0.0442,  0.0455,
#           0.0341, -0.0630,  0.0137,  0.0576, -0.0412,  0.0418, -0.0170, -0.0270,
#          -0.0043, -0.0559, -0.0009,  0.0054, -0.0231, -0.0101, -0.0186, -0.0186,
#          -0.0344, -0.0626,  0.0584, -0.0234, -0.0251, -0.0377,  0.0517, -0.0207,
#          -0.0427,  0.0220, -0.0112, -0.0154, -0.0038, -0.0024, -0.0161,  0.0072,
#          -0.0303,  0.0110,  0.0221,  0.0136, -0.0808, -0.0179,  0.0397, -0.0342,
#          -0.0344, -0.0226, -0.0139, -0.0394,  0.0179,  0.0148, -0.0088, -0.0273,
#          -0.0471, -0.0165,  0.0459, -0.0270, -0.0007, -0.0305,  0.0264, -0.0023,
#           0.0374, -0.0285,  0.0689, -0.0519, -0.0300, -0.0080, -0.0328, -0.0333,
#          -0.0822, -0.0376,  0.0243, -0.0012,  0.1173,  0.0418, -0.0036, -0.0009,
#          -0.0247,  0.0646, -0.0276,  0.0253,  0.0399, -0.0648, -0.0148,  0.0553,
#           0.0088, -0.0791,  0.0062, -0.0227,  0.0478, -0.0469, -0.0482, -0.0135,
#           0.0163,  0.0009,  0.0224, -0.0542,  0.0279,  0.0108,  0.0611, -0.0737,
#           0.0596, -0.0167, -0.0260,  0.0184,  0.0486, -0.0321, -0.0463, -0.0390,
#          -0.0049,  0.0119,  0.0290, -0.0330,  0.1070, -0.0389, -0.0117,  0.0193,
#          -0.0204, -0.0367,  0.0098,  0.0070, -0.0292, -0.0178, -0.0046,  0.0019,
#          -0.0137,  0.0012, -0.0407,  0.0664, -0.1055, -0.0372,  0.0536,  0.0552,
#           0.0688, -0.0033, -0.0533,  0.0114, -0.0348, -0.0444, -0.0041,  0.0601,
#           0.0509, -0.0354, -0.0291, -0.0066, -0.0141, -0.0413,  0.0431, -0.0012,
#          -0.0114,  0.0206,  0.0159,  0.0270,  0.0314, -0.0607, -0.0107,  0.0389,
#           0.0155, -0.0117,  0.0225, -0.0035, -0.0171, -0.0322, -0.0264,  0.0068,
#          -0.0186,  0.0198, -0.0322, -0.0347,  0.0283,  0.0287,  0.0056, -0.0301,
#           0.0498, -0.0392, -0.0425,  0.0117,  0.0433, -0.0491,  0.0034, -0.0329,
#           0.0044, -0.0545,  0.0294,  0.0418, -0.0266,  0.0482,  0.0045, -0.0587,
#          -0.0509, -0.0644,  0.0170, -0.0058, -0.0204,  0.0033, -0.0117, -0.0010,
#           0.0155, -0.0374,  0.0543, -0.0115,  0.0474, -0.0185,  0.0139,  0.0263,
#           0.0345,  0.0268,  0.0475, -0.0315,  0.0162,  0.0005,  0.0631,  0.0706,
#          -0.0196, -0.0318, -0.0061, -0.0019,  0.0344,  0.0146,  0.0048, -0.0079,
#           0.0560, -0.0195,  0.0531, -0.0658,  0.0424, -0.0667,  0.0141, -0.0115]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.0520], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 4.0703e-01, -3.3209e-01,  2.4541e-01],
#         [ 3.9574e-01,  4.4300e-01, -4.7536e-01],
#         [ 5.3288e-01,  3.8867e-01, -4.8479e-01],
#         [ 8.6288e-02,  2.2755e-01, -5.6166e-01],
#         [ 4.5703e-01,  4.7261e-01,  3.9110e-01],
#         [-1.0874e-01,  4.3502e-01, -2.9330e-01],
#         [-4.7408e-01,  2.2947e-01, -1.5686e-01],
#         [ 3.7815e-01, -3.5651e-01, -4.3197e-01],
#         [-1.8735e-02, -3.5852e-01, -4.3461e-01],
#         [ 1.5751e-02,  1.7131e-01,  3.0135e-02],
#         [-5.5786e-01, -1.5186e-01, -5.5708e-02],
#         [-3.2261e-01, -1.0598e-01,  7.4610e-02],
#         [-3.3268e-01,  1.2492e-01,  3.4374e-02],
#         [ 4.7166e-01,  1.1620e-01, -1.9587e-01],
#         [-3.8253e-01,  2.6799e-01,  3.7434e-01],
#         [-2.7552e-01, -2.0934e-01,  3.6939e-04],
#         [ 2.5972e-01, -5.0087e-01, -1.0369e-01],
#         [-3.9376e-01,  5.0110e-01,  9.8127e-02],
#         [ 1.8719e-01, -8.1313e-02, -2.8015e-01],
#         [-1.1466e-01, -4.5091e-01, -3.6362e-01],
#         [-3.8132e-01,  8.7239e-02,  8.6272e-02],
#         [-4.3027e-01,  1.3524e-02,  2.1827e-01],
#         [-2.0852e-01,  1.6656e-01,  3.2412e-01],
#         [ 3.8629e-01,  3.0472e-01,  4.1659e-01],
#         [ 2.0792e-01,  9.1386e-02, -5.2300e-01],
#         [-3.8574e-01,  3.0005e-01,  2.2964e-01],
#         [ 3.2233e-01,  3.9980e-01, -4.8669e-01],
#         [-8.3361e-02, -1.8442e-02,  3.5311e-02],
#         [-3.4851e-01,  3.7308e-01, -1.7108e-01],
#         [-9.7168e-02, -3.8977e-01,  9.4209e-02],
#         [ 1.7467e-01, -1.8738e-01,  1.4916e-01],
#         [-3.3370e-01,  1.6417e-01,  1.6782e-02],
#         [-2.3076e-02, -5.5705e-01,  1.9449e-01],
#         [-5.4737e-01, -5.6938e-02,  4.8260e-01],
#         [-2.0278e-01,  4.4483e-01, -6.6182e-02],
#         [ 4.3948e-01,  1.9841e-01,  3.4938e-01],
#         [ 4.5413e-01, -1.9597e-01,  5.7271e-01],
#         [ 4.6930e-01,  2.7708e-01, -2.8002e-01],
#         [-5.2297e-01,  2.1001e-01,  1.3550e-01],
#         [ 2.1478e-01,  4.9793e-01,  1.3830e-01],
#         [ 5.0789e-02,  4.9282e-01, -4.8851e-01],
#         [-7.8824e-02,  3.9813e-01,  4.9718e-01],
#         [ 4.3622e-01,  3.6230e-01,  1.8949e-01],
#         [-8.5955e-02, -9.7836e-02,  2.5725e-01],
#         [-2.6691e-01,  4.0066e-01,  2.3975e-01],
#         [-3.2434e-01, -3.2835e-02,  2.6271e-02],
#         [ 4.4681e-01, -3.8512e-01, -4.4964e-01],
#         [-4.9077e-01, -1.7938e-01,  4.1816e-01],
#         [ 1.4816e-01, -2.7735e-01, -4.1722e-01],
#         [ 1.0778e-01,  2.9132e-01,  3.3804e-01],
#         [-3.7778e-01, -4.6641e-01,  5.6872e-01],
#         [-4.0338e-01,  3.4110e-01, -2.4774e-02],
#         [ 1.1895e-01,  2.7858e-01, -4.0135e-02],
#         [ 3.4615e-01,  3.3874e-02, -1.3440e-01],
#         [ 2.7207e-01,  1.1176e-01, -1.5754e-01],
#         [-1.0054e-01, -4.0024e-01,  1.3083e-01],
#         [ 4.7844e-01, -5.0384e-01,  2.1797e-01],
#         [-3.0219e-01,  8.3160e-02,  1.1197e-01],
#         [ 4.7103e-01,  4.6320e-01, -1.0860e-01],
#         [ 3.9115e-01, -5.6066e-01, -5.4771e-01],
#         [-4.0218e-01,  2.4949e-01, -9.9419e-02],
#         [ 5.5686e-01, -4.1523e-01, -2.1529e-01],
#         [-8.5780e-02, -3.6724e-01, -4.6862e-01],
#         [ 8.6542e-02, -4.3628e-02, -3.7930e-01],
#         [-3.5181e-02,  4.1098e-01, -1.5650e-01],
#         [-2.8010e-01, -1.2258e-01, -2.9233e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([ 0.3392, -0.0676,  0.3211, -0.1155, -0.1619,  0.5251, -0.1288,  0.2064,
#          0.0868, -0.6112, -0.3304, -0.0647, -0.1194,  0.1181,  0.2438,  0.3304,
#          0.2704,  0.2447,  0.0634, -0.3550, -0.4921,  0.3307,  0.2780, -0.5304,
#          0.3452, -0.5146,  0.1472,  0.2347,  0.0982, -0.5379,  0.3258, -0.0582,
#         -0.2312, -0.0098, -0.1853,  0.1103, -0.5430,  0.2692, -0.1088,  0.3683,
#         -0.1022, -0.1591, -0.4521,  0.4869, -0.3064,  0.0855,  0.4093, -0.3121,
#          0.1299,  0.4032, -0.1672, -0.1366, -0.5081, -0.2706, -0.4001,  0.4441,
#         -0.0102,  0.1336, -0.0675,  0.2166, -0.0840,  0.4400,  0.5121,  0.0026,
#          0.4079, -0.2059], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0873, -0.0195, -0.0606,  ..., -0.0262,  0.1149, -0.1003],
#         [ 0.0947,  0.0575, -0.0667,  ...,  0.0040,  0.0228,  0.0592],
#         [ 0.1583, -0.0099, -0.0207,  ..., -0.0428, -0.0093,  0.0552],
#         ...,
#         [-0.0414,  0.0492,  0.1124,  ..., -0.1509,  0.0773,  0.0805],
#         [ 0.0674, -0.0686, -0.1204,  ..., -0.0756,  0.0318, -0.0314],
#         [ 0.0820, -0.0867, -0.0201,  ...,  0.0635,  0.0909,  0.1181]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-6.7190e-02,  5.0857e-02, -6.0886e-02, -6.8841e-02,  5.4440e-02,
#         -2.7378e-02,  1.9591e-02, -3.9092e-03,  2.7291e-02, -8.2242e-02,
#         -3.6240e-02,  3.0468e-03, -1.0347e-01, -9.6846e-02, -8.0039e-02,
#         -5.6724e-02, -5.1376e-02, -1.1534e-01,  1.0357e-02, -1.3662e-01,
#          1.5152e-01, -5.6677e-02,  2.9142e-02,  2.3898e-02,  9.6004e-02,
#          9.3752e-02,  1.8263e-04, -3.1107e-02,  3.1472e-02,  1.8765e-02,
#         -4.7950e-02,  3.1196e-02,  4.3236e-02, -1.1498e-01, -6.2510e-02,
#         -6.5710e-02,  1.5251e-02, -1.2221e-01, -3.5116e-03, -1.6307e-01,
#         -5.4335e-02,  1.0923e-01,  8.8543e-02, -4.6167e-05,  9.1507e-02,
#         -7.2172e-02, -7.4399e-02, -6.0050e-02,  1.1322e-01, -5.9231e-02,
#         -3.8494e-02,  5.8541e-02,  1.4531e-02, -3.0604e-02,  4.2338e-03,
#          2.2296e-02, -7.0445e-02, -3.7109e-02, -5.5375e-02, -6.9400e-02,
#          2.4298e-02,  3.3955e-02, -6.5531e-03, -1.3046e-01, -3.1256e-02,
#          3.1977e-02, -4.1889e-02, -1.2122e-01,  4.5195e-03, -9.9163e-02,
#          6.2637e-02, -8.8915e-02,  8.6932e-02, -6.0316e-03, -1.2568e-01,
#         -1.1934e-02,  5.2724e-02,  7.8431e-02, -1.0713e-01,  1.6137e-02,
#         -1.1494e-01,  1.0203e-01, -3.3963e-03, -3.9456e-02, -1.1026e-01,
#          9.8439e-02,  6.2919e-02, -7.1842e-02,  5.5712e-02, -1.1066e-01,
#         -1.1016e-01,  5.0132e-02, -6.3693e-02,  1.2336e-01,  3.9105e-02,
#         -9.8456e-03, -1.7194e-03,  7.5350e-02, -1.0851e-01,  4.4660e-02,
#         -9.7707e-02,  8.1962e-02, -4.4100e-02, -7.5631e-02,  3.8937e-03,
#         -7.8049e-02,  1.3895e-01,  6.7897e-03, -9.0964e-02, -6.0723e-02,
#         -3.8648e-02, -7.8081e-02,  1.0854e-01, -4.2285e-02, -7.0650e-02,
#          7.3057e-02,  1.4174e-02,  1.3661e-02,  3.3792e-02, -2.7828e-02,
#         -5.6915e-02, -9.1549e-02,  1.0506e-02, -4.6265e-02, -3.0409e-02,
#         -1.0162e-01,  1.2938e-02,  4.7439e-02, -7.5812e-03,  2.2817e-02,
#          1.1625e-01, -1.4128e-01,  1.0284e-01,  6.3534e-03,  1.0080e-01,
#          1.3292e-02, -8.3533e-02, -3.2160e-02,  7.3365e-02, -1.5122e-01,
#          1.5269e-01, -2.3433e-02, -1.1118e-02, -1.2607e-01,  9.1366e-02,
#         -9.6396e-02,  1.0193e-01,  2.1217e-02,  5.3439e-03, -5.5557e-02,
#          7.4500e-03, -8.2530e-03,  5.8513e-02, -1.2266e-01,  5.8895e-02,
#         -8.0074e-03,  5.1904e-02,  1.3722e-01,  3.6998e-03,  5.1571e-03,
#          1.4235e-02,  1.2329e-01,  1.2539e-02,  8.4832e-03, -2.3336e-02,
#         -8.3123e-02, -4.2803e-02, -6.8731e-02, -1.3958e-03,  1.4646e-02,
#         -7.7777e-02, -1.3160e-01,  8.2007e-02, -8.2963e-02,  2.8125e-03,
#          5.3237e-02, -1.3795e-01,  7.3768e-02,  6.1554e-02,  1.0941e-01,
#         -2.5339e-02,  7.4934e-02, -2.3276e-02, -7.0945e-02,  1.5682e-02,
#         -1.7887e-01, -1.1670e-01, -1.4050e-02,  1.3051e-01, -9.0232e-02,
#          6.7767e-02, -1.6114e-01,  7.2662e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0028,  0.0422, -0.0524,  ...,  0.0286,  0.0162, -0.0446],
#         [-0.0195, -0.0292,  0.0102,  ...,  0.0308, -0.0195, -0.0486],
#         [-0.0217, -0.0434,  0.0426,  ..., -0.0491,  0.0659, -0.0044],
#         ...,
#         [ 0.0163, -0.0542,  0.0471,  ..., -0.0106, -0.0019, -0.0550],
#         [ 0.0558, -0.0143, -0.0409,  ..., -0.0150,  0.0234,  0.0233],
#         [-0.0663, -0.0431,  0.0350,  ..., -0.0612,  0.0283, -0.0155]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0513, -0.0680,  0.0608, -0.0439,  0.0321,  0.0399,  0.0239,  0.0294,
#          0.0328, -0.0746,  0.0094, -0.0688,  0.0567, -0.0016, -0.0845,  0.0270,
#          0.0153, -0.0675,  0.0068, -0.0661,  0.0596,  0.0092, -0.0036,  0.0032,
#          0.0159,  0.0190, -0.0258,  0.0505, -0.0561, -0.0333, -0.0343,  0.0895,
#         -0.0615,  0.0209, -0.0564, -0.0156,  0.0888, -0.0418, -0.0338, -0.0685,
#         -0.0728, -0.0678,  0.0322, -0.0778, -0.0034, -0.0196,  0.0351, -0.0980,
#         -0.0631, -0.0047,  0.0241,  0.0236,  0.0055, -0.0541,  0.0019, -0.0244,
#          0.0302, -0.0198,  0.0120, -0.0711,  0.0347, -0.0753, -0.0091, -0.0387,
#          0.0047,  0.0134, -0.1244,  0.0499,  0.0180, -0.0419, -0.0619, -0.0702,
#         -0.0313, -0.1349,  0.0178, -0.0733, -0.0703, -0.0312, -0.0004, -0.0533,
#          0.0768, -0.0146,  0.0538,  0.0148, -0.0588, -0.0164,  0.0212, -0.0202,
#          0.0485, -0.0038, -0.0265, -0.0488, -0.0229,  0.0165, -0.0247,  0.0126,
#          0.0107,  0.0453,  0.0018, -0.0051, -0.0293, -0.0701, -0.0664,  0.0195,
#          0.0507, -0.0465, -0.0041, -0.0211,  0.1363,  0.0763, -0.0856, -0.0788,
#         -0.0488, -0.0436, -0.0473, -0.0154, -0.0146, -0.0461,  0.0268,  0.0214,
#         -0.0097,  0.0339, -0.0642,  0.0014, -0.0200,  0.1042,  0.0252, -0.0182,
#         -0.0189,  0.0003, -0.0557, -0.0855,  0.1325,  0.0281, -0.0156, -0.0024,
#         -0.0538, -0.0548, -0.0766,  0.0029, -0.0816, -0.0779, -0.0235,  0.0182,
#          0.0476, -0.0653, -0.0522,  0.0020, -0.0149, -0.0721,  0.0698, -0.0189,
#          0.0387,  0.0228,  0.0291,  0.1051,  0.0469, -0.0186, -0.0237,  0.0282,
#          0.0793, -0.0465, -0.0807, -0.0580, -0.0489, -0.0445, -0.0212, -0.0964,
#         -0.0702, -0.0274, -0.0345,  0.1591, -0.0244,  0.0139, -0.0510,  0.0545,
#         -0.0212,  0.0046,  0.0457, -0.1043, -0.0293,  0.0580,  0.0166,  0.0094,
#         -0.0191,  0.0015, -0.0621,  0.0824,  0.0786,  0.0280, -0.0258, -0.0198,
#         -0.0566, -0.0772, -0.0258, -0.1017, -0.0438, -0.0503, -0.0778, -0.0292,
#          0.0090, -0.0034,  0.0020,  0.1365, -0.0732, -0.0048, -0.0587, -0.0118,
#         -0.0834, -0.0136,  0.0248, -0.0977, -0.0403, -0.0629, -0.1594, -0.0888,
#         -0.0973,  0.0210,  0.0362, -0.0766,  0.0415, -0.1538,  0.0166,  0.0273,
#          0.0226,  0.0572,  0.0437, -0.0484, -0.0307, -0.0591, -0.0355,  0.0778,
#          0.0024,  0.0132,  0.0111, -0.0194,  0.0826, -0.0759, -0.0270, -0.0656,
#          0.0409, -0.0611,  0.0380,  0.0280, -0.0566, -0.0027, -0.0267, -0.0262],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0173,  0.0248,  0.0477, -0.0128, -0.0174, -0.0694, -0.0663,  0.0539,
#           0.0474, -0.0002, -0.0184, -0.0006,  0.0426, -0.0102, -0.0292,  0.0191,
#           0.0557,  0.0349,  0.0511, -0.0018,  0.0149, -0.0027,  0.0442,  0.0455,
#           0.0341, -0.0630,  0.0137,  0.0576, -0.0412,  0.0418, -0.0170, -0.0270,
#          -0.0043, -0.0559, -0.0009,  0.0054, -0.0231, -0.0101, -0.0186, -0.0186,
#          -0.0344, -0.0626,  0.0584, -0.0234, -0.0251, -0.0377,  0.0517, -0.0207,
#          -0.0427,  0.0220, -0.0112, -0.0154, -0.0038, -0.0024, -0.0161,  0.0072,
#          -0.0303,  0.0110,  0.0221,  0.0136, -0.0808, -0.0179,  0.0397, -0.0342,
#          -0.0344, -0.0226, -0.0139, -0.0394,  0.0179,  0.0148, -0.0088, -0.0273,
#          -0.0471, -0.0165,  0.0459, -0.0270, -0.0007, -0.0305,  0.0264, -0.0023,
#           0.0374, -0.0285,  0.0689, -0.0519, -0.0300, -0.0080, -0.0328, -0.0333,
#          -0.0822, -0.0376,  0.0243, -0.0012,  0.1173,  0.0418, -0.0036, -0.0009,
#          -0.0247,  0.0646, -0.0276,  0.0253,  0.0399, -0.0648, -0.0148,  0.0553,
#           0.0088, -0.0791,  0.0062, -0.0227,  0.0478, -0.0469, -0.0482, -0.0135,
#           0.0163,  0.0009,  0.0224, -0.0542,  0.0279,  0.0108,  0.0611, -0.0737,
#           0.0596, -0.0167, -0.0260,  0.0184,  0.0486, -0.0321, -0.0463, -0.0390,
#          -0.0049,  0.0119,  0.0290, -0.0330,  0.1070, -0.0389, -0.0117,  0.0193,
#          -0.0204, -0.0367,  0.0098,  0.0070, -0.0292, -0.0178, -0.0046,  0.0019,
#          -0.0137,  0.0012, -0.0407,  0.0664, -0.1055, -0.0372,  0.0536,  0.0552,
#           0.0688, -0.0033, -0.0533,  0.0114, -0.0348, -0.0444, -0.0041,  0.0601,
#           0.0509, -0.0354, -0.0291, -0.0066, -0.0141, -0.0413,  0.0431, -0.0012,
#          -0.0114,  0.0206,  0.0159,  0.0270,  0.0314, -0.0607, -0.0107,  0.0389,
#           0.0155, -0.0117,  0.0225, -0.0035, -0.0171, -0.0322, -0.0264,  0.0068,
#          -0.0186,  0.0198, -0.0322, -0.0347,  0.0283,  0.0287,  0.0056, -0.0301,
#           0.0498, -0.0392, -0.0425,  0.0117,  0.0433, -0.0491,  0.0034, -0.0329,
#           0.0044, -0.0545,  0.0294,  0.0418, -0.0266,  0.0482,  0.0045, -0.0587,
#          -0.0509, -0.0644,  0.0170, -0.0058, -0.0204,  0.0033, -0.0117, -0.0010,
#           0.0155, -0.0374,  0.0543, -0.0115,  0.0474, -0.0185,  0.0139,  0.0263,
#           0.0345,  0.0268,  0.0475, -0.0315,  0.0162,  0.0005,  0.0631,  0.0706,
#          -0.0196, -0.0318, -0.0061, -0.0019,  0.0344,  0.0146,  0.0048, -0.0079,
#           0.0560, -0.0195,  0.0531, -0.0658,  0.0424, -0.0667,  0.0141, -0.0115]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.0520], device='cuda:0', requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=66, bias=True)
#     (1): Linear(in_features=66, out_features=193, bias=True)
#     (2): Linear(in_features=193, out_features=248, bias=True)
#     (3): Linear(in_features=248, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[ 8.4823,  1.2874,  3.8433],
#         [ 6.3628,  4.5830,  6.8709],
#         [ 9.5007, 10.5686, 14.5369],
#         [ 2.7702,  9.1947,  8.4208],
#         [ 8.1549,  8.1288,  4.1824],
#         [ 2.8599,  0.6266,  5.7706],
#         [ 9.4994, 24.8554, 24.3957],
#         [ 5.9511,  6.8335,  5.0241],
#         [ 1.0827,  0.7347,  1.1826],
#         [ 3.3039,  4.2094,  4.9122],
#         [ 5.1887, 10.3858,  9.6000],
#         [ 8.6661, 16.7210, 16.3864],
#         [ 6.5375,  1.9848,  7.9297],
#         [ 9.7648, 31.8522, 29.5890],
#         [12.9340, 11.8892,  5.2417],
#         [ 9.3644,  3.6599,  3.9022],
#         [ 3.9849, 10.0192,  8.5279],
#         [ 0.7702,  1.3431,  0.9888],
#         [ 9.5696,  0.1444,  2.6998],
#         [ 7.7714, 11.4869, 16.6507]], device='cuda:0')

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5118], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.9178], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.7084], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8224], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.5924], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8309], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.6044], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.5020], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.6911], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.3360], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.0112], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.8099], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.1734], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([6.8929], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.4184], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.2030], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7629], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.1825], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8001], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.7673], device='cuda:0', grad_fn=<ReluBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=66, bias=True)
#     (1): Linear(in_features=66, out_features=193, bias=True)
#     (2): Linear(in_features=193, out_features=248, bias=True)
#     (3): Linear(in_features=248, out_features=1, bias=True)
#   )
# )

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5118], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.9178], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.7084], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8224], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.5924], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8309], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.6044], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.5020], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.6911], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.3360], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.0112], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.8099], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.1734], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([6.8929], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.4184], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.2030], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7629], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.1825], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8001], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.7673], device='cuda:0', grad_fn=<ReluBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[-0.8978, -0.1536, -1.5254]], device='cuda:0')
# tensor([[2.0342, 2.2249, 4.1557]], device='cuda:0')
# tensor([[2.4340]], device='cuda:0', grad_fn=<ReluBackward0>)
