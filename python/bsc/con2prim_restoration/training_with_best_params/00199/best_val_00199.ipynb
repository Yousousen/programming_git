# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# **training with found best parameters:**
# ```
# [I 2023-05-16 00:22:24,802] Trial 328 finished with value: 0.0019935011098627 and parameters: {'n_layers': 5, 'n_units_0': 617, 'n_units_1': 858, 'n_units_2': 720, 'n_units_3': 989, 'n_units_4': 613, 'hidden_activation': 'ReLU', 'output_activation': 'ReLU', 'loss': 'MSE', 'optimizer': 'Adagrad', 'lr': 0.0016884179922857007, 'batch_size': 16, 'n_epochs': 132, 'scheduler': 'CosineAnnealingLR', 'T_max': 8}. Best is trial 328 with value: 0.0019935011098627.
# ```

# %%
#%%script echo skipping

# !jupyter nbconvert best_val_00199.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# C:\Users\bvptr\anaconda3\lib\site-packages\traitlets\traitlets.py:2544: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'remove_cell' instead of "'remove_cell'" if you require traitlets >=5.
#   warn(
# [NbConvertApp] Converting notebook best_val_00199.ipynb to script
# [NbConvertApp] Writing 51068 bytes to best_val_00199.py

# %% [markdown]
# Next some cells for working on google colab,

# %%
# %%script echo skipping
#
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Couldn't find program: 'echo'

# %%
# %%script echo skipping
#
# !pip install optuna tensorboard tensorboardX
# Out:
# Couldn't find program: 'echo'

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.
#
# NOTE: Some subparameters still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 5
N_UNITS_NO_OPT = [617, 858, 720, 989, 613]
HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "MSE"
OPTIMIZER_NAME_NO_OPT = "Adagrad"
LR_NO_OPT = 0.0016884179922857007
BATCH_SIZE_NO_OPT = 16
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "CosineAnnealingLR"

c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)
# Out:
# tensor([1.9220, 2.2925, 1.3112,  ..., 1.3882, 1.4931, 5.2596], device='cuda:0')

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
if ZSCORE_NORMALIZATION:
    # Computing the mean and standard deviation of each input variable from the training set
    D_mean = torch.mean(x_train[:, 0])
    D_std = torch.std(x_train[:, 0])
    Sx_mean = torch.mean(x_train[:, 1])
    Sx_std = torch.std(x_train[:, 1])
    tau_mean = torch.mean(x_train[:, 2])
    tau_std = torch.std(x_train[:, 2])

    # Applying z-score normalization to both train and test sets using the statistics from the training set
    x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
    x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
    x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
    x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
    x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
    x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
print(torch.mean(x_train[:, 0]))
print(torch.std(x_train[:, 0]))
print(torch.mean(x_train[:, 1]))
print(torch.std(x_train[:, 1]))
print(torch.mean(x_train[:, 2]))
print(torch.std(x_train[:, 2]))

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()
# Out:
# tensor(5.6259, device='cuda:0')
# tensor(3.3305, device='cuda:0')
# tensor(6.8267, device='cuda:0')
# tensor(8.0801, device='cuda:0')
# tensor(8.0068, device='cuda:0')
# tensor(7.8406, device='cuda:0')

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=8)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                    )
        else:
            scheduler = None


    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: MSELoss()
# batch_size: 16
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x7f1390ffca00>
# loss_name: MSE
# optimizer_name: Adagrad
# scheduler_name: CosineAnnealingLR
# n_units: [617, 858, 720, 989, 613]
# n_layers: 5
# hidden_activation: ReLU()
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.0386, Test Loss: 0.0000, Train L1 Norm: 0.0667, Test L1 Norm: 0.0175, Train Linf Norm: 0.8310, Test Linf Norm: 0.2204
# Epoch 2: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0146, Test L1 Norm: 0.0087, Train Linf Norm: 0.1879, Test Linf Norm: 0.1062
# Epoch 3: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0103, Test L1 Norm: 0.0054, Train Linf Norm: 0.1340, Test Linf Norm: 0.0581
# Epoch 4: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0070, Train Linf Norm: 0.0940, Test Linf Norm: 0.0863
# Epoch 5: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0048, Train Linf Norm: 0.0907, Test Linf Norm: 0.0546
# Epoch 6: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0049, Train Linf Norm: 0.0784, Test Linf Norm: 0.0534
# Epoch 7: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0040, Train Linf Norm: 0.0728, Test Linf Norm: 0.0425
# Epoch 8: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0040, Train Linf Norm: 0.0689, Test Linf Norm: 0.0419
# Epoch 9: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0040, Train Linf Norm: 0.0669, Test Linf Norm: 0.0419
# Epoch 10: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0040, Train Linf Norm: 0.0675, Test Linf Norm: 0.0424
# Epoch 11: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0038, Train Linf Norm: 0.0709, Test Linf Norm: 0.0402
# Epoch 12: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0056, Train Linf Norm: 0.0686, Test Linf Norm: 0.0690
# Epoch 13: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0044, Train Linf Norm: 0.0702, Test Linf Norm: 0.0479
# Epoch 14: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0042, Train Linf Norm: 0.0688, Test Linf Norm: 0.0479
# Epoch 15: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0062, Test L1 Norm: 0.0046, Train Linf Norm: 0.0777, Test Linf Norm: 0.0513
# Epoch 16: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0050, Train Linf Norm: 0.0766, Test Linf Norm: 0.0590
# Epoch 17: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0037, Train Linf Norm: 0.0915, Test Linf Norm: 0.0404
# Epoch 18: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0057, Train Linf Norm: 0.0735, Test Linf Norm: 0.0614
# Epoch 19: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.0593, Test Linf Norm: 0.0545
# Epoch 20: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0034, Train Linf Norm: 0.0505, Test Linf Norm: 0.0372
# Epoch 21: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0047, Train Linf Norm: 0.0485, Test Linf Norm: 0.0578
# Epoch 22: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0030, Train Linf Norm: 0.0477, Test Linf Norm: 0.0319
# Epoch 23: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0034, Train Linf Norm: 0.0435, Test Linf Norm: 0.0388
# Epoch 24: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0029, Train Linf Norm: 0.0431, Test Linf Norm: 0.0308
# Epoch 25: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0035, Test L1 Norm: 0.0029, Train Linf Norm: 0.0420, Test Linf Norm: 0.0308
# Epoch 26: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0031, Train Linf Norm: 0.0426, Test Linf Norm: 0.0329
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0034, Train Linf Norm: 0.0450, Test Linf Norm: 0.0389
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0032, Train Linf Norm: 0.0438, Test Linf Norm: 0.0345
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0029, Train Linf Norm: 0.0450, Test Linf Norm: 0.0313
# Epoch 30: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.0452, Test Linf Norm: 0.0493
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0035, Train Linf Norm: 0.0537, Test Linf Norm: 0.0404
# Epoch 32: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0028, Train Linf Norm: 0.0485, Test Linf Norm: 0.0293
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0041, Train Linf Norm: 0.0546, Test Linf Norm: 0.0468
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0071, Train Linf Norm: 0.0443, Test Linf Norm: 0.0935
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0041, Train Linf Norm: 0.0490, Test Linf Norm: 0.0497
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0026, Train Linf Norm: 0.0477, Test Linf Norm: 0.0267
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0034, Test L1 Norm: 0.0029, Train Linf Norm: 0.0409, Test Linf Norm: 0.0319
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0033, Test L1 Norm: 0.0026, Train Linf Norm: 0.0388, Test Linf Norm: 0.0286
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0027, Train Linf Norm: 0.0387, Test Linf Norm: 0.0297
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0025, Train Linf Norm: 0.0371, Test Linf Norm: 0.0272
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0030, Test L1 Norm: 0.0025, Train Linf Norm: 0.0359, Test Linf Norm: 0.0272
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0025, Train Linf Norm: 0.0373, Test Linf Norm: 0.0271
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0026, Train Linf Norm: 0.0370, Test Linf Norm: 0.0286
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0029, Train Linf Norm: 0.0377, Test Linf Norm: 0.0320
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0034, Test L1 Norm: 0.0028, Train Linf Norm: 0.0412, Test Linf Norm: 0.0315
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0033, Test L1 Norm: 0.0029, Train Linf Norm: 0.0388, Test Linf Norm: 0.0332
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0035, Train Linf Norm: 0.0422, Test Linf Norm: 0.0395
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0052, Train Linf Norm: 0.0455, Test Linf Norm: 0.0678
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0036, Train Linf Norm: 0.0503, Test Linf Norm: 0.0428
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0028, Train Linf Norm: 0.0428, Test Linf Norm: 0.0307
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0034, Test L1 Norm: 0.0034, Train Linf Norm: 0.0411, Test Linf Norm: 0.0403
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0033, Test L1 Norm: 0.0032, Train Linf Norm: 0.0400, Test Linf Norm: 0.0366
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0027, Train Linf Norm: 0.0368, Test Linf Norm: 0.0301
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0030, Test L1 Norm: 0.0026, Train Linf Norm: 0.0353, Test Linf Norm: 0.0279
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0026, Train Linf Norm: 0.0339, Test Linf Norm: 0.0287
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0025, Train Linf Norm: 0.0337, Test Linf Norm: 0.0268
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0025, Train Linf Norm: 0.0325, Test Linf Norm: 0.0268
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0025, Train Linf Norm: 0.0330, Test Linf Norm: 0.0270
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0026, Train Linf Norm: 0.0339, Test Linf Norm: 0.0276
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0027, Train Linf Norm: 0.0349, Test Linf Norm: 0.0292
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0030, Test L1 Norm: 0.0030, Train Linf Norm: 0.0354, Test Linf Norm: 0.0355
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0027, Train Linf Norm: 0.0379, Test Linf Norm: 0.0297
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0026, Train Linf Norm: 0.0363, Test Linf Norm: 0.0285
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0034, Test L1 Norm: 0.0027, Train Linf Norm: 0.0391, Test Linf Norm: 0.0304
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0032, Train Linf Norm: 0.0438, Test Linf Norm: 0.0376
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0039, Train Linf Norm: 0.0441, Test Linf Norm: 0.0460
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0035, Train Linf Norm: 0.0378, Test Linf Norm: 0.0419
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0028, Train Linf Norm: 0.0343, Test Linf Norm: 0.0324
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0024, Train Linf Norm: 0.0352, Test Linf Norm: 0.0276
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0025, Train Linf Norm: 0.0348, Test Linf Norm: 0.0278
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0026, Train Linf Norm: 0.0313, Test Linf Norm: 0.0289
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0025, Train Linf Norm: 0.0327, Test Linf Norm: 0.0278
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0025, Train Linf Norm: 0.0320, Test Linf Norm: 0.0278
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0024, Train Linf Norm: 0.0320, Test Linf Norm: 0.0274
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0024, Train Linf Norm: 0.0339, Test Linf Norm: 0.0258
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0024, Train Linf Norm: 0.0333, Test Linf Norm: 0.0278
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0025, Train Linf Norm: 0.0330, Test Linf Norm: 0.0272
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0025, Train Linf Norm: 0.0350, Test Linf Norm: 0.0284
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0033, Test L1 Norm: 0.0026, Train Linf Norm: 0.0406, Test Linf Norm: 0.0282
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0036, Test L1 Norm: 0.0035, Train Linf Norm: 0.0443, Test Linf Norm: 0.0419
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0033, Test L1 Norm: 0.0036, Train Linf Norm: 0.0388, Test Linf Norm: 0.0421
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0027, Train Linf Norm: 0.0365, Test Linf Norm: 0.0297
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0025, Train Linf Norm: 0.0388, Test Linf Norm: 0.0270
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0028, Train Linf Norm: 0.0338, Test Linf Norm: 0.0309
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0026, Train Linf Norm: 0.0302, Test Linf Norm: 0.0286
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0025, Train Linf Norm: 0.0311, Test Linf Norm: 0.0281
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0024, Train Linf Norm: 0.0302, Test Linf Norm: 0.0253
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0023, Train Linf Norm: 0.0295, Test Linf Norm: 0.0256
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0023, Train Linf Norm: 0.0298, Test Linf Norm: 0.0256
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0024, Train Linf Norm: 0.0299, Test Linf Norm: 0.0264
# Epoch 91: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0024, Train Linf Norm: 0.0309, Test Linf Norm: 0.0269
# Epoch 92: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0025, Train Linf Norm: 0.0312, Test Linf Norm: 0.0284
# Epoch 93: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0025, Train Linf Norm: 0.0316, Test Linf Norm: 0.0282
# Epoch 94: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0030, Train Linf Norm: 0.0316, Test Linf Norm: 0.0366
# Epoch 95: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0027, Train Linf Norm: 0.0398, Test Linf Norm: 0.0303
# Epoch 96: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0035, Train Linf Norm: 0.0387, Test Linf Norm: 0.0441
# Epoch 97: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0027, Train Linf Norm: 0.0378, Test Linf Norm: 0.0298
# Epoch 98: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0035, Test L1 Norm: 0.0027, Train Linf Norm: 0.0434, Test Linf Norm: 0.0297
# Epoch 99: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0031, Train Linf Norm: 0.0353, Test Linf Norm: 0.0367
# Epoch 100: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0028, Train Linf Norm: 0.0302, Test Linf Norm: 0.0331
# Epoch 101: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0024, Train Linf Norm: 0.0304, Test Linf Norm: 0.0275
# Epoch 102: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0022, Train Linf Norm: 0.0310, Test Linf Norm: 0.0247
# Epoch 103: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0284, Test Linf Norm: 0.0265
# Epoch 104: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0280, Test Linf Norm: 0.0264
# Epoch 105: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0286, Test Linf Norm: 0.0264
# Epoch 106: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0281, Test Linf Norm: 0.0258
# Epoch 107: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0289, Test Linf Norm: 0.0261
# Epoch 108: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0291, Test Linf Norm: 0.0253
# Epoch 109: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0028, Train Linf Norm: 0.0309, Test Linf Norm: 0.0332
# Epoch 110: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0025, Train Linf Norm: 0.0334, Test Linf Norm: 0.0275
# Epoch 111: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0024, Train Linf Norm: 0.0333, Test Linf Norm: 0.0255
# Epoch 112: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0036, Train Linf Norm: 0.0301, Test Linf Norm: 0.0436
# Epoch 113: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0030, Train Linf Norm: 0.0502, Test Linf Norm: 0.0352
# Epoch 114: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0035, Test L1 Norm: 0.0043, Train Linf Norm: 0.0430, Test Linf Norm: 0.0382
# Epoch 115: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0024, Train Linf Norm: 0.0338, Test Linf Norm: 0.0277
# Epoch 116: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0024, Train Linf Norm: 0.0324, Test Linf Norm: 0.0262
# Epoch 117: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0024, Train Linf Norm: 0.0297, Test Linf Norm: 0.0283
# Epoch 118: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0023, Train Linf Norm: 0.0301, Test Linf Norm: 0.0258
# Epoch 119: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0285, Test Linf Norm: 0.0257
# Epoch 120: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0023, Train Linf Norm: 0.0279, Test Linf Norm: 0.0260
# Epoch 121: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0282, Test Linf Norm: 0.0260
# Epoch 122: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0283, Test Linf Norm: 0.0275
# Epoch 123: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0286, Test Linf Norm: 0.0257
# Epoch 124: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0023, Train Linf Norm: 0.0300, Test Linf Norm: 0.0261
# Epoch 125: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0025, Train Linf Norm: 0.0294, Test Linf Norm: 0.0279
# Epoch 126: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0023, Train Linf Norm: 0.0321, Test Linf Norm: 0.0253
# Epoch 127: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0028, Train Linf Norm: 0.0332, Test Linf Norm: 0.0293
# Epoch 128: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0030, Train Linf Norm: 0.0325, Test Linf Norm: 0.0363
# Epoch 129: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0026, Train Linf Norm: 0.0343, Test Linf Norm: 0.0302
# Epoch 130: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0025, Train Linf Norm: 0.0389, Test Linf Norm: 0.0275
# Epoch 131: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0036, Train Linf Norm: 0.0332, Test Linf Norm: 0.0464
# Epoch 132: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0022, Train Linf Norm: 0.0271, Test Linf Norm: 0.0244
# Epoch 133: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0291, Test Linf Norm: 0.0267
# Epoch 134: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0288, Test Linf Norm: 0.0254
# Epoch 135: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0024, Train Linf Norm: 0.0272, Test Linf Norm: 0.0274
# Epoch 136: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0267, Test Linf Norm: 0.0237
# Epoch 137: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0260, Test Linf Norm: 0.0237
# Epoch 138: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0268, Test Linf Norm: 0.0237
# Epoch 139: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0265, Test Linf Norm: 0.0234
# Epoch 140: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0025, Train Linf Norm: 0.0277, Test Linf Norm: 0.0281
# Epoch 141: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0021, Train Linf Norm: 0.0301, Test Linf Norm: 0.0222
# Epoch 142: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0028, Train Linf Norm: 0.0290, Test Linf Norm: 0.0325
# Epoch 143: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0022, Train Linf Norm: 0.0293, Test Linf Norm: 0.0244
# Epoch 144: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0024, Train Linf Norm: 0.0386, Test Linf Norm: 0.0278
# Epoch 145: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0032, Test L1 Norm: 0.0024, Train Linf Norm: 0.0390, Test Linf Norm: 0.0274
# Epoch 146: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0034, Train Linf Norm: 0.0307, Test Linf Norm: 0.0312
# Epoch 147: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0028, Test L1 Norm: 0.0025, Train Linf Norm: 0.0348, Test Linf Norm: 0.0287
# Epoch 148: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0023, Train Linf Norm: 0.0288, Test Linf Norm: 0.0263
# Epoch 149: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0028, Train Linf Norm: 0.0285, Test Linf Norm: 0.0333
# Epoch 150: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0021, Train Linf Norm: 0.0272, Test Linf Norm: 0.0232
# Epoch 151: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0022, Train Linf Norm: 0.0250, Test Linf Norm: 0.0244
# Epoch 152: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0020, Train Linf Norm: 0.0259, Test Linf Norm: 0.0222
# Epoch 153: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0020, Train Linf Norm: 0.0262, Test Linf Norm: 0.0222
# Epoch 154: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0020, Train Linf Norm: 0.0258, Test Linf Norm: 0.0223
# Epoch 155: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0267, Test Linf Norm: 0.0231
# Epoch 156: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0255, Test Linf Norm: 0.0234
# Epoch 157: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0021, Train Linf Norm: 0.0279, Test Linf Norm: 0.0230
# Epoch 158: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0029, Train Linf Norm: 0.0299, Test Linf Norm: 0.0329
# Epoch 159: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0021, Train Linf Norm: 0.0309, Test Linf Norm: 0.0227
# Epoch 160: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0022, Train Linf Norm: 0.0303, Test Linf Norm: 0.0226
# Epoch 161: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0030, Test L1 Norm: 0.0025, Train Linf Norm: 0.0354, Test Linf Norm: 0.0278
# Epoch 162: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0022, Train Linf Norm: 0.0304, Test Linf Norm: 0.0241
# Epoch 163: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0022, Train Linf Norm: 0.0304, Test Linf Norm: 0.0232
# Epoch 164: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0021, Train Linf Norm: 0.0279, Test Linf Norm: 0.0228
# Epoch 165: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0026, Train Linf Norm: 0.0276, Test Linf Norm: 0.0285
# Epoch 166: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0267, Test Linf Norm: 0.0235
# Epoch 167: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0256, Test Linf Norm: 0.0239
# Epoch 168: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0021, Train Linf Norm: 0.0254, Test Linf Norm: 0.0231
# Epoch 169: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0021, Train Linf Norm: 0.0256, Test Linf Norm: 0.0231
# Epoch 170: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0020, Train Linf Norm: 0.0249, Test Linf Norm: 0.0225
# Epoch 171: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0262, Test Linf Norm: 0.0242
# Epoch 172: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0254, Test Linf Norm: 0.0214
# Epoch 173: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0020, Train Linf Norm: 0.0261, Test Linf Norm: 0.0227
# Epoch 174: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0026, Train Linf Norm: 0.0269, Test Linf Norm: 0.0289
# Epoch 175: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0019, Train Linf Norm: 0.0281, Test Linf Norm: 0.0205
# Epoch 176: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0026, Train Linf Norm: 0.0293, Test Linf Norm: 0.0300
# Epoch 177: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0029, Test L1 Norm: 0.0022, Train Linf Norm: 0.0353, Test Linf Norm: 0.0239
# Epoch 178: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0029, Train Linf Norm: 0.0299, Test Linf Norm: 0.0321
# Epoch 179: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0020, Train Linf Norm: 0.0297, Test Linf Norm: 0.0216
# Epoch 180: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0020, Train Linf Norm: 0.0287, Test Linf Norm: 0.0216
# Epoch 181: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0022, Train Linf Norm: 0.0256, Test Linf Norm: 0.0258
# Epoch 182: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0248, Test Linf Norm: 0.0211
# Epoch 183: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0239, Test Linf Norm: 0.0212
# Epoch 184: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0243, Test Linf Norm: 0.0224
# Epoch 185: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0237, Test Linf Norm: 0.0224
# Epoch 186: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0240, Test Linf Norm: 0.0218
# Epoch 187: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0021, Train Linf Norm: 0.0235, Test Linf Norm: 0.0229
# Epoch 188: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0020, Train Linf Norm: 0.0260, Test Linf Norm: 0.0222
# Epoch 189: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0022, Train Linf Norm: 0.0217, Test Linf Norm: 0.0253
# Epoch 190: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0019, Train Linf Norm: 0.0265, Test Linf Norm: 0.0204
# Epoch 191: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0019, Train Linf Norm: 0.0284, Test Linf Norm: 0.0195
# Epoch 192: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0258, Test Linf Norm: 0.0253
# Epoch 193: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0027, Test L1 Norm: 0.0023, Train Linf Norm: 0.0330, Test Linf Norm: 0.0265
# Epoch 194: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0026, Train Linf Norm: 0.0283, Test Linf Norm: 0.0308
# Epoch 195: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0260, Test Linf Norm: 0.0238
# Epoch 196: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0261, Test Linf Norm: 0.0228
# Epoch 197: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0243, Test Linf Norm: 0.0199
# Epoch 198: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0219, Test Linf Norm: 0.0206
# Epoch 199: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0019, Train Linf Norm: 0.0232, Test Linf Norm: 0.0208
# Epoch 200: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0228, Test Linf Norm: 0.0214
# Epoch 201: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0231, Test Linf Norm: 0.0214
# Epoch 202: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0230, Test Linf Norm: 0.0206
# Epoch 203: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0229, Test Linf Norm: 0.0208
# Epoch 204: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0018, Train Linf Norm: 0.0231, Test Linf Norm: 0.0194
# Epoch 205: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0252, Test Linf Norm: 0.0186
# Epoch 206: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0244, Test Linf Norm: 0.0203
# Epoch 207: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0020, Train Linf Norm: 0.0274, Test Linf Norm: 0.0228
# Epoch 208: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0030, Train Linf Norm: 0.0246, Test Linf Norm: 0.0366
# Epoch 209: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0024, Train Linf Norm: 0.0275, Test Linf Norm: 0.0240
# Epoch 210: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0023, Train Linf Norm: 0.0263, Test Linf Norm: 0.0260
# Epoch 211: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0019, Train Linf Norm: 0.0253, Test Linf Norm: 0.0209
# Epoch 212: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0022, Train Linf Norm: 0.0248, Test Linf Norm: 0.0251
# Epoch 213: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0245, Test Linf Norm: 0.0213
# Epoch 214: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0225, Test Linf Norm: 0.0217
# Epoch 215: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0019, Train Linf Norm: 0.0237, Test Linf Norm: 0.0200
# Epoch 216: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0225, Test Linf Norm: 0.0201
# Epoch 217: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0224, Test Linf Norm: 0.0201
# Epoch 218: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0223, Test Linf Norm: 0.0202
# Epoch 219: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0217, Test Linf Norm: 0.0206
# Epoch 220: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0226, Test Linf Norm: 0.0222
# Epoch 221: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0020, Train Linf Norm: 0.0236, Test Linf Norm: 0.0224
# Epoch 222: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0253, Test Linf Norm: 0.0195
# Epoch 223: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0029, Train Linf Norm: 0.0261, Test Linf Norm: 0.0362
# Epoch 224: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0019, Train Linf Norm: 0.0282, Test Linf Norm: 0.0196
# Epoch 225: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0026, Test L1 Norm: 0.0022, Train Linf Norm: 0.0305, Test Linf Norm: 0.0249
# Epoch 226: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0023, Train Linf Norm: 0.0271, Test Linf Norm: 0.0272
# Epoch 227: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0242, Test Linf Norm: 0.0189
# Epoch 228: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0251, Test Linf Norm: 0.0199
# Epoch 229: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0020, Train Linf Norm: 0.0205, Test Linf Norm: 0.0219
# Epoch 230: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0237, Test Linf Norm: 0.0185
# Epoch 231: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0224, Test Linf Norm: 0.0201
# Epoch 232: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0214, Test Linf Norm: 0.0202
# Epoch 233: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0212, Test Linf Norm: 0.0202
# Epoch 234: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0216, Test Linf Norm: 0.0201
# Epoch 235: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0224, Test Linf Norm: 0.0190
# Epoch 236: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0217, Test Linf Norm: 0.0195
# Epoch 237: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0220, Test Linf Norm: 0.0194
# Epoch 238: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0228, Test Linf Norm: 0.0181
# Epoch 239: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0019, Train Linf Norm: 0.0277, Test Linf Norm: 0.0205
# Epoch 240: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0023, Train Linf Norm: 0.0263, Test Linf Norm: 0.0246
# Epoch 241: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0031, Test L1 Norm: 0.0023, Train Linf Norm: 0.0394, Test Linf Norm: 0.0259
# Epoch 242: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0022, Train Linf Norm: 0.0261, Test Linf Norm: 0.0251
# Epoch 243: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0023, Train Linf Norm: 0.0236, Test Linf Norm: 0.0254
# Epoch 244: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0019, Train Linf Norm: 0.0231, Test Linf Norm: 0.0208
# Epoch 245: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0217, Test Linf Norm: 0.0225
# Epoch 246: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0213, Test Linf Norm: 0.0173
# Epoch 247: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0018, Train Linf Norm: 0.0202, Test Linf Norm: 0.0199
# Epoch 248: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0202, Test Linf Norm: 0.0179
# Epoch 249: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0200, Test Linf Norm: 0.0179
# Epoch 250: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0201, Test Linf Norm: 0.0184
# Epoch 251: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0201, Test Linf Norm: 0.0181
# Epoch 252: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0018, Train Linf Norm: 0.0200, Test Linf Norm: 0.0198
# Epoch 253: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0216, Test Linf Norm: 0.0196
# Epoch 254: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0018, Train Linf Norm: 0.0237, Test Linf Norm: 0.0186
# Epoch 255: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0021, Train Linf Norm: 0.0230, Test Linf Norm: 0.0247
# Epoch 256: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0021, Train Linf Norm: 0.0280, Test Linf Norm: 0.0246
# Epoch 257: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0233, Test Linf Norm: 0.0213
# Epoch 258: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0241, Test Linf Norm: 0.0190
# Epoch 259: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0017, Train Linf Norm: 0.0268, Test Linf Norm: 0.0190
# Epoch 260: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0019, Train Linf Norm: 0.0228, Test Linf Norm: 0.0213
# Epoch 261: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0024, Train Linf Norm: 0.0216, Test Linf Norm: 0.0292
# Epoch 262: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0018, Train Linf Norm: 0.0194, Test Linf Norm: 0.0196
# Epoch 263: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0200, Test Linf Norm: 0.0185
# Epoch 264: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0198, Test Linf Norm: 0.0177
# Epoch 265: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0192, Test Linf Norm: 0.0177
# Epoch 266: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0192, Test Linf Norm: 0.0175
# Epoch 267: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0197, Test Linf Norm: 0.0174
# Epoch 268: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0211, Test Linf Norm: 0.0183
# Epoch 269: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0198, Test Linf Norm: 0.0182
# Epoch 270: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0220, Test Linf Norm: 0.0191
# Epoch 271: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0021, Train Linf Norm: 0.0267, Test Linf Norm: 0.0231
# Epoch 272: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0025, Train Linf Norm: 0.0262, Test Linf Norm: 0.0302
# Epoch 273: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0018, Train Linf Norm: 0.0248, Test Linf Norm: 0.0188
# Epoch 274: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0018, Train Linf Norm: 0.0266, Test Linf Norm: 0.0200
# Epoch 275: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0018, Train Linf Norm: 0.0281, Test Linf Norm: 0.0193
# Epoch 276: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0017, Train Linf Norm: 0.0214, Test Linf Norm: 0.0173
# Epoch 277: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0217, Test Linf Norm: 0.0178
# Epoch 278: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0194, Test Linf Norm: 0.0171
# Epoch 279: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0196, Test Linf Norm: 0.0175
# Epoch 280: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0191, Test Linf Norm: 0.0171
# Epoch 281: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0192, Test Linf Norm: 0.0171
# Epoch 282: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0195, Test Linf Norm: 0.0170
# Epoch 283: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0194, Test Linf Norm: 0.0170
# Epoch 284: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0016, Train Linf Norm: 0.0210, Test Linf Norm: 0.0172
# Epoch 285: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0197, Test Linf Norm: 0.0173
# Epoch 286: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0021, Train Linf Norm: 0.0214, Test Linf Norm: 0.0244
# Epoch 287: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0017, Train Linf Norm: 0.0255, Test Linf Norm: 0.0184
# Epoch 288: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0026, Train Linf Norm: 0.0283, Test Linf Norm: 0.0294
# Epoch 289: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0025, Test L1 Norm: 0.0027, Train Linf Norm: 0.0307, Test Linf Norm: 0.0335
# Epoch 290: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0019, Train Linf Norm: 0.0242, Test Linf Norm: 0.0195
# Epoch 291: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0017, Train Linf Norm: 0.0225, Test Linf Norm: 0.0183
# Epoch 292: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0015, Train Linf Norm: 0.0238, Test Linf Norm: 0.0145
# Epoch 293: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0016, Train Linf Norm: 0.0215, Test Linf Norm: 0.0166
# Epoch 294: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0018, Train Linf Norm: 0.0206, Test Linf Norm: 0.0195
# Epoch 295: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0197, Test Linf Norm: 0.0174
# Epoch 296: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0195, Test Linf Norm: 0.0166
# Epoch 297: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0187, Test Linf Norm: 0.0166
# Epoch 298: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0195, Test Linf Norm: 0.0167
# Epoch 299: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0196, Test Linf Norm: 0.0166
# Epoch 300: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0190, Test Linf Norm: 0.0177
# Epoch 301: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0201, Test Linf Norm: 0.0180
# Epoch 302: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0018, Train Linf Norm: 0.0212, Test Linf Norm: 0.0199
# Epoch 303: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0016, Train Linf Norm: 0.0212, Test Linf Norm: 0.0168
# Epoch 304: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0251, Test Linf Norm: 0.0194
# Epoch 305: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0024, Test L1 Norm: 0.0019, Train Linf Norm: 0.0287, Test Linf Norm: 0.0213
# Epoch 306: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0255, Test Linf Norm: 0.0196
# Epoch 307: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0017, Train Linf Norm: 0.0256, Test Linf Norm: 0.0171
# Epoch 308: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0018, Train Linf Norm: 0.0196, Test Linf Norm: 0.0201
# Epoch 309: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0207, Test Linf Norm: 0.0184
# Epoch 310: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0015, Train Linf Norm: 0.0193, Test Linf Norm: 0.0159
# Epoch 311: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0197, Test Linf Norm: 0.0174
# Epoch 312: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0184, Test Linf Norm: 0.0160
# Epoch 313: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0187, Test Linf Norm: 0.0160
# Epoch 314: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0187, Test Linf Norm: 0.0163
# Epoch 315: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0182, Test Linf Norm: 0.0165
# Epoch 316: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0205, Test Linf Norm: 0.0171
# Epoch 317: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0193, Test Linf Norm: 0.0165
# Epoch 318: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0016, Train Linf Norm: 0.0208, Test Linf Norm: 0.0166
# Epoch 319: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0023, Train Linf Norm: 0.0203, Test Linf Norm: 0.0283
# Epoch 320: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0232, Test Linf Norm: 0.0175
# Epoch 321: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0021, Test L1 Norm: 0.0018, Train Linf Norm: 0.0245, Test Linf Norm: 0.0189
# Epoch 322: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0205, Test Linf Norm: 0.0229
# Epoch 323: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0241, Test Linf Norm: 0.0188
# Epoch 324: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0016, Train Linf Norm: 0.0220, Test Linf Norm: 0.0168
# Epoch 325: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0019, Train Linf Norm: 0.0196, Test Linf Norm: 0.0218
# Epoch 326: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0194, Test Linf Norm: 0.0165
# Epoch 327: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0184, Test Linf Norm: 0.0160
# Epoch 328: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0184, Test Linf Norm: 0.0170
# Epoch 329: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0181, Test Linf Norm: 0.0170
# Epoch 330: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0184, Test Linf Norm: 0.0166
# Epoch 331: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0184, Test Linf Norm: 0.0153
# Epoch 332: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0014, Train Linf Norm: 0.0183, Test Linf Norm: 0.0144
# Epoch 333: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0190, Test Linf Norm: 0.0183
# Epoch 334: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0206, Test Linf Norm: 0.0191
# Epoch 335: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0015, Train Linf Norm: 0.0230, Test Linf Norm: 0.0160
# Epoch 336: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0221, Test Linf Norm: 0.0224
# Epoch 337: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0017, Train Linf Norm: 0.0251, Test Linf Norm: 0.0183
# Epoch 338: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0235, Test Linf Norm: 0.0182
# Epoch 339: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0018, Train Linf Norm: 0.0218, Test Linf Norm: 0.0207
# Epoch 340: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0199, Test Linf Norm: 0.0164
# Epoch 341: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0017, Train Linf Norm: 0.0191, Test Linf Norm: 0.0183
# Epoch 342: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0182, Test Linf Norm: 0.0175
# Epoch 343: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0184, Test Linf Norm: 0.0170
# Epoch 344: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0174, Test Linf Norm: 0.0161
# Epoch 345: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0173, Test Linf Norm: 0.0161
# Epoch 346: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0176, Test Linf Norm: 0.0160
# Epoch 347: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0179, Test Linf Norm: 0.0166
# Epoch 348: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0017, Train Linf Norm: 0.0185, Test Linf Norm: 0.0181
# Epoch 349: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0022, Train Linf Norm: 0.0199, Test Linf Norm: 0.0272
# Epoch 350: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0220, Test Linf Norm: 0.0185
# Epoch 351: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0022, Train Linf Norm: 0.0220, Test Linf Norm: 0.0263
# Epoch 352: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0023, Test L1 Norm: 0.0018, Train Linf Norm: 0.0284, Test Linf Norm: 0.0203
# Epoch 353: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0022, Train Linf Norm: 0.0232, Test Linf Norm: 0.0249
# Epoch 354: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0019, Train Linf Norm: 0.0259, Test Linf Norm: 0.0208
# Epoch 355: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0017, Train Linf Norm: 0.0215, Test Linf Norm: 0.0175
# Epoch 356: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0017, Train Linf Norm: 0.0189, Test Linf Norm: 0.0173
# Epoch 357: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0018, Train Linf Norm: 0.0188, Test Linf Norm: 0.0194
# Epoch 358: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0181, Test Linf Norm: 0.0173
# Epoch 359: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0017, Train Linf Norm: 0.0176, Test Linf Norm: 0.0183
# Epoch 360: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0172, Test Linf Norm: 0.0157
# Epoch 361: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0174, Test Linf Norm: 0.0157
# Epoch 362: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0172, Test Linf Norm: 0.0145
# Epoch 363: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0016, Train Linf Norm: 0.0175, Test Linf Norm: 0.0171
# Epoch 364: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0171, Test Linf Norm: 0.0155
# Epoch 365: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0015, Train Linf Norm: 0.0194, Test Linf Norm: 0.0160
# Epoch 366: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0019, Train Linf Norm: 0.0179, Test Linf Norm: 0.0214
# Epoch 367: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0015, Train Linf Norm: 0.0220, Test Linf Norm: 0.0159
# Epoch 368: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0023, Train Linf Norm: 0.0230, Test Linf Norm: 0.0278
# Epoch 369: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0020, Test L1 Norm: 0.0017, Train Linf Norm: 0.0230, Test Linf Norm: 0.0177
# Epoch 370: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0017, Train Linf Norm: 0.0226, Test Linf Norm: 0.0192
# Epoch 371: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0018, Train Linf Norm: 0.0191, Test Linf Norm: 0.0195
# Epoch 372: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0210, Test Linf Norm: 0.0228
# Epoch 373: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0016, Train Linf Norm: 0.0174, Test Linf Norm: 0.0171
# Epoch 374: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0179, Test Linf Norm: 0.0157
# Epoch 375: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0176, Test Linf Norm: 0.0145
# Epoch 376: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0167, Test Linf Norm: 0.0139
# Epoch 377: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0166, Test Linf Norm: 0.0139
# Epoch 378: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0171, Test Linf Norm: 0.0139
# Epoch 379: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0175, Test Linf Norm: 0.0157
# Epoch 380: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0016, Train Linf Norm: 0.0167, Test Linf Norm: 0.0185
# Epoch 381: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0016, Train Linf Norm: 0.0193, Test Linf Norm: 0.0175
# Epoch 382: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0016, Train Linf Norm: 0.0176, Test Linf Norm: 0.0168
# Epoch 383: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0016, Train Linf Norm: 0.0224, Test Linf Norm: 0.0158
# Epoch 384: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0022, Test L1 Norm: 0.0018, Train Linf Norm: 0.0270, Test Linf Norm: 0.0202
# Epoch 385: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0207, Test Linf Norm: 0.0213
# Epoch 386: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0018, Test L1 Norm: 0.0019, Train Linf Norm: 0.0205, Test Linf Norm: 0.0219
# Epoch 387: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0017, Test L1 Norm: 0.0015, Train Linf Norm: 0.0189, Test Linf Norm: 0.0156
# Epoch 388: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0185, Test Linf Norm: 0.0152
# Epoch 389: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0193, Test Linf Norm: 0.0148
# Epoch 390: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0016, Train Linf Norm: 0.0165, Test Linf Norm: 0.0173
# Epoch 391: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0173, Test Linf Norm: 0.0153
# Epoch 392: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0164, Test Linf Norm: 0.0139
# Epoch 393: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0170, Test Linf Norm: 0.0139
# Epoch 394: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0165, Test Linf Norm: 0.0143
# Epoch 395: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0015, Train Linf Norm: 0.0172, Test Linf Norm: 0.0163
# Epoch 396: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0015, Test L1 Norm: 0.0014, Train Linf Norm: 0.0162, Test Linf Norm: 0.0150
# Epoch 397: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0015, Train Linf Norm: 0.0185, Test Linf Norm: 0.0157
# Epoch 398: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0016, Test L1 Norm: 0.0019, Train Linf Norm: 0.0182, Test Linf Norm: 0.0224
# Epoch 399: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0017, Train Linf Norm: 0.0222, Test Linf Norm: 0.0195
# Epoch 400: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0019, Test L1 Norm: 0.0020, Train Linf Norm: 0.0214, Test Linf Norm: 0.0229

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration/00199" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
if torch.cuda.is_available():
 net_loaded.load_state_dict(torch.load("net.pth"))
else: 
  net_loaded.load_state_dict(torch.load("net.pth", map_location=torch.device('cpu')))
# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if torch.cuda.is_available():
  optimizer_loaded_state_dict = torch.load("optimizer.pth")
else:
  optimizer_loaded_state_dict = torch.load("optimizer.pth", map_location=torch.device('cpu'))
if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
if torch.cuda.is_available():
  scheduler_loaded_state_dict = torch.load("scheduler.pth")
else: 
  scheduler_loaded_state_dict = torch.load("scheduler.pth", map_location=torch.device('cpu'))
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded
# Out:
# {'T_max': 8,
#  'eta_min': 0,
#  'optimizer': Adagrad (
#  Parameter Group 0
#      differentiable: False
#      eps: 1e-10
#      foreach: None
#      initial_accumulator_value: 0
#      initial_lr: 0.0016884179922857007
#      lr: 0.001688417992285733
#      lr_decay: 0
#      maximize: False
#      weight_decay: 0
#  ),
#  'base_lrs': [0.0016884179922857007],
#  'last_epoch': 400,
#  'verbose': False,
#  '_step_count': 401,
#  '_get_lr_called_within_step': False,
#  '_last_lr': [0.001688417992285733]}

# %% [markdown]
# ---
# ## Thesis

# %%
test_metrics_loaded[-10:]
# Out:
# [{'l1_norm': 0.0014535326558863, 'linf_norm': 0.0153201853174716},
#  {'l1_norm': 0.0013672316838754, 'linf_norm': 0.0139126368719153},
#  {'l1_norm': 0.0013672316838754, 'linf_norm': 0.0139126368719153},
#  {'l1_norm': 0.0013890511600533, 'linf_norm': 0.0142997976215556},
#  {'l1_norm': 0.0015378000712953, 'linf_norm': 0.0162572996105998},
#  {'l1_norm': 0.0014281199517659, 'linf_norm': 0.0150303277610801},
#  {'l1_norm': 0.0015201295708306, 'linf_norm': 0.0156678079846315},
#  {'l1_norm': 0.0019355070243356, 'linf_norm': 0.0223580407978966},
#  {'l1_norm': 0.001735449816822, 'linf_norm': 0.0194741725038737},
#  {'l1_norm': 0.0019689017488388, 'linf_norm': 0.0228751682881265}]

# %% [markdown]
# ---

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# First figure: Train and Test L1 Norm
plt.figure(figsize=(6, 4))
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm", color='blue')
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
plt.title("NNSR4 Train and Test L1 Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR4_L1_norm_plot.png", dpi=300)

# Second figure: Train and Test Linf Norm
plt.figure(figsize=(6, 4))
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm", color='blue')
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm", color='red')
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
plt.title("NNSR4 Train and Test Linf Norm per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR4_Linf_norm_plot.png", dpi=300)

# Third figure: MSE of training data and test data
plt.figure(figsize=(6, 4))
plt.plot(train_losses_loaded, label="Training Data", color='blue')
plt.plot(test_losses_loaded, label="Test Data", color='red')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("NNSR4 MSE of Training and Test Data per Epoch")
plt.yscale("log")
plt.grid(True)
plt.xlim(right=200)
plt.ylim(1e-7, 1e0)
plt.legend()
plt.tight_layout()
plt.savefig("NNSR4_MSE_plot.png", dpi=300)

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

def save_metrics_to_csv(metrics_data, filename):
    df = pd.DataFrame(metrics_data)
    df.columns = ['L1 Norm', 'Linf Norm']
    df.to_csv(filename, index=False)

save_metrics_to_csv(train_metrics_loaded, 'train_metrics_NNSR4.csv')
save_metrics_to_csv(test_metrics_loaded, 'test_metrics_NNSR4.csv')

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.2076,  0.4897,  0.1011],
#         [ 0.3493,  0.0625,  0.2235],
#         [-0.4251, -0.3084,  0.0922],
#         ...,
#         [ 0.2639, -0.5629, -0.3328],
#         [ 0.2076, -0.0958,  0.2623],
#         [-0.2717,  0.3120,  0.2945]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 0.1571, -0.2820, -0.1120,  0.5288, -0.1910,  0.1295, -0.4708,  0.5416,
#          0.1047,  0.5519,  0.1971,  0.1332, -0.2223,  0.2659,  0.2572, -0.2029,
#         -0.4961,  0.2113,  0.1180,  0.3308,  0.4376,  0.1717,  0.4500,  0.0830,
#          0.1395,  0.0349,  0.4899, -0.4264,  0.0713,  0.1079, -0.4390, -0.0478,
#         -0.0045, -0.1085, -0.0447,  0.1404, -0.0945, -0.4175, -0.1780,  0.1042,
#          0.1899, -0.4785,  0.5411,  0.5049,  0.4304, -0.2365, -0.3615, -0.5016,
#         -0.0057, -0.0566, -0.4988, -0.0053,  0.1763, -0.1292,  0.4806,  0.2882,
#         -0.4293,  0.1096, -0.3447, -0.3130,  0.1731,  0.0360, -0.0501,  0.5473,
#          0.2927, -0.5316,  0.1212, -0.2136, -0.2412, -0.2487,  0.4190, -0.5424,
#         -0.3000,  0.3775,  0.3795,  0.4091,  0.2243,  0.0389, -0.1755, -0.5733,
#         -0.2668,  0.3406, -0.2964, -0.4189, -0.0075,  0.4128, -0.2645, -0.5609,
#         -0.2287, -0.1281,  0.1182,  0.1739,  0.5844, -0.5082,  0.4170,  0.3530,
#         -0.2269, -0.0114, -0.4586,  0.3810, -0.5478, -0.0620, -0.3874, -0.5677,
#          0.2665,  0.5090, -0.4516, -0.2227, -0.2398,  0.0045,  0.3482, -0.0964,
#         -0.5105,  0.0315, -0.2699, -0.4832,  0.5018, -0.2480, -0.1795,  0.4804,
#         -0.2927,  0.4652,  0.2042, -0.3123, -0.4935,  0.1398, -0.3504, -0.0818,
#         -0.1603,  0.2799,  0.4096, -0.4807,  0.0320,  0.3255,  0.3447,  0.1245,
#          0.2909, -0.5593,  0.3578, -0.3613,  0.1653, -0.3478,  0.3753,  0.1253,
#         -0.0994, -0.3993, -0.2074,  0.0360,  0.2827, -0.2592, -0.2158,  0.4201,
#          0.5155,  0.3224,  0.1741,  0.2174, -0.1277, -0.0142,  0.2136, -0.1696,
#         -0.2176,  0.0861,  0.4233,  0.2997, -0.1858, -0.0609, -0.1271,  0.0796,
#         -0.5692,  0.1509,  0.5727,  0.3400, -0.1583, -0.4104,  0.0050,  0.2666,
#         -0.3229, -0.2794, -0.0095,  0.2157, -0.5221, -0.5355,  0.4422,  0.3948,
#          0.0460,  0.0751,  0.2045, -0.4793,  0.5697, -0.4638, -0.1221,  0.1368,
#          0.1925,  0.1962, -0.3378,  0.3988, -0.1748, -0.0878, -0.3973,  0.3835,
#          0.2776, -0.0586, -0.2944,  0.1759,  0.3125,  0.0491, -0.0596,  0.2172,
#         -0.4780,  0.0871, -0.2530, -0.5234, -0.5111, -0.4684, -0.4570,  0.1944,
#         -0.4929,  0.5194,  0.2228,  0.4998,  0.2736,  0.2431,  0.2513, -0.0785,
#         -0.5295,  0.2246,  0.1379,  0.2684,  0.1837,  0.4023,  0.5475,  0.1485,
#          0.4831,  0.1644, -0.2321,  0.5428,  0.1664,  0.4776,  0.3631,  0.4931,
#          0.0567,  0.5287, -0.1301,  0.3492,  0.1697, -0.5697, -0.2417,  0.0017,
#         -0.4586, -0.0194,  0.3462,  0.3331, -0.4834,  0.1757, -0.4518,  0.2010,
#          0.5437, -0.2532,  0.1352,  0.5531,  0.0245,  0.3485,  0.3074,  0.4484,
#          0.3296,  0.2595, -0.2916, -0.4082,  0.3832, -0.0687, -0.3160, -0.1748,
#          0.1172, -0.2076, -0.3120, -0.3733,  0.4740, -0.0995, -0.0661,  0.5609,
#         -0.0825, -0.2316, -0.2232,  0.1025,  0.0719, -0.2253, -0.3309, -0.5260,
#         -0.3926,  0.2144,  0.4627,  0.5802,  0.0202, -0.2326,  0.4459, -0.5614,
#         -0.0104,  0.2860,  0.2619, -0.2575, -0.4555,  0.3638, -0.2047,  0.1288,
#          0.4801, -0.0179, -0.1001, -0.0616,  0.2325,  0.2708, -0.2735, -0.2294,
#         -0.3702,  0.5483, -0.2383, -0.1073, -0.1175,  0.5289, -0.0422,  0.3116,
#          0.1219,  0.0039,  0.4574, -0.1561, -0.1778,  0.2400, -0.1401,  0.2170,
#          0.4068, -0.4952, -0.1789, -0.2621, -0.5559, -0.1087,  0.5047,  0.4791,
#          0.2350, -0.2854, -0.3690, -0.4328,  0.2214,  0.0317,  0.4387,  0.1165,
#         -0.1644, -0.3171, -0.2663,  0.0788,  0.3159,  0.2870, -0.1433, -0.1963,
#         -0.0233, -0.5021,  0.5041,  0.1374, -0.2328, -0.2153, -0.2862, -0.4313,
#          0.0817,  0.1824,  0.1939, -0.5202, -0.2247,  0.0646, -0.3887,  0.1948,
#          0.0855, -0.1444, -0.3120, -0.2281,  0.4810,  0.5564, -0.0417,  0.4114,
#          0.3031, -0.3157, -0.4976, -0.2926, -0.1896,  0.4485, -0.1936, -0.1592,
#         -0.5051, -0.3674,  0.2822, -0.0104, -0.1745, -0.4224, -0.1926, -0.1704,
#          0.5071, -0.2425,  0.5223, -0.3396, -0.3260, -0.2347,  0.0026,  0.2831,
#          0.5462, -0.2454,  0.5322,  0.2786, -0.1482, -0.4545, -0.2748,  0.1296,
#          0.1035, -0.1734,  0.1131, -0.5281,  0.3173, -0.3133, -0.1026, -0.1758,
#          0.3608, -0.3539, -0.4665, -0.0233, -0.0619,  0.2999,  0.3930,  0.3625,
#         -0.2566, -0.5731,  0.3560, -0.0756,  0.1133, -0.1304,  0.2400, -0.2339,
#          0.4691,  0.4485, -0.5387,  0.1033,  0.0726, -0.2030,  0.3164, -0.2098,
#          0.1271, -0.2340, -0.0298,  0.0983,  0.3514, -0.2419, -0.2865,  0.2821,
#          0.3007, -0.1083,  0.0929, -0.0241, -0.5391,  0.4435,  0.2104,  0.3717,
#         -0.2212, -0.5670, -0.3772, -0.4365,  0.5671,  0.4641, -0.0270, -0.2457,
#         -0.5193, -0.4157,  0.2284, -0.0881, -0.2183,  0.1909,  0.3264, -0.3119,
#         -0.5493, -0.0639,  0.4148,  0.2829,  0.5068, -0.2803, -0.4692, -0.4879,
#          0.4324,  0.1693,  0.5610, -0.4312,  0.0501, -0.1360, -0.1840, -0.2577,
#         -0.2795, -0.0082,  0.4735,  0.4941, -0.0012, -0.2760, -0.4597,  0.3753,
#          0.4757,  0.1029,  0.5039,  0.1318, -0.3283,  0.0401, -0.0392, -0.1060,
#          0.5475,  0.5227,  0.2679, -0.0994, -0.1656,  0.4495,  0.3725, -0.0626,
#          0.1681,  0.2715, -0.2613, -0.3560,  0.5325, -0.1449,  0.4777,  0.1994,
#         -0.3482, -0.2310, -0.0907,  0.1569,  0.1681,  0.1507,  0.3148,  0.3907,
#          0.2405,  0.2560,  0.1088,  0.0437, -0.2660, -0.4627, -0.2505, -0.4787,
#          0.5503, -0.4811,  0.0794,  0.5361,  0.2351,  0.5519, -0.2055,  0.3198,
#          0.1579, -0.4326,  0.3774, -0.1895, -0.2369, -0.4128, -0.0426, -0.5628,
#         -0.0860, -0.2064, -0.1111,  0.5271,  0.2942,  0.0904, -0.1929,  0.5409,
#         -0.2427,  0.3342,  0.0365,  0.0526,  0.1577,  0.0511,  0.5783,  0.1521,
#         -0.4223, -0.4014, -0.0129,  0.4548,  0.2279,  0.4945,  0.3724,  0.3311,
#         -0.3508,  0.2121,  0.4834, -0.1346,  0.3547,  0.5482,  0.1967, -0.5881,
#         -0.4323,  0.2262, -0.2383,  0.0052, -0.4299, -0.3879, -0.0283, -0.1277,
#          0.1802, -0.2621,  0.0032,  0.3399,  0.0253, -0.5589,  0.3313,  0.4514,
#         -0.2045,  0.5020, -0.0137, -0.3502, -0.1032, -0.0042, -0.4673,  0.0412,
#          0.2465, -0.4596, -0.4734,  0.0571, -0.1439, -0.2915,  0.2300,  0.5642,
#          0.5493], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0053, -0.0378,  0.0222,  ..., -0.0386, -0.0141,  0.0227],
#         [ 0.0114, -0.0255,  0.0352,  ...,  0.0309,  0.0176,  0.0237],
#         [ 0.0185,  0.0272, -0.0393,  ..., -0.0101,  0.0223, -0.0018],
#         ...,
#         [ 0.0156, -0.0283,  0.0221,  ..., -0.0136, -0.0331, -0.0086],
#         [-0.0238,  0.0303, -0.0332,  ..., -0.0267, -0.0237,  0.0041],
#         [-0.0159,  0.0110, -0.0333,  ...,  0.0115,  0.0203,  0.0097]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0157,  0.0387,  0.0070,  0.0122,  0.0162, -0.0321, -0.0326, -0.0356,
#          0.0234, -0.0413, -0.0038, -0.0084, -0.0398,  0.0042, -0.0198,  0.0137,
#          0.0245, -0.0376, -0.0222, -0.0232, -0.0204, -0.0367,  0.0366,  0.0005,
#         -0.0306,  0.0284,  0.0426,  0.0281,  0.0028,  0.0175, -0.0353, -0.0039,
#          0.0193,  0.0211,  0.0252, -0.0295, -0.0051,  0.0363,  0.0114, -0.0026,
#          0.0039, -0.0255, -0.0075,  0.0193, -0.0171, -0.0338, -0.0046,  0.0361,
#          0.0019, -0.0189,  0.0215,  0.0356,  0.0174, -0.0336, -0.0244, -0.0410,
#          0.0043, -0.0144,  0.0061, -0.0122, -0.0280,  0.0198, -0.0272, -0.0299,
#          0.0016,  0.0443,  0.0089,  0.0232, -0.0290, -0.0092, -0.0278,  0.0014,
#         -0.0112, -0.0045, -0.0219,  0.0010,  0.0319,  0.0247,  0.0309, -0.0026,
#         -0.0465, -0.0307,  0.0244, -0.0311, -0.0388, -0.0385, -0.0261,  0.0050,
#         -0.0360, -0.0323, -0.0290,  0.0245, -0.0170, -0.0391, -0.0279, -0.0155,
#         -0.0316, -0.0126, -0.0369, -0.0091,  0.0061,  0.0302, -0.0182, -0.0108,
#          0.0256,  0.0065,  0.0069,  0.0270, -0.0278, -0.0257, -0.0020, -0.0354,
#         -0.0384, -0.0061, -0.0150, -0.0220,  0.0419,  0.0266, -0.0211,  0.0277,
#         -0.0225,  0.0235,  0.0353, -0.0220, -0.0290, -0.0379,  0.0061,  0.0291,
#         -0.0197,  0.0201, -0.0319, -0.0136,  0.0310, -0.0259, -0.0284,  0.0025,
#         -0.0061,  0.0273,  0.0186,  0.0051,  0.0256, -0.0296, -0.0138,  0.0089,
#         -0.0129,  0.0090,  0.0127,  0.0212,  0.0223, -0.0189, -0.0405, -0.0263,
#         -0.0048,  0.0210,  0.0297,  0.0028, -0.0216, -0.0241,  0.0356,  0.0190,
#         -0.0392, -0.0110, -0.0360,  0.0002,  0.0427, -0.0330,  0.0010,  0.0132,
#          0.0375,  0.0081,  0.0365,  0.0145, -0.0086, -0.0354, -0.0405,  0.0280,
#         -0.0130, -0.0253, -0.0140, -0.0161,  0.0355,  0.0253, -0.0169,  0.0110,
#         -0.0183,  0.0104,  0.0386, -0.0323,  0.0192, -0.0112,  0.0243, -0.0008,
#         -0.0148,  0.0319, -0.0197,  0.0294, -0.0179, -0.0237, -0.0091, -0.0415,
#          0.0274, -0.0147,  0.0381, -0.0250,  0.0245,  0.0160,  0.0300,  0.0259,
#         -0.0268, -0.0185, -0.0409, -0.0031,  0.0124,  0.0389, -0.0048, -0.0003,
#         -0.0292, -0.0293,  0.0166, -0.0276, -0.0194,  0.0096, -0.0130, -0.0334,
#          0.0264,  0.0302, -0.0098,  0.0428,  0.0078, -0.0218,  0.0242,  0.0176,
#         -0.0076, -0.0092,  0.0124,  0.0043, -0.0072, -0.0108, -0.0373,  0.0211,
#          0.0160,  0.0173, -0.0327,  0.0219, -0.0068, -0.0355,  0.0124, -0.0431,
#         -0.0323,  0.0316,  0.0300, -0.0028, -0.0074,  0.0337, -0.0144,  0.0307,
#         -0.0303, -0.0236,  0.0348,  0.0386, -0.0161, -0.0021,  0.0003, -0.0203,
#          0.0174, -0.0230, -0.0025, -0.0315, -0.0091, -0.0012, -0.0017,  0.0173,
#          0.0080,  0.0173, -0.0205,  0.0003,  0.0036, -0.0248, -0.0296, -0.0402,
#          0.0359, -0.0321, -0.0227,  0.0382,  0.0339,  0.0353,  0.0406, -0.0220,
#         -0.0243, -0.0389, -0.0402,  0.0282, -0.0112,  0.0346, -0.0100, -0.0293,
#         -0.0150, -0.0220, -0.0256, -0.0357, -0.0249, -0.0138,  0.0047,  0.0338,
#         -0.0277, -0.0350, -0.0366, -0.0361, -0.0291,  0.0183, -0.0359, -0.0014,
#         -0.0258, -0.0132, -0.0093,  0.0102, -0.0417, -0.0343, -0.0118, -0.0164,
#          0.0088, -0.0056,  0.0318,  0.0303, -0.0194, -0.0159,  0.0405,  0.0024,
#          0.0229,  0.0375,  0.0311,  0.0277,  0.0263, -0.0226,  0.0270, -0.0289,
#         -0.0372, -0.0376, -0.0062, -0.0352,  0.0289, -0.0073,  0.0206, -0.0021,
#          0.0372,  0.0350, -0.0346,  0.0369,  0.0363, -0.0326,  0.0142, -0.0338,
#          0.0109,  0.0110,  0.0163,  0.0419, -0.0237,  0.0359,  0.0100, -0.0357,
#          0.0263, -0.0065,  0.0112,  0.0285,  0.0232, -0.0168,  0.0241, -0.0097,
#         -0.0247, -0.0164, -0.0244,  0.0222,  0.0377,  0.0581,  0.0190,  0.0346,
#         -0.0307,  0.0371,  0.0105, -0.0110,  0.0012, -0.0355,  0.0352,  0.0164,
#         -0.0091,  0.0271, -0.0118, -0.0265, -0.0023, -0.0245, -0.0226,  0.0151,
#         -0.0178, -0.0091, -0.0371, -0.0379,  0.0077, -0.0351,  0.0118,  0.0040,
#          0.0061, -0.0146, -0.0214,  0.0297,  0.0168,  0.0214, -0.0055,  0.0157,
#          0.0045, -0.0114,  0.0069,  0.0193,  0.0261,  0.0164,  0.0404,  0.0044,
#         -0.0262, -0.0080, -0.0370, -0.0079, -0.0008, -0.0170, -0.0104, -0.0328,
#         -0.0109,  0.0325,  0.0296,  0.0273, -0.0258, -0.0026,  0.0094, -0.0220,
#         -0.0018,  0.0447, -0.0211,  0.0028, -0.0359, -0.0147, -0.0086,  0.0303,
#         -0.0300,  0.0252, -0.0193,  0.0276, -0.0034,  0.0106, -0.0347,  0.0238,
#          0.0054, -0.0199,  0.0070, -0.0226,  0.0337,  0.0135,  0.0264,  0.0032,
#         -0.0050,  0.0288,  0.0128,  0.0217,  0.0294, -0.0248,  0.0382, -0.0158,
#          0.0397,  0.0025, -0.0240,  0.0289, -0.0385,  0.0266, -0.0315,  0.0110,
#          0.0098, -0.0135, -0.0179,  0.0310, -0.0397,  0.0076,  0.0103, -0.0355,
#          0.0235,  0.0035, -0.0343, -0.0015,  0.0144, -0.0175, -0.0384,  0.0150,
#          0.0041, -0.0176, -0.0133, -0.0035,  0.0218, -0.0324, -0.0035,  0.0234,
#         -0.0174, -0.0264, -0.0174, -0.0093, -0.0415, -0.0015,  0.0326, -0.0357,
#         -0.0406, -0.0259,  0.0039, -0.0406, -0.0186, -0.0374,  0.0230, -0.0344,
#         -0.0043, -0.0249,  0.0198, -0.0013,  0.0071, -0.0143, -0.0373, -0.0285,
#         -0.0061,  0.0354,  0.0322,  0.0243,  0.0073, -0.0063,  0.0201,  0.0234,
#          0.0131,  0.0342,  0.0033, -0.0174, -0.0208, -0.0213,  0.0327, -0.0320,
#          0.0169,  0.0309,  0.0156,  0.0205, -0.0373,  0.0050,  0.0313,  0.0178,
#          0.0243, -0.0074,  0.0167, -0.0059, -0.0133, -0.0376, -0.0311,  0.0299,
#          0.0165,  0.0224, -0.0406,  0.0169, -0.0409, -0.0295, -0.0062,  0.0045,
#          0.0352, -0.0338,  0.0167, -0.0090,  0.0350,  0.0047,  0.0300, -0.0051,
#         -0.0106,  0.0030,  0.0026,  0.0187,  0.0352,  0.0271, -0.0378, -0.0393,
#         -0.0227, -0.0080,  0.0050, -0.0190,  0.0037,  0.0106, -0.0240, -0.0066,
#          0.0067,  0.0104, -0.0288, -0.0304,  0.0158, -0.0090, -0.0242, -0.0161,
#         -0.0211,  0.0110, -0.0218,  0.0211,  0.0077, -0.0329, -0.0054, -0.0325,
#         -0.0207,  0.0208, -0.0140,  0.0178, -0.0418, -0.0047,  0.0075,  0.0053,
#         -0.0259, -0.0246,  0.0043, -0.0191,  0.0196,  0.0197, -0.0379, -0.0009,
#          0.0206, -0.0328,  0.0355,  0.0345, -0.0262, -0.0139, -0.0288,  0.0152,
#         -0.0332, -0.0125, -0.0276, -0.0330,  0.0016,  0.0139, -0.0370,  0.0134,
#         -0.0059,  0.0058, -0.0053, -0.0073, -0.0122, -0.0063,  0.0145,  0.0141,
#          0.0373,  0.0271, -0.0032, -0.0329,  0.0340,  0.0264,  0.0171,  0.0044,
#         -0.0296,  0.0300,  0.0329,  0.0284,  0.0075, -0.0143,  0.0367,  0.0133,
#         -0.0313, -0.0041, -0.0299, -0.0048,  0.0331,  0.0241, -0.0301, -0.0135,
#         -0.0040, -0.0029,  0.0455, -0.0006, -0.0294,  0.0173,  0.0414, -0.0041,
#          0.0011,  0.0113, -0.0167, -0.0046,  0.0204,  0.0232,  0.0291,  0.0340,
#         -0.0384,  0.0013, -0.0379, -0.0131, -0.0377,  0.0308,  0.0369, -0.0352,
#          0.0346, -0.0311,  0.0302, -0.0274, -0.0297,  0.0279, -0.0045, -0.0187,
#          0.0106,  0.0269,  0.0063, -0.0416, -0.0280, -0.0107,  0.0295, -0.0048,
#          0.0303,  0.0045,  0.0060, -0.0167,  0.0168, -0.0122,  0.0171,  0.0137,
#         -0.0171, -0.0415, -0.0408,  0.0361,  0.0202, -0.0035,  0.0275, -0.0055,
#         -0.0019, -0.0045,  0.0115,  0.0204, -0.0242,  0.0277,  0.0288,  0.0327,
#         -0.0192,  0.0094,  0.0377, -0.0274, -0.0174, -0.0320, -0.0181,  0.0313,
#          0.0247,  0.0075,  0.0116,  0.0369,  0.0158,  0.0012,  0.0119,  0.0260,
#         -0.0099,  0.0002,  0.0111, -0.0281,  0.0033,  0.0016,  0.0079, -0.0027,
#         -0.0222,  0.0019, -0.0323,  0.0017, -0.0091, -0.0384,  0.0204, -0.0256,
#         -0.0242, -0.0200, -0.0024, -0.0153,  0.0196, -0.0207, -0.0205, -0.0398,
#         -0.0370,  0.0324,  0.0047, -0.0320,  0.0179,  0.0070,  0.0264, -0.0061,
#         -0.0393, -0.0269, -0.0056, -0.0378, -0.0376, -0.0338, -0.0250, -0.0196,
#         -0.0153, -0.0206,  0.0233, -0.0073,  0.0007, -0.0211,  0.0330,  0.0007,
#          0.0434,  0.0313, -0.0205,  0.0283,  0.0100, -0.0418, -0.0399, -0.0135,
#         -0.0327, -0.0273,  0.0098, -0.0198, -0.0247, -0.0287,  0.0332,  0.0362,
#         -0.0126, -0.0429, -0.0162, -0.0257,  0.0152,  0.0236, -0.0342, -0.0123,
#          0.0168, -0.0207, -0.0228, -0.0393,  0.0074,  0.0373,  0.0233, -0.0194,
#          0.0134, -0.0307, -0.0232, -0.0149,  0.0294, -0.0122,  0.0014,  0.0188,
#         -0.0151,  0.0217, -0.0395,  0.0299,  0.0352, -0.0112, -0.0366, -0.0201,
#          0.0172,  0.0006, -0.0322,  0.0007, -0.0274,  0.0020, -0.0037,  0.0091,
#          0.0168,  0.0071,  0.0218, -0.0067, -0.0364,  0.0036,  0.0156, -0.0105,
#          0.0373,  0.0303], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0338, -0.0291, -0.0225,  ..., -0.0022, -0.0018, -0.0240],
#         [-0.0109, -0.0247, -0.0173,  ...,  0.0349, -0.0098,  0.0266],
#         [-0.0236, -0.0229,  0.0206,  ..., -0.0179,  0.0104,  0.0269],
#         ...,
#         [-0.0038,  0.0182, -0.0044,  ...,  0.0284, -0.0078,  0.0099],
#         [-0.0255,  0.0132, -0.0067,  ...,  0.0346,  0.0213,  0.0316],
#         [-0.0226,  0.0273,  0.0145,  ...,  0.0098, -0.0232,  0.0266]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-2.7028e-02,  2.0658e-02,  2.1882e-02, -8.2557e-03,  3.0737e-03,
#         -2.8638e-02,  2.8851e-02, -1.7252e-02,  4.0003e-03,  1.0917e-02,
#         -1.9680e-02, -1.2046e-02,  1.6872e-02, -8.0580e-03,  1.5208e-02,
#          1.6744e-02,  1.4672e-02, -3.6943e-03, -1.0073e-02, -4.9567e-03,
#         -1.4182e-03, -9.1403e-04, -2.7062e-02, -1.0708e-02,  1.0760e-02,
#         -2.7890e-02,  2.1225e-02, -2.8541e-02,  1.6813e-02, -3.1584e-02,
#          2.6539e-02, -1.2026e-02,  1.9681e-02,  5.4691e-03,  6.3391e-03,
#         -4.0272e-03, -1.1182e-02,  4.6787e-03,  9.8802e-03, -1.1412e-02,
#          2.6894e-02, -2.3383e-02, -1.8721e-02,  1.9377e-03,  1.8224e-02,
#          6.3765e-03,  2.5706e-02, -9.8553e-03, -2.9642e-03, -2.3521e-02,
#          4.6376e-03, -6.6135e-04,  2.5794e-03,  1.6322e-02, -1.6392e-03,
#         -1.6744e-02, -2.3005e-03,  3.0260e-03, -1.7579e-02, -2.5824e-02,
#         -1.7427e-02,  2.2391e-02, -1.9790e-02, -3.0614e-02, -2.5729e-02,
#          1.2904e-02, -1.5200e-02, -1.1449e-02, -1.1171e-02,  2.6626e-03,
#         -2.4142e-02, -2.2276e-02,  2.8634e-02,  4.0601e-03,  3.1268e-02,
#         -1.0690e-02, -3.4861e-02,  2.5443e-03,  2.2624e-02, -1.9124e-02,
#         -1.3752e-02, -2.6679e-02,  1.2369e-02, -6.9777e-03,  1.7332e-03,
#          3.1194e-02,  2.9338e-02, -2.0327e-02,  2.3349e-02, -1.4979e-02,
#          8.2456e-03, -1.8713e-02, -3.0727e-03, -3.3193e-02, -1.0935e-02,
#          1.2125e-02, -3.2874e-02, -6.2537e-03, -1.3108e-02,  1.1659e-02,
#          2.9360e-02,  3.1464e-02, -2.3658e-02,  2.6533e-02, -3.2271e-02,
#          7.7671e-04,  2.2658e-02,  1.3755e-02, -6.9763e-03,  7.1671e-03,
#          1.8531e-02,  1.7552e-02,  6.1609e-03, -2.8835e-02,  4.7270e-03,
#         -3.1179e-02, -2.9140e-02, -3.1883e-02, -9.8206e-03, -2.9543e-03,
#         -3.4868e-02,  2.2298e-02,  1.2077e-02, -9.3853e-04, -1.1552e-02,
#          1.8727e-02,  9.0520e-04,  2.4560e-02,  2.6182e-03,  5.3231e-03,
#          2.8834e-02,  5.4148e-03, -6.8575e-03, -1.3829e-02,  6.6270e-03,
#          1.6927e-02, -1.7588e-02,  2.1576e-02,  5.2969e-03, -2.4718e-02,
#          1.5984e-02,  2.8835e-02, -8.5407e-03,  8.6736e-03, -1.2283e-02,
#         -3.4746e-02,  1.2749e-02, -1.1846e-02,  1.6347e-02, -2.6133e-02,
#          3.0282e-02, -1.9016e-02, -2.2067e-02,  2.8420e-02, -3.1342e-03,
#         -1.6843e-02,  1.3202e-02, -1.5041e-02, -3.4786e-02,  2.3190e-02,
#         -3.2814e-02,  2.5348e-02, -3.1905e-02, -1.8669e-02, -1.8486e-02,
#         -2.3035e-03,  2.1619e-02,  8.5356e-03, -4.1201e-03,  2.0809e-02,
#          1.3175e-02,  4.5101e-03,  2.5278e-02, -2.0410e-02, -2.3704e-02,
#         -1.8867e-02, -9.8674e-03,  8.4492e-03, -3.0443e-02,  6.1111e-03,
#          2.9547e-02, -1.4118e-03, -2.8024e-02,  2.2802e-02,  5.2308e-03,
#         -2.7683e-02, -2.0733e-02, -3.1048e-02, -1.8787e-02, -7.7320e-03,
#          1.7431e-02,  4.0333e-02, -4.1437e-02,  1.2617e-02, -2.3193e-02,
#          1.2835e-02,  2.1264e-02, -2.0740e-02,  2.2258e-02,  2.2020e-02,
#          1.1879e-02, -5.5378e-03, -1.7413e-02,  1.1542e-02,  1.1815e-02,
#          8.3742e-03,  5.4017e-03,  2.2208e-02,  3.0819e-02,  1.4712e-02,
#          7.9173e-03, -1.8443e-03, -1.3820e-02,  1.3843e-03, -6.7924e-03,
#          1.0728e-02,  8.2420e-03,  1.5163e-02, -1.0549e-02,  1.3037e-02,
#         -1.6125e-02, -3.3187e-02,  2.6759e-02, -3.1896e-02,  1.1832e-02,
#          2.6191e-02, -8.2139e-05,  5.6533e-04,  2.9558e-02,  2.5421e-02,
#          1.1216e-02, -1.3017e-02,  2.7551e-02,  3.3968e-02, -2.8065e-02,
#          2.3772e-02,  2.6436e-02, -1.9667e-02, -2.2041e-02, -2.1375e-02,
#          7.4428e-03, -2.7744e-02, -2.0178e-02, -2.8445e-02, -2.1254e-02,
#          1.6356e-02,  6.3127e-03,  1.2461e-02, -2.5037e-02, -3.0173e-02,
#          2.5989e-02, -2.6038e-02,  9.8605e-03, -3.1424e-02,  2.1528e-02,
#         -5.7107e-03, -2.3076e-02,  9.5833e-03,  1.0506e-02, -2.4135e-02,
#          1.1120e-02,  3.6614e-03,  1.6673e-02,  5.2346e-03, -7.4353e-03,
#          1.5025e-02, -1.0480e-02, -7.5003e-03,  3.0941e-02,  2.9639e-02,
#         -3.7690e-02,  3.5819e-02, -1.8909e-02,  2.3779e-02, -6.0929e-03,
#         -3.1781e-02, -1.9560e-02,  2.5232e-02, -3.1778e-02, -3.3973e-02,
#          2.3950e-02,  8.0579e-03, -2.8686e-02,  1.4245e-02,  1.1532e-02,
#         -2.8047e-02, -2.1229e-02, -3.1362e-02,  3.4501e-03,  2.8685e-02,
#          4.5824e-03,  1.4884e-02, -9.3261e-03, -3.3462e-03, -3.1538e-02,
#         -7.3716e-03,  1.3243e-03,  2.1741e-02,  2.0994e-02,  2.0115e-02,
#         -5.0336e-03, -2.0787e-02,  2.8869e-02,  1.7903e-02,  2.1906e-02,
#         -6.0246e-03, -3.4838e-02, -3.0368e-02,  3.1202e-02, -2.7661e-02,
#         -2.6027e-02, -8.8784e-03,  7.2320e-03, -2.7186e-02, -2.3303e-02,
#          1.7528e-02, -3.1893e-02, -2.9202e-02,  2.6409e-02,  1.7955e-02,
#         -2.3332e-02, -2.7703e-02, -1.8406e-02, -2.5480e-02,  2.3406e-02,
#         -1.3743e-02, -2.2107e-02, -3.3620e-03,  4.9164e-03, -2.6123e-02,
#         -3.0128e-02,  3.7790e-02,  2.8713e-02, -4.7365e-03,  1.3277e-02,
#         -5.6212e-03,  4.2399e-03, -1.4162e-02, -1.3542e-02,  1.4167e-02,
#         -3.4326e-02,  3.2153e-02,  1.1941e-02,  6.2430e-03, -2.8136e-02,
#         -3.5372e-03,  7.0592e-03, -3.0992e-02,  2.2430e-02,  1.9133e-02,
#         -2.2022e-02, -2.4523e-02, -2.4182e-02, -4.6605e-03, -3.3727e-02,
#          5.0864e-03,  3.1020e-02, -9.4604e-03,  1.6394e-02,  3.5153e-03,
#          3.3348e-02,  3.0974e-02, -3.5651e-02, -1.1851e-02,  1.1000e-02,
#          9.4891e-03, -1.8460e-02,  9.1689e-04, -4.6128e-03,  1.2489e-02,
#          3.0331e-02,  2.6366e-02, -6.9939e-03,  1.0161e-02, -3.5940e-03,
#         -2.2895e-02,  8.4119e-03,  7.7994e-03, -3.5844e-03, -2.6626e-02,
#         -3.8728e-03,  1.8983e-02,  2.7600e-02,  3.0057e-02, -9.0008e-03,
#         -2.5472e-02, -1.9631e-02, -2.4063e-02,  1.2296e-02,  2.4083e-02,
#         -1.3021e-02,  4.5405e-03, -3.4771e-02, -1.8983e-02, -2.8638e-02,
#         -1.6366e-02, -3.1638e-02,  2.7744e-02,  1.4130e-02, -1.9867e-03,
#          3.1157e-02,  3.0313e-02,  2.7782e-02,  2.1285e-02, -1.8261e-02,
#          2.1334e-02,  6.2839e-03,  3.7654e-02,  1.7552e-02, -3.1969e-02,
#         -2.7557e-02,  5.3212e-03,  2.8822e-02, -2.3490e-02,  2.7143e-03,
#         -4.1699e-03,  1.4893e-03,  2.8274e-02, -3.4152e-02, -3.4548e-02,
#         -2.1255e-02, -2.0405e-02, -2.7044e-02,  3.0418e-02,  7.2105e-03,
#          7.4576e-03, -3.1467e-02,  2.3525e-02, -2.2469e-02,  5.4639e-03,
#         -2.0067e-02,  2.0650e-02,  7.8412e-03,  1.6499e-02, -1.3561e-02,
#          3.1990e-02, -1.2961e-02,  1.6529e-02,  7.2582e-03, -3.7681e-02,
#          2.8358e-02,  1.0448e-02,  1.7318e-03, -3.4367e-02,  5.2667e-03,
#          2.0068e-02,  2.5225e-02,  1.7085e-04, -3.3868e-02, -3.0144e-02,
#          1.4826e-02, -4.4774e-03,  3.4003e-03,  6.4563e-03,  1.2210e-02,
#         -2.9271e-02,  1.4356e-02, -5.3736e-03,  1.5723e-02,  2.0907e-02,
#         -1.0769e-02,  2.1915e-02, -3.2559e-02,  2.3866e-02, -3.0037e-02,
#          7.4096e-03, -3.2095e-02, -1.7652e-02,  4.3016e-03, -1.9915e-02,
#          3.0106e-02, -2.1436e-02, -2.5892e-02,  8.2996e-03, -2.3025e-02,
#          3.2147e-02, -1.2847e-02, -1.1717e-02, -9.9196e-03, -2.3405e-02,
#         -2.8149e-02,  1.8214e-02, -8.9459e-04, -6.6299e-03, -1.5890e-02,
#         -9.2779e-03, -1.4865e-02,  9.7765e-03, -1.1396e-02, -7.4375e-03,
#         -1.2330e-02,  1.2733e-02, -1.0176e-02,  1.0634e-02, -2.2080e-02,
#         -3.1141e-02,  6.3992e-04, -1.1758e-03,  6.4232e-04,  2.7200e-02,
#          1.7858e-02, -3.2018e-02,  8.6788e-03,  1.1127e-02,  1.3429e-02,
#          3.0900e-02, -2.1904e-02, -1.0484e-02, -2.2162e-02, -1.2238e-02,
#          2.7388e-02,  3.3277e-02, -2.1710e-02,  1.3705e-02,  2.4921e-02,
#         -1.3803e-02, -2.9361e-02, -2.0278e-02, -1.0721e-02,  1.5519e-02,
#          6.1975e-03,  1.8043e-02,  1.8398e-02,  3.0528e-02, -5.8010e-03,
#         -2.8242e-02,  1.4040e-02, -1.8481e-03, -2.5367e-02,  1.2356e-02,
#         -2.3469e-02, -1.2677e-02,  1.5184e-02, -1.5720e-02, -1.2411e-02,
#          3.1217e-02, -3.0069e-02,  2.7242e-03, -1.6598e-02,  2.4427e-02,
#         -2.8949e-02,  2.1957e-02, -6.7357e-03, -4.8904e-03,  1.8606e-02,
#          2.4289e-02, -3.0326e-02,  3.6537e-03, -7.9144e-03, -3.5702e-03,
#         -3.9920e-03,  2.6674e-02,  1.2820e-03, -1.0912e-04, -3.0273e-03,
#          1.5676e-02, -2.0162e-02, -3.4089e-02,  5.5755e-03,  3.0361e-02,
#         -1.9515e-02,  1.0003e-02,  8.8632e-03,  2.3180e-02,  7.3669e-03,
#         -2.7145e-03,  9.4633e-04,  1.6395e-02, -1.6580e-03, -2.3656e-02,
#         -5.8179e-03, -1.4666e-02, -1.8443e-04, -2.5139e-02,  2.7049e-02,
#          2.9654e-03, -8.9992e-03, -2.0723e-02, -4.0667e-03,  1.7162e-03,
#          2.9063e-02,  7.2380e-03,  2.5236e-03,  3.2032e-02,  1.8549e-02,
#          2.7457e-02, -1.3702e-02,  2.0656e-02, -2.3470e-02,  1.6852e-02,
#          1.0969e-02,  2.7397e-02, -8.7977e-03,  1.1843e-02,  3.3744e-03,
#         -3.0994e-02,  2.1801e-02, -2.9706e-02, -2.6023e-02, -8.2690e-03,
#         -8.8341e-03,  1.7581e-02,  1.7300e-02, -2.8252e-02, -8.9680e-03,
#         -1.5202e-02, -2.8544e-02, -1.0477e-02, -8.6913e-03,  2.1263e-02,
#         -2.8003e-02, -2.3665e-02, -2.7864e-02, -3.2677e-02,  2.3249e-02,
#          2.2354e-02, -6.2131e-03, -3.8592e-03,  1.6187e-02,  2.0539e-02,
#          1.3643e-02, -9.3222e-03,  2.6583e-02,  2.7269e-02,  8.0602e-03,
#         -2.6091e-02,  1.2464e-02, -2.5929e-02,  3.1768e-02, -1.4052e-02,
#          2.3494e-03,  1.2847e-02, -2.1107e-02, -1.6611e-02,  2.3743e-02,
#         -3.2507e-03, -1.1875e-02,  2.9532e-02, -4.0324e-04,  3.5315e-03,
#         -2.9240e-02, -2.7865e-02, -2.6379e-02,  2.1571e-02, -1.6827e-02,
#         -3.1286e-02,  1.4739e-02, -2.1390e-02, -3.1132e-02, -3.0402e-02,
#         -2.8223e-02, -1.8398e-02, -6.7490e-03,  3.9646e-02,  2.4659e-02,
#          2.4487e-02, -1.6736e-02, -2.8208e-02,  2.6662e-02, -2.8895e-02,
#         -1.4672e-02, -1.0138e-03, -3.9106e-02, -4.1023e-04,  2.6146e-03,
#         -2.8123e-02,  2.3652e-02,  3.6123e-03, -5.4925e-03, -1.9098e-02,
#          1.9509e-02, -3.1944e-02,  4.1500e-03, -1.8079e-02,  3.8921e-03,
#         -1.1470e-02, -4.9598e-03,  1.7685e-02, -3.7645e-03,  1.4680e-02,
#         -1.9267e-02,  9.1993e-05, -9.0442e-03,  3.0578e-02,  1.3292e-02,
#          2.3791e-02, -2.3603e-02,  2.8646e-02, -3.9579e-04, -2.9103e-02,
#          1.7320e-02, -2.7198e-02,  2.7439e-02,  2.4842e-02, -7.8135e-03,
#         -2.6831e-02, -2.7202e-02,  1.6476e-02, -2.6091e-02, -2.9337e-03,
#         -7.0863e-03,  2.3675e-02,  7.9154e-03,  9.0150e-03, -1.0523e-02,
#          2.5261e-02,  2.0984e-02,  2.6341e-02,  2.2772e-02, -2.7819e-02,
#         -2.0783e-02, -2.2009e-03,  3.8177e-03,  2.8162e-02,  1.1913e-02,
#         -1.7300e-02, -2.4767e-02,  2.3652e-02, -9.4774e-03,  4.8648e-03],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0256,  0.0050,  0.0008,  ...,  0.0316,  0.0264, -0.0347],
#         [-0.0177, -0.0028,  0.0003,  ..., -0.0118, -0.0229, -0.0376],
#         [ 0.0223, -0.0355, -0.0051,  ...,  0.0029, -0.0127, -0.0110],
#         ...,
#         [-0.0089, -0.0272, -0.0267,  ..., -0.0003,  0.0205, -0.0221],
#         [-0.0365,  0.0112, -0.0075,  ..., -0.0102, -0.0241,  0.0160],
#         [ 0.0263, -0.0308,  0.0254,  ...,  0.0054, -0.0338,  0.0361]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-3.3433e-02,  1.0088e-02, -1.7315e-02,  1.1555e-02,  1.3804e-02,
#          2.0118e-02,  2.5337e-02,  1.2852e-02,  3.3911e-02,  2.6534e-03,
#         -3.8014e-02,  2.5560e-02, -3.4354e-02, -2.9052e-02,  2.2418e-02,
#          3.5763e-02,  8.1305e-03,  7.0245e-04,  2.2403e-02, -1.5051e-02,
#         -3.3189e-02,  1.1975e-02, -3.5065e-03,  2.5433e-02, -2.9877e-02,
#         -2.3199e-02, -1.4059e-02, -3.0228e-02, -2.4606e-02,  1.0776e-02,
#         -7.8367e-03, -2.7064e-02,  5.7560e-03,  2.6224e-02, -4.3213e-03,
#         -2.4672e-02, -1.9300e-02, -2.2803e-02, -1.5885e-02,  1.7193e-03,
#         -3.1200e-02,  1.8805e-02, -1.1682e-02, -3.0354e-02, -3.2378e-02,
#         -1.7660e-02,  2.9765e-02, -1.0891e-02,  2.6607e-02, -2.4437e-02,
#         -1.5874e-02, -2.6914e-02, -9.1926e-03,  2.9604e-02, -5.4778e-03,
#         -1.2316e-02, -3.6910e-02,  1.2823e-02, -1.9875e-02, -3.8832e-02,
#         -1.2300e-03,  9.2381e-04,  3.8356e-03,  2.6971e-02, -1.3995e-02,
#          1.7291e-02, -3.7079e-02,  2.5774e-02,  8.0423e-03,  1.9109e-02,
#         -3.3680e-02, -2.0602e-02, -1.5742e-02,  1.6155e-02,  1.9693e-02,
#          2.2352e-03,  6.6661e-03, -2.1291e-02, -3.1545e-02,  8.0565e-03,
#         -2.2797e-02,  2.2874e-02,  3.0235e-02,  1.4285e-02,  3.5486e-02,
#          1.7045e-02, -3.6525e-02, -1.7569e-02, -3.6849e-03,  2.3311e-02,
#          1.2348e-02, -3.3992e-02,  2.8224e-02,  3.1276e-02, -6.9981e-03,
#          8.5252e-03, -3.1328e-02,  1.7703e-02,  1.8292e-02, -3.0418e-02,
#          2.5006e-02, -3.3459e-02,  1.7922e-02, -2.5070e-02, -3.7110e-02,
#          4.5960e-03, -3.5333e-02, -2.6135e-02, -1.5645e-02,  3.0973e-02,
#         -1.8378e-02,  1.0947e-04, -1.6599e-02, -3.8005e-02,  3.2412e-02,
#          1.4529e-02, -1.8069e-02, -1.3653e-02,  2.1411e-03, -7.0462e-03,
#          1.8205e-03, -9.1590e-03, -2.0029e-02,  1.3009e-02,  2.4749e-02,
#         -2.7761e-02,  6.1411e-03,  3.0898e-02,  1.0098e-02,  7.5646e-03,
#          1.0120e-02,  1.3817e-02,  2.4889e-03, -3.3293e-02,  1.4703e-02,
#         -3.1058e-02,  3.4465e-03, -5.2375e-03, -1.5571e-02, -2.7686e-02,
#          9.7646e-03,  2.4083e-02, -1.0557e-02, -2.4151e-03,  1.8073e-02,
#          2.5990e-02, -2.6779e-02,  1.9199e-02, -6.6912e-03,  1.1795e-02,
#          2.9784e-02,  1.3568e-03, -9.1380e-03, -1.9059e-02, -3.9758e-03,
#          2.3040e-02,  1.5786e-02,  1.9339e-02,  2.2048e-02,  4.1570e-03,
#         -2.4380e-02,  2.0298e-03,  7.0166e-03,  8.5679e-03,  1.1992e-02,
#          1.7800e-02, -3.0656e-02,  8.6871e-03,  2.5208e-02,  3.0590e-02,
#          8.5796e-03, -1.5792e-02,  3.3816e-02,  1.1066e-02,  3.1762e-02,
#          3.5345e-02, -1.3760e-03, -2.0201e-02,  7.6686e-03,  7.5903e-03,
#          1.4519e-02, -9.6425e-03, -2.0763e-04, -1.0372e-02, -1.1838e-02,
#          2.2425e-02,  9.9995e-03,  3.9345e-03,  2.3054e-02, -2.8603e-02,
#          1.8109e-02,  3.1742e-02, -3.3174e-02, -3.4664e-02,  1.8777e-02,
#          1.7414e-02, -1.2217e-02, -3.1612e-03, -2.9348e-02, -4.8952e-03,
#         -1.8244e-02, -1.6545e-02, -2.9301e-02,  1.5571e-02, -5.8677e-03,
#          1.0062e-03,  3.3484e-02,  2.0996e-02, -2.9417e-02,  2.9596e-02,
#         -2.0666e-02,  2.4566e-03,  3.4009e-04,  1.8612e-02, -3.7389e-03,
#          4.6121e-03,  2.8737e-02, -2.8816e-02,  9.7840e-03,  6.6094e-03,
#         -2.0003e-02,  2.7508e-02,  2.4168e-03,  6.4410e-03, -3.4033e-02,
#          3.7358e-02, -2.4205e-02, -1.6966e-02, -2.3299e-02, -3.7806e-02,
#          2.1757e-02, -2.4989e-02,  3.3767e-04, -1.9675e-03, -3.4094e-02,
#         -2.6098e-02,  5.0234e-03,  1.5229e-02, -1.5480e-02, -3.2177e-03,
#         -3.5964e-02,  3.5127e-02, -1.4287e-02,  1.0755e-02,  3.0811e-02,
#         -7.0118e-04, -3.5930e-02, -1.4821e-02,  9.3687e-03, -1.7867e-02,
#          1.5362e-02, -1.4113e-02, -3.2818e-02,  8.2295e-03,  2.1419e-02,
#         -2.3095e-03, -2.1508e-02, -1.5008e-02, -3.2520e-02,  3.1466e-02,
#          2.8819e-03, -2.9016e-02,  1.2288e-02, -4.5892e-04, -3.3283e-02,
#          2.3759e-02,  2.4413e-02,  8.5230e-03,  1.5232e-02, -2.7593e-02,
#         -2.6959e-02, -2.4732e-02,  1.3739e-02,  2.8728e-02, -1.3242e-02,
#         -1.3960e-02, -1.8497e-02, -3.0655e-02,  3.4352e-02,  2.8285e-02,
#         -3.8854e-02, -6.8137e-04, -6.9336e-03, -2.0249e-03,  6.4608e-04,
#          1.9840e-02,  9.7297e-03, -4.8097e-03,  2.0947e-02, -8.7084e-03,
#         -1.0564e-02, -2.2666e-02, -3.8520e-02, -3.5477e-02, -1.0704e-02,
#         -3.3905e-02, -9.5294e-03,  1.0875e-02, -2.5318e-02,  1.8171e-02,
#          2.9865e-02,  2.9568e-03, -1.2046e-02,  2.9009e-02, -3.9471e-02,
#          6.2804e-03, -8.8717e-03,  3.4696e-02, -1.6523e-02,  2.0725e-03,
#         -1.9235e-02,  1.6709e-02, -9.3412e-04, -2.3195e-02,  7.9592e-03,
#         -2.6585e-03,  2.5847e-02, -2.5826e-02, -3.0205e-02,  1.3086e-02,
#         -1.3359e-02,  3.1920e-02,  3.1153e-02,  2.8801e-02,  3.4030e-02,
#          3.0960e-02,  2.0708e-02,  2.8889e-02, -1.4189e-02, -2.2614e-02,
#         -1.9555e-02,  8.7599e-03,  1.3019e-02,  1.5776e-03, -3.9941e-02,
#          8.6152e-03, -1.5708e-03, -4.3612e-03, -1.6373e-02, -3.1675e-02,
#          1.9545e-02,  9.1255e-03,  3.2760e-03,  3.5640e-02,  2.8447e-02,
#          2.8700e-02,  6.0698e-03, -1.4733e-03,  7.7081e-03,  3.4514e-02,
#          2.4799e-02, -2.3549e-02, -3.7236e-03,  2.1877e-02,  2.9383e-03,
#         -1.1847e-02, -6.2165e-03, -2.6979e-02, -3.2927e-02, -2.5065e-02,
#          7.3243e-03,  4.3450e-03,  7.2391e-03, -3.1675e-02,  3.1017e-02,
#          5.5395e-03, -2.4027e-02, -1.5077e-02,  1.6086e-02, -7.1667e-03,
#          1.6201e-02,  2.4013e-02,  1.3221e-02,  9.4276e-03,  1.8044e-02,
#          9.6352e-04,  1.4862e-02, -3.0501e-02, -1.0522e-02, -1.9290e-02,
#         -6.5045e-04, -3.3195e-02, -8.5112e-03, -1.0691e-02, -3.7739e-02,
#          2.3898e-02,  8.1964e-03, -2.0046e-02,  2.5437e-02, -1.3629e-02,
#          1.9998e-02,  1.7355e-02, -8.9565e-03, -2.6987e-02, -2.9569e-02,
#         -2.0629e-03,  3.4116e-02, -2.1622e-02,  1.7405e-03, -1.1598e-02,
#          3.3722e-02,  1.3486e-02,  1.8780e-02,  3.3845e-02, -3.0550e-02,
#         -2.9526e-02,  9.8578e-03,  2.9776e-02, -2.4563e-02,  3.4312e-02,
#          2.9336e-02, -1.7256e-02,  1.7740e-02,  2.6482e-02,  1.9030e-02,
#          3.4382e-02, -2.2393e-02, -4.3642e-03,  1.3918e-03,  3.8968e-02,
#          2.6302e-02,  1.5797e-02, -8.6564e-03, -2.7788e-02, -1.0343e-02,
#         -3.0556e-02, -2.9031e-02,  3.5548e-02,  2.0096e-03, -6.3906e-03,
#         -8.9334e-03,  2.3651e-02,  1.5362e-02,  9.0196e-03,  9.1213e-03,
#         -2.5697e-02, -1.4274e-02,  1.0733e-02, -2.8496e-02, -1.2242e-02,
#         -6.8422e-03,  5.6213e-03,  2.0386e-02,  3.3237e-02,  1.9454e-02,
#          2.4529e-02, -3.5538e-02, -2.9880e-02, -2.4128e-02, -6.3102e-03,
#         -3.0956e-02,  2.9105e-03, -2.1094e-03, -3.0026e-04,  3.4358e-02,
#          1.6189e-02, -1.1186e-03, -4.4572e-03, -1.5867e-03,  2.7528e-02,
#          3.1891e-03,  3.8067e-03, -8.0532e-03, -9.4393e-03,  2.6138e-02,
#         -2.0130e-02,  1.7371e-03, -1.1904e-02, -1.2045e-02,  1.5227e-02,
#          2.5623e-02,  6.0706e-03, -2.3858e-02,  1.7062e-02,  4.9357e-03,
#          2.3528e-02, -2.7303e-03,  2.6619e-02,  1.1904e-02,  3.5313e-02,
#         -4.5872e-03, -2.6892e-02,  3.4548e-02,  2.0146e-02, -1.8343e-02,
#         -7.7302e-03, -6.2882e-03,  3.2206e-02, -1.5241e-02,  2.1146e-02,
#         -3.2912e-02, -1.6862e-02, -2.1201e-02,  1.6790e-02, -8.8222e-03,
#         -5.5975e-03,  1.7259e-02, -2.2579e-03, -2.8657e-02, -1.1749e-02,
#         -3.1286e-02,  2.3392e-02, -1.5827e-02, -3.1087e-02,  2.4764e-02,
#         -1.1634e-02, -1.8345e-02,  1.2877e-02,  1.1240e-02, -3.0706e-02,
#          3.8659e-03, -4.5538e-03, -1.0127e-02,  1.1759e-03, -5.8159e-03,
#          4.7388e-03,  2.4140e-02,  2.3596e-02,  1.1583e-02,  1.2437e-02,
#         -2.3911e-02,  2.2785e-02, -4.3299e-03, -7.0486e-03, -3.5438e-02,
#         -1.8180e-02,  5.2524e-03, -3.3761e-02,  3.3045e-02, -1.7740e-02,
#         -2.8436e-02, -3.3926e-02, -2.4934e-02,  2.7759e-02, -5.9123e-04,
#         -3.0590e-02, -3.3783e-02,  5.7499e-03,  1.7440e-02,  1.0090e-02,
#          4.2221e-03,  2.9207e-02,  2.7148e-02, -5.2852e-03, -6.4436e-03,
#          2.0831e-02,  2.8212e-02, -3.5821e-02,  3.1701e-02, -7.6090e-03,
#          7.0977e-03,  5.0319e-03, -3.2172e-02, -2.3980e-03,  1.3860e-02,
#         -3.9435e-03, -1.1970e-03,  3.7128e-02,  1.9034e-02,  1.9614e-02,
#          2.6673e-03,  1.5465e-02, -2.6496e-03,  1.2718e-02, -2.0575e-02,
#         -5.2172e-03,  3.3415e-02, -2.5798e-02, -3.6610e-02, -1.4467e-02,
#          7.8263e-03, -1.4587e-02, -1.1086e-02, -2.8406e-02,  2.7740e-02,
#          6.4845e-03, -2.3192e-02, -3.5886e-02, -1.7962e-02, -3.7089e-02,
#         -2.5317e-02,  1.9813e-02, -1.0750e-02, -8.2324e-03, -3.0732e-02,
#          7.4805e-03,  2.6592e-02, -7.7360e-03,  9.0657e-03, -2.2457e-02,
#         -1.0287e-02,  1.9019e-02,  1.2113e-02,  8.3673e-03, -3.4256e-03,
#          9.9436e-03, -1.3698e-02, -4.2793e-03, -8.6202e-03, -7.1471e-03,
#          3.4894e-02, -3.8545e-02, -1.8126e-02, -2.1943e-02,  1.6190e-02,
#          2.7423e-02,  1.3628e-02,  6.2209e-03, -3.4107e-02, -1.8589e-03,
#         -1.4154e-02, -2.9276e-02,  3.2322e-02,  3.9176e-02,  1.4267e-03,
#          1.0415e-02,  5.3706e-03,  2.8721e-02, -3.4416e-02, -2.6853e-02,
#          1.4104e-02, -4.5175e-03, -1.9961e-03, -3.0790e-02,  3.0512e-02,
#         -2.9559e-02, -2.2476e-03, -2.5889e-02,  2.9981e-02, -1.0343e-02,
#         -1.7942e-03, -2.5725e-02, -3.8282e-03,  2.6800e-02,  3.0227e-02,
#          1.2858e-02,  2.4759e-02, -3.2648e-02,  7.4258e-03,  4.0313e-03,
#          4.7966e-03, -1.4717e-02,  2.7153e-03,  1.4435e-02, -1.1729e-02,
#         -2.1233e-02,  2.9850e-02, -2.5915e-02,  1.6868e-02,  3.1713e-02,
#          1.5128e-02,  8.6744e-03, -4.2085e-02, -2.8778e-02,  2.0635e-02,
#         -2.8940e-02, -1.7957e-02, -6.6418e-03,  1.5757e-02, -7.2058e-03,
#          2.3186e-02, -3.5996e-02, -1.5913e-02, -1.6448e-02,  3.0441e-02,
#         -1.4165e-02,  2.9231e-02, -3.2646e-02,  3.8530e-04, -1.4177e-02,
#          2.9765e-03,  2.0653e-03,  3.3208e-02, -3.3326e-02,  3.3926e-02,
#         -4.3477e-03, -2.5801e-02, -2.9279e-02,  1.8531e-02, -2.9204e-02,
#          4.4656e-03,  1.7940e-02,  3.5832e-02,  3.7559e-02, -2.6208e-02,
#         -2.6961e-02,  2.3892e-02,  2.2296e-03,  2.0909e-02, -3.5297e-02,
#          1.9858e-02,  1.3971e-02,  1.3493e-02,  1.2311e-02, -1.4554e-03,
#         -1.5428e-02,  9.1470e-03,  1.0985e-02, -1.8840e-02, -1.0562e-02,
#          6.8789e-03, -3.0716e-02,  2.0629e-02,  8.0562e-03, -3.3360e-02,
#          2.5288e-02, -2.0937e-02,  2.2568e-02,  3.0532e-02, -4.0342e-03,
#          2.7497e-02,  3.9924e-02,  2.5660e-03,  9.4359e-03,  1.1584e-02,
#         -2.4076e-02,  1.2374e-03,  2.4729e-03,  7.9716e-04, -1.0364e-02,
#          3.6931e-03, -2.8496e-02,  3.1323e-02,  3.8118e-02,  1.9118e-02,
#         -2.3349e-02,  3.3034e-02, -1.9000e-02, -2.3116e-02,  2.5320e-02,
#         -3.1348e-02,  2.0482e-03,  2.7545e-02, -2.1042e-02, -1.3319e-02,
#         -1.9148e-02, -1.2188e-02,  3.3747e-02,  3.6868e-03, -1.9515e-02,
#          7.6656e-04, -3.7143e-02,  6.9474e-03, -1.9240e-02,  2.7420e-02,
#          2.5923e-02, -3.3895e-02, -4.0868e-02, -1.3612e-03,  6.5439e-03,
#         -1.7236e-02,  2.6937e-02,  1.5018e-02,  1.7434e-02, -1.5727e-02,
#          3.2208e-02, -1.9376e-02, -3.1937e-02, -3.6156e-02, -1.1754e-02,
#          9.1020e-03, -2.4964e-02,  8.0740e-03,  1.1798e-02,  2.2263e-02,
#         -9.5019e-03,  8.8039e-03, -2.0237e-02,  6.1342e-03, -2.4751e-02,
#          2.5852e-02, -2.0762e-02,  2.6144e-02,  2.1514e-02, -3.7445e-02,
#         -1.1822e-02, -3.4335e-03,  2.5368e-02, -7.2454e-03, -2.5221e-02,
#         -3.5504e-02,  2.2052e-02, -1.3658e-02,  3.4100e-02, -2.5192e-02,
#         -6.1144e-03,  3.6546e-02, -5.6366e-03, -6.0857e-03,  2.8845e-02,
#         -3.5907e-02,  2.4774e-02,  2.2641e-02,  1.1458e-02, -6.5549e-03,
#          8.7348e-03, -2.9146e-02, -6.7316e-03,  1.4234e-02,  2.1516e-02,
#          2.2584e-02, -1.7397e-02,  3.2178e-03,  2.4292e-02,  2.1277e-02,
#         -2.8861e-02, -3.4443e-02, -2.2292e-02, -1.5098e-02,  3.0964e-02,
#          1.1106e-02,  2.7126e-02,  7.5440e-03,  2.3087e-02, -1.6267e-02,
#          8.4463e-03,  2.4751e-02, -4.1414e-05, -2.6204e-02,  2.7404e-02,
#          1.2811e-02,  2.8110e-02, -1.6883e-02,  9.6921e-03, -3.6746e-02,
#          2.1528e-02, -6.9322e-03,  1.4481e-02,  3.2928e-02, -3.5648e-02,
#          3.3189e-02, -2.9149e-03,  3.5056e-03,  6.7146e-03,  2.1043e-02,
#         -7.7083e-03,  1.1173e-02, -1.4766e-02, -2.6583e-02, -4.5554e-03,
#         -1.8190e-02, -1.5294e-02,  2.3218e-03, -2.6795e-02,  1.1386e-02,
#         -2.7476e-02,  2.2592e-02,  3.5162e-02, -3.8385e-02,  1.6617e-03,
#          3.3131e-02, -3.1134e-02,  9.9623e-03, -2.8179e-02,  1.3790e-02,
#          8.3366e-03, -3.7018e-02, -9.5471e-03, -2.0404e-02,  8.8928e-03,
#         -9.7352e-03,  2.8869e-03, -1.9461e-02,  3.4353e-03,  1.6585e-02,
#         -1.2832e-02,  2.0594e-02, -7.2709e-03,  4.4800e-03, -2.3017e-03,
#         -3.1693e-02, -6.8958e-03, -2.4355e-02, -1.3156e-02,  3.0942e-02,
#          2.4739e-02,  2.5848e-02, -1.7154e-02,  3.7244e-02, -3.1933e-02,
#         -3.4959e-02,  4.8998e-04, -1.2789e-02,  1.8819e-02, -1.7911e-02,
#         -3.6509e-02, -3.5201e-02, -3.8000e-02,  3.9763e-02,  6.0033e-03,
#          5.4890e-03, -2.1235e-02, -2.8736e-02, -3.1731e-02,  1.1192e-02,
#         -3.5590e-02, -2.1306e-02,  1.4404e-02,  1.2968e-02, -1.5478e-02,
#          1.6058e-02,  3.1359e-02,  8.6954e-03,  1.9594e-02, -2.7099e-03,
#         -3.7228e-02,  1.8265e-02,  1.9775e-02,  1.5894e-02, -2.0027e-02,
#         -2.9665e-02,  7.1031e-03, -3.9023e-02, -4.0127e-03, -1.1550e-02,
#         -6.6930e-03, -1.9874e-02, -2.6593e-02,  3.0423e-02, -4.5152e-04,
#         -2.0298e-02,  2.0058e-02,  9.5116e-03,  3.5813e-02,  1.9792e-02,
#         -2.7937e-02,  2.8904e-02,  2.6493e-02, -6.9786e-03,  4.9849e-03,
#          1.7729e-02,  7.0577e-03,  1.8185e-02,  1.0223e-02, -8.2851e-03,
#         -3.8607e-02, -2.8320e-02, -5.0101e-03, -5.3026e-04, -7.1175e-03,
#         -2.2831e-02,  3.0515e-02, -5.2846e-03,  1.2986e-02,  3.8330e-02,
#         -5.6933e-04,  1.5743e-02, -3.2131e-02,  1.8337e-02,  1.2264e-03,
#         -3.7159e-02, -6.3872e-03, -1.2050e-02, -2.4075e-02,  2.5462e-02,
#         -2.4760e-02,  2.1630e-03,  3.4930e-02, -2.8806e-03,  1.3309e-02,
#          8.7116e-03,  1.2038e-02,  1.8960e-02, -3.0859e-03,  2.5609e-02,
#          2.0512e-02, -1.7839e-02, -3.7036e-02, -2.5602e-04, -2.1523e-02,
#          7.8869e-03,  1.8169e-02, -1.7561e-02,  2.8851e-03,  1.6798e-02,
#         -5.3780e-03, -8.1937e-03,  3.6506e-02,  1.2378e-02,  9.6542e-04,
#          3.5003e-02, -1.2257e-02, -2.8790e-02, -1.7084e-02, -3.8421e-03,
#         -3.6285e-02,  9.2310e-03,  2.6738e-02, -2.1916e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0238,  0.0001, -0.0222,  ...,  0.0259,  0.0227, -0.0130],
#         [-0.0109,  0.0059,  0.0207,  ..., -0.0010,  0.0104, -0.0271],
#         [ 0.0126,  0.0318, -0.0267,  ...,  0.0010, -0.0135,  0.0191],
#         ...,
#         [-0.0112, -0.0040,  0.0075,  ..., -0.0325,  0.0462, -0.0267],
#         [-0.0005, -0.0161,  0.0118,  ...,  0.0233, -0.0245,  0.0310],
#         [ 0.0282,  0.0082, -0.0131,  ...,  0.0280,  0.0320,  0.0221]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 2.2797e-02,  5.3039e-03, -1.7466e-02,  1.8118e-02, -1.2966e-02,
#         -2.0916e-02, -9.5724e-03,  2.8303e-03,  1.4512e-02, -2.3265e-03,
#          2.7124e-03, -2.8902e-02, -3.1648e-02,  2.0558e-02, -3.3483e-02,
#         -4.8372e-03, -5.0136e-03, -1.2792e-02,  2.9727e-02,  5.2491e-03,
#         -1.3435e-02, -2.0119e-02, -2.3168e-02, -1.8538e-02,  1.7572e-05,
#          2.2765e-02,  1.9163e-02,  2.2773e-03,  2.0045e-02,  8.1675e-03,
#         -9.8198e-03, -4.7332e-03,  1.5949e-02,  1.1143e-02,  1.2208e-02,
#         -1.8318e-02,  2.1678e-02,  1.1916e-03, -1.4703e-02, -1.5149e-02,
#         -2.4143e-02, -2.8627e-02,  1.4107e-02,  1.1177e-02, -2.0446e-02,
#          1.4354e-02,  2.1095e-02, -4.5120e-03, -3.2073e-03,  4.3145e-03,
#          7.7136e-03, -1.5547e-02, -2.4648e-02,  2.2146e-02, -1.9575e-02,
#          1.9489e-02,  2.2330e-02, -1.3551e-02,  1.2113e-02, -8.0878e-03,
#          2.9491e-02, -3.0799e-02,  1.2504e-02, -8.5808e-03, -2.2987e-02,
#          2.2646e-02, -2.7518e-02,  1.8772e-02, -2.7943e-02,  2.3814e-02,
#         -2.8122e-02, -1.2152e-02, -2.2849e-02, -2.5280e-02, -1.6859e-02,
#          3.0207e-02, -1.5273e-02,  7.6413e-03, -2.2747e-02,  1.1530e-02,
#          3.0025e-03,  2.3164e-02,  1.7600e-02, -8.4929e-03, -9.0112e-03,
#         -2.3049e-02, -2.5906e-02,  7.3704e-04,  3.4048e-02,  1.5967e-02,
#          2.3849e-02, -1.8138e-02, -1.9478e-02,  2.9098e-02,  3.5174e-03,
#         -2.8453e-02, -2.0729e-02, -1.1465e-03, -2.6284e-02, -1.0226e-02,
#          1.4311e-02,  2.3921e-02,  9.8973e-03, -1.8984e-02, -1.1671e-02,
#         -1.1816e-02,  3.3903e-02, -2.1695e-02, -1.3518e-02,  2.5522e-02,
#         -2.4750e-02,  1.9863e-02,  2.0374e-02, -2.1659e-02,  1.4186e-02,
#          2.1326e-02, -2.4187e-02, -4.6927e-03, -1.6643e-02,  6.7343e-03,
#         -1.9287e-02,  2.2433e-02,  2.5659e-02,  1.2223e-02, -7.9314e-03,
#          1.5384e-02,  2.5141e-02,  3.3497e-02, -2.1108e-03, -1.6362e-02,
#         -2.9692e-02, -8.9396e-04,  1.5135e-02, -1.8258e-02,  2.0400e-02,
#         -2.6834e-02,  1.0638e-02,  2.0557e-02, -2.0102e-02,  8.5654e-03,
#         -2.3459e-02, -4.7496e-03, -1.8505e-02, -1.0601e-02, -6.2731e-03,
#          1.5460e-02,  3.2834e-02, -2.8859e-03, -4.4223e-03, -2.6199e-02,
#         -1.5798e-02,  1.2842e-02,  3.1610e-02,  1.4278e-02,  3.1410e-02,
#         -1.2012e-02,  1.1369e-02,  7.9331e-04, -2.6568e-02,  2.3969e-02,
#          2.2148e-02, -3.1658e-03,  1.9815e-02, -1.7566e-02, -2.1669e-02,
#         -1.6813e-02, -2.2238e-02,  2.0450e-02, -2.5015e-02,  3.0301e-02,
#         -1.3383e-02,  1.6164e-03,  1.6393e-02, -2.4806e-02,  2.5285e-02,
#         -1.7792e-02, -1.2870e-02,  9.4381e-03, -1.7158e-02,  2.5707e-02,
#          2.7712e-02, -6.2615e-03,  1.3257e-03, -9.4087e-04, -2.5881e-02,
#         -2.7452e-02,  9.8865e-03, -2.6378e-02,  3.1829e-02, -2.7868e-02,
#          1.0025e-02,  1.5727e-02, -3.0749e-02, -7.1063e-03, -1.8766e-03,
#          8.1553e-03, -1.6611e-02, -7.9622e-03, -2.0186e-04, -8.4521e-03,
#         -2.8760e-03, -9.7305e-03, -2.6165e-02, -3.3107e-02,  1.4029e-02,
#         -5.5513e-03, -1.6290e-03, -5.2544e-03,  7.8204e-03, -2.1947e-02,
#          2.2426e-02,  2.4640e-02,  2.6730e-02,  2.9307e-02,  2.6034e-02,
#         -1.2631e-02,  2.5880e-03,  4.5194e-03,  2.2003e-02,  2.3851e-02,
#         -3.3092e-02,  1.1045e-02,  1.2318e-02,  1.9134e-02,  2.3030e-02,
#          2.6391e-02,  2.5083e-02,  2.1346e-02,  2.7919e-02,  1.5650e-02,
#          5.4978e-03,  2.1739e-02,  9.2633e-03, -6.7770e-03, -5.6715e-03,
#         -8.6117e-03, -2.5043e-02, -7.7056e-04, -4.5929e-03,  1.9689e-02,
#         -3.2545e-02, -2.1630e-02, -5.6770e-03,  8.6417e-03, -1.1635e-02,
#          2.4951e-02, -1.3135e-02,  5.2484e-03,  2.7856e-02, -2.0698e-02,
#         -1.8695e-02,  1.3315e-02,  2.9087e-02, -2.1805e-02,  1.2951e-02,
#         -1.4607e-02, -1.9923e-02,  6.6556e-03, -3.5085e-03, -2.4799e-02,
#          1.7730e-02,  1.2800e-02, -1.5814e-02, -1.9941e-02, -2.9747e-02,
#         -3.1621e-02,  1.5087e-02, -1.2591e-02,  2.4017e-02,  1.3015e-02,
#          1.4488e-02,  1.1205e-02,  1.8991e-02, -2.8987e-04, -1.8525e-02,
#          2.1767e-02, -2.7613e-02, -5.2606e-04, -2.5164e-03, -6.7868e-03,
#         -1.3137e-02,  2.3253e-02,  2.4083e-02,  2.1094e-02, -1.2349e-03,
#         -2.0243e-02, -2.5565e-02,  3.0128e-02, -4.3012e-03,  3.3320e-03,
#         -2.0242e-02,  2.3801e-03,  1.2599e-02,  2.1717e-03, -2.2725e-02,
#         -1.8134e-02,  6.9744e-03,  2.6895e-02, -2.9277e-02, -1.4490e-02,
#          1.8832e-02, -9.6978e-03, -4.4133e-03, -1.0428e-02,  2.4109e-02,
#          1.7435e-02,  2.2393e-02, -5.9590e-03,  2.8719e-02,  5.4231e-03,
#          2.7801e-02, -9.4561e-03, -1.4193e-02, -2.6813e-02,  3.7918e-04,
#          1.4844e-03, -1.4760e-02, -8.0552e-03, -3.0459e-02, -1.4793e-02,
#          2.2373e-02,  2.8898e-02,  3.3558e-02,  1.8384e-02,  1.4853e-02,
#         -1.4580e-03, -7.9142e-03,  1.9683e-02, -2.0722e-02, -1.1707e-02,
#         -2.0709e-02, -2.0059e-02, -8.4255e-03, -3.0117e-03,  1.4990e-03,
#          2.7381e-02, -2.4559e-03, -3.0645e-02, -2.8792e-02,  2.1667e-02,
#          1.3292e-02,  1.4574e-02,  1.1132e-02,  6.3941e-03,  1.9354e-02,
#         -1.5894e-02,  2.2805e-02,  2.4949e-02, -2.1671e-02, -3.9728e-03,
#         -2.2508e-02, -6.5806e-03, -2.7002e-02,  1.9192e-02,  1.1666e-02,
#          1.1574e-02, -4.9970e-03, -8.5795e-03,  1.1449e-03, -3.4424e-02,
#          2.1968e-02,  1.3108e-02, -2.5838e-02, -2.2965e-02,  2.2304e-02,
#         -2.7064e-02,  1.7899e-03,  4.2982e-03,  2.2276e-02, -1.9189e-02,
#          1.8723e-02, -2.6141e-04,  1.0621e-02, -1.1753e-02, -1.7206e-02,
#          2.5523e-02,  1.0626e-02,  2.8680e-02,  2.2880e-02, -1.2356e-02,
#         -5.2589e-03, -1.4750e-02,  5.2899e-03, -2.3291e-02, -4.5088e-03,
#         -2.6658e-02, -7.7310e-03,  2.3300e-02,  2.5793e-02,  2.4470e-02,
#         -1.5007e-02,  1.6274e-02,  3.0193e-02, -2.6785e-02,  1.2306e-02,
#         -5.2207e-03, -2.5619e-03, -2.1693e-03,  2.8743e-02, -3.2643e-03,
#         -3.0485e-02, -2.9871e-02,  7.6798e-03,  2.4455e-02, -1.3084e-02,
#          2.7269e-03, -8.7948e-03,  6.0306e-03, -1.4082e-02,  1.8245e-02,
#          2.7146e-02, -4.6475e-03, -2.2069e-02, -1.3805e-02,  4.7140e-03,
#         -1.5807e-02, -3.7091e-03, -4.3208e-03,  3.0258e-02,  2.9937e-02,
#         -4.5360e-03,  2.5031e-02, -5.9761e-03, -1.1617e-02,  1.5293e-02,
#          7.6715e-03,  7.7226e-03, -8.1980e-03,  8.2457e-03,  1.2706e-02,
#          2.3077e-02, -1.6161e-02,  1.4043e-02, -2.0139e-02,  1.2936e-02,
#         -1.4637e-02, -2.6367e-02, -2.4996e-02, -8.0577e-03,  1.9949e-02,
#          2.1701e-02,  2.4550e-02,  3.5360e-03, -1.7012e-02, -2.3162e-02,
#          4.0443e-03, -1.1556e-02, -2.9198e-02,  3.0129e-02,  7.1528e-03,
#         -9.4022e-03, -1.6991e-02,  1.8806e-02, -2.6402e-02,  2.4227e-02,
#         -1.9426e-02,  3.6811e-03,  2.4716e-02, -3.0333e-03, -2.7457e-02,
#          2.9599e-02, -1.3990e-02, -3.1326e-02, -2.7242e-02,  2.8455e-02,
#         -2.0590e-02, -1.1063e-02, -4.8865e-03, -8.4844e-03, -2.5128e-02,
#         -3.3373e-02,  1.3738e-02,  5.0829e-03, -2.8015e-02, -4.9686e-03,
#         -1.2866e-02,  2.3880e-02,  8.5485e-03, -2.5185e-02, -5.8503e-03,
#          1.8303e-02, -8.6672e-03,  2.8426e-02,  1.7247e-02,  2.1306e-02,
#         -2.7342e-02, -1.5537e-02,  2.8359e-02, -1.7898e-02, -2.4308e-02,
#          1.3883e-03,  2.9384e-02, -2.0425e-02,  1.2998e-02,  3.6402e-03,
#         -3.7168e-03, -1.1495e-02, -1.5485e-03, -6.9615e-03, -1.5799e-02,
#         -6.2259e-03, -6.0779e-03,  1.4925e-03,  8.9204e-03,  5.7965e-03,
#          1.8202e-02,  3.2989e-02,  4.5080e-03,  2.3680e-02,  1.0907e-02,
#          9.4396e-03, -1.4725e-02, -1.4501e-02,  2.3672e-02,  1.7302e-02,
#         -3.1640e-02,  2.4180e-02, -1.8217e-02,  3.4733e-03,  2.2564e-02,
#         -3.1570e-02, -1.9351e-02, -1.1581e-02,  2.9566e-02,  2.3808e-02,
#          1.2018e-02,  2.7164e-02, -1.4856e-02, -1.7184e-02, -4.3657e-03,
#         -1.1064e-02, -6.2580e-03,  1.3008e-02, -7.6189e-03, -1.5284e-02,
#          1.6197e-02,  1.6639e-02, -1.9033e-02, -1.6065e-02, -2.1268e-02,
#          1.4057e-03,  8.1535e-03, -3.0067e-02, -2.7391e-02,  1.5501e-02,
#         -2.2537e-02,  9.6004e-03,  6.4805e-04, -2.3988e-02,  5.9036e-03,
#          1.6920e-02, -1.0193e-02, -3.0116e-02,  1.7380e-02, -2.2944e-03,
#          3.2452e-02, -3.3852e-03,  1.7647e-02,  2.0923e-02, -2.6650e-02,
#          1.4941e-02, -2.3806e-02, -2.9960e-02,  3.2715e-02, -2.9792e-02,
#          1.5323e-03, -1.7969e-02, -4.3232e-03,  8.4602e-03,  1.2117e-02,
#         -4.3908e-03,  1.9435e-02, -2.3862e-02, -2.0926e-02,  4.9969e-03,
#         -2.5812e-02, -2.0311e-02, -7.2182e-03,  5.4307e-04, -1.3833e-02,
#          1.6902e-02, -2.8585e-02,  9.9241e-03, -6.9337e-04, -1.4809e-03,
#          6.0666e-03,  7.0439e-04,  1.6823e-02, -2.5249e-02, -1.3601e-02,
#          1.2267e-02,  9.1512e-03, -1.4182e-02, -5.8234e-03,  1.4802e-02,
#          1.5738e-02, -3.4307e-04, -9.1496e-03,  1.3670e-02, -2.1515e-02,
#         -1.4893e-03,  1.7270e-02,  2.0809e-03, -1.0042e-02,  2.4884e-02,
#          3.0756e-02,  9.5966e-03,  1.3706e-02, -1.2569e-02,  2.0432e-03,
#          1.2858e-02,  6.4333e-04,  1.3741e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-1.9171e-02,  2.3385e-03,  2.4162e-02, -3.3349e-02, -6.1967e-03,
#           3.9288e-02,  8.0303e-03,  6.1971e-03,  3.4514e-02, -3.6055e-02,
#          -3.2154e-02, -3.4635e-02, -3.7192e-02,  3.9441e-02, -6.0038e-03,
#           2.0160e-02,  1.4734e-02,  1.0574e-02,  1.2708e-02,  2.5096e-02,
#           8.7503e-04,  2.0684e-02,  1.0074e-02,  3.5906e-02, -3.5769e-02,
#          -1.5850e-02,  3.0942e-02,  1.1865e-02,  2.8790e-03, -6.4385e-03,
#           5.3851e-03, -1.1990e-02, -9.9885e-03,  2.3476e-02,  4.0630e-02,
#          -2.0363e-02, -6.4680e-03,  3.0206e-02,  2.0806e-02, -2.9855e-03,
#           6.3436e-03, -1.6514e-02,  1.7351e-02,  3.9659e-04,  3.0659e-02,
#           2.7954e-02, -1.0554e-03, -8.8836e-03, -3.4602e-04, -3.8285e-02,
#          -5.5424e-03, -4.1464e-02,  3.1242e-02,  1.2970e-02,  2.0551e-03,
#           2.6871e-02,  2.1356e-03,  1.3162e-02, -3.3979e-02, -3.0460e-02,
#           1.0970e-02, -1.6859e-02,  4.2749e-03,  1.8149e-02,  3.4497e-02,
#           3.8702e-03,  3.5059e-02,  2.5902e-02,  3.2092e-02, -1.7361e-02,
#           7.5200e-03, -3.6769e-02,  3.1979e-02,  4.0438e-02, -3.9039e-02,
#          -1.1883e-02, -1.1871e-02,  8.0411e-04, -8.5720e-05,  2.1894e-02,
#          -3.8287e-02, -3.6470e-02, -2.6565e-02, -3.2409e-02, -4.8395e-03,
#           3.1240e-02, -2.5122e-02,  8.7603e-05,  1.7842e-02, -2.8143e-02,
#           2.7605e-02,  1.2260e-02,  1.6393e-02,  2.7254e-02,  2.8462e-02,
#           8.4783e-03, -1.1030e-03, -2.2103e-03,  2.0768e-02,  2.6592e-02,
#           2.1506e-02, -2.2521e-02, -3.0851e-02, -3.6893e-02, -8.3024e-03,
#           2.4776e-02, -2.1983e-02, -2.0451e-02, -1.5583e-02, -2.2162e-02,
#           1.1481e-03,  3.6772e-02,  2.8090e-02,  6.1830e-03,  3.0543e-02,
#          -1.3502e-02, -2.3558e-02, -2.7400e-02, -6.8308e-03,  2.9748e-02,
#          -2.5661e-02,  3.7863e-02,  9.8995e-03,  4.0483e-02,  3.8935e-02,
#           1.9910e-02, -3.6755e-03,  4.9892e-03, -2.2269e-02,  3.7370e-02,
#          -1.4188e-02,  2.2840e-02, -2.4265e-02,  1.7845e-02, -2.2876e-02,
#          -1.3605e-03, -2.7219e-03,  1.4603e-02, -1.9764e-02,  3.1225e-02,
#          -3.4559e-02, -2.7567e-02,  6.2236e-03, -3.2626e-02, -1.6555e-02,
#          -3.1775e-02,  2.4376e-02,  3.9416e-02,  3.5781e-02, -7.1633e-03,
#           2.9885e-02,  1.0226e-02,  1.4797e-02, -2.5607e-02,  1.6426e-02,
#          -6.3630e-03, -1.5697e-02, -2.3114e-02,  1.6057e-02, -3.5316e-02,
#          -2.9035e-02, -3.2986e-02,  2.5360e-03,  1.9537e-02, -9.4876e-04,
#          -1.1712e-02,  2.5625e-02, -1.9437e-02,  8.5348e-03, -2.7007e-02,
#           9.3517e-03,  1.7583e-02,  2.4555e-02, -6.6513e-03, -2.8649e-02,
#           4.0564e-02, -3.3240e-03,  3.4091e-02,  2.6597e-02, -3.0279e-02,
#          -3.4911e-02,  2.4267e-02, -1.4975e-02, -5.3223e-03,  1.5964e-02,
#           2.5487e-02,  8.4030e-03,  1.4886e-02, -1.4958e-04, -1.7724e-02,
#          -1.5284e-02, -2.0844e-02, -3.8260e-02,  3.6055e-04,  1.3444e-02,
#          -2.3592e-02,  2.0810e-02, -1.4423e-02, -2.6655e-02,  4.4883e-03,
#           3.8848e-02,  1.1257e-02,  2.5936e-03,  2.1948e-02,  1.5892e-02,
#          -3.0573e-02,  3.0839e-02, -1.7373e-02,  3.9176e-02, -9.3273e-03,
#           2.8665e-02, -3.2918e-04, -3.0050e-02, -3.8119e-02, -3.9860e-03,
#           3.6301e-02, -1.8237e-02, -2.2690e-03, -3.7320e-02, -5.4201e-03,
#           1.8783e-02, -5.9588e-03,  8.4970e-04, -1.9312e-02,  1.1383e-02,
#          -2.6976e-02,  1.6726e-02, -2.8412e-02,  2.9605e-02,  1.2241e-02,
#           2.0035e-02,  2.4568e-02,  1.7680e-03, -1.8107e-02,  2.0467e-02,
#          -2.7223e-02,  1.4110e-02, -1.9015e-02, -2.4243e-02, -3.3757e-02,
#          -3.4975e-02, -1.2728e-02,  2.9983e-02, -2.8511e-05,  3.4559e-02,
#           2.5850e-02,  1.5304e-02,  4.5310e-03, -1.7087e-02,  1.6509e-02,
#          -5.8350e-03, -1.9614e-03, -1.5011e-02, -2.2176e-02, -8.6824e-03,
#          -2.2182e-02, -1.5908e-02,  1.1530e-02, -7.3371e-03, -2.4309e-02,
#           2.9278e-02, -3.4274e-02, -2.8378e-02,  1.7417e-02,  4.7914e-03,
#          -1.9528e-02, -6.6725e-03,  4.7689e-03, -2.9296e-02, -3.5244e-02,
#           3.7342e-02, -1.6323e-02,  2.5724e-02, -1.7547e-03,  3.3367e-02,
#           2.3625e-02, -3.3377e-02, -5.4497e-03, -3.7726e-03, -9.6981e-03,
#          -3.5216e-06, -2.2233e-02,  1.8326e-02,  3.2932e-02,  1.3344e-03,
#          -2.6504e-02, -2.8535e-02,  2.4820e-02,  2.8941e-02,  2.4186e-02,
#           3.0665e-02,  1.5006e-02,  5.6359e-04, -3.5200e-02, -3.0697e-02,
#          -7.0026e-03, -1.6452e-02, -6.7163e-03, -2.9083e-02, -2.8087e-02,
#           8.7009e-03, -6.8220e-03, -3.8352e-02,  2.2187e-02,  3.7375e-02,
#          -2.4820e-02,  3.7449e-02,  7.3181e-03,  2.2737e-02, -3.1026e-02,
#           2.5293e-02, -2.9865e-02,  3.3828e-02, -2.7034e-02, -3.0476e-02,
#           3.6318e-02, -3.6566e-02,  3.5282e-02, -2.7857e-02, -2.3140e-03,
#           3.0986e-02,  1.2630e-02,  1.8290e-02, -1.6807e-02,  3.1432e-02,
#          -3.0426e-03,  5.6128e-03,  1.5610e-03,  8.3905e-05, -2.3912e-02,
#           3.9774e-02,  2.0587e-02,  1.2544e-02, -6.2324e-03,  3.5769e-02,
#           3.9545e-02,  2.3307e-02,  1.1342e-02, -1.2895e-02,  1.2663e-02,
#           3.0478e-02,  3.4635e-03,  1.5362e-02,  2.3373e-02,  3.5053e-02,
#          -3.0379e-02,  1.5797e-03, -2.2488e-02, -1.2980e-02,  3.0099e-02,
#          -1.2221e-02,  3.0042e-02,  3.0542e-03, -2.5565e-02,  3.0537e-02,
#          -1.0277e-02, -3.4526e-02, -1.9424e-02,  2.2844e-02, -7.3467e-03,
#          -2.0306e-02, -3.1272e-02,  1.0858e-02, -2.8960e-02, -7.1549e-04,
#           3.2188e-03, -3.5986e-02,  2.2320e-02,  1.7309e-02, -1.0024e-02,
#           4.9286e-03, -3.1836e-02,  3.4464e-02, -3.0054e-02, -9.7962e-03,
#          -3.2331e-02,  1.4402e-03, -3.2051e-02,  3.3053e-03, -2.5388e-02,
#           3.7389e-02, -1.5455e-02, -2.0180e-03,  1.9316e-02,  1.4332e-02,
#           2.0899e-02,  2.5427e-02,  3.8295e-02, -1.3724e-02, -3.5655e-03,
#          -5.6163e-03, -1.0945e-02, -3.2521e-02,  2.3533e-02,  1.7835e-02,
#           2.0067e-02, -2.9809e-02, -2.7494e-02,  3.7139e-02, -2.7250e-02,
#           1.0935e-02,  1.2698e-02,  3.1240e-02,  1.7378e-02, -2.0243e-03,
#          -1.0553e-02,  3.0817e-02,  2.9612e-02,  1.9682e-02,  1.6868e-02,
#          -1.3057e-02, -3.6455e-02, -3.4035e-02, -7.5899e-03, -8.6369e-04,
#           1.6794e-04, -2.6515e-03, -1.6906e-02,  1.6263e-03, -7.5860e-03,
#           2.7032e-02, -2.6733e-02,  3.9242e-02, -3.8371e-03,  3.8531e-02,
#          -3.4585e-02, -1.9060e-02, -1.4726e-02, -1.3131e-02,  1.4097e-02,
#          -1.5279e-02, -3.6706e-02, -2.3941e-02, -3.3983e-02,  2.1045e-02,
#          -3.0426e-03,  8.5491e-03, -1.3064e-04, -2.0225e-02,  2.8152e-02,
#           1.3540e-02, -4.9262e-03,  1.1881e-02, -3.2555e-02, -2.4850e-02,
#          -2.6257e-03,  1.0711e-02, -1.8385e-02,  1.3249e-02,  1.6883e-02,
#          -2.2758e-02, -1.8385e-02,  1.1712e-02,  9.4163e-03, -1.3358e-02,
#          -1.4517e-02,  5.9876e-03,  3.5074e-02,  3.3367e-03, -3.8232e-02,
#           2.1645e-02,  3.7517e-02, -9.1379e-03, -5.1898e-03, -8.2503e-03,
#           2.9404e-02,  2.4504e-02, -1.7403e-03, -1.2273e-02,  3.6032e-02,
#          -2.3300e-02, -3.9469e-04,  4.2000e-02,  5.0773e-05,  5.2702e-03,
#           2.8235e-02, -1.4188e-02,  4.2535e-03,  1.8388e-02,  1.8942e-02,
#          -1.8818e-02, -2.7141e-02, -1.4187e-02,  9.5856e-03, -3.6019e-02,
#           1.4477e-02, -3.8531e-02,  2.9410e-02,  1.6865e-02, -2.8260e-02,
#           1.1622e-03, -1.1412e-02,  1.4267e-03,  3.4687e-02, -3.5144e-03,
#           5.4962e-05, -3.0338e-02,  3.7745e-02,  1.7373e-02, -2.7162e-02,
#          -6.4843e-03,  1.0316e-02,  1.4573e-02, -2.0919e-02,  1.1296e-02,
#           4.0005e-02,  3.6852e-02, -6.9608e-03, -2.1592e-02,  7.1570e-03,
#          -6.1113e-04, -3.5255e-02,  2.1404e-02, -3.3543e-02, -3.3751e-03,
#          -3.4742e-02,  3.1238e-02, -8.2760e-03, -2.3147e-02,  3.6726e-02,
#          -6.1382e-03, -2.4243e-02, -1.0589e-02,  3.3432e-02,  1.4706e-02,
#           7.1991e-03, -3.4433e-02, -2.3955e-02, -1.3337e-02,  1.0835e-02,
#           9.0033e-03,  3.0418e-02, -1.3136e-02, -2.4416e-02,  2.6374e-02,
#           4.0234e-02, -2.8725e-02, -2.3821e-02, -1.0850e-02, -4.9247e-03,
#           2.5141e-02,  3.6834e-02, -9.4672e-03,  3.2142e-02,  1.0570e-02,
#          -2.0797e-02,  1.2695e-02,  1.5753e-02,  1.3318e-02,  4.4551e-03,
#          -2.0225e-02,  4.2355e-02, -2.9652e-02,  6.1125e-03, -3.4582e-02,
#           3.3879e-02, -3.3417e-03,  2.2021e-02, -1.9923e-03, -1.9976e-02,
#          -1.9501e-02,  1.1034e-02,  3.1232e-02,  5.4924e-03,  2.8825e-02,
#           2.7714e-03, -1.9450e-04, -3.4162e-02, -5.1993e-03,  1.9691e-02,
#           3.2825e-02, -3.4057e-02,  2.3917e-02,  1.4656e-02, -8.5178e-03,
#           3.8042e-02, -1.0492e-02, -1.4133e-02,  1.2774e-02,  1.4537e-03,
#          -5.9021e-03, -4.5817e-03, -7.8459e-03, -1.4687e-02, -1.6988e-02,
#          -3.6000e-02, -3.9912e-03, -3.7653e-02,  2.0906e-03,  1.5010e-02,
#          -2.3324e-02,  2.1363e-03,  2.1172e-02,  1.4024e-03,  2.4233e-02,
#           3.4027e-02, -3.8028e-02, -2.0072e-02,  1.0758e-03,  1.0684e-02,
#          -1.3147e-03,  1.4534e-03, -3.5420e-02,  4.4491e-03,  2.0429e-02,
#           3.7194e-02,  3.4255e-02, -2.2685e-02,  7.4886e-03, -5.0316e-03,
#          -9.1734e-03,  8.3073e-03, -1.0064e-02]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([0.0399], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.2076,  0.4897,  0.1011],
#         [ 0.3493,  0.0625,  0.2235],
#         [-0.4251, -0.3084,  0.0922],
#         ...,
#         [ 0.2639, -0.5629, -0.3328],
#         [ 0.2076, -0.0958,  0.2623],
#         [-0.2717,  0.3120,  0.2945]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 0.1571, -0.2820, -0.1120,  0.5288, -0.1910,  0.1295, -0.4708,  0.5416,
#          0.1047,  0.5519,  0.1971,  0.1332, -0.2223,  0.2659,  0.2572, -0.2029,
#         -0.4961,  0.2113,  0.1180,  0.3308,  0.4376,  0.1717,  0.4500,  0.0830,
#          0.1395,  0.0349,  0.4899, -0.4264,  0.0713,  0.1079, -0.4390, -0.0478,
#         -0.0045, -0.1085, -0.0447,  0.1404, -0.0945, -0.4175, -0.1780,  0.1042,
#          0.1899, -0.4785,  0.5411,  0.5049,  0.4304, -0.2365, -0.3615, -0.5016,
#         -0.0057, -0.0566, -0.4988, -0.0053,  0.1763, -0.1292,  0.4806,  0.2882,
#         -0.4293,  0.1096, -0.3447, -0.3130,  0.1731,  0.0360, -0.0501,  0.5473,
#          0.2927, -0.5316,  0.1212, -0.2136, -0.2412, -0.2487,  0.4190, -0.5424,
#         -0.3000,  0.3775,  0.3795,  0.4091,  0.2243,  0.0389, -0.1755, -0.5733,
#         -0.2668,  0.3406, -0.2964, -0.4189, -0.0075,  0.4128, -0.2645, -0.5609,
#         -0.2287, -0.1281,  0.1182,  0.1739,  0.5844, -0.5082,  0.4170,  0.3530,
#         -0.2269, -0.0114, -0.4586,  0.3810, -0.5478, -0.0620, -0.3874, -0.5677,
#          0.2665,  0.5090, -0.4516, -0.2227, -0.2398,  0.0045,  0.3482, -0.0964,
#         -0.5105,  0.0315, -0.2699, -0.4832,  0.5018, -0.2480, -0.1795,  0.4804,
#         -0.2927,  0.4652,  0.2042, -0.3123, -0.4935,  0.1398, -0.3504, -0.0818,
#         -0.1603,  0.2799,  0.4096, -0.4807,  0.0320,  0.3255,  0.3447,  0.1245,
#          0.2909, -0.5593,  0.3578, -0.3613,  0.1653, -0.3478,  0.3753,  0.1253,
#         -0.0994, -0.3993, -0.2074,  0.0360,  0.2827, -0.2592, -0.2158,  0.4201,
#          0.5155,  0.3224,  0.1741,  0.2174, -0.1277, -0.0142,  0.2136, -0.1696,
#         -0.2176,  0.0861,  0.4233,  0.2997, -0.1858, -0.0609, -0.1271,  0.0796,
#         -0.5692,  0.1509,  0.5727,  0.3400, -0.1583, -0.4104,  0.0050,  0.2666,
#         -0.3229, -0.2794, -0.0095,  0.2157, -0.5221, -0.5355,  0.4422,  0.3948,
#          0.0460,  0.0751,  0.2045, -0.4793,  0.5697, -0.4638, -0.1221,  0.1368,
#          0.1925,  0.1962, -0.3378,  0.3988, -0.1748, -0.0878, -0.3973,  0.3835,
#          0.2776, -0.0586, -0.2944,  0.1759,  0.3125,  0.0491, -0.0596,  0.2172,
#         -0.4780,  0.0871, -0.2530, -0.5234, -0.5111, -0.4684, -0.4570,  0.1944,
#         -0.4929,  0.5194,  0.2228,  0.4998,  0.2736,  0.2431,  0.2513, -0.0785,
#         -0.5295,  0.2246,  0.1379,  0.2684,  0.1837,  0.4023,  0.5475,  0.1485,
#          0.4831,  0.1644, -0.2321,  0.5428,  0.1664,  0.4776,  0.3631,  0.4931,
#          0.0567,  0.5287, -0.1301,  0.3492,  0.1697, -0.5697, -0.2417,  0.0017,
#         -0.4586, -0.0194,  0.3462,  0.3331, -0.4834,  0.1757, -0.4518,  0.2010,
#          0.5437, -0.2532,  0.1352,  0.5531,  0.0245,  0.3485,  0.3074,  0.4484,
#          0.3296,  0.2595, -0.2916, -0.4082,  0.3832, -0.0687, -0.3160, -0.1748,
#          0.1172, -0.2076, -0.3120, -0.3733,  0.4740, -0.0995, -0.0661,  0.5609,
#         -0.0825, -0.2316, -0.2232,  0.1025,  0.0719, -0.2253, -0.3309, -0.5260,
#         -0.3926,  0.2144,  0.4627,  0.5802,  0.0202, -0.2326,  0.4459, -0.5614,
#         -0.0104,  0.2860,  0.2619, -0.2575, -0.4555,  0.3638, -0.2047,  0.1288,
#          0.4801, -0.0179, -0.1001, -0.0616,  0.2325,  0.2708, -0.2735, -0.2294,
#         -0.3702,  0.5483, -0.2383, -0.1073, -0.1175,  0.5289, -0.0422,  0.3116,
#          0.1219,  0.0039,  0.4574, -0.1561, -0.1778,  0.2400, -0.1401,  0.2170,
#          0.4068, -0.4952, -0.1789, -0.2621, -0.5559, -0.1087,  0.5047,  0.4791,
#          0.2350, -0.2854, -0.3690, -0.4328,  0.2214,  0.0317,  0.4387,  0.1165,
#         -0.1644, -0.3171, -0.2663,  0.0788,  0.3159,  0.2870, -0.1433, -0.1963,
#         -0.0233, -0.5021,  0.5041,  0.1374, -0.2328, -0.2153, -0.2862, -0.4313,
#          0.0817,  0.1824,  0.1939, -0.5202, -0.2247,  0.0646, -0.3887,  0.1948,
#          0.0855, -0.1444, -0.3120, -0.2281,  0.4810,  0.5564, -0.0417,  0.4114,
#          0.3031, -0.3157, -0.4976, -0.2926, -0.1896,  0.4485, -0.1936, -0.1592,
#         -0.5051, -0.3674,  0.2822, -0.0104, -0.1745, -0.4224, -0.1926, -0.1704,
#          0.5071, -0.2425,  0.5223, -0.3396, -0.3260, -0.2347,  0.0026,  0.2831,
#          0.5462, -0.2454,  0.5322,  0.2786, -0.1482, -0.4545, -0.2748,  0.1296,
#          0.1035, -0.1734,  0.1131, -0.5281,  0.3173, -0.3133, -0.1026, -0.1758,
#          0.3608, -0.3539, -0.4665, -0.0233, -0.0619,  0.2999,  0.3930,  0.3625,
#         -0.2566, -0.5731,  0.3560, -0.0756,  0.1133, -0.1304,  0.2400, -0.2339,
#          0.4691,  0.4485, -0.5387,  0.1033,  0.0726, -0.2030,  0.3164, -0.2098,
#          0.1271, -0.2340, -0.0298,  0.0983,  0.3514, -0.2419, -0.2865,  0.2821,
#          0.3007, -0.1083,  0.0929, -0.0241, -0.5391,  0.4435,  0.2104,  0.3717,
#         -0.2212, -0.5670, -0.3772, -0.4365,  0.5671,  0.4641, -0.0270, -0.2457,
#         -0.5193, -0.4157,  0.2284, -0.0881, -0.2183,  0.1909,  0.3264, -0.3119,
#         -0.5493, -0.0639,  0.4148,  0.2829,  0.5068, -0.2803, -0.4692, -0.4879,
#          0.4324,  0.1693,  0.5610, -0.4312,  0.0501, -0.1360, -0.1840, -0.2577,
#         -0.2795, -0.0082,  0.4735,  0.4941, -0.0012, -0.2760, -0.4597,  0.3753,
#          0.4757,  0.1029,  0.5039,  0.1318, -0.3283,  0.0401, -0.0392, -0.1060,
#          0.5475,  0.5227,  0.2679, -0.0994, -0.1656,  0.4495,  0.3725, -0.0626,
#          0.1681,  0.2715, -0.2613, -0.3560,  0.5325, -0.1449,  0.4777,  0.1994,
#         -0.3482, -0.2310, -0.0907,  0.1569,  0.1681,  0.1507,  0.3148,  0.3907,
#          0.2405,  0.2560,  0.1088,  0.0437, -0.2660, -0.4627, -0.2505, -0.4787,
#          0.5503, -0.4811,  0.0794,  0.5361,  0.2351,  0.5519, -0.2055,  0.3198,
#          0.1579, -0.4326,  0.3774, -0.1895, -0.2369, -0.4128, -0.0426, -0.5628,
#         -0.0860, -0.2064, -0.1111,  0.5271,  0.2942,  0.0904, -0.1929,  0.5409,
#         -0.2427,  0.3342,  0.0365,  0.0526,  0.1577,  0.0511,  0.5783,  0.1521,
#         -0.4223, -0.4014, -0.0129,  0.4548,  0.2279,  0.4945,  0.3724,  0.3311,
#         -0.3508,  0.2121,  0.4834, -0.1346,  0.3547,  0.5482,  0.1967, -0.5881,
#         -0.4323,  0.2262, -0.2383,  0.0052, -0.4299, -0.3879, -0.0283, -0.1277,
#          0.1802, -0.2621,  0.0032,  0.3399,  0.0253, -0.5589,  0.3313,  0.4514,
#         -0.2045,  0.5020, -0.0137, -0.3502, -0.1032, -0.0042, -0.4673,  0.0412,
#          0.2465, -0.4596, -0.4734,  0.0571, -0.1439, -0.2915,  0.2300,  0.5642,
#          0.5493], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0053, -0.0378,  0.0222,  ..., -0.0386, -0.0141,  0.0227],
#         [ 0.0114, -0.0255,  0.0352,  ...,  0.0309,  0.0176,  0.0237],
#         [ 0.0185,  0.0272, -0.0393,  ..., -0.0101,  0.0223, -0.0018],
#         ...,
#         [ 0.0156, -0.0283,  0.0221,  ..., -0.0136, -0.0331, -0.0086],
#         [-0.0238,  0.0303, -0.0332,  ..., -0.0267, -0.0237,  0.0041],
#         [-0.0159,  0.0110, -0.0333,  ...,  0.0115,  0.0203,  0.0097]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0157,  0.0387,  0.0070,  0.0122,  0.0162, -0.0321, -0.0326, -0.0356,
#          0.0234, -0.0413, -0.0038, -0.0084, -0.0398,  0.0042, -0.0198,  0.0137,
#          0.0245, -0.0376, -0.0222, -0.0232, -0.0204, -0.0367,  0.0366,  0.0005,
#         -0.0306,  0.0284,  0.0426,  0.0281,  0.0028,  0.0175, -0.0353, -0.0039,
#          0.0193,  0.0211,  0.0252, -0.0295, -0.0051,  0.0363,  0.0114, -0.0026,
#          0.0039, -0.0255, -0.0075,  0.0193, -0.0171, -0.0338, -0.0046,  0.0361,
#          0.0019, -0.0189,  0.0215,  0.0356,  0.0174, -0.0336, -0.0244, -0.0410,
#          0.0043, -0.0144,  0.0061, -0.0122, -0.0280,  0.0198, -0.0272, -0.0299,
#          0.0016,  0.0443,  0.0089,  0.0232, -0.0290, -0.0092, -0.0278,  0.0014,
#         -0.0112, -0.0045, -0.0219,  0.0010,  0.0319,  0.0247,  0.0309, -0.0026,
#         -0.0465, -0.0307,  0.0244, -0.0311, -0.0388, -0.0385, -0.0261,  0.0050,
#         -0.0360, -0.0323, -0.0290,  0.0245, -0.0170, -0.0391, -0.0279, -0.0155,
#         -0.0316, -0.0126, -0.0369, -0.0091,  0.0061,  0.0302, -0.0182, -0.0108,
#          0.0256,  0.0065,  0.0069,  0.0270, -0.0278, -0.0257, -0.0020, -0.0354,
#         -0.0384, -0.0061, -0.0150, -0.0220,  0.0419,  0.0266, -0.0211,  0.0277,
#         -0.0225,  0.0235,  0.0353, -0.0220, -0.0290, -0.0379,  0.0061,  0.0291,
#         -0.0197,  0.0201, -0.0319, -0.0136,  0.0310, -0.0259, -0.0284,  0.0025,
#         -0.0061,  0.0273,  0.0186,  0.0051,  0.0256, -0.0296, -0.0138,  0.0089,
#         -0.0129,  0.0090,  0.0127,  0.0212,  0.0223, -0.0189, -0.0405, -0.0263,
#         -0.0048,  0.0210,  0.0297,  0.0028, -0.0216, -0.0241,  0.0356,  0.0190,
#         -0.0392, -0.0110, -0.0360,  0.0002,  0.0427, -0.0330,  0.0010,  0.0132,
#          0.0375,  0.0081,  0.0365,  0.0145, -0.0086, -0.0354, -0.0405,  0.0280,
#         -0.0130, -0.0253, -0.0140, -0.0161,  0.0355,  0.0253, -0.0169,  0.0110,
#         -0.0183,  0.0104,  0.0386, -0.0323,  0.0192, -0.0112,  0.0243, -0.0008,
#         -0.0148,  0.0319, -0.0197,  0.0294, -0.0179, -0.0237, -0.0091, -0.0415,
#          0.0274, -0.0147,  0.0381, -0.0250,  0.0245,  0.0160,  0.0300,  0.0259,
#         -0.0268, -0.0185, -0.0409, -0.0031,  0.0124,  0.0389, -0.0048, -0.0003,
#         -0.0292, -0.0293,  0.0166, -0.0276, -0.0194,  0.0096, -0.0130, -0.0334,
#          0.0264,  0.0302, -0.0098,  0.0428,  0.0078, -0.0218,  0.0242,  0.0176,
#         -0.0076, -0.0092,  0.0124,  0.0043, -0.0072, -0.0108, -0.0373,  0.0211,
#          0.0160,  0.0173, -0.0327,  0.0219, -0.0068, -0.0355,  0.0124, -0.0431,
#         -0.0323,  0.0316,  0.0300, -0.0028, -0.0074,  0.0337, -0.0144,  0.0307,
#         -0.0303, -0.0236,  0.0348,  0.0386, -0.0161, -0.0021,  0.0003, -0.0203,
#          0.0174, -0.0230, -0.0025, -0.0315, -0.0091, -0.0012, -0.0017,  0.0173,
#          0.0080,  0.0173, -0.0205,  0.0003,  0.0036, -0.0248, -0.0296, -0.0402,
#          0.0359, -0.0321, -0.0227,  0.0382,  0.0339,  0.0353,  0.0406, -0.0220,
#         -0.0243, -0.0389, -0.0402,  0.0282, -0.0112,  0.0346, -0.0100, -0.0293,
#         -0.0150, -0.0220, -0.0256, -0.0357, -0.0249, -0.0138,  0.0047,  0.0338,
#         -0.0277, -0.0350, -0.0366, -0.0361, -0.0291,  0.0183, -0.0359, -0.0014,
#         -0.0258, -0.0132, -0.0093,  0.0102, -0.0417, -0.0343, -0.0118, -0.0164,
#          0.0088, -0.0056,  0.0318,  0.0303, -0.0194, -0.0159,  0.0405,  0.0024,
#          0.0229,  0.0375,  0.0311,  0.0277,  0.0263, -0.0226,  0.0270, -0.0289,
#         -0.0372, -0.0376, -0.0062, -0.0352,  0.0289, -0.0073,  0.0206, -0.0021,
#          0.0372,  0.0350, -0.0346,  0.0369,  0.0363, -0.0326,  0.0142, -0.0338,
#          0.0109,  0.0110,  0.0163,  0.0419, -0.0237,  0.0359,  0.0100, -0.0357,
#          0.0263, -0.0065,  0.0112,  0.0285,  0.0232, -0.0168,  0.0241, -0.0097,
#         -0.0247, -0.0164, -0.0244,  0.0222,  0.0377,  0.0581,  0.0190,  0.0346,
#         -0.0307,  0.0371,  0.0105, -0.0110,  0.0012, -0.0355,  0.0352,  0.0164,
#         -0.0091,  0.0271, -0.0118, -0.0265, -0.0023, -0.0245, -0.0226,  0.0151,
#         -0.0178, -0.0091, -0.0371, -0.0379,  0.0077, -0.0351,  0.0118,  0.0040,
#          0.0061, -0.0146, -0.0214,  0.0297,  0.0168,  0.0214, -0.0055,  0.0157,
#          0.0045, -0.0114,  0.0069,  0.0193,  0.0261,  0.0164,  0.0404,  0.0044,
#         -0.0262, -0.0080, -0.0370, -0.0079, -0.0008, -0.0170, -0.0104, -0.0328,
#         -0.0109,  0.0325,  0.0296,  0.0273, -0.0258, -0.0026,  0.0094, -0.0220,
#         -0.0018,  0.0447, -0.0211,  0.0028, -0.0359, -0.0147, -0.0086,  0.0303,
#         -0.0300,  0.0252, -0.0193,  0.0276, -0.0034,  0.0106, -0.0347,  0.0238,
#          0.0054, -0.0199,  0.0070, -0.0226,  0.0337,  0.0135,  0.0264,  0.0032,
#         -0.0050,  0.0288,  0.0128,  0.0217,  0.0294, -0.0248,  0.0382, -0.0158,
#          0.0397,  0.0025, -0.0240,  0.0289, -0.0385,  0.0266, -0.0315,  0.0110,
#          0.0098, -0.0135, -0.0179,  0.0310, -0.0397,  0.0076,  0.0103, -0.0355,
#          0.0235,  0.0035, -0.0343, -0.0015,  0.0144, -0.0175, -0.0384,  0.0150,
#          0.0041, -0.0176, -0.0133, -0.0035,  0.0218, -0.0324, -0.0035,  0.0234,
#         -0.0174, -0.0264, -0.0174, -0.0093, -0.0415, -0.0015,  0.0326, -0.0357,
#         -0.0406, -0.0259,  0.0039, -0.0406, -0.0186, -0.0374,  0.0230, -0.0344,
#         -0.0043, -0.0249,  0.0198, -0.0013,  0.0071, -0.0143, -0.0373, -0.0285,
#         -0.0061,  0.0354,  0.0322,  0.0243,  0.0073, -0.0063,  0.0201,  0.0234,
#          0.0131,  0.0342,  0.0033, -0.0174, -0.0208, -0.0213,  0.0327, -0.0320,
#          0.0169,  0.0309,  0.0156,  0.0205, -0.0373,  0.0050,  0.0313,  0.0178,
#          0.0243, -0.0074,  0.0167, -0.0059, -0.0133, -0.0376, -0.0311,  0.0299,
#          0.0165,  0.0224, -0.0406,  0.0169, -0.0409, -0.0295, -0.0062,  0.0045,
#          0.0352, -0.0338,  0.0167, -0.0090,  0.0350,  0.0047,  0.0300, -0.0051,
#         -0.0106,  0.0030,  0.0026,  0.0187,  0.0352,  0.0271, -0.0378, -0.0393,
#         -0.0227, -0.0080,  0.0050, -0.0190,  0.0037,  0.0106, -0.0240, -0.0066,
#          0.0067,  0.0104, -0.0288, -0.0304,  0.0158, -0.0090, -0.0242, -0.0161,
#         -0.0211,  0.0110, -0.0218,  0.0211,  0.0077, -0.0329, -0.0054, -0.0325,
#         -0.0207,  0.0208, -0.0140,  0.0178, -0.0418, -0.0047,  0.0075,  0.0053,
#         -0.0259, -0.0246,  0.0043, -0.0191,  0.0196,  0.0197, -0.0379, -0.0009,
#          0.0206, -0.0328,  0.0355,  0.0345, -0.0262, -0.0139, -0.0288,  0.0152,
#         -0.0332, -0.0125, -0.0276, -0.0330,  0.0016,  0.0139, -0.0370,  0.0134,
#         -0.0059,  0.0058, -0.0053, -0.0073, -0.0122, -0.0063,  0.0145,  0.0141,
#          0.0373,  0.0271, -0.0032, -0.0329,  0.0340,  0.0264,  0.0171,  0.0044,
#         -0.0296,  0.0300,  0.0329,  0.0284,  0.0075, -0.0143,  0.0367,  0.0133,
#         -0.0313, -0.0041, -0.0299, -0.0048,  0.0331,  0.0241, -0.0301, -0.0135,
#         -0.0040, -0.0029,  0.0455, -0.0006, -0.0294,  0.0173,  0.0414, -0.0041,
#          0.0011,  0.0113, -0.0167, -0.0046,  0.0204,  0.0232,  0.0291,  0.0340,
#         -0.0384,  0.0013, -0.0379, -0.0131, -0.0377,  0.0308,  0.0369, -0.0352,
#          0.0346, -0.0311,  0.0302, -0.0274, -0.0297,  0.0279, -0.0045, -0.0187,
#          0.0106,  0.0269,  0.0063, -0.0416, -0.0280, -0.0107,  0.0295, -0.0048,
#          0.0303,  0.0045,  0.0060, -0.0167,  0.0168, -0.0122,  0.0171,  0.0137,
#         -0.0171, -0.0415, -0.0408,  0.0361,  0.0202, -0.0035,  0.0275, -0.0055,
#         -0.0019, -0.0045,  0.0115,  0.0204, -0.0242,  0.0277,  0.0288,  0.0327,
#         -0.0192,  0.0094,  0.0377, -0.0274, -0.0174, -0.0320, -0.0181,  0.0313,
#          0.0247,  0.0075,  0.0116,  0.0369,  0.0158,  0.0012,  0.0119,  0.0260,
#         -0.0099,  0.0002,  0.0111, -0.0281,  0.0033,  0.0016,  0.0079, -0.0027,
#         -0.0222,  0.0019, -0.0323,  0.0017, -0.0091, -0.0384,  0.0204, -0.0256,
#         -0.0242, -0.0200, -0.0024, -0.0153,  0.0196, -0.0207, -0.0205, -0.0398,
#         -0.0370,  0.0324,  0.0047, -0.0320,  0.0179,  0.0070,  0.0264, -0.0061,
#         -0.0393, -0.0269, -0.0056, -0.0378, -0.0376, -0.0338, -0.0250, -0.0196,
#         -0.0153, -0.0206,  0.0233, -0.0073,  0.0007, -0.0211,  0.0330,  0.0007,
#          0.0434,  0.0313, -0.0205,  0.0283,  0.0100, -0.0418, -0.0399, -0.0135,
#         -0.0327, -0.0273,  0.0098, -0.0198, -0.0247, -0.0287,  0.0332,  0.0362,
#         -0.0126, -0.0429, -0.0162, -0.0257,  0.0152,  0.0236, -0.0342, -0.0123,
#          0.0168, -0.0207, -0.0228, -0.0393,  0.0074,  0.0373,  0.0233, -0.0194,
#          0.0134, -0.0307, -0.0232, -0.0149,  0.0294, -0.0122,  0.0014,  0.0188,
#         -0.0151,  0.0217, -0.0395,  0.0299,  0.0352, -0.0112, -0.0366, -0.0201,
#          0.0172,  0.0006, -0.0322,  0.0007, -0.0274,  0.0020, -0.0037,  0.0091,
#          0.0168,  0.0071,  0.0218, -0.0067, -0.0364,  0.0036,  0.0156, -0.0105,
#          0.0373,  0.0303], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0338, -0.0291, -0.0225,  ..., -0.0022, -0.0018, -0.0240],
#         [-0.0109, -0.0247, -0.0173,  ...,  0.0349, -0.0098,  0.0266],
#         [-0.0236, -0.0229,  0.0206,  ..., -0.0179,  0.0104,  0.0269],
#         ...,
#         [-0.0038,  0.0182, -0.0044,  ...,  0.0284, -0.0078,  0.0099],
#         [-0.0255,  0.0132, -0.0067,  ...,  0.0346,  0.0213,  0.0316],
#         [-0.0226,  0.0273,  0.0145,  ...,  0.0098, -0.0232,  0.0266]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-2.7028e-02,  2.0658e-02,  2.1882e-02, -8.2557e-03,  3.0737e-03,
#         -2.8638e-02,  2.8851e-02, -1.7252e-02,  4.0003e-03,  1.0917e-02,
#         -1.9680e-02, -1.2046e-02,  1.6872e-02, -8.0580e-03,  1.5208e-02,
#          1.6744e-02,  1.4672e-02, -3.6943e-03, -1.0073e-02, -4.9567e-03,
#         -1.4182e-03, -9.1403e-04, -2.7062e-02, -1.0708e-02,  1.0760e-02,
#         -2.7890e-02,  2.1225e-02, -2.8541e-02,  1.6813e-02, -3.1584e-02,
#          2.6539e-02, -1.2026e-02,  1.9681e-02,  5.4691e-03,  6.3391e-03,
#         -4.0272e-03, -1.1182e-02,  4.6787e-03,  9.8802e-03, -1.1412e-02,
#          2.6894e-02, -2.3383e-02, -1.8721e-02,  1.9377e-03,  1.8224e-02,
#          6.3765e-03,  2.5706e-02, -9.8553e-03, -2.9642e-03, -2.3521e-02,
#          4.6376e-03, -6.6135e-04,  2.5794e-03,  1.6322e-02, -1.6392e-03,
#         -1.6744e-02, -2.3005e-03,  3.0260e-03, -1.7579e-02, -2.5824e-02,
#         -1.7427e-02,  2.2391e-02, -1.9790e-02, -3.0614e-02, -2.5729e-02,
#          1.2904e-02, -1.5200e-02, -1.1449e-02, -1.1171e-02,  2.6626e-03,
#         -2.4142e-02, -2.2276e-02,  2.8634e-02,  4.0601e-03,  3.1268e-02,
#         -1.0690e-02, -3.4861e-02,  2.5443e-03,  2.2624e-02, -1.9124e-02,
#         -1.3752e-02, -2.6679e-02,  1.2369e-02, -6.9777e-03,  1.7332e-03,
#          3.1194e-02,  2.9338e-02, -2.0327e-02,  2.3349e-02, -1.4979e-02,
#          8.2456e-03, -1.8713e-02, -3.0727e-03, -3.3193e-02, -1.0935e-02,
#          1.2125e-02, -3.2874e-02, -6.2537e-03, -1.3108e-02,  1.1659e-02,
#          2.9360e-02,  3.1464e-02, -2.3658e-02,  2.6533e-02, -3.2271e-02,
#          7.7671e-04,  2.2658e-02,  1.3755e-02, -6.9763e-03,  7.1671e-03,
#          1.8531e-02,  1.7552e-02,  6.1609e-03, -2.8835e-02,  4.7270e-03,
#         -3.1179e-02, -2.9140e-02, -3.1883e-02, -9.8206e-03, -2.9543e-03,
#         -3.4868e-02,  2.2298e-02,  1.2077e-02, -9.3853e-04, -1.1552e-02,
#          1.8727e-02,  9.0520e-04,  2.4560e-02,  2.6182e-03,  5.3231e-03,
#          2.8834e-02,  5.4148e-03, -6.8575e-03, -1.3829e-02,  6.6270e-03,
#          1.6927e-02, -1.7588e-02,  2.1576e-02,  5.2969e-03, -2.4718e-02,
#          1.5984e-02,  2.8835e-02, -8.5407e-03,  8.6736e-03, -1.2283e-02,
#         -3.4746e-02,  1.2749e-02, -1.1846e-02,  1.6347e-02, -2.6133e-02,
#          3.0282e-02, -1.9016e-02, -2.2067e-02,  2.8420e-02, -3.1342e-03,
#         -1.6843e-02,  1.3202e-02, -1.5041e-02, -3.4786e-02,  2.3190e-02,
#         -3.2814e-02,  2.5348e-02, -3.1905e-02, -1.8669e-02, -1.8486e-02,
#         -2.3035e-03,  2.1619e-02,  8.5356e-03, -4.1201e-03,  2.0809e-02,
#          1.3175e-02,  4.5101e-03,  2.5278e-02, -2.0410e-02, -2.3704e-02,
#         -1.8867e-02, -9.8674e-03,  8.4492e-03, -3.0443e-02,  6.1111e-03,
#          2.9547e-02, -1.4118e-03, -2.8024e-02,  2.2802e-02,  5.2308e-03,
#         -2.7683e-02, -2.0733e-02, -3.1048e-02, -1.8787e-02, -7.7320e-03,
#          1.7431e-02,  4.0333e-02, -4.1437e-02,  1.2617e-02, -2.3193e-02,
#          1.2835e-02,  2.1264e-02, -2.0740e-02,  2.2258e-02,  2.2020e-02,
#          1.1879e-02, -5.5378e-03, -1.7413e-02,  1.1542e-02,  1.1815e-02,
#          8.3742e-03,  5.4017e-03,  2.2208e-02,  3.0819e-02,  1.4712e-02,
#          7.9173e-03, -1.8443e-03, -1.3820e-02,  1.3843e-03, -6.7924e-03,
#          1.0728e-02,  8.2420e-03,  1.5163e-02, -1.0549e-02,  1.3037e-02,
#         -1.6125e-02, -3.3187e-02,  2.6759e-02, -3.1896e-02,  1.1832e-02,
#          2.6191e-02, -8.2139e-05,  5.6533e-04,  2.9558e-02,  2.5421e-02,
#          1.1216e-02, -1.3017e-02,  2.7551e-02,  3.3968e-02, -2.8065e-02,
#          2.3772e-02,  2.6436e-02, -1.9667e-02, -2.2041e-02, -2.1375e-02,
#          7.4428e-03, -2.7744e-02, -2.0178e-02, -2.8445e-02, -2.1254e-02,
#          1.6356e-02,  6.3127e-03,  1.2461e-02, -2.5037e-02, -3.0173e-02,
#          2.5989e-02, -2.6038e-02,  9.8605e-03, -3.1424e-02,  2.1528e-02,
#         -5.7107e-03, -2.3076e-02,  9.5833e-03,  1.0506e-02, -2.4135e-02,
#          1.1120e-02,  3.6614e-03,  1.6673e-02,  5.2346e-03, -7.4353e-03,
#          1.5025e-02, -1.0480e-02, -7.5003e-03,  3.0941e-02,  2.9639e-02,
#         -3.7690e-02,  3.5819e-02, -1.8909e-02,  2.3779e-02, -6.0929e-03,
#         -3.1781e-02, -1.9560e-02,  2.5232e-02, -3.1778e-02, -3.3973e-02,
#          2.3950e-02,  8.0579e-03, -2.8686e-02,  1.4245e-02,  1.1532e-02,
#         -2.8047e-02, -2.1229e-02, -3.1362e-02,  3.4501e-03,  2.8685e-02,
#          4.5824e-03,  1.4884e-02, -9.3261e-03, -3.3462e-03, -3.1538e-02,
#         -7.3716e-03,  1.3243e-03,  2.1741e-02,  2.0994e-02,  2.0115e-02,
#         -5.0336e-03, -2.0787e-02,  2.8869e-02,  1.7903e-02,  2.1906e-02,
#         -6.0246e-03, -3.4838e-02, -3.0368e-02,  3.1202e-02, -2.7661e-02,
#         -2.6027e-02, -8.8784e-03,  7.2320e-03, -2.7186e-02, -2.3303e-02,
#          1.7528e-02, -3.1893e-02, -2.9202e-02,  2.6409e-02,  1.7955e-02,
#         -2.3332e-02, -2.7703e-02, -1.8406e-02, -2.5480e-02,  2.3406e-02,
#         -1.3743e-02, -2.2107e-02, -3.3620e-03,  4.9164e-03, -2.6123e-02,
#         -3.0128e-02,  3.7790e-02,  2.8713e-02, -4.7365e-03,  1.3277e-02,
#         -5.6212e-03,  4.2399e-03, -1.4162e-02, -1.3542e-02,  1.4167e-02,
#         -3.4326e-02,  3.2153e-02,  1.1941e-02,  6.2430e-03, -2.8136e-02,
#         -3.5372e-03,  7.0592e-03, -3.0992e-02,  2.2430e-02,  1.9133e-02,
#         -2.2022e-02, -2.4523e-02, -2.4182e-02, -4.6605e-03, -3.3727e-02,
#          5.0864e-03,  3.1020e-02, -9.4604e-03,  1.6394e-02,  3.5153e-03,
#          3.3348e-02,  3.0974e-02, -3.5651e-02, -1.1851e-02,  1.1000e-02,
#          9.4891e-03, -1.8460e-02,  9.1689e-04, -4.6128e-03,  1.2489e-02,
#          3.0331e-02,  2.6366e-02, -6.9939e-03,  1.0161e-02, -3.5940e-03,
#         -2.2895e-02,  8.4119e-03,  7.7994e-03, -3.5844e-03, -2.6626e-02,
#         -3.8728e-03,  1.8983e-02,  2.7600e-02,  3.0057e-02, -9.0008e-03,
#         -2.5472e-02, -1.9631e-02, -2.4063e-02,  1.2296e-02,  2.4083e-02,
#         -1.3021e-02,  4.5405e-03, -3.4771e-02, -1.8983e-02, -2.8638e-02,
#         -1.6366e-02, -3.1638e-02,  2.7744e-02,  1.4130e-02, -1.9867e-03,
#          3.1157e-02,  3.0313e-02,  2.7782e-02,  2.1285e-02, -1.8261e-02,
#          2.1334e-02,  6.2839e-03,  3.7654e-02,  1.7552e-02, -3.1969e-02,
#         -2.7557e-02,  5.3212e-03,  2.8822e-02, -2.3490e-02,  2.7143e-03,
#         -4.1699e-03,  1.4893e-03,  2.8274e-02, -3.4152e-02, -3.4548e-02,
#         -2.1255e-02, -2.0405e-02, -2.7044e-02,  3.0418e-02,  7.2105e-03,
#          7.4576e-03, -3.1467e-02,  2.3525e-02, -2.2469e-02,  5.4639e-03,
#         -2.0067e-02,  2.0650e-02,  7.8412e-03,  1.6499e-02, -1.3561e-02,
#          3.1990e-02, -1.2961e-02,  1.6529e-02,  7.2582e-03, -3.7681e-02,
#          2.8358e-02,  1.0448e-02,  1.7318e-03, -3.4367e-02,  5.2667e-03,
#          2.0068e-02,  2.5225e-02,  1.7085e-04, -3.3868e-02, -3.0144e-02,
#          1.4826e-02, -4.4774e-03,  3.4003e-03,  6.4563e-03,  1.2210e-02,
#         -2.9271e-02,  1.4356e-02, -5.3736e-03,  1.5723e-02,  2.0907e-02,
#         -1.0769e-02,  2.1915e-02, -3.2559e-02,  2.3866e-02, -3.0037e-02,
#          7.4096e-03, -3.2095e-02, -1.7652e-02,  4.3016e-03, -1.9915e-02,
#          3.0106e-02, -2.1436e-02, -2.5892e-02,  8.2996e-03, -2.3025e-02,
#          3.2147e-02, -1.2847e-02, -1.1717e-02, -9.9196e-03, -2.3405e-02,
#         -2.8149e-02,  1.8214e-02, -8.9459e-04, -6.6299e-03, -1.5890e-02,
#         -9.2779e-03, -1.4865e-02,  9.7765e-03, -1.1396e-02, -7.4375e-03,
#         -1.2330e-02,  1.2733e-02, -1.0176e-02,  1.0634e-02, -2.2080e-02,
#         -3.1141e-02,  6.3992e-04, -1.1758e-03,  6.4232e-04,  2.7200e-02,
#          1.7858e-02, -3.2018e-02,  8.6788e-03,  1.1127e-02,  1.3429e-02,
#          3.0900e-02, -2.1904e-02, -1.0484e-02, -2.2162e-02, -1.2238e-02,
#          2.7388e-02,  3.3277e-02, -2.1710e-02,  1.3705e-02,  2.4921e-02,
#         -1.3803e-02, -2.9361e-02, -2.0278e-02, -1.0721e-02,  1.5519e-02,
#          6.1975e-03,  1.8043e-02,  1.8398e-02,  3.0528e-02, -5.8010e-03,
#         -2.8242e-02,  1.4040e-02, -1.8481e-03, -2.5367e-02,  1.2356e-02,
#         -2.3469e-02, -1.2677e-02,  1.5184e-02, -1.5720e-02, -1.2411e-02,
#          3.1217e-02, -3.0069e-02,  2.7242e-03, -1.6598e-02,  2.4427e-02,
#         -2.8949e-02,  2.1957e-02, -6.7357e-03, -4.8904e-03,  1.8606e-02,
#          2.4289e-02, -3.0326e-02,  3.6537e-03, -7.9144e-03, -3.5702e-03,
#         -3.9920e-03,  2.6674e-02,  1.2820e-03, -1.0912e-04, -3.0273e-03,
#          1.5676e-02, -2.0162e-02, -3.4089e-02,  5.5755e-03,  3.0361e-02,
#         -1.9515e-02,  1.0003e-02,  8.8632e-03,  2.3180e-02,  7.3669e-03,
#         -2.7145e-03,  9.4633e-04,  1.6395e-02, -1.6580e-03, -2.3656e-02,
#         -5.8179e-03, -1.4666e-02, -1.8443e-04, -2.5139e-02,  2.7049e-02,
#          2.9654e-03, -8.9992e-03, -2.0723e-02, -4.0667e-03,  1.7162e-03,
#          2.9063e-02,  7.2380e-03,  2.5236e-03,  3.2032e-02,  1.8549e-02,
#          2.7457e-02, -1.3702e-02,  2.0656e-02, -2.3470e-02,  1.6852e-02,
#          1.0969e-02,  2.7397e-02, -8.7977e-03,  1.1843e-02,  3.3744e-03,
#         -3.0994e-02,  2.1801e-02, -2.9706e-02, -2.6023e-02, -8.2690e-03,
#         -8.8341e-03,  1.7581e-02,  1.7300e-02, -2.8252e-02, -8.9680e-03,
#         -1.5202e-02, -2.8544e-02, -1.0477e-02, -8.6913e-03,  2.1263e-02,
#         -2.8003e-02, -2.3665e-02, -2.7864e-02, -3.2677e-02,  2.3249e-02,
#          2.2354e-02, -6.2131e-03, -3.8592e-03,  1.6187e-02,  2.0539e-02,
#          1.3643e-02, -9.3222e-03,  2.6583e-02,  2.7269e-02,  8.0602e-03,
#         -2.6091e-02,  1.2464e-02, -2.5929e-02,  3.1768e-02, -1.4052e-02,
#          2.3494e-03,  1.2847e-02, -2.1107e-02, -1.6611e-02,  2.3743e-02,
#         -3.2507e-03, -1.1875e-02,  2.9532e-02, -4.0324e-04,  3.5315e-03,
#         -2.9240e-02, -2.7865e-02, -2.6379e-02,  2.1571e-02, -1.6827e-02,
#         -3.1286e-02,  1.4739e-02, -2.1390e-02, -3.1132e-02, -3.0402e-02,
#         -2.8223e-02, -1.8398e-02, -6.7490e-03,  3.9646e-02,  2.4659e-02,
#          2.4487e-02, -1.6736e-02, -2.8208e-02,  2.6662e-02, -2.8895e-02,
#         -1.4672e-02, -1.0138e-03, -3.9106e-02, -4.1023e-04,  2.6146e-03,
#         -2.8123e-02,  2.3652e-02,  3.6123e-03, -5.4925e-03, -1.9098e-02,
#          1.9509e-02, -3.1944e-02,  4.1500e-03, -1.8079e-02,  3.8921e-03,
#         -1.1470e-02, -4.9598e-03,  1.7685e-02, -3.7645e-03,  1.4680e-02,
#         -1.9267e-02,  9.1993e-05, -9.0442e-03,  3.0578e-02,  1.3292e-02,
#          2.3791e-02, -2.3603e-02,  2.8646e-02, -3.9579e-04, -2.9103e-02,
#          1.7320e-02, -2.7198e-02,  2.7439e-02,  2.4842e-02, -7.8135e-03,
#         -2.6831e-02, -2.7202e-02,  1.6476e-02, -2.6091e-02, -2.9337e-03,
#         -7.0863e-03,  2.3675e-02,  7.9154e-03,  9.0150e-03, -1.0523e-02,
#          2.5261e-02,  2.0984e-02,  2.6341e-02,  2.2772e-02, -2.7819e-02,
#         -2.0783e-02, -2.2009e-03,  3.8177e-03,  2.8162e-02,  1.1913e-02,
#         -1.7300e-02, -2.4767e-02,  2.3652e-02, -9.4774e-03,  4.8648e-03],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0256,  0.0050,  0.0008,  ...,  0.0316,  0.0264, -0.0347],
#         [-0.0177, -0.0028,  0.0003,  ..., -0.0118, -0.0229, -0.0376],
#         [ 0.0223, -0.0355, -0.0051,  ...,  0.0029, -0.0127, -0.0110],
#         ...,
#         [-0.0089, -0.0272, -0.0267,  ..., -0.0003,  0.0205, -0.0221],
#         [-0.0365,  0.0112, -0.0075,  ..., -0.0102, -0.0241,  0.0160],
#         [ 0.0263, -0.0308,  0.0254,  ...,  0.0054, -0.0338,  0.0361]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-3.3433e-02,  1.0088e-02, -1.7315e-02,  1.1555e-02,  1.3804e-02,
#          2.0118e-02,  2.5337e-02,  1.2852e-02,  3.3911e-02,  2.6534e-03,
#         -3.8014e-02,  2.5560e-02, -3.4354e-02, -2.9052e-02,  2.2418e-02,
#          3.5763e-02,  8.1305e-03,  7.0245e-04,  2.2403e-02, -1.5051e-02,
#         -3.3189e-02,  1.1975e-02, -3.5065e-03,  2.5433e-02, -2.9877e-02,
#         -2.3199e-02, -1.4059e-02, -3.0228e-02, -2.4606e-02,  1.0776e-02,
#         -7.8367e-03, -2.7064e-02,  5.7560e-03,  2.6224e-02, -4.3213e-03,
#         -2.4672e-02, -1.9300e-02, -2.2803e-02, -1.5885e-02,  1.7193e-03,
#         -3.1200e-02,  1.8805e-02, -1.1682e-02, -3.0354e-02, -3.2378e-02,
#         -1.7660e-02,  2.9765e-02, -1.0891e-02,  2.6607e-02, -2.4437e-02,
#         -1.5874e-02, -2.6914e-02, -9.1926e-03,  2.9604e-02, -5.4778e-03,
#         -1.2316e-02, -3.6910e-02,  1.2823e-02, -1.9875e-02, -3.8832e-02,
#         -1.2300e-03,  9.2381e-04,  3.8356e-03,  2.6971e-02, -1.3995e-02,
#          1.7291e-02, -3.7079e-02,  2.5774e-02,  8.0423e-03,  1.9109e-02,
#         -3.3680e-02, -2.0602e-02, -1.5742e-02,  1.6155e-02,  1.9693e-02,
#          2.2352e-03,  6.6661e-03, -2.1291e-02, -3.1545e-02,  8.0565e-03,
#         -2.2797e-02,  2.2874e-02,  3.0235e-02,  1.4285e-02,  3.5486e-02,
#          1.7045e-02, -3.6525e-02, -1.7569e-02, -3.6849e-03,  2.3311e-02,
#          1.2348e-02, -3.3992e-02,  2.8224e-02,  3.1276e-02, -6.9981e-03,
#          8.5252e-03, -3.1328e-02,  1.7703e-02,  1.8292e-02, -3.0418e-02,
#          2.5006e-02, -3.3459e-02,  1.7922e-02, -2.5070e-02, -3.7110e-02,
#          4.5960e-03, -3.5333e-02, -2.6135e-02, -1.5645e-02,  3.0973e-02,
#         -1.8378e-02,  1.0947e-04, -1.6599e-02, -3.8005e-02,  3.2412e-02,
#          1.4529e-02, -1.8069e-02, -1.3653e-02,  2.1411e-03, -7.0462e-03,
#          1.8205e-03, -9.1590e-03, -2.0029e-02,  1.3009e-02,  2.4749e-02,
#         -2.7761e-02,  6.1411e-03,  3.0898e-02,  1.0098e-02,  7.5646e-03,
#          1.0120e-02,  1.3817e-02,  2.4889e-03, -3.3293e-02,  1.4703e-02,
#         -3.1058e-02,  3.4465e-03, -5.2375e-03, -1.5571e-02, -2.7686e-02,
#          9.7646e-03,  2.4083e-02, -1.0557e-02, -2.4151e-03,  1.8073e-02,
#          2.5990e-02, -2.6779e-02,  1.9199e-02, -6.6912e-03,  1.1795e-02,
#          2.9784e-02,  1.3568e-03, -9.1380e-03, -1.9059e-02, -3.9758e-03,
#          2.3040e-02,  1.5786e-02,  1.9339e-02,  2.2048e-02,  4.1570e-03,
#         -2.4380e-02,  2.0298e-03,  7.0166e-03,  8.5679e-03,  1.1992e-02,
#          1.7800e-02, -3.0656e-02,  8.6871e-03,  2.5208e-02,  3.0590e-02,
#          8.5796e-03, -1.5792e-02,  3.3816e-02,  1.1066e-02,  3.1762e-02,
#          3.5345e-02, -1.3760e-03, -2.0201e-02,  7.6686e-03,  7.5903e-03,
#          1.4519e-02, -9.6425e-03, -2.0763e-04, -1.0372e-02, -1.1838e-02,
#          2.2425e-02,  9.9995e-03,  3.9345e-03,  2.3054e-02, -2.8603e-02,
#          1.8109e-02,  3.1742e-02, -3.3174e-02, -3.4664e-02,  1.8777e-02,
#          1.7414e-02, -1.2217e-02, -3.1612e-03, -2.9348e-02, -4.8952e-03,
#         -1.8244e-02, -1.6545e-02, -2.9301e-02,  1.5571e-02, -5.8677e-03,
#          1.0062e-03,  3.3484e-02,  2.0996e-02, -2.9417e-02,  2.9596e-02,
#         -2.0666e-02,  2.4566e-03,  3.4009e-04,  1.8612e-02, -3.7389e-03,
#          4.6121e-03,  2.8737e-02, -2.8816e-02,  9.7840e-03,  6.6094e-03,
#         -2.0003e-02,  2.7508e-02,  2.4168e-03,  6.4410e-03, -3.4033e-02,
#          3.7358e-02, -2.4205e-02, -1.6966e-02, -2.3299e-02, -3.7806e-02,
#          2.1757e-02, -2.4989e-02,  3.3767e-04, -1.9675e-03, -3.4094e-02,
#         -2.6098e-02,  5.0234e-03,  1.5229e-02, -1.5480e-02, -3.2177e-03,
#         -3.5964e-02,  3.5127e-02, -1.4287e-02,  1.0755e-02,  3.0811e-02,
#         -7.0118e-04, -3.5930e-02, -1.4821e-02,  9.3687e-03, -1.7867e-02,
#          1.5362e-02, -1.4113e-02, -3.2818e-02,  8.2295e-03,  2.1419e-02,
#         -2.3095e-03, -2.1508e-02, -1.5008e-02, -3.2520e-02,  3.1466e-02,
#          2.8819e-03, -2.9016e-02,  1.2288e-02, -4.5892e-04, -3.3283e-02,
#          2.3759e-02,  2.4413e-02,  8.5230e-03,  1.5232e-02, -2.7593e-02,
#         -2.6959e-02, -2.4732e-02,  1.3739e-02,  2.8728e-02, -1.3242e-02,
#         -1.3960e-02, -1.8497e-02, -3.0655e-02,  3.4352e-02,  2.8285e-02,
#         -3.8854e-02, -6.8137e-04, -6.9336e-03, -2.0249e-03,  6.4608e-04,
#          1.9840e-02,  9.7297e-03, -4.8097e-03,  2.0947e-02, -8.7084e-03,
#         -1.0564e-02, -2.2666e-02, -3.8520e-02, -3.5477e-02, -1.0704e-02,
#         -3.3905e-02, -9.5294e-03,  1.0875e-02, -2.5318e-02,  1.8171e-02,
#          2.9865e-02,  2.9568e-03, -1.2046e-02,  2.9009e-02, -3.9471e-02,
#          6.2804e-03, -8.8717e-03,  3.4696e-02, -1.6523e-02,  2.0725e-03,
#         -1.9235e-02,  1.6709e-02, -9.3412e-04, -2.3195e-02,  7.9592e-03,
#         -2.6585e-03,  2.5847e-02, -2.5826e-02, -3.0205e-02,  1.3086e-02,
#         -1.3359e-02,  3.1920e-02,  3.1153e-02,  2.8801e-02,  3.4030e-02,
#          3.0960e-02,  2.0708e-02,  2.8889e-02, -1.4189e-02, -2.2614e-02,
#         -1.9555e-02,  8.7599e-03,  1.3019e-02,  1.5776e-03, -3.9941e-02,
#          8.6152e-03, -1.5708e-03, -4.3612e-03, -1.6373e-02, -3.1675e-02,
#          1.9545e-02,  9.1255e-03,  3.2760e-03,  3.5640e-02,  2.8447e-02,
#          2.8700e-02,  6.0698e-03, -1.4733e-03,  7.7081e-03,  3.4514e-02,
#          2.4799e-02, -2.3549e-02, -3.7236e-03,  2.1877e-02,  2.9383e-03,
#         -1.1847e-02, -6.2165e-03, -2.6979e-02, -3.2927e-02, -2.5065e-02,
#          7.3243e-03,  4.3450e-03,  7.2391e-03, -3.1675e-02,  3.1017e-02,
#          5.5395e-03, -2.4027e-02, -1.5077e-02,  1.6086e-02, -7.1667e-03,
#          1.6201e-02,  2.4013e-02,  1.3221e-02,  9.4276e-03,  1.8044e-02,
#          9.6352e-04,  1.4862e-02, -3.0501e-02, -1.0522e-02, -1.9290e-02,
#         -6.5045e-04, -3.3195e-02, -8.5112e-03, -1.0691e-02, -3.7739e-02,
#          2.3898e-02,  8.1964e-03, -2.0046e-02,  2.5437e-02, -1.3629e-02,
#          1.9998e-02,  1.7355e-02, -8.9565e-03, -2.6987e-02, -2.9569e-02,
#         -2.0629e-03,  3.4116e-02, -2.1622e-02,  1.7405e-03, -1.1598e-02,
#          3.3722e-02,  1.3486e-02,  1.8780e-02,  3.3845e-02, -3.0550e-02,
#         -2.9526e-02,  9.8578e-03,  2.9776e-02, -2.4563e-02,  3.4312e-02,
#          2.9336e-02, -1.7256e-02,  1.7740e-02,  2.6482e-02,  1.9030e-02,
#          3.4382e-02, -2.2393e-02, -4.3642e-03,  1.3918e-03,  3.8968e-02,
#          2.6302e-02,  1.5797e-02, -8.6564e-03, -2.7788e-02, -1.0343e-02,
#         -3.0556e-02, -2.9031e-02,  3.5548e-02,  2.0096e-03, -6.3906e-03,
#         -8.9334e-03,  2.3651e-02,  1.5362e-02,  9.0196e-03,  9.1213e-03,
#         -2.5697e-02, -1.4274e-02,  1.0733e-02, -2.8496e-02, -1.2242e-02,
#         -6.8422e-03,  5.6213e-03,  2.0386e-02,  3.3237e-02,  1.9454e-02,
#          2.4529e-02, -3.5538e-02, -2.9880e-02, -2.4128e-02, -6.3102e-03,
#         -3.0956e-02,  2.9105e-03, -2.1094e-03, -3.0026e-04,  3.4358e-02,
#          1.6189e-02, -1.1186e-03, -4.4572e-03, -1.5867e-03,  2.7528e-02,
#          3.1891e-03,  3.8067e-03, -8.0532e-03, -9.4393e-03,  2.6138e-02,
#         -2.0130e-02,  1.7371e-03, -1.1904e-02, -1.2045e-02,  1.5227e-02,
#          2.5623e-02,  6.0706e-03, -2.3858e-02,  1.7062e-02,  4.9357e-03,
#          2.3528e-02, -2.7303e-03,  2.6619e-02,  1.1904e-02,  3.5313e-02,
#         -4.5872e-03, -2.6892e-02,  3.4548e-02,  2.0146e-02, -1.8343e-02,
#         -7.7302e-03, -6.2882e-03,  3.2206e-02, -1.5241e-02,  2.1146e-02,
#         -3.2912e-02, -1.6862e-02, -2.1201e-02,  1.6790e-02, -8.8222e-03,
#         -5.5975e-03,  1.7259e-02, -2.2579e-03, -2.8657e-02, -1.1749e-02,
#         -3.1286e-02,  2.3392e-02, -1.5827e-02, -3.1087e-02,  2.4764e-02,
#         -1.1634e-02, -1.8345e-02,  1.2877e-02,  1.1240e-02, -3.0706e-02,
#          3.8659e-03, -4.5538e-03, -1.0127e-02,  1.1759e-03, -5.8159e-03,
#          4.7388e-03,  2.4140e-02,  2.3596e-02,  1.1583e-02,  1.2437e-02,
#         -2.3911e-02,  2.2785e-02, -4.3299e-03, -7.0486e-03, -3.5438e-02,
#         -1.8180e-02,  5.2524e-03, -3.3761e-02,  3.3045e-02, -1.7740e-02,
#         -2.8436e-02, -3.3926e-02, -2.4934e-02,  2.7759e-02, -5.9123e-04,
#         -3.0590e-02, -3.3783e-02,  5.7499e-03,  1.7440e-02,  1.0090e-02,
#          4.2221e-03,  2.9207e-02,  2.7148e-02, -5.2852e-03, -6.4436e-03,
#          2.0831e-02,  2.8212e-02, -3.5821e-02,  3.1701e-02, -7.6090e-03,
#          7.0977e-03,  5.0319e-03, -3.2172e-02, -2.3980e-03,  1.3860e-02,
#         -3.9435e-03, -1.1970e-03,  3.7128e-02,  1.9034e-02,  1.9614e-02,
#          2.6673e-03,  1.5465e-02, -2.6496e-03,  1.2718e-02, -2.0575e-02,
#         -5.2172e-03,  3.3415e-02, -2.5798e-02, -3.6610e-02, -1.4467e-02,
#          7.8263e-03, -1.4587e-02, -1.1086e-02, -2.8406e-02,  2.7740e-02,
#          6.4845e-03, -2.3192e-02, -3.5886e-02, -1.7962e-02, -3.7089e-02,
#         -2.5317e-02,  1.9813e-02, -1.0750e-02, -8.2324e-03, -3.0732e-02,
#          7.4805e-03,  2.6592e-02, -7.7360e-03,  9.0657e-03, -2.2457e-02,
#         -1.0287e-02,  1.9019e-02,  1.2113e-02,  8.3673e-03, -3.4256e-03,
#          9.9436e-03, -1.3698e-02, -4.2793e-03, -8.6202e-03, -7.1471e-03,
#          3.4894e-02, -3.8545e-02, -1.8126e-02, -2.1943e-02,  1.6190e-02,
#          2.7423e-02,  1.3628e-02,  6.2209e-03, -3.4107e-02, -1.8589e-03,
#         -1.4154e-02, -2.9276e-02,  3.2322e-02,  3.9176e-02,  1.4267e-03,
#          1.0415e-02,  5.3706e-03,  2.8721e-02, -3.4416e-02, -2.6853e-02,
#          1.4104e-02, -4.5175e-03, -1.9961e-03, -3.0790e-02,  3.0512e-02,
#         -2.9559e-02, -2.2476e-03, -2.5889e-02,  2.9981e-02, -1.0343e-02,
#         -1.7942e-03, -2.5725e-02, -3.8282e-03,  2.6800e-02,  3.0227e-02,
#          1.2858e-02,  2.4759e-02, -3.2648e-02,  7.4258e-03,  4.0313e-03,
#          4.7966e-03, -1.4717e-02,  2.7153e-03,  1.4435e-02, -1.1729e-02,
#         -2.1233e-02,  2.9850e-02, -2.5915e-02,  1.6868e-02,  3.1713e-02,
#          1.5128e-02,  8.6744e-03, -4.2085e-02, -2.8778e-02,  2.0635e-02,
#         -2.8940e-02, -1.7957e-02, -6.6418e-03,  1.5757e-02, -7.2058e-03,
#          2.3186e-02, -3.5996e-02, -1.5913e-02, -1.6448e-02,  3.0441e-02,
#         -1.4165e-02,  2.9231e-02, -3.2646e-02,  3.8530e-04, -1.4177e-02,
#          2.9765e-03,  2.0653e-03,  3.3208e-02, -3.3326e-02,  3.3926e-02,
#         -4.3477e-03, -2.5801e-02, -2.9279e-02,  1.8531e-02, -2.9204e-02,
#          4.4656e-03,  1.7940e-02,  3.5832e-02,  3.7559e-02, -2.6208e-02,
#         -2.6961e-02,  2.3892e-02,  2.2296e-03,  2.0909e-02, -3.5297e-02,
#          1.9858e-02,  1.3971e-02,  1.3493e-02,  1.2311e-02, -1.4554e-03,
#         -1.5428e-02,  9.1470e-03,  1.0985e-02, -1.8840e-02, -1.0562e-02,
#          6.8789e-03, -3.0716e-02,  2.0629e-02,  8.0562e-03, -3.3360e-02,
#          2.5288e-02, -2.0937e-02,  2.2568e-02,  3.0532e-02, -4.0342e-03,
#          2.7497e-02,  3.9924e-02,  2.5660e-03,  9.4359e-03,  1.1584e-02,
#         -2.4076e-02,  1.2374e-03,  2.4729e-03,  7.9716e-04, -1.0364e-02,
#          3.6931e-03, -2.8496e-02,  3.1323e-02,  3.8118e-02,  1.9118e-02,
#         -2.3349e-02,  3.3034e-02, -1.9000e-02, -2.3116e-02,  2.5320e-02,
#         -3.1348e-02,  2.0482e-03,  2.7545e-02, -2.1042e-02, -1.3319e-02,
#         -1.9148e-02, -1.2188e-02,  3.3747e-02,  3.6868e-03, -1.9515e-02,
#          7.6656e-04, -3.7143e-02,  6.9474e-03, -1.9240e-02,  2.7420e-02,
#          2.5923e-02, -3.3895e-02, -4.0868e-02, -1.3612e-03,  6.5439e-03,
#         -1.7236e-02,  2.6937e-02,  1.5018e-02,  1.7434e-02, -1.5727e-02,
#          3.2208e-02, -1.9376e-02, -3.1937e-02, -3.6156e-02, -1.1754e-02,
#          9.1020e-03, -2.4964e-02,  8.0740e-03,  1.1798e-02,  2.2263e-02,
#         -9.5019e-03,  8.8039e-03, -2.0237e-02,  6.1342e-03, -2.4751e-02,
#          2.5852e-02, -2.0762e-02,  2.6144e-02,  2.1514e-02, -3.7445e-02,
#         -1.1822e-02, -3.4335e-03,  2.5368e-02, -7.2454e-03, -2.5221e-02,
#         -3.5504e-02,  2.2052e-02, -1.3658e-02,  3.4100e-02, -2.5192e-02,
#         -6.1144e-03,  3.6546e-02, -5.6366e-03, -6.0857e-03,  2.8845e-02,
#         -3.5907e-02,  2.4774e-02,  2.2641e-02,  1.1458e-02, -6.5549e-03,
#          8.7348e-03, -2.9146e-02, -6.7316e-03,  1.4234e-02,  2.1516e-02,
#          2.2584e-02, -1.7397e-02,  3.2178e-03,  2.4292e-02,  2.1277e-02,
#         -2.8861e-02, -3.4443e-02, -2.2292e-02, -1.5098e-02,  3.0964e-02,
#          1.1106e-02,  2.7126e-02,  7.5440e-03,  2.3087e-02, -1.6267e-02,
#          8.4463e-03,  2.4751e-02, -4.1414e-05, -2.6204e-02,  2.7404e-02,
#          1.2811e-02,  2.8110e-02, -1.6883e-02,  9.6921e-03, -3.6746e-02,
#          2.1528e-02, -6.9322e-03,  1.4481e-02,  3.2928e-02, -3.5648e-02,
#          3.3189e-02, -2.9149e-03,  3.5056e-03,  6.7146e-03,  2.1043e-02,
#         -7.7083e-03,  1.1173e-02, -1.4766e-02, -2.6583e-02, -4.5554e-03,
#         -1.8190e-02, -1.5294e-02,  2.3218e-03, -2.6795e-02,  1.1386e-02,
#         -2.7476e-02,  2.2592e-02,  3.5162e-02, -3.8385e-02,  1.6617e-03,
#          3.3131e-02, -3.1134e-02,  9.9623e-03, -2.8179e-02,  1.3790e-02,
#          8.3366e-03, -3.7018e-02, -9.5471e-03, -2.0404e-02,  8.8928e-03,
#         -9.7352e-03,  2.8869e-03, -1.9461e-02,  3.4353e-03,  1.6585e-02,
#         -1.2832e-02,  2.0594e-02, -7.2709e-03,  4.4800e-03, -2.3017e-03,
#         -3.1693e-02, -6.8958e-03, -2.4355e-02, -1.3156e-02,  3.0942e-02,
#          2.4739e-02,  2.5848e-02, -1.7154e-02,  3.7244e-02, -3.1933e-02,
#         -3.4959e-02,  4.8998e-04, -1.2789e-02,  1.8819e-02, -1.7911e-02,
#         -3.6509e-02, -3.5201e-02, -3.8000e-02,  3.9763e-02,  6.0033e-03,
#          5.4890e-03, -2.1235e-02, -2.8736e-02, -3.1731e-02,  1.1192e-02,
#         -3.5590e-02, -2.1306e-02,  1.4404e-02,  1.2968e-02, -1.5478e-02,
#          1.6058e-02,  3.1359e-02,  8.6954e-03,  1.9594e-02, -2.7099e-03,
#         -3.7228e-02,  1.8265e-02,  1.9775e-02,  1.5894e-02, -2.0027e-02,
#         -2.9665e-02,  7.1031e-03, -3.9023e-02, -4.0127e-03, -1.1550e-02,
#         -6.6930e-03, -1.9874e-02, -2.6593e-02,  3.0423e-02, -4.5152e-04,
#         -2.0298e-02,  2.0058e-02,  9.5116e-03,  3.5813e-02,  1.9792e-02,
#         -2.7937e-02,  2.8904e-02,  2.6493e-02, -6.9786e-03,  4.9849e-03,
#          1.7729e-02,  7.0577e-03,  1.8185e-02,  1.0223e-02, -8.2851e-03,
#         -3.8607e-02, -2.8320e-02, -5.0101e-03, -5.3026e-04, -7.1175e-03,
#         -2.2831e-02,  3.0515e-02, -5.2846e-03,  1.2986e-02,  3.8330e-02,
#         -5.6933e-04,  1.5743e-02, -3.2131e-02,  1.8337e-02,  1.2264e-03,
#         -3.7159e-02, -6.3872e-03, -1.2050e-02, -2.4075e-02,  2.5462e-02,
#         -2.4760e-02,  2.1630e-03,  3.4930e-02, -2.8806e-03,  1.3309e-02,
#          8.7116e-03,  1.2038e-02,  1.8960e-02, -3.0859e-03,  2.5609e-02,
#          2.0512e-02, -1.7839e-02, -3.7036e-02, -2.5602e-04, -2.1523e-02,
#          7.8869e-03,  1.8169e-02, -1.7561e-02,  2.8851e-03,  1.6798e-02,
#         -5.3780e-03, -8.1937e-03,  3.6506e-02,  1.2378e-02,  9.6542e-04,
#          3.5003e-02, -1.2257e-02, -2.8790e-02, -1.7084e-02, -3.8421e-03,
#         -3.6285e-02,  9.2310e-03,  2.6738e-02, -2.1916e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0238,  0.0001, -0.0222,  ...,  0.0259,  0.0227, -0.0130],
#         [-0.0109,  0.0059,  0.0207,  ..., -0.0010,  0.0104, -0.0271],
#         [ 0.0126,  0.0318, -0.0267,  ...,  0.0010, -0.0135,  0.0191],
#         ...,
#         [-0.0112, -0.0040,  0.0075,  ..., -0.0325,  0.0462, -0.0267],
#         [-0.0005, -0.0161,  0.0118,  ...,  0.0233, -0.0245,  0.0310],
#         [ 0.0282,  0.0082, -0.0131,  ...,  0.0280,  0.0320,  0.0221]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 2.2797e-02,  5.3039e-03, -1.7466e-02,  1.8118e-02, -1.2966e-02,
#         -2.0916e-02, -9.5724e-03,  2.8303e-03,  1.4512e-02, -2.3265e-03,
#          2.7124e-03, -2.8902e-02, -3.1648e-02,  2.0558e-02, -3.3483e-02,
#         -4.8372e-03, -5.0136e-03, -1.2792e-02,  2.9727e-02,  5.2491e-03,
#         -1.3435e-02, -2.0119e-02, -2.3168e-02, -1.8538e-02,  1.7572e-05,
#          2.2765e-02,  1.9163e-02,  2.2773e-03,  2.0045e-02,  8.1675e-03,
#         -9.8198e-03, -4.7332e-03,  1.5949e-02,  1.1143e-02,  1.2208e-02,
#         -1.8318e-02,  2.1678e-02,  1.1916e-03, -1.4703e-02, -1.5149e-02,
#         -2.4143e-02, -2.8627e-02,  1.4107e-02,  1.1177e-02, -2.0446e-02,
#          1.4354e-02,  2.1095e-02, -4.5120e-03, -3.2073e-03,  4.3145e-03,
#          7.7136e-03, -1.5547e-02, -2.4648e-02,  2.2146e-02, -1.9575e-02,
#          1.9489e-02,  2.2330e-02, -1.3551e-02,  1.2113e-02, -8.0878e-03,
#          2.9491e-02, -3.0799e-02,  1.2504e-02, -8.5808e-03, -2.2987e-02,
#          2.2646e-02, -2.7518e-02,  1.8772e-02, -2.7943e-02,  2.3814e-02,
#         -2.8122e-02, -1.2152e-02, -2.2849e-02, -2.5280e-02, -1.6859e-02,
#          3.0207e-02, -1.5273e-02,  7.6413e-03, -2.2747e-02,  1.1530e-02,
#          3.0025e-03,  2.3164e-02,  1.7600e-02, -8.4929e-03, -9.0112e-03,
#         -2.3049e-02, -2.5906e-02,  7.3704e-04,  3.4048e-02,  1.5967e-02,
#          2.3849e-02, -1.8138e-02, -1.9478e-02,  2.9098e-02,  3.5174e-03,
#         -2.8453e-02, -2.0729e-02, -1.1465e-03, -2.6284e-02, -1.0226e-02,
#          1.4311e-02,  2.3921e-02,  9.8973e-03, -1.8984e-02, -1.1671e-02,
#         -1.1816e-02,  3.3903e-02, -2.1695e-02, -1.3518e-02,  2.5522e-02,
#         -2.4750e-02,  1.9863e-02,  2.0374e-02, -2.1659e-02,  1.4186e-02,
#          2.1326e-02, -2.4187e-02, -4.6927e-03, -1.6643e-02,  6.7343e-03,
#         -1.9287e-02,  2.2433e-02,  2.5659e-02,  1.2223e-02, -7.9314e-03,
#          1.5384e-02,  2.5141e-02,  3.3497e-02, -2.1108e-03, -1.6362e-02,
#         -2.9692e-02, -8.9396e-04,  1.5135e-02, -1.8258e-02,  2.0400e-02,
#         -2.6834e-02,  1.0638e-02,  2.0557e-02, -2.0102e-02,  8.5654e-03,
#         -2.3459e-02, -4.7496e-03, -1.8505e-02, -1.0601e-02, -6.2731e-03,
#          1.5460e-02,  3.2834e-02, -2.8859e-03, -4.4223e-03, -2.6199e-02,
#         -1.5798e-02,  1.2842e-02,  3.1610e-02,  1.4278e-02,  3.1410e-02,
#         -1.2012e-02,  1.1369e-02,  7.9331e-04, -2.6568e-02,  2.3969e-02,
#          2.2148e-02, -3.1658e-03,  1.9815e-02, -1.7566e-02, -2.1669e-02,
#         -1.6813e-02, -2.2238e-02,  2.0450e-02, -2.5015e-02,  3.0301e-02,
#         -1.3383e-02,  1.6164e-03,  1.6393e-02, -2.4806e-02,  2.5285e-02,
#         -1.7792e-02, -1.2870e-02,  9.4381e-03, -1.7158e-02,  2.5707e-02,
#          2.7712e-02, -6.2615e-03,  1.3257e-03, -9.4087e-04, -2.5881e-02,
#         -2.7452e-02,  9.8865e-03, -2.6378e-02,  3.1829e-02, -2.7868e-02,
#          1.0025e-02,  1.5727e-02, -3.0749e-02, -7.1063e-03, -1.8766e-03,
#          8.1553e-03, -1.6611e-02, -7.9622e-03, -2.0186e-04, -8.4521e-03,
#         -2.8760e-03, -9.7305e-03, -2.6165e-02, -3.3107e-02,  1.4029e-02,
#         -5.5513e-03, -1.6290e-03, -5.2544e-03,  7.8204e-03, -2.1947e-02,
#          2.2426e-02,  2.4640e-02,  2.6730e-02,  2.9307e-02,  2.6034e-02,
#         -1.2631e-02,  2.5880e-03,  4.5194e-03,  2.2003e-02,  2.3851e-02,
#         -3.3092e-02,  1.1045e-02,  1.2318e-02,  1.9134e-02,  2.3030e-02,
#          2.6391e-02,  2.5083e-02,  2.1346e-02,  2.7919e-02,  1.5650e-02,
#          5.4978e-03,  2.1739e-02,  9.2633e-03, -6.7770e-03, -5.6715e-03,
#         -8.6117e-03, -2.5043e-02, -7.7056e-04, -4.5929e-03,  1.9689e-02,
#         -3.2545e-02, -2.1630e-02, -5.6770e-03,  8.6417e-03, -1.1635e-02,
#          2.4951e-02, -1.3135e-02,  5.2484e-03,  2.7856e-02, -2.0698e-02,
#         -1.8695e-02,  1.3315e-02,  2.9087e-02, -2.1805e-02,  1.2951e-02,
#         -1.4607e-02, -1.9923e-02,  6.6556e-03, -3.5085e-03, -2.4799e-02,
#          1.7730e-02,  1.2800e-02, -1.5814e-02, -1.9941e-02, -2.9747e-02,
#         -3.1621e-02,  1.5087e-02, -1.2591e-02,  2.4017e-02,  1.3015e-02,
#          1.4488e-02,  1.1205e-02,  1.8991e-02, -2.8987e-04, -1.8525e-02,
#          2.1767e-02, -2.7613e-02, -5.2606e-04, -2.5164e-03, -6.7868e-03,
#         -1.3137e-02,  2.3253e-02,  2.4083e-02,  2.1094e-02, -1.2349e-03,
#         -2.0243e-02, -2.5565e-02,  3.0128e-02, -4.3012e-03,  3.3320e-03,
#         -2.0242e-02,  2.3801e-03,  1.2599e-02,  2.1717e-03, -2.2725e-02,
#         -1.8134e-02,  6.9744e-03,  2.6895e-02, -2.9277e-02, -1.4490e-02,
#          1.8832e-02, -9.6978e-03, -4.4133e-03, -1.0428e-02,  2.4109e-02,
#          1.7435e-02,  2.2393e-02, -5.9590e-03,  2.8719e-02,  5.4231e-03,
#          2.7801e-02, -9.4561e-03, -1.4193e-02, -2.6813e-02,  3.7918e-04,
#          1.4844e-03, -1.4760e-02, -8.0552e-03, -3.0459e-02, -1.4793e-02,
#          2.2373e-02,  2.8898e-02,  3.3558e-02,  1.8384e-02,  1.4853e-02,
#         -1.4580e-03, -7.9142e-03,  1.9683e-02, -2.0722e-02, -1.1707e-02,
#         -2.0709e-02, -2.0059e-02, -8.4255e-03, -3.0117e-03,  1.4990e-03,
#          2.7381e-02, -2.4559e-03, -3.0645e-02, -2.8792e-02,  2.1667e-02,
#          1.3292e-02,  1.4574e-02,  1.1132e-02,  6.3941e-03,  1.9354e-02,
#         -1.5894e-02,  2.2805e-02,  2.4949e-02, -2.1671e-02, -3.9728e-03,
#         -2.2508e-02, -6.5806e-03, -2.7002e-02,  1.9192e-02,  1.1666e-02,
#          1.1574e-02, -4.9970e-03, -8.5795e-03,  1.1449e-03, -3.4424e-02,
#          2.1968e-02,  1.3108e-02, -2.5838e-02, -2.2965e-02,  2.2304e-02,
#         -2.7064e-02,  1.7899e-03,  4.2982e-03,  2.2276e-02, -1.9189e-02,
#          1.8723e-02, -2.6141e-04,  1.0621e-02, -1.1753e-02, -1.7206e-02,
#          2.5523e-02,  1.0626e-02,  2.8680e-02,  2.2880e-02, -1.2356e-02,
#         -5.2589e-03, -1.4750e-02,  5.2899e-03, -2.3291e-02, -4.5088e-03,
#         -2.6658e-02, -7.7310e-03,  2.3300e-02,  2.5793e-02,  2.4470e-02,
#         -1.5007e-02,  1.6274e-02,  3.0193e-02, -2.6785e-02,  1.2306e-02,
#         -5.2207e-03, -2.5619e-03, -2.1693e-03,  2.8743e-02, -3.2643e-03,
#         -3.0485e-02, -2.9871e-02,  7.6798e-03,  2.4455e-02, -1.3084e-02,
#          2.7269e-03, -8.7948e-03,  6.0306e-03, -1.4082e-02,  1.8245e-02,
#          2.7146e-02, -4.6475e-03, -2.2069e-02, -1.3805e-02,  4.7140e-03,
#         -1.5807e-02, -3.7091e-03, -4.3208e-03,  3.0258e-02,  2.9937e-02,
#         -4.5360e-03,  2.5031e-02, -5.9761e-03, -1.1617e-02,  1.5293e-02,
#          7.6715e-03,  7.7226e-03, -8.1980e-03,  8.2457e-03,  1.2706e-02,
#          2.3077e-02, -1.6161e-02,  1.4043e-02, -2.0139e-02,  1.2936e-02,
#         -1.4637e-02, -2.6367e-02, -2.4996e-02, -8.0577e-03,  1.9949e-02,
#          2.1701e-02,  2.4550e-02,  3.5360e-03, -1.7012e-02, -2.3162e-02,
#          4.0443e-03, -1.1556e-02, -2.9198e-02,  3.0129e-02,  7.1528e-03,
#         -9.4022e-03, -1.6991e-02,  1.8806e-02, -2.6402e-02,  2.4227e-02,
#         -1.9426e-02,  3.6811e-03,  2.4716e-02, -3.0333e-03, -2.7457e-02,
#          2.9599e-02, -1.3990e-02, -3.1326e-02, -2.7242e-02,  2.8455e-02,
#         -2.0590e-02, -1.1063e-02, -4.8865e-03, -8.4844e-03, -2.5128e-02,
#         -3.3373e-02,  1.3738e-02,  5.0829e-03, -2.8015e-02, -4.9686e-03,
#         -1.2866e-02,  2.3880e-02,  8.5485e-03, -2.5185e-02, -5.8503e-03,
#          1.8303e-02, -8.6672e-03,  2.8426e-02,  1.7247e-02,  2.1306e-02,
#         -2.7342e-02, -1.5537e-02,  2.8359e-02, -1.7898e-02, -2.4308e-02,
#          1.3883e-03,  2.9384e-02, -2.0425e-02,  1.2998e-02,  3.6402e-03,
#         -3.7168e-03, -1.1495e-02, -1.5485e-03, -6.9615e-03, -1.5799e-02,
#         -6.2259e-03, -6.0779e-03,  1.4925e-03,  8.9204e-03,  5.7965e-03,
#          1.8202e-02,  3.2989e-02,  4.5080e-03,  2.3680e-02,  1.0907e-02,
#          9.4396e-03, -1.4725e-02, -1.4501e-02,  2.3672e-02,  1.7302e-02,
#         -3.1640e-02,  2.4180e-02, -1.8217e-02,  3.4733e-03,  2.2564e-02,
#         -3.1570e-02, -1.9351e-02, -1.1581e-02,  2.9566e-02,  2.3808e-02,
#          1.2018e-02,  2.7164e-02, -1.4856e-02, -1.7184e-02, -4.3657e-03,
#         -1.1064e-02, -6.2580e-03,  1.3008e-02, -7.6189e-03, -1.5284e-02,
#          1.6197e-02,  1.6639e-02, -1.9033e-02, -1.6065e-02, -2.1268e-02,
#          1.4057e-03,  8.1535e-03, -3.0067e-02, -2.7391e-02,  1.5501e-02,
#         -2.2537e-02,  9.6004e-03,  6.4805e-04, -2.3988e-02,  5.9036e-03,
#          1.6920e-02, -1.0193e-02, -3.0116e-02,  1.7380e-02, -2.2944e-03,
#          3.2452e-02, -3.3852e-03,  1.7647e-02,  2.0923e-02, -2.6650e-02,
#          1.4941e-02, -2.3806e-02, -2.9960e-02,  3.2715e-02, -2.9792e-02,
#          1.5323e-03, -1.7969e-02, -4.3232e-03,  8.4602e-03,  1.2117e-02,
#         -4.3908e-03,  1.9435e-02, -2.3862e-02, -2.0926e-02,  4.9969e-03,
#         -2.5812e-02, -2.0311e-02, -7.2182e-03,  5.4307e-04, -1.3833e-02,
#          1.6902e-02, -2.8585e-02,  9.9241e-03, -6.9337e-04, -1.4809e-03,
#          6.0666e-03,  7.0439e-04,  1.6823e-02, -2.5249e-02, -1.3601e-02,
#          1.2267e-02,  9.1512e-03, -1.4182e-02, -5.8234e-03,  1.4802e-02,
#          1.5738e-02, -3.4307e-04, -9.1496e-03,  1.3670e-02, -2.1515e-02,
#         -1.4893e-03,  1.7270e-02,  2.0809e-03, -1.0042e-02,  2.4884e-02,
#          3.0756e-02,  9.5966e-03,  1.3706e-02, -1.2569e-02,  2.0432e-03,
#          1.2858e-02,  6.4333e-04,  1.3741e-02], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-1.9171e-02,  2.3385e-03,  2.4162e-02, -3.3349e-02, -6.1967e-03,
#           3.9288e-02,  8.0303e-03,  6.1971e-03,  3.4514e-02, -3.6055e-02,
#          -3.2154e-02, -3.4635e-02, -3.7192e-02,  3.9441e-02, -6.0038e-03,
#           2.0160e-02,  1.4734e-02,  1.0574e-02,  1.2708e-02,  2.5096e-02,
#           8.7503e-04,  2.0684e-02,  1.0074e-02,  3.5906e-02, -3.5769e-02,
#          -1.5850e-02,  3.0942e-02,  1.1865e-02,  2.8790e-03, -6.4385e-03,
#           5.3851e-03, -1.1990e-02, -9.9885e-03,  2.3476e-02,  4.0630e-02,
#          -2.0363e-02, -6.4680e-03,  3.0206e-02,  2.0806e-02, -2.9855e-03,
#           6.3436e-03, -1.6514e-02,  1.7351e-02,  3.9659e-04,  3.0659e-02,
#           2.7954e-02, -1.0554e-03, -8.8836e-03, -3.4602e-04, -3.8285e-02,
#          -5.5424e-03, -4.1464e-02,  3.1242e-02,  1.2970e-02,  2.0551e-03,
#           2.6871e-02,  2.1356e-03,  1.3162e-02, -3.3979e-02, -3.0460e-02,
#           1.0970e-02, -1.6859e-02,  4.2749e-03,  1.8149e-02,  3.4497e-02,
#           3.8702e-03,  3.5059e-02,  2.5902e-02,  3.2092e-02, -1.7361e-02,
#           7.5200e-03, -3.6769e-02,  3.1979e-02,  4.0438e-02, -3.9039e-02,
#          -1.1883e-02, -1.1871e-02,  8.0411e-04, -8.5720e-05,  2.1894e-02,
#          -3.8287e-02, -3.6470e-02, -2.6565e-02, -3.2409e-02, -4.8395e-03,
#           3.1240e-02, -2.5122e-02,  8.7603e-05,  1.7842e-02, -2.8143e-02,
#           2.7605e-02,  1.2260e-02,  1.6393e-02,  2.7254e-02,  2.8462e-02,
#           8.4783e-03, -1.1030e-03, -2.2103e-03,  2.0768e-02,  2.6592e-02,
#           2.1506e-02, -2.2521e-02, -3.0851e-02, -3.6893e-02, -8.3024e-03,
#           2.4776e-02, -2.1983e-02, -2.0451e-02, -1.5583e-02, -2.2162e-02,
#           1.1481e-03,  3.6772e-02,  2.8090e-02,  6.1830e-03,  3.0543e-02,
#          -1.3502e-02, -2.3558e-02, -2.7400e-02, -6.8308e-03,  2.9748e-02,
#          -2.5661e-02,  3.7863e-02,  9.8995e-03,  4.0483e-02,  3.8935e-02,
#           1.9910e-02, -3.6755e-03,  4.9892e-03, -2.2269e-02,  3.7370e-02,
#          -1.4188e-02,  2.2840e-02, -2.4265e-02,  1.7845e-02, -2.2876e-02,
#          -1.3605e-03, -2.7219e-03,  1.4603e-02, -1.9764e-02,  3.1225e-02,
#          -3.4559e-02, -2.7567e-02,  6.2236e-03, -3.2626e-02, -1.6555e-02,
#          -3.1775e-02,  2.4376e-02,  3.9416e-02,  3.5781e-02, -7.1633e-03,
#           2.9885e-02,  1.0226e-02,  1.4797e-02, -2.5607e-02,  1.6426e-02,
#          -6.3630e-03, -1.5697e-02, -2.3114e-02,  1.6057e-02, -3.5316e-02,
#          -2.9035e-02, -3.2986e-02,  2.5360e-03,  1.9537e-02, -9.4876e-04,
#          -1.1712e-02,  2.5625e-02, -1.9437e-02,  8.5348e-03, -2.7007e-02,
#           9.3517e-03,  1.7583e-02,  2.4555e-02, -6.6513e-03, -2.8649e-02,
#           4.0564e-02, -3.3240e-03,  3.4091e-02,  2.6597e-02, -3.0279e-02,
#          -3.4911e-02,  2.4267e-02, -1.4975e-02, -5.3223e-03,  1.5964e-02,
#           2.5487e-02,  8.4030e-03,  1.4886e-02, -1.4958e-04, -1.7724e-02,
#          -1.5284e-02, -2.0844e-02, -3.8260e-02,  3.6055e-04,  1.3444e-02,
#          -2.3592e-02,  2.0810e-02, -1.4423e-02, -2.6655e-02,  4.4883e-03,
#           3.8848e-02,  1.1257e-02,  2.5936e-03,  2.1948e-02,  1.5892e-02,
#          -3.0573e-02,  3.0839e-02, -1.7373e-02,  3.9176e-02, -9.3273e-03,
#           2.8665e-02, -3.2918e-04, -3.0050e-02, -3.8119e-02, -3.9860e-03,
#           3.6301e-02, -1.8237e-02, -2.2690e-03, -3.7320e-02, -5.4201e-03,
#           1.8783e-02, -5.9588e-03,  8.4970e-04, -1.9312e-02,  1.1383e-02,
#          -2.6976e-02,  1.6726e-02, -2.8412e-02,  2.9605e-02,  1.2241e-02,
#           2.0035e-02,  2.4568e-02,  1.7680e-03, -1.8107e-02,  2.0467e-02,
#          -2.7223e-02,  1.4110e-02, -1.9015e-02, -2.4243e-02, -3.3757e-02,
#          -3.4975e-02, -1.2728e-02,  2.9983e-02, -2.8511e-05,  3.4559e-02,
#           2.5850e-02,  1.5304e-02,  4.5310e-03, -1.7087e-02,  1.6509e-02,
#          -5.8350e-03, -1.9614e-03, -1.5011e-02, -2.2176e-02, -8.6824e-03,
#          -2.2182e-02, -1.5908e-02,  1.1530e-02, -7.3371e-03, -2.4309e-02,
#           2.9278e-02, -3.4274e-02, -2.8378e-02,  1.7417e-02,  4.7914e-03,
#          -1.9528e-02, -6.6725e-03,  4.7689e-03, -2.9296e-02, -3.5244e-02,
#           3.7342e-02, -1.6323e-02,  2.5724e-02, -1.7547e-03,  3.3367e-02,
#           2.3625e-02, -3.3377e-02, -5.4497e-03, -3.7726e-03, -9.6981e-03,
#          -3.5216e-06, -2.2233e-02,  1.8326e-02,  3.2932e-02,  1.3344e-03,
#          -2.6504e-02, -2.8535e-02,  2.4820e-02,  2.8941e-02,  2.4186e-02,
#           3.0665e-02,  1.5006e-02,  5.6359e-04, -3.5200e-02, -3.0697e-02,
#          -7.0026e-03, -1.6452e-02, -6.7163e-03, -2.9083e-02, -2.8087e-02,
#           8.7009e-03, -6.8220e-03, -3.8352e-02,  2.2187e-02,  3.7375e-02,
#          -2.4820e-02,  3.7449e-02,  7.3181e-03,  2.2737e-02, -3.1026e-02,
#           2.5293e-02, -2.9865e-02,  3.3828e-02, -2.7034e-02, -3.0476e-02,
#           3.6318e-02, -3.6566e-02,  3.5282e-02, -2.7857e-02, -2.3140e-03,
#           3.0986e-02,  1.2630e-02,  1.8290e-02, -1.6807e-02,  3.1432e-02,
#          -3.0426e-03,  5.6128e-03,  1.5610e-03,  8.3905e-05, -2.3912e-02,
#           3.9774e-02,  2.0587e-02,  1.2544e-02, -6.2324e-03,  3.5769e-02,
#           3.9545e-02,  2.3307e-02,  1.1342e-02, -1.2895e-02,  1.2663e-02,
#           3.0478e-02,  3.4635e-03,  1.5362e-02,  2.3373e-02,  3.5053e-02,
#          -3.0379e-02,  1.5797e-03, -2.2488e-02, -1.2980e-02,  3.0099e-02,
#          -1.2221e-02,  3.0042e-02,  3.0542e-03, -2.5565e-02,  3.0537e-02,
#          -1.0277e-02, -3.4526e-02, -1.9424e-02,  2.2844e-02, -7.3467e-03,
#          -2.0306e-02, -3.1272e-02,  1.0858e-02, -2.8960e-02, -7.1549e-04,
#           3.2188e-03, -3.5986e-02,  2.2320e-02,  1.7309e-02, -1.0024e-02,
#           4.9286e-03, -3.1836e-02,  3.4464e-02, -3.0054e-02, -9.7962e-03,
#          -3.2331e-02,  1.4402e-03, -3.2051e-02,  3.3053e-03, -2.5388e-02,
#           3.7389e-02, -1.5455e-02, -2.0180e-03,  1.9316e-02,  1.4332e-02,
#           2.0899e-02,  2.5427e-02,  3.8295e-02, -1.3724e-02, -3.5655e-03,
#          -5.6163e-03, -1.0945e-02, -3.2521e-02,  2.3533e-02,  1.7835e-02,
#           2.0067e-02, -2.9809e-02, -2.7494e-02,  3.7139e-02, -2.7250e-02,
#           1.0935e-02,  1.2698e-02,  3.1240e-02,  1.7378e-02, -2.0243e-03,
#          -1.0553e-02,  3.0817e-02,  2.9612e-02,  1.9682e-02,  1.6868e-02,
#          -1.3057e-02, -3.6455e-02, -3.4035e-02, -7.5899e-03, -8.6369e-04,
#           1.6794e-04, -2.6515e-03, -1.6906e-02,  1.6263e-03, -7.5860e-03,
#           2.7032e-02, -2.6733e-02,  3.9242e-02, -3.8371e-03,  3.8531e-02,
#          -3.4585e-02, -1.9060e-02, -1.4726e-02, -1.3131e-02,  1.4097e-02,
#          -1.5279e-02, -3.6706e-02, -2.3941e-02, -3.3983e-02,  2.1045e-02,
#          -3.0426e-03,  8.5491e-03, -1.3064e-04, -2.0225e-02,  2.8152e-02,
#           1.3540e-02, -4.9262e-03,  1.1881e-02, -3.2555e-02, -2.4850e-02,
#          -2.6257e-03,  1.0711e-02, -1.8385e-02,  1.3249e-02,  1.6883e-02,
#          -2.2758e-02, -1.8385e-02,  1.1712e-02,  9.4163e-03, -1.3358e-02,
#          -1.4517e-02,  5.9876e-03,  3.5074e-02,  3.3367e-03, -3.8232e-02,
#           2.1645e-02,  3.7517e-02, -9.1379e-03, -5.1898e-03, -8.2503e-03,
#           2.9404e-02,  2.4504e-02, -1.7403e-03, -1.2273e-02,  3.6032e-02,
#          -2.3300e-02, -3.9469e-04,  4.2000e-02,  5.0773e-05,  5.2702e-03,
#           2.8235e-02, -1.4188e-02,  4.2535e-03,  1.8388e-02,  1.8942e-02,
#          -1.8818e-02, -2.7141e-02, -1.4187e-02,  9.5856e-03, -3.6019e-02,
#           1.4477e-02, -3.8531e-02,  2.9410e-02,  1.6865e-02, -2.8260e-02,
#           1.1622e-03, -1.1412e-02,  1.4267e-03,  3.4687e-02, -3.5144e-03,
#           5.4962e-05, -3.0338e-02,  3.7745e-02,  1.7373e-02, -2.7162e-02,
#          -6.4843e-03,  1.0316e-02,  1.4573e-02, -2.0919e-02,  1.1296e-02,
#           4.0005e-02,  3.6852e-02, -6.9608e-03, -2.1592e-02,  7.1570e-03,
#          -6.1113e-04, -3.5255e-02,  2.1404e-02, -3.3543e-02, -3.3751e-03,
#          -3.4742e-02,  3.1238e-02, -8.2760e-03, -2.3147e-02,  3.6726e-02,
#          -6.1382e-03, -2.4243e-02, -1.0589e-02,  3.3432e-02,  1.4706e-02,
#           7.1991e-03, -3.4433e-02, -2.3955e-02, -1.3337e-02,  1.0835e-02,
#           9.0033e-03,  3.0418e-02, -1.3136e-02, -2.4416e-02,  2.6374e-02,
#           4.0234e-02, -2.8725e-02, -2.3821e-02, -1.0850e-02, -4.9247e-03,
#           2.5141e-02,  3.6834e-02, -9.4672e-03,  3.2142e-02,  1.0570e-02,
#          -2.0797e-02,  1.2695e-02,  1.5753e-02,  1.3318e-02,  4.4551e-03,
#          -2.0225e-02,  4.2355e-02, -2.9652e-02,  6.1125e-03, -3.4582e-02,
#           3.3879e-02, -3.3417e-03,  2.2021e-02, -1.9923e-03, -1.9976e-02,
#          -1.9501e-02,  1.1034e-02,  3.1232e-02,  5.4924e-03,  2.8825e-02,
#           2.7714e-03, -1.9450e-04, -3.4162e-02, -5.1993e-03,  1.9691e-02,
#           3.2825e-02, -3.4057e-02,  2.3917e-02,  1.4656e-02, -8.5178e-03,
#           3.8042e-02, -1.0492e-02, -1.4133e-02,  1.2774e-02,  1.4537e-03,
#          -5.9021e-03, -4.5817e-03, -7.8459e-03, -1.4687e-02, -1.6988e-02,
#          -3.6000e-02, -3.9912e-03, -3.7653e-02,  2.0906e-03,  1.5010e-02,
#          -2.3324e-02,  2.1363e-03,  2.1172e-02,  1.4024e-03,  2.4233e-02,
#           3.4027e-02, -3.8028e-02, -2.0072e-02,  1.0758e-03,  1.0684e-02,
#          -1.3147e-03,  1.4534e-03, -3.5420e-02,  4.4491e-03,  2.0429e-02,
#           3.7194e-02,  3.4255e-02, -2.2685e-02,  7.4886e-03, -5.0316e-03,
#          -9.1734e-03,  8.3073e-03, -1.0064e-02]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([0.0399], device='cuda:0', requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=617, bias=True)
#     (1): Linear(in_features=617, out_features=858, bias=True)
#     (2): Linear(in_features=858, out_features=720, bias=True)
#     (3): Linear(in_features=720, out_features=989, bias=True)
#     (4): Linear(in_features=989, out_features=613, bias=True)
#     (5): Linear(in_features=613, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[ 8.4823,  1.2874,  3.8433],
#         [ 6.3628,  4.5830,  6.8709],
#         [ 9.5007, 10.5686, 14.5369],
#         [ 2.7702,  9.1947,  8.4208],
#         [ 8.1549,  8.1288,  4.1824],
#         [ 2.8599,  0.6266,  5.7706],
#         [ 9.4994, 24.8554, 24.3957],
#         [ 5.9511,  6.8335,  5.0241],
#         [ 1.0827,  0.7347,  1.1826],
#         [ 3.3039,  4.2094,  4.9122],
#         [ 5.1887, 10.3858,  9.6000],
#         [ 8.6661, 16.7210, 16.3864],
#         [ 6.5375,  1.9848,  7.9297],
#         [ 9.7648, 31.8522, 29.5890],
#         [12.9340, 11.8892,  5.2417],
#         [ 9.3644,  3.6599,  3.9022],
#         [ 3.9849, 10.0192,  8.5279],
#         [ 0.7702,  1.3431,  0.9888],
#         [ 9.5696,  0.1444,  2.6998],
#         [ 7.7714, 11.4869, 16.6507]], device='cuda:0')

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5091], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.9191], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.7094], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8222], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.5884], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8286], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.6004], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.5002], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.6899], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.3369], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.0099], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.8070], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.1761], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([6.8930], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.4192], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.2016], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7600], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.1816], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7998], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.7712], device='cuda:0', grad_fn=<ReluBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=617, bias=True)
#     (1): Linear(in_features=617, out_features=858, bias=True)
#     (2): Linear(in_features=858, out_features=720, bias=True)
#     (3): Linear(in_features=720, out_features=989, bias=True)
#     (4): Linear(in_features=989, out_features=613, bias=True)
#     (5): Linear(in_features=613, out_features=1, bias=True)
#   )
# )

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5091], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.9191], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.7094], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.8222], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.5884], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.8286], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.6004], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.5002], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.6899], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.3369], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([3.0099], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.8070], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([5.1761], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([6.8930], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.4192], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([2.2016], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7600], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([0.1816], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([1.7998], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([8.7712], device='cuda:0', grad_fn=<ReluBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[ 0.2856,  1.0171, -0.3333]], device='cuda:0')
# tensor([[2.0342, 2.2249, 4.1557]], device='cuda:0')
# tensor([[2.4343]], device='cuda:0', grad_fn=<ReluBackward0>)
