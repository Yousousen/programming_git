# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# **training with found best parameters:**
# ```
# [I 2023-05-13 13:36:16,457] Trial 42 finished with value: 0.004305121898895595 and parameters: {'n_layers': 3, 'n_units_0': 86, 'n_units_1': 201, 'n_units_2': 87, 'hidden_activation': 'ReLU', 'output_activation': 'Linear', 'loss': 'MAE', 'optimizer': 'Adam', 'lr': 0.0007324856218845869, 'batch_size': 223, 'n_epochs': 62, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 42 with value: 0.004305121898895595.
#
# ```

# %%
# %%script echo skipping
#
# !jupyter nbconvert 0043.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on google colab,

# %%
#%%script echo skipping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (2.6)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.
#
# NOTE: Some subparameters still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 3
N_UNITS_NO_OPT = [86, 201, 87]
HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
LOSS_NAME_NO_OPT = "MAE"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 0.0007324856218845869
BATCH_SIZE_NO_OPT = 223
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

#Best trial:
# Adam', 'lr': 0.0007324856218845869, 'batch_size': 223, 'n_epochs': 62, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 42 with value: 0.004305121898895595.


c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)
# Out:
# tensor([1.9220, 2.2925, 1.3112,  ..., 1.3882, 1.4931, 5.2596], device='cuda:0')

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
if ZSCORE_NORMALIZATION:
    # Computing the mean and standard deviation of each input variable from the training set
    D_mean = torch.mean(x_train[:, 0])
    D_std = torch.std(x_train[:, 0])
    Sx_mean = torch.mean(x_train[:, 1])
    Sx_std = torch.std(x_train[:, 1])
    tau_mean = torch.mean(x_train[:, 2])
    tau_std = torch.std(x_train[:, 2])

    # Applying z-score normalization to both train and test sets using the statistics from the training set
    x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
    x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
    x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
    x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
    x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
    x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
print(torch.mean(x_train[:, 0]))
print(torch.std(x_train[:, 0]))
print(torch.mean(x_train[:, 1]))
print(torch.std(x_train[:, 1]))
print(torch.mean(x_train[:, 2]))
print(torch.std(x_train[:, 2]))

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()
# Out:
# tensor(5.6259, device='cuda:0')
# tensor(3.3305, device='cuda:0')
# tensor(6.8267, device='cuda:0')
# tensor(8.0801, device='cuda:0')
# tensor(8.0068, device='cuda:0')
# tensor(7.8406, device='cuda:0')

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min" #, factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        else:
            scheduler = None
#Best trial:
#  Value:  0.00270861783316941
#  Params: 
#    n_layers: 3
#    n_units_0: 555
#    n_units_1: 458
#    n_units_2: 115
#    hidden_activation: ReLU
#    output_activation: ReLU
#    loss: Huber
#    optimizer: RMSprop
#    lr: 0.000122770896701404
#    batch_size: 49
#    n_epochs: 152
#    scheduler: ReduceLROnPlateau
#    factor: 0.18979341786654758
#    patience: 11
#    threshold: 0.0017197466122611932


    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: L1Loss()
# batch_size: 223
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f6d3d0745e0>
# loss_name: MAE
# optimizer_name: Adam
# scheduler_name: ReduceLROnPlateau
# n_units: [86, 201, 87]
# n_layers: 3
# hidden_activation: ReLU()
# output_activation: Identity()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.1977, Test Loss: 0.0483, Train L1 Norm: 0.3784, Test L1 Norm: 0.0472, Train Linf Norm: 47.5735, Test Linf Norm: 4.3275
# Epoch 2: Train Loss: 0.0474, Test Loss: 0.0374, Train L1 Norm: 0.0885, Test L1 Norm: 0.1056, Train Linf Norm: 11.9416, Test Linf Norm: 13.7052
# Epoch 3: Train Loss: 0.0327, Test Loss: 0.0219, Train L1 Norm: 0.0696, Test L1 Norm: 0.0523, Train Linf Norm: 9.8283, Test Linf Norm: 5.8738
# Epoch 4: Train Loss: 0.0349, Test Loss: 0.0189, Train L1 Norm: 0.0710, Test L1 Norm: 0.0249, Train Linf Norm: 10.3052, Test Linf Norm: 2.1444
# Epoch 5: Train Loss: 0.0403, Test Loss: 0.0768, Train L1 Norm: 0.0643, Test L1 Norm: 0.1035, Train Linf Norm: 8.3140, Test Linf Norm: 10.0536
# Epoch 6: Train Loss: 0.0303, Test Loss: 0.0094, Train L1 Norm: 0.0620, Test L1 Norm: 0.0292, Train Linf Norm: 9.0030, Test Linf Norm: 3.5120
# Epoch 7: Train Loss: 0.0324, Test Loss: 0.0148, Train L1 Norm: 0.0566, Test L1 Norm: 0.0288, Train Linf Norm: 7.7429, Test Linf Norm: 3.2206
# Epoch 8: Train Loss: 0.0248, Test Loss: 0.0205, Train L1 Norm: 0.0379, Test L1 Norm: 0.0455, Train Linf Norm: 4.4628, Test Linf Norm: 6.2969
# Epoch 9: Train Loss: 0.0242, Test Loss: 0.0210, Train L1 Norm: 0.0453, Test L1 Norm: 0.0355, Train Linf Norm: 6.0211, Test Linf Norm: 4.6940
# Epoch 10: Train Loss: 0.0273, Test Loss: 0.0232, Train L1 Norm: 0.0443, Test L1 Norm: 0.0476, Train Linf Norm: 5.6896, Test Linf Norm: 6.1144
# Epoch 11: Train Loss: 0.0259, Test Loss: 0.0410, Train L1 Norm: 0.0426, Test L1 Norm: 0.0398, Train Linf Norm: 5.3224, Test Linf Norm: 3.0654
# Epoch 12: Train Loss: 0.0340, Test Loss: 0.0213, Train L1 Norm: 0.0540, Test L1 Norm: 0.0379, Train Linf Norm: 7.1303, Test Linf Norm: 4.9787
# Epoch 13: Train Loss: 0.0218, Test Loss: 0.0414, Train L1 Norm: 0.0423, Test L1 Norm: 0.0880, Train Linf Norm: 5.8882, Test Linf Norm: 10.4252
# Epoch 14: Train Loss: 0.0269, Test Loss: 0.0366, Train L1 Norm: 0.0401, Test L1 Norm: 0.0425, Train Linf Norm: 5.0165, Test Linf Norm: 4.3361
# Epoch 15: Train Loss: 0.0217, Test Loss: 0.0198, Train L1 Norm: 0.0370, Test L1 Norm: 0.0600, Train Linf Norm: 4.9089, Test Linf Norm: 8.2116
# Epoch 16: Train Loss: 0.0332, Test Loss: 0.0321, Train L1 Norm: 0.0475, Test L1 Norm: 0.0486, Train Linf Norm: 5.8678, Test Linf Norm: 6.0919
# Epoch 17: Train Loss: 0.0278, Test Loss: 0.0168, Train L1 Norm: 0.0432, Test L1 Norm: 0.0256, Train Linf Norm: 5.4242, Test Linf Norm: 2.6671
# Epoch 18: Train Loss: 0.0064, Test Loss: 0.0061, Train L1 Norm: 0.0175, Test L1 Norm: 0.0212, Train Linf Norm: 2.4807, Test Linf Norm: 3.0062
# Epoch 19: Train Loss: 0.0056, Test Loss: 0.0053, Train L1 Norm: 0.0154, Test L1 Norm: 0.0189, Train Linf Norm: 2.1601, Test Linf Norm: 2.6614
# Epoch 20: Train Loss: 0.0054, Test Loss: 0.0050, Train L1 Norm: 0.0155, Test L1 Norm: 0.0197, Train Linf Norm: 2.2460, Test Linf Norm: 2.8132
# Epoch 21: Train Loss: 0.0052, Test Loss: 0.0053, Train L1 Norm: 0.0139, Test L1 Norm: 0.0191, Train Linf Norm: 1.8847, Test Linf Norm: 2.7093
# Epoch 22: Train Loss: 0.0050, Test Loss: 0.0057, Train L1 Norm: 0.0147, Test L1 Norm: 0.0192, Train Linf Norm: 2.0735, Test Linf Norm: 2.7150
# Epoch 23: Train Loss: 0.0049, Test Loss: 0.0048, Train L1 Norm: 0.0148, Test L1 Norm: 0.0200, Train Linf Norm: 2.1961, Test Linf Norm: 2.9263
# Epoch 24: Train Loss: 0.0047, Test Loss: 0.0041, Train L1 Norm: 0.0128, Test L1 Norm: 0.0180, Train Linf Norm: 1.7297, Test Linf Norm: 2.6079
# Epoch 25: Train Loss: 0.0045, Test Loss: 0.0045, Train L1 Norm: 0.0130, Test L1 Norm: 0.0156, Train Linf Norm: 1.8314, Test Linf Norm: 2.1307
# Epoch 26: Train Loss: 0.0045, Test Loss: 0.0065, Train L1 Norm: 0.0137, Test L1 Norm: 0.0215, Train Linf Norm: 1.9579, Test Linf Norm: 3.0506
# Epoch 27: Train Loss: 0.0044, Test Loss: 0.0044, Train L1 Norm: 0.0121, Test L1 Norm: 0.0142, Train Linf Norm: 1.6763, Test Linf Norm: 1.9102
# Epoch 28: Train Loss: 0.0042, Test Loss: 0.0042, Train L1 Norm: 0.0125, Test L1 Norm: 0.0159, Train Linf Norm: 1.7431, Test Linf Norm: 2.2107
# Epoch 29: Train Loss: 0.0041, Test Loss: 0.0042, Train L1 Norm: 0.0120, Test L1 Norm: 0.0187, Train Linf Norm: 1.6802, Test Linf Norm: 2.7640
# Epoch 30: Train Loss: 0.0041, Test Loss: 0.0040, Train L1 Norm: 0.0123, Test L1 Norm: 0.0189, Train Linf Norm: 1.7706, Test Linf Norm: 2.7365
# Epoch 31: Train Loss: 0.0041, Test Loss: 0.0034, Train L1 Norm: 0.0120, Test L1 Norm: 0.0148, Train Linf Norm: 1.7040, Test Linf Norm: 2.1070
# Epoch 32: Train Loss: 0.0038, Test Loss: 0.0032, Train L1 Norm: 0.0113, Test L1 Norm: 0.0146, Train Linf Norm: 1.6005, Test Linf Norm: 2.0078
# Epoch 33: Train Loss: 0.0038, Test Loss: 0.0046, Train L1 Norm: 0.0110, Test L1 Norm: 0.0139, Train Linf Norm: 1.5382, Test Linf Norm: 1.8868
# Epoch 34: Train Loss: 0.0036, Test Loss: 0.0030, Train L1 Norm: 0.0104, Test L1 Norm: 0.0110, Train Linf Norm: 1.4076, Test Linf Norm: 1.4179
# Epoch 35: Train Loss: 0.0037, Test Loss: 0.0044, Train L1 Norm: 0.0115, Test L1 Norm: 0.0115, Train Linf Norm: 1.6630, Test Linf Norm: 1.4255
# Epoch 36: Train Loss: 0.0039, Test Loss: 0.0029, Train L1 Norm: 0.0114, Test L1 Norm: 0.0100, Train Linf Norm: 1.6067, Test Linf Norm: 1.2463
# Epoch 37: Train Loss: 0.0034, Test Loss: 0.0056, Train L1 Norm: 0.0095, Test L1 Norm: 0.0124, Train Linf Norm: 1.2925, Test Linf Norm: 1.4823
# Epoch 38: Train Loss: 0.0037, Test Loss: 0.0030, Train L1 Norm: 0.0103, Test L1 Norm: 0.0139, Train Linf Norm: 1.4060, Test Linf Norm: 1.8785
# Epoch 39: Train Loss: 0.0035, Test Loss: 0.0029, Train L1 Norm: 0.0102, Test L1 Norm: 0.0102, Train Linf Norm: 1.4440, Test Linf Norm: 1.2733
# Epoch 40: Train Loss: 0.0036, Test Loss: 0.0036, Train L1 Norm: 0.0096, Test L1 Norm: 0.0117, Train Linf Norm: 1.2820, Test Linf Norm: 1.4497
# Epoch 41: Train Loss: 0.0035, Test Loss: 0.0028, Train L1 Norm: 0.0095, Test L1 Norm: 0.0086, Train Linf Norm: 1.3129, Test Linf Norm: 1.0451
# Epoch 42: Train Loss: 0.0034, Test Loss: 0.0028, Train L1 Norm: 0.0098, Test L1 Norm: 0.0090, Train Linf Norm: 1.3707, Test Linf Norm: 1.1249
# Epoch 43: Train Loss: 0.0034, Test Loss: 0.0038, Train L1 Norm: 0.0081, Test L1 Norm: 0.0078, Train Linf Norm: 0.9746, Test Linf Norm: 0.8353
# Epoch 44: Train Loss: 0.0034, Test Loss: 0.0041, Train L1 Norm: 0.0093, Test L1 Norm: 0.0071, Train Linf Norm: 1.2821, Test Linf Norm: 0.6824
# Epoch 45: Train Loss: 0.0033, Test Loss: 0.0034, Train L1 Norm: 0.0094, Test L1 Norm: 0.0091, Train Linf Norm: 1.3008, Test Linf Norm: 1.0705
# Epoch 46: Train Loss: 0.0033, Test Loss: 0.0029, Train L1 Norm: 0.0087, Test L1 Norm: 0.0066, Train Linf Norm: 1.1593, Test Linf Norm: 0.7084
# Epoch 47: Train Loss: 0.0034, Test Loss: 0.0031, Train L1 Norm: 0.0078, Test L1 Norm: 0.0073, Train Linf Norm: 0.9282, Test Linf Norm: 0.7655
# Epoch 48: Train Loss: 0.0031, Test Loss: 0.0043, Train L1 Norm: 0.0079, Test L1 Norm: 0.0084, Train Linf Norm: 1.0201, Test Linf Norm: 0.8835
# Epoch 49: Train Loss: 0.0033, Test Loss: 0.0025, Train L1 Norm: 0.0081, Test L1 Norm: 0.0082, Train Linf Norm: 1.0090, Test Linf Norm: 0.9939
# Epoch 50: Train Loss: 0.0033, Test Loss: 0.0045, Train L1 Norm: 0.0082, Test L1 Norm: 0.0082, Train Linf Norm: 1.0978, Test Linf Norm: 0.8971
# Epoch 51: Train Loss: 0.0032, Test Loss: 0.0026, Train L1 Norm: 0.0082, Test L1 Norm: 0.0078, Train Linf Norm: 1.0926, Test Linf Norm: 0.9306
# Epoch 52: Train Loss: 0.0031, Test Loss: 0.0028, Train L1 Norm: 0.0079, Test L1 Norm: 0.0076, Train Linf Norm: 1.0118, Test Linf Norm: 0.9062
# Epoch 53: Train Loss: 0.0033, Test Loss: 0.0052, Train L1 Norm: 0.0085, Test L1 Norm: 0.0113, Train Linf Norm: 1.1609, Test Linf Norm: 1.2547
# Epoch 54: Train Loss: 0.0031, Test Loss: 0.0030, Train L1 Norm: 0.0093, Test L1 Norm: 0.0084, Train Linf Norm: 1.3438, Test Linf Norm: 0.9165
# Epoch 55: Train Loss: 0.0031, Test Loss: 0.0024, Train L1 Norm: 0.0076, Test L1 Norm: 0.0081, Train Linf Norm: 0.9623, Test Linf Norm: 0.9634
# Epoch 56: Train Loss: 0.0030, Test Loss: 0.0026, Train L1 Norm: 0.0087, Test L1 Norm: 0.0098, Train Linf Norm: 1.2200, Test Linf Norm: 1.2843
# Epoch 57: Train Loss: 0.0030, Test Loss: 0.0024, Train L1 Norm: 0.0084, Test L1 Norm: 0.0086, Train Linf Norm: 1.1483, Test Linf Norm: 1.1052
# Epoch 58: Train Loss: 0.0032, Test Loss: 0.0044, Train L1 Norm: 0.0088, Test L1 Norm: 0.0080, Train Linf Norm: 1.2193, Test Linf Norm: 0.9415
# Epoch 59: Train Loss: 0.0033, Test Loss: 0.0023, Train L1 Norm: 0.0071, Test L1 Norm: 0.0096, Train Linf Norm: 0.8675, Test Linf Norm: 1.2911
# Epoch 60: Train Loss: 0.0032, Test Loss: 0.0083, Train L1 Norm: 0.0082, Test L1 Norm: 0.0115, Train Linf Norm: 1.1111, Test Linf Norm: 1.3050
# Epoch 61: Train Loss: 0.0034, Test Loss: 0.0040, Train L1 Norm: 0.0077, Test L1 Norm: 0.0121, Train Linf Norm: 0.9710, Test Linf Norm: 1.6144
# Epoch 62: Train Loss: 0.0028, Test Loss: 0.0023, Train L1 Norm: 0.0071, Test L1 Norm: 0.0085, Train Linf Norm: 0.8810, Test Linf Norm: 1.0526
# Epoch 63: Train Loss: 0.0034, Test Loss: 0.0026, Train L1 Norm: 0.0080, Test L1 Norm: 0.0097, Train Linf Norm: 1.0718, Test Linf Norm: 1.2441
# Epoch 64: Train Loss: 0.0030, Test Loss: 0.0025, Train L1 Norm: 0.0082, Test L1 Norm: 0.0119, Train Linf Norm: 1.1390, Test Linf Norm: 1.6524
# Epoch 65: Train Loss: 0.0028, Test Loss: 0.0035, Train L1 Norm: 0.0076, Test L1 Norm: 0.0107, Train Linf Norm: 1.0110, Test Linf Norm: 1.4620
# Epoch 66: Train Loss: 0.0035, Test Loss: 0.0032, Train L1 Norm: 0.0093, Test L1 Norm: 0.0090, Train Linf Norm: 1.3389, Test Linf Norm: 1.0960
# Epoch 67: Train Loss: 0.0033, Test Loss: 0.0023, Train L1 Norm: 0.0077, Test L1 Norm: 0.0092, Train Linf Norm: 1.0237, Test Linf Norm: 1.2409
# Epoch 68: Train Loss: 0.0030, Test Loss: 0.0025, Train L1 Norm: 0.0073, Test L1 Norm: 0.0090, Train Linf Norm: 0.9465, Test Linf Norm: 1.2114
# Epoch 69: Train Loss: 0.0030, Test Loss: 0.0022, Train L1 Norm: 0.0068, Test L1 Norm: 0.0080, Train Linf Norm: 0.8627, Test Linf Norm: 1.0322
# Epoch 70: Train Loss: 0.0031, Test Loss: 0.0034, Train L1 Norm: 0.0078, Test L1 Norm: 0.0087, Train Linf Norm: 1.0680, Test Linf Norm: 1.1103
# Epoch 71: Train Loss: 0.0028, Test Loss: 0.0023, Train L1 Norm: 0.0079, Test L1 Norm: 0.0088, Train Linf Norm: 1.0890, Test Linf Norm: 1.1224
# Epoch 72: Train Loss: 0.0029, Test Loss: 0.0029, Train L1 Norm: 0.0080, Test L1 Norm: 0.0085, Train Linf Norm: 1.1267, Test Linf Norm: 1.0767
# Epoch 73: Train Loss: 0.0029, Test Loss: 0.0021, Train L1 Norm: 0.0070, Test L1 Norm: 0.0069, Train Linf Norm: 0.8708, Test Linf Norm: 0.8600
# Epoch 74: Train Loss: 0.0029, Test Loss: 0.0023, Train L1 Norm: 0.0077, Test L1 Norm: 0.0073, Train Linf Norm: 1.0769, Test Linf Norm: 0.8895
# Epoch 75: Train Loss: 0.0031, Test Loss: 0.0023, Train L1 Norm: 0.0074, Test L1 Norm: 0.0112, Train Linf Norm: 0.9759, Test Linf Norm: 1.5359
# Epoch 76: Train Loss: 0.0029, Test Loss: 0.0025, Train L1 Norm: 0.0072, Test L1 Norm: 0.0087, Train Linf Norm: 0.9803, Test Linf Norm: 1.1672
# Epoch 77: Train Loss: 0.0034, Test Loss: 0.0023, Train L1 Norm: 0.0081, Test L1 Norm: 0.0076, Train Linf Norm: 1.0630, Test Linf Norm: 0.9412
# Epoch 78: Train Loss: 0.0031, Test Loss: 0.0035, Train L1 Norm: 0.0064, Test L1 Norm: 0.0103, Train Linf Norm: 0.7629, Test Linf Norm: 1.3059
# Epoch 79: Train Loss: 0.0027, Test Loss: 0.0022, Train L1 Norm: 0.0065, Test L1 Norm: 0.0084, Train Linf Norm: 0.8081, Test Linf Norm: 1.1017
# Epoch 80: Train Loss: 0.0028, Test Loss: 0.0024, Train L1 Norm: 0.0067, Test L1 Norm: 0.0084, Train Linf Norm: 0.8950, Test Linf Norm: 1.1285
# Epoch 81: Train Loss: 0.0028, Test Loss: 0.0023, Train L1 Norm: 0.0077, Test L1 Norm: 0.0072, Train Linf Norm: 1.0705, Test Linf Norm: 0.9385
# Epoch 82: Train Loss: 0.0031, Test Loss: 0.0021, Train L1 Norm: 0.0063, Test L1 Norm: 0.0090, Train Linf Norm: 0.7635, Test Linf Norm: 1.2119
# Epoch 83: Train Loss: 0.0032, Test Loss: 0.0022, Train L1 Norm: 0.0077, Test L1 Norm: 0.0097, Train Linf Norm: 1.0538, Test Linf Norm: 1.3077
# Epoch 84: Train Loss: 0.0026, Test Loss: 0.0021, Train L1 Norm: 0.0073, Test L1 Norm: 0.0087, Train Linf Norm: 1.0321, Test Linf Norm: 1.1962
# Epoch 85: Train Loss: 0.0027, Test Loss: 0.0020, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.9616, Test Linf Norm: 0.7873
# Epoch 86: Train Loss: 0.0027, Test Loss: 0.0021, Train L1 Norm: 0.0066, Test L1 Norm: 0.0087, Train Linf Norm: 0.8790, Test Linf Norm: 1.2042
# Epoch 87: Train Loss: 0.0028, Test Loss: 0.0029, Train L1 Norm: 0.0071, Test L1 Norm: 0.0086, Train Linf Norm: 0.9701, Test Linf Norm: 1.1113
# Epoch 88: Train Loss: 0.0025, Test Loss: 0.0022, Train L1 Norm: 0.0065, Test L1 Norm: 0.0084, Train Linf Norm: 0.8576, Test Linf Norm: 1.0632
# Epoch 89: Train Loss: 0.0029, Test Loss: 0.0020, Train L1 Norm: 0.0065, Test L1 Norm: 0.0088, Train Linf Norm: 0.8217, Test Linf Norm: 1.2299
# Epoch 90: Train Loss: 0.0025, Test Loss: 0.0020, Train L1 Norm: 0.0064, Test L1 Norm: 0.0110, Train Linf Norm: 0.8694, Test Linf Norm: 1.5442
# Epoch 91: Train Loss: 0.0030, Test Loss: 0.0035, Train L1 Norm: 0.0069, Test L1 Norm: 0.0079, Train Linf Norm: 0.9130, Test Linf Norm: 1.0073
# Epoch 92: Train Loss: 0.0029, Test Loss: 0.0023, Train L1 Norm: 0.0075, Test L1 Norm: 0.0087, Train Linf Norm: 1.0572, Test Linf Norm: 1.1603
# Epoch 93: Train Loss: 0.0027, Test Loss: 0.0021, Train L1 Norm: 0.0063, Test L1 Norm: 0.0079, Train Linf Norm: 0.8072, Test Linf Norm: 1.0165
# Epoch 94: Train Loss: 0.0030, Test Loss: 0.0022, Train L1 Norm: 0.0062, Test L1 Norm: 0.0110, Train Linf Norm: 0.7719, Test Linf Norm: 1.5304
# Epoch 95: Train Loss: 0.0027, Test Loss: 0.0020, Train L1 Norm: 0.0066, Test L1 Norm: 0.0083, Train Linf Norm: 0.8623, Test Linf Norm: 1.1454
# Epoch 96: Train Loss: 0.0027, Test Loss: 0.0029, Train L1 Norm: 0.0066, Test L1 Norm: 0.0089, Train Linf Norm: 0.8874, Test Linf Norm: 1.1609
# Epoch 97: Train Loss: 0.0026, Test Loss: 0.0019, Train L1 Norm: 0.0055, Test L1 Norm: 0.0067, Train Linf Norm: 0.6605, Test Linf Norm: 0.8819
# Epoch 98: Train Loss: 0.0030, Test Loss: 0.0025, Train L1 Norm: 0.0066, Test L1 Norm: 0.0096, Train Linf Norm: 0.8730, Test Linf Norm: 1.2648
# Epoch 99: Train Loss: 0.0026, Test Loss: 0.0042, Train L1 Norm: 0.0067, Test L1 Norm: 0.0066, Train Linf Norm: 0.9266, Test Linf Norm: 0.7952
# Epoch 100: Train Loss: 0.0030, Test Loss: 0.0034, Train L1 Norm: 0.0058, Test L1 Norm: 0.0095, Train Linf Norm: 0.6784, Test Linf Norm: 1.2018
# Epoch 101: Train Loss: 0.0029, Test Loss: 0.0019, Train L1 Norm: 0.0068, Test L1 Norm: 0.0079, Train Linf Norm: 0.9065, Test Linf Norm: 1.0803
# Epoch 102: Train Loss: 0.0028, Test Loss: 0.0019, Train L1 Norm: 0.0061, Test L1 Norm: 0.0095, Train Linf Norm: 0.7699, Test Linf Norm: 1.3024
# Epoch 103: Train Loss: 0.0028, Test Loss: 0.0018, Train L1 Norm: 0.0054, Test L1 Norm: 0.0076, Train Linf Norm: 0.6079, Test Linf Norm: 1.0418
# Epoch 104: Train Loss: 0.0027, Test Loss: 0.0042, Train L1 Norm: 0.0058, Test L1 Norm: 0.0092, Train Linf Norm: 0.7087, Test Linf Norm: 1.1856
# Epoch 105: Train Loss: 0.0027, Test Loss: 0.0018, Train L1 Norm: 0.0056, Test L1 Norm: 0.0043, Train Linf Norm: 0.6817, Test Linf Norm: 0.3996
# Epoch 106: Train Loss: 0.0025, Test Loss: 0.0034, Train L1 Norm: 0.0059, Test L1 Norm: 0.0052, Train Linf Norm: 0.7442, Test Linf Norm: 0.5471
# Epoch 107: Train Loss: 0.0029, Test Loss: 0.0030, Train L1 Norm: 0.0061, Test L1 Norm: 0.0080, Train Linf Norm: 0.7709, Test Linf Norm: 0.9897
# Epoch 108: Train Loss: 0.0033, Test Loss: 0.0019, Train L1 Norm: 0.0066, Test L1 Norm: 0.0067, Train Linf Norm: 0.8536, Test Linf Norm: 0.9152
# Epoch 109: Train Loss: 0.0028, Test Loss: 0.0021, Train L1 Norm: 0.0063, Test L1 Norm: 0.0088, Train Linf Norm: 0.8377, Test Linf Norm: 1.2056
# Epoch 110: Train Loss: 0.0028, Test Loss: 0.0020, Train L1 Norm: 0.0066, Test L1 Norm: 0.0074, Train Linf Norm: 0.8970, Test Linf Norm: 0.9726
# Epoch 111: Train Loss: 0.0025, Test Loss: 0.0023, Train L1 Norm: 0.0063, Test L1 Norm: 0.0076, Train Linf Norm: 0.8428, Test Linf Norm: 1.0387
# Epoch 112: Train Loss: 0.0029, Test Loss: 0.0027, Train L1 Norm: 0.0063, Test L1 Norm: 0.0058, Train Linf Norm: 0.7937, Test Linf Norm: 0.6856
# Epoch 113: Train Loss: 0.0026, Test Loss: 0.0050, Train L1 Norm: 0.0059, Test L1 Norm: 0.0065, Train Linf Norm: 0.7650, Test Linf Norm: 0.6708
# Epoch 114: Train Loss: 0.0024, Test Loss: 0.0020, Train L1 Norm: 0.0050, Test L1 Norm: 0.0070, Train Linf Norm: 0.5920, Test Linf Norm: 0.8493
# Epoch 115: Train Loss: 0.0027, Test Loss: 0.0030, Train L1 Norm: 0.0060, Test L1 Norm: 0.0073, Train Linf Norm: 0.7786, Test Linf Norm: 0.9027
# Epoch 116: Train Loss: 0.0027, Test Loss: 0.0042, Train L1 Norm: 0.0069, Test L1 Norm: 0.0071, Train Linf Norm: 0.9516, Test Linf Norm: 0.7823
# Epoch 117: Train Loss: 0.0017, Test Loss: 0.0017, Train L1 Norm: 0.0043, Test L1 Norm: 0.0055, Train Linf Norm: 0.5409, Test Linf Norm: 0.6910
# Epoch 118: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0054, Train Linf Norm: 0.4872, Test Linf Norm: 0.6921
# Epoch 119: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0050, Train Linf Norm: 0.4999, Test Linf Norm: 0.6151
# Epoch 120: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0057, Train Linf Norm: 0.4719, Test Linf Norm: 0.7547
# Epoch 121: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0041, Test L1 Norm: 0.0057, Train Linf Norm: 0.5135, Test Linf Norm: 0.7367
# Epoch 122: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0041, Test L1 Norm: 0.0049, Train Linf Norm: 0.5184, Test Linf Norm: 0.5818
# Epoch 123: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0051, Train Linf Norm: 0.4878, Test Linf Norm: 0.6396
# Epoch 124: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0047, Train Linf Norm: 0.4642, Test Linf Norm: 0.5592
# Epoch 125: Train Loss: 0.0016, Test Loss: 0.0017, Train L1 Norm: 0.0040, Test L1 Norm: 0.0052, Train Linf Norm: 0.4925, Test Linf Norm: 0.6501
# Epoch 126: Train Loss: 0.0016, Test Loss: 0.0018, Train L1 Norm: 0.0041, Test L1 Norm: 0.0049, Train Linf Norm: 0.4966, Test Linf Norm: 0.6039
# Epoch 127: Train Loss: 0.0016, Test Loss: 0.0017, Train L1 Norm: 0.0038, Test L1 Norm: 0.0055, Train Linf Norm: 0.4480, Test Linf Norm: 0.6928
# Epoch 128: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0038, Test L1 Norm: 0.0048, Train Linf Norm: 0.4406, Test Linf Norm: 0.5874
# Epoch 129: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0052, Train Linf Norm: 0.4564, Test Linf Norm: 0.6657
# Epoch 130: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0038, Test L1 Norm: 0.0054, Train Linf Norm: 0.4475, Test Linf Norm: 0.6990
# Epoch 131: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0049, Train Linf Norm: 0.4651, Test Linf Norm: 0.5958
# Epoch 132: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0052, Train Linf Norm: 0.4871, Test Linf Norm: 0.6439
# Epoch 133: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0038, Test L1 Norm: 0.0053, Train Linf Norm: 0.4522, Test Linf Norm: 0.6775
# Epoch 134: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0059, Train Linf Norm: 0.4713, Test Linf Norm: 0.7576
# Epoch 135: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0053, Train Linf Norm: 0.4691, Test Linf Norm: 0.6756
# Epoch 136: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0050, Train Linf Norm: 0.4853, Test Linf Norm: 0.6288
# Epoch 137: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0051, Train Linf Norm: 0.4647, Test Linf Norm: 0.6470
# Epoch 138: Train Loss: 0.0016, Test Loss: 0.0017, Train L1 Norm: 0.0038, Test L1 Norm: 0.0045, Train Linf Norm: 0.4394, Test Linf Norm: 0.5310
# Epoch 139: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0041, Test L1 Norm: 0.0051, Train Linf Norm: 0.4983, Test Linf Norm: 0.6272
# Epoch 140: Train Loss: 0.0016, Test Loss: 0.0018, Train L1 Norm: 0.0037, Test L1 Norm: 0.0051, Train Linf Norm: 0.4192, Test Linf Norm: 0.6505
# Epoch 141: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0038, Test L1 Norm: 0.0048, Train Linf Norm: 0.4424, Test Linf Norm: 0.5946
# Epoch 142: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0040, Test L1 Norm: 0.0050, Train Linf Norm: 0.4847, Test Linf Norm: 0.6316
# Epoch 143: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0050, Train Linf Norm: 0.4846, Test Linf Norm: 0.6349
# Epoch 144: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0037, Test L1 Norm: 0.0048, Train Linf Norm: 0.4286, Test Linf Norm: 0.5858
# Epoch 145: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0039, Test L1 Norm: 0.0045, Train Linf Norm: 0.4654, Test Linf Norm: 0.5342
# Epoch 146: Train Loss: 0.0016, Test Loss: 0.0016, Train L1 Norm: 0.0038, Test L1 Norm: 0.0049, Train Linf Norm: 0.4422, Test Linf Norm: 0.6096
# Epoch 147: Train Loss: 0.0015, Test Loss: 0.0016, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4247, Test Linf Norm: 0.6004
# Epoch 148: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0049, Train Linf Norm: 0.4010, Test Linf Norm: 0.6066
# Epoch 149: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4123, Test Linf Norm: 0.6039
# Epoch 150: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4038, Test Linf Norm: 0.5931
# Epoch 151: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4080, Test Linf Norm: 0.5989
# Epoch 152: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4028, Test Linf Norm: 0.6068
# Epoch 153: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4036, Test Linf Norm: 0.6079
# Epoch 154: Train Loss: 0.0015, Test Loss: 0.0016, Train L1 Norm: 0.0036, Test L1 Norm: 0.0047, Train Linf Norm: 0.4106, Test Linf Norm: 0.5835
# Epoch 155: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3921, Test Linf Norm: 0.5963
# Epoch 156: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.3987, Test Linf Norm: 0.6072
# Epoch 157: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4033, Test Linf Norm: 0.5933
# Epoch 158: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0047, Train Linf Norm: 0.4179, Test Linf Norm: 0.5892
# Epoch 159: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4209, Test Linf Norm: 0.5938
# Epoch 160: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0049, Train Linf Norm: 0.4094, Test Linf Norm: 0.6080
# Epoch 161: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4133, Test Linf Norm: 0.6022
# Epoch 162: Train Loss: 0.0015, Test Loss: 0.0016, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4033, Test Linf Norm: 0.5906
# Epoch 163: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4114, Test Linf Norm: 0.5930
# Epoch 164: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3946, Test Linf Norm: 0.6002
# Epoch 165: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0036, Test L1 Norm: 0.0048, Train Linf Norm: 0.4152, Test Linf Norm: 0.6058
# Epoch 166: Train Loss: 0.0015, Test Loss: 0.0016, Train L1 Norm: 0.0036, Test L1 Norm: 0.0049, Train Linf Norm: 0.4300, Test Linf Norm: 0.6163
# Epoch 167: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4080, Test Linf Norm: 0.6001
# Epoch 168: Train Loss: 0.0015, Test Loss: 0.0016, Train L1 Norm: 0.0036, Test L1 Norm: 0.0049, Train Linf Norm: 0.4224, Test Linf Norm: 0.6217
# Epoch 169: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0049, Train Linf Norm: 0.4083, Test Linf Norm: 0.6114
# Epoch 170: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4005, Test Linf Norm: 0.6036
# Epoch 171: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3995, Test Linf Norm: 0.6071
# Epoch 172: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4121, Test Linf Norm: 0.5993
# Epoch 173: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3806, Test Linf Norm: 0.6061
# Epoch 174: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3899, Test Linf Norm: 0.6053
# Epoch 175: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4020, Test Linf Norm: 0.6032
# Epoch 176: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4036, Test Linf Norm: 0.6056
# Epoch 177: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4029, Test Linf Norm: 0.5998
# Epoch 178: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4019, Test Linf Norm: 0.6009
# Epoch 179: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3996, Test Linf Norm: 0.5978
# Epoch 180: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4044, Test Linf Norm: 0.6008
# Epoch 181: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4078, Test Linf Norm: 0.5999
# Epoch 182: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4093, Test Linf Norm: 0.6021
# Epoch 183: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4029, Test Linf Norm: 0.6017
# Epoch 184: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3891, Test Linf Norm: 0.6017
# Epoch 185: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4088, Test Linf Norm: 0.6022
# Epoch 186: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3983, Test Linf Norm: 0.6024
# Epoch 187: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4065, Test Linf Norm: 0.6028
# Epoch 188: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3998, Test Linf Norm: 0.6030
# Epoch 189: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3915, Test Linf Norm: 0.6029
# Epoch 190: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4044, Test Linf Norm: 0.6028
# Epoch 191: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4046, Test Linf Norm: 0.6024
# Epoch 192: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4037, Test Linf Norm: 0.6025
# Epoch 193: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3959, Test Linf Norm: 0.6024
# Epoch 194: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4121, Test Linf Norm: 0.6030
# Epoch 195: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4073, Test Linf Norm: 0.6026
# Epoch 196: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4030, Test Linf Norm: 0.6023
# Epoch 197: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4089, Test Linf Norm: 0.6030
# Epoch 198: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4033, Test Linf Norm: 0.6027
# Epoch 199: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4029, Test Linf Norm: 0.6024
# Epoch 200: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4057, Test Linf Norm: 0.6024
# Epoch 201: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3983, Test Linf Norm: 0.6023
# Epoch 202: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3975, Test Linf Norm: 0.6024
# Epoch 203: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4087, Test Linf Norm: 0.6023
# Epoch 204: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4000, Test Linf Norm: 0.6023
# Epoch 205: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4061, Test Linf Norm: 0.6021
# Epoch 206: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4123, Test Linf Norm: 0.6019
# Epoch 207: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3997, Test Linf Norm: 0.6021
# Epoch 208: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3905, Test Linf Norm: 0.6024
# Epoch 209: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3978, Test Linf Norm: 0.6020
# Epoch 210: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4104, Test Linf Norm: 0.6021
# Epoch 211: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3949, Test Linf Norm: 0.6021
# Epoch 212: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3987, Test Linf Norm: 0.6025
# Epoch 213: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4033, Test Linf Norm: 0.6023
# Epoch 214: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3949, Test Linf Norm: 0.6023
# Epoch 215: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3965, Test Linf Norm: 0.6017
# Epoch 216: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3944, Test Linf Norm: 0.6023
# Epoch 217: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3895, Test Linf Norm: 0.6023
# Epoch 218: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4061, Test Linf Norm: 0.6022
# Epoch 219: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4068, Test Linf Norm: 0.6020
# Epoch 220: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4083, Test Linf Norm: 0.6020
# Epoch 221: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3968, Test Linf Norm: 0.6028
# Epoch 222: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4031, Test Linf Norm: 0.6030
# Epoch 223: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4095, Test Linf Norm: 0.6021
# Epoch 224: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3927, Test Linf Norm: 0.6016
# Epoch 225: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3931, Test Linf Norm: 0.6018
# Epoch 226: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4022, Test Linf Norm: 0.6020
# Epoch 227: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4047, Test Linf Norm: 0.6023
# Epoch 228: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3999, Test Linf Norm: 0.6018
# Epoch 229: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3890, Test Linf Norm: 0.6022
# Epoch 230: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4035, Test Linf Norm: 0.6017
# Epoch 231: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3851, Test Linf Norm: 0.6015
# Epoch 232: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4042, Test Linf Norm: 0.6018
# Epoch 233: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4067, Test Linf Norm: 0.6012
# Epoch 234: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3959, Test Linf Norm: 0.6018
# Epoch 235: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4136, Test Linf Norm: 0.6016
# Epoch 236: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4044, Test Linf Norm: 0.6019
# Epoch 237: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4013, Test Linf Norm: 0.6018
# Epoch 238: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4075, Test Linf Norm: 0.6015
# Epoch 239: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3989, Test Linf Norm: 0.6015
# Epoch 240: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4127, Test Linf Norm: 0.6018
# Epoch 241: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4079, Test Linf Norm: 0.6011
# Epoch 242: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4115, Test Linf Norm: 0.6015
# Epoch 243: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3848, Test Linf Norm: 0.6019
# Epoch 244: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6011
# Epoch 245: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3946, Test Linf Norm: 0.6015
# Epoch 246: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4142, Test Linf Norm: 0.6017
# Epoch 247: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4105, Test Linf Norm: 0.6016
# Epoch 248: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4038, Test Linf Norm: 0.6016
# Epoch 249: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4087, Test Linf Norm: 0.6010
# Epoch 250: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4040, Test Linf Norm: 0.6015
# Epoch 251: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3999, Test Linf Norm: 0.6016
# Epoch 252: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4057, Test Linf Norm: 0.6018
# Epoch 253: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3961, Test Linf Norm: 0.6016
# Epoch 254: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4058, Test Linf Norm: 0.6018
# Epoch 255: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4031, Test Linf Norm: 0.6018
# Epoch 256: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3985, Test Linf Norm: 0.6013
# Epoch 257: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3887, Test Linf Norm: 0.6013
# Epoch 258: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4094, Test Linf Norm: 0.6014
# Epoch 259: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4062, Test Linf Norm: 0.6013
# Epoch 260: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4060, Test Linf Norm: 0.6014
# Epoch 261: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4050, Test Linf Norm: 0.6012
# Epoch 262: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3985, Test Linf Norm: 0.6017
# Epoch 263: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4012, Test Linf Norm: 0.6015
# Epoch 264: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4078, Test Linf Norm: 0.6010
# Epoch 265: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4014, Test Linf Norm: 0.6013
# Epoch 266: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4067, Test Linf Norm: 0.6012
# Epoch 267: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4013, Test Linf Norm: 0.6012
# Epoch 268: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4071, Test Linf Norm: 0.6011
# Epoch 269: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3955, Test Linf Norm: 0.6015
# Epoch 270: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3958, Test Linf Norm: 0.6017
# Epoch 271: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4032, Test Linf Norm: 0.6011
# Epoch 272: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4081, Test Linf Norm: 0.6009
# Epoch 273: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4049, Test Linf Norm: 0.6011
# Epoch 274: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4047, Test Linf Norm: 0.6013
# Epoch 275: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4093, Test Linf Norm: 0.6019
# Epoch 276: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4067, Test Linf Norm: 0.6017
# Epoch 277: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4022, Test Linf Norm: 0.6016
# Epoch 278: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4060, Test Linf Norm: 0.6015
# Epoch 279: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3991, Test Linf Norm: 0.6012
# Epoch 280: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4048, Test Linf Norm: 0.6017
# Epoch 281: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3962, Test Linf Norm: 0.6019
# Epoch 282: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6017
# Epoch 283: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4067, Test Linf Norm: 0.6012
# Epoch 284: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3943, Test Linf Norm: 0.6010
# Epoch 285: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3983, Test Linf Norm: 0.6008
# Epoch 286: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4051, Test Linf Norm: 0.6013
# Epoch 287: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4003, Test Linf Norm: 0.6013
# Epoch 288: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3980, Test Linf Norm: 0.6009
# Epoch 289: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3972, Test Linf Norm: 0.6010
# Epoch 290: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6010
# Epoch 291: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4074, Test Linf Norm: 0.6014
# Epoch 292: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3906, Test Linf Norm: 0.6009
# Epoch 293: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3947, Test Linf Norm: 0.6010
# Epoch 294: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4038, Test Linf Norm: 0.6007
# Epoch 295: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4028, Test Linf Norm: 0.6009
# Epoch 296: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3969, Test Linf Norm: 0.6009
# Epoch 297: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4067, Test Linf Norm: 0.6007
# Epoch 298: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3932, Test Linf Norm: 0.6009
# Epoch 299: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4027, Test Linf Norm: 0.6013
# Epoch 300: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4082, Test Linf Norm: 0.6008
# Epoch 301: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4058, Test Linf Norm: 0.6005
# Epoch 302: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4044, Test Linf Norm: 0.6008
# Epoch 303: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4000, Test Linf Norm: 0.6007
# Epoch 304: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3903, Test Linf Norm: 0.6007
# Epoch 305: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4030, Test Linf Norm: 0.6007
# Epoch 306: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4071, Test Linf Norm: 0.6010
# Epoch 307: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3947, Test Linf Norm: 0.6011
# Epoch 308: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3981, Test Linf Norm: 0.6008
# Epoch 309: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4133, Test Linf Norm: 0.6006
# Epoch 310: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4018, Test Linf Norm: 0.6013
# Epoch 311: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4029, Test Linf Norm: 0.6008
# Epoch 312: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3997, Test Linf Norm: 0.6009
# Epoch 313: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4106, Test Linf Norm: 0.6003
# Epoch 314: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3887, Test Linf Norm: 0.6007
# Epoch 315: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3975, Test Linf Norm: 0.6010
# Epoch 316: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3874, Test Linf Norm: 0.6005
# Epoch 317: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4024, Test Linf Norm: 0.6006
# Epoch 318: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4046, Test Linf Norm: 0.6007
# Epoch 319: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3991, Test Linf Norm: 0.6006
# Epoch 320: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4063, Test Linf Norm: 0.6002
# Epoch 321: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3972, Test Linf Norm: 0.6009
# Epoch 322: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4020, Test Linf Norm: 0.6008
# Epoch 323: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4032, Test Linf Norm: 0.6005
# Epoch 324: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4065, Test Linf Norm: 0.6006
# Epoch 325: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3920, Test Linf Norm: 0.5999
# Epoch 326: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6001
# Epoch 327: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3908, Test Linf Norm: 0.6000
# Epoch 328: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3960, Test Linf Norm: 0.6004
# Epoch 329: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4014, Test Linf Norm: 0.6006
# Epoch 330: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4134, Test Linf Norm: 0.6008
# Epoch 331: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4070, Test Linf Norm: 0.6008
# Epoch 332: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4057, Test Linf Norm: 0.6007
# Epoch 333: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4038, Test Linf Norm: 0.6001
# Epoch 334: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3958, Test Linf Norm: 0.6004
# Epoch 335: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3883, Test Linf Norm: 0.6006
# Epoch 336: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4055, Test Linf Norm: 0.6007
# Epoch 337: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4069, Test Linf Norm: 0.6003
# Epoch 338: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3920, Test Linf Norm: 0.6010
# Epoch 339: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4052, Test Linf Norm: 0.6003
# Epoch 340: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3989, Test Linf Norm: 0.6005
# Epoch 341: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3939, Test Linf Norm: 0.6003
# Epoch 342: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4049, Test Linf Norm: 0.6006
# Epoch 343: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4094, Test Linf Norm: 0.6005
# Epoch 344: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3884, Test Linf Norm: 0.6003
# Epoch 345: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3913, Test Linf Norm: 0.6007
# Epoch 346: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4057, Test Linf Norm: 0.6003
# Epoch 347: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6007
# Epoch 348: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4124, Test Linf Norm: 0.6007
# Epoch 349: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4084, Test Linf Norm: 0.6003
# Epoch 350: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6006
# Epoch 351: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4008, Test Linf Norm: 0.6006
# Epoch 352: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4072, Test Linf Norm: 0.5997
# Epoch 353: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3943, Test Linf Norm: 0.6004
# Epoch 354: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4005, Test Linf Norm: 0.6004
# Epoch 355: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3983, Test Linf Norm: 0.6001
# Epoch 356: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4077, Test Linf Norm: 0.6005
# Epoch 357: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4092, Test Linf Norm: 0.6003
# Epoch 358: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3884, Test Linf Norm: 0.6009
# Epoch 359: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3949, Test Linf Norm: 0.6007
# Epoch 360: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3904, Test Linf Norm: 0.6010
# Epoch 361: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4092, Test Linf Norm: 0.6005
# Epoch 362: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4028, Test Linf Norm: 0.6008
# Epoch 363: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3895, Test Linf Norm: 0.6005
# Epoch 364: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4045, Test Linf Norm: 0.6003
# Epoch 365: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4093, Test Linf Norm: 0.6007
# Epoch 366: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3975, Test Linf Norm: 0.6010
# Epoch 367: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4084, Test Linf Norm: 0.6006
# Epoch 368: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3974, Test Linf Norm: 0.6012
# Epoch 369: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3877, Test Linf Norm: 0.6009
# Epoch 370: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4143, Test Linf Norm: 0.6005
# Epoch 371: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4079, Test Linf Norm: 0.6001
# Epoch 372: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4076, Test Linf Norm: 0.6006
# Epoch 373: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4071, Test Linf Norm: 0.6012
# Epoch 374: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4030, Test Linf Norm: 0.6005
# Epoch 375: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4072, Test Linf Norm: 0.6006
# Epoch 376: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4080, Test Linf Norm: 0.6011
# Epoch 377: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3951, Test Linf Norm: 0.6002
# Epoch 378: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4065, Test Linf Norm: 0.6005
# Epoch 379: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4044, Test Linf Norm: 0.6004
# Epoch 380: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4105, Test Linf Norm: 0.6007
# Epoch 381: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4055, Test Linf Norm: 0.6005
# Epoch 382: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4023, Test Linf Norm: 0.6002
# Epoch 383: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3800, Test Linf Norm: 0.6005
# Epoch 384: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4060, Test Linf Norm: 0.6003
# Epoch 385: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4066, Test Linf Norm: 0.6006
# Epoch 386: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3958, Test Linf Norm: 0.6004
# Epoch 387: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4079, Test Linf Norm: 0.6011
# Epoch 388: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4028, Test Linf Norm: 0.6003
# Epoch 389: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4041, Test Linf Norm: 0.6002
# Epoch 390: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4042, Test Linf Norm: 0.6003
# Epoch 391: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3841, Test Linf Norm: 0.6005
# Epoch 392: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4100, Test Linf Norm: 0.6006
# Epoch 393: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4102, Test Linf Norm: 0.6009
# Epoch 394: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4086, Test Linf Norm: 0.6003
# Epoch 395: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4069, Test Linf Norm: 0.6005
# Epoch 396: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4046, Test Linf Norm: 0.6004
# Epoch 397: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4034, Test Linf Norm: 0.6003
# Epoch 398: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.3982, Test Linf Norm: 0.6002
# Epoch 399: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4027, Test Linf Norm: 0.6007
# Epoch 400: Train Loss: 0.0015, Test Loss: 0.0015, Train L1 Norm: 0.0035, Test L1 Norm: 0.0048, Train Linf Norm: 0.4058, Test Linf Norm: 0.6006

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration/0043" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
optimizer_loaded_state_dict = torch.load("optimizer.pth")
if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
scheduler_loaded_state_dict = torch.load("scheduler.pth")
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded
# Out:
# 223
# 400
# 'MAE'
# 'Adam'
# 'ReduceLROnPlateau'
# [86, 201, 87]
# 3
# 'ReLU'
# 'Identity'
# 0.0007324856218845869
# ReLU()
# Identity()
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=86, bias=True)
#     (1): Linear(in_features=86, out_features=201, bias=True)
#     (2): Linear(in_features=201, out_features=87, bias=True)
#     (3): Linear(in_features=87, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation', ReLU()),
#               ('output_activation', Identity()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=3, out_features=86, bias=True)
#                  (1): Linear(in_features=86, out_features=201, bias=True)
#                  (2): Linear(in_features=201, out_features=87, bias=True)
#                  (3): Linear(in_features=87, out_features=1, bias=True)
#                ))]),
#  'n_layers': 3,
#  'n_units': [86, 201, 87]}
# L1Loss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 7.324856218845872e-09
#     maximize: False
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.0007324856218845869,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0,
#   'amsgrad': False,
#   'maximize': False,
#   'foreach': None,
#   'capturable': False,
#   'differentiable': False,
#   'fused': None},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#Adam.zero_grad',
#  'state': defaultdict(dict,
#              {Parameter containing:
#               tensor([[ 3.2871e-01,  2.6898e-01,  5.7468e-02],
#                       [ 2.5778e-01,  8.8501e-02,  2.4048e-01],
#                       [ 2.5637e-01,  1.3040e-01,  5.3219e-01],
#                       [-3.0651e-01,  7.9911e-02, -6.4790e-01],
#                       [ 5.2635e-01,  4.1950e-01, -2.5271e-01],
#                       [ 1.1814e-01,  2.1640e-01, -8.5747e-02],
#                       [ 2.6105e-01, -2.1145e-01,  5.1708e-01],
#                       [-3.9715e-01,  2.6906e-01, -3.2654e-02],
#                       [ 3.1769e-01, -6.8356e-01, -3.0824e-01],
#                       [ 4.4977e-01, -2.9523e-01, -2.6803e-01],
#                       [-4.1099e-01,  5.1398e-01, -1.5696e-01],
#                       [ 8.4840e-02, -5.5002e-01,  6.0617e-02],
#                       [ 1.8896e-01,  4.7925e-01, -1.1237e-01],
#                       [-5.2464e-01, -5.4133e-01,  2.4577e-01],
#                       [-1.2535e-02,  3.3904e-01,  4.3744e-01],
#                       [ 3.6593e-01, -2.0036e-01, -4.5450e-01],
#                       [-3.0429e-01,  1.6153e-01,  5.6210e-02],
#                       [-4.4021e-03, -2.1958e-01,  2.7260e-01],
#                       [ 1.5623e-01,  3.6463e-01,  3.7926e-01],
#                       [ 1.0592e-01, -4.0440e-01,  5.7294e-01],
#                       [-2.4927e-01,  5.3309e-01,  1.5319e-01],
#                       [-3.3921e-01,  4.9197e-01,  3.6111e-01],
#                       [-4.4925e-02, -1.9818e-02, -2.7950e-01],
#                       [ 3.5500e-01,  5.5291e-01, -1.6360e-01],
#                       [-4.8770e-01, -2.6103e-01,  5.8190e-01],
#                       [-3.9900e-01, -3.2412e-01,  5.0834e-01],
#                       [-4.6377e-01, -5.3170e-01,  5.7401e-02],
#                       [-1.4497e-02, -5.3492e-01, -5.4522e-01],
#                       [ 4.6929e-01, -4.4872e-01, -4.1446e-01],
#                       [-8.1824e-02,  8.1445e-02,  3.6286e-01],
#                       [-1.1411e-01,  2.6083e-01,  7.0875e-02],
#                       [ 2.4323e-01, -4.8877e-01,  5.1622e-01],
#                       [-5.4809e-01,  2.7598e-01,  1.2297e-01],
#                       [ 4.2695e-02, -5.4644e-01, -1.5226e-01],
#                       [-1.5729e-01, -5.6521e-01,  3.9754e-01],
#                       [-3.1936e-01, -2.9530e-01, -2.4608e-01],
#                       [ 4.9724e-02, -4.8120e-01,  5.8377e-01],
#                       [-3.7218e-01,  1.9860e-01,  4.8038e-01],
#                       [ 1.2279e-01,  7.2694e-03, -4.0758e-01],
#                       [-3.6026e-01,  9.1022e-03, -1.3550e-01],
#                       [ 7.7872e-07,  5.6584e-01, -4.6152e-01],
#                       [-3.9895e-01, -6.7139e-02, -4.8775e-01],
#                       [ 2.8171e-01, -4.6808e-02, -3.5956e-02],
#                       [ 8.4000e-02, -3.1155e-01,  4.1534e-01],
#                       [-1.9195e-01,  4.8585e-01, -5.0702e-02],
#                       [ 3.4703e-01, -6.5787e-02,  1.3387e-01],
#                       [ 2.5140e-01, -3.5971e-01, -9.2266e-02],
#                       [-3.9539e-01,  2.6799e-01, -5.8117e-02],
#                       [ 4.0500e-01,  2.6658e-01,  3.2638e-01],
#                       [ 4.5794e-01,  1.9248e-01,  5.4904e-01],
#                       [ 3.5493e-02, -5.5742e-02,  5.2931e-01],
#                       [ 2.0006e-01, -4.0809e-01,  5.4375e-01],
#                       [-1.8784e-01,  1.2742e-01, -5.5037e-01],
#                       [-3.7811e-01, -4.4661e-01, -3.7102e-01],
#                       [ 8.5449e-02,  1.8750e-01, -1.7184e-01],
#                       [-2.9145e-01, -4.7472e-01, -2.9594e-01],
#                       [ 5.3985e-01, -5.7166e-02,  2.2915e-01],
#                       [-2.0408e-01, -3.2365e-01,  1.2394e-01],
#                       [ 4.0671e-01,  2.7815e-01, -4.5224e-01],
#                       [-1.7122e-01, -1.2344e-01,  2.7737e-01],
#                       [-3.0876e-01, -6.7135e-01, -2.5156e-02],
#                       [ 5.5943e-02, -2.9807e-02,  2.4742e-01],
#                       [ 1.5911e-01, -5.3110e-01,  2.6574e-01],
#                       [-1.1771e-02,  9.1098e-02, -1.8666e-01],
#                       [ 1.0149e-01, -1.0748e-01, -4.6810e-01],
#                       [ 2.3736e-01, -3.2327e-01, -1.4917e-02],
#                       [ 2.1822e-01,  2.7498e-01, -2.1260e-01],
#                       [ 8.8678e-02,  2.3149e-01,  3.0235e-01],
#                       [ 5.0060e-01, -1.6139e-01, -2.1722e-01],
#                       [-4.2235e-01, -1.7428e-01,  2.1604e-01],
#                       [ 1.0512e-01, -3.0967e-01, -4.4836e-01],
#                       [ 4.1386e-01, -1.0671e-01,  2.3909e-01],
#                       [-3.4282e-01, -2.5743e-01,  1.4845e-01],
#                       [ 3.6988e-01,  8.0510e-02,  2.5896e-01],
#                       [ 2.7613e-01, -5.0307e-01,  6.9001e-03],
#                       [ 3.0913e-01, -2.7830e-02, -5.8690e-01],
#                       [ 1.4536e-01, -5.0987e-01, -2.7912e-01],
#                       [-3.6681e-02, -2.0823e-01,  2.4248e-01],
#                       [-2.9568e-01,  4.3802e-02,  5.2083e-01],
#                       [-1.4245e-01,  2.1458e-01, -8.0099e-02],
#                       [-3.1543e-02,  3.6534e-01, -1.6282e-01],
#                       [-4.6629e-01,  1.2862e-01,  5.3923e-02],
#                       [-5.5387e-01,  2.0793e-02,  1.8427e-01],
#                       [-1.5975e-02,  4.5797e-01,  7.5040e-02],
#                       [-4.3012e-03,  2.6723e-01,  4.1088e-01],
#                       [ 3.8252e-01,  2.5043e-01, -4.8714e-01]], device='cuda:0',
#                      requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([[-8.8860e-04, -5.9484e-04, -1.0191e-03],
#                        [-1.4397e-04, -4.2181e-04,  1.5133e-04],
#                        [ 1.3709e-04, -7.6578e-04, -8.1119e-04],
#                        [ 8.2424e-05,  1.1117e-04,  4.2240e-05],
#                        [ 1.4658e-03,  6.5463e-04,  1.3258e-03],
#                        [-2.1933e-04, -5.8799e-05,  2.7162e-04],
#                        [-1.8600e-03, -3.7429e-04, -1.3880e-03],
#                        [ 4.1520e-03,  1.2773e-02,  1.4650e-02],
#                        [ 1.4130e-03,  2.8855e-04,  4.1837e-04],
#                        [ 5.6074e-04,  5.3789e-05,  1.2798e-04],
#                        [-4.9773e-03, -9.7453e-04,  1.5164e-03],
#                        [-1.3792e-04, -2.7849e-04, -2.6422e-03],
#                        [ 8.7449e-04,  6.8453e-04,  1.0319e-03],
#                        [ 4.3191e-04,  7.9030e-05,  6.7556e-04],
#                        [-2.0625e-03, -1.2646e-03, -1.4611e-03],
#                        [ 3.2183e-03,  9.9740e-04,  9.9698e-04],
#                        [-2.1967e-03, -7.4043e-04, -2.4264e-04],
#                        [-3.4786e-03, -8.8353e-03, -8.2798e-03],
#                        [-1.3907e-03,  1.8052e-04, -6.0247e-04],
#                        [ 4.9038e-03,  2.9516e-03, -1.2406e-03],
#                        [-1.0361e-03, -3.0641e-04,  3.9975e-04],
#                        [-7.8580e-04, -1.1362e-04,  1.0919e-04],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 8.8940e-04,  5.1974e-04,  1.2794e-03],
#                        [-1.8851e-03, -6.1537e-03, -6.7903e-03],
#                        [-2.0103e-03, -8.8070e-03, -8.0650e-03],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 2.5599e-03,  4.6214e-04,  1.0639e-03],
#                        [-2.9285e-04, -5.4313e-04, -8.3811e-04],
#                        [-3.5390e-04, -2.7872e-04, -9.5709e-05],
#                        [ 1.4670e-03,  1.7594e-03, -2.3007e-03],
#                        [ 1.4682e-03,  5.4008e-03,  5.9717e-03],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [-8.6809e-04,  1.4789e-04, -7.8992e-04],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [-4.8649e-03, -9.6569e-03, -9.3353e-03],
#                        [ 2.4521e-03, -3.0399e-04, -6.4746e-04],
#                        [ 1.2421e-03,  3.5538e-05,  9.5849e-05],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [-2.1557e-03, -8.0885e-04,  1.1622e-03],
#                        [ 1.8932e-05,  2.0633e-05,  1.0537e-05],
#                        [ 5.7707e-04,  1.2461e-03,  5.4420e-04],
#                        [-9.1211e-04, -3.1997e-03, -4.8563e-03],
#                        [ 7.1496e-04,  1.1769e-03,  3.0482e-03],
#                        [-7.3843e-04, -4.2185e-04, -1.4451e-03],
#                        [-2.0697e-04, -4.1613e-04, -3.0535e-03],
#                        [ 2.8545e-03,  8.7645e-03,  7.8502e-03],
#                        [-7.0603e-04, -6.2082e-04, -5.5171e-04],
#                        [ 6.7133e-05,  5.0517e-04,  3.3553e-05],
#                        [-1.7153e-03, -2.2198e-03, -2.7569e-03],
#                        [-1.7346e-03, -6.1889e-04, -2.8273e-03],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 4.3988e-03,  3.6048e-03,  7.5656e-03],
#                        [-1.1922e-07, -4.3862e-07, -2.1215e-06],
#                        [-4.0325e-04,  8.8234e-04,  1.5412e-04],
#                        [ 5.6052e-45,  5.6052e-45,  5.6052e-45],
#                        [-3.4998e-04, -3.5744e-03, -2.6883e-03],
#                        [-4.8833e-03, -1.0063e-02, -1.0100e-02],
#                        [-4.7510e-05, -1.3213e-05, -6.2669e-05],
#                        [ 6.4114e-04, -4.8961e-04, -1.2712e-03],
#                        [ 2.6353e-03,  1.5342e-03,  1.1613e-03],
#                        [ 1.5921e-03,  6.0994e-04, -4.0102e-05],
#                        [ 5.1075e-04,  4.0541e-04,  4.4488e-05],
#                        [ 2.9957e-03,  1.0731e-03, -7.9807e-04],
#                        [ 1.1275e-03,  8.6675e-04,  1.3511e-03],
#                        [-6.8764e-04,  2.0716e-04,  1.0642e-04],
#                        [ 1.7850e-03,  2.7182e-03,  2.2164e-03],
#                        [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#                        [ 8.1368e-04, -3.5781e-06,  1.0048e-04],
#                        [-9.6422e-04, -2.7924e-04, -1.2427e-03],
#                        [-2.9285e-05, -1.3814e-04,  8.8959e-05],
#                        [-1.8247e-03, -1.6082e-03, -2.0028e-03],
#                        [ 3.1553e-03,  1.1572e-03, -1.4445e-04],
#                        [ 4.9115e-03,  2.4300e-03,  1.3638e-03],
#                        [ 4.9782e-04,  1.1854e-04, -1.4590e-04],
#                        [-2.0199e-03, -7.2624e-03, -7.1456e-03],
#                        [ 2.7294e-03,  7.3720e-04, -3.5185e-05],
#                        [-1.3337e-03, -8.8418e-04, -6.1180e-04],
#                        [-4.1464e-03, -1.4437e-03, -2.9337e-04],
#                        [ 2.6893e-04,  2.2576e-03,  2.5801e-03],
#                        [ 1.5057e-03,  5.1521e-03,  5.0881e-03],
#                        [-1.0307e-03, -9.5663e-04, -2.7088e-04],
#                        [-5.6471e-04,  1.0304e-04, -4.2349e-05],
#                        [-7.0470e-04, -3.6059e-03, -2.8629e-03]], device='cuda:0'),
#                'exp_avg_sq': tensor([[1.7494e-04, 6.4487e-04, 6.4910e-04],
#                        [1.4534e-04, 5.2168e-04, 5.1762e-04],
#                        [2.0377e-04, 7.5368e-04, 8.0001e-04],
#                        [1.7063e-07, 1.2356e-07, 9.3799e-08],
#                        [4.7399e-04, 1.2125e-03, 1.4203e-03],
#                        [1.3169e-05, 4.2877e-05, 3.7899e-05],
#                        [1.5403e-03, 4.6702e-03, 4.7209e-03],
#                        [1.1960e-03, 9.4010e-03, 8.6632e-03],
#                        [1.0591e-05, 2.4856e-07, 1.4685e-06],
#                        [1.2211e-05, 2.5206e-06, 3.9106e-06],
#                        [1.3138e-03, 7.4118e-03, 6.6996e-03],
#                        [1.0342e-04, 2.7942e-06, 1.3056e-04],
#                        [1.0470e-04, 4.0829e-04, 3.9135e-04],
#                        [1.8211e-06, 2.2451e-07, 6.0216e-06],
#                        [1.1732e-04, 9.4748e-05, 1.9372e-04],
#                        [9.7667e-05, 1.7020e-05, 1.3358e-05],
#                        [1.4900e-04, 9.7094e-04, 9.0967e-04],
#                        [1.0615e-03, 5.9819e-03, 5.8770e-03],
#                        [1.7613e-04, 2.1792e-04, 2.8813e-04],
#                        [3.5678e-03, 1.3124e-02, 1.3547e-02],
#                        [2.7630e-04, 1.1073e-03, 9.8045e-04],
#                        [3.5331e-05, 2.3884e-04, 2.1443e-04],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [5.0032e-04, 1.5018e-03, 1.6255e-03],
#                        [3.2059e-04, 1.7172e-03, 1.9515e-03],
#                        [2.9424e-04, 1.9635e-03, 2.1171e-03],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [1.6442e-05, 6.9239e-07, 2.7593e-06],
#                        [4.8515e-04, 1.5354e-03, 1.6910e-03],
#                        [1.6271e-05, 3.4919e-05, 3.7772e-05],
#                        [4.4331e-03, 1.7329e-02, 1.6531e-02],
#                        [3.7588e-04, 2.5024e-03, 2.3528e-03],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [5.8956e-05, 6.3111e-06, 1.3687e-04],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [3.3244e-03, 1.4237e-02, 1.4576e-02],
#                        [8.8818e-04, 2.5599e-03, 3.0338e-03],
#                        [6.1307e-05, 6.9638e-06, 1.2788e-06],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [2.1119e-03, 1.0707e-02, 9.4885e-03],
#                        [9.6342e-09, 5.7818e-09, 6.9580e-09],
#                        [2.6724e-05, 5.9035e-05, 4.2157e-05],
#                        [1.9303e-03, 8.6032e-03, 8.7091e-03],
#                        [3.5121e-04, 1.2336e-03, 1.2144e-03],
#                        [5.4118e-04, 2.1398e-03, 2.0616e-03],
#                        [9.6885e-05, 1.1818e-05, 8.1486e-05],
#                        [6.5699e-04, 6.2113e-03, 5.5961e-03],
#                        [4.7204e-05, 1.2488e-04, 1.4929e-04],
#                        [3.9055e-04, 1.2253e-03, 1.2588e-03],
#                        [4.6118e-04, 1.6223e-03, 1.7746e-03],
#                        [3.7820e-03, 1.3001e-02, 1.2985e-02],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [1.6747e-03, 6.4862e-03, 6.1646e-03],
#                        [6.0889e-10, 3.9320e-11, 4.0198e-10],
#                        [3.5564e-04, 1.3797e-03, 1.2387e-03],
#                        [7.0065e-43, 7.0065e-43, 7.0065e-43],
#                        [1.2268e-04, 2.0907e-04, 1.5416e-04],
#                        [5.2843e-04, 2.3542e-03, 2.6075e-03],
#                        [1.4181e-08, 1.5719e-09, 1.9972e-08],
#                        [8.7737e-04, 2.9178e-03, 3.1052e-03],
#                        [2.5366e-04, 5.9843e-05, 4.3884e-04],
#                        [6.6945e-05, 6.2473e-05, 2.4396e-05],
#                        [4.0082e-06, 7.4843e-07, 2.2326e-07],
#                        [4.3655e-04, 7.1547e-05, 5.8207e-04],
#                        [3.0104e-04, 1.1054e-03, 1.0923e-03],
#                        [4.4910e-05, 2.2607e-05, 5.9468e-05],
#                        [8.1703e-05, 9.6797e-05, 8.3210e-05],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00],
#                        [2.5060e-05, 4.3151e-07, 3.0533e-07],
#                        [5.4383e-04, 1.9354e-03, 1.9270e-03],
#                        [2.0926e-07, 7.5862e-08, 4.1835e-07],
#                        [5.4934e-04, 1.3565e-03, 1.5702e-03],
#                        [3.0821e-04, 2.3347e-05, 3.9392e-04],
#                        [1.4719e-04, 4.7318e-05, 1.6510e-05],
#                        [7.7352e-06, 1.7062e-07, 6.9435e-07],
#                        [4.4928e-04, 3.4879e-03, 3.3589e-03],
#                        [4.7904e-04, 1.4787e-03, 1.7317e-03],
#                        [1.4649e-04, 5.4610e-04, 5.0348e-04],
#                        [7.9312e-04, 3.9813e-03, 3.6585e-03],
#                        [1.8983e-04, 1.9920e-03, 1.8274e-03],
#                        [1.3556e-04, 1.6714e-03, 1.5313e-03],
#                        [1.5455e-04, 6.3438e-04, 5.6302e-04],
#                        [1.0438e-03, 2.4539e-03, 2.8792e-03],
#                        [1.5641e-04, 2.1996e-04, 1.2803e-04]], device='cuda:0')},
#               Parameter containing:
#               tensor([-0.5549,  0.2452, -0.3872,  0.4292, -0.3885, -0.3058, -0.2567, -0.1654,
#                       -0.2002, -0.2534,  0.5046,  0.2089,  0.3455,  0.4646, -0.1994, -0.2333,
#                        0.3698,  0.0242, -0.4556, -0.0540,  0.0688,  0.1146, -0.2387, -0.4058,
#                       -0.1903,  0.2314, -0.0865, -0.1604, -0.5121,  0.2907,  0.2931, -0.0076,
#                       -0.2417, -0.4053, -0.4360, -0.4643,  0.2409,  0.1942, -0.2581, -0.3488,
#                        0.0896,  0.1908, -0.6561, -0.3972,  0.3677, -0.4977,  0.4286, -0.3894,
#                       -0.4120, -0.5496, -0.3718,  0.5063, -0.4250, -0.2714, -0.0464,  0.1012,
#                        0.1782, -0.4319, -0.4426, -0.1678,  0.2534, -0.4319, -0.1718,  0.4408,
#                        0.4424,  0.3544, -0.1139, -0.4922,  0.2264, -0.2194,  0.1309,  0.0819,
#                        0.5901,  0.3242,  0.1449,  0.2318,  0.3965,  0.1507, -0.1453,  0.4624,
#                       -0.4706,  0.4079,  0.2755, -0.5699,  0.3576, -0.3817], device='cuda:0',
#                      requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([-5.9795e-05,  1.2272e-04,  2.7103e-04,  7.3525e-05, -6.9116e-05,
#                        -1.6126e-05,  4.0685e-04,  4.6404e-04,  1.8137e-04,  7.8944e-05,
#                        -8.2520e-04, -4.6969e-04,  8.9751e-05,  4.1666e-04, -7.0798e-05,
#                         3.0353e-04, -4.0449e-04,  1.8868e-04,  3.4603e-05,  1.9809e-03,
#                        -1.5159e-04, -7.4071e-05,  0.0000e+00, -1.8989e-05, -1.3858e-04,
#                         8.6964e-05,  0.0000e+00,  0.0000e+00,  3.5123e-04,  3.8396e-04,
#                         4.5568e-05,  1.0206e-03,  1.1917e-04,  0.0000e+00, -2.4981e-04,
#                         0.0000e+00,  9.1890e-04,  1.0243e-03,  1.9604e-04,  0.0000e+00,
#                         5.3564e-06, -1.9189e-05,  5.8926e-05,  4.8591e-04, -1.0151e-04,
#                         6.6246e-06, -4.1730e-04,  1.6722e-04, -1.0459e-04,  2.6251e-04,
#                         2.7993e-04,  7.6623e-04,  0.0000e+00,  0.0000e+00,  3.5612e-04,
#                        -2.7815e-05,  7.6864e-05,  5.6052e-45, -1.4149e-05, -4.1047e-04,
#                        -1.1064e-04,  7.3051e-04,  7.1359e-05,  2.2056e-04,  9.2819e-05,
#                        -2.7601e-04,  9.7152e-05, -2.9811e-05, -3.7135e-04,  0.0000e+00,
#                        -7.7999e-05,  3.1761e-04, -6.7587e-05,  2.3450e-04, -2.7761e-04,
#                         9.1687e-04, -1.4114e-04,  2.7784e-04,  1.0144e-03, -2.8497e-04,
#                        -6.3970e-04,  7.4314e-05,  6.2492e-04, -2.8282e-04,  7.9411e-04,
#                        -5.8950e-05], device='cuda:0'),
#                'exp_avg_sq': tensor([3.2773e-06, 3.4728e-06, 4.3457e-06, 1.3237e-06, 1.0725e-05, 2.2527e-07,
#                        3.2674e-05, 1.8854e-05, 2.1476e-07, 3.3879e-07, 2.6551e-05, 4.0037e-06,
#                        2.1929e-06, 1.4427e-06, 2.9707e-06, 2.1592e-06, 2.6678e-06, 2.3589e-05,
#                        4.2668e-06, 7.8037e-05, 5.7183e-06, 7.7779e-07, 0.0000e+00, 1.1312e-05,
#                        5.5855e-06, 6.7707e-06, 0.0000e+00, 0.0000e+00, 3.4296e-07, 1.0827e-05,
#                        4.3593e-07, 9.3874e-05, 6.2560e-06, 0.0000e+00, 1.3701e-06, 0.0000e+00,
#                        8.4626e-05, 2.2176e-05, 1.0870e-06, 0.0000e+00, 4.6874e-05, 5.1850e-07,
#                        3.6683e-07, 3.4486e-05, 8.9124e-06, 9.8337e-06, 3.6639e-06, 8.9242e-06,
#                        9.0240e-07, 7.6111e-06, 1.0153e-05, 8.4807e-05, 0.0000e+00, 0.0000e+00,
#                        3.5346e-05, 5.4140e-08, 8.2603e-06, 7.0065e-43, 1.9787e-06, 9.4602e-06,
#                        1.3344e-07, 1.7029e-05, 6.3791e-06, 2.8592e-06, 7.8923e-07, 1.2953e-05,
#                        6.4029e-06, 1.1004e-06, 2.5537e-06, 0.0000e+00, 2.1567e-06, 1.1716e-05,
#                        3.3906e-07, 1.3701e-05, 9.6517e-06, 5.2413e-06, 8.2503e-07, 1.2603e-05,
#                        1.0362e-05, 3.5833e-06, 1.2782e-05, 4.2914e-06, 3.2940e-06, 2.9093e-06,
#                        2.4691e-05, 2.2797e-06], device='cuda:0')},
#               Parameter containing:
#               tensor([[-0.0411,  0.0393, -0.1237,  ...,  0.0618,  0.0553, -0.0659],
#                       [ 0.0812, -0.0912,  0.0764,  ..., -0.0883, -0.0810, -0.2688],
#                       [-0.0283, -0.0206,  0.0323,  ..., -0.0615,  0.0806,  0.0894],
#                       ...,
#                       [-0.0189,  0.0344, -0.0930,  ...,  0.0716,  0.0712, -0.0378],
#                       [ 0.0858,  0.0551,  0.0899,  ...,  0.0489,  0.0097, -0.0940],
#                       [-0.0792, -0.0461,  0.0707,  ...,  0.0717, -0.0207, -0.0763]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([[-5.0307e-06, -1.3458e-05, -1.5300e-05,  ...,  5.6052e-45,
#                         -1.0620e-05, -1.4761e-07],
#                        [ 1.4539e-04,  5.4089e-05,  1.2827e-04,  ...,  2.1957e-04,
#                          1.3583e-04,  1.2077e-05],
#                        [-5.6858e-05,  5.5687e-05, -1.7255e-04,  ..., -1.5215e-04,
#                         -4.1191e-05,  9.6887e-05],
#                        ...,
#                        [ 5.6052e-45,  5.6052e-45,  5.6052e-45,  ...,  5.6052e-45,
#                          5.6052e-45,  5.6052e-45],
#                        [-4.8099e-04, -4.7485e-04, -6.3956e-04,  ..., -5.5844e-04,
#                         -7.1007e-04, -1.1051e-04],
#                        [ 5.6052e-45,  5.6052e-45,  5.6052e-45,  ...,  5.6052e-45,
#                          5.6052e-45,  5.6052e-45]], device='cuda:0'),
#                'exp_avg_sq': tensor([[6.8488e-09, 1.1409e-07, 6.8556e-08,  ..., 7.0065e-43, 8.7315e-08,
#                         1.5863e-11],
#                        [8.4867e-06, 9.7942e-06, 2.3782e-05,  ..., 9.5807e-06, 2.0805e-05,
#                         1.4241e-08],
#                        [4.2079e-05, 4.8112e-05, 1.2744e-04,  ..., 5.0593e-05, 1.0388e-04,
#                         6.8432e-07],
#                        ...,
#                        [7.0065e-43, 7.0065e-43, 7.0065e-43,  ..., 7.0065e-43, 7.0065e-43,
#                         7.0065e-43],
#                        [1.9600e-05, 2.0058e-05, 3.8348e-05,  ..., 1.3549e-05, 2.9102e-05,
#                         2.9501e-06],
#                        [7.0065e-43, 7.0065e-43, 7.0065e-43,  ..., 7.0065e-43, 7.0065e-43,
#                         7.0065e-43]], device='cuda:0')},
#               Parameter containing:
#               tensor([-0.0102,  0.0100,  0.1059,  0.0794, -0.0971, -0.0997,  0.0283, -0.0284,
#                       -0.0404, -0.0963,  0.0564, -0.0580, -0.0818, -0.0877,  0.1045,  0.0079,
#                        0.0501, -0.0042, -0.0433,  0.0288, -0.1294,  0.0415, -0.0922,  0.0417,
#                       -0.0077,  0.0007, -0.0164,  0.0771,  0.0377, -0.1064, -0.0987,  0.0771,
#                        0.0992, -0.0811,  0.0832,  0.0886, -0.0893,  0.0345,  0.0355, -0.0932,
#                        0.0777,  0.0896, -0.0207, -0.0468, -0.0495,  0.0059, -0.0873, -0.0652,
#                       -0.0448,  0.0076,  0.0534, -0.0898,  0.0963,  0.0508, -0.0581,  0.0090,
#                       -0.0731, -0.0464,  0.0580,  0.0737, -0.0328,  0.0654,  0.1240, -0.0973,
#                        0.0223, -0.0019, -0.0770, -0.0410,  0.0085, -0.0132, -0.1091,  0.0504,
#                       -0.0077,  0.0778,  0.0101,  0.0036, -0.0933, -0.0110,  0.0729, -0.0515,
#                        0.0935,  0.0432, -0.0555,  0.1043, -0.0837,  0.0494, -0.0354, -0.0115,
#                        0.0250,  0.0523, -0.0429, -0.0926,  0.0473, -0.0295, -0.0006,  0.1040,
#                       -0.1030,  0.0726, -0.0475, -0.0006,  0.1069, -0.0508,  0.0737, -0.0489,
#                        0.0557, -0.1087,  0.0027,  0.0469,  0.1028,  0.1107,  0.0097, -0.0647,
#                       -0.0761, -0.0580, -0.0922,  0.0696, -0.0420,  0.0115, -0.0994, -0.0426,
#                       -0.0355, -0.0720,  0.1162, -0.0825, -0.0402, -0.0015, -0.0030,  0.0697,
#                       -0.0095, -0.0632, -0.0981,  0.0201,  0.0330,  0.0055,  0.0125,  0.0355,
#                        0.0882,  0.0636,  0.0793, -0.0553,  0.0346, -0.0928, -0.0053,  0.0489,
#                       -0.0219,  0.0343, -0.0959,  0.0835,  0.0276, -0.0198,  0.1300,  0.0158,
#                        0.1152,  0.1349,  0.1202,  0.1139,  0.0422,  0.0060, -0.0662, -0.1575,
#                       -0.0118, -0.1028, -0.0263,  0.0668,  0.0466,  0.0658, -0.0828,  0.0684,
#                       -0.0255, -0.0888, -0.0470,  0.0876, -0.0956, -0.1188, -0.1177, -0.0340,
#                        0.0335, -0.0369,  0.0885,  0.0545,  0.0541, -0.0609, -0.0195, -0.0752,
#                       -0.0298, -0.1367, -0.0523, -0.0875,  0.0660,  0.0564, -0.0588, -0.0847,
#                        0.0532,  0.0312,  0.0713, -0.0092, -0.0593,  0.0616, -0.0010, -0.0127,
#                        0.0898], device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([-4.2430e-06, -2.9399e-05,  2.4866e-04, -1.9685e-04,  5.6052e-45,
#                         4.6274e-05,  5.6052e-45,  0.0000e+00,  0.0000e+00,  2.6690e-04,
#                         0.0000e+00,  5.6052e-45, -2.6164e-05,  5.6052e-45,  6.2734e-04,
#                         1.6613e-04,  4.3414e-04, -1.5032e-05,  6.4278e-05,  5.6052e-45,
#                         5.6052e-45,  1.1279e-04,  5.6052e-45,  5.6052e-45,  0.0000e+00,
#                        -7.7438e-05,  1.3446e-05,  3.7615e-04,  0.0000e+00, -4.3651e-05,
#                         5.6052e-45, -1.1861e-04,  1.6167e-04, -2.0153e-05,  5.6052e-45,
#                         2.8182e-04,  5.1530e-05,  5.6052e-45,  1.1934e-04, -1.4698e-04,
#                        -2.4241e-04,  9.1548e-05,  1.4254e-05,  6.8517e-04,  1.9678e-04,
#                        -3.2608e-04,  1.1302e-04,  4.2193e-04,  0.0000e+00,  5.6052e-45,
#                        -2.7344e-04,  2.2676e-04,  0.0000e+00,  3.0623e-04, -7.0871e-05,
#                         0.0000e+00,  0.0000e+00,  5.6052e-45,  5.6052e-45,  9.4223e-05,
#                         5.6052e-45,  5.6052e-45,  3.2315e-04,  5.6052e-45,  5.6052e-45,
#                        -2.8678e-04,  1.1338e-04, -1.8910e-04,  5.6052e-45,  2.9462e-05,
#                        -3.5268e-06,  6.8920e-05,  5.6052e-45,  5.6052e-45,  6.7896e-04,
#                         4.2371e-04, -5.3597e-05,  0.0000e+00,  8.0671e-04,  3.5037e-05,
#                         2.6895e-04,  5.6052e-45,  0.0000e+00,  3.7195e-04,  2.4808e-05,
#                         1.6154e-04, -2.5555e-04, -1.1263e-04,  1.5167e-05,  5.6052e-45,
#                         5.6052e-45,  0.0000e+00, -1.7070e-04,  5.8188e-05, -5.8554e-05,
#                         1.3510e-05,  9.5017e-07,  5.6052e-45,  5.6052e-45,  5.6052e-45,
#                         2.2095e-04,  1.3947e-04,  5.6052e-45,  5.6052e-45,  5.6052e-45,
#                         5.6052e-45,  0.0000e+00,  5.6052e-45,  4.8079e-04, -1.8674e-04,
#                         2.1137e-04, -1.0725e-04,  0.0000e+00,  5.6052e-45,  5.6052e-45,
#                         3.9117e-04,  0.0000e+00,  1.8594e-04,  3.6629e-04,  1.7482e-04,
#                        -1.2864e-04, -1.3606e-04,  2.1579e-04,  0.0000e+00,  3.2511e-04,
#                         0.0000e+00,  1.0202e-04,  1.2774e-04, -5.3442e-05, -2.6710e-04,
#                         1.8798e-04,  6.5482e-05,  2.0876e-05,  5.6052e-45,  3.1099e-04,
#                         1.1882e-04, -8.1503e-05,  1.9489e-04,  2.9564e-04,  8.5156e-04,
#                         5.6052e-45,  9.0493e-05,  3.2648e-04,  4.6469e-04, -1.6071e-04,
#                         2.5022e-04,  5.6052e-45,  1.4247e-04,  2.5131e-04,  0.0000e+00,
#                         3.7896e-04,  7.8430e-05, -1.7563e-04,  1.0923e-04,  4.8899e-04,
#                         4.5074e-04,  4.3409e-04, -2.4579e-04,  0.0000e+00, -6.5411e-05,
#                        -1.7232e-04,  5.6052e-45, -8.0256e-05,  5.6052e-45,  1.6834e-04,
#                         1.6784e-04,  4.1669e-04,  5.6052e-45,  3.3822e-04,  2.6240e-04,
#                         7.5729e-06,  5.6052e-45,  2.3038e-04, -1.1664e-06,  5.6052e-45,
#                         1.3214e-04,  5.6052e-45,  6.7445e-05,  4.0003e-04,  5.6052e-45,
#                         5.6052e-45,  5.6052e-45,  5.6052e-45,  2.5417e-04, -3.3137e-05,
#                        -6.8539e-05,  0.0000e+00,  5.6052e-45,  8.1336e-05,  2.2790e-04,
#                         1.5396e-04,  1.0333e-04,  1.3921e-04,  1.1764e-04,  1.7327e-04,
#                         5.6052e-45,  5.6052e-45,  1.6627e-04,  5.6052e-45, -1.9046e-04,
#                         5.6052e-45], device='cuda:0'),
#                'exp_avg_sq': tensor([1.1032e-07, 6.8871e-07, 1.6000e-06, 3.2871e-06, 7.0065e-43, 4.5149e-08,
#                        7.0065e-43, 0.0000e+00, 0.0000e+00, 5.1031e-06, 0.0000e+00, 7.0065e-43,
#                        1.3203e-07, 7.0065e-43, 8.6305e-06, 5.3786e-06, 1.7431e-06, 1.3195e-07,
#                        3.0996e-07, 7.0065e-43, 7.0065e-43, 4.6005e-07, 7.0065e-43, 7.0065e-43,
#                        0.0000e+00, 1.9129e-08, 9.4837e-08, 1.3359e-05, 0.0000e+00, 1.8202e-07,
#                        7.0065e-43, 3.1629e-06, 1.0651e-06, 5.2828e-09, 7.0065e-43, 1.5383e-05,
#                        7.8774e-07, 7.0065e-43, 5.0268e-06, 2.0698e-07, 3.2228e-06, 2.1105e-07,
#                        1.3549e-06, 2.5994e-05, 2.1129e-06, 1.5985e-06, 1.5987e-07, 4.0252e-06,
#                        0.0000e+00, 7.0065e-43, 4.5563e-07, 4.9943e-07, 0.0000e+00, 1.6198e-05,
#                        3.2281e-06, 0.0000e+00, 0.0000e+00, 7.0065e-43, 7.0065e-43, 8.0020e-08,
#                        7.0065e-43, 7.0065e-43, 1.2367e-05, 7.0065e-43, 7.0065e-43, 1.9889e-06,
#                        3.6115e-06, 2.4159e-06, 7.0065e-43, 2.3219e-07, 3.5758e-08, 3.3979e-06,
#                        7.0065e-43, 7.0065e-43, 4.6685e-06, 7.9339e-07, 1.3103e-06, 0.0000e+00,
#                        3.1246e-06, 3.7274e-06, 2.4223e-06, 7.0065e-43, 0.0000e+00, 1.6858e-06,
#                        6.2592e-08, 9.9889e-06, 1.8563e-06, 4.1910e-07, 2.1705e-07, 7.0065e-43,
#                        7.0065e-43, 0.0000e+00, 6.7085e-07, 1.1038e-06, 1.4928e-07, 3.5398e-06,
#                        2.0174e-07, 7.0065e-43, 7.0065e-43, 7.0065e-43, 1.1852e-05, 1.5044e-05,
#                        7.0065e-43, 7.0065e-43, 7.0065e-43, 7.0065e-43, 0.0000e+00, 7.0065e-43,
#                        2.7820e-05, 2.8229e-06, 3.8032e-06, 3.0096e-06, 0.0000e+00, 7.0065e-43,
#                        7.0065e-43, 1.0849e-06, 0.0000e+00, 1.7968e-05, 2.5146e-06, 5.1803e-07,
#                        1.0543e-06, 6.7972e-07, 3.3978e-07, 0.0000e+00, 4.9941e-06, 0.0000e+00,
#                        1.6702e-06, 5.6022e-06, 7.4937e-07, 3.4592e-06, 3.8434e-07, 8.2828e-06,
#                        2.0580e-07, 7.0065e-43, 3.9372e-06, 2.9496e-07, 1.6486e-06, 1.9312e-05,
#                        1.5128e-06, 2.0447e-05, 7.0065e-43, 2.3499e-07, 9.5953e-06, 1.2617e-06,
#                        7.8158e-07, 8.2524e-07, 7.0065e-43, 2.6017e-07, 3.6209e-06, 0.0000e+00,
#                        6.3249e-07, 2.6781e-07, 1.1616e-05, 7.4055e-07, 4.1138e-06, 2.7661e-05,
#                        1.0550e-05, 6.5721e-07, 0.0000e+00, 2.0546e-07, 6.0944e-07, 7.0065e-43,
#                        4.4065e-07, 7.0065e-43, 1.4238e-05, 7.9482e-06, 2.1761e-06, 7.0065e-43,
#                        1.6619e-06, 1.1673e-06, 4.6634e-06, 7.0065e-43, 8.0325e-06, 8.5389e-08,
#                        7.0065e-43, 2.9093e-07, 7.0065e-43, 2.9952e-07, 5.1246e-06, 7.0065e-43,
#                        7.0065e-43, 7.0065e-43, 7.0065e-43, 5.5197e-06, 1.1920e-06, 2.3160e-07,
#                        0.0000e+00, 7.0065e-43, 3.6287e-07, 1.6589e-06, 4.4712e-07, 1.0492e-06,
#                        2.7759e-07, 2.5948e-07, 2.1217e-06, 7.0065e-43, 7.0065e-43, 1.5727e-06,
#                        7.0065e-43, 1.7078e-06, 7.0065e-43], device='cuda:0')},
#               Parameter containing:
#               tensor([[ 0.0082,  0.0024, -0.0846,  ..., -0.0441, -0.0531,  0.0572],
#                       [-0.0309, -0.0519,  0.0197,  ...,  0.0408, -0.0497, -0.0388],
#                       [-0.0346,  0.0220, -0.0591,  ...,  0.0335, -0.0395,  0.0596],
#                       ...,
#                       [ 0.0594,  0.0444,  0.0342,  ...,  0.0266, -0.0787, -0.0470],
#                       [ 0.0760,  0.0449, -0.0195,  ...,  0.0388, -0.0327, -0.0227],
#                       [-0.0163, -0.0359, -0.0048,  ...,  0.0317,  0.0283, -0.0222]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([[ 0.0000e+00,  5.6052e-45,  5.6052e-45,  ...,  0.0000e+00,
#                          5.6052e-45,  0.0000e+00],
#                        [ 5.6052e-45,  5.6052e-45,  5.6052e-45,  ...,  5.6052e-45,
#                          5.6052e-45,  5.6052e-45],
#                        [ 5.6052e-45,  5.6052e-45,  5.6052e-45,  ...,  5.6052e-45,
#                          5.6052e-45,  5.6052e-45],
#                        ...,
#                        [-2.1631e-07,  5.9402e-05, -6.1566e-06,  ..., -5.6052e-45,
#                          2.3737e-04, -5.6052e-45],
#                        [-2.6778e-07,  7.3537e-05, -9.5480e-06,  ..., -5.6052e-45,
#                          2.9385e-04, -5.6052e-45],
#                        [-5.1517e-07,  1.4147e-04, -1.6290e-05,  ..., -5.6052e-45,
#                          5.6533e-04, -5.6052e-45]], device='cuda:0'),
#                'exp_avg_sq': tensor([[0.0000e+00, 7.0065e-43, 7.0065e-43,  ..., 0.0000e+00, 7.0065e-43,
#                         0.0000e+00],
#                        [7.0065e-43, 7.0065e-43, 7.0065e-43,  ..., 7.0065e-43, 7.0065e-43,
#                         7.0065e-43],
#                        [7.0065e-43, 7.0065e-43, 7.0065e-43,  ..., 7.0065e-43, 7.0065e-43,
#                         7.0065e-43],
#                        ...,
#                        [4.0097e-10, 1.1281e-07, 1.9658e-05,  ..., 7.0065e-43, 7.8279e-07,
#                         7.0065e-43],
#                        [6.1451e-10, 1.7289e-07, 3.0126e-05,  ..., 7.0065e-43, 1.2001e-06,
#                         7.0065e-43],
#                        [2.2744e-09, 6.3991e-07, 1.1148e-04,  ..., 7.0065e-43, 4.4402e-06,
#                         7.0065e-43]], device='cuda:0')},
#               Parameter containing:
#               tensor([-0.0407,  0.0517,  0.0384, -0.0487,  0.0394, -0.0088,  0.0162, -0.0464,
#                        0.0261,  0.0030, -0.0070,  0.0030,  0.0292, -0.0313,  0.0231, -0.0599,
#                        0.0421, -0.0310, -0.0630, -0.0360, -0.0237,  0.0057, -0.0088, -0.0425,
#                       -0.0423, -0.0273,  0.0050, -0.0335,  0.0427, -0.0640,  0.0029,  0.0718,
#                       -0.0594, -0.0300,  0.0175, -0.0479,  0.0290,  0.0344,  0.0011, -0.0708,
#                       -0.0593, -0.0429, -0.0054, -0.0017,  0.0367,  0.0045, -0.0365,  0.0565,
#                       -0.0164, -0.0348, -0.0128,  0.0420,  0.0169,  0.0214,  0.0326,  0.0959,
#                       -0.0624, -0.0688, -0.0172,  0.0151,  0.0166,  0.0617,  0.0830,  0.0399,
#                       -0.0163, -0.0281, -0.0029,  0.0778,  0.0304,  0.0344, -0.0129, -0.0196,
#                        0.0408,  0.0446,  0.0422, -0.0280,  0.0348,  0.0710, -0.0142,  0.0032,
#                        0.0779, -0.0011, -0.1069,  0.0568,  0.0147, -0.0257, -0.0357],
#                      device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([ 5.6052e-45,  5.6052e-45,  5.6052e-45,  5.6052e-45,  1.0036e-03,
#                         5.6052e-45,  5.6052e-45,  5.6052e-45,  5.9964e-04,  5.6052e-45,
#                         4.3827e-04,  5.4561e-04,  5.6052e-45,  5.6714e-04, -9.4930e-04,
#                         5.6052e-45,  1.7763e-04,  5.6052e-45,  5.6052e-45,  3.8975e-04,
#                         9.6692e-05, -2.3930e-04,  2.0145e-04,  5.6052e-45,  2.1675e-04,
#                         5.6052e-45,  5.6052e-45,  6.7394e-04,  5.6052e-45,  5.6052e-45,
#                         5.6052e-45,  1.0604e-04,  0.0000e+00,  5.6052e-45,  5.6052e-45,
#                         2.0527e-04,  4.0955e-05,  5.6052e-45, -2.2087e-04,  5.6052e-45,
#                         2.1987e-05,  5.6052e-45,  4.3906e-04,  5.6052e-45,  5.6052e-45,
#                         5.6052e-45,  2.1946e-04,  3.1776e-04,  2.3143e-04,  0.0000e+00,
#                         1.3153e-04,  5.6052e-45,  2.7073e-04,  4.8002e-04,  5.6052e-45,
#                         4.5889e-04,  5.6052e-45,  5.6052e-45,  5.6052e-45, -1.1887e-03,
#                         5.6052e-45,  5.7413e-04,  4.8341e-04,  3.3815e-04,  5.6052e-45,
#                         5.6052e-45,  5.6052e-45,  3.2304e-04,  6.6403e-04,  2.7685e-04,
#                         5.6306e-04,  4.5100e-04, -1.2841e-04,  7.7156e-05,  3.2449e-04,
#                        -1.7590e-05,  5.6052e-45,  2.5951e-04,  0.0000e+00,  5.6052e-45,
#                         2.2617e-04,  5.6052e-45,  2.3397e-04,  1.4254e-04,  2.3402e-04,
#                         2.4686e-04,  5.3479e-04], device='cuda:0'),
#                'exp_avg_sq': tensor([7.0065e-43, 7.0065e-43, 7.0065e-43, 7.0065e-43, 1.6550e-06, 7.0065e-43,
#                        7.0065e-43, 7.0065e-43, 1.0051e-05, 7.0065e-43, 7.0338e-06, 3.6709e-06,
#                        7.0065e-43, 5.0028e-05, 1.8292e-05, 7.0065e-43, 1.8120e-06, 7.0065e-43,
#                        7.0065e-43, 2.5688e-05, 1.3586e-06, 1.0851e-05, 2.8616e-06, 7.0065e-43,
#                        8.6810e-07, 7.0065e-43, 7.0065e-43, 3.4333e-05, 7.0065e-43, 7.0065e-43,
#                        7.0065e-43, 9.4698e-07, 0.0000e+00, 7.0065e-43, 7.0065e-43, 9.6907e-07,
#                        5.3167e-08, 7.0065e-43, 1.2492e-05, 7.0065e-43, 7.3095e-07, 7.0065e-43,
#                        2.9964e-05, 7.0065e-43, 7.0065e-43, 7.0065e-43, 7.4913e-06, 4.2121e-06,
#                        8.3278e-06, 0.0000e+00, 1.5852e-06, 7.0065e-43, 1.2149e-05, 6.3462e-07,
#                        7.0065e-43, 3.3241e-05, 7.0065e-43, 7.0065e-43, 7.0065e-43, 1.4233e-05,
#                        7.0065e-43, 4.1219e-05, 3.6774e-05, 7.5019e-07, 7.0065e-43, 7.0065e-43,
#                        7.0065e-43, 1.6232e-05, 2.4995e-05, 4.4811e-07, 4.9772e-05, 3.0741e-06,
#                        1.4872e-06, 9.2588e-07, 1.6377e-05, 7.0182e-09, 7.0065e-43, 1.0475e-05,
#                        0.0000e+00, 7.0065e-43, 7.9558e-06, 7.0065e-43, 5.6308e-07, 2.5626e-06,
#                        8.5182e-06, 1.2989e-05, 4.7942e-05], device='cuda:0')},
#               Parameter containing:
#               tensor([[ 0.0316, -0.0070, -0.0702, -0.0766, -0.1184, -0.0139,  0.0674, -0.0831,
#                         0.0479,  0.0006,  0.0391, -0.0839, -0.0951,  0.1038,  0.1078,  0.0713,
#                         0.0202, -0.0509, -0.0567,  0.0744,  0.0798, -0.0752, -0.0779, -0.0703,
#                        -0.0699,  0.0730, -0.0652,  0.0889, -0.0094, -0.0223, -0.0115,  0.0143,
#                         0.0992, -0.0687,  0.0513,  0.0149,  0.0040, -0.0564, -0.0713, -0.0695,
#                         0.0761, -0.0029,  0.0803, -0.0235, -0.0608, -0.0974,  0.0401,  0.0362,
#                         0.0424,  0.0651,  0.0189, -0.0361,  0.0512, -0.0692, -0.0310,  0.0846,
#                        -0.0743, -0.0406,  0.0699, -0.1347, -0.0949,  0.0942,  0.0890, -0.0908,
#                        -0.0291,  0.0272, -0.0846,  0.0591,  0.0742, -0.0704,  0.1035, -0.0577,
#                        -0.0550,  0.0141,  0.0594,  0.0042, -0.0561,  0.0475, -0.0574, -0.0536,
#                         0.0414, -0.0302, -0.0796,  0.0237,  0.0428,  0.0530,  0.1020]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([[ 5.6052e-45, -5.6052e-45, -5.6052e-45, -5.6052e-45, -3.3873e-04,
#                         -5.6052e-45,  5.6052e-45, -5.6052e-45, -3.7306e-03, -5.6052e-45,
#                         -7.1357e-03, -8.2602e-04, -5.6052e-45, -1.0894e-02,  3.2704e-04,
#                          5.6052e-45, -5.0980e-03, -5.6052e-45, -5.6052e-45, -8.9859e-03,
#                         -1.8528e-04, -6.2873e-04, -9.6241e-04, -5.6052e-45, -1.8226e-04,
#                          5.6052e-45, -5.6052e-45, -4.6336e-03, -5.6052e-45, -5.6052e-45,
#                          5.6052e-45, -1.1720e-03,  0.0000e+00, -5.6052e-45,  5.6052e-45,
#                         -2.2702e-03, -2.3762e-04, -5.6052e-45, -1.8950e-03, -5.6052e-45,
#                          1.2971e-05, -5.6052e-45, -7.5546e-03, -5.6052e-45, -5.6052e-45,
#                         -5.6052e-45, -7.2199e-03,  1.2389e-03, -4.3695e-03,  0.0000e+00,
#                         -3.7003e-03, -5.6052e-45, -6.0715e-03, -8.1959e-04, -5.6052e-45,
#                         -7.6699e-03, -5.6052e-45, -5.6052e-45,  5.6052e-45,  2.6679e-04,
#                         -5.6052e-45, -8.4968e-03, -9.5590e-03, -3.1628e-04, -5.6052e-45,
#                          5.6052e-45, -5.6052e-45, -7.2977e-03, -7.1178e-03, -5.0718e-04,
#                         -1.0387e-02, -1.3107e-03, -2.7977e-05, -3.0031e-03, -6.5939e-03,
#                         -1.7116e-04, -5.6052e-45, -3.2602e-03,  0.0000e+00, -5.6052e-45,
#                         -6.8232e-03, -5.6052e-45, -2.8751e-04, -3.7467e-03, -4.7611e-03,
#                         -5.3729e-03, -1.2949e-02]], device='cuda:0'),
#                'exp_avg_sq': tensor([[7.0065e-43, 7.0065e-43, 7.0065e-43, 7.0065e-43, 1.7729e-07, 7.0065e-43,
#                         7.0065e-43, 7.0065e-43, 1.8152e-02, 7.0065e-43, 4.9452e-02, 3.6411e-05,
#                         7.0065e-43, 5.4411e-02, 1.6377e-04, 7.0065e-43, 1.8341e-02, 7.0065e-43,
#                         7.0065e-43, 4.3949e-02, 6.2488e-07, 8.0047e-04, 1.8986e-04, 7.0065e-43,
#                         7.2959e-06, 7.0065e-43, 7.0065e-43, 1.9231e-02, 7.0065e-43, 7.0065e-43,
#                         7.0065e-43, 9.2077e-03, 0.0000e+00, 7.0065e-43, 7.0065e-43, 9.3497e-03,
#                         4.0481e-04, 7.0065e-43, 1.9871e-03, 7.0065e-43, 1.0700e-07, 7.0065e-43,
#                         5.4002e-02, 7.0065e-43, 7.0065e-43, 7.0065e-43, 4.8344e-02, 8.3130e-05,
#                         1.8311e-02, 0.0000e+00, 1.2347e-02, 7.0065e-43, 4.9583e-02, 2.6446e-06,
#                         7.0065e-43, 8.2061e-02, 7.0065e-43, 7.0065e-43, 7.0065e-43, 1.7078e-06,
#                         7.0065e-43, 5.5698e-02, 6.0202e-02, 5.5524e-07, 7.0065e-43, 7.0065e-43,
#                         7.0065e-43, 3.7964e-02, 3.3071e-02, 1.8982e-06, 5.8504e-02, 3.1239e-04,
#                         2.6801e-06, 1.5355e-02, 3.4157e-02, 5.5597e-07, 7.0065e-43, 2.1065e-02,
#                         0.0000e+00, 7.0065e-43, 3.4112e-02, 7.0065e-43, 1.8156e-06, 1.1477e-02,
#                         4.0702e-02, 3.1466e-02, 8.0673e-02]], device='cuda:0')},
#               Parameter containing:
#               tensor([-0.0490], device='cuda:0', requires_grad=True): {'step': tensor(143600.),
#                'exp_avg': tensor([0.0055], device='cuda:0'),
#                'exp_avg_sq': tensor([0.0046], device='cuda:0')}}),
#  'param_groups': [{'lr': 7.324856218845872e-09,
#    'betas': (0.9, 0.999),
#    'eps': 1e-08,
#    'weight_decay': 0,
#    'amsgrad': False,
#    'maximize': False,
#    'foreach': None,
#    'capturable': False,
#    'differentiable': False,
#    'fused': None,
#    'params': [Parameter containing:
#     tensor([[ 3.2871e-01,  2.6898e-01,  5.7468e-02],
#             [ 2.5778e-01,  8.8501e-02,  2.4048e-01],
#             [ 2.5637e-01,  1.3040e-01,  5.3219e-01],
#             [-3.0651e-01,  7.9911e-02, -6.4790e-01],
#             [ 5.2635e-01,  4.1950e-01, -2.5271e-01],
#             [ 1.1814e-01,  2.1640e-01, -8.5747e-02],
#             [ 2.6105e-01, -2.1145e-01,  5.1708e-01],
#             [-3.9715e-01,  2.6906e-01, -3.2654e-02],
#             [ 3.1769e-01, -6.8356e-01, -3.0824e-01],
#             [ 4.4977e-01, -2.9523e-01, -2.6803e-01],
#             [-4.1099e-01,  5.1398e-01, -1.5696e-01],
#             [ 8.4840e-02, -5.5002e-01,  6.0617e-02],
#             [ 1.8896e-01,  4.7925e-01, -1.1237e-01],
#             [-5.2464e-01, -5.4133e-01,  2.4577e-01],
#             [-1.2535e-02,  3.3904e-01,  4.3744e-01],
#             [ 3.6593e-01, -2.0036e-01, -4.5450e-01],
#             [-3.0429e-01,  1.6153e-01,  5.6210e-02],
#             [-4.4021e-03, -2.1958e-01,  2.7260e-01],
#             [ 1.5623e-01,  3.6463e-01,  3.7926e-01],
#             [ 1.0592e-01, -4.0440e-01,  5.7294e-01],
#             [-2.4927e-01,  5.3309e-01,  1.5319e-01],
#             [-3.3921e-01,  4.9197e-01,  3.6111e-01],
#             [-4.4925e-02, -1.9818e-02, -2.7950e-01],
#             [ 3.5500e-01,  5.5291e-01, -1.6360e-01],
#             [-4.8770e-01, -2.6103e-01,  5.8190e-01],
#             [-3.9900e-01, -3.2412e-01,  5.0834e-01],
#             [-4.6377e-01, -5.3170e-01,  5.7401e-02],
#             [-1.4497e-02, -5.3492e-01, -5.4522e-01],
#             [ 4.6929e-01, -4.4872e-01, -4.1446e-01],
#             [-8.1824e-02,  8.1445e-02,  3.6286e-01],
#             [-1.1411e-01,  2.6083e-01,  7.0875e-02],
#             [ 2.4323e-01, -4.8877e-01,  5.1622e-01],
#             [-5.4809e-01,  2.7598e-01,  1.2297e-01],
#             [ 4.2695e-02, -5.4644e-01, -1.5226e-01],
#             [-1.5729e-01, -5.6521e-01,  3.9754e-01],
#             [-3.1936e-01, -2.9530e-01, -2.4608e-01],
#             [ 4.9724e-02, -4.8120e-01,  5.8377e-01],
#             [-3.7218e-01,  1.9860e-01,  4.8038e-01],
#             [ 1.2279e-01,  7.2694e-03, -4.0758e-01],
#             [-3.6026e-01,  9.1022e-03, -1.3550e-01],
#             [ 7.7872e-07,  5.6584e-01, -4.6152e-01],
#             [-3.9895e-01, -6.7139e-02, -4.8775e-01],
#             [ 2.8171e-01, -4.6808e-02, -3.5956e-02],
#             [ 8.4000e-02, -3.1155e-01,  4.1534e-01],
#             [-1.9195e-01,  4.8585e-01, -5.0702e-02],
#             [ 3.4703e-01, -6.5787e-02,  1.3387e-01],
#             [ 2.5140e-01, -3.5971e-01, -9.2266e-02],
#             [-3.9539e-01,  2.6799e-01, -5.8117e-02],
#             [ 4.0500e-01,  2.6658e-01,  3.2638e-01],
#             [ 4.5794e-01,  1.9248e-01,  5.4904e-01],
#             [ 3.5493e-02, -5.5742e-02,  5.2931e-01],
#             [ 2.0006e-01, -4.0809e-01,  5.4375e-01],
#             [-1.8784e-01,  1.2742e-01, -5.5037e-01],
#             [-3.7811e-01, -4.4661e-01, -3.7102e-01],
#             [ 8.5449e-02,  1.8750e-01, -1.7184e-01],
#             [-2.9145e-01, -4.7472e-01, -2.9594e-01],
#             [ 5.3985e-01, -5.7166e-02,  2.2915e-01],
#             [-2.0408e-01, -3.2365e-01,  1.2394e-01],
#             [ 4.0671e-01,  2.7815e-01, -4.5224e-01],
#             [-1.7122e-01, -1.2344e-01,  2.7737e-01],
#             [-3.0876e-01, -6.7135e-01, -2.5156e-02],
#             [ 5.5943e-02, -2.9807e-02,  2.4742e-01],
#             [ 1.5911e-01, -5.3110e-01,  2.6574e-01],
#             [-1.1771e-02,  9.1098e-02, -1.8666e-01],
#             [ 1.0149e-01, -1.0748e-01, -4.6810e-01],
#             [ 2.3736e-01, -3.2327e-01, -1.4917e-02],
#             [ 2.1822e-01,  2.7498e-01, -2.1260e-01],
#             [ 8.8678e-02,  2.3149e-01,  3.0235e-01],
#             [ 5.0060e-01, -1.6139e-01, -2.1722e-01],
#             [-4.2235e-01, -1.7428e-01,  2.1604e-01],
#             [ 1.0512e-01, -3.0967e-01, -4.4836e-01],
#             [ 4.1386e-01, -1.0671e-01,  2.3909e-01],
#             [-3.4282e-01, -2.5743e-01,  1.4845e-01],
#             [ 3.6988e-01,  8.0510e-02,  2.5896e-01],
#             [ 2.7613e-01, -5.0307e-01,  6.9001e-03],
#             [ 3.0913e-01, -2.7830e-02, -5.8690e-01],
#             [ 1.4536e-01, -5.0987e-01, -2.7912e-01],
#             [-3.6681e-02, -2.0823e-01,  2.4248e-01],
#             [-2.9568e-01,  4.3802e-02,  5.2083e-01],
#             [-1.4245e-01,  2.1458e-01, -8.0099e-02],
#             [-3.1543e-02,  3.6534e-01, -1.6282e-01],
#             [-4.6629e-01,  1.2862e-01,  5.3923e-02],
#             [-5.5387e-01,  2.0793e-02,  1.8427e-01],
#             [-1.5975e-02,  4.5797e-01,  7.5040e-02],
#             [-4.3012e-03,  2.6723e-01,  4.1088e-01],
#             [ 3.8252e-01,  2.5043e-01, -4.8714e-01]], device='cuda:0',
#            requires_grad=True),
#     Parameter containing:
#     tensor([-0.5549,  0.2452, -0.3872,  0.4292, -0.3885, -0.3058, -0.2567, -0.1654,
#             -0.2002, -0.2534,  0.5046,  0.2089,  0.3455,  0.4646, -0.1994, -0.2333,
#              0.3698,  0.0242, -0.4556, -0.0540,  0.0688,  0.1146, -0.2387, -0.4058,
#             -0.1903,  0.2314, -0.0865, -0.1604, -0.5121,  0.2907,  0.2931, -0.0076,
#             -0.2417, -0.4053, -0.4360, -0.4643,  0.2409,  0.1942, -0.2581, -0.3488,
#              0.0896,  0.1908, -0.6561, -0.3972,  0.3677, -0.4977,  0.4286, -0.3894,
#             -0.4120, -0.5496, -0.3718,  0.5063, -0.4250, -0.2714, -0.0464,  0.1012,
#              0.1782, -0.4319, -0.4426, -0.1678,  0.2534, -0.4319, -0.1718,  0.4408,
#              0.4424,  0.3544, -0.1139, -0.4922,  0.2264, -0.2194,  0.1309,  0.0819,
#              0.5901,  0.3242,  0.1449,  0.2318,  0.3965,  0.1507, -0.1453,  0.4624,
#             -0.4706,  0.4079,  0.2755, -0.5699,  0.3576, -0.3817], device='cuda:0',
#            requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0411,  0.0393, -0.1237,  ...,  0.0618,  0.0553, -0.0659],
#             [ 0.0812, -0.0912,  0.0764,  ..., -0.0883, -0.0810, -0.2688],
#             [-0.0283, -0.0206,  0.0323,  ..., -0.0615,  0.0806,  0.0894],
#             ...,
#             [-0.0189,  0.0344, -0.0930,  ...,  0.0716,  0.0712, -0.0378],
#             [ 0.0858,  0.0551,  0.0899,  ...,  0.0489,  0.0097, -0.0940],
#             [-0.0792, -0.0461,  0.0707,  ...,  0.0717, -0.0207, -0.0763]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-0.0102,  0.0100,  0.1059,  0.0794, -0.0971, -0.0997,  0.0283, -0.0284,
#             -0.0404, -0.0963,  0.0564, -0.0580, -0.0818, -0.0877,  0.1045,  0.0079,
#              0.0501, -0.0042, -0.0433,  0.0288, -0.1294,  0.0415, -0.0922,  0.0417,
#             -0.0077,  0.0007, -0.0164,  0.0771,  0.0377, -0.1064, -0.0987,  0.0771,
#              0.0992, -0.0811,  0.0832,  0.0886, -0.0893,  0.0345,  0.0355, -0.0932,
#              0.0777,  0.0896, -0.0207, -0.0468, -0.0495,  0.0059, -0.0873, -0.0652,
#             -0.0448,  0.0076,  0.0534, -0.0898,  0.0963,  0.0508, -0.0581,  0.0090,
#             -0.0731, -0.0464,  0.0580,  0.0737, -0.0328,  0.0654,  0.1240, -0.0973,
#              0.0223, -0.0019, -0.0770, -0.0410,  0.0085, -0.0132, -0.1091,  0.0504,
#             -0.0077,  0.0778,  0.0101,  0.0036, -0.0933, -0.0110,  0.0729, -0.0515,
#              0.0935,  0.0432, -0.0555,  0.1043, -0.0837,  0.0494, -0.0354, -0.0115,
#              0.0250,  0.0523, -0.0429, -0.0926,  0.0473, -0.0295, -0.0006,  0.1040,
#             -0.1030,  0.0726, -0.0475, -0.0006,  0.1069, -0.0508,  0.0737, -0.0489,
#              0.0557, -0.1087,  0.0027,  0.0469,  0.1028,  0.1107,  0.0097, -0.0647,
#             -0.0761, -0.0580, -0.0922,  0.0696, -0.0420,  0.0115, -0.0994, -0.0426,
#             -0.0355, -0.0720,  0.1162, -0.0825, -0.0402, -0.0015, -0.0030,  0.0697,
#             -0.0095, -0.0632, -0.0981,  0.0201,  0.0330,  0.0055,  0.0125,  0.0355,
#              0.0882,  0.0636,  0.0793, -0.0553,  0.0346, -0.0928, -0.0053,  0.0489,
#             -0.0219,  0.0343, -0.0959,  0.0835,  0.0276, -0.0198,  0.1300,  0.0158,
#              0.1152,  0.1349,  0.1202,  0.1139,  0.0422,  0.0060, -0.0662, -0.1575,
#             -0.0118, -0.1028, -0.0263,  0.0668,  0.0466,  0.0658, -0.0828,  0.0684,
#             -0.0255, -0.0888, -0.0470,  0.0876, -0.0956, -0.1188, -0.1177, -0.0340,
#              0.0335, -0.0369,  0.0885,  0.0545,  0.0541, -0.0609, -0.0195, -0.0752,
#             -0.0298, -0.1367, -0.0523, -0.0875,  0.0660,  0.0564, -0.0588, -0.0847,
#              0.0532,  0.0312,  0.0713, -0.0092, -0.0593,  0.0616, -0.0010, -0.0127,
#              0.0898], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[ 0.0082,  0.0024, -0.0846,  ..., -0.0441, -0.0531,  0.0572],
#             [-0.0309, -0.0519,  0.0197,  ...,  0.0408, -0.0497, -0.0388],
#             [-0.0346,  0.0220, -0.0591,  ...,  0.0335, -0.0395,  0.0596],
#             ...,
#             [ 0.0594,  0.0444,  0.0342,  ...,  0.0266, -0.0787, -0.0470],
#             [ 0.0760,  0.0449, -0.0195,  ...,  0.0388, -0.0327, -0.0227],
#             [-0.0163, -0.0359, -0.0048,  ...,  0.0317,  0.0283, -0.0222]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-0.0407,  0.0517,  0.0384, -0.0487,  0.0394, -0.0088,  0.0162, -0.0464,
#              0.0261,  0.0030, -0.0070,  0.0030,  0.0292, -0.0313,  0.0231, -0.0599,
#              0.0421, -0.0310, -0.0630, -0.0360, -0.0237,  0.0057, -0.0088, -0.0425,
#             -0.0423, -0.0273,  0.0050, -0.0335,  0.0427, -0.0640,  0.0029,  0.0718,
#             -0.0594, -0.0300,  0.0175, -0.0479,  0.0290,  0.0344,  0.0011, -0.0708,
#             -0.0593, -0.0429, -0.0054, -0.0017,  0.0367,  0.0045, -0.0365,  0.0565,
#             -0.0164, -0.0348, -0.0128,  0.0420,  0.0169,  0.0214,  0.0326,  0.0959,
#             -0.0624, -0.0688, -0.0172,  0.0151,  0.0166,  0.0617,  0.0830,  0.0399,
#             -0.0163, -0.0281, -0.0029,  0.0778,  0.0304,  0.0344, -0.0129, -0.0196,
#              0.0408,  0.0446,  0.0422, -0.0280,  0.0348,  0.0710, -0.0142,  0.0032,
#              0.0779, -0.0011, -0.1069,  0.0568,  0.0147, -0.0257, -0.0357],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[ 0.0316, -0.0070, -0.0702, -0.0766, -0.1184, -0.0139,  0.0674, -0.0831,
#               0.0479,  0.0006,  0.0391, -0.0839, -0.0951,  0.1038,  0.1078,  0.0713,
#               0.0202, -0.0509, -0.0567,  0.0744,  0.0798, -0.0752, -0.0779, -0.0703,
#              -0.0699,  0.0730, -0.0652,  0.0889, -0.0094, -0.0223, -0.0115,  0.0143,
#               0.0992, -0.0687,  0.0513,  0.0149,  0.0040, -0.0564, -0.0713, -0.0695,
#               0.0761, -0.0029,  0.0803, -0.0235, -0.0608, -0.0974,  0.0401,  0.0362,
#               0.0424,  0.0651,  0.0189, -0.0361,  0.0512, -0.0692, -0.0310,  0.0846,
#              -0.0743, -0.0406,  0.0699, -0.1347, -0.0949,  0.0942,  0.0890, -0.0908,
#              -0.0291,  0.0272, -0.0846,  0.0591,  0.0742, -0.0704,  0.1035, -0.0577,
#              -0.0550,  0.0141,  0.0594,  0.0042, -0.0561,  0.0475, -0.0574, -0.0536,
#               0.0414, -0.0302, -0.0796,  0.0237,  0.0428,  0.0530,  0.1020]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-0.0490], device='cuda:0', requires_grad=True)]}],
#  '_warned_capturable_if_run_uncaptured': True}
# {'factor': 0.1,
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 7.324856218845872e-09
#      maximize: False
#      weight_decay: 0
#  ),
#  'min_lrs': [0],
#  'patience': 10,
#  'verbose': False,
#  'cooldown': 0,
#  'cooldown_counter': 0,
#  'mode': 'min',
#  'threshold': 0.0001,
#  'threshold_mode': 'rel',
#  'best': 0.0015331237063976005,
#  'num_bad_epochs': 5,
#  'mode_worse': inf,
#  'eps': 1e-08,
#  'last_epoch': 400,
#  '_last_lr': [7.324856218845872e-09]}

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 3.2871e-01,  2.6898e-01,  5.7468e-02],
#         [ 2.5778e-01,  8.8501e-02,  2.4048e-01],
#         [ 2.5637e-01,  1.3040e-01,  5.3219e-01],
#         [-3.0651e-01,  7.9911e-02, -6.4790e-01],
#         [ 5.2635e-01,  4.1950e-01, -2.5271e-01],
#         [ 1.1814e-01,  2.1640e-01, -8.5747e-02],
#         [ 2.6105e-01, -2.1145e-01,  5.1708e-01],
#         [-3.9715e-01,  2.6906e-01, -3.2654e-02],
#         [ 3.1769e-01, -6.8356e-01, -3.0824e-01],
#         [ 4.4977e-01, -2.9523e-01, -2.6803e-01],
#         [-4.1099e-01,  5.1398e-01, -1.5696e-01],
#         [ 8.4840e-02, -5.5002e-01,  6.0617e-02],
#         [ 1.8896e-01,  4.7925e-01, -1.1237e-01],
#         [-5.2464e-01, -5.4133e-01,  2.4577e-01],
#         [-1.2535e-02,  3.3904e-01,  4.3744e-01],
#         [ 3.6593e-01, -2.0036e-01, -4.5450e-01],
#         [-3.0429e-01,  1.6153e-01,  5.6210e-02],
#         [-4.4021e-03, -2.1958e-01,  2.7260e-01],
#         [ 1.5623e-01,  3.6463e-01,  3.7926e-01],
#         [ 1.0592e-01, -4.0440e-01,  5.7294e-01],
#         [-2.4927e-01,  5.3309e-01,  1.5319e-01],
#         [-3.3921e-01,  4.9197e-01,  3.6111e-01],
#         [-4.4925e-02, -1.9818e-02, -2.7950e-01],
#         [ 3.5500e-01,  5.5291e-01, -1.6360e-01],
#         [-4.8770e-01, -2.6103e-01,  5.8190e-01],
#         [-3.9900e-01, -3.2412e-01,  5.0834e-01],
#         [-4.6377e-01, -5.3170e-01,  5.7401e-02],
#         [-1.4497e-02, -5.3492e-01, -5.4522e-01],
#         [ 4.6929e-01, -4.4872e-01, -4.1446e-01],
#         [-8.1824e-02,  8.1445e-02,  3.6286e-01],
#         [-1.1411e-01,  2.6083e-01,  7.0875e-02],
#         [ 2.4323e-01, -4.8877e-01,  5.1622e-01],
#         [-5.4809e-01,  2.7598e-01,  1.2297e-01],
#         [ 4.2695e-02, -5.4644e-01, -1.5226e-01],
#         [-1.5729e-01, -5.6521e-01,  3.9754e-01],
#         [-3.1936e-01, -2.9530e-01, -2.4608e-01],
#         [ 4.9724e-02, -4.8120e-01,  5.8377e-01],
#         [-3.7218e-01,  1.9860e-01,  4.8038e-01],
#         [ 1.2279e-01,  7.2694e-03, -4.0758e-01],
#         [-3.6026e-01,  9.1022e-03, -1.3550e-01],
#         [ 7.7872e-07,  5.6584e-01, -4.6152e-01],
#         [-3.9895e-01, -6.7139e-02, -4.8775e-01],
#         [ 2.8171e-01, -4.6808e-02, -3.5956e-02],
#         [ 8.4000e-02, -3.1155e-01,  4.1534e-01],
#         [-1.9195e-01,  4.8585e-01, -5.0702e-02],
#         [ 3.4703e-01, -6.5787e-02,  1.3387e-01],
#         [ 2.5140e-01, -3.5971e-01, -9.2266e-02],
#         [-3.9539e-01,  2.6799e-01, -5.8117e-02],
#         [ 4.0500e-01,  2.6658e-01,  3.2638e-01],
#         [ 4.5794e-01,  1.9248e-01,  5.4904e-01],
#         [ 3.5493e-02, -5.5742e-02,  5.2931e-01],
#         [ 2.0006e-01, -4.0809e-01,  5.4375e-01],
#         [-1.8784e-01,  1.2742e-01, -5.5037e-01],
#         [-3.7811e-01, -4.4661e-01, -3.7102e-01],
#         [ 8.5449e-02,  1.8750e-01, -1.7184e-01],
#         [-2.9145e-01, -4.7472e-01, -2.9594e-01],
#         [ 5.3985e-01, -5.7166e-02,  2.2915e-01],
#         [-2.0408e-01, -3.2365e-01,  1.2394e-01],
#         [ 4.0671e-01,  2.7815e-01, -4.5224e-01],
#         [-1.7122e-01, -1.2344e-01,  2.7737e-01],
#         [-3.0876e-01, -6.7135e-01, -2.5156e-02],
#         [ 5.5943e-02, -2.9807e-02,  2.4742e-01],
#         [ 1.5911e-01, -5.3110e-01,  2.6574e-01],
#         [-1.1771e-02,  9.1098e-02, -1.8666e-01],
#         [ 1.0149e-01, -1.0748e-01, -4.6810e-01],
#         [ 2.3736e-01, -3.2327e-01, -1.4917e-02],
#         [ 2.1822e-01,  2.7498e-01, -2.1260e-01],
#         [ 8.8678e-02,  2.3149e-01,  3.0235e-01],
#         [ 5.0060e-01, -1.6139e-01, -2.1722e-01],
#         [-4.2235e-01, -1.7428e-01,  2.1604e-01],
#         [ 1.0512e-01, -3.0967e-01, -4.4836e-01],
#         [ 4.1386e-01, -1.0671e-01,  2.3909e-01],
#         [-3.4282e-01, -2.5743e-01,  1.4845e-01],
#         [ 3.6988e-01,  8.0510e-02,  2.5896e-01],
#         [ 2.7613e-01, -5.0307e-01,  6.9001e-03],
#         [ 3.0913e-01, -2.7830e-02, -5.8690e-01],
#         [ 1.4536e-01, -5.0987e-01, -2.7912e-01],
#         [-3.6681e-02, -2.0823e-01,  2.4248e-01],
#         [-2.9568e-01,  4.3802e-02,  5.2083e-01],
#         [-1.4245e-01,  2.1458e-01, -8.0099e-02],
#         [-3.1543e-02,  3.6534e-01, -1.6282e-01],
#         [-4.6629e-01,  1.2862e-01,  5.3923e-02],
#         [-5.5387e-01,  2.0793e-02,  1.8427e-01],
#         [-1.5975e-02,  4.5797e-01,  7.5040e-02],
#         [-4.3012e-03,  2.6723e-01,  4.1088e-01],
#         [ 3.8252e-01,  2.5043e-01, -4.8714e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([-0.5549,  0.2452, -0.3872,  0.4292, -0.3885, -0.3058, -0.2567, -0.1654,
#         -0.2002, -0.2534,  0.5046,  0.2089,  0.3455,  0.4646, -0.1994, -0.2333,
#          0.3698,  0.0242, -0.4556, -0.0540,  0.0688,  0.1146, -0.2387, -0.4058,
#         -0.1903,  0.2314, -0.0865, -0.1604, -0.5121,  0.2907,  0.2931, -0.0076,
#         -0.2417, -0.4053, -0.4360, -0.4643,  0.2409,  0.1942, -0.2581, -0.3488,
#          0.0896,  0.1908, -0.6561, -0.3972,  0.3677, -0.4977,  0.4286, -0.3894,
#         -0.4120, -0.5496, -0.3718,  0.5063, -0.4250, -0.2714, -0.0464,  0.1012,
#          0.1782, -0.4319, -0.4426, -0.1678,  0.2534, -0.4319, -0.1718,  0.4408,
#          0.4424,  0.3544, -0.1139, -0.4922,  0.2264, -0.2194,  0.1309,  0.0819,
#          0.5901,  0.3242,  0.1449,  0.2318,  0.3965,  0.1507, -0.1453,  0.4624,
#         -0.4706,  0.4079,  0.2755, -0.5699,  0.3576, -0.3817], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0411,  0.0393, -0.1237,  ...,  0.0618,  0.0553, -0.0659],
#         [ 0.0812, -0.0912,  0.0764,  ..., -0.0883, -0.0810, -0.2688],
#         [-0.0283, -0.0206,  0.0323,  ..., -0.0615,  0.0806,  0.0894],
#         ...,
#         [-0.0189,  0.0344, -0.0930,  ...,  0.0716,  0.0712, -0.0378],
#         [ 0.0858,  0.0551,  0.0899,  ...,  0.0489,  0.0097, -0.0940],
#         [-0.0792, -0.0461,  0.0707,  ...,  0.0717, -0.0207, -0.0763]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0102,  0.0100,  0.1059,  0.0794, -0.0971, -0.0997,  0.0283, -0.0284,
#         -0.0404, -0.0963,  0.0564, -0.0580, -0.0818, -0.0877,  0.1045,  0.0079,
#          0.0501, -0.0042, -0.0433,  0.0288, -0.1294,  0.0415, -0.0922,  0.0417,
#         -0.0077,  0.0007, -0.0164,  0.0771,  0.0377, -0.1064, -0.0987,  0.0771,
#          0.0992, -0.0811,  0.0832,  0.0886, -0.0893,  0.0345,  0.0355, -0.0932,
#          0.0777,  0.0896, -0.0207, -0.0468, -0.0495,  0.0059, -0.0873, -0.0652,
#         -0.0448,  0.0076,  0.0534, -0.0898,  0.0963,  0.0508, -0.0581,  0.0090,
#         -0.0731, -0.0464,  0.0580,  0.0737, -0.0328,  0.0654,  0.1240, -0.0973,
#          0.0223, -0.0019, -0.0770, -0.0410,  0.0085, -0.0132, -0.1091,  0.0504,
#         -0.0077,  0.0778,  0.0101,  0.0036, -0.0933, -0.0110,  0.0729, -0.0515,
#          0.0935,  0.0432, -0.0555,  0.1043, -0.0837,  0.0494, -0.0354, -0.0115,
#          0.0250,  0.0523, -0.0429, -0.0926,  0.0473, -0.0295, -0.0006,  0.1040,
#         -0.1030,  0.0726, -0.0475, -0.0006,  0.1069, -0.0508,  0.0737, -0.0489,
#          0.0557, -0.1087,  0.0027,  0.0469,  0.1028,  0.1107,  0.0097, -0.0647,
#         -0.0761, -0.0580, -0.0922,  0.0696, -0.0420,  0.0115, -0.0994, -0.0426,
#         -0.0355, -0.0720,  0.1162, -0.0825, -0.0402, -0.0015, -0.0030,  0.0697,
#         -0.0095, -0.0632, -0.0981,  0.0201,  0.0330,  0.0055,  0.0125,  0.0355,
#          0.0882,  0.0636,  0.0793, -0.0553,  0.0346, -0.0928, -0.0053,  0.0489,
#         -0.0219,  0.0343, -0.0959,  0.0835,  0.0276, -0.0198,  0.1300,  0.0158,
#          0.1152,  0.1349,  0.1202,  0.1139,  0.0422,  0.0060, -0.0662, -0.1575,
#         -0.0118, -0.1028, -0.0263,  0.0668,  0.0466,  0.0658, -0.0828,  0.0684,
#         -0.0255, -0.0888, -0.0470,  0.0876, -0.0956, -0.1188, -0.1177, -0.0340,
#          0.0335, -0.0369,  0.0885,  0.0545,  0.0541, -0.0609, -0.0195, -0.0752,
#         -0.0298, -0.1367, -0.0523, -0.0875,  0.0660,  0.0564, -0.0588, -0.0847,
#          0.0532,  0.0312,  0.0713, -0.0092, -0.0593,  0.0616, -0.0010, -0.0127,
#          0.0898], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0082,  0.0024, -0.0846,  ..., -0.0441, -0.0531,  0.0572],
#         [-0.0309, -0.0519,  0.0197,  ...,  0.0408, -0.0497, -0.0388],
#         [-0.0346,  0.0220, -0.0591,  ...,  0.0335, -0.0395,  0.0596],
#         ...,
#         [ 0.0594,  0.0444,  0.0342,  ...,  0.0266, -0.0787, -0.0470],
#         [ 0.0760,  0.0449, -0.0195,  ...,  0.0388, -0.0327, -0.0227],
#         [-0.0163, -0.0359, -0.0048,  ...,  0.0317,  0.0283, -0.0222]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0407,  0.0517,  0.0384, -0.0487,  0.0394, -0.0088,  0.0162, -0.0464,
#          0.0261,  0.0030, -0.0070,  0.0030,  0.0292, -0.0313,  0.0231, -0.0599,
#          0.0421, -0.0310, -0.0630, -0.0360, -0.0237,  0.0057, -0.0088, -0.0425,
#         -0.0423, -0.0273,  0.0050, -0.0335,  0.0427, -0.0640,  0.0029,  0.0718,
#         -0.0594, -0.0300,  0.0175, -0.0479,  0.0290,  0.0344,  0.0011, -0.0708,
#         -0.0593, -0.0429, -0.0054, -0.0017,  0.0367,  0.0045, -0.0365,  0.0565,
#         -0.0164, -0.0348, -0.0128,  0.0420,  0.0169,  0.0214,  0.0326,  0.0959,
#         -0.0624, -0.0688, -0.0172,  0.0151,  0.0166,  0.0617,  0.0830,  0.0399,
#         -0.0163, -0.0281, -0.0029,  0.0778,  0.0304,  0.0344, -0.0129, -0.0196,
#          0.0408,  0.0446,  0.0422, -0.0280,  0.0348,  0.0710, -0.0142,  0.0032,
#          0.0779, -0.0011, -0.1069,  0.0568,  0.0147, -0.0257, -0.0357],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0316, -0.0070, -0.0702, -0.0766, -0.1184, -0.0139,  0.0674, -0.0831,
#           0.0479,  0.0006,  0.0391, -0.0839, -0.0951,  0.1038,  0.1078,  0.0713,
#           0.0202, -0.0509, -0.0567,  0.0744,  0.0798, -0.0752, -0.0779, -0.0703,
#          -0.0699,  0.0730, -0.0652,  0.0889, -0.0094, -0.0223, -0.0115,  0.0143,
#           0.0992, -0.0687,  0.0513,  0.0149,  0.0040, -0.0564, -0.0713, -0.0695,
#           0.0761, -0.0029,  0.0803, -0.0235, -0.0608, -0.0974,  0.0401,  0.0362,
#           0.0424,  0.0651,  0.0189, -0.0361,  0.0512, -0.0692, -0.0310,  0.0846,
#          -0.0743, -0.0406,  0.0699, -0.1347, -0.0949,  0.0942,  0.0890, -0.0908,
#          -0.0291,  0.0272, -0.0846,  0.0591,  0.0742, -0.0704,  0.1035, -0.0577,
#          -0.0550,  0.0141,  0.0594,  0.0042, -0.0561,  0.0475, -0.0574, -0.0536,
#           0.0414, -0.0302, -0.0796,  0.0237,  0.0428,  0.0530,  0.1020]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0490], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 3.2871e-01,  2.6898e-01,  5.7468e-02],
#         [ 2.5778e-01,  8.8501e-02,  2.4048e-01],
#         [ 2.5637e-01,  1.3040e-01,  5.3219e-01],
#         [-3.0651e-01,  7.9911e-02, -6.4790e-01],
#         [ 5.2635e-01,  4.1950e-01, -2.5271e-01],
#         [ 1.1814e-01,  2.1640e-01, -8.5747e-02],
#         [ 2.6105e-01, -2.1145e-01,  5.1708e-01],
#         [-3.9715e-01,  2.6906e-01, -3.2654e-02],
#         [ 3.1769e-01, -6.8356e-01, -3.0824e-01],
#         [ 4.4977e-01, -2.9523e-01, -2.6803e-01],
#         [-4.1099e-01,  5.1398e-01, -1.5696e-01],
#         [ 8.4840e-02, -5.5002e-01,  6.0617e-02],
#         [ 1.8896e-01,  4.7925e-01, -1.1237e-01],
#         [-5.2464e-01, -5.4133e-01,  2.4577e-01],
#         [-1.2535e-02,  3.3904e-01,  4.3744e-01],
#         [ 3.6593e-01, -2.0036e-01, -4.5450e-01],
#         [-3.0429e-01,  1.6153e-01,  5.6210e-02],
#         [-4.4021e-03, -2.1958e-01,  2.7260e-01],
#         [ 1.5623e-01,  3.6463e-01,  3.7926e-01],
#         [ 1.0592e-01, -4.0440e-01,  5.7294e-01],
#         [-2.4927e-01,  5.3309e-01,  1.5319e-01],
#         [-3.3921e-01,  4.9197e-01,  3.6111e-01],
#         [-4.4925e-02, -1.9818e-02, -2.7950e-01],
#         [ 3.5500e-01,  5.5291e-01, -1.6360e-01],
#         [-4.8770e-01, -2.6103e-01,  5.8190e-01],
#         [-3.9900e-01, -3.2412e-01,  5.0834e-01],
#         [-4.6377e-01, -5.3170e-01,  5.7401e-02],
#         [-1.4497e-02, -5.3492e-01, -5.4522e-01],
#         [ 4.6929e-01, -4.4872e-01, -4.1446e-01],
#         [-8.1824e-02,  8.1445e-02,  3.6286e-01],
#         [-1.1411e-01,  2.6083e-01,  7.0875e-02],
#         [ 2.4323e-01, -4.8877e-01,  5.1622e-01],
#         [-5.4809e-01,  2.7598e-01,  1.2297e-01],
#         [ 4.2695e-02, -5.4644e-01, -1.5226e-01],
#         [-1.5729e-01, -5.6521e-01,  3.9754e-01],
#         [-3.1936e-01, -2.9530e-01, -2.4608e-01],
#         [ 4.9724e-02, -4.8120e-01,  5.8377e-01],
#         [-3.7218e-01,  1.9860e-01,  4.8038e-01],
#         [ 1.2279e-01,  7.2694e-03, -4.0758e-01],
#         [-3.6026e-01,  9.1022e-03, -1.3550e-01],
#         [ 7.7872e-07,  5.6584e-01, -4.6152e-01],
#         [-3.9895e-01, -6.7139e-02, -4.8775e-01],
#         [ 2.8171e-01, -4.6808e-02, -3.5956e-02],
#         [ 8.4000e-02, -3.1155e-01,  4.1534e-01],
#         [-1.9195e-01,  4.8585e-01, -5.0702e-02],
#         [ 3.4703e-01, -6.5787e-02,  1.3387e-01],
#         [ 2.5140e-01, -3.5971e-01, -9.2266e-02],
#         [-3.9539e-01,  2.6799e-01, -5.8117e-02],
#         [ 4.0500e-01,  2.6658e-01,  3.2638e-01],
#         [ 4.5794e-01,  1.9248e-01,  5.4904e-01],
#         [ 3.5493e-02, -5.5742e-02,  5.2931e-01],
#         [ 2.0006e-01, -4.0809e-01,  5.4375e-01],
#         [-1.8784e-01,  1.2742e-01, -5.5037e-01],
#         [-3.7811e-01, -4.4661e-01, -3.7102e-01],
#         [ 8.5449e-02,  1.8750e-01, -1.7184e-01],
#         [-2.9145e-01, -4.7472e-01, -2.9594e-01],
#         [ 5.3985e-01, -5.7166e-02,  2.2915e-01],
#         [-2.0408e-01, -3.2365e-01,  1.2394e-01],
#         [ 4.0671e-01,  2.7815e-01, -4.5224e-01],
#         [-1.7122e-01, -1.2344e-01,  2.7737e-01],
#         [-3.0876e-01, -6.7135e-01, -2.5156e-02],
#         [ 5.5943e-02, -2.9807e-02,  2.4742e-01],
#         [ 1.5911e-01, -5.3110e-01,  2.6574e-01],
#         [-1.1771e-02,  9.1098e-02, -1.8666e-01],
#         [ 1.0149e-01, -1.0748e-01, -4.6810e-01],
#         [ 2.3736e-01, -3.2327e-01, -1.4917e-02],
#         [ 2.1822e-01,  2.7498e-01, -2.1260e-01],
#         [ 8.8678e-02,  2.3149e-01,  3.0235e-01],
#         [ 5.0060e-01, -1.6139e-01, -2.1722e-01],
#         [-4.2235e-01, -1.7428e-01,  2.1604e-01],
#         [ 1.0512e-01, -3.0967e-01, -4.4836e-01],
#         [ 4.1386e-01, -1.0671e-01,  2.3909e-01],
#         [-3.4282e-01, -2.5743e-01,  1.4845e-01],
#         [ 3.6988e-01,  8.0510e-02,  2.5896e-01],
#         [ 2.7613e-01, -5.0307e-01,  6.9001e-03],
#         [ 3.0913e-01, -2.7830e-02, -5.8690e-01],
#         [ 1.4536e-01, -5.0987e-01, -2.7912e-01],
#         [-3.6681e-02, -2.0823e-01,  2.4248e-01],
#         [-2.9568e-01,  4.3802e-02,  5.2083e-01],
#         [-1.4245e-01,  2.1458e-01, -8.0099e-02],
#         [-3.1543e-02,  3.6534e-01, -1.6282e-01],
#         [-4.6629e-01,  1.2862e-01,  5.3923e-02],
#         [-5.5387e-01,  2.0793e-02,  1.8427e-01],
#         [-1.5975e-02,  4.5797e-01,  7.5040e-02],
#         [-4.3012e-03,  2.6723e-01,  4.1088e-01],
#         [ 3.8252e-01,  2.5043e-01, -4.8714e-01]], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([-0.5549,  0.2452, -0.3872,  0.4292, -0.3885, -0.3058, -0.2567, -0.1654,
#         -0.2002, -0.2534,  0.5046,  0.2089,  0.3455,  0.4646, -0.1994, -0.2333,
#          0.3698,  0.0242, -0.4556, -0.0540,  0.0688,  0.1146, -0.2387, -0.4058,
#         -0.1903,  0.2314, -0.0865, -0.1604, -0.5121,  0.2907,  0.2931, -0.0076,
#         -0.2417, -0.4053, -0.4360, -0.4643,  0.2409,  0.1942, -0.2581, -0.3488,
#          0.0896,  0.1908, -0.6561, -0.3972,  0.3677, -0.4977,  0.4286, -0.3894,
#         -0.4120, -0.5496, -0.3718,  0.5063, -0.4250, -0.2714, -0.0464,  0.1012,
#          0.1782, -0.4319, -0.4426, -0.1678,  0.2534, -0.4319, -0.1718,  0.4408,
#          0.4424,  0.3544, -0.1139, -0.4922,  0.2264, -0.2194,  0.1309,  0.0819,
#          0.5901,  0.3242,  0.1449,  0.2318,  0.3965,  0.1507, -0.1453,  0.4624,
#         -0.4706,  0.4079,  0.2755, -0.5699,  0.3576, -0.3817], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([[-0.0411,  0.0393, -0.1237,  ...,  0.0618,  0.0553, -0.0659],
#         [ 0.0812, -0.0912,  0.0764,  ..., -0.0883, -0.0810, -0.2688],
#         [-0.0283, -0.0206,  0.0323,  ..., -0.0615,  0.0806,  0.0894],
#         ...,
#         [-0.0189,  0.0344, -0.0930,  ...,  0.0716,  0.0712, -0.0378],
#         [ 0.0858,  0.0551,  0.0899,  ...,  0.0489,  0.0097, -0.0940],
#         [-0.0792, -0.0461,  0.0707,  ...,  0.0717, -0.0207, -0.0763]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0102,  0.0100,  0.1059,  0.0794, -0.0971, -0.0997,  0.0283, -0.0284,
#         -0.0404, -0.0963,  0.0564, -0.0580, -0.0818, -0.0877,  0.1045,  0.0079,
#          0.0501, -0.0042, -0.0433,  0.0288, -0.1294,  0.0415, -0.0922,  0.0417,
#         -0.0077,  0.0007, -0.0164,  0.0771,  0.0377, -0.1064, -0.0987,  0.0771,
#          0.0992, -0.0811,  0.0832,  0.0886, -0.0893,  0.0345,  0.0355, -0.0932,
#          0.0777,  0.0896, -0.0207, -0.0468, -0.0495,  0.0059, -0.0873, -0.0652,
#         -0.0448,  0.0076,  0.0534, -0.0898,  0.0963,  0.0508, -0.0581,  0.0090,
#         -0.0731, -0.0464,  0.0580,  0.0737, -0.0328,  0.0654,  0.1240, -0.0973,
#          0.0223, -0.0019, -0.0770, -0.0410,  0.0085, -0.0132, -0.1091,  0.0504,
#         -0.0077,  0.0778,  0.0101,  0.0036, -0.0933, -0.0110,  0.0729, -0.0515,
#          0.0935,  0.0432, -0.0555,  0.1043, -0.0837,  0.0494, -0.0354, -0.0115,
#          0.0250,  0.0523, -0.0429, -0.0926,  0.0473, -0.0295, -0.0006,  0.1040,
#         -0.1030,  0.0726, -0.0475, -0.0006,  0.1069, -0.0508,  0.0737, -0.0489,
#          0.0557, -0.1087,  0.0027,  0.0469,  0.1028,  0.1107,  0.0097, -0.0647,
#         -0.0761, -0.0580, -0.0922,  0.0696, -0.0420,  0.0115, -0.0994, -0.0426,
#         -0.0355, -0.0720,  0.1162, -0.0825, -0.0402, -0.0015, -0.0030,  0.0697,
#         -0.0095, -0.0632, -0.0981,  0.0201,  0.0330,  0.0055,  0.0125,  0.0355,
#          0.0882,  0.0636,  0.0793, -0.0553,  0.0346, -0.0928, -0.0053,  0.0489,
#         -0.0219,  0.0343, -0.0959,  0.0835,  0.0276, -0.0198,  0.1300,  0.0158,
#          0.1152,  0.1349,  0.1202,  0.1139,  0.0422,  0.0060, -0.0662, -0.1575,
#         -0.0118, -0.1028, -0.0263,  0.0668,  0.0466,  0.0658, -0.0828,  0.0684,
#         -0.0255, -0.0888, -0.0470,  0.0876, -0.0956, -0.1188, -0.1177, -0.0340,
#          0.0335, -0.0369,  0.0885,  0.0545,  0.0541, -0.0609, -0.0195, -0.0752,
#         -0.0298, -0.1367, -0.0523, -0.0875,  0.0660,  0.0564, -0.0588, -0.0847,
#          0.0532,  0.0312,  0.0713, -0.0092, -0.0593,  0.0616, -0.0010, -0.0127,
#          0.0898], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0082,  0.0024, -0.0846,  ..., -0.0441, -0.0531,  0.0572],
#         [-0.0309, -0.0519,  0.0197,  ...,  0.0408, -0.0497, -0.0388],
#         [-0.0346,  0.0220, -0.0591,  ...,  0.0335, -0.0395,  0.0596],
#         ...,
#         [ 0.0594,  0.0444,  0.0342,  ...,  0.0266, -0.0787, -0.0470],
#         [ 0.0760,  0.0449, -0.0195,  ...,  0.0388, -0.0327, -0.0227],
#         [-0.0163, -0.0359, -0.0048,  ...,  0.0317,  0.0283, -0.0222]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0407,  0.0517,  0.0384, -0.0487,  0.0394, -0.0088,  0.0162, -0.0464,
#          0.0261,  0.0030, -0.0070,  0.0030,  0.0292, -0.0313,  0.0231, -0.0599,
#          0.0421, -0.0310, -0.0630, -0.0360, -0.0237,  0.0057, -0.0088, -0.0425,
#         -0.0423, -0.0273,  0.0050, -0.0335,  0.0427, -0.0640,  0.0029,  0.0718,
#         -0.0594, -0.0300,  0.0175, -0.0479,  0.0290,  0.0344,  0.0011, -0.0708,
#         -0.0593, -0.0429, -0.0054, -0.0017,  0.0367,  0.0045, -0.0365,  0.0565,
#         -0.0164, -0.0348, -0.0128,  0.0420,  0.0169,  0.0214,  0.0326,  0.0959,
#         -0.0624, -0.0688, -0.0172,  0.0151,  0.0166,  0.0617,  0.0830,  0.0399,
#         -0.0163, -0.0281, -0.0029,  0.0778,  0.0304,  0.0344, -0.0129, -0.0196,
#          0.0408,  0.0446,  0.0422, -0.0280,  0.0348,  0.0710, -0.0142,  0.0032,
#          0.0779, -0.0011, -0.1069,  0.0568,  0.0147, -0.0257, -0.0357],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[ 0.0316, -0.0070, -0.0702, -0.0766, -0.1184, -0.0139,  0.0674, -0.0831,
#           0.0479,  0.0006,  0.0391, -0.0839, -0.0951,  0.1038,  0.1078,  0.0713,
#           0.0202, -0.0509, -0.0567,  0.0744,  0.0798, -0.0752, -0.0779, -0.0703,
#          -0.0699,  0.0730, -0.0652,  0.0889, -0.0094, -0.0223, -0.0115,  0.0143,
#           0.0992, -0.0687,  0.0513,  0.0149,  0.0040, -0.0564, -0.0713, -0.0695,
#           0.0761, -0.0029,  0.0803, -0.0235, -0.0608, -0.0974,  0.0401,  0.0362,
#           0.0424,  0.0651,  0.0189, -0.0361,  0.0512, -0.0692, -0.0310,  0.0846,
#          -0.0743, -0.0406,  0.0699, -0.1347, -0.0949,  0.0942,  0.0890, -0.0908,
#          -0.0291,  0.0272, -0.0846,  0.0591,  0.0742, -0.0704,  0.1035, -0.0577,
#          -0.0550,  0.0141,  0.0594,  0.0042, -0.0561,  0.0475, -0.0574, -0.0536,
#           0.0414, -0.0302, -0.0796,  0.0237,  0.0428,  0.0530,  0.1020]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0490], device='cuda:0', requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=86, bias=True)
#     (1): Linear(in_features=86, out_features=201, bias=True)
#     (2): Linear(in_features=201, out_features=87, bias=True)
#     (3): Linear(in_features=87, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[ 8.4823,  1.2874,  3.8433],
#         [ 6.3628,  4.5830,  6.8709],
#         [ 9.5007, 10.5686, 14.5369],
#         [ 2.7702,  9.1947,  8.4208],
#         [ 8.1549,  8.1288,  4.1824],
#         [ 2.8599,  0.6266,  5.7706],
#         [ 9.4994, 24.8554, 24.3957],
#         [ 5.9511,  6.8335,  5.0241],
#         [ 1.0827,  0.7347,  1.1826],
#         [ 3.3039,  4.2094,  4.9122],
#         [ 5.1887, 10.3858,  9.6000],
#         [ 8.6661, 16.7210, 16.3864],
#         [ 6.5375,  1.9848,  7.9297],
#         [ 9.7648, 31.8522, 29.5890],
#         [12.9340, 11.8892,  5.2417],
#         [ 9.3644,  3.6599,  3.9022],
#         [ 3.9849, 10.0192,  8.5279],
#         [ 0.7702,  1.3431,  0.9888],
#         [ 9.5696,  0.1444,  2.6998],
#         [ 7.7714, 11.4869, 16.6507]], device='cuda:0')

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5082], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.9183], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.7075], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8220], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.5902], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.8274], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.6014], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.5033], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.6891], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.3369], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.0091], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.8035], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.1756], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([6.8908], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.4217], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.2019], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7577], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.1828], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7968], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([8.7691], device='cuda:0', grad_fn=<AddBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=86, bias=True)
#     (1): Linear(in_features=86, out_features=201, bias=True)
#     (2): Linear(in_features=201, out_features=87, bias=True)
#     (3): Linear(in_features=87, out_features=1, bias=True)
#   )
# )

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5082], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.9183], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.7075], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8220], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.5902], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.8274], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.6014], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.5033], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.6891], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.3369], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.0091], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.8035], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.1756], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([6.8908], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.4217], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.2019], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7577], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.1828], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7968], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([8.7691], device='cuda:0', grad_fn=<AddBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[ 1.1821, -1.4161,  0.8185]], device='cuda:0')
# tensor([[2.0342, 2.2249, 4.1557]], device='cuda:0')
# tensor([[2.4331]], device='cuda:0', grad_fn=<AddmmBackward0>)
