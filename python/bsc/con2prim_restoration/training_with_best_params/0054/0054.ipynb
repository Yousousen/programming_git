# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# **training with found best parameters:**
# ```
# Best trial:
#   Value:  0.005391954869031906
#   Params:
#     n_layers: 2
#     n_units_0: 851
#     n_units_1: 951
#     hidden_activation: ReLU
#     output_activation: ReLU
#     loss: Huber
#     optimizer: Adagrad
#     lr: 0.0009397168155771956
#     batch_size: 160
#     n_epochs: 100
#     scheduler: CosineAnnealingLR
#     T_max: 15
# ```

# %%
# %%script echo skipping
#
# !jupyter nbconvert 0054.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on google colab,

# %%
# %%script echo skipping
#
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%script echo skipping
#
# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (2.6)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.
#
# NOTE: Some subparameters still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 2
N_UNITS_NO_OPT = [851, 951]
HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "Adagrad"
LR_NO_OPT = 0.0009397168155771956
BATCH_SIZE_NO_OPT = 160
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "CosineAnnealingLR"
#
#Best trial:
#  Value:  0.005391954869031906
#  Params: 
#    n_layers: 2
#    n_units_0: 851
#    n_units_1: 951
#    hidden_activation: ReLU
#    output_activation: ReLU
#    loss: Huber
#    optimizer: Adagrad
#    lr: 0.0009397168155771956
#    batch_size: 160
#    n_epochs: 100
#    scheduler: CosineAnnealingLR
#    T_max: 15

c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)
# Out:
# tensor([1.9220, 2.2925, 1.3112,  ..., 1.3882, 1.4931, 5.2596])

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
if ZSCORE_NORMALIZATION:
    # Computing the mean and standard deviation of each input variable from the training set
    D_mean = torch.mean(x_train[:, 0])
    D_std = torch.std(x_train[:, 0])
    Sx_mean = torch.mean(x_train[:, 1])
    Sx_std = torch.std(x_train[:, 1])
    tau_mean = torch.mean(x_train[:, 2])
    tau_std = torch.std(x_train[:, 2])

    # Applying z-score normalization to both train and test sets using the statistics from the training set
    x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
    x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
    x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
    x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
    x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
    x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
print(torch.mean(x_train[:, 0]))
print(torch.std(x_train[:, 0]))
print(torch.mean(x_train[:, 1]))
print(torch.std(x_train[:, 1]))
print(torch.mean(x_train[:, 2]))
print(torch.std(x_train[:, 2]))

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()
# Out:
# tensor(5.6259)
# tensor(3.3305)
# tensor(6.8267)
# tensor(8.0801)
# tensor(8.0068)
# tensor(7.8406)

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                    )
        else:
            scheduler = None


    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: SmoothL1Loss()
# batch_size: 160
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x7fd7f5c6c370>
# loss_name: Huber
# optimizer_name: Adagrad
# scheduler_name: CosineAnnealingLR
# n_units: [851, 951]
# n_layers: 2
# hidden_activation: ReLU()
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.0992, Test Loss: 0.0067, Train L1 Norm: 0.1672, Test L1 Norm: 0.0878, Train Linf Norm: 8.0770, Test Linf Norm: 4.5042
# Epoch 2: Train Loss: 0.0008, Test Loss: 0.0001, Train L1 Norm: 0.0236, Test L1 Norm: 0.0167, Train Linf Norm: 0.9904, Test Linf Norm: 0.7380
# Epoch 3: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0185, Test L1 Norm: 0.0245, Train Linf Norm: 1.0899, Test Linf Norm: 1.4573
# Epoch 4: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0158, Test L1 Norm: 0.0137, Train Linf Norm: 1.0689, Test Linf Norm: 0.7728
# Epoch 5: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0142, Test L1 Norm: 0.0125, Train Linf Norm: 0.9931, Test Linf Norm: 0.7431
# Epoch 6: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0114, Train Linf Norm: 0.9265, Test Linf Norm: 0.6657
# Epoch 7: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0124, Test L1 Norm: 0.0106, Train Linf Norm: 0.8701, Test Linf Norm: 0.6137
# Epoch 8: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0117, Test L1 Norm: 0.0102, Train Linf Norm: 0.8250, Test Linf Norm: 0.5967
# Epoch 9: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0113, Test L1 Norm: 0.0098, Train Linf Norm: 0.7825, Test Linf Norm: 0.5756
# Epoch 10: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0110, Test L1 Norm: 0.0097, Train Linf Norm: 0.7613, Test Linf Norm: 0.5725
# Epoch 11: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0109, Test L1 Norm: 0.0096, Train Linf Norm: 0.7578, Test Linf Norm: 0.5687
# Epoch 12: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0107, Test L1 Norm: 0.0094, Train Linf Norm: 0.7468, Test Linf Norm: 0.5480
# Epoch 13: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0106, Test L1 Norm: 0.0093, Train Linf Norm: 0.7101, Test Linf Norm: 0.5408
# Epoch 14: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0092, Train Linf Norm: 0.7421, Test Linf Norm: 0.5350
# Epoch 15: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0093, Train Linf Norm: 0.7228, Test Linf Norm: 0.5412
# Epoch 16: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0093, Train Linf Norm: 0.7405, Test Linf Norm: 0.5412
# Epoch 17: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0093, Train Linf Norm: 0.7270, Test Linf Norm: 0.5417
# Epoch 18: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0093, Train Linf Norm: 0.7449, Test Linf Norm: 0.5430
# Epoch 19: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0094, Train Linf Norm: 0.7268, Test Linf Norm: 0.5503
# Epoch 20: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0104, Test L1 Norm: 0.0092, Train Linf Norm: 0.7143, Test Linf Norm: 0.5365
# Epoch 21: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0103, Test L1 Norm: 0.0091, Train Linf Norm: 0.7226, Test Linf Norm: 0.5379
# Epoch 22: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0102, Test L1 Norm: 0.0090, Train Linf Norm: 0.7160, Test Linf Norm: 0.5294
# Epoch 23: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0100, Test L1 Norm: 0.0088, Train Linf Norm: 0.6950, Test Linf Norm: 0.5204
# Epoch 24: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0098, Test L1 Norm: 0.0087, Train Linf Norm: 0.6644, Test Linf Norm: 0.5337
# Epoch 25: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0097, Test L1 Norm: 0.0087, Train Linf Norm: 0.6875, Test Linf Norm: 0.5510
# Epoch 26: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0094, Test L1 Norm: 0.0081, Train Linf Norm: 0.6603, Test Linf Norm: 0.4866
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0081, Train Linf Norm: 0.6419, Test Linf Norm: 0.4786
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0078, Train Linf Norm: 0.6324, Test Linf Norm: 0.4607
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0107, Test L1 Norm: 0.0078, Train Linf Norm: 0.8041, Test Linf Norm: 0.4930
# Epoch 30: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0101, Test L1 Norm: 0.0076, Train Linf Norm: 0.6463, Test Linf Norm: 0.4579
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0095, Test L1 Norm: 0.0073, Train Linf Norm: 0.6646, Test Linf Norm: 0.4485
# Epoch 32: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0125, Test L1 Norm: 0.0083, Train Linf Norm: 0.7920, Test Linf Norm: 0.5189
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0074, Train Linf Norm: 0.5283, Test Linf Norm: 0.4620
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0069, Train Linf Norm: 0.5344, Test Linf Norm: 0.4112
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0071, Train Linf Norm: 0.5232, Test Linf Norm: 0.4389
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0069, Train Linf Norm: 0.4919, Test Linf Norm: 0.4306
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0071, Train Linf Norm: 0.4911, Test Linf Norm: 0.4118
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0069, Train Linf Norm: 0.4896, Test Linf Norm: 0.4277
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0066, Train Linf Norm: 0.4937, Test Linf Norm: 0.4054
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.4864, Test Linf Norm: 0.3880
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0067, Train Linf Norm: 0.4931, Test Linf Norm: 0.4099
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.4759, Test Linf Norm: 0.3957
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.4848, Test Linf Norm: 0.3918
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0066, Train Linf Norm: 0.4823, Test Linf Norm: 0.3993
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0066, Train Linf Norm: 0.4853, Test Linf Norm: 0.3996
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0066, Train Linf Norm: 0.4889, Test Linf Norm: 0.3996
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0066, Train Linf Norm: 0.4867, Test Linf Norm: 0.3989
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0066, Train Linf Norm: 0.4811, Test Linf Norm: 0.4028
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.4903, Test Linf Norm: 0.3945
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0065, Train Linf Norm: 0.4774, Test Linf Norm: 0.3932
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0064, Train Linf Norm: 0.4797, Test Linf Norm: 0.3841
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0065, Train Linf Norm: 0.4769, Test Linf Norm: 0.3897
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0063, Train Linf Norm: 0.4730, Test Linf Norm: 0.3810
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0063, Train Linf Norm: 0.5014, Test Linf Norm: 0.3749
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0062, Train Linf Norm: 0.4743, Test Linf Norm: 0.3677
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0065, Train Linf Norm: 0.4631, Test Linf Norm: 0.3929
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0064, Train Linf Norm: 0.4610, Test Linf Norm: 0.3832
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0061, Train Linf Norm: 0.4678, Test Linf Norm: 0.3541
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0059, Train Linf Norm: 0.4646, Test Linf Norm: 0.3466
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0061, Train Linf Norm: 0.6322, Test Linf Norm: 0.3534
# Epoch 61: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0087, Test L1 Norm: 0.0059, Train Linf Norm: 0.5410, Test Linf Norm: 0.3533
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0087, Train Linf Norm: 0.4814, Test Linf Norm: 0.5484
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0002, Train L1 Norm: 0.0067, Test L1 Norm: 0.0126, Train Linf Norm: 0.4708, Test Linf Norm: 0.5340
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0065, Test L1 Norm: 0.0060, Train Linf Norm: 0.4533, Test Linf Norm: 0.3765
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0058, Train Linf Norm: 0.4560, Test Linf Norm: 0.3516
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0062, Test L1 Norm: 0.0056, Train Linf Norm: 0.4421, Test Linf Norm: 0.3321
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0061, Test L1 Norm: 0.0057, Train Linf Norm: 0.4386, Test Linf Norm: 0.3452
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0060, Test L1 Norm: 0.0059, Train Linf Norm: 0.4108, Test Linf Norm: 0.3649
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0060, Test L1 Norm: 0.0056, Train Linf Norm: 0.4319, Test Linf Norm: 0.3304
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0056, Train Linf Norm: 0.4034, Test Linf Norm: 0.3290
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0056, Train Linf Norm: 0.4278, Test Linf Norm: 0.3380
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4236, Test Linf Norm: 0.3249
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4132, Test Linf Norm: 0.3261
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4177, Test Linf Norm: 0.3284
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4028, Test Linf Norm: 0.3273
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4005, Test Linf Norm: 0.3273
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4134, Test Linf Norm: 0.3270
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4112, Test Linf Norm: 0.3233
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4037, Test Linf Norm: 0.3290
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0054, Train Linf Norm: 0.4148, Test Linf Norm: 0.3182
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0056, Train Linf Norm: 0.4197, Test Linf Norm: 0.3397
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0055, Train Linf Norm: 0.4207, Test Linf Norm: 0.3226
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0055, Train Linf Norm: 0.4085, Test Linf Norm: 0.3334
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0054, Train Linf Norm: 0.4060, Test Linf Norm: 0.3126
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0053, Train Linf Norm: 0.4115, Test Linf Norm: 0.3144
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0058, Train Linf Norm: 0.3943, Test Linf Norm: 0.3632
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0056, Train Linf Norm: 0.4001, Test Linf Norm: 0.3430
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0055, Train Linf Norm: 0.4045, Test Linf Norm: 0.3378
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0062, Test L1 Norm: 0.0053, Train Linf Norm: 0.4550, Test Linf Norm: 0.3141
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0069, Test L1 Norm: 0.0150, Train Linf Norm: 0.4505, Test Linf Norm: 0.9114
# Epoch 91: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0054, Train Linf Norm: 0.6952, Test Linf Norm: 0.3413
# Epoch 92: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0062, Test L1 Norm: 0.0055, Train Linf Norm: 0.4479, Test Linf Norm: 0.3422
# Epoch 93: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0052, Train Linf Norm: 0.3876, Test Linf Norm: 0.3168
# Epoch 94: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0053, Train Linf Norm: 0.3820, Test Linf Norm: 0.3230
# Epoch 95: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0050, Train Linf Norm: 0.3804, Test Linf Norm: 0.2911
# Epoch 96: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0049, Train Linf Norm: 0.3764, Test Linf Norm: 0.2794
# Epoch 97: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0051, Train Linf Norm: 0.3818, Test Linf Norm: 0.3002
# Epoch 98: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0053, Train Linf Norm: 0.3777, Test Linf Norm: 0.3269
# Epoch 99: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0050, Train Linf Norm: 0.3614, Test Linf Norm: 0.2941
# Epoch 100: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0053, Train Linf Norm: 0.3685, Test Linf Norm: 0.3373
# Epoch 101: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0052, Train Linf Norm: 0.3708, Test Linf Norm: 0.3129
# Epoch 102: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0050, Train Linf Norm: 0.3686, Test Linf Norm: 0.3003
# Epoch 103: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0051, Train Linf Norm: 0.3686, Test Linf Norm: 0.3055
# Epoch 104: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0049, Train Linf Norm: 0.3627, Test Linf Norm: 0.2929
# Epoch 105: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3738, Test Linf Norm: 0.2967
# Epoch 106: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3684, Test Linf Norm: 0.2967
# Epoch 107: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3662, Test Linf Norm: 0.2956
# Epoch 108: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3614, Test Linf Norm: 0.2955
# Epoch 109: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0049, Train Linf Norm: 0.3682, Test Linf Norm: 0.2862
# Epoch 110: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3703, Test Linf Norm: 0.2963
# Epoch 111: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0049, Train Linf Norm: 0.3695, Test Linf Norm: 0.2934
# Epoch 112: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0050, Train Linf Norm: 0.3664, Test Linf Norm: 0.2886
# Epoch 113: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0048, Train Linf Norm: 0.3771, Test Linf Norm: 0.2707
# Epoch 114: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0054, Train Linf Norm: 0.3739, Test Linf Norm: 0.3437
# Epoch 115: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0049, Train Linf Norm: 0.3648, Test Linf Norm: 0.2824
# Epoch 116: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0048, Train Linf Norm: 0.3679, Test Linf Norm: 0.2785
# Epoch 117: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0056, Train Linf Norm: 0.3669, Test Linf Norm: 0.3492
# Epoch 118: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0053, Train Linf Norm: 0.3890, Test Linf Norm: 0.3351
# Epoch 119: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0060, Train Linf Norm: 0.4047, Test Linf Norm: 0.3325
# Epoch 120: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0064, Test L1 Norm: 0.0054, Train Linf Norm: 0.4124, Test Linf Norm: 0.3443
# Epoch 121: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0056, Train Linf Norm: 0.6387, Test Linf Norm: 0.3788
# Epoch 122: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0060, Test L1 Norm: 0.0055, Train Linf Norm: 0.4459, Test Linf Norm: 0.3225
# Epoch 123: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0050, Train Linf Norm: 0.3928, Test Linf Norm: 0.3189
# Epoch 124: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0049, Train Linf Norm: 0.3489, Test Linf Norm: 0.3061
# Epoch 125: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0046, Train Linf Norm: 0.3796, Test Linf Norm: 0.2724
# Epoch 126: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0051, Train Linf Norm: 0.3595, Test Linf Norm: 0.3155
# Epoch 127: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0048, Train Linf Norm: 0.3616, Test Linf Norm: 0.2961
# Epoch 128: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0047, Train Linf Norm: 0.3698, Test Linf Norm: 0.2859
# Epoch 129: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0049, Train Linf Norm: 0.3491, Test Linf Norm: 0.3041
# Epoch 130: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3371, Test Linf Norm: 0.2890
# Epoch 131: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3446, Test Linf Norm: 0.2836
# Epoch 132: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0045, Train Linf Norm: 0.3505, Test Linf Norm: 0.2703
# Epoch 133: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3560, Test Linf Norm: 0.2861
# Epoch 134: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0048, Train Linf Norm: 0.3515, Test Linf Norm: 0.2931
# Epoch 135: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3546, Test Linf Norm: 0.2862
# Epoch 136: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3472, Test Linf Norm: 0.2862
# Epoch 137: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0046, Train Linf Norm: 0.3502, Test Linf Norm: 0.2849
# Epoch 138: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0046, Train Linf Norm: 0.3419, Test Linf Norm: 0.2820
# Epoch 139: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0046, Train Linf Norm: 0.3558, Test Linf Norm: 0.2747
# Epoch 140: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0047, Train Linf Norm: 0.3589, Test Linf Norm: 0.2928
# Epoch 141: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0046, Train Linf Norm: 0.3591, Test Linf Norm: 0.2801
# Epoch 142: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0048, Train Linf Norm: 0.3589, Test Linf Norm: 0.2960
# Epoch 143: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0045, Train Linf Norm: 0.3497, Test Linf Norm: 0.2650
# Epoch 144: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0050, Train Linf Norm: 0.3499, Test Linf Norm: 0.3225
# Epoch 145: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0048, Train Linf Norm: 0.3544, Test Linf Norm: 0.3107
# Epoch 146: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0048, Train Linf Norm: 0.3662, Test Linf Norm: 0.3129
# Epoch 147: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0045, Train Linf Norm: 0.3658, Test Linf Norm: 0.2623
# Epoch 148: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0051, Train Linf Norm: 0.4048, Test Linf Norm: 0.3324
# Epoch 149: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0045, Train Linf Norm: 0.3469, Test Linf Norm: 0.2583
# Epoch 150: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0132, Test L1 Norm: 0.0067, Train Linf Norm: 1.2817, Test Linf Norm: 0.4170
# Epoch 151: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0051, Train Linf Norm: 0.3857, Test Linf Norm: 0.3246
# Epoch 152: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0048, Train Linf Norm: 0.3445, Test Linf Norm: 0.3257
# Epoch 153: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0048, Train Linf Norm: 0.3504, Test Linf Norm: 0.2916
# Epoch 154: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0046, Train Linf Norm: 0.3479, Test Linf Norm: 0.2786
# Epoch 155: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0049, Train Linf Norm: 0.3350, Test Linf Norm: 0.3201
# Epoch 156: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0049, Train Linf Norm: 0.3346, Test Linf Norm: 0.3301
# Epoch 157: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0044, Train Linf Norm: 0.3361, Test Linf Norm: 0.2747
# Epoch 158: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0043, Train Linf Norm: 0.3162, Test Linf Norm: 0.2632
# Epoch 159: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3253, Test Linf Norm: 0.2788
# Epoch 160: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3260, Test Linf Norm: 0.2749
# Epoch 161: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3353, Test Linf Norm: 0.2804
# Epoch 162: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3425, Test Linf Norm: 0.2810
# Epoch 163: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3329, Test Linf Norm: 0.2873
# Epoch 164: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3409, Test Linf Norm: 0.2861
# Epoch 165: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3345, Test Linf Norm: 0.2846
# Epoch 166: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3292, Test Linf Norm: 0.2846
# Epoch 167: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3393, Test Linf Norm: 0.2858
# Epoch 168: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3309, Test Linf Norm: 0.2913
# Epoch 169: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3322, Test Linf Norm: 0.2768
# Epoch 170: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3257, Test Linf Norm: 0.2891
# Epoch 171: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3338, Test Linf Norm: 0.2775
# Epoch 172: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3379, Test Linf Norm: 0.2815
# Epoch 173: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3414, Test Linf Norm: 0.2798
# Epoch 174: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3327, Test Linf Norm: 0.2939
# Epoch 175: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3442, Test Linf Norm: 0.2907
# Epoch 176: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0045, Train Linf Norm: 0.3381, Test Linf Norm: 0.2983
# Epoch 177: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0045, Train Linf Norm: 0.3312, Test Linf Norm: 0.2955
# Epoch 178: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0048, Train Linf Norm: 0.3430, Test Linf Norm: 0.3156
# Epoch 179: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0047, Test L1 Norm: 0.0054, Train Linf Norm: 0.3271, Test Linf Norm: 0.3635
# Epoch 180: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0045, Train Linf Norm: 0.3594, Test Linf Norm: 0.3006
# Epoch 181: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0053, Test L1 Norm: 0.0046, Train Linf Norm: 0.3590, Test Linf Norm: 0.2984
# Epoch 182: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0063, Train Linf Norm: 0.3249, Test Linf Norm: 0.4143
# Epoch 183: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0043, Train Linf Norm: 0.3576, Test Linf Norm: 0.2677
# Epoch 184: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0043, Train Linf Norm: 0.3316, Test Linf Norm: 0.2619
# Epoch 185: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0046, Train Linf Norm: 0.3362, Test Linf Norm: 0.3099
# Epoch 186: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3401, Test Linf Norm: 0.2931
# Epoch 187: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0046, Train Linf Norm: 0.3397, Test Linf Norm: 0.3103
# Epoch 188: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3325, Test Linf Norm: 0.2681
# Epoch 189: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0043, Train Linf Norm: 0.3308, Test Linf Norm: 0.2784
# Epoch 190: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3216, Test Linf Norm: 0.2615
# Epoch 191: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0044, Train Linf Norm: 0.3263, Test Linf Norm: 0.2959
# Epoch 192: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0044, Train Linf Norm: 0.3205, Test Linf Norm: 0.2961
# Epoch 193: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3303, Test Linf Norm: 0.2737
# Epoch 194: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3295, Test Linf Norm: 0.2757
# Epoch 195: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3299, Test Linf Norm: 0.2761
# Epoch 196: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3190, Test Linf Norm: 0.2761
# Epoch 197: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0043, Train Linf Norm: 0.3319, Test Linf Norm: 0.2779
# Epoch 198: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3326, Test Linf Norm: 0.2759
# Epoch 199: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0044, Train Linf Norm: 0.3265, Test Linf Norm: 0.2936
# Epoch 200: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0043, Train Linf Norm: 0.3316, Test Linf Norm: 0.2803
# Epoch 201: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3294, Test Linf Norm: 0.2702
# Epoch 202: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0043, Train Linf Norm: 0.3368, Test Linf Norm: 0.2795
# Epoch 203: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3383, Test Linf Norm: 0.2690
# Epoch 204: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0042, Train Linf Norm: 0.3154, Test Linf Norm: 0.2612
# Epoch 205: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0043, Train Linf Norm: 0.3271, Test Linf Norm: 0.2827
# Epoch 206: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0043, Train Linf Norm: 0.3167, Test Linf Norm: 0.2787
# Epoch 207: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0046, Train Linf Norm: 0.3356, Test Linf Norm: 0.3199
# Epoch 208: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3276, Test Linf Norm: 0.2668
# Epoch 209: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0045, Train Linf Norm: 0.3147, Test Linf Norm: 0.3013
# Epoch 210: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0046, Train Linf Norm: 0.3447, Test Linf Norm: 0.3127
# Epoch 211: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0045, Train Linf Norm: 0.3372, Test Linf Norm: 0.2967
# Epoch 212: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0055, Train Linf Norm: 0.4017, Test Linf Norm: 0.3863
# Epoch 213: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0044, Train Linf Norm: 0.3325, Test Linf Norm: 0.2802
# Epoch 214: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0044, Train Linf Norm: 0.3335, Test Linf Norm: 0.2993
# Epoch 215: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3120, Test Linf Norm: 0.2871
# Epoch 216: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3167, Test Linf Norm: 0.2833
# Epoch 217: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0047, Train Linf Norm: 0.3180, Test Linf Norm: 0.3249
# Epoch 218: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0044, Train Linf Norm: 0.3266, Test Linf Norm: 0.3039
# Epoch 219: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3193, Test Linf Norm: 0.2859
# Epoch 220: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3184, Test Linf Norm: 0.2827
# Epoch 221: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0043, Train Linf Norm: 0.3086, Test Linf Norm: 0.2916
# Epoch 222: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0044, Train Linf Norm: 0.3204, Test Linf Norm: 0.2952
# Epoch 223: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0042, Train Linf Norm: 0.3116, Test Linf Norm: 0.2792
# Epoch 224: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3193, Test Linf Norm: 0.2858
# Epoch 225: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3163, Test Linf Norm: 0.2865
# Epoch 226: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0043, Train Linf Norm: 0.3184, Test Linf Norm: 0.2865
# Epoch 227: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3133, Test Linf Norm: 0.2871
# Epoch 228: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3124, Test Linf Norm: 0.2859
# Epoch 229: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3113, Test Linf Norm: 0.2868
# Epoch 230: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0042, Train Linf Norm: 0.3158, Test Linf Norm: 0.2761
# Epoch 231: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0044, Train Linf Norm: 0.3176, Test Linf Norm: 0.2958
# Epoch 232: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0043, Train Linf Norm: 0.3128, Test Linf Norm: 0.2933
# Epoch 233: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0044, Train Linf Norm: 0.3290, Test Linf Norm: 0.2963
# Epoch 234: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0044, Train Linf Norm: 0.3278, Test Linf Norm: 0.3135
# Epoch 235: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0045, Train Linf Norm: 0.3109, Test Linf Norm: 0.3109
# Epoch 236: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0046, Train Linf Norm: 0.3063, Test Linf Norm: 0.3153
# Epoch 237: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3232, Test Linf Norm: 0.3012
# Epoch 238: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0043, Train Linf Norm: 0.3430, Test Linf Norm: 0.2746
# Epoch 239: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0045, Train Linf Norm: 0.3358, Test Linf Norm: 0.2885
# Epoch 240: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0054, Train Linf Norm: 0.3130, Test Linf Norm: 0.3678
# Epoch 241: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0051, Test L1 Norm: 0.0057, Train Linf Norm: 0.3786, Test Linf Norm: 0.3711
# Epoch 242: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0049, Test L1 Norm: 0.0045, Train Linf Norm: 0.3680, Test Linf Norm: 0.3188
# Epoch 243: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0047, Train Linf Norm: 0.3466, Test Linf Norm: 0.3154
# Epoch 244: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0050, Train Linf Norm: 0.2935, Test Linf Norm: 0.3351
# Epoch 245: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0041, Train Linf Norm: 0.3218, Test Linf Norm: 0.2654
# Epoch 246: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0044, Train Linf Norm: 0.3131, Test Linf Norm: 0.3022
# Epoch 247: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0045, Train Linf Norm: 0.2965, Test Linf Norm: 0.2996
# Epoch 248: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0045, Train Linf Norm: 0.3212, Test Linf Norm: 0.3216
# Epoch 249: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0047, Train Linf Norm: 0.3059, Test Linf Norm: 0.3252
# Epoch 250: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0042, Train Linf Norm: 0.3138, Test Linf Norm: 0.2886
# Epoch 251: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0042, Train Linf Norm: 0.3050, Test Linf Norm: 0.2837
# Epoch 252: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0044, Train Linf Norm: 0.3111, Test Linf Norm: 0.3047
# Epoch 253: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3127, Test Linf Norm: 0.2897
# Epoch 254: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3061, Test Linf Norm: 0.2996
# Epoch 255: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3090, Test Linf Norm: 0.2988
# Epoch 256: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3096, Test Linf Norm: 0.2988
# Epoch 257: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3105, Test Linf Norm: 0.2991
# Epoch 258: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0044, Train Linf Norm: 0.3021, Test Linf Norm: 0.3027
# Epoch 259: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0044, Train Linf Norm: 0.3153, Test Linf Norm: 0.3078
# Epoch 260: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3151, Test Linf Norm: 0.2931
# Epoch 261: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0044, Train Linf Norm: 0.3122, Test Linf Norm: 0.3092
# Epoch 262: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0042, Train Linf Norm: 0.3103, Test Linf Norm: 0.2810
# Epoch 263: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3002, Test Linf Norm: 0.2981
# Epoch 264: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0047, Train Linf Norm: 0.3168, Test Linf Norm: 0.3337
# Epoch 265: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.2851, Test Linf Norm: 0.3076
# Epoch 266: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0049, Train Linf Norm: 0.2988, Test Linf Norm: 0.3497
# Epoch 267: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0042, Train Linf Norm: 0.2964, Test Linf Norm: 0.2702
# Epoch 268: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0046, Train Linf Norm: 0.3481, Test Linf Norm: 0.3185
# Epoch 269: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0046, Train Linf Norm: 0.3403, Test Linf Norm: 0.3267
# Epoch 270: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0054, Train Linf Norm: 0.3387, Test Linf Norm: 0.3599
# Epoch 271: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0047, Train Linf Norm: 0.4119, Test Linf Norm: 0.3007
# Epoch 272: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0052, Test L1 Norm: 0.0080, Train Linf Norm: 0.4195, Test Linf Norm: 0.5162
# Epoch 273: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0049, Train Linf Norm: 0.3434, Test Linf Norm: 0.3256
# Epoch 274: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.2806, Test Linf Norm: 0.3018
# Epoch 275: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0046, Train Linf Norm: 0.2932, Test Linf Norm: 0.3431
# Epoch 276: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0047, Train Linf Norm: 0.3066, Test Linf Norm: 0.3357
# Epoch 277: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0045, Train Linf Norm: 0.2841, Test Linf Norm: 0.3033
# Epoch 278: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0041, Train Linf Norm: 0.3082, Test Linf Norm: 0.2754
# Epoch 279: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3032, Test Linf Norm: 0.2965
# Epoch 280: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3098, Test Linf Norm: 0.2879
# Epoch 281: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3073, Test Linf Norm: 0.2938
# Epoch 282: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3039, Test Linf Norm: 0.3024
# Epoch 283: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.2992, Test Linf Norm: 0.2963
# Epoch 284: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3046, Test Linf Norm: 0.2949
# Epoch 285: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3015, Test Linf Norm: 0.2938
# Epoch 286: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3043, Test Linf Norm: 0.2938
# Epoch 287: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.2972, Test Linf Norm: 0.2936
# Epoch 288: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3021, Test Linf Norm: 0.2902
# Epoch 289: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3061, Test Linf Norm: 0.2999
# Epoch 290: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3042, Test Linf Norm: 0.2937
# Epoch 291: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3031, Test Linf Norm: 0.2994
# Epoch 292: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0041, Train Linf Norm: 0.2990, Test Linf Norm: 0.2883
# Epoch 293: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.3021, Test Linf Norm: 0.3052
# Epoch 294: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.2991, Test Linf Norm: 0.2930
# Epoch 295: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.2913, Test Linf Norm: 0.2837
# Epoch 296: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0041, Train Linf Norm: 0.3049, Test Linf Norm: 0.2659
# Epoch 297: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0048, Train Linf Norm: 0.3065, Test Linf Norm: 0.3417
# Epoch 298: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.2919, Test Linf Norm: 0.3055
# Epoch 299: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0043, Train Linf Norm: 0.3156, Test Linf Norm: 0.2944
# Epoch 300: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0046, Train Linf Norm: 0.2917, Test Linf Norm: 0.3336
# Epoch 301: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0040, Train Linf Norm: 0.3409, Test Linf Norm: 0.2682
# Epoch 302: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3333, Test Linf Norm: 0.2763
# Epoch 303: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0046, Train Linf Norm: 0.3226, Test Linf Norm: 0.3193
# Epoch 304: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2873, Test Linf Norm: 0.2975
# Epoch 305: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0046, Train Linf Norm: 0.3033, Test Linf Norm: 0.3257
# Epoch 306: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.2792, Test Linf Norm: 0.2833
# Epoch 307: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3105, Test Linf Norm: 0.2964
# Epoch 308: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.3055, Test Linf Norm: 0.3098
# Epoch 309: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2963, Test Linf Norm: 0.3045
# Epoch 310: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.3086, Test Linf Norm: 0.2978
# Epoch 311: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0044, Train Linf Norm: 0.2956, Test Linf Norm: 0.3139
# Epoch 312: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2960, Test Linf Norm: 0.2803
# Epoch 313: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0044, Train Linf Norm: 0.2993, Test Linf Norm: 0.3079
# Epoch 314: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3006, Test Linf Norm: 0.3011
# Epoch 315: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2984, Test Linf Norm: 0.3002
# Epoch 316: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3018, Test Linf Norm: 0.3002
# Epoch 317: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2966, Test Linf Norm: 0.2994
# Epoch 318: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3027, Test Linf Norm: 0.2996
# Epoch 319: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.3028, Test Linf Norm: 0.2942
# Epoch 320: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3027, Test Linf Norm: 0.2977
# Epoch 321: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0044, Train Linf Norm: 0.3021, Test Linf Norm: 0.3153
# Epoch 322: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0045, Train Linf Norm: 0.3008, Test Linf Norm: 0.3128
# Epoch 323: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3033, Test Linf Norm: 0.3003
# Epoch 324: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0040, Train Linf Norm: 0.3045, Test Linf Norm: 0.2628
# Epoch 325: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0043, Train Linf Norm: 0.3057, Test Linf Norm: 0.2997
# Epoch 326: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.3007, Test Linf Norm: 0.2816
# Epoch 327: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0043, Train Linf Norm: 0.3185, Test Linf Norm: 0.3059
# Epoch 328: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.2992, Test Linf Norm: 0.2819
# Epoch 329: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0042, Train Linf Norm: 0.3179, Test Linf Norm: 0.2980
# Epoch 330: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0045, Train Linf Norm: 0.3701, Test Linf Norm: 0.2924
# Epoch 331: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0050, Train Linf Norm: 0.3918, Test Linf Norm: 0.3350
# Epoch 332: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0044, Test L1 Norm: 0.0045, Train Linf Norm: 0.3088, Test Linf Norm: 0.3409
# Epoch 333: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0042, Test L1 Norm: 0.0050, Train Linf Norm: 0.3347, Test Linf Norm: 0.3474
# Epoch 334: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2873, Test Linf Norm: 0.3069
# Epoch 335: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0047, Train Linf Norm: 0.3041, Test Linf Norm: 0.3243
# Epoch 336: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0044, Train Linf Norm: 0.3168, Test Linf Norm: 0.3107
# Epoch 337: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.3146, Test Linf Norm: 0.2870
# Epoch 338: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2975, Test Linf Norm: 0.2895
# Epoch 339: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3098, Test Linf Norm: 0.3001
# Epoch 340: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3103, Test Linf Norm: 0.2999
# Epoch 341: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3082, Test Linf Norm: 0.3013
# Epoch 342: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3032, Test Linf Norm: 0.3052
# Epoch 343: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0044, Train Linf Norm: 0.2976, Test Linf Norm: 0.3076
# Epoch 344: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2922, Test Linf Norm: 0.2955
# Epoch 345: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.3045, Test Linf Norm: 0.2968
# Epoch 346: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.3003, Test Linf Norm: 0.2968
# Epoch 347: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2964, Test Linf Norm: 0.2970
# Epoch 348: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2969, Test Linf Norm: 0.2950
# Epoch 349: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.2976, Test Linf Norm: 0.3021
# Epoch 350: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.2976, Test Linf Norm: 0.2831
# Epoch 351: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2927, Test Linf Norm: 0.2896
# Epoch 352: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0040, Train Linf Norm: 0.2994, Test Linf Norm: 0.2736
# Epoch 353: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.3030, Test Linf Norm: 0.2838
# Epoch 354: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3051, Test Linf Norm: 0.2982
# Epoch 355: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0043, Train Linf Norm: 0.2914, Test Linf Norm: 0.3121
# Epoch 356: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0041, Train Linf Norm: 0.3182, Test Linf Norm: 0.2819
# Epoch 357: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0042, Train Linf Norm: 0.3236, Test Linf Norm: 0.2926
# Epoch 358: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0043, Train Linf Norm: 0.3052, Test Linf Norm: 0.2976
# Epoch 359: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0042, Train Linf Norm: 0.2876, Test Linf Norm: 0.2881
# Epoch 360: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0045, Test L1 Norm: 0.0042, Train Linf Norm: 0.3469, Test Linf Norm: 0.2807
# Epoch 361: Train Loss: 0.0000, Test Loss: 0.0002, Train L1 Norm: 0.0044, Test L1 Norm: 0.0183, Train Linf Norm: 0.3130, Test Linf Norm: 1.2043
# Epoch 362: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0045, Train Linf Norm: 0.3526, Test Linf Norm: 0.3124
# Epoch 363: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0058, Train Linf Norm: 0.3096, Test Linf Norm: 0.4020
# Epoch 364: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0040, Train Linf Norm: 0.3291, Test Linf Norm: 0.2675
# Epoch 365: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0041, Train Linf Norm: 0.2790, Test Linf Norm: 0.2965
# Epoch 366: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0045, Train Linf Norm: 0.3142, Test Linf Norm: 0.3268
# Epoch 367: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0043, Train Linf Norm: 0.2911, Test Linf Norm: 0.3056
# Epoch 368: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0046, Train Linf Norm: 0.3056, Test Linf Norm: 0.3264
# Epoch 369: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0040, Train Linf Norm: 0.3028, Test Linf Norm: 0.2809
# Epoch 370: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.3047, Test Linf Norm: 0.2910
# Epoch 371: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2982, Test Linf Norm: 0.2904
# Epoch 372: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2993, Test Linf Norm: 0.2961
# Epoch 373: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.3026, Test Linf Norm: 0.2987
# Epoch 374: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.2966, Test Linf Norm: 0.2906
# Epoch 375: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.2974, Test Linf Norm: 0.2901
# Epoch 376: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.2675, Test Linf Norm: 0.2901
# Epoch 377: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.3037, Test Linf Norm: 0.2897
# Epoch 378: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2971, Test Linf Norm: 0.2915
# Epoch 379: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2956, Test Linf Norm: 0.2930
# Epoch 380: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.3014, Test Linf Norm: 0.2840
# Epoch 381: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0040, Train Linf Norm: 0.2981, Test Linf Norm: 0.2850
# Epoch 382: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.3015, Test Linf Norm: 0.2918
# Epoch 383: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.3042, Test Linf Norm: 0.2887
# Epoch 384: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0041, Train Linf Norm: 0.3043, Test Linf Norm: 0.2829
# Epoch 385: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0040, Train Linf Norm: 0.3056, Test Linf Norm: 0.2716
# Epoch 386: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0048, Train Linf Norm: 0.2799, Test Linf Norm: 0.3506
# Epoch 387: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0042, Train Linf Norm: 0.2851, Test Linf Norm: 0.2983
# Epoch 388: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0041, Test L1 Norm: 0.0039, Train Linf Norm: 0.3332, Test Linf Norm: 0.2609
# Epoch 389: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0040, Test L1 Norm: 0.0050, Train Linf Norm: 0.3125, Test Linf Norm: 0.3529
# Epoch 390: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0048, Test L1 Norm: 0.0040, Train Linf Norm: 0.3743, Test Linf Norm: 0.2889
# Epoch 391: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0050, Test L1 Norm: 0.0043, Train Linf Norm: 0.3085, Test Linf Norm: 0.2897
# Epoch 392: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0046, Test L1 Norm: 0.0041, Train Linf Norm: 0.3767, Test Linf Norm: 0.3012
# Epoch 393: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0043, Test L1 Norm: 0.0043, Train Linf Norm: 0.3518, Test Linf Norm: 0.3072
# Epoch 394: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0039, Test L1 Norm: 0.0045, Train Linf Norm: 0.3149, Test Linf Norm: 0.3023
# Epoch 395: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0040, Train Linf Norm: 0.2944, Test Linf Norm: 0.2814
# Epoch 396: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0037, Test L1 Norm: 0.0038, Train Linf Norm: 0.2885, Test Linf Norm: 0.2704
# Epoch 397: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0041, Train Linf Norm: 0.2999, Test Linf Norm: 0.2767
# Epoch 398: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0039, Train Linf Norm: 0.2959, Test Linf Norm: 0.2824
# Epoch 399: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0038, Train Linf Norm: 0.2968, Test Linf Norm: 0.2668
# Epoch 400: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0038, Test L1 Norm: 0.0039, Train Linf Norm: 0.3053, Test Linf Norm: 0.2771

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration/0054" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
optimizer_loaded_state_dict = torch.load("optimizer.pth")
if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
scheduler_loaded_state_dict = torch.load("scheduler.pth")
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded
# Out:
# 160
# 400
# 'Huber'
# 'Adagrad'
# 'CosineAnnealingLR'
# [851, 951]
# 2
# 'ReLU'
# 'ReLU'
# 0.0009397168155771956
# ReLU()
# ReLU()
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=851, bias=True)
#     (1): Linear(in_features=851, out_features=951, bias=True)
#     (2): Linear(in_features=951, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation', ReLU()),
#               ('output_activation', ReLU()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=3, out_features=851, bias=True)
#                  (1): Linear(in_features=851, out_features=951, bias=True)
#                  (2): Linear(in_features=951, out_features=1, bias=True)
#                ))]),
#  'n_layers': 2,
#  'n_units': [851, 951]}
# SmoothL1Loss()
# Adagrad (
# Parameter Group 0
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     initial_accumulator_value: 0
#     initial_lr: 0.0009397168155771956
#     lr: 0.00023492920389429358
#     lr_decay: 0
#     maximize: False
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.0009397168155771956,
#   'lr_decay': 0,
#   'eps': 1e-10,
#   'weight_decay': 0,
#   'initial_accumulator_value': 0,
#   'foreach': None,
#   'maximize': False,
#   'differentiable': False},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#Adagrad.zero_grad',
#  'state': defaultdict(dict,
#              {Parameter containing:
#               tensor([[ 0.0218,  0.5239, -0.1728],
#                       [ 0.2383, -0.2804,  0.0983],
#                       [-0.5354, -0.5441,  0.0681],
#                       ...,
#                       [ 0.1954,  0.5206, -0.2022],
#                       [ 0.4110, -0.0352, -0.0605],
#                       [-0.2288, -0.1308,  0.2053]], requires_grad=True): {'step': tensor(200000.),
#                'sum': tensor([[8.7298e-03, 3.2299e-02, 3.1885e-02],
#                        [2.8616e-03, 9.2256e-04, 4.1656e-03],
#                        [2.3534e-11, 9.4112e-12, 4.6860e-11],
#                        ...,
#                        [2.3651e-02, 9.1967e-02, 8.7568e-02],
#                        [2.3396e-01, 6.1358e-01, 7.1558e-01],
#                        [1.5872e-02, 4.2962e-02, 8.8192e-02]])},
#               Parameter containing:
#               tensor([-0.5563, -0.3818,  0.1068, -0.0460,  0.4071,  0.4021,  0.3479, -0.3041,
#                        0.2244,  0.0718, -0.0049, -0.2536, -0.4152, -0.0226,  0.1733,  0.4650,
#                        0.2917,  0.0442, -0.4351,  0.5098,  0.3299, -0.4532,  0.1896,  0.2639,
#                       -0.3345,  0.0337,  0.1326,  0.4005, -0.5640, -0.1094,  0.0241, -0.3049,
#                       -0.1328,  0.5232, -0.5129, -0.1281,  0.2191,  0.2618,  0.4820, -0.0530,
#                       -0.4718,  0.1786,  0.2077,  0.0274, -0.1160, -0.5413, -0.0825,  0.1859,
#                        0.3271, -0.1032, -0.0975, -0.1710, -0.3692,  0.5535, -0.5657,  0.2642,
#                       -0.1752, -0.5310, -0.1825,  0.2438,  0.5516, -0.0945,  0.3723,  0.5589,
#                        0.1902,  0.4184,  0.1350, -0.3173, -0.1333,  0.2774,  0.2044,  0.0776,
#                        0.0139, -0.5239, -0.0249,  0.4041, -0.4692, -0.5597,  0.1387,  0.5323,
#                        0.3524, -0.2864,  0.2370, -0.5358,  0.3837, -0.0375, -0.3328, -0.4398,
#                        0.0064, -0.1513,  0.2043, -0.4391, -0.2068, -0.1510,  0.3204,  0.0853,
#                        0.0098, -0.2013,  0.2621,  0.1222, -0.3359, -0.0070, -0.4877,  0.3599,
#                       -0.2800, -0.4207,  0.0555,  0.1891,  0.1068, -0.0244,  0.1765,  0.5451,
#                        0.0250, -0.1616,  0.5709, -0.2075, -0.4208, -0.1544,  0.1088,  0.1256,
#                       -0.2561, -0.4465, -0.4058,  0.2083, -0.2983,  0.2476,  0.1913,  0.0339,
#                       -0.3021, -0.5552,  0.1948, -0.1837,  0.1096, -0.5406, -0.4495,  0.2897,
#                       -0.4527, -0.0834, -0.5622, -0.2274,  0.2694, -0.3240,  0.0361,  0.5627,
#                        0.0113,  0.5348, -0.3224,  0.2911,  0.0651, -0.3556, -0.3851, -0.0883,
#                        0.5287,  0.0649,  0.5678,  0.3956, -0.0264, -0.3602, -0.1719,  0.3916,
#                        0.2902,  0.2660,  0.2513,  0.2707,  0.3691,  0.2478, -0.0632,  0.4946,
#                       -0.3357, -0.3514,  0.2720, -0.3205, -0.1096,  0.1902, -0.2575,  0.3335,
#                        0.4671, -0.2920, -0.4116, -0.1813, -0.2515, -0.5409, -0.3215, -0.4533,
#                       -0.1250, -0.2847,  0.0065,  0.0892, -0.2435, -0.0570,  0.0264,  0.0119,
#                       -0.3943, -0.2817, -0.4869, -0.5389,  0.0167,  0.3835,  0.4901, -0.5414,
#                       -0.3369,  0.2382, -0.3949, -0.4688,  0.3139, -0.4553,  0.0254,  0.2235,
#                        0.1381,  0.1164,  0.1353, -0.5466,  0.0776, -0.0498,  0.1476,  0.4691,
#                        0.5447, -0.1541,  0.5175, -0.1624, -0.1960, -0.5432, -0.1004, -0.1954,
#                       -0.4537,  0.2144, -0.0804,  0.5277, -0.0446, -0.3931, -0.4778, -0.0509,
#                       -0.4900,  0.3648, -0.5730,  0.5314, -0.0016,  0.1706,  0.4480, -0.2472,
#                        0.3155, -0.5647,  0.1631, -0.3813,  0.4342, -0.2335, -0.4539, -0.4978,
#                       -0.1959, -0.4073, -0.2859, -0.2347, -0.5524,  0.4651, -0.3802,  0.3101,
#                        0.1606, -0.5242, -0.1922, -0.1302,  0.5577, -0.4762,  0.0196,  0.3199,
#                       -0.3548, -0.2999,  0.4328, -0.1457, -0.5074,  0.3912,  0.1424, -0.1941,
#                        0.4595,  0.1089,  0.4132, -0.1810,  0.4973,  0.0821, -0.3871,  0.2595,
#                        0.2190, -0.3108,  0.1848,  0.1295, -0.4013, -0.3261,  0.1705,  0.0937,
#                        0.0455,  0.2106, -0.0514,  0.0855,  0.2760,  0.0872, -0.3460, -0.3038,
#                       -0.4683,  0.3187,  0.2963, -0.5451,  0.0681,  0.0184, -0.1454,  0.3373,
#                       -0.1443, -0.5061, -0.4523, -0.0764, -0.1249, -0.3320, -0.0576, -0.5265,
#                        0.0741, -0.2627, -0.5692, -0.4578,  0.2583,  0.4004,  0.3435, -0.1758,
#                       -0.1409, -0.3994,  0.2533,  0.1710,  0.5458,  0.1999, -0.0363, -0.1103,
#                        0.2263,  0.3637, -0.3441, -0.2158, -0.5679,  0.4839, -0.4903, -0.3259,
#                        0.0408,  0.0810, -0.2277, -0.5143, -0.1786,  0.1853, -0.2684,  0.2704,
#                       -0.2122,  0.2526,  0.4758, -0.2355, -0.3863, -0.3530,  0.1510,  0.0285,
#                        0.5541, -0.5029,  0.4235,  0.4513, -0.4660,  0.4723, -0.1924, -0.0209,
#                        0.1519,  0.0456, -0.1463, -0.1155,  0.1708,  0.1659,  0.5446, -0.1215,
#                        0.0699, -0.1254,  0.3748,  0.4411, -0.5247, -0.5375,  0.2499, -0.2903,
#                       -0.3300, -0.1417,  0.0152, -0.3560, -0.3320,  0.0902,  0.3923,  0.1607,
#                        0.3435, -0.2324,  0.0151, -0.4961,  0.4183,  0.2119,  0.2950, -0.1537,
#                       -0.2163, -0.4782,  0.4469,  0.3635,  0.3986,  0.4700, -0.2590,  0.1742,
#                        0.5015, -0.2699, -0.3319,  0.4228, -0.3116, -0.4215, -0.5356, -0.2644,
#                        0.2517, -0.0139, -0.5653,  0.3388,  0.5393,  0.1851,  0.2072, -0.3635,
#                        0.2688, -0.4578,  0.3848,  0.2408,  0.1271, -0.3380,  0.2868, -0.3859,
#                       -0.3555,  0.4604,  0.2167,  0.2341,  0.4072,  0.4555, -0.2190,  0.4435,
#                       -0.0857,  0.2777, -0.1429, -0.2649,  0.1100,  0.0847,  0.0458, -0.5088,
#                       -0.0500, -0.4431, -0.4362,  0.0353,  0.3233,  0.1995, -0.0716, -0.4822,
#                       -0.4291,  0.0276, -0.2670, -0.2340,  0.1192, -0.4347,  0.5394,  0.5226,
#                        0.0870,  0.3905,  0.5253, -0.0031, -0.3665, -0.0633, -0.3047, -0.3319,
#                        0.0076, -0.3711, -0.2283,  0.3391, -0.0397, -0.4978, -0.4102,  0.3291,
#                       -0.0849, -0.1428, -0.0420,  0.2761,  0.4503,  0.2582, -0.2524,  0.1473,
#                        0.1943,  0.3597,  0.0439,  0.0201, -0.4295,  0.0094, -0.5695, -0.3918,
#                       -0.5128,  0.0769,  0.5250, -0.2545, -0.0586, -0.1991,  0.4180,  0.5021,
#                       -0.2710,  0.0402, -0.3913, -0.1044,  0.5640, -0.1343, -0.0307, -0.5709,
#                       -0.4168,  0.5286, -0.1336, -0.3746, -0.3118, -0.4123, -0.0616, -0.4566,
#                       -0.1007,  0.2887, -0.4709, -0.4531,  0.4064, -0.5439,  0.2955, -0.4362,
#                       -0.4068,  0.3948, -0.5392,  0.1525,  0.5675,  0.1724, -0.5208, -0.3180,
#                        0.0039, -0.5210,  0.4504,  0.0697,  0.2998,  0.3256, -0.2004, -0.3629,
#                       -0.3666,  0.3179, -0.5306, -0.4801,  0.3706,  0.1290,  0.2378, -0.0448,
#                       -0.2541, -0.4762,  0.2890, -0.5395,  0.0084, -0.0185, -0.5342, -0.3863,
#                        0.2996, -0.5023,  0.3282, -0.3981, -0.2113, -0.1212, -0.1715,  0.3330,
#                        0.3368,  0.4572, -0.1721,  0.1833,  0.2932,  0.0418,  0.3771,  0.5228,
#                       -0.2561,  0.0193,  0.4089, -0.2522, -0.3781,  0.0419, -0.5688,  0.1244,
#                        0.3271,  0.5519, -0.1438,  0.3209, -0.4199,  0.0303, -0.4964,  0.3757,
#                        0.4610, -0.4880,  0.5452,  0.3394, -0.0948, -0.1607, -0.4627, -0.1787,
#                       -0.0479, -0.1698,  0.0042, -0.0063,  0.1834,  0.3442, -0.2567,  0.4695,
#                       -0.3396,  0.4853,  0.3311, -0.2432, -0.4547,  0.2416,  0.0245, -0.5721,
#                        0.5550, -0.2136, -0.5787,  0.5056,  0.1890, -0.4200, -0.4025,  0.0583,
#                       -0.0290,  0.0718,  0.2747, -0.5188, -0.4958, -0.3299, -0.3232, -0.3036,
#                        0.3807,  0.1682,  0.0994,  0.0123, -0.5050, -0.1309, -0.0862,  0.1735,
#                        0.3657, -0.2942, -0.0515,  0.1181,  0.1455, -0.4975,  0.3112,  0.2505,
#                        0.5151, -0.5502,  0.4763, -0.2466,  0.3284, -0.2087,  0.5186,  0.3113,
#                       -0.2745, -0.2228, -0.1524, -0.0358,  0.1085,  0.0812,  0.1153, -0.3129,
#                        0.4997,  0.4219,  0.3576,  0.4132,  0.5533, -0.3676, -0.3450, -0.5067,
#                        0.2507, -0.0981,  0.1846,  0.1661,  0.3873,  0.0290,  0.5322, -0.2536,
#                       -0.4673,  0.2817, -0.2455, -0.2618, -0.1829,  0.2275, -0.5077,  0.1419,
#                        0.1090,  0.1163, -0.1180, -0.2704,  0.4213,  0.2980, -0.0347, -0.4352,
#                       -0.2169, -0.1340, -0.5768,  0.4986, -0.2068, -0.4768,  0.2729,  0.0970,
#                        0.1189,  0.2046, -0.1145, -0.0626, -0.0751,  0.2430,  0.3025,  0.2358,
#                        0.0117,  0.4658,  0.1759,  0.5549, -0.4624, -0.2589,  0.0997,  0.1819,
#                       -0.0238, -0.3876,  0.3612, -0.3771, -0.3031,  0.0700,  0.1771,  0.4460,
#                       -0.4087,  0.4046, -0.3099, -0.4838,  0.4893, -0.3948,  0.3477,  0.2439,
#                       -0.3866,  0.0896,  0.4223,  0.3261,  0.3489, -0.5182,  0.0310,  0.2468,
#                       -0.1670,  0.5538,  0.1284,  0.0349,  0.0743,  0.0164,  0.4482,  0.2362,
#                       -0.0504,  0.4120,  0.4114, -0.1274, -0.5733, -0.3512,  0.3352,  0.2698,
#                        0.0953, -0.2653,  0.3472, -0.4698, -0.4871, -0.5453, -0.4955, -0.4521,
#                        0.1083,  0.0152,  0.0389, -0.4222, -0.4735,  0.1807,  0.1176, -0.4871,
#                       -0.5319,  0.5582, -0.5345, -0.3511,  0.5242, -0.3795, -0.5765, -0.3439,
#                        0.4925, -0.4835, -0.1596,  0.1842,  0.0905, -0.1338,  0.0043,  0.3293,
#                        0.5112, -0.1895, -0.1765, -0.2145, -0.0196, -0.0736,  0.3081,  0.0529,
#                        0.1012, -0.2621,  0.2177, -0.0895, -0.2004, -0.0611,  0.5219, -0.3454,
#                       -0.3419, -0.1686,  0.1687,  0.0680,  0.2299, -0.4461, -0.4278, -0.1666,
#                        0.5438,  0.2980,  0.1774,  0.3133, -0.3310,  0.2083,  0.0258,  0.0475,
#                        0.5617,  0.1726,  0.2075,  0.1302, -0.3792, -0.2439,  0.4288, -0.0509,
#                        0.4852,  0.3111,  0.2138,  0.3702,  0.5474, -0.3914,  0.4049,  0.0817,
#                       -0.0668, -0.0169, -0.2481,  0.1983,  0.4546, -0.0562, -0.0340,  0.1725,
#                       -0.1111, -0.1653, -0.5170, -0.1494, -0.3195, -0.0030,  0.4212,  0.0500,
#                        0.0888,  0.5120, -0.0623], requires_grad=True): {'step': tensor(200000.),
#                'sum': tensor([1.4081e-04, 5.7613e-05, 2.3221e-09, 0.0000e+00, 1.2988e-07, 1.0576e-07,
#                        3.3090e-05, 1.6179e-03, 6.8839e-06, 4.4604e-04, 0.0000e+00, 1.9306e-05,
#                        1.5254e-04, 1.1728e-04, 1.2673e-08, 8.6117e-07, 1.6003e-03, 1.7126e-03,
#                        0.0000e+00, 4.3761e-08, 1.9616e-03, 2.5545e-04, 6.0937e-04, 1.2691e-05,
#                        8.1133e-05, 1.3126e-04, 1.1666e-03, 8.9475e-08, 0.0000e+00, 1.4772e-04,
#                        1.9939e-03, 4.4263e-04, 3.9731e-04, 1.0724e-03, 0.0000e+00, 1.4142e-03,
#                        3.3479e-08, 4.0268e-06, 6.3308e-05, 2.2325e-03, 0.0000e+00, 2.8116e-03,
#                        5.4141e-04, 2.9656e-03, 0.0000e+00, 8.7312e-04, 3.1785e-05, 2.3096e-04,
#                        9.0255e-05, 2.1735e-04, 2.8191e-04, 3.1169e-04, 1.4472e-03, 4.7073e-03,
#                        0.0000e+00, 2.4143e-03, 9.9112e-03, 0.0000e+00, 6.1960e-04, 7.2518e-05,
#                        1.7673e-04, 0.0000e+00, 1.5441e-04, 3.2211e-03, 1.8732e-07, 8.4259e-05,
#                        2.4244e-03, 1.3084e-04, 5.1691e-04, 5.1757e-03, 5.8101e-06, 4.1537e-06,
#                        6.7770e-08, 0.0000e+00, 2.3699e-04, 6.7991e-04, 9.0496e-05, 2.0833e-03,
#                        1.2663e-03, 1.8501e-04, 1.8152e-07, 2.0334e-04, 9.0921e-05, 5.9673e-04,
#                        8.5598e-06, 7.0252e-06, 3.3047e-04, 6.0261e-05, 3.5265e-04, 4.1449e-05,
#                        7.3646e-08, 1.4176e-03, 3.4209e-03, 0.0000e+00, 1.6746e-03, 9.4082e-05,
#                        2.6513e-04, 0.0000e+00, 8.2803e-05, 6.4424e-04, 4.8453e-03, 7.3634e-04,
#                        4.9130e-04, 1.6168e-03, 1.4375e-03, 6.4370e-06, 7.4803e-07, 4.0841e-06,
#                        5.1857e-05, 3.7021e-03, 1.1343e-07, 3.7432e-04, 9.2398e-05, 1.5054e-03,
#                        2.3894e-04, 1.2897e-04, 0.0000e+00, 5.2487e-04, 7.0291e-06, 9.1712e-05,
#                        4.7829e-05, 6.7964e-04, 1.2164e-04, 1.1372e-07, 0.0000e+00, 6.3402e-07,
#                        8.5666e-09, 4.2565e-04, 0.0000e+00, 7.1512e-04, 1.9490e-07, 1.3679e-03,
#                        1.7996e-03, 0.0000e+00, 5.9694e-07, 1.6516e-04, 5.2554e-05, 2.2404e-03,
#                        3.8338e-08, 1.3022e-04, 8.8259e-07, 0.0000e+00, 2.0509e-09, 6.3584e-05,
#                        2.9093e-03, 1.9601e-03, 0.0000e+00, 1.6045e-03, 1.8199e-09, 0.0000e+00,
#                        1.0842e-03, 7.4439e-04, 4.0680e-04, 1.7121e-03, 1.1809e-07, 8.4884e-05,
#                        3.3272e-04, 8.1967e-03, 9.3189e-04, 1.4962e-05, 5.9157e-08, 8.5482e-03,
#                        8.3934e-05, 5.3830e-04, 1.8672e-03, 2.2727e-06, 1.1325e-03, 9.6566e-09,
#                        4.9831e-05, 9.2594e-07, 4.3531e-09, 7.6207e-06, 1.1794e-03, 5.1700e-03,
#                        1.2056e-02, 9.8326e-05, 1.3987e-03, 5.2415e-03, 6.5017e-05, 3.2444e-04,
#                        1.2433e-03, 7.1682e-04, 7.1350e-06, 2.3794e-04, 1.0351e-03, 1.8491e-05,
#                        2.8696e-03, 1.7757e-09, 1.0442e-03, 1.5903e-04, 8.8609e-06, 9.1450e-04,
#                        4.4056e-03, 1.2442e-03, 1.1543e-04, 1.7048e-07, 4.2635e-03, 4.3005e-04,
#                        4.2296e-04, 2.4788e-04, 3.5425e-03, 1.9759e-04, 3.3766e-03, 1.6382e-03,
#                        4.8414e-04, 1.1542e-03, 1.8574e-03, 1.7344e-04, 7.8600e-04, 4.4234e-05,
#                        2.0873e-09, 2.7082e-03, 3.5487e-05, 3.0266e-04, 4.2606e-05, 2.4121e-04,
#                        4.4542e-07, 0.0000e+00, 2.9337e-04, 1.1474e-04, 3.6567e-04, 0.0000e+00,
#                        7.7913e-03, 3.6023e-03, 5.6887e-05, 3.7886e-03, 2.8939e-03, 3.9865e-06,
#                        1.5897e-03, 2.5415e-04, 8.4916e-04, 0.0000e+00, 0.0000e+00, 6.6136e-08,
#                        1.9642e-05, 6.5224e-07, 2.7446e-04, 2.6718e-05, 1.4605e-03, 6.0349e-05,
#                        9.7832e-08, 3.5542e-04, 8.4858e-05, 3.9247e-04, 3.6524e-09, 0.0000e+00,
#                        4.3658e-03, 6.8952e-04, 1.6127e-04, 8.7078e-06, 3.6604e-03, 6.5239e-04,
#                        4.7822e-05, 3.4148e-05, 1.8979e-07, 1.4082e-03, 4.6057e-04, 9.7718e-06,
#                        8.4832e-03, 5.5944e-04, 1.3652e-08, 2.0812e-04, 1.5380e-04, 2.3476e-03,
#                        8.9915e-04, 1.9916e-03, 5.8550e-03, 0.0000e+00, 5.4327e-05, 3.7946e-04,
#                        2.5599e-03, 0.0000e+00, 4.8508e-03, 1.0048e-03, 6.5640e-05, 7.7781e-04,
#                        1.8484e-03, 3.5460e-04, 1.1144e-03, 1.0716e-07, 1.1187e-03, 0.0000e+00,
#                        9.1113e-04, 4.9151e-04, 5.7778e-08, 1.0355e-03, 5.2881e-05, 8.1508e-04,
#                        1.2120e-09, 3.1076e-04, 6.9468e-05, 3.2114e-04, 1.0021e-05, 4.6155e-04,
#                        1.0369e-03, 0.0000e+00, 0.0000e+00, 1.3895e-04, 2.0384e-03, 1.9555e-05,
#                        6.0148e-10, 1.5274e-04, 2.6706e-03, 2.1492e-04, 1.7671e-03, 6.9211e-04,
#                        0.0000e+00, 1.6246e-03, 5.4655e-04, 1.1375e-03, 9.2015e-06, 1.4541e-03,
#                        3.8419e-04, 4.2533e-03, 0.0000e+00, 0.0000e+00, 8.5519e-05, 2.3442e-03,
#                        3.5131e-07, 1.4338e-04, 0.0000e+00, 5.3133e-04, 1.2572e-07, 9.0212e-03,
#                        1.6265e-04, 2.6098e-08, 3.1999e-05, 0.0000e+00, 1.9865e-05, 2.5542e-03,
#                        0.0000e+00, 4.5243e-04, 0.0000e+00, 1.5688e-03, 9.8214e-05, 7.0133e-08,
#                        3.6776e-06, 2.4194e-06, 4.6684e-03, 4.9024e-04, 0.0000e+00, 7.9783e-05,
#                        7.1782e-07, 9.5566e-07, 6.3277e-07, 5.1121e-04, 1.0443e-06, 5.8511e-04,
#                        1.3798e-03, 0.0000e+00, 2.3610e-05, 2.4656e-06, 3.0195e-06, 2.0075e-03,
#                        9.4472e-05, 5.3201e-04, 1.7361e-03, 1.0047e-04, 0.0000e+00, 1.1018e-03,
#                        4.5350e-05, 1.1538e-03, 6.4645e-08, 2.5429e-04, 3.4489e-05, 1.7133e-03,
#                        6.8376e-06, 1.7667e-03, 9.6827e-10, 2.1269e-04, 5.0794e-04, 1.9164e-03,
#                        1.7220e-03, 2.9924e-06, 2.7636e-05, 4.3383e-04, 0.0000e+00, 8.2040e-05,
#                        1.3004e-03, 0.0000e+00, 9.0666e-06, 5.2440e-04, 9.0741e-04, 2.2720e-04,
#                        1.8513e-04, 3.3000e-06, 3.4517e-05, 7.8324e-04, 1.7994e-03, 1.8956e-07,
#                        2.4140e-04, 8.0103e-04, 2.4279e-04, 0.0000e+00, 1.3423e-05, 7.8255e-04,
#                        6.2815e-03, 1.6254e-03, 0.0000e+00, 1.0457e-04, 8.8231e-07, 1.6710e-03,
#                        1.3166e-04, 8.7485e-06, 1.3762e-06, 4.0420e-04, 6.4058e-04, 3.9603e-04,
#                        1.0307e-05, 1.9611e-03, 0.0000e+00, 2.3820e-08, 4.7772e-05, 1.6245e-08,
#                        9.1867e-03, 1.2689e-03, 7.2459e-04, 0.0000e+00, 3.6149e-03, 7.0387e-05,
#                        2.4343e-03, 2.4735e-04, 1.1517e-03, 2.2137e-04, 2.4163e-05, 3.0517e-04,
#                        3.5797e-04, 4.6454e-03, 6.6506e-04, 3.2801e-03, 1.2162e-03, 1.1468e-04,
#                        1.5787e-04, 4.7930e-04, 1.2055e-04, 2.8632e-03, 2.1620e-04, 4.5832e-04,
#                        1.2045e-09, 1.4795e-05, 6.9899e-05, 2.2840e-04, 2.1884e-05, 3.6906e-08,
#                        4.5455e-04, 3.2572e-04, 5.7474e-05, 0.0000e+00, 0.0000e+00, 3.1435e-07,
#                        2.3272e-04, 1.8428e-03, 7.0283e-04, 2.2889e-04, 2.1364e-07, 4.4251e-04,
#                        5.9438e-05, 2.0933e-03, 1.0753e-04, 2.3158e-04, 2.5366e-05, 1.5543e-03,
#                        6.3962e-04, 1.1738e-02, 5.9427e-03, 0.0000e+00, 9.6320e-05, 1.5916e-08,
#                        5.9062e-03, 7.1628e-04, 0.0000e+00, 5.3105e-04, 2.6535e-03, 3.2975e-06,
#                        4.6285e-04, 9.1556e-04, 1.6196e-03, 1.8502e-03, 9.0275e-07, 8.0862e-05,
#                        6.5755e-05, 1.5953e-03, 2.3093e-06, 2.8325e-04, 0.0000e+00, 1.1392e-10,
#                        0.0000e+00, 0.0000e+00, 4.9694e-05, 1.7568e-03, 4.8835e-04, 1.1019e-03,
#                        1.1149e-03, 0.0000e+00, 2.4702e-04, 2.3343e-04, 4.4654e-03, 6.7514e-05,
#                        6.8625e-04, 4.8250e-03, 3.4976e-04, 3.7022e-04, 2.8645e-04, 3.0509e-03,
#                        4.3631e-03, 1.6574e-03, 1.1015e-03, 1.1544e-06, 1.7080e-03, 0.0000e+00,
#                        9.7136e-05, 2.4457e-03, 3.1572e-06, 8.3453e-05, 3.1050e-03, 1.3151e-04,
#                        3.7511e-04, 5.2568e-03, 3.8429e-04, 1.8996e-04, 2.8985e-05, 1.7439e-03,
#                        4.5012e-03, 1.6505e-04, 1.0911e-06, 1.5643e-04, 0.0000e+00, 4.3742e-03,
#                        1.4216e-04, 7.1123e-04, 4.7929e-04, 4.8481e-04, 1.4864e-05, 8.4519e-04,
#                        0.0000e+00, 9.6915e-06, 4.8161e-04, 9.2819e-05, 2.2173e-04, 1.1449e-03,
#                        8.2762e-08, 2.0605e-03, 7.8316e-04, 7.6438e-05, 1.6381e-03, 1.2189e-03,
#                        1.9142e-04, 9.8773e-04, 1.2477e-04, 8.4215e-05, 2.2173e-05, 0.0000e+00,
#                        2.6973e-04, 0.0000e+00, 4.4562e-08, 3.3251e-03, 1.6462e-03, 0.0000e+00,
#                        3.7698e-05, 2.6006e-04, 2.4513e-04, 1.2984e-04, 1.0901e-02, 1.2970e-08,
#                        6.8621e-08, 3.6808e-03, 1.1067e-04, 3.9115e-04, 1.0927e-02, 5.1776e-03,
#                        2.2379e-03, 0.0000e+00, 6.2855e-03, 1.7489e-09, 6.2864e-06, 6.5216e-04,
#                        1.0620e-03, 4.1660e-04, 1.0822e-03, 2.4176e-07, 1.1792e-04, 2.1870e-04,
#                        1.2799e-04, 3.9938e-03, 1.8306e-04, 0.0000e+00, 4.2212e-04, 4.1424e-04,
#                        5.8363e-03, 1.4583e-03, 1.7972e-03, 0.0000e+00, 4.7572e-04, 7.5496e-04,
#                        7.6371e-04, 2.2984e-03, 1.3258e-04, 2.0340e-04, 3.7463e-03, 4.3817e-05,
#                        0.0000e+00, 8.9865e-08, 4.0634e-04, 3.9104e-04, 1.0925e-04, 1.1220e-04,
#                        3.9144e-04, 3.0206e-05, 3.1534e-04, 1.4820e-05, 1.6092e-04, 2.0134e-06,
#                        8.8157e-09, 1.6671e-03, 2.4296e-03, 2.5641e-07, 2.2845e-04, 1.0001e-09,
#                        1.5491e-04, 1.0179e-04, 1.5530e-04, 2.8566e-04, 3.2936e-05, 6.5273e-05,
#                        4.4959e-04, 6.9514e-04, 5.3027e-06, 3.0658e-06, 1.6760e-05, 1.7180e-08,
#                        7.9931e-05, 7.5788e-06, 7.6005e-04, 0.0000e+00, 1.1379e-03, 2.7999e-09,
#                        7.0785e-09, 5.9612e-05, 4.5240e-04, 6.2272e-08, 7.4997e-08, 1.7537e-03,
#                        5.8979e-04, 2.3721e-07, 1.3331e-04, 5.0954e-04, 7.0012e-04, 1.8149e-05,
#                        1.4126e-03, 5.5935e-04, 0.0000e+00, 0.0000e+00, 1.0865e-04, 7.7215e-04,
#                        7.0500e-03, 7.6426e-06, 1.8736e-03, 8.8048e-04, 3.6147e-08, 1.0300e-03,
#                        1.9722e-04, 0.0000e+00, 8.8544e-04, 8.1022e-05, 1.2052e-03, 1.4416e-03,
#                        1.1735e-03, 4.1505e-05, 2.4744e-03, 7.4029e-05, 2.0069e-04, 0.0000e+00,
#                        1.0236e-04, 4.7616e-07, 1.5693e-02, 0.0000e+00, 4.2137e-04, 2.1326e-08,
#                        4.8802e-04, 1.7013e-03, 6.2945e-05, 7.3925e-05, 0.0000e+00, 8.2649e-04,
#                        2.5163e-08, 6.3361e-06, 2.9832e-04, 1.1128e-03, 4.9162e-05, 0.0000e+00,
#                        0.0000e+00, 2.1920e-03, 6.6069e-05, 2.1547e-04, 4.6149e-05, 1.3826e-07,
#                        5.4728e-09, 2.7506e-04, 1.7271e-04, 4.5023e-05, 1.7647e-04, 2.6943e-05,
#                        1.3241e-03, 8.5280e-06, 1.7711e-04, 1.5906e-03, 3.4258e-08, 5.0832e-03,
#                        6.2555e-05, 1.7084e-04, 1.0466e-06, 1.1716e-04, 0.0000e+00, 2.4236e-04,
#                        1.2981e-06, 3.3798e-03, 3.5153e-05, 3.1772e-04, 1.7067e-04, 1.8209e-05,
#                        0.0000e+00, 1.0816e-03, 1.0881e-02, 3.1119e-03, 6.0254e-07, 1.0911e-04,
#                        2.4665e-05, 1.7155e-03, 1.4350e-05, 5.3157e-07, 3.0767e-07, 2.2382e-05,
#                        1.6224e-07, 0.0000e+00, 1.0332e-03, 3.6462e-04, 3.1389e-04, 4.9325e-04,
#                        4.6946e-04, 1.1800e-04, 6.8263e-10, 7.6465e-04, 8.5688e-05, 3.5159e-03,
#                        2.5666e-04, 2.5130e-05, 1.2105e-03, 1.6895e-14, 1.6944e-06, 6.1604e-06,
#                        7.7366e-05, 5.2751e-03, 8.7570e-05, 0.0000e+00, 1.4343e-04, 6.0612e-10,
#                        2.2566e-03, 7.7218e-05, 7.6755e-06, 0.0000e+00, 2.5922e-03, 8.2924e-04,
#                        1.5400e-03, 0.0000e+00, 3.0246e-05, 3.8951e-04, 1.6031e-04, 0.0000e+00,
#                        9.2195e-06, 4.2723e-07, 0.0000e+00, 0.0000e+00, 3.8677e-04, 2.6129e-06,
#                        1.0763e-03, 0.0000e+00, 3.2817e-05, 2.5600e-07, 5.8078e-03, 3.6672e-08,
#                        1.1002e-08, 7.5726e-05, 1.1052e-03, 1.4899e-03, 1.3770e-04, 6.1956e-07,
#                        3.6937e-03, 2.0853e-06, 5.1151e-05, 4.1497e-09, 1.0066e-02, 3.9790e-09,
#                        5.2402e-08, 2.9799e-03, 7.6426e-04, 4.1460e-05, 2.7139e-04, 5.9253e-04,
#                        4.7093e-07, 0.0000e+00, 1.7033e-04, 1.0394e-03, 3.6759e-06, 1.4883e-08,
#                        1.5784e-02, 3.9139e-04, 2.3126e-06, 6.3531e-04, 1.3397e-04, 2.4358e-07,
#                        5.8868e-04, 1.7153e-06, 1.7783e-05, 3.3609e-08, 4.2977e-09, 2.7479e-09,
#                        3.0434e-04, 2.5623e-03, 1.2745e-04, 9.9083e-09, 3.8380e-04, 1.5224e-05,
#                        5.5076e-09, 5.2371e-04, 1.9370e-04, 4.4424e-08, 1.9392e-04, 9.0818e-08,
#                        2.9125e-04, 1.1839e-04, 3.1728e-03, 7.7442e-04, 4.6541e-04, 1.0755e-04,
#                        2.4919e-05, 4.0816e-03, 1.4471e-04, 1.4350e-04, 9.3250e-04, 2.8080e-04,
#                        7.6601e-06, 2.1760e-04, 1.9497e-05, 0.0000e+00, 4.2125e-03, 2.6038e-04,
#                        1.3658e-08, 6.2480e-04, 4.2736e-04, 4.4357e-03, 2.8421e-04])},
#               Parameter containing:
#               tensor([[-0.0230, -0.0115,  0.0002,  ...,  0.0013, -0.0130,  0.0113],
#                       [-0.0024, -0.0300,  0.0293,  ...,  0.0189, -0.0274, -0.0156],
#                       [-0.0268, -0.0213, -0.0047,  ...,  0.0316,  0.0228, -0.0376],
#                       ...,
#                       [-0.0141,  0.0337,  0.0254,  ...,  0.0165,  0.0267, -0.0173],
#                       [ 0.0321, -0.0126, -0.0017,  ..., -0.0176,  0.0018,  0.0301],
#                       [-0.0298, -0.0318,  0.0268,  ..., -0.0003,  0.0158, -0.0206]],
#                      requires_grad=True): {'step': tensor(200000.),
#                'sum': tensor([[1.7623e-01, 6.4983e-04, 0.0000e+00,  ..., 3.1445e-01, 5.4609e-02,
#                         5.8435e-06],
#                        [5.1283e-05, 0.0000e+00, 0.0000e+00,  ..., 6.4943e-05, 2.5869e-06,
#                         0.0000e+00],
#                        [0.0000e+00, 0.0000e+00, 2.8506e-12,  ..., 3.9889e-09, 2.7451e-08,
#                         3.7384e-15],
#                        ...,
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#                         0.0000e+00],
#                        [7.0628e-06, 0.0000e+00, 3.9480e-11,  ..., 1.7111e-05, 5.3425e-06,
#                         1.5938e-12],
#                        [6.6369e-04, 1.6404e-05, 0.0000e+00,  ..., 1.2213e-03, 3.3550e-04,
#                         1.7074e-07]])},
#               Parameter containing:
#               tensor([-7.4487e-03,  1.4697e-02,  1.8189e-02, -2.1421e-02,  2.8543e-02,
#                        2.2181e-02,  1.9918e-02,  1.2793e-02,  2.5495e-02,  2.2588e-02,
#                        1.6025e-02, -8.8453e-03, -7.0436e-03, -2.3311e-03, -1.8607e-02,
#                       -9.5370e-03, -1.2128e-02,  5.1497e-03,  4.3444e-03, -2.6624e-02,
#                       -1.7092e-02, -2.6033e-02,  2.4757e-02, -1.7330e-02, -1.0334e-02,
#                       -2.2848e-02,  1.6834e-02,  7.8508e-03,  9.0624e-03, -3.1399e-02,
#                        1.1610e-02,  1.3648e-02,  1.5273e-02, -1.5813e-03, -2.5559e-03,
#                        2.6196e-02,  2.3121e-02,  5.8172e-03,  2.4086e-02,  2.1571e-02,
#                       -2.1987e-02,  2.2005e-02,  6.4230e-03, -2.7450e-02,  2.5295e-02,
#                       -2.9251e-02, -5.6616e-03, -4.9454e-03,  8.9645e-03,  3.3267e-02,
#                       -2.5601e-03, -1.5112e-02, -1.4543e-02,  1.8251e-02, -1.3628e-02,
#                       -1.7059e-02,  1.3899e-02, -1.1023e-02, -1.4225e-02,  2.5828e-02,
#                        3.0598e-02, -2.3817e-02,  1.9961e-03, -2.3506e-02, -1.3619e-02,
#                       -1.0765e-02, -1.4252e-02,  1.7503e-02, -1.6499e-02,  1.2952e-02,
#                       -2.2147e-02,  1.6597e-03, -2.8192e-02, -2.7700e-03, -3.1046e-02,
#                       -3.1575e-03,  8.0940e-03, -2.1398e-02, -2.7571e-02, -8.0228e-03,
#                       -2.2322e-02, -2.8853e-02,  3.2296e-02,  1.7179e-02,  2.2097e-02,
#                       -2.1851e-02,  2.4886e-02, -1.2286e-02,  2.6174e-02, -1.0513e-02,
#                       -2.3547e-02,  7.7160e-03, -2.8372e-02,  3.6638e-03, -3.1071e-02,
#                        1.9309e-02,  9.1188e-03, -5.5801e-04,  2.5992e-02, -1.3246e-02,
#                       -3.0926e-02,  2.7342e-02, -9.7243e-03, -1.8423e-02, -1.0431e-02,
#                       -3.0981e-02,  2.8603e-02,  2.4550e-02,  2.8717e-02, -1.0339e-02,
#                        3.2337e-02,  2.7078e-03, -8.5499e-03,  2.2176e-02,  1.2535e-04,
#                        2.8481e-02, -3.1407e-02,  2.8995e-02,  2.2638e-02,  1.9668e-03,
#                        6.7044e-03, -3.7460e-03,  1.0602e-02, -1.8741e-02,  2.7360e-02,
#                       -1.9931e-02,  4.8558e-03, -2.6093e-03,  2.1242e-03, -2.8414e-02,
#                        1.4621e-02,  2.5641e-02, -1.5654e-02,  1.2623e-02,  4.7686e-03,
#                        7.0338e-03, -2.6392e-02, -5.4601e-03,  2.2997e-02,  2.3018e-02,
#                        1.9335e-02,  8.0948e-03,  2.5668e-02, -6.2289e-03, -8.4752e-03,
#                        2.9747e-02,  1.2772e-02, -2.2460e-02, -2.4984e-02, -1.7168e-02,
#                        3.9635e-03, -2.7941e-02,  2.2669e-02,  1.8963e-02,  1.7809e-02,
#                        2.7627e-02, -1.8350e-02, -2.4096e-02, -2.0471e-02, -1.2386e-02,
#                       -3.1299e-03,  1.3877e-02, -2.5767e-02, -3.2577e-02,  4.5389e-03,
#                        1.4584e-02, -1.3493e-02,  1.6845e-02, -1.8803e-02, -3.9594e-03,
#                       -9.9400e-03, -8.1128e-03,  1.6099e-02, -1.8034e-02, -2.8062e-02,
#                       -2.2388e-02,  1.5194e-03,  5.3519e-03,  3.1750e-02,  1.0255e-02,
#                        9.8897e-03,  9.5875e-03, -1.9058e-03,  2.9927e-02,  2.6870e-02,
#                        1.7523e-02,  1.7917e-02, -3.9171e-03,  2.2548e-02, -1.1978e-02,
#                        2.7727e-02,  2.9883e-02,  1.3563e-02,  2.5921e-02, -3.0295e-02,
#                       -1.2410e-02, -1.2889e-02,  1.5802e-02, -3.2854e-02, -1.8004e-02,
#                        9.6140e-03, -2.2208e-02, -1.8487e-02, -1.9043e-02, -2.9185e-03,
#                        2.8569e-02, -2.5718e-02, -2.5499e-02, -1.0722e-02, -1.8036e-02,
#                       -1.4639e-02,  2.0938e-03, -1.8947e-02,  3.1570e-03, -1.5187e-02,
#                       -2.0791e-02, -2.2863e-02,  1.3286e-02,  3.0173e-02, -5.8598e-04,
#                        1.2169e-02,  1.6190e-02,  2.3164e-02, -1.3521e-02,  1.4877e-02,
#                       -1.0158e-02, -1.8595e-02, -1.0197e-02, -1.6373e-02, -1.9104e-02,
#                       -2.9724e-02, -1.0733e-02,  1.1409e-02,  1.2373e-02, -3.2518e-02,
#                       -8.8389e-03,  2.9270e-02,  2.4230e-02, -5.4014e-03, -5.2420e-03,
#                        3.3144e-03, -1.0760e-02, -2.9835e-02,  8.4822e-03, -1.0895e-02,
#                        2.8244e-02,  3.3336e-02, -3.9586e-03,  1.6590e-02, -1.2632e-02,
#                        2.3865e-02, -9.5998e-03, -1.0586e-03, -3.3224e-02,  2.0680e-02,
#                        1.3297e-02, -5.7036e-03, -3.4336e-03,  2.2356e-02, -1.9877e-02,
#                        1.5886e-02,  2.4603e-02,  3.1527e-02,  3.4594e-02,  9.9309e-03,
#                        5.9076e-03, -1.2528e-02, -1.2970e-03,  2.9338e-02,  9.4960e-03,
#                        1.3468e-02,  1.8524e-02, -1.4964e-02,  6.7808e-03,  2.8710e-02,
#                       -2.2431e-02, -1.2386e-02, -8.3380e-03,  2.2979e-02,  2.8676e-02,
#                       -7.5216e-03, -1.3449e-02, -7.3443e-03,  1.8731e-02, -1.1666e-02,
#                        2.9626e-02, -7.3521e-03, -2.6571e-02, -3.2595e-02, -3.1838e-02,
#                        4.8482e-04, -8.9395e-03, -1.8735e-02,  2.0895e-02, -1.2782e-02,
#                        6.1028e-03,  1.3059e-02, -2.6514e-02,  5.3324e-03, -7.0107e-03,
#                        1.9812e-02,  6.7305e-03, -3.1085e-02,  3.1996e-02,  2.1784e-02,
#                        2.7642e-02,  1.3673e-02, -3.9625e-03, -4.1565e-03, -2.3698e-02,
#                       -2.4703e-03,  3.1333e-02,  3.3898e-02,  1.5293e-03, -1.0845e-02,
#                        1.8942e-02,  1.4502e-02,  7.3257e-03,  3.2246e-02,  3.3393e-02,
#                       -2.5199e-02,  1.8149e-02,  2.4253e-03,  1.1928e-02,  1.8187e-02,
#                        1.6167e-02, -1.6975e-02,  2.6845e-02,  2.6052e-02,  3.2752e-02,
#                       -3.5029e-02, -1.7989e-03, -3.4381e-02, -2.9743e-02, -1.5064e-02,
#                       -9.2180e-03, -2.3600e-02,  3.3187e-02,  1.0983e-02, -1.4925e-03,
#                        1.4890e-02,  9.4933e-03, -1.4405e-02,  9.5131e-03, -2.2294e-03,
#                        4.0925e-03, -2.4136e-02, -1.3183e-02,  2.9010e-02,  1.3063e-02,
#                       -1.6369e-02,  2.0508e-02,  3.2785e-03, -2.7036e-02, -1.0299e-03,
#                       -1.4634e-02,  1.2499e-03, -1.2832e-02,  1.9640e-02, -2.0937e-02,
#                        3.3548e-02, -2.2105e-02, -8.0858e-03,  2.9931e-02,  3.0729e-02,
#                        5.9163e-03,  1.2845e-02, -2.2068e-02, -2.0388e-02,  3.4966e-03,
#                       -7.1744e-03, -7.0424e-03, -1.0760e-02,  2.0020e-02,  3.0121e-02,
#                       -1.6936e-02,  2.6324e-02,  2.1169e-02,  3.2512e-02,  2.9045e-02,
#                        5.5136e-03, -3.3219e-02,  2.5037e-02,  3.5655e-02, -1.3205e-02,
#                       -1.3755e-02,  1.9958e-02, -1.3748e-03, -2.8221e-02,  2.7328e-02,
#                       -1.5629e-02,  5.6525e-03, -6.6532e-03, -1.8285e-02, -3.3615e-02,
#                       -8.8677e-03, -1.3628e-02, -1.1499e-03, -2.4264e-02, -2.1307e-02,
#                       -4.3409e-03,  1.9503e-02,  2.4728e-02,  8.8560e-03,  6.9499e-06,
#                        1.2173e-02, -9.1809e-03,  1.9217e-04, -1.7174e-02,  2.6475e-02,
#                       -3.3681e-02, -1.0575e-02,  2.0488e-02, -1.5557e-02, -3.1548e-02,
#                        2.1478e-04,  4.4287e-03, -1.9828e-02, -3.2017e-03, -1.8842e-02,
#                       -2.9550e-02,  2.5738e-02, -2.1219e-02,  1.6742e-02,  1.2226e-02,
#                        1.0399e-02,  3.1987e-02,  3.2634e-02, -2.2594e-02, -2.4326e-02,
#                        6.7197e-04,  2.6496e-02,  1.9609e-02,  8.4514e-03, -2.6985e-02,
#                        1.2484e-02, -8.4143e-03,  7.0294e-03, -2.1362e-02, -1.0089e-02,
#                       -1.5743e-02,  2.5558e-02,  1.8209e-02,  3.1934e-02,  2.2663e-02,
#                       -2.3369e-02, -1.7101e-02,  1.7006e-02, -3.5022e-02, -2.5759e-02,
#                        6.6514e-03,  1.3054e-02, -1.7245e-02,  2.1760e-02, -1.9839e-02,
#                        4.3059e-03,  2.3422e-04,  8.5801e-03,  1.4597e-02, -1.3513e-02,
#                        5.7054e-05,  3.1101e-02,  2.3083e-02, -6.0878e-03, -2.0490e-02,
#                        2.2378e-02, -7.2150e-03, -1.9221e-02,  2.0001e-03, -2.4689e-02,
#                       -1.6906e-03,  1.8435e-02, -2.7878e-03, -1.7937e-02,  3.4591e-03,
#                        1.1679e-02, -1.0938e-02, -1.8325e-02, -3.4527e-02, -9.1731e-03,
#                       -8.2236e-03, -2.8503e-02, -2.9148e-02,  2.9531e-02,  5.5397e-03,
#                        2.5015e-02,  8.8723e-03, -2.9980e-02, -1.0878e-02,  9.8364e-03,
#                       -5.6205e-03, -3.1959e-02,  2.2059e-02,  2.9161e-02,  2.0468e-02,
#                       -1.2179e-02,  1.8138e-02,  1.8758e-02, -2.3226e-02,  3.2232e-02,
#                       -2.3837e-03, -2.1720e-03,  3.1128e-02,  4.6101e-03,  2.8987e-02,
#                       -2.5197e-02, -1.6690e-02,  2.0253e-02, -2.9136e-02,  1.5743e-02,
#                       -2.5996e-03,  1.3863e-02,  1.6172e-02,  7.3228e-04, -2.5104e-02,
#                       -1.8013e-02, -9.6907e-03,  2.4667e-02, -1.7485e-02,  2.6608e-02,
#                        2.1868e-02, -4.1768e-03,  1.8198e-02, -7.6214e-03, -1.6403e-02,
#                        3.1467e-02,  2.2055e-02,  4.1540e-03,  2.9701e-02,  2.0725e-02,
#                        2.1559e-02, -2.8508e-02,  2.9749e-02, -1.1753e-02,  7.6746e-03,
#                        3.3633e-02, -2.9131e-02,  1.7742e-03,  2.0125e-02, -3.3214e-02,
#                        2.8341e-02, -2.6718e-02, -2.8664e-02, -1.1852e-02,  2.8578e-02,
#                       -2.3249e-02,  1.2387e-02,  6.1706e-03, -9.3228e-03,  2.5633e-02,
#                        1.6895e-02,  3.0199e-02,  3.1993e-02,  2.8015e-03,  5.1203e-04,
#                       -1.3733e-02, -1.8928e-02, -3.3047e-02,  1.4925e-02,  1.9782e-02,
#                        3.0918e-02, -2.2652e-02, -1.2206e-02,  1.9720e-02,  1.2879e-03,
#                       -8.0605e-03, -2.5273e-02,  1.7732e-02, -1.2996e-02,  3.0180e-02,
#                       -6.5285e-03,  2.9882e-02, -3.9229e-03,  9.0582e-03, -1.6713e-02,
#                        1.4467e-02,  1.0905e-02,  1.6663e-02, -5.5820e-03, -1.9070e-03,
#                       -1.0674e-02,  1.3076e-02, -3.0742e-02, -1.9605e-02,  2.3273e-02,
#                       -1.0136e-02, -1.2850e-02, -1.1332e-03,  2.7819e-02, -2.0811e-02,
#                        2.1269e-03, -3.4675e-02, -7.8888e-03, -2.8627e-02, -2.7327e-03,
#                       -1.6283e-02, -2.5437e-02, -2.6182e-02, -9.1303e-03,  2.9280e-02,
#                       -2.6547e-02,  2.4576e-02, -2.7595e-02,  3.2126e-02,  1.8710e-02,
#                        1.1298e-02,  8.8349e-03, -6.4281e-03, -2.1347e-02,  1.5033e-02,
#                       -3.3915e-02,  2.8645e-02, -2.2764e-02,  1.8872e-02, -2.2958e-02,
#                        1.9289e-02, -3.0173e-03, -3.3559e-03, -1.1731e-02,  6.4684e-03,
#                       -3.5085e-02,  3.2369e-02,  1.8554e-02, -3.3540e-02, -8.6685e-03,
#                        1.6775e-02, -9.0154e-03,  4.7198e-03,  1.2530e-02, -2.8532e-02,
#                       -2.5923e-02,  1.9028e-02, -2.8744e-02, -1.6212e-02, -1.6823e-02,
#                        2.7619e-02, -1.2112e-02, -1.0547e-02,  2.6960e-02, -1.0562e-02,
#                        8.4209e-03, -3.4513e-03, -8.5530e-03,  1.3950e-02, -2.2057e-02,
#                        1.3209e-02,  1.1884e-02,  3.3759e-02,  3.3281e-02,  8.1127e-03,
#                        2.4979e-02,  1.9697e-02,  1.6582e-02,  2.0763e-02,  1.0890e-02,
#                        9.5054e-03, -2.0340e-03, -2.3389e-02,  1.8603e-02,  1.9282e-02,
#                        1.0240e-02,  7.3058e-03,  2.0042e-02, -2.5788e-02, -1.7638e-02,
#                       -2.7467e-02,  3.1853e-02,  1.3621e-03, -2.9592e-02,  6.1431e-03,
#                       -1.0196e-02,  1.8662e-02,  1.0159e-02,  3.1378e-02,  1.3117e-02,
#                        5.9075e-03,  2.9331e-03, -6.1504e-04, -1.8306e-03, -9.2198e-03,
#                       -1.8369e-02, -7.7757e-03, -2.4926e-02,  1.4797e-02, -3.2872e-03,
#                        1.2211e-02, -6.7795e-03, -8.2863e-03,  4.5192e-03,  8.2982e-04,
#                        7.5252e-03, -1.3557e-02,  2.3928e-02, -3.1954e-02, -1.7709e-02,
#                        2.7415e-02,  1.2729e-03,  2.2374e-02, -8.4816e-04,  1.5193e-02,
#                       -3.0780e-02, -1.7936e-03,  1.2504e-02, -2.3954e-02,  3.4243e-03,
#                       -8.2112e-03, -2.5552e-02, -1.0306e-02, -1.2155e-02, -1.9878e-02,
#                        2.3695e-02, -2.0043e-02, -5.9374e-03, -8.0350e-03, -1.4919e-02,
#                        3.5746e-03, -1.5082e-02,  2.6745e-02,  4.3956e-03,  9.9890e-03,
#                       -2.6494e-02,  3.4856e-03,  1.0992e-02,  1.4571e-02,  2.1195e-02,
#                       -1.7772e-02,  2.3805e-02,  2.5245e-03,  2.9216e-02, -4.3362e-03,
#                        1.0775e-02,  3.3863e-02,  2.4154e-03, -2.7214e-02, -3.3716e-02,
#                       -5.6058e-03, -1.3475e-02,  8.7195e-03, -2.3890e-02,  2.4564e-02,
#                        1.9346e-02, -2.2133e-02,  3.1932e-02, -1.6063e-03,  3.6573e-03,
#                        5.8466e-03,  7.8625e-03,  2.6576e-02, -6.1509e-03,  3.0489e-03,
#                       -2.8598e-02, -8.6835e-03,  1.6867e-02,  6.4389e-03, -3.3364e-02,
#                       -2.4010e-02,  5.2636e-03,  1.6303e-02, -5.2049e-03,  3.4142e-02,
#                       -3.1905e-02, -7.8159e-03, -8.1552e-03, -4.4740e-03, -2.1453e-02,
#                       -5.3903e-04, -9.6175e-03, -6.0318e-03,  3.7888e-03, -2.3228e-02,
#                       -2.8764e-03, -3.5972e-03,  3.1937e-02, -4.5544e-04,  8.9446e-03,
#                       -1.7953e-02,  1.7132e-02, -3.2623e-02, -2.6352e-02,  6.7692e-03,
#                        2.5306e-02, -1.8823e-02,  1.3027e-03, -1.7241e-03, -2.3650e-02,
#                       -2.1614e-02, -7.6175e-03,  1.7385e-02,  4.7902e-03,  1.8385e-02,
#                        1.6310e-02, -2.3032e-02, -2.8424e-02,  5.2682e-03,  9.0011e-03,
#                       -2.0634e-02,  2.6915e-02, -6.9943e-03,  3.8912e-03,  4.4749e-03,
#                        8.6480e-03, -2.8092e-02, -1.0885e-02, -1.8312e-02, -2.2356e-03,
#                        1.5508e-02, -4.5561e-03,  1.9451e-02, -3.1440e-03, -3.2522e-02,
#                       -3.4776e-03, -8.8831e-04,  2.8750e-02, -3.3755e-02,  3.1666e-02,
#                       -2.5413e-02,  2.4808e-02, -3.4798e-04,  3.2415e-02,  2.6930e-02,
#                       -1.1999e-03,  1.4354e-02,  2.1362e-03,  2.7750e-02, -6.3487e-03,
#                        8.0317e-03, -2.4106e-03, -2.3522e-05,  7.9354e-03,  8.7542e-03,
#                        7.9646e-03, -2.4973e-02, -7.9198e-03, -5.8943e-04,  3.3459e-03,
#                       -3.6430e-04, -2.1559e-02, -2.8166e-02, -3.4025e-02, -1.0342e-02,
#                        2.7012e-02, -9.8377e-03,  1.9506e-02, -1.9894e-03, -1.4018e-02,
#                       -2.0683e-02,  1.2268e-02,  6.6622e-03,  2.5272e-02, -6.1035e-03,
#                       -8.0014e-03, -1.5103e-02,  2.1614e-02,  2.9834e-02, -8.5504e-03,
#                        2.6375e-02,  1.2814e-02,  1.0590e-02, -5.6151e-03, -3.0418e-02,
#                       -7.9381e-03,  3.6985e-04,  2.4725e-02,  2.7959e-03,  1.0847e-02,
#                       -1.0080e-02,  2.2252e-02,  1.8585e-02, -2.1953e-02, -1.0732e-02,
#                       -1.2085e-02,  2.5417e-03,  3.0708e-02, -8.2395e-03, -2.0523e-02,
#                        3.0786e-02,  2.8953e-02, -2.5118e-02, -1.9545e-02,  3.2561e-02,
#                        1.2496e-02,  2.5610e-02, -3.9593e-04,  1.7377e-02, -9.6441e-03,
#                       -2.2914e-02, -3.1767e-02, -2.3016e-03,  1.4144e-02, -3.1374e-02,
#                        3.5552e-03, -2.2241e-03, -2.4742e-02, -1.6879e-02,  2.5244e-02,
#                        2.3226e-02,  1.2729e-02, -2.3470e-02, -2.6177e-02,  2.5296e-02,
#                        1.3904e-03, -1.1275e-02,  1.8244e-02, -2.8539e-02,  8.1270e-03,
#                        2.1578e-02,  2.9779e-02, -1.7482e-02,  2.3602e-02,  4.2660e-03,
#                       -2.1095e-02,  1.3915e-02,  1.1208e-02,  2.3307e-02, -1.1356e-04,
#                        1.2780e-02, -1.7859e-02,  8.7622e-03,  2.0560e-02,  2.0446e-02,
#                       -1.7073e-02, -3.1790e-02, -9.5088e-03, -1.5182e-02, -3.4173e-03,
#                       -9.6644e-03,  1.5989e-02, -2.9250e-02,  2.6250e-03,  1.0659e-02,
#                       -8.8401e-03,  2.5108e-02,  2.9623e-02,  1.2387e-02, -1.4631e-02,
#                        2.0311e-03,  9.0267e-03, -1.6261e-02, -1.5020e-02, -2.2927e-02,
#                        1.0938e-02, -6.4121e-03, -7.6177e-03, -1.3453e-02,  3.1659e-02,
#                        1.6471e-02,  1.5221e-02, -2.3089e-02, -1.7204e-02, -7.4887e-03,
#                        6.8231e-04], requires_grad=True): {'step': tensor(200000.),
#                'sum': tensor([9.9226e-03, 5.9914e-07, 6.7261e-08, 6.1606e-04, 1.5288e-05, 3.3463e-13,
#                        3.2350e-05, 1.9754e-03, 1.4390e-02, 4.8029e-03, 0.0000e+00, 2.8846e-05,
#                        8.9079e-03, 7.0268e-12, 5.2809e-03, 0.0000e+00, 1.8605e-04, 1.1847e-02,
#                        1.7388e-02, 2.5796e-02, 1.1899e-08, 1.2702e-08, 1.6585e-03, 2.7834e-04,
#                        1.2259e-03, 1.2105e-03, 2.5634e-06, 1.5756e-04, 1.5878e-04, 7.0568e-03,
#                        6.5217e-05, 7.3266e-06, 4.5101e-03, 2.2334e-04, 1.7885e-04, 0.0000e+00,
#                        7.8509e-04, 6.9741e-04, 1.0317e-03, 1.3164e-02, 1.9426e-04, 5.7585e-10,
#                        0.0000e+00, 1.7421e-09, 2.5838e-03, 0.0000e+00, 3.6648e-04, 6.6961e-03,
#                        2.1841e-02, 4.1091e-04, 1.1951e-02, 2.3144e-03, 6.2779e-03, 7.3377e-04,
#                        3.9773e-03, 3.5769e-03, 0.0000e+00, 8.5614e-06, 1.8133e-04, 2.2052e-04,
#                        4.1444e-04, 2.0594e-07, 8.0003e-04, 1.0164e-03, 1.9767e-05, 7.4370e-04,
#                        2.7237e-05, 5.9585e-11, 2.5633e-04, 7.3116e-04, 1.8218e-04, 4.7723e-04,
#                        4.3083e-03, 9.7319e-05, 0.0000e+00, 1.8063e-02, 1.0761e-11, 5.1954e-04,
#                        0.0000e+00, 1.4184e-02, 2.2330e-04, 5.6256e-03, 1.0428e-04, 5.8587e-07,
#                        0.0000e+00, 9.4682e-06, 2.2998e-03, 2.5665e-03, 8.9176e-08, 0.0000e+00,
#                        2.2218e-04, 7.4995e-05, 1.3465e-02, 1.9866e-02, 5.1626e-04, 2.9137e-04,
#                        1.1237e-03, 2.6352e-07, 5.2208e-03, 1.3282e-03, 3.5473e-03, 5.0630e-04,
#                        1.6161e-05, 1.3831e-03, 2.1832e-06, 1.0124e-03, 0.0000e+00, 1.3755e-04,
#                        4.6087e-05, 1.9042e-03, 2.8523e-03, 1.7356e-03, 2.7178e-05, 2.7899e-04,
#                        6.7694e-03, 4.9112e-06, 1.0095e-03, 1.1814e-04, 1.5678e-03, 2.3950e-12,
#                        1.0642e-02, 9.1486e-08, 7.9112e-03, 1.7579e-06, 1.7317e-06, 5.4559e-05,
#                        0.0000e+00, 5.8361e-07, 1.2116e-03, 9.0311e-03, 1.4459e-03, 4.8541e-04,
#                        1.5030e-02, 4.7092e-03, 9.3827e-04, 4.4208e-05, 1.6439e-04, 1.4438e-02,
#                        3.0408e-08, 9.2261e-10, 2.6305e-04, 1.6404e-03, 4.8853e-07, 4.1733e-05,
#                        9.6065e-04, 4.2441e-04, 6.7137e-03, 1.9526e-06, 1.5912e-07, 4.7784e-05,
#                        7.3455e-04, 7.0320e-03, 9.6577e-05, 4.6753e-03, 2.7678e-05, 6.1519e-06,
#                        4.7679e-04, 8.8628e-05, 4.4058e-04, 2.4821e-02, 3.9372e-04, 0.0000e+00,
#                        1.5329e-02, 1.9053e-02, 5.6768e-06, 3.8808e-03, 2.0400e-07, 2.5830e-04,
#                        1.7981e-04, 0.0000e+00, 6.8119e-04, 5.5805e-05, 1.0983e-06, 2.4637e-11,
#                        1.6948e-06, 7.9601e-04, 8.4934e-04, 3.5796e-05, 4.1433e-06, 4.2531e-12,
#                        9.7087e-08, 1.5768e-02, 1.7725e-02, 1.2135e-05, 2.5179e-02, 3.0683e-04,
#                        1.2718e-02, 6.0853e-04, 1.1332e-02, 2.3599e-06, 8.6856e-03, 8.2470e-05,
#                        2.6774e-04, 7.6034e-04, 1.5075e-02, 1.3577e-07, 6.0072e-03, 1.3588e-03,
#                        6.5380e-13, 2.6210e-02, 6.8364e-03, 0.0000e+00, 2.2093e-03, 8.5202e-08,
#                        2.5535e-12, 5.2285e-11, 3.1258e-06, 1.0709e-03, 3.6847e-05, 1.8785e-05,
#                        8.9290e-04, 3.5554e-07, 1.9703e-03, 4.5333e-04, 1.6616e-09, 1.9486e-02,
# ...
#             -8.8401e-03,  2.5108e-02,  2.9623e-02,  1.2387e-02, -1.4631e-02,
#              2.0311e-03,  9.0267e-03, -1.6261e-02, -1.5020e-02, -2.2927e-02,
#              1.0938e-02, -6.4121e-03, -7.6177e-03, -1.3453e-02,  3.1659e-02,
#              1.6471e-02,  1.5221e-02, -2.3089e-02, -1.7204e-02, -7.4887e-03,
#              6.8231e-04], requires_grad=True),
#     Parameter containing:
#     tensor([[-2.3034e-02, -3.0022e-02, -8.3155e-03,  2.2399e-02,  4.9010e-05,
#               2.4541e-02,  9.7841e-03,  1.4650e-02,  2.3386e-02, -1.3130e-02,
#              -2.2744e-02,  5.8882e-04, -2.2510e-02,  2.6441e-04,  2.0091e-02,
#              -8.4445e-03,  2.7329e-02,  2.8363e-02,  2.5817e-02,  3.1519e-02,
#              -2.8705e-02,  7.5164e-04, -2.8698e-02, -2.8828e-02,  6.6436e-03,
#               3.0318e-02, -1.2557e-03,  1.3913e-02,  2.2430e-03,  1.6304e-02,
#               7.3189e-03,  2.4475e-02,  1.2913e-02, -2.3240e-02,  2.5142e-02,
#              -2.6805e-02, -2.0151e-02,  2.2691e-02,  6.0232e-03,  2.2383e-02,
#               9.8732e-03, -2.2442e-03,  1.4111e-02, -4.3281e-03, -9.7966e-03,
#              -3.0319e-02,  1.6338e-02,  1.7200e-02,  2.8861e-02,  1.8001e-02,
#               2.1331e-02,  1.4173e-02,  1.5448e-02,  2.9148e-02,  1.7233e-02,
#              -1.1458e-02,  1.7066e-02,  1.2360e-02,  1.2514e-02,  1.3690e-02,
#               3.8001e-03, -3.5039e-03, -6.0353e-03, -1.7121e-02, -2.1114e-02,
#               4.8753e-03, -1.8875e-03, -1.1423e-02, -1.4340e-02, -3.0345e-02,
#               2.3385e-03, -4.0552e-03, -1.3323e-02, -2.0399e-02, -2.1497e-02,
#              -2.7708e-02,  1.8381e-02,  3.0956e-02, -8.6024e-03, -2.3058e-02,
#               8.1349e-03,  1.4513e-02,  1.7817e-03,  2.0703e-02,  8.2891e-03,
#              -1.0922e-02,  9.2520e-03, -1.9638e-02,  5.2158e-03, -3.0568e-03,
#              -1.9118e-02, -2.4485e-03, -2.2266e-02,  2.7554e-02,  4.3907e-03,
#               9.8041e-03,  6.1729e-03, -5.1110e-03, -2.1794e-02, -3.1719e-02,
#               1.1455e-02, -1.3102e-02, -7.1478e-03,  7.0687e-03, -1.6067e-02,
#               5.9424e-03,  2.4874e-02,  8.9744e-03,  2.1574e-02,  8.4495e-03,
#               1.0375e-02,  2.8301e-02,  2.6360e-02,  8.2671e-03,  1.6915e-02,
#               1.8290e-04, -1.3347e-02, -2.1239e-03,  7.3126e-03, -1.3175e-02,
#               3.1615e-02,  1.7289e-02, -2.0581e-02, -5.8520e-03,  7.0541e-03,
#              -2.1669e-03,  2.8677e-02, -2.0514e-02,  6.5443e-03,  1.8290e-02,
#               6.8069e-03, -3.9473e-03, -2.3791e-02, -2.4335e-02, -5.8046e-03,
#              -8.0121e-03, -1.4957e-02,  2.4550e-02, -2.4286e-02,  6.9911e-04,
#              -2.0943e-02,  8.4233e-03, -6.6382e-03,  5.3343e-03, -7.6273e-03,
#               2.6411e-02,  1.6032e-02, -4.5160e-03, -9.6976e-03, -2.3118e-02,
#               2.8709e-02,  2.1012e-02, -4.7469e-03,  1.2919e-02, -1.7017e-02,
#              -3.6852e-03, -1.5125e-02, -1.8588e-02, -9.9410e-03,  3.0888e-02,
#               2.3687e-02,  1.8172e-05,  2.7766e-02, -2.7658e-02, -2.5378e-03,
#               1.3150e-02, -1.5935e-03,  1.0512e-02,  3.4336e-03,  5.8471e-03,
#              -3.1099e-02,  1.6100e-03,  6.5269e-03,  2.9515e-02,  1.7518e-02,
#              -1.6099e-02,  3.0058e-02, -2.7810e-02, -7.2053e-03,  2.2233e-04,
#              -2.0352e-02,  2.4189e-02,  2.7062e-02,  2.5505e-03,  3.0942e-02,
#               3.3835e-03, -2.6639e-02,  1.5943e-02, -2.6317e-02, -1.3896e-03,
#               1.8049e-02, -1.3727e-02,  1.2427e-02,  2.6308e-02,  2.4041e-02,
#              -5.6110e-03,  1.5783e-02, -6.8385e-03,  2.1549e-02,  3.1761e-02,
#               1.6240e-02,  1.4382e-02, -1.6120e-02,  9.7058e-05, -1.7374e-02,
#              -2.0761e-02, -2.0355e-02, -2.0202e-02, -2.1254e-02, -5.4811e-03,
#               5.4168e-03,  2.3832e-03,  8.0222e-03,  2.2740e-02, -5.0783e-03,
#               3.0792e-02,  2.7339e-02, -3.0697e-02,  2.0246e-02, -2.4664e-02,
#               1.0979e-02, -1.4981e-02, -2.4712e-02,  6.7187e-03, -7.3065e-03,
#              -2.0245e-02, -8.7245e-03, -6.5916e-03,  1.4922e-02,  4.3723e-04,
#               2.1066e-02,  2.8824e-02, -3.2745e-02, -2.7250e-02, -2.6801e-02,
#               4.1199e-03, -5.8794e-03, -2.4620e-02,  1.7576e-02,  3.0310e-02,
#               1.6856e-02, -2.1089e-03, -1.8174e-02, -8.0022e-03, -3.4879e-03,
#               1.1378e-02, -3.3195e-03,  2.2095e-02,  1.0083e-02, -2.6745e-02,
#              -2.7684e-02,  1.7442e-02, -2.3885e-04, -1.4887e-02, -6.4816e-03,
#              -6.0535e-04,  6.9546e-04,  3.7519e-03, -2.5482e-02,  8.7476e-03,
#               2.1630e-02,  3.2085e-02, -1.3125e-02, -2.0268e-02,  2.1173e-02,
#               6.1958e-03, -2.4409e-02, -1.7575e-02,  1.9426e-02,  2.9556e-02,
#               1.0401e-02, -2.6040e-02,  1.6752e-02,  4.8640e-04, -5.6810e-03,
#               4.0364e-03,  3.1409e-02,  1.9696e-02, -1.1566e-02,  2.2876e-02,
#              -4.2504e-03,  2.0900e-02, -1.7955e-02, -2.5374e-02,  5.0315e-03,
#               2.0412e-02,  2.9603e-02, -8.4941e-03, -1.0180e-02, -8.8753e-03,
#              -7.6365e-03, -2.7265e-02,  1.5544e-02,  2.2835e-02, -2.8282e-02,
#               1.4436e-03, -1.8616e-02, -2.1649e-03,  5.2806e-03,  2.4661e-02,
#              -9.0162e-03, -9.7121e-03, -1.3720e-02, -1.5615e-02,  6.0308e-04,
#              -2.9283e-02,  8.7591e-03,  2.4325e-02,  9.4640e-04, -4.9387e-03,
#              -1.0003e-02, -1.6037e-02, -2.8453e-03,  3.0167e-02, -2.4284e-04,
#               1.1208e-02, -1.6202e-03, -1.0401e-02,  2.6843e-02,  4.7570e-03,
#               1.1520e-03, -2.2218e-02,  2.8086e-02,  2.2075e-02,  1.9070e-02,
#               1.0763e-02,  6.2699e-03, -7.5168e-03, -2.3748e-02, -1.3072e-02,
#              -1.7537e-02, -7.9869e-04,  6.3113e-03, -6.7345e-03, -2.0594e-02,
#               3.7726e-03, -1.4587e-02,  2.5924e-03, -3.1005e-02, -7.1899e-04,
#              -1.5219e-02, -2.1846e-02,  6.4224e-03, -3.1189e-02, -2.2485e-02,
#              -2.8232e-02, -1.3731e-02,  3.1307e-02, -1.0673e-03,  2.7934e-02,
#              -1.4305e-02, -2.3463e-02, -7.6722e-03, -2.8283e-02, -2.8159e-02,
#               3.0903e-02, -3.1179e-02, -1.0583e-02,  2.4164e-02,  4.2862e-02,
#               2.5818e-02,  1.3588e-02, -8.7280e-03,  2.9034e-02, -2.7607e-02,
#              -2.7918e-02, -3.1653e-03,  2.3062e-02,  1.1314e-02,  1.8622e-02,
#               1.9753e-02,  2.2220e-02,  1.0214e-02, -2.0315e-02, -3.0250e-02,
#              -2.7569e-02,  2.1377e-03, -1.1002e-02,  3.0140e-02, -1.9758e-02,
#               2.3247e-02,  2.3343e-02,  1.3418e-02, -3.6218e-02,  1.5876e-02,
#               1.5732e-02,  9.5759e-03,  1.4638e-02,  1.6807e-03,  2.0963e-02,
#               2.5777e-03,  3.1318e-02, -2.5967e-03,  1.3352e-02, -1.6305e-03,
#              -8.7502e-03, -1.9955e-02, -2.8631e-02,  2.3180e-02, -4.0587e-03,
#               2.5773e-02, -2.2672e-02, -2.6659e-02, -2.1485e-02,  5.4658e-03,
#               1.6085e-02, -2.0697e-02,  2.3859e-02,  1.7322e-02,  2.0418e-02,
#              -8.4782e-03, -1.8321e-02, -2.9956e-02, -2.6773e-02,  8.8108e-03,
#               2.0673e-02, -2.5671e-02,  9.8271e-03, -1.3286e-02, -2.3078e-02,
#              -1.9973e-03,  1.8448e-02,  7.8605e-03,  8.9411e-03, -2.6524e-02,
#               2.0226e-02, -1.4592e-02,  2.9144e-02, -2.9282e-02,  1.7567e-02,
#               1.3128e-02, -2.5443e-02, -1.7575e-02,  6.8060e-03,  1.6948e-02,
#              -2.4093e-02, -2.1347e-02,  2.2430e-02, -1.3733e-02, -1.2621e-02,
#               9.3438e-03,  1.5283e-02, -1.8992e-02,  6.2487e-03,  2.3257e-02,
#              -1.7856e-02,  9.8013e-04,  1.5087e-02, -7.3331e-03,  1.8406e-02,
#              -2.7723e-03, -1.6646e-02, -1.1521e-02,  1.7273e-02, -2.4477e-02,
#               4.9510e-03, -2.0222e-02, -1.4977e-02, -1.4177e-02,  1.0613e-04,
#              -2.8034e-02, -2.7269e-02, -2.5573e-03, -7.9386e-03,  1.8339e-02,
#               2.9830e-02, -2.9911e-02, -1.6538e-02, -4.0604e-03,  2.6738e-02,
#               1.1872e-02, -2.3940e-03, -1.6966e-02,  2.0443e-02, -3.5490e-03,
#               2.9699e-02, -2.7064e-02,  1.9781e-03, -7.2597e-03,  8.5318e-03,
#               1.2191e-02,  3.6889e-03, -8.8823e-03, -2.7262e-02, -1.9042e-02,
#              -2.3913e-03,  6.6689e-03,  4.4283e-03,  1.3141e-02,  1.4706e-02,
#              -3.2367e-03,  1.6855e-02, -1.1650e-02, -2.0613e-02, -2.5651e-02,
#              -1.8940e-02,  3.2215e-02,  2.4177e-02, -1.0119e-02,  2.8968e-02,
#               8.3350e-03,  1.2671e-02,  2.2957e-02,  1.0386e-02,  2.7773e-02,
#              -6.1832e-03,  3.8824e-03, -2.1189e-02, -2.1830e-02,  2.5568e-02,
#              -2.6194e-02, -1.9564e-02,  9.0416e-03,  6.6898e-03, -6.0015e-03,
#              -2.8576e-02, -1.5978e-04, -3.0018e-03,  1.4781e-02,  1.0611e-02,
#               2.4035e-03,  2.8961e-02, -5.9715e-03, -1.9356e-02,  7.5436e-03,
#              -1.2946e-02, -1.4902e-02,  2.3430e-02, -1.3412e-02,  1.8381e-02,
#               1.5392e-02,  2.5561e-03,  2.7685e-02,  3.2626e-03,  2.9109e-02,
#               5.7891e-03,  1.6877e-02,  7.2305e-03, -2.7783e-02, -1.9402e-02,
#               8.7519e-03, -1.5795e-02,  1.8098e-02, -1.0620e-02,  2.4879e-02,
#              -3.1192e-02, -1.2155e-02, -2.8510e-02, -2.1073e-03,  8.8223e-03,
#              -1.1753e-02, -1.1575e-02,  1.4335e-02,  3.1729e-02, -2.4718e-02,
#              -1.0193e-02,  7.6084e-04,  2.5680e-02, -2.7106e-02,  1.9505e-02,
#               2.1563e-02,  1.4220e-02,  1.8141e-02,  1.3511e-02,  3.0499e-02,
#               4.4208e-03,  2.1253e-02, -2.2453e-02, -1.5635e-02, -1.2309e-02,
#               1.5995e-02, -2.3982e-02,  2.5816e-02,  4.0533e-03, -1.4297e-02,
#              -3.4868e-03,  6.3890e-03, -1.1007e-02,  7.5020e-03, -1.8042e-03,
#              -1.4128e-02, -6.4973e-03,  8.6819e-03,  1.6963e-02, -2.7257e-02,
#               2.9824e-02, -8.9742e-03, -1.2077e-02, -2.0002e-02, -8.0487e-03,
#               1.7374e-04, -9.7143e-03, -1.8991e-02, -2.1400e-02,  2.2626e-02,
#              -7.4873e-03,  2.2248e-02, -1.3038e-02,  2.2180e-02, -1.8680e-03,
#              -1.2773e-02, -3.6796e-03, -5.6356e-03, -2.2699e-02, -9.3350e-03,
#               1.3665e-02, -2.0914e-02, -2.2327e-02, -3.3119e-03, -1.2838e-02,
#              -1.0651e-02, -2.8113e-03,  2.2021e-02, -3.0646e-02,  2.0509e-02,
#              -1.2472e-02, -2.0967e-02, -2.5782e-02, -3.1062e-02, -2.8018e-02,
#              -2.4781e-02, -1.0170e-02, -1.1500e-02, -1.4157e-02,  8.4673e-03,
#              -1.8725e-02,  1.4584e-03, -1.5016e-02, -6.3635e-03,  8.7333e-03,
#              -1.7013e-02, -7.0574e-03,  7.3983e-04,  1.0714e-02, -3.1661e-02,
#               2.6202e-03, -4.1418e-03, -5.2588e-03,  1.3510e-02, -7.0236e-03,
#              -9.1063e-03,  5.5409e-03, -2.5933e-02, -4.5329e-04, -3.0036e-02,
#              -4.1766e-03,  4.4265e-04, -1.6495e-02,  2.1334e-02,  2.8259e-02,
#               1.9332e-02, -2.3221e-02,  2.0507e-02,  2.3852e-02,  5.3718e-03,
#              -1.1058e-02,  1.4574e-02,  3.1978e-02,  1.7982e-02,  6.3096e-04,
#               1.5430e-02,  1.9230e-02, -2.8978e-02,  3.5665e-03, -1.0564e-02,
#               6.1287e-03, -2.8823e-02,  2.9021e-02, -2.9753e-02,  1.3982e-02,
#              -2.9980e-02,  1.2557e-02,  1.8348e-02,  1.0755e-02,  6.7396e-03,
#              -2.0546e-03,  2.2346e-02, -2.3202e-02,  5.4953e-03, -2.2014e-02,
#               1.6579e-02,  2.6599e-02,  2.7566e-02,  1.4876e-02,  2.1047e-04,
#               2.8336e-02,  2.8064e-02,  1.9469e-02, -1.3497e-02,  1.6557e-02,
#               8.7262e-04,  2.9327e-02, -1.4471e-03,  1.7423e-02,  7.9326e-03,
#               9.2998e-03, -1.2638e-02,  2.6577e-02,  6.1924e-03,  2.4498e-02,
#               1.4016e-02, -5.2968e-03,  3.8881e-03, -1.1445e-03, -2.6461e-02,
#               2.2568e-02,  3.1428e-02, -1.1835e-02, -2.7541e-02, -1.6705e-02,
#              -1.1392e-02,  1.6342e-02,  2.2284e-02, -1.0392e-02, -2.5902e-02,
#              -2.8012e-02,  2.6254e-02, -1.2765e-02,  4.5893e-03, -7.8011e-03,
#               9.1281e-03,  2.8897e-02, -9.6038e-03,  1.5134e-04, -1.4454e-02,
#              -1.5682e-02, -2.6998e-02,  9.3219e-03, -1.6541e-02, -2.4518e-02,
#               3.0804e-02,  2.9600e-02,  2.3558e-02,  3.2961e-04, -3.0142e-02,
#               2.1461e-02, -9.4307e-03, -8.4092e-03,  9.5361e-03, -2.6046e-02,
#              -1.4169e-02, -4.2447e-03, -2.9484e-02,  1.7330e-02, -1.0720e-03,
#               1.0277e-02,  2.8566e-02,  1.1286e-03, -1.5542e-02, -1.0786e-02,
#               2.5223e-02,  1.3621e-02, -3.1081e-02,  5.3393e-03,  1.2445e-02,
#               1.9490e-02,  1.4043e-03, -3.0697e-02, -1.0483e-02,  9.4352e-03,
#              -2.3404e-02,  1.4285e-02,  1.3450e-02, -1.0795e-02, -8.6684e-05,
#              -8.2561e-03,  1.1092e-02, -1.4651e-02, -2.9767e-02,  4.5541e-03,
#               1.8088e-03, -2.5180e-02,  1.7880e-02,  1.5189e-02,  1.4398e-02,
#              -1.7391e-03,  1.4773e-02, -2.6024e-02, -1.7855e-02, -3.0412e-02,
#               2.9361e-02, -2.5590e-02, -1.1497e-02, -1.4840e-02,  2.0468e-03,
#               1.4583e-02, -2.5205e-02,  3.1511e-02, -5.1816e-04, -2.4969e-03,
#               2.6782e-02, -1.3341e-02, -1.3610e-02, -2.2280e-02, -1.4610e-02,
#               1.8599e-03,  6.0237e-03,  3.1547e-02, -2.5399e-02, -2.3836e-02,
#              -2.6812e-02, -1.8263e-02, -1.0211e-02,  9.2099e-03, -2.0657e-02,
#              -2.3862e-02,  2.0851e-02, -2.2735e-02,  1.0561e-02, -1.1691e-02,
#              -2.0171e-02, -2.2399e-02,  8.5430e-04,  2.7830e-02,  2.8206e-02,
#              -2.3879e-02,  1.1196e-02, -4.1043e-03, -2.9989e-02, -2.2411e-03,
#               1.8035e-02,  5.6263e-03,  5.4781e-03, -8.6444e-04, -1.4884e-02,
#              -2.3547e-03,  2.3227e-02, -1.3512e-02, -1.0416e-02,  1.3051e-02,
#              -1.5043e-02, -2.5463e-02,  8.6667e-03,  2.2629e-02,  2.4096e-02,
#               1.7882e-02, -2.7627e-02, -4.0419e-03,  1.3545e-02,  6.8346e-03,
#               2.2994e-02, -2.7614e-03,  2.0270e-02,  9.2415e-03, -3.1295e-02,
#               6.6556e-03,  2.8585e-02,  1.5980e-02,  2.7098e-02, -3.5683e-03,
#              -1.7939e-02, -7.7373e-03, -2.7563e-02,  3.2018e-02, -2.5919e-02,
#               3.7375e-03,  2.4782e-02, -8.1774e-03, -2.1618e-02,  6.7963e-04,
#               1.9072e-02,  2.9801e-02, -9.4571e-03,  2.9169e-02, -2.2079e-03,
#              -4.9863e-03,  2.0993e-02, -2.9533e-02,  2.5058e-03,  2.2914e-02,
#               2.3116e-02, -1.7571e-03, -1.3140e-02,  2.0656e-02, -6.0943e-03,
#               1.6870e-02, -2.5456e-02, -2.9936e-02,  1.7863e-02, -8.8403e-03,
#               2.8801e-02,  2.9179e-02,  1.1647e-02,  1.6679e-02,  2.9607e-02,
#              -1.8823e-04,  2.0164e-02,  2.1988e-02, -2.7186e-02,  1.2240e-02,
#               5.9944e-03,  1.4187e-02, -3.0767e-02, -1.5271e-02,  5.3389e-03,
#               1.4404e-02,  6.3039e-03,  1.1204e-02, -1.2000e-02, -3.0934e-03,
#              -3.0955e-02,  3.3417e-02,  8.1823e-03,  6.4656e-03,  3.0074e-02,
#              -2.2648e-03,  1.4399e-03, -2.7922e-02,  2.1540e-02,  2.4542e-02,
#               1.8802e-02,  2.6529e-02, -4.4488e-03,  5.1588e-03,  3.8337e-03,
#               2.0764e-02, -2.6803e-04,  2.3254e-02, -9.3052e-03, -2.6988e-03,
#              -2.3882e-02,  6.9104e-04,  2.7089e-02,  8.6919e-03, -2.9739e-02,
#               4.5873e-03,  8.2374e-03,  1.7412e-02, -2.8611e-02, -2.7504e-02,
#               2.5615e-04, -2.1096e-02, -3.0661e-02,  3.1356e-02, -8.1808e-03,
#              -2.4663e-02, -2.3353e-02, -2.3970e-02, -2.5898e-02,  4.4282e-03,
#               3.0026e-03,  1.5095e-02, -6.1679e-03,  6.3061e-03, -1.5876e-02,
#              -9.6868e-03, -3.0867e-02,  2.0866e-02,  9.4526e-03, -5.5329e-02,
#              -5.1942e-03]], requires_grad=True),
#     Parameter containing:
#     tensor([0.0281], requires_grad=True)]}],
#  '_warned_capturable_if_run_uncaptured': True,
#  'step': <function torch.optim.optimizer._use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)>,
#  '_step_count': 0}
# {'T_max': 15,
#  'eta_min': 0,
#  'optimizer': Adagrad (
#  Parameter Group 0
#      differentiable: False
#      eps: 1e-10
#      foreach: None
#      initial_accumulator_value: 0
#      initial_lr: 0.0009397168155771956
#      lr: 0.00023492920389429358
#      lr_decay: 0
#      maximize: False
#      weight_decay: 0
#  ),
#  'base_lrs': [0.0009397168155771956],
#  'last_epoch': 400,
#  'verbose': False,
#  '_step_count': 401,
#  '_get_lr_called_within_step': False,
#  '_last_lr': [0.00023492920389429358]}

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 0.0218,  0.5239, -0.1728],
#         [ 0.2383, -0.2804,  0.0983],
#         [-0.5354, -0.5441,  0.0681],
#         ...,
#         [ 0.1954,  0.5206, -0.2022],
#         [ 0.4110, -0.0352, -0.0605],
#         [-0.2288, -0.1308,  0.2053]], requires_grad=True), Parameter containing:
# tensor([-0.5563, -0.3818,  0.1068, -0.0460,  0.4071,  0.4021,  0.3479, -0.3041,
#          0.2244,  0.0718, -0.0049, -0.2536, -0.4152, -0.0226,  0.1733,  0.4650,
#          0.2917,  0.0442, -0.4351,  0.5098,  0.3299, -0.4532,  0.1896,  0.2639,
#         -0.3345,  0.0337,  0.1326,  0.4005, -0.5640, -0.1094,  0.0241, -0.3049,
#         -0.1328,  0.5232, -0.5129, -0.1281,  0.2191,  0.2618,  0.4820, -0.0530,
#         -0.4718,  0.1786,  0.2077,  0.0274, -0.1160, -0.5413, -0.0825,  0.1859,
#          0.3271, -0.1032, -0.0975, -0.1710, -0.3692,  0.5535, -0.5657,  0.2642,
#         -0.1752, -0.5310, -0.1825,  0.2438,  0.5516, -0.0945,  0.3723,  0.5589,
#          0.1902,  0.4184,  0.1350, -0.3173, -0.1333,  0.2774,  0.2044,  0.0776,
#          0.0139, -0.5239, -0.0249,  0.4041, -0.4692, -0.5597,  0.1387,  0.5323,
#          0.3524, -0.2864,  0.2370, -0.5358,  0.3837, -0.0375, -0.3328, -0.4398,
#          0.0064, -0.1513,  0.2043, -0.4391, -0.2068, -0.1510,  0.3204,  0.0853,
#          0.0098, -0.2013,  0.2621,  0.1222, -0.3359, -0.0070, -0.4877,  0.3599,
#         -0.2800, -0.4207,  0.0555,  0.1891,  0.1068, -0.0244,  0.1765,  0.5451,
#          0.0250, -0.1616,  0.5709, -0.2075, -0.4208, -0.1544,  0.1088,  0.1256,
#         -0.2561, -0.4465, -0.4058,  0.2083, -0.2983,  0.2476,  0.1913,  0.0339,
#         -0.3021, -0.5552,  0.1948, -0.1837,  0.1096, -0.5406, -0.4495,  0.2897,
#         -0.4527, -0.0834, -0.5622, -0.2274,  0.2694, -0.3240,  0.0361,  0.5627,
#          0.0113,  0.5348, -0.3224,  0.2911,  0.0651, -0.3556, -0.3851, -0.0883,
#          0.5287,  0.0649,  0.5678,  0.3956, -0.0264, -0.3602, -0.1719,  0.3916,
#          0.2902,  0.2660,  0.2513,  0.2707,  0.3691,  0.2478, -0.0632,  0.4946,
#         -0.3357, -0.3514,  0.2720, -0.3205, -0.1096,  0.1902, -0.2575,  0.3335,
#          0.4671, -0.2920, -0.4116, -0.1813, -0.2515, -0.5409, -0.3215, -0.4533,
#         -0.1250, -0.2847,  0.0065,  0.0892, -0.2435, -0.0570,  0.0264,  0.0119,
#         -0.3943, -0.2817, -0.4869, -0.5389,  0.0167,  0.3835,  0.4901, -0.5414,
#         -0.3369,  0.2382, -0.3949, -0.4688,  0.3139, -0.4553,  0.0254,  0.2235,
#          0.1381,  0.1164,  0.1353, -0.5466,  0.0776, -0.0498,  0.1476,  0.4691,
#          0.5447, -0.1541,  0.5175, -0.1624, -0.1960, -0.5432, -0.1004, -0.1954,
#         -0.4537,  0.2144, -0.0804,  0.5277, -0.0446, -0.3931, -0.4778, -0.0509,
#         -0.4900,  0.3648, -0.5730,  0.5314, -0.0016,  0.1706,  0.4480, -0.2472,
#          0.3155, -0.5647,  0.1631, -0.3813,  0.4342, -0.2335, -0.4539, -0.4978,
#         -0.1959, -0.4073, -0.2859, -0.2347, -0.5524,  0.4651, -0.3802,  0.3101,
#          0.1606, -0.5242, -0.1922, -0.1302,  0.5577, -0.4762,  0.0196,  0.3199,
#         -0.3548, -0.2999,  0.4328, -0.1457, -0.5074,  0.3912,  0.1424, -0.1941,
#          0.4595,  0.1089,  0.4132, -0.1810,  0.4973,  0.0821, -0.3871,  0.2595,
#          0.2190, -0.3108,  0.1848,  0.1295, -0.4013, -0.3261,  0.1705,  0.0937,
#          0.0455,  0.2106, -0.0514,  0.0855,  0.2760,  0.0872, -0.3460, -0.3038,
#         -0.4683,  0.3187,  0.2963, -0.5451,  0.0681,  0.0184, -0.1454,  0.3373,
#         -0.1443, -0.5061, -0.4523, -0.0764, -0.1249, -0.3320, -0.0576, -0.5265,
#          0.0741, -0.2627, -0.5692, -0.4578,  0.2583,  0.4004,  0.3435, -0.1758,
#         -0.1409, -0.3994,  0.2533,  0.1710,  0.5458,  0.1999, -0.0363, -0.1103,
#          0.2263,  0.3637, -0.3441, -0.2158, -0.5679,  0.4839, -0.4903, -0.3259,
#          0.0408,  0.0810, -0.2277, -0.5143, -0.1786,  0.1853, -0.2684,  0.2704,
#         -0.2122,  0.2526,  0.4758, -0.2355, -0.3863, -0.3530,  0.1510,  0.0285,
#          0.5541, -0.5029,  0.4235,  0.4513, -0.4660,  0.4723, -0.1924, -0.0209,
#          0.1519,  0.0456, -0.1463, -0.1155,  0.1708,  0.1659,  0.5446, -0.1215,
#          0.0699, -0.1254,  0.3748,  0.4411, -0.5247, -0.5375,  0.2499, -0.2903,
#         -0.3300, -0.1417,  0.0152, -0.3560, -0.3320,  0.0902,  0.3923,  0.1607,
#          0.3435, -0.2324,  0.0151, -0.4961,  0.4183,  0.2119,  0.2950, -0.1537,
#         -0.2163, -0.4782,  0.4469,  0.3635,  0.3986,  0.4700, -0.2590,  0.1742,
#          0.5015, -0.2699, -0.3319,  0.4228, -0.3116, -0.4215, -0.5356, -0.2644,
#          0.2517, -0.0139, -0.5653,  0.3388,  0.5393,  0.1851,  0.2072, -0.3635,
#          0.2688, -0.4578,  0.3848,  0.2408,  0.1271, -0.3380,  0.2868, -0.3859,
#         -0.3555,  0.4604,  0.2167,  0.2341,  0.4072,  0.4555, -0.2190,  0.4435,
#         -0.0857,  0.2777, -0.1429, -0.2649,  0.1100,  0.0847,  0.0458, -0.5088,
#         -0.0500, -0.4431, -0.4362,  0.0353,  0.3233,  0.1995, -0.0716, -0.4822,
#         -0.4291,  0.0276, -0.2670, -0.2340,  0.1192, -0.4347,  0.5394,  0.5226,
#          0.0870,  0.3905,  0.5253, -0.0031, -0.3665, -0.0633, -0.3047, -0.3319,
#          0.0076, -0.3711, -0.2283,  0.3391, -0.0397, -0.4978, -0.4102,  0.3291,
#         -0.0849, -0.1428, -0.0420,  0.2761,  0.4503,  0.2582, -0.2524,  0.1473,
#          0.1943,  0.3597,  0.0439,  0.0201, -0.4295,  0.0094, -0.5695, -0.3918,
#         -0.5128,  0.0769,  0.5250, -0.2545, -0.0586, -0.1991,  0.4180,  0.5021,
#         -0.2710,  0.0402, -0.3913, -0.1044,  0.5640, -0.1343, -0.0307, -0.5709,
#         -0.4168,  0.5286, -0.1336, -0.3746, -0.3118, -0.4123, -0.0616, -0.4566,
#         -0.1007,  0.2887, -0.4709, -0.4531,  0.4064, -0.5439,  0.2955, -0.4362,
#         -0.4068,  0.3948, -0.5392,  0.1525,  0.5675,  0.1724, -0.5208, -0.3180,
#          0.0039, -0.5210,  0.4504,  0.0697,  0.2998,  0.3256, -0.2004, -0.3629,
#         -0.3666,  0.3179, -0.5306, -0.4801,  0.3706,  0.1290,  0.2378, -0.0448,
#         -0.2541, -0.4762,  0.2890, -0.5395,  0.0084, -0.0185, -0.5342, -0.3863,
#          0.2996, -0.5023,  0.3282, -0.3981, -0.2113, -0.1212, -0.1715,  0.3330,
#          0.3368,  0.4572, -0.1721,  0.1833,  0.2932,  0.0418,  0.3771,  0.5228,
#         -0.2561,  0.0193,  0.4089, -0.2522, -0.3781,  0.0419, -0.5688,  0.1244,
#          0.3271,  0.5519, -0.1438,  0.3209, -0.4199,  0.0303, -0.4964,  0.3757,
#          0.4610, -0.4880,  0.5452,  0.3394, -0.0948, -0.1607, -0.4627, -0.1787,
#         -0.0479, -0.1698,  0.0042, -0.0063,  0.1834,  0.3442, -0.2567,  0.4695,
#         -0.3396,  0.4853,  0.3311, -0.2432, -0.4547,  0.2416,  0.0245, -0.5721,
#          0.5550, -0.2136, -0.5787,  0.5056,  0.1890, -0.4200, -0.4025,  0.0583,
#         -0.0290,  0.0718,  0.2747, -0.5188, -0.4958, -0.3299, -0.3232, -0.3036,
#          0.3807,  0.1682,  0.0994,  0.0123, -0.5050, -0.1309, -0.0862,  0.1735,
#          0.3657, -0.2942, -0.0515,  0.1181,  0.1455, -0.4975,  0.3112,  0.2505,
#          0.5151, -0.5502,  0.4763, -0.2466,  0.3284, -0.2087,  0.5186,  0.3113,
#         -0.2745, -0.2228, -0.1524, -0.0358,  0.1085,  0.0812,  0.1153, -0.3129,
#          0.4997,  0.4219,  0.3576,  0.4132,  0.5533, -0.3676, -0.3450, -0.5067,
#          0.2507, -0.0981,  0.1846,  0.1661,  0.3873,  0.0290,  0.5322, -0.2536,
#         -0.4673,  0.2817, -0.2455, -0.2618, -0.1829,  0.2275, -0.5077,  0.1419,
#          0.1090,  0.1163, -0.1180, -0.2704,  0.4213,  0.2980, -0.0347, -0.4352,
#         -0.2169, -0.1340, -0.5768,  0.4986, -0.2068, -0.4768,  0.2729,  0.0970,
#          0.1189,  0.2046, -0.1145, -0.0626, -0.0751,  0.2430,  0.3025,  0.2358,
#          0.0117,  0.4658,  0.1759,  0.5549, -0.4624, -0.2589,  0.0997,  0.1819,
#         -0.0238, -0.3876,  0.3612, -0.3771, -0.3031,  0.0700,  0.1771,  0.4460,
#         -0.4087,  0.4046, -0.3099, -0.4838,  0.4893, -0.3948,  0.3477,  0.2439,
#         -0.3866,  0.0896,  0.4223,  0.3261,  0.3489, -0.5182,  0.0310,  0.2468,
#         -0.1670,  0.5538,  0.1284,  0.0349,  0.0743,  0.0164,  0.4482,  0.2362,
#         -0.0504,  0.4120,  0.4114, -0.1274, -0.5733, -0.3512,  0.3352,  0.2698,
#          0.0953, -0.2653,  0.3472, -0.4698, -0.4871, -0.5453, -0.4955, -0.4521,
#          0.1083,  0.0152,  0.0389, -0.4222, -0.4735,  0.1807,  0.1176, -0.4871,
#         -0.5319,  0.5582, -0.5345, -0.3511,  0.5242, -0.3795, -0.5765, -0.3439,
#          0.4925, -0.4835, -0.1596,  0.1842,  0.0905, -0.1338,  0.0043,  0.3293,
#          0.5112, -0.1895, -0.1765, -0.2145, -0.0196, -0.0736,  0.3081,  0.0529,
#          0.1012, -0.2621,  0.2177, -0.0895, -0.2004, -0.0611,  0.5219, -0.3454,
#         -0.3419, -0.1686,  0.1687,  0.0680,  0.2299, -0.4461, -0.4278, -0.1666,
#          0.5438,  0.2980,  0.1774,  0.3133, -0.3310,  0.2083,  0.0258,  0.0475,
#          0.5617,  0.1726,  0.2075,  0.1302, -0.3792, -0.2439,  0.4288, -0.0509,
#          0.4852,  0.3111,  0.2138,  0.3702,  0.5474, -0.3914,  0.4049,  0.0817,
#         -0.0668, -0.0169, -0.2481,  0.1983,  0.4546, -0.0562, -0.0340,  0.1725,
#         -0.1111, -0.1653, -0.5170, -0.1494, -0.3195, -0.0030,  0.4212,  0.0500,
#          0.0888,  0.5120, -0.0623], requires_grad=True), Parameter containing:
# tensor([[-0.0230, -0.0115,  0.0002,  ...,  0.0013, -0.0130,  0.0113],
#         [-0.0024, -0.0300,  0.0293,  ...,  0.0189, -0.0274, -0.0156],
#         [-0.0268, -0.0213, -0.0047,  ...,  0.0316,  0.0228, -0.0376],
#         ...,
#         [-0.0141,  0.0337,  0.0254,  ...,  0.0165,  0.0267, -0.0173],
#         [ 0.0321, -0.0126, -0.0017,  ..., -0.0176,  0.0018,  0.0301],
#         [-0.0298, -0.0318,  0.0268,  ..., -0.0003,  0.0158, -0.0206]],
#        requires_grad=True), Parameter containing:
# tensor([-7.4487e-03,  1.4697e-02,  1.8189e-02, -2.1421e-02,  2.8543e-02,
#          2.2181e-02,  1.9918e-02,  1.2793e-02,  2.5495e-02,  2.2588e-02,
#          1.6025e-02, -8.8453e-03, -7.0436e-03, -2.3311e-03, -1.8607e-02,
#         -9.5370e-03, -1.2128e-02,  5.1497e-03,  4.3444e-03, -2.6624e-02,
#         -1.7092e-02, -2.6033e-02,  2.4757e-02, -1.7330e-02, -1.0334e-02,
#         -2.2848e-02,  1.6834e-02,  7.8508e-03,  9.0624e-03, -3.1399e-02,
#          1.1610e-02,  1.3648e-02,  1.5273e-02, -1.5813e-03, -2.5559e-03,
#          2.6196e-02,  2.3121e-02,  5.8172e-03,  2.4086e-02,  2.1571e-02,
#         -2.1987e-02,  2.2005e-02,  6.4230e-03, -2.7450e-02,  2.5295e-02,
#         -2.9251e-02, -5.6616e-03, -4.9454e-03,  8.9645e-03,  3.3267e-02,
#         -2.5601e-03, -1.5112e-02, -1.4543e-02,  1.8251e-02, -1.3628e-02,
#         -1.7059e-02,  1.3899e-02, -1.1023e-02, -1.4225e-02,  2.5828e-02,
#          3.0598e-02, -2.3817e-02,  1.9961e-03, -2.3506e-02, -1.3619e-02,
#         -1.0765e-02, -1.4252e-02,  1.7503e-02, -1.6499e-02,  1.2952e-02,
#         -2.2147e-02,  1.6597e-03, -2.8192e-02, -2.7700e-03, -3.1046e-02,
#         -3.1575e-03,  8.0940e-03, -2.1398e-02, -2.7571e-02, -8.0228e-03,
#         -2.2322e-02, -2.8853e-02,  3.2296e-02,  1.7179e-02,  2.2097e-02,
#         -2.1851e-02,  2.4886e-02, -1.2286e-02,  2.6174e-02, -1.0513e-02,
#         -2.3547e-02,  7.7160e-03, -2.8372e-02,  3.6638e-03, -3.1071e-02,
#          1.9309e-02,  9.1188e-03, -5.5801e-04,  2.5992e-02, -1.3246e-02,
#         -3.0926e-02,  2.7342e-02, -9.7243e-03, -1.8423e-02, -1.0431e-02,
#         -3.0981e-02,  2.8603e-02,  2.4550e-02,  2.8717e-02, -1.0339e-02,
#          3.2337e-02,  2.7078e-03, -8.5499e-03,  2.2176e-02,  1.2535e-04,
#          2.8481e-02, -3.1407e-02,  2.8995e-02,  2.2638e-02,  1.9668e-03,
#          6.7044e-03, -3.7460e-03,  1.0602e-02, -1.8741e-02,  2.7360e-02,
#         -1.9931e-02,  4.8558e-03, -2.6093e-03,  2.1242e-03, -2.8414e-02,
#          1.4621e-02,  2.5641e-02, -1.5654e-02,  1.2623e-02,  4.7686e-03,
#          7.0338e-03, -2.6392e-02, -5.4601e-03,  2.2997e-02,  2.3018e-02,
#          1.9335e-02,  8.0948e-03,  2.5668e-02, -6.2289e-03, -8.4752e-03,
#          2.9747e-02,  1.2772e-02, -2.2460e-02, -2.4984e-02, -1.7168e-02,
#          3.9635e-03, -2.7941e-02,  2.2669e-02,  1.8963e-02,  1.7809e-02,
#          2.7627e-02, -1.8350e-02, -2.4096e-02, -2.0471e-02, -1.2386e-02,
#         -3.1299e-03,  1.3877e-02, -2.5767e-02, -3.2577e-02,  4.5389e-03,
#          1.4584e-02, -1.3493e-02,  1.6845e-02, -1.8803e-02, -3.9594e-03,
#         -9.9400e-03, -8.1128e-03,  1.6099e-02, -1.8034e-02, -2.8062e-02,
#         -2.2388e-02,  1.5194e-03,  5.3519e-03,  3.1750e-02,  1.0255e-02,
#          9.8897e-03,  9.5875e-03, -1.9058e-03,  2.9927e-02,  2.6870e-02,
#          1.7523e-02,  1.7917e-02, -3.9171e-03,  2.2548e-02, -1.1978e-02,
#          2.7727e-02,  2.9883e-02,  1.3563e-02,  2.5921e-02, -3.0295e-02,
#         -1.2410e-02, -1.2889e-02,  1.5802e-02, -3.2854e-02, -1.8004e-02,
#          9.6140e-03, -2.2208e-02, -1.8487e-02, -1.9043e-02, -2.9185e-03,
#          2.8569e-02, -2.5718e-02, -2.5499e-02, -1.0722e-02, -1.8036e-02,
#         -1.4639e-02,  2.0938e-03, -1.8947e-02,  3.1570e-03, -1.5187e-02,
#         -2.0791e-02, -2.2863e-02,  1.3286e-02,  3.0173e-02, -5.8598e-04,
#          1.2169e-02,  1.6190e-02,  2.3164e-02, -1.3521e-02,  1.4877e-02,
#         -1.0158e-02, -1.8595e-02, -1.0197e-02, -1.6373e-02, -1.9104e-02,
#         -2.9724e-02, -1.0733e-02,  1.1409e-02,  1.2373e-02, -3.2518e-02,
#         -8.8389e-03,  2.9270e-02,  2.4230e-02, -5.4014e-03, -5.2420e-03,
#          3.3144e-03, -1.0760e-02, -2.9835e-02,  8.4822e-03, -1.0895e-02,
#          2.8244e-02,  3.3336e-02, -3.9586e-03,  1.6590e-02, -1.2632e-02,
#          2.3865e-02, -9.5998e-03, -1.0586e-03, -3.3224e-02,  2.0680e-02,
#          1.3297e-02, -5.7036e-03, -3.4336e-03,  2.2356e-02, -1.9877e-02,
#          1.5886e-02,  2.4603e-02,  3.1527e-02,  3.4594e-02,  9.9309e-03,
#          5.9076e-03, -1.2528e-02, -1.2970e-03,  2.9338e-02,  9.4960e-03,
#          1.3468e-02,  1.8524e-02, -1.4964e-02,  6.7808e-03,  2.8710e-02,
#         -2.2431e-02, -1.2386e-02, -8.3380e-03,  2.2979e-02,  2.8676e-02,
#         -7.5216e-03, -1.3449e-02, -7.3443e-03,  1.8731e-02, -1.1666e-02,
#          2.9626e-02, -7.3521e-03, -2.6571e-02, -3.2595e-02, -3.1838e-02,
#          4.8482e-04, -8.9395e-03, -1.8735e-02,  2.0895e-02, -1.2782e-02,
#          6.1028e-03,  1.3059e-02, -2.6514e-02,  5.3324e-03, -7.0107e-03,
#          1.9812e-02,  6.7305e-03, -3.1085e-02,  3.1996e-02,  2.1784e-02,
#          2.7642e-02,  1.3673e-02, -3.9625e-03, -4.1565e-03, -2.3698e-02,
#         -2.4703e-03,  3.1333e-02,  3.3898e-02,  1.5293e-03, -1.0845e-02,
#          1.8942e-02,  1.4502e-02,  7.3257e-03,  3.2246e-02,  3.3393e-02,
#         -2.5199e-02,  1.8149e-02,  2.4253e-03,  1.1928e-02,  1.8187e-02,
#          1.6167e-02, -1.6975e-02,  2.6845e-02,  2.6052e-02,  3.2752e-02,
#         -3.5029e-02, -1.7989e-03, -3.4381e-02, -2.9743e-02, -1.5064e-02,
#         -9.2180e-03, -2.3600e-02,  3.3187e-02,  1.0983e-02, -1.4925e-03,
#          1.4890e-02,  9.4933e-03, -1.4405e-02,  9.5131e-03, -2.2294e-03,
#          4.0925e-03, -2.4136e-02, -1.3183e-02,  2.9010e-02,  1.3063e-02,
#         -1.6369e-02,  2.0508e-02,  3.2785e-03, -2.7036e-02, -1.0299e-03,
#         -1.4634e-02,  1.2499e-03, -1.2832e-02,  1.9640e-02, -2.0937e-02,
#          3.3548e-02, -2.2105e-02, -8.0858e-03,  2.9931e-02,  3.0729e-02,
#          5.9163e-03,  1.2845e-02, -2.2068e-02, -2.0388e-02,  3.4966e-03,
#         -7.1744e-03, -7.0424e-03, -1.0760e-02,  2.0020e-02,  3.0121e-02,
#         -1.6936e-02,  2.6324e-02,  2.1169e-02,  3.2512e-02,  2.9045e-02,
#          5.5136e-03, -3.3219e-02,  2.5037e-02,  3.5655e-02, -1.3205e-02,
#         -1.3755e-02,  1.9958e-02, -1.3748e-03, -2.8221e-02,  2.7328e-02,
#         -1.5629e-02,  5.6525e-03, -6.6532e-03, -1.8285e-02, -3.3615e-02,
#         -8.8677e-03, -1.3628e-02, -1.1499e-03, -2.4264e-02, -2.1307e-02,
#         -4.3409e-03,  1.9503e-02,  2.4728e-02,  8.8560e-03,  6.9499e-06,
#          1.2173e-02, -9.1809e-03,  1.9217e-04, -1.7174e-02,  2.6475e-02,
#         -3.3681e-02, -1.0575e-02,  2.0488e-02, -1.5557e-02, -3.1548e-02,
#          2.1478e-04,  4.4287e-03, -1.9828e-02, -3.2017e-03, -1.8842e-02,
#         -2.9550e-02,  2.5738e-02, -2.1219e-02,  1.6742e-02,  1.2226e-02,
#          1.0399e-02,  3.1987e-02,  3.2634e-02, -2.2594e-02, -2.4326e-02,
#          6.7197e-04,  2.6496e-02,  1.9609e-02,  8.4514e-03, -2.6985e-02,
#          1.2484e-02, -8.4143e-03,  7.0294e-03, -2.1362e-02, -1.0089e-02,
#         -1.5743e-02,  2.5558e-02,  1.8209e-02,  3.1934e-02,  2.2663e-02,
#         -2.3369e-02, -1.7101e-02,  1.7006e-02, -3.5022e-02, -2.5759e-02,
#          6.6514e-03,  1.3054e-02, -1.7245e-02,  2.1760e-02, -1.9839e-02,
#          4.3059e-03,  2.3422e-04,  8.5801e-03,  1.4597e-02, -1.3513e-02,
#          5.7054e-05,  3.1101e-02,  2.3083e-02, -6.0878e-03, -2.0490e-02,
#          2.2378e-02, -7.2150e-03, -1.9221e-02,  2.0001e-03, -2.4689e-02,
#         -1.6906e-03,  1.8435e-02, -2.7878e-03, -1.7937e-02,  3.4591e-03,
#          1.1679e-02, -1.0938e-02, -1.8325e-02, -3.4527e-02, -9.1731e-03,
#         -8.2236e-03, -2.8503e-02, -2.9148e-02,  2.9531e-02,  5.5397e-03,
#          2.5015e-02,  8.8723e-03, -2.9980e-02, -1.0878e-02,  9.8364e-03,
#         -5.6205e-03, -3.1959e-02,  2.2059e-02,  2.9161e-02,  2.0468e-02,
#         -1.2179e-02,  1.8138e-02,  1.8758e-02, -2.3226e-02,  3.2232e-02,
#         -2.3837e-03, -2.1720e-03,  3.1128e-02,  4.6101e-03,  2.8987e-02,
#         -2.5197e-02, -1.6690e-02,  2.0253e-02, -2.9136e-02,  1.5743e-02,
#         -2.5996e-03,  1.3863e-02,  1.6172e-02,  7.3228e-04, -2.5104e-02,
#         -1.8013e-02, -9.6907e-03,  2.4667e-02, -1.7485e-02,  2.6608e-02,
#          2.1868e-02, -4.1768e-03,  1.8198e-02, -7.6214e-03, -1.6403e-02,
#          3.1467e-02,  2.2055e-02,  4.1540e-03,  2.9701e-02,  2.0725e-02,
#          2.1559e-02, -2.8508e-02,  2.9749e-02, -1.1753e-02,  7.6746e-03,
#          3.3633e-02, -2.9131e-02,  1.7742e-03,  2.0125e-02, -3.3214e-02,
#          2.8341e-02, -2.6718e-02, -2.8664e-02, -1.1852e-02,  2.8578e-02,
#         -2.3249e-02,  1.2387e-02,  6.1706e-03, -9.3228e-03,  2.5633e-02,
#          1.6895e-02,  3.0199e-02,  3.1993e-02,  2.8015e-03,  5.1203e-04,
#         -1.3733e-02, -1.8928e-02, -3.3047e-02,  1.4925e-02,  1.9782e-02,
#          3.0918e-02, -2.2652e-02, -1.2206e-02,  1.9720e-02,  1.2879e-03,
#         -8.0605e-03, -2.5273e-02,  1.7732e-02, -1.2996e-02,  3.0180e-02,
#         -6.5285e-03,  2.9882e-02, -3.9229e-03,  9.0582e-03, -1.6713e-02,
#          1.4467e-02,  1.0905e-02,  1.6663e-02, -5.5820e-03, -1.9070e-03,
#         -1.0674e-02,  1.3076e-02, -3.0742e-02, -1.9605e-02,  2.3273e-02,
#         -1.0136e-02, -1.2850e-02, -1.1332e-03,  2.7819e-02, -2.0811e-02,
#          2.1269e-03, -3.4675e-02, -7.8888e-03, -2.8627e-02, -2.7327e-03,
#         -1.6283e-02, -2.5437e-02, -2.6182e-02, -9.1303e-03,  2.9280e-02,
#         -2.6547e-02,  2.4576e-02, -2.7595e-02,  3.2126e-02,  1.8710e-02,
#          1.1298e-02,  8.8349e-03, -6.4281e-03, -2.1347e-02,  1.5033e-02,
#         -3.3915e-02,  2.8645e-02, -2.2764e-02,  1.8872e-02, -2.2958e-02,
#          1.9289e-02, -3.0173e-03, -3.3559e-03, -1.1731e-02,  6.4684e-03,
#         -3.5085e-02,  3.2369e-02,  1.8554e-02, -3.3540e-02, -8.6685e-03,
#          1.6775e-02, -9.0154e-03,  4.7198e-03,  1.2530e-02, -2.8532e-02,
#         -2.5923e-02,  1.9028e-02, -2.8744e-02, -1.6212e-02, -1.6823e-02,
#          2.7619e-02, -1.2112e-02, -1.0547e-02,  2.6960e-02, -1.0562e-02,
#          8.4209e-03, -3.4513e-03, -8.5530e-03,  1.3950e-02, -2.2057e-02,
#          1.3209e-02,  1.1884e-02,  3.3759e-02,  3.3281e-02,  8.1127e-03,
#          2.4979e-02,  1.9697e-02,  1.6582e-02,  2.0763e-02,  1.0890e-02,
#          9.5054e-03, -2.0340e-03, -2.3389e-02,  1.8603e-02,  1.9282e-02,
#          1.0240e-02,  7.3058e-03,  2.0042e-02, -2.5788e-02, -1.7638e-02,
#         -2.7467e-02,  3.1853e-02,  1.3621e-03, -2.9592e-02,  6.1431e-03,
#         -1.0196e-02,  1.8662e-02,  1.0159e-02,  3.1378e-02,  1.3117e-02,
#          5.9075e-03,  2.9331e-03, -6.1504e-04, -1.8306e-03, -9.2198e-03,
#         -1.8369e-02, -7.7757e-03, -2.4926e-02,  1.4797e-02, -3.2872e-03,
#          1.2211e-02, -6.7795e-03, -8.2863e-03,  4.5192e-03,  8.2982e-04,
#          7.5252e-03, -1.3557e-02,  2.3928e-02, -3.1954e-02, -1.7709e-02,
#          2.7415e-02,  1.2729e-03,  2.2374e-02, -8.4816e-04,  1.5193e-02,
#         -3.0780e-02, -1.7936e-03,  1.2504e-02, -2.3954e-02,  3.4243e-03,
#         -8.2112e-03, -2.5552e-02, -1.0306e-02, -1.2155e-02, -1.9878e-02,
#          2.3695e-02, -2.0043e-02, -5.9374e-03, -8.0350e-03, -1.4919e-02,
#          3.5746e-03, -1.5082e-02,  2.6745e-02,  4.3956e-03,  9.9890e-03,
#         -2.6494e-02,  3.4856e-03,  1.0992e-02,  1.4571e-02,  2.1195e-02,
#         -1.7772e-02,  2.3805e-02,  2.5245e-03,  2.9216e-02, -4.3362e-03,
#          1.0775e-02,  3.3863e-02,  2.4154e-03, -2.7214e-02, -3.3716e-02,
#         -5.6058e-03, -1.3475e-02,  8.7195e-03, -2.3890e-02,  2.4564e-02,
#          1.9346e-02, -2.2133e-02,  3.1932e-02, -1.6063e-03,  3.6573e-03,
#          5.8466e-03,  7.8625e-03,  2.6576e-02, -6.1509e-03,  3.0489e-03,
#         -2.8598e-02, -8.6835e-03,  1.6867e-02,  6.4389e-03, -3.3364e-02,
#         -2.4010e-02,  5.2636e-03,  1.6303e-02, -5.2049e-03,  3.4142e-02,
#         -3.1905e-02, -7.8159e-03, -8.1552e-03, -4.4740e-03, -2.1453e-02,
#         -5.3903e-04, -9.6175e-03, -6.0318e-03,  3.7888e-03, -2.3228e-02,
#         -2.8764e-03, -3.5972e-03,  3.1937e-02, -4.5544e-04,  8.9446e-03,
#         -1.7953e-02,  1.7132e-02, -3.2623e-02, -2.6352e-02,  6.7692e-03,
#          2.5306e-02, -1.8823e-02,  1.3027e-03, -1.7241e-03, -2.3650e-02,
#         -2.1614e-02, -7.6175e-03,  1.7385e-02,  4.7902e-03,  1.8385e-02,
#          1.6310e-02, -2.3032e-02, -2.8424e-02,  5.2682e-03,  9.0011e-03,
#         -2.0634e-02,  2.6915e-02, -6.9943e-03,  3.8912e-03,  4.4749e-03,
#          8.6480e-03, -2.8092e-02, -1.0885e-02, -1.8312e-02, -2.2356e-03,
#          1.5508e-02, -4.5561e-03,  1.9451e-02, -3.1440e-03, -3.2522e-02,
#         -3.4776e-03, -8.8831e-04,  2.8750e-02, -3.3755e-02,  3.1666e-02,
#         -2.5413e-02,  2.4808e-02, -3.4798e-04,  3.2415e-02,  2.6930e-02,
#         -1.1999e-03,  1.4354e-02,  2.1362e-03,  2.7750e-02, -6.3487e-03,
#          8.0317e-03, -2.4106e-03, -2.3522e-05,  7.9354e-03,  8.7542e-03,
#          7.9646e-03, -2.4973e-02, -7.9198e-03, -5.8943e-04,  3.3459e-03,
#         -3.6430e-04, -2.1559e-02, -2.8166e-02, -3.4025e-02, -1.0342e-02,
#          2.7012e-02, -9.8377e-03,  1.9506e-02, -1.9894e-03, -1.4018e-02,
#         -2.0683e-02,  1.2268e-02,  6.6622e-03,  2.5272e-02, -6.1035e-03,
#         -8.0014e-03, -1.5103e-02,  2.1614e-02,  2.9834e-02, -8.5504e-03,
#          2.6375e-02,  1.2814e-02,  1.0590e-02, -5.6151e-03, -3.0418e-02,
#         -7.9381e-03,  3.6985e-04,  2.4725e-02,  2.7959e-03,  1.0847e-02,
#         -1.0080e-02,  2.2252e-02,  1.8585e-02, -2.1953e-02, -1.0732e-02,
#         -1.2085e-02,  2.5417e-03,  3.0708e-02, -8.2395e-03, -2.0523e-02,
#          3.0786e-02,  2.8953e-02, -2.5118e-02, -1.9545e-02,  3.2561e-02,
#          1.2496e-02,  2.5610e-02, -3.9593e-04,  1.7377e-02, -9.6441e-03,
#         -2.2914e-02, -3.1767e-02, -2.3016e-03,  1.4144e-02, -3.1374e-02,
#          3.5552e-03, -2.2241e-03, -2.4742e-02, -1.6879e-02,  2.5244e-02,
#          2.3226e-02,  1.2729e-02, -2.3470e-02, -2.6177e-02,  2.5296e-02,
#          1.3904e-03, -1.1275e-02,  1.8244e-02, -2.8539e-02,  8.1270e-03,
#          2.1578e-02,  2.9779e-02, -1.7482e-02,  2.3602e-02,  4.2660e-03,
#         -2.1095e-02,  1.3915e-02,  1.1208e-02,  2.3307e-02, -1.1356e-04,
#          1.2780e-02, -1.7859e-02,  8.7622e-03,  2.0560e-02,  2.0446e-02,
#         -1.7073e-02, -3.1790e-02, -9.5088e-03, -1.5182e-02, -3.4173e-03,
#         -9.6644e-03,  1.5989e-02, -2.9250e-02,  2.6250e-03,  1.0659e-02,
#         -8.8401e-03,  2.5108e-02,  2.9623e-02,  1.2387e-02, -1.4631e-02,
#          2.0311e-03,  9.0267e-03, -1.6261e-02, -1.5020e-02, -2.2927e-02,
#          1.0938e-02, -6.4121e-03, -7.6177e-03, -1.3453e-02,  3.1659e-02,
#          1.6471e-02,  1.5221e-02, -2.3089e-02, -1.7204e-02, -7.4887e-03,
#          6.8231e-04], requires_grad=True), Parameter containing:
# tensor([[-2.3034e-02, -3.0022e-02, -8.3155e-03,  2.2399e-02,  4.9010e-05,
#           2.4541e-02,  9.7841e-03,  1.4650e-02,  2.3386e-02, -1.3130e-02,
#          -2.2744e-02,  5.8882e-04, -2.2510e-02,  2.6441e-04,  2.0091e-02,
#          -8.4445e-03,  2.7329e-02,  2.8363e-02,  2.5817e-02,  3.1519e-02,
#          -2.8705e-02,  7.5164e-04, -2.8698e-02, -2.8828e-02,  6.6436e-03,
#           3.0318e-02, -1.2557e-03,  1.3913e-02,  2.2430e-03,  1.6304e-02,
#           7.3189e-03,  2.4475e-02,  1.2913e-02, -2.3240e-02,  2.5142e-02,
#          -2.6805e-02, -2.0151e-02,  2.2691e-02,  6.0232e-03,  2.2383e-02,
#           9.8732e-03, -2.2442e-03,  1.4111e-02, -4.3281e-03, -9.7966e-03,
#          -3.0319e-02,  1.6338e-02,  1.7200e-02,  2.8861e-02,  1.8001e-02,
#           2.1331e-02,  1.4173e-02,  1.5448e-02,  2.9148e-02,  1.7233e-02,
#          -1.1458e-02,  1.7066e-02,  1.2360e-02,  1.2514e-02,  1.3690e-02,
#           3.8001e-03, -3.5039e-03, -6.0353e-03, -1.7121e-02, -2.1114e-02,
#           4.8753e-03, -1.8875e-03, -1.1423e-02, -1.4340e-02, -3.0345e-02,
#           2.3385e-03, -4.0552e-03, -1.3323e-02, -2.0399e-02, -2.1497e-02,
#          -2.7708e-02,  1.8381e-02,  3.0956e-02, -8.6024e-03, -2.3058e-02,
#           8.1349e-03,  1.4513e-02,  1.7817e-03,  2.0703e-02,  8.2891e-03,
#          -1.0922e-02,  9.2520e-03, -1.9638e-02,  5.2158e-03, -3.0568e-03,
#          -1.9118e-02, -2.4485e-03, -2.2266e-02,  2.7554e-02,  4.3907e-03,
#           9.8041e-03,  6.1729e-03, -5.1110e-03, -2.1794e-02, -3.1719e-02,
#           1.1455e-02, -1.3102e-02, -7.1478e-03,  7.0687e-03, -1.6067e-02,
#           5.9424e-03,  2.4874e-02,  8.9744e-03,  2.1574e-02,  8.4495e-03,
#           1.0375e-02,  2.8301e-02,  2.6360e-02,  8.2671e-03,  1.6915e-02,
#           1.8290e-04, -1.3347e-02, -2.1239e-03,  7.3126e-03, -1.3175e-02,
#           3.1615e-02,  1.7289e-02, -2.0581e-02, -5.8520e-03,  7.0541e-03,
#          -2.1669e-03,  2.8677e-02, -2.0514e-02,  6.5443e-03,  1.8290e-02,
#           6.8069e-03, -3.9473e-03, -2.3791e-02, -2.4335e-02, -5.8046e-03,
#          -8.0121e-03, -1.4957e-02,  2.4550e-02, -2.4286e-02,  6.9911e-04,
#          -2.0943e-02,  8.4233e-03, -6.6382e-03,  5.3343e-03, -7.6273e-03,
#           2.6411e-02,  1.6032e-02, -4.5160e-03, -9.6976e-03, -2.3118e-02,
#           2.8709e-02,  2.1012e-02, -4.7469e-03,  1.2919e-02, -1.7017e-02,
#          -3.6852e-03, -1.5125e-02, -1.8588e-02, -9.9410e-03,  3.0888e-02,
#           2.3687e-02,  1.8172e-05,  2.7766e-02, -2.7658e-02, -2.5378e-03,
#           1.3150e-02, -1.5935e-03,  1.0512e-02,  3.4336e-03,  5.8471e-03,
#          -3.1099e-02,  1.6100e-03,  6.5269e-03,  2.9515e-02,  1.7518e-02,
#          -1.6099e-02,  3.0058e-02, -2.7810e-02, -7.2053e-03,  2.2233e-04,
#          -2.0352e-02,  2.4189e-02,  2.7062e-02,  2.5505e-03,  3.0942e-02,
#           3.3835e-03, -2.6639e-02,  1.5943e-02, -2.6317e-02, -1.3896e-03,
#           1.8049e-02, -1.3727e-02,  1.2427e-02,  2.6308e-02,  2.4041e-02,
#          -5.6110e-03,  1.5783e-02, -6.8385e-03,  2.1549e-02,  3.1761e-02,
#           1.6240e-02,  1.4382e-02, -1.6120e-02,  9.7058e-05, -1.7374e-02,
#          -2.0761e-02, -2.0355e-02, -2.0202e-02, -2.1254e-02, -5.4811e-03,
#           5.4168e-03,  2.3832e-03,  8.0222e-03,  2.2740e-02, -5.0783e-03,
#           3.0792e-02,  2.7339e-02, -3.0697e-02,  2.0246e-02, -2.4664e-02,
#           1.0979e-02, -1.4981e-02, -2.4712e-02,  6.7187e-03, -7.3065e-03,
#          -2.0245e-02, -8.7245e-03, -6.5916e-03,  1.4922e-02,  4.3723e-04,
#           2.1066e-02,  2.8824e-02, -3.2745e-02, -2.7250e-02, -2.6801e-02,
#           4.1199e-03, -5.8794e-03, -2.4620e-02,  1.7576e-02,  3.0310e-02,
#           1.6856e-02, -2.1089e-03, -1.8174e-02, -8.0022e-03, -3.4879e-03,
#           1.1378e-02, -3.3195e-03,  2.2095e-02,  1.0083e-02, -2.6745e-02,
#          -2.7684e-02,  1.7442e-02, -2.3885e-04, -1.4887e-02, -6.4816e-03,
#          -6.0535e-04,  6.9546e-04,  3.7519e-03, -2.5482e-02,  8.7476e-03,
#           2.1630e-02,  3.2085e-02, -1.3125e-02, -2.0268e-02,  2.1173e-02,
#           6.1958e-03, -2.4409e-02, -1.7575e-02,  1.9426e-02,  2.9556e-02,
#           1.0401e-02, -2.6040e-02,  1.6752e-02,  4.8640e-04, -5.6810e-03,
#           4.0364e-03,  3.1409e-02,  1.9696e-02, -1.1566e-02,  2.2876e-02,
#          -4.2504e-03,  2.0900e-02, -1.7955e-02, -2.5374e-02,  5.0315e-03,
#           2.0412e-02,  2.9603e-02, -8.4941e-03, -1.0180e-02, -8.8753e-03,
#          -7.6365e-03, -2.7265e-02,  1.5544e-02,  2.2835e-02, -2.8282e-02,
#           1.4436e-03, -1.8616e-02, -2.1649e-03,  5.2806e-03,  2.4661e-02,
#          -9.0162e-03, -9.7121e-03, -1.3720e-02, -1.5615e-02,  6.0308e-04,
#          -2.9283e-02,  8.7591e-03,  2.4325e-02,  9.4640e-04, -4.9387e-03,
#          -1.0003e-02, -1.6037e-02, -2.8453e-03,  3.0167e-02, -2.4284e-04,
#           1.1208e-02, -1.6202e-03, -1.0401e-02,  2.6843e-02,  4.7570e-03,
#           1.1520e-03, -2.2218e-02,  2.8086e-02,  2.2075e-02,  1.9070e-02,
#           1.0763e-02,  6.2699e-03, -7.5168e-03, -2.3748e-02, -1.3072e-02,
#          -1.7537e-02, -7.9869e-04,  6.3113e-03, -6.7345e-03, -2.0594e-02,
#           3.7726e-03, -1.4587e-02,  2.5924e-03, -3.1005e-02, -7.1899e-04,
#          -1.5219e-02, -2.1846e-02,  6.4224e-03, -3.1189e-02, -2.2485e-02,
#          -2.8232e-02, -1.3731e-02,  3.1307e-02, -1.0673e-03,  2.7934e-02,
#          -1.4305e-02, -2.3463e-02, -7.6722e-03, -2.8283e-02, -2.8159e-02,
#           3.0903e-02, -3.1179e-02, -1.0583e-02,  2.4164e-02,  4.2862e-02,
#           2.5818e-02,  1.3588e-02, -8.7280e-03,  2.9034e-02, -2.7607e-02,
#          -2.7918e-02, -3.1653e-03,  2.3062e-02,  1.1314e-02,  1.8622e-02,
#           1.9753e-02,  2.2220e-02,  1.0214e-02, -2.0315e-02, -3.0250e-02,
#          -2.7569e-02,  2.1377e-03, -1.1002e-02,  3.0140e-02, -1.9758e-02,
#           2.3247e-02,  2.3343e-02,  1.3418e-02, -3.6218e-02,  1.5876e-02,
#           1.5732e-02,  9.5759e-03,  1.4638e-02,  1.6807e-03,  2.0963e-02,
#           2.5777e-03,  3.1318e-02, -2.5967e-03,  1.3352e-02, -1.6305e-03,
#          -8.7502e-03, -1.9955e-02, -2.8631e-02,  2.3180e-02, -4.0587e-03,
#           2.5773e-02, -2.2672e-02, -2.6659e-02, -2.1485e-02,  5.4658e-03,
#           1.6085e-02, -2.0697e-02,  2.3859e-02,  1.7322e-02,  2.0418e-02,
#          -8.4782e-03, -1.8321e-02, -2.9956e-02, -2.6773e-02,  8.8108e-03,
#           2.0673e-02, -2.5671e-02,  9.8271e-03, -1.3286e-02, -2.3078e-02,
#          -1.9973e-03,  1.8448e-02,  7.8605e-03,  8.9411e-03, -2.6524e-02,
#           2.0226e-02, -1.4592e-02,  2.9144e-02, -2.9282e-02,  1.7567e-02,
#           1.3128e-02, -2.5443e-02, -1.7575e-02,  6.8060e-03,  1.6948e-02,
#          -2.4093e-02, -2.1347e-02,  2.2430e-02, -1.3733e-02, -1.2621e-02,
#           9.3438e-03,  1.5283e-02, -1.8992e-02,  6.2487e-03,  2.3257e-02,
#          -1.7856e-02,  9.8013e-04,  1.5087e-02, -7.3331e-03,  1.8406e-02,
#          -2.7723e-03, -1.6646e-02, -1.1521e-02,  1.7273e-02, -2.4477e-02,
#           4.9510e-03, -2.0222e-02, -1.4977e-02, -1.4177e-02,  1.0613e-04,
#          -2.8034e-02, -2.7269e-02, -2.5573e-03, -7.9386e-03,  1.8339e-02,
#           2.9830e-02, -2.9911e-02, -1.6538e-02, -4.0604e-03,  2.6738e-02,
#           1.1872e-02, -2.3940e-03, -1.6966e-02,  2.0443e-02, -3.5490e-03,
#           2.9699e-02, -2.7064e-02,  1.9781e-03, -7.2597e-03,  8.5318e-03,
#           1.2191e-02,  3.6889e-03, -8.8823e-03, -2.7262e-02, -1.9042e-02,
#          -2.3913e-03,  6.6689e-03,  4.4283e-03,  1.3141e-02,  1.4706e-02,
#          -3.2367e-03,  1.6855e-02, -1.1650e-02, -2.0613e-02, -2.5651e-02,
#          -1.8940e-02,  3.2215e-02,  2.4177e-02, -1.0119e-02,  2.8968e-02,
#           8.3350e-03,  1.2671e-02,  2.2957e-02,  1.0386e-02,  2.7773e-02,
#          -6.1832e-03,  3.8824e-03, -2.1189e-02, -2.1830e-02,  2.5568e-02,
#          -2.6194e-02, -1.9564e-02,  9.0416e-03,  6.6898e-03, -6.0015e-03,
#          -2.8576e-02, -1.5978e-04, -3.0018e-03,  1.4781e-02,  1.0611e-02,
#           2.4035e-03,  2.8961e-02, -5.9715e-03, -1.9356e-02,  7.5436e-03,
#          -1.2946e-02, -1.4902e-02,  2.3430e-02, -1.3412e-02,  1.8381e-02,
#           1.5392e-02,  2.5561e-03,  2.7685e-02,  3.2626e-03,  2.9109e-02,
#           5.7891e-03,  1.6877e-02,  7.2305e-03, -2.7783e-02, -1.9402e-02,
#           8.7519e-03, -1.5795e-02,  1.8098e-02, -1.0620e-02,  2.4879e-02,
#          -3.1192e-02, -1.2155e-02, -2.8510e-02, -2.1073e-03,  8.8223e-03,
#          -1.1753e-02, -1.1575e-02,  1.4335e-02,  3.1729e-02, -2.4718e-02,
#          -1.0193e-02,  7.6084e-04,  2.5680e-02, -2.7106e-02,  1.9505e-02,
#           2.1563e-02,  1.4220e-02,  1.8141e-02,  1.3511e-02,  3.0499e-02,
#           4.4208e-03,  2.1253e-02, -2.2453e-02, -1.5635e-02, -1.2309e-02,
#           1.5995e-02, -2.3982e-02,  2.5816e-02,  4.0533e-03, -1.4297e-02,
#          -3.4868e-03,  6.3890e-03, -1.1007e-02,  7.5020e-03, -1.8042e-03,
#          -1.4128e-02, -6.4973e-03,  8.6819e-03,  1.6963e-02, -2.7257e-02,
#           2.9824e-02, -8.9742e-03, -1.2077e-02, -2.0002e-02, -8.0487e-03,
#           1.7374e-04, -9.7143e-03, -1.8991e-02, -2.1400e-02,  2.2626e-02,
#          -7.4873e-03,  2.2248e-02, -1.3038e-02,  2.2180e-02, -1.8680e-03,
#          -1.2773e-02, -3.6796e-03, -5.6356e-03, -2.2699e-02, -9.3350e-03,
#           1.3665e-02, -2.0914e-02, -2.2327e-02, -3.3119e-03, -1.2838e-02,
#          -1.0651e-02, -2.8113e-03,  2.2021e-02, -3.0646e-02,  2.0509e-02,
#          -1.2472e-02, -2.0967e-02, -2.5782e-02, -3.1062e-02, -2.8018e-02,
#          -2.4781e-02, -1.0170e-02, -1.1500e-02, -1.4157e-02,  8.4673e-03,
#          -1.8725e-02,  1.4584e-03, -1.5016e-02, -6.3635e-03,  8.7333e-03,
#          -1.7013e-02, -7.0574e-03,  7.3983e-04,  1.0714e-02, -3.1661e-02,
#           2.6202e-03, -4.1418e-03, -5.2588e-03,  1.3510e-02, -7.0236e-03,
#          -9.1063e-03,  5.5409e-03, -2.5933e-02, -4.5329e-04, -3.0036e-02,
#          -4.1766e-03,  4.4265e-04, -1.6495e-02,  2.1334e-02,  2.8259e-02,
#           1.9332e-02, -2.3221e-02,  2.0507e-02,  2.3852e-02,  5.3718e-03,
#          -1.1058e-02,  1.4574e-02,  3.1978e-02,  1.7982e-02,  6.3096e-04,
#           1.5430e-02,  1.9230e-02, -2.8978e-02,  3.5665e-03, -1.0564e-02,
#           6.1287e-03, -2.8823e-02,  2.9021e-02, -2.9753e-02,  1.3982e-02,
#          -2.9980e-02,  1.2557e-02,  1.8348e-02,  1.0755e-02,  6.7396e-03,
#          -2.0546e-03,  2.2346e-02, -2.3202e-02,  5.4953e-03, -2.2014e-02,
#           1.6579e-02,  2.6599e-02,  2.7566e-02,  1.4876e-02,  2.1047e-04,
#           2.8336e-02,  2.8064e-02,  1.9469e-02, -1.3497e-02,  1.6557e-02,
#           8.7262e-04,  2.9327e-02, -1.4471e-03,  1.7423e-02,  7.9326e-03,
#           9.2998e-03, -1.2638e-02,  2.6577e-02,  6.1924e-03,  2.4498e-02,
#           1.4016e-02, -5.2968e-03,  3.8881e-03, -1.1445e-03, -2.6461e-02,
#           2.2568e-02,  3.1428e-02, -1.1835e-02, -2.7541e-02, -1.6705e-02,
#          -1.1392e-02,  1.6342e-02,  2.2284e-02, -1.0392e-02, -2.5902e-02,
#          -2.8012e-02,  2.6254e-02, -1.2765e-02,  4.5893e-03, -7.8011e-03,
#           9.1281e-03,  2.8897e-02, -9.6038e-03,  1.5134e-04, -1.4454e-02,
#          -1.5682e-02, -2.6998e-02,  9.3219e-03, -1.6541e-02, -2.4518e-02,
#           3.0804e-02,  2.9600e-02,  2.3558e-02,  3.2961e-04, -3.0142e-02,
#           2.1461e-02, -9.4307e-03, -8.4092e-03,  9.5361e-03, -2.6046e-02,
#          -1.4169e-02, -4.2447e-03, -2.9484e-02,  1.7330e-02, -1.0720e-03,
#           1.0277e-02,  2.8566e-02,  1.1286e-03, -1.5542e-02, -1.0786e-02,
#           2.5223e-02,  1.3621e-02, -3.1081e-02,  5.3393e-03,  1.2445e-02,
#           1.9490e-02,  1.4043e-03, -3.0697e-02, -1.0483e-02,  9.4352e-03,
#          -2.3404e-02,  1.4285e-02,  1.3450e-02, -1.0795e-02, -8.6684e-05,
#          -8.2561e-03,  1.1092e-02, -1.4651e-02, -2.9767e-02,  4.5541e-03,
#           1.8088e-03, -2.5180e-02,  1.7880e-02,  1.5189e-02,  1.4398e-02,
#          -1.7391e-03,  1.4773e-02, -2.6024e-02, -1.7855e-02, -3.0412e-02,
#           2.9361e-02, -2.5590e-02, -1.1497e-02, -1.4840e-02,  2.0468e-03,
#           1.4583e-02, -2.5205e-02,  3.1511e-02, -5.1816e-04, -2.4969e-03,
#           2.6782e-02, -1.3341e-02, -1.3610e-02, -2.2280e-02, -1.4610e-02,
#           1.8599e-03,  6.0237e-03,  3.1547e-02, -2.5399e-02, -2.3836e-02,
#          -2.6812e-02, -1.8263e-02, -1.0211e-02,  9.2099e-03, -2.0657e-02,
#          -2.3862e-02,  2.0851e-02, -2.2735e-02,  1.0561e-02, -1.1691e-02,
#          -2.0171e-02, -2.2399e-02,  8.5430e-04,  2.7830e-02,  2.8206e-02,
#          -2.3879e-02,  1.1196e-02, -4.1043e-03, -2.9989e-02, -2.2411e-03,
#           1.8035e-02,  5.6263e-03,  5.4781e-03, -8.6444e-04, -1.4884e-02,
#          -2.3547e-03,  2.3227e-02, -1.3512e-02, -1.0416e-02,  1.3051e-02,
#          -1.5043e-02, -2.5463e-02,  8.6667e-03,  2.2629e-02,  2.4096e-02,
#           1.7882e-02, -2.7627e-02, -4.0419e-03,  1.3545e-02,  6.8346e-03,
#           2.2994e-02, -2.7614e-03,  2.0270e-02,  9.2415e-03, -3.1295e-02,
#           6.6556e-03,  2.8585e-02,  1.5980e-02,  2.7098e-02, -3.5683e-03,
#          -1.7939e-02, -7.7373e-03, -2.7563e-02,  3.2018e-02, -2.5919e-02,
#           3.7375e-03,  2.4782e-02, -8.1774e-03, -2.1618e-02,  6.7963e-04,
#           1.9072e-02,  2.9801e-02, -9.4571e-03,  2.9169e-02, -2.2079e-03,
#          -4.9863e-03,  2.0993e-02, -2.9533e-02,  2.5058e-03,  2.2914e-02,
#           2.3116e-02, -1.7571e-03, -1.3140e-02,  2.0656e-02, -6.0943e-03,
#           1.6870e-02, -2.5456e-02, -2.9936e-02,  1.7863e-02, -8.8403e-03,
#           2.8801e-02,  2.9179e-02,  1.1647e-02,  1.6679e-02,  2.9607e-02,
#          -1.8823e-04,  2.0164e-02,  2.1988e-02, -2.7186e-02,  1.2240e-02,
#           5.9944e-03,  1.4187e-02, -3.0767e-02, -1.5271e-02,  5.3389e-03,
#           1.4404e-02,  6.3039e-03,  1.1204e-02, -1.2000e-02, -3.0934e-03,
#          -3.0955e-02,  3.3417e-02,  8.1823e-03,  6.4656e-03,  3.0074e-02,
#          -2.2648e-03,  1.4399e-03, -2.7922e-02,  2.1540e-02,  2.4542e-02,
#           1.8802e-02,  2.6529e-02, -4.4488e-03,  5.1588e-03,  3.8337e-03,
#           2.0764e-02, -2.6803e-04,  2.3254e-02, -9.3052e-03, -2.6988e-03,
#          -2.3882e-02,  6.9104e-04,  2.7089e-02,  8.6919e-03, -2.9739e-02,
#           4.5873e-03,  8.2374e-03,  1.7412e-02, -2.8611e-02, -2.7504e-02,
#           2.5615e-04, -2.1096e-02, -3.0661e-02,  3.1356e-02, -8.1808e-03,
#          -2.4663e-02, -2.3353e-02, -2.3970e-02, -2.5898e-02,  4.4282e-03,
#           3.0026e-03,  1.5095e-02, -6.1679e-03,  6.3061e-03, -1.5876e-02,
#          -9.6868e-03, -3.0867e-02,  2.0866e-02,  9.4526e-03, -5.5329e-02,
#          -5.1942e-03]], requires_grad=True), Parameter containing:
# tensor([0.0281], requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 0.0218,  0.5239, -0.1728],
#         [ 0.2383, -0.2804,  0.0983],
#         [-0.5354, -0.5441,  0.0681],
#         ...,
#         [ 0.1954,  0.5206, -0.2022],
#         [ 0.4110, -0.0352, -0.0605],
#         [-0.2288, -0.1308,  0.2053]], requires_grad=True), Parameter containing:
# tensor([-0.5563, -0.3818,  0.1068, -0.0460,  0.4071,  0.4021,  0.3479, -0.3041,
#          0.2244,  0.0718, -0.0049, -0.2536, -0.4152, -0.0226,  0.1733,  0.4650,
#          0.2917,  0.0442, -0.4351,  0.5098,  0.3299, -0.4532,  0.1896,  0.2639,
#         -0.3345,  0.0337,  0.1326,  0.4005, -0.5640, -0.1094,  0.0241, -0.3049,
#         -0.1328,  0.5232, -0.5129, -0.1281,  0.2191,  0.2618,  0.4820, -0.0530,
#         -0.4718,  0.1786,  0.2077,  0.0274, -0.1160, -0.5413, -0.0825,  0.1859,
#          0.3271, -0.1032, -0.0975, -0.1710, -0.3692,  0.5535, -0.5657,  0.2642,
#         -0.1752, -0.5310, -0.1825,  0.2438,  0.5516, -0.0945,  0.3723,  0.5589,
#          0.1902,  0.4184,  0.1350, -0.3173, -0.1333,  0.2774,  0.2044,  0.0776,
#          0.0139, -0.5239, -0.0249,  0.4041, -0.4692, -0.5597,  0.1387,  0.5323,
#          0.3524, -0.2864,  0.2370, -0.5358,  0.3837, -0.0375, -0.3328, -0.4398,
#          0.0064, -0.1513,  0.2043, -0.4391, -0.2068, -0.1510,  0.3204,  0.0853,
#          0.0098, -0.2013,  0.2621,  0.1222, -0.3359, -0.0070, -0.4877,  0.3599,
#         -0.2800, -0.4207,  0.0555,  0.1891,  0.1068, -0.0244,  0.1765,  0.5451,
#          0.0250, -0.1616,  0.5709, -0.2075, -0.4208, -0.1544,  0.1088,  0.1256,
#         -0.2561, -0.4465, -0.4058,  0.2083, -0.2983,  0.2476,  0.1913,  0.0339,
#         -0.3021, -0.5552,  0.1948, -0.1837,  0.1096, -0.5406, -0.4495,  0.2897,
#         -0.4527, -0.0834, -0.5622, -0.2274,  0.2694, -0.3240,  0.0361,  0.5627,
#          0.0113,  0.5348, -0.3224,  0.2911,  0.0651, -0.3556, -0.3851, -0.0883,
#          0.5287,  0.0649,  0.5678,  0.3956, -0.0264, -0.3602, -0.1719,  0.3916,
#          0.2902,  0.2660,  0.2513,  0.2707,  0.3691,  0.2478, -0.0632,  0.4946,
#         -0.3357, -0.3514,  0.2720, -0.3205, -0.1096,  0.1902, -0.2575,  0.3335,
#          0.4671, -0.2920, -0.4116, -0.1813, -0.2515, -0.5409, -0.3215, -0.4533,
#         -0.1250, -0.2847,  0.0065,  0.0892, -0.2435, -0.0570,  0.0264,  0.0119,
#         -0.3943, -0.2817, -0.4869, -0.5389,  0.0167,  0.3835,  0.4901, -0.5414,
#         -0.3369,  0.2382, -0.3949, -0.4688,  0.3139, -0.4553,  0.0254,  0.2235,
#          0.1381,  0.1164,  0.1353, -0.5466,  0.0776, -0.0498,  0.1476,  0.4691,
#          0.5447, -0.1541,  0.5175, -0.1624, -0.1960, -0.5432, -0.1004, -0.1954,
#         -0.4537,  0.2144, -0.0804,  0.5277, -0.0446, -0.3931, -0.4778, -0.0509,
#         -0.4900,  0.3648, -0.5730,  0.5314, -0.0016,  0.1706,  0.4480, -0.2472,
#          0.3155, -0.5647,  0.1631, -0.3813,  0.4342, -0.2335, -0.4539, -0.4978,
#         -0.1959, -0.4073, -0.2859, -0.2347, -0.5524,  0.4651, -0.3802,  0.3101,
#          0.1606, -0.5242, -0.1922, -0.1302,  0.5577, -0.4762,  0.0196,  0.3199,
#         -0.3548, -0.2999,  0.4328, -0.1457, -0.5074,  0.3912,  0.1424, -0.1941,
#          0.4595,  0.1089,  0.4132, -0.1810,  0.4973,  0.0821, -0.3871,  0.2595,
#          0.2190, -0.3108,  0.1848,  0.1295, -0.4013, -0.3261,  0.1705,  0.0937,
#          0.0455,  0.2106, -0.0514,  0.0855,  0.2760,  0.0872, -0.3460, -0.3038,
#         -0.4683,  0.3187,  0.2963, -0.5451,  0.0681,  0.0184, -0.1454,  0.3373,
#         -0.1443, -0.5061, -0.4523, -0.0764, -0.1249, -0.3320, -0.0576, -0.5265,
#          0.0741, -0.2627, -0.5692, -0.4578,  0.2583,  0.4004,  0.3435, -0.1758,
#         -0.1409, -0.3994,  0.2533,  0.1710,  0.5458,  0.1999, -0.0363, -0.1103,
#          0.2263,  0.3637, -0.3441, -0.2158, -0.5679,  0.4839, -0.4903, -0.3259,
#          0.0408,  0.0810, -0.2277, -0.5143, -0.1786,  0.1853, -0.2684,  0.2704,
#         -0.2122,  0.2526,  0.4758, -0.2355, -0.3863, -0.3530,  0.1510,  0.0285,
#          0.5541, -0.5029,  0.4235,  0.4513, -0.4660,  0.4723, -0.1924, -0.0209,
#          0.1519,  0.0456, -0.1463, -0.1155,  0.1708,  0.1659,  0.5446, -0.1215,
#          0.0699, -0.1254,  0.3748,  0.4411, -0.5247, -0.5375,  0.2499, -0.2903,
#         -0.3300, -0.1417,  0.0152, -0.3560, -0.3320,  0.0902,  0.3923,  0.1607,
#          0.3435, -0.2324,  0.0151, -0.4961,  0.4183,  0.2119,  0.2950, -0.1537,
#         -0.2163, -0.4782,  0.4469,  0.3635,  0.3986,  0.4700, -0.2590,  0.1742,
#          0.5015, -0.2699, -0.3319,  0.4228, -0.3116, -0.4215, -0.5356, -0.2644,
#          0.2517, -0.0139, -0.5653,  0.3388,  0.5393,  0.1851,  0.2072, -0.3635,
#          0.2688, -0.4578,  0.3848,  0.2408,  0.1271, -0.3380,  0.2868, -0.3859,
#         -0.3555,  0.4604,  0.2167,  0.2341,  0.4072,  0.4555, -0.2190,  0.4435,
#         -0.0857,  0.2777, -0.1429, -0.2649,  0.1100,  0.0847,  0.0458, -0.5088,
#         -0.0500, -0.4431, -0.4362,  0.0353,  0.3233,  0.1995, -0.0716, -0.4822,
#         -0.4291,  0.0276, -0.2670, -0.2340,  0.1192, -0.4347,  0.5394,  0.5226,
#          0.0870,  0.3905,  0.5253, -0.0031, -0.3665, -0.0633, -0.3047, -0.3319,
#          0.0076, -0.3711, -0.2283,  0.3391, -0.0397, -0.4978, -0.4102,  0.3291,
#         -0.0849, -0.1428, -0.0420,  0.2761,  0.4503,  0.2582, -0.2524,  0.1473,
#          0.1943,  0.3597,  0.0439,  0.0201, -0.4295,  0.0094, -0.5695, -0.3918,
#         -0.5128,  0.0769,  0.5250, -0.2545, -0.0586, -0.1991,  0.4180,  0.5021,
#         -0.2710,  0.0402, -0.3913, -0.1044,  0.5640, -0.1343, -0.0307, -0.5709,
#         -0.4168,  0.5286, -0.1336, -0.3746, -0.3118, -0.4123, -0.0616, -0.4566,
#         -0.1007,  0.2887, -0.4709, -0.4531,  0.4064, -0.5439,  0.2955, -0.4362,
#         -0.4068,  0.3948, -0.5392,  0.1525,  0.5675,  0.1724, -0.5208, -0.3180,
#          0.0039, -0.5210,  0.4504,  0.0697,  0.2998,  0.3256, -0.2004, -0.3629,
#         -0.3666,  0.3179, -0.5306, -0.4801,  0.3706,  0.1290,  0.2378, -0.0448,
#         -0.2541, -0.4762,  0.2890, -0.5395,  0.0084, -0.0185, -0.5342, -0.3863,
#          0.2996, -0.5023,  0.3282, -0.3981, -0.2113, -0.1212, -0.1715,  0.3330,
#          0.3368,  0.4572, -0.1721,  0.1833,  0.2932,  0.0418,  0.3771,  0.5228,
#         -0.2561,  0.0193,  0.4089, -0.2522, -0.3781,  0.0419, -0.5688,  0.1244,
#          0.3271,  0.5519, -0.1438,  0.3209, -0.4199,  0.0303, -0.4964,  0.3757,
#          0.4610, -0.4880,  0.5452,  0.3394, -0.0948, -0.1607, -0.4627, -0.1787,
#         -0.0479, -0.1698,  0.0042, -0.0063,  0.1834,  0.3442, -0.2567,  0.4695,
#         -0.3396,  0.4853,  0.3311, -0.2432, -0.4547,  0.2416,  0.0245, -0.5721,
#          0.5550, -0.2136, -0.5787,  0.5056,  0.1890, -0.4200, -0.4025,  0.0583,
#         -0.0290,  0.0718,  0.2747, -0.5188, -0.4958, -0.3299, -0.3232, -0.3036,
#          0.3807,  0.1682,  0.0994,  0.0123, -0.5050, -0.1309, -0.0862,  0.1735,
#          0.3657, -0.2942, -0.0515,  0.1181,  0.1455, -0.4975,  0.3112,  0.2505,
#          0.5151, -0.5502,  0.4763, -0.2466,  0.3284, -0.2087,  0.5186,  0.3113,
#         -0.2745, -0.2228, -0.1524, -0.0358,  0.1085,  0.0812,  0.1153, -0.3129,
#          0.4997,  0.4219,  0.3576,  0.4132,  0.5533, -0.3676, -0.3450, -0.5067,
#          0.2507, -0.0981,  0.1846,  0.1661,  0.3873,  0.0290,  0.5322, -0.2536,
#         -0.4673,  0.2817, -0.2455, -0.2618, -0.1829,  0.2275, -0.5077,  0.1419,
#          0.1090,  0.1163, -0.1180, -0.2704,  0.4213,  0.2980, -0.0347, -0.4352,
#         -0.2169, -0.1340, -0.5768,  0.4986, -0.2068, -0.4768,  0.2729,  0.0970,
#          0.1189,  0.2046, -0.1145, -0.0626, -0.0751,  0.2430,  0.3025,  0.2358,
#          0.0117,  0.4658,  0.1759,  0.5549, -0.4624, -0.2589,  0.0997,  0.1819,
#         -0.0238, -0.3876,  0.3612, -0.3771, -0.3031,  0.0700,  0.1771,  0.4460,
#         -0.4087,  0.4046, -0.3099, -0.4838,  0.4893, -0.3948,  0.3477,  0.2439,
#         -0.3866,  0.0896,  0.4223,  0.3261,  0.3489, -0.5182,  0.0310,  0.2468,
#         -0.1670,  0.5538,  0.1284,  0.0349,  0.0743,  0.0164,  0.4482,  0.2362,
#         -0.0504,  0.4120,  0.4114, -0.1274, -0.5733, -0.3512,  0.3352,  0.2698,
#          0.0953, -0.2653,  0.3472, -0.4698, -0.4871, -0.5453, -0.4955, -0.4521,
#          0.1083,  0.0152,  0.0389, -0.4222, -0.4735,  0.1807,  0.1176, -0.4871,
#         -0.5319,  0.5582, -0.5345, -0.3511,  0.5242, -0.3795, -0.5765, -0.3439,
#          0.4925, -0.4835, -0.1596,  0.1842,  0.0905, -0.1338,  0.0043,  0.3293,
#          0.5112, -0.1895, -0.1765, -0.2145, -0.0196, -0.0736,  0.3081,  0.0529,
#          0.1012, -0.2621,  0.2177, -0.0895, -0.2004, -0.0611,  0.5219, -0.3454,
#         -0.3419, -0.1686,  0.1687,  0.0680,  0.2299, -0.4461, -0.4278, -0.1666,
#          0.5438,  0.2980,  0.1774,  0.3133, -0.3310,  0.2083,  0.0258,  0.0475,
#          0.5617,  0.1726,  0.2075,  0.1302, -0.3792, -0.2439,  0.4288, -0.0509,
#          0.4852,  0.3111,  0.2138,  0.3702,  0.5474, -0.3914,  0.4049,  0.0817,
#         -0.0668, -0.0169, -0.2481,  0.1983,  0.4546, -0.0562, -0.0340,  0.1725,
#         -0.1111, -0.1653, -0.5170, -0.1494, -0.3195, -0.0030,  0.4212,  0.0500,
#          0.0888,  0.5120, -0.0623], requires_grad=True), Parameter containing:
# tensor([[-0.0230, -0.0115,  0.0002,  ...,  0.0013, -0.0130,  0.0113],
#         [-0.0024, -0.0300,  0.0293,  ...,  0.0189, -0.0274, -0.0156],
#         [-0.0268, -0.0213, -0.0047,  ...,  0.0316,  0.0228, -0.0376],
#         ...,
#         [-0.0141,  0.0337,  0.0254,  ...,  0.0165,  0.0267, -0.0173],
#         [ 0.0321, -0.0126, -0.0017,  ..., -0.0176,  0.0018,  0.0301],
#         [-0.0298, -0.0318,  0.0268,  ..., -0.0003,  0.0158, -0.0206]],
#        requires_grad=True), Parameter containing:
# tensor([-7.4487e-03,  1.4697e-02,  1.8189e-02, -2.1421e-02,  2.8543e-02,
#          2.2181e-02,  1.9918e-02,  1.2793e-02,  2.5495e-02,  2.2588e-02,
#          1.6025e-02, -8.8453e-03, -7.0436e-03, -2.3311e-03, -1.8607e-02,
#         -9.5370e-03, -1.2128e-02,  5.1497e-03,  4.3444e-03, -2.6624e-02,
#         -1.7092e-02, -2.6033e-02,  2.4757e-02, -1.7330e-02, -1.0334e-02,
#         -2.2848e-02,  1.6834e-02,  7.8508e-03,  9.0624e-03, -3.1399e-02,
#          1.1610e-02,  1.3648e-02,  1.5273e-02, -1.5813e-03, -2.5559e-03,
#          2.6196e-02,  2.3121e-02,  5.8172e-03,  2.4086e-02,  2.1571e-02,
#         -2.1987e-02,  2.2005e-02,  6.4230e-03, -2.7450e-02,  2.5295e-02,
#         -2.9251e-02, -5.6616e-03, -4.9454e-03,  8.9645e-03,  3.3267e-02,
#         -2.5601e-03, -1.5112e-02, -1.4543e-02,  1.8251e-02, -1.3628e-02,
#         -1.7059e-02,  1.3899e-02, -1.1023e-02, -1.4225e-02,  2.5828e-02,
#          3.0598e-02, -2.3817e-02,  1.9961e-03, -2.3506e-02, -1.3619e-02,
#         -1.0765e-02, -1.4252e-02,  1.7503e-02, -1.6499e-02,  1.2952e-02,
#         -2.2147e-02,  1.6597e-03, -2.8192e-02, -2.7700e-03, -3.1046e-02,
#         -3.1575e-03,  8.0940e-03, -2.1398e-02, -2.7571e-02, -8.0228e-03,
#         -2.2322e-02, -2.8853e-02,  3.2296e-02,  1.7179e-02,  2.2097e-02,
#         -2.1851e-02,  2.4886e-02, -1.2286e-02,  2.6174e-02, -1.0513e-02,
#         -2.3547e-02,  7.7160e-03, -2.8372e-02,  3.6638e-03, -3.1071e-02,
#          1.9309e-02,  9.1188e-03, -5.5801e-04,  2.5992e-02, -1.3246e-02,
#         -3.0926e-02,  2.7342e-02, -9.7243e-03, -1.8423e-02, -1.0431e-02,
#         -3.0981e-02,  2.8603e-02,  2.4550e-02,  2.8717e-02, -1.0339e-02,
#          3.2337e-02,  2.7078e-03, -8.5499e-03,  2.2176e-02,  1.2535e-04,
#          2.8481e-02, -3.1407e-02,  2.8995e-02,  2.2638e-02,  1.9668e-03,
#          6.7044e-03, -3.7460e-03,  1.0602e-02, -1.8741e-02,  2.7360e-02,
#         -1.9931e-02,  4.8558e-03, -2.6093e-03,  2.1242e-03, -2.8414e-02,
#          1.4621e-02,  2.5641e-02, -1.5654e-02,  1.2623e-02,  4.7686e-03,
#          7.0338e-03, -2.6392e-02, -5.4601e-03,  2.2997e-02,  2.3018e-02,
#          1.9335e-02,  8.0948e-03,  2.5668e-02, -6.2289e-03, -8.4752e-03,
#          2.9747e-02,  1.2772e-02, -2.2460e-02, -2.4984e-02, -1.7168e-02,
#          3.9635e-03, -2.7941e-02,  2.2669e-02,  1.8963e-02,  1.7809e-02,
#          2.7627e-02, -1.8350e-02, -2.4096e-02, -2.0471e-02, -1.2386e-02,
#         -3.1299e-03,  1.3877e-02, -2.5767e-02, -3.2577e-02,  4.5389e-03,
#          1.4584e-02, -1.3493e-02,  1.6845e-02, -1.8803e-02, -3.9594e-03,
#         -9.9400e-03, -8.1128e-03,  1.6099e-02, -1.8034e-02, -2.8062e-02,
#         -2.2388e-02,  1.5194e-03,  5.3519e-03,  3.1750e-02,  1.0255e-02,
#          9.8897e-03,  9.5875e-03, -1.9058e-03,  2.9927e-02,  2.6870e-02,
#          1.7523e-02,  1.7917e-02, -3.9171e-03,  2.2548e-02, -1.1978e-02,
#          2.7727e-02,  2.9883e-02,  1.3563e-02,  2.5921e-02, -3.0295e-02,
#         -1.2410e-02, -1.2889e-02,  1.5802e-02, -3.2854e-02, -1.8004e-02,
#          9.6140e-03, -2.2208e-02, -1.8487e-02, -1.9043e-02, -2.9185e-03,
#          2.8569e-02, -2.5718e-02, -2.5499e-02, -1.0722e-02, -1.8036e-02,
#         -1.4639e-02,  2.0938e-03, -1.8947e-02,  3.1570e-03, -1.5187e-02,
#         -2.0791e-02, -2.2863e-02,  1.3286e-02,  3.0173e-02, -5.8598e-04,
#          1.2169e-02,  1.6190e-02,  2.3164e-02, -1.3521e-02,  1.4877e-02,
#         -1.0158e-02, -1.8595e-02, -1.0197e-02, -1.6373e-02, -1.9104e-02,
#         -2.9724e-02, -1.0733e-02,  1.1409e-02,  1.2373e-02, -3.2518e-02,
#         -8.8389e-03,  2.9270e-02,  2.4230e-02, -5.4014e-03, -5.2420e-03,
#          3.3144e-03, -1.0760e-02, -2.9835e-02,  8.4822e-03, -1.0895e-02,
#          2.8244e-02,  3.3336e-02, -3.9586e-03,  1.6590e-02, -1.2632e-02,
#          2.3865e-02, -9.5998e-03, -1.0586e-03, -3.3224e-02,  2.0680e-02,
#          1.3297e-02, -5.7036e-03, -3.4336e-03,  2.2356e-02, -1.9877e-02,
#          1.5886e-02,  2.4603e-02,  3.1527e-02,  3.4594e-02,  9.9309e-03,
#          5.9076e-03, -1.2528e-02, -1.2970e-03,  2.9338e-02,  9.4960e-03,
#          1.3468e-02,  1.8524e-02, -1.4964e-02,  6.7808e-03,  2.8710e-02,
#         -2.2431e-02, -1.2386e-02, -8.3380e-03,  2.2979e-02,  2.8676e-02,
#         -7.5216e-03, -1.3449e-02, -7.3443e-03,  1.8731e-02, -1.1666e-02,
#          2.9626e-02, -7.3521e-03, -2.6571e-02, -3.2595e-02, -3.1838e-02,
#          4.8482e-04, -8.9395e-03, -1.8735e-02,  2.0895e-02, -1.2782e-02,
#          6.1028e-03,  1.3059e-02, -2.6514e-02,  5.3324e-03, -7.0107e-03,
#          1.9812e-02,  6.7305e-03, -3.1085e-02,  3.1996e-02,  2.1784e-02,
#          2.7642e-02,  1.3673e-02, -3.9625e-03, -4.1565e-03, -2.3698e-02,
#         -2.4703e-03,  3.1333e-02,  3.3898e-02,  1.5293e-03, -1.0845e-02,
#          1.8942e-02,  1.4502e-02,  7.3257e-03,  3.2246e-02,  3.3393e-02,
#         -2.5199e-02,  1.8149e-02,  2.4253e-03,  1.1928e-02,  1.8187e-02,
#          1.6167e-02, -1.6975e-02,  2.6845e-02,  2.6052e-02,  3.2752e-02,
#         -3.5029e-02, -1.7989e-03, -3.4381e-02, -2.9743e-02, -1.5064e-02,
#         -9.2180e-03, -2.3600e-02,  3.3187e-02,  1.0983e-02, -1.4925e-03,
#          1.4890e-02,  9.4933e-03, -1.4405e-02,  9.5131e-03, -2.2294e-03,
#          4.0925e-03, -2.4136e-02, -1.3183e-02,  2.9010e-02,  1.3063e-02,
#         -1.6369e-02,  2.0508e-02,  3.2785e-03, -2.7036e-02, -1.0299e-03,
#         -1.4634e-02,  1.2499e-03, -1.2832e-02,  1.9640e-02, -2.0937e-02,
#          3.3548e-02, -2.2105e-02, -8.0858e-03,  2.9931e-02,  3.0729e-02,
#          5.9163e-03,  1.2845e-02, -2.2068e-02, -2.0388e-02,  3.4966e-03,
#         -7.1744e-03, -7.0424e-03, -1.0760e-02,  2.0020e-02,  3.0121e-02,
#         -1.6936e-02,  2.6324e-02,  2.1169e-02,  3.2512e-02,  2.9045e-02,
#          5.5136e-03, -3.3219e-02,  2.5037e-02,  3.5655e-02, -1.3205e-02,
#         -1.3755e-02,  1.9958e-02, -1.3748e-03, -2.8221e-02,  2.7328e-02,
#         -1.5629e-02,  5.6525e-03, -6.6532e-03, -1.8285e-02, -3.3615e-02,
#         -8.8677e-03, -1.3628e-02, -1.1499e-03, -2.4264e-02, -2.1307e-02,
#         -4.3409e-03,  1.9503e-02,  2.4728e-02,  8.8560e-03,  6.9499e-06,
#          1.2173e-02, -9.1809e-03,  1.9217e-04, -1.7174e-02,  2.6475e-02,
#         -3.3681e-02, -1.0575e-02,  2.0488e-02, -1.5557e-02, -3.1548e-02,
#          2.1478e-04,  4.4287e-03, -1.9828e-02, -3.2017e-03, -1.8842e-02,
#         -2.9550e-02,  2.5738e-02, -2.1219e-02,  1.6742e-02,  1.2226e-02,
#          1.0399e-02,  3.1987e-02,  3.2634e-02, -2.2594e-02, -2.4326e-02,
#          6.7197e-04,  2.6496e-02,  1.9609e-02,  8.4514e-03, -2.6985e-02,
#          1.2484e-02, -8.4143e-03,  7.0294e-03, -2.1362e-02, -1.0089e-02,
#         -1.5743e-02,  2.5558e-02,  1.8209e-02,  3.1934e-02,  2.2663e-02,
#         -2.3369e-02, -1.7101e-02,  1.7006e-02, -3.5022e-02, -2.5759e-02,
#          6.6514e-03,  1.3054e-02, -1.7245e-02,  2.1760e-02, -1.9839e-02,
#          4.3059e-03,  2.3422e-04,  8.5801e-03,  1.4597e-02, -1.3513e-02,
#          5.7054e-05,  3.1101e-02,  2.3083e-02, -6.0878e-03, -2.0490e-02,
#          2.2378e-02, -7.2150e-03, -1.9221e-02,  2.0001e-03, -2.4689e-02,
#         -1.6906e-03,  1.8435e-02, -2.7878e-03, -1.7937e-02,  3.4591e-03,
#          1.1679e-02, -1.0938e-02, -1.8325e-02, -3.4527e-02, -9.1731e-03,
#         -8.2236e-03, -2.8503e-02, -2.9148e-02,  2.9531e-02,  5.5397e-03,
#          2.5015e-02,  8.8723e-03, -2.9980e-02, -1.0878e-02,  9.8364e-03,
#         -5.6205e-03, -3.1959e-02,  2.2059e-02,  2.9161e-02,  2.0468e-02,
#         -1.2179e-02,  1.8138e-02,  1.8758e-02, -2.3226e-02,  3.2232e-02,
#         -2.3837e-03, -2.1720e-03,  3.1128e-02,  4.6101e-03,  2.8987e-02,
#         -2.5197e-02, -1.6690e-02,  2.0253e-02, -2.9136e-02,  1.5743e-02,
#         -2.5996e-03,  1.3863e-02,  1.6172e-02,  7.3228e-04, -2.5104e-02,
#         -1.8013e-02, -9.6907e-03,  2.4667e-02, -1.7485e-02,  2.6608e-02,
#          2.1868e-02, -4.1768e-03,  1.8198e-02, -7.6214e-03, -1.6403e-02,
#          3.1467e-02,  2.2055e-02,  4.1540e-03,  2.9701e-02,  2.0725e-02,
#          2.1559e-02, -2.8508e-02,  2.9749e-02, -1.1753e-02,  7.6746e-03,
#          3.3633e-02, -2.9131e-02,  1.7742e-03,  2.0125e-02, -3.3214e-02,
#          2.8341e-02, -2.6718e-02, -2.8664e-02, -1.1852e-02,  2.8578e-02,
#         -2.3249e-02,  1.2387e-02,  6.1706e-03, -9.3228e-03,  2.5633e-02,
#          1.6895e-02,  3.0199e-02,  3.1993e-02,  2.8015e-03,  5.1203e-04,
#         -1.3733e-02, -1.8928e-02, -3.3047e-02,  1.4925e-02,  1.9782e-02,
#          3.0918e-02, -2.2652e-02, -1.2206e-02,  1.9720e-02,  1.2879e-03,
#         -8.0605e-03, -2.5273e-02,  1.7732e-02, -1.2996e-02,  3.0180e-02,
#         -6.5285e-03,  2.9882e-02, -3.9229e-03,  9.0582e-03, -1.6713e-02,
#          1.4467e-02,  1.0905e-02,  1.6663e-02, -5.5820e-03, -1.9070e-03,
#         -1.0674e-02,  1.3076e-02, -3.0742e-02, -1.9605e-02,  2.3273e-02,
#         -1.0136e-02, -1.2850e-02, -1.1332e-03,  2.7819e-02, -2.0811e-02,
#          2.1269e-03, -3.4675e-02, -7.8888e-03, -2.8627e-02, -2.7327e-03,
#         -1.6283e-02, -2.5437e-02, -2.6182e-02, -9.1303e-03,  2.9280e-02,
#         -2.6547e-02,  2.4576e-02, -2.7595e-02,  3.2126e-02,  1.8710e-02,
#          1.1298e-02,  8.8349e-03, -6.4281e-03, -2.1347e-02,  1.5033e-02,
#         -3.3915e-02,  2.8645e-02, -2.2764e-02,  1.8872e-02, -2.2958e-02,
#          1.9289e-02, -3.0173e-03, -3.3559e-03, -1.1731e-02,  6.4684e-03,
#         -3.5085e-02,  3.2369e-02,  1.8554e-02, -3.3540e-02, -8.6685e-03,
#          1.6775e-02, -9.0154e-03,  4.7198e-03,  1.2530e-02, -2.8532e-02,
#         -2.5923e-02,  1.9028e-02, -2.8744e-02, -1.6212e-02, -1.6823e-02,
#          2.7619e-02, -1.2112e-02, -1.0547e-02,  2.6960e-02, -1.0562e-02,
#          8.4209e-03, -3.4513e-03, -8.5530e-03,  1.3950e-02, -2.2057e-02,
#          1.3209e-02,  1.1884e-02,  3.3759e-02,  3.3281e-02,  8.1127e-03,
#          2.4979e-02,  1.9697e-02,  1.6582e-02,  2.0763e-02,  1.0890e-02,
#          9.5054e-03, -2.0340e-03, -2.3389e-02,  1.8603e-02,  1.9282e-02,
#          1.0240e-02,  7.3058e-03,  2.0042e-02, -2.5788e-02, -1.7638e-02,
#         -2.7467e-02,  3.1853e-02,  1.3621e-03, -2.9592e-02,  6.1431e-03,
#         -1.0196e-02,  1.8662e-02,  1.0159e-02,  3.1378e-02,  1.3117e-02,
#          5.9075e-03,  2.9331e-03, -6.1504e-04, -1.8306e-03, -9.2198e-03,
#         -1.8369e-02, -7.7757e-03, -2.4926e-02,  1.4797e-02, -3.2872e-03,
#          1.2211e-02, -6.7795e-03, -8.2863e-03,  4.5192e-03,  8.2982e-04,
#          7.5252e-03, -1.3557e-02,  2.3928e-02, -3.1954e-02, -1.7709e-02,
#          2.7415e-02,  1.2729e-03,  2.2374e-02, -8.4816e-04,  1.5193e-02,
#         -3.0780e-02, -1.7936e-03,  1.2504e-02, -2.3954e-02,  3.4243e-03,
#         -8.2112e-03, -2.5552e-02, -1.0306e-02, -1.2155e-02, -1.9878e-02,
#          2.3695e-02, -2.0043e-02, -5.9374e-03, -8.0350e-03, -1.4919e-02,
#          3.5746e-03, -1.5082e-02,  2.6745e-02,  4.3956e-03,  9.9890e-03,
#         -2.6494e-02,  3.4856e-03,  1.0992e-02,  1.4571e-02,  2.1195e-02,
#         -1.7772e-02,  2.3805e-02,  2.5245e-03,  2.9216e-02, -4.3362e-03,
#          1.0775e-02,  3.3863e-02,  2.4154e-03, -2.7214e-02, -3.3716e-02,
#         -5.6058e-03, -1.3475e-02,  8.7195e-03, -2.3890e-02,  2.4564e-02,
#          1.9346e-02, -2.2133e-02,  3.1932e-02, -1.6063e-03,  3.6573e-03,
#          5.8466e-03,  7.8625e-03,  2.6576e-02, -6.1509e-03,  3.0489e-03,
#         -2.8598e-02, -8.6835e-03,  1.6867e-02,  6.4389e-03, -3.3364e-02,
#         -2.4010e-02,  5.2636e-03,  1.6303e-02, -5.2049e-03,  3.4142e-02,
#         -3.1905e-02, -7.8159e-03, -8.1552e-03, -4.4740e-03, -2.1453e-02,
#         -5.3903e-04, -9.6175e-03, -6.0318e-03,  3.7888e-03, -2.3228e-02,
#         -2.8764e-03, -3.5972e-03,  3.1937e-02, -4.5544e-04,  8.9446e-03,
#         -1.7953e-02,  1.7132e-02, -3.2623e-02, -2.6352e-02,  6.7692e-03,
#          2.5306e-02, -1.8823e-02,  1.3027e-03, -1.7241e-03, -2.3650e-02,
#         -2.1614e-02, -7.6175e-03,  1.7385e-02,  4.7902e-03,  1.8385e-02,
#          1.6310e-02, -2.3032e-02, -2.8424e-02,  5.2682e-03,  9.0011e-03,
#         -2.0634e-02,  2.6915e-02, -6.9943e-03,  3.8912e-03,  4.4749e-03,
#          8.6480e-03, -2.8092e-02, -1.0885e-02, -1.8312e-02, -2.2356e-03,
#          1.5508e-02, -4.5561e-03,  1.9451e-02, -3.1440e-03, -3.2522e-02,
#         -3.4776e-03, -8.8831e-04,  2.8750e-02, -3.3755e-02,  3.1666e-02,
#         -2.5413e-02,  2.4808e-02, -3.4798e-04,  3.2415e-02,  2.6930e-02,
#         -1.1999e-03,  1.4354e-02,  2.1362e-03,  2.7750e-02, -6.3487e-03,
#          8.0317e-03, -2.4106e-03, -2.3522e-05,  7.9354e-03,  8.7542e-03,
#          7.9646e-03, -2.4973e-02, -7.9198e-03, -5.8943e-04,  3.3459e-03,
#         -3.6430e-04, -2.1559e-02, -2.8166e-02, -3.4025e-02, -1.0342e-02,
#          2.7012e-02, -9.8377e-03,  1.9506e-02, -1.9894e-03, -1.4018e-02,
#         -2.0683e-02,  1.2268e-02,  6.6622e-03,  2.5272e-02, -6.1035e-03,
#         -8.0014e-03, -1.5103e-02,  2.1614e-02,  2.9834e-02, -8.5504e-03,
#          2.6375e-02,  1.2814e-02,  1.0590e-02, -5.6151e-03, -3.0418e-02,
#         -7.9381e-03,  3.6985e-04,  2.4725e-02,  2.7959e-03,  1.0847e-02,
#         -1.0080e-02,  2.2252e-02,  1.8585e-02, -2.1953e-02, -1.0732e-02,
#         -1.2085e-02,  2.5417e-03,  3.0708e-02, -8.2395e-03, -2.0523e-02,
#          3.0786e-02,  2.8953e-02, -2.5118e-02, -1.9545e-02,  3.2561e-02,
#          1.2496e-02,  2.5610e-02, -3.9593e-04,  1.7377e-02, -9.6441e-03,
#         -2.2914e-02, -3.1767e-02, -2.3016e-03,  1.4144e-02, -3.1374e-02,
#          3.5552e-03, -2.2241e-03, -2.4742e-02, -1.6879e-02,  2.5244e-02,
#          2.3226e-02,  1.2729e-02, -2.3470e-02, -2.6177e-02,  2.5296e-02,
#          1.3904e-03, -1.1275e-02,  1.8244e-02, -2.8539e-02,  8.1270e-03,
#          2.1578e-02,  2.9779e-02, -1.7482e-02,  2.3602e-02,  4.2660e-03,
#         -2.1095e-02,  1.3915e-02,  1.1208e-02,  2.3307e-02, -1.1356e-04,
#          1.2780e-02, -1.7859e-02,  8.7622e-03,  2.0560e-02,  2.0446e-02,
#         -1.7073e-02, -3.1790e-02, -9.5088e-03, -1.5182e-02, -3.4173e-03,
#         -9.6644e-03,  1.5989e-02, -2.9250e-02,  2.6250e-03,  1.0659e-02,
#         -8.8401e-03,  2.5108e-02,  2.9623e-02,  1.2387e-02, -1.4631e-02,
#          2.0311e-03,  9.0267e-03, -1.6261e-02, -1.5020e-02, -2.2927e-02,
#          1.0938e-02, -6.4121e-03, -7.6177e-03, -1.3453e-02,  3.1659e-02,
#          1.6471e-02,  1.5221e-02, -2.3089e-02, -1.7204e-02, -7.4887e-03,
#          6.8231e-04], requires_grad=True), Parameter containing:
# tensor([[-2.3034e-02, -3.0022e-02, -8.3155e-03,  2.2399e-02,  4.9010e-05,
#           2.4541e-02,  9.7841e-03,  1.4650e-02,  2.3386e-02, -1.3130e-02,
#          -2.2744e-02,  5.8882e-04, -2.2510e-02,  2.6441e-04,  2.0091e-02,
#          -8.4445e-03,  2.7329e-02,  2.8363e-02,  2.5817e-02,  3.1519e-02,
#          -2.8705e-02,  7.5164e-04, -2.8698e-02, -2.8828e-02,  6.6436e-03,
#           3.0318e-02, -1.2557e-03,  1.3913e-02,  2.2430e-03,  1.6304e-02,
#           7.3189e-03,  2.4475e-02,  1.2913e-02, -2.3240e-02,  2.5142e-02,
#          -2.6805e-02, -2.0151e-02,  2.2691e-02,  6.0232e-03,  2.2383e-02,
#           9.8732e-03, -2.2442e-03,  1.4111e-02, -4.3281e-03, -9.7966e-03,
#          -3.0319e-02,  1.6338e-02,  1.7200e-02,  2.8861e-02,  1.8001e-02,
#           2.1331e-02,  1.4173e-02,  1.5448e-02,  2.9148e-02,  1.7233e-02,
#          -1.1458e-02,  1.7066e-02,  1.2360e-02,  1.2514e-02,  1.3690e-02,
#           3.8001e-03, -3.5039e-03, -6.0353e-03, -1.7121e-02, -2.1114e-02,
#           4.8753e-03, -1.8875e-03, -1.1423e-02, -1.4340e-02, -3.0345e-02,
#           2.3385e-03, -4.0552e-03, -1.3323e-02, -2.0399e-02, -2.1497e-02,
#          -2.7708e-02,  1.8381e-02,  3.0956e-02, -8.6024e-03, -2.3058e-02,
#           8.1349e-03,  1.4513e-02,  1.7817e-03,  2.0703e-02,  8.2891e-03,
#          -1.0922e-02,  9.2520e-03, -1.9638e-02,  5.2158e-03, -3.0568e-03,
#          -1.9118e-02, -2.4485e-03, -2.2266e-02,  2.7554e-02,  4.3907e-03,
#           9.8041e-03,  6.1729e-03, -5.1110e-03, -2.1794e-02, -3.1719e-02,
#           1.1455e-02, -1.3102e-02, -7.1478e-03,  7.0687e-03, -1.6067e-02,
#           5.9424e-03,  2.4874e-02,  8.9744e-03,  2.1574e-02,  8.4495e-03,
#           1.0375e-02,  2.8301e-02,  2.6360e-02,  8.2671e-03,  1.6915e-02,
#           1.8290e-04, -1.3347e-02, -2.1239e-03,  7.3126e-03, -1.3175e-02,
#           3.1615e-02,  1.7289e-02, -2.0581e-02, -5.8520e-03,  7.0541e-03,
#          -2.1669e-03,  2.8677e-02, -2.0514e-02,  6.5443e-03,  1.8290e-02,
#           6.8069e-03, -3.9473e-03, -2.3791e-02, -2.4335e-02, -5.8046e-03,
#          -8.0121e-03, -1.4957e-02,  2.4550e-02, -2.4286e-02,  6.9911e-04,
#          -2.0943e-02,  8.4233e-03, -6.6382e-03,  5.3343e-03, -7.6273e-03,
#           2.6411e-02,  1.6032e-02, -4.5160e-03, -9.6976e-03, -2.3118e-02,
#           2.8709e-02,  2.1012e-02, -4.7469e-03,  1.2919e-02, -1.7017e-02,
#          -3.6852e-03, -1.5125e-02, -1.8588e-02, -9.9410e-03,  3.0888e-02,
#           2.3687e-02,  1.8172e-05,  2.7766e-02, -2.7658e-02, -2.5378e-03,
#           1.3150e-02, -1.5935e-03,  1.0512e-02,  3.4336e-03,  5.8471e-03,
#          -3.1099e-02,  1.6100e-03,  6.5269e-03,  2.9515e-02,  1.7518e-02,
#          -1.6099e-02,  3.0058e-02, -2.7810e-02, -7.2053e-03,  2.2233e-04,
#          -2.0352e-02,  2.4189e-02,  2.7062e-02,  2.5505e-03,  3.0942e-02,
#           3.3835e-03, -2.6639e-02,  1.5943e-02, -2.6317e-02, -1.3896e-03,
#           1.8049e-02, -1.3727e-02,  1.2427e-02,  2.6308e-02,  2.4041e-02,
#          -5.6110e-03,  1.5783e-02, -6.8385e-03,  2.1549e-02,  3.1761e-02,
#           1.6240e-02,  1.4382e-02, -1.6120e-02,  9.7058e-05, -1.7374e-02,
#          -2.0761e-02, -2.0355e-02, -2.0202e-02, -2.1254e-02, -5.4811e-03,
#           5.4168e-03,  2.3832e-03,  8.0222e-03,  2.2740e-02, -5.0783e-03,
#           3.0792e-02,  2.7339e-02, -3.0697e-02,  2.0246e-02, -2.4664e-02,
#           1.0979e-02, -1.4981e-02, -2.4712e-02,  6.7187e-03, -7.3065e-03,
#          -2.0245e-02, -8.7245e-03, -6.5916e-03,  1.4922e-02,  4.3723e-04,
#           2.1066e-02,  2.8824e-02, -3.2745e-02, -2.7250e-02, -2.6801e-02,
#           4.1199e-03, -5.8794e-03, -2.4620e-02,  1.7576e-02,  3.0310e-02,
#           1.6856e-02, -2.1089e-03, -1.8174e-02, -8.0022e-03, -3.4879e-03,
#           1.1378e-02, -3.3195e-03,  2.2095e-02,  1.0083e-02, -2.6745e-02,
#          -2.7684e-02,  1.7442e-02, -2.3885e-04, -1.4887e-02, -6.4816e-03,
#          -6.0535e-04,  6.9546e-04,  3.7519e-03, -2.5482e-02,  8.7476e-03,
#           2.1630e-02,  3.2085e-02, -1.3125e-02, -2.0268e-02,  2.1173e-02,
#           6.1958e-03, -2.4409e-02, -1.7575e-02,  1.9426e-02,  2.9556e-02,
#           1.0401e-02, -2.6040e-02,  1.6752e-02,  4.8640e-04, -5.6810e-03,
#           4.0364e-03,  3.1409e-02,  1.9696e-02, -1.1566e-02,  2.2876e-02,
#          -4.2504e-03,  2.0900e-02, -1.7955e-02, -2.5374e-02,  5.0315e-03,
#           2.0412e-02,  2.9603e-02, -8.4941e-03, -1.0180e-02, -8.8753e-03,
#          -7.6365e-03, -2.7265e-02,  1.5544e-02,  2.2835e-02, -2.8282e-02,
#           1.4436e-03, -1.8616e-02, -2.1649e-03,  5.2806e-03,  2.4661e-02,
#          -9.0162e-03, -9.7121e-03, -1.3720e-02, -1.5615e-02,  6.0308e-04,
#          -2.9283e-02,  8.7591e-03,  2.4325e-02,  9.4640e-04, -4.9387e-03,
#          -1.0003e-02, -1.6037e-02, -2.8453e-03,  3.0167e-02, -2.4284e-04,
#           1.1208e-02, -1.6202e-03, -1.0401e-02,  2.6843e-02,  4.7570e-03,
#           1.1520e-03, -2.2218e-02,  2.8086e-02,  2.2075e-02,  1.9070e-02,
#           1.0763e-02,  6.2699e-03, -7.5168e-03, -2.3748e-02, -1.3072e-02,
#          -1.7537e-02, -7.9869e-04,  6.3113e-03, -6.7345e-03, -2.0594e-02,
#           3.7726e-03, -1.4587e-02,  2.5924e-03, -3.1005e-02, -7.1899e-04,
#          -1.5219e-02, -2.1846e-02,  6.4224e-03, -3.1189e-02, -2.2485e-02,
#          -2.8232e-02, -1.3731e-02,  3.1307e-02, -1.0673e-03,  2.7934e-02,
#          -1.4305e-02, -2.3463e-02, -7.6722e-03, -2.8283e-02, -2.8159e-02,
#           3.0903e-02, -3.1179e-02, -1.0583e-02,  2.4164e-02,  4.2862e-02,
#           2.5818e-02,  1.3588e-02, -8.7280e-03,  2.9034e-02, -2.7607e-02,
#          -2.7918e-02, -3.1653e-03,  2.3062e-02,  1.1314e-02,  1.8622e-02,
#           1.9753e-02,  2.2220e-02,  1.0214e-02, -2.0315e-02, -3.0250e-02,
#          -2.7569e-02,  2.1377e-03, -1.1002e-02,  3.0140e-02, -1.9758e-02,
#           2.3247e-02,  2.3343e-02,  1.3418e-02, -3.6218e-02,  1.5876e-02,
#           1.5732e-02,  9.5759e-03,  1.4638e-02,  1.6807e-03,  2.0963e-02,
#           2.5777e-03,  3.1318e-02, -2.5967e-03,  1.3352e-02, -1.6305e-03,
#          -8.7502e-03, -1.9955e-02, -2.8631e-02,  2.3180e-02, -4.0587e-03,
#           2.5773e-02, -2.2672e-02, -2.6659e-02, -2.1485e-02,  5.4658e-03,
#           1.6085e-02, -2.0697e-02,  2.3859e-02,  1.7322e-02,  2.0418e-02,
#          -8.4782e-03, -1.8321e-02, -2.9956e-02, -2.6773e-02,  8.8108e-03,
#           2.0673e-02, -2.5671e-02,  9.8271e-03, -1.3286e-02, -2.3078e-02,
#          -1.9973e-03,  1.8448e-02,  7.8605e-03,  8.9411e-03, -2.6524e-02,
#           2.0226e-02, -1.4592e-02,  2.9144e-02, -2.9282e-02,  1.7567e-02,
#           1.3128e-02, -2.5443e-02, -1.7575e-02,  6.8060e-03,  1.6948e-02,
#          -2.4093e-02, -2.1347e-02,  2.2430e-02, -1.3733e-02, -1.2621e-02,
#           9.3438e-03,  1.5283e-02, -1.8992e-02,  6.2487e-03,  2.3257e-02,
#          -1.7856e-02,  9.8013e-04,  1.5087e-02, -7.3331e-03,  1.8406e-02,
#          -2.7723e-03, -1.6646e-02, -1.1521e-02,  1.7273e-02, -2.4477e-02,
#           4.9510e-03, -2.0222e-02, -1.4977e-02, -1.4177e-02,  1.0613e-04,
#          -2.8034e-02, -2.7269e-02, -2.5573e-03, -7.9386e-03,  1.8339e-02,
#           2.9830e-02, -2.9911e-02, -1.6538e-02, -4.0604e-03,  2.6738e-02,
#           1.1872e-02, -2.3940e-03, -1.6966e-02,  2.0443e-02, -3.5490e-03,
#           2.9699e-02, -2.7064e-02,  1.9781e-03, -7.2597e-03,  8.5318e-03,
#           1.2191e-02,  3.6889e-03, -8.8823e-03, -2.7262e-02, -1.9042e-02,
#          -2.3913e-03,  6.6689e-03,  4.4283e-03,  1.3141e-02,  1.4706e-02,
#          -3.2367e-03,  1.6855e-02, -1.1650e-02, -2.0613e-02, -2.5651e-02,
#          -1.8940e-02,  3.2215e-02,  2.4177e-02, -1.0119e-02,  2.8968e-02,
#           8.3350e-03,  1.2671e-02,  2.2957e-02,  1.0386e-02,  2.7773e-02,
#          -6.1832e-03,  3.8824e-03, -2.1189e-02, -2.1830e-02,  2.5568e-02,
#          -2.6194e-02, -1.9564e-02,  9.0416e-03,  6.6898e-03, -6.0015e-03,
#          -2.8576e-02, -1.5978e-04, -3.0018e-03,  1.4781e-02,  1.0611e-02,
#           2.4035e-03,  2.8961e-02, -5.9715e-03, -1.9356e-02,  7.5436e-03,
#          -1.2946e-02, -1.4902e-02,  2.3430e-02, -1.3412e-02,  1.8381e-02,
#           1.5392e-02,  2.5561e-03,  2.7685e-02,  3.2626e-03,  2.9109e-02,
#           5.7891e-03,  1.6877e-02,  7.2305e-03, -2.7783e-02, -1.9402e-02,
#           8.7519e-03, -1.5795e-02,  1.8098e-02, -1.0620e-02,  2.4879e-02,
#          -3.1192e-02, -1.2155e-02, -2.8510e-02, -2.1073e-03,  8.8223e-03,
#          -1.1753e-02, -1.1575e-02,  1.4335e-02,  3.1729e-02, -2.4718e-02,
#          -1.0193e-02,  7.6084e-04,  2.5680e-02, -2.7106e-02,  1.9505e-02,
#           2.1563e-02,  1.4220e-02,  1.8141e-02,  1.3511e-02,  3.0499e-02,
#           4.4208e-03,  2.1253e-02, -2.2453e-02, -1.5635e-02, -1.2309e-02,
#           1.5995e-02, -2.3982e-02,  2.5816e-02,  4.0533e-03, -1.4297e-02,
#          -3.4868e-03,  6.3890e-03, -1.1007e-02,  7.5020e-03, -1.8042e-03,
#          -1.4128e-02, -6.4973e-03,  8.6819e-03,  1.6963e-02, -2.7257e-02,
#           2.9824e-02, -8.9742e-03, -1.2077e-02, -2.0002e-02, -8.0487e-03,
#           1.7374e-04, -9.7143e-03, -1.8991e-02, -2.1400e-02,  2.2626e-02,
#          -7.4873e-03,  2.2248e-02, -1.3038e-02,  2.2180e-02, -1.8680e-03,
#          -1.2773e-02, -3.6796e-03, -5.6356e-03, -2.2699e-02, -9.3350e-03,
#           1.3665e-02, -2.0914e-02, -2.2327e-02, -3.3119e-03, -1.2838e-02,
#          -1.0651e-02, -2.8113e-03,  2.2021e-02, -3.0646e-02,  2.0509e-02,
#          -1.2472e-02, -2.0967e-02, -2.5782e-02, -3.1062e-02, -2.8018e-02,
#          -2.4781e-02, -1.0170e-02, -1.1500e-02, -1.4157e-02,  8.4673e-03,
#          -1.8725e-02,  1.4584e-03, -1.5016e-02, -6.3635e-03,  8.7333e-03,
#          -1.7013e-02, -7.0574e-03,  7.3983e-04,  1.0714e-02, -3.1661e-02,
#           2.6202e-03, -4.1418e-03, -5.2588e-03,  1.3510e-02, -7.0236e-03,
#          -9.1063e-03,  5.5409e-03, -2.5933e-02, -4.5329e-04, -3.0036e-02,
#          -4.1766e-03,  4.4265e-04, -1.6495e-02,  2.1334e-02,  2.8259e-02,
#           1.9332e-02, -2.3221e-02,  2.0507e-02,  2.3852e-02,  5.3718e-03,
#          -1.1058e-02,  1.4574e-02,  3.1978e-02,  1.7982e-02,  6.3096e-04,
#           1.5430e-02,  1.9230e-02, -2.8978e-02,  3.5665e-03, -1.0564e-02,
#           6.1287e-03, -2.8823e-02,  2.9021e-02, -2.9753e-02,  1.3982e-02,
#          -2.9980e-02,  1.2557e-02,  1.8348e-02,  1.0755e-02,  6.7396e-03,
#          -2.0546e-03,  2.2346e-02, -2.3202e-02,  5.4953e-03, -2.2014e-02,
#           1.6579e-02,  2.6599e-02,  2.7566e-02,  1.4876e-02,  2.1047e-04,
#           2.8336e-02,  2.8064e-02,  1.9469e-02, -1.3497e-02,  1.6557e-02,
#           8.7262e-04,  2.9327e-02, -1.4471e-03,  1.7423e-02,  7.9326e-03,
#           9.2998e-03, -1.2638e-02,  2.6577e-02,  6.1924e-03,  2.4498e-02,
#           1.4016e-02, -5.2968e-03,  3.8881e-03, -1.1445e-03, -2.6461e-02,
#           2.2568e-02,  3.1428e-02, -1.1835e-02, -2.7541e-02, -1.6705e-02,
#          -1.1392e-02,  1.6342e-02,  2.2284e-02, -1.0392e-02, -2.5902e-02,
#          -2.8012e-02,  2.6254e-02, -1.2765e-02,  4.5893e-03, -7.8011e-03,
#           9.1281e-03,  2.8897e-02, -9.6038e-03,  1.5134e-04, -1.4454e-02,
#          -1.5682e-02, -2.6998e-02,  9.3219e-03, -1.6541e-02, -2.4518e-02,
#           3.0804e-02,  2.9600e-02,  2.3558e-02,  3.2961e-04, -3.0142e-02,
#           2.1461e-02, -9.4307e-03, -8.4092e-03,  9.5361e-03, -2.6046e-02,
#          -1.4169e-02, -4.2447e-03, -2.9484e-02,  1.7330e-02, -1.0720e-03,
#           1.0277e-02,  2.8566e-02,  1.1286e-03, -1.5542e-02, -1.0786e-02,
#           2.5223e-02,  1.3621e-02, -3.1081e-02,  5.3393e-03,  1.2445e-02,
#           1.9490e-02,  1.4043e-03, -3.0697e-02, -1.0483e-02,  9.4352e-03,
#          -2.3404e-02,  1.4285e-02,  1.3450e-02, -1.0795e-02, -8.6684e-05,
#          -8.2561e-03,  1.1092e-02, -1.4651e-02, -2.9767e-02,  4.5541e-03,
#           1.8088e-03, -2.5180e-02,  1.7880e-02,  1.5189e-02,  1.4398e-02,
#          -1.7391e-03,  1.4773e-02, -2.6024e-02, -1.7855e-02, -3.0412e-02,
#           2.9361e-02, -2.5590e-02, -1.1497e-02, -1.4840e-02,  2.0468e-03,
#           1.4583e-02, -2.5205e-02,  3.1511e-02, -5.1816e-04, -2.4969e-03,
#           2.6782e-02, -1.3341e-02, -1.3610e-02, -2.2280e-02, -1.4610e-02,
#           1.8599e-03,  6.0237e-03,  3.1547e-02, -2.5399e-02, -2.3836e-02,
#          -2.6812e-02, -1.8263e-02, -1.0211e-02,  9.2099e-03, -2.0657e-02,
#          -2.3862e-02,  2.0851e-02, -2.2735e-02,  1.0561e-02, -1.1691e-02,
#          -2.0171e-02, -2.2399e-02,  8.5430e-04,  2.7830e-02,  2.8206e-02,
#          -2.3879e-02,  1.1196e-02, -4.1043e-03, -2.9989e-02, -2.2411e-03,
#           1.8035e-02,  5.6263e-03,  5.4781e-03, -8.6444e-04, -1.4884e-02,
#          -2.3547e-03,  2.3227e-02, -1.3512e-02, -1.0416e-02,  1.3051e-02,
#          -1.5043e-02, -2.5463e-02,  8.6667e-03,  2.2629e-02,  2.4096e-02,
#           1.7882e-02, -2.7627e-02, -4.0419e-03,  1.3545e-02,  6.8346e-03,
#           2.2994e-02, -2.7614e-03,  2.0270e-02,  9.2415e-03, -3.1295e-02,
#           6.6556e-03,  2.8585e-02,  1.5980e-02,  2.7098e-02, -3.5683e-03,
#          -1.7939e-02, -7.7373e-03, -2.7563e-02,  3.2018e-02, -2.5919e-02,
#           3.7375e-03,  2.4782e-02, -8.1774e-03, -2.1618e-02,  6.7963e-04,
#           1.9072e-02,  2.9801e-02, -9.4571e-03,  2.9169e-02, -2.2079e-03,
#          -4.9863e-03,  2.0993e-02, -2.9533e-02,  2.5058e-03,  2.2914e-02,
#           2.3116e-02, -1.7571e-03, -1.3140e-02,  2.0656e-02, -6.0943e-03,
#           1.6870e-02, -2.5456e-02, -2.9936e-02,  1.7863e-02, -8.8403e-03,
#           2.8801e-02,  2.9179e-02,  1.1647e-02,  1.6679e-02,  2.9607e-02,
#          -1.8823e-04,  2.0164e-02,  2.1988e-02, -2.7186e-02,  1.2240e-02,
#           5.9944e-03,  1.4187e-02, -3.0767e-02, -1.5271e-02,  5.3389e-03,
#           1.4404e-02,  6.3039e-03,  1.1204e-02, -1.2000e-02, -3.0934e-03,
#          -3.0955e-02,  3.3417e-02,  8.1823e-03,  6.4656e-03,  3.0074e-02,
#          -2.2648e-03,  1.4399e-03, -2.7922e-02,  2.1540e-02,  2.4542e-02,
#           1.8802e-02,  2.6529e-02, -4.4488e-03,  5.1588e-03,  3.8337e-03,
#           2.0764e-02, -2.6803e-04,  2.3254e-02, -9.3052e-03, -2.6988e-03,
#          -2.3882e-02,  6.9104e-04,  2.7089e-02,  8.6919e-03, -2.9739e-02,
#           4.5873e-03,  8.2374e-03,  1.7412e-02, -2.8611e-02, -2.7504e-02,
#           2.5615e-04, -2.1096e-02, -3.0661e-02,  3.1356e-02, -8.1808e-03,
#          -2.4663e-02, -2.3353e-02, -2.3970e-02, -2.5898e-02,  4.4282e-03,
#           3.0026e-03,  1.5095e-02, -6.1679e-03,  6.3061e-03, -1.5876e-02,
#          -9.6868e-03, -3.0867e-02,  2.0866e-02,  9.4526e-03, -5.5329e-02,
#          -5.1942e-03]], requires_grad=True), Parameter containing:
# tensor([0.0281], requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=851, bias=True)
#     (1): Linear(in_features=851, out_features=951, bias=True)
#     (2): Linear(in_features=951, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[ 8.4823,  1.2874,  3.8433],
#         [ 6.3628,  4.5830,  6.8709],
#         [ 9.5007, 10.5686, 14.5369],
#         [ 2.7702,  9.1947,  8.4208],
#         [ 8.1549,  8.1288,  4.1824],
#         [ 2.8599,  0.6266,  5.7706],
#         [ 9.4994, 24.8554, 24.3957],
#         [ 5.9511,  6.8335,  5.0241],
#         [ 1.0827,  0.7347,  1.1826],
#         [ 3.3039,  4.2094,  4.9122],
#         [ 5.1887, 10.3858,  9.6000],
#         [ 8.6661, 16.7210, 16.3864],
#         [ 6.5375,  1.9848,  7.9297],
#         [ 9.7648, 31.8522, 29.5890],
#         [12.9340, 11.8892,  5.2417],
#         [ 9.3644,  3.6599,  3.9022],
#         [ 3.9849, 10.0192,  8.5279],
#         [ 0.7702,  1.3431,  0.9888],
#         [ 9.5696,  0.1444,  2.6998],
#         [ 7.7714, 11.4869, 16.6507]])

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5099], grad_fn=<ReluBackward0>),
#  tensor([3.9191], grad_fn=<ReluBackward0>),
#  tensor([7.7069], grad_fn=<ReluBackward0>),
#  tensor([1.8213], grad_fn=<ReluBackward0>),
#  tensor([0.5894], grad_fn=<ReluBackward0>),
#  tensor([3.8259], grad_fn=<ReluBackward0>),
#  tensor([7.6028], grad_fn=<ReluBackward0>),
#  tensor([1.5016], grad_fn=<ReluBackward0>),
#  tensor([0.6869], grad_fn=<ReluBackward0>),
#  tensor([2.3385], grad_fn=<ReluBackward0>),
#  tensor([3.0060], grad_fn=<ReluBackward0>),
#  tensor([5.8042], grad_fn=<ReluBackward0>),
#  tensor([5.1747], grad_fn=<ReluBackward0>),
#  tensor([6.8909], grad_fn=<ReluBackward0>),
#  tensor([0.4213], grad_fn=<ReluBackward0>),
#  tensor([2.2013], grad_fn=<ReluBackward0>),
#  tensor([1.7629], grad_fn=<ReluBackward0>),
#  tensor([0.1828], grad_fn=<ReluBackward0>),
#  tensor([1.8003], grad_fn=<ReluBackward0>),
#  tensor([8.7671], grad_fn=<ReluBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=851, bias=True)
#     (1): Linear(in_features=851, out_features=951, bias=True)
#     (2): Linear(in_features=951, out_features=1, bias=True)
#   )
# )

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5099], grad_fn=<ReluBackward0>),
#  tensor([3.9191], grad_fn=<ReluBackward0>),
#  tensor([7.7069], grad_fn=<ReluBackward0>),
#  tensor([1.8213], grad_fn=<ReluBackward0>),
#  tensor([0.5894], grad_fn=<ReluBackward0>),
#  tensor([3.8259], grad_fn=<ReluBackward0>),
#  tensor([7.6028], grad_fn=<ReluBackward0>),
#  tensor([1.5016], grad_fn=<ReluBackward0>),
#  tensor([0.6869], grad_fn=<ReluBackward0>),
#  tensor([2.3385], grad_fn=<ReluBackward0>),
#  tensor([3.0060], grad_fn=<ReluBackward0>),
#  tensor([5.8042], grad_fn=<ReluBackward0>),
#  tensor([5.1747], grad_fn=<ReluBackward0>),
#  tensor([6.8909], grad_fn=<ReluBackward0>),
#  tensor([0.4213], grad_fn=<ReluBackward0>),
#  tensor([2.2013], grad_fn=<ReluBackward0>),
#  tensor([1.7629], grad_fn=<ReluBackward0>),
#  tensor([0.1828], grad_fn=<ReluBackward0>),
#  tensor([1.8003], grad_fn=<ReluBackward0>),
#  tensor([8.7671], grad_fn=<ReluBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[ 0.0764, -1.0654, -1.0088]])
# tensor([[2.0342, 2.2249, 4.1557]])
# tensor([[2.4368]], grad_fn=<ReluBackward0>)
