# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# **training with found best parameters:**
# ```
# [I 2023-05-13 12:52:32,479] Trial 38 finished with value: 0.007381363410007907 and parameters: {'n_layers': 2, 'n_units_0': 172, 'n_units_1': 249, 'hidden_activation': 'LeakyReLU', 'output_activation': 'Linear', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 0.0001468891993074274, 'batch_size': 55, 'n_epochs': 90, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 38 with value: 0.007381363410007907.
# ```

# %%
# %%script echo skipping
#
# !jupyter nbconvert 0073.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %% [markdown]
# Next some cells for working on google colab,

# %%
#%%script echo skipping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (2.6)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.
#
# NOTE: Some subparameters still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 2
N_UNITS_NO_OPT = [172, 249]
HIDDEN_ACTIVATION_NAME_NO_OPT = "LeakyReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 0.0001468891993074274
BATCH_SIZE_NO_OPT = 55
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"
#Best trial:
# Adam', 'lr': 0.0001468891993074274, 'batch_size': 55, 'n_epochs': 90, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 38 with value: 0.007381363410007907.



c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test)
# Out:
# tensor([1.9220, 2.2925, 1.3112,  ..., 1.3882, 1.4931, 5.2596], device='cuda:0')

# %%
# Plotting the histograms of the input data before normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data before normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform z-score normalization

# %%
if ZSCORE_NORMALIZATION:
    # Computing the mean and standard deviation of each input variable from the training set
    D_mean = torch.mean(x_train[:, 0])
    D_std = torch.std(x_train[:, 0])
    Sx_mean = torch.mean(x_train[:, 1])
    Sx_std = torch.std(x_train[:, 1])
    tau_mean = torch.mean(x_train[:, 2])
    tau_std = torch.std(x_train[:, 2])

    # Applying z-score normalization to both train and test sets using the statistics from the training set
    x_train[:, 0] = torch.sub(x_train[:, 0], D_mean).div(D_std)
    x_train[:, 1] = torch.sub(x_train[:, 1], Sx_mean).div(Sx_std)
    x_train[:, 2] = torch.sub(x_train[:, 2], tau_mean).div(tau_std)
    x_test[:, 0] = torch.sub(x_test[:, 0], D_mean).div(D_std)
    x_test[:, 1] = torch.sub(x_test[:, 1], Sx_mean).div(Sx_std)
    x_test[:, 2] = torch.sub(x_test[:, 2], tau_mean).div(tau_std)

# %%
# Verifying that the means and the stds of the input data are close to 0 and 1 respectively.
print(torch.mean(x_train[:, 0]))
print(torch.std(x_train[:, 0]))
print(torch.mean(x_train[:, 1]))
print(torch.std(x_train[:, 1]))
print(torch.mean(x_train[:, 2]))
print(torch.std(x_train[:, 2]))

# Plotting the histograms of the input data after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x_train[:, 0].cpu().numpy(), bins=20)
plt.xlabel("D")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 2)
plt.hist(x_train[:, 1].cpu().numpy(), bins=20)
plt.xlabel("Sx")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 3, 3)
plt.hist(x_train[:, 2].cpu().numpy(), bins=20)
plt.xlabel("tau")
plt.ylabel("Frequency")
plt.yscale("log")
plt.suptitle("Input data after normalization")
plt.tight_layout()
plt.show()
# Out:
# tensor(5.6259, device='cuda:0')
# tensor(3.3305, device='cuda:0')
# tensor(6.8267, device='cuda:0')
# tensor(8.0801, device='cuda:0')
# tensor(8.0068, device='cuda:0')
# tensor(7.8406, device='cuda:0')

# %%
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            #gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer) #, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min"#, factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        else:
            scheduler = None
#Best trial:
#  Value:  0.00270861783316941
#  Params: 
#    n_layers: 3
#    n_units_0: 555
#    n_units_1: 458
#    n_units_2: 115
#    hidden_activation: ReLU
#    output_activation: ReLU
#    loss: Huber
#    optimizer: RMSprop
#    lr: 0.000122770896701404
#    batch_size: 49
#    n_epochs: 152
#    scheduler: ReduceLROnPlateau
#    factor: 0.18979341786654758
#    patience: 11
#    threshold: 0.0017197466122611932


    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: SmoothL1Loss()
# batch_size: 55
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f4521d44c70>
# loss_name: Huber
# optimizer_name: Adam
# scheduler_name: ReduceLROnPlateau
# n_units: [172, 249]
# n_layers: 2
# hidden_activation: LeakyReLU(negative_slope=0.01)
# output_activation: Identity()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.0415, Test Loss: 0.0003, Train L1 Norm: 0.2012, Test L1 Norm: 0.0311, Train Linf Norm: 7.7340, Test Linf Norm: 0.8774
# Epoch 2: Train Loss: 0.0002, Test Loss: 0.0006, Train L1 Norm: 0.0368, Test L1 Norm: 0.0592, Train Linf Norm: 1.3242, Test Linf Norm: 2.0649
# Epoch 3: Train Loss: 0.0003, Test Loss: 0.0001, Train L1 Norm: 0.0349, Test L1 Norm: 0.0419, Train Linf Norm: 1.3088, Test Linf Norm: 1.5387
# Epoch 4: Train Loss: 0.0005, Test Loss: 0.0001, Train L1 Norm: 0.0359, Test L1 Norm: 0.0302, Train Linf Norm: 1.3391, Test Linf Norm: 1.0741
# Epoch 5: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0306, Test L1 Norm: 0.0205, Train Linf Norm: 1.2192, Test Linf Norm: 0.6951
# Epoch 6: Train Loss: 0.0003, Test Loss: 0.0008, Train L1 Norm: 0.0352, Test L1 Norm: 0.0348, Train Linf Norm: 1.3730, Test Linf Norm: 1.1045
# Epoch 7: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0316, Test L1 Norm: 0.0185, Train Linf Norm: 1.2241, Test Linf Norm: 0.6350
# Epoch 8: Train Loss: 0.0004, Test Loss: 0.0000, Train L1 Norm: 0.0299, Test L1 Norm: 0.0186, Train Linf Norm: 1.1676, Test Linf Norm: 0.6720
# Epoch 9: Train Loss: 0.0003, Test Loss: 0.0001, Train L1 Norm: 0.0344, Test L1 Norm: 0.0293, Train Linf Norm: 1.3668, Test Linf Norm: 1.0090
# Epoch 10: Train Loss: 0.0003, Test Loss: 0.0000, Train L1 Norm: 0.0275, Test L1 Norm: 0.0185, Train Linf Norm: 1.0607, Test Linf Norm: 0.6658
# Epoch 11: Train Loss: 0.0002, Test Loss: 0.0004, Train L1 Norm: 0.0284, Test L1 Norm: 0.0334, Train Linf Norm: 1.1354, Test Linf Norm: 1.0037
# Epoch 12: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0274, Test L1 Norm: 0.0335, Train Linf Norm: 1.0500, Test Linf Norm: 1.2516
# Epoch 13: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0205, Test L1 Norm: 0.0241, Train Linf Norm: 0.7296, Test Linf Norm: 0.7920
# Epoch 14: Train Loss: 0.0003, Test Loss: 0.0000, Train L1 Norm: 0.0290, Test L1 Norm: 0.0111, Train Linf Norm: 1.1658, Test Linf Norm: 0.3625
# Epoch 15: Train Loss: 0.0006, Test Loss: 0.0000, Train L1 Norm: 0.0287, Test L1 Norm: 0.0203, Train Linf Norm: 1.1446, Test Linf Norm: 0.7360
# Epoch 16: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0207, Test L1 Norm: 0.0138, Train Linf Norm: 0.8622, Test Linf Norm: 0.4131
# Epoch 17: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0199, Test L1 Norm: 0.0169, Train Linf Norm: 0.7539, Test Linf Norm: 0.5267
# Epoch 18: Train Loss: 0.0003, Test Loss: 0.0000, Train L1 Norm: 0.0266, Test L1 Norm: 0.0152, Train Linf Norm: 1.1105, Test Linf Norm: 0.5320
# Epoch 19: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0240, Test L1 Norm: 0.0142, Train Linf Norm: 0.9581, Test Linf Norm: 0.4845
# Epoch 20: Train Loss: 0.0003, Test Loss: 0.0001, Train L1 Norm: 0.0243, Test L1 Norm: 0.0308, Train Linf Norm: 0.9019, Test Linf Norm: 1.1415
# Epoch 21: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0216, Test L1 Norm: 0.0158, Train Linf Norm: 0.8839, Test Linf Norm: 0.5346
# Epoch 22: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0313, Test L1 Norm: 0.0138, Train Linf Norm: 1.3145, Test Linf Norm: 0.4983
# Epoch 23: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0208, Test L1 Norm: 0.0213, Train Linf Norm: 0.8320, Test Linf Norm: 0.7989
# Epoch 24: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0243, Test L1 Norm: 0.0177, Train Linf Norm: 0.9699, Test Linf Norm: 0.6799
# Epoch 25: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0226, Test L1 Norm: 0.0174, Train Linf Norm: 0.9350, Test Linf Norm: 0.6564
# Epoch 26: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0241, Test L1 Norm: 0.0298, Train Linf Norm: 0.9973, Test Linf Norm: 1.1222
# Epoch 27: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0183, Test L1 Norm: 0.0115, Train Linf Norm: 0.7120, Test Linf Norm: 0.3882
# Epoch 28: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0230, Test L1 Norm: 0.0124, Train Linf Norm: 0.9456, Test Linf Norm: 0.3473
# Epoch 29: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0233, Test L1 Norm: 0.0235, Train Linf Norm: 0.9299, Test Linf Norm: 0.9085
# Epoch 30: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0184, Test L1 Norm: 0.0238, Train Linf Norm: 0.7102, Test Linf Norm: 0.8746
# Epoch 31: Train Loss: 0.0002, Test Loss: 0.0016, Train L1 Norm: 0.0197, Test L1 Norm: 0.0527, Train Linf Norm: 0.7728, Test Linf Norm: 1.8123
# Epoch 32: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0142, Test L1 Norm: 0.0235, Train Linf Norm: 0.5429, Test Linf Norm: 0.8410
# Epoch 33: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0219, Test L1 Norm: 0.0111, Train Linf Norm: 0.8943, Test Linf Norm: 0.3798
# Epoch 34: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0197, Test L1 Norm: 0.0075, Train Linf Norm: 0.7725, Test Linf Norm: 0.2334
# Epoch 35: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0172, Test L1 Norm: 0.0105, Train Linf Norm: 0.6534, Test Linf Norm: 0.3634
# Epoch 36: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0217, Test L1 Norm: 0.0078, Train Linf Norm: 0.9248, Test Linf Norm: 0.2386
# Epoch 37: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0185, Test L1 Norm: 0.0098, Train Linf Norm: 0.7310, Test Linf Norm: 0.3158
# Epoch 38: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0219, Test L1 Norm: 0.0144, Train Linf Norm: 0.9022, Test Linf Norm: 0.4478
# Epoch 39: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0203, Test L1 Norm: 0.0213, Train Linf Norm: 0.8243, Test Linf Norm: 0.8509
# Epoch 40: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0165, Test L1 Norm: 0.0096, Train Linf Norm: 0.6274, Test Linf Norm: 0.3370
# Epoch 41: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0169, Test L1 Norm: 0.0105, Train Linf Norm: 0.6784, Test Linf Norm: 0.3310
# Epoch 42: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0178, Test L1 Norm: 0.0098, Train Linf Norm: 0.6776, Test Linf Norm: 0.3522
# Epoch 43: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0188, Test L1 Norm: 0.0156, Train Linf Norm: 0.7354, Test Linf Norm: 0.6087
# Epoch 44: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0158, Test L1 Norm: 0.0280, Train Linf Norm: 0.6424, Test Linf Norm: 1.1130
# Epoch 45: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0197, Test L1 Norm: 0.0108, Train Linf Norm: 0.8057, Test Linf Norm: 0.3688
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0150, Test L1 Norm: 0.0176, Train Linf Norm: 0.6291, Test Linf Norm: 0.6811
# Epoch 47: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0173, Test L1 Norm: 0.0141, Train Linf Norm: 0.6883, Test Linf Norm: 0.5341
# Epoch 48: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0193, Test L1 Norm: 0.0199, Train Linf Norm: 0.7962, Test Linf Norm: 0.7200
# Epoch 49: Train Loss: 0.0001, Test Loss: 0.0023, Train L1 Norm: 0.0154, Test L1 Norm: 0.0603, Train Linf Norm: 0.6011, Test Linf Norm: 1.8858
# Epoch 50: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0170, Test L1 Norm: 0.0120, Train Linf Norm: 0.6750, Test Linf Norm: 0.3800
# Epoch 51: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0185, Test L1 Norm: 0.0126, Train Linf Norm: 0.7863, Test Linf Norm: 0.4662
# Epoch 52: Train Loss: 0.0002, Test Loss: 0.0000, Train L1 Norm: 0.0158, Test L1 Norm: 0.0090, Train Linf Norm: 0.6157, Test Linf Norm: 0.3362
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0002, Train L1 Norm: 0.0151, Test L1 Norm: 0.0151, Train Linf Norm: 0.6419, Test Linf Norm: 0.4078
# Epoch 54: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0177, Test L1 Norm: 0.0141, Train Linf Norm: 0.6942, Test Linf Norm: 0.5663
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0142, Test L1 Norm: 0.0139, Train Linf Norm: 0.5602, Test Linf Norm: 0.5480
# Epoch 56: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0218, Test L1 Norm: 0.0135, Train Linf Norm: 0.9537, Test Linf Norm: 0.5284
# Epoch 57: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0185, Test L1 Norm: 0.0121, Train Linf Norm: 0.7781, Test Linf Norm: 0.4729
# Epoch 58: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0145, Train Linf Norm: 0.7309, Test Linf Norm: 0.5202
# Epoch 59: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0182, Test L1 Norm: 0.0097, Train Linf Norm: 0.7693, Test Linf Norm: 0.3529
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0180, Test L1 Norm: 0.0174, Train Linf Norm: 0.7746, Test Linf Norm: 0.6968
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0160, Test L1 Norm: 0.0116, Train Linf Norm: 0.6639, Test Linf Norm: 0.4075
# Epoch 62: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0221, Test L1 Norm: 0.0078, Train Linf Norm: 0.9538, Test Linf Norm: 0.2646
# Epoch 63: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0193, Test L1 Norm: 0.0106, Train Linf Norm: 0.8360, Test Linf Norm: 0.3930
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0124, Test L1 Norm: 0.0089, Train Linf Norm: 0.5614, Test Linf Norm: 0.3475
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0120, Test L1 Norm: 0.0093, Train Linf Norm: 0.5351, Test Linf Norm: 0.3739
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0114, Test L1 Norm: 0.0075, Train Linf Norm: 0.5061, Test Linf Norm: 0.2743
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0111, Test L1 Norm: 0.0104, Train Linf Norm: 0.4886, Test Linf Norm: 0.4049
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0116, Test L1 Norm: 0.0082, Train Linf Norm: 0.5167, Test Linf Norm: 0.3165
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0106, Test L1 Norm: 0.0095, Train Linf Norm: 0.4568, Test Linf Norm: 0.3702
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0107, Test L1 Norm: 0.0082, Train Linf Norm: 0.4633, Test Linf Norm: 0.3200
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0106, Test L1 Norm: 0.0099, Train Linf Norm: 0.4593, Test Linf Norm: 0.4006
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0113, Test L1 Norm: 0.0095, Train Linf Norm: 0.5029, Test Linf Norm: 0.3721
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0097, Test L1 Norm: 0.0064, Train Linf Norm: 0.4043, Test Linf Norm: 0.2209
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0094, Test L1 Norm: 0.0060, Train Linf Norm: 0.4012, Test Linf Norm: 0.2099
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0095, Test L1 Norm: 0.0065, Train Linf Norm: 0.4122, Test Linf Norm: 0.2392
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0093, Test L1 Norm: 0.0099, Train Linf Norm: 0.3963, Test Linf Norm: 0.3864
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0093, Test L1 Norm: 0.0068, Train Linf Norm: 0.3964, Test Linf Norm: 0.2514
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0060, Train Linf Norm: 0.3750, Test Linf Norm: 0.2197
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0071, Train Linf Norm: 0.3720, Test Linf Norm: 0.2610
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0096, Test L1 Norm: 0.0076, Train Linf Norm: 0.4180, Test Linf Norm: 0.2783
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0064, Train Linf Norm: 0.3328, Test Linf Norm: 0.2330
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0068, Train Linf Norm: 0.3865, Test Linf Norm: 0.2530
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0070, Train Linf Norm: 0.3750, Test Linf Norm: 0.2526
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0074, Train Linf Norm: 0.3478, Test Linf Norm: 0.2739
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0093, Train Linf Norm: 0.3969, Test Linf Norm: 0.3511
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0064, Train Linf Norm: 0.3560, Test Linf Norm: 0.2300
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0097, Test L1 Norm: 0.0087, Train Linf Norm: 0.4073, Test Linf Norm: 0.3310
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0061, Train Linf Norm: 0.3518, Test Linf Norm: 0.2146
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0059, Train Linf Norm: 0.3414, Test Linf Norm: 0.2163
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0086, Test L1 Norm: 0.0064, Train Linf Norm: 0.3704, Test Linf Norm: 0.2215
# Epoch 91: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0073, Train Linf Norm: 0.3812, Test Linf Norm: 0.2718
# Epoch 92: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0080, Train Linf Norm: 0.3973, Test Linf Norm: 0.2977
# Epoch 93: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0070, Train Linf Norm: 0.3414, Test Linf Norm: 0.2588
# Epoch 94: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0075, Train Linf Norm: 0.3632, Test Linf Norm: 0.2869
# Epoch 95: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0087, Test L1 Norm: 0.0070, Train Linf Norm: 0.3719, Test Linf Norm: 0.2615
# Epoch 96: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0052, Train Linf Norm: 0.3818, Test Linf Norm: 0.1846
# Epoch 97: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0086, Test L1 Norm: 0.0069, Train Linf Norm: 0.3706, Test Linf Norm: 0.2442
# Epoch 98: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0059, Train Linf Norm: 0.3741, Test Linf Norm: 0.2173
# Epoch 99: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0095, Test L1 Norm: 0.0056, Train Linf Norm: 0.4169, Test Linf Norm: 0.2075
# Epoch 100: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0061, Train Linf Norm: 0.3214, Test Linf Norm: 0.2259
# Epoch 101: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0086, Test L1 Norm: 0.0065, Train Linf Norm: 0.3746, Test Linf Norm: 0.2447
# Epoch 102: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0059, Train Linf Norm: 0.3817, Test Linf Norm: 0.2099
# Epoch 103: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0082, Test L1 Norm: 0.0062, Train Linf Norm: 0.3524, Test Linf Norm: 0.2318
# Epoch 104: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0054, Train Linf Norm: 0.3579, Test Linf Norm: 0.1980
# Epoch 105: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0052, Train Linf Norm: 0.3813, Test Linf Norm: 0.1718
# Epoch 106: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0087, Test L1 Norm: 0.0082, Train Linf Norm: 0.3765, Test Linf Norm: 0.2766
# Epoch 107: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0052, Train Linf Norm: 0.3598, Test Linf Norm: 0.1911
# Epoch 108: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0084, Test L1 Norm: 0.0060, Train Linf Norm: 0.3655, Test Linf Norm: 0.2218
# Epoch 109: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0099, Train Linf Norm: 0.3234, Test Linf Norm: 0.3843
# Epoch 110: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0061, Train Linf Norm: 0.3469, Test Linf Norm: 0.2287
# Epoch 111: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0084, Test L1 Norm: 0.0059, Train Linf Norm: 0.3679, Test Linf Norm: 0.2247
# Epoch 112: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0114, Train Linf Norm: 0.3403, Test Linf Norm: 0.4319
# Epoch 113: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0064, Train Linf Norm: 0.3406, Test Linf Norm: 0.2397
# Epoch 114: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0084, Test L1 Norm: 0.0066, Train Linf Norm: 0.3604, Test Linf Norm: 0.2454
# Epoch 115: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0053, Train Linf Norm: 0.3329, Test Linf Norm: 0.1993
# Epoch 116: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0056, Train Linf Norm: 0.3359, Test Linf Norm: 0.2105
# Epoch 117: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0052, Train Linf Norm: 0.3417, Test Linf Norm: 0.1912
# Epoch 118: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0058, Train Linf Norm: 0.3448, Test Linf Norm: 0.2156
# Epoch 119: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0055, Train Linf Norm: 0.3308, Test Linf Norm: 0.2071
# Epoch 120: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0053, Train Linf Norm: 0.3354, Test Linf Norm: 0.1968
# Epoch 121: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0056, Train Linf Norm: 0.3287, Test Linf Norm: 0.2128
# Epoch 122: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0058, Train Linf Norm: 0.3230, Test Linf Norm: 0.2181
# Epoch 123: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0056, Train Linf Norm: 0.3373, Test Linf Norm: 0.2101
# Epoch 124: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0054, Train Linf Norm: 0.3289, Test Linf Norm: 0.2037
# Epoch 125: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0053, Train Linf Norm: 0.3251, Test Linf Norm: 0.2015
# Epoch 126: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0056, Train Linf Norm: 0.3315, Test Linf Norm: 0.2115
# Epoch 127: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0053, Train Linf Norm: 0.3250, Test Linf Norm: 0.1996
# Epoch 128: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0058, Train Linf Norm: 0.3292, Test Linf Norm: 0.2178
# Epoch 129: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0052, Train Linf Norm: 0.3297, Test Linf Norm: 0.1942
# Epoch 130: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0054, Train Linf Norm: 0.3478, Test Linf Norm: 0.2020
# Epoch 131: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0052, Train Linf Norm: 0.3401, Test Linf Norm: 0.1915
# Epoch 132: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0055, Train Linf Norm: 0.3362, Test Linf Norm: 0.2092
# Epoch 133: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0054, Train Linf Norm: 0.3215, Test Linf Norm: 0.2054
# Epoch 134: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0052, Train Linf Norm: 0.3300, Test Linf Norm: 0.1943
# Epoch 135: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0050, Train Linf Norm: 0.3285, Test Linf Norm: 0.1862
# Epoch 136: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0051, Train Linf Norm: 0.3351, Test Linf Norm: 0.1896
# Epoch 137: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0054, Train Linf Norm: 0.3317, Test Linf Norm: 0.2019
# Epoch 138: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0055, Train Linf Norm: 0.3308, Test Linf Norm: 0.2086
# Epoch 139: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0056, Train Linf Norm: 0.3256, Test Linf Norm: 0.2091
# Epoch 140: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0051, Train Linf Norm: 0.3156, Test Linf Norm: 0.1920
# Epoch 141: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0050, Train Linf Norm: 0.3332, Test Linf Norm: 0.1839
# Epoch 142: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0050, Train Linf Norm: 0.3261, Test Linf Norm: 0.1823
# Epoch 143: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0052, Train Linf Norm: 0.3241, Test Linf Norm: 0.1951
# Epoch 144: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0052, Train Linf Norm: 0.3303, Test Linf Norm: 0.1957
# Epoch 145: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0057, Train Linf Norm: 0.3245, Test Linf Norm: 0.2157
# Epoch 146: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0058, Train Linf Norm: 0.3279, Test Linf Norm: 0.2179
# Epoch 147: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0051, Train Linf Norm: 0.3444, Test Linf Norm: 0.1896
# Epoch 148: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3150, Test Linf Norm: 0.2053
# Epoch 149: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0058, Train Linf Norm: 0.3232, Test Linf Norm: 0.2186
# Epoch 150: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0053, Train Linf Norm: 0.3398, Test Linf Norm: 0.1973
# Epoch 151: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0053, Train Linf Norm: 0.3261, Test Linf Norm: 0.2011
# Epoch 152: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0053, Train Linf Norm: 0.3364, Test Linf Norm: 0.1982
# Epoch 153: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0059, Train Linf Norm: 0.3291, Test Linf Norm: 0.2259
# Epoch 154: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0054, Train Linf Norm: 0.3232, Test Linf Norm: 0.2047
# Epoch 155: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0058, Train Linf Norm: 0.3289, Test Linf Norm: 0.2221
# Epoch 156: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0055, Train Linf Norm: 0.3290, Test Linf Norm: 0.2073
# Epoch 157: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0051, Train Linf Norm: 0.3239, Test Linf Norm: 0.1891
# Epoch 158: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0059, Train Linf Norm: 0.3228, Test Linf Norm: 0.2267
# Epoch 159: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0052, Train Linf Norm: 0.3241, Test Linf Norm: 0.1968
# Epoch 160: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0053, Train Linf Norm: 0.3256, Test Linf Norm: 0.2019
# Epoch 161: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0054, Train Linf Norm: 0.3201, Test Linf Norm: 0.2071
# Epoch 162: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0053, Train Linf Norm: 0.3226, Test Linf Norm: 0.1993
# Epoch 163: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0055, Train Linf Norm: 0.3275, Test Linf Norm: 0.2074
# Epoch 164: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0055, Train Linf Norm: 0.3352, Test Linf Norm: 0.2077
# Epoch 165: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0052, Train Linf Norm: 0.3215, Test Linf Norm: 0.1957
# Epoch 166: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0051, Train Linf Norm: 0.3205, Test Linf Norm: 0.1893
# Epoch 167: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0051, Train Linf Norm: 0.3162, Test Linf Norm: 0.1930
# Epoch 168: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0053, Train Linf Norm: 0.3065, Test Linf Norm: 0.2004
# Epoch 169: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0050, Train Linf Norm: 0.3202, Test Linf Norm: 0.1849
# Epoch 170: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0054, Train Linf Norm: 0.3164, Test Linf Norm: 0.2043
# Epoch 171: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0051, Train Linf Norm: 0.3181, Test Linf Norm: 0.1919
# Epoch 172: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0054, Train Linf Norm: 0.3319, Test Linf Norm: 0.2070
# Epoch 173: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0054, Train Linf Norm: 0.3156, Test Linf Norm: 0.2035
# Epoch 174: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0060, Train Linf Norm: 0.3271, Test Linf Norm: 0.2325
# Epoch 175: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0056, Train Linf Norm: 0.3068, Test Linf Norm: 0.2159
# Epoch 176: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0050, Train Linf Norm: 0.3182, Test Linf Norm: 0.1850
# Epoch 177: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0054, Train Linf Norm: 0.3273, Test Linf Norm: 0.2040
# Epoch 178: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0052, Train Linf Norm: 0.3260, Test Linf Norm: 0.1976
# Epoch 179: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3201, Test Linf Norm: 0.2113
# Epoch 180: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0051, Train Linf Norm: 0.3246, Test Linf Norm: 0.1927
# Epoch 181: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0052, Train Linf Norm: 0.3212, Test Linf Norm: 0.1978
# Epoch 182: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3228, Test Linf Norm: 0.2100
# Epoch 183: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0050, Train Linf Norm: 0.3235, Test Linf Norm: 0.1868
# Epoch 184: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0049, Train Linf Norm: 0.3173, Test Linf Norm: 0.1830
# Epoch 185: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0051, Train Linf Norm: 0.3181, Test Linf Norm: 0.1941
# Epoch 186: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0051, Train Linf Norm: 0.3077, Test Linf Norm: 0.1944
# Epoch 187: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0051, Train Linf Norm: 0.3125, Test Linf Norm: 0.1910
# Epoch 188: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0050, Train Linf Norm: 0.3299, Test Linf Norm: 0.1863
# Epoch 189: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0050, Train Linf Norm: 0.3316, Test Linf Norm: 0.1859
# Epoch 190: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0054, Train Linf Norm: 0.3188, Test Linf Norm: 0.2084
# Epoch 191: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3200, Test Linf Norm: 0.2099
# Epoch 192: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0050, Train Linf Norm: 0.3181, Test Linf Norm: 0.1883
# Epoch 193: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0049, Train Linf Norm: 0.3148, Test Linf Norm: 0.1829
# Epoch 194: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0050, Train Linf Norm: 0.3156, Test Linf Norm: 0.1826
# Epoch 195: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0054, Train Linf Norm: 0.3105, Test Linf Norm: 0.2065
# Epoch 196: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0053, Train Linf Norm: 0.3203, Test Linf Norm: 0.2021
# Epoch 197: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0059, Train Linf Norm: 0.3200, Test Linf Norm: 0.2327
# Epoch 198: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3212, Test Linf Norm: 0.2127
# Epoch 199: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0055, Train Linf Norm: 0.3292, Test Linf Norm: 0.2105
# Epoch 200: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0054, Train Linf Norm: 0.3246, Test Linf Norm: 0.2055
# Epoch 201: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0049, Train Linf Norm: 0.3277, Test Linf Norm: 0.1830
# Epoch 202: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0053, Train Linf Norm: 0.3091, Test Linf Norm: 0.2033
# Epoch 203: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0055, Train Linf Norm: 0.3099, Test Linf Norm: 0.2124
# Epoch 204: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0055, Train Linf Norm: 0.3115, Test Linf Norm: 0.2103
# Epoch 205: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0054, Train Linf Norm: 0.3071, Test Linf Norm: 0.2074
# Epoch 206: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0057, Train Linf Norm: 0.3125, Test Linf Norm: 0.2213
# Epoch 207: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0053, Train Linf Norm: 0.3173, Test Linf Norm: 0.2010
# Epoch 208: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0053, Train Linf Norm: 0.3148, Test Linf Norm: 0.2053
# Epoch 209: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0051, Train Linf Norm: 0.3122, Test Linf Norm: 0.1916
# Epoch 210: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0056, Train Linf Norm: 0.3189, Test Linf Norm: 0.2171
# Epoch 211: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0054, Train Linf Norm: 0.3199, Test Linf Norm: 0.2097
# Epoch 212: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0051, Train Linf Norm: 0.3138, Test Linf Norm: 0.1927
# Epoch 213: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0055, Train Linf Norm: 0.3171, Test Linf Norm: 0.2100
# Epoch 214: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0055, Train Linf Norm: 0.3014, Test Linf Norm: 0.2130
# Epoch 215: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3209, Test Linf Norm: 0.2129
# Epoch 216: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0050, Train Linf Norm: 0.3121, Test Linf Norm: 0.1891
# Epoch 217: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0059, Train Linf Norm: 0.3153, Test Linf Norm: 0.2297
# Epoch 218: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0058, Train Linf Norm: 0.3091, Test Linf Norm: 0.2271
# Epoch 219: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0051, Train Linf Norm: 0.3036, Test Linf Norm: 0.1943
# Epoch 220: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0075, Test L1 Norm: 0.0059, Train Linf Norm: 0.3309, Test Linf Norm: 0.2301
# Epoch 221: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0054, Train Linf Norm: 0.3060, Test Linf Norm: 0.2087
# Epoch 222: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0050, Train Linf Norm: 0.3173, Test Linf Norm: 0.1924
# Epoch 223: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0059, Train Linf Norm: 0.3048, Test Linf Norm: 0.2323
# Epoch 224: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0052, Train Linf Norm: 0.3106, Test Linf Norm: 0.2019
# Epoch 225: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0058, Train Linf Norm: 0.3203, Test Linf Norm: 0.2274
# Epoch 226: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0056, Train Linf Norm: 0.3096, Test Linf Norm: 0.2196
# Epoch 227: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0049, Train Linf Norm: 0.3113, Test Linf Norm: 0.1850
# Epoch 228: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0055, Train Linf Norm: 0.3162, Test Linf Norm: 0.2111
# Epoch 229: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0052, Train Linf Norm: 0.3032, Test Linf Norm: 0.2018
# Epoch 230: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0053, Train Linf Norm: 0.3206, Test Linf Norm: 0.2034
# Epoch 231: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0055, Train Linf Norm: 0.3145, Test Linf Norm: 0.2122
# Epoch 232: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0057, Train Linf Norm: 0.3049, Test Linf Norm: 0.2206
# Epoch 233: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0059, Train Linf Norm: 0.2883, Test Linf Norm: 0.2285
# Epoch 234: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0057, Train Linf Norm: 0.3179, Test Linf Norm: 0.2202
# Epoch 235: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0059, Train Linf Norm: 0.3078, Test Linf Norm: 0.2324
# Epoch 236: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0054, Train Linf Norm: 0.3182, Test Linf Norm: 0.2107
# Epoch 237: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0051, Train Linf Norm: 0.3036, Test Linf Norm: 0.1942
# Epoch 238: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0055, Train Linf Norm: 0.3098, Test Linf Norm: 0.2127
# Epoch 239: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0049, Train Linf Norm: 0.3161, Test Linf Norm: 0.1849
# Epoch 240: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0053, Train Linf Norm: 0.3124, Test Linf Norm: 0.2020
# Epoch 241: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3240, Test Linf Norm: 0.2138
# Epoch 242: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0053, Train Linf Norm: 0.3228, Test Linf Norm: 0.2043
# Epoch 243: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0055, Train Linf Norm: 0.3224, Test Linf Norm: 0.2123
# Epoch 244: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0052, Train Linf Norm: 0.3029, Test Linf Norm: 0.1986
# Epoch 245: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0053, Train Linf Norm: 0.3040, Test Linf Norm: 0.2042
# Epoch 246: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0055, Train Linf Norm: 0.3127, Test Linf Norm: 0.2126
# Epoch 247: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0053, Train Linf Norm: 0.3077, Test Linf Norm: 0.2005
# Epoch 248: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0050, Train Linf Norm: 0.3193, Test Linf Norm: 0.1878
# Epoch 249: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0052, Train Linf Norm: 0.3154, Test Linf Norm: 0.1977
# Epoch 250: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0051, Train Linf Norm: 0.3085, Test Linf Norm: 0.1943
# Epoch 251: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0053, Train Linf Norm: 0.3004, Test Linf Norm: 0.2044
# Epoch 252: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0051, Train Linf Norm: 0.3212, Test Linf Norm: 0.1924
# Epoch 253: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0056, Train Linf Norm: 0.3154, Test Linf Norm: 0.2168
# Epoch 254: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0056, Train Linf Norm: 0.2976, Test Linf Norm: 0.2157
# Epoch 255: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0053, Train Linf Norm: 0.3126, Test Linf Norm: 0.2043
# Epoch 256: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0055, Train Linf Norm: 0.3063, Test Linf Norm: 0.2113
# Epoch 257: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0061, Train Linf Norm: 0.3029, Test Linf Norm: 0.2377
# Epoch 258: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0058, Train Linf Norm: 0.2993, Test Linf Norm: 0.2221
# Epoch 259: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0054, Train Linf Norm: 0.3090, Test Linf Norm: 0.2065
# Epoch 260: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0055, Train Linf Norm: 0.3042, Test Linf Norm: 0.2045
# Epoch 261: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0053, Train Linf Norm: 0.2976, Test Linf Norm: 0.1983
# Epoch 262: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0048, Train Linf Norm: 0.2979, Test Linf Norm: 0.1803
# Epoch 263: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0047, Train Linf Norm: 0.2956, Test Linf Norm: 0.1762
# Epoch 264: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0062, Train Linf Norm: 0.3128, Test Linf Norm: 0.2444
# Epoch 265: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0054, Train Linf Norm: 0.3031, Test Linf Norm: 0.2074
# Epoch 266: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0055, Train Linf Norm: 0.2957, Test Linf Norm: 0.2115
# Epoch 267: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0054, Train Linf Norm: 0.3002, Test Linf Norm: 0.2102
# Epoch 268: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0055, Train Linf Norm: 0.2998, Test Linf Norm: 0.2112
# Epoch 269: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0052, Train Linf Norm: 0.3052, Test Linf Norm: 0.1994
# Epoch 270: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2912, Test Linf Norm: 0.2241
# Epoch 271: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0056, Train Linf Norm: 0.2912, Test Linf Norm: 0.2147
# Epoch 272: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0055, Train Linf Norm: 0.3080, Test Linf Norm: 0.2110
# Epoch 273: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0056, Train Linf Norm: 0.2948, Test Linf Norm: 0.2170
# Epoch 274: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0053, Train Linf Norm: 0.3055, Test Linf Norm: 0.2029
# Epoch 275: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0050, Train Linf Norm: 0.2980, Test Linf Norm: 0.1892
# Epoch 276: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0060, Train Linf Norm: 0.2913, Test Linf Norm: 0.2330
# Epoch 277: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0055, Train Linf Norm: 0.2996, Test Linf Norm: 0.2092
# Epoch 278: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0060, Train Linf Norm: 0.2897, Test Linf Norm: 0.2338
# Epoch 279: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0057, Train Linf Norm: 0.3055, Test Linf Norm: 0.2216
# Epoch 280: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0055, Train Linf Norm: 0.3022, Test Linf Norm: 0.2114
# Epoch 281: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0054, Train Linf Norm: 0.3083, Test Linf Norm: 0.2042
# Epoch 282: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0051, Train Linf Norm: 0.3015, Test Linf Norm: 0.1947
# Epoch 283: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0053, Train Linf Norm: 0.3052, Test Linf Norm: 0.2020
# Epoch 284: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0056, Train Linf Norm: 0.3123, Test Linf Norm: 0.2178
# Epoch 285: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0055, Train Linf Norm: 0.2861, Test Linf Norm: 0.2134
# Epoch 286: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0055, Train Linf Norm: 0.3004, Test Linf Norm: 0.2103
# Epoch 287: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0055, Train Linf Norm: 0.2907, Test Linf Norm: 0.2089
# Epoch 288: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0057, Train Linf Norm: 0.2869, Test Linf Norm: 0.2182
# Epoch 289: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0057, Train Linf Norm: 0.2849, Test Linf Norm: 0.2211
# Epoch 290: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0056, Train Linf Norm: 0.3055, Test Linf Norm: 0.2160
# Epoch 291: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0064, Train Linf Norm: 0.3027, Test Linf Norm: 0.2478
# Epoch 292: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0054, Train Linf Norm: 0.3050, Test Linf Norm: 0.2059
# Epoch 293: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0055, Train Linf Norm: 0.2901, Test Linf Norm: 0.2125
# Epoch 294: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0057, Train Linf Norm: 0.2976, Test Linf Norm: 0.2219
# Epoch 295: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0056, Train Linf Norm: 0.2918, Test Linf Norm: 0.2182
# Epoch 296: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0053, Train Linf Norm: 0.3004, Test Linf Norm: 0.2010
# Epoch 297: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0057, Train Linf Norm: 0.2882, Test Linf Norm: 0.2189
# Epoch 298: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0057, Train Linf Norm: 0.2940, Test Linf Norm: 0.2169
# Epoch 299: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0070, Test L1 Norm: 0.0063, Train Linf Norm: 0.3093, Test Linf Norm: 0.2423
# Epoch 300: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0061, Train Linf Norm: 0.3135, Test Linf Norm: 0.2352
# Epoch 301: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2233
# Epoch 302: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0054, Train Linf Norm: 0.3012, Test Linf Norm: 0.2064
# Epoch 303: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0061, Train Linf Norm: 0.3052, Test Linf Norm: 0.2378
# Epoch 304: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0057, Train Linf Norm: 0.3048, Test Linf Norm: 0.2169
# Epoch 305: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0057, Train Linf Norm: 0.2926, Test Linf Norm: 0.2183
# Epoch 306: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2960, Test Linf Norm: 0.2228
# Epoch 307: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2967, Test Linf Norm: 0.2242
# Epoch 308: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2966, Test Linf Norm: 0.2236
# Epoch 309: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0058, Train Linf Norm: 0.2924, Test Linf Norm: 0.2233
# Epoch 310: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2934, Test Linf Norm: 0.2231
# Epoch 311: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0057, Train Linf Norm: 0.2944, Test Linf Norm: 0.2190
# Epoch 312: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2953, Test Linf Norm: 0.2221
# Epoch 313: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0059, Train Linf Norm: 0.2973, Test Linf Norm: 0.2267
# Epoch 314: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0066, Test L1 Norm: 0.0057, Train Linf Norm: 0.2930, Test Linf Norm: 0.2192
# Epoch 315: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0057, Train Linf Norm: 0.2971, Test Linf Norm: 0.2218
# Epoch 316: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2759, Test Linf Norm: 0.2261
# Epoch 317: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0057, Train Linf Norm: 0.2931, Test Linf Norm: 0.2211
# Epoch 318: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0057, Train Linf Norm: 0.2952, Test Linf Norm: 0.2180
# Epoch 319: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0056, Train Linf Norm: 0.2992, Test Linf Norm: 0.2141
# Epoch 320: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2970, Test Linf Norm: 0.2223
# Epoch 321: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2949, Test Linf Norm: 0.2238
# Epoch 322: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2959, Test Linf Norm: 0.2255
# Epoch 323: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0059, Train Linf Norm: 0.2957, Test Linf Norm: 0.2263
# Epoch 324: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0059, Train Linf Norm: 0.2980, Test Linf Norm: 0.2271
# Epoch 325: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2981, Test Linf Norm: 0.2250
# Epoch 326: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2263
# Epoch 327: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2974, Test Linf Norm: 0.2263
# Epoch 328: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2968, Test Linf Norm: 0.2248
# Epoch 329: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2958, Test Linf Norm: 0.2243
# Epoch 330: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2953, Test Linf Norm: 0.2256
# Epoch 331: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2967, Test Linf Norm: 0.2258
# Epoch 332: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2961, Test Linf Norm: 0.2248
# Epoch 333: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2944, Test Linf Norm: 0.2236
# Epoch 334: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2952, Test Linf Norm: 0.2244
# Epoch 335: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2930, Test Linf Norm: 0.2240
# Epoch 336: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2958, Test Linf Norm: 0.2241
# Epoch 337: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2937, Test Linf Norm: 0.2245
# Epoch 338: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2953, Test Linf Norm: 0.2244
# Epoch 339: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2955, Test Linf Norm: 0.2244
# Epoch 340: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2965, Test Linf Norm: 0.2244
# Epoch 341: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2970, Test Linf Norm: 0.2244
# Epoch 342: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2952, Test Linf Norm: 0.2244
# Epoch 343: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2964, Test Linf Norm: 0.2244
# Epoch 344: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2947, Test Linf Norm: 0.2244
# Epoch 345: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2950, Test Linf Norm: 0.2244
# Epoch 346: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2960, Test Linf Norm: 0.2245
# Epoch 347: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2975, Test Linf Norm: 0.2245
# Epoch 348: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2978, Test Linf Norm: 0.2245
# Epoch 349: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2972, Test Linf Norm: 0.2245
# Epoch 350: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2962, Test Linf Norm: 0.2245
# Epoch 351: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2961, Test Linf Norm: 0.2246
# Epoch 352: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2959, Test Linf Norm: 0.2245
# Epoch 353: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2950, Test Linf Norm: 0.2245
# Epoch 354: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2958, Test Linf Norm: 0.2245
# Epoch 355: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2974, Test Linf Norm: 0.2245
# Epoch 356: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2930, Test Linf Norm: 0.2246
# Epoch 357: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2928, Test Linf Norm: 0.2245
# Epoch 358: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2962, Test Linf Norm: 0.2245
# Epoch 359: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2245
# Epoch 360: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2960, Test Linf Norm: 0.2246
# Epoch 361: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2967, Test Linf Norm: 0.2246
# Epoch 362: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2964, Test Linf Norm: 0.2246
# Epoch 363: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2955, Test Linf Norm: 0.2246
# Epoch 364: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2966, Test Linf Norm: 0.2246
# Epoch 365: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2246
# Epoch 366: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2951, Test Linf Norm: 0.2246
# Epoch 367: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2934, Test Linf Norm: 0.2246
# Epoch 368: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2967, Test Linf Norm: 0.2247
# Epoch 369: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2967, Test Linf Norm: 0.2246
# Epoch 370: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2957, Test Linf Norm: 0.2246
# Epoch 371: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2964, Test Linf Norm: 0.2246
# Epoch 372: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2246
# Epoch 373: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2960, Test Linf Norm: 0.2247
# Epoch 374: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2953, Test Linf Norm: 0.2247
# Epoch 375: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2966, Test Linf Norm: 0.2247
# Epoch 376: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2966, Test Linf Norm: 0.2247
# Epoch 377: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2940, Test Linf Norm: 0.2247
# Epoch 378: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2945, Test Linf Norm: 0.2247
# Epoch 379: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2931, Test Linf Norm: 0.2247
# Epoch 380: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2976, Test Linf Norm: 0.2247
# Epoch 381: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2959, Test Linf Norm: 0.2247
# Epoch 382: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2948, Test Linf Norm: 0.2247
# Epoch 383: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2913, Test Linf Norm: 0.2247
# Epoch 384: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2963, Test Linf Norm: 0.2247
# Epoch 385: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2954, Test Linf Norm: 0.2247
# Epoch 386: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2973, Test Linf Norm: 0.2247
# Epoch 387: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2965, Test Linf Norm: 0.2247
# Epoch 388: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2813, Test Linf Norm: 0.2247
# Epoch 389: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2956, Test Linf Norm: 0.2247
# Epoch 390: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2940, Test Linf Norm: 0.2247
# Epoch 391: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2944, Test Linf Norm: 0.2246
# Epoch 392: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2946, Test Linf Norm: 0.2247
# Epoch 393: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2969, Test Linf Norm: 0.2247
# Epoch 394: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2960, Test Linf Norm: 0.2247
# Epoch 395: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2966, Test Linf Norm: 0.2246
# Epoch 396: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2958, Test Linf Norm: 0.2246
# Epoch 397: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2945, Test Linf Norm: 0.2246
# Epoch 398: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2959, Test Linf Norm: 0.2247
# Epoch 399: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2954, Test Linf Norm: 0.2247
# Epoch 400: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0067, Test L1 Norm: 0.0058, Train Linf Norm: 0.2974, Test Linf Norm: 0.2247

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    drive_folder = "/content/drive/My Drive/bsc/con2prim_restoration/0073" # change this to your desired folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
optimizer_loaded_state_dict = torch.load("optimizer.pth")
if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
scheduler_loaded_state_dict = torch.load("scheduler.pth")
if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded
# Out:
# 55
# 400
# 'Huber'
# 'Adam'
# 'ReduceLROnPlateau'
# [172, 249]
# 2
# 'LeakyReLU'
# 'Identity'
# 0.0001468891993074274
# LeakyReLU(negative_slope=0.01)
# Identity()
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=172, bias=True)
#     (1): Linear(in_features=172, out_features=249, bias=True)
#     (2): Linear(in_features=249, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation',
#                LeakyReLU(negative_slope=0.01)),
#               ('output_activation', Identity()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=3, out_features=172, bias=True)
#                  (1): Linear(in_features=172, out_features=249, bias=True)
#                  (2): Linear(in_features=249, out_features=1, bias=True)
#                ))]),
#  'n_layers': 2,
#  'n_units': [172, 249]}
# SmoothL1Loss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1.4688919930742743e-09
#     maximize: False
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.0001468891993074274,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0,
#   'amsgrad': False,
#   'maximize': False,
#   'foreach': None,
#   'capturable': False,
#   'differentiable': False,
#   'fused': None},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#Adam.zero_grad',
#  'state': defaultdict(dict,
#              {Parameter containing:
#               tensor([[-0.2998, -0.4319,  0.5439],
#                       [ 0.5629, -0.0901,  0.4522],
#                       [ 0.1565, -0.4186,  0.5600],
#                       [ 0.2897, -0.1508, -0.0238],
#                       [ 0.2772,  0.3156, -0.0873],
#                       [ 0.3044, -0.5143, -0.2675],
#                       [-0.3185, -0.3033,  0.2705],
#                       [ 0.5440, -0.2043, -0.5360],
#                       [-0.2133, -0.0142, -0.4281],
#                       [ 0.5028, -0.1171, -0.5127],
#                       [-0.0226, -0.2806,  0.0448],
#                       [ 0.1825, -0.3443, -0.1991],
#                       [ 0.4354, -0.0597, -0.2317],
#                       [ 0.0254, -0.1802,  0.1985],
#                       [ 0.3486, -0.2960, -0.0128],
#                       [-0.4308,  0.1163,  0.2727],
#                       [ 0.4292, -0.0410, -0.1581],
#                       [-0.1393,  0.1391, -0.0611],
#                       [ 0.0163,  0.1881, -0.4177],
#                       [-0.5087,  0.2603,  0.3802],
#                       [ 0.1561,  0.5527, -0.0632],
#                       [-0.0942,  0.0131, -0.0606],
#                       [ 0.2875, -0.3379, -0.0114],
#                       [-0.3723, -0.1919, -0.1168],
#                       [-0.0996,  0.2440, -0.3734],
#                       [ 0.0837, -0.4004,  0.0194],
#                       [-0.2271, -0.4629, -0.4036],
#                       [-0.2831,  0.4782,  0.2875],
#                       [ 0.4705, -0.3909,  0.3464],
#                       [ 0.5051, -0.4063,  0.5469],
#                       [ 0.2351,  0.2874, -0.2469],
#                       [ 0.0030, -0.5380,  0.1464],
#                       [-0.4524, -0.3463, -0.3415],
#                       [ 0.4515, -0.3627, -0.4374],
#                       [ 0.3880, -0.4699,  0.0577],
#                       [-0.5640,  0.2130,  0.3658],
#                       [-0.5833,  0.1395,  0.2061],
#                       [-0.5277, -0.3988,  0.1057],
#                       [-0.2053, -0.3499, -0.0971],
#                       [-0.4363, -0.3756, -0.2766],
#                       [ 0.4712,  0.2021, -0.4159],
#                       [-0.0226,  0.0986,  0.0585],
#                       [ 0.1388,  0.0760, -0.4648],
#                       [-0.6500, -0.5271,  0.4240],
#                       [ 0.5517, -0.1768,  0.0780],
#                       [-0.1616,  0.3362,  0.1941],
#                       [ 0.4571,  0.1591,  0.5368],
#                       [ 0.5324,  0.0713, -0.3376],
#                       [ 0.0702, -0.3081, -0.3241],
#                       [ 0.1168,  0.0653, -0.1642],
#                       [ 0.1783, -0.5946,  0.1516],
#                       [ 0.0430,  0.3883,  0.1514],
#                       [ 0.2043, -0.1777, -0.0749],
#                       [-0.3739,  0.5387,  0.2247],
#                       [ 0.0665,  0.4085, -0.4253],
#                       [ 0.0028,  0.1469,  0.5331],
#                       [-0.4612, -0.3700, -0.2387],
#                       [-0.5275,  0.0598, -0.2187],
#                       [-0.1748, -0.1243, -0.1172],
#                       [-0.2971,  0.0758,  0.3523],
#                       [-0.1606, -0.4476,  0.1844],
#                       [-0.1193, -0.0970,  0.4194],
#                       [-0.3446, -0.1425,  0.4445],
#                       [-0.4435,  0.5486, -0.0128],
#                       [ 0.2371, -0.3152,  0.2936],
#                       [-0.4925,  0.0667, -0.2939],
#                       [-0.4480,  0.4477, -0.3292],
#                       [ 0.4694, -0.1675, -0.2859],
#                       [ 0.1576, -0.0564,  0.4544],
#                       [ 0.2085, -0.5056,  0.5278],
#                       [ 0.4151, -0.4460,  0.3739],
#                       [-0.2305, -0.2822,  0.1268],
#                       [-0.1698,  0.2971, -0.2058],
#                       [ 0.1101, -0.5753,  0.1461],
#                       [-0.2142, -0.1263, -0.2282],
#                       [-0.2923,  0.4319, -0.3884],
#                       [ 0.3048,  0.5174, -0.3283],
#                       [ 0.3050, -0.1984,  0.5469],
#                       [-0.4373, -0.0693,  0.1853],
#                       [-0.0649,  0.1460,  0.4383],
#                       [-0.4325,  0.0728, -0.1188],
#                       [-0.4793,  0.4885, -0.3247],
#                       [-0.2846,  0.5476, -0.3434],
#                       [-0.4882, -0.1080,  0.3514],
#                       [ 0.2761,  0.3550,  0.0917],
#                       [-0.0736, -0.5533,  0.3211],
#                       [-0.4380, -0.1182,  0.2244],
#                       [-0.0581, -0.2849, -0.2128],
#                       [ 0.3453, -0.1953,  0.5252],
#                       [-0.2329,  0.5219, -0.3098],
#                       [ 0.4791,  0.4938, -0.3501],
#                       [ 0.4002,  0.1975,  0.4682],
#                       [ 0.2350, -0.2736,  0.5120],
#                       [-0.4529,  0.2886,  0.1396],
#                       [-0.4594, -0.0766,  0.2634],
#                       [-0.2091,  0.3726, -0.1573],
#                       [-0.0135, -0.2059, -0.1971],
#                       [-0.2721, -0.1724,  0.4119],
#                       [-0.4786,  0.1785,  0.4803],
#                       [-0.1224,  0.1576, -0.2817],
#                       [-0.1227,  0.2817,  0.3301],
#                       [-0.3852,  0.1467,  0.3342],
#                       [-0.1222, -0.0105,  0.0404],
#                       [-0.1280, -0.5021,  0.5671],
#                       [-0.1190, -0.4607,  0.4417],
#                       [-0.3015, -0.1087,  0.2815],
#                       [ 0.4170, -0.5860, -0.1596],
#                       [-0.0698, -0.1962, -0.2539],
#                       [ 0.3483, -0.2478,  0.4262],
#                       [ 0.3880,  0.0154,  0.4431],
#                       [-0.2632, -0.2808,  0.2500],
#                       [-0.3350,  0.0214, -0.1989],
#                       [-0.4282,  0.0596,  0.5069],
#                       [-0.3159, -0.4609, -0.5005],
#                       [-0.3374,  0.1077, -0.2972],
#                       [-0.5339, -0.2378,  0.4834],
#                       [ 0.3870,  0.0034,  0.2811],
#                       [ 0.2275, -0.1340,  0.5710],
#                       [ 0.3639, -0.3060,  0.2277],
#                       [-0.1902,  0.5570, -0.1624],
#                       [ 0.1102, -0.4569,  0.3420],
#                       [ 0.2528,  0.4176, -0.0534],
#                       [ 0.0138, -0.3898, -0.2768],
#                       [ 0.3394, -0.0463,  0.0850],
#                       [-0.5059, -0.0853,  0.2517],
#                       [ 0.0178,  0.0211, -0.0448],
#                       [ 0.4217, -0.1523,  0.3181],
#                       [-0.4495, -0.2519, -0.0525],
#                       [ 0.0195,  0.3398, -0.2857],
#                       [-0.1307,  0.0699, -0.0132],
#                       [ 0.1118, -0.3459,  0.4674],
#                       [ 0.2900,  0.1445, -0.2052],
#                       [-0.0138, -0.0457, -0.1061],
#                       [ 0.0211,  0.1487, -0.0734],
#                       [ 0.3079,  0.3757, -0.0992],
#                       [-0.4130,  0.3321,  0.4133],
#                       [ 0.3920,  0.4781, -0.4077],
#                       [-0.1037,  0.4439, -0.3723],
#                       [ 0.3934,  0.1494, -0.5076],
#                       [-0.3648, -0.2989, -0.4551],
#                       [ 0.1963, -0.1884,  0.2301],
#                       [ 0.4316, -0.0069,  0.4059],
#                       [-0.3532,  0.5345,  0.4388],
#                       [-0.1302, -0.5111,  0.0946],
#                       [-0.4586,  0.1153,  0.0150],
#                       [ 0.0553,  0.0037,  0.2610],
#                       [ 0.5321, -0.4045, -0.0648],
#                       [ 0.4812, -0.0529, -0.4357],
#                       [ 0.1205,  0.1505,  0.1166],
#                       [ 0.3696, -0.0382, -0.4384],
#                       [-0.5335, -0.1955,  0.4332],
#                       [-0.5691, -0.4341,  0.3570],
#                       [-0.0895, -0.4784,  0.1782],
#                       [ 0.1291, -0.4386,  0.0222],
#                       [-0.3313,  0.1067,  0.1252],
#                       [ 0.0595,  0.0756,  0.4180],
#                       [-0.0730,  0.1882,  0.4026],
#                       [-0.2212,  0.2195, -0.1525],
#                       [ 0.4667, -0.2018,  0.0997],
#                       [-0.1265, -0.4451,  0.1485],
#                       [ 0.3754, -0.2899,  0.1526],
#                       [ 0.0674,  0.0068, -0.4487],
#                       [ 0.0276,  0.3470, -0.0393],
#                       [ 0.4576, -0.3903, -0.0836],
#                       [ 0.3271,  0.0662, -0.1060],
#                       [-0.5527,  0.1998,  0.3347],
#                       [-0.0586,  0.0155, -0.1888],
#                       [ 0.2859,  0.0633,  0.4174],
#                       [ 0.0076,  0.3002,  0.3758],
#                       [-0.0512, -0.0870,  0.0779],
#                       [-0.0905, -0.0369,  0.1475],
#                       [ 0.0080, -0.0368,  0.1590]], device='cuda:0', requires_grad=True): {'step': tensor(582000.),
#                'exp_avg': tensor([[ 2.2519e-06,  8.1468e-06,  1.0359e-05],
#                        [-2.1012e-07,  5.6306e-06,  1.0502e-05],
#                        [ 1.4139e-06,  9.6478e-06,  1.5749e-05],
#                        [ 5.7057e-06,  8.0173e-07,  2.3146e-06],
#                        [ 1.7995e-06,  7.1616e-09, -2.0926e-06],
#                        [ 2.4558e-06, -2.3953e-08,  6.0665e-07],
#                        [ 5.2354e-07,  1.5965e-07,  9.4818e-07],
#                        [ 5.6738e-06, -3.1602e-07,  2.6656e-06],
#                        [ 3.2816e-07,  9.6606e-08,  5.8041e-08],
#                        [ 3.3447e-06, -5.3252e-07,  1.1525e-06],
#                        [-3.5460e-08, -1.4846e-08, -1.1783e-07],
#                        [ 5.2644e-06,  1.6987e-07,  1.7174e-06],
#                        [-2.0260e-06, -2.8987e-06, -2.9049e-06],
#                        [-2.5260e-06,  1.1796e-05,  2.0414e-05],
#                        [ 3.7790e-06,  3.4947e-08, -1.2491e-07],
#                        [ 3.0811e-06,  3.5560e-06,  5.2202e-06],
#                        [-4.8791e-07, -4.1399e-06, -4.6762e-06],
#                        [-1.1874e-06, -2.7572e-06, -3.8430e-06],
#                        [ 5.8555e-06,  5.1283e-06,  2.2987e-06],
#                        [ 2.2217e-06,  3.9915e-06,  5.1739e-06],
#                        [-8.0818e-08, -3.5622e-06, -7.1035e-06],
#                        [-7.0670e-07, -1.1256e-06, -1.2298e-06],
#                        [ 2.6132e-06,  9.7231e-07,  1.0457e-06],
#                        [-9.5923e-10,  1.0504e-08,  1.4585e-08],
#                        [-1.1095e-08, -7.4697e-08, -1.3512e-07],
#                        [ 6.2617e-07, -1.2448e-07, -9.1055e-07],
#                        [ 2.1822e-09, -1.4155e-08, -2.0778e-08],
#                        [ 1.8845e-06,  3.1920e-06,  4.8521e-06],
#                        [-1.0306e-06,  6.5417e-06,  1.5191e-05],
#                        [-1.8180e-06,  6.8392e-06,  1.4566e-05],
#                        [-2.9295e-06, -4.8011e-06, -4.9392e-06],
#                        [-7.6638e-07, -1.0707e-06, -4.9605e-06],
#                        [ 1.7882e-08,  4.8664e-09,  2.5353e-08],
#                        [ 5.6393e-06,  1.2936e-06,  2.6897e-06],
#                        [ 7.9360e-06,  3.8492e-06,  6.1746e-06],
#                        [ 1.5085e-06,  2.6838e-06,  3.1895e-06],
#                        [ 8.2375e-07,  3.5817e-07, -2.7281e-07],
#                        [-2.4502e-09,  1.6637e-08,  2.5669e-08],
#                        [ 3.9412e-08,  6.2693e-08,  4.5263e-08],
#                        [-1.4839e-08, -1.5666e-08, -4.0174e-08],
#                        [ 9.4997e-06,  1.3473e-05,  1.4969e-05],
#                        [-2.7976e-06, -3.7436e-06, -4.3379e-06],
#                        [ 3.8989e-06,  1.9877e-06,  1.0799e-06],
#                        [ 2.4402e-08, -3.3142e-08,  3.9742e-08],
#                        [-1.8400e-06,  1.9377e-06,  8.1760e-06],
#                        [-1.9380e-06, -3.3764e-06, -4.2605e-06],
#                        [-3.3485e-06, -2.1801e-06,  1.1189e-06],
#                        [-2.1159e-06, -3.5583e-06, -3.2994e-06],
#                        [ 8.1032e-07,  3.2704e-08,  1.1682e-08],
#                        [ 9.2311e-06,  8.6640e-07,  5.1235e-06],
#                        [ 6.7266e-06,  1.2516e-06,  3.6529e-07],
#                        [ 8.3836e-07,  3.6259e-06,  4.3107e-06],
#                        [ 4.5192e-06,  4.7878e-07,  1.9981e-06],
#                        [ 2.8442e-06,  3.5948e-06,  1.8792e-06],
#                        [ 7.9114e-06,  1.0235e-05,  7.2943e-06],
#                        [ 5.1537e-07,  5.2443e-06,  7.0145e-06],
#                        [ 7.7800e-10, -2.4644e-08, -4.0474e-08],
#                        [ 6.0354e-09, -3.2052e-08, -6.8112e-08],
#                        [-6.2857e-08,  3.2813e-08, -9.3629e-08],
#                        [ 3.5107e-06,  4.2093e-06,  8.3772e-06],
#                        [-3.7038e-07, -8.4017e-08, -5.3396e-07],
#                        [ 2.1036e-06,  7.9414e-06,  1.2367e-05],
#                        [ 5.2111e-06,  5.9761e-06,  1.8943e-05],
#                        [ 4.0469e-07,  1.4357e-06, -4.7557e-07],
#                        [-1.5783e-06,  8.8386e-06,  1.9461e-05],
#                        [-2.8254e-08, -6.0467e-08, -9.1122e-08],
#                        [-5.1977e-06, -2.5305e-05, -2.5047e-05],
#                        [ 2.5402e-06, -2.2104e-06, -2.8262e-07],
#                        [ 1.1558e-06,  7.1695e-06,  1.0638e-05],
#                        [ 6.1077e-06,  2.0447e-05,  2.6869e-05],
#                        [-2.3483e-06,  1.0560e-05,  2.2511e-05],
#                        [-2.6997e-08, -8.2647e-09,  1.2476e-08],
#                        [ 2.0021e-05,  3.0764e-05,  2.1830e-05],
#                        [ 4.3982e-06, -4.7078e-08, -2.1998e-06],
#                        [ 8.6921e-09, -4.0817e-08, -7.6742e-08],
#                        [ 1.9167e-09, -1.0830e-07, -1.7574e-07],
#                        [ 3.0262e-06, -1.9765e-06, -1.7328e-06],
#                        [ 2.7515e-07,  6.5168e-06,  1.0422e-05],
#                        [ 5.8768e-07,  2.0935e-06,  2.3036e-06],
#                        [-1.7910e-07,  1.2879e-06,  2.8716e-06],
#                        [ 3.3430e-08,  1.8079e-08,  2.3934e-09],
#                        [ 8.5473e-06,  6.3837e-06,  3.5808e-06],
#                        [ 1.1059e-05,  1.5482e-05,  9.1169e-06],
#                        [ 2.5622e-06,  2.7343e-06,  7.1404e-06],
#                        [-9.5915e-07, -5.3817e-07,  5.1611e-08],
#                        [ 1.0117e-06, -1.3939e-06, -4.9585e-06],
#                        [ 6.9181e-09,  3.4662e-08,  5.0989e-08],
#                        [-6.3769e-09, -2.8431e-08, -4.6046e-08],
#                        [ 1.1561e-06,  5.3428e-06,  1.1020e-05],
#                        [-3.3452e-06, -4.9808e-06, -9.7171e-06],
#                        [ 1.8908e-06, -3.1364e-07, -1.6049e-06],
#                        [ 2.0890e-07,  2.6701e-06,  4.6669e-06],
#                        [-6.7638e-07,  3.6036e-06,  7.9124e-06],
#                        [ 2.7646e-06,  3.4850e-06,  2.0358e-06],
#                        [ 4.1798e-06,  2.7660e-06,  8.4425e-06],
#                        [-4.7609e-06, -6.2674e-06, -1.0285e-05],
#                        [-2.5724e-07, -7.3835e-08, -1.1941e-07],
#                        [ 4.6754e-06,  9.4668e-06,  1.6911e-05],
#                        [ 4.3332e-06,  5.4606e-06,  1.0121e-05],
#                        [ 6.0926e-09, -6.5578e-08, -1.4172e-07],
#                        [ 3.5663e-06,  7.4828e-06,  1.0952e-05],
#                        [ 5.0418e-06,  6.3030e-06,  1.1438e-05],
#                        [ 1.7614e-06, -4.5164e-07,  2.0557e-06],
#                        [ 1.2974e-06,  1.1349e-05,  1.3435e-05],
#                        [-2.1030e-06, -8.9482e-07,  1.5482e-06],
#                        [ 5.0628e-06,  8.1359e-06,  1.8835e-05],
#                        [ 2.4648e-06,  1.4966e-08,  7.8374e-07],
#                        [ 2.3791e-08,  3.1046e-08,  1.5466e-08],
#                        [ 2.8396e-06,  1.1182e-05,  1.6979e-05],
#                        [-1.9063e-06, -2.1056e-06, -2.1858e-06],
#                        [ 4.8985e-06,  2.7504e-06,  8.5045e-06],
#                        [-4.9558e-09, -4.4644e-10,  1.2709e-09],
#                        [ 5.3232e-06,  7.7084e-06,  1.4999e-05],
#                        [ 4.5051e-09, -3.8471e-08, -6.6642e-08],
#                        [-1.2512e-08, -9.5753e-08, -1.3155e-07],
#                        [ 1.0813e-05,  2.3232e-05,  3.3749e-05],
#                        [-4.8490e-08,  1.2224e-06,  4.9351e-06],
#                        [ 3.3412e-07,  6.0910e-06,  1.1442e-05],
#                        [-2.0401e-06,  1.1283e-05,  2.0702e-05],
#                        [-1.1179e-05, -1.6176e-05, -2.0007e-05],
#                        [-1.2153e-06,  1.1593e-07,  1.3942e-06],
#                        [-1.3437e-06, -2.4270e-06, -1.7602e-06],
#                        [-2.0164e-08, -3.2607e-08, -1.4197e-08],
#                        [-1.1311e-06,  5.2446e-06,  9.7784e-06],
#                        [ 9.5366e-07,  4.8074e-06,  4.4908e-06],
#                        [-2.3813e-06, -4.0606e-06, -4.4216e-06],
#                        [-4.7975e-07,  3.6573e-06,  6.8407e-06],
#                        [-7.1481e-09, -2.2984e-08, -3.1069e-08],
#                        [-3.1531e-06, -4.6611e-06, -8.5387e-06],
#                        [ 1.3121e-05,  1.8025e-05,  1.3831e-05],
#                        [ 3.0435e-06,  1.3749e-05,  2.1075e-05],
#                        [-3.1823e-06, -4.7353e-06, -4.6740e-06],
#                        [ 1.6287e-07,  9.5636e-08,  1.1977e-08],
#                        [-3.8548e-07, -2.2883e-06, -2.2834e-06],
#                        [-2.8641e-06, -7.0798e-06, -1.0247e-05],
#                        [ 6.3240e-06,  7.1883e-06,  1.3014e-05],
#                        [ 4.8925e-06, -1.5070e-06, -1.8936e-06],
#                        [ 8.8120e-06,  1.3692e-05,  9.3636e-06],
#                        [ 7.9960e-06,  8.0527e-08,  3.9624e-06],
#                        [ 2.0730e-08,  3.0320e-08,  1.2638e-08],
#                        [ 1.1223e-06,  5.7526e-06,  1.0146e-05],
#                        [-5.9872e-07,  5.5090e-06,  8.8643e-06],
#                        [-5.6071e-07, -1.4547e-06, -3.3224e-06],
#                        [ 4.7288e-08, -1.8202e-08,  6.2665e-07],
#                        [-5.8318e-07, -2.7599e-06, -2.6744e-06],
#                        [-7.0393e-09,  3.1588e-06,  4.5543e-06],
#                        [ 6.0574e-06,  2.0989e-06,  2.6026e-06],
#                        [ 1.5164e-06,  6.5260e-07,  7.6407e-07],
#                        [-1.9458e-06,  4.6640e-07,  3.6880e-06],
#                        [ 2.2096e-06, -1.3077e-06,  5.4267e-07],
#                        [ 3.1039e-06,  3.5086e-06,  7.3572e-06],
#                        [-2.1463e-08, -5.9712e-09, -1.4238e-08],
#                        [-2.7107e-06, -5.6540e-07, -3.3992e-06],
#                        [ 5.2834e-06,  3.6928e-07,  8.8345e-07],
#                        [ 1.1337e-06,  1.5678e-06,  1.3174e-06],
#                        [-1.2910e-06,  4.4914e-06,  8.5188e-06],
#                        [-4.7551e-07,  6.8104e-06,  1.2666e-05],
#                        [-2.7312e-05, -1.0267e-04, -9.7926e-05],
#                        [-2.2464e-06,  6.8216e-06,  1.4412e-05],
#                        [-8.1480e-07, -2.3312e-07, -1.2380e-06],
#                        [-5.1972e-06, -1.1894e-05, -8.4905e-06],
#                        [-2.2535e-07, -1.7925e-07, -1.4781e-07],
#                        [ 5.7895e-07, -2.0932e-06, -4.0421e-06],
#                        [ 4.2371e-06,  1.2298e-06,  2.8936e-06],
#                        [-1.3453e-06, -2.9092e-06, -4.6224e-06],
#                        [ 3.1549e-06,  5.1392e-06,  9.1718e-06],
#                        [-3.6695e-09, -3.9859e-08, -7.6462e-08],
#                        [-1.3415e-06,  1.8496e-06,  5.2046e-06],
#                        [ 8.8148e-07,  5.5280e-06,  8.7608e-06],
#                        [ 4.0304e-07,  1.9890e-07,  7.3579e-07],
#                        [ 1.4427e-06,  4.5444e-07,  2.9445e-06],
#                        [-8.8697e-07, -9.2512e-07,  8.1776e-07]], device='cuda:0'),
#                'exp_avg_sq': tensor([[3.6646e-10, 1.7297e-09, 2.1688e-09],
#                        [6.0464e-09, 2.6220e-08, 2.5079e-08],
#                        [1.1593e-08, 5.7888e-08, 5.4459e-08],
#                        [1.5651e-09, 1.2642e-09, 1.7704e-09],
#                        [1.3306e-09, 6.2056e-09, 6.0319e-09],
#                        [8.5205e-11, 4.9380e-12, 1.2648e-11],
#                        [1.6310e-12, 5.9846e-13, 5.5781e-12],
#                        [1.0342e-09, 3.4706e-10, 2.7522e-10],
#                        [7.3449e-13, 1.2151e-12, 1.1781e-12],
#                        [3.7805e-10, 1.5172e-10, 1.0713e-10],
#                        [3.0644e-13, 9.5984e-15, 9.1208e-13],
#                        [1.5711e-10, 5.4295e-12, 1.6625e-11],
#                        [7.6286e-11, 1.1345e-10, 8.5222e-11],
#                        [1.3830e-08, 7.3748e-08, 7.4522e-08],
#                        [5.0534e-10, 3.1863e-10, 5.7333e-10],
#                        [2.8506e-10, 8.9695e-10, 1.0287e-09],
#                        [5.8385e-10, 1.0365e-09, 9.7552e-10],
#                        [4.7233e-10, 2.9362e-09, 2.5883e-09],
#                        [8.7603e-10, 3.9602e-10, 9.9320e-11],
#                        [1.9583e-10, 7.0403e-10, 7.3800e-10],
#                        [3.2868e-09, 1.3770e-08, 1.3322e-08],
#                        [2.0290e-11, 2.1809e-11, 1.9858e-11],
#                        [1.7909e-10, 2.8564e-11, 1.2549e-10],
#                        [7.1501e-15, 1.7210e-14, 1.8323e-14],
#                        [5.3772e-13, 2.3679e-12, 2.3320e-12],
#                        [2.4354e-11, 4.4462e-13, 1.7104e-11],
#                        [1.8533e-14, 4.9473e-14, 5.6530e-14],
#                        [2.4298e-10, 3.7628e-10, 5.8386e-10],
#                        [1.3262e-08, 6.3376e-08, 6.0969e-08],
#                        [1.1394e-08, 5.6109e-08, 5.3093e-08],
#                        [2.0023e-10, 7.5393e-10, 6.6258e-10],
#                        [2.9153e-10, 1.2242e-11, 3.9222e-10],
#                        [1.8151e-14, 4.2335e-14, 4.3027e-14],
#                        [3.5713e-10, 6.8346e-11, 7.3030e-11],
#                        [9.1902e-10, 2.6214e-10, 9.3679e-10],
#                        [6.3539e-11, 1.1500e-10, 1.7467e-10],
#                        [1.3407e-10, 9.2849e-10, 8.7660e-10],
#                        [6.6675e-14, 3.5675e-13, 3.2165e-13],
#                        [2.1046e-13, 5.2844e-14, 1.4894e-13],
#                        [6.7472e-14, 2.1262e-13, 2.3070e-13],
#                        [8.5580e-09, 2.1024e-08, 1.7294e-08],
#                        [5.9190e-11, 1.9623e-10, 2.1850e-10],
#                        [8.3655e-10, 2.7987e-10, 8.5176e-11],
#                        [7.8037e-14, 3.2235e-14, 2.6859e-13],
#                        [6.2250e-09, 2.7368e-08, 2.6964e-08],
#                        [5.1683e-10, 2.3594e-09, 2.2098e-09],
#                        [1.3737e-09, 6.7539e-09, 6.5017e-09],
#                        [2.7665e-10, 5.7673e-10, 5.1111e-10],
#                        [1.4004e-11, 2.6004e-13, 4.9588e-13],
#                        [4.0095e-09, 4.4700e-09, 2.4230e-09],
#                        [8.1749e-10, 7.7507e-11, 7.6024e-10],
#                        [1.6164e-10, 1.7401e-10, 2.9894e-10],
#                        [8.2820e-10, 2.0379e-10, 4.3090e-10],
#                        [9.6178e-10, 5.6860e-09, 5.1165e-09],
#                        [3.3010e-09, 2.2024e-08, 1.8682e-08],
#                        [1.1293e-09, 3.4935e-09, 3.8112e-09],
#                        [8.7406e-14, 3.2763e-13, 3.2969e-13],
#                        [3.4067e-13, 1.3988e-12, 1.3499e-12],
#                        [3.4426e-13, 6.7804e-13, 6.9478e-13],
#                        [9.1616e-10, 3.0428e-09, 3.4651e-09],
#                        [2.2485e-12, 8.3753e-14, 6.5884e-12],
#                        [4.6063e-09, 2.0983e-08, 2.0518e-08],
#                        [1.2089e-08, 6.3584e-08, 6.3806e-08],
#                        [1.5265e-09, 8.2570e-09, 7.7336e-09],
#                        [1.9012e-08, 9.2426e-08, 8.8101e-08],
#                        [6.5940e-14, 2.2884e-13, 2.0974e-13],
#                        [2.2088e-09, 3.0196e-08, 2.7135e-08],
#                        [9.9983e-10, 3.8492e-10, 4.6888e-10],
#                        [1.4796e-09, 4.6843e-09, 5.2404e-09],
#                        [2.2702e-08, 1.1091e-07, 1.0697e-07],
#                        [2.5926e-08, 1.2154e-07, 1.1596e-07],
#                        [1.3979e-13, 8.1342e-13, 7.5069e-13],
#                        [5.5726e-08, 3.6206e-07, 3.2093e-07],
#                        [5.1918e-10, 2.6685e-11, 5.2926e-10],
#                        [1.8292e-13, 7.9552e-13, 7.9475e-13],
#                        [1.3051e-12, 6.6562e-12, 6.2303e-12],
#                        [4.0237e-09, 1.9156e-08, 1.8137e-08],
#                        [3.5007e-09, 1.5516e-08, 1.4987e-08],
#                        [1.9372e-11, 2.6411e-10, 2.5793e-10],
#                        [7.1017e-11, 9.9997e-11, 1.4196e-10],
#                        [1.0290e-13, 5.2828e-13, 4.8867e-13],
#                        [8.2031e-09, 7.9654e-08, 7.1628e-08],
#                        [2.6506e-08, 1.5827e-07, 1.4351e-07],
#                        [4.9650e-10, 3.2275e-09, 3.3256e-09],
#                        [1.8626e-10, 3.4964e-10, 2.8103e-10],
#                        [2.9448e-10, 7.3809e-11, 4.9735e-10],
#                        [3.2608e-14, 8.1157e-14, 1.0167e-13],
#                        [8.2659e-14, 3.8315e-13, 3.8759e-13],
#                        [3.9588e-09, 1.6443e-08, 1.6068e-08],
#                        [2.4224e-08, 1.2845e-07, 1.1962e-07],
#                        [2.3026e-09, 1.1971e-08, 1.1042e-08],
#                        [1.3862e-09, 5.1399e-09, 5.0366e-09],
#                        [5.3852e-09, 2.3620e-08, 2.2585e-08],
#                        [6.4135e-10, 3.4313e-09, 3.1485e-09],
#                        [1.4424e-10, 3.7306e-10, 6.9841e-10],
#                        [3.7740e-09, 1.9867e-08, 1.8380e-08],
#                        [7.3052e-13, 1.3513e-12, 1.3848e-12],
#                        [7.8660e-09, 4.0257e-08, 3.9845e-08],
#                        [1.3447e-09, 4.7347e-09, 5.0938e-09],
#                        [7.0633e-13, 2.7576e-12, 2.7806e-12],
#                        [9.9574e-10, 2.7339e-09, 3.3644e-09],
#                        [2.1733e-09, 9.4399e-09, 9.6736e-09],
#                        [1.0569e-10, 2.6493e-10, 4.0708e-10],
#                        [6.3525e-10, 2.8239e-09, 3.2021e-09],
#                        [6.9666e-10, 1.1719e-09, 2.3371e-09],
#                        [4.3762e-09, 2.3781e-08, 2.5022e-08],
#                        [1.3047e-10, 1.0103e-11, 6.3696e-11],
#                        [2.4148e-13, 1.1874e-13, 1.5036e-13],
#                        [8.8170e-09, 3.8128e-08, 3.7336e-08],
#                        [2.3090e-10, 1.3632e-09, 1.2632e-09],
#                        [1.0772e-10, 3.9741e-11, 3.0023e-10],
#                        [6.0064e-15, 2.4270e-14, 2.3232e-14],
#                        [4.3197e-09, 1.8480e-08, 1.8863e-08],
#                        [1.7618e-13, 7.8861e-13, 7.9036e-13],
#                        [2.3134e-13, 1.0169e-12, 1.0216e-12],
#                        [6.9934e-09, 4.6875e-08, 4.9231e-08],
#                        [6.9067e-10, 2.5878e-09, 2.7285e-09],
#                        [5.8723e-09, 2.5325e-08, 2.4851e-08],
#                        [1.8045e-08, 8.7121e-08, 8.3188e-08],
#                        [1.0577e-08, 4.5492e-08, 4.4621e-08],
#                        [5.8741e-10, 1.0507e-09, 1.8503e-09],
#                        [3.4166e-10, 1.0010e-09, 1.0049e-09],
#                        [1.8210e-14, 6.7803e-14, 7.0725e-14],
#                        [3.7491e-09, 1.5523e-08, 1.5777e-08],
#                        [9.0244e-11, 9.9235e-10, 9.6638e-10],
#                        [5.4801e-11, 1.1730e-10, 1.3015e-10],
#                        [1.7951e-09, 8.9568e-09, 8.6935e-09],
#                        [3.7103e-14, 1.9303e-13, 1.8193e-13],
#                        [7.0427e-09, 3.9346e-08, 3.5304e-08],
#                        [8.4338e-09, 6.5253e-08, 6.0076e-08],
#                        [1.4308e-08, 6.7747e-08, 6.4695e-08],
#                        [1.5903e-10, 7.3152e-10, 7.1693e-10],
#                        [9.6314e-13, 2.9091e-13, 3.0436e-13],
#                        [2.1001e-10, 9.5991e-10, 8.8497e-10],
#                        [1.8968e-09, 6.8635e-09, 6.8880e-09],
#                        [2.9697e-09, 1.1787e-08, 1.1842e-08],
#                        [5.2149e-09, 2.4729e-08, 2.3426e-08],
#                        [9.1062e-09, 5.8785e-08, 5.0680e-08],
#                        [1.8392e-09, 2.3193e-09, 1.4176e-09],
#                        [1.0344e-14, 5.8635e-14, 5.6014e-14],
#                        [2.8773e-09, 1.3680e-08, 1.3116e-08],
#                        [2.4647e-09, 1.1244e-08, 1.0875e-08],
#                        [8.5262e-10, 4.5955e-09, 4.1953e-09],
#                        [1.1970e-11, 4.3578e-13, 2.2050e-11],
#                        [2.4948e-11, 4.0199e-10, 3.6894e-10],
#                        [7.5445e-10, 2.3273e-09, 2.3945e-09],
#                        [7.6835e-10, 3.5811e-10, 9.0020e-10],
#                        [6.1982e-11, 5.1836e-11, 3.5131e-11],
#                        [7.0537e-10, 2.5669e-09, 2.5955e-09],
#                        [4.6400e-10, 2.5691e-10, 1.5657e-10],
#                        [1.2512e-10, 5.6833e-10, 7.6389e-10],
#                        [1.7379e-13, 1.0398e-13, 4.7538e-13],
#                        [4.5609e-11, 2.3148e-12, 9.0446e-11],
#                        [3.5206e-10, 1.1836e-11, 2.6280e-10],
#                        [4.4279e-11, 3.6158e-10, 3.4054e-10],
#                        [2.5997e-09, 1.0630e-08, 1.0553e-08],
#                        [6.0251e-09, 2.4853e-08, 2.4533e-08],
#                        [2.4482e-08, 2.7593e-07, 2.4802e-07],
#                        [1.1076e-08, 5.5910e-08, 5.3247e-08],
#                        [2.5221e-11, 1.1815e-12, 5.4408e-11],
#                        [8.2293e-10, 2.8213e-09, 2.5131e-09],
#                        [3.4534e-11, 4.0253e-12, 1.2795e-12],
#                        [1.8092e-09, 7.9037e-09, 7.8590e-09],
#                        [4.6752e-10, 1.6997e-10, 3.0671e-10],
#                        [6.9505e-10, 2.8987e-09, 2.8639e-09],
#                        [1.3155e-09, 4.6750e-09, 5.1489e-09],
#                        [1.9989e-13, 8.2988e-13, 8.1068e-13],
#                        [2.9723e-09, 1.2375e-08, 1.1845e-08],
#                        [2.1704e-09, 6.7091e-09, 6.8883e-09],
#                        [4.3372e-13, 5.8505e-14, 1.2804e-12],
#                        [1.4073e-10, 4.0592e-10, 5.4206e-10],
#                        [4.9280e-10, 2.8268e-09, 2.6946e-09]], device='cuda:0')},
#               Parameter containing:
#               tensor([-2.2451e-01, -3.2155e-01,  4.1440e-01, -4.4994e-01,  4.9293e-01,
#                       -9.8513e-02, -4.5887e-01, -1.9143e-02,  4.0415e-01,  1.3321e-01,
#                       -3.2794e-01, -1.6638e-01, -3.5363e-01, -3.0757e-02,  4.4387e-01,
#                        3.6144e-01, -4.6658e-01,  4.1079e-01,  1.9378e-01,  3.7178e-01,
#                       -3.5973e-01,  7.2380e-01, -3.4947e-01, -7.8773e-03, -2.5767e-01,
#                       -3.5563e-01, -1.3169e-01,  5.2439e-01,  5.4178e-01, -1.6629e-01,
#                       -1.7093e-01,  8.4062e-02,  3.2197e-01,  8.2156e-02, -2.1926e-01,
#                        2.8959e-01,  4.0993e-01, -5.6458e-03,  2.6242e-01,  1.7632e-01,
#                       -2.5934e-01, -6.6266e-01,  1.7308e-01, -6.5116e-02, -4.7941e-01,
#                        3.4933e-01, -4.3404e-01,  5.5535e-01,  2.0954e-01, -1.8984e-01,
#                       -1.7546e-01, -4.8592e-01, -4.0133e-02, -1.0570e-01,  5.0783e-02,
#                        9.3589e-02,  1.6901e-04, -4.4388e-01,  3.0872e-01, -1.8306e-01,
#                       -5.1330e-01, -1.2012e-01, -2.2160e-01,  2.7642e-01,  8.6628e-02,
#                        4.5424e-01,  3.0607e-03, -4.4802e-01, -5.9644e-01, -9.2750e-02,
#                       -6.0267e-02, -9.2864e-02,  4.7706e-02, -1.9251e-01,  7.9747e-05,
#                       -2.7302e-01, -5.4409e-01, -5.1328e-01,  2.5231e-01,  3.0291e-01,
#                       -3.7160e-01,  5.6689e-02,  2.2817e-02,  3.4865e-01, -2.0916e-01,
#                        4.4923e-01, -1.1091e-01, -3.3912e-01, -2.6371e-01,  4.4890e-02,
#                       -2.0240e-01, -1.5056e-01, -3.7509e-01,  3.3254e-01,  3.3871e-01,
#                        5.0654e-01,  6.8075e-02,  3.6328e-01, -2.5000e-02, -4.8289e-01,
#                       -5.2287e-01,  2.6407e-01,  5.2527e-01,  4.8552e-01,  2.5692e-01,
#                        3.3677e-01, -1.3080e-01,  5.6182e-01, -5.2509e-01,  1.3203e-01,
#                        3.8970e-01,  4.3776e-02, -3.8959e-01, -2.1080e-01, -2.4674e-04,
#                        2.3858e-01,  1.8674e-01,  2.7993e-02,  3.4785e-01,  5.3587e-02,
#                       -4.9900e-02, -3.3917e-01, -3.6669e-01,  2.2411e-01,  3.4112e-01,
#                        4.9310e-01, -1.0719e-01,  1.1658e-01, -4.4799e-01,  1.7463e-01,
#                       -2.7412e-02,  3.1501e-01,  9.6626e-02, -4.7456e-02, -2.6837e-01,
#                       -1.2041e-01, -4.6174e-01, -3.2054e-01,  3.6107e-01, -3.7208e-01,
#                       -3.3077e-01,  5.4137e-01, -4.8606e-01,  4.5039e-01, -3.2612e-01,
#                       -1.1276e-01,  1.8683e-01,  3.8790e-01, -9.8524e-02,  2.8797e-01,
#                       -3.3349e-01,  2.1280e-01, -1.0242e-01, -7.3465e-02, -5.4830e-01,
#                       -3.4714e-01,  5.3367e-01,  7.9825e-03,  1.2812e-01,  6.3131e-02,
#                        2.0648e-01, -3.7564e-02, -4.4058e-01,  5.5595e-02,  2.9998e-01,
#                        5.4537e-01, -4.1203e-01, -4.4003e-01,  1.0777e-02, -3.8543e-01,
#                       -3.6952e-01, -6.1119e-01], device='cuda:0', requires_grad=True): {'step': tensor(582000.),
#                'exp_avg': tensor([ 1.8155e-07,  4.3692e-07,  1.1259e-07,  8.4661e-07,  1.5731e-07,
#                         1.1680e-07,  5.7688e-08,  1.2726e-07,  6.3308e-07,  2.8477e-07,
#                        -3.1878e-09,  6.2972e-07, -1.7080e-07, -2.6443e-07,  2.0394e-07,
#                         4.5907e-07,  1.3011e-08,  5.7253e-08,  1.6833e-06,  2.5108e-07,
#                        -2.8905e-07, -3.4210e-08,  1.3880e-07, -1.3534e-09, -1.9100e-09,
#                         9.2893e-08, -9.3890e-10,  2.7895e-07,  5.6136e-08,  2.2557e-07,
#                        -4.6160e-07,  5.1911e-08,  1.2770e-07,  6.6105e-07,  5.4577e-07,
#                         2.4171e-07,  3.2918e-07, -6.8728e-10,  2.9837e-07,  1.6735e-08,
#                        -3.4079e-08, -2.7112e-07,  1.0487e-06,  2.5138e-09,  3.7638e-08,
#                        -4.5171e-07, -2.4922e-07, -3.5102e-07,  7.1764e-08,  1.0727e-06,
#                         3.5480e-07,  1.2942e-07,  9.8286e-08,  3.0940e-07,  1.0766e-06,
#                         2.2607e-07, -2.2689e-09,  7.4391e-10,  4.1615e-08,  3.9956e-07,
#                        -3.4149e-08,  8.4886e-07,  7.9773e-07,  2.8109e-07,  6.4780e-08,
#                        -1.0069e-07, -3.4209e-07,  3.2220e-08,  1.3940e-07,  1.5520e-06,
#                         2.6087e-07, -2.9132e-09,  5.1546e-06,  5.7041e-07, -1.3851e-09,
#                        -1.2372e-09,  3.1877e-07,  5.6661e-07,  1.1318e-07,  2.1356e-09,
#                         1.4277e-09,  5.3655e-07,  3.0960e-06,  4.4034e-07, -1.0524e-07,
#                         1.5240e-07,  5.1140e-10, -4.6235e-10,  5.7401e-07,  1.1766e-06,
#                         1.7357e-07, -6.9745e-08,  3.4021e-07,  3.2913e-07,  3.5446e-07,
#                        -7.0938e-07, -1.3019e-07,  4.8545e-07,  4.8501e-07, -1.5532e-09,
#                         3.5950e-07,  5.5878e-07,  5.4652e-07,  3.8032e-07, -2.1356e-07,
#                         5.4996e-07,  9.6758e-08,  7.9276e-08,  9.4352e-07, -3.6589e-08,
#                         8.7344e-07, -1.9961e-08,  4.2149e-07, -1.6613e-09, -3.7554e-09,
#                         6.9298e-07, -1.3180e-07,  4.1537e-07,  2.5319e-07, -1.4253e-06,
#                        -2.6747e-07, -5.3697e-08, -3.0844e-09,  3.2479e-07, -7.3838e-08,
#                        -2.0624e-07, -6.6627e-08, -2.3282e-08, -8.6581e-07,  1.4626e-06,
#                         5.4968e-07, -2.3282e-07,  3.7282e-07, -3.4569e-09, -5.0106e-07,
#                         9.5274e-07,  4.8411e-07,  2.8162e-07,  9.5072e-07,  3.5123e-09,
#                         6.1724e-07, -1.8410e-07, -1.9215e-07, -1.5855e-07, -2.2574e-08,
#                         2.0710e-07,  1.9184e-07,  4.3219e-08, -1.5652e-07,  1.6724e-07,
#                         3.9298e-07, -1.9583e-07, -1.8466e-07,  6.7634e-07,  1.4592e-07,
#                         1.3716e-07,  5.7598e-08, -3.2391e-06, -2.7005e-07, -4.1462e-08,
#                        -4.1153e-07, -7.3930e-08,  1.1485e-07,  2.0301e-07, -3.7722e-07,
#                         5.4968e-07, -1.4298e-09,  1.0683e-07,  3.7926e-07,  4.3250e-08,
#                         5.4450e-08, -1.6633e-07], device='cuda:0'),
#                'exp_avg_sq': tensor([5.6171e-12, 9.0588e-11, 1.5846e-10, 2.3206e-11, 1.9837e-11, 2.0692e-12,
#                        2.4651e-14, 2.0033e-11, 1.7636e-12, 7.6661e-12, 4.0887e-15, 2.8481e-12,
#                        1.0339e-12, 1.9922e-10, 1.0973e-11, 4.2628e-12, 8.6527e-12, 6.5188e-12,
#                        3.5061e-11, 3.3192e-12, 4.8204e-11, 3.0936e-12, 3.1815e-12, 1.2622e-16,
#                        7.8310e-15, 3.7378e-13, 3.1127e-16, 4.8974e-12, 1.9253e-10, 1.6215e-10,
#                        3.2277e-12, 7.0731e-12, 1.9143e-13, 8.9418e-12, 1.9150e-11, 1.5765e-12,
#                        2.2100e-12, 8.8884e-16, 1.2280e-12, 1.8046e-14, 1.2298e-10, 7.8695e-13,
#                        1.9499e-11, 1.8507e-15, 8.6060e-11, 7.4781e-12, 1.9376e-11, 4.5898e-12,
#                        1.0405e-12, 5.3054e-11, 1.7320e-11, 3.2553e-12, 1.7324e-11, 1.3050e-11,
#                        4.3848e-11, 1.8218e-11, 1.4564e-15, 5.3203e-15, 3.6311e-13, 1.4324e-11,
#                        3.6943e-14, 6.6553e-11, 1.6192e-10, 2.1729e-11, 2.8162e-10, 2.2527e-13,
#                        3.0848e-11, 1.7462e-11, 2.4279e-11, 3.2133e-10, 3.7864e-10, 1.8203e-15,
#                        7.3274e-10, 1.0052e-11, 2.9724e-15, 1.8485e-14, 5.4469e-11, 5.2544e-11,
#                        1.8616e-12, 1.7826e-12, 1.5225e-15, 1.0151e-10, 3.4770e-10, 9.0185e-12,
#                        3.4554e-12, 7.4201e-12, 6.1034e-16, 1.1648e-15, 6.1946e-11, 3.3019e-10,
#                        3.4044e-11, 2.3157e-11, 7.9644e-11, 8.0406e-12, 4.0329e-12, 5.6321e-11,
#                        1.1823e-12, 1.1406e-10, 2.0746e-11, 1.0899e-14, 1.6585e-11, 3.4864e-11,
#                        4.6475e-12, 1.1377e-11, 1.3191e-11, 7.0628e-11, 2.6914e-12, 3.7060e-13,
#                        1.2578e-10, 3.5974e-12, 4.6424e-12, 7.3831e-14, 5.9363e-11, 2.7080e-15,
#                        3.4940e-15, 1.0385e-10, 1.2397e-11, 8.6982e-11, 2.6279e-10, 1.5914e-10,
#                        9.4214e-12, 4.9835e-12, 3.0591e-16, 5.7892e-11, 1.7804e-12, 1.5292e-12,
#                        2.5385e-11, 2.7076e-14, 8.2197e-11, 1.1420e-10, 2.0704e-10, 2.1354e-12,
#                        1.2750e-12, 2.8247e-12, 2.9334e-11, 4.3566e-11, 7.0376e-11, 1.0022e-10,
#                        3.5411e-11, 1.5701e-16, 3.9653e-11, 3.6773e-11, 1.1595e-11, 1.4600e-12,
#                        2.2822e-13, 1.2602e-11, 1.7431e-11, 1.0976e-12, 1.0791e-11, 1.3417e-11,
#                        1.8060e-12, 9.3372e-13, 9.0321e-13, 6.6428e-12, 5.5132e-13, 3.9744e-11,
#                        9.1696e-11, 3.0998e-10, 1.6402e-10, 2.0841e-12, 1.3356e-11, 8.1366e-13,
#                        2.5580e-11, 1.2119e-11, 1.1167e-11, 2.2400e-11, 3.2070e-15, 4.2659e-11,
#                        3.5083e-11, 5.6174e-15, 2.0047e-12, 5.9257e-12], device='cuda:0')},
#               Parameter containing:
#               tensor([[-0.0605, -0.0635, -0.0779,  ...,  0.0061, -0.0381,  0.0566],
#                       [-0.0405,  0.0148, -0.0688,  ...,  0.0212, -0.0350,  0.0575],
#                       [ 0.0428, -0.0730,  0.0161,  ...,  0.0287, -0.0066,  0.0640],
#                       ...,
#                       [ 0.0377,  0.0537,  0.0525,  ...,  0.0614, -0.0715, -0.0267],
#                       [ 0.0378, -0.0401,  0.0919,  ..., -0.0510,  0.0514,  0.0170],
#                       [ 0.0987, -0.0479,  0.0614,  ..., -0.0184, -0.0069,  0.0799]],
#                      device='cuda:0', requires_grad=True): {'step': tensor(582000.),
#                'exp_avg': tensor([[-2.6533e-08, -5.0814e-08, -4.1650e-08,  ..., -5.4844e-10,
#                         -1.3556e-08, -1.7111e-08],
#                        [-1.1278e-08,  1.0001e-08, -1.7319e-08,  ..., -1.7016e-10,
#                         -5.6891e-09, -7.0985e-09],
#                        [-3.2750e-08, -6.2721e-08, -5.1410e-08,  ..., -6.7695e-10,
#                         -1.6733e-08, -2.1121e-08],
#                        ...,
#                        [ 1.6235e-06,  4.7227e-06,  2.9957e-06,  ...,  2.8676e-08,
#                          8.3186e-07,  1.0543e-06],
#                        [ 1.3636e-06,  3.2100e-06,  2.1181e-06,  ...,  2.6955e-08,
#                          7.0431e-07,  9.0659e-07],
#                        [-2.6795e-06, -9.1823e-06, -4.5177e-06,  ..., -4.7306e-08,
#                         -1.1436e-06, -1.8891e-06]], device='cuda:0'),
#                'exp_avg_sq': tensor([[4.3006e-15, 7.9442e-13, 1.4035e-13,  ..., 2.4172e-18, 7.0969e-15,
#                         2.0311e-14],
#                        [7.7424e-16, 2.4555e-13, 5.7439e-14,  ..., 1.6721e-18, 1.2685e-15,
#                         3.6278e-15],
#                        [6.5523e-15, 1.2104e-12, 2.1383e-13,  ..., 3.6827e-18, 1.0813e-14,
#                         3.0945e-14],
#                        ...,
#                        [1.6351e-11, 3.0021e-09, 5.3345e-10,  ..., 9.0044e-15, 2.6996e-11,
#                         7.7213e-11],
#                        [1.1382e-11, 2.0670e-09, 3.6852e-10,  ..., 6.1854e-15, 1.8764e-11,
#                         5.3655e-11],
#                        [3.7417e-11, 2.1090e-09, 5.9809e-10,  ..., 2.0360e-14, 4.8329e-12,
#                         2.5150e-11]], device='cuda:0')},
#               Parameter containing:
#               tensor([ 0.0302,  0.0005,  0.0322,  0.0751,  0.0274,  0.0659, -0.0829, -0.0159,
#                       -0.0554, -0.0703, -0.0645,  0.0036,  0.0183,  0.0552,  0.0138, -0.0548,
#                        0.0391,  0.0916,  0.0636,  0.0415, -0.0521, -0.0690,  0.0444, -0.0433,
#                       -0.0751,  0.0334,  0.0327,  0.0191,  0.0585, -0.0343,  0.0019, -0.0604,
#                        0.0348, -0.0597,  0.0327, -0.0119, -0.0035,  0.0476, -0.0967,  0.0401,
#                        0.0391, -0.0373, -0.0708,  0.0833, -0.0421, -0.0469, -0.0341, -0.0631,
#                       -0.0103,  0.0054, -0.0615,  0.0345, -0.0087,  0.0332, -0.0192, -0.0025,
#                       -0.1045,  0.0356,  0.0431,  0.0178,  0.0704,  0.0723,  0.0157,  0.0105,
#                       -0.0831,  0.0754,  0.0166,  0.0327, -0.0465,  0.0656,  0.1202,  0.0037,
#                        0.0562, -0.0348,  0.0374, -0.0037,  0.0284,  0.0414, -0.0776,  0.0370,
#                       -0.0064,  0.0637,  0.0737,  0.0014,  0.0138,  0.0446, -0.0580,  0.0268,
#                       -0.0696, -0.0186, -0.0530,  0.0436,  0.0401, -0.0795, -0.0798, -0.0237,
#                        0.0471, -0.0259,  0.0023, -0.0810, -0.0292,  0.0777, -0.0154,  0.0014,
#                        0.0572, -0.0576,  0.0314, -0.0119, -0.0240,  0.0291, -0.0562, -0.0156,
#                       -0.0296, -0.0354,  0.0122, -0.0544, -0.0147, -0.0487, -0.0047,  0.0262,
#                       -0.0689, -0.0375, -0.0295,  0.0680,  0.0189,  0.0271, -0.0678,  0.0569,
#                        0.0299, -0.0107,  0.0586, -0.0186, -0.0186, -0.0257,  0.0557, -0.0832,
#                       -0.0445, -0.0311,  0.0174, -0.0007,  0.0190,  0.0430, -0.0053,  0.0167,
#                        0.0022,  0.0463,  0.0476, -0.0644, -0.0620,  0.0423, -0.0501, -0.0783,
#                       -0.0905,  0.0260,  0.0219,  0.0256,  0.0542,  0.0082,  0.0709,  0.0094,
#                       -0.0533, -0.0219,  0.0649, -0.0204, -0.0329, -0.0108,  0.0601,  0.0255,
#                       -0.0450,  0.0284, -0.0075, -0.0625,  0.0293, -0.0201,  0.0186, -0.0207,
#                        0.0030, -0.0800,  0.0091, -0.0318, -0.0021, -0.0370, -0.0076,  0.0530,
#                       -0.0366, -0.0005,  0.0354,  0.0721,  0.0243, -0.0912,  0.0645,  0.0742,
#                        0.0547,  0.0266, -0.0168,  0.0206,  0.0792,  0.0329, -0.0257,  0.0513,
#                       -0.0581, -0.0560,  0.0660, -0.0093, -0.0538,  0.0009, -0.0500,  0.0603,
#                        0.0132,  0.0591,  0.0559, -0.0250, -0.0428,  0.0481, -0.0262,  0.0648,
#                        0.0505,  0.0290,  0.0466,  0.0061,  0.0565, -0.0474, -0.0313, -0.0359,
#                        0.0455,  0.0582,  0.0700, -0.0604, -0.0269,  0.0173,  0.0468,  0.0515,
#                       -0.0340, -0.0572, -0.0174,  0.0058,  0.0586,  0.0331, -0.0180, -0.0779,
#                        0.0009, -0.0581,  0.0042,  0.0790, -0.0652,  0.0424, -0.0208, -0.0761,
#                        0.0223], device='cuda:0', requires_grad=True): {'step': tensor(582000.),
#                'exp_avg': tensor([-1.2408e-09, -2.1351e-08, -1.5315e-09,  3.5983e-07,  2.4341e-07,
#                        -2.7476e-08, -1.3891e-07,  9.9630e-08,  1.7423e-08, -1.4267e-09,
#                         2.0835e-07, -8.1096e-11,  2.8655e-07, -6.6546e-09, -4.9574e-10,
#                        -5.8499e-10,  1.9570e-07,  2.0886e-07, -2.3093e-11,  1.1957e-07,
#                        -1.1621e-09,  4.4938e-09, -3.7990e-07, -1.0163e-10, -3.2049e-07,
#                         2.1189e-07,  1.2084e-07, -7.3095e-10, -7.8767e-11, -6.5344e-07,
#                         1.2686e-07,  2.3690e-07,  6.4540e-08, -1.9193e-09, -7.1011e-07,
#                        -1.3201e-07,  9.9708e-08,  3.1689e-10, -1.2064e-06,  1.4868e-07,
#                         3.1889e-07,  3.1911e-07, -6.8271e-10,  3.9861e-07, -4.3726e-08,
#                         4.8902e-08,  1.4888e-07,  1.9047e-06,  1.9416e-07,  1.1012e-07,
#                         6.6239e-07, -6.4830e-08, -1.3150e-07, -1.6506e-09,  1.5968e-07,
#                         4.5549e-08, -8.3194e-08,  1.2450e-11, -1.7491e-09,  5.3997e-07,
# ...
#             [ 0.4354, -0.0597, -0.2317],
#             [ 0.0254, -0.1802,  0.1985],
#             [ 0.3486, -0.2960, -0.0128],
#             [-0.4308,  0.1163,  0.2727],
#             [ 0.4292, -0.0410, -0.1581],
#             [-0.1393,  0.1391, -0.0611],
#             [ 0.0163,  0.1881, -0.4177],
#             [-0.5087,  0.2603,  0.3802],
#             [ 0.1561,  0.5527, -0.0632],
#             [-0.0942,  0.0131, -0.0606],
#             [ 0.2875, -0.3379, -0.0114],
#             [-0.3723, -0.1919, -0.1168],
#             [-0.0996,  0.2440, -0.3734],
#             [ 0.0837, -0.4004,  0.0194],
#             [-0.2271, -0.4629, -0.4036],
#             [-0.2831,  0.4782,  0.2875],
#             [ 0.4705, -0.3909,  0.3464],
#             [ 0.5051, -0.4063,  0.5469],
#             [ 0.2351,  0.2874, -0.2469],
#             [ 0.0030, -0.5380,  0.1464],
#             [-0.4524, -0.3463, -0.3415],
#             [ 0.4515, -0.3627, -0.4374],
#             [ 0.3880, -0.4699,  0.0577],
#             [-0.5640,  0.2130,  0.3658],
#             [-0.5833,  0.1395,  0.2061],
#             [-0.5277, -0.3988,  0.1057],
#             [-0.2053, -0.3499, -0.0971],
#             [-0.4363, -0.3756, -0.2766],
#             [ 0.4712,  0.2021, -0.4159],
#             [-0.0226,  0.0986,  0.0585],
#             [ 0.1388,  0.0760, -0.4648],
#             [-0.6500, -0.5271,  0.4240],
#             [ 0.5517, -0.1768,  0.0780],
#             [-0.1616,  0.3362,  0.1941],
#             [ 0.4571,  0.1591,  0.5368],
#             [ 0.5324,  0.0713, -0.3376],
#             [ 0.0702, -0.3081, -0.3241],
#             [ 0.1168,  0.0653, -0.1642],
#             [ 0.1783, -0.5946,  0.1516],
#             [ 0.0430,  0.3883,  0.1514],
#             [ 0.2043, -0.1777, -0.0749],
#             [-0.3739,  0.5387,  0.2247],
#             [ 0.0665,  0.4085, -0.4253],
#             [ 0.0028,  0.1469,  0.5331],
#             [-0.4612, -0.3700, -0.2387],
#             [-0.5275,  0.0598, -0.2187],
#             [-0.1748, -0.1243, -0.1172],
#             [-0.2971,  0.0758,  0.3523],
#             [-0.1606, -0.4476,  0.1844],
#             [-0.1193, -0.0970,  0.4194],
#             [-0.3446, -0.1425,  0.4445],
#             [-0.4435,  0.5486, -0.0128],
#             [ 0.2371, -0.3152,  0.2936],
#             [-0.4925,  0.0667, -0.2939],
#             [-0.4480,  0.4477, -0.3292],
#             [ 0.4694, -0.1675, -0.2859],
#             [ 0.1576, -0.0564,  0.4544],
#             [ 0.2085, -0.5056,  0.5278],
#             [ 0.4151, -0.4460,  0.3739],
#             [-0.2305, -0.2822,  0.1268],
#             [-0.1698,  0.2971, -0.2058],
#             [ 0.1101, -0.5753,  0.1461],
#             [-0.2142, -0.1263, -0.2282],
#             [-0.2923,  0.4319, -0.3884],
#             [ 0.3048,  0.5174, -0.3283],
#             [ 0.3050, -0.1984,  0.5469],
#             [-0.4373, -0.0693,  0.1853],
#             [-0.0649,  0.1460,  0.4383],
#             [-0.4325,  0.0728, -0.1188],
#             [-0.4793,  0.4885, -0.3247],
#             [-0.2846,  0.5476, -0.3434],
#             [-0.4882, -0.1080,  0.3514],
#             [ 0.2761,  0.3550,  0.0917],
#             [-0.0736, -0.5533,  0.3211],
#             [-0.4380, -0.1182,  0.2244],
#             [-0.0581, -0.2849, -0.2128],
#             [ 0.3453, -0.1953,  0.5252],
#             [-0.2329,  0.5219, -0.3098],
#             [ 0.4791,  0.4938, -0.3501],
#             [ 0.4002,  0.1975,  0.4682],
#             [ 0.2350, -0.2736,  0.5120],
#             [-0.4529,  0.2886,  0.1396],
#             [-0.4594, -0.0766,  0.2634],
#             [-0.2091,  0.3726, -0.1573],
#             [-0.0135, -0.2059, -0.1971],
#             [-0.2721, -0.1724,  0.4119],
#             [-0.4786,  0.1785,  0.4803],
#             [-0.1224,  0.1576, -0.2817],
#             [-0.1227,  0.2817,  0.3301],
#             [-0.3852,  0.1467,  0.3342],
#             [-0.1222, -0.0105,  0.0404],
#             [-0.1280, -0.5021,  0.5671],
#             [-0.1190, -0.4607,  0.4417],
#             [-0.3015, -0.1087,  0.2815],
#             [ 0.4170, -0.5860, -0.1596],
#             [-0.0698, -0.1962, -0.2539],
#             [ 0.3483, -0.2478,  0.4262],
#             [ 0.3880,  0.0154,  0.4431],
#             [-0.2632, -0.2808,  0.2500],
#             [-0.3350,  0.0214, -0.1989],
#             [-0.4282,  0.0596,  0.5069],
#             [-0.3159, -0.4609, -0.5005],
#             [-0.3374,  0.1077, -0.2972],
#             [-0.5339, -0.2378,  0.4834],
#             [ 0.3870,  0.0034,  0.2811],
#             [ 0.2275, -0.1340,  0.5710],
#             [ 0.3639, -0.3060,  0.2277],
#             [-0.1902,  0.5570, -0.1624],
#             [ 0.1102, -0.4569,  0.3420],
#             [ 0.2528,  0.4176, -0.0534],
#             [ 0.0138, -0.3898, -0.2768],
#             [ 0.3394, -0.0463,  0.0850],
#             [-0.5059, -0.0853,  0.2517],
#             [ 0.0178,  0.0211, -0.0448],
#             [ 0.4217, -0.1523,  0.3181],
#             [-0.4495, -0.2519, -0.0525],
#             [ 0.0195,  0.3398, -0.2857],
#             [-0.1307,  0.0699, -0.0132],
#             [ 0.1118, -0.3459,  0.4674],
#             [ 0.2900,  0.1445, -0.2052],
#             [-0.0138, -0.0457, -0.1061],
#             [ 0.0211,  0.1487, -0.0734],
#             [ 0.3079,  0.3757, -0.0992],
#             [-0.4130,  0.3321,  0.4133],
#             [ 0.3920,  0.4781, -0.4077],
#             [-0.1037,  0.4439, -0.3723],
#             [ 0.3934,  0.1494, -0.5076],
#             [-0.3648, -0.2989, -0.4551],
#             [ 0.1963, -0.1884,  0.2301],
#             [ 0.4316, -0.0069,  0.4059],
#             [-0.3532,  0.5345,  0.4388],
#             [-0.1302, -0.5111,  0.0946],
#             [-0.4586,  0.1153,  0.0150],
#             [ 0.0553,  0.0037,  0.2610],
#             [ 0.5321, -0.4045, -0.0648],
#             [ 0.4812, -0.0529, -0.4357],
#             [ 0.1205,  0.1505,  0.1166],
#             [ 0.3696, -0.0382, -0.4384],
#             [-0.5335, -0.1955,  0.4332],
#             [-0.5691, -0.4341,  0.3570],
#             [-0.0895, -0.4784,  0.1782],
#             [ 0.1291, -0.4386,  0.0222],
#             [-0.3313,  0.1067,  0.1252],
#             [ 0.0595,  0.0756,  0.4180],
#             [-0.0730,  0.1882,  0.4026],
#             [-0.2212,  0.2195, -0.1525],
#             [ 0.4667, -0.2018,  0.0997],
#             [-0.1265, -0.4451,  0.1485],
#             [ 0.3754, -0.2899,  0.1526],
#             [ 0.0674,  0.0068, -0.4487],
#             [ 0.0276,  0.3470, -0.0393],
#             [ 0.4576, -0.3903, -0.0836],
#             [ 0.3271,  0.0662, -0.1060],
#             [-0.5527,  0.1998,  0.3347],
#             [-0.0586,  0.0155, -0.1888],
#             [ 0.2859,  0.0633,  0.4174],
#             [ 0.0076,  0.3002,  0.3758],
#             [-0.0512, -0.0870,  0.0779],
#             [-0.0905, -0.0369,  0.1475],
#             [ 0.0080, -0.0368,  0.1590]], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-2.2451e-01, -3.2155e-01,  4.1440e-01, -4.4994e-01,  4.9293e-01,
#             -9.8513e-02, -4.5887e-01, -1.9143e-02,  4.0415e-01,  1.3321e-01,
#             -3.2794e-01, -1.6638e-01, -3.5363e-01, -3.0757e-02,  4.4387e-01,
#              3.6144e-01, -4.6658e-01,  4.1079e-01,  1.9378e-01,  3.7178e-01,
#             -3.5973e-01,  7.2380e-01, -3.4947e-01, -7.8773e-03, -2.5767e-01,
#             -3.5563e-01, -1.3169e-01,  5.2439e-01,  5.4178e-01, -1.6629e-01,
#             -1.7093e-01,  8.4062e-02,  3.2197e-01,  8.2156e-02, -2.1926e-01,
#              2.8959e-01,  4.0993e-01, -5.6458e-03,  2.6242e-01,  1.7632e-01,
#             -2.5934e-01, -6.6266e-01,  1.7308e-01, -6.5116e-02, -4.7941e-01,
#              3.4933e-01, -4.3404e-01,  5.5535e-01,  2.0954e-01, -1.8984e-01,
#             -1.7546e-01, -4.8592e-01, -4.0133e-02, -1.0570e-01,  5.0783e-02,
#              9.3589e-02,  1.6901e-04, -4.4388e-01,  3.0872e-01, -1.8306e-01,
#             -5.1330e-01, -1.2012e-01, -2.2160e-01,  2.7642e-01,  8.6628e-02,
#              4.5424e-01,  3.0607e-03, -4.4802e-01, -5.9644e-01, -9.2750e-02,
#             -6.0267e-02, -9.2864e-02,  4.7706e-02, -1.9251e-01,  7.9747e-05,
#             -2.7302e-01, -5.4409e-01, -5.1328e-01,  2.5231e-01,  3.0291e-01,
#             -3.7160e-01,  5.6689e-02,  2.2817e-02,  3.4865e-01, -2.0916e-01,
#              4.4923e-01, -1.1091e-01, -3.3912e-01, -2.6371e-01,  4.4890e-02,
#             -2.0240e-01, -1.5056e-01, -3.7509e-01,  3.3254e-01,  3.3871e-01,
#              5.0654e-01,  6.8075e-02,  3.6328e-01, -2.5000e-02, -4.8289e-01,
#             -5.2287e-01,  2.6407e-01,  5.2527e-01,  4.8552e-01,  2.5692e-01,
#              3.3677e-01, -1.3080e-01,  5.6182e-01, -5.2509e-01,  1.3203e-01,
#              3.8970e-01,  4.3776e-02, -3.8959e-01, -2.1080e-01, -2.4674e-04,
#              2.3858e-01,  1.8674e-01,  2.7993e-02,  3.4785e-01,  5.3587e-02,
#             -4.9900e-02, -3.3917e-01, -3.6669e-01,  2.2411e-01,  3.4112e-01,
#              4.9310e-01, -1.0719e-01,  1.1658e-01, -4.4799e-01,  1.7463e-01,
#             -2.7412e-02,  3.1501e-01,  9.6626e-02, -4.7456e-02, -2.6837e-01,
#             -1.2041e-01, -4.6174e-01, -3.2054e-01,  3.6107e-01, -3.7208e-01,
#             -3.3077e-01,  5.4137e-01, -4.8606e-01,  4.5039e-01, -3.2612e-01,
#             -1.1276e-01,  1.8683e-01,  3.8790e-01, -9.8524e-02,  2.8797e-01,
#             -3.3349e-01,  2.1280e-01, -1.0242e-01, -7.3465e-02, -5.4830e-01,
#             -3.4714e-01,  5.3367e-01,  7.9825e-03,  1.2812e-01,  6.3131e-02,
#              2.0648e-01, -3.7564e-02, -4.4058e-01,  5.5595e-02,  2.9998e-01,
#              5.4537e-01, -4.1203e-01, -4.4003e-01,  1.0777e-02, -3.8543e-01,
#             -3.6952e-01, -6.1119e-01], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0605, -0.0635, -0.0779,  ...,  0.0061, -0.0381,  0.0566],
#             [-0.0405,  0.0148, -0.0688,  ...,  0.0212, -0.0350,  0.0575],
#             [ 0.0428, -0.0730,  0.0161,  ...,  0.0287, -0.0066,  0.0640],
#             ...,
#             [ 0.0377,  0.0537,  0.0525,  ...,  0.0614, -0.0715, -0.0267],
#             [ 0.0378, -0.0401,  0.0919,  ..., -0.0510,  0.0514,  0.0170],
#             [ 0.0987, -0.0479,  0.0614,  ..., -0.0184, -0.0069,  0.0799]],
#            device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([ 0.0302,  0.0005,  0.0322,  0.0751,  0.0274,  0.0659, -0.0829, -0.0159,
#             -0.0554, -0.0703, -0.0645,  0.0036,  0.0183,  0.0552,  0.0138, -0.0548,
#              0.0391,  0.0916,  0.0636,  0.0415, -0.0521, -0.0690,  0.0444, -0.0433,
#             -0.0751,  0.0334,  0.0327,  0.0191,  0.0585, -0.0343,  0.0019, -0.0604,
#              0.0348, -0.0597,  0.0327, -0.0119, -0.0035,  0.0476, -0.0967,  0.0401,
#              0.0391, -0.0373, -0.0708,  0.0833, -0.0421, -0.0469, -0.0341, -0.0631,
#             -0.0103,  0.0054, -0.0615,  0.0345, -0.0087,  0.0332, -0.0192, -0.0025,
#             -0.1045,  0.0356,  0.0431,  0.0178,  0.0704,  0.0723,  0.0157,  0.0105,
#             -0.0831,  0.0754,  0.0166,  0.0327, -0.0465,  0.0656,  0.1202,  0.0037,
#              0.0562, -0.0348,  0.0374, -0.0037,  0.0284,  0.0414, -0.0776,  0.0370,
#             -0.0064,  0.0637,  0.0737,  0.0014,  0.0138,  0.0446, -0.0580,  0.0268,
#             -0.0696, -0.0186, -0.0530,  0.0436,  0.0401, -0.0795, -0.0798, -0.0237,
#              0.0471, -0.0259,  0.0023, -0.0810, -0.0292,  0.0777, -0.0154,  0.0014,
#              0.0572, -0.0576,  0.0314, -0.0119, -0.0240,  0.0291, -0.0562, -0.0156,
#             -0.0296, -0.0354,  0.0122, -0.0544, -0.0147, -0.0487, -0.0047,  0.0262,
#             -0.0689, -0.0375, -0.0295,  0.0680,  0.0189,  0.0271, -0.0678,  0.0569,
#              0.0299, -0.0107,  0.0586, -0.0186, -0.0186, -0.0257,  0.0557, -0.0832,
#             -0.0445, -0.0311,  0.0174, -0.0007,  0.0190,  0.0430, -0.0053,  0.0167,
#              0.0022,  0.0463,  0.0476, -0.0644, -0.0620,  0.0423, -0.0501, -0.0783,
#             -0.0905,  0.0260,  0.0219,  0.0256,  0.0542,  0.0082,  0.0709,  0.0094,
#             -0.0533, -0.0219,  0.0649, -0.0204, -0.0329, -0.0108,  0.0601,  0.0255,
#             -0.0450,  0.0284, -0.0075, -0.0625,  0.0293, -0.0201,  0.0186, -0.0207,
#              0.0030, -0.0800,  0.0091, -0.0318, -0.0021, -0.0370, -0.0076,  0.0530,
#             -0.0366, -0.0005,  0.0354,  0.0721,  0.0243, -0.0912,  0.0645,  0.0742,
#              0.0547,  0.0266, -0.0168,  0.0206,  0.0792,  0.0329, -0.0257,  0.0513,
#             -0.0581, -0.0560,  0.0660, -0.0093, -0.0538,  0.0009, -0.0500,  0.0603,
#              0.0132,  0.0591,  0.0559, -0.0250, -0.0428,  0.0481, -0.0262,  0.0648,
#              0.0505,  0.0290,  0.0466,  0.0061,  0.0565, -0.0474, -0.0313, -0.0359,
#              0.0455,  0.0582,  0.0700, -0.0604, -0.0269,  0.0173,  0.0468,  0.0515,
#             -0.0340, -0.0572, -0.0174,  0.0058,  0.0586,  0.0331, -0.0180, -0.0779,
#              0.0009, -0.0581,  0.0042,  0.0790, -0.0652,  0.0424, -0.0208, -0.0761,
#              0.0223], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([[-0.0405, -0.0171, -0.0500,  0.0228, -0.0165,  0.0202, -0.0270,  0.0325,
#               0.0488,  0.0030, -0.0244, -0.0026, -0.0273,  0.0027, -0.0162, -0.0191,
#               0.0639,  0.0429, -0.0008,  0.0064, -0.0380, -0.0020, -0.0154,  0.0040,
#              -0.0446, -0.0069,  0.0398, -0.0239, -0.0026, -0.0461, -0.0111,  0.0085,
#               0.0190, -0.0627, -0.0498, -0.0431,  0.0355, -0.0010, -0.0423, -0.0226,
#              -0.0174, -0.0363, -0.0223, -0.0219, -0.0109, -0.0131, -0.0350, -0.0508,
#              -0.0308, -0.0126,  0.0178, -0.0362, -0.0133, -0.0539,  0.0522, -0.0019,
#              -0.0086,  0.0004, -0.0571, -0.0501, -0.0019,  0.0476, -0.0577, -0.0222,
#              -0.0100,  0.0330, -0.0149, -0.0076,  0.0032, -0.0238,  0.0079, -0.0195,
#              -0.0206, -0.0369,  0.0282,  0.0107, -0.0143, -0.0147,  0.0004, -0.0241,
#              -0.0068,  0.0155,  0.0208,  0.0360,  0.0322, -0.0337,  0.0586,  0.0505,
#               0.0217, -0.0267,  0.0251, -0.0137,  0.0301, -0.0546,  0.0013,  0.0206,
#               0.0125, -0.0228,  0.0219, -0.0020,  0.0300,  0.0207,  0.0518, -0.0159,
#               0.0146,  0.0014,  0.0036,  0.0056, -0.0222,  0.0460, -0.0515, -0.0348,
#               0.0229, -0.0370,  0.0181,  0.0527, -0.0239, -0.0343,  0.0081, -0.0398,
#               0.0119, -0.0152, -0.0139, -0.0050, -0.0283, -0.0270, -0.0148,  0.0415,
#              -0.0357,  0.0005, -0.0139, -0.0035, -0.1074,  0.0491,  0.0105,  0.0176,
#               0.0460,  0.0068, -0.0091,  0.0267,  0.0150,  0.0526, -0.0010,  0.0423,
#              -0.0313, -0.0016,  0.0092, -0.0110, -0.0211,  0.0361,  0.0467, -0.0302,
#              -0.0212, -0.0166, -0.0671,  0.0069,  0.0311, -0.0040,  0.0026,  0.0411,
#              -0.0013,  0.0509, -0.0222, -0.0147, -0.0043, -0.0446,  0.0243, -0.0055,
#               0.0532, -0.0472, -0.0153, -0.0049, -0.0253,  0.0123, -0.0225, -0.0087,
#               0.0298,  0.0018,  0.0025,  0.0340,  0.0211, -0.0468,  0.0369,  0.0008,
#              -0.0138,  0.0045, -0.0140,  0.0094,  0.0095,  0.0083, -0.0206,  0.0173,
#              -0.0423,  0.0413, -0.0331,  0.0347,  0.0361, -0.0418, -0.0381,  0.0247,
#              -0.0086,  0.0103,  0.0331,  0.0345,  0.0310,  0.0331,  0.0382,  0.0174,
#               0.0151, -0.0109,  0.0272,  0.0227, -0.0221,  0.0158, -0.0112, -0.0341,
#              -0.0280, -0.0219,  0.0311, -0.0452, -0.0039, -0.0343, -0.0317,  0.0446,
#              -0.0348, -0.0255,  0.0383,  0.0616, -0.0234, -0.0364,  0.0129, -0.0341,
#              -0.0500, -0.0035,  0.0165,  0.0205,  0.0472, -0.0591, -0.0253, -0.0491,
#               0.0223,  0.0184, -0.0122,  0.0284,  0.0227, -0.0093,  0.0250,  0.0209,
#              -0.0418]], device='cuda:0', requires_grad=True),
#     Parameter containing:
#     tensor([-0.0418], device='cuda:0', requires_grad=True)]}],
#  '_warned_capturable_if_run_uncaptured': True}
# {'factor': 0.1,
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 1.4688919930742743e-09
#      maximize: False
#      weight_decay: 0
#  ),
#  'min_lrs': [0],
#  'patience': 10,
#  'verbose': False,
#  'cooldown': 0,
#  'cooldown_counter': 0,
#  'mode': 'min',
#  'threshold': 0.0001,
#  'threshold_mode': 'rel',
#  'best': 1.54629475568413e-06,
#  'num_bad_epochs': 8,
#  'mode_worse': inf,
#  'eps': 1e-08,
#  'last_epoch': 400,
#  '_last_lr': [1.4688919930742743e-09]}

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.2998, -0.4319,  0.5439],
#         [ 0.5629, -0.0901,  0.4522],
#         [ 0.1565, -0.4186,  0.5600],
#         [ 0.2897, -0.1508, -0.0238],
#         [ 0.2772,  0.3156, -0.0873],
#         [ 0.3044, -0.5143, -0.2675],
#         [-0.3185, -0.3033,  0.2705],
#         [ 0.5440, -0.2043, -0.5360],
#         [-0.2133, -0.0142, -0.4281],
#         [ 0.5028, -0.1171, -0.5127],
#         [-0.0226, -0.2806,  0.0448],
#         [ 0.1825, -0.3443, -0.1991],
#         [ 0.4354, -0.0597, -0.2317],
#         [ 0.0254, -0.1802,  0.1985],
#         [ 0.3486, -0.2960, -0.0128],
#         [-0.4308,  0.1163,  0.2727],
#         [ 0.4292, -0.0410, -0.1581],
#         [-0.1393,  0.1391, -0.0611],
#         [ 0.0163,  0.1881, -0.4177],
#         [-0.5087,  0.2603,  0.3802],
#         [ 0.1561,  0.5527, -0.0632],
#         [-0.0942,  0.0131, -0.0606],
#         [ 0.2875, -0.3379, -0.0114],
#         [-0.3723, -0.1919, -0.1168],
#         [-0.0996,  0.2440, -0.3734],
#         [ 0.0837, -0.4004,  0.0194],
#         [-0.2271, -0.4629, -0.4036],
#         [-0.2831,  0.4782,  0.2875],
#         [ 0.4705, -0.3909,  0.3464],
#         [ 0.5051, -0.4063,  0.5469],
#         [ 0.2351,  0.2874, -0.2469],
#         [ 0.0030, -0.5380,  0.1464],
#         [-0.4524, -0.3463, -0.3415],
#         [ 0.4515, -0.3627, -0.4374],
#         [ 0.3880, -0.4699,  0.0577],
#         [-0.5640,  0.2130,  0.3658],
#         [-0.5833,  0.1395,  0.2061],
#         [-0.5277, -0.3988,  0.1057],
#         [-0.2053, -0.3499, -0.0971],
#         [-0.4363, -0.3756, -0.2766],
#         [ 0.4712,  0.2021, -0.4159],
#         [-0.0226,  0.0986,  0.0585],
#         [ 0.1388,  0.0760, -0.4648],
#         [-0.6500, -0.5271,  0.4240],
#         [ 0.5517, -0.1768,  0.0780],
#         [-0.1616,  0.3362,  0.1941],
#         [ 0.4571,  0.1591,  0.5368],
#         [ 0.5324,  0.0713, -0.3376],
#         [ 0.0702, -0.3081, -0.3241],
#         [ 0.1168,  0.0653, -0.1642],
#         [ 0.1783, -0.5946,  0.1516],
#         [ 0.0430,  0.3883,  0.1514],
#         [ 0.2043, -0.1777, -0.0749],
#         [-0.3739,  0.5387,  0.2247],
#         [ 0.0665,  0.4085, -0.4253],
#         [ 0.0028,  0.1469,  0.5331],
#         [-0.4612, -0.3700, -0.2387],
#         [-0.5275,  0.0598, -0.2187],
#         [-0.1748, -0.1243, -0.1172],
#         [-0.2971,  0.0758,  0.3523],
#         [-0.1606, -0.4476,  0.1844],
#         [-0.1193, -0.0970,  0.4194],
#         [-0.3446, -0.1425,  0.4445],
#         [-0.4435,  0.5486, -0.0128],
#         [ 0.2371, -0.3152,  0.2936],
#         [-0.4925,  0.0667, -0.2939],
#         [-0.4480,  0.4477, -0.3292],
#         [ 0.4694, -0.1675, -0.2859],
#         [ 0.1576, -0.0564,  0.4544],
#         [ 0.2085, -0.5056,  0.5278],
#         [ 0.4151, -0.4460,  0.3739],
#         [-0.2305, -0.2822,  0.1268],
#         [-0.1698,  0.2971, -0.2058],
#         [ 0.1101, -0.5753,  0.1461],
#         [-0.2142, -0.1263, -0.2282],
#         [-0.2923,  0.4319, -0.3884],
#         [ 0.3048,  0.5174, -0.3283],
#         [ 0.3050, -0.1984,  0.5469],
#         [-0.4373, -0.0693,  0.1853],
#         [-0.0649,  0.1460,  0.4383],
#         [-0.4325,  0.0728, -0.1188],
#         [-0.4793,  0.4885, -0.3247],
#         [-0.2846,  0.5476, -0.3434],
#         [-0.4882, -0.1080,  0.3514],
#         [ 0.2761,  0.3550,  0.0917],
#         [-0.0736, -0.5533,  0.3211],
#         [-0.4380, -0.1182,  0.2244],
#         [-0.0581, -0.2849, -0.2128],
#         [ 0.3453, -0.1953,  0.5252],
#         [-0.2329,  0.5219, -0.3098],
#         [ 0.4791,  0.4938, -0.3501],
#         [ 0.4002,  0.1975,  0.4682],
#         [ 0.2350, -0.2736,  0.5120],
#         [-0.4529,  0.2886,  0.1396],
#         [-0.4594, -0.0766,  0.2634],
#         [-0.2091,  0.3726, -0.1573],
#         [-0.0135, -0.2059, -0.1971],
#         [-0.2721, -0.1724,  0.4119],
#         [-0.4786,  0.1785,  0.4803],
#         [-0.1224,  0.1576, -0.2817],
#         [-0.1227,  0.2817,  0.3301],
#         [-0.3852,  0.1467,  0.3342],
#         [-0.1222, -0.0105,  0.0404],
#         [-0.1280, -0.5021,  0.5671],
#         [-0.1190, -0.4607,  0.4417],
#         [-0.3015, -0.1087,  0.2815],
#         [ 0.4170, -0.5860, -0.1596],
#         [-0.0698, -0.1962, -0.2539],
#         [ 0.3483, -0.2478,  0.4262],
#         [ 0.3880,  0.0154,  0.4431],
#         [-0.2632, -0.2808,  0.2500],
#         [-0.3350,  0.0214, -0.1989],
#         [-0.4282,  0.0596,  0.5069],
#         [-0.3159, -0.4609, -0.5005],
#         [-0.3374,  0.1077, -0.2972],
#         [-0.5339, -0.2378,  0.4834],
#         [ 0.3870,  0.0034,  0.2811],
#         [ 0.2275, -0.1340,  0.5710],
#         [ 0.3639, -0.3060,  0.2277],
#         [-0.1902,  0.5570, -0.1624],
#         [ 0.1102, -0.4569,  0.3420],
#         [ 0.2528,  0.4176, -0.0534],
#         [ 0.0138, -0.3898, -0.2768],
#         [ 0.3394, -0.0463,  0.0850],
#         [-0.5059, -0.0853,  0.2517],
#         [ 0.0178,  0.0211, -0.0448],
#         [ 0.4217, -0.1523,  0.3181],
#         [-0.4495, -0.2519, -0.0525],
#         [ 0.0195,  0.3398, -0.2857],
#         [-0.1307,  0.0699, -0.0132],
#         [ 0.1118, -0.3459,  0.4674],
#         [ 0.2900,  0.1445, -0.2052],
#         [-0.0138, -0.0457, -0.1061],
#         [ 0.0211,  0.1487, -0.0734],
#         [ 0.3079,  0.3757, -0.0992],
#         [-0.4130,  0.3321,  0.4133],
#         [ 0.3920,  0.4781, -0.4077],
#         [-0.1037,  0.4439, -0.3723],
#         [ 0.3934,  0.1494, -0.5076],
#         [-0.3648, -0.2989, -0.4551],
#         [ 0.1963, -0.1884,  0.2301],
#         [ 0.4316, -0.0069,  0.4059],
#         [-0.3532,  0.5345,  0.4388],
#         [-0.1302, -0.5111,  0.0946],
#         [-0.4586,  0.1153,  0.0150],
#         [ 0.0553,  0.0037,  0.2610],
#         [ 0.5321, -0.4045, -0.0648],
#         [ 0.4812, -0.0529, -0.4357],
#         [ 0.1205,  0.1505,  0.1166],
#         [ 0.3696, -0.0382, -0.4384],
#         [-0.5335, -0.1955,  0.4332],
#         [-0.5691, -0.4341,  0.3570],
#         [-0.0895, -0.4784,  0.1782],
#         [ 0.1291, -0.4386,  0.0222],
#         [-0.3313,  0.1067,  0.1252],
#         [ 0.0595,  0.0756,  0.4180],
#         [-0.0730,  0.1882,  0.4026],
#         [-0.2212,  0.2195, -0.1525],
#         [ 0.4667, -0.2018,  0.0997],
#         [-0.1265, -0.4451,  0.1485],
#         [ 0.3754, -0.2899,  0.1526],
#         [ 0.0674,  0.0068, -0.4487],
#         [ 0.0276,  0.3470, -0.0393],
#         [ 0.4576, -0.3903, -0.0836],
#         [ 0.3271,  0.0662, -0.1060],
#         [-0.5527,  0.1998,  0.3347],
#         [-0.0586,  0.0155, -0.1888],
#         [ 0.2859,  0.0633,  0.4174],
#         [ 0.0076,  0.3002,  0.3758],
#         [-0.0512, -0.0870,  0.0779],
#         [-0.0905, -0.0369,  0.1475],
#         [ 0.0080, -0.0368,  0.1590]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-2.2451e-01, -3.2155e-01,  4.1440e-01, -4.4994e-01,  4.9293e-01,
#         -9.8513e-02, -4.5887e-01, -1.9143e-02,  4.0415e-01,  1.3321e-01,
#         -3.2794e-01, -1.6638e-01, -3.5363e-01, -3.0757e-02,  4.4387e-01,
#          3.6144e-01, -4.6658e-01,  4.1079e-01,  1.9378e-01,  3.7178e-01,
#         -3.5973e-01,  7.2380e-01, -3.4947e-01, -7.8773e-03, -2.5767e-01,
#         -3.5563e-01, -1.3169e-01,  5.2439e-01,  5.4178e-01, -1.6629e-01,
#         -1.7093e-01,  8.4062e-02,  3.2197e-01,  8.2156e-02, -2.1926e-01,
#          2.8959e-01,  4.0993e-01, -5.6458e-03,  2.6242e-01,  1.7632e-01,
#         -2.5934e-01, -6.6266e-01,  1.7308e-01, -6.5116e-02, -4.7941e-01,
#          3.4933e-01, -4.3404e-01,  5.5535e-01,  2.0954e-01, -1.8984e-01,
#         -1.7546e-01, -4.8592e-01, -4.0133e-02, -1.0570e-01,  5.0783e-02,
#          9.3589e-02,  1.6901e-04, -4.4388e-01,  3.0872e-01, -1.8306e-01,
#         -5.1330e-01, -1.2012e-01, -2.2160e-01,  2.7642e-01,  8.6628e-02,
#          4.5424e-01,  3.0607e-03, -4.4802e-01, -5.9644e-01, -9.2750e-02,
#         -6.0267e-02, -9.2864e-02,  4.7706e-02, -1.9251e-01,  7.9747e-05,
#         -2.7302e-01, -5.4409e-01, -5.1328e-01,  2.5231e-01,  3.0291e-01,
#         -3.7160e-01,  5.6689e-02,  2.2817e-02,  3.4865e-01, -2.0916e-01,
#          4.4923e-01, -1.1091e-01, -3.3912e-01, -2.6371e-01,  4.4890e-02,
#         -2.0240e-01, -1.5056e-01, -3.7509e-01,  3.3254e-01,  3.3871e-01,
#          5.0654e-01,  6.8075e-02,  3.6328e-01, -2.5000e-02, -4.8289e-01,
#         -5.2287e-01,  2.6407e-01,  5.2527e-01,  4.8552e-01,  2.5692e-01,
#          3.3677e-01, -1.3080e-01,  5.6182e-01, -5.2509e-01,  1.3203e-01,
#          3.8970e-01,  4.3776e-02, -3.8959e-01, -2.1080e-01, -2.4674e-04,
#          2.3858e-01,  1.8674e-01,  2.7993e-02,  3.4785e-01,  5.3587e-02,
#         -4.9900e-02, -3.3917e-01, -3.6669e-01,  2.2411e-01,  3.4112e-01,
#          4.9310e-01, -1.0719e-01,  1.1658e-01, -4.4799e-01,  1.7463e-01,
#         -2.7412e-02,  3.1501e-01,  9.6626e-02, -4.7456e-02, -2.6837e-01,
#         -1.2041e-01, -4.6174e-01, -3.2054e-01,  3.6107e-01, -3.7208e-01,
#         -3.3077e-01,  5.4137e-01, -4.8606e-01,  4.5039e-01, -3.2612e-01,
#         -1.1276e-01,  1.8683e-01,  3.8790e-01, -9.8524e-02,  2.8797e-01,
#         -3.3349e-01,  2.1280e-01, -1.0242e-01, -7.3465e-02, -5.4830e-01,
#         -3.4714e-01,  5.3367e-01,  7.9825e-03,  1.2812e-01,  6.3131e-02,
#          2.0648e-01, -3.7564e-02, -4.4058e-01,  5.5595e-02,  2.9998e-01,
#          5.4537e-01, -4.1203e-01, -4.4003e-01,  1.0777e-02, -3.8543e-01,
#         -3.6952e-01, -6.1119e-01], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0605, -0.0635, -0.0779,  ...,  0.0061, -0.0381,  0.0566],
#         [-0.0405,  0.0148, -0.0688,  ...,  0.0212, -0.0350,  0.0575],
#         [ 0.0428, -0.0730,  0.0161,  ...,  0.0287, -0.0066,  0.0640],
#         ...,
#         [ 0.0377,  0.0537,  0.0525,  ...,  0.0614, -0.0715, -0.0267],
#         [ 0.0378, -0.0401,  0.0919,  ..., -0.0510,  0.0514,  0.0170],
#         [ 0.0987, -0.0479,  0.0614,  ..., -0.0184, -0.0069,  0.0799]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 0.0302,  0.0005,  0.0322,  0.0751,  0.0274,  0.0659, -0.0829, -0.0159,
#         -0.0554, -0.0703, -0.0645,  0.0036,  0.0183,  0.0552,  0.0138, -0.0548,
#          0.0391,  0.0916,  0.0636,  0.0415, -0.0521, -0.0690,  0.0444, -0.0433,
#         -0.0751,  0.0334,  0.0327,  0.0191,  0.0585, -0.0343,  0.0019, -0.0604,
#          0.0348, -0.0597,  0.0327, -0.0119, -0.0035,  0.0476, -0.0967,  0.0401,
#          0.0391, -0.0373, -0.0708,  0.0833, -0.0421, -0.0469, -0.0341, -0.0631,
#         -0.0103,  0.0054, -0.0615,  0.0345, -0.0087,  0.0332, -0.0192, -0.0025,
#         -0.1045,  0.0356,  0.0431,  0.0178,  0.0704,  0.0723,  0.0157,  0.0105,
#         -0.0831,  0.0754,  0.0166,  0.0327, -0.0465,  0.0656,  0.1202,  0.0037,
#          0.0562, -0.0348,  0.0374, -0.0037,  0.0284,  0.0414, -0.0776,  0.0370,
#         -0.0064,  0.0637,  0.0737,  0.0014,  0.0138,  0.0446, -0.0580,  0.0268,
#         -0.0696, -0.0186, -0.0530,  0.0436,  0.0401, -0.0795, -0.0798, -0.0237,
#          0.0471, -0.0259,  0.0023, -0.0810, -0.0292,  0.0777, -0.0154,  0.0014,
#          0.0572, -0.0576,  0.0314, -0.0119, -0.0240,  0.0291, -0.0562, -0.0156,
#         -0.0296, -0.0354,  0.0122, -0.0544, -0.0147, -0.0487, -0.0047,  0.0262,
#         -0.0689, -0.0375, -0.0295,  0.0680,  0.0189,  0.0271, -0.0678,  0.0569,
#          0.0299, -0.0107,  0.0586, -0.0186, -0.0186, -0.0257,  0.0557, -0.0832,
#         -0.0445, -0.0311,  0.0174, -0.0007,  0.0190,  0.0430, -0.0053,  0.0167,
#          0.0022,  0.0463,  0.0476, -0.0644, -0.0620,  0.0423, -0.0501, -0.0783,
#         -0.0905,  0.0260,  0.0219,  0.0256,  0.0542,  0.0082,  0.0709,  0.0094,
#         -0.0533, -0.0219,  0.0649, -0.0204, -0.0329, -0.0108,  0.0601,  0.0255,
#         -0.0450,  0.0284, -0.0075, -0.0625,  0.0293, -0.0201,  0.0186, -0.0207,
#          0.0030, -0.0800,  0.0091, -0.0318, -0.0021, -0.0370, -0.0076,  0.0530,
#         -0.0366, -0.0005,  0.0354,  0.0721,  0.0243, -0.0912,  0.0645,  0.0742,
#          0.0547,  0.0266, -0.0168,  0.0206,  0.0792,  0.0329, -0.0257,  0.0513,
#         -0.0581, -0.0560,  0.0660, -0.0093, -0.0538,  0.0009, -0.0500,  0.0603,
#          0.0132,  0.0591,  0.0559, -0.0250, -0.0428,  0.0481, -0.0262,  0.0648,
#          0.0505,  0.0290,  0.0466,  0.0061,  0.0565, -0.0474, -0.0313, -0.0359,
#          0.0455,  0.0582,  0.0700, -0.0604, -0.0269,  0.0173,  0.0468,  0.0515,
#         -0.0340, -0.0572, -0.0174,  0.0058,  0.0586,  0.0331, -0.0180, -0.0779,
#          0.0009, -0.0581,  0.0042,  0.0790, -0.0652,  0.0424, -0.0208, -0.0761,
#          0.0223], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0405, -0.0171, -0.0500,  0.0228, -0.0165,  0.0202, -0.0270,  0.0325,
#           0.0488,  0.0030, -0.0244, -0.0026, -0.0273,  0.0027, -0.0162, -0.0191,
#           0.0639,  0.0429, -0.0008,  0.0064, -0.0380, -0.0020, -0.0154,  0.0040,
#          -0.0446, -0.0069,  0.0398, -0.0239, -0.0026, -0.0461, -0.0111,  0.0085,
#           0.0190, -0.0627, -0.0498, -0.0431,  0.0355, -0.0010, -0.0423, -0.0226,
#          -0.0174, -0.0363, -0.0223, -0.0219, -0.0109, -0.0131, -0.0350, -0.0508,
#          -0.0308, -0.0126,  0.0178, -0.0362, -0.0133, -0.0539,  0.0522, -0.0019,
#          -0.0086,  0.0004, -0.0571, -0.0501, -0.0019,  0.0476, -0.0577, -0.0222,
#          -0.0100,  0.0330, -0.0149, -0.0076,  0.0032, -0.0238,  0.0079, -0.0195,
#          -0.0206, -0.0369,  0.0282,  0.0107, -0.0143, -0.0147,  0.0004, -0.0241,
#          -0.0068,  0.0155,  0.0208,  0.0360,  0.0322, -0.0337,  0.0586,  0.0505,
#           0.0217, -0.0267,  0.0251, -0.0137,  0.0301, -0.0546,  0.0013,  0.0206,
#           0.0125, -0.0228,  0.0219, -0.0020,  0.0300,  0.0207,  0.0518, -0.0159,
#           0.0146,  0.0014,  0.0036,  0.0056, -0.0222,  0.0460, -0.0515, -0.0348,
#           0.0229, -0.0370,  0.0181,  0.0527, -0.0239, -0.0343,  0.0081, -0.0398,
#           0.0119, -0.0152, -0.0139, -0.0050, -0.0283, -0.0270, -0.0148,  0.0415,
#          -0.0357,  0.0005, -0.0139, -0.0035, -0.1074,  0.0491,  0.0105,  0.0176,
#           0.0460,  0.0068, -0.0091,  0.0267,  0.0150,  0.0526, -0.0010,  0.0423,
#          -0.0313, -0.0016,  0.0092, -0.0110, -0.0211,  0.0361,  0.0467, -0.0302,
#          -0.0212, -0.0166, -0.0671,  0.0069,  0.0311, -0.0040,  0.0026,  0.0411,
#          -0.0013,  0.0509, -0.0222, -0.0147, -0.0043, -0.0446,  0.0243, -0.0055,
#           0.0532, -0.0472, -0.0153, -0.0049, -0.0253,  0.0123, -0.0225, -0.0087,
#           0.0298,  0.0018,  0.0025,  0.0340,  0.0211, -0.0468,  0.0369,  0.0008,
#          -0.0138,  0.0045, -0.0140,  0.0094,  0.0095,  0.0083, -0.0206,  0.0173,
#          -0.0423,  0.0413, -0.0331,  0.0347,  0.0361, -0.0418, -0.0381,  0.0247,
#          -0.0086,  0.0103,  0.0331,  0.0345,  0.0310,  0.0331,  0.0382,  0.0174,
#           0.0151, -0.0109,  0.0272,  0.0227, -0.0221,  0.0158, -0.0112, -0.0341,
#          -0.0280, -0.0219,  0.0311, -0.0452, -0.0039, -0.0343, -0.0317,  0.0446,
#          -0.0348, -0.0255,  0.0383,  0.0616, -0.0234, -0.0364,  0.0129, -0.0341,
#          -0.0500, -0.0035,  0.0165,  0.0205,  0.0472, -0.0591, -0.0253, -0.0491,
#           0.0223,  0.0184, -0.0122,  0.0284,  0.0227, -0.0093,  0.0250,  0.0209,
#          -0.0418]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0418], device='cuda:0', requires_grad=True)]

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.2998, -0.4319,  0.5439],
#         [ 0.5629, -0.0901,  0.4522],
#         [ 0.1565, -0.4186,  0.5600],
#         [ 0.2897, -0.1508, -0.0238],
#         [ 0.2772,  0.3156, -0.0873],
#         [ 0.3044, -0.5143, -0.2675],
#         [-0.3185, -0.3033,  0.2705],
#         [ 0.5440, -0.2043, -0.5360],
#         [-0.2133, -0.0142, -0.4281],
#         [ 0.5028, -0.1171, -0.5127],
#         [-0.0226, -0.2806,  0.0448],
#         [ 0.1825, -0.3443, -0.1991],
#         [ 0.4354, -0.0597, -0.2317],
#         [ 0.0254, -0.1802,  0.1985],
#         [ 0.3486, -0.2960, -0.0128],
#         [-0.4308,  0.1163,  0.2727],
#         [ 0.4292, -0.0410, -0.1581],
#         [-0.1393,  0.1391, -0.0611],
#         [ 0.0163,  0.1881, -0.4177],
#         [-0.5087,  0.2603,  0.3802],
#         [ 0.1561,  0.5527, -0.0632],
#         [-0.0942,  0.0131, -0.0606],
#         [ 0.2875, -0.3379, -0.0114],
#         [-0.3723, -0.1919, -0.1168],
#         [-0.0996,  0.2440, -0.3734],
#         [ 0.0837, -0.4004,  0.0194],
#         [-0.2271, -0.4629, -0.4036],
#         [-0.2831,  0.4782,  0.2875],
#         [ 0.4705, -0.3909,  0.3464],
#         [ 0.5051, -0.4063,  0.5469],
#         [ 0.2351,  0.2874, -0.2469],
#         [ 0.0030, -0.5380,  0.1464],
#         [-0.4524, -0.3463, -0.3415],
#         [ 0.4515, -0.3627, -0.4374],
#         [ 0.3880, -0.4699,  0.0577],
#         [-0.5640,  0.2130,  0.3658],
#         [-0.5833,  0.1395,  0.2061],
#         [-0.5277, -0.3988,  0.1057],
#         [-0.2053, -0.3499, -0.0971],
#         [-0.4363, -0.3756, -0.2766],
#         [ 0.4712,  0.2021, -0.4159],
#         [-0.0226,  0.0986,  0.0585],
#         [ 0.1388,  0.0760, -0.4648],
#         [-0.6500, -0.5271,  0.4240],
#         [ 0.5517, -0.1768,  0.0780],
#         [-0.1616,  0.3362,  0.1941],
#         [ 0.4571,  0.1591,  0.5368],
#         [ 0.5324,  0.0713, -0.3376],
#         [ 0.0702, -0.3081, -0.3241],
#         [ 0.1168,  0.0653, -0.1642],
#         [ 0.1783, -0.5946,  0.1516],
#         [ 0.0430,  0.3883,  0.1514],
#         [ 0.2043, -0.1777, -0.0749],
#         [-0.3739,  0.5387,  0.2247],
#         [ 0.0665,  0.4085, -0.4253],
#         [ 0.0028,  0.1469,  0.5331],
#         [-0.4612, -0.3700, -0.2387],
#         [-0.5275,  0.0598, -0.2187],
#         [-0.1748, -0.1243, -0.1172],
#         [-0.2971,  0.0758,  0.3523],
#         [-0.1606, -0.4476,  0.1844],
#         [-0.1193, -0.0970,  0.4194],
#         [-0.3446, -0.1425,  0.4445],
#         [-0.4435,  0.5486, -0.0128],
#         [ 0.2371, -0.3152,  0.2936],
#         [-0.4925,  0.0667, -0.2939],
#         [-0.4480,  0.4477, -0.3292],
#         [ 0.4694, -0.1675, -0.2859],
#         [ 0.1576, -0.0564,  0.4544],
#         [ 0.2085, -0.5056,  0.5278],
#         [ 0.4151, -0.4460,  0.3739],
#         [-0.2305, -0.2822,  0.1268],
#         [-0.1698,  0.2971, -0.2058],
#         [ 0.1101, -0.5753,  0.1461],
#         [-0.2142, -0.1263, -0.2282],
#         [-0.2923,  0.4319, -0.3884],
#         [ 0.3048,  0.5174, -0.3283],
#         [ 0.3050, -0.1984,  0.5469],
#         [-0.4373, -0.0693,  0.1853],
#         [-0.0649,  0.1460,  0.4383],
#         [-0.4325,  0.0728, -0.1188],
#         [-0.4793,  0.4885, -0.3247],
#         [-0.2846,  0.5476, -0.3434],
#         [-0.4882, -0.1080,  0.3514],
#         [ 0.2761,  0.3550,  0.0917],
#         [-0.0736, -0.5533,  0.3211],
#         [-0.4380, -0.1182,  0.2244],
#         [-0.0581, -0.2849, -0.2128],
#         [ 0.3453, -0.1953,  0.5252],
#         [-0.2329,  0.5219, -0.3098],
#         [ 0.4791,  0.4938, -0.3501],
#         [ 0.4002,  0.1975,  0.4682],
#         [ 0.2350, -0.2736,  0.5120],
#         [-0.4529,  0.2886,  0.1396],
#         [-0.4594, -0.0766,  0.2634],
#         [-0.2091,  0.3726, -0.1573],
#         [-0.0135, -0.2059, -0.1971],
#         [-0.2721, -0.1724,  0.4119],
#         [-0.4786,  0.1785,  0.4803],
#         [-0.1224,  0.1576, -0.2817],
#         [-0.1227,  0.2817,  0.3301],
#         [-0.3852,  0.1467,  0.3342],
#         [-0.1222, -0.0105,  0.0404],
#         [-0.1280, -0.5021,  0.5671],
#         [-0.1190, -0.4607,  0.4417],
#         [-0.3015, -0.1087,  0.2815],
#         [ 0.4170, -0.5860, -0.1596],
#         [-0.0698, -0.1962, -0.2539],
#         [ 0.3483, -0.2478,  0.4262],
#         [ 0.3880,  0.0154,  0.4431],
#         [-0.2632, -0.2808,  0.2500],
#         [-0.3350,  0.0214, -0.1989],
#         [-0.4282,  0.0596,  0.5069],
#         [-0.3159, -0.4609, -0.5005],
#         [-0.3374,  0.1077, -0.2972],
#         [-0.5339, -0.2378,  0.4834],
#         [ 0.3870,  0.0034,  0.2811],
#         [ 0.2275, -0.1340,  0.5710],
#         [ 0.3639, -0.3060,  0.2277],
#         [-0.1902,  0.5570, -0.1624],
#         [ 0.1102, -0.4569,  0.3420],
#         [ 0.2528,  0.4176, -0.0534],
#         [ 0.0138, -0.3898, -0.2768],
#         [ 0.3394, -0.0463,  0.0850],
#         [-0.5059, -0.0853,  0.2517],
#         [ 0.0178,  0.0211, -0.0448],
#         [ 0.4217, -0.1523,  0.3181],
#         [-0.4495, -0.2519, -0.0525],
#         [ 0.0195,  0.3398, -0.2857],
#         [-0.1307,  0.0699, -0.0132],
#         [ 0.1118, -0.3459,  0.4674],
#         [ 0.2900,  0.1445, -0.2052],
#         [-0.0138, -0.0457, -0.1061],
#         [ 0.0211,  0.1487, -0.0734],
#         [ 0.3079,  0.3757, -0.0992],
#         [-0.4130,  0.3321,  0.4133],
#         [ 0.3920,  0.4781, -0.4077],
#         [-0.1037,  0.4439, -0.3723],
#         [ 0.3934,  0.1494, -0.5076],
#         [-0.3648, -0.2989, -0.4551],
#         [ 0.1963, -0.1884,  0.2301],
#         [ 0.4316, -0.0069,  0.4059],
#         [-0.3532,  0.5345,  0.4388],
#         [-0.1302, -0.5111,  0.0946],
#         [-0.4586,  0.1153,  0.0150],
#         [ 0.0553,  0.0037,  0.2610],
#         [ 0.5321, -0.4045, -0.0648],
#         [ 0.4812, -0.0529, -0.4357],
#         [ 0.1205,  0.1505,  0.1166],
#         [ 0.3696, -0.0382, -0.4384],
#         [-0.5335, -0.1955,  0.4332],
#         [-0.5691, -0.4341,  0.3570],
#         [-0.0895, -0.4784,  0.1782],
#         [ 0.1291, -0.4386,  0.0222],
#         [-0.3313,  0.1067,  0.1252],
#         [ 0.0595,  0.0756,  0.4180],
#         [-0.0730,  0.1882,  0.4026],
#         [-0.2212,  0.2195, -0.1525],
#         [ 0.4667, -0.2018,  0.0997],
#         [-0.1265, -0.4451,  0.1485],
#         [ 0.3754, -0.2899,  0.1526],
#         [ 0.0674,  0.0068, -0.4487],
#         [ 0.0276,  0.3470, -0.0393],
#         [ 0.4576, -0.3903, -0.0836],
#         [ 0.3271,  0.0662, -0.1060],
#         [-0.5527,  0.1998,  0.3347],
#         [-0.0586,  0.0155, -0.1888],
#         [ 0.2859,  0.0633,  0.4174],
#         [ 0.0076,  0.3002,  0.3758],
#         [-0.0512, -0.0870,  0.0779],
#         [-0.0905, -0.0369,  0.1475],
#         [ 0.0080, -0.0368,  0.1590]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-2.2451e-01, -3.2155e-01,  4.1440e-01, -4.4994e-01,  4.9293e-01,
#         -9.8513e-02, -4.5887e-01, -1.9143e-02,  4.0415e-01,  1.3321e-01,
#         -3.2794e-01, -1.6638e-01, -3.5363e-01, -3.0757e-02,  4.4387e-01,
#          3.6144e-01, -4.6658e-01,  4.1079e-01,  1.9378e-01,  3.7178e-01,
#         -3.5973e-01,  7.2380e-01, -3.4947e-01, -7.8773e-03, -2.5767e-01,
#         -3.5563e-01, -1.3169e-01,  5.2439e-01,  5.4178e-01, -1.6629e-01,
#         -1.7093e-01,  8.4062e-02,  3.2197e-01,  8.2156e-02, -2.1926e-01,
#          2.8959e-01,  4.0993e-01, -5.6458e-03,  2.6242e-01,  1.7632e-01,
#         -2.5934e-01, -6.6266e-01,  1.7308e-01, -6.5116e-02, -4.7941e-01,
#          3.4933e-01, -4.3404e-01,  5.5535e-01,  2.0954e-01, -1.8984e-01,
#         -1.7546e-01, -4.8592e-01, -4.0133e-02, -1.0570e-01,  5.0783e-02,
#          9.3589e-02,  1.6901e-04, -4.4388e-01,  3.0872e-01, -1.8306e-01,
#         -5.1330e-01, -1.2012e-01, -2.2160e-01,  2.7642e-01,  8.6628e-02,
#          4.5424e-01,  3.0607e-03, -4.4802e-01, -5.9644e-01, -9.2750e-02,
#         -6.0267e-02, -9.2864e-02,  4.7706e-02, -1.9251e-01,  7.9747e-05,
#         -2.7302e-01, -5.4409e-01, -5.1328e-01,  2.5231e-01,  3.0291e-01,
#         -3.7160e-01,  5.6689e-02,  2.2817e-02,  3.4865e-01, -2.0916e-01,
#          4.4923e-01, -1.1091e-01, -3.3912e-01, -2.6371e-01,  4.4890e-02,
#         -2.0240e-01, -1.5056e-01, -3.7509e-01,  3.3254e-01,  3.3871e-01,
#          5.0654e-01,  6.8075e-02,  3.6328e-01, -2.5000e-02, -4.8289e-01,
#         -5.2287e-01,  2.6407e-01,  5.2527e-01,  4.8552e-01,  2.5692e-01,
#          3.3677e-01, -1.3080e-01,  5.6182e-01, -5.2509e-01,  1.3203e-01,
#          3.8970e-01,  4.3776e-02, -3.8959e-01, -2.1080e-01, -2.4674e-04,
#          2.3858e-01,  1.8674e-01,  2.7993e-02,  3.4785e-01,  5.3587e-02,
#         -4.9900e-02, -3.3917e-01, -3.6669e-01,  2.2411e-01,  3.4112e-01,
#          4.9310e-01, -1.0719e-01,  1.1658e-01, -4.4799e-01,  1.7463e-01,
#         -2.7412e-02,  3.1501e-01,  9.6626e-02, -4.7456e-02, -2.6837e-01,
#         -1.2041e-01, -4.6174e-01, -3.2054e-01,  3.6107e-01, -3.7208e-01,
#         -3.3077e-01,  5.4137e-01, -4.8606e-01,  4.5039e-01, -3.2612e-01,
#         -1.1276e-01,  1.8683e-01,  3.8790e-01, -9.8524e-02,  2.8797e-01,
#         -3.3349e-01,  2.1280e-01, -1.0242e-01, -7.3465e-02, -5.4830e-01,
#         -3.4714e-01,  5.3367e-01,  7.9825e-03,  1.2812e-01,  6.3131e-02,
#          2.0648e-01, -3.7564e-02, -4.4058e-01,  5.5595e-02,  2.9998e-01,
#          5.4537e-01, -4.1203e-01, -4.4003e-01,  1.0777e-02, -3.8543e-01,
#         -3.6952e-01, -6.1119e-01], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0605, -0.0635, -0.0779,  ...,  0.0061, -0.0381,  0.0566],
#         [-0.0405,  0.0148, -0.0688,  ...,  0.0212, -0.0350,  0.0575],
#         [ 0.0428, -0.0730,  0.0161,  ...,  0.0287, -0.0066,  0.0640],
#         ...,
#         [ 0.0377,  0.0537,  0.0525,  ...,  0.0614, -0.0715, -0.0267],
#         [ 0.0378, -0.0401,  0.0919,  ..., -0.0510,  0.0514,  0.0170],
#         [ 0.0987, -0.0479,  0.0614,  ..., -0.0184, -0.0069,  0.0799]],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([ 0.0302,  0.0005,  0.0322,  0.0751,  0.0274,  0.0659, -0.0829, -0.0159,
#         -0.0554, -0.0703, -0.0645,  0.0036,  0.0183,  0.0552,  0.0138, -0.0548,
#          0.0391,  0.0916,  0.0636,  0.0415, -0.0521, -0.0690,  0.0444, -0.0433,
#         -0.0751,  0.0334,  0.0327,  0.0191,  0.0585, -0.0343,  0.0019, -0.0604,
#          0.0348, -0.0597,  0.0327, -0.0119, -0.0035,  0.0476, -0.0967,  0.0401,
#          0.0391, -0.0373, -0.0708,  0.0833, -0.0421, -0.0469, -0.0341, -0.0631,
#         -0.0103,  0.0054, -0.0615,  0.0345, -0.0087,  0.0332, -0.0192, -0.0025,
#         -0.1045,  0.0356,  0.0431,  0.0178,  0.0704,  0.0723,  0.0157,  0.0105,
#         -0.0831,  0.0754,  0.0166,  0.0327, -0.0465,  0.0656,  0.1202,  0.0037,
#          0.0562, -0.0348,  0.0374, -0.0037,  0.0284,  0.0414, -0.0776,  0.0370,
#         -0.0064,  0.0637,  0.0737,  0.0014,  0.0138,  0.0446, -0.0580,  0.0268,
#         -0.0696, -0.0186, -0.0530,  0.0436,  0.0401, -0.0795, -0.0798, -0.0237,
#          0.0471, -0.0259,  0.0023, -0.0810, -0.0292,  0.0777, -0.0154,  0.0014,
#          0.0572, -0.0576,  0.0314, -0.0119, -0.0240,  0.0291, -0.0562, -0.0156,
#         -0.0296, -0.0354,  0.0122, -0.0544, -0.0147, -0.0487, -0.0047,  0.0262,
#         -0.0689, -0.0375, -0.0295,  0.0680,  0.0189,  0.0271, -0.0678,  0.0569,
#          0.0299, -0.0107,  0.0586, -0.0186, -0.0186, -0.0257,  0.0557, -0.0832,
#         -0.0445, -0.0311,  0.0174, -0.0007,  0.0190,  0.0430, -0.0053,  0.0167,
#          0.0022,  0.0463,  0.0476, -0.0644, -0.0620,  0.0423, -0.0501, -0.0783,
#         -0.0905,  0.0260,  0.0219,  0.0256,  0.0542,  0.0082,  0.0709,  0.0094,
#         -0.0533, -0.0219,  0.0649, -0.0204, -0.0329, -0.0108,  0.0601,  0.0255,
#         -0.0450,  0.0284, -0.0075, -0.0625,  0.0293, -0.0201,  0.0186, -0.0207,
#          0.0030, -0.0800,  0.0091, -0.0318, -0.0021, -0.0370, -0.0076,  0.0530,
#         -0.0366, -0.0005,  0.0354,  0.0721,  0.0243, -0.0912,  0.0645,  0.0742,
#          0.0547,  0.0266, -0.0168,  0.0206,  0.0792,  0.0329, -0.0257,  0.0513,
#         -0.0581, -0.0560,  0.0660, -0.0093, -0.0538,  0.0009, -0.0500,  0.0603,
#          0.0132,  0.0591,  0.0559, -0.0250, -0.0428,  0.0481, -0.0262,  0.0648,
#          0.0505,  0.0290,  0.0466,  0.0061,  0.0565, -0.0474, -0.0313, -0.0359,
#          0.0455,  0.0582,  0.0700, -0.0604, -0.0269,  0.0173,  0.0468,  0.0515,
#         -0.0340, -0.0572, -0.0174,  0.0058,  0.0586,  0.0331, -0.0180, -0.0779,
#          0.0009, -0.0581,  0.0042,  0.0790, -0.0652,  0.0424, -0.0208, -0.0761,
#          0.0223], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([[-0.0405, -0.0171, -0.0500,  0.0228, -0.0165,  0.0202, -0.0270,  0.0325,
#           0.0488,  0.0030, -0.0244, -0.0026, -0.0273,  0.0027, -0.0162, -0.0191,
#           0.0639,  0.0429, -0.0008,  0.0064, -0.0380, -0.0020, -0.0154,  0.0040,
#          -0.0446, -0.0069,  0.0398, -0.0239, -0.0026, -0.0461, -0.0111,  0.0085,
#           0.0190, -0.0627, -0.0498, -0.0431,  0.0355, -0.0010, -0.0423, -0.0226,
#          -0.0174, -0.0363, -0.0223, -0.0219, -0.0109, -0.0131, -0.0350, -0.0508,
#          -0.0308, -0.0126,  0.0178, -0.0362, -0.0133, -0.0539,  0.0522, -0.0019,
#          -0.0086,  0.0004, -0.0571, -0.0501, -0.0019,  0.0476, -0.0577, -0.0222,
#          -0.0100,  0.0330, -0.0149, -0.0076,  0.0032, -0.0238,  0.0079, -0.0195,
#          -0.0206, -0.0369,  0.0282,  0.0107, -0.0143, -0.0147,  0.0004, -0.0241,
#          -0.0068,  0.0155,  0.0208,  0.0360,  0.0322, -0.0337,  0.0586,  0.0505,
#           0.0217, -0.0267,  0.0251, -0.0137,  0.0301, -0.0546,  0.0013,  0.0206,
#           0.0125, -0.0228,  0.0219, -0.0020,  0.0300,  0.0207,  0.0518, -0.0159,
#           0.0146,  0.0014,  0.0036,  0.0056, -0.0222,  0.0460, -0.0515, -0.0348,
#           0.0229, -0.0370,  0.0181,  0.0527, -0.0239, -0.0343,  0.0081, -0.0398,
#           0.0119, -0.0152, -0.0139, -0.0050, -0.0283, -0.0270, -0.0148,  0.0415,
#          -0.0357,  0.0005, -0.0139, -0.0035, -0.1074,  0.0491,  0.0105,  0.0176,
#           0.0460,  0.0068, -0.0091,  0.0267,  0.0150,  0.0526, -0.0010,  0.0423,
#          -0.0313, -0.0016,  0.0092, -0.0110, -0.0211,  0.0361,  0.0467, -0.0302,
#          -0.0212, -0.0166, -0.0671,  0.0069,  0.0311, -0.0040,  0.0026,  0.0411,
#          -0.0013,  0.0509, -0.0222, -0.0147, -0.0043, -0.0446,  0.0243, -0.0055,
#           0.0532, -0.0472, -0.0153, -0.0049, -0.0253,  0.0123, -0.0225, -0.0087,
#           0.0298,  0.0018,  0.0025,  0.0340,  0.0211, -0.0468,  0.0369,  0.0008,
#          -0.0138,  0.0045, -0.0140,  0.0094,  0.0095,  0.0083, -0.0206,  0.0173,
#          -0.0423,  0.0413, -0.0331,  0.0347,  0.0361, -0.0418, -0.0381,  0.0247,
#          -0.0086,  0.0103,  0.0331,  0.0345,  0.0310,  0.0331,  0.0382,  0.0174,
#           0.0151, -0.0109,  0.0272,  0.0227, -0.0221,  0.0158, -0.0112, -0.0341,
#          -0.0280, -0.0219,  0.0311, -0.0452, -0.0039, -0.0343, -0.0317,  0.0446,
#          -0.0348, -0.0255,  0.0383,  0.0616, -0.0234, -0.0364,  0.0129, -0.0341,
#          -0.0500, -0.0035,  0.0165,  0.0205,  0.0472, -0.0591, -0.0253, -0.0491,
#           0.0223,  0.0184, -0.0122,  0.0284,  0.0227, -0.0093,  0.0250,  0.0209,
#          -0.0418]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([-0.0418], device='cuda:0', requires_grad=True)]

# %%
# Set the network to evaluation mode
net.eval()
# Out:
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=172, bias=True)
#     (1): Linear(in_features=172, out_features=249, bias=True)
#     (2): Linear(in_features=249, out_features=1, bias=True)
#   )
# )

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs
# Out:
# tensor([[ 8.4823,  1.2874,  3.8433],
#         [ 6.3628,  4.5830,  6.8709],
#         [ 9.5007, 10.5686, 14.5369],
#         [ 2.7702,  9.1947,  8.4208],
#         [ 8.1549,  8.1288,  4.1824],
#         [ 2.8599,  0.6266,  5.7706],
#         [ 9.4994, 24.8554, 24.3957],
#         [ 5.9511,  6.8335,  5.0241],
#         [ 1.0827,  0.7347,  1.1826],
#         [ 3.3039,  4.2094,  4.9122],
#         [ 5.1887, 10.3858,  9.6000],
#         [ 8.6661, 16.7210, 16.3864],
#         [ 6.5375,  1.9848,  7.9297],
#         [ 9.7648, 31.8522, 29.5890],
#         [12.9340, 11.8892,  5.2417],
#         [ 9.3644,  3.6599,  3.9022],
#         [ 3.9849, 10.0192,  8.5279],
#         [ 0.7702,  1.3431,  0.9888],
#         [ 9.5696,  0.1444,  2.6998],
#         [ 7.7714, 11.4869, 16.6507]], device='cuda:0')

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5098], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.9153], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.7086], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8213], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.5889], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.8275], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.5996], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.4982], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.6884], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.3386], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.0099], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.8077], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.1744], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([6.8886], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.4195], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.2008], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7623], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.1800], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8012], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([8.7729], device='cuda:0', grad_fn=<AddBackward0>)]

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Out:
# Net(
#   (hidden_activation): LeakyReLU(negative_slope=0.01)
#   (output_activation): Identity()
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=172, bias=True)
#     (1): Linear(in_features=172, out_features=249, bias=True)
#     (2): Linear(in_features=249, out_features=1, bias=True)
#   )
# )

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs
# Out:
# [tensor([2.5098], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.9153], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.7086], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8213], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.5889], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.8275], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([7.5996], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.4982], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.6884], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.3386], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([3.0099], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.8077], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([5.1744], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([6.8886], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.4195], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([2.2008], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.7623], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([0.1800], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([1.8012], device='cuda:0', grad_fn=<AddBackward0>),
#  tensor([8.7729], device='cuda:0', grad_fn=<AddBackward0>)]

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
# Out:
# tensor([[1.9373, 1.2759, 0.9697]], device='cuda:0')
# tensor([[2.0342, 2.2249, 4.1557]], device='cuda:0')
# tensor([[2.4319]], device='cuda:0', grad_fn=<AddmmBackward0>)
