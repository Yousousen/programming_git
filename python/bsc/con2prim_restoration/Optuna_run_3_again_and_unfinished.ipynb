# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.
#
# test

# %%
# %%script echo skipping
#
# !jupyter nbconvert pt4.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 10.8 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Installing collected packages: tensorboardX, Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1 tensorboardX-2.6

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.

# %%
N_TRIALS = 150 # Number of trials for hyperparameter optimization
OPTIMIZE = True # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..

# Hyperparameters when no hyperparameter optimization is performed. 
N_LAYERS_NO_OPT = 2
N_UNITS_NO_OPT = [600, 200]
HIDDEN_ACTIVATION_NAME_NO_OPT = "Sigmoid"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "MSE"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 6e-3
BATCH_SIZE_NO_OPT = 32
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(2) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %%
# Sampling the primitive variables using the sample_primitive_variables function
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# Generating the input and output data for train and test sets using the modified functions
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test) 

# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20)
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20)
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Checking the shapes of the data tensors
print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: torch.Size([80000, 3])
# Shape of y_train: torch.Size([80000])
# Shape of x_test: torch.Size([10000, 3])
# Shape of y_test: torch.Size([10000])

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 3)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 256) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            "output_activation", ["Linear", "ReLU"]
        ) 
        loss_name = trial.suggest_categorical(
            "loss", ["MSE", "MAE", "Huber", "LogCosh"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 32, 256)
        n_epochs = trial.suggest_int("n_epochs", 50, 100) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )
    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    # Creating the optimizer from its name
    if optimizer_name == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=lr)
    elif optimizer_name == "Adam":
        optimizer = optim.Adam(net.parameters(), lr=lr)
    elif optimizer_name == "RMSprop":
        optimizer = optim.RMSprop(net.parameters(), lr=lr)
    else:
        # Added creating the Adagrad optimizer
        optimizer = optim.Adagrad(net.parameters(), lr=lr)

    # Creating the learning rate scheduler from its name
    if scheduler_name == "StepLR":
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif scheduler_name == "ExponentialLR":
        scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    elif scheduler_name == "CosineAnnealingLR":
        # Added creating the CosineAnnealingLR scheduler
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
    elif scheduler_name == "ReduceLROnPlateau":
        # Added creating the ReduceLROnPlateau scheduler
        # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
        #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
        #)
        # Use Dieseldorst et al. settings and add to that a minimum lr.
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                )
    else:
        scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
# Out:
# [I 2023-05-13 12:00:11,974] A new study created in memory with name: no-name-7f1ee04a-2859-41d2-9a33-388fc223ee58
# <ipython-input-8-bd4fe74facdf>:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# Epoch 1: Train Loss: 0.6237, Test Loss: 0.3615, Train L1 Norm: 0.7700, Test L1 Norm: 0.5114, Train Linf Norm: 49.3403, Test Linf Norm: 27.9252
# Epoch 2: Train Loss: 0.2933, Test Loss: 0.2330, Train L1 Norm: 0.3218, Test L1 Norm: 0.3375, Train Linf Norm: 19.5764, Test Linf Norm: 20.5816
# Epoch 3: Train Loss: 0.2047, Test Loss: 0.1776, Train L1 Norm: 0.3655, Test L1 Norm: 0.2770, Train Linf Norm: 31.8587, Test Linf Norm: 19.3048
# Epoch 4: Train Loss: 0.1654, Test Loss: 0.1476, Train L1 Norm: 0.3230, Test L1 Norm: 0.3355, Train Linf Norm: 28.3411, Test Linf Norm: 25.0890
# Epoch 5: Train Loss: 0.1442, Test Loss: 0.1308, Train L1 Norm: 0.2854, Test L1 Norm: 0.2940, Train Linf Norm: 24.6293, Test Linf Norm: 21.8540
# Epoch 6: Train Loss: 0.1296, Test Loss: 0.1188, Train L1 Norm: 0.2321, Test L1 Norm: 0.2354, Train Linf Norm: 18.7855, Test Linf Norm: 16.9221
# Epoch 7: Train Loss: 0.1186, Test Loss: 0.1095, Train L1 Norm: 0.2055, Test L1 Norm: 0.2335, Train Linf Norm: 16.0442, Test Linf Norm: 16.7346
# Epoch 8: Train Loss: 0.1097, Test Loss: 0.1024, Train L1 Norm: 0.1932, Test L1 Norm: 0.2248, Train Linf Norm: 15.0604, Test Linf Norm: 15.6571
# Epoch 9: Train Loss: 0.1026, Test Loss: 0.0965, Train L1 Norm: 0.1725, Test L1 Norm: 0.2105, Train Linf Norm: 12.7754, Test Linf Norm: 14.7318
# Epoch 10: Train Loss: 0.0965, Test Loss: 0.0903, Train L1 Norm: 0.1611, Test L1 Norm: 0.2146, Train Linf Norm: 11.8816, Test Linf Norm: 15.0149
# Epoch 11: Train Loss: 0.0925, Test Loss: 0.0894, Train L1 Norm: 0.1553, Test L1 Norm: 0.2149, Train Linf Norm: 11.1801, Test Linf Norm: 15.3474
# Epoch 12: Train Loss: 0.0920, Test Loss: 0.0889, Train L1 Norm: 0.1542, Test L1 Norm: 0.2105, Train Linf Norm: 11.1965, Test Linf Norm: 14.8971
# Epoch 13: Train Loss: 0.0915, Test Loss: 0.0884, Train L1 Norm: 0.1515, Test L1 Norm: 0.2110, Train Linf Norm: 11.0379, Test Linf Norm: 14.9339
# Epoch 14: Train Loss: 0.0910, Test Loss: 0.0880, Train L1 Norm: 0.1513, Test L1 Norm: 0.2103, Train Linf Norm: 10.9823, Test Linf Norm: 14.9046
# Epoch 15: Train Loss: 0.0905, Test Loss: 0.0875, Train L1 Norm: 0.1509, Test L1 Norm: 0.2061, Train Linf Norm: 10.9497, Test Linf Norm: 14.4960
# Epoch 16: Train Loss: 0.0900, Test Loss: 0.0871, Train L1 Norm: 0.1499, Test L1 Norm: 0.2081, Train Linf Norm: 10.7786, Test Linf Norm: 14.6883
# Epoch 17: Train Loss: 0.0896, Test Loss: 0.0866, Train L1 Norm: 0.1481, Test L1 Norm: 0.2072, Train Linf Norm: 10.6452, Test Linf Norm: 14.6296
# Epoch 18: Train Loss: 0.0892, Test Loss: 0.0863, Train L1 Norm: 0.1483, Test L1 Norm: 0.2062, Train Linf Norm: 10.6058, Test Linf Norm: 14.6114
# Epoch 19: Train Loss: 0.0887, Test Loss: 0.0859, Train L1 Norm: 0.1474, Test L1 Norm: 0.2084, Train Linf Norm: 10.4668, Test Linf Norm: 14.8157
# Epoch 20: Train Loss: 0.0883, Test Loss: 0.0855, Train L1 Norm: 0.1474, Test L1 Norm: 0.2060, Train Linf Norm: 10.5973, Test Linf Norm: 14.5411
# Epoch 21: Train Loss: 0.0881, Test Loss: 0.0854, Train L1 Norm: 0.1460, Test L1 Norm: 0.2050, Train Linf Norm: 10.5122, Test Linf Norm: 14.4392
# Epoch 22: Train Loss: 0.0880, Test Loss: 0.0853, Train L1 Norm: 0.1463, Test L1 Norm: 0.2045, Train Linf Norm: 10.2993, Test Linf Norm: 14.3731
# Epoch 23: Train Loss: 0.0880, Test Loss: 0.0853, Train L1 Norm: 0.1460, Test L1 Norm: 0.2048, Train Linf Norm: 10.4031, Test Linf Norm: 14.4056
# Epoch 24: Train Loss: 0.0880, Test Loss: 0.0853, Train L1 Norm: 0.1463, Test L1 Norm: 0.2046, Train Linf Norm: 10.4103, Test Linf Norm: 14.3873
# Epoch 25: Train Loss: 0.0879, Test Loss: 0.0852, Train L1 Norm: 0.1464, Test L1 Norm: 0.2047, Train Linf Norm: 10.4186, Test Linf Norm: 14.3877
# Epoch 26: Train Loss: 0.0879, Test Loss: 0.0852, Train L1 Norm: 0.1461, Test L1 Norm: 0.2055, Train Linf Norm: 10.4845, Test Linf Norm: 14.4791
# Epoch 27: Train Loss: 0.0878, Test Loss: 0.0852, Train L1 Norm: 0.1459, Test L1 Norm: 0.2049, Train Linf Norm: 10.4510, Test Linf Norm: 14.4131
# Epoch 28: Train Loss: 0.0878, Test Loss: 0.0851, Train L1 Norm: 0.1459, Test L1 Norm: 0.2054, Train Linf Norm: 10.4510, Test Linf Norm: 14.4651
# Epoch 29: Train Loss: 0.0878, Test Loss: 0.0851, Train L1 Norm: 0.1460, Test L1 Norm: 0.2050, Train Linf Norm: 10.4694, Test Linf Norm: 14.4294
# Epoch 30: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1459, Test L1 Norm: 0.2047, Train Linf Norm: 10.4007, Test Linf Norm: 14.3894
# Epoch 31: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1457, Test L1 Norm: 0.2048, Train Linf Norm: 10.2623, Test Linf Norm: 14.4042
# Epoch 32: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3928, Test Linf Norm: 14.4095
# Epoch 33: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1459, Test L1 Norm: 0.2048, Train Linf Norm: 10.1420, Test Linf Norm: 14.4071
# Epoch 34: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1460, Test L1 Norm: 0.2048, Train Linf Norm: 10.2250, Test Linf Norm: 14.4047
# Epoch 35: Train Loss: 0.0877, Test Loss: 0.0851, Train L1 Norm: 0.1459, Test L1 Norm: 0.2048, Train Linf Norm: 10.3779, Test Linf Norm: 14.4056
# Epoch 36: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1459, Test L1 Norm: 0.2048, Train Linf Norm: 10.4033, Test Linf Norm: 14.4057
# Epoch 37: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2049, Train Linf Norm: 10.2638, Test Linf Norm: 14.4092
# Epoch 38: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1460, Test L1 Norm: 0.2048, Train Linf Norm: 10.4483, Test Linf Norm: 14.4058
# Epoch 39: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1459, Test L1 Norm: 0.2048, Train Linf Norm: 10.0373, Test Linf Norm: 14.4043
# Epoch 40: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1459, Test L1 Norm: 0.2048, Train Linf Norm: 10.3589, Test Linf Norm: 14.4015
# Epoch 41: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3467, Test Linf Norm: 14.4015
# Epoch 42: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3080, Test Linf Norm: 14.4014
# Epoch 43: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4341, Test Linf Norm: 14.4015
# Epoch 44: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4747, Test Linf Norm: 14.4017
# Epoch 45: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3914, Test Linf Norm: 14.4018
# Epoch 46: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4232, Test Linf Norm: 14.4020
# Epoch 47: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3750, Test Linf Norm: 14.4020
# Epoch 48: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3022, Test Linf Norm: 14.4020
# Epoch 49: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2116, Test Linf Norm: 14.4021
# Epoch 50: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4849, Test Linf Norm: 14.4020
# Epoch 51: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4894, Test Linf Norm: 14.4020
# Epoch 52: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2956, Test Linf Norm: 14.4020
# Epoch 53: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3911, Test Linf Norm: 14.4020
# Epoch 54: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3544, Test Linf Norm: 14.4020
# Epoch 55: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4188, Test Linf Norm: 14.4020
# Epoch 56: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.5088, Test Linf Norm: 14.4020
# Epoch 57: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4109, Test Linf Norm: 14.4020
# Epoch 58: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3889, Test Linf Norm: 14.4020
# Epoch 59: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2605, Test Linf Norm: 14.4020
# Epoch 60: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2702, Test Linf Norm: 14.4020
# Epoch 61: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4232, Test Linf Norm: 14.4020
# Epoch 62: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3773, Test Linf Norm: 14.4020
# Epoch 63: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2219, Test Linf Norm: 14.4020
# Epoch 64: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4081, Test Linf Norm: 14.4020
# Epoch 65: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4032, Test Linf Norm: 14.4020
# Epoch 66: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3104, Test Linf Norm: 14.4020
# Epoch 67: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4247, Test Linf Norm: 14.4020
# Epoch 68: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3472, Test Linf Norm: 14.4020
# Epoch 69: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3855, Test Linf Norm: 14.4020
# Epoch 70: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4498, Test Linf Norm: 14.4020
# Epoch 71: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3693, Test Linf Norm: 14.4020
# Epoch 72: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4322, Test Linf Norm: 14.4020
# Epoch 73: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2047, Test Linf Norm: 14.4020
# Epoch 74: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.1718, Test Linf Norm: 14.4020
# Epoch 75: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3774, Test Linf Norm: 14.4020
# Epoch 76: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.2787, Test Linf Norm: 14.4020
# Epoch 77: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3090, Test Linf Norm: 14.4020
# Epoch 78: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3632, Test Linf Norm: 14.4020
# Epoch 79: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.1954, Test Linf Norm: 14.4020
# Epoch 80: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3149, Test Linf Norm: 14.4020
# Epoch 81: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4559, Test Linf Norm: 14.4020
# Epoch 82: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4555, Test Linf Norm: 14.4020
# Epoch 83: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4092, Test Linf Norm: 14.4020
# Epoch 84: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.4589, Test Linf Norm: 14.4020
# Epoch 85: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3761, Test Linf Norm: 14.4020
# [I 2023-05-13 12:02:37,686] Trial 0 finished with value: 0.20479029345847666 and parameters: {'n_layers': 1, 'n_units_0': 243, 'hidden_activation': 'Sigmoid', 'output_activation': 'ReLU', 'loss': 'MAE', 'optimizer': 'Adagrad', 'lr': 0.00597163798444708, 'batch_size': 127, 'n_epochs': 86, 'scheduler': 'StepLR'}. Best is trial 0 with value: 0.20479029345847666.
# Epoch 86: Train Loss: 0.0877, Test Loss: 0.0850, Train L1 Norm: 0.1458, Test L1 Norm: 0.2048, Train Linf Norm: 10.3252, Test Linf Norm: 14.4020
# Epoch 1: Train Loss: 1.9906, Test Loss: 0.9757, Train L1 Norm: 8.6800, Test L1 Norm: 6.9103, Train Linf Norm: 1220.7431, Test Linf Norm: 790.8480
# Epoch 2: Train Loss: 0.7082, Test Loss: 0.4640, Train L1 Norm: 5.7176, Test L1 Norm: 3.0452, Train Linf Norm: 815.7636, Test Linf Norm: 353.9351
# Epoch 3: Train Loss: 0.3816, Test Loss: 0.2786, Train L1 Norm: 2.4818, Test L1 Norm: 1.4797, Train Linf Norm: 344.3357, Test Linf Norm: 180.0968
# Epoch 4: Train Loss: 0.2473, Test Loss: 0.1913, Train L1 Norm: 1.5567, Test L1 Norm: 1.2021, Train Linf Norm: 226.6062, Test Linf Norm: 149.1830
# Epoch 5: Train Loss: 0.1776, Test Loss: 0.1429, Train L1 Norm: 1.4842, Test L1 Norm: 1.2374, Train Linf Norm: 217.5058, Test Linf Norm: 152.5837
# Epoch 6: Train Loss: 0.1363, Test Loss: 0.1124, Train L1 Norm: 1.5819, Test L1 Norm: 1.3510, Train Linf Norm: 230.3066, Test Linf Norm: 165.3067
# Epoch 7: Train Loss: 0.1093, Test Loss: 0.0927, Train L1 Norm: 1.7080, Test L1 Norm: 1.4475, Train Linf Norm: 247.7856, Test Linf Norm: 178.2311
# Epoch 8: Train Loss: 0.0908, Test Loss: 0.0778, Train L1 Norm: 1.7739, Test L1 Norm: 1.4974, Train Linf Norm: 262.1537, Test Linf Norm: 185.1428
# Epoch 9: Train Loss: 0.0773, Test Loss: 0.0670, Train L1 Norm: 1.8087, Test L1 Norm: 1.5259, Train Linf Norm: 267.6473, Test Linf Norm: 189.5357
# Epoch 10: Train Loss: 0.0668, Test Loss: 0.0583, Train L1 Norm: 1.8194, Test L1 Norm: 1.5254, Train Linf Norm: 270.7124, Test Linf Norm: 191.3767
# Epoch 11: Train Loss: 0.0585, Test Loss: 0.0514, Train L1 Norm: 1.8046, Test L1 Norm: 1.4880, Train Linf Norm: 268.5444, Test Linf Norm: 187.5240
# Epoch 12: Train Loss: 0.0518, Test Loss: 0.0459, Train L1 Norm: 1.7667, Test L1 Norm: 1.4785, Train Linf Norm: 260.7375, Test Linf Norm: 187.1101
# Epoch 13: Train Loss: 0.0462, Test Loss: 0.0410, Train L1 Norm: 1.7211, Test L1 Norm: 1.4461, Train Linf Norm: 257.5242, Test Linf Norm: 185.0960
# Epoch 14: Train Loss: 0.0415, Test Loss: 0.0372, Train L1 Norm: 1.6824, Test L1 Norm: 1.4251, Train Linf Norm: 253.8896, Test Linf Norm: 183.6416
# Epoch 15: Train Loss: 0.0376, Test Loss: 0.0336, Train L1 Norm: 1.6559, Test L1 Norm: 1.3779, Train Linf Norm: 246.6961, Test Linf Norm: 177.8872
# Epoch 16: Train Loss: 0.0342, Test Loss: 0.0308, Train L1 Norm: 1.6043, Test L1 Norm: 1.3797, Train Linf Norm: 241.4384, Test Linf Norm: 178.2201
# Epoch 17: Train Loss: 0.0313, Test Loss: 0.0282, Train L1 Norm: 1.5669, Test L1 Norm: 1.3303, Train Linf Norm: 238.5350, Test Linf Norm: 172.7040
# Epoch 18: Train Loss: 0.0288, Test Loss: 0.0265, Train L1 Norm: 1.5241, Test L1 Norm: 1.2867, Train Linf Norm: 229.6308, Test Linf Norm: 167.5149
# Epoch 19: Train Loss: 0.0266, Test Loss: 0.0246, Train L1 Norm: 1.4925, Test L1 Norm: 1.2766, Train Linf Norm: 223.6721, Test Linf Norm: 165.4818
# Epoch 20: Train Loss: 0.0247, Test Loss: 0.0224, Train L1 Norm: 1.4675, Test L1 Norm: 1.2420, Train Linf Norm: 222.4476, Test Linf Norm: 161.5926
# Epoch 21: Train Loss: 0.0230, Test Loss: 0.0208, Train L1 Norm: 1.4287, Test L1 Norm: 1.1980, Train Linf Norm: 216.3830, Test Linf Norm: 155.7573
# Epoch 22: Train Loss: 0.0215, Test Loss: 0.0195, Train L1 Norm: 1.3915, Test L1 Norm: 1.1606, Train Linf Norm: 213.8333, Test Linf Norm: 151.0457
# Epoch 23: Train Loss: 0.0201, Test Loss: 0.0182, Train L1 Norm: 1.3579, Test L1 Norm: 1.1454, Train Linf Norm: 206.1667, Test Linf Norm: 149.2865
# Epoch 24: Train Loss: 0.0189, Test Loss: 0.0173, Train L1 Norm: 1.3231, Test L1 Norm: 1.1087, Train Linf Norm: 200.1111, Test Linf Norm: 144.1023
# Epoch 25: Train Loss: 0.0178, Test Loss: 0.0162, Train L1 Norm: 1.2830, Test L1 Norm: 1.0768, Train Linf Norm: 189.0434, Test Linf Norm: 140.4969
# Epoch 26: Train Loss: 0.0168, Test Loss: 0.0154, Train L1 Norm: 1.2574, Test L1 Norm: 1.0518, Train Linf Norm: 190.1644, Test Linf Norm: 137.1620
# Epoch 27: Train Loss: 0.0159, Test Loss: 0.0145, Train L1 Norm: 1.2245, Test L1 Norm: 1.0296, Train Linf Norm: 185.2629, Test Linf Norm: 134.2124
# Epoch 28: Train Loss: 0.0151, Test Loss: 0.0137, Train L1 Norm: 1.2018, Test L1 Norm: 0.9964, Train Linf Norm: 174.4199, Test Linf Norm: 130.0315
# Epoch 29: Train Loss: 0.0143, Test Loss: 0.0132, Train L1 Norm: 1.1643, Test L1 Norm: 0.9846, Train Linf Norm: 177.3371, Test Linf Norm: 128.4683
# Epoch 30: Train Loss: 0.0136, Test Loss: 0.0127, Train L1 Norm: 1.1456, Test L1 Norm: 0.9423, Train Linf Norm: 174.3759, Test Linf Norm: 122.9963
# Epoch 31: Train Loss: 0.0130, Test Loss: 0.0118, Train L1 Norm: 1.1079, Test L1 Norm: 0.9167, Train Linf Norm: 168.7137, Test Linf Norm: 119.6903
# Epoch 32: Train Loss: 0.0124, Test Loss: 0.0114, Train L1 Norm: 1.0788, Test L1 Norm: 0.9088, Train Linf Norm: 165.6436, Test Linf Norm: 118.5676
# Epoch 33: Train Loss: 0.0118, Test Loss: 0.0108, Train L1 Norm: 1.0630, Test L1 Norm: 0.8667, Train Linf Norm: 158.7497, Test Linf Norm: 113.4834
# Epoch 34: Train Loss: 0.0113, Test Loss: 0.0106, Train L1 Norm: 1.0279, Test L1 Norm: 0.8656, Train Linf Norm: 156.0193, Test Linf Norm: 113.2013
# Epoch 35: Train Loss: 0.0109, Test Loss: 0.0100, Train L1 Norm: 1.0036, Test L1 Norm: 0.8515, Train Linf Norm: 152.7650, Test Linf Norm: 111.4633
# Epoch 36: Train Loss: 0.0104, Test Loss: 0.0097, Train L1 Norm: 0.9935, Test L1 Norm: 0.8264, Train Linf Norm: 151.3248, Test Linf Norm: 107.6501
# Epoch 37: Train Loss: 0.0100, Test Loss: 0.0092, Train L1 Norm: 0.9663, Test L1 Norm: 0.8104, Train Linf Norm: 148.8561, Test Linf Norm: 106.0071
# Epoch 38: Train Loss: 0.0096, Test Loss: 0.0088, Train L1 Norm: 0.9434, Test L1 Norm: 0.7917, Train Linf Norm: 143.6737, Test Linf Norm: 104.2664
# Epoch 39: Train Loss: 0.0093, Test Loss: 0.0088, Train L1 Norm: 0.9247, Test L1 Norm: 0.7696, Train Linf Norm: 141.0403, Test Linf Norm: 101.1076
# Epoch 40: Train Loss: 0.0089, Test Loss: 0.0082, Train L1 Norm: 0.9025, Test L1 Norm: 0.7384, Train Linf Norm: 139.3003, Test Linf Norm: 96.9006
# Epoch 41: Train Loss: 0.0086, Test Loss: 0.0080, Train L1 Norm: 0.8819, Test L1 Norm: 0.7320, Train Linf Norm: 133.7599, Test Linf Norm: 96.3017
# Epoch 42: Train Loss: 0.0083, Test Loss: 0.0076, Train L1 Norm: 0.8638, Test L1 Norm: 0.7200, Train Linf Norm: 132.9345, Test Linf Norm: 95.1196
# Epoch 43: Train Loss: 0.0081, Test Loss: 0.0074, Train L1 Norm: 0.8496, Test L1 Norm: 0.7045, Train Linf Norm: 130.6083, Test Linf Norm: 92.6769
# Epoch 44: Train Loss: 0.0078, Test Loss: 0.0072, Train L1 Norm: 0.8314, Test L1 Norm: 0.6863, Train Linf Norm: 126.9951, Test Linf Norm: 90.5050
# Epoch 45: Train Loss: 0.0076, Test Loss: 0.0069, Train L1 Norm: 0.8192, Test L1 Norm: 0.6561, Train Linf Norm: 124.7411, Test Linf Norm: 86.6802
# Epoch 46: Train Loss: 0.0073, Test Loss: 0.0069, Train L1 Norm: 0.7939, Test L1 Norm: 0.6613, Train Linf Norm: 121.7192, Test Linf Norm: 87.2734
# Epoch 47: Train Loss: 0.0071, Test Loss: 0.0065, Train L1 Norm: 0.7822, Test L1 Norm: 0.6503, Train Linf Norm: 120.1092, Test Linf Norm: 86.0444
# Epoch 48: Train Loss: 0.0069, Test Loss: 0.0063, Train L1 Norm: 0.7717, Test L1 Norm: 0.6454, Train Linf Norm: 118.6106, Test Linf Norm: 84.8378
# Epoch 49: Train Loss: 0.0067, Test Loss: 0.0061, Train L1 Norm: 0.7554, Test L1 Norm: 0.6215, Train Linf Norm: 114.8633, Test Linf Norm: 82.3585
# Epoch 50: Train Loss: 0.0065, Test Loss: 0.0059, Train L1 Norm: 0.7396, Test L1 Norm: 0.6045, Train Linf Norm: 112.8552, Test Linf Norm: 80.3130
# Epoch 51: Train Loss: 0.0063, Test Loss: 0.0058, Train L1 Norm: 0.7282, Test L1 Norm: 0.6057, Train Linf Norm: 111.3345, Test Linf Norm: 80.5345
# Epoch 52: Train Loss: 0.0062, Test Loss: 0.0056, Train L1 Norm: 0.7153, Test L1 Norm: 0.5903, Train Linf Norm: 108.3640, Test Linf Norm: 78.3749
# Epoch 53: Train Loss: 0.0060, Test Loss: 0.0055, Train L1 Norm: 0.7060, Test L1 Norm: 0.5819, Train Linf Norm: 109.3321, Test Linf Norm: 77.2353
# Epoch 54: Train Loss: 0.0058, Test Loss: 0.0053, Train L1 Norm: 0.6965, Test L1 Norm: 0.5778, Train Linf Norm: 107.1954, Test Linf Norm: 76.7078
# Epoch 55: Train Loss: 0.0057, Test Loss: 0.0052, Train L1 Norm: 0.6828, Test L1 Norm: 0.5638, Train Linf Norm: 105.7600, Test Linf Norm: 75.0759
# Epoch 56: Train Loss: 0.0056, Test Loss: 0.0051, Train L1 Norm: 0.6740, Test L1 Norm: 0.5474, Train Linf Norm: 103.5986, Test Linf Norm: 72.9831
# Epoch 57: Train Loss: 0.0054, Test Loss: 0.0049, Train L1 Norm: 0.6624, Test L1 Norm: 0.5493, Train Linf Norm: 100.8852, Test Linf Norm: 73.1143
# Epoch 58: Train Loss: 0.0053, Test Loss: 0.0048, Train L1 Norm: 0.6522, Test L1 Norm: 0.5381, Train Linf Norm: 101.1860, Test Linf Norm: 71.7402
# Epoch 59: Train Loss: 0.0052, Test Loss: 0.0048, Train L1 Norm: 0.6440, Test L1 Norm: 0.5363, Train Linf Norm: 98.7176, Test Linf Norm: 71.6307
# Epoch 60: Train Loss: 0.0051, Test Loss: 0.0046, Train L1 Norm: 0.6381, Test L1 Norm: 0.5221, Train Linf Norm: 98.1630, Test Linf Norm: 69.7307
# Epoch 61: Train Loss: 0.0049, Test Loss: 0.0045, Train L1 Norm: 0.6295, Test L1 Norm: 0.5123, Train Linf Norm: 98.1054, Test Linf Norm: 68.4623
# Epoch 62: Train Loss: 0.0048, Test Loss: 0.0044, Train L1 Norm: 0.6213, Test L1 Norm: 0.5070, Train Linf Norm: 96.3754, Test Linf Norm: 67.5048
# Epoch 63: Train Loss: 0.0047, Test Loss: 0.0044, Train L1 Norm: 0.6137, Test L1 Norm: 0.4944, Train Linf Norm: 91.7807, Test Linf Norm: 66.1418
# Epoch 64: Train Loss: 0.0046, Test Loss: 0.0042, Train L1 Norm: 0.6026, Test L1 Norm: 0.4958, Train Linf Norm: 93.6930, Test Linf Norm: 66.4111
# Epoch 65: Train Loss: 0.0045, Test Loss: 0.0042, Train L1 Norm: 0.5972, Test L1 Norm: 0.4871, Train Linf Norm: 92.5885, Test Linf Norm: 65.2515
# Epoch 66: Train Loss: 0.0044, Test Loss: 0.0041, Train L1 Norm: 0.5889, Test L1 Norm: 0.4821, Train Linf Norm: 90.1873, Test Linf Norm: 64.5944
# [I 2023-05-13 12:04:19,235] Trial 1 finished with value: 0.4774089967790991 and parameters: {'n_layers': 2, 'n_units_0': 233, 'n_units_1': 222, 'hidden_activation': 'Tanh', 'output_activation': 'Linear', 'loss': 'MSE', 'optimizer': 'Adagrad', 'lr': 0.0010802429981352731, 'batch_size': 182, 'n_epochs': 67, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 0 with value: 0.20479029345847666.
# Epoch 67: Train Loss: 0.0044, Test Loss: 0.0040, Train L1 Norm: 0.5827, Test L1 Norm: 0.4774, Train Linf Norm: 90.7539, Test Linf Norm: 63.9660
# Epoch 1: Train Loss: 2.8204, Test Loss: 2.8210, Train L1 Norm: 1.0057, Test L1 Norm: 1.0000, Train Linf Norm: 1.1304, Test Linf Norm: 1.0000
# Epoch 2: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 3: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 4: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 5: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 6: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 7: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 8: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 9: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 10: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 11: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 12: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 13: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 14: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 15: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 16: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 17: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 18: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 19: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 20: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 21: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 22: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 23: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 24: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 25: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 26: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 27: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 28: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 29: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 30: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 31: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 32: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 33: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 34: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 35: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 36: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 37: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 38: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 39: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 40: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 41: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 42: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 43: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 44: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 45: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 46: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 47: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 48: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 49: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 50: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 51: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 52: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 53: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 54: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 55: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 56: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 57: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 58: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 59: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 60: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 61: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 62: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 63: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 64: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 65: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 66: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 67: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 68: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 69: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 70: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 71: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 72: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 73: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 74: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 75: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 76: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 77: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 78: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 79: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 80: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 81: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 82: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 83: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 84: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 85: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 86: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 87: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 88: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 89: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 90: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 91: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 92: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 93: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 94: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# [I 2023-05-13 12:07:41,808] Trial 2 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_0': 87, 'n_units_1': 105, 'n_units_2': 233, 'hidden_activation': 'LeakyReLU', 'output_activation': 'ReLU', 'loss': 'LogCosh', 'optimizer': 'RMSprop', 'lr': 0.0032200689067155602, 'batch_size': 95, 'n_epochs': 95, 'scheduler': 'CosineAnnealingLR'}. Best is trial 0 with value: 0.20479029345847666.
# Epoch 95: Train Loss: 2.8128, Test Loss: 2.8210, Train L1 Norm: 1.0000, Test L1 Norm: 1.0000, Train Linf Norm: 1.0000, Test Linf Norm: 1.0000
# Epoch 1: Train Loss: 0.0274, Test Loss: 0.0028, Train L1 Norm: 0.1695, Test L1 Norm: 0.1830, Train Linf Norm: 4.0738, Test Linf Norm: 9.6513
# Epoch 2: Train Loss: 0.0020, Test Loss: 0.0017, Train L1 Norm: 0.0936, Test L1 Norm: 0.1796, Train Linf Norm: 3.6684, Test Linf Norm: 10.2143
# Epoch 3: Train Loss: 0.0011, Test Loss: 0.0009, Train L1 Norm: 0.1083, Test L1 Norm: 0.1579, Train Linf Norm: 5.1749, Test Linf Norm: 8.9407
# Epoch 4: Train Loss: 0.0008, Test Loss: 0.0007, Train L1 Norm: 0.0944, Test L1 Norm: 0.1398, Train Linf Norm: 4.4169, Test Linf Norm: 7.8184
# Epoch 5: Train Loss: 0.0006, Test Loss: 0.0007, Train L1 Norm: 0.0829, Test L1 Norm: 0.1347, Train Linf Norm: 3.7428, Test Linf Norm: 7.5876
# Epoch 6: Train Loss: 0.0005, Test Loss: 0.0006, Train L1 Norm: 0.0703, Test L1 Norm: 0.1032, Train Linf Norm: 2.9709, Test Linf Norm: 5.4250
# Epoch 7: Train Loss: 0.0005, Test Loss: 0.0004, Train L1 Norm: 0.0636, Test L1 Norm: 0.1001, Train Linf Norm: 2.5895, Test Linf Norm: 5.3355
# Epoch 8: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.0562, Test L1 Norm: 0.0970, Train Linf Norm: 2.1693, Test Linf Norm: 5.1662
# Epoch 9: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.0528, Test L1 Norm: 0.0879, Train Linf Norm: 1.9593, Test Linf Norm: 4.5423
# Epoch 10: Train Loss: 0.0004, Test Loss: 0.0007, Train L1 Norm: 0.0496, Test L1 Norm: 0.0820, Train Linf Norm: 1.7965, Test Linf Norm: 3.9695
# Epoch 11: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0468, Test L1 Norm: 0.0840, Train Linf Norm: 1.6032, Test Linf Norm: 4.3742
# Epoch 12: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0450, Test L1 Norm: 0.0817, Train Linf Norm: 1.5186, Test Linf Norm: 4.2312
# Epoch 13: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0440, Test L1 Norm: 0.0764, Train Linf Norm: 1.4373, Test Linf Norm: 3.8246
# Epoch 14: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0430, Test L1 Norm: 0.0772, Train Linf Norm: 1.3917, Test Linf Norm: 3.9147
# Epoch 15: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0431, Test L1 Norm: 0.0776, Train Linf Norm: 1.4016, Test Linf Norm: 3.9504
# Epoch 16: Train Loss: 0.0003, Test Loss: 0.0004, Train L1 Norm: 0.0427, Test L1 Norm: 0.0743, Train Linf Norm: 1.4034, Test Linf Norm: 3.6180
# Epoch 17: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0425, Test L1 Norm: 0.0749, Train Linf Norm: 1.3696, Test Linf Norm: 3.7440
# Epoch 18: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0422, Test L1 Norm: 0.0762, Train Linf Norm: 1.3736, Test Linf Norm: 3.8517
# Epoch 19: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0424, Test L1 Norm: 0.0729, Train Linf Norm: 1.3834, Test Linf Norm: 3.5947
# Epoch 20: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0421, Test L1 Norm: 0.0734, Train Linf Norm: 1.3731, Test Linf Norm: 3.6402
# Epoch 21: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0418, Test L1 Norm: 0.0725, Train Linf Norm: 1.3530, Test Linf Norm: 3.5724
# Epoch 22: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0419, Test L1 Norm: 0.0727, Train Linf Norm: 1.3619, Test Linf Norm: 3.5859
# Epoch 23: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0420, Test L1 Norm: 0.0720, Train Linf Norm: 1.3694, Test Linf Norm: 3.5410
# Epoch 24: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.0418, Test L1 Norm: 0.0707, Train Linf Norm: 1.3780, Test Linf Norm: 3.4365
# Epoch 25: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0418, Test L1 Norm: 0.0718, Train Linf Norm: 1.3606, Test Linf Norm: 3.5359
# Epoch 26: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0418, Test L1 Norm: 0.0716, Train Linf Norm: 1.3544, Test Linf Norm: 3.5187
# Epoch 27: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0417, Test L1 Norm: 0.0703, Train Linf Norm: 1.3520, Test Linf Norm: 3.4168
# Epoch 28: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0704, Train Linf Norm: 1.3361, Test Linf Norm: 3.4280
# Epoch 29: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0706, Train Linf Norm: 1.3545, Test Linf Norm: 3.4427
# Epoch 30: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0702, Train Linf Norm: 1.3497, Test Linf Norm: 3.4100
# Epoch 31: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0704, Train Linf Norm: 1.3513, Test Linf Norm: 3.4279
# Epoch 32: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0703, Train Linf Norm: 1.3621, Test Linf Norm: 3.4212
# Epoch 33: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0416, Test L1 Norm: 0.0699, Train Linf Norm: 1.3672, Test Linf Norm: 3.3902
# Epoch 34: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0415, Test L1 Norm: 0.0700, Train Linf Norm: 1.3428, Test Linf Norm: 3.3986
# Epoch 35: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0415, Test L1 Norm: 0.0700, Train Linf Norm: 1.3606, Test Linf Norm: 3.4039
# Epoch 36: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0415, Test L1 Norm: 0.0697, Train Linf Norm: 1.3313, Test Linf Norm: 3.3840
# Epoch 37: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0698, Train Linf Norm: 1.3520, Test Linf Norm: 3.3937
# Epoch 38: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0415, Test L1 Norm: 0.0698, Train Linf Norm: 1.3445, Test Linf Norm: 3.3872
# Epoch 39: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0415, Test L1 Norm: 0.0694, Train Linf Norm: 1.3553, Test Linf Norm: 3.3557
# Epoch 40: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0695, Train Linf Norm: 1.3211, Test Linf Norm: 3.3687
# Epoch 41: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0695, Train Linf Norm: 1.3460, Test Linf Norm: 3.3697
# Epoch 42: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0696, Train Linf Norm: 1.3296, Test Linf Norm: 3.3738
# Epoch 43: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0695, Train Linf Norm: 1.3421, Test Linf Norm: 3.3722
# Epoch 44: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0694, Train Linf Norm: 1.3463, Test Linf Norm: 3.3622
# Epoch 45: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0694, Train Linf Norm: 1.3391, Test Linf Norm: 3.3617
# Epoch 46: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3628, Test Linf Norm: 3.3462
# Epoch 47: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0694, Train Linf Norm: 1.3426, Test Linf Norm: 3.3616
# Epoch 48: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0690, Train Linf Norm: 1.3464, Test Linf Norm: 3.3329
# Epoch 49: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0693, Train Linf Norm: 1.3463, Test Linf Norm: 3.3555
# Epoch 50: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3432, Test Linf Norm: 3.3467
# Epoch 51: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3561, Test Linf Norm: 3.3467
# Epoch 52: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3510, Test Linf Norm: 3.3454
# Epoch 53: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3514, Test Linf Norm: 3.3475
# Epoch 54: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3452, Test Linf Norm: 3.3461
# Epoch 55: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3294, Test Linf Norm: 3.3401
# Epoch 56: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3519, Test Linf Norm: 3.3504
# Epoch 57: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3508, Test Linf Norm: 3.3425
# Epoch 58: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3264, Test Linf Norm: 3.3476
# Epoch 59: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3464, Test Linf Norm: 3.3465
# Epoch 60: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3520, Test Linf Norm: 3.3450
# Epoch 61: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3437, Test Linf Norm: 3.3440
# Epoch 62: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0692, Train Linf Norm: 1.3289, Test Linf Norm: 3.3455
# Epoch 63: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0692, Train Linf Norm: 1.3405, Test Linf Norm: 3.3449
# Epoch 64: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3588, Test Linf Norm: 3.3444
# Epoch 65: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3477, Test Linf Norm: 3.3441
# Epoch 66: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3239, Test Linf Norm: 3.3442
# Epoch 67: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3498, Test Linf Norm: 3.3433
# Epoch 68: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3552, Test Linf Norm: 3.3428
# Epoch 69: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3483, Test Linf Norm: 3.3419
# Epoch 70: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3316, Test Linf Norm: 3.3415
# Epoch 71: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0414, Test L1 Norm: 0.0691, Train Linf Norm: 1.3416, Test Linf Norm: 3.3406
# Epoch 72: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0691, Train Linf Norm: 1.3358, Test Linf Norm: 3.3402
# Epoch 73: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0691, Train Linf Norm: 1.3434, Test Linf Norm: 3.3404
# Epoch 74: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0691, Train Linf Norm: 1.3565, Test Linf Norm: 3.3402
# Epoch 75: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0691, Train Linf Norm: 1.3397, Test Linf Norm: 3.3401
# Epoch 76: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0413, Test L1 Norm: 0.0691, Train Linf Norm: 1.3380, Test Linf Norm: 3.3402
# ...
# Epoch 4: Train Loss: 0.0063, Test Loss: 0.0004, Train L1 Norm: 0.0627, Test L1 Norm: 0.0431, Train Linf Norm: 2.5935, Test Linf Norm: 2.0057
# Epoch 5: Train Loss: 0.0058, Test Loss: 0.0003, Train L1 Norm: 0.0550, Test L1 Norm: 0.0481, Train Linf Norm: 2.2616, Test Linf Norm: 1.9434
# Epoch 6: Train Loss: 0.0050, Test Loss: 0.0002, Train L1 Norm: 0.0522, Test L1 Norm: 0.0412, Train Linf Norm: 2.1341, Test Linf Norm: 1.5944
# [I 2023-05-13 12:47:58,510] Trial 37 pruned.
# Epoch 7: Train Loss: 0.0044, Test Loss: 0.0004, Train L1 Norm: 0.0474, Test L1 Norm: 0.0393, Train Linf Norm: 1.8316, Test Linf Norm: 1.3370
# Epoch 1: Train Loss: 0.0494, Test Loss: 0.0001, Train L1 Norm: 0.2238, Test L1 Norm: 0.0400, Train Linf Norm: 8.1617, Test Linf Norm: 1.2828
# Epoch 2: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0451, Test L1 Norm: 0.0363, Train Linf Norm: 1.7201, Test Linf Norm: 1.1130
# Epoch 3: Train Loss: 0.0002, Test Loss: 0.0013, Train L1 Norm: 0.0381, Test L1 Norm: 0.0415, Train Linf Norm: 1.4841, Test Linf Norm: 1.2960
# Epoch 4: Train Loss: 0.0004, Test Loss: 0.0000, Train L1 Norm: 0.0360, Test L1 Norm: 0.0220, Train Linf Norm: 1.3523, Test Linf Norm: 0.7515
# Epoch 5: Train Loss: 0.0003, Test Loss: 0.0002, Train L1 Norm: 0.0325, Test L1 Norm: 0.0517, Train Linf Norm: 1.2405, Test Linf Norm: 1.8918
# Epoch 6: Train Loss: 0.0003, Test Loss: 0.0000, Train L1 Norm: 0.0297, Test L1 Norm: 0.0255, Train Linf Norm: 1.1525, Test Linf Norm: 0.9555
# Epoch 7: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0286, Test L1 Norm: 0.0232, Train Linf Norm: 1.0880, Test Linf Norm: 0.8479
# Epoch 8: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0363, Test L1 Norm: 0.0387, Train Linf Norm: 1.5155, Test Linf Norm: 1.4676
# Epoch 9: Train Loss: 0.0002, Test Loss: 0.0004, Train L1 Norm: 0.0277, Test L1 Norm: 0.0254, Train Linf Norm: 1.1050, Test Linf Norm: 0.8568
# Epoch 10: Train Loss: 0.0008, Test Loss: 0.0001, Train L1 Norm: 0.0320, Test L1 Norm: 0.0307, Train Linf Norm: 1.2409, Test Linf Norm: 1.1078
# Epoch 11: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0202, Test L1 Norm: 0.0162, Train Linf Norm: 0.8343, Test Linf Norm: 0.5783
# Epoch 12: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0198, Test L1 Norm: 0.0172, Train Linf Norm: 0.8135, Test Linf Norm: 0.6517
# Epoch 13: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0201, Test L1 Norm: 0.0133, Train Linf Norm: 0.7997, Test Linf Norm: 0.4160
# Epoch 14: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0200, Test L1 Norm: 0.0158, Train Linf Norm: 0.8085, Test Linf Norm: 0.5542
# Epoch 15: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0206, Test L1 Norm: 0.0139, Train Linf Norm: 0.8297, Test Linf Norm: 0.5191
# Epoch 16: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0188, Test L1 Norm: 0.0186, Train Linf Norm: 0.7901, Test Linf Norm: 0.7310
# Epoch 17: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0182, Test L1 Norm: 0.0146, Train Linf Norm: 0.7108, Test Linf Norm: 0.5662
# Epoch 18: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0180, Test L1 Norm: 0.0208, Train Linf Norm: 0.7465, Test Linf Norm: 0.7674
# Epoch 19: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0225, Test L1 Norm: 0.0104, Train Linf Norm: 0.9799, Test Linf Norm: 0.3323
# Epoch 20: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0176, Test L1 Norm: 0.0106, Train Linf Norm: 0.7161, Test Linf Norm: 0.3561
# Epoch 21: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0186, Test L1 Norm: 0.0348, Train Linf Norm: 0.7452, Test Linf Norm: 1.3852
# Epoch 22: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0164, Test L1 Norm: 0.0183, Train Linf Norm: 0.6704, Test Linf Norm: 0.6898
# Epoch 23: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0192, Test L1 Norm: 0.0186, Train Linf Norm: 0.8307, Test Linf Norm: 0.7552
# Epoch 24: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 0.6646, Test Linf Norm: 0.4441
# Epoch 25: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0202, Test L1 Norm: 0.0195, Train Linf Norm: 0.8159, Test Linf Norm: 0.7750
# Epoch 26: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0149, Test L1 Norm: 0.0129, Train Linf Norm: 0.6164, Test Linf Norm: 0.4911
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0170, Test L1 Norm: 0.0101, Train Linf Norm: 0.7275, Test Linf Norm: 0.3451
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0169, Test L1 Norm: 0.0114, Train Linf Norm: 0.6935, Test Linf Norm: 0.4290
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0146, Test L1 Norm: 0.0116, Train Linf Norm: 0.5671, Test Linf Norm: 0.4461
# Epoch 30: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0174, Test L1 Norm: 0.0151, Train Linf Norm: 0.7133, Test Linf Norm: 0.5341
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0179, Test L1 Norm: 0.0102, Train Linf Norm: 0.7652, Test Linf Norm: 0.3894
# Epoch 32: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0162, Test L1 Norm: 0.0106, Train Linf Norm: 0.6390, Test Linf Norm: 0.3872
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0159, Test L1 Norm: 0.0095, Train Linf Norm: 0.6700, Test Linf Norm: 0.2670
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0147, Test L1 Norm: 0.0179, Train Linf Norm: 0.5653, Test Linf Norm: 0.6973
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0164, Test L1 Norm: 0.0136, Train Linf Norm: 0.6978, Test Linf Norm: 0.5260
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0150, Test L1 Norm: 0.0105, Train Linf Norm: 0.6083, Test Linf Norm: 0.3372
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0156, Test L1 Norm: 0.0162, Train Linf Norm: 0.6488, Test Linf Norm: 0.5191
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0116, Test L1 Norm: 0.0089, Train Linf Norm: 0.4836, Test Linf Norm: 0.2843
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0121, Test L1 Norm: 0.0136, Train Linf Norm: 0.4965, Test Linf Norm: 0.5059
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0124, Test L1 Norm: 0.0092, Train Linf Norm: 0.5172, Test Linf Norm: 0.3231
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0108, Test L1 Norm: 0.0066, Train Linf Norm: 0.4313, Test Linf Norm: 0.2139
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0115, Test L1 Norm: 0.0205, Train Linf Norm: 0.4589, Test Linf Norm: 0.7335
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0112, Test L1 Norm: 0.0103, Train Linf Norm: 0.4615, Test Linf Norm: 0.3537
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0126, Test L1 Norm: 0.0117, Train Linf Norm: 0.5279, Test Linf Norm: 0.4464
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0109, Test L1 Norm: 0.0089, Train Linf Norm: 0.4484, Test Linf Norm: 0.3130
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0113, Test L1 Norm: 0.0068, Train Linf Norm: 0.4753, Test Linf Norm: 0.2326
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0123, Test L1 Norm: 0.0086, Train Linf Norm: 0.5122, Test Linf Norm: 0.2989
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0099, Test L1 Norm: 0.0070, Train Linf Norm: 0.3993, Test Linf Norm: 0.2362
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0112, Test L1 Norm: 0.0153, Train Linf Norm: 0.4598, Test Linf Norm: 0.5573
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0098, Test L1 Norm: 0.0094, Train Linf Norm: 0.3849, Test Linf Norm: 0.3568
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0102, Test L1 Norm: 0.0077, Train Linf Norm: 0.4113, Test Linf Norm: 0.2784
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0082, Train Linf Norm: 0.3468, Test Linf Norm: 0.3162
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0113, Test L1 Norm: 0.0132, Train Linf Norm: 0.4782, Test Linf Norm: 0.4960
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0066, Train Linf Norm: 0.3454, Test Linf Norm: 0.2308
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0101, Test L1 Norm: 0.0109, Train Linf Norm: 0.4046, Test Linf Norm: 0.4374
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0097, Test L1 Norm: 0.0092, Train Linf Norm: 0.3867, Test Linf Norm: 0.3423
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0101, Test L1 Norm: 0.0081, Train Linf Norm: 0.4049, Test Linf Norm: 0.2972
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0113, Test L1 Norm: 0.0141, Train Linf Norm: 0.4611, Test Linf Norm: 0.5478
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0082, Test L1 Norm: 0.0076, Train Linf Norm: 0.3393, Test Linf Norm: 0.2818
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0098, Test L1 Norm: 0.0071, Train Linf Norm: 0.4147, Test Linf Norm: 0.2553
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0096, Test L1 Norm: 0.0091, Train Linf Norm: 0.4099, Test Linf Norm: 0.3463
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0083, Train Linf Norm: 0.3717, Test Linf Norm: 0.3220
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0113, Train Linf Norm: 0.3334, Test Linf Norm: 0.4256
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0098, Test L1 Norm: 0.0095, Train Linf Norm: 0.4186, Test Linf Norm: 0.3617
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0075, Train Linf Norm: 0.3530, Test Linf Norm: 0.2545
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0064, Train Linf Norm: 0.3831, Test Linf Norm: 0.2264
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0090, Test L1 Norm: 0.0089, Train Linf Norm: 0.3793, Test Linf Norm: 0.3387
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0099, Train Linf Norm: 0.3642, Test Linf Norm: 0.3801
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0093, Test L1 Norm: 0.0066, Train Linf Norm: 0.3945, Test Linf Norm: 0.2277
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0061, Train Linf Norm: 0.3728, Test Linf Norm: 0.2123
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0078, Train Linf Norm: 0.3642, Test Linf Norm: 0.3007
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0092, Test L1 Norm: 0.0081, Train Linf Norm: 0.4071, Test Linf Norm: 0.3129
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0072, Train Linf Norm: 0.3551, Test Linf Norm: 0.2733
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0073, Train Linf Norm: 0.2897, Test Linf Norm: 0.2759
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0082, Test L1 Norm: 0.0103, Train Linf Norm: 0.3464, Test Linf Norm: 0.4099
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0075, Train Linf Norm: 0.2922, Test Linf Norm: 0.2686
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0071, Train Linf Norm: 0.3309, Test Linf Norm: 0.2705
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0089, Test L1 Norm: 0.0061, Train Linf Norm: 0.3812, Test Linf Norm: 0.2211
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0106, Train Linf Norm: 0.3423, Test Linf Norm: 0.4009
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0073, Train Linf Norm: 0.3770, Test Linf Norm: 0.2762
# Epoch 81: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0076, Test L1 Norm: 0.0068, Train Linf Norm: 0.3157, Test Linf Norm: 0.2569
# Epoch 82: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0086, Test L1 Norm: 0.0086, Train Linf Norm: 0.3714, Test Linf Norm: 0.3341
# Epoch 83: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0085, Train Linf Norm: 0.3000, Test Linf Norm: 0.3225
# Epoch 84: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0072, Train Linf Norm: 0.3000, Test Linf Norm: 0.2760
# Epoch 85: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0076, Train Linf Norm: 0.3206, Test Linf Norm: 0.2915
# Epoch 86: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0065, Train Linf Norm: 0.2901, Test Linf Norm: 0.2270
# Epoch 87: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0099, Train Linf Norm: 0.3268, Test Linf Norm: 0.3724
# Epoch 88: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0075, Train Linf Norm: 0.3407, Test Linf Norm: 0.2877
# Epoch 89: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0075, Train Linf Norm: 0.3033, Test Linf Norm: 0.2787
# [I 2023-05-13 12:52:32,479] Trial 38 finished with value: 0.007381363410007907 and parameters: {'n_layers': 2, 'n_units_0': 172, 'n_units_1': 249, 'hidden_activation': 'LeakyReLU', 'output_activation': 'Linear', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 0.0001468891993074274, 'batch_size': 55, 'n_epochs': 90, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 38 with value: 0.007381363410007907.
# Epoch 90: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0074, Train Linf Norm: 0.3341, Test Linf Norm: 0.2798
# [I 2023-05-13 12:52:36,174] Trial 39 pruned.
# Epoch 1: Train Loss: 1.2788, Test Loss: 0.1186, Train L1 Norm: 1.2246, Test L1 Norm: 0.2903, Train Linf Norm: 47.7431, Test Linf Norm: 7.3242
# Epoch 1: Train Loss: 0.1104, Test Loss: 0.0143, Train L1 Norm: 0.2665, Test L1 Norm: 0.0564, Train Linf Norm: 10.4947, Test Linf Norm: 2.1671
# Epoch 2: Train Loss: 0.0190, Test Loss: 0.0227, Train L1 Norm: 0.0500, Test L1 Norm: 0.0479, Train Linf Norm: 1.8429, Test Linf Norm: 1.5776
# Epoch 3: Train Loss: 0.0162, Test Loss: 0.0127, Train L1 Norm: 0.0334, Test L1 Norm: 0.0212, Train Linf Norm: 1.1174, Test Linf Norm: 0.6691
# Epoch 4: Train Loss: 0.0179, Test Loss: 0.0108, Train L1 Norm: 0.0454, Test L1 Norm: 0.0623, Train Linf Norm: 1.7108, Test Linf Norm: 2.4929
# Epoch 5: Train Loss: 0.0154, Test Loss: 0.0073, Train L1 Norm: 0.0369, Test L1 Norm: 0.0258, Train Linf Norm: 1.3374, Test Linf Norm: 0.9386
# Epoch 6: Train Loss: 0.0155, Test Loss: 0.0137, Train L1 Norm: 0.0333, Test L1 Norm: 0.0229, Train Linf Norm: 1.1884, Test Linf Norm: 0.7530
# Epoch 7: Train Loss: 0.0159, Test Loss: 0.0090, Train L1 Norm: 0.0327, Test L1 Norm: 0.0258, Train Linf Norm: 1.1346, Test Linf Norm: 0.8871
# Epoch 8: Train Loss: 0.0139, Test Loss: 0.0103, Train L1 Norm: 0.0304, Test L1 Norm: 0.0158, Train Linf Norm: 1.0807, Test Linf Norm: 0.5271
# Epoch 9: Train Loss: 0.0157, Test Loss: 0.0134, Train L1 Norm: 0.0303, Test L1 Norm: 0.0316, Train Linf Norm: 1.0403, Test Linf Norm: 1.0963
# Epoch 10: Train Loss: 0.0133, Test Loss: 0.0066, Train L1 Norm: 0.0320, Test L1 Norm: 0.0314, Train Linf Norm: 1.1728, Test Linf Norm: 1.3012
# Epoch 11: Train Loss: 0.0145, Test Loss: 0.0205, Train L1 Norm: 0.0243, Test L1 Norm: 0.0369, Train Linf Norm: 0.7760, Test Linf Norm: 1.1937
# Epoch 12: Train Loss: 0.0143, Test Loss: 0.0081, Train L1 Norm: 0.0373, Test L1 Norm: 0.0375, Train Linf Norm: 1.4211, Test Linf Norm: 1.4904
# Epoch 13: Train Loss: 0.0140, Test Loss: 0.0210, Train L1 Norm: 0.0298, Test L1 Norm: 0.0332, Train Linf Norm: 1.0648, Test Linf Norm: 1.0083
# Epoch 14: Train Loss: 0.0122, Test Loss: 0.0128, Train L1 Norm: 0.0237, Test L1 Norm: 0.0303, Train Linf Norm: 0.7981, Test Linf Norm: 1.1619

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
  output_activation_loaded = nn.ReLU()
else:
  output_activation_loaded = nn.Identity()

# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if optimizer_name_loaded == "SGD":
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "Adam":
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(torch.load("optimizer.pth"))

if scheduler_name_loaded == "StepLR":
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=10, gamma=0.1)
elif scheduler_name_loaded == "ExponentialLR":
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=0.9)
elif scheduler_name_loaded == "CosineAnnealingLR":
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=10)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  scheduler_loaded.load_state_dict(torch.load("scheduler.pth"))
            

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
loss_fn_loaded
optimizer_loaded
scheduler_loaded
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))

# %%
print(list(net_loaded.parameters()))

# %%
# Set the network to evaluation mode
net.eval()

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
