# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics

# %% [markdown]
# ## How to use this notebook
# 0. Install required packages with `pip install -r requirements.txt`
#
# ### Training without optimization
#
# 1. Set `OPTIMIZE = False` in section _Constants and flags to set_.
# 2. Run the entire notebook.
#
# ### Training with optimization
#
# 1. Set `OPTIMIZE = True` in section _Constants and flags to set_.
# 2. Run the entire notebook.
#
# ### Loading an already trained model
#
# 1. Run cells in section _Initialization_.
# 2. Run cells with definitions in section _Generating the data_.
# 3. Run cell with the definition of _Net_ in section _Defining the neural network_.
# 4. Make sure the `net.pth`, `optimizer.pth`, `scheduler.pth`, `var_dict.json` and `train_output.csv` files are in the directory containing this notebook.
# 5. Run the cells in section _Loading_ and continue from there.
#
# ### Generating the C++ model
#
# 1. Run section _Porting the model to C++_, this requires a model to be loaded.
# 2. Set the path to the `net.pt` file in the C++ source file.
# 3. `mkdir build && cd build`,
# 4. `cmake -DCMAKE_PREFIX_PATH=/path/to/libtorch/ ..`,
# 3. Compile and run, e.g. `cmake --build . --config release && ./executable`

# %% [markdown]
# ## Initialization

# %% [markdown]
# Use this first cell to **convert this notebook** to a python script.

# %%
# %%script echo skipping
#
# !jupyter nbconvert conversion_attempt_2.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# Next some cells for working on **google colab**,

# %%
import os
import shutil

# check if the drive is mounted
drive_mounted = os.path.exists("/content/drive")
# change this to your desired folder
drive_folder = "/content/drive/My Drive/bsc/con2prim_towards_GRMHD/ca2_nan_fixed/"

# define a function to save a file to the drive or the current directory
def save_file(file_name):
  if drive_mounted:
    # save the file to the drive folder
    file_path = os.path.join(drive_folder, file_name)
    # copy the file from the current directory to the drive folder
    shutil.copyfile(file_name, file_path)
  else:
    # do nothing as the file is already in the current directory
    pass

# %%
# %%script echo skipping
#
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Couldn't find program: 'echo'

# %%
# %%script echo skipping
#
# !pip install optuna tensorboard tensorboardX
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# Importing the **libraries** and setting the **device**,

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Constants and flags to set
# Defining some constants and parameters for convenience.
#
# **NOTE**: Some **subparameters** still need to be adjusted in the `create_model` function itself as of (Tue May 16 07:42:45 AM CEST 2023).

# %%
N_TRIALS = 250 # Number of trials for hyperparameter optimization
OPTIMIZE = False # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..
ZSCORE_NORMALIZATION = False # Whether to z-score normalize the input data.

# I try out here the values as obtained in Optuna run 5, but I will increase the number of epochs.
# N_LAYERS_NO_OPT = 3
# N_UNITS_NO_OPT = [78, 193, 99]
# HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
# OUTPUT_ACTIVATION_NAME_NO_OPT = "Linear"
# LOSS_NAME_NO_OPT = "MSE"
# OPTIMIZER_NAME_NO_OPT = "Adam"
# LR_NO_OPT = 0.00036516467819506355
# BATCH_SIZE_NO_OPT = 170
# N_EPOCHS_NO_OPT = 400
# SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

N_LAYERS_NO_OPT = 3
N_UNITS_NO_OPT = [555, 458, 115]
HIDDEN_ACTIVATION_NAME_NO_OPT = "ReLU"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "Huber"
OPTIMIZER_NAME_NO_OPT = "RMSprop"
LR_NO_OPT = 0.000122770896701404
BATCH_SIZE_NO_OPT = 49
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0.1, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0.1, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
vy_interval = (0.1, 0.721 * c) # Sampling interval for velocity in y-direction (used in sample_primitive_variables function)
vz_interval = (0.1, 0.721 * c) # Sampling interval for velocity in z-direction (used in sample_primitive_variables function)
epsilon_interval = (0.1, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)
SMALL_CONSTANT = 1e-8 # Small constant to avoid possible division by zero in the calculation of W.
FILTER_INFS = True # Whether to filter out infinities in the input data.
FILTER_INVALID_VALS = True # Whether to filter out infinities in the input data.
NAN_TO_NUM = True # Whether to replace NaNs with zeros in the input data.

np.random.seed(41) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have 
    # the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon



# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, vy, vz, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            vy is velocity in y-direction,
            vz is velocity in z-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst 
    # et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    vy = np.random.uniform(*vy_interval, size=n_samples)  # Velocity in y-direction
    vz = np.random.uniform(*vz_interval, size=n_samples)  # Velocity in z-direction 
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy


    if FILTER_INVALID_VALS:
        # Checking for other invalid values in the primitive variables using logical operators
        valid_mask = (rho > 0) & (vx < c) & (vy < c) & (vz < c) & (epsilon > 0)

        # Filtering out the invalid values using the valid_mask
        rho = rho[valid_mask]
        vx = vx[valid_mask]
        vy = vy[valid_mask]
        vz = vz[valid_mask]
        epsilon = epsilon[valid_mask]

    # Returning the primitive variables
    return rho, vx, vy, vz, epsilon



# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, vy, vz, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,)
        vy (torch.Tensor): The velocity in y-direction tensor of shape (n_samples,)
        vz (torch.Tensor): The velocity in z-direction tensor of shape (n_samples,)
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, Sy, Sz, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            Sy is conserved momentum in y-direction,
            Sz is conserved momentum in z-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

  # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    v2 = vx ** 2 + vy ** 2 + vz ** 2
    W = 1 / torch.sqrt(1 - v2 / c ** 2 + SMALL_CONSTANT)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    Sy = rho * h * W ** 2 * vy  # Conserved momentum in y-direction
    Sz = rho * h * W ** 2 * vz  # Conserved momentum in z-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, Sy, Sz, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, vy, vz, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    vy = torch.tensor(vy, dtype=torch.float32).to(device)
    vz = torch.tensor(vz, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    if FILTER_INFS:
        # Checking the validity of the primitive variables using torch.isfinite function
        valid_mask = torch.isfinite(rho) & torch.isfinite(vx) & torch.isfinite(vy) & torch.isfinite(vz)

        # Filtering out the invalid values using the valid_mask
        rho = rho[valid_mask]
        vx = vx[valid_mask]
        vy = vy[valid_mask]
        vz = vz[valid_mask]
        epsilon = epsilon[valid_mask]


    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, Sy, Sz, tau = compute_conserved_variables(rho, vx, vy, vz, epsilon) 

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, Sy, Sz, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    if FILTER_INFS:
        # Checking the validity of the primitive variables using torch.isfinite function
        valid_mask = torch.isfinite(rho) & torch.isfinite(epsilon)

        # Filtering out the invalid values using the valid_mask
        rho = rho[valid_mask]
        epsilon = epsilon[valid_mask]
   
    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %% [markdown]
# Sampling the primitive variables using the sample_primitive_variables function

# %%
rho_train, vx_train, vy_train, vz_train ,epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test ,vy_test ,vz_test ,epsilon_test = sample_primitive_variables(n_test_samples)

# %%
rho_train
vx_train
vy_train
vz_train 
epsilon_train
rho_test
vx_test 
vy_test 
vz_test 
epsilon_test
# Out:
# array([0.15502344, 0.12268782, 1.11552152, ..., 1.6177594 , 1.71402539,
#        0.44841102])

# %%
# TODO: Remove this if it is not needed. I mean I do it in the sample_primitive_variables function already, but I believe I stil got nan-values in test then, while now with this cell I do not any longer.
if FILTER_INVALID_VALS:
    # Sampling the primitive variables using the sample_primitive_variables function
    rho_train, vx_train, vy_train, vz_train ,epsilon_train = sample_primitive_variables(n_train_samples)
    rho_test, vx_test ,vy_test ,vz_test ,epsilon_test = sample_primitive_variables(n_test_samples)

    # Checking for other invalid values in the train set using logical operators
    valid_mask_train = (rho_train > 0) & (vx_train < c) & (vy_train < c) & (vz_train < c) & (epsilon_train > 0)

    # Filtering out the invalid values from the train set using the valid_mask
    rho_train = rho_train[valid_mask_train]
    vx_train = vx_train[valid_mask_train]
    vy_train = vy_train[valid_mask_train]
    vz_train = vz_train[valid_mask_train]
    epsilon_train = epsilon_train[valid_mask_train]

    # Checking for other invalid values in the test set using logical operators
    valid_mask_test = (rho_test > 0) & (vx_test < c) & (vy_test < c) & (vz_test < c) & (epsilon_test > 0)

    # Filtering out the invalid values from the test set using the valid_mask
    rho_test = rho_test[valid_mask_test]
    vx_test = vx_test[valid_mask_test]
    vy_test = vy_test[valid_mask_test]
    vz_test = vz_test[valid_mask_test]
    epsilon_test = epsilon_test[valid_mask_test]

    # Generating the input and output data for train and test sets.
    x_train = generate_input_data(rho_train ,vx_train ,vy_train, vz_train, epsilon_train)
    y_train = generate_labels(rho_train, epsilon_train) 
    x_test = generate_input_data(rho_test, vx_test, vy_test, vz_test, epsilon_test)
    y_test = generate_labels(rho_test, epsilon_test)

# %%
rho_train
vx_train
vy_train
vz_train 
epsilon_train
rho_test
vx_test 
vy_test 
vz_test 
epsilon_test
# Out:
# array([0.60791181, 0.97550387, 1.27596641, ..., 0.96730695, 0.49328435,
#        1.16435379])

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the histograms of rho, vx and epsilon
plt.figure(figsize=(16, 4))
plt.subplot(1, 5, 1)
plt.hist(rho_train, bins=20)
plt.xlabel("rho")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 5, 2)
plt.hist(vx_train, bins=20)
plt.xlabel("vx")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 5, 3)
plt.hist(vy_train, bins=20)
plt.xlabel("vy")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 5, 4)
plt.hist(vz_train, bins=20)
plt.xlabel("vz")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.subplot(1, 5, 5)
plt.hist(epsilon_train, bins=20)
plt.xlabel("epsilon")
plt.ylabel("Frequency")
#plt.yscale("log")
plt.suptitle("Primitive variables")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
# Generating the input and output data for train and test sets.
x_train = generate_input_data(rho_train, vx_train ,vy_train, vz_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, vy_test, vz_test, epsilon_test)
y_test = generate_labels(rho_test, epsilon_test)

# %%
x_train
y_train
x_test
y_test
# Out:
# tensor([[ 6.0072,  7.1436,  5.7178,  3.4958,  7.7803],
#         [ 2.0518,  1.0021,  3.8746,  0.8686,  4.2574],
#         [    nan,     nan,     nan,     nan,     nan],
#         ...,
#         [ 7.4774,  9.4220, 16.1935, 10.9508, 17.9820],
#         [12.6355, 18.5101, 30.7898, 45.0721, 48.9392],
#         [11.9450, 29.5190,  8.0415, 28.9164, 39.4901]], device='cuda:0')
# tensor([1.9993, 1.6254, 3.5986,  ..., 2.6313, 2.9344, 9.0354], device='cuda:0')
# tensor([[ 3.4228,  6.6900,  3.9172,  5.3593,  7.4334],
#         [ 1.2989,  0.4642,  1.4219,  2.4618,  2.5201],
#         [10.0171,  7.5512, 14.8620,  4.5838, 18.2978],
#         ...,
#         [ 1.9836,  0.8878,  4.5246,  1.5619,  4.1938],
#         [ 0.8111,  0.4035,  0.1678,  0.4802,  0.5590],
#         [    nan,     nan,     nan,     nan,     nan]], device='cuda:0')
# tensor([0.8187, 0.6453, 7.4599,  ..., 0.9323, 0.2442, 3.2426], device='cuda:0')

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting histograms of the input variables before z-score normalization
plt.figure(figsize=(10, 10))
plt.suptitle('Histograms of input variables before z-score normalization')
for i in range(5):
    plt.subplot(3, 2, i+1)
    plt.hist(x_train[:, i].cpu(), bins=50)
    plt.xlabel(f'Variable {i}')
plt.show()

# %%
# print('Summary statistics of input variables before z-score normalization')
# print(torch.stack([torch.min(x_train, dim=0).values,
#                 torch.max(x_train, dim=0).values,
#                 torch.mean(x_train, dim=0),
#                 torch.median(x_train, dim=0).values,
#                 torch.std(x_train, dim=0)], dim=1))

# Computing summary statistics of the input variables before and after z-score normalization
print('Summary statistics of input variables before z-score normalization')
print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.nanmean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))
# Out:
# Summary statistics of input variables before z-score normalization
# tensor([[    nan,     nan,  9.5943,     nan,     nan],
#         [    nan,     nan, 54.0834,     nan,     nan],
#         [    nan,     nan, 54.7718,     nan,     nan],
#         [    nan,     nan, 56.2176,     nan,     nan],
#         [    nan,     nan, 93.9981,     nan,     nan]], device='cuda:0')

# %%
if NAN_TO_NUM:
    # Replacing NaNs with zeros using torch.nan_to_num
    x_train = torch.nan_to_num(x_train)
    x_test = torch.nan_to_num(x_test) # replace NaNs with zeros

    print('Summary statistics of input variables before z-score normalization')
    print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.nanmean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))
# Out:
# Summary statistics of input variables before z-score normalization
# tensor([[0.0000e+00, 9.6148e+02, 8.8893e+00, 7.3836e+00, 1.2404e+01],
#         [0.0000e+00, 1.7103e+05, 5.0110e+01, 8.7975e+00, 1.1435e+03],
#         [0.0000e+00, 2.4170e+05, 5.0747e+01, 8.7208e+00, 1.1910e+03],
#         [0.0000e+00, 2.9575e+05, 5.2087e+01, 8.7281e+00, 1.4195e+03],
#         [0.0000e+00, 4.1754e+05, 8.7092e+01, 1.5938e+01, 2.1692e+03]],
#        device='cuda:0')

# %% [markdown]
# Perform z-score normalization

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %%
if ZSCORE_NORMALIZATION:
    
    # # Computing the median of each input variable from the training set using torch.nanmedian function
    # D_median = torch.nanmedian(x_train[:, 0])
    # Sx_median = torch.nanmedian(x_train[:, 1])
    # Sy_median = torch.nanmedian(x_train[:, 2])
    # Sz_median = torch.nanmedian(x_train[:, 3])
    # tau_median = torch.nanmedian(x_train[:, 4])

    # # Computing the standard deviation of each input variable from the training set using torch.std function with a boolean mask to ignore nan values
    # D_std = torch.std(x_train[~torch.isnan(x_train[:, 0]), 0])
    # Sx_std = torch.std(x_train[~torch.isnan(x_train[:, 1]), 1])
    # Sy_std = torch.std(x_train[~torch.isnan(x_train[:, 2]), 2])
    # Sz_std = torch.std(x_train[~torch.isnan(x_train[:, 3]), 3])
    # tau_std = torch.std(x_train[~torch.isnan(x_train[:, 4]), 4])


    # # Applying z-score normalization to both train and test sets using the statistics from the training set
    # x_train[:, 0] = torch.sub(x_train[:, 0], D_median).div(D_std)
    # x_train[:, 1] = torch.sub(x_train[:, 1], Sx_median).div(Sx_std)
    # x_train[:, 2] = torch.sub(x_train[:, 2], Sy_median).div(Sy_std)
    # x_train[:, 3] = torch.sub(x_train[:, 3], Sz_median).div(Sz_std)
    # x_train[:, 4] = torch.sub(x_train[:, 4], tau_median).div(tau_std)

    # x_test[:, 0] = torch.sub(x_test[:, 0], D_median).div(D_std)
    # x_test[:, 1] = torch.sub(x_test[:, 1], Sx_median).div(Sx_std)
    # x_test[:, 2] = torch.sub(x_test[:, 2], Sy_median).div(Sy_std)
    # x_test[:, 3] = torch.sub(x_test[:, 3], Sz_median).div(Sz_std)
    # x_test[:, 4] = torch.sub(x_test[:, 4], tau_median).div(tau_std)

    # Computing the mean and standard deviation of each column
    mean = x_train.mean(dim=0)
    std = x_train.std(dim=0)

    # Applying z-score normalization
    x_train = (x_train - mean) / std
    # Use the same mean and std from the training data as we don't want test data leakage.
    x_test = (x_test - mean) / std

# %%
torch.__version__
# Out:
# '2.0.0+cu118'

# %%
x_train[:, 0]
x_train.shape
x_train
x_test
# Out:
# tensor([ 6.0072,  2.0518,  0.0000,  ...,  7.4774, 12.6355, 11.9450],
#        device='cuda:0')
# torch.Size([80000, 5])
# tensor([[ 6.0072,  7.1436,  5.7178,  3.4958,  7.7803],
#         [ 2.0518,  1.0021,  3.8746,  0.8686,  4.2574],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         ...,
#         [ 7.4774,  9.4220, 16.1935, 10.9508, 17.9820],
#         [12.6355, 18.5101, 30.7898, 45.0721, 48.9392],
#         [11.9450, 29.5190,  8.0415, 28.9164, 39.4901]], device='cuda:0')
# tensor([[ 3.4228,  6.6900,  3.9172,  5.3593,  7.4334],
#         [ 1.2989,  0.4642,  1.4219,  2.4618,  2.5201],
#         [10.0171,  7.5512, 14.8620,  4.5838, 18.2978],
#         ...,
#         [ 1.9836,  0.8878,  4.5246,  1.5619,  4.1938],
#         [ 0.8111,  0.4035,  0.1678,  0.4802,  0.5590],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000]], device='cuda:0')

# %% [markdown]
# Plotting the histograms of the input data after normalization if z-score normalization was performed.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
if ZSCORE_NORMALIZATION: 
    # Plotting histograms of the input variables after z-score normalization
    plt.figure(figsize=(10, 10))
    plt.suptitle('Histograms of input variables after z-score normalization')
    for i in range(5):
        plt.subplot(3, 2, i+1)
        plt.hist(x_train[:, i], bins=50)
        plt.xlabel(f'Variable {i}')
    plt.show()

# %%
if ZSCORE_NORMALIZATION:
    # print('Summary statistics of input variables after z-score normalization')
    # print(torch.stack([torch.min(x_train, dim=0).values,
    #                 torch.max(x_train, dim=0).values,
    #                 torch.mean(x_train, dim=0),
    #                 torch.median(x_train, dim=0).values,
    #                 torch.std(x_train, dim=0)], dim=1))
    # Computing summary statistics of the input variables after z-score normalization
    print('Summary statistics of input variables after z-score normalization')
    print(torch.stack([torch.min(x_train, dim=0).values, torch.max(x_train, dim=0).values, torch.mean(x_train, dim=0), torch.median(x_train, dim=0).values, torch.std(x_train, dim=0)], dim=1))

# %% [markdown]
# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors

# %%
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20) # must be cpu here.
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.yscale("log")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20) # must be cpu here
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(5, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 5).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Adding an assertion to check that the input tensor has the expected shape and type
        assert isinstance(x, torch.Tensor), "x must be a torch.Tensor"
        assert x.shape[1] == 5, "x must have shape (batch_size, 5)"

        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 5)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 1048) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            #"output_activation", ["Linear", "ReLU", "Softplus"]
            # Assuming pressure cannot be negative, linear output activation is not an option.
            "output_activation", ["ReLU", "Softplus"]
        ) 
        loss_name = trial.suggest_categorical(
            #"loss", ["MSE", "MAE", "Huber", "LogCosh"] 
            "loss", ["MSE", "MAE", "Huber"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 16, 512)
        n_epochs = trial.suggest_int("n_epochs", 50, 200) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )

    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Softplus":
        output_activation = nn.Softplus()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    if optimize:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            # Added sampling the weight decay and momentum for SGD
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            momentum = trial.suggest_uniform("momentum", 0.0, 0.99)
            optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
        elif optimizer_name == "Adam":
            # Added sampling the weight decay and beta parameters for Adam
            weight_decay = trial.suggest_loguniform("weight_decay", 1e-5, 1e-2)
            beta1 = trial.suggest_uniform("beta1", 0.5, 0.99)
            beta2 = trial.suggest_uniform("beta2", 0.9, 0.999)
            optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay, betas=(beta1, beta2))
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            # Added sampling the step_size and gamma for StepLR
            step_size = trial.suggest_int("step_size", 5, 15)
            gamma = trial.suggest_uniform("gamma", 0.05, 0.5)
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
        elif scheduler_name == "ExponentialLR":
            # Added sampling the gamma for ExponentialLR
            gamma = trial.suggest_uniform("gamma", 0.8, 0.99)
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
        elif scheduler_name == "CosineAnnealingLR":
            # Added sampling the T_max for CosineAnnealingLR
            T_max = trial.suggest_int("T_max", 5, 15)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added sampling the factor, patience and threshold for ReduceLROnPlateau
            factor = trial.suggest_uniform("factor", 0.1, 0.9)
            patience = trial.suggest_int("patience", 5, 15)
            threshold = trial.suggest_loguniform("threshold", 1e-4, 1e-2)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode="min", factor=factor, patience=patience, threshold=threshold
            )
        # # Added using OneCycleLR scheduler as an option
        # elif scheduler_name == "OneCycleLR":
        #         # Added sampling the max_lr and pct_start for OneCycleLR
        #         max_lr = trial.suggest_loguniform("max_lr", lr, 10 * lr) 
        #         pct_start = trial.suggest_uniform("pct_start", 0.1, 0.9)
        #         scheduler = optim.lr_scheduler.OneCycleLR(
        #             optimizer,
        #             max_lr=max_lr,
        #             epochs=n_epochs,
        #             steps_per_epoch=len(train_loader),
        #             pct_start=pct_start,
        #         )
        else:
            scheduler = None
    else:
        # Creating the optimizer from its name
        if optimizer_name == "SGD":
            optimizer = optim.SGD(net.parameters(), lr=lr)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(net.parameters(), lr=lr)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(net.parameters(), lr=lr)
        else:
            # Added creating the Adagrad optimizer
            optimizer = optim.Adagrad(net.parameters(), lr=lr)

        # Creating the learning rate scheduler from its name
        if scheduler_name == "StepLR":
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        elif scheduler_name == "ExponentialLR":
            scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
        elif scheduler_name == "CosineAnnealingLR":
            # Added creating the CosineAnnealingLR scheduler
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
        elif scheduler_name == "ReduceLROnPlateau":
            # Added creating the ReduceLROnPlateau scheduler
            # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
            #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
            #)
            # Use Dieseldorst et al. settings and add to that a minimum lr.
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                        optimizer, mode="min", factor=0.18979341786654758, patience=11, threshold=0.0017197466122611932 #, min_lr=1e-6
                    )
        else:
            scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)
# Out:
# loss_fn: SmoothL1Loss()
# batch_size: 49
# n_epochs: 400
# scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7efe8c270a00>
# loss_name: Huber
# optimizer_name: RMSprop
# scheduler_name: ReduceLROnPlateau
# n_units: [555, 458, 115]
# n_layers: 3
# hidden_activation: ReLU()
# output_activation: ReLU()

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)
# Out:
# Epoch 1: Train Loss: 0.9100, Test Loss: 0.4402, Train L1 Norm: 0.7145, Test L1 Norm: 0.4565, Train Linf Norm: 13.0054, Test Linf Norm: 10.0540
# Epoch 2: Train Loss: 0.5885, Test Loss: 0.7167, Train L1 Norm: 0.4726, Test L1 Norm: 0.6461, Train Linf Norm: 8.8086, Test Linf Norm: 12.4769
# Epoch 3: Train Loss: 0.4987, Test Loss: 0.3232, Train L1 Norm: 0.4158, Test L1 Norm: 0.3640, Train Linf Norm: 7.9736, Test Linf Norm: 7.4221
# Epoch 4: Train Loss: 0.4680, Test Loss: 0.4033, Train L1 Norm: 0.3930, Test L1 Norm: 0.4238, Train Linf Norm: 7.4249, Test Linf Norm: 7.4152
# Epoch 5: Train Loss: 0.4216, Test Loss: 0.8216, Train L1 Norm: 0.3604, Test L1 Norm: 0.5796, Train Linf Norm: 7.1150, Test Linf Norm: 11.6747
# Epoch 6: Train Loss: 0.3884, Test Loss: 0.3059, Train L1 Norm: 0.3344, Test L1 Norm: 0.3164, Train Linf Norm: 6.9352, Test Linf Norm: 8.0856
# Epoch 7: Train Loss: 0.3499, Test Loss: 0.4161, Train L1 Norm: 0.3270, Test L1 Norm: 0.3092, Train Linf Norm: 6.8571, Test Linf Norm: 6.7622
# Epoch 8: Train Loss: 0.3391, Test Loss: 0.2919, Train L1 Norm: 0.3098, Test L1 Norm: 0.3183, Train Linf Norm: 6.7371, Test Linf Norm: 7.1146
# Epoch 9: Train Loss: 0.3371, Test Loss: 0.3091, Train L1 Norm: 0.3056, Test L1 Norm: 0.3625, Train Linf Norm: 6.6592, Test Linf Norm: 7.5788
# Epoch 10: Train Loss: 0.3034, Test Loss: 0.2874, Train L1 Norm: 0.2830, Test L1 Norm: 0.2708, Train Linf Norm: 6.4924, Test Linf Norm: 6.8105
# Epoch 11: Train Loss: 0.2997, Test Loss: 0.2446, Train L1 Norm: 0.2796, Test L1 Norm: 0.2773, Train Linf Norm: 6.4981, Test Linf Norm: 6.5611
# Epoch 12: Train Loss: 0.3034, Test Loss: 0.1970, Train L1 Norm: 0.2768, Test L1 Norm: 0.2376, Train Linf Norm: 6.6380, Test Linf Norm: 6.2995
# Epoch 13: Train Loss: 0.2920, Test Loss: 0.3127, Train L1 Norm: 0.2683, Test L1 Norm: 0.3379, Train Linf Norm: 6.2679, Test Linf Norm: 7.2182
# Epoch 14: Train Loss: 0.2793, Test Loss: 0.3858, Train L1 Norm: 0.2625, Test L1 Norm: 0.3351, Train Linf Norm: 6.2920, Test Linf Norm: 6.4212
# Epoch 15: Train Loss: 0.2655, Test Loss: 0.2120, Train L1 Norm: 0.2529, Test L1 Norm: 0.2715, Train Linf Norm: 6.1954, Test Linf Norm: 7.6048
# Epoch 16: Train Loss: 0.2597, Test Loss: 0.3897, Train L1 Norm: 0.2544, Test L1 Norm: 0.2870, Train Linf Norm: 6.3055, Test Linf Norm: 5.9893
# Epoch 17: Train Loss: 0.2510, Test Loss: 0.1989, Train L1 Norm: 0.2469, Test L1 Norm: 0.2280, Train Linf Norm: 6.1591, Test Linf Norm: 6.0678
# Epoch 18: Train Loss: 0.2428, Test Loss: 0.5326, Train L1 Norm: 0.2428, Test L1 Norm: 0.4178, Train Linf Norm: 6.1875, Test Linf Norm: 8.4033
# Epoch 19: Train Loss: 0.2464, Test Loss: 0.2465, Train L1 Norm: 0.2427, Test L1 Norm: 0.2626, Train Linf Norm: 6.1859, Test Linf Norm: 6.4437
# Epoch 20: Train Loss: 0.2352, Test Loss: 0.2147, Train L1 Norm: 0.2363, Test L1 Norm: 0.2630, Train Linf Norm: 6.0383, Test Linf Norm: 7.6224
# Epoch 21: Train Loss: 0.2458, Test Loss: 0.2982, Train L1 Norm: 0.2401, Test L1 Norm: 0.2558, Train Linf Norm: 6.0867, Test Linf Norm: 6.4479
# Epoch 22: Train Loss: 0.2389, Test Loss: 0.1962, Train L1 Norm: 0.2361, Test L1 Norm: 0.2316, Train Linf Norm: 6.0972, Test Linf Norm: 5.9435
# Epoch 23: Train Loss: 0.2429, Test Loss: 0.1881, Train L1 Norm: 0.2394, Test L1 Norm: 0.2125, Train Linf Norm: 6.1235, Test Linf Norm: 6.0283
# Epoch 24: Train Loss: 0.2369, Test Loss: 0.1921, Train L1 Norm: 0.2372, Test L1 Norm: 0.2313, Train Linf Norm: 6.1731, Test Linf Norm: 6.6918
# Epoch 25: Train Loss: 0.2389, Test Loss: 0.3830, Train L1 Norm: 0.2353, Test L1 Norm: 0.2772, Train Linf Norm: 6.0643, Test Linf Norm: 6.2175
# Epoch 26: Train Loss: 0.2347, Test Loss: 0.1862, Train L1 Norm: 0.2351, Test L1 Norm: 0.2425, Train Linf Norm: 6.0896, Test Linf Norm: 6.8178
# Epoch 27: Train Loss: 0.2374, Test Loss: 0.2791, Train L1 Norm: 0.2369, Test L1 Norm: 0.2906, Train Linf Norm: 6.0500, Test Linf Norm: 7.2937
# Epoch 28: Train Loss: 0.2267, Test Loss: 0.1898, Train L1 Norm: 0.2309, Test L1 Norm: 0.2401, Train Linf Norm: 6.0675, Test Linf Norm: 7.1557
# Epoch 29: Train Loss: 0.2354, Test Loss: 0.2767, Train L1 Norm: 0.2335, Test L1 Norm: 0.2336, Train Linf Norm: 6.0349, Test Linf Norm: 5.4831
# Epoch 30: Train Loss: 0.2402, Test Loss: 0.2961, Train L1 Norm: 0.2348, Test L1 Norm: 0.2843, Train Linf Norm: 6.0852, Test Linf Norm: 6.2496
# Epoch 31: Train Loss: 0.2277, Test Loss: 0.1893, Train L1 Norm: 0.2308, Test L1 Norm: 0.2158, Train Linf Norm: 5.9949, Test Linf Norm: 6.0521
# Epoch 32: Train Loss: 0.2198, Test Loss: 0.2820, Train L1 Norm: 0.2263, Test L1 Norm: 0.2531, Train Linf Norm: 5.9577, Test Linf Norm: 5.8139
# Epoch 33: Train Loss: 0.2225, Test Loss: 0.1942, Train L1 Norm: 0.2306, Test L1 Norm: 0.2205, Train Linf Norm: 6.1200, Test Linf Norm: 5.9813
# Epoch 34: Train Loss: 0.2218, Test Loss: 0.3508, Train L1 Norm: 0.2302, Test L1 Norm: 0.3075, Train Linf Norm: 6.0591, Test Linf Norm: 6.0610
# Epoch 35: Train Loss: 0.2226, Test Loss: 0.2059, Train L1 Norm: 0.2269, Test L1 Norm: 0.2374, Train Linf Norm: 6.1522, Test Linf Norm: 6.5189
# Epoch 36: Train Loss: 0.2132, Test Loss: 0.2435, Train L1 Norm: 0.2249, Test L1 Norm: 0.2519, Train Linf Norm: 6.0717, Test Linf Norm: 6.1827
# Epoch 37: Train Loss: 0.2123, Test Loss: 0.1880, Train L1 Norm: 0.2221, Test L1 Norm: 0.2156, Train Linf Norm: 6.0324, Test Linf Norm: 6.2225
# Epoch 38: Train Loss: 0.2219, Test Loss: 0.2146, Train L1 Norm: 0.2254, Test L1 Norm: 0.2331, Train Linf Norm: 6.0401, Test Linf Norm: 6.4899
# Epoch 39: Train Loss: 0.1690, Test Loss: 0.1722, Train L1 Norm: 0.1991, Test L1 Norm: 0.2018, Train Linf Norm: 5.8788, Test Linf Norm: 5.9693
# Epoch 40: Train Loss: 0.1646, Test Loss: 0.1591, Train L1 Norm: 0.1949, Test L1 Norm: 0.2040, Train Linf Norm: 5.8257, Test Linf Norm: 6.0770
# Epoch 41: Train Loss: 0.1620, Test Loss: 0.1571, Train L1 Norm: 0.1923, Test L1 Norm: 0.2065, Train Linf Norm: 5.7899, Test Linf Norm: 6.2835
# Epoch 42: Train Loss: 0.1622, Test Loss: 0.1567, Train L1 Norm: 0.1924, Test L1 Norm: 0.2032, Train Linf Norm: 5.8705, Test Linf Norm: 6.2326
# Epoch 43: Train Loss: 0.1644, Test Loss: 0.1577, Train L1 Norm: 0.1933, Test L1 Norm: 0.2028, Train Linf Norm: 5.8958, Test Linf Norm: 6.1214
# Epoch 44: Train Loss: 0.1613, Test Loss: 0.1572, Train L1 Norm: 0.1893, Test L1 Norm: 0.2015, Train Linf Norm: 5.8620, Test Linf Norm: 6.2894
# Epoch 45: Train Loss: 0.1596, Test Loss: 0.1577, Train L1 Norm: 0.1906, Test L1 Norm: 0.1993, Train Linf Norm: 5.8424, Test Linf Norm: 6.1612
# Epoch 46: Train Loss: 0.1607, Test Loss: 0.1654, Train L1 Norm: 0.1905, Test L1 Norm: 0.1935, Train Linf Norm: 5.9773, Test Linf Norm: 5.8650
# Epoch 47: Train Loss: 0.1593, Test Loss: 0.1611, Train L1 Norm: 0.1891, Test L1 Norm: 0.1954, Train Linf Norm: 5.8541, Test Linf Norm: 5.9811
# Epoch 48: Train Loss: 0.1590, Test Loss: 0.1648, Train L1 Norm: 0.1862, Test L1 Norm: 0.2095, Train Linf Norm: 5.8026, Test Linf Norm: 6.4139
# Epoch 49: Train Loss: 0.1608, Test Loss: 0.1590, Train L1 Norm: 0.1900, Test L1 Norm: 0.1973, Train Linf Norm: 5.9215, Test Linf Norm: 6.0886
# Epoch 50: Train Loss: 0.1619, Test Loss: 0.1646, Train L1 Norm: 0.1899, Test L1 Norm: 0.1974, Train Linf Norm: 5.9487, Test Linf Norm: 5.9738
# Epoch 51: Train Loss: 0.1657, Test Loss: 0.2095, Train L1 Norm: 0.1886, Test L1 Norm: 0.2155, Train Linf Norm: 5.9011, Test Linf Norm: 6.2320
# Epoch 52: Train Loss: 0.1624, Test Loss: 0.1541, Train L1 Norm: 0.1886, Test L1 Norm: 0.1913, Train Linf Norm: 5.8639, Test Linf Norm: 5.9642
# Epoch 53: Train Loss: 0.1583, Test Loss: 0.1623, Train L1 Norm: 0.1879, Test L1 Norm: 0.1955, Train Linf Norm: 5.8268, Test Linf Norm: 6.0315
# Epoch 54: Train Loss: 0.1594, Test Loss: 0.1579, Train L1 Norm: 0.1881, Test L1 Norm: 0.1958, Train Linf Norm: 5.8541, Test Linf Norm: 5.9850
# Epoch 55: Train Loss: 0.1596, Test Loss: 0.1759, Train L1 Norm: 0.1879, Test L1 Norm: 0.1984, Train Linf Norm: 5.8097, Test Linf Norm: 5.9586
# Epoch 56: Train Loss: 0.1592, Test Loss: 0.1571, Train L1 Norm: 0.1870, Test L1 Norm: 0.2011, Train Linf Norm: 5.8273, Test Linf Norm: 6.2651
# Epoch 57: Train Loss: 0.1591, Test Loss: 0.1620, Train L1 Norm: 0.1899, Test L1 Norm: 0.2015, Train Linf Norm: 5.9171, Test Linf Norm: 6.1119
# Epoch 58: Train Loss: 0.1588, Test Loss: 0.1574, Train L1 Norm: 0.1879, Test L1 Norm: 0.1915, Train Linf Norm: 5.8687, Test Linf Norm: 5.9322
# Epoch 59: Train Loss: 0.1582, Test Loss: 0.1801, Train L1 Norm: 0.1846, Test L1 Norm: 0.2292, Train Linf Norm: 5.7779, Test Linf Norm: 6.7034
# Epoch 60: Train Loss: 0.1577, Test Loss: 0.1646, Train L1 Norm: 0.1892, Test L1 Norm: 0.2003, Train Linf Norm: 5.9181, Test Linf Norm: 6.0868
# Epoch 61: Train Loss: 0.1578, Test Loss: 0.1541, Train L1 Norm: 0.1859, Test L1 Norm: 0.1917, Train Linf Norm: 5.8159, Test Linf Norm: 5.9623
# Epoch 62: Train Loss: 0.1591, Test Loss: 0.2216, Train L1 Norm: 0.1860, Test L1 Norm: 0.2288, Train Linf Norm: 5.7702, Test Linf Norm: 6.0731
# Epoch 63: Train Loss: 0.1570, Test Loss: 0.1862, Train L1 Norm: 0.1868, Test L1 Norm: 0.2113, Train Linf Norm: 5.8740, Test Linf Norm: 5.9172
# Epoch 64: Train Loss: 0.1596, Test Loss: 0.1597, Train L1 Norm: 0.1877, Test L1 Norm: 0.1895, Train Linf Norm: 5.8810, Test Linf Norm: 5.8313
# Epoch 65: Train Loss: 0.1491, Test Loss: 0.1547, Train L1 Norm: 0.1785, Test L1 Norm: 0.1896, Train Linf Norm: 5.6547, Test Linf Norm: 5.9323
# Epoch 66: Train Loss: 0.1480, Test Loss: 0.1533, Train L1 Norm: 0.1802, Test L1 Norm: 0.1893, Train Linf Norm: 5.8311, Test Linf Norm: 5.9475
# Epoch 67: Train Loss: 0.1476, Test Loss: 0.1549, Train L1 Norm: 0.1797, Test L1 Norm: 0.1897, Train Linf Norm: 5.8372, Test Linf Norm: 5.9634
# Epoch 68: Train Loss: 0.1471, Test Loss: 0.1541, Train L1 Norm: 0.1800, Test L1 Norm: 0.1893, Train Linf Norm: 5.8037, Test Linf Norm: 5.9383
# Epoch 69: Train Loss: 0.1471, Test Loss: 0.1545, Train L1 Norm: 0.1790, Test L1 Norm: 0.1918, Train Linf Norm: 5.7620, Test Linf Norm: 5.9969
# Epoch 70: Train Loss: 0.1468, Test Loss: 0.1539, Train L1 Norm: 0.1785, Test L1 Norm: 0.1929, Train Linf Norm: 5.8114, Test Linf Norm: 6.0608
# Epoch 71: Train Loss: 0.1466, Test Loss: 0.1546, Train L1 Norm: 0.1794, Test L1 Norm: 0.1918, Train Linf Norm: 5.8072, Test Linf Norm: 6.0352
# Epoch 72: Train Loss: 0.1468, Test Loss: 0.1537, Train L1 Norm: 0.1803, Test L1 Norm: 0.1923, Train Linf Norm: 5.8329, Test Linf Norm: 6.0494
# Epoch 73: Train Loss: 0.1465, Test Loss: 0.1544, Train L1 Norm: 0.1794, Test L1 Norm: 0.1909, Train Linf Norm: 5.6854, Test Linf Norm: 6.0207
# Epoch 74: Train Loss: 0.1466, Test Loss: 0.1544, Train L1 Norm: 0.1790, Test L1 Norm: 0.1922, Train Linf Norm: 5.7232, Test Linf Norm: 6.0399
# Epoch 75: Train Loss: 0.1464, Test Loss: 0.1519, Train L1 Norm: 0.1800, Test L1 Norm: 0.1898, Train Linf Norm: 5.7828, Test Linf Norm: 5.9821
# Epoch 76: Train Loss: 0.1465, Test Loss: 0.1537, Train L1 Norm: 0.1786, Test L1 Norm: 0.1906, Train Linf Norm: 5.7821, Test Linf Norm: 5.9900
# Epoch 77: Train Loss: 0.1465, Test Loss: 0.1527, Train L1 Norm: 0.1790, Test L1 Norm: 0.1903, Train Linf Norm: 5.7999, Test Linf Norm: 6.0036
# Epoch 78: Train Loss: 0.1464, Test Loss: 0.1518, Train L1 Norm: 0.1780, Test L1 Norm: 0.1906, Train Linf Norm: 5.7783, Test Linf Norm: 6.0077
# Epoch 79: Train Loss: 0.1465, Test Loss: 0.1561, Train L1 Norm: 0.1790, Test L1 Norm: 0.1930, Train Linf Norm: 5.8465, Test Linf Norm: 6.0287
# Epoch 80: Train Loss: 0.1466, Test Loss: 0.1506, Train L1 Norm: 0.1789, Test L1 Norm: 0.1896, Train Linf Norm: 5.8234, Test Linf Norm: 6.0053
# Epoch 81: Train Loss: 0.1459, Test Loss: 0.1534, Train L1 Norm: 0.1785, Test L1 Norm: 0.1930, Train Linf Norm: 5.7890, Test Linf Norm: 6.0466
# Epoch 82: Train Loss: 0.1463, Test Loss: 0.1535, Train L1 Norm: 0.1787, Test L1 Norm: 0.1914, Train Linf Norm: 5.8280, Test Linf Norm: 6.0327
# Epoch 83: Train Loss: 0.1463, Test Loss: 0.1519, Train L1 Norm: 0.1800, Test L1 Norm: 0.1889, Train Linf Norm: 5.8545, Test Linf Norm: 5.9725
# Epoch 84: Train Loss: 0.1462, Test Loss: 0.1529, Train L1 Norm: 0.1780, Test L1 Norm: 0.1898, Train Linf Norm: 5.7719, Test Linf Norm: 5.9906
# Epoch 85: Train Loss: 0.1461, Test Loss: 0.1511, Train L1 Norm: 0.1789, Test L1 Norm: 0.1886, Train Linf Norm: 5.8037, Test Linf Norm: 5.9551
# Epoch 86: Train Loss: 0.1462, Test Loss: 0.1528, Train L1 Norm: 0.1783, Test L1 Norm: 0.1889, Train Linf Norm: 5.8030, Test Linf Norm: 5.9488
# Epoch 87: Train Loss: 0.1460, Test Loss: 0.1540, Train L1 Norm: 0.1772, Test L1 Norm: 0.1913, Train Linf Norm: 5.7312, Test Linf Norm: 6.0240
# Epoch 88: Train Loss: 0.1458, Test Loss: 0.1563, Train L1 Norm: 0.1780, Test L1 Norm: 0.1928, Train Linf Norm: 5.7617, Test Linf Norm: 6.0781
# Epoch 89: Train Loss: 0.1460, Test Loss: 0.1508, Train L1 Norm: 0.1775, Test L1 Norm: 0.1909, Train Linf Norm: 5.7256, Test Linf Norm: 6.0576
# Epoch 90: Train Loss: 0.1460, Test Loss: 0.1512, Train L1 Norm: 0.1796, Test L1 Norm: 0.1896, Train Linf Norm: 5.8271, Test Linf Norm: 6.0171
# Epoch 91: Train Loss: 0.1460, Test Loss: 0.1513, Train L1 Norm: 0.1789, Test L1 Norm: 0.1899, Train Linf Norm: 5.8369, Test Linf Norm: 5.9873
# Epoch 92: Train Loss: 0.1462, Test Loss: 0.1517, Train L1 Norm: 0.1779, Test L1 Norm: 0.1897, Train Linf Norm: 5.8438, Test Linf Norm: 5.9875
# Epoch 93: Train Loss: 0.1441, Test Loss: 0.1507, Train L1 Norm: 0.1773, Test L1 Norm: 0.1895, Train Linf Norm: 5.7764, Test Linf Norm: 6.0003
# Epoch 94: Train Loss: 0.1439, Test Loss: 0.1505, Train L1 Norm: 0.1770, Test L1 Norm: 0.1893, Train Linf Norm: 5.7840, Test Linf Norm: 6.0005
# Epoch 95: Train Loss: 0.1439, Test Loss: 0.1510, Train L1 Norm: 0.1775, Test L1 Norm: 0.1897, Train Linf Norm: 5.7874, Test Linf Norm: 6.0111
# Epoch 96: Train Loss: 0.1438, Test Loss: 0.1501, Train L1 Norm: 0.1771, Test L1 Norm: 0.1890, Train Linf Norm: 5.7631, Test Linf Norm: 5.9896
# Epoch 97: Train Loss: 0.1438, Test Loss: 0.1502, Train L1 Norm: 0.1771, Test L1 Norm: 0.1891, Train Linf Norm: 5.8510, Test Linf Norm: 5.9938
# Epoch 98: Train Loss: 0.1437, Test Loss: 0.1520, Train L1 Norm: 0.1773, Test L1 Norm: 0.1903, Train Linf Norm: 5.7892, Test Linf Norm: 6.0113
# Epoch 99: Train Loss: 0.1437, Test Loss: 0.1503, Train L1 Norm: 0.1773, Test L1 Norm: 0.1892, Train Linf Norm: 5.6821, Test Linf Norm: 5.9970
# Epoch 100: Train Loss: 0.1437, Test Loss: 0.1506, Train L1 Norm: 0.1773, Test L1 Norm: 0.1892, Train Linf Norm: 5.7809, Test Linf Norm: 5.9942
# Epoch 101: Train Loss: 0.1437, Test Loss: 0.1502, Train L1 Norm: 0.1773, Test L1 Norm: 0.1890, Train Linf Norm: 5.6720, Test Linf Norm: 5.9896
# Epoch 102: Train Loss: 0.1436, Test Loss: 0.1499, Train L1 Norm: 0.1769, Test L1 Norm: 0.1887, Train Linf Norm: 5.7982, Test Linf Norm: 5.9873
# Epoch 103: Train Loss: 0.1436, Test Loss: 0.1502, Train L1 Norm: 0.1771, Test L1 Norm: 0.1890, Train Linf Norm: 5.8248, Test Linf Norm: 5.9866
# Epoch 104: Train Loss: 0.1437, Test Loss: 0.1506, Train L1 Norm: 0.1768, Test L1 Norm: 0.1894, Train Linf Norm: 5.7213, Test Linf Norm: 5.9956
# Epoch 105: Train Loss: 0.1436, Test Loss: 0.1498, Train L1 Norm: 0.1771, Test L1 Norm: 0.1890, Train Linf Norm: 5.8653, Test Linf Norm: 5.9858
# Epoch 106: Train Loss: 0.1436, Test Loss: 0.1498, Train L1 Norm: 0.1771, Test L1 Norm: 0.1888, Train Linf Norm: 5.7375, Test Linf Norm: 5.9831
# Epoch 107: Train Loss: 0.1436, Test Loss: 0.1500, Train L1 Norm: 0.1770, Test L1 Norm: 0.1887, Train Linf Norm: 5.7907, Test Linf Norm: 5.9869
# Epoch 108: Train Loss: 0.1436, Test Loss: 0.1500, Train L1 Norm: 0.1772, Test L1 Norm: 0.1887, Train Linf Norm: 5.8560, Test Linf Norm: 5.9846
# Epoch 109: Train Loss: 0.1436, Test Loss: 0.1502, Train L1 Norm: 0.1769, Test L1 Norm: 0.1889, Train Linf Norm: 5.7550, Test Linf Norm: 5.9855
# Epoch 110: Train Loss: 0.1436, Test Loss: 0.1500, Train L1 Norm: 0.1770, Test L1 Norm: 0.1889, Train Linf Norm: 5.8575, Test Linf Norm: 5.9875
# Epoch 111: Train Loss: 0.1436, Test Loss: 0.1506, Train L1 Norm: 0.1769, Test L1 Norm: 0.1894, Train Linf Norm: 5.8433, Test Linf Norm: 5.9980
# Epoch 112: Train Loss: 0.1435, Test Loss: 0.1502, Train L1 Norm: 0.1770, Test L1 Norm: 0.1888, Train Linf Norm: 5.7301, Test Linf Norm: 5.9809
# Epoch 113: Train Loss: 0.1435, Test Loss: 0.1501, Train L1 Norm: 0.1769, Test L1 Norm: 0.1888, Train Linf Norm: 5.7588, Test Linf Norm: 5.9870
# Epoch 114: Train Loss: 0.1434, Test Loss: 0.1517, Train L1 Norm: 0.1770, Test L1 Norm: 0.1899, Train Linf Norm: 5.8192, Test Linf Norm: 6.0020
# Epoch 115: Train Loss: 0.1437, Test Loss: 0.1501, Train L1 Norm: 0.1768, Test L1 Norm: 0.1889, Train Linf Norm: 5.8446, Test Linf Norm: 5.9879
# Epoch 116: Train Loss: 0.1435, Test Loss: 0.1504, Train L1 Norm: 0.1768, Test L1 Norm: 0.1890, Train Linf Norm: 5.7216, Test Linf Norm: 5.9893
# Epoch 117: Train Loss: 0.1435, Test Loss: 0.1498, Train L1 Norm: 0.1769, Test L1 Norm: 0.1887, Train Linf Norm: 5.7787, Test Linf Norm: 5.9816
# Epoch 118: Train Loss: 0.1431, Test Loss: 0.1498, Train L1 Norm: 0.1767, Test L1 Norm: 0.1887, Train Linf Norm: 5.7240, Test Linf Norm: 5.9813
# Epoch 119: Train Loss: 0.1431, Test Loss: 0.1500, Train L1 Norm: 0.1767, Test L1 Norm: 0.1888, Train Linf Norm: 5.7693, Test Linf Norm: 5.9860
# Epoch 120: Train Loss: 0.1431, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8484, Test Linf Norm: 5.9845
# Epoch 121: Train Loss: 0.1431, Test Loss: 0.1499, Train L1 Norm: 0.1767, Test L1 Norm: 0.1888, Train Linf Norm: 5.8375, Test Linf Norm: 5.9843
# Epoch 122: Train Loss: 0.1431, Test Loss: 0.1499, Train L1 Norm: 0.1767, Test L1 Norm: 0.1887, Train Linf Norm: 5.7959, Test Linf Norm: 5.9835
# Epoch 123: Train Loss: 0.1431, Test Loss: 0.1501, Train L1 Norm: 0.1767, Test L1 Norm: 0.1889, Train Linf Norm: 5.7671, Test Linf Norm: 5.9888
# Epoch 124: Train Loss: 0.1431, Test Loss: 0.1503, Train L1 Norm: 0.1767, Test L1 Norm: 0.1889, Train Linf Norm: 5.7601, Test Linf Norm: 5.9887
# Epoch 125: Train Loss: 0.1431, Test Loss: 0.1502, Train L1 Norm: 0.1767, Test L1 Norm: 0.1888, Train Linf Norm: 5.8068, Test Linf Norm: 5.9860
# Epoch 126: Train Loss: 0.1431, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7996, Test Linf Norm: 5.9846
# Epoch 127: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7200, Test Linf Norm: 5.9834
# Epoch 128: Train Loss: 0.1431, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7956, Test Linf Norm: 5.9859
# Epoch 129: Train Loss: 0.1431, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7284, Test Linf Norm: 5.9830
# Epoch 130: Train Loss: 0.1430, Test Loss: 0.1502, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8428, Test Linf Norm: 5.9865
# Epoch 131: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7495, Test Linf Norm: 5.9858
# Epoch 132: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7469, Test Linf Norm: 5.9853
# Epoch 133: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8056, Test Linf Norm: 5.9851
# Epoch 134: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7723, Test Linf Norm: 5.9855
# Epoch 135: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7633, Test Linf Norm: 5.9851
# Epoch 136: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8531, Test Linf Norm: 5.9863
# Epoch 137: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8175, Test Linf Norm: 5.9853
# Epoch 138: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7828, Test Linf Norm: 5.9848
# Epoch 139: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7644, Test Linf Norm: 5.9852
# Epoch 140: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7980, Test Linf Norm: 5.9836
# Epoch 141: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7608, Test Linf Norm: 5.9859
# Epoch 142: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8236, Test Linf Norm: 5.9856
# Epoch 143: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7873, Test Linf Norm: 5.9855
# Epoch 144: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7696, Test Linf Norm: 5.9855
# Epoch 145: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6504, Test Linf Norm: 5.9855
# Epoch 146: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8131, Test Linf Norm: 5.9854
# Epoch 147: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8271, Test Linf Norm: 5.9854
# Epoch 148: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7771, Test Linf Norm: 5.9855
# Epoch 149: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8108, Test Linf Norm: 5.9856
# Epoch 150: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7920, Test Linf Norm: 5.9856
# Epoch 151: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7541, Test Linf Norm: 5.9852
# Epoch 152: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7682, Test Linf Norm: 5.9854
# Epoch 153: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8332, Test Linf Norm: 5.9855
# Epoch 154: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7184, Test Linf Norm: 5.9853
# Epoch 155: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7216, Test Linf Norm: 5.9852
# Epoch 156: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7811, Test Linf Norm: 5.9853
# Epoch 157: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7603, Test Linf Norm: 5.9854
# Epoch 158: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7988, Test Linf Norm: 5.9854
# Epoch 159: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7898, Test Linf Norm: 5.9853
# Epoch 160: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7356, Test Linf Norm: 5.9853
# Epoch 161: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8065, Test Linf Norm: 5.9850
# Epoch 162: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7028, Test Linf Norm: 5.9853
# Epoch 163: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7524, Test Linf Norm: 5.9851
# Epoch 164: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7573, Test Linf Norm: 5.9850
# Epoch 165: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8062, Test Linf Norm: 5.9852
# Epoch 166: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6875, Test Linf Norm: 5.9855
# Epoch 167: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6951, Test Linf Norm: 5.9855
# Epoch 168: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8370, Test Linf Norm: 5.9853
# Epoch 169: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7851, Test Linf Norm: 5.9852
# Epoch 170: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8739, Test Linf Norm: 5.9853
# Epoch 171: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7071, Test Linf Norm: 5.9852
# Epoch 172: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7787, Test Linf Norm: 5.9851
# Epoch 173: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8189, Test Linf Norm: 5.9853
# Epoch 174: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7594, Test Linf Norm: 5.9853
# Epoch 175: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7671, Test Linf Norm: 5.9855
# Epoch 176: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7959, Test Linf Norm: 5.9854
# Epoch 177: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7968, Test Linf Norm: 5.9855
# Epoch 178: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7885, Test Linf Norm: 5.9852
# Epoch 179: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8544, Test Linf Norm: 5.9853
# Epoch 180: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8739, Test Linf Norm: 5.9854
# Epoch 181: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8599, Test Linf Norm: 5.9854
# Epoch 182: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8687, Test Linf Norm: 5.9855
# Epoch 183: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8276, Test Linf Norm: 5.9856
# Epoch 184: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7758, Test Linf Norm: 5.9854
# Epoch 185: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7875, Test Linf Norm: 5.9859
# Epoch 186: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7293, Test Linf Norm: 5.9858
# Epoch 187: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8212, Test Linf Norm: 5.9854
# Epoch 188: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8059, Test Linf Norm: 5.9854
# Epoch 189: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7871, Test Linf Norm: 5.9855
# Epoch 190: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7703, Test Linf Norm: 5.9854
# Epoch 191: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8208, Test Linf Norm: 5.9854
# Epoch 192: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7658, Test Linf Norm: 5.9856
# Epoch 193: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7774, Test Linf Norm: 5.9854
# Epoch 194: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7643, Test Linf Norm: 5.9853
# Epoch 195: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8814, Test Linf Norm: 5.9854
# Epoch 196: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7457, Test Linf Norm: 5.9853
# Epoch 197: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6958, Test Linf Norm: 5.9852
# Epoch 198: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8391, Test Linf Norm: 5.9851
# Epoch 199: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7682, Test Linf Norm: 5.9855
# Epoch 200: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7848, Test Linf Norm: 5.9853
# Epoch 201: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7940, Test Linf Norm: 5.9853
# Epoch 202: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8548, Test Linf Norm: 5.9852
# Epoch 203: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7352, Test Linf Norm: 5.9852
# Epoch 204: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8145, Test Linf Norm: 5.9853
# Epoch 205: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7940, Test Linf Norm: 5.9854
# Epoch 206: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7323, Test Linf Norm: 5.9852
# Epoch 207: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7193, Test Linf Norm: 5.9855
# Epoch 208: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8502, Test Linf Norm: 5.9855
# Epoch 209: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7726, Test Linf Norm: 5.9854
# Epoch 210: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7952, Test Linf Norm: 5.9857
# Epoch 211: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7792, Test Linf Norm: 5.9853
# Epoch 212: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7630, Test Linf Norm: 5.9854
# Epoch 213: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8007, Test Linf Norm: 5.9855
# Epoch 214: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8432, Test Linf Norm: 5.9855
# Epoch 215: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7803, Test Linf Norm: 5.9855
# Epoch 216: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7850, Test Linf Norm: 5.9854
# Epoch 217: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8234, Test Linf Norm: 5.9855
# Epoch 218: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7944, Test Linf Norm: 5.9854
# Epoch 219: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8113, Test Linf Norm: 5.9855
# Epoch 220: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7416, Test Linf Norm: 5.9854
# Epoch 221: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7881, Test Linf Norm: 5.9853
# Epoch 222: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6962, Test Linf Norm: 5.9853
# Epoch 223: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7504, Test Linf Norm: 5.9853
# Epoch 224: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7590, Test Linf Norm: 5.9855
# Epoch 225: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7937, Test Linf Norm: 5.9855
# Epoch 226: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7398, Test Linf Norm: 5.9855
# Epoch 227: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8174, Test Linf Norm: 5.9852
# Epoch 228: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7885, Test Linf Norm: 5.9855
# Epoch 229: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8262, Test Linf Norm: 5.9856
# Epoch 230: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8674, Test Linf Norm: 5.9854
# Epoch 231: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8004, Test Linf Norm: 5.9850
# Epoch 232: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7817, Test Linf Norm: 5.9853
# Epoch 233: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7885, Test Linf Norm: 5.9853
# Epoch 234: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8156, Test Linf Norm: 5.9853
# Epoch 235: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7824, Test Linf Norm: 5.9852
# Epoch 236: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6967, Test Linf Norm: 5.9854
# Epoch 237: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8257, Test Linf Norm: 5.9855
# Epoch 238: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7669, Test Linf Norm: 5.9854
# Epoch 239: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7857, Test Linf Norm: 5.9852
# Epoch 240: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8369, Test Linf Norm: 5.9854
# Epoch 241: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7854, Test Linf Norm: 5.9853
# Epoch 242: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7559, Test Linf Norm: 5.9853
# Epoch 243: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6862, Test Linf Norm: 5.9853
# Epoch 244: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8448, Test Linf Norm: 5.9853
# Epoch 245: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7663, Test Linf Norm: 5.9855
# Epoch 246: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7569, Test Linf Norm: 5.9853
# Epoch 247: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7885, Test Linf Norm: 5.9855
# Epoch 248: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7360, Test Linf Norm: 5.9853
# Epoch 249: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7576, Test Linf Norm: 5.9854
# Epoch 250: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8457, Test Linf Norm: 5.9851
# Epoch 251: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8168, Test Linf Norm: 5.9854
# Epoch 252: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8529, Test Linf Norm: 5.9854
# Epoch 253: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8137, Test Linf Norm: 5.9859
# Epoch 254: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6693, Test Linf Norm: 5.9854
# Epoch 255: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.6802, Test Linf Norm: 5.9854
# Epoch 256: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8157, Test Linf Norm: 5.9852
# Epoch 257: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7691, Test Linf Norm: 5.9850
# Epoch 258: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7615, Test Linf Norm: 5.9853
# Epoch 259: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7393, Test Linf Norm: 5.9852
# Epoch 260: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8661, Test Linf Norm: 5.9854
# Epoch 261: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7873, Test Linf Norm: 5.9854
# Epoch 262: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8156, Test Linf Norm: 5.9853
# Epoch 263: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6969, Test Linf Norm: 5.9853
# Epoch 264: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7396, Test Linf Norm: 5.9855
# Epoch 265: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7329, Test Linf Norm: 5.9857
# Epoch 266: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8074, Test Linf Norm: 5.9855
# Epoch 267: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7691, Test Linf Norm: 5.9853
# Epoch 268: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7305, Test Linf Norm: 5.9854
# Epoch 269: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7118, Test Linf Norm: 5.9855
# Epoch 270: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8156, Test Linf Norm: 5.9856
# Epoch 271: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7256, Test Linf Norm: 5.9855
# Epoch 272: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7901, Test Linf Norm: 5.9855
# Epoch 273: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7625, Test Linf Norm: 5.9855
# Epoch 274: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7664, Test Linf Norm: 5.9855
# Epoch 275: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7456, Test Linf Norm: 5.9853
# Epoch 276: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8119, Test Linf Norm: 5.9853
# Epoch 277: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8335, Test Linf Norm: 5.9852
# Epoch 278: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7796, Test Linf Norm: 5.9854
# Epoch 279: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7143, Test Linf Norm: 5.9855
# Epoch 280: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7821, Test Linf Norm: 5.9852
# Epoch 281: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8690, Test Linf Norm: 5.9851
# Epoch 282: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7753, Test Linf Norm: 5.9854
# Epoch 283: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7366, Test Linf Norm: 5.9855
# Epoch 284: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7588, Test Linf Norm: 5.9855
# Epoch 285: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7226, Test Linf Norm: 5.9854
# Epoch 286: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7453, Test Linf Norm: 5.9854
# Epoch 287: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7634, Test Linf Norm: 5.9855
# Epoch 288: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7827, Test Linf Norm: 5.9855
# Epoch 289: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7789, Test Linf Norm: 5.9854
# Epoch 290: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8123, Test Linf Norm: 5.9854
# Epoch 291: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7979, Test Linf Norm: 5.9857
# Epoch 292: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7875, Test Linf Norm: 5.9858
# Epoch 293: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7621, Test Linf Norm: 5.9857
# Epoch 294: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8160, Test Linf Norm: 5.9860
# Epoch 295: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8204, Test Linf Norm: 5.9859
# Epoch 296: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7506, Test Linf Norm: 5.9855
# Epoch 297: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7201, Test Linf Norm: 5.9855
# Epoch 298: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8350, Test Linf Norm: 5.9854
# Epoch 299: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7972, Test Linf Norm: 5.9854
# Epoch 300: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8023, Test Linf Norm: 5.9856
# Epoch 301: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7564, Test Linf Norm: 5.9855
# Epoch 302: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8160, Test Linf Norm: 5.9855
# Epoch 303: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8046, Test Linf Norm: 5.9857
# Epoch 304: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7344, Test Linf Norm: 5.9858
# Epoch 305: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.8445, Test Linf Norm: 5.9857
# Epoch 306: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8378, Test Linf Norm: 5.9855
# Epoch 307: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7771, Test Linf Norm: 5.9855
# Epoch 308: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8073, Test Linf Norm: 5.9856
# Epoch 309: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7980, Test Linf Norm: 5.9855
# Epoch 310: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7737, Test Linf Norm: 5.9855
# Epoch 311: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7503, Test Linf Norm: 5.9855
# Epoch 312: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7999, Test Linf Norm: 5.9854
# Epoch 313: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7767, Test Linf Norm: 5.9853
# Epoch 314: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7175, Test Linf Norm: 5.9852
# Epoch 315: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7467, Test Linf Norm: 5.9854
# Epoch 316: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7710, Test Linf Norm: 5.9859
# Epoch 317: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1888, Train Linf Norm: 5.7493, Test Linf Norm: 5.9858
# Epoch 318: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8493, Test Linf Norm: 5.9856
# Epoch 319: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7776, Test Linf Norm: 5.9853
# Epoch 320: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7819, Test Linf Norm: 5.9854
# Epoch 321: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7397, Test Linf Norm: 5.9853
# Epoch 322: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7235, Test Linf Norm: 5.9853
# Epoch 323: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8246, Test Linf Norm: 5.9854
# Epoch 324: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7579, Test Linf Norm: 5.9852
# Epoch 325: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8362, Test Linf Norm: 5.9855
# Epoch 326: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6804, Test Linf Norm: 5.9853
# Epoch 327: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8480, Test Linf Norm: 5.9854
# Epoch 328: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7887, Test Linf Norm: 5.9856
# Epoch 329: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7881, Test Linf Norm: 5.9856
# Epoch 330: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7713, Test Linf Norm: 5.9857
# Epoch 331: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8293, Test Linf Norm: 5.9854
# Epoch 332: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7678, Test Linf Norm: 5.9857
# Epoch 333: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7497, Test Linf Norm: 5.9855
# Epoch 334: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7662, Test Linf Norm: 5.9854
# Epoch 335: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8099, Test Linf Norm: 5.9854
# Epoch 336: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7810, Test Linf Norm: 5.9854
# Epoch 337: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8510, Test Linf Norm: 5.9853
# Epoch 338: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7620, Test Linf Norm: 5.9855
# Epoch 339: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7938, Test Linf Norm: 5.9855
# Epoch 340: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6465, Test Linf Norm: 5.9855
# Epoch 341: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8363, Test Linf Norm: 5.9856
# Epoch 342: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7548, Test Linf Norm: 5.9855
# Epoch 343: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8030, Test Linf Norm: 5.9852
# Epoch 344: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7629, Test Linf Norm: 5.9854
# Epoch 345: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8053, Test Linf Norm: 5.9854
# Epoch 346: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7249, Test Linf Norm: 5.9852
# Epoch 347: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8223, Test Linf Norm: 5.9856
# Epoch 348: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8543, Test Linf Norm: 5.9852
# Epoch 349: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8036, Test Linf Norm: 5.9854
# Epoch 350: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8326, Test Linf Norm: 5.9855
# Epoch 351: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7415, Test Linf Norm: 5.9857
# Epoch 352: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8055, Test Linf Norm: 5.9856
# Epoch 353: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7707, Test Linf Norm: 5.9856
# Epoch 354: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7556, Test Linf Norm: 5.9857
# Epoch 355: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7853, Test Linf Norm: 5.9854
# Epoch 356: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8110, Test Linf Norm: 5.9856
# Epoch 357: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8192, Test Linf Norm: 5.9856
# Epoch 358: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7923, Test Linf Norm: 5.9856
# Epoch 359: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8304, Test Linf Norm: 5.9854
# Epoch 360: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6573, Test Linf Norm: 5.9856
# Epoch 361: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7035, Test Linf Norm: 5.9855
# Epoch 362: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.6821, Test Linf Norm: 5.9855
# Epoch 363: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7493, Test Linf Norm: 5.9854
# Epoch 364: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8053, Test Linf Norm: 5.9854
# Epoch 365: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7630, Test Linf Norm: 5.9853
# Epoch 366: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8093, Test Linf Norm: 5.9853
# Epoch 367: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7936, Test Linf Norm: 5.9851
# Epoch 368: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8315, Test Linf Norm: 5.9853
# Epoch 369: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8054, Test Linf Norm: 5.9852
# Epoch 370: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8658, Test Linf Norm: 5.9853
# Epoch 371: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7763, Test Linf Norm: 5.9854
# Epoch 372: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8248, Test Linf Norm: 5.9855
# Epoch 373: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7249, Test Linf Norm: 5.9853
# Epoch 374: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7014, Test Linf Norm: 5.9853
# Epoch 375: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8323, Test Linf Norm: 5.9856
# Epoch 376: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7741, Test Linf Norm: 5.9854
# Epoch 377: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8430, Test Linf Norm: 5.9856
# Epoch 378: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7601, Test Linf Norm: 5.9855
# Epoch 379: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7292, Test Linf Norm: 5.9854
# Epoch 380: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7630, Test Linf Norm: 5.9855
# Epoch 381: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7183, Test Linf Norm: 5.9855
# Epoch 382: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8029, Test Linf Norm: 5.9854
# Epoch 383: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7698, Test Linf Norm: 5.9857
# Epoch 384: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7560, Test Linf Norm: 5.9858
# Epoch 385: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8219, Test Linf Norm: 5.9856
# Epoch 386: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7606, Test Linf Norm: 5.9854
# Epoch 387: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7310, Test Linf Norm: 5.9851
# Epoch 388: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7738, Test Linf Norm: 5.9853
# Epoch 389: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7892, Test Linf Norm: 5.9854
# Epoch 390: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7243, Test Linf Norm: 5.9857
# Epoch 391: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7377, Test Linf Norm: 5.9855
# Epoch 392: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7907, Test Linf Norm: 5.9855
# Epoch 393: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7779, Test Linf Norm: 5.9855
# Epoch 394: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7466, Test Linf Norm: 5.9855
# Epoch 395: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7765, Test Linf Norm: 5.9853
# Epoch 396: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7759, Test Linf Norm: 5.9851
# Epoch 397: Train Loss: 0.1430, Test Loss: 0.1501, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8155, Test Linf Norm: 5.9856
# Epoch 398: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7845, Test Linf Norm: 5.9854
# Epoch 399: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.8473, Test Linf Norm: 5.9851
# Epoch 400: Train Loss: 0.1430, Test Loss: 0.1500, Train L1 Norm: 0.1766, Test L1 Norm: 0.1887, Train Linf Norm: 5.7670, Test Linf Norm: 5.9854

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")
save_file("net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")
save_file("optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")
  save_file("scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)
save_file("var_dict.json")

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)
save_file("train_output.csv")

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
#plt.subplot(2, 2, 1)
#plt.plot(train_losses, label="Train Loss")
#plt.plot(test_losses, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()
# Out:
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'L1 Norm')
# (0.001, 100.0)
# <Axes: >
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Linf Norm')
# (0.001, 100.0)
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'MSE')
# (1e-07, 1.0)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
    output_activation_loaded = nn.ReLU()
elif output_activation_name_loaded == "Softplus":
    output_activation_loaded = nn.Softplus()
else:
    output_activation_loaded = nn.Identity()



# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
if torch.cuda.is_available():
 net_loaded.load_state_dict(torch.load("net.pth"))
else: 
  net_loaded.load_state_dict(torch.load("net.pth", map_location=torch.device('cpu')))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if torch.cuda.is_available():
  optimizer_loaded_state_dict = torch.load("optimizer.pth")
else:
  optimizer_loaded_state_dict = torch.load("optimizer.pth", map_location=torch.device('cpu'))

if optimizer_name_loaded == "SGD":
  # Added getting the weight decay and momentum parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  momentum_loaded = optimizer_loaded_state_dict["param_groups"][0]["momentum"]
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, momentum=momentum_loaded)
elif optimizer_name_loaded == "Adam":
  # Added getting the weight decay and beta parameters from the state dict
  weight_decay_loaded = optimizer_loaded_state_dict["param_groups"][0]["weight_decay"]
  beta1_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][0]
  beta2_loaded = optimizer_loaded_state_dict["param_groups"][0]["betas"][1]
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded, weight_decay=weight_decay_loaded, betas=(beta1_loaded, beta2_loaded))
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(optimizer_loaded_state_dict)

# load the scheduler from the .pth file
if torch.cuda.is_available():
  scheduler_loaded_state_dict = torch.load("scheduler.pth")
else: 
  scheduler_loaded_state_dict = torch.load("scheduler.pth", map_location=torch.device('cpu'))

if scheduler_name_loaded == "StepLR":
  # Added getting the step_size and gamma parameters from the state dict
  step_size_loaded = scheduler_loaded_state_dict["step_size"]
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=step_size_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "ExponentialLR":
  # Added getting the gamma parameter from the state dict
  gamma_loaded = scheduler_loaded_state_dict["gamma"]
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=gamma_loaded)
elif scheduler_name_loaded == "CosineAnnealingLR":
  # Added getting the T_max parameter from the state dict
  T_max_loaded = scheduler_loaded_state_dict["T_max"]
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=T_max_loaded)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  # Added getting the mode, factor, patience, threshold and min_lr parameters from the state dict
  mode_loaded = scheduler_loaded_state_dict["mode"]
  factor_loaded = scheduler_loaded_state_dict["factor"]
  patience_loaded = scheduler_loaded_state_dict["patience"]
  threshold_loaded = scheduler_loaded_state_dict["threshold"]
  min_lr_loaded = scheduler_loaded_state_dict["min_lrs"][0]
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode=mode_loaded, factor=factor_loaded, patience=patience_loaded, threshold=threshold_loaded, min_lr=min_lr_loaded
                )
# elif scheduler_name_loaded == "OneCycleLR":
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   epochs_loaded = scheduler_loaded_state_dict["epochs"]
#   steps_per_epoch_loaded = scheduler_loaded_state_dict["steps_per_epoch"]
#   pct_start_loaded = scheduler_loaded_state_dict["pct_start"]
#   max_lr_loaded = scheduler_loaded_state_dict["max_lr"]
#   scheduler_loaded = optim.lr_scheduler.OneCycleLR(
#                     optimizer_loaded, max_lr=max_lr_loaded, epochs=epochs_loaded, steps_per_epoch=steps_per_epoch_loaded, pct_start=pct_start_loaded
#                 )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  # Added loading the state dict to the scheduler_loaded
  scheduler_loaded.load_state_dict(scheduler_loaded_state_dict)

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
# Out:
# <All keys matched successfully>

# %%
#%%script echo skipping

batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
net_loaded.__dict__ # print the subparameters of the network
loss_fn_loaded
optimizer_loaded
optimizer_loaded.__dict__ # print the subparameters of the optimizer
scheduler_loaded
scheduler_loaded.__dict__ # print the subparameters of the scheduler
train_losses_loaded
test_losses_loaded
train_metrics_loaded
test_metrics_loaded
# Out:
# 49
# 400
# 'Huber'
# 'RMSprop'
# 'ReduceLROnPlateau'
# [555, 458, 115]
# 3
# 'ReLU'
# 'ReLU'
# 0.000122770896701404
# ReLU()
# ReLU()
# Net(
#   (hidden_activation): ReLU()
#   (output_activation): ReLU()
#   (layers): ModuleList(
#     (0): Linear(in_features=5, out_features=555, bias=True)
#     (1): Linear(in_features=555, out_features=458, bias=True)
#     (2): Linear(in_features=458, out_features=115, bias=True)
#     (3): Linear(in_features=115, out_features=1, bias=True)
#   )
# )
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('hidden_activation', ReLU()),
#               ('output_activation', ReLU()),
#               ('layers',
#                ModuleList(
#                  (0): Linear(in_features=5, out_features=555, bias=True)
#                  (1): Linear(in_features=555, out_features=458, bias=True)
#                  (2): Linear(in_features=458, out_features=115, bias=True)
#                  (3): Linear(in_features=115, out_features=1, bias=True)
#                ))]),
#  'n_layers': 3,
#  'n_units': [555, 458, 115]}
# SmoothL1Loss()
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 5.738287568126183e-09
#     maximize: False
#     momentum: 0
#     weight_decay: 0
# )
# {'defaults': {'lr': 0.000122770896701404,
#   'momentum': 0,
#   'alpha': 0.99,
#   'eps': 1e-08,
#   'centered': False,
#   'weight_decay': 0,
#   'foreach': None,
#   'maximize': False,
#   'differentiable': False},
#  '_optimizer_step_pre_hooks': OrderedDict(),
#  '_optimizer_step_post_hooks': OrderedDict(),
#  '_zero_grad_profile_name': 'Optimizer.zero_grad#RMSprop.zero_grad',
#  'state': defaultdict(dict,
#              {Parameter containing:
#               tensor([[-0.3156, -0.2507,  0.0507,  0.0562,  0.0242],
#                       [-0.6527, -0.0857,  0.3037, -0.2116,  0.0627],
#                       [-0.0347,  0.2098, -0.3777, -0.0809,  0.2956],
#                       ...,
#                       [-0.7137, -0.8349, -0.7205, -0.6012, -1.0251],
#                       [ 0.3980,  0.4896, -0.1317, -0.3497, -0.0582],
#                       [ 0.4427,  0.2015, -0.3135,  0.0172,  0.3554]], requires_grad=True): {'step': 653200,
#                'square_avg': tensor([[2.7034e-06, 3.1746e-04, 1.9948e-03, 1.9825e-03, 4.1457e-03],
#                        [4.6471e-05, 5.3334e-02, 7.0347e-02, 4.5115e-02, 1.6474e-01],
#                        [2.9465e-05, 2.6510e-02, 3.1283e-02, 2.4762e-02, 8.0251e-02],
#                        ...,
#                        [2.2620e-16, 4.3966e-17, 3.5675e-17, 7.9478e-17, 7.5506e-17],
#                        [5.5994e-07, 2.0847e-04, 1.2797e-04, 1.2397e-04, 4.3765e-04],
#                        [3.8262e-05, 3.2761e-02, 3.9407e-02, 3.0331e-02, 9.9638e-02]])},
#               Parameter containing:
#               tensor([-1.5864e-01, -4.5188e-02, -5.8418e-01, -3.6333e-01, -5.4607e-01,
#                       -2.0101e-02,  4.4603e-01,  8.2036e-02, -4.1950e-01,  6.6539e-02,
#                        2.2252e-01,  3.2391e-01, -3.4294e-01, -3.3480e-01,  3.8276e-01,
#                        8.4282e-02, -3.7038e-01,  3.5512e-01, -2.7730e-01,  3.8707e-01,
#                       -4.3646e-01, -2.4856e-01, -5.3218e-02,  2.3011e-01, -3.1801e-01,
#                        2.5634e-01, -5.1178e-01, -3.5265e-01,  3.9054e-01,  3.0589e-01,
#                       -3.7837e-01, -3.5605e-01, -1.7866e-01,  1.0560e-01,  7.2869e-02,
#                        2.6971e-01,  2.6551e-01,  1.9171e-01,  8.5119e-02,  2.8128e-01,
#                        6.9079e-02,  3.8679e-01, -2.8540e-01, -5.5494e-01, -3.7828e-01,
#                       -2.5171e-01,  4.4430e-01,  2.8489e-01,  4.9839e-01,  2.4881e-01,
#                       -3.3638e-01,  2.6810e-03, -1.5250e-01,  3.7707e-01,  1.2082e-01,
#                       -1.5912e-01, -9.5542e-02, -9.0795e-02,  1.5151e-01, -6.3524e-02,
#                       -9.1127e-01, -3.0960e-03, -1.1572e-02, -2.8789e-01, -7.5726e-01,
#                       -6.2491e-01, -1.3692e-01,  2.0494e-02, -1.7089e-01,  9.8177e-02,
#                        8.9721e-03, -9.1402e-02, -1.8276e-01, -1.0862e-01, -4.8001e-01,
#                       -2.3060e-01, -2.8091e-01, -3.4822e-01, -3.2014e-01,  4.1550e-01,
#                        3.6407e-01,  2.5939e-01,  5.9784e-02, -3.8032e-01,  2.1530e-01,
#                        1.7663e-01,  2.7703e-01, -4.3726e-01, -6.5343e-01,  3.3561e-01,
#                       -1.4434e-01,  9.3587e-02,  1.6431e-02,  1.9923e-01, -1.9929e-01,
#                       -1.4770e-01, -9.6046e-01,  2.1377e-01,  1.9674e-01,  3.4996e-01,
#                        1.6961e-01, -1.0147e-02, -5.0070e-02,  1.3680e-01,  3.4167e-01,
#                       -3.6427e-01, -4.7207e-01, -8.5481e-02,  3.5277e-01, -1.1026e-02,
#                        3.8581e-01,  3.6150e-01, -5.8125e-01,  9.2424e-02, -1.2736e-01,
#                        3.8432e-02, -9.0190e-01, -2.1223e-01, -6.3554e-01, -1.8548e-01,
#                        1.8320e-02, -2.1313e-01, -7.3280e-01, -2.1826e-01, -4.4102e-02,
#                        4.9118e-01,  1.7356e-01, -6.8327e-02,  1.7231e-02,  3.2510e-01,
#                       -4.4501e-01, -3.6305e-01, -1.1667e-01, -5.8448e-01,  4.1915e-01,
#                       -2.9632e-01,  2.5615e-01,  4.2885e-02,  1.8136e-01,  1.8778e-02,
#                       -4.4936e-01,  4.6475e-02,  2.4420e-01, -2.1480e-01,  6.7232e-02,
#                       -3.1299e-01, -4.0886e-02, -2.0209e-02,  3.3917e-01,  3.3329e-01,
#                        3.4138e-01, -5.9674e-02,  1.5409e-02, -6.5934e-01, -1.0750e-01,
#                       -7.3421e-01,  3.8182e-01, -2.3057e-01,  1.6600e-03,  4.0101e-01,
#                        7.7357e-02,  2.4305e-01, -3.9791e-01, -3.5147e-01,  7.6824e-02,
#                        1.3661e-01,  2.6257e-01,  3.9946e-03,  1.6416e-01, -2.7090e-01,
#                        3.9560e-01, -1.6089e-01,  3.2335e-01, -3.0110e-03, -2.3171e-01,
#                       -1.6396e-02,  1.0379e-01,  2.8606e-01, -2.9575e-01,  3.9206e-01,
#                       -9.8456e-01, -1.1696e-01,  3.7289e-01,  1.4480e-01, -6.1272e-01,
#                        3.8995e-01, -1.6830e-01, -3.4383e-01,  1.2860e-01,  1.2302e-01,
#                       -5.1332e-02, -3.2254e-01,  7.8491e-02,  2.0475e-01,  6.9717e-02,
#                        2.8361e-01,  5.0136e-01,  1.4016e-01, -2.9107e-01,  2.6640e-02,
#                       -1.3959e-01,  4.5761e-01, -2.6110e-01,  8.4384e-02, -1.0331e-01,
#                        3.1987e-03, -4.0377e-02, -1.2292e-01,  9.0318e-03,  2.5723e-02,
#                       -5.8444e-01, -1.1740e+00, -2.2396e-01, -8.9833e-01, -3.0503e-02,
#                       -1.4217e-01, -3.7225e-01,  3.4916e-01, -3.5571e-01, -6.8244e-01,
#                       -3.3742e-01, -7.0132e-01, -3.3317e-01,  4.1611e-01,  2.1920e-01,
#                       -1.9441e-03, -9.1230e-01,  5.3104e-02, -3.2369e-01,  4.5731e-05,
#                        4.9503e-01, -4.1872e-01,  2.3292e-03,  9.6286e-02,  3.7913e-03,
#                       -3.8611e-01, -6.4454e-02,  1.8353e-01,  2.9017e-01, -1.3955e-01,
#                       -5.0226e-01,  9.1533e-02, -3.9561e-01,  3.9529e-01, -6.0938e-01,
#                        1.6873e-01,  1.4047e-02, -4.3484e-01,  3.6740e-01, -1.9938e-01,
#                       -2.1854e-01,  3.2784e-02, -4.0342e-01, -2.0020e-01,  4.2294e-01,
#                       -4.0991e-02,  3.0669e-01,  1.2976e-01, -7.0670e-01, -1.3261e-01,
#                        4.0370e-01,  4.8226e-04,  2.0889e-02, -2.0483e-01, -2.1916e-01,
#                        3.4400e-01, -3.3211e-01, -1.9426e-01,  1.9758e-01,  4.0050e-01,
#                        1.6395e-01, -4.2642e-01,  1.0988e-01, -1.8721e-01,  4.4645e-01,
#                        2.0710e-01,  3.6180e-01, -2.3829e-01, -4.6466e-01, -6.0501e-02,
#                        3.6729e-02,  2.1979e-01,  2.7051e-01, -7.9167e-03, -4.9924e-02,
#                       -3.1379e-01, -2.6173e-01, -1.3754e-02, -2.4388e-01, -9.9226e-01,
#                        4.4258e-01,  3.7231e-01,  4.1725e-01, -2.3237e-01,  4.2045e-01,
#                        2.6338e-01, -5.2305e-01,  1.0211e-01,  3.1673e-01,  2.2636e-01,
#                        2.4646e-02, -5.0408e-01,  4.4218e-01, -2.1354e-01, -4.0231e-02,
#                        4.6663e-01, -2.7641e-01, -4.5164e-01, -3.0189e-01, -3.1735e-02,
#                       -1.5909e-01, -9.7723e-01,  4.5551e-02,  3.2187e-01, -2.1995e-01,
#                       -8.5168e-01, -3.1541e-02,  2.0960e-01, -4.2571e-01,  2.0035e-01,
#                       -3.4408e-02, -1.0695e-01,  1.4238e-01,  2.6975e-01, -1.4356e-01,
#                        6.2990e-03,  1.5001e-01,  2.6729e-01, -4.3564e-02,  3.7410e-02,
#                        1.5025e-01,  7.6418e-04,  2.2325e-02, -1.0792e-01,  3.5962e-01,
#                        2.2789e-01, -5.1878e-03,  4.1476e-01, -2.9033e-01, -3.2687e-01,
#                        4.0559e-01,  3.2793e-01,  1.5473e-01,  3.1025e-03, -2.1219e-01,
#                        1.1412e-01, -2.5983e-01,  3.8251e-01,  6.7008e-02, -8.9012e-02,
#                       -4.7457e-02, -1.7744e-01, -3.7809e-01,  3.3434e-01, -1.9743e-01,
#                       -5.1470e-01,  5.7492e-02, -4.1318e-01,  1.4901e-01,  5.5213e-02,
#                       -3.2693e-01, -4.6611e-01, -9.7829e-02, -1.1343e+00,  4.2394e-01,
#                       -1.2633e-01, -1.8079e-02, -7.8308e-02, -2.5931e-02,  3.0198e-01,
#                       -2.2654e-01,  1.4014e-01,  3.0673e-01,  1.9204e-02,  1.0498e-01,
#                        3.0944e-01,  5.5157e-01,  2.2305e-01,  4.2152e-01,  2.6023e-01,
#                        3.4079e-01, -4.0347e-02, -3.4436e-03, -2.3439e-02, -3.5494e-01,
#                        3.1837e-01,  4.3662e-01,  1.4613e-03, -4.0999e-01, -1.9669e-01,
#                       -4.3861e-01,  1.9397e-01, -4.0689e-02, -3.6383e-01, -3.8108e-01,
#                        1.6473e-01,  5.0931e-02, -2.3691e-01, -3.3043e-01,  5.8709e-03,
#                        2.4101e-01,  3.1249e-01, -2.9141e-01, -3.5759e-01, -1.8164e-01,
#                        8.3154e-02,  2.4573e-01, -3.5459e-01, -2.4871e-01, -3.5210e-02,
#                        3.4052e-01,  1.3161e-02, -5.4187e-01,  1.2084e-01, -1.9655e-03,
#                       -4.2160e-01,  8.7466e-02, -1.1872e-01,  5.1407e-02, -1.6858e-01,
#                       -2.8988e-01,  3.6171e-01, -3.0833e-01,  2.9441e-01, -5.9022e-03,
#                       -6.0141e-01, -6.9701e-02,  2.8257e-01,  3.4550e-01,  3.9960e-01,
#                       -1.8394e-01, -6.4310e-02,  1.8462e-01, -1.7185e-02, -3.6347e-01,
#                       -1.2170e+00,  1.8866e-01, -3.6264e-01, -2.2072e-01, -4.9328e-01,
#                       -6.6631e-02,  2.1385e-01,  4.1746e-01,  4.4868e-01, -3.5609e-01,
#                       -1.5444e-01, -1.0242e+00, -5.1656e-01, -3.2843e-01,  2.5898e-02,
#                       -2.0875e-01,  2.5904e-01, -2.7747e-01,  9.3152e-03, -2.4825e-02,
#                        3.3327e-01,  3.6004e-01, -5.2745e-01, -6.0797e-01, -8.6160e-02,
#                        6.1690e-02,  7.8271e-02, -1.9763e-01,  4.7791e-01,  5.4652e-04,
#                       -3.7661e-01,  1.6033e-02, -2.2352e-01, -2.4776e-01,  3.5249e-01,
#                       -2.8808e-01,  1.8194e-01,  3.2260e-01, -3.8265e-01,  2.0079e-01,
#                       -2.5230e-01, -4.0831e-02,  1.6153e-01,  3.3943e-01, -2.9084e-01,
#                        2.7564e-01,  3.0600e-03, -1.2901e-01, -1.9619e-01,  2.9607e-01,
#                       -5.0576e-01, -4.6382e-01,  2.0271e-01,  1.1486e-01, -4.5229e-01,
#                       -2.3199e-01,  1.0199e-03, -3.5975e-01,  6.4560e-02,  9.2231e-03,
#                        1.9654e-01, -4.3628e-02, -6.2591e-03, -2.0781e-02,  3.5563e-01,
#                       -6.7115e-02, -1.2606e-01, -2.9304e-01, -1.5458e-01, -5.6333e-01,
#                        4.6967e-05,  1.6018e-01, -1.0291e-01, -2.1679e-02,  2.5433e-01,
#                        3.7827e-01, -4.1044e-01, -2.2576e-01, -4.4066e-01,  7.4297e-03,
#                       -3.6511e-01, -4.2846e-01,  1.6636e-01,  2.9671e-01,  1.4878e-01,
#                        2.6144e-01, -5.4661e-01, -3.1646e-01, -3.0271e-01,  4.7936e-01,
#                       -4.2506e-02,  4.6894e-03,  7.3573e-02,  8.4531e-02,  1.7583e-01,
#                       -6.0268e-02,  1.4991e-03, -8.9516e-02, -5.4977e-01,  7.5246e-02,
#                       -9.6576e-01,  2.8201e-01, -6.1405e-02, -3.5439e-01,  2.4903e-02,
#                       -6.7277e-01, -2.1228e-01, -3.3058e-01,  4.9039e-02,  3.9701e-01,
#                       -3.0553e-01, -2.6808e-01,  2.2095e-01, -4.0206e-01, -4.2851e-01,
#                       -4.4595e-01, -5.2537e-01,  3.7424e-01, -1.9239e-01, -3.5724e-01],
#                      requires_grad=True): {'step': 653200,
#                'square_avg': tensor([1.1571e-09, 1.3855e-08, 1.0452e-08, 4.9195e-11, 1.2011e-09, 2.2397e-08,
#                        2.3435e-05, 2.2676e-05, 4.9622e-09, 5.2114e-06, 9.1751e-05, 1.0284e-06,
#                        0.0000e+00, 7.8454e-08, 5.5959e-06, 1.2374e-06, 1.3190e-08, 1.0540e-05,
#                        3.5421e-09, 4.3404e-05, 1.5793e-07, 4.6231e-08, 2.8106e-08, 1.3674e-07,
#                        1.1910e-08, 2.2337e-07, 6.8970e-10, 3.2111e-08, 3.2791e-06, 2.7061e-05,
#                        0.0000e+00, 0.0000e+00, 2.7549e-07, 5.2175e-05, 4.8789e-07, 5.8375e-05,
#                        7.0253e-07, 6.4842e-07, 3.4923e-06, 5.6706e-06, 8.5465e-05, 1.1465e-06,
#                        6.5868e-07, 8.9647e-10, 0.0000e+00, 4.0868e-08, 1.5280e-05, 1.0682e-05,
#                        2.2640e-05, 3.1879e-06, 0.0000e+00, 2.8831e-05, 0.0000e+00, 2.1539e-05,
#                        6.1520e-07, 7.3308e-09, 2.8611e-08, 0.0000e+00, 2.8236e-06, 1.1618e-08,
#                        3.7844e-09, 9.3912e-07, 1.8440e-09, 1.5827e-15, 1.8998e-10, 5.6946e-10,
#                        1.6070e-08, 9.9292e-07, 1.9683e-08, 3.1720e-06, 4.3306e-05, 4.1444e-07,
#                        2.0197e-07, 3.9350e-08, 1.7376e-08, 5.2480e-08, 1.6828e-08, 0.0000e+00,
#                        8.2187e-09, 2.3822e-06, 2.2771e-05, 2.9542e-06, 1.2544e-07, 6.0701e-11,
#                        8.5249e-05, 7.4382e-07, 1.4532e-05, 0.0000e+00, 1.7861e-09, 5.2866e-06,
#                        2.5197e-10, 1.1528e-06, 2.0484e-05, 2.2738e-05, 4.1173e-09, 1.3238e-08,
#                        5.1170e-08, 1.0253e-06, 3.2671e-07, 1.8400e-07, 8.6498e-05, 4.0061e-09,
#                        5.1045e-08, 1.6555e-07, 2.2640e-06, 4.3713e-09, 1.3015e-08, 6.9729e-10,
#                        7.6050e-06, 1.4474e-09, 4.8617e-06, 6.6430e-07, 1.0058e-10, 1.8012e-06,
#                        1.1089e-07, 1.6175e-08, 1.8623e-11, 1.9653e-07, 1.3454e-09, 1.1192e-08,
#                        4.5843e-06, 0.0000e+00, 1.5482e-09, 2.6215e-08, 0.0000e+00, 1.6870e-06,
#                        4.3079e-07, 0.0000e+00, 1.0623e-05, 3.1737e-05, 2.2739e-10, 0.0000e+00,
#                        1.0244e-08, 3.7442e-08, 2.7092e-05, 0.0000e+00, 5.9792e-06, 9.2442e-07,
#                        8.2863e-09, 6.4812e-07, 4.1437e-09, 2.6013e-07, 6.7666e-05, 9.8659e-09,
#                        2.1234e-05, 3.4846e-10, 2.3883e-08, 1.7741e-07, 1.4437e-06, 3.0319e-05,
#                        1.2630e-06, 1.5230e-07, 3.7287e-06, 5.1242e-09, 1.5549e-09, 2.5425e-10,
#                        2.1976e-07, 6.6122e-09, 2.1859e-05, 5.4189e-06, 2.8738e-07, 8.5900e-06,
#                        3.5037e-09, 4.4436e-09, 4.5875e-06, 5.0104e-07, 3.5368e-05, 9.5873e-06,
#                        1.5152e-06, 1.0429e-08, 1.5067e-05, 5.7705e-08, 7.3462e-06, 1.0747e-09,
#                        0.0000e+00, 6.1995e-09, 5.8161e-06, 5.6765e-07, 0.0000e+00, 2.3886e-05,
#                        5.6028e-10, 1.2090e-07, 3.7321e-05, 2.3418e-06, 1.6091e-09, 4.2320e-06,
#                        0.0000e+00, 6.5691e-08, 5.0720e-08, 1.4127e-08, 2.9709e-09, 2.7525e-08,
#                        5.5448e-06, 4.8032e-06, 4.5662e-06, 5.5504e-06, 1.5099e-06, 9.6790e-06,
#                        0.0000e+00, 1.7799e-08, 4.8941e-08, 3.3640e-06, 3.2159e-08, 4.7871e-05,
#                        5.9946e-08, 4.6481e-05, 1.9595e-07, 1.2998e-07, 1.3110e-05, 7.5303e-08,
#                        2.1630e-08, 1.9094e-11, 1.2305e-08, 5.8295e-09, 8.1758e-09, 3.7910e-07,
#                        7.8115e-08, 9.9361e-06, 1.0825e-06, 3.9088e-10, 7.0976e-08, 6.7071e-09,
#                        0.0000e+00, 2.6163e-05, 3.2132e-07, 3.1188e-08, 9.1575e-11, 5.2585e-06,
#                        3.2236e-08, 1.9878e-09, 1.1073e-05, 6.4748e-09, 3.9009e-05, 1.1338e-06,
#                        4.7722e-07, 4.5976e-08, 9.3776e-11, 2.8908e-06, 9.1191e-06, 1.7563e-07,
#                        2.4445e-09, 1.5416e-07, 6.9095e-11, 4.2340e-05, 4.9733e-09, 8.1328e-05,
#                        7.5983e-07, 1.6388e-09, 8.2406e-06, 6.2303e-08, 1.1075e-13, 3.4886e-08,
#                        1.4602e-08, 5.5283e-09, 4.8546e-06, 3.8037e-08, 1.1378e-06, 4.4708e-07,
#                        4.1148e-10, 0.0000e+00, 1.9235e-05, 1.4310e-04, 5.9426e-07, 3.8513e-08,
#                        1.2530e-08, 1.1017e-06, 0.0000e+00, 0.0000e+00, 5.9069e-08, 9.3604e-07,
#                        7.3927e-05, 1.5641e-09, 1.1543e-04, 9.0605e-08, 4.4077e-07, 1.5873e-06,
#                        1.5913e-05, 3.2808e-07, 1.0460e-10, 0.0000e+00, 3.8536e-05, 5.4193e-05,
#                        8.3848e-05, 0.0000e+00, 2.0950e-07, 0.0000e+00, 5.0533e-09, 2.6760e-09,
#                        4.8716e-09, 1.3869e-09, 2.8143e-05, 6.1133e-06, 1.7103e-05, 5.3843e-10,
#                        8.9567e-06, 7.5871e-06, 8.3360e-10, 1.4174e-05, 3.8132e-06, 1.2705e-05,
#                        2.5395e-08, 5.5894e-10, 1.0070e-05, 3.9267e-09, 1.5722e-08, 6.2994e-06,
#                        8.4278e-09, 1.4045e-10, 1.3324e-08, 4.4235e-08, 2.1263e-07, 1.2714e-10,
#                        5.8033e-07, 6.5280e-06, 7.0065e-44, 1.6424e-10, 2.5397e-08, 1.1519e-06,
#                        7.7696e-09, 5.1946e-08, 0.0000e+00, 7.3653e-08, 6.0697e-08, 8.1459e-08,
#                        0.0000e+00, 2.8410e-04, 2.4255e-06, 2.6727e-09, 0.0000e+00, 3.7086e-06,
#                        4.8744e-08, 2.8547e-05, 1.7384e-06, 7.0065e-44, 9.3434e-07, 2.6427e-07,
#                        4.1682e-08, 5.5168e-05, 9.2593e-09, 1.6848e-07, 2.9423e-05, 1.5187e-06,
#                        7.5782e-05, 1.8640e-04, 4.7204e-10, 1.0076e-04, 4.9854e-10, 1.2746e-06,
#                        2.3101e-08, 0.0000e+00, 0.0000e+00, 2.3314e-08, 2.1588e-07, 6.1870e-05,
#                        1.6520e-09, 2.2174e-09, 9.5411e-09, 6.3893e-07, 2.0647e-06, 1.0306e-07,
#                        0.0000e+00, 7.7416e-12, 7.5680e-08, 2.1696e-10, 1.7663e-06, 3.0379e-08,
#                        2.1121e-09, 8.1684e-07, 3.7512e-08, 4.6667e-06, 0.0000e+00, 1.1309e-04,
#                        6.5206e-07, 2.9899e-05, 1.7213e-06, 3.4019e-05, 3.1949e-08, 6.2690e-07,
#                        2.2731e-06, 1.2295e-06, 4.0388e-08, 1.8457e-08, 0.0000e+00, 9.0465e-07,
#                        2.0946e-08, 5.5465e-06, 1.9156e-05, 1.7190e-05, 5.3348e-08, 0.0000e+00,
#                        0.0000e+00, 7.6813e-06, 1.6941e-07, 4.8373e-08, 9.2091e-09, 6.7891e-05,
#                        6.2483e-06, 0.0000e+00, 5.2169e-08, 1.9853e-06, 3.5749e-08, 4.2575e-06,
#                        0.0000e+00, 7.3304e-08, 0.0000e+00, 7.6870e-08, 1.8272e-08, 4.4665e-08,
#                        2.3425e-09, 2.0775e-08, 4.1413e-05, 6.1303e-08, 4.6522e-08, 3.4946e-06,
#                        1.0463e-07, 9.8947e-08, 4.8952e-06, 9.5055e-10, 2.4182e-07, 4.4126e-11,
#                        2.2853e-07, 5.5510e-05, 4.9678e-08, 2.5203e-05, 1.2210e-09, 1.1408e-12,
#                        1.8256e-08, 1.5988e-08, 4.8364e-08, 3.7302e-07, 7.4363e-07, 3.7540e-08,
#                        1.8318e-06, 7.0065e-44, 0.0000e+00, 2.8953e-10, 1.0026e-07, 1.0163e-07,
#                        0.0000e+00, 2.9962e-08, 0.0000e+00, 2.8519e-06, 2.3504e-07, 1.4567e-05,
#                        1.4926e-07, 5.4901e-08, 9.6899e-09, 2.1502e-09, 7.0541e-08, 3.4640e-07,
#                        2.5929e-08, 3.6738e-07, 8.8304e-09, 1.8285e-06, 4.2889e-11, 1.4414e-05,
#                        1.0125e-05, 2.4238e-08, 3.0286e-09, 0.0000e+00, 2.4056e-08, 2.3379e-07,
#                        2.8388e-08, 5.7175e-05, 5.0171e-06, 2.2681e-07, 3.2241e-07, 5.3621e-09,
#                        4.1471e-08, 7.3811e-07, 0.0000e+00, 7.5639e-07, 3.5812e-05, 6.5486e-10,
#                        7.5042e-06, 2.1394e-08, 8.9000e-09, 3.0452e-08, 1.4124e-06, 2.2806e-08,
#                        3.5456e-08, 1.5021e-06, 1.7342e-07, 0.0000e+00, 2.7972e-05, 4.9002e-11,
#                        1.1943e-10, 1.0762e-04, 9.9637e-05, 9.8632e-09, 8.2937e-07, 5.8256e-05,
#                        4.3233e-07, 6.5440e-07, 4.1252e-05, 3.1482e-06, 4.3360e-09, 3.9037e-08,
#                        2.0834e-08, 1.5189e-07, 3.0645e-07, 0.0000e+00, 7.4003e-08, 4.1975e-08,
#                        1.0353e-09, 2.1355e-05, 1.1489e-04, 4.3375e-09, 4.0323e-08, 2.2930e-08,
#                        4.3233e-06, 0.0000e+00, 2.5861e-08, 1.8469e-09, 1.6029e-06, 9.7506e-08,
#                        0.0000e+00, 2.2442e-06, 2.1738e-05, 3.0710e-07, 5.0152e-05, 4.3629e-11,
#                        1.0572e-06, 4.7322e-10, 1.0171e-05, 0.0000e+00, 1.1249e-06, 3.2293e-07,
#                        1.8186e-06, 4.1522e-07, 4.1822e-09, 1.0409e-04, 2.2820e-10, 7.7725e-09,
#                        4.7056e-06, 1.6385e-10, 3.4679e-06, 5.3907e-07, 4.0831e-07, 3.1176e-05,
#                        9.0837e-09, 0.0000e+00, 6.3372e-09, 7.1251e-06, 5.1147e-05, 1.0436e-07,
#                        8.6588e-09, 9.8560e-08, 0.0000e+00, 2.8806e-09, 6.3208e-08, 2.0059e-09,
#                        3.5140e-05, 5.8410e-10, 1.3847e-08])},
#               Parameter containing:
#               tensor([[ 0.0230,  0.0313, -0.0224,  ...,  0.0112,  0.0310, -0.0408],
#                       [ 0.0098, -0.0313, -0.0105,  ...,  0.0072, -0.0387,  0.0075],
#                       [-0.0396, -0.0331, -0.0187,  ..., -0.0055, -0.0167,  0.0408],
#                       ...,
#                       [ 0.0291, -0.0025,  0.0607,  ..., -0.0298, -0.0112, -0.0066],
#                       [-0.0150, -0.0229,  0.0111,  ...,  0.0783,  0.0140,  0.0062],
#                       [-0.0389, -0.0440,  0.0147,  ..., -0.0074, -0.0269, -0.0003]],
#                      requires_grad=True): {'step': 653200,
#                'square_avg': tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#                         0.0000e+00],
#                        [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#                         0.0000e+00],
#                        [3.7930e-06, 1.0007e-03, 2.8131e-03,  ..., 7.0065e-44, 4.2771e-05,
#                         1.1366e-02],
#                        ...,
#                        [1.5908e-06, 9.8885e-04, 3.2862e-03,  ..., 7.0065e-44, 4.5344e-05,
#                         1.3083e-02],
#                        [7.0065e-44, 7.0065e-44, 7.0065e-44,  ..., 7.4497e-08, 7.0065e-44,
#                         7.0065e-44],
#                        [7.0065e-44, 7.0065e-44, 7.0065e-44,  ..., 0.0000e+00, 7.0065e-44,
#                         7.0065e-44]])},
#               Parameter containing:
#               tensor([-3.9350e-02,  2.9048e-02,  4.8958e-02, -4.6583e-02, -5.3765e-02,
#                       -1.2073e-02,  2.1046e-02, -1.5566e-01, -4.5301e-03,  1.8019e-02,
#                       -4.1212e-02,  1.6428e-02, -4.8582e-03, -2.8542e-02, -3.1766e-02,
#                        3.6105e-02, -5.6809e-02, -4.8833e-03, -1.4992e-01, -1.2937e-01,
#                        1.0799e-01, -2.2616e-02,  1.8455e-02,  3.1840e-02,  3.4023e-02,
#                       -1.2388e-02, -2.1006e-02, -3.6105e-02, -1.2039e-02, -2.6956e-02,
#                        3.3536e-02, -2.0308e-01, -6.9950e-03,  7.7043e-02,  1.9173e-03,
#                        1.6467e-02, -5.1083e-02, -3.4657e-02, -7.5084e-02,  7.4737e-02,
#                       -1.7059e-02, -1.9565e-02, -5.3259e-02, -3.3710e-01, -5.0112e-02,
#                       -4.2779e-02,  1.6018e-02, -5.5486e-02, -2.5110e-02, -7.0243e-04,
#                        6.9425e-02, -1.4850e-02,  2.6200e-02,  2.0286e-01, -1.8177e-02,
#                       -1.6186e-02, -2.5321e-02,  1.3458e-01, -7.1095e-02, -1.4874e-02,
#                       -3.8239e-02, -4.2919e-02, -2.3743e-01,  1.7353e-02, -8.8012e-02,
#                        1.5670e-02,  5.2658e-03, -3.8072e-02,  6.6127e-02, -1.3294e-02,
#                       -5.8096e-02, -2.3675e-03,  5.2023e-02, -6.2282e-02, -1.8606e-02,
#                        5.2970e-02,  1.2712e-02, -1.0040e-02,  2.4358e-04, -2.1771e-01,
#                       -2.3710e-02,  8.4742e-03, -1.5274e-01,  1.8363e-02, -3.3762e-02,
#                       -2.6774e-02, -3.7916e-02, -2.5160e-02, -1.5648e-02, -3.9101e-02,
#                       -8.6659e-02, -4.5561e-02, -1.0435e-01, -1.3207e-02,  1.9101e-01,
#                        6.0242e-02,  5.1865e-02,  6.2336e-03, -3.0353e-01, -5.2684e-02,
#                        3.7725e-02,  1.7308e-02, -2.2252e-03, -5.9559e-03, -1.4860e-03,
#                       -2.8550e-02,  9.6724e-03,  3.7310e-02,  4.4816e-02,  3.8631e-01,
#                       -5.6510e-03, -4.5588e-03, -7.4981e-04,  1.5941e-02,  1.4352e-01,
#                        6.9571e-03,  9.7123e-03,  7.0265e-03, -7.0781e-02, -1.4472e-02,
#                       -3.6984e-02, -2.5252e-02, -1.3466e-01, -3.8655e-02, -1.1350e-03,
#                       -2.0762e-02,  1.8008e-02, -4.5117e-02, -1.5798e-01, -5.2725e-02,
#                       -7.9743e-02, -3.4434e-02, -1.2017e-01, -1.1117e-01, -1.7297e-02,
#                       -2.4515e-04,  7.3194e-03, -1.1194e-02, -3.1611e-02,  2.9801e-02,
#                        2.6526e-02,  2.0917e-02,  2.6367e-02, -2.0328e-02,  2.1373e-02,
#                       -5.2136e-02,  1.9310e-01,  4.1673e-02, -1.6062e-03, -7.4249e-02,
#                       -4.0413e-02, -7.5780e-02, -1.8977e-02, -2.6403e-02,  1.7630e-02,
#                       -4.5402e-02,  3.7094e-02, -3.7786e-02,  1.1041e-01,  9.9950e-02,
#                       -3.2318e-02, -6.6167e-02, -4.9857e-03,  2.5404e-02, -2.8874e-02,
#                        4.3953e-02,  1.2495e-02,  7.2713e-04,  6.6379e-02, -2.5317e-02,
#                       -2.4073e-02,  4.4722e-02,  5.1625e-02,  1.7758e-02, -3.0089e-02,
#                        3.0406e-02,  3.3645e-02, -2.9498e-02, -3.3229e-02, -1.1360e-02,
#                       -6.6895e-02,  2.1772e-02,  1.4964e-01, -3.5466e-02, -1.3319e-02,
#                       -1.2887e-01, -2.3099e-02, -2.9032e-02,  7.8629e-03, -3.0934e-01,
#                       -1.0003e-01, -1.8144e-02,  1.0694e-02, -4.1066e-03,  3.8278e-02,
#                       -8.9353e-03, -2.5112e-02, -2.0646e-02,  8.1572e-02,  2.1091e-02,
#                       -1.9226e-01,  1.7592e-02,  1.3775e-01, -3.8977e-02,  6.4554e-03,
#                        6.7759e-02,  3.3335e-02,  1.4779e-02,  5.6715e-02, -5.5729e-03,
#                        1.2465e-02, -2.4020e-02,  1.3563e-02, -6.3556e-02, -1.6992e-03,
#                       -3.0299e-02, -1.0550e-01, -1.0616e-03, -1.4339e-02, -3.4910e-02,
#                       -2.5886e-01, -5.9557e-03, -3.5309e-02, -1.4286e-05,  2.6267e-02,
#                        1.0505e-02,  2.8299e-02,  6.2807e-02,  1.7223e-01,  2.5183e-02,
#                       -4.5877e-02, -6.9773e-02, -2.0328e-02,  3.1446e-02, -2.4529e-02,
#                       -6.6726e-02,  1.6797e-02, -7.5360e-02, -2.9163e-02,  5.6187e-02,
#                       -3.3172e-02, -3.3130e-02,  1.4096e-02, -4.5876e-02, -1.0970e-01,
#                       -9.1463e-02,  9.5535e-02, -3.3220e-02, -3.8102e-02, -1.9081e-02,
#                        1.9227e-02,  1.9708e-03, -7.4710e-02, -8.8083e-02, -1.9382e-02,
#                       -1.0675e-02,  1.8408e-02, -2.7588e-02,  2.6229e-02, -1.4017e-02,
#                        2.3126e-02,  7.8626e-03, -4.8435e-02, -2.5555e-02, -1.3353e-02,
#                        4.7211e-03, -1.2993e-02, -1.8849e-02, -2.4678e-02, -1.1368e-02,
#                       -1.1574e-01, -6.1512e-02,  2.4342e-03, -7.4745e-02,  4.4739e-02,
#                        1.0485e-02,  1.2455e-02, -1.5020e-02, -3.9900e-02,  1.1037e-01,
#                        1.3208e-02, -2.2604e-02, -5.0275e-02, -3.1289e-02, -1.2834e-02,
#                       -1.8028e-02,  1.8902e-02,  2.2337e-04, -7.4164e-02,  3.6103e-02,
#                        2.1465e-02,  1.8343e-02,  1.9701e-02, -1.2482e-02,  1.4073e-03,
#                        1.9747e-02, -4.7899e-02, -3.6365e-02, -5.4548e-02,  3.3051e-02,
#                       -6.9012e-02, -1.5928e-01, -9.0042e-03, -8.9888e-02,  1.4195e-01,
#                       -1.1298e-01, -2.5044e-03, -1.0212e-01, -4.8519e-02, -1.1851e-01,
#                       -3.6623e-02,  1.5519e-01,  3.1976e-03, -1.3946e-02, -4.2008e-02,
#                       -4.6002e-02, -5.5250e-02, -7.5018e-02, -3.1867e-02,  2.3446e-02,
#                        9.7282e-03, -1.1241e-01, -1.5345e-02, -1.9131e-02, -3.8942e-02,
#                       -9.0737e-02,  4.2130e-03,  6.5806e-02,  2.7811e-02, -1.6938e-01,
#                       -1.7129e-03,  3.8207e-02,  1.2200e-02,  3.8600e-02, -1.5666e-01,
#                       -2.2980e-04, -9.5293e-03, -1.7284e-02, -2.1760e-01, -3.3956e-01,
#                       -2.4381e-02, -1.7207e-02,  2.7246e-02,  2.1185e-02, -9.8379e-03,
#                        2.5248e-02,  9.6581e-03,  4.0706e-02, -2.2910e-01,  3.1332e-02,
#                        1.0054e-01, -3.9420e-02, -3.2073e-02, -1.2131e-02, -2.2759e-02,
#                       -1.6493e-02, -2.3998e-02,  1.5102e-02, -2.5657e-02,  3.3619e-03,
#                       -4.7703e-02, -3.6423e-02, -2.9414e-02, -2.2661e-02,  1.4743e-03,
#                        2.3747e-02,  6.4968e-02, -2.6418e-02, -4.6847e-02,  1.5450e-02,
#                        5.5668e-02, -8.6438e-02,  4.1963e-02, -3.7150e-02, -2.1739e-02,
#                       -2.6674e-02, -3.2396e-02, -3.6569e-02, -6.6595e-02, -9.8850e-02,
#                       -3.3553e-03,  4.1613e-02, -1.9943e-02,  1.2948e-02,  6.3844e-02,
#                       -1.4451e-02, -2.4836e-02,  1.2665e-01, -6.5845e-02,  1.7154e-02,
#                        2.5733e-01, -3.7186e-02, -1.5203e-01, -3.5912e-02, -2.5782e-02,
#                       -2.8677e-02,  3.7525e-02, -2.2777e-02, -1.7252e-02, -3.0064e-02,
#                       -4.0372e-02, -2.5969e-02,  7.4031e-02, -1.7852e-02, -1.1402e-02,
#                       -3.7357e-02,  2.8382e-02, -5.8919e-02, -4.6606e-02, -7.1119e-02,
#                        6.3601e-02,  4.0798e-02, -9.6501e-02, -2.0868e-02,  1.4952e-02,
#                        4.4560e-03, -3.0213e-02, -3.1047e-02,  2.4181e-03, -5.4692e-02,
#                        2.0647e-02, -2.7544e-02, -1.9714e-02, -3.5802e-02,  1.0703e-02,
#                       -1.4185e-04, -8.4746e-03,  5.6952e-02,  6.9400e-03, -2.1497e-02,
#                        9.7163e-02, -8.3905e-02, -5.9660e-03,  1.7887e-02,  1.8336e-02,
#                       -7.2197e-03,  2.2482e-02, -1.0769e-02,  4.7605e-02,  4.9707e-02,
#                       -1.3599e-02, -1.0286e-01, -2.8093e-02,  5.8114e-02,  6.1053e-04,
#                       -1.0028e-01,  1.7483e-02, -2.9388e-02, -6.1534e-02, -9.1282e-02,
#                       -7.2290e-02, -4.3511e-02,  2.8791e-02, -2.5928e-02, -3.6296e-02,
#                       -2.3408e-02, -7.5807e-03, -2.6410e-02], requires_grad=True): {'step': 653200,
#                'square_avg': tensor([0.0000e+00, 0.0000e+00, 1.7594e-08, 7.0065e-44, 7.0065e-44, 4.4994e-07,
#                        7.0065e-44, 7.0065e-44, 2.0708e-06, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        1.4400e-06, 1.8423e-07, 5.1116e-06, 1.5886e-06, 7.0065e-44, 4.2305e-08,
#                        3.9471e-09, 7.0065e-44, 8.1428e-09, 7.0065e-44, 7.0065e-44, 5.3705e-07,
#                        2.0188e-07, 7.0065e-44, 3.5407e-06, 5.7060e-09, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 1.0985e-06, 2.0019e-10, 9.7449e-08, 2.5111e-09,
#                        4.6230e-09, 7.0065e-44, 7.0065e-44, 1.5244e-07, 1.0083e-06, 7.0065e-44,
#                        1.1967e-06, 7.0065e-44, 7.0065e-44, 7.0065e-44, 1.2491e-07, 2.1310e-08,
#                        3.3399e-07, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0048e-10,
#                        0.0000e+00, 7.0065e-44, 7.0065e-44, 3.8073e-09, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 2.8519e-07,
#                        1.9683e-07, 7.0065e-44, 2.1758e-06, 7.0065e-44, 7.0065e-44, 4.0127e-07,
#                        2.8667e-06, 1.6103e-06, 7.0065e-44, 1.3988e-06, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 0.0000e+00, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 2.0722e-09, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        4.0764e-08, 7.0065e-44, 3.8846e-08, 4.4092e-07, 3.6959e-10, 4.6409e-07,
#                        1.8688e-06, 7.0065e-44, 7.0065e-44, 1.3561e-07, 0.0000e+00, 2.5264e-06,
#                        4.2745e-07, 7.0065e-44, 2.8238e-10, 7.0065e-44, 2.7644e-08, 7.0065e-44,
#                        3.6804e-09, 3.7749e-09, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        2.2709e-06, 2.7690e-07, 7.0065e-44, 0.0000e+00, 7.0065e-44, 9.6612e-08,
#                        5.9831e-06, 2.0607e-07, 7.0065e-44, 7.0822e-09, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 6.2254e-09, 7.3607e-09, 6.4746e-10,
#                        7.0065e-44, 1.3499e-08, 9.2431e-07, 0.0000e+00, 7.0065e-44, 1.7574e-06,
#                        7.0065e-44, 4.6769e-09, 1.1697e-06, 9.4896e-08, 3.1560e-07, 4.3043e-07,
#                        1.0856e-06, 4.0040e-08, 4.4244e-09, 7.0065e-44, 9.5426e-07, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 4.5409e-10, 5.8595e-10,
#                        7.7682e-07, 7.0065e-44, 3.0762e-09, 8.4913e-10, 7.0065e-44, 1.4750e-10,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 1.4016e-06, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 1.7406e-08, 4.1876e-07, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 3.3111e-08,
#                        3.5291e-06, 1.8803e-09, 3.4280e-09, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 3.1723e-06, 7.0065e-44, 7.0065e-44, 6.0558e-07,
#                        5.5955e-09, 7.0065e-44, 1.8702e-06, 7.0065e-44, 7.0065e-44, 0.0000e+00,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 3.0281e-06, 3.5196e-09, 7.0065e-44,
#                        3.7527e-09, 7.0065e-44, 1.0628e-09, 1.4756e-06, 1.3491e-06, 7.2246e-07,
#                        7.0065e-44, 7.0065e-44, 4.6659e-10, 7.0065e-44, 4.4835e-07, 4.3393e-07,
#                        2.7059e-09, 7.0065e-44, 1.0875e-06, 7.0065e-44, 7.0065e-44, 1.5365e-09,
#                        7.0065e-44, 4.0703e-07, 7.0065e-44, 7.0065e-44, 7.0065e-44, 4.7477e-07,
#                        1.1044e-06, 7.0065e-44, 6.6093e-09, 6.2808e-10, 1.0088e-07, 8.8556e-07,
#                        1.4364e-09, 5.6298e-09, 1.3072e-06, 3.8191e-07, 2.4834e-06, 4.2196e-08,
#                        1.1730e-06, 0.0000e+00, 7.0065e-44, 2.6318e-08, 7.0065e-44, 4.6280e-06,
#                        2.9120e-10, 0.0000e+00, 7.0065e-44, 0.0000e+00, 4.5566e-06, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 3.9826e-07, 3.3543e-07, 6.1503e-09,
#                        1.3062e-06, 2.6461e-08, 2.9835e-06, 2.2171e-10, 7.0065e-44, 3.0093e-06,
#                        4.6265e-09, 7.0065e-44, 1.7105e-07, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 1.8123e-08, 3.6228e-07, 7.0065e-44,
#                        2.2819e-07, 7.0065e-44, 6.1907e-09, 2.8307e-09, 1.7084e-07, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 5.0475e-07, 7.7306e-09, 7.0065e-44,
#                        3.6265e-09, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        1.0717e-09, 3.4906e-10, 7.0065e-44, 7.6417e-08, 7.0065e-44, 1.4132e-06,
#                        7.0065e-44, 7.0065e-44, 1.0310e-06, 7.0065e-44, 3.8015e-10, 4.1625e-06,
#                        7.0065e-44, 7.0065e-44, 6.0496e-06, 8.2869e-09, 7.0065e-44, 2.1924e-10,
#                        7.6021e-10, 4.3030e-07, 7.0065e-44, 1.2440e-06, 7.0065e-44, 7.0065e-44,
#                        3.6154e-43, 7.0065e-44, 6.3881e-07, 7.0065e-44, 7.0065e-44, 4.9493e-07,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 8.3816e-09, 8.2831e-07, 7.0065e-44,
#                        7.0065e-44, 7.2089e-07, 7.0065e-44, 4.8645e-07, 7.0065e-44, 0.0000e+00,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 1.4369e-06,
#                        0.0000e+00, 2.5177e-07, 5.2653e-07, 7.0065e-44, 6.5928e-09, 5.1248e-07,
#                        7.0065e-44, 7.0065e-44, 7.4768e-07, 4.1857e-09, 3.6355e-07, 0.0000e+00,
#                        7.0065e-44, 7.0065e-44, 2.0331e-06, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        3.3841e-08, 7.0065e-44, 7.0065e-44, 7.0065e-44, 1.4675e-06, 4.7047e-07,
#                        3.0222e-06, 7.0065e-44, 1.5152e-07, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        5.4017e-09, 0.0000e+00, 9.8354e-08, 7.0065e-44, 7.0065e-44, 0.0000e+00,
#                        9.3441e-07, 7.0065e-44, 0.0000e+00, 0.0000e+00, 7.0065e-44, 7.0065e-44,
#                        2.0585e-06, 7.0065e-44, 7.0065e-44, 6.9123e-08, 7.0065e-44, 7.0065e-44,
#                        1.4546e-09, 2.6194e-08, 7.0065e-44, 6.1798e-09, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 3.1777e-07, 7.0065e-44, 1.4827e-06, 7.0065e-44, 0.0000e+00,
#                        7.0065e-44, 1.9331e-09, 1.2999e-06, 7.0065e-44, 7.6093e-16, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 3.6895e-06, 6.5239e-07, 7.0065e-44, 2.6434e-07,
#                        0.0000e+00, 7.0065e-44, 7.0065e-44, 1.4231e-07, 2.9381e-09, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 8.9208e-10, 7.0065e-44, 7.0065e-44, 5.8526e-10, 7.0065e-44,
#                        9.5058e-09, 7.0065e-44, 1.9128e-06, 7.0065e-44, 7.9145e-07, 2.8615e-06,
#                        3.1839e-06, 3.5827e-07, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 5.3856e-07, 7.0065e-44, 7.0065e-44, 8.9172e-11,
#                        5.4967e-08, 7.0065e-44, 4.9340e-07, 7.0065e-44, 7.0065e-44, 2.5933e-08,
#                        5.3198e-07, 7.0065e-44])},
#               Parameter containing:
#               tensor([[-0.0266, -0.0006, -0.0280,  ..., -0.0868,  0.0164, -0.0284],
#                       [-0.0295, -0.0019,  0.0534,  ..., -0.0061,  0.0380, -0.0039],
#                       [ 0.0079,  0.0034, -0.0321,  ..., -0.0416,  0.0762,  0.0028],
#                       ...,
#                       [ 0.0184, -0.0395, -0.0160,  ..., -0.0595,  0.0428, -0.0313],
#                       [ 0.0191, -0.0146, -0.0206,  ..., -0.0318, -0.0086,  0.0071],
#                       [-0.0370, -0.0211, -0.0755,  ..., -0.0569,  0.0361, -0.0102]],
#                      requires_grad=True): {'step': 653200,
#                'square_avg': tensor([[0.0000e+00, 0.0000e+00, 7.0065e-44,  ..., 4.4114e-12, 4.9271e-14,
#                         7.0065e-44],
#                        [0.0000e+00, 0.0000e+00, 2.0331e-03,  ..., 1.7694e-04, 2.4681e-07,
#                         7.0065e-44],
#                        [0.0000e+00, 0.0000e+00, 7.0065e-44,  ..., 9.8099e-21, 1.2049e-14,
#                         7.0065e-44],
#                        ...,
#                        [0.0000e+00, 0.0000e+00, 7.0065e-44,  ..., 7.0065e-44, 7.0065e-44,
#                         7.0065e-44],
#                        [0.0000e+00, 0.0000e+00, 7.0065e-44,  ..., 7.0065e-44, 6.3672e-14,
#                         7.0065e-44],
#                        [0.0000e+00, 0.0000e+00, 7.0065e-44,  ..., 3.3696e-17, 5.6786e-08,
#                         7.0065e-44]])},
#               Parameter containing:
#               tensor([ 9.5644e-02, -1.5662e-02, -8.8716e-02, -1.1009e-01, -7.6189e-02,
#                        1.0609e-01, -3.6765e-01, -3.1680e-02, -8.8258e-02, -2.7483e-02,
#                       -1.3945e-03, -8.9368e-02,  7.0704e-02, -1.1381e-01, -8.7690e-03,
#                        3.3460e-02, -5.6634e-02, -8.6632e-03, -5.1757e-02,  4.0574e-02,
#                        3.0262e-02, -6.6998e-02,  3.0042e-02, -1.3571e-02, -5.3723e-02,
#                        1.1023e-01,  2.6178e-02, -4.1284e-02,  3.5702e-02, -1.1659e-02,
#                        5.9294e-02, -2.0597e-03, -2.7487e-01, -3.1781e-01, -7.3198e-02,
#                       -5.4948e-02, -7.8445e-02, -3.2975e-02, -5.2452e-02, -6.8884e-02,
#                       -4.8793e-02, -1.1198e-01,  1.5292e-01, -8.0198e-04,  1.8853e-01,
#                       -3.0579e-02,  9.0960e-03,  1.5947e-01,  5.8451e-02,  5.9531e-02,
#                        2.4163e-04, -1.4431e-02, -9.7899e-03, -5.9583e-02,  1.5116e-01,
#                       -1.0736e-01, -6.5358e-02,  1.6682e-02, -2.3551e-02, -1.9115e-02,
#                       -4.2119e-02, -4.5007e-02, -3.1457e-02,  3.4576e-02,  2.8925e-02,
#                       -4.6224e-03,  9.0925e-02, -4.5819e-02, -4.2308e-02,  1.4560e-02,
#                        1.8649e-01, -4.8051e-02,  5.5574e-02, -1.0449e-02, -5.7263e-02,
#                       -5.8479e-02, -7.4141e-02, -9.9814e-03, -1.2965e-02,  1.1823e-01,
#                        4.3179e-02,  2.4893e-02, -9.1277e-03,  1.0587e-01,  6.4853e-02,
#                       -3.8530e-02,  1.5661e-02, -1.0777e-01,  6.8289e-02, -8.1283e-02,
#                       -3.7188e-02,  1.0126e-01, -2.8780e-03,  4.4786e-01,  3.5007e-03,
#                       -2.1424e-02, -1.5969e-01, -2.1359e-02, -1.8238e-03,  6.4336e-02,
#                        1.3317e-02, -2.4501e-02,  1.8877e-02,  1.4746e-02, -2.3384e-01,
#                        6.5540e-02,  2.5248e-02,  1.4773e-03,  7.0950e-02,  3.4062e-02,
#                        6.5557e-02, -3.9221e-02, -7.7849e-02, -9.4499e-03, -2.4417e-02],
#                      requires_grad=True): {'step': 653200,
#                'square_avg': tensor([4.6146e-10, 3.0119e-07, 3.8146e-11, 7.0065e-44, 1.1689e-06, 6.2303e-08,
#                        9.2192e-08, 5.2000e-08, 7.0065e-44, 3.5195e-07, 2.5605e-07, 7.0065e-44,
#                        8.0955e-09, 7.0065e-44, 7.0065e-44, 7.0065e-44, 3.0697e-09, 8.5726e-07,
#                        7.0065e-44, 7.0065e-44, 1.2725e-07, 1.1408e-05, 4.6774e-08, 7.0065e-44,
#                        2.1768e-07, 3.9485e-08, 7.1204e-09, 7.0065e-44, 4.6925e-08, 7.4502e-08,
#                        3.1945e-06, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 1.6300e-07,
#                        7.0065e-44, 1.1297e-11, 7.0065e-44, 7.0065e-44, 6.1971e-07, 2.3574e-06,
#                        1.6032e-10, 5.1747e-09, 6.2915e-10, 7.0065e-44, 1.2077e-06, 8.1850e-08,
#                        4.4288e-08, 1.6776e-06, 7.0065e-44, 2.1604e-11, 7.0065e-44, 7.0065e-44,
#                        3.7211e-08, 1.2466e-06, 1.7892e-07, 2.4842e-06, 9.4017e-15, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 2.1571e-07, 1.7142e-09, 1.6579e-07,
#                        4.2481e-07, 1.5429e-07, 7.0065e-44, 7.0065e-44, 5.5448e-09, 7.0065e-44,
#                        2.8609e-06, 5.2811e-06, 7.0065e-44, 7.0065e-44, 7.0065e-44, 6.2383e-10,
#                        7.0065e-44, 2.4746e-08, 1.5529e-08, 7.0065e-44, 4.9552e-06, 2.0338e-09,
#                        7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 5.9926e-07, 7.0065e-44,
#                        7.0065e-44, 1.5293e-07, 3.9045e-07, 2.2853e-08, 7.0065e-44, 7.0065e-44,
#                        7.0065e-44, 7.0065e-44, 5.2440e-07, 6.8220e-10, 7.0065e-44, 1.0261e-05,
#                        1.7104e-09, 2.1482e-08, 2.4475e-09, 6.2768e-07, 3.3364e-10, 1.1175e-06,
#                        7.3156e-09, 6.7656e-09, 1.8246e-07, 7.0065e-44, 7.0065e-44, 8.2345e-11,
#                        6.3427e-08])},
#               Parameter containing:
#               tensor([[ 9.0927e-02,  1.4655e-02, -4.4965e-02, -2.4187e-02, -2.9902e-02,
#                        -2.5911e-02, -3.3028e-02,  6.1628e-03, -8.3272e-02,  1.6550e-02,
#                         1.4125e-02, -3.7347e-02,  9.6605e-03, -1.9153e-02, -6.2318e-04,
#                        -1.0754e-02, -1.5465e-03,  2.4879e-02, -4.2610e-02, -8.9792e-04,
#                         3.3488e-02,  9.0245e-02,  5.7872e-03,  8.2913e-04, -1.3025e-02,
#                        -3.8265e-02,  2.3554e-03,  5.2427e-02,  5.9688e-03,  5.7011e-02,
#                         4.9559e-02,  4.3245e-02, -3.6641e-02, -3.8268e-02, -7.4686e-02,
#                        -1.1272e-02, -1.6850e-04, -2.1675e-02, -1.5264e-02,  3.1030e-03,
#                         2.1382e-02, -4.2858e-02, -1.8378e-02, -2.0086e-03, -5.8625e-03,
#                        -3.8343e-02,  2.9528e-02,  7.9944e-03,  5.5443e-03,  3.6153e-02,
#                         6.8932e-02, -2.9104e-02,  6.6458e-03,  4.3229e-04, -1.9463e-02,
#                         3.0110e-02,  6.0658e-02,  4.2895e-02, -5.3042e-03, -9.6454e-04,
#                        -5.6839e-02, -3.6114e-02, -4.2703e-03, -1.2965e-02,  2.3578e-02,
#                         1.1365e-02, -1.7721e-02, -1.0964e-02, -8.0448e-02, -2.0554e-04,
#                         1.0002e-02, -3.4878e-03, -4.7025e-02,  6.4156e-02, -2.3102e-02,
#                         3.4294e-04, -5.7147e-02, -2.2392e-02,  4.3600e-02, -2.1540e-02,
#                         3.2858e-03,  4.2024e-05,  6.0260e-02, -2.5721e-02, -6.9758e-03,
#                         5.7116e-02,  5.3613e-04, -9.0786e-03,  2.1586e-02, -2.3549e-02,
#                        -1.8729e-02, -1.0736e-02,  1.7442e-02,  5.9073e-02,  1.0831e-03,
#                        -6.8850e-02, -6.7324e-02,  2.1024e-02,  2.0213e-02, -1.1409e-01,
#                        -1.1565e-03,  8.9415e-02, -4.3320e-02,  3.9261e-03, -1.3809e-03,
#                         2.1343e-02,  3.1127e-02,  2.9264e-02, -2.2927e-02, -5.8790e-02,
#                         1.1765e-02,  7.0806e-02, -4.4326e-02, -1.0438e-01, -7.0296e-03]],
#                      requires_grad=True): {'step': 653200,
#                'square_avg': tensor([[5.3029e-09, 1.1384e+00, 2.0268e-09, 7.0065e-44, 3.6345e-03, 2.9933e-02,
#                         3.2857e+01, 2.1395e-02, 7.0065e-44, 1.9114e-02, 4.1500e-03, 7.0065e-44,
#                         1.0853e+01, 7.0065e-44, 7.0065e-44, 7.0065e-44, 4.5356e-08, 6.9654e-01,
#                         7.0065e-44, 7.0065e-44, 4.8739e+00, 7.6758e-02, 1.2827e+00, 7.0065e-44,
#                         2.7372e-04, 9.5029e-04, 1.7980e-04, 7.0065e-44, 1.6980e+00, 8.3876e-04,
#                         1.6055e-02, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 1.3767e-06,
#                         7.0065e-44, 1.1227e-05, 7.0065e-44, 7.0065e-44, 3.4295e-02, 1.1767e-05,
#                         8.5973e-07, 2.7189e-06, 5.0956e-01, 7.0065e-44, 9.6951e-01, 1.2419e-03,
#                         9.4943e-01, 1.0316e-02, 7.0065e-44, 4.7600e-07, 7.0065e-44, 7.0065e-44,
#                         6.2150e-01, 3.9608e-02, 3.3158e-02, 5.3500e-02, 8.7126e-17, 7.0065e-44,
#                         7.0065e-44, 7.0065e-44, 7.0065e-44, 3.4920e-06, 2.7635e-06, 8.4323e-03,
#                         3.2952e-03, 2.5919e-06, 7.0065e-44, 7.0065e-44, 9.1492e+00, 7.0065e-44,
#                         6.3800e-04, 1.1778e-02, 7.0065e-44, 7.0065e-44, 7.0065e-44, 5.8415e-02,
#                         7.0065e-44, 2.7172e-01, 1.0005e+00, 7.0065e-44, 7.2732e-02, 8.3411e-04,
#                         7.0065e-44, 7.0065e-44, 7.0065e-44, 7.0065e-44, 7.2758e-03, 7.0065e-44,
#                         7.0065e-44, 2.0801e-03, 4.2782e-03, 1.3450e-06, 7.0065e-44, 7.0065e-44,
#                         7.0065e-44, 7.0065e-44, 6.0634e-03, 1.2905e-08, 7.0065e-44, 2.2915e-02,
#                         1.5846e-06, 8.3698e-01, 1.0100e-04, 8.8730e-02, 4.4757e-07, 7.2299e-03,
#                         2.9091e-04, 9.3049e-07, 8.5956e+00, 7.0065e-44, 7.0065e-44, 1.2832e-11,
#                         3.0410e-04]])},
#               Parameter containing:
# ...
#  {'l1_norm': 0.1887548783505335, 'linf_norm': 5.985364563822001},
#  {'l1_norm': 0.1887512089287862, 'linf_norm': 5.985252747799456},
#  {'l1_norm': 0.1887521520849317, 'linf_norm': 5.985275082745403},
#  {'l1_norm': 0.1887442749279551, 'linf_norm': 5.985029062007367},
#  {'l1_norm': 0.1887536230107769, 'linf_norm': 5.985297163495422},
#  {'l1_norm': 0.1887477084079757, 'linf_norm': 5.985074586458504},
#  {'l1_norm': 0.1887454935902729, 'linf_norm': 5.984990829028934},
#  {'l1_norm': 0.1887496597726829, 'linf_norm': 5.985150567222386},
#  {'l1_norm': 0.1887636745908297, 'linf_norm': 5.985541577731818},
#  {'l1_norm': 0.1887629287834279, 'linf_norm': 5.985491883886605},
#  {'l1_norm': 0.1887549226656556, 'linf_norm': 5.98525458028838},
#  {'l1_norm': 0.1887520827530883, 'linf_norm': 5.985214582087845},
#  {'l1_norm': 0.1887535282554105, 'linf_norm': 5.985288262659311},
#  {'l1_norm': 0.1887498659639619, 'linf_norm': 5.985215221802145},
#  {'l1_norm': 0.1887474656443111, 'linf_norm': 5.985124476999045},
#  {'l1_norm': 0.1887524851113557, 'linf_norm': 5.985284559124708},
#  {'l1_norm': 0.1887516146857291, 'linf_norm': 5.985277373673021},
#  {'l1_norm': 0.1887598577877506, 'linf_norm': 5.985508931234479},
#  {'l1_norm': 0.1887552145032212, 'linf_norm': 5.985382091717422},
#  {'l1_norm': 0.188759574328456, 'linf_norm': 5.985484587588906},
#  {'l1_norm': 0.188748826039955, 'linf_norm': 5.985176583825052},
#  {'l1_norm': 0.1887518344954587, 'linf_norm': 5.985274535097182},
#  {'l1_norm': 0.1887557137948461, 'linf_norm': 5.985403412149101},
#  {'l1_norm': 0.1887549049871042, 'linf_norm': 5.985395206555724},
#  {'l1_norm': 0.1887564452968538, 'linf_norm': 5.985452455842495},
#  {'l1_norm': 0.1887590900100767, 'linf_norm': 5.9855573547557},
#  {'l1_norm': 0.1887530831281095, 'linf_norm': 5.985408109354973},
#  {'l1_norm': 0.1887676992472261, 'linf_norm': 5.985894417915493},
#  {'l1_norm': 0.1887654871804639, 'linf_norm': 5.985797280513495},
#  {'l1_norm': 0.1887532493873499, 'linf_norm': 5.98539820529446},
#  {'l1_norm': 0.1887539007415995, 'linf_norm': 5.985412111457437},
#  {'l1_norm': 0.1887570465970784, 'linf_norm': 5.985509642983228},
#  {'l1_norm': 0.1887551916129887, 'linf_norm': 5.985419330536574},
#  {'l1_norm': 0.1887541573761962, 'linf_norm': 5.985391221806407},
#  {'l1_norm': 0.1887603429509327, 'linf_norm': 5.985579397596418},
#  {'l1_norm': 0.1887536798967048, 'linf_norm': 5.98535773806423},
#  {'l1_norm': 0.1887498529160395, 'linf_norm': 5.98526369721368},
#  {'l1_norm': 0.1887556520508602, 'linf_norm': 5.985416108462214},
#  {'l1_norm': 0.1887519643470644, 'linf_norm': 5.98531825197488},
#  {'l1_norm': 0.1887483009427785, 'linf_norm': 5.985175255893916},
#  {'l1_norm': 0.188745314559061, 'linf_norm': 5.985121665046364},
#  {'l1_norm': 0.1887599110887386, 'linf_norm': 5.985534680158645},
#  {'l1_norm': 0.1887505729274824, 'linf_norm': 5.985264277595282},
#  {'l1_norm': 0.1887515859819948, 'linf_norm': 5.98528491396904},
#  {'l1_norm': 0.1887507601991296, 'linf_norm': 5.985234911272674},
#  {'l1_norm': 0.1887487609659321, 'linf_norm': 5.985206144836545},
#  {'l1_norm': 0.1887501370474696, 'linf_norm': 5.985257527958602},
#  {'l1_norm': 0.1887553982554934, 'linf_norm': 5.98543257746622},
#  {'l1_norm': 0.1887483797491528, 'linf_norm': 5.985215341537446},
#  {'l1_norm': 0.1887562626415863, 'linf_norm': 5.985475322809815},
#  {'l1_norm': 0.1887575677929446, 'linf_norm': 5.985454919075966},
#  {'l1_norm': 0.188753987755347, 'linf_norm': 5.985366689693928},
#  {'l1_norm': 0.1887641799017787, 'linf_norm': 5.985711491312086},
#  {'l1_norm': 0.1887505223412066, 'linf_norm': 5.985312550135702},
#  {'l1_norm': 0.1887518830868415, 'linf_norm': 5.985376889985055},
#  {'l1_norm': 0.1887554832800291, 'linf_norm': 5.985483253302426},
#  {'l1_norm': 0.18875430143876, 'linf_norm': 5.985469240728766},
#  {'l1_norm': 0.1887556157651357, 'linf_norm': 5.985503866736591},
#  {'l1_norm': 0.1887516065409407, 'linf_norm': 5.985399554962664},
#  {'l1_norm': 0.1887553112156689, 'linf_norm': 5.985498569831252},
#  {'l1_norm': 0.188749663288705, 'linf_norm': 5.985351857503503},
#  {'l1_norm': 0.1887548319404013, 'linf_norm': 5.985496674161404},
#  {'l1_norm': 0.1887526374123059, 'linf_norm': 5.98539915208593},
#  {'l1_norm': 0.1887505537728779, 'linf_norm': 5.985345491544157},
#  {'l1_norm': 0.1887492072855122, 'linf_norm': 5.985336914669722},
#  {'l1_norm': 0.1887474457671865, 'linf_norm': 5.985308245444298},
#  {'l1_norm': 0.188754777301196, 'linf_norm': 5.9855380025960505},
#  {'l1_norm': 0.1887540639227256, 'linf_norm': 5.98552188307792},
#  {'l1_norm': 0.188755125758145, 'linf_norm': 5.985537790193408},
#  {'l1_norm': 0.188745149658434, 'linf_norm': 5.9852364819034936},
#  {'l1_norm': 0.1887551189786754, 'linf_norm': 5.985530189342052},
#  {'l1_norm': 0.1887584674865938, 'linf_norm': 5.985567754264921},
#  {'l1_norm': 0.1887536824357696, 'linf_norm': 5.985444171747566},
#  {'l1_norm': 0.1887396716314368, 'linf_norm': 5.985017720483244},
#  {'l1_norm': 0.1887480980613269, 'linf_norm': 5.985307120520622},
#  {'l1_norm': 0.1887485211824998, 'linf_norm': 5.985279468277096},
#  {'l1_norm': 0.1887495475426316, 'linf_norm': 5.985310096557439},
#  {'l1_norm': 0.1887464402250945, 'linf_norm': 5.9852161585338415},
#  {'l1_norm': 0.188752547421772, 'linf_norm': 5.9853993664130565},
#  {'l1_norm': 0.1887557746903971, 'linf_norm': 5.985529196833074},
#  {'l1_norm': 0.1887513486166484, 'linf_norm': 5.98542736383751},
#  {'l1_norm': 0.188744046499487, 'linf_norm': 5.985195203655213},
#  {'l1_norm': 0.1887504698854871, 'linf_norm': 5.985372942247242},
#  {'l1_norm': 0.1887500573975034, 'linf_norm': 5.985321276049316},
#  {'l1_norm': 0.1887502414282411, 'linf_norm': 5.98530733108148},
#  {'l1_norm': 0.1887490704346448, 'linf_norm': 5.985265552339703},
#  {'l1_norm': 0.1887503712261095, 'linf_norm': 5.985285011989624},
#  {'l1_norm': 0.1887564159050583, 'linf_norm': 5.98546161993742},
#  {'l1_norm': 0.1887506106780841, 'linf_norm': 5.985293932325393},
#  {'l1_norm': 0.1887590000769123, 'linf_norm': 5.985547670157999},
#  {'l1_norm': 0.1887504768974147, 'linf_norm': 5.9852836424298586},
#  {'l1_norm': 0.1887526444116607, 'linf_norm': 5.985353537183255},
#  {'l1_norm': 0.1887436056578532, 'linf_norm': 5.98508936316222},
#  {'l1_norm': 0.1887536915129982, 'linf_norm': 5.98540908704102},
#  {'l1_norm': 0.1887544526712037, 'linf_norm': 5.985448559496552},
#  {'l1_norm': 0.1887704265070147, 'linf_norm': 5.9859056965701285},
#  {'l1_norm': 0.1887533922385424, 'linf_norm': 5.98541546838209},
#  {'l1_norm': 0.188752647952456, 'linf_norm': 5.985419629005342},
#  {'l1_norm': 0.1887440860319882, 'linf_norm': 5.985179642373323},
#  {'l1_norm': 0.1887354381193406, 'linf_norm': 5.984955665021389},
#  {'l1_norm': 0.188745650971774, 'linf_norm': 5.98526257898435},
#  {'l1_norm': 0.18874242226528, 'linf_norm': 5.985192398231477},
#  {'l1_norm': 0.1887497219193726, 'linf_norm': 5.985434632001817},
#  {'l1_norm': 0.1887485962358303, 'linf_norm': 5.985429492878168},
#  {'l1_norm': 0.1887449202662333, 'linf_norm': 5.985283443864435},
#  {'l1_norm': 0.1887448178067803, 'linf_norm': 5.9852988112322985},
#  {'l1_norm': 0.1887505843290128, 'linf_norm': 5.985471226998419},
#  {'l1_norm': 0.1887587131167762, 'linf_norm': 5.985685202666372},
#  {'l1_norm': 0.1887529186284169, 'linf_norm': 5.985510775873065},
#  {'l1_norm': 0.1887472638932056, 'linf_norm': 5.985331317190081},
#  {'l1_norm': 0.1887512225629762, 'linf_norm': 5.985444906438887},
#  {'l1_norm': 0.1887506982857361, 'linf_norm': 5.985489975738526},
#  {'l1_norm': 0.1887530593816191, 'linf_norm': 5.985576734177023},
#  {'l1_norm': 0.1887508075799793, 'linf_norm': 5.985526944452524},
#  {'l1_norm': 0.1887483917610719, 'linf_norm': 5.98547262378335},
#  {'l1_norm': 0.1887495166700333, 'linf_norm': 5.985467279356718},
#  {'l1_norm': 0.1887492760783992, 'linf_norm': 5.985497458659112},
#  {'l1_norm': 0.1887436857199296, 'linf_norm': 5.98533441163376},
#  {'l1_norm': 0.1887429134932346, 'linf_norm': 5.985293905542046},
#  {'l1_norm': 0.1887390712033026, 'linf_norm': 5.985177389025688},
#  {'l1_norm': 0.1887462320469319, 'linf_norm': 5.985411016359925},
#  {'l1_norm': 0.1887494923042133, 'linf_norm': 5.985529069560021},
#  {'l1_norm': 0.1887389881011098, 'linf_norm': 5.985225396031141},
#  {'l1_norm': 0.1887343000002205, 'linf_norm': 5.985115228739381},
#  {'l1_norm': 0.1887446934664622, 'linf_norm': 5.985415451006591},
#  {'l1_norm': 0.1887476802194491, 'linf_norm': 5.985479342463613},
#  {'l1_norm': 0.1887497977945022, 'linf_norm': 5.985538272491097},
#  {'l1_norm': 0.1887425924643874, 'linf_norm': 5.9853576797187324},
#  {'l1_norm': 0.1887439180677756, 'linf_norm': 5.985426417631656},
#  {'l1_norm': 0.1887460431743413, 'linf_norm': 5.985521330049634},
#  {'l1_norm': 0.1887435666582547, 'linf_norm': 5.985453382122516},
#  {'l1_norm': 0.18874183500465, 'linf_norm': 5.985413690925389},
#  {'l1_norm': 0.1887438909701071, 'linf_norm': 5.98543610264957},
#  {'l1_norm': 0.1887532037688419, 'linf_norm': 5.985707553751022},
#  {'l1_norm': 0.1887557504684664, 'linf_norm': 5.985773976316303},
#  {'l1_norm': 0.1887523483294993, 'linf_norm': 5.985704792904854},
#  {'l1_norm': 0.1887612026092596, 'linf_norm': 5.985997485950589},
#  {'l1_norm': 0.1887604225976392, 'linf_norm': 5.985936119484902},
#  {'l1_norm': 0.1887466306876391, 'linf_norm': 5.985521836511791},
#  {'l1_norm': 0.1887446086843498, 'linf_norm': 5.985450620818138},
#  {'l1_norm': 0.188741049076803, 'linf_norm': 5.985358491723985},
#  {'l1_norm': 0.188740965075884, 'linf_norm': 5.985430589192361},
#  {'l1_norm': 0.1887464678302407, 'linf_norm': 5.985613649404049},
#  {'l1_norm': 0.1887447519149631, 'linf_norm': 5.985530458722264},
#  {'l1_norm': 0.1887432745059021, 'linf_norm': 5.985478569914401},
#  {'l1_norm': 0.1887521881467662, 'linf_norm': 5.985710597354919},
#  {'l1_norm': 0.1887549977389164, 'linf_norm': 5.985791849808395},
#  {'l1_norm': 0.1887513483447022, 'linf_norm': 5.985713115363568},
#  {'l1_norm': 0.1887451742134988, 'linf_norm': 5.985541703679413},
#  {'l1_norm': 0.1887420202578417, 'linf_norm': 5.985461582385003},
#  {'l1_norm': 0.1887460053168237, 'linf_norm': 5.9855744081512094},
#  {'l1_norm': 0.1887440195037983, 'linf_norm': 5.9855188028700645},
#  {'l1_norm': 0.1887421009222045, 'linf_norm': 5.985475029267371},
#  {'l1_norm': 0.1887424741102382, 'linf_norm': 5.985466177979856},
#  {'l1_norm': 0.1887410859664902, 'linf_norm': 5.985401663064956},
#  {'l1_norm': 0.1887362240935675, 'linf_norm': 5.985267164716125},
#  {'l1_norm': 0.188733071924001, 'linf_norm': 5.98518493469134},
#  {'l1_norm': 0.1887420095833018, 'linf_norm': 5.985438730051368},
#  {'l1_norm': 0.1887590854334645, 'linf_norm': 5.985937043002993},
#  {'l1_norm': 0.1887521808811463, 'linf_norm': 5.985752956469357},
#  {'l1_norm': 0.1887468944438733, 'linf_norm': 5.985601435945183},
#  {'l1_norm': 0.188739054235816, 'linf_norm': 5.985340212054551},
#  {'l1_norm': 0.1887410821435973, 'linf_norm': 5.985432610941678},
#  {'l1_norm': 0.1887349478110671, 'linf_norm': 5.985259170884639},
#  {'l1_norm': 0.1887364664236083, 'linf_norm': 5.9852858861811455},
#  {'l1_norm': 0.1887399875135161, 'linf_norm': 5.985407152517885},
#  {'l1_norm': 0.1887350757821463, 'linf_norm': 5.985230143892765},
#  {'l1_norm': 0.1887457322870381, 'linf_norm': 5.985544464321435},
#  {'l1_norm': 0.1887382928755134, 'linf_norm': 5.985348693900556},
#  {'l1_norm': 0.1887401567758061, 'linf_norm': 5.985441824129224},
#  {'l1_norm': 0.1887428528621793, 'linf_norm': 5.985556195929647},
#  {'l1_norm': 0.1887454460703767, 'linf_norm': 5.985648501784355},
#  {'l1_norm': 0.1887482370137237, 'linf_norm': 5.985713717702776},
#  {'l1_norm': 0.1887392553609795, 'linf_norm': 5.985443308133632},
#  {'l1_norm': 0.188748461546842, 'linf_norm': 5.985716444522888},
#  {'l1_norm': 0.1887437512390315, 'linf_norm': 5.985526875337959},
#  {'l1_norm': 0.1887382825185544, 'linf_norm': 5.985386239700019},
#  {'l1_norm': 0.188739250643365, 'linf_norm': 5.985393080563843},
#  {'l1_norm': 0.1887371478620916, 'linf_norm': 5.985352272965014},
#  {'l1_norm': 0.1887370202706195, 'linf_norm': 5.985332734179496},
#  {'l1_norm': 0.1887405843223445, 'linf_norm': 5.985455047236383},
#  {'l1_norm': 0.1887428153321147, 'linf_norm': 5.985499273668975},
#  {'l1_norm': 0.1887420022063888, 'linf_norm': 5.985510312131047},
#  {'l1_norm': 0.1887437527941539, 'linf_norm': 5.985550995387882},
#  {'l1_norm': 0.1887401463994756, 'linf_norm': 5.985463801390678},
#  {'l1_norm': 0.1887319018983282, 'linf_norm': 5.985246292668581},
#  {'l1_norm': 0.188737698238343, 'linf_norm': 5.985432642573119},
#  {'l1_norm': 0.1887356689164415, 'linf_norm': 5.9853734117470685},
#  {'l1_norm': 0.1887308162329718, 'linf_norm': 5.98523667852059},
#  {'l1_norm': 0.1887418490596115, 'linf_norm': 5.985559686750919},
#  {'l1_norm': 0.1887302500586025, 'linf_norm': 5.985221006536484},
#  {'l1_norm': 0.1887339384331368, 'linf_norm': 5.985359909816832},
#  {'l1_norm': 0.18873767688144, 'linf_norm': 5.98549267282635},
#  {'l1_norm': 0.1887442924310453, 'linf_norm': 5.985701013469696},
#  {'l1_norm': 0.1887406360574998, 'linf_norm': 5.985599218086898},
#  {'l1_norm': 0.1887403673832304, 'linf_norm': 5.985574142320454},
#  {'l1_norm': 0.1887430817762389, 'linf_norm': 5.985657747638226},
#  {'l1_norm': 0.1887353025883436, 'linf_norm': 5.985423382062465},
#  {'l1_norm': 0.1887383888411335, 'linf_norm': 5.985552617065609},
#  {'l1_norm': 0.188739831726253, 'linf_norm': 5.9856134244583545},
#  {'l1_norm': 0.1887413308621384, 'linf_norm': 5.985645906338096},
#  {'l1_norm': 0.18873421436809, 'linf_norm': 5.985421604143828},
#  {'l1_norm': 0.1887391092314385, 'linf_norm': 5.98555947373733},
#  {'l1_norm': 0.1887401491887867, 'linf_norm': 5.985518952477723},
#  {'l1_norm': 0.1887378293472342, 'linf_norm': 5.985456130405516},
#  {'l1_norm': 0.1887354596409946, 'linf_norm': 5.985403521140665},
#  {'l1_norm': 0.1887352316171862, 'linf_norm': 5.985413845991343},
#  {'l1_norm': 0.1887311698278412, 'linf_norm': 5.985290844855458},
#  {'l1_norm': 0.1887319710231386, 'linf_norm': 5.985313660176844},
#  {'l1_norm': 0.1887222782031632, 'linf_norm': 5.985064308854192},
#  {'l1_norm': 0.1887294237880036, 'linf_norm': 5.985282741630077},
#  {'l1_norm': 0.1887247778995893, 'linf_norm': 5.985154951999337},
#  {'l1_norm': 0.1887276516963728, 'linf_norm': 5.985253799077868},
#  {'l1_norm': 0.1887309861103072, 'linf_norm': 5.9853515117913485},
#  {'l1_norm': 0.1887357905521057, 'linf_norm': 5.985491569574922},
#  {'l1_norm': 0.1887293970861472, 'linf_norm': 5.985297544214874},
#  {'l1_norm': 0.1887296405622735, 'linf_norm': 5.985283025731146},
#  {'l1_norm': 0.1887386102205142, 'linf_norm': 5.985566611927748},
#  {'l1_norm': 0.1887322373902425, 'linf_norm': 5.985394989456982},
#  {'l1_norm': 0.1887389575581997, 'linf_norm': 5.985576355561614},
#  {'l1_norm': 0.1887344757127575, 'linf_norm': 5.985454285468906},
#  {'l1_norm': 0.1887323345742188, 'linf_norm': 5.985397044798732},
#  {'l1_norm': 0.1887365608684718, 'linf_norm': 5.9855360858529805},
#  {'l1_norm': 0.1887361800977028, 'linf_norm': 5.98554276137203},
#  {'l1_norm': 0.1887319063846022, 'linf_norm': 5.985402239165455},
#  {'l1_norm': 0.1887399326090701, 'linf_norm': 5.985656663227826},
#  {'l1_norm': 0.1887446530109271, 'linf_norm': 5.985755385648459},
#  {'l1_norm': 0.1887384279233403, 'linf_norm': 5.985566622526199},
#  {'l1_norm': 0.1887314946225844, 'linf_norm': 5.985394126788527},
#  {'l1_norm': 0.1887212650203146, 'linf_norm': 5.985093027510494},
#  {'l1_norm': 0.1887268829710781, 'linf_norm': 5.985264580485225},
#  {'l1_norm': 0.188728919078689, 'linf_norm': 5.985372434606403},
#  {'l1_norm': 0.1887413352684117, 'linf_norm': 5.9857053878553215},
#  {'l1_norm': 0.1887336850918829, 'linf_norm': 5.985454819055646},
#  {'l1_norm': 0.188736766321212, 'linf_norm': 5.985546174856276},
#  {'l1_norm': 0.1887353730962611, 'linf_norm': 5.98551495019123},
#  {'l1_norm': 0.1887367985114455, 'linf_norm': 5.98553643886745},
#  {'l1_norm': 0.1887273861059919, 'linf_norm': 5.985277664892376},
#  {'l1_norm': 0.1887217875041067, 'linf_norm': 5.985107003775984},
#  {'l1_norm': 0.188737827766221, 'linf_norm': 5.98557144363001},
#  {'l1_norm': 0.1887325349255465, 'linf_norm': 5.985396692787111},
#  {'l1_norm': 0.1887242454337887, 'linf_norm': 5.985146767457574},
#  {'l1_norm': 0.188731927043572, 'linf_norm': 5.985397728969157}]

# %%
train_losses_loaded[-1]
test_losses_loaded[-1]
test_metrics_loaded[-1]['l1_norm']
test_metrics_loaded[-1]['linf_norm']
print(f'Error is {test_metrics_loaded[-1]["l1_norm"] / (3.84e-4)} times bigger than in Dieselhorst et al.')
print(f'Error is {test_metrics_loaded[-1]["linf_norm"] / (8.14e-3)} times bigger than in Dieselhorst et al.')
# Out:
# 0.1429526623694684
# 0.150043303305516
# 0.188731927043572
# 5.985397728969157
# Error is 491.4893933426354 times bigger than in Dieselhorst et al.
# Error is 735.3068463107072 times bigger than in Dieselhorst et al.

# %% [markdown]
# ### Visualize loaded results

# %% [markdown]
# Let us verify correct loading of the train and test metrics by visualizing them again but now through the loaded values. Likewise for the train and test losses.

# %%
# %config InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# Plotting the losses and metrics for the best network plt.figure(figsize=(12, 
#plt.subplot(2, 2, 1)
#plt.plot(train_losses_loaded, label="Train Loss")
#plt.plot(test_losses_loaded, label="Test Loss")
#plt.xlabel("Epoch")
#plt.ylabel("Loss")
#plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics_loaded], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics_loaded], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics_loaded], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics_loaded], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-3, 1e2)
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses_loaded,label="training data")
plt.plot(test_losses_loaded,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Added setting the vertical axis to be in powers of 10
plt.yscale("log")
# Added setting the vertical axis limits to be from 10^-7 to 10^0
plt.ylim(1e-7, 1e0)
plt.legend()
plt.show()

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network. Note that `net` is only available if we have trained the model in this session.

# %%
# %%script echo skipping
#
# print(list(net.parameters()))
# Out:
# Couldn't find program: 'echo'

# %%
print(list(net_loaded.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.3156, -0.2507,  0.0507,  0.0562,  0.0242],
#         [-0.6527, -0.0857,  0.3037, -0.2116,  0.0627],
#         [-0.0347,  0.2098, -0.3777, -0.0809,  0.2956],
#         ...,
#         [-0.7137, -0.8349, -0.7205, -0.6012, -1.0251],
#         [ 0.3980,  0.4896, -0.1317, -0.3497, -0.0582],
#         [ 0.4427,  0.2015, -0.3135,  0.0172,  0.3554]], requires_grad=True), Parameter containing:
# tensor([-1.5864e-01, -4.5188e-02, -5.8418e-01, -3.6333e-01, -5.4607e-01,
#         -2.0101e-02,  4.4603e-01,  8.2036e-02, -4.1950e-01,  6.6539e-02,
#          2.2252e-01,  3.2391e-01, -3.4294e-01, -3.3480e-01,  3.8276e-01,
#          8.4282e-02, -3.7038e-01,  3.5512e-01, -2.7730e-01,  3.8707e-01,
#         -4.3646e-01, -2.4856e-01, -5.3218e-02,  2.3011e-01, -3.1801e-01,
#          2.5634e-01, -5.1178e-01, -3.5265e-01,  3.9054e-01,  3.0589e-01,
#         -3.7837e-01, -3.5605e-01, -1.7866e-01,  1.0560e-01,  7.2869e-02,
#          2.6971e-01,  2.6551e-01,  1.9171e-01,  8.5119e-02,  2.8128e-01,
#          6.9079e-02,  3.8679e-01, -2.8540e-01, -5.5494e-01, -3.7828e-01,
#         -2.5171e-01,  4.4430e-01,  2.8489e-01,  4.9839e-01,  2.4881e-01,
#         -3.3638e-01,  2.6810e-03, -1.5250e-01,  3.7707e-01,  1.2082e-01,
#         -1.5912e-01, -9.5542e-02, -9.0795e-02,  1.5151e-01, -6.3524e-02,
#         -9.1127e-01, -3.0960e-03, -1.1572e-02, -2.8789e-01, -7.5726e-01,
#         -6.2491e-01, -1.3692e-01,  2.0494e-02, -1.7089e-01,  9.8177e-02,
#          8.9721e-03, -9.1402e-02, -1.8276e-01, -1.0862e-01, -4.8001e-01,
#         -2.3060e-01, -2.8091e-01, -3.4822e-01, -3.2014e-01,  4.1550e-01,
#          3.6407e-01,  2.5939e-01,  5.9784e-02, -3.8032e-01,  2.1530e-01,
#          1.7663e-01,  2.7703e-01, -4.3726e-01, -6.5343e-01,  3.3561e-01,
#         -1.4434e-01,  9.3587e-02,  1.6431e-02,  1.9923e-01, -1.9929e-01,
#         -1.4770e-01, -9.6046e-01,  2.1377e-01,  1.9674e-01,  3.4996e-01,
#          1.6961e-01, -1.0147e-02, -5.0070e-02,  1.3680e-01,  3.4167e-01,
#         -3.6427e-01, -4.7207e-01, -8.5481e-02,  3.5277e-01, -1.1026e-02,
#          3.8581e-01,  3.6150e-01, -5.8125e-01,  9.2424e-02, -1.2736e-01,
#          3.8432e-02, -9.0190e-01, -2.1223e-01, -6.3554e-01, -1.8548e-01,
#          1.8320e-02, -2.1313e-01, -7.3280e-01, -2.1826e-01, -4.4102e-02,
#          4.9118e-01,  1.7356e-01, -6.8327e-02,  1.7231e-02,  3.2510e-01,
#         -4.4501e-01, -3.6305e-01, -1.1667e-01, -5.8448e-01,  4.1915e-01,
#         -2.9632e-01,  2.5615e-01,  4.2885e-02,  1.8136e-01,  1.8778e-02,
#         -4.4936e-01,  4.6475e-02,  2.4420e-01, -2.1480e-01,  6.7232e-02,
#         -3.1299e-01, -4.0886e-02, -2.0209e-02,  3.3917e-01,  3.3329e-01,
#          3.4138e-01, -5.9674e-02,  1.5409e-02, -6.5934e-01, -1.0750e-01,
#         -7.3421e-01,  3.8182e-01, -2.3057e-01,  1.6600e-03,  4.0101e-01,
#          7.7357e-02,  2.4305e-01, -3.9791e-01, -3.5147e-01,  7.6824e-02,
#          1.3661e-01,  2.6257e-01,  3.9946e-03,  1.6416e-01, -2.7090e-01,
#          3.9560e-01, -1.6089e-01,  3.2335e-01, -3.0110e-03, -2.3171e-01,
#         -1.6396e-02,  1.0379e-01,  2.8606e-01, -2.9575e-01,  3.9206e-01,
#         -9.8456e-01, -1.1696e-01,  3.7289e-01,  1.4480e-01, -6.1272e-01,
#          3.8995e-01, -1.6830e-01, -3.4383e-01,  1.2860e-01,  1.2302e-01,
#         -5.1332e-02, -3.2254e-01,  7.8491e-02,  2.0475e-01,  6.9717e-02,
#          2.8361e-01,  5.0136e-01,  1.4016e-01, -2.9107e-01,  2.6640e-02,
#         -1.3959e-01,  4.5761e-01, -2.6110e-01,  8.4384e-02, -1.0331e-01,
#          3.1987e-03, -4.0377e-02, -1.2292e-01,  9.0318e-03,  2.5723e-02,
#         -5.8444e-01, -1.1740e+00, -2.2396e-01, -8.9833e-01, -3.0503e-02,
#         -1.4217e-01, -3.7225e-01,  3.4916e-01, -3.5571e-01, -6.8244e-01,
#         -3.3742e-01, -7.0132e-01, -3.3317e-01,  4.1611e-01,  2.1920e-01,
#         -1.9441e-03, -9.1230e-01,  5.3104e-02, -3.2369e-01,  4.5731e-05,
#          4.9503e-01, -4.1872e-01,  2.3292e-03,  9.6286e-02,  3.7913e-03,
#         -3.8611e-01, -6.4454e-02,  1.8353e-01,  2.9017e-01, -1.3955e-01,
#         -5.0226e-01,  9.1533e-02, -3.9561e-01,  3.9529e-01, -6.0938e-01,
#          1.6873e-01,  1.4047e-02, -4.3484e-01,  3.6740e-01, -1.9938e-01,
#         -2.1854e-01,  3.2784e-02, -4.0342e-01, -2.0020e-01,  4.2294e-01,
#         -4.0991e-02,  3.0669e-01,  1.2976e-01, -7.0670e-01, -1.3261e-01,
#          4.0370e-01,  4.8226e-04,  2.0889e-02, -2.0483e-01, -2.1916e-01,
#          3.4400e-01, -3.3211e-01, -1.9426e-01,  1.9758e-01,  4.0050e-01,
#          1.6395e-01, -4.2642e-01,  1.0988e-01, -1.8721e-01,  4.4645e-01,
#          2.0710e-01,  3.6180e-01, -2.3829e-01, -4.6466e-01, -6.0501e-02,
#          3.6729e-02,  2.1979e-01,  2.7051e-01, -7.9167e-03, -4.9924e-02,
#         -3.1379e-01, -2.6173e-01, -1.3754e-02, -2.4388e-01, -9.9226e-01,
#          4.4258e-01,  3.7231e-01,  4.1725e-01, -2.3237e-01,  4.2045e-01,
#          2.6338e-01, -5.2305e-01,  1.0211e-01,  3.1673e-01,  2.2636e-01,
#          2.4646e-02, -5.0408e-01,  4.4218e-01, -2.1354e-01, -4.0231e-02,
#          4.6663e-01, -2.7641e-01, -4.5164e-01, -3.0189e-01, -3.1735e-02,
#         -1.5909e-01, -9.7723e-01,  4.5551e-02,  3.2187e-01, -2.1995e-01,
#         -8.5168e-01, -3.1541e-02,  2.0960e-01, -4.2571e-01,  2.0035e-01,
#         -3.4408e-02, -1.0695e-01,  1.4238e-01,  2.6975e-01, -1.4356e-01,
#          6.2990e-03,  1.5001e-01,  2.6729e-01, -4.3564e-02,  3.7410e-02,
#          1.5025e-01,  7.6418e-04,  2.2325e-02, -1.0792e-01,  3.5962e-01,
#          2.2789e-01, -5.1878e-03,  4.1476e-01, -2.9033e-01, -3.2687e-01,
#          4.0559e-01,  3.2793e-01,  1.5473e-01,  3.1025e-03, -2.1219e-01,
#          1.1412e-01, -2.5983e-01,  3.8251e-01,  6.7008e-02, -8.9012e-02,
#         -4.7457e-02, -1.7744e-01, -3.7809e-01,  3.3434e-01, -1.9743e-01,
#         -5.1470e-01,  5.7492e-02, -4.1318e-01,  1.4901e-01,  5.5213e-02,
#         -3.2693e-01, -4.6611e-01, -9.7829e-02, -1.1343e+00,  4.2394e-01,
#         -1.2633e-01, -1.8079e-02, -7.8308e-02, -2.5931e-02,  3.0198e-01,
#         -2.2654e-01,  1.4014e-01,  3.0673e-01,  1.9204e-02,  1.0498e-01,
#          3.0944e-01,  5.5157e-01,  2.2305e-01,  4.2152e-01,  2.6023e-01,
#          3.4079e-01, -4.0347e-02, -3.4436e-03, -2.3439e-02, -3.5494e-01,
#          3.1837e-01,  4.3662e-01,  1.4613e-03, -4.0999e-01, -1.9669e-01,
#         -4.3861e-01,  1.9397e-01, -4.0689e-02, -3.6383e-01, -3.8108e-01,
#          1.6473e-01,  5.0931e-02, -2.3691e-01, -3.3043e-01,  5.8709e-03,
#          2.4101e-01,  3.1249e-01, -2.9141e-01, -3.5759e-01, -1.8164e-01,
#          8.3154e-02,  2.4573e-01, -3.5459e-01, -2.4871e-01, -3.5210e-02,
#          3.4052e-01,  1.3161e-02, -5.4187e-01,  1.2084e-01, -1.9655e-03,
#         -4.2160e-01,  8.7466e-02, -1.1872e-01,  5.1407e-02, -1.6858e-01,
#         -2.8988e-01,  3.6171e-01, -3.0833e-01,  2.9441e-01, -5.9022e-03,
#         -6.0141e-01, -6.9701e-02,  2.8257e-01,  3.4550e-01,  3.9960e-01,
#         -1.8394e-01, -6.4310e-02,  1.8462e-01, -1.7185e-02, -3.6347e-01,
#         -1.2170e+00,  1.8866e-01, -3.6264e-01, -2.2072e-01, -4.9328e-01,
#         -6.6631e-02,  2.1385e-01,  4.1746e-01,  4.4868e-01, -3.5609e-01,
#         -1.5444e-01, -1.0242e+00, -5.1656e-01, -3.2843e-01,  2.5898e-02,
#         -2.0875e-01,  2.5904e-01, -2.7747e-01,  9.3152e-03, -2.4825e-02,
#          3.3327e-01,  3.6004e-01, -5.2745e-01, -6.0797e-01, -8.6160e-02,
#          6.1690e-02,  7.8271e-02, -1.9763e-01,  4.7791e-01,  5.4652e-04,
#         -3.7661e-01,  1.6033e-02, -2.2352e-01, -2.4776e-01,  3.5249e-01,
#         -2.8808e-01,  1.8194e-01,  3.2260e-01, -3.8265e-01,  2.0079e-01,
#         -2.5230e-01, -4.0831e-02,  1.6153e-01,  3.3943e-01, -2.9084e-01,
#          2.7564e-01,  3.0600e-03, -1.2901e-01, -1.9619e-01,  2.9607e-01,
#         -5.0576e-01, -4.6382e-01,  2.0271e-01,  1.1486e-01, -4.5229e-01,
#         -2.3199e-01,  1.0199e-03, -3.5975e-01,  6.4560e-02,  9.2231e-03,
#          1.9654e-01, -4.3628e-02, -6.2591e-03, -2.0781e-02,  3.5563e-01,
#         -6.7115e-02, -1.2606e-01, -2.9304e-01, -1.5458e-01, -5.6333e-01,
#          4.6967e-05,  1.6018e-01, -1.0291e-01, -2.1679e-02,  2.5433e-01,
#          3.7827e-01, -4.1044e-01, -2.2576e-01, -4.4066e-01,  7.4297e-03,
#         -3.6511e-01, -4.2846e-01,  1.6636e-01,  2.9671e-01,  1.4878e-01,
#          2.6144e-01, -5.4661e-01, -3.1646e-01, -3.0271e-01,  4.7936e-01,
#         -4.2506e-02,  4.6894e-03,  7.3573e-02,  8.4531e-02,  1.7583e-01,
#         -6.0268e-02,  1.4991e-03, -8.9516e-02, -5.4977e-01,  7.5246e-02,
#         -9.6576e-01,  2.8201e-01, -6.1405e-02, -3.5439e-01,  2.4903e-02,
#         -6.7277e-01, -2.1228e-01, -3.3058e-01,  4.9039e-02,  3.9701e-01,
#         -3.0553e-01, -2.6808e-01,  2.2095e-01, -4.0206e-01, -4.2851e-01,
#         -4.4595e-01, -5.2537e-01,  3.7424e-01, -1.9239e-01, -3.5724e-01],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0230,  0.0313, -0.0224,  ...,  0.0112,  0.0310, -0.0408],
#         [ 0.0098, -0.0313, -0.0105,  ...,  0.0072, -0.0387,  0.0075],
#         [-0.0396, -0.0331, -0.0187,  ..., -0.0055, -0.0167,  0.0408],
#         ...,
#         [ 0.0291, -0.0025,  0.0607,  ..., -0.0298, -0.0112, -0.0066],
#         [-0.0150, -0.0229,  0.0111,  ...,  0.0783,  0.0140,  0.0062],
#         [-0.0389, -0.0440,  0.0147,  ..., -0.0074, -0.0269, -0.0003]],
#        requires_grad=True), Parameter containing:
# tensor([-3.9350e-02,  2.9048e-02,  4.8958e-02, -4.6583e-02, -5.3765e-02,
#         -1.2073e-02,  2.1046e-02, -1.5566e-01, -4.5301e-03,  1.8019e-02,
#         -4.1212e-02,  1.6428e-02, -4.8582e-03, -2.8542e-02, -3.1766e-02,
#          3.6105e-02, -5.6809e-02, -4.8833e-03, -1.4992e-01, -1.2937e-01,
#          1.0799e-01, -2.2616e-02,  1.8455e-02,  3.1840e-02,  3.4023e-02,
#         -1.2388e-02, -2.1006e-02, -3.6105e-02, -1.2039e-02, -2.6956e-02,
#          3.3536e-02, -2.0308e-01, -6.9950e-03,  7.7043e-02,  1.9173e-03,
#          1.6467e-02, -5.1083e-02, -3.4657e-02, -7.5084e-02,  7.4737e-02,
#         -1.7059e-02, -1.9565e-02, -5.3259e-02, -3.3710e-01, -5.0112e-02,
#         -4.2779e-02,  1.6018e-02, -5.5486e-02, -2.5110e-02, -7.0243e-04,
#          6.9425e-02, -1.4850e-02,  2.6200e-02,  2.0286e-01, -1.8177e-02,
#         -1.6186e-02, -2.5321e-02,  1.3458e-01, -7.1095e-02, -1.4874e-02,
#         -3.8239e-02, -4.2919e-02, -2.3743e-01,  1.7353e-02, -8.8012e-02,
#          1.5670e-02,  5.2658e-03, -3.8072e-02,  6.6127e-02, -1.3294e-02,
#         -5.8096e-02, -2.3675e-03,  5.2023e-02, -6.2282e-02, -1.8606e-02,
#          5.2970e-02,  1.2712e-02, -1.0040e-02,  2.4358e-04, -2.1771e-01,
#         -2.3710e-02,  8.4742e-03, -1.5274e-01,  1.8363e-02, -3.3762e-02,
#         -2.6774e-02, -3.7916e-02, -2.5160e-02, -1.5648e-02, -3.9101e-02,
#         -8.6659e-02, -4.5561e-02, -1.0435e-01, -1.3207e-02,  1.9101e-01,
#          6.0242e-02,  5.1865e-02,  6.2336e-03, -3.0353e-01, -5.2684e-02,
#          3.7725e-02,  1.7308e-02, -2.2252e-03, -5.9559e-03, -1.4860e-03,
#         -2.8550e-02,  9.6724e-03,  3.7310e-02,  4.4816e-02,  3.8631e-01,
#         -5.6510e-03, -4.5588e-03, -7.4981e-04,  1.5941e-02,  1.4352e-01,
#          6.9571e-03,  9.7123e-03,  7.0265e-03, -7.0781e-02, -1.4472e-02,
#         -3.6984e-02, -2.5252e-02, -1.3466e-01, -3.8655e-02, -1.1350e-03,
#         -2.0762e-02,  1.8008e-02, -4.5117e-02, -1.5798e-01, -5.2725e-02,
#         -7.9743e-02, -3.4434e-02, -1.2017e-01, -1.1117e-01, -1.7297e-02,
#         -2.4515e-04,  7.3194e-03, -1.1194e-02, -3.1611e-02,  2.9801e-02,
#          2.6526e-02,  2.0917e-02,  2.6367e-02, -2.0328e-02,  2.1373e-02,
#         -5.2136e-02,  1.9310e-01,  4.1673e-02, -1.6062e-03, -7.4249e-02,
#         -4.0413e-02, -7.5780e-02, -1.8977e-02, -2.6403e-02,  1.7630e-02,
#         -4.5402e-02,  3.7094e-02, -3.7786e-02,  1.1041e-01,  9.9950e-02,
#         -3.2318e-02, -6.6167e-02, -4.9857e-03,  2.5404e-02, -2.8874e-02,
#          4.3953e-02,  1.2495e-02,  7.2713e-04,  6.6379e-02, -2.5317e-02,
#         -2.4073e-02,  4.4722e-02,  5.1625e-02,  1.7758e-02, -3.0089e-02,
#          3.0406e-02,  3.3645e-02, -2.9498e-02, -3.3229e-02, -1.1360e-02,
#         -6.6895e-02,  2.1772e-02,  1.4964e-01, -3.5466e-02, -1.3319e-02,
#         -1.2887e-01, -2.3099e-02, -2.9032e-02,  7.8629e-03, -3.0934e-01,
#         -1.0003e-01, -1.8144e-02,  1.0694e-02, -4.1066e-03,  3.8278e-02,
#         -8.9353e-03, -2.5112e-02, -2.0646e-02,  8.1572e-02,  2.1091e-02,
#         -1.9226e-01,  1.7592e-02,  1.3775e-01, -3.8977e-02,  6.4554e-03,
#          6.7759e-02,  3.3335e-02,  1.4779e-02,  5.6715e-02, -5.5729e-03,
#          1.2465e-02, -2.4020e-02,  1.3563e-02, -6.3556e-02, -1.6992e-03,
#         -3.0299e-02, -1.0550e-01, -1.0616e-03, -1.4339e-02, -3.4910e-02,
#         -2.5886e-01, -5.9557e-03, -3.5309e-02, -1.4286e-05,  2.6267e-02,
#          1.0505e-02,  2.8299e-02,  6.2807e-02,  1.7223e-01,  2.5183e-02,
#         -4.5877e-02, -6.9773e-02, -2.0328e-02,  3.1446e-02, -2.4529e-02,
#         -6.6726e-02,  1.6797e-02, -7.5360e-02, -2.9163e-02,  5.6187e-02,
#         -3.3172e-02, -3.3130e-02,  1.4096e-02, -4.5876e-02, -1.0970e-01,
#         -9.1463e-02,  9.5535e-02, -3.3220e-02, -3.8102e-02, -1.9081e-02,
#          1.9227e-02,  1.9708e-03, -7.4710e-02, -8.8083e-02, -1.9382e-02,
#         -1.0675e-02,  1.8408e-02, -2.7588e-02,  2.6229e-02, -1.4017e-02,
#          2.3126e-02,  7.8626e-03, -4.8435e-02, -2.5555e-02, -1.3353e-02,
#          4.7211e-03, -1.2993e-02, -1.8849e-02, -2.4678e-02, -1.1368e-02,
#         -1.1574e-01, -6.1512e-02,  2.4342e-03, -7.4745e-02,  4.4739e-02,
#          1.0485e-02,  1.2455e-02, -1.5020e-02, -3.9900e-02,  1.1037e-01,
#          1.3208e-02, -2.2604e-02, -5.0275e-02, -3.1289e-02, -1.2834e-02,
#         -1.8028e-02,  1.8902e-02,  2.2337e-04, -7.4164e-02,  3.6103e-02,
#          2.1465e-02,  1.8343e-02,  1.9701e-02, -1.2482e-02,  1.4073e-03,
#          1.9747e-02, -4.7899e-02, -3.6365e-02, -5.4548e-02,  3.3051e-02,
#         -6.9012e-02, -1.5928e-01, -9.0042e-03, -8.9888e-02,  1.4195e-01,
#         -1.1298e-01, -2.5044e-03, -1.0212e-01, -4.8519e-02, -1.1851e-01,
#         -3.6623e-02,  1.5519e-01,  3.1976e-03, -1.3946e-02, -4.2008e-02,
#         -4.6002e-02, -5.5250e-02, -7.5018e-02, -3.1867e-02,  2.3446e-02,
#          9.7282e-03, -1.1241e-01, -1.5345e-02, -1.9131e-02, -3.8942e-02,
#         -9.0737e-02,  4.2130e-03,  6.5806e-02,  2.7811e-02, -1.6938e-01,
#         -1.7129e-03,  3.8207e-02,  1.2200e-02,  3.8600e-02, -1.5666e-01,
#         -2.2980e-04, -9.5293e-03, -1.7284e-02, -2.1760e-01, -3.3956e-01,
#         -2.4381e-02, -1.7207e-02,  2.7246e-02,  2.1185e-02, -9.8379e-03,
#          2.5248e-02,  9.6581e-03,  4.0706e-02, -2.2910e-01,  3.1332e-02,
#          1.0054e-01, -3.9420e-02, -3.2073e-02, -1.2131e-02, -2.2759e-02,
#         -1.6493e-02, -2.3998e-02,  1.5102e-02, -2.5657e-02,  3.3619e-03,
#         -4.7703e-02, -3.6423e-02, -2.9414e-02, -2.2661e-02,  1.4743e-03,
#          2.3747e-02,  6.4968e-02, -2.6418e-02, -4.6847e-02,  1.5450e-02,
#          5.5668e-02, -8.6438e-02,  4.1963e-02, -3.7150e-02, -2.1739e-02,
#         -2.6674e-02, -3.2396e-02, -3.6569e-02, -6.6595e-02, -9.8850e-02,
#         -3.3553e-03,  4.1613e-02, -1.9943e-02,  1.2948e-02,  6.3844e-02,
#         -1.4451e-02, -2.4836e-02,  1.2665e-01, -6.5845e-02,  1.7154e-02,
#          2.5733e-01, -3.7186e-02, -1.5203e-01, -3.5912e-02, -2.5782e-02,
#         -2.8677e-02,  3.7525e-02, -2.2777e-02, -1.7252e-02, -3.0064e-02,
#         -4.0372e-02, -2.5969e-02,  7.4031e-02, -1.7852e-02, -1.1402e-02,
#         -3.7357e-02,  2.8382e-02, -5.8919e-02, -4.6606e-02, -7.1119e-02,
#          6.3601e-02,  4.0798e-02, -9.6501e-02, -2.0868e-02,  1.4952e-02,
#          4.4560e-03, -3.0213e-02, -3.1047e-02,  2.4181e-03, -5.4692e-02,
#          2.0647e-02, -2.7544e-02, -1.9714e-02, -3.5802e-02,  1.0703e-02,
#         -1.4185e-04, -8.4746e-03,  5.6952e-02,  6.9400e-03, -2.1497e-02,
#          9.7163e-02, -8.3905e-02, -5.9660e-03,  1.7887e-02,  1.8336e-02,
#         -7.2197e-03,  2.2482e-02, -1.0769e-02,  4.7605e-02,  4.9707e-02,
#         -1.3599e-02, -1.0286e-01, -2.8093e-02,  5.8114e-02,  6.1053e-04,
#         -1.0028e-01,  1.7483e-02, -2.9388e-02, -6.1534e-02, -9.1282e-02,
#         -7.2290e-02, -4.3511e-02,  2.8791e-02, -2.5928e-02, -3.6296e-02,
#         -2.3408e-02, -7.5807e-03, -2.6410e-02], requires_grad=True), Parameter containing:
# tensor([[-0.0266, -0.0006, -0.0280,  ..., -0.0868,  0.0164, -0.0284],
#         [-0.0295, -0.0019,  0.0534,  ..., -0.0061,  0.0380, -0.0039],
#         [ 0.0079,  0.0034, -0.0321,  ..., -0.0416,  0.0762,  0.0028],
#         ...,
#         [ 0.0184, -0.0395, -0.0160,  ..., -0.0595,  0.0428, -0.0313],
#         [ 0.0191, -0.0146, -0.0206,  ..., -0.0318, -0.0086,  0.0071],
#         [-0.0370, -0.0211, -0.0755,  ..., -0.0569,  0.0361, -0.0102]],
#        requires_grad=True), Parameter containing:
# tensor([ 9.5644e-02, -1.5662e-02, -8.8716e-02, -1.1009e-01, -7.6189e-02,
#          1.0609e-01, -3.6765e-01, -3.1680e-02, -8.8258e-02, -2.7483e-02,
#         -1.3945e-03, -8.9368e-02,  7.0704e-02, -1.1381e-01, -8.7690e-03,
#          3.3460e-02, -5.6634e-02, -8.6632e-03, -5.1757e-02,  4.0574e-02,
#          3.0262e-02, -6.6998e-02,  3.0042e-02, -1.3571e-02, -5.3723e-02,
#          1.1023e-01,  2.6178e-02, -4.1284e-02,  3.5702e-02, -1.1659e-02,
#          5.9294e-02, -2.0597e-03, -2.7487e-01, -3.1781e-01, -7.3198e-02,
#         -5.4948e-02, -7.8445e-02, -3.2975e-02, -5.2452e-02, -6.8884e-02,
#         -4.8793e-02, -1.1198e-01,  1.5292e-01, -8.0198e-04,  1.8853e-01,
#         -3.0579e-02,  9.0960e-03,  1.5947e-01,  5.8451e-02,  5.9531e-02,
#          2.4163e-04, -1.4431e-02, -9.7899e-03, -5.9583e-02,  1.5116e-01,
#         -1.0736e-01, -6.5358e-02,  1.6682e-02, -2.3551e-02, -1.9115e-02,
#         -4.2119e-02, -4.5007e-02, -3.1457e-02,  3.4576e-02,  2.8925e-02,
#         -4.6224e-03,  9.0925e-02, -4.5819e-02, -4.2308e-02,  1.4560e-02,
#          1.8649e-01, -4.8051e-02,  5.5574e-02, -1.0449e-02, -5.7263e-02,
#         -5.8479e-02, -7.4141e-02, -9.9814e-03, -1.2965e-02,  1.1823e-01,
#          4.3179e-02,  2.4893e-02, -9.1277e-03,  1.0587e-01,  6.4853e-02,
#         -3.8530e-02,  1.5661e-02, -1.0777e-01,  6.8289e-02, -8.1283e-02,
#         -3.7188e-02,  1.0126e-01, -2.8780e-03,  4.4786e-01,  3.5007e-03,
#         -2.1424e-02, -1.5969e-01, -2.1359e-02, -1.8238e-03,  6.4336e-02,
#          1.3317e-02, -2.4501e-02,  1.8877e-02,  1.4746e-02, -2.3384e-01,
#          6.5540e-02,  2.5248e-02,  1.4773e-03,  7.0950e-02,  3.4062e-02,
#          6.5557e-02, -3.9221e-02, -7.7849e-02, -9.4499e-03, -2.4417e-02],
#        requires_grad=True), Parameter containing:
# tensor([[ 9.0927e-02,  1.4655e-02, -4.4965e-02, -2.4187e-02, -2.9902e-02,
#          -2.5911e-02, -3.3028e-02,  6.1628e-03, -8.3272e-02,  1.6550e-02,
#           1.4125e-02, -3.7347e-02,  9.6605e-03, -1.9153e-02, -6.2318e-04,
#          -1.0754e-02, -1.5465e-03,  2.4879e-02, -4.2610e-02, -8.9792e-04,
#           3.3488e-02,  9.0245e-02,  5.7872e-03,  8.2913e-04, -1.3025e-02,
#          -3.8265e-02,  2.3554e-03,  5.2427e-02,  5.9688e-03,  5.7011e-02,
#           4.9559e-02,  4.3245e-02, -3.6641e-02, -3.8268e-02, -7.4686e-02,
#          -1.1272e-02, -1.6850e-04, -2.1675e-02, -1.5264e-02,  3.1030e-03,
#           2.1382e-02, -4.2858e-02, -1.8378e-02, -2.0086e-03, -5.8625e-03,
#          -3.8343e-02,  2.9528e-02,  7.9944e-03,  5.5443e-03,  3.6153e-02,
#           6.8932e-02, -2.9104e-02,  6.6458e-03,  4.3229e-04, -1.9463e-02,
#           3.0110e-02,  6.0658e-02,  4.2895e-02, -5.3042e-03, -9.6454e-04,
#          -5.6839e-02, -3.6114e-02, -4.2703e-03, -1.2965e-02,  2.3578e-02,
#           1.1365e-02, -1.7721e-02, -1.0964e-02, -8.0448e-02, -2.0554e-04,
#           1.0002e-02, -3.4878e-03, -4.7025e-02,  6.4156e-02, -2.3102e-02,
#           3.4294e-04, -5.7147e-02, -2.2392e-02,  4.3600e-02, -2.1540e-02,
#           3.2858e-03,  4.2024e-05,  6.0260e-02, -2.5721e-02, -6.9758e-03,
#           5.7116e-02,  5.3613e-04, -9.0786e-03,  2.1586e-02, -2.3549e-02,
#          -1.8729e-02, -1.0736e-02,  1.7442e-02,  5.9073e-02,  1.0831e-03,
#          -6.8850e-02, -6.7324e-02,  2.1024e-02,  2.0213e-02, -1.1409e-01,
#          -1.1565e-03,  8.9415e-02, -4.3320e-02,  3.9261e-03, -1.3809e-03,
#           2.1343e-02,  3.1127e-02,  2.9264e-02, -2.2927e-02, -5.8790e-02,
#           1.1765e-02,  7.0806e-02, -4.4326e-02, -1.0438e-01, -7.0296e-03]],
#        requires_grad=True), Parameter containing:
# tensor([0.0687], requires_grad=True)]

# %%
# %%script echo skipping
#
# # Set the network to evaluation mode
# net.eval()
# Out:
# Couldn't find program: 'echo'

# %%
rho_example, vx_example, vy_example, vz_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
torch.nan_to_num
inputs =  generate_input_data(rho_example, vx_example, vy_example, vz_example, epsilon_example)
inputs
# Out:
# tensor([[  5.0399,   6.9169,   4.5646,   9.2075,   8.9307],
#         [     nan,      nan,      nan,      nan,      nan],
#         [ 10.8714,  17.5291,  15.4886,  29.3673,  32.5780],
#         [  0.8992,   2.0343,   2.2791,   3.6320,   4.3828],
#         [  1.3606,   0.4545,   0.4686,   0.2174,   0.3636],
#         [  7.2260,   5.6707,   4.1747,   3.7822,   6.0070],
#         [  3.0166,   5.7396,  10.6108,   4.5929,  12.0221],
#         [ 13.3127,  43.7267,  60.8011,  31.7829,  74.1365],
#         [ 10.5011,   5.4970,   6.3969,  13.4820,  16.5364],
#         [  5.9394,  18.7949,   9.1873,  10.0485,  22.3233],
#         [  4.2210,   2.0200,   5.6754,   4.9467,   6.9639],
#         [  5.0719,   4.2946,  15.8759,  10.7540,  16.9608],
#         [  2.6084,   2.8277,   4.4612,   3.2411,   5.4548],
#         [  6.4215,  10.3266,  10.9543,   9.4960,  13.4239],
#         [  9.0796,  35.8940,  13.7212,  16.6758,  36.8613],
#         [  0.8893,   0.7826,   0.7747,   0.6457,   1.3680],
#         [  8.9252,  20.5648,   8.7797,  14.5330,  27.0526],
#         [ 16.7203,  86.4251,  68.9657,  72.2462, 117.1904],
#         [     nan,      nan,      nan,      nan,      nan],
#         [  6.4830,   5.4265,  12.0569,  12.0750,  14.5434]])

# %%
# %%script echo skipping
#
# # Pass the inputs to the network and get the outputs
# outputs = [net(input) for input in inputs]
# # Print the outputs
# outputs
# Out:
# Couldn't find program: 'echo'

# %%
# Set the network to evaluation mode
net_loaded.eval()

# %%
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 5) to trace the model
dummy_input = torch.randn(1, 5).to(device)
dummy_input

# Ensure that net_loaded is in evaluation mode.
net_loaded.eval()

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("net.pt")
save_file("net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
