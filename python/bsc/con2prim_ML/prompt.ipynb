# %% [markdown]
# # Neural network to learn conservative to primitive conversion
#
# <u>**This is the script used that was used as a prompt for the SRHD Prompt 5**.</u> (Or actually, the converted notebook was used as the input. The conversion can be done with teh first cell in this notebook)
#
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to approximate the function $f$ that we define in this notebook.

# %% [markdown]
# Use this first cell to convert the notebook to a python script.

# %%
# !jupyter nbconvert script.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# [NbConvertApp] Converting notebook script.ipynb to script
# [NbConvertApp] Writing 20370 bytes to script.py

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import optuna
import tensorboardX as tbx

# %% [markdown]
# ## Generating the data

# %%
# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Generating the data
np.random.seed(0)
x = np.random.uniform(-10, 10, size=(10000, 3))
y = 2 * x[:, 0] - 3 * x[:, 1] + 5 * x[:, 2] + np.random.normal(0, 1, size=10000)

# Splitting the data into train and test sets
x_train = torch.tensor(x[:8000], dtype=torch.float32).to(device) # Added moving the tensor to the device
y_train = torch.tensor(y[:8000], dtype=torch.float32).to(device) # Added moving the tensor to the device
x_test = torch.tensor(x[8000:], dtype=torch.float32).to(device) # Added moving the tensor to the device
y_test = torch.tensor(y[8000:], dtype=torch.float32).to(device) # Added moving the tensor to the device

# %% [markdown]
# ## Checking and visualizing the data

# %%
# Checking for NaN values in the data
print("Number of NaN values in x:", np.isnan(x).sum())
print("Number of NaN values in y:", np.isnan(y).sum())

# Plotting the input and output variables
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.scatter(x[:, 0], y)
plt.xlabel("x0")
plt.ylabel("y")
plt.subplot(2, 2, 2)
plt.scatter(x[:, 1], y)
plt.xlabel("x1")
plt.ylabel("y")
plt.subplot(2, 2, 3)
plt.scatter(x[:, 2], y)
plt.xlabel("x2")
plt.ylabel("y")
plt.tight_layout()
plt.show()

# Computing the mean and standard deviation of the data
print("Mean and standard deviation of x_train:", torch.mean(x_train), torch.std(x_train))
print("Mean and standard deviation of y_train:", torch.mean(y_train), torch.std(y_train))
print("Mean and standard deviation of x_test:", torch.mean(x_test), torch.std(x_test))
print("Mean and standard deviation of y_test:", torch.mean(y_test), torch.std(y_test))
# Out:
# Number of NaN values in x: 0
# Number of NaN values in y: 0
# <Axes: >
# Text(0.5, 0, 'x0')
# Text(0, 0.5, 'y')
# <Axes: >
# Text(0.5, 0, 'x1')
# Text(0, 0.5, 'y')
# <Axes: >
# Text(0.5, 0, 'x2')
# Text(0, 0.5, 'y')
# Mean and standard deviation of x_train: tensor(-0.0730) tensor(5.8088)
# Mean and standard deviation of y_train: tensor(0.0441) tensor(35.7456)
# Mean and standard deviation of x_test: tensor(0.0390) tensor(5.7697)
# Mean and standard deviation of y_test: tensor(0.0522) tensor(35.1231)

# %% [markdown]
# ## Defining the neural network class

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))

        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Setting the search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler), where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler.
    """

    # Sampling the hyperparameters from the search space
    n_layers = trial.suggest_int("n_layers", 1, 5)
    n_layers = trial.suggest_int("n_layers", 1, 5)
    n_units = [trial.suggest_int(f"n_units_{i}", 1, 256) for i in range(n_layers)]
    hidden_activation_name = trial.suggest_categorical("hidden_activation", ["ReLU", "Tanh", "Sigmoid"])
    output_activation_name = trial.suggest_categorical("output_activation", ["ReLU", "Tanh", "Sigmoid"])
    # Added another common loss function: CrossEntropyLoss
    loss_name = trial.suggest_categorical("loss", ["MSE", "MAE", "Huber", "CrossEntropy"])
    # Added another common optimizer: Adagrad
    optimizer_name = trial.suggest_categorical("optimizer", ["SGD", "Adam", "RMSprop", "Adagrad"])
    lr = trial.suggest_loguniform("lr", 1e-5, 1e-1)
    batch_size = trial.suggest_int("batch_size", 1, 512)
    # Increased the maximum number of epochs that are tried
    n_epochs = trial.suggest_int("n_epochs", 10, 200)
    # Added the possibility of having different schedulers: CosineAnnealingLR and ReduceLROnPlateau
    scheduler_name = trial.suggest_categorical("scheduler", ["None", "StepLR", "ExponentialLR", "CosineAnnealingLR", "ReduceLROnPlateau"])

    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    elif output_activation_name == "Tanh":
        output_activation = nn.Tanh()
    else:
        output_activation = nn.Sigmoid()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss()
    else:
        # Added creating the CrossEntropyLoss function
        loss_fn = nn.CrossEntropyLoss()

    # Creating the network with the sampled hyperparameters
    net = Net(n_layers, n_units, hidden_activation, output_activation).to(device) # Added moving the network to the device

    # Creating the optimizer from its name
    if optimizer_name == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=lr)
    elif optimizer_name == "Adam":
        optimizer = optim.Adam(net.parameters(), lr=lr)
    elif optimizer_name == "RMSprop":
        optimizer = optim.RMSprop(net.parameters(), lr=lr)
    else:
        # Added creating the Adagrad optimizer
        optimizer = optim.Adagrad(net.parameters(), lr=lr)

    # Creating the learning rate scheduler from its name
    if scheduler_name == "StepLR":
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif scheduler_name == "ExponentialLR":
        scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    elif scheduler_name == "CosineAnnealingLR":
        # Added creating the CosineAnnealingLR scheduler
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
    elif scheduler_name == "ReduceLROnPlateau":
        # Added creating the ReduceLROnPlateau scheduler
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.1, patience=10)
    else:
        scheduler = None

    # Returning the network, the loss function, the optimizer, the batch size, the number of epochs and the scheduler
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler

# %% [markdown]
# ## The train and eval loop

# %%
# Defining a function to train and evaluate a network on the train and test sets
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler):
    """Trains and evaluates a network on the train and test sets.

    Args:
        net (Net): The network to train and evaluate.
        loss_fn (torch.nn.Module): The loss function to use.
        optimizer (torch.optim.Optimizer): The optimizer to use.
        batch_size (int): The batch size to use.
        n_epochs (int): The number of epochs to train for.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.

    Returns:
        tuple: A tuple of (train_losses, test_losses,
            train_accuracies, test_accuracies), where train_losses and test_losses are lists of average losses per epoch for the train and test sets,
            train_accuracies and test_accuracies are lists of average accuracies per epoch for the train and test sets.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size)

    # Initializing lists to store the losses and accuracies for each epoch
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    # Looping over the epochs
    for epoch in range(n_epochs):
        # Setting the network to training mode
        net.train()
        # Initializing variables to store the total loss and correct predictions for the train set
        train_loss = 0.0
        train_correct = 0
        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:
            # Zeroing the gradients
            optimizer.zero_grad()
            # Forward pass
            y_pred = net(x_batch)
            # Reshaping the target tensor to match the input tensor
            y_batch = y_batch.view(-1, 1)
            # Computing the loss
            loss = loss_fn(y_pred, y_batch)
            # Backward pass and optimization
            loss.backward()
            optimizer.step()
            # Updating the total loss and correct predictions
            train_loss += loss.item() * x_batch.size(0)
            train_correct += torch.sum((y_pred - y_batch).abs() < 1e-3)

        # Setting the network to evaluation mode
        net.eval()
        # Initializing variables to store the total loss and correct predictions for the test set
        test_loss = 0.0
        test_correct = 0
        # Looping over the batches in the test set
        for x_batch, y_batch in test_loader:
            # Forward pass
            y_pred = net(x_batch)
            # Reshaping the target tensor to match the input tensor
            y_batch = y_batch.view(-1, 1)
            # Computing the loss
            loss = loss_fn(y_pred, y_batch)
            # Updating the total loss and correct predictions
            test_loss += loss.item() * x_batch.size(0)
            test_correct += torch.sum((y_pred - y_batch).abs() < 1e-3)

        # Computing the average losses and accuracies for the train and test sets
        train_loss /= len(x_train)
        test_loss /= len(x_test)
        train_accuracy = train_correct / len(x_train)
        test_accuracy = test_correct / len(x_test)

        # Appending the losses and accuracies to the lists
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)

        # Updating the learning rate scheduler with validation loss if applicable
        if scheduler is not None: # Added checking if scheduler is not None
            if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_loss) # Added passing validation loss as metric value
            else:
                scheduler.step()

        # Printing the epoch summary
        print(f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

    # Returning the lists of losses and accuracies
    return train_losses, test_losses, train_accuracies, test_accuracies

# %%
# Defining a function to compute the objective value for a trial
def objective(trial):
    """Computes the objective value (final test loss) for a trial.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The objective value (final test loss) for the trial.
    """
    # Creating a trial network and optimizer with the create_model function
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler = create_model(trial)

    # Training and evaluating the network with the train_and_eval function
    train_losses, test_losses, train_accuracies, test_accuracies = train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler)

    # Returning the final test loss as the objective value
    return test_losses[-1]

# %% [markdown]
# ## Finding the best hyperparameters with Optuna

# %%
# Creating a study object with Optuna
study = optuna.create_study(direction="minimize")

# Running the optimization for 100 trials
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-05-04 19:29:05,378] A new study created in memory with name: no-name-d4314516-045b-423b-aea4-9feb086c89d9
# /tmp/ipykernel_27400/1147161505.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   lr = trial.suggest_loguniform("lr", 1e-5, 1e-1)
# Epoch 1: Train Loss: 28.9927, Train Accuracy: 0.0000, Test Loss: 28.1356, Test Accuracy: 0.0000
# Epoch 2: Train Loss: 28.9240, Train Accuracy: 0.0000, Test Loss: 28.0342, Test Accuracy: 0.0005
# Epoch 3: Train Loss: 28.7852, Train Accuracy: 0.0000, Test Loss: 27.8791, Test Accuracy: 0.0000
# Epoch 4: Train Loss: 28.6501, Train Accuracy: 0.0000, Test Loss: 27.7858, Test Accuracy: 0.0000
# Epoch 5: Train Loss: 28.5899, Train Accuracy: 0.0000, Test Loss: 27.7503, Test Accuracy: 0.0000
# Epoch 6: Train Loss: 28.5672, Train Accuracy: 0.0000, Test Loss: 27.7347, Test Accuracy: 0.0000
# Epoch 7: Train Loss: 28.5563, Train Accuracy: 0.0000, Test Loss: 27.7261, Test Accuracy: 0.0000
# Epoch 8: Train Loss: 28.5501, Train Accuracy: 0.0000, Test Loss: 27.7217, Test Accuracy: 0.0000
# Epoch 9: Train Loss: 28.5460, Train Accuracy: 0.0000, Test Loss: 27.7179, Test Accuracy: 0.0000
# Epoch 10: Train Loss: 28.5433, Train Accuracy: 0.0000, Test Loss: 27.7150, Test Accuracy: 0.0000
# Epoch 11: Train Loss: 28.5412, Train Accuracy: 0.0000, Test Loss: 27.7130, Test Accuracy: 0.0000
# Epoch 12: Train Loss: 28.5396, Train Accuracy: 0.0000, Test Loss: 27.7117, Test Accuracy: 0.0000
# Epoch 13: Train Loss: 28.5383, Train Accuracy: 0.0000, Test Loss: 27.7104, Test Accuracy: 0.0000
# Epoch 14: Train Loss: 28.5373, Train Accuracy: 0.0000, Test Loss: 27.7097, Test Accuracy: 0.0000
# Epoch 15: Train Loss: 28.5366, Train Accuracy: 0.0000, Test Loss: 27.7088, Test Accuracy: 0.0000
# Epoch 16: Train Loss: 28.5360, Train Accuracy: 0.0000, Test Loss: 27.7080, Test Accuracy: 0.0000
# Epoch 17: Train Loss: 28.5353, Train Accuracy: 0.0000, Test Loss: 27.7076, Test Accuracy: 0.0000
# Epoch 18: Train Loss: 28.5347, Train Accuracy: 0.0000, Test Loss: 27.7069, Test Accuracy: 0.0000
# Epoch 19: Train Loss: 28.5344, Train Accuracy: 0.0000, Test Loss: 27.7065, Test Accuracy: 0.0000
# Epoch 20: Train Loss: 28.5341, Train Accuracy: 0.0000, Test Loss: 27.7063, Test Accuracy: 0.0000
# Epoch 21: Train Loss: 28.5337, Train Accuracy: 0.0000, Test Loss: 27.7059, Test Accuracy: 0.0000
# Epoch 22: Train Loss: 28.5334, Train Accuracy: 0.0000, Test Loss: 27.7057, Test Accuracy: 0.0000
# Epoch 23: Train Loss: 28.5332, Train Accuracy: 0.0001, Test Loss: 27.7054, Test Accuracy: 0.0000
# Epoch 24: Train Loss: 28.5330, Train Accuracy: 0.0000, Test Loss: 27.7052, Test Accuracy: 0.0000
# Epoch 25: Train Loss: 28.5328, Train Accuracy: 0.0000, Test Loss: 27.7050, Test Accuracy: 0.0000
# Epoch 26: Train Loss: 28.5327, Train Accuracy: 0.0000, Test Loss: 27.7049, Test Accuracy: 0.0000
# Epoch 27: Train Loss: 28.5325, Train Accuracy: 0.0000, Test Loss: 27.7048, Test Accuracy: 0.0000
# Epoch 28: Train Loss: 28.5324, Train Accuracy: 0.0000, Test Loss: 27.7046, Test Accuracy: 0.0000
# Epoch 29: Train Loss: 28.5323, Train Accuracy: 0.0000, Test Loss: 27.7045, Test Accuracy: 0.0000
# Epoch 30: Train Loss: 28.5322, Train Accuracy: 0.0000, Test Loss: 27.7044, Test Accuracy: 0.0000
# Epoch 31: Train Loss: 28.5321, Train Accuracy: 0.0000, Test Loss: 27.7043, Test Accuracy: 0.0000
# Epoch 32: Train Loss: 28.5320, Train Accuracy: 0.0000, Test Loss: 27.7042, Test Accuracy: 0.0000
# Epoch 33: Train Loss: 28.5320, Train Accuracy: 0.0000, Test Loss: 27.7041, Test Accuracy: 0.0000
# Epoch 34: Train Loss: 28.5319, Train Accuracy: 0.0000, Test Loss: 27.7041, Test Accuracy: 0.0000
# Epoch 35: Train Loss: 28.5318, Train Accuracy: 0.0000, Test Loss: 27.7041, Test Accuracy: 0.0000
# Epoch 36: Train Loss: 28.5318, Train Accuracy: 0.0000, Test Loss: 27.7040, Test Accuracy: 0.0000
# Epoch 37: Train Loss: 28.5318, Train Accuracy: 0.0000, Test Loss: 27.7039, Test Accuracy: 0.0000
# Epoch 38: Train Loss: 28.5317, Train Accuracy: 0.0000, Test Loss: 27.7039, Test Accuracy: 0.0000
# Epoch 39: Train Loss: 28.5317, Train Accuracy: 0.0000, Test Loss: 27.7038, Test Accuracy: 0.0000
# Epoch 40: Train Loss: 28.5316, Train Accuracy: 0.0000, Test Loss: 27.7038, Test Accuracy: 0.0000
# Epoch 41: Train Loss: 28.5316, Train Accuracy: 0.0000, Test Loss: 27.7038, Test Accuracy: 0.0000
# Epoch 42: Train Loss: 28.5316, Train Accuracy: 0.0000, Test Loss: 27.7038, Test Accuracy: 0.0000
# Epoch 43: Train Loss: 28.5316, Train Accuracy: 0.0000, Test Loss: 27.7037, Test Accuracy: 0.0000
# Epoch 44: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7037, Test Accuracy: 0.0000
# Epoch 45: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7037, Test Accuracy: 0.0000
# Epoch 46: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7037, Test Accuracy: 0.0000
# Epoch 47: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 48: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 49: Train Loss: 28.5315, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 50: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 51: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 52: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 53: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 54: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 55: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 56: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 57: Train Loss: 28.5314, Train Accuracy: 0.0000, Test Loss: 27.7036, Test Accuracy: 0.0000
# Epoch 58: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 59: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 60: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 61: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 62: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 63: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 64: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 65: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 66: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 67: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 68: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 69: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 70: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 71: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 72: Train Loss: 28.5314, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 73: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 74: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 75: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 76: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 77: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 78: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 79: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 80: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 81: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 82: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 83: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 84: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 85: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 86: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 87: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 88: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 89: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 90: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 91: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 92: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 93: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 94: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 95: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 96: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 97: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 98: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 99: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 100: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 101: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# [I 2023-05-04 19:29:23,632] Trial 0 finished with value: 27.70350021648407 and parameters: {'n_layers': 5, 'n_units_0': 150, 'n_units_1': 235, 'n_units_2': 166, 'n_units_3': 177, 'n_units_4': 128, 'hidden_activation': 'ReLU', 'output_activation': 'Sigmoid', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 7.228679339815848e-05, 'batch_size': 331, 'n_epochs': 102, 'scheduler': 'ExponentialLR'}. Best is trial 0 with value: 27.70350021648407.
# Epoch 102: Train Loss: 28.5313, Train Accuracy: 0.0001, Test Loss: 27.7035, Test Accuracy: 0.0000
# Epoch 1: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 2: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 3: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 4: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 5: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 6: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 7: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 8: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 9: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 10: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 11: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 12: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 13: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 14: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 15: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 16: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 17: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 18: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 19: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 20: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 21: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 22: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 23: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 24: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 25: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 26: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 27: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 28: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 29: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 30: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 31: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 32: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 33: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 34: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 35: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 36: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 37: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 38: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 39: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 40: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 41: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 42: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 43: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 44: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 45: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 46: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 47: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 48: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 49: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 50: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 51: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 52: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 53: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 54: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 55: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 56: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 57: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 58: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 59: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 60: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 61: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 62: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 63: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 64: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 65: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 66: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 67: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 68: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 69: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 70: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 71: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 72: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 73: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 74: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 75: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 76: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 77: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 78: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 79: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 80: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 81: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 82: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 83: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 84: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 85: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 86: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 87: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 88: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 89: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 90: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 91: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 92: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 93: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 94: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 95: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 96: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 97: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 98: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 99: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 100: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 101: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 102: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 103: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 104: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 105: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 106: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 107: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 108: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 109: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 110: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 111: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 112: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 113: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 114: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 115: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 116: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 117: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 118: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 119: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 120: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 121: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 122: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 123: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 124: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 125: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 126: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 127: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 128: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 129: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 130: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 131: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 132: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 133: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 134: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 135: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 136: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 137: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 138: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 139: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 140: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 141: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 142: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 143: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 144: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 145: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 146: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 147: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 148: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 149: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 150: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 151: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 152: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# [I 2023-05-04 19:29:43,746] Trial 1 finished with value: 0.0 and parameters: {'n_layers': 5, 'n_units_0': 88, 'n_units_1': 160, 'n_units_2': 57, 'n_units_3': 125, 'n_units_4': 198, 'hidden_activation': 'Sigmoid', 'output_activation': 'Tanh', 'loss': 'CrossEntropy', 'optimizer': 'RMSprop', 'lr': 2.8581465528391114e-05, 'batch_size': 477, 'n_epochs': 154, 'scheduler': 'StepLR'}. Best is trial 1 with value: 0.0.
# Epoch 153: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 154: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 1: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 2: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 3: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 4: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 5: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 6: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 7: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 8: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 9: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 10: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 11: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 12: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 13: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 14: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 15: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 16: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 17: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 18: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 19: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 20: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 21: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 22: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 23: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 24: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 25: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 26: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 27: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 28: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 29: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 30: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 31: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 32: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 33: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 34: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 35: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 36: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 37: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 38: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 39: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 40: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 41: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 42: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 43: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 44: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 45: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 46: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 47: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 48: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 49: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 50: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 51: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 52: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 53: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 54: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 55: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 56: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 57: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 58: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 59: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 60: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 61: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 62: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 63: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 64: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 65: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 66: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 67: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 68: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 69: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 70: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 71: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 72: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 73: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 74: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 75: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 76: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 77: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 78: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 79: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 80: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 81: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 82: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 83: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 84: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 85: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 86: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 87: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 88: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 89: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 90: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 91: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 92: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 93: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 94: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 95: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 96: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 97: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 98: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 99: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 100: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 101: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 102: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 103: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 104: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 105: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 106: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 107: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 108: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 109: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 110: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 111: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 112: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 113: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 114: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 115: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 116: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 117: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 118: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 119: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 120: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 121: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 122: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 123: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 124: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 125: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 126: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 127: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 128: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 129: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 130: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 131: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 132: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 133: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 134: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 135: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 136: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 137: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 138: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 139: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 140: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 141: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 142: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 143: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 144: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 145: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 146: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 147: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 148: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 149: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 150: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 151: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 152: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 153: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 154: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 155: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 156: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 157: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 158: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 159: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 160: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 161: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 162: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 163: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 164: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 165: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 166: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 167: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 168: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 169: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 170: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 171: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 172: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 173: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 174: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 175: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 176: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 177: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 178: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 179: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 180: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 181: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 182: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 183: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 184: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 185: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 186: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 187: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 188: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# [I 2023-05-04 19:30:12,813] Trial 2 finished with value: 0.0 and parameters: {'n_layers': 2, 'n_units_0': 25, 'n_units_1': 11, 'hidden_activation': 'ReLU', 'output_activation': 'Sigmoid', 'loss': 'CrossEntropy', 'optimizer': 'Adam', 'lr': 0.001859837594520376, 'batch_size': 88, 'n_epochs': 189, 'scheduler': 'None'}. Best is trial 1 with value: 0.0.
# Epoch 189: Train Loss: 0.0000, Train Accuracy: 0.0001, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 1: Train Loss: 1250.3432, Train Accuracy: 0.0000, Test Loss: 1204.8981, Test Accuracy: 0.0000
# Epoch 2: Train Loss: 1248.6138, Train Accuracy: 0.0000, Test Loss: 1204.8481, Test Accuracy: 0.0000
# Epoch 3: Train Loss: 1248.5871, Train Accuracy: 0.0000, Test Loss: 1204.8312, Test Accuracy: 0.0000
# Epoch 4: Train Loss: 1248.5756, Train Accuracy: 0.0000, Test Loss: 1204.8233, Test Accuracy: 0.0000
# Epoch 5: Train Loss: 1248.5703, Train Accuracy: 0.0000, Test Loss: 1204.8185, Test Accuracy: 0.0000
# Epoch 6: Train Loss: 1248.5666, Train Accuracy: 0.0000, Test Loss: 1204.8143, Test Accuracy: 0.0000
# Epoch 7: Train Loss: 1248.5637, Train Accuracy: 0.0000, Test Loss: 1204.8117, Test Accuracy: 0.0000
# Epoch 8: Train Loss: 1248.5618, Train Accuracy: 0.0000, Test Loss: 1204.8100, Test Accuracy: 0.0005
# Epoch 9: Train Loss: 1248.5601, Train Accuracy: 0.0000, Test Loss: 1204.8119, Test Accuracy: 0.0000
# Epoch 10: Train Loss: 1248.5588, Train Accuracy: 0.0000, Test Loss: 1204.8080, Test Accuracy: 0.0000
# Epoch 11: Train Loss: 1248.5578, Train Accuracy: 0.0000, Test Loss: 1204.8084, Test Accuracy: 0.0000
# Epoch 12: Train Loss: 1248.5572, Train Accuracy: 0.0000, Test Loss: 1204.8066, Test Accuracy: 0.0005
# Epoch 13: Train Loss: 1248.5564, Train Accuracy: 0.0000, Test Loss: 1204.8058, Test Accuracy: 0.0000
# Epoch 14: Train Loss: 1248.5557, Train Accuracy: 0.0001, Test Loss: 1204.8048, Test Accuracy: 0.0000
# Epoch 15: Train Loss: 1248.5549, Train Accuracy: 0.0000, Test Loss: 1204.8066, Test Accuracy: 0.0000
# Epoch 16: Train Loss: 1248.5548, Train Accuracy: 0.0000, Test Loss: 1204.8041, Test Accuracy: 0.0000
# Epoch 17: Train Loss: 1248.5541, Train Accuracy: 0.0000, Test Loss: 1204.8079, Test Accuracy: 0.0000
# Epoch 18: Train Loss: 1248.5540, Train Accuracy: 0.0000, Test Loss: 1204.8040, Test Accuracy: 0.0000
# Epoch 19: Train Loss: 1248.5536, Train Accuracy: 0.0001, Test Loss: 1204.8044, Test Accuracy: 0.0000
# Epoch 20: Train Loss: 1248.5534, Train Accuracy: 0.0000, Test Loss: 1204.8033, Test Accuracy: 0.0000
# Epoch 21: Train Loss: 1248.5528, Train Accuracy: 0.0000, Test Loss: 1204.8057, Test Accuracy: 0.0000
# Epoch 22: Train Loss: 1248.5528, Train Accuracy: 0.0000, Test Loss: 1204.8033, Test Accuracy: 0.0000
# Epoch 23: Train Loss: 1248.5526, Train Accuracy: 0.0001, Test Loss: 1204.8033, Test Accuracy: 0.0000
# Epoch 24: Train Loss: 1248.5524, Train Accuracy: 0.0000, Test Loss: 1204.8032, Test Accuracy: 0.0000
# Epoch 25: Train Loss: 1248.5522, Train Accuracy: 0.0000, Test Loss: 1204.8024, Test Accuracy: 0.0000
# Epoch 26: Train Loss: 1248.5519, Train Accuracy: 0.0000, Test Loss: 1204.8017, Test Accuracy: 0.0000
# Epoch 27: Train Loss: 1248.5518, Train Accuracy: 0.0000, Test Loss: 1204.8013, Test Accuracy: 0.0000
# Epoch 28: Train Loss: 1248.5517, Train Accuracy: 0.0001, Test Loss: 1204.8020, Test Accuracy: 0.0000
# Epoch 29: Train Loss: 1248.5515, Train Accuracy: 0.0000, Test Loss: 1204.8026, Test Accuracy: 0.0000
# Epoch 30: Train Loss: 1248.5514, Train Accuracy: 0.0000, Test Loss: 1204.8022, Test Accuracy: 0.0000
# Epoch 31: Train Loss: 1248.5513, Train Accuracy: 0.0000, Test Loss: 1204.8022, Test Accuracy: 0.0000
# Epoch 32: Train Loss: 1248.5511, Train Accuracy: 0.0000, Test Loss: 1204.8016, Test Accuracy: 0.0000
# Epoch 33: Train Loss: 1248.5511, Train Accuracy: 0.0000, Test Loss: 1204.8018, Test Accuracy: 0.0000
# Epoch 34: Train Loss: 1248.5510, Train Accuracy: 0.0000, Test Loss: 1204.8019, Test Accuracy: 0.0000
# Epoch 35: Train Loss: 1248.5509, Train Accuracy: 0.0000, Test Loss: 1204.8018, Test Accuracy: 0.0000
# Epoch 36: Train Loss: 1248.5509, Train Accuracy: 0.0000, Test Loss: 1204.8018, Test Accuracy: 0.0000
# Epoch 37: Train Loss: 1248.5508, Train Accuracy: 0.0000, Test Loss: 1204.8019, Test Accuracy: 0.0000
# ...
# Epoch 145: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 146: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 147: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 148: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 149: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 150: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 151: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 152: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 153: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 154: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 155: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 156: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 157: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 158: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 159: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 160: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 161: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 162: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 163: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 164: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 165: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 166: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 167: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 168: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 169: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 170: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 171: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 172: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 173: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 174: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 175: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 176: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 177: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 178: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 179: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 180: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 181: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 182: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 183: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 184: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 185: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 186: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 187: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 188: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 189: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# [I 2023-05-04 19:48:00,998] Trial 41 finished with value: 0.0 and parameters: {'n_layers': 2, 'n_units_0': 10, 'n_units_1': 102, 'hidden_activation': 'Sigmoid', 'output_activation': 'Tanh', 'loss': 'CrossEntropy', 'optimizer': 'Adam', 'lr': 0.0001660260244270245, 'batch_size': 165, 'n_epochs': 191, 'scheduler': 'ReduceLROnPlateau'}. Best is trial 1 with value: 0.0.
# Epoch 190: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 191: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0005
# Epoch 1: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 2: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 3: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 4: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 5: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 6: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 7: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 8: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 9: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 10: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 11: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 12: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 13: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 14: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 15: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 16: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 17: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 18: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 19: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 20: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# [W 2023-05-04 19:48:04,327] Trial 42 failed with parameters: {'n_layers': 2, 'n_units_0': 1, 'n_units_1': 116, 'hidden_activation': 'Sigmoid', 'output_activation': 'Tanh', 'loss': 'CrossEntropy', 'optimizer': 'Adam', 'lr': 8.39657741799233e-05, 'batch_size': 102, 'n_epochs': 188, 'scheduler': 'ReduceLROnPlateau'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_27400/851963682.py", line 15, in objective
#     train_losses, test_losses, train_accuracies, test_accuracies = train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler)
#   File "/tmp/ipykernel_27400/2609798293.py", line 47, in train_and_eval
#     optimizer.step()
#   File "/home/codespace/.local/lib/python3.10/site-packages/torch/optim/optimizer.py", line 280, in wrapper
#     out = func(*args, **kwargs)
#   File "/home/codespace/.local/lib/python3.10/site-packages/torch/optim/optimizer.py", line 33, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/home/codespace/.local/lib/python3.10/site-packages/torch/optim/adam.py", line 141, in step
#     adam(
#   File "/home/codespace/.local/lib/python3.10/site-packages/torch/optim/adam.py", line 281, in adam
#     func(params,
#   File "/home/codespace/.local/lib/python3.10/site-packages/torch/optim/adam.py", line 391, in _single_tensor_adam
#     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# KeyboardInterrupt
# [W 2023-05-04 19:48:04,329] Trial 42 failed with value None.
# Epoch 21: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# Epoch 22: Train Loss: 0.0000, Train Accuracy: 0.0000, Test Loss: 0.0000, Test Accuracy: 0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       2 study = optuna.create_study(direction="minimize")
#       4 # Running the optimization for 100 trials
# ----> 5 study.optimize(objective, n_trials=100)
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/study.py:425, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     321 def optimize(
#     322     self,
#     323     func: ObjectiveFuncType,
#    (...)
#     330     show_progress_bar: bool = False,
#     331 ) -> None:
#     332     """Optimize an objective function.
#     333
#     334     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     422             If nested invocation of this method occurs.
#     423     """
# --> 425     _optimize(
#     426         study=self,
#     427         func=func,
#     428         n_trials=n_trials,
#     429         timeout=timeout,
#     430         n_jobs=n_jobs,
#     431         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     432         callbacks=callbacks,
#     433         gc_after_trial=gc_after_trial,
#     434         show_progress_bar=show_progress_bar,
#     435     )
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[20], line 15, in objective(trial)
#      12 net, loss_fn, optimizer, batch_size, n_epochs, scheduler = create_model(trial)
#      14 # Training and evaluating the network with the train_and_eval function
# ---> 15 train_losses, test_losses, train_accuracies, test_accuracies = train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler)
#      17 # Returning the final test loss as the objective value
#      18 return test_losses[-1]
#
# Cell In[25], line 47, in train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler)
#      45 # Backward pass and optimization
#      46 loss.backward()
# ---> 47 optimizer.step()
#      48 # Updating the total loss and correct predictions
#      49 train_loss += loss.item() * x_batch.size(0)
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     389     denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     390 else:
# --> 391     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     393 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training with the best parameters

# %%
# Printing the best parameters and the best value
print("Best parameters:", study.best_params)
print("Best value:", study.best_value)

# Creating a network with the best parameters
best_net, best_loss_fn, best_optimizer, best_batch_size, best_n_epochs, best_scheduler = create_model(study.best_trial)

# Training and evaluating the network with the best parameters
best_train_losses, best_test_losses, best_train_accuracies, best_test_accuracies = train_and_eval(best_net, best_loss_fn, best_optimizer, best_batch_size, best_n_epochs, best_scheduler)

# Saving the network with the best parameters
torch.save(best_net.state_dict(), "best_net.pth")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Printing the best parameters and the best value
# ----> 2 print("Best parameters:", study.best_params)
#       3 print("Best value:", study.best_value)
#       5 # Creating a network with the best parameters
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/study.py:116, in Study.best_params(self)
#     104 @property
#     105 def best_params(self) -> Dict[str, Any]:
#     106     """Return parameters of the best trial in the study.
#     107
#     108     .. note::
#    (...)
#     113
#     114     """
# --> 116     return self.best_trial.params
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/study/study.py:159, in Study.best_trial(self)
#     153 if self._is_multi_objective():
#     154     raise RuntimeError(
#     155         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     156         "using Study.best_trials to retrieve a list containing the best trials."
#     157     )
# --> 159 return copy.deepcopy(self._storage.get_best_trial(self._study_id))
#
# File ~/.python/current/lib/python3.10/site-packages/optuna/storages/_in_memory.py:250, in InMemoryStorage.get_best_trial(self, study_id)
#     247 best_trial_id = self._studies[study_id].best_trial_id
#     249 if best_trial_id is None:
# --> 250     raise ValueError("No trials are completed yet.")
#     251 elif len(self._studies[study_id].directions) > 1:
#     252     raise RuntimeError(
#     253         "Best trial can be obtained only for single-objective optimization."
#     254     )
#
# ValueError: No trials are completed yet.

# %% [markdown]
# ## Visualizing results

# %%
# Creating a tensorboard writer
writer = tbx.SummaryWriter()

# Logging the losses and accuracies for each epoch
for epoch in range(best_n_epochs):
    writer.add_scalars("Loss", {"Train": best_train_losses[epoch], "Test": best_test_losses[epoch]}, epoch + 1)
    writer.add_scalars("Accuracy", {"Train": best_train_accuracies[epoch], "Test": best_test_accuracies[epoch]}, epoch + 1)

# Closing the writer
writer.close()

# Plotting the predicted values and true values for a random sample of 1000 test points
indices = np.random.choice(len(x_test), size=1000)
x_sample = x_test[indices]
y_sample = y_test[indices]
y_pred = best_net(x_sample).detach().numpy()
plt.scatter(y_sample, y_pred, alpha=0.1)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Predicted Values vs True Values")
plt.savefig("pred_vs_true.png")
plt.figure()

# Plotting the bias (difference between predicted values and true values) for a random sample of 1000 test points
bias = y_pred - y_sample.numpy()
plt.hist(bias)
plt.xlabel("Bias")
plt.ylabel("Frequency")
plt.title("Bias Distribution")
plt.savefig("bias_dist.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 writer = tbx.SummaryWriter()
#       4 # Logging the losses and accuracies for each epoch
# ----> 5 for epoch in range(best_n_epochs):
#       6     writer.add_scalars("Loss", {"Train": best_train_losses[epoch], "Test": best_test_losses[epoch]}, epoch + 1)
#       7     writer.add_scalars("Accuracy", {"Train": best_train_accuracies[epoch], "Test": best_test_accuracies[epoch]}, epoch + 1)
#
# NameError: name 'best_n_epochs' is not defined

# %% [markdown]
# ## Saving data

# %% [markdown]
# ### Pickle

# %%
import pickle

# Save the objects to a file
with open("best_objects.pkl", "wb") as f:
    pickle.dump(best_net, f)
    pickle.dump(best_loss_fn, f)
    pickle.dump(best_optimizer, f)
    pickle.dump(best_batch_size, f)
    pickle.dump(best_n_epochs, f)
    pickle.dump(best_scheduler, f)
    pickle.dump(best_train_losses, f)
    pickle.dump(best_test_losses, f)
    pickle.dump(best_train_accuracies, f)
    pickle.dump(best_test_accuracies, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 # Save the objects to a file
#       4 with open("best_objects.pkl", "wb") as f:
# ----> 5     pickle.dump(best_net, f)
#       6     pickle.dump(best_loss_fn, f)
#       7     pickle.dump(best_optimizer, f)
#
# NameError: name 'best_net' is not defined

# %% [markdown]
# ### Pandas

# %% [markdown]
# Pandas is not suitable for saving complex objects like PyTorch models, loss functions, optimizers, or schedulers. Pandas is mainly used for saving tabular data, such as lists of numbers or strings. If you want to save these objects for later analysis, you may want to use pickle or torch.save instead. However, if you only want to save the hyperparameters and the metrics, you can use pandas.DataFrame to create a data frame with one row and multiple columns. You can then use pandas.to_csv to write the data frame to a CSV file. For example, you could use the following code:

# %%
import pandas as pd

# Get the names of the loss function, optimizer, and scheduler
loss_name = type(best_loss_fn).__name__
optimizer_name = type(best_optimizer).__name__
scheduler_name = type(best_scheduler).__name__ if best_scheduler else "None"

# Create a data frame with one row and multiple columns
data = pd.DataFrame({
    "hidden_activation": [best_net.hidden_activation.__class__.__name__],
    "output_activation": [best_net.output_activation.__class__.__name__],
    "n_units": [str(study.best_params["n_units"])],
    "loss": [loss_name],
    "optimizer": [optimizer_name],
    "lr": [best_optimizer.param_groups[0]["lr"]],
    "batch_size": [best_batch_size],
    "n_epochs": [best_n_epochs],
    "scheduler": [scheduler_name],
    "train_loss": [best_train_losses[-1]],
    "test_loss": [best_test_losses[-1]],
    "train_accuracy": [best_train_accuracies[-1]],
    "test_accuracy": [best_test_accuracies[-1]]
})

# Save the data frame to a CSV file
data.to_csv("best_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       3 # Get the names of the loss function, optimizer, and scheduler
# ----> 4 loss_name = type(best_loss_fn).__name__
#       5 optimizer_name = type(best_optimizer).__name__
#       6 scheduler_name = type(best_scheduler).__name__ if best_scheduler else "None"
#
# NameError: name 'best_loss_fn' is not defined

# %% [markdown]
# ### JSON to store study values

# %%
import json

# Save the values to a file
with open("best_values.json", "w") as f:
    json.dump({"params": study.best_params, "value": study.best_value}, f)

# Load the values from the file
with open("best_values.json", "r") as f:
    best_values = json.load(f)

# %% [markdown]
# ## Loading data

# %% [markdown]
# ### Pickle

# %%
import pickle

# Load the objects from the file
with open("best_objects.pkl", "rb") as f:
    best_net = pickle.load(f)
    best_loss_fn = pickle.load(f)
    best_optimizer = pickle.load(f)
    best_batch_size = pickle.load(f)
    best_n_epochs = pickle.load(f)
    best_scheduler = pickle.load(f)
    best_train_losses = pickle.load(f)
    best_test_losses = pickle.load(f)
    best_train_accuracies = pickle.load(f)
    best_test_accuracies = pickle.load(f)

# %% [markdown]
# ### Loading the model
#
# To load your saved best_net.pth, you need to create an instance of the same model class first, and then load the state dictionary using the torch.load and load_state_dict methods. For example, you could use the following code:

# %%
import json

# Load the values from the file
with open("best_values.json", "r") as f:
    best_values = json.load(f)

# Get the number of layers, the number of units, the hidden activation and the output activation
n_layers = best_values["params"]["n_layers"]
n_units = best_values["params"]["n_units"]
hidden_activation = best_values["params"]["hidden_activation"]
output_activation = best_values["params"]["output_activation"]

# Print the values
print("Number of layers:", n_layers)
print("Number of units:", n_units)
print("Hidden activation:", hidden_activation)
print("Output activation:", output_activation)
# Out:
# Number of layers: 1
# Number of units: 6
# Hidden activation: ReLU
# Output activation: ReLU

# %%
# Create an instance of the same model class
model = Net(n_layers, n_units, hidden_activation, output_activation)

# Load the state dictionary from the file
model.load_state_dict(torch.load("best_net.pth"))

# Set the model to evaluation mode
model.eval()
