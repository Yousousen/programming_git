# %%
import numpy as np
import matplotlib.pyplot as plt

def softmax(z):
    return np.exp(z) / np.sum(np.exp(z))

z = np.linspace(-5, 5, 100)
p = softmax(z)

plt.plot(z, p)
plt.xlabel('z')
plt.ylabel('softmax(z)')
plt.show()
# Out:
# Text(0.5, 0, 'z')
# Text(0, 0.5, 'softmax(z)')
