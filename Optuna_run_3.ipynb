# %% [markdown]
# <a href="https://colab.research.google.com/github/Yousousen/programming_git/blob/main/Optuna_run_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural network to learn conservative-to-primitive conversion in relativistic hydrodynamics
# We use Optuna to do a type of Bayesian optimization of the hyperparameters of the model. We then train the model using these hyperparameters to recover the primitive pressure from the conserved variables.
#
# Use this first cell to convert this notebook to a python script.

# %%
# %%script echo skipping
#
# !jupyter nbconvert pt4.ipynb --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"remove_cell"}' --to script
# Out:
# skipping

# %%
#%%script echo skipping

# !pip install optuna tensorboard tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 3.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 9.9 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Installing collected packages: tensorboardX, Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1 tensorboardX-2.6

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import optuna
import tensorboardX as tbx

# Checking if GPU is available and setting the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and flags to set
# Defining some constants and parameters for convenience.

# %%
N_TRIALS = 150 # Number of trials for hyperparameter optimization
OPTIMIZE = True # Whether to optimize the hyperparameters or to use predetermined values from Dieseldorst et al..

# Hyperparameters when no hyperparameter optimization is performed. 
N_LAYERS_NO_OPT = 2
N_UNITS_NO_OPT = [600, 200]
HIDDEN_ACTIVATION_NAME_NO_OPT = "Sigmoid"
OUTPUT_ACTIVATION_NAME_NO_OPT = "ReLU"
LOSS_NAME_NO_OPT = "MSE"
OPTIMIZER_NAME_NO_OPT = "Adam"
LR_NO_OPT = 6e-3
BATCH_SIZE_NO_OPT = 32
N_EPOCHS_NO_OPT = 400
SCHEDULER_NAME_NO_OPT = "ReduceLROnPlateau"

c = 1  # Speed of light (used in compute_conserved_variables and sample_primitive_variables functions)
gamma = 5 / 3  # Adiabatic index (used in eos_analytic function)
n_train_samples = 80000 # Number of training samples (used in generate_input_data and generate_labels functions)
n_test_samples = 10000 # Number of test samples (used in generate_input_data and generate_labels functions)
rho_interval = (0, 10.1) # Sampling interval for rest-mass density (used in sample_primitive_variables function)
vx_interval = (0, 0.721 * c) # Sampling interval for velocity in x-direction (used in sample_primitive_variables function)
epsilon_interval = (0, 2.02) # Sampling interval for specific internal energy (used in sample_primitive_variables function)

np.random.seed(1) # Uncomment for pseudorandom data.

# %% [markdown]
# ## Generating the data

# %%
# Defining an analytic equation of state (EOS) for an ideal gas
def eos_analytic(rho, epsilon):
    """Computes the pressure from rest-mass density and specific internal energy using an analytic EOS.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        torch.Tensor: The pressure tensor of shape (n_samples,).
    """
    # Adding some assertions to check that the input tensors are valid and have the expected shape and type 
    assert isinstance(rho, torch.Tensor), "rho must be a torch.Tensor"
    assert isinstance(epsilon, torch.Tensor), "epsilon must be a torch.Tensor"
    assert rho.shape == epsilon.shape, "rho and epsilon must have the same shape"
    assert rho.ndim == 1, "rho and epsilon must be one-dimensional tensors"
    assert rho.dtype == torch.float32, "rho and epsilon must have dtype torch.float32"

    return (gamma - 1) * rho * epsilon


# Defining a function that samples primitive variables from uniform distributions
def sample_primitive_variables(n_samples):
    """Samples primitive variables from uniform distributions.

    Args:
        n_samples (int): The number of samples to generate.

    Returns:
        tuple: A tuple of (rho, vx, epsilon), where rho is rest-mass density,
            vx is velocity in x-direction,
            epsilon is specific internal energy,
            each being a numpy array of shape (n_samples,).
    """
    # Sampling from uniform distributions with intervals matching Dieseldorst et al.
    rho = np.random.uniform(*rho_interval, size=n_samples)  # Rest-mass density
    vx = np.random.uniform(*vx_interval, size=n_samples)  # Velocity in x-direction
    epsilon = np.random.uniform(*epsilon_interval, size=n_samples)  # Specific internal energy

    # Returning the primitive variables
    return rho, vx, epsilon


# Defining a function that computes conserved variables from primitive variables
def compute_conserved_variables(rho, vx, epsilon):
    """Computes conserved variables from primitive variables.

    Args:
        rho (torch.Tensor): The rest-mass density tensor of shape (n_samples,).
        vx (torch.Tensor): The velocity in x-direction tensor of shape (n_samples,).
        epsilon (torch.Tensor): The specific internal energy tensor of shape (n_samples,).

    Returns:
        tuple: A tuple of (D, Sx, tau), where D is conserved density,
            Sx is conserved momentum in x-direction,
            tau is conserved energy density,
            each being a torch tensor of shape (n_samples,).
    """

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)
    # Computing the Lorentz factor from the velocity.
    W = 1 / torch.sqrt(1 - vx ** 2 / c ** 2)
    # Specific enthalpy
    h = 1 + epsilon + p / rho  

    # Computing the conserved variables from the primitive variables
    D = rho * W  # Conserved density
    Sx = rho * h * W ** 2 * vx  # Conserved momentum in x-direction
    tau = rho * h * W ** 2 - p - D  # Conserved energy density

    # Returning the conserved variables
    return D, Sx, tau

# Defining a function that generates input data (conserved variables) from given samples of primitive variables
def generate_input_data(rho, vx, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    vx = torch.tensor(vx, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the conserved variables using the compute_conserved_variables function
    D, Sx, tau = compute_conserved_variables(rho, vx, epsilon)

    # Stacking the conserved variables into a torch tensor
    x = torch.stack([D, Sx, tau], axis=1)

    # Returning the input data tensor
    return x

# Defining a function that generates output data (labels) from given samples of primitive variables
def generate_labels(rho, epsilon):
    # Converting the numpy arrays to torch tensors and moving them to the device
    rho = torch.tensor(rho, dtype=torch.float32).to(device)
    epsilon = torch.tensor(epsilon, dtype=torch.float32).to(device)

    # Computing the pressure from the primitive variables using the EOS
    p = eos_analytic(rho, epsilon)

    # Returning the output data tensor
    return p

# %%
# Sampling the primitive variables using the sample_primitive_variables function
rho_train, vx_train, epsilon_train = sample_primitive_variables(n_train_samples)
rho_test, vx_test, epsilon_test = sample_primitive_variables(n_test_samples)

# Generating the input and output data for train and test sets using the modified functions
x_train = generate_input_data(rho_train, vx_train, epsilon_train)
y_train = generate_labels(rho_train, epsilon_train) 
x_test = generate_input_data(rho_test, vx_test, epsilon_test) 
y_test = generate_labels(rho_test, epsilon_test) 

# Checking if our output is always positive by plotting a histogram of y_train and y_test tensors 
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(y_train.cpu().numpy(), bins=20)
plt.xlabel("y_train")
plt.ylabel("Frequency")
plt.subplot(1, 2, 2)
plt.hist(y_test.cpu().numpy(), bins=20)
plt.xlabel("y_test")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Checking the shapes of the data tensors
print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: torch.Size([80000, 3])
# Shape of y_train: torch.Size([80000])
# Shape of x_test: torch.Size([10000, 3])
# Shape of y_test: torch.Size([10000])

# %% [markdown]
# ## Defining the neural network

# %%
# Defining a class for the network
class Net(nn.Module):
    """A class for creating a network with a
    variable number of hidden layers and units.

    Attributes:
        n_layers (int): The number of hidden layers in the network.
        n_units (list): A list of integers representing the number of units in each hidden layer.
        hidden_activation (torch.nn.Module): The activation function for the hidden layers.
        output_activation (torch.nn.Module): The activation function for the output layer.
        layers (torch.nn.ModuleList): A list of linear layers in the network.
    """

    def __init__(self, n_layers, n_units, hidden_activation, output_activation):
        """Initializes the network with the given hyperparameters.

        Args:
            n_layers (int): The number of hidden layers in the network.
            n_units (list): A list of integers representing the number of units in each hidden layer.
            hidden_activation (torch.nn.Module): The activation function for the hidden layers.
            output_activation (torch.nn.Module): The activation function for the output layer.
        """
        super().__init__()
        self.n_layers = n_layers
        self.n_units = n_units
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation

        # Creating a list of linear layers with different numbers of units for each layer
        self.layers = nn.ModuleList([nn.Linear(3, n_units[0])])
        for i in range(1, n_layers):
            self.layers.append(nn.Linear(n_units[i - 1], n_units[i]))
        self.layers.append(nn.Linear(n_units[-1], 1))

        # Adding some assertions to check that the input arguments are valid
        assert isinstance(n_layers, int) and n_layers > 0, "n_layers must be a positive integer"
        assert isinstance(n_units, list) and len(n_units) == n_layers, "n_units must be a list of length n_layers"
        assert all(isinstance(n, int) and n > 0 for n in n_units), "n_units must contain positive integers"
        assert isinstance(hidden_activation, nn.Module), "hidden_activation must be a torch.nn.Module"
        assert isinstance(output_activation, nn.Module), "output_activation must be a torch.nn.Module"

    def forward(self, x):
        """Performs a forward pass on the input tensor.

        Args:
            x (torch.Tensor): The input tensor of shape (batch_size, 3).

        Returns:
            torch.Tensor: The output tensor of shape (batch_size, 1).
        """
        # Looping over the hidden layers and applying the linear transformation and the activation function
        for layer in self.layers[:-1]:
            x = self.hidden_activation(layer(x))
        # Applying the linear transformation and the activation function on the output layer
        x = self.output_activation(self.layers[-1](x))

        # Returning the output tensor
        return x

# %% [markdown]
# ## Defining the model and search space

# %%
# Defining a function to create a trial network and optimizer
def create_model(trial, optimize):
    """Creates a trial network and optimizer based on the sampled hyperparameters.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.
        optimize (boolean): Whether to optimize the hyperparameters or to use predefined values.

    Returns:
        tuple: A tuple of (net, loss_fn, optimizer, batch_size, n_epochs,
            scheduler, loss_name, optimizer_name, scheduler_name,
            n_units, n_layers, hidden_activation, output_activation),
            where net is the trial network,
            loss_fn is the loss function,
            optimizer is the optimizer,
            batch_size is the batch size,
            n_epochs is the number of epochs,
            scheduler is the learning rate scheduler,
            loss_name is the name of the loss function,
            optimizer_name is the name of the optimizer,
            scheduler_name is the name of the scheduler,
            n_units is a list of integers representing
            the number of units in each hidden layer,
            n_layers is an integer representing the number of hidden layers in the network,
            hidden_activation is a torch.nn.Module representing the activation function for the hidden layers,
            output_activation is a torch.nn.Module representing the activation function for the output layer,
            lr is the (initial) learning rate.
    """
    # If optimize is True, sample the hyperparameters from the search space
    if optimize:
        # Sampling the hyperparameters from the search space
        n_layers = trial.suggest_int("n_layers", 1, 3)
        n_units = [trial.suggest_int(f"n_units_{i}", 16, 256) for i in range(n_layers)] 
        hidden_activation_name = trial.suggest_categorical(
            "hidden_activation", ["ReLU", "LeakyReLU", "ELU", "Tanh", "Sigmoid"]
        )
        output_activation_name = trial.suggest_categorical(
            "output_activation", ["Linear", "ReLU"]
        ) 
        loss_name = trial.suggest_categorical(
            "loss", ["MSE", "MAE", "Huber", "LogCosh"] 
        )
        optimizer_name = trial.suggest_categorical(
            "optimizer", ["Adam", "SGD", "RMSprop", "Adagrad"] 
        )
        lr = trial.suggest_loguniform("lr", 1e-4, 1e-2) 
        batch_size = trial.suggest_int("batch_size", 32, 256)
        n_epochs = trial.suggest_int("n_epochs", 50, 100) 
        scheduler_name = trial.suggest_categorical(
            "scheduler",
            ["None", "CosineAnnealingLR", "ReduceLROnPlateau", "StepLR", "ExponentialLR"],
        )
    # If optimize is False, use the predefined values
    else:
        # Setting the hyperparameters to the predefined values
        n_layers = N_LAYERS_NO_OPT
        n_units = N_UNITS_NO_OPT
        hidden_activation_name = HIDDEN_ACTIVATION_NAME_NO_OPT
        output_activation_name = OUTPUT_ACTIVATION_NAME_NO_OPT
        loss_name = LOSS_NAME_NO_OPT
        optimizer_name = OPTIMIZER_NAME_NO_OPT
        lr = LR_NO_OPT
        batch_size = BATCH_SIZE_NO_OPT
        n_epochs = N_EPOCHS_NO_OPT
        scheduler_name = SCHEDULER_NAME_NO_OPT


    # Creating the activation functions from their names
    if hidden_activation_name == "ReLU":
        hidden_activation = nn.ReLU()
    elif hidden_activation_name == "LeakyReLU":
        hidden_activation = nn.LeakyReLU() 
    elif hidden_activation_name == "ELU":
        hidden_activation = nn.ELU() 
    elif hidden_activation_name == "Tanh":
        hidden_activation = nn.Tanh()
    else:
        hidden_activation = nn.Sigmoid()

    if output_activation_name == "ReLU":
        output_activation = nn.ReLU()
    else:
        output_activation = nn.Identity()

    # Creating the loss function from its name
    if loss_name == "MSE":
        loss_fn = nn.MSELoss()
    elif loss_name == "MAE":
        loss_fn = nn.L1Loss()
    elif loss_name == "Huber":
        loss_fn = nn.SmoothL1Loss() 
    else:
        # Creating the log-cosh loss function
        def log_cosh_loss(y_pred, y_true):
            return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
            
        loss_fn = log_cosh_loss

    # Creating the network with the sampled hyperparameters
    net = Net(
        n_layers, n_units, hidden_activation, output_activation
    ).to(device)

    # Creating the optimizer from its name
    if optimizer_name == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=lr)
    elif optimizer_name == "Adam":
        optimizer = optim.Adam(net.parameters(), lr=lr)
    elif optimizer_name == "RMSprop":
        optimizer = optim.RMSprop(net.parameters(), lr=lr)
    else:
        # Added creating the Adagrad optimizer
        optimizer = optim.Adagrad(net.parameters(), lr=lr)

    # Creating the learning rate scheduler from its name
    if scheduler_name == "StepLR":
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif scheduler_name == "ExponentialLR":
        scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    elif scheduler_name == "CosineAnnealingLR":
        # Added creating the CosineAnnealingLR scheduler
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
    elif scheduler_name == "ReduceLROnPlateau":
        # Added creating the ReduceLROnPlateau scheduler
        # Creating the ReduceLROnPlateau scheduler with a threshold value of 0.01
        #scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        #    optimizer, mode="min", factor=0.1, patience=10, threshold=0.01
        #)
        # Use Dieseldorst et al. settings and add to that a minimum lr.
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                )
    else:
        scheduler = None

    # Returning all variables needed for saving and loading
    return net, loss_fn, optimizer, batch_size, n_epochs, scheduler, loss_name, optimizer_name, scheduler_name, n_units, n_layers, hidden_activation, output_activation, lr

# %% [markdown]
#  ## The training and evaluation loop
#
#  We first define a couple of functions used in the training and evaluation.

# %%
# Defining a function that computes loss and metrics for a given batch
def compute_loss_and_metrics(y_pred, y_true, loss_fn):
    """Computes loss and metrics for a given batch.

    Args:
        y_pred (torch.Tensor): The predicted pressure tensor of shape (batch_size, 1).
        y_true (torch.Tensor): The true pressure tensor of shape (batch_size,).
        loss_fn (torch.nn.Module or function): The loss function to use.

    Returns:
        tuple: A tuple of (loss, l1_norm), where loss is a scalar tensor,
            l1_norm is L1 norm for relative error of pressure,
            each being a scalar tensor.
            linf_norm is Linf norm for relative error of pressure.
    """
    # Reshaping the target tensor to match the input tensor
    y_true = y_true.view(-1, 1)

    # Computing the loss using the loss function
    loss = loss_fn(y_pred, y_true)

    # Computing the relative error of pressure
    rel_error = torch.abs((y_pred - y_true) / y_true)

    # Computing the L1 norm for the relative error of pressure
    l1_norm = torch.mean(rel_error) 
    # Computing the Linf norm for the relative error of pressure
    linf_norm = torch.max(rel_error) 

    # Returning the loss and metrics
    return loss, l1_norm, linf_norm


# Defining a function that updates the learning rate scheduler with validation loss if applicable
def update_scheduler(scheduler, test_loss):
    """Updates the learning rate scheduler with validation loss if applicable.

    Args:
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler to use.
        test_loss (float): The validation loss to use.

    Returns:
        None
    """
    # Checking if scheduler is not None
    if scheduler is not None:
        # Checking if scheduler is ReduceLROnPlateau
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            # Updating the scheduler with test_loss
            scheduler.step(test_loss)
        else:
            # Updating the scheduler without test_loss
            scheduler.step()

# %% [markdown]
# Now for the actual training and evaluation loop,

# %%
# Defining a function to train and evaluate a network
def train_and_eval(net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial=None):
    """Trains and evaluates a network.

    Args:
        net (torch.nn.Module): The network to train and evaluate.
        loss_fn (torch.nn.Module or function): The loss function.
        optimizer (torch.optim.Optimizer): The optimizer.
        batch_size (int): The batch size.
        n_epochs (int): The number of epochs.
        scheduler (torch.optim.lr_scheduler._LRScheduler or None): The learning rate scheduler.
    Returns:
        tuple: A tuple of (train_losses, test_losses, train_metrics, test_metrics), where
            train_losses is a list of training losses for each epoch,
            test_losses is a list of validation losses for each epoch,
            train_metrics is a list of dictionaries containing training metrics for each epoch,
            test_metrics is a list of dictionaries containing validation metrics for each epoch.
    """
    # Creating data loaders for train and test sets
    train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True
    )
    test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(x_test, y_test), batch_size=batch_size
    )

    # Initializing lists to store the losses and metrics for each epoch
    train_losses = []
    test_losses = []
    train_metrics = []
    test_metrics = []

    # Creating a SummaryWriter object to log data for tensorboard
    writer = tbx.SummaryWriter()

    # Looping over the epochs
    for epoch in range(n_epochs):

        # Setting the network to training mode
        net.train()

        # Initializing variables to store the total loss and metrics for the train set
        train_loss = 0.0
        train_l1_norm = 0.0
        train_linf_norm = 0.0

        # Looping over the batches in the train set
        for x_batch, y_batch in train_loader:

            # Moving the batch tensors to the device
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            # Zeroing the gradients
            optimizer.zero_grad()

            # Performing a forward pass and computing the loss and metrics
            y_pred = net(x_batch)
            loss, l1_norm, linf_norm = compute_loss_and_metrics(
                y_pred, y_batch, loss_fn
            )


            # Performing a backward pass and updating the weights
            loss.backward()
            optimizer.step()

            # Updating the total loss and metrics for the train set
            train_loss += loss.item() * x_batch.size(0)
            train_l1_norm += l1_norm.item() * x_batch.size(0)
            train_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the train set
        train_loss /= len(train_loader.dataset)
        train_l1_norm /= len(train_loader.dataset)
        train_linf_norm /= len(train_loader.dataset)

        # Appending the average loss and metrics for the train set to the lists
        train_losses.append(train_loss)
        train_metrics.append(
            {
                "l1_norm": train_l1_norm,
                "linf_norm": train_linf_norm,
            }
        )

        # Logging the average loss and metrics for the train set to tensorboard
        writer.add_scalar("Loss/train", train_loss, epoch)
        writer.add_scalar("L1 norm/train", train_l1_norm, epoch)
        writer.add_scalar("Linf norm/train", train_linf_norm, epoch)

        # Setting the network to evaluation mode
        net.eval()

        # Initializing variables to store the total loss and metrics for the test set
        test_loss = 0.0
        test_l1_norm = 0.0
        test_linf_norm = 0.0

        # Looping over the batches in the test set
        with torch.no_grad():
            for x_batch, y_batch in test_loader:

                # Moving the batch tensors to the device
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                # Performing a forward pass and computing the loss and metrics
                y_pred = net(x_batch)
                loss, l1_norm, linf_norm = compute_loss_and_metrics(
                    y_pred, y_batch, loss_fn
                )


                # Updating the total loss and metrics for the test set
                test_loss += loss.item() * x_batch.size(0)
                test_l1_norm += l1_norm.item() * x_batch.size(0)
                test_linf_norm += linf_norm.item() * x_batch.size(0)

        # Computing the average loss and metrics for the test set
        test_loss /= len(test_loader.dataset)
        test_l1_norm /= len(test_loader.dataset)
        test_linf_norm /= len(test_loader.dataset)

        # Appending the average loss and metrics for the test set to the lists
        test_losses.append(test_loss)
        test_metrics.append(
            {
                "l1_norm": test_l1_norm,
                "linf_norm": test_linf_norm,
            }
        )

        # Logging the average loss and metrics for the test set to tensorboard
        writer.add_scalar("Loss/test", test_loss, epoch)
        writer.add_scalar("L1 norm/test", test_l1_norm, epoch)
        writer.add_scalar("Linf norm/test", test_linf_norm, epoch)

        # Printing the average loss and metrics for both sets for this epoch
        print(
            f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, "
            f"Train L1 Norm: {train_l1_norm:.4f}, Test L1 Norm: {test_l1_norm:.4f}, "
            f"Train Linf Norm: {train_linf_norm:.4f}, Test Linf Norm: {test_linf_norm:.4f}"
        )

        # Updating the learning rate scheduler with validation loss if applicable
        update_scheduler(scheduler, test_loss)

        # Reporting the intermediate metric value to Optuna if trial is not None
        if trial is not None:
            trial.report(test_metrics[-1]["l1_norm"], epoch)

            # Checking if the trial should be pruned based on the intermediate value if trial is not None
            if trial.should_prune():
                raise optuna.TrialPruned()

    # Closing the SummaryWriter object
    writer.close()

    # Returning the losses and metrics lists
    return train_losses, test_losses, train_metrics, test_metrics

# %% [markdown]
# ## The objective function and hyperparameter tuning

# %%
# Defining an objective function for Optuna to minimize
def objective(trial):
    """Defines an objective function for Optuna to minimize.

    Args:
        trial (optuna.trial.Trial): The trial object that contains the hyperparameters.

    Returns:
        float: The validation L1 norm to minimize.
    """
    # Creating a trial network and optimizer using the create_model function
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)

    # Training and evaluating the network using the train_and_eval function
    _, _, _, test_metrics = train_and_eval(
        net, loss_fn, optimizer, batch_size, n_epochs, scheduler, trial
    )

    # Returning the last validation L1 norm as the objective value to minimize
    return test_metrics[-1]["l1_norm"]

# %%
if OPTIMIZE:
    # Creating a study object with Optuna with TPE sampler and median pruner 
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    # Running Optuna with 100 trials when we are optimizing.
    study.optimize(objective, n_trials=N_TRIALS)

    # Printing the best trial information
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
# Out:
# [I 2023-05-13 08:40:55,971] A new study created in memory with name: no-name-e634f3cf-ceee-45ee-9795-0579f451c66d
# <ipython-input-8-bd4fe74facdf>:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# Epoch 1: Train Loss: 0.2257, Test Loss: 0.0135, Train L1 Norm: 2.1184, Test L1 Norm: 0.2871, Train Linf Norm: 272.9235, Test Linf Norm: 31.6390
# Epoch 2: Train Loss: 0.0080, Test Loss: 0.0064, Train L1 Norm: 0.4576, Test L1 Norm: 0.4083, Train Linf Norm: 63.4319, Test Linf Norm: 56.0546
# Epoch 3: Train Loss: 0.0031, Test Loss: 0.0040, Train L1 Norm: 0.3605, Test L1 Norm: 0.2953, Train Linf Norm: 50.4954, Test Linf Norm: 39.9503
# Epoch 4: Train Loss: 0.0026, Test Loss: 0.0031, Train L1 Norm: 0.2482, Test L1 Norm: 0.2617, Train Linf Norm: 33.4326, Test Linf Norm: 35.0366
# Epoch 5: Train Loss: 0.0017, Test Loss: 0.0021, Train L1 Norm: 0.1870, Test L1 Norm: 0.0901, Train Linf Norm: 24.8577, Test Linf Norm: 8.0908
# Epoch 6: Train Loss: 0.0024, Test Loss: 0.0010, Train L1 Norm: 0.1859, Test L1 Norm: 0.0749, Train Linf Norm: 24.6177, Test Linf Norm: 7.1293
# Epoch 7: Train Loss: 0.0014, Test Loss: 0.0129, Train L1 Norm: 0.1802, Test L1 Norm: 0.3510, Train Linf Norm: 24.8536, Test Linf Norm: 40.1929
# Epoch 8: Train Loss: 0.0014, Test Loss: 0.0024, Train L1 Norm: 0.1742, Test L1 Norm: 0.1518, Train Linf Norm: 23.8969, Test Linf Norm: 19.2157
# Epoch 9: Train Loss: 0.0020, Test Loss: 0.0011, Train L1 Norm: 0.1717, Test L1 Norm: 0.1337, Train Linf Norm: 22.5524, Test Linf Norm: 17.3064
# Epoch 10: Train Loss: 0.0016, Test Loss: 0.0005, Train L1 Norm: 0.1883, Test L1 Norm: 0.1416, Train Linf Norm: 24.9367, Test Linf Norm: 19.2046
# Epoch 11: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1330, Test L1 Norm: 0.0909, Train Linf Norm: 18.7879, Test Linf Norm: 12.0466
# Epoch 12: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1370, Test L1 Norm: 0.0871, Train Linf Norm: 20.3293, Test Linf Norm: 11.4642
# Epoch 13: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1385, Test L1 Norm: 0.0936, Train Linf Norm: 19.7854, Test Linf Norm: 12.5959
# Epoch 14: Train Loss: 0.0004, Test Loss: 0.0005, Train L1 Norm: 0.1369, Test L1 Norm: 0.1072, Train Linf Norm: 19.7556, Test Linf Norm: 14.2174
# Epoch 15: Train Loss: 0.0004, Test Loss: 0.0005, Train L1 Norm: 0.1427, Test L1 Norm: 0.0831, Train Linf Norm: 20.6023, Test Linf Norm: 10.6502
# Epoch 16: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1376, Test L1 Norm: 0.1217, Train Linf Norm: 19.6008, Test Linf Norm: 16.9300
# Epoch 17: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1521, Test L1 Norm: 0.1150, Train Linf Norm: 22.3418, Test Linf Norm: 15.5307
# Epoch 18: Train Loss: 0.0004, Test Loss: 0.0004, Train L1 Norm: 0.1498, Test L1 Norm: 0.0861, Train Linf Norm: 21.8290, Test Linf Norm: 11.2907
# Epoch 19: Train Loss: 0.0003, Test Loss: 0.0013, Train L1 Norm: 0.1452, Test L1 Norm: 0.1125, Train Linf Norm: 21.1440, Test Linf Norm: 14.3604
# Epoch 20: Train Loss: 0.0004, Test Loss: 0.0003, Train L1 Norm: 0.1525, Test L1 Norm: 0.0918, Train Linf Norm: 22.9088, Test Linf Norm: 12.3425
# Epoch 21: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1469, Test L1 Norm: 0.0912, Train Linf Norm: 21.4296, Test Linf Norm: 12.2660
# Epoch 22: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1446, Test L1 Norm: 0.0938, Train Linf Norm: 21.2328, Test Linf Norm: 12.6852
# Epoch 23: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0872, Train Linf Norm: 21.2693, Test Linf Norm: 11.5233
# Epoch 24: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1453, Test L1 Norm: 0.0861, Train Linf Norm: 21.3188, Test Linf Norm: 11.3303
# Epoch 25: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1432, Test L1 Norm: 0.0951, Train Linf Norm: 21.0992, Test Linf Norm: 12.9148
# Epoch 26: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1464, Test L1 Norm: 0.0981, Train Linf Norm: 21.2636, Test Linf Norm: 13.4293
# Epoch 27: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0957, Train Linf Norm: 21.2980, Test Linf Norm: 12.9866
# Epoch 28: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0903, Train Linf Norm: 21.5437, Test Linf Norm: 12.1126
# Epoch 29: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1463, Test L1 Norm: 0.0876, Train Linf Norm: 21.8295, Test Linf Norm: 11.5926
# Epoch 30: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1484, Test L1 Norm: 0.0930, Train Linf Norm: 21.4026, Test Linf Norm: 12.5784
# Epoch 31: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1464, Test L1 Norm: 0.0928, Train Linf Norm: 21.7508, Test Linf Norm: 12.5209
# Epoch 32: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1467, Test L1 Norm: 0.0940, Train Linf Norm: 21.7632, Test Linf Norm: 12.7259
# Epoch 33: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1465, Test L1 Norm: 0.0936, Train Linf Norm: 21.7651, Test Linf Norm: 12.6616
# Epoch 34: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0926, Train Linf Norm: 21.8365, Test Linf Norm: 12.4826
# Epoch 35: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1463, Test L1 Norm: 0.0981, Train Linf Norm: 21.8918, Test Linf Norm: 13.3885
# Epoch 36: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1483, Test L1 Norm: 0.0893, Train Linf Norm: 21.8352, Test Linf Norm: 11.9168
# Epoch 37: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1465, Test L1 Norm: 0.0937, Train Linf Norm: 21.5493, Test Linf Norm: 12.6837
# Epoch 38: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0931, Train Linf Norm: 21.6619, Test Linf Norm: 12.6013
# Epoch 39: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1476, Test L1 Norm: 0.0926, Train Linf Norm: 21.3445, Test Linf Norm: 12.4934
# Epoch 40: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1466, Test L1 Norm: 0.0920, Train Linf Norm: 21.6798, Test Linf Norm: 12.3971
# Epoch 41: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0938, Train Linf Norm: 21.0769, Test Linf Norm: 12.7034
# Epoch 42: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1472, Test L1 Norm: 0.0939, Train Linf Norm: 22.2025, Test Linf Norm: 12.7188
# Epoch 43: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1473, Test L1 Norm: 0.0935, Train Linf Norm: 22.4576, Test Linf Norm: 12.6607
# Epoch 44: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1472, Test L1 Norm: 0.0931, Train Linf Norm: 21.4852, Test Linf Norm: 12.5903
# Epoch 45: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1472, Test L1 Norm: 0.0937, Train Linf Norm: 21.6571, Test Linf Norm: 12.6920
# Epoch 46: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1473, Test L1 Norm: 0.0930, Train Linf Norm: 20.6922, Test Linf Norm: 12.5790
# Epoch 47: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1469, Test L1 Norm: 0.0937, Train Linf Norm: 21.6100, Test Linf Norm: 12.6840
# Epoch 48: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1472, Test L1 Norm: 0.0933, Train Linf Norm: 21.6841, Test Linf Norm: 12.6232
# Epoch 49: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1474, Test L1 Norm: 0.0938, Train Linf Norm: 21.8376, Test Linf Norm: 12.7030
# Epoch 50: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1476, Test L1 Norm: 0.0938, Train Linf Norm: 21.2081, Test Linf Norm: 12.6986
# Epoch 51: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0934, Train Linf Norm: 21.9372, Test Linf Norm: 12.6380
# Epoch 52: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0934, Train Linf Norm: 21.5587, Test Linf Norm: 12.6426
# Epoch 53: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1469, Test L1 Norm: 0.0934, Train Linf Norm: 20.3861, Test Linf Norm: 12.6496
# Epoch 54: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 21.3603, Test Linf Norm: 12.6505
# Epoch 55: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 21.7979, Test Linf Norm: 12.6526
# Epoch 56: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 21.3599, Test Linf Norm: 12.6542
# Epoch 57: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 21.1602, Test Linf Norm: 12.6620
# Epoch 58: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 22.0356, Test Linf Norm: 12.6594
# Epoch 59: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0934, Train Linf Norm: 21.7813, Test Linf Norm: 12.6458
# Epoch 60: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1470, Test L1 Norm: 0.0935, Train Linf Norm: 20.6662, Test Linf Norm: 12.6576
# Epoch 61: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.7109, Test Linf Norm: 12.6576
# Epoch 62: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 20.7222, Test Linf Norm: 12.6575
# Epoch 63: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.8911, Test Linf Norm: 12.6575
# Epoch 64: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.6848, Test Linf Norm: 12.6574
# Epoch 65: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.8753, Test Linf Norm: 12.6573
# Epoch 66: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.3492, Test Linf Norm: 12.6573
# Epoch 67: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.7202, Test Linf Norm: 12.6573
# Epoch 68: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 22.0825, Test Linf Norm: 12.6573
# Epoch 69: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.9890, Test Linf Norm: 12.6574
# Epoch 70: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 22.0678, Test Linf Norm: 12.6574
# Epoch 71: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.9644, Test Linf Norm: 12.6574
# Epoch 72: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.6170, Test Linf Norm: 12.6574
# Epoch 73: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 22.0327, Test Linf Norm: 12.6574
# Epoch 74: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 21.6999, Test Linf Norm: 12.6574
# Epoch 75: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 20.8984, Test Linf Norm: 12.6574
# [I 2023-05-13 08:43:46,335] Trial 0 finished with value: 0.09349791657105089 and parameters: {'n_layers': 1, 'n_units_0': 115, 'hidden_activation': 'Sigmoid', 'output_activation': 'Linear', 'loss': 'LogCosh', 'optimizer': 'Adam', 'lr': 0.005437659891769128, 'batch_size': 203, 'n_epochs': 76, 'scheduler': 'StepLR'}. Best is trial 0 with value: 0.09349791657105089.
# Epoch 76: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1471, Test L1 Norm: 0.0935, Train Linf Norm: 22.1207, Test Linf Norm: 12.6574
# Epoch 1: Train Loss: 1.1074, Test Loss: 0.7713, Train L1 Norm: 1.9932, Test L1 Norm: 0.4786, Train Linf Norm: 170.5691, Test Linf Norm: 2.1535
# Epoch 2: Train Loss: 0.6181, Test Loss: 0.5405, Train L1 Norm: 0.4300, Test L1 Norm: 0.4102, Train Linf Norm: 2.0836, Test Linf Norm: 2.4570
# Epoch 3: Train Loss: 0.4610, Test Loss: 0.4315, Train L1 Norm: 0.4147, Test L1 Norm: 0.4137, Train Linf Norm: 4.7927, Test Linf Norm: 5.1073
# Epoch 4: Train Loss: 0.3815, Test Loss: 0.3704, Train L1 Norm: 0.4718, Test L1 Norm: 0.4198, Train Linf Norm: 14.3184, Test Linf Norm: 6.4497
# Epoch 5: Train Loss: 0.3351, Test Loss: 0.3321, Train L1 Norm: 0.4991, Test L1 Norm: 0.4275, Train Linf Norm: 18.2614, Test Linf Norm: 7.3031
# Epoch 6: Train Loss: 0.3044, Test Loss: 0.3054, Train L1 Norm: 0.5228, Test L1 Norm: 0.4266, Train Linf Norm: 21.5122, Test Linf Norm: 7.1539
# Epoch 7: Train Loss: 0.2818, Test Loss: 0.2850, Train L1 Norm: 0.5243, Test L1 Norm: 0.4215, Train Linf Norm: 21.6069, Test Linf Norm: 6.7470
# Epoch 8: Train Loss: 0.2636, Test Loss: 0.2676, Train L1 Norm: 0.5177, Test L1 Norm: 0.4229, Train Linf Norm: 21.2096, Test Linf Norm: 7.1705
# Epoch 9: Train Loss: 0.2480, Test Loss: 0.2523, Train L1 Norm: 0.5170, Test L1 Norm: 0.4082, Train Linf Norm: 21.7040, Test Linf Norm: 5.9669
# Epoch 10: Train Loss: 0.2341, Test Loss: 0.2386, Train L1 Norm: 0.4936, Test L1 Norm: 0.4008, Train Linf Norm: 19.0082, Test Linf Norm: 5.6860
# Epoch 11: Train Loss: 0.2268, Test Loss: 0.2373, Train L1 Norm: 0.4878, Test L1 Norm: 0.4000, Train Linf Norm: 18.7260, Test Linf Norm: 5.6421
# Epoch 12: Train Loss: 0.2255, Test Loss: 0.2360, Train L1 Norm: 0.4849, Test L1 Norm: 0.3993, Train Linf Norm: 18.1971, Test Linf Norm: 5.6151
# Epoch 13: Train Loss: 0.2244, Test Loss: 0.2348, Train L1 Norm: 0.4833, Test L1 Norm: 0.3992, Train Linf Norm: 17.9865, Test Linf Norm: 5.6560
# Epoch 14: Train Loss: 0.2232, Test Loss: 0.2336, Train L1 Norm: 0.4820, Test L1 Norm: 0.3979, Train Linf Norm: 18.0126, Test Linf Norm: 5.5595
# Epoch 15: Train Loss: 0.2221, Test Loss: 0.2325, Train L1 Norm: 0.4810, Test L1 Norm: 0.3957, Train Linf Norm: 17.9751, Test Linf Norm: 5.3704
# Epoch 16: Train Loss: 0.2210, Test Loss: 0.2313, Train L1 Norm: 0.4782, Test L1 Norm: 0.3959, Train Linf Norm: 17.7810, Test Linf Norm: 5.4402
# Epoch 17: Train Loss: 0.2199, Test Loss: 0.2303, Train L1 Norm: 0.4774, Test L1 Norm: 0.3951, Train Linf Norm: 17.7152, Test Linf Norm: 5.4042
# Epoch 18: Train Loss: 0.2189, Test Loss: 0.2292, Train L1 Norm: 0.4754, Test L1 Norm: 0.3943, Train Linf Norm: 17.1276, Test Linf Norm: 5.3561
# Epoch 19: Train Loss: 0.2179, Test Loss: 0.2282, Train L1 Norm: 0.4743, Test L1 Norm: 0.3932, Train Linf Norm: 17.3817, Test Linf Norm: 5.2919
# Epoch 20: Train Loss: 0.2169, Test Loss: 0.2272, Train L1 Norm: 0.4725, Test L1 Norm: 0.3923, Train Linf Norm: 17.0528, Test Linf Norm: 5.2364
# Epoch 21: Train Loss: 0.2164, Test Loss: 0.2271, Train L1 Norm: 0.4717, Test L1 Norm: 0.3923, Train Linf Norm: 17.1358, Test Linf Norm: 5.2426
# Epoch 22: Train Loss: 0.2163, Test Loss: 0.2270, Train L1 Norm: 0.4717, Test L1 Norm: 0.3923, Train Linf Norm: 17.0056, Test Linf Norm: 5.2470
# Epoch 23: Train Loss: 0.2162, Test Loss: 0.2269, Train L1 Norm: 0.4716, Test L1 Norm: 0.3923, Train Linf Norm: 17.0866, Test Linf Norm: 5.2490
# Epoch 24: Train Loss: 0.2161, Test Loss: 0.2268, Train L1 Norm: 0.4717, Test L1 Norm: 0.3922, Train Linf Norm: 17.1183, Test Linf Norm: 5.2483
# Epoch 25: Train Loss: 0.2160, Test Loss: 0.2267, Train L1 Norm: 0.4715, Test L1 Norm: 0.3922, Train Linf Norm: 16.9457, Test Linf Norm: 5.2495
# Epoch 26: Train Loss: 0.2159, Test Loss: 0.2266, Train L1 Norm: 0.4715, Test L1 Norm: 0.3921, Train Linf Norm: 17.0204, Test Linf Norm: 5.2476
# Epoch 27: Train Loss: 0.2158, Test Loss: 0.2265, Train L1 Norm: 0.4715, Test L1 Norm: 0.3921, Train Linf Norm: 17.1298, Test Linf Norm: 5.2435
# Epoch 28: Train Loss: 0.2157, Test Loss: 0.2264, Train L1 Norm: 0.4714, Test L1 Norm: 0.3920, Train Linf Norm: 17.1055, Test Linf Norm: 5.2378
# Epoch 29: Train Loss: 0.2157, Test Loss: 0.2263, Train L1 Norm: 0.4712, Test L1 Norm: 0.3919, Train Linf Norm: 17.0110, Test Linf Norm: 5.2364
# Epoch 30: Train Loss: 0.2156, Test Loss: 0.2263, Train L1 Norm: 0.4712, Test L1 Norm: 0.3918, Train Linf Norm: 16.9542, Test Linf Norm: 5.2310
# Epoch 31: Train Loss: 0.2155, Test Loss: 0.2263, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 16.8995, Test Linf Norm: 5.2314
# Epoch 32: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 16.9168, Test Linf Norm: 5.2315
# Epoch 33: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 17.0568, Test Linf Norm: 5.2314
# Epoch 34: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 16.9642, Test Linf Norm: 5.2312
# Epoch 35: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 16.9938, Test Linf Norm: 5.2311
# Epoch 36: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 16.9351, Test Linf Norm: 5.2312
# Epoch 37: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.6946, Test Linf Norm: 5.2308
# Epoch 38: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4710, Test L1 Norm: 0.3918, Train Linf Norm: 17.0131, Test Linf Norm: 5.2306
# Epoch 39: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.8441, Test Linf Norm: 5.2305
# Epoch 40: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.1015, Test Linf Norm: 5.2305
# Epoch 41: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9392, Test Linf Norm: 5.2305
# Epoch 42: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.8841, Test Linf Norm: 5.2305
# Epoch 43: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.8553, Test Linf Norm: 5.2305
# Epoch 44: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.0575, Test Linf Norm: 5.2306
# Epoch 45: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9600, Test Linf Norm: 5.2305
# Epoch 46: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9518, Test Linf Norm: 5.2305
# Epoch 47: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9807, Test Linf Norm: 5.2305
# Epoch 48: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9927, Test Linf Norm: 5.2306
# Epoch 49: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.1230, Test Linf Norm: 5.2306
# Epoch 50: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9902, Test Linf Norm: 5.2306
# Epoch 51: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.0520, Test Linf Norm: 5.2306
# Epoch 52: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.9788, Test Linf Norm: 5.2306
# Epoch 53: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.1822, Test Linf Norm: 5.2306
# Epoch 54: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 16.7669, Test Linf Norm: 5.2306
# Epoch 55: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.1598, Test Linf Norm: 5.2306
# [I 2023-05-13 08:46:50,918] Trial 1 finished with value: 0.39181348830461504 and parameters: {'n_layers': 3, 'n_units_0': 152, 'n_units_1': 117, 'n_units_2': 209, 'hidden_activation': 'Tanh', 'output_activation': 'ReLU', 'loss': 'LogCosh', 'optimizer': 'Adagrad', 'lr': 0.000267533921514484, 'batch_size': 150, 'n_epochs': 56, 'scheduler': 'StepLR'}. Best is trial 0 with value: 0.09349791657105089.
# Epoch 56: Train Loss: 0.2155, Test Loss: 0.2262, Train L1 Norm: 0.4709, Test L1 Norm: 0.3918, Train Linf Norm: 17.1409, Test Linf Norm: 5.2306
# Epoch 1: Train Loss: 0.0507, Test Loss: 0.0238, Train L1 Norm: 0.1463, Test L1 Norm: 0.0874, Train Linf Norm: 11.2985, Test Linf Norm: 1.0209
# Epoch 2: Train Loss: 0.0052, Test Loss: 0.0006, Train L1 Norm: 0.0620, Test L1 Norm: 0.0445, Train Linf Norm: 5.2773, Test Linf Norm: 4.0249
# Epoch 3: Train Loss: 0.0008, Test Loss: 0.0174, Train L1 Norm: 0.0445, Test L1 Norm: 0.1661, Train Linf Norm: 4.0572, Test Linf Norm: 13.6351
# Epoch 4: Train Loss: 0.0017, Test Loss: 0.0003, Train L1 Norm: 0.0475, Test L1 Norm: 0.0516, Train Linf Norm: 4.0162, Test Linf Norm: 5.3080
# Epoch 5: Train Loss: 0.0012, Test Loss: 0.0003, Train L1 Norm: 0.0390, Test L1 Norm: 0.0490, Train Linf Norm: 2.9987, Test Linf Norm: 5.2729
# Epoch 6: Train Loss: 0.0012, Test Loss: 0.0030, Train L1 Norm: 0.0461, Test L1 Norm: 0.0422, Train Linf Norm: 4.5287, Test Linf Norm: 0.9888
# Epoch 7: Train Loss: 0.0008, Test Loss: 0.0001, Train L1 Norm: 0.0347, Test L1 Norm: 0.0281, Train Linf Norm: 2.7555, Test Linf Norm: 2.6100
# Epoch 8: Train Loss: 0.0006, Test Loss: 0.0001, Train L1 Norm: 0.0305, Test L1 Norm: 0.0223, Train Linf Norm: 2.2294, Test Linf Norm: 1.6685
# Epoch 9: Train Loss: 0.0008, Test Loss: 0.0002, Train L1 Norm: 0.0338, Test L1 Norm: 0.0203, Train Linf Norm: 2.6761, Test Linf Norm: 1.2107
# Epoch 10: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0248, Test L1 Norm: 0.0272, Train Linf Norm: 1.9793, Test Linf Norm: 0.9257
# Epoch 11: Train Loss: 0.0004, Test Loss: 0.0001, Train L1 Norm: 0.0370, Test L1 Norm: 0.0185, Train Linf Norm: 4.0129, Test Linf Norm: 1.2235
# Epoch 12: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.0260, Test L1 Norm: 0.0183, Train Linf Norm: 2.4078, Test Linf Norm: 1.0595
# Epoch 13: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0264, Test L1 Norm: 0.0168, Train Linf Norm: 2.4915, Test Linf Norm: 1.1930
# Epoch 14: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0240, Test L1 Norm: 0.0204, Train Linf Norm: 1.8799, Test Linf Norm: 1.4004
# Epoch 15: Train Loss: 0.0001, Test Loss: 0.0009, Train L1 Norm: 0.0235, Test L1 Norm: 0.0281, Train Linf Norm: 2.1729, Test Linf Norm: 1.7820
# Epoch 16: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0222, Test L1 Norm: 0.0157, Train Linf Norm: 1.9742, Test Linf Norm: 0.9605
# Epoch 17: Train Loss: 0.0001, Test Loss: 0.0005, Train L1 Norm: 0.0200, Test L1 Norm: 0.0193, Train Linf Norm: 1.5048, Test Linf Norm: 1.1295
# Epoch 18: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0227, Test L1 Norm: 0.0161, Train Linf Norm: 2.3858, Test Linf Norm: 1.2806
# Epoch 19: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0201, Test L1 Norm: 0.0147, Train Linf Norm: 1.7112, Test Linf Norm: 1.0465
# Epoch 20: Train Loss: 0.0001, Test Loss: 0.0003, Train L1 Norm: 0.0214, Test L1 Norm: 0.0220, Train Linf Norm: 2.0994, Test Linf Norm: 1.1557
# Epoch 21: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0199, Test L1 Norm: 0.0148, Train Linf Norm: 1.9724, Test Linf Norm: 1.1667
# Epoch 22: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0177, Test L1 Norm: 0.0147, Train Linf Norm: 1.5913, Test Linf Norm: 1.1409
# Epoch 23: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0198, Test L1 Norm: 0.0130, Train Linf Norm: 2.0506, Test Linf Norm: 0.9919
# Epoch 24: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0178, Test L1 Norm: 0.0138, Train Linf Norm: 1.6807, Test Linf Norm: 1.1171
# Epoch 25: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0187, Test L1 Norm: 0.0136, Train Linf Norm: 1.8417, Test Linf Norm: 1.0121
# Epoch 26: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0195, Test L1 Norm: 0.0127, Train Linf Norm: 2.0282, Test Linf Norm: 0.9951
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0130, Train Linf Norm: 1.6941, Test Linf Norm: 1.0103
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0188, Test L1 Norm: 0.0139, Train Linf Norm: 1.9850, Test Linf Norm: 0.8767
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0188, Test L1 Norm: 0.0140, Train Linf Norm: 2.0214, Test Linf Norm: 0.8931
# Epoch 30: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0193, Test L1 Norm: 0.0132, Train Linf Norm: 2.1480, Test Linf Norm: 0.9700
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0187, Test L1 Norm: 0.0129, Train Linf Norm: 2.0192, Test Linf Norm: 1.0162
# Epoch 32: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0185, Test L1 Norm: 0.0126, Train Linf Norm: 2.0575, Test Linf Norm: 1.0206
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0185, Test L1 Norm: 0.0133, Train Linf Norm: 2.0550, Test Linf Norm: 1.1075
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0180, Test L1 Norm: 0.0126, Train Linf Norm: 1.9295, Test Linf Norm: 0.9677
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0176, Test L1 Norm: 0.0126, Train Linf Norm: 1.9103, Test Linf Norm: 0.9925
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0183, Test L1 Norm: 0.0125, Train Linf Norm: 2.0335, Test Linf Norm: 1.0012
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0181, Test L1 Norm: 0.0122, Train Linf Norm: 2.0314, Test Linf Norm: 0.9786
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0188, Test L1 Norm: 0.0129, Train Linf Norm: 2.1863, Test Linf Norm: 1.0317
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0174, Test L1 Norm: 0.0123, Train Linf Norm: 1.8811, Test Linf Norm: 0.9565
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0180, Test L1 Norm: 0.0133, Train Linf Norm: 2.0536, Test Linf Norm: 1.1674
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0128, Train Linf Norm: 1.9126, Test Linf Norm: 1.1307
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0165, Test L1 Norm: 0.0120, Train Linf Norm: 1.6807, Test Linf Norm: 0.8994
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0173, Test L1 Norm: 0.0122, Train Linf Norm: 1.9091, Test Linf Norm: 0.9257
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0170, Test L1 Norm: 0.0130, Train Linf Norm: 1.8719, Test Linf Norm: 1.1337
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0171, Test L1 Norm: 0.0125, Train Linf Norm: 1.8716, Test Linf Norm: 1.0917
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0126, Train Linf Norm: 1.8254, Test Linf Norm: 1.1125
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.7711, Test Linf Norm: 1.0982
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0175, Test L1 Norm: 0.0121, Train Linf Norm: 1.9847, Test Linf Norm: 0.9731
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0169, Test L1 Norm: 0.0123, Train Linf Norm: 1.8396, Test Linf Norm: 1.0361
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0170, Test L1 Norm: 0.0123, Train Linf Norm: 1.8708, Test Linf Norm: 1.0510
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.8221, Test Linf Norm: 1.0575
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0168, Test L1 Norm: 0.0128, Train Linf Norm: 1.8812, Test Linf Norm: 1.1497
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0129, Train Linf Norm: 1.8285, Test Linf Norm: 1.1682
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0171, Test L1 Norm: 0.0123, Train Linf Norm: 1.9157, Test Linf Norm: 1.0466
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8370, Test Linf Norm: 1.1013
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0173, Test L1 Norm: 0.0123, Train Linf Norm: 2.0037, Test Linf Norm: 1.0347
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0126, Train Linf Norm: 1.8503, Test Linf Norm: 1.1455
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0168, Test L1 Norm: 0.0122, Train Linf Norm: 1.8763, Test Linf Norm: 1.0439
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0126, Train Linf Norm: 1.8732, Test Linf Norm: 1.1504
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0169, Test L1 Norm: 0.0124, Train Linf Norm: 1.8972, Test Linf Norm: 1.1065
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0126, Train Linf Norm: 1.8890, Test Linf Norm: 1.1478
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0124, Train Linf Norm: 1.8592, Test Linf Norm: 1.1089
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8452, Test Linf Norm: 1.1289
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.8883, Test Linf Norm: 1.1328
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0126, Train Linf Norm: 1.8450, Test Linf Norm: 1.1469
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.7930, Test Linf Norm: 1.1360
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0126, Train Linf Norm: 1.8656, Test Linf Norm: 1.1312
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0165, Test L1 Norm: 0.0125, Train Linf Norm: 1.8286, Test Linf Norm: 1.1166
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0165, Test L1 Norm: 0.0126, Train Linf Norm: 1.8353, Test Linf Norm: 1.0994
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.8816, Test Linf Norm: 1.1140
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0127, Train Linf Norm: 1.8778, Test Linf Norm: 1.1742
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0126, Train Linf Norm: 1.8661, Test Linf Norm: 1.1646
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0168, Test L1 Norm: 0.0125, Train Linf Norm: 1.9170, Test Linf Norm: 1.0918
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.5291, Test Linf Norm: 1.1133
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8712, Test Linf Norm: 1.1297
# Epoch 76: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0126, Train Linf Norm: 1.8674, Test Linf Norm: 1.1395
# Epoch 77: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0167, Test L1 Norm: 0.0125, Train Linf Norm: 1.8655, Test Linf Norm: 1.1262
# Epoch 78: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8731, Test Linf Norm: 1.1346
# Epoch 79: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8731, Test Linf Norm: 1.1178
# [I 2023-05-13 08:49:14,933] Trial 2 finished with value: 0.012478173578856513 and parameters: {'n_layers': 1, 'n_units_0': 134, 'hidden_activation': 'ReLU', 'output_activation': 'ReLU', 'loss': 'LogCosh', 'optimizer': 'Adam', 'lr': 0.007939943483396496, 'batch_size': 234, 'n_epochs': 80, 'scheduler': 'ExponentialLR'}. Best is trial 2 with value: 0.012478173578856513.
# Epoch 80: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0166, Test L1 Norm: 0.0125, Train Linf Norm: 1.8597, Test Linf Norm: 1.1142
# Epoch 1: Train Loss: 0.2157, Test Loss: 0.0403, Train L1 Norm: 0.5951, Test L1 Norm: 0.1882, Train Linf Norm: 73.9444, Test Linf Norm: 18.4794
# Epoch 2: Train Loss: 0.0449, Test Loss: 0.0248, Train L1 Norm: 0.1724, Test L1 Norm: 0.0825, Train Linf Norm: 14.6923, Test Linf Norm: 1.8998
# Epoch 3: Train Loss: 0.0277, Test Loss: 0.0061, Train L1 Norm: 0.1425, Test L1 Norm: 0.1058, Train Linf Norm: 13.5322, Test Linf Norm: 11.4858
# Epoch 4: Train Loss: 0.0198, Test Loss: 0.0022, Train L1 Norm: 0.1383, Test L1 Norm: 0.0654, Train Linf Norm: 15.8461, Test Linf Norm: 8.0598
# Epoch 5: Train Loss: 0.0136, Test Loss: 0.0185, Train L1 Norm: 0.1166, Test L1 Norm: 0.0709, Train Linf Norm: 13.5327, Test Linf Norm: 0.9364
# Epoch 6: Train Loss: 0.0109, Test Loss: 0.0056, Train L1 Norm: 0.0796, Test L1 Norm: 0.0853, Train Linf Norm: 7.4760, Test Linf Norm: 9.5319
# Epoch 7: Train Loss: 0.0083, Test Loss: 0.0038, Train L1 Norm: 0.0763, Test L1 Norm: 0.0394, Train Linf Norm: 7.5791, Test Linf Norm: 2.6586
# Epoch 8: Train Loss: 0.0066, Test Loss: 0.0410, Train L1 Norm: 0.0637, Test L1 Norm: 0.1855, Train Linf Norm: 5.5533, Test Linf Norm: 17.2432
# Epoch 9: Train Loss: 0.0053, Test Loss: 0.0003, Train L1 Norm: 0.0488, Test L1 Norm: 0.0223, Train Linf Norm: 4.0397, Test Linf Norm: 2.3744
# Epoch 10: Train Loss: 0.0041, Test Loss: 0.0002, Train L1 Norm: 0.0516, Test L1 Norm: 0.0138, Train Linf Norm: 4.5946, Test Linf Norm: 0.7307
# Epoch 11: Train Loss: 0.0032, Test Loss: 0.0286, Train L1 Norm: 0.0428, Test L1 Norm: 0.0811, Train Linf Norm: 3.7791, Test Linf Norm: 0.9846
# Epoch 12: Train Loss: 0.0027, Test Loss: 0.0006, Train L1 Norm: 0.0522, Test L1 Norm: 0.0181, Train Linf Norm: 5.3890, Test Linf Norm: 1.3685
# Epoch 13: Train Loss: 0.0022, Test Loss: 0.0001, Train L1 Norm: 0.0341, Test L1 Norm: 0.0101, Train Linf Norm: 2.8870, Test Linf Norm: 0.6498
# Epoch 14: Train Loss: 0.0018, Test Loss: 0.0002, Train L1 Norm: 0.0351, Test L1 Norm: 0.0129, Train Linf Norm: 3.3293, Test Linf Norm: 0.6844
# Epoch 15: Train Loss: 0.0014, Test Loss: 0.0031, Train L1 Norm: 0.0293, Test L1 Norm: 0.0278, Train Linf Norm: 2.8043, Test Linf Norm: 0.7134
# Epoch 16: Train Loss: 0.0012, Test Loss: 0.0001, Train L1 Norm: 0.0255, Test L1 Norm: 0.0092, Train Linf Norm: 2.2792, Test Linf Norm: 0.7038
# Epoch 17: Train Loss: 0.0009, Test Loss: 0.0032, Train L1 Norm: 0.0212, Test L1 Norm: 0.0331, Train Linf Norm: 1.8694, Test Linf Norm: 1.8701
# Epoch 18: Train Loss: 0.0008, Test Loss: 0.0001, Train L1 Norm: 0.0224, Test L1 Norm: 0.0108, Train Linf Norm: 1.8117, Test Linf Norm: 1.0896
# Epoch 19: Train Loss: 0.0007, Test Loss: 0.0001, Train L1 Norm: 0.0208, Test L1 Norm: 0.0099, Train Linf Norm: 1.8425, Test Linf Norm: 0.7153
# Epoch 20: Train Loss: 0.0005, Test Loss: 0.0004, Train L1 Norm: 0.0199, Test L1 Norm: 0.0180, Train Linf Norm: 2.1220, Test Linf Norm: 1.7786
# Epoch 21: Train Loss: 0.0005, Test Loss: 0.0001, Train L1 Norm: 0.0190, Test L1 Norm: 0.0111, Train Linf Norm: 1.9177, Test Linf Norm: 0.6710
# Epoch 22: Train Loss: 0.0004, Test Loss: 0.0008, Train L1 Norm: 0.0181, Test L1 Norm: 0.0319, Train Linf Norm: 1.7546, Test Linf Norm: 3.2445
# Epoch 23: Train Loss: 0.0003, Test Loss: 0.0005, Train L1 Norm: 0.0177, Test L1 Norm: 0.0140, Train Linf Norm: 1.9933, Test Linf Norm: 0.6779
# Epoch 24: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.0155, Test L1 Norm: 0.0116, Train Linf Norm: 1.6146, Test Linf Norm: 0.7264
# Epoch 25: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0138, Test L1 Norm: 0.0082, Train Linf Norm: 1.3584, Test Linf Norm: 0.7934
# Epoch 26: Train Loss: 0.0002, Test Loss: 0.0001, Train L1 Norm: 0.0159, Test L1 Norm: 0.0082, Train Linf Norm: 1.8115, Test Linf Norm: 0.6681
# Epoch 27: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0120, Test L1 Norm: 0.0096, Train Linf Norm: 1.2598, Test Linf Norm: 1.0297
# Epoch 28: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0116, Test L1 Norm: 0.0073, Train Linf Norm: 1.1115, Test Linf Norm: 0.6045
# Epoch 29: Train Loss: 0.0001, Test Loss: 0.0003, Train L1 Norm: 0.0103, Test L1 Norm: 0.0141, Train Linf Norm: 0.9453, Test Linf Norm: 0.6573
# Epoch 30: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0106, Test L1 Norm: 0.0072, Train Linf Norm: 1.0671, Test Linf Norm: 0.6599
# Epoch 31: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0105, Test L1 Norm: 0.0069, Train Linf Norm: 1.0917, Test Linf Norm: 0.6004
# Epoch 32: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0105, Test L1 Norm: 0.0074, Train Linf Norm: 1.1522, Test Linf Norm: 0.6165
# Epoch 33: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0099, Test L1 Norm: 0.0071, Train Linf Norm: 1.0540, Test Linf Norm: 0.6804
# Epoch 34: Train Loss: 0.0001, Test Loss: 0.0001, Train L1 Norm: 0.0089, Test L1 Norm: 0.0093, Train Linf Norm: 0.8711, Test Linf Norm: 0.8997
# Epoch 35: Train Loss: 0.0001, Test Loss: 0.0000, Train L1 Norm: 0.0101, Test L1 Norm: 0.0075, Train Linf Norm: 1.1687, Test Linf Norm: 0.7849
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0091, Test L1 Norm: 0.0072, Train Linf Norm: 0.9794, Test Linf Norm: 0.6161
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0084, Test L1 Norm: 0.0073, Train Linf Norm: 0.8637, Test Linf Norm: 0.6238
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0073, Train Linf Norm: 0.9346, Test Linf Norm: 0.7614
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0078, Train Linf Norm: 0.8682, Test Linf Norm: 0.8537
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0073, Train Linf Norm: 0.9702, Test Linf Norm: 0.7793
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0001, Train L1 Norm: 0.0083, Test L1 Norm: 0.0071, Train Linf Norm: 0.8977, Test Linf Norm: 0.6029
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0082, Test L1 Norm: 0.0072, Train Linf Norm: 0.8993, Test Linf Norm: 0.7689
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0085, Test L1 Norm: 0.0070, Train Linf Norm: 0.9640, Test Linf Norm: 0.7060
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0066, Train Linf Norm: 0.8403, Test Linf Norm: 0.6534
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0068, Train Linf Norm: 0.9007, Test Linf Norm: 0.6783
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0067, Train Linf Norm: 0.8535, Test Linf Norm: 0.6862
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0067, Train Linf Norm: 0.9232, Test Linf Norm: 0.6735
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0066, Train Linf Norm: 0.8952, Test Linf Norm: 0.6676
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0065, Train Linf Norm: 0.8313, Test Linf Norm: 0.6497
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0080, Test L1 Norm: 0.0064, Train Linf Norm: 0.9123, Test Linf Norm: 0.6283
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0081, Test L1 Norm: 0.0062, Train Linf Norm: 0.9195, Test Linf Norm: 0.5867
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0064, Train Linf Norm: 0.8379, Test Linf Norm: 0.6322
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0063, Train Linf Norm: 0.8797, Test Linf Norm: 0.6226
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0065, Train Linf Norm: 0.8532, Test Linf Norm: 0.6541
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0064, Train Linf Norm: 0.9041, Test Linf Norm: 0.6358
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0065, Train Linf Norm: 0.8926, Test Linf Norm: 0.6492
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0065, Train Linf Norm: 0.9142, Test Linf Norm: 0.6422
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0064, Train Linf Norm: 0.8398, Test Linf Norm: 0.6356
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0063, Train Linf Norm: 0.8617, Test Linf Norm: 0.6201
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8645, Test Linf Norm: 0.6345
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8724, Test Linf Norm: 0.6260
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0064, Train Linf Norm: 0.9102, Test Linf Norm: 0.6353
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8984, Test Linf Norm: 0.6417
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8927, Test Linf Norm: 0.6317
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8964, Test Linf Norm: 0.6220
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0065, Train Linf Norm: 0.8615, Test Linf Norm: 0.6487
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0079, Test L1 Norm: 0.0065, Train Linf Norm: 0.9138, Test Linf Norm: 0.6445
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0063, Train Linf Norm: 0.8832, Test Linf Norm: 0.6239
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0063, Train Linf Norm: 0.8909, Test Linf Norm: 0.6208
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8719, Test Linf Norm: 0.6340
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0077, Test L1 Norm: 0.0064, Train Linf Norm: 0.8829, Test Linf Norm: 0.6342
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8863, Test Linf Norm: 0.6391
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0063, Train Linf Norm: 0.8869, Test Linf Norm: 0.6267
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0064, Train Linf Norm: 0.8779, Test Linf Norm: 0.6350
# [I 2023-05-13 08:55:00,777] Trial 3 finished with value: 0.006290217362344265 and parameters: {'n_layers': 3, 'n_units_0': 78, 'n_units_1': 226, 'n_units_2': 227, 'hidden_activation': 'ReLU', 'output_activation': 'ReLU', 'loss': 'Huber', 'optimizer': 'RMSprop', 'lr': 0.0015499457937344077, 'batch_size': 236, 'n_epochs': 75, 'scheduler': 'ExponentialLR'}. Best is trial 3 with value: 0.006290217362344265.
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0078, Test L1 Norm: 0.0063, Train Linf Norm: 0.8986, Test Linf Norm: 0.6164
# Epoch 1: Train Loss: 0.1574, Test Loss: 0.0299, Train L1 Norm: 1.3948, Test L1 Norm: 0.2347, Train Linf Norm: 87.2956, Test Linf Norm: 9.2978
# Epoch 2: Train Loss: 0.0192, Test Loss: 0.2517, Train L1 Norm: 0.6167, Test L1 Norm: 0.7080, Train Linf Norm: 41.4028, Test Linf Norm: 34.0734
# Epoch 3: Train Loss: 0.0126, Test Loss: 0.0047, Train L1 Norm: 0.4178, Test L1 Norm: 0.1794, Train Linf Norm: 25.0783, Test Linf Norm: 9.7736
# Epoch 4: Train Loss: 0.0104, Test Loss: 0.0176, Train L1 Norm: 0.4135, Test L1 Norm: 0.2933, Train Linf Norm: 25.7828, Test Linf Norm: 16.0394
# Epoch 5: Train Loss: 0.0089, Test Loss: 0.0025, Train L1 Norm: 0.3812, Test L1 Norm: 0.1419, Train Linf Norm: 24.3184, Test Linf Norm: 7.8859
# Epoch 6: Train Loss: 0.0080, Test Loss: 0.0019, Train L1 Norm: 0.3518, Test L1 Norm: 0.1115, Train Linf Norm: 22.5836, Test Linf Norm: 5.9359
# Epoch 7: Train Loss: 0.0070, Test Loss: 0.0047, Train L1 Norm: 0.3684, Test L1 Norm: 0.1270, Train Linf Norm: 24.9071, Test Linf Norm: 6.4764
# Epoch 8: Train Loss: 0.0064, Test Loss: 0.0024, Train L1 Norm: 0.2897, Test L1 Norm: 0.3467, Train Linf Norm: 17.4257, Test Linf Norm: 21.5224
# Epoch 9: Train Loss: 0.0060, Test Loss: 0.0029, Train L1 Norm: 0.2830, Test L1 Norm: 0.1807, Train Linf Norm: 18.1666, Test Linf Norm: 10.7238
# Epoch 10: Train Loss: 0.0055, Test Loss: 0.0107, Train L1 Norm: 0.2637, Test L1 Norm: 0.2746, Train Linf Norm: 16.7391, Test Linf Norm: 16.3465
# Epoch 11: Train Loss: 0.0007, Test Loss: 0.0014, Train L1 Norm: 0.1371, Test L1 Norm: 0.1791, Train Linf Norm: 8.7437, Test Linf Norm: 11.0768
# Epoch 12: Train Loss: 0.0006, Test Loss: 0.0006, Train L1 Norm: 0.1414, Test L1 Norm: 0.1177, Train Linf Norm: 9.1732, Test Linf Norm: 7.2930
# Epoch 13: Train Loss: 0.0005, Test Loss: 0.0005, Train L1 Norm: 0.1427, Test L1 Norm: 0.1213, Train Linf Norm: 9.1502, Test Linf Norm: 7.6625
# Epoch 14: Train Loss: 0.0004, Test Loss: 0.0005, Train L1 Norm: 0.1415, Test L1 Norm: 0.0760, Train Linf Norm: 9.3123, Test Linf Norm: 4.1340
# Epoch 15: Train Loss: 0.0004, Test Loss: 0.0005, Train L1 Norm: 0.1368, Test L1 Norm: 0.1028, Train Linf Norm: 8.8498, Test Linf Norm: 6.4041
# Epoch 16: Train Loss: 0.0004, Test Loss: 0.0003, Train L1 Norm: 0.1330, Test L1 Norm: 0.0598, Train Linf Norm: 8.8471, Test Linf Norm: 3.1139
# Epoch 17: Train Loss: 0.0003, Test Loss: 0.0004, Train L1 Norm: 0.1354, Test L1 Norm: 0.1519, Train Linf Norm: 9.1194, Test Linf Norm: 10.2061
# Epoch 18: Train Loss: 0.0003, Test Loss: 0.0003, Train L1 Norm: 0.1310, Test L1 Norm: 0.0694, Train Linf Norm: 8.7606, Test Linf Norm: 3.9437
# Epoch 19: Train Loss: 0.0003, Test Loss: 0.0002, Train L1 Norm: 0.1258, Test L1 Norm: 0.0910, Train Linf Norm: 8.2841, Test Linf Norm: 5.7364
# Epoch 20: Train Loss: 0.0003, Test Loss: 0.0002, Train L1 Norm: 0.1246, Test L1 Norm: 0.0770, Train Linf Norm: 8.3312, Test Linf Norm: 4.6836
# Epoch 21: Train Loss: 0.0002, Test Loss: 0.0003, Train L1 Norm: 0.1167, Test L1 Norm: 0.0907, Train Linf Norm: 7.7739, Test Linf Norm: 5.7119
# Epoch 22: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1165, Test L1 Norm: 0.0780, Train Linf Norm: 7.7171, Test Linf Norm: 4.7787
# Epoch 23: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1156, Test L1 Norm: 0.0767, Train Linf Norm: 7.6310, Test Linf Norm: 4.6786
# Epoch 24: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1160, Test L1 Norm: 0.0805, Train Linf Norm: 7.7389, Test Linf Norm: 4.9857
# Epoch 25: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1170, Test L1 Norm: 0.0765, Train Linf Norm: 7.8829, Test Linf Norm: 4.6716
# Epoch 26: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1159, Test L1 Norm: 0.0810, Train Linf Norm: 7.7854, Test Linf Norm: 5.0364
# Epoch 27: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1139, Test L1 Norm: 0.0794, Train Linf Norm: 7.6648, Test Linf Norm: 4.9199
# Epoch 28: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1138, Test L1 Norm: 0.0798, Train Linf Norm: 7.6507, Test Linf Norm: 4.9592
# Epoch 29: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1128, Test L1 Norm: 0.0845, Train Linf Norm: 7.5881, Test Linf Norm: 5.3279
# Epoch 30: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1138, Test L1 Norm: 0.0906, Train Linf Norm: 7.7291, Test Linf Norm: 5.7590
# Epoch 31: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1126, Test L1 Norm: 0.0805, Train Linf Norm: 7.6842, Test Linf Norm: 5.0140
# Epoch 32: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1122, Test L1 Norm: 0.0798, Train Linf Norm: 7.6232, Test Linf Norm: 4.9626
# Epoch 33: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1124, Test L1 Norm: 0.0806, Train Linf Norm: 7.5539, Test Linf Norm: 5.0276
# Epoch 34: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1126, Test L1 Norm: 0.0807, Train Linf Norm: 7.6045, Test Linf Norm: 5.0331
# Epoch 35: Train Loss: 0.0002, Test Loss: 0.0002, Train L1 Norm: 0.1124, Test L1 Norm: 0.0811, Train Linf Norm: 7.5762, Test Linf Norm: 5.0664
# ...
# Epoch 24: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0096, Test L1 Norm: 0.0074, Train Linf Norm: 0.5517, Test Linf Norm: 0.4228
# Epoch 25: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0107, Test L1 Norm: 0.0069, Train Linf Norm: 0.6688, Test Linf Norm: 0.3781
# Epoch 26: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0102, Test L1 Norm: 0.0079, Train Linf Norm: 0.6443, Test Linf Norm: 0.3819
# Epoch 27: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0097, Test L1 Norm: 0.0079, Train Linf Norm: 0.6016, Test Linf Norm: 0.4785
# Epoch 28: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0083, Test L1 Norm: 0.0102, Train Linf Norm: 0.4859, Test Linf Norm: 0.6335
# Epoch 29: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0084, Test L1 Norm: 0.0087, Train Linf Norm: 0.4891, Test Linf Norm: 0.5307
# Epoch 30: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0088, Test L1 Norm: 0.0076, Train Linf Norm: 0.5498, Test Linf Norm: 0.4615
# Epoch 31: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0074, Test L1 Norm: 0.0063, Train Linf Norm: 0.4211, Test Linf Norm: 0.3555
# Epoch 32: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0072, Test L1 Norm: 0.0071, Train Linf Norm: 0.4276, Test Linf Norm: 0.4126
# Epoch 33: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0073, Test L1 Norm: 0.0074, Train Linf Norm: 0.4285, Test Linf Norm: 0.4194
# Epoch 34: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0071, Test L1 Norm: 0.0065, Train Linf Norm: 0.4196, Test Linf Norm: 0.3742
# Epoch 35: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0064, Train Linf Norm: 0.3982, Test Linf Norm: 0.3688
# Epoch 36: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0069, Test L1 Norm: 0.0070, Train Linf Norm: 0.4113, Test Linf Norm: 0.3856
# Epoch 37: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0068, Test L1 Norm: 0.0061, Train Linf Norm: 0.3989, Test Linf Norm: 0.3541
# Epoch 38: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0065, Test L1 Norm: 0.0059, Train Linf Norm: 0.3813, Test Linf Norm: 0.3376
# Epoch 39: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0075, Train Linf Norm: 0.3645, Test Linf Norm: 0.4559
# Epoch 40: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0060, Test L1 Norm: 0.0065, Train Linf Norm: 0.3498, Test Linf Norm: 0.3283
# Epoch 41: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0064, Test L1 Norm: 0.0055, Train Linf Norm: 0.3843, Test Linf Norm: 0.3109
# Epoch 42: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0060, Test L1 Norm: 0.0057, Train Linf Norm: 0.3400, Test Linf Norm: 0.3056
# Epoch 43: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0063, Test L1 Norm: 0.0059, Train Linf Norm: 0.3710, Test Linf Norm: 0.3486
# Epoch 44: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0058, Test L1 Norm: 0.0054, Train Linf Norm: 0.3325, Test Linf Norm: 0.3088
# Epoch 45: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0062, Train Linf Norm: 0.3252, Test Linf Norm: 0.3527
# Epoch 46: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0059, Train Linf Norm: 0.3463, Test Linf Norm: 0.3445
# Epoch 47: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0057, Train Linf Norm: 0.3221, Test Linf Norm: 0.3336
# Epoch 48: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0061, Test L1 Norm: 0.0060, Train Linf Norm: 0.3647, Test Linf Norm: 0.3513
# Epoch 49: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0057, Train Linf Norm: 0.3192, Test Linf Norm: 0.3288
# Epoch 50: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0054, Train Linf Norm: 0.3521, Test Linf Norm: 0.3060
# Epoch 51: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0059, Test L1 Norm: 0.0052, Train Linf Norm: 0.3430, Test Linf Norm: 0.2835
# Epoch 52: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0053, Train Linf Norm: 0.3287, Test Linf Norm: 0.2952
# Epoch 53: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0052, Train Linf Norm: 0.3333, Test Linf Norm: 0.2918
# Epoch 54: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0052, Train Linf Norm: 0.3176, Test Linf Norm: 0.2931
# Epoch 55: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0051, Train Linf Norm: 0.3300, Test Linf Norm: 0.2864
# Epoch 56: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0051, Train Linf Norm: 0.3092, Test Linf Norm: 0.2825
# Epoch 57: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0057, Test L1 Norm: 0.0050, Train Linf Norm: 0.3345, Test Linf Norm: 0.2803
# Epoch 58: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0050, Train Linf Norm: 0.3265, Test Linf Norm: 0.2783
# Epoch 59: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0052, Train Linf Norm: 0.3222, Test Linf Norm: 0.2914
# Epoch 60: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0052, Train Linf Norm: 0.3269, Test Linf Norm: 0.2957
# Epoch 61: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0051, Train Linf Norm: 0.3241, Test Linf Norm: 0.2810
# Epoch 62: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0052, Train Linf Norm: 0.3201, Test Linf Norm: 0.2943
# Epoch 63: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0051, Train Linf Norm: 0.3168, Test Linf Norm: 0.2823
# Epoch 64: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0053, Train Linf Norm: 0.3258, Test Linf Norm: 0.2988
# Epoch 65: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0051, Train Linf Norm: 0.3240, Test Linf Norm: 0.2884
# Epoch 66: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0051, Train Linf Norm: 0.3168, Test Linf Norm: 0.2857
# Epoch 67: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0052, Train Linf Norm: 0.3210, Test Linf Norm: 0.2916
# Epoch 68: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0051, Train Linf Norm: 0.3116, Test Linf Norm: 0.2870
# Epoch 69: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0051, Train Linf Norm: 0.3091, Test Linf Norm: 0.2838
# Epoch 70: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0052, Train Linf Norm: 0.3235, Test Linf Norm: 0.2948
# Epoch 71: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0051, Train Linf Norm: 0.3127, Test Linf Norm: 0.2891
# Epoch 72: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0050, Train Linf Norm: 0.3211, Test Linf Norm: 0.2821
# Epoch 73: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0055, Test L1 Norm: 0.0051, Train Linf Norm: 0.3224, Test Linf Norm: 0.2898
# Epoch 74: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0056, Test L1 Norm: 0.0051, Train Linf Norm: 0.3277, Test Linf Norm: 0.2901
# [I 2023-05-13 09:46:08,618] Trial 28 finished with value: 0.005086912204336841 and parameters: {'n_layers': 3, 'n_units_0': 69, 'n_units_1': 232, 'n_units_2': 96, 'hidden_activation': 'ReLU', 'output_activation': 'Linear', 'loss': 'Huber', 'optimizer': 'Adam', 'lr': 0.0009955346312080897, 'batch_size': 90, 'n_epochs': 75, 'scheduler': 'ExponentialLR'}. Best is trial 13 with value: 0.004641101454215823.
# Epoch 75: Train Loss: 0.0000, Test Loss: 0.0000, Train L1 Norm: 0.0054, Test L1 Norm: 0.0051, Train Linf Norm: 0.3119, Test Linf Norm: 0.2850
# Epoch 1: Train Loss: 0.0830, Test Loss: 0.0346, Train L1 Norm: 0.2101, Test L1 Norm: 0.0539, Train Linf Norm: 11.6127, Test Linf Norm: 2.2389
# Epoch 2: Train Loss: 0.0273, Test Loss: 0.0114, Train L1 Norm: 0.0633, Test L1 Norm: 0.0373, Train Linf Norm: 3.3983, Test Linf Norm: 1.9686
# Epoch 3: Train Loss: 0.0214, Test Loss: 0.0190, Train L1 Norm: 0.0567, Test L1 Norm: 0.0529, Train Linf Norm: 3.2675, Test Linf Norm: 2.6380
# Epoch 4: Train Loss: 0.0222, Test Loss: 0.0246, Train L1 Norm: 0.0464, Test L1 Norm: 0.0440, Train Linf Norm: 2.4904, Test Linf Norm: 2.0765
# Epoch 5: Train Loss: 0.0165, Test Loss: 0.0229, Train L1 Norm: 0.0392, Test L1 Norm: 0.0287, Train Linf Norm: 2.1493, Test Linf Norm: 1.1639
# Epoch 6: Train Loss: 0.0137, Test Loss: 0.0126, Train L1 Norm: 0.0301, Test L1 Norm: 0.0196, Train Linf Norm: 1.5929, Test Linf Norm: 0.9245
# Epoch 7: Train Loss: 0.0129, Test Loss: 0.0122, Train L1 Norm: 0.0252, Test L1 Norm: 0.0213, Train Linf Norm: 1.2561, Test Linf Norm: 1.0700
# Epoch 8: Train Loss: 0.0131, Test Loss: 0.0090, Train L1 Norm: 0.0244, Test L1 Norm: 0.0160, Train Linf Norm: 1.2264, Test Linf Norm: 0.7960
# Epoch 9: Train Loss: 0.0093, Test Loss: 0.0075, Train L1 Norm: 0.0235, Test L1 Norm: 0.0100, Train Linf Norm: 1.3270, Test Linf Norm: 0.3651
# Epoch 10: Train Loss: 0.0100, Test Loss: 0.0067, Train L1 Norm: 0.0232, Test L1 Norm: 0.0140, Train Linf Norm: 1.2939, Test Linf Norm: 0.7212
# Epoch 11: Train Loss: 0.0080, Test Loss: 0.0044, Train L1 Norm: 0.0195, Test L1 Norm: 0.0121, Train Linf Norm: 1.0843, Test Linf Norm: 0.6132
# Epoch 12: Train Loss: 0.0085, Test Loss: 0.0047, Train L1 Norm: 0.0191, Test L1 Norm: 0.0164, Train Linf Norm: 1.0315, Test Linf Norm: 0.8393
# Epoch 13: Train Loss: 0.0064, Test Loss: 0.0058, Train L1 Norm: 0.0155, Test L1 Norm: 0.0095, Train Linf Norm: 0.8483, Test Linf Norm: 0.3929
# Epoch 14: Train Loss: 0.0062, Test Loss: 0.0032, Train L1 Norm: 0.0155, Test L1 Norm: 0.0063, Train Linf Norm: 0.8721, Test Linf Norm: 0.2808
# Epoch 15: Train Loss: 0.0058, Test Loss: 0.0080, Train L1 Norm: 0.0127, Test L1 Norm: 0.0098, Train Linf Norm: 0.6627, Test Linf Norm: 0.4604
# Epoch 16: Train Loss: 0.0050, Test Loss: 0.0053, Train L1 Norm: 0.0126, Test L1 Norm: 0.0057, Train Linf Norm: 0.6861, Test Linf Norm: 0.2141
# Epoch 17: Train Loss: 0.0048, Test Loss: 0.0036, Train L1 Norm: 0.0102, Test L1 Norm: 0.0058, Train Linf Norm: 0.5189, Test Linf Norm: 0.2221
# Epoch 18: Train Loss: 0.0043, Test Loss: 0.0033, Train L1 Norm: 0.0109, Test L1 Norm: 0.0059, Train Linf Norm: 0.5931, Test Linf Norm: 0.2739
# Epoch 19: Train Loss: 0.0041, Test Loss: 0.0032, Train L1 Norm: 0.0093, Test L1 Norm: 0.0061, Train Linf Norm: 0.4857, Test Linf Norm: 0.2815
# Epoch 20: Train Loss: 0.0038, Test Loss: 0.0033, Train L1 Norm: 0.0089, Test L1 Norm: 0.0068, Train Linf Norm: 0.4632, Test Linf Norm: 0.3393
# Epoch 21: Train Loss: 0.0039, Test Loss: 0.0037, Train L1 Norm: 0.0082, Test L1 Norm: 0.0080, Train Linf Norm: 0.4147, Test Linf Norm: 0.4087
# Epoch 22: Train Loss: 0.0034, Test Loss: 0.0027, Train L1 Norm: 0.0085, Test L1 Norm: 0.0046, Train Linf Norm: 0.4572, Test Linf Norm: 0.2030
# Epoch 23: Train Loss: 0.0033, Test Loss: 0.0043, Train L1 Norm: 0.0082, Test L1 Norm: 0.0065, Train Linf Norm: 0.4422, Test Linf Norm: 0.2804
# Epoch 24: Train Loss: 0.0032, Test Loss: 0.0038, Train L1 Norm: 0.0076, Test L1 Norm: 0.0050, Train Linf Norm: 0.4020, Test Linf Norm: 0.2118
# Epoch 25: Train Loss: 0.0030, Test Loss: 0.0024, Train L1 Norm: 0.0067, Test L1 Norm: 0.0042, Train Linf Norm: 0.3428, Test Linf Norm: 0.1741
# Epoch 26: Train Loss: 0.0030, Test Loss: 0.0025, Train L1 Norm: 0.0073, Test L1 Norm: 0.0042, Train Linf Norm: 0.3931, Test Linf Norm: 0.1786
# Epoch 27: Train Loss: 0.0028, Test Loss: 0.0024, Train L1 Norm: 0.0073, Test L1 Norm: 0.0049, Train Linf Norm: 0.4052, Test Linf Norm: 0.2271
# Epoch 28: Train Loss: 0.0028, Test Loss: 0.0026, Train L1 Norm: 0.0068, Test L1 Norm: 0.0047, Train Linf Norm: 0.3570, Test Linf Norm: 0.2258
# Epoch 29: Train Loss: 0.0027, Test Loss: 0.0023, Train L1 Norm: 0.0070, Test L1 Norm: 0.0041, Train Linf Norm: 0.3839, Test Linf Norm: 0.1706
# Epoch 30: Train Loss: 0.0025, Test Loss: 0.0024, Train L1 Norm: 0.0063, Test L1 Norm: 0.0044, Train Linf Norm: 0.3306, Test Linf Norm: 0.2024
# Epoch 31: Train Loss: 0.0025, Test Loss: 0.0027, Train L1 Norm: 0.0067, Test L1 Norm: 0.0046, Train Linf Norm: 0.3601, Test Linf Norm: 0.2047
# Epoch 32: Train Loss: 0.0025, Test Loss: 0.0024, Train L1 Norm: 0.0063, Test L1 Norm: 0.0047, Train Linf Norm: 0.3367, Test Linf Norm: 0.2178
# Epoch 33: Train Loss: 0.0024, Test Loss: 0.0023, Train L1 Norm: 0.0060, Test L1 Norm: 0.0052, Train Linf Norm: 0.3234, Test Linf Norm: 0.2499
# Epoch 34: Train Loss: 0.0023, Test Loss: 0.0022, Train L1 Norm: 0.0058, Test L1 Norm: 0.0038, Train Linf Norm: 0.3028, Test Linf Norm: 0.1696
# Epoch 35: Train Loss: 0.0023, Test Loss: 0.0022, Train L1 Norm: 0.0057, Test L1 Norm: 0.0044, Train Linf Norm: 0.3003, Test Linf Norm: 0.2105
# Epoch 36: Train Loss: 0.0023, Test Loss: 0.0024, Train L1 Norm: 0.0054, Test L1 Norm: 0.0041, Train Linf Norm: 0.2806, Test Linf Norm: 0.1842
# Epoch 37: Train Loss: 0.0023, Test Loss: 0.0021, Train L1 Norm: 0.0053, Test L1 Norm: 0.0038, Train Linf Norm: 0.2733, Test Linf Norm: 0.1743
# Epoch 38: Train Loss: 0.0022, Test Loss: 0.0025, Train L1 Norm: 0.0056, Test L1 Norm: 0.0037, Train Linf Norm: 0.2965, Test Linf Norm: 0.1473
# Epoch 39: Train Loss: 0.0022, Test Loss: 0.0021, Train L1 Norm: 0.0053, Test L1 Norm: 0.0038, Train Linf Norm: 0.2675, Test Linf Norm: 0.1702
# Epoch 40: Train Loss: 0.0022, Test Loss: 0.0021, Train L1 Norm: 0.0052, Test L1 Norm: 0.0038, Train Linf Norm: 0.2589, Test Linf Norm: 0.1690
# Epoch 41: Train Loss: 0.0022, Test Loss: 0.0021, Train L1 Norm: 0.0054, Test L1 Norm: 0.0036, Train Linf Norm: 0.2924, Test Linf Norm: 0.1587
# Epoch 42: Train Loss: 0.0021, Test Loss: 0.0021, Train L1 Norm: 0.0050, Test L1 Norm: 0.0036, Train Linf Norm: 0.2573, Test Linf Norm: 0.1590
# Epoch 43: Train Loss: 0.0021, Test Loss: 0.0021, Train L1 Norm: 0.0051, Test L1 Norm: 0.0038, Train Linf Norm: 0.2611, Test Linf Norm: 0.1737
# Epoch 44: Train Loss: 0.0021, Test Loss: 0.0022, Train L1 Norm: 0.0050, Test L1 Norm: 0.0038, Train Linf Norm: 0.2602, Test Linf Norm: 0.1716
# Epoch 45: Train Loss: 0.0021, Test Loss: 0.0023, Train L1 Norm: 0.0050, Test L1 Norm: 0.0034, Train Linf Norm: 0.2574, Test Linf Norm: 0.1415
# Epoch 46: Train Loss: 0.0021, Test Loss: 0.0023, Train L1 Norm: 0.0049, Test L1 Norm: 0.0043, Train Linf Norm: 0.2520, Test Linf Norm: 0.2024
# Epoch 47: Train Loss: 0.0021, Test Loss: 0.0021, Train L1 Norm: 0.0050, Test L1 Norm: 0.0037, Train Linf Norm: 0.2602, Test Linf Norm: 0.1645
# Epoch 48: Train Loss: 0.0020, Test Loss: 0.0021, Train L1 Norm: 0.0048, Test L1 Norm: 0.0035, Train Linf Norm: 0.2461, Test Linf Norm: 0.1543
# Epoch 49: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0048, Test L1 Norm: 0.0035, Train Linf Norm: 0.2459, Test Linf Norm: 0.1555
# Epoch 50: Train Loss: 0.0020, Test Loss: 0.0021, Train L1 Norm: 0.0048, Test L1 Norm: 0.0041, Train Linf Norm: 0.2500, Test Linf Norm: 0.1919
# Epoch 51: Train Loss: 0.0020, Test Loss: 0.0021, Train L1 Norm: 0.0045, Test L1 Norm: 0.0037, Train Linf Norm: 0.2260, Test Linf Norm: 0.1681
# Epoch 52: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0048, Test L1 Norm: 0.0036, Train Linf Norm: 0.2475, Test Linf Norm: 0.1600
# Epoch 53: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0048, Test L1 Norm: 0.0035, Train Linf Norm: 0.2533, Test Linf Norm: 0.1536
# Epoch 54: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0048, Test L1 Norm: 0.0036, Train Linf Norm: 0.2417, Test Linf Norm: 0.1646
# Epoch 55: Train Loss: 0.0020, Test Loss: 0.0022, Train L1 Norm: 0.0048, Test L1 Norm: 0.0034, Train Linf Norm: 0.2477, Test Linf Norm: 0.1428
# Epoch 56: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0048, Test L1 Norm: 0.0037, Train Linf Norm: 0.2466, Test Linf Norm: 0.1655
# Epoch 57: Train Loss: 0.0020, Test Loss: 0.0020, Train L1 Norm: 0.0046, Test L1 Norm: 0.0034, Train Linf Norm: 0.2379, Test Linf Norm: 0.1481

# %% [markdown]
# ## Training the model

# %%
# Creating the best network and optimizer using the best hyperparameters
if OPTIMIZE:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial, optimize=True)
# Creating the network with predefined hyperparameters
else:
    net, \
    loss_fn, \
    optimizer, \
    batch_size, \
    n_epochs, \
    scheduler, \
    loss_name, \
    optimizer_name, \
    scheduler_name, \
    n_units, \
    n_layers, \
    hidden_activation, \
    output_activation, \
    lr = create_model(trial=None, optimize=False)

# %%
print("loss_fn:", loss_fn)
print("batch_size:", batch_size)
print("n_epochs:", n_epochs)
print("scheduler:", scheduler)
print("loss_name:", loss_name)
print("optimizer_name:", optimizer_name)
print("scheduler_name:", scheduler_name)
print("n_units:", n_units)
print("n_layers:", n_layers)
print("hidden_activation:", hidden_activation)
print("output_activation:", output_activation)

# %%
# Training and evaluating the network using the train_and_eval function
train_losses, test_losses, train_metrics, test_metrics = train_and_eval(
    net, loss_fn, optimizer, batch_size, n_epochs, scheduler
)

# %% [markdown]
# ## Visualizing the results

# %%
# Plotting the losses and metrics for the best network 
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.subplot(2, 2, 2)
plt.plot([m["l1_norm"] for m in train_metrics], label="Train L1 Norm")
plt.plot([m["l1_norm"] for m in test_metrics], label="Test L1 Norm")
plt.xlabel("Epoch")
plt.ylabel("L1 Norm")
plt.legend()
plt.subplot(2, 2, 3)
plt.plot([m["linf_norm"] for m in train_metrics], label="Train Linf Norm")
plt.plot([m["linf_norm"] for m in test_metrics], label="Test Linf Norm")
plt.xlabel("Epoch")
plt.ylabel("Linf Norm")
plt.legend()
plt.tight_layout()
plt.show()

# Added plotting MSE of training data and MSE of test data in one plot 
plt.figure(figsize=(8, 6))
plt.plot(train_losses,label="training data")
plt.plot(test_losses,label="test data")
#if scheduler is not None:
#    plt.plot([scheduler.get_last_lr()[0] for _ in range(n_epochs)], label="Learning rate") 
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.legend()
plt.show()

# %% [markdown]
# ## Saving

# %%
import json
import pandas as pd

# save the network to a .pth file
torch.save(net.state_dict(), "net.pth")

# save the optimizer to a .pth file
torch.save(optimizer.state_dict(), "optimizer.pth")

# save the scheduler to a .pth file if it is not None
if scheduler is not None:
  torch.save(scheduler.state_dict(), "scheduler.pth")

# create a dictionary to store the rest of the variables
var_dict = {
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "loss_name": loss_name,
  "optimizer_name": optimizer_name,
  "scheduler_name": scheduler_name,
  "n_units": n_units,
  "n_layers": n_layers,
  "hidden_activation_name": hidden_activation.__class__.__name__,
  "output_activation_name": output_activation.__class__.__name__,
  "lr": lr,
}

# save the dictionary to a .json file
with open("var_dict.json", "w") as f:
  json.dump(var_dict, f)

# Saving the output of the training using pandas
train_df = pd.DataFrame(
    {
        "train_loss": train_losses,
        "test_loss": test_losses,
        "train_l1_norm": [m["l1_norm"] for m in train_metrics],
        "test_l1_norm": [m["l1_norm"] for m in test_metrics],
        "train_linf_norm": [m["linf_norm"] for m in train_metrics],
        "test_linf_norm": [m["linf_norm"] for m in test_metrics],
    }
)
train_df.to_csv("train_output.csv", index=False)

# %% [markdown]
# ## Loading

# %%
import json
import pandas as pd

# load the dictionary from the .json file
with open("var_dict.json", "r") as f:
  var_dict_loaded = json.load(f)

# extract the variables from the dictionary
batch_size_loaded = var_dict_loaded["batch_size"]
n_epochs_loaded = var_dict_loaded["n_epochs"]
loss_name_loaded = var_dict_loaded["loss_name"]
optimizer_name_loaded = var_dict_loaded["optimizer_name"]
scheduler_name_loaded = var_dict_loaded["scheduler_name"]
n_units_loaded = var_dict_loaded["n_units"]
n_layers_loaded = var_dict_loaded["n_layers"]
hidden_activation_name_loaded = var_dict_loaded["hidden_activation_name"]
output_activation_name_loaded = var_dict_loaded["output_activation_name"]
lr_loaded = var_dict_loaded["lr"]

# create the activation functions from their names
if hidden_activation_name_loaded == "ReLU":
  hidden_activation_loaded = nn.ReLU()
elif hidden_activation_name_loaded == "LeakyReLU":
  hidden_activation_loaded = nn.LeakyReLU() 
elif hidden_activation_name_loaded == "ELU":
  hidden_activation_loaded = nn.ELU() 
elif hidden_activation_name_loaded == "Tanh":
  hidden_activation_loaded = nn.Tanh()
else:
  hidden_activation_loaded = nn.Sigmoid()

if output_activation_name_loaded == "ReLU":
  output_activation_loaded = nn.ReLU()
else:
  output_activation_loaded = nn.Identity()

# load the network from the .pth file
net_loaded = Net(n_layers_loaded, n_units_loaded, hidden_activation_loaded, output_activation_loaded).to(device)
net_loaded.load_state_dict(torch.load("net.pth"))

# create the loss function from its name
if loss_name_loaded == "MSE":
  loss_fn_loaded = nn.MSELoss()
elif loss_name_loaded == "MAE":
  loss_fn_loaded = nn.L1Loss()
elif loss_name_loaded == "Huber":
  loss_fn_loaded = nn.SmoothL1Loss() 
else:
  # create the log-cosh loss function
  def log_cosh_loss_loaded(y_pred, y_true):
    return torch.mean(torch.log(torch.cosh(y_pred - y_true)))
  loss_fn_loaded = log_cosh_loss_loaded

# load the optimizer from the .pth file
if optimizer_name_loaded == "SGD":
  optimizer_loaded = optim.SGD(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "Adam":
  optimizer_loaded = optim.Adam(net_loaded.parameters(), lr=lr_loaded)
elif optimizer_name_loaded == "RMSprop":
  optimizer_loaded = optim.RMSprop(net_loaded.parameters(), lr=lr_loaded)
else:
  # Added loading the Adagrad optimizer
  optimizer_loaded = optim.Adagrad(net_loaded.parameters(), lr=lr_loaded)
optimizer_loaded.load_state_dict(torch.load("optimizer.pth"))

if scheduler_name_loaded == "StepLR":
  scheduler_loaded = optim.lr_scheduler.StepLR(optimizer_loaded, step_size=10, gamma=0.1)
elif scheduler_name_loaded == "ExponentialLR":
  scheduler_loaded = optim.lr_scheduler.ExponentialLR(optimizer_loaded, gamma=0.9)
elif scheduler_name_loaded == "CosineAnnealingLR":
  scheduler_loaded = optim.lr_scheduler.CosineAnnealingLR(optimizer_loaded, T_max=10)
elif scheduler_name_loaded == "ReduceLROnPlateau":
  scheduler_loaded = optim.lr_scheduler.ReduceLROnPlateau(
                    optimizer_loaded, mode="min", factor=0.5, patience=5, threshold=0.0005, min_lr=1e-6
                )
else:
  scheduler_loaded = None

if scheduler_loaded is not None:
  scheduler_loaded.load_state_dict(torch.load("scheduler.pth"))
            

# Loading the output of the training using pandas
train_df_loaded = pd.read_csv("train_output.csv")
train_losses_loaded = train_df_loaded["train_loss"].tolist()
test_losses_loaded = train_df_loaded["test_loss"].tolist()
train_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["train_l1_norm"][i],
        "linf_norm": train_df_loaded["train_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]
test_metrics_loaded = [
    {
        "l1_norm": train_df_loaded["test_l1_norm"][i],
        "linf_norm": train_df_loaded["test_linf_norm"][i],
    }
    for i in range(len(train_df_loaded))
]

# %%
batch_size_loaded
n_epochs_loaded
loss_name_loaded
optimizer_name_loaded
scheduler_name_loaded
n_units_loaded
n_layers_loaded
hidden_activation_name_loaded
output_activation_name_loaded
lr_loaded
hidden_activation_loaded
output_activation_loaded
net_loaded
loss_fn_loaded
optimizer_loaded
scheduler_loaded
#train_losses_loaded
#test_losses_loaded
#train_metrics_loaded
#test_metrics_loaded

# %% [markdown]
# ## Evaluating the network on arbirary input
# ### Comparing `net` and `net_loaded`
#
# We compare `net` and `net_loaded` to confirm correct loading of the network.

# %%
print(list(net.parameters()))

# %%
print(list(net_loaded.parameters()))

# %%
# Set the network to evaluation mode
net.eval()

# %%
rho_example, vx_example, epsilon_example = sample_primitive_variables(20)

# Create arbitrary input
inputs =  generate_input_data(rho_example, vx_example, epsilon_example)
inputs

# %%
# Pass the inputs to the network and get the outputs
outputs = [net(input) for input in inputs]
# Print the outputs
outputs

# %%
# Set the network to evaluation mode
net_loaded.eval()
# Pass the inputs to the network and get the outputs
outputs = [net_loaded(input) for input in inputs]
# Print the outputs
outputs

# %% [markdown]
# ## Porting the model to C++

# %%
import torch.jit

# Creating a dummy input tensor of shape (1, 3) to trace the model
dummy_input = torch.randn(1, 3).to(device)
dummy_input

# Tracing the model using the torch.jit.trace function
traced_model = torch.jit.trace(net_loaded, dummy_input)

# Saving the traced model to a file named "net.pt"
traced_model.save("cpp/build/net.pt")

example_input_to_validate_correct_export_and_import = generate_input_data(*sample_primitive_variables(1))
example_input_to_validate_correct_export_and_import
net_loaded(example_input_to_validate_correct_export_and_import)
